# %%
from adeft import available_shortforms
from adeft.disambiguate import load_disambiguator
from adeft_indra.s3 import model_to_s3

# %%
disambiguators = {shortform: load_disambiguator(shortform) for shortform in available_shortforms}

# %%
grounding_dicts = {shortform: disambiguator.grounding_dict for shortform, disambiguator in disambiguators.items()}

# %%
grounding_dicts
# Out:
# {'PC': {'PC': {'phosphatidylcholine': 'CHEBI:CHEBI:64482',
#    'cancer': 'ungrounded',
#    'cells': 'ungrounded',
#    'protein c': 'HGNC:9451',
#    'preconditioning': 'ungrounded',
#    'pyruvate carboxylase': 'HGNC:8636',
#    'phosphocholine': 'ungrounded',
#    'phosphorylcholine': 'ungrounded',
#    'protein carbonyl': 'MESH:D050050',
#    'es li': 'ungrounded',
#    'principal component': 'ungrounded',
#    'peritoneal carcinomatosis': 'ungrounded',
#    'platelet concentrations': 'ungrounded',
#    'complex': 'ungrounded',
#    'phosphatidyl choline': 'CHEBI:CHEBI:64482',
#    'cortex': 'ungrounded',
#    'control': 'ungrounded',
#    'care': 'ungrounded',
#    'carcinoma': 'ungrounded',
#    'pericytes': 'ungrounded',
#    'phycocyanin': 'ungrounded',
#    'portland cement': 'ungrounded',
#    'polycarbonate': 'ungrounded',
#    'plastocyanin': 'ungrounded',
#    'pachyonychia congenita': 'ungrounded',
#    'phosphocitrate': 'ungrounded',
#    'protein content': 'ungrounded',
#    'phytochelatin': 'ungrounded',
#    'photonic crystal': 'ungrounded',
#    'of acrylonitrile butadiene styrene m30i abs polyjet photopolymer med610 med polycarbonate iso': 'ungrounded',
#    'polycomb': 'ungrounded',
#    'precore': 'ungrounded',
#    'adenocarcinoma': 'ungrounded',
#    'convertase': 'ungrounded',
#    '2': 'ungrounded',
#    'conditioning': 'ungrounded',
#    'lip': 'ungrounded',
#    'the primary cilium': 'ungrounded',
#    'primary cilia': 'ungrounded',
#    'periosteal circumference': 'ungrounded',
#    'procyanidin': 'ungrounded',
#    'group': 'ungrounded',
#    'phenolic compounds': 'ungrounded',
#    'platelet count': 'ungrounded',
#    'palmitoyl carnitine': 'ungrounded',
#    'phospholipids': 'ungrounded',
#    'phase contrast': 'ungrounded',
#    'p cresol': 'ungrounded',
#    'punicalagin': 'ungrounded',
#    'propylene carbonate': 'ungrounded'}},
#  'EMT': {'EMT': {'mesenchymal transition': 'MESH:D058750',
#    'mesenchymal transformation': 'MESH:D058750',
#    'epithelial to mesenchymal': 'MESH:D058750',
#    'mesenchymal transdifferentiation': 'MESH:D058750',
#    'phenotype': 'ungrounded',
#    'cells': 'ungrounded',
#    'mesenchymal transition ”': 'MESH:D058750',
#    'training': 'ungrounded',
#    'mesenchymal like': 'MESH:D058750'}},
#  'SP': {'SP': {'substance p': 'HGNC:11517',
#    'side population': 'ungrounded',
#    'single positive': 'ungrounded',
#    'peptide': 'ungrounded',
#    'surfactant protein': 'HGNC:10798',
#    'pyrimethamine': 'CHEBI:CHEBI:8673',
#    'seminal plasma': 'ungrounded',
#    'ssvenus ‐': 'ungrounded',
#    'sp600125': 'CHEBI:CHEBI:90695',
#    'serine protease': 'HGNC:9475',
#    'streptococcus pneumoniae': 'ungrounded',
#    'senile plaques': 'ungrounded',
#    '16 16': 'ungrounded',
#    'spironolactone': 'ungrounded',
#    'potential': 'ungrounded',
#    'silent period': 'ungrounded',
#    'spleen': 'ungrounded',
#    'short photoperiod': 'ungrounded',
#    'surface plasmon': 'ungrounded',
#    'sodium pyruvate': 'ungrounded',
#    'preference': 'ungrounded',
#    '”': 'ungrounded',
#    'subplate': 'ungrounded',
#    'pressure': 'ungrounded',
#    'cells': 'ungrounded',
#    'specific': 'ungrounded',
#    'sulfapyridine': 'ungrounded',
#    'spirulina platensis': 'ungrounded',
#    'serine proline': 'ungrounded',
#    'secondary progressive': 'ungrounded',
#    'polysaccharide': 'ungrounded',
#    'production': 'ungrounded',
#    'pulse': 'ungrounded'}},
#  'PE': {'PE': {'phenylephrine': 'CHEBI:CHEBI:8093',
#    'phosphatidylethanolamine': 'CHEBI:CHEBI:16038',
#    'pulmonary embolism': 'MESH:D011655',
#    'preeclampsia': 'MESH:D011225',
#    'extract': 'ungrounded',
#    'pre eclampsia': 'MESH:D011225',
#    'polyethylene': 'CHEBI:CHEBI:60034',
#    'phycoerythrin': 'MESH:D010799',
#    'plasma exchange': 'ungrounded',
#    'premature ejaculation': 'ungrounded',
#    'physical education': 'ungrounded',
#    'pseudomonas exotoxin a': 'ungrounded',
#    'prediction error': 'ungrounded',
#    'phosphoethanolamine': 'ungrounded',
#    'preeclamptic': 'ungrounded',
#    'prolonged exposure': 'ungrounded',
#    'pseudomonas exotoxin': 'ungrounded',
#    'exercise': 'ungrounded',
#    'endoderm': 'ungrounded',
#    'pulmonary edema': 'ungrounded',
#    'phosphatidyl ethanolamine': 'CHEBI:CHEBI:16038',
#    'the proepicardium': 'ungrounded',
#    'proximal enhancer': 'ungrounded',
#    'penile erection': 'ungrounded',
#    'positive emotionality': 'ungrounded',
#    'erythrocytes': 'ungrounded',
#    'pleural effusion': 'ungrounded',
#    'effects': 'ungrounded',
#    'epithelium': 'ungrounded',
#    'proenkephalin': 'HGNC:8831',
#    'phorbol ester': 'ungrounded',
#    'plasma extravasation': 'ungrounded',
#    'ethanol': 'ungrounded',
#    'phenylephrine hydrochloride': 'ungrounded',
#    'e': 'ungrounded',
#    'pomegranate emulsion': 'ungrounded',
#    'petroleum ether': 'ungrounded',
#    'prolyl endopeptidase': 'HGNC:9358',
#    'elastase': 'FPLX:ELA',
#    'peritoneal exudate': 'ungrounded',
#    'efficiency': 'ungrounded',
#    'phenoxyethanol': 'ungrounded',
#    'the population equivalent': 'ungrounded',
#    'phase encoding': 'ungrounded',
#    'pectinesterase': 'ungrounded',
#    'pulmonary emboli': 'MESH:D011655',
#    'pulmonary embolus': 'MESH:D011655',
#    'polyelectrolyte': 'ungrounded',
#    'psychoeducation': 'ungrounded',
#    'phosphotidylethanolamine': 'CHEBI:CHEBI:16038',
#    'psychotic experiences': 'ungrounded',
#    'phosphoesterase': 'ungrounded',
#    'participatory ergonomics': 'ungrounded',
#    'mice were exposed to pbs ct cont or pe ct': 'ungrounded',
#    'post eclosion': 'ungrounded'}},
#  'ROS': {'ROS': {'reactive oxygen species': 'MESH:D017382',
#    'rod outer segments': 'MESH:D012374',
#    'reactive oxygen': 'MESH:D017382',
#    'oxidative stress': 'MESH:D017382',
#    'radicals': 'MESH:D017382',
#    'oxidative': 'MESH:D017382',
#    'h 2 o 2': 'MESH:D017382',
#    'production': 'MESH:D017382',
#    'rosiglitazone': 'ungrounded',
#    'reactive oxygen species generation': 'MESH:D017382',
#    'reactive oxygen spices': 'MESH:D017382',
#    '“ reactive oxygen species ”': 'MESH:D017382'}},
#  'NP': {'NP': {'nanoparticle': 'MESH:D053758',
#    'nucleus pulposus': 'MESH:D000070614',
#    'nucleoprotein': 'MESH:D009698',
#    'nonylphenol': 'CHEBI:CHEBI:79516',
#    'neuropathic pain': 'MESH:D009437',
#    'natriuretic peptide': 'FPLX:Natriuretic_peptide',
#    'curcumin': 'ungrounded',
#    'nitroprusside': 'ungrounded',
#    'au': 'ungrounded',
#    'sam': 'ungrounded',
#    'nucleocapsid protein': 'MESH:D019590',
#    'nasopharyngeal': 'ungrounded',
#    'nasal polyps': 'ungrounded',
#    '4 hydroxy 3 nitrophenyl acetyl': 'ungrounded',
#    'neural progenitor': 'ungrounded',
#    'normal pregnant': 'ungrounded',
#    'nurse practitioner': 'ungrounded',
#    'negative priming': 'ungrounded',
#    '4 hydroxy 3 nitrophenylacetyl': 'ungrounded',
#    'np': 'ungrounded',
#    'nasal polyposis': 'ungrounded',
#    '”': 'ungrounded',
#    'neuritic plaque': 'ungrounded',
#    'nosocomial pneumonia': 'ungrounded',
#    'neuropoietin': 'HGNC:33173',
#    'nps': 'ungrounded',
#    'neural plate': 'ungrounded',
#    'm': 'ungrounded',
#    'nitrophenol': 'ungrounded',
#    'neuropsychological': 'ungrounded',
#    'non preferring': 'ungrounded',
#    'nausea only': 'ungrounded',
#    'zno': 'ungrounded',
#    'neuropsychiatric': 'ungrounded',
#    'natural production': 'ungrounded',
#    'nitrophenyl': 'ungrounded',
#    'neural precursor': 'ungrounded',
#    'non pathogenic': 'ungrounded',
#    'particles': 'MESH:D053758',
#    'viral antigen': 'ungrounded',
#    'nonpreferring': 'ungrounded',
#    'c': 'ungrounded'},
#   'NPs': {'nanoparticles': 'MESH:D053758',
#    'natriuretic peptides': 'FPLX:Natriuretic_peptide',
#    'au': 'ungrounded',
#    'neural progenitors': 'ungrounded',
#    'nurse practitioners': 'ungrounded',
#    'natural products': 'ungrounded',
#    'particles': 'MESH:D053758',
#    'ag': 'ungrounded',
#    'neural precursors': 'ungrounded',
#    'nasal polyps': 'ungrounded',
#    'neuropeptides': 'ungrounded',
#    'nitrophorins': 'ungrounded',
#    'neuritic plaques': 'ungrounded',
#    'nanoparticulates': 'MESH:D053758',
#    'nucleoproteins': 'MESH:D009698',
#    'neuroprogenitors': 'ungrounded',
#    'nanopillars': 'ungrounded'}},
#  'NPs': {'NP': {'nanoparticle': 'MESH:D053758',
#    'nucleus pulposus': 'MESH:D000070614',
#    'nucleoprotein': 'MESH:D009698',
#    'nonylphenol': 'CHEBI:CHEBI:79516',
#    'neuropathic pain': 'MESH:D009437',
#    'natriuretic peptide': 'FPLX:Natriuretic_peptide',
#    'curcumin': 'ungrounded',
#    'nitroprusside': 'ungrounded',
#    'au': 'ungrounded',
#    'sam': 'ungrounded',
#    'nucleocapsid protein': 'MESH:D019590',
#    'nasopharyngeal': 'ungrounded',
#    'nasal polyps': 'ungrounded',
#    '4 hydroxy 3 nitrophenyl acetyl': 'ungrounded',
#    'neural progenitor': 'ungrounded',
#    'normal pregnant': 'ungrounded',
#    'nurse practitioner': 'ungrounded',
#    'negative priming': 'ungrounded',
#    '4 hydroxy 3 nitrophenylacetyl': 'ungrounded',
#    'np': 'ungrounded',
#    'nasal polyposis': 'ungrounded',
#    '”': 'ungrounded',
#    'neuritic plaque': 'ungrounded',
#    'nosocomial pneumonia': 'ungrounded',
#    'neuropoietin': 'HGNC:33173',
#    'nps': 'ungrounded',
#    'neural plate': 'ungrounded',
#    'm': 'ungrounded',
#    'nitrophenol': 'ungrounded',
#    'neuropsychological': 'ungrounded',
#    'non preferring': 'ungrounded',
#    'nausea only': 'ungrounded',
#    'zno': 'ungrounded',
#    'neuropsychiatric': 'ungrounded',
#    'natural production': 'ungrounded',
#    'nitrophenyl': 'ungrounded',
#    'neural precursor': 'ungrounded',
#    'non pathogenic': 'ungrounded',
#    'particles': 'MESH:D053758',
#    'viral antigen': 'ungrounded',
#    'nonpreferring': 'ungrounded',
#    'c': 'ungrounded'},
#   'NPs': {'nanoparticles': 'MESH:D053758',
#    'natriuretic peptides': 'FPLX:Natriuretic_peptide',
#    'au': 'ungrounded',
#    'neural progenitors': 'ungrounded',
#    'nurse practitioners': 'ungrounded',
#    'natural products': 'ungrounded',
#    'particles': 'MESH:D053758',
#    'ag': 'ungrounded',
#    'neural precursors': 'ungrounded',
#    'nasal polyps': 'ungrounded',
#    'neuropeptides': 'ungrounded',
#    'nitrophorins': 'ungrounded',
#    'neuritic plaques': 'ungrounded',
#    'nanoparticulates': 'MESH:D053758',
#    'nucleoproteins': 'MESH:D009698',
#    'neuroprogenitors': 'ungrounded',
#    'nanopillars': 'ungrounded'}},
#  'MS': {'MS': {'multiple sclerosis': 'MESH:D009103',
#    'metabolic syndrome': 'ungrounded',
#    'mass spectrometry': 'ungrounded',
#    'maternal separation': 'ungrounded',
#    'methionine synthase': 'HGNC:7468',
#    'stress': 'ungrounded',
#    'medial septum': 'ungrounded',
#    'mutans streptococci': 'ungrounded',
#    'stimulation': 'ungrounded',
#    'mechanosensitive': 'ungrounded',
#    'mitral stenosis': 'ungrounded',
#    'microspheres': 'ungrounded',
#    'mass spectrometric': 'ungrounded',
#    'm ⋆': 'ungrounded',
#    'morphine sulfate': 'ungrounded',
#    'medial septal': 'ungrounded',
#    'mammospheres': 'ungrounded',
#    'murashige and skoog': 'ungrounded',
#    'meal size': 'ungrounded',
#    'mainstream': 'ungrounded',
#    'myeloid sarcoma': 'ungrounded',
#    'mass spectrometer': 'ungrounded',
#    'motion sickness': 'ungrounded',
#    'biogas digestate bd and mining waste': 'ungrounded',
#    'mechanical stretch': 'ungrounded'}},
#  'MT': {'MT': {'microtubule': 'MESH:D008870',
#    'metallothionein': 'FPLX:MT',
#    'melatonin': 'CHEBI:CHEBI:16796',
#    'magnetization transfer': 'ungrounded',
#    'mutant': 'ungrounded',
#    'methyltestosterone': 'ungrounded',
#    'therapy': 'ungrounded',
#    'trained': 'ungrounded',
#    'myogenic tone': 'ungrounded',
#    'movement time': 'ungrounded',
#    'type': 'ungrounded',
#    'microbial translocation': 'ungrounded',
#    'middle t antigen': 'ungrounded',
#    'methyltransferase': 'ungrounded',
#    'mechanism thrombectomy': 'ungrounded',
#    'metacyclic trypomastigotes': 'ungrounded',
#    'thickness': 'ungrounded',
#    'mitochondria': 'ungrounded',
#    'motor threshold': 'ungrounded',
#    'middle t': 'ungrounded',
#    'milk thistle': 'ungrounded',
#    'middle temporal area': 'ungrounded',
#    'k m': 'ungrounded',
#    'methanethiol': 'ungrounded',
#    'massive transfusion': 'ungrounded'}},
#  'BP': {'BP': {'blood pressure': 'MESH:D001794',
#    'benzo a pyrene': 'CHEBI:29865',
#    'bullous pemphigoid': 'ungrounded',
#    'bisphosphonate': 'MESH:D004164',
#    'binding potential': 'ungrounded',
#    'bipolar disorder': 'ungrounded',
#    'n butylidenephthalide': 'ungrounded',
#    'black phosphorus': 'ungrounded',
#    'brevipedicellus': 'ungrounded',
#    'protein': 'ungrounded',
#    'bacterial production': 'ungrounded',
#    'benzophenone': 'ungrounded',
#    'rcas': 'ungrounded',
#    'bipolar': 'ungrounded',
#    'biological process': 'ungrounded',
#    'point': 'ungrounded',
#    'butylparaben': 'ungrounded',
#    'benzoyl peroxide': 'ungrounded',
#    'brachial plexus': 'ungrounded'}},
#  'GH': {'GH': {'growth hormone': 'HGNC:4261',
#    'glycoside hydrolase': 'MESH:D006026',
#    'gestational hypertension': 'ungrounded',
#    'glycogenic hepatopathy': 'ungrounded'}},
#  'AD': {'AD': {'s disease': 'MESH:D000544',
#    'atopic dermatitis': 'MESH:D003876',
#    'alcohol dependence': 'MESH:D000437',
#    'axial diffusivity': 'ungrounded',
#    'anaerobic digestion': 'ungrounded',
#    'activation domain': 'ungrounded',
#    'autosomal dominant': 'ungrounded',
#    'antidepressant': 'ungrounded',
#    's': 'ungrounded',
#    'androstenedione': 'MESH:D000735',
#    'afterdischarge': 'ungrounded',
#    'dementia': 'ungrounded',
#    'aortic dissection': 'ungrounded',
#    'autonomic dysreflexia': 'ungrounded',
#    'androgen deprivation': 'ungrounded',
#    'adenocarcinoma': 'ungrounded',
#    'aortic distensibility': 'ungrounded',
#    'adenosine': 'ungrounded',
#    'disorders': 'ungrounded',
#    'adiponectin': 'HGNC:13633',
#    'anoxic depolarization': 'ungrounded',
#    'actinomycin d': 'ungrounded',
#    'atherogenic diet': 'ungrounded',
#    'p': 'ungrounded',
#    'adrenaline': 'MESH:D004837',
#    'patients': 'ungrounded',
#    'alzheimer': 'MESH:D000544',
#    '3 17 dione': 'ungrounded',
#    'cases': 'ungrounded',
#    'adriamycin': 'ungrounded',
#    'drugs': 'ungrounded',
#    'amiodarone': 'ungrounded',
#    'atherogenic dyslipidemia': 'ungrounded',
#    'axial': 'ungrounded',
#    'ad': 'ungrounded',
#    'acetabular dysplasia': 'ungrounded'}},
#  'GT': {'GT': {'the': 'ungrounded',
#    'green tea': 'MESH:D013662',
#    'ho 1': 'ungrounded',
#    'of': 'ungrounded',
#    'gene targeting': 'ungrounded',
#    'gliotoxin': 'ungrounded',
#    'glycosyltransferase': 'FPLX:Glycosyltransferase',
#    'a': 'ungrounded',
#    'glanzmann thrombasthenia': 'ungrounded',
#    'glucose transporter': 'FPLX:SLC2A',
#    'genotype': 'ungrounded',
#    'gene therapy': 'ungrounded',
#    'and': 'ungrounded',
#    'galactosyltransferase': 'FPLX:Glycosyltransferase',
#    'longer': 'ungrounded',
#    'ho 1 promoter region': 'ungrounded',
#    'microsatellite': 'ungrounded',
#    'transferase': 'FPLX:Glycosyltransferase',
#    'the genital tubercle': 'ungrounded',
#    'genital tract': 'ungrounded',
#    'green tea extract': 'MESH:D013662',
#    'ganoderma tsugae': 'ungrounded',
#    '25': 'ungrounded',
#    'hmox1': 'ungrounded',
#    'for': 'ungrounded',
#    'gallotannin': 'ungrounded',
#    'm': 'ungrounded',
#    'short': 'ungrounded',
#    'long': 'ungrounded',
#    'with': 'ungrounded',
#    'geographic tongue': 'ungrounded',
#    'polymorphism': 'ungrounded',
#    'treatment': 'ungrounded',
#    'gene trap': 'ungrounded',
#    'glucose tolerance': 'ungrounded',
#    'allele': 'ungrounded',
#    'or': 'ungrounded',
#    'granulation tissue': 'ungrounded'}},
#  'DA': {'DA': {'dopamine': 'CHEBI:CHEBI:18243',
#    'dopaminergic': 'CHEBI:CHEBI:18243',
#    'acid': 'ungrounded',
#    'the ductus arteriosus': 'ungrounded',
#    'dopamine agonist': 'MESH:D015259',
#    'dark agouti': 'ungrounded',
#    'the dorsal aorta': 'ungrounded',
#    'τ off − 1': 'ungrounded',
#    'drugs abuse': 'ungrounded',
#    'decursinol angelate': 'ungrounded',
#    'diminazene aceturate': 'ungrounded',
#    'danaparoid sodium': 'ungrounded',
#    'darbepoetin alfa': 'ungrounded',
#    'activity': 'ungrounded'}},
#  'GR': {'GR': {'glucocorticoid receptor': 'HGNC:7978',
#    'glutathione reductase': 'HGNC:4623',
#    'glucocorticoid': 'HGNC:7978',
#    'resistant': 'ungrounded',
#    'poly': 'ungrounded',
#    'nr3c1': 'HGNC:7978',
#    'and': 'ungrounded',
#    'glucose restriction': 'ungrounded',
#    'of': 'ungrounded',
#    'graphene': 'ungrounded',
#    '2': 'ungrounded',
#    'uas': 'ungrounded',
#    'growth rate': 'ungrounded',
#    'glycyrrhizae radix': 'ungrounded',
#    'expression': 'ungrounded'}},
#  'IR': {'IR': {'ionizing radiation': 'MESH:D011839',
#    'insulin resistance': 'MESH:D007333',
#    'insulin receptor': 'HGNC:6091',
#    'ischemia reperfusion': 'MESH:D015427',
#    'irradiation': 'MESH:D011839',
#    'immunoreactivity': 'ungrounded',
#    'infrared': 'MESH:D007259',
#    'immediate release': 'ungrounded',
#    'msc cm iec 6': 'ungrounded',
#    'inverted repeat': 'ungrounded',
#    'rate': 'ungrounded',
#    'intron retention': 'ungrounded',
#    'k': 'ungrounded',
#    'iterative reconstruction': 'ungrounded',
#    'ik': 'ungrounded',
#    'inversion recovery': 'ungrounded',
#    'response': 'ungrounded',
#    'region': 'ungrounded',
#    'ischemia reperfusion injury': 'MESH:D015427',
#    'internal rotation': 'ungrounded',
#    'gfp': 'ungrounded',
#    'isolated rearing': 'ungrounded',
#    'loki': 'ungrounded',
#    'group': 'ungrounded',
#    'gy': 'ungrounded',
#    'gypsy': 'ungrounded',
#    'intrarectal': 'ungrounded',
#    'interventional radiology': 'ungrounded',
#    'immune reconstitution': 'ungrounded'}},
#  'HK2': {'HK2': {'hexokinase 2': 'HGNC:4923',
#    'hexokinase ii': 'HGNC:4923',
#    'cells': 'ungrounded',
#    'hexokinase': 'HGNC:4923',
#    'epithelial': 'ungrounded'}},
#  'ARF': {'ARF': {'acute renal failure': 'MESH:D058186',
#    'p14': 'HGNC:30833',
#    'adp ribosylation factor': 'FPLX:ARF_GTPase_family',
#    'p19': 'HGNC:30833',
#    'alternative reading frame': 'ungrounded',
#    'acute rheumatic fever': 'ungrounded',
#    'acoustic radiation force': 'ungrounded',
#    'adventitious root formation': 'ungrounded',
#    'rich fraction': 'ungrounded'}},
#  'CS': {'CS': {'cigarette smoke': 'MESH:D000073865',
#    'chondroitin sulfate': 'CHEBI:CHEBI:37397',
#    'citrate synthase': 'HGNC:2422',
#    'conditioned stimulus': 'ungrounded',
#    'chitosan': 'CHEBI:CHEBI:16261',
#    'syndrome': 'ungrounded',
#    'corticosteroids': 'MESH:D000305',
#    'sensitivity': 'ungrounded',
#    'compressed sensing': 'ungrounded',
#    'stress': 'ungrounded',
#    'chondroitin sulphate': 'ungrounded',
#    'corticosterone': 'MESH:D000305',
#    'cardiogenic shock': 'ungrounded',
#    'section': 'ungrounded',
#    'coronary sinus': 'ungrounded',
#    'cordyceps sinensis': 'ungrounded',
#    'circumsporozoite': 'ungrounded',
#    'conditioned stimuli': 'ungrounded',
#    'cyclic stretch': 'ungrounded',
#    'stimulation': 'ungrounded',
#    'complex spike': 'ungrounded',
#    'pias1': 'HGNC:2752',
#    'culture supernatant': 'ungrounded',
#    'calcium silicate': 'ungrounded',
#    'cold storage': 'ungrounded',
#    'score': 'ungrounded',
#    'strain': 'ungrounded',
#    'surgery': 'ungrounded',
#    'cardiac sarcoidosis': 'ungrounded',
#    'chinese spring': 'ungrounded',
#    'circumsporozoite protein': 'ungrounded',
#    'corn stover': 'ungrounded',
#    'crystalline silica': 'ungrounded',
#    'craniosynostosis': 'ungrounded',
#    'mutant': 'ungrounded',
#    'congenital scoliosis': 'ungrounded',
#    'cyclosporin a': 'ungrounded',
#    'cellular senescence': 'ungrounded',
#    'castasterone': 'ungrounded',
#    'centriolar satellites': 'ungrounded',
#    'tone': 'ungrounded'}},
#  'EC': {'EC': {'endothelial cells': 'MESH:D042783',
#    'endometrial cancer': 'MESH:D016889',
#    'carcinoma': 'ungrounded',
#    'epicatechin': 'CHEBI:CHEBI:25053',
#    'entorhinal cortex': 'ungrounded',
#    'a': 'ungrounded',
#    'enterochromaffin': 'MESH:D004759',
#    'excitation contraction': 'ungrounded',
#    'elemental carbon': 'ungrounded',
#    'complex': 'ungrounded',
#    'control': 'ungrounded',
#    'electrical conductivity': 'ungrounded',
#    'extracellular': 'ungrounded',
#    'endocannabinoid': 'MESH:D063388',
#    'endothelial': 'MESH:D042783',
#    'epicutaneous': 'ungrounded',
#    'regulation': 'ungrounded',
#    'eyes closed': 'ungrounded',
#    'enriched condition': 'ungrounded',
#    'electrochemical': 'ungrounded',
#    'escherichia coli': 'ungrounded',
#    'ethyl carbamate': 'ungrounded',
#    'esterified cholesterol': 'ungrounded',
#    'enzyme commission': 'ungrounded',
#    'electrocoagulation': 'ungrounded',
#    'energy charge': 'ungrounded',
#    'enriched': 'ungrounded',
#    'concentrations': 'ungrounded',
#    'ethylcellulose': 'ungrounded',
#    'endothelium': 'MESH:D042783',
#    'electronic cigarette': 'ungrounded',
#    'enterocyte': 'ungrounded',
#    'ethyl cellulose': 'ungrounded',
#    'capacity': 'ungrounded',
#    'salinity': 'ungrounded'}},
#  'STD': {'STD': {'saturation transfer difference': 'MESH:D009682',
#    'short term depression': 'MESH:D003866',
#    'sexually transmitted disease': 'MESH:D012749',
#    'standard diet': 'ungrounded',
#    'standard': 'ungrounded',
#    'standard deviation': 'ungrounded',
#    'u c c d and': 'ungrounded'}},
#  'PD1': {'PD1': {'programmed cell death protein 1': 'HGNC:8760',
#    'programmed death 1': 'HGNC:8760',
#    'programmed cell death 1': 'HGNC:8760',
#    'protectin d1': 'HGNC:11138'}},
#  'TGH': {'TGH': {'triacylglycerol hydrolase': 'HGNC:1863',
#    'high': 'ungrounded',
#    'tough': 'ungrounded'}},
#  'PKD': {'PKD': {'protein kinase d': 'HGNC:9407',
#    'polycystic kidney disease': 'ungrounded',
#    'paroxysmal kinesigenic dyskinesia': 'ungrounded',
#    'domain': 'ungrounded',
#    'pyruvate kinase deficiency': 'ungrounded',
#    'protein kinase d1': 'HGNC:9407'}},
#  'RA': {'RA': {'rheumatoid arthritis': 'MESH:D001172',
#    'retinoic acid': 'CHEBI:CHEBI:26536',
#    'right atrial': 'ungrounded',
#    'radial artery': 'ungrounded',
#    'the right atrium': 'ungrounded',
#    'ras associated': 'ungrounded',
#    'the robust nucleus of the arcopallium': 'ungrounded',
#    'rapidly adapting': 'ungrounded',
#    'ra': 'ungrounded',
#    'room air': 'ungrounded',
#    'rectus abdominis': 'ungrounded',
#    'rotational atherectomy': 'ungrounded',
#    'radix astragali': 'ungrounded',
#    'activity': 'ungrounded',
#    'atra': 'ungrounded',
#    'a': 'ungrounded'}},
#  'PCP': {'PCP': {'phencyclidine': 'CHEBI:CHEBI:8058',
#    'planar cell polarity': 'MESH:D016764',
#    'pentachlorophenol': 'CHEBI:CHEBI:17642',
#    'pneumonia': 'ungrounded',
#    'peptidyl carrier protein': 'ungrounded',
#    'primary care physician': 'ungrounded',
#    'primary care provider': 'ungrounded',
#    'phencyclidine hydrochloride': 'ungrounded',
#    '3 5': 'ungrounded',
#    'pathway': 'ungrounded',
#    'pulmonary capillary pressure': 'ungrounded',
#    'precleaved 40 bp primary site containing dna': 'ungrounded'}},
#  'PI': {'PI': {'phosphatidylinositol': 'CHEBI:CHEBI:28874',
#    'propidium iodide': 'CHEBI:CHEBI:51240',
#    'protease inhibitor': 'MESH:D011480',
#    'index': 'ungrounded',
#    'phosphoinositide': 'CHEBI:CHEBI:28874',
#    'post infection': 'ungrounded',
#    'phosphatidyl inositol': 'CHEBI:CHEBI:28874',
#    'pistillata': 'ungrounded',
#    'pneumatosis intestinalis': 'ungrounded',
#    'pelvic incidence': 'ungrounded',
#    'proactive interference': 'ungrounded',
#    'imidazole': 'ungrounded',
#    'postinfection': 'ungrounded',
#    'the pars intercerebralis': 'ungrounded',
#    'phosphoinositol': 'CHEBI:CHEBI:28874',
#    'interval': 'ungrounded',
#    'insufficiency': 'ungrounded',
#    'polyimide': 'ungrounded',
#    'parallel imaging': 'ungrounded',
#    'povidone iodine': 'ungrounded',
#    'indicated': 'ungrounded',
#    'prescriptive information': 'ungrounded',
#    'phosphatidylinositide': 'CHEBI:CHEBI:28874',
#    'intensity': 'ungrounded',
#    'inhibition': 'ungrounded'}},
#  'PS': {'PS': {'phosphatidylserine': 'CHEBI:18303',
#    'photosensitizer': 'ungrounded',
#    'polystyrene': 'ungrounded',
#    'population spike': 'ungrounded',
#    'stress': 'ungrounded',
#    'presenilin': 'HGNC:9508',
#    'polysaccharide': 'ungrounded',
#    'protein s': 'HGNC:9456',
#    'paradoxical sleep': 'ungrounded',
#    'pregnenolone sulfate': 'ungrounded',
#    'performance status': 'ungrounded',
#    'phosphorothioate': 'ungrounded',
#    'phosphatidyl serine': 'CHEBI:18303',
#    'peak shortening': 'ungrounded',
#    'phytosterols': 'ungrounded',
#    'pulmonary surfactant': 'ungrounded',
#    'plant sterols': 'ungrounded',
#    'moe25': 'ungrounded',
#    'persulfate': 'ungrounded',
#    'syndrome': 'ungrounded',
#    'protein synthesis': 'ungrounded',
#    'porous silicon': 'ungrounded',
#    'phytosiderophores': 'ungrounded',
#    'primitive streak': 'ungrounded',
#    'panobinostat': 'ungrounded',
#    'permeability surface area product': 'ungrounded',
#    'photosystem': 'ungrounded',
#    'propensity score': 'ungrounded',
#    'serum': 'ungrounded',
#    'pressure support': 'ungrounded',
#    'permeability surface area': 'ungrounded',
#    'psoriasis': 'ungrounded',
#    'sensitive': 'ungrounded',
#    'polysulfone': 'ungrounded',
#    'starch': 'ungrounded',
#    'stimulation': 'ungrounded',
#    'prosaposin': 'HGNC:9498',
#    'size': 'ungrounded',
#    'pedicle screw': 'ungrounded',
#    'physical': 'ungrounded',
#    'posterior stabilized': 'ungrounded',
#    'pregnenolone sulphate': 'ungrounded',
#    'process speed': 'ungrounded',
#    'packaging signal': 'ungrounded',
#    'moe20': 'ungrounded',
#    'k': 'ungrounded',
#    'primary septum': 'ungrounded',
#    'probe sets': 'ungrounded',
#    'separation': 'ungrounded',
#    'permeability': 'ungrounded',
#    'sedation': 'ungrounded',
#    'δ i': 'ungrounded',
#    'system': 'ungrounded',
#    'photosensitiser': 'ungrounded',
#    'pachytene spermatocytes': 'ungrounded',
#    'stanols': 'ungrounded',
#    'skin': 'ungrounded',
#    'group': 'ungrounded',
#    'phosphotidylserine': 'CHEBI:18303',
#    'stents': 'ungrounded'}},
#  'PA': {'PA': {'acid': 'CHEBI:16337',
#    'physical activity': 'MESH:D015444',
#    'protective antigen': 'ungrounded',
#    'pulmonary artery': 'ungrounded',
#    'palmitic': 'ungrounded',
#    'photoacoustic': 'ungrounded',
#    'pseudomonas aeruginosa': 'ungrounded',
#    'primary aldosteronism': 'ungrounded',
#    'positive affect': 'ungrounded',
#    'proanthocyanidin': 'CHEBI:26267',
#    'peptide amphiphile': 'ungrounded',
#    'a': 'ungrounded',
#    'platelet aggregation': 'ungrounded',
#    'ty21a': 'ungrounded',
#    'polyamine': 'CHEBI:88061',
#    'passive avoidance': 'ungrounded',
#    'phosphatidic': 'CHEBI:16337',
#    'perinatal asphyxia': 'ungrounded',
#    'puromycin aminonucleoside': 'ungrounded',
#    'phenylacetate': 'ungrounded',
#    'acetate': 'ungrounded',
#    'polyamide': 'ungrounded',
#    'adenoma': 'ungrounded',
#    'patchouli alcohol': 'ungrounded',
#    'pilocytic astrocytoma': 'ungrounded',
#    'phonological awareness': 'ungrounded',
#    'angle': 'ungrounded',
#    'polyacrylamide': 'ungrounded',
#    'phthalic anhydride': 'ungrounded',
#    'phosphoramidon': 'ungrounded',
#    'polymerase acid protein': 'ungrounded',
#    'anterior': 'ungrounded',
#    'procainamide': 'ungrounded',
#    'propionic acidemia': 'ungrounded',
#    'paeonol': 'ungrounded',
#    'the chimeric protein with': 'ungrounded',
#    'd penicillamine': 'ungrounded',
#    'power amplifier': 'ungrounded',
#    'polar assortant': 'ungrounded'}},
#  'MB': {'MB': {'methylene blue': 'CHEBI:6872',
#    'medulloblastoma': 'ungrounded',
#    'mushroom body': 'ungrounded',
#    'microbubbles': 'ungrounded',
#    'molecular beacon': 'ungrounded',
#    'sio 2': 'ungrounded',
#    'myocardial bridge': 'ungrounded',
#    'maneb': 'ungrounded',
#    'multibacillary': 'ungrounded',
#    'mitochondrial biogenesis': 'ungrounded',
#    'myoblasts': 'ungrounded',
#    'multiband': 'ungrounded',
#    'b': 'ungrounded',
#    'hfc diet or the hfc diet supplemented with monobutyrin at 1 g kg diet 0 · 1 mb mb at 5 g kg diet': 'ungrounded',
#    'major bleeding': 'ungrounded',
#    'mibolerone': 'ungrounded',
#    'maternal behavior': 'ungrounded',
#    'midbrain': 'ungrounded',
#    'band': 'ungrounded',
#    'myoglobin': 'HGNC:6915',
#    'midbody': 'ungrounded'}},
#  'HA': {'HA': {'hyaluronic acid': 'CHEBI:CHEBI:16336',
#    'hemagglutinin': 'MESH:D006388',
#    'hyaluronan': 'CHEBI:CHEBI:16336',
#    'hydroxyapatite': 'CHEBI:CHEBI:52255',
#    'histamine': 'MESH:D006632',
#    'haemagglutinin': 'MESH:D006388',
#    'hemagglutination': 'MESH:D006388',
#    'a': 'ungrounded',
#    'hyaluronic': 'CHEBI:CHEBI:16336',
#    'hydroxylamine': 'CHEBI:CHEBI:15429',
#    'heat acclimation': 'ungrounded',
#    'tis 2': 'ungrounded',
#    'harm avoidance': 'ungrounded',
#    'pc 70 bm': 'ungrounded',
#    'activity': 'ungrounded',
#    'high altitude': 'ungrounded',
#    'hemiarthroplasty': 'ungrounded',
#    'haemagglutination': 'MESH:D006388',
#    'hemaglutinin': 'MESH:D006388'}},
#  'AR': {'AR': {'androgen receptor': 'HGNC:644',
#    'aldose reductase': 'HGNC:381',
#    'allergic rhinitis': 'ungrounded',
#    'acrosome reaction': 'GO:GO:0007340',
#    'amphiregulin': 'HGNC:651',
#    'acute rejection': 'ungrounded',
#    'pc 3': 'ungrounded',
#    'resistant': 'ungrounded',
#    'response': 'ungrounded',
#    'aortic regurgitation': 'ungrounded',
#    'autosomal recessive': 'ungrounded',
#    'androgen': 'HGNC:644',
#    'adrenoceptor': 'FPLX:ADRB',
#    'adventitious root': 'ungrounded',
#    'ar': 'ungrounded',
#    'ratio': 'ungrounded',
#    'antigen retrieval': 'ungrounded',
#    'gene': 'ungrounded',
#    'ankyrin repeat': 'ungrounded',
#    'nes': 'ungrounded',
#    'astragali radix': 'ungrounded',
#    'rate': 'ungrounded',
#    'red': 'ungrounded',
#    'autoregressive': 'ungrounded',
#    '”': 'ungrounded',
#    'acid rain': 'ungrounded',
#    'after ripening': 'ungrounded'}},
#  'HR': {'HR': {'heart rate': 'MESH:D006339',
#    'homologous recombination': 'MESH:D059765',
#    'hazard ratio': 'ungrounded',
#    'hypersensitive response': 'MESH:D006967',
#    'hormone receptor': 'ungrounded',
#    'high risk': 'ungrounded',
#    'hypersensitive reaction': 'MESH:D006967',
#    'hypoxia reoxygenation': 'ungrounded',
#    'repair': 'ungrounded',
#    'histamine release': 'ungrounded',
#    'high responders': 'ungrounded',
#    'high': 'ungrounded',
#    'hairy roots': 'ungrounded',
#    'high resolution': 'ungrounded',
#    'hepatic resection': 'ungrounded',
#    'resistance': 'ungrounded',
#    'region': 'ungrounded',
#    'hairless': 'HGNC:5172',
#    'high reward': 'ungrounded',
#    'cancer': 'ungrounded',
#    'h atpase rich': 'ungrounded',
#    'cells death': 'ungrounded',
#    'hypersensitive': 'ungrounded'}},
#  'NE': {'NE': {'norepinephrine': 'CHEBI:CHEBI:33569',
#    'neutrophil elastase': 'HGNC:3309',
#    'the nuclear envelope': 'ungrounded',
#    'neuroendocrine': 'ungrounded',
#    'noradrenaline': 'CHEBI:CHEBI:33569',
#    'noradrenergic': 'CHEBI:CHEBI:33569',
#    'nuclear extract': 'ungrounded',
#    'nanoemulsion': 'ungrounded',
#    'necrotic enteritis': 'ungrounded',
#    'negative emotionality': 'ungrounded',
#    'nocturnal enuresis': 'ungrounded',
#    'neuroectoderm': 'ungrounded',
#    'neonatal encephalopathy': 'ungrounded',
#    'neuroepithelial': 'ungrounded',
#    'nephropathia epidemica': 'ungrounded',
#    'trimcyp minor': 'ungrounded',
#    'neural ectoderm': 'ungrounded'}},
#  'UBC': {'UBC': {'urothelial bladder cancer': 'MESH:D001749',
#    'ubiquitin c': 'HGNC:12468',
#    'urothelial bladder carcinoma': 'MESH:D001749',
#    'cells': 'ungrounded',
#    'ubiquitin conjugating': 'FPLX:UBE2',
#    'ubiquitin conjugating enzyme': 'FPLX:UBE2',
#    'concentration': 'ungrounded'}},
#  'GSC': {'GSC': {'stem cells': 'ungrounded', 'goosecoid': 'HGNC:4612'}},
#  'AA': {'AA': {'arachidonic acid': 'CHEBI:CHEBI:15843',
#    'african american': 'ungrounded',
#    'alopecia areata': 'ungrounded',
#    'aplastic anemia': 'ungrounded',
#    'adjuvant arthritis': 'ungrounded',
#    'abiraterone acetate': 'CHEBI:CHEBI:68639',
#    'antimycin a': 'CHEBI:CHEBI:22584',
#    'acrylamide': 'CHEBI:CHEBI:28619',
#    'arachidonic': 'CHEBI:CHEBI:15843',
#    'activity': 'ungrounded',
#    'p': 'ungrounded',
#    'acetaldehyde': 'CHEBI:CHEBI:15343',
#    'ascorbic': 'ungrounded',
#    'acetaminophen': 'ungrounded',
#    'aplastic anaemia': 'ungrounded',
#    'acetoacetate': 'ungrounded',
#    '16': 'ungrounded',
#    'aortic aneurysm': 'ungrounded',
#    'anaplastic astrocytoma': 'ungrounded',
#    'activity avoidance': 'ungrounded',
#    'poly': 'ungrounded',
#    'abdominal aorta': 'ungrounded',
#    '6': 'ungrounded',
#    'allergic asthma': 'ungrounded',
#    'alcohol': 'ungrounded',
#    'acupuncture analgesia': 'ungrounded',
#    'alcohol anonymous': 'ungrounded',
#    'auricular acupuncture': 'ungrounded',
#    'allergic asthmatic': 'ungrounded',
#    'afferent arteriole': 'ungrounded'}},
#  'NIS': {'NIS': {'sodium iodide symporter': 'HGNC:11040',
#    'n iodosuccinimide': 'CHEBI:CHEBI:11040',
#    'trials were assigned one of the three feeding pressure categories based on non bt node injury scale': 'ungrounded',
#    'species': 'ungrounded',
#    'slc5a5': 'HGNC:11040',
#    'score': 'ungrounded',
#    'protein': 'ungrounded',
#    'non invasive support': 'ungrounded',
#    'non interventional study': 'ungrounded',
#    'nationwide inpatient sample': 'ungrounded',
#    'gene': 'ungrounded',
#    'signal': 'ungrounded',
#    'surfactants': 'ungrounded'}},
#  'GC': {'GC': {'gastric cancer': 'MESH:D013274',
#    'glucocorticoid': 'MESH:D005938',
#    'germinal center': 'ungrounded',
#    'cells': 'ungrounded',
#    'cyclase': 'FPLX:GUCY',
#    'gastric carcinoma': 'MESH:D013274',
#    'gene conversion': 'ungrounded',
#    'germinal centre': 'ungrounded',
#    'glucocerebrosidase': 'HGNC:4177',
#    'gas chromatography': 'ungrounded',
#    'growth cone': 'ungrounded',
#    'glucocorticosteroids': 'MESH:D005938',
#    'chitosan': 'ungrounded',
#    'gustatory cortex': 'ungrounded',
#    'glucosylceramide': 'HGNC:4177',
#    'neisseria gonorrhoeae': 'ungrounded',
#    'glucocorticoid hormone': 'MESH:D005938',
#    'gastric adenocarcinoma': 'MESH:D013274',
#    'carbon': 'ungrounded',
#    'c': 'ungrounded',
#    'control': 'ungrounded',
#    'genomic classifier': 'ungrounded'}},
#  'CM': {'CM': {'conditioned medium': 'MESH:D017077',
#    'conditioned media': 'MESH:D017077',
#    'cerebral malaria': 'ungrounded',
#    'cardiomyocyte': 'ungrounded',
#    'contingency management': 'ungrounded',
#    'chronic migraine': 'ungrounded',
#    'membrane': 'ungrounded',
#    'chylomicrons': 'MESH:D002914',
#    'central memory': 'ungrounded',
#    'cutaneous melanoma': 'ungrounded',
#    'cryptococcal meningitis': 'ungrounded',
#    'cochlear microphonic': 'ungrounded',
#    'childhood maltreatment': 'ungrounded',
#    'chinese medicine': 'ungrounded',
#    'muscle': 'ungrounded',
#    'milk': 'ungrounded',
#    'cardiomyopathy': 'ungrounded',
#    'cardiac myocytes': 'ungrounded',
#    'mixture': 'ungrounded',
#    'malformation': 'ungrounded',
#    'cordyceps militaris': 'ungrounded',
#    't': 'ungrounded',
#    'curcumin': 'ungrounded',
#    'carboxymethyl': 'ungrounded',
#    'chorismate mutase': 'ungrounded',
#    'clinical mastitis': 'ungrounded',
#    'calmodulin': 'FPLX:CALM',
#    'cross metathesis': 'ungrounded',
#    'cells': 'ungrounded',
#    'ciliary margin': 'ungrounded',
#    'cap mesenchymal': 'ungrounded',
#    'meal': 'ungrounded',
#    'or without': 'ungrounded',
#    'contrast material': 'ungrounded'}},
#  'RB': {'RB': {'retinoblastoma': 'HGNC:9884',
#    'retinoblastoma protein': 'HGNC:9884',
#    'rose bengal': 'CHEBI:CHEBI:52261',
#    'retinoblastoma tumor suppressor': 'HGNC:9884',
#    'rohon beard': 'ungrounded',
#    'respiratory burst': 'GO:GO:0045730',
#    'retinoblastoma gene': 'HGNC:9884',
#    'rice bran': 'ungrounded',
#    'b': 'ungrounded',
#    'retinoblastoma gene product': 'HGNC:9884',
#    'reticulate body': 'ungrounded',
#    'rule based': 'ungrounded',
#    'bdnf': 'ungrounded',
#    'blue': 'ungrounded',
#    'rod bipolar': 'ungrounded',
#    'retinoblastoma tumor suppressor gene': 'HGNC:9884'},
#   'Rb': {'retinoblastoma': 'HGNC:9884',
#    'retinoblastoma protein': 'HGNC:9884',
#    'retinoblastoma gene product': 'HGNC:9884',
#    'retinoblastoma gene': 'HGNC:9884',
#    'retinoblastoma tumor suppressor': 'HGNC:9884',
#    'k': 'ungrounded',
#    'rubidium': 'CHEBI:CHEBI:33322',
#    'retinoblastoma 1': 'HGNC:9884',
#    'k m': 'ungrounded'}},
#  'Rb': {'RB': {'retinoblastoma': 'HGNC:9884',
#    'retinoblastoma protein': 'HGNC:9884',
#    'rose bengal': 'CHEBI:CHEBI:52261',
#    'retinoblastoma tumor suppressor': 'HGNC:9884',
#    'rohon beard': 'ungrounded',
#    'respiratory burst': 'GO:GO:0045730',
#    'retinoblastoma gene': 'HGNC:9884',
#    'rice bran': 'ungrounded',
#    'b': 'ungrounded',
#    'retinoblastoma gene product': 'HGNC:9884',
#    'reticulate body': 'ungrounded',
#    'rule based': 'ungrounded',
#    'bdnf': 'ungrounded',
#    'blue': 'ungrounded',
#    'rod bipolar': 'ungrounded',
#    'retinoblastoma tumor suppressor gene': 'HGNC:9884'},
#   'Rb': {'retinoblastoma': 'HGNC:9884',
#    'retinoblastoma protein': 'HGNC:9884',
#    'retinoblastoma gene product': 'HGNC:9884',
#    'retinoblastoma gene': 'HGNC:9884',
#    'retinoblastoma tumor suppressor': 'HGNC:9884',
#    'k': 'ungrounded',
#    'rubidium': 'CHEBI:CHEBI:33322',
#    'retinoblastoma 1': 'HGNC:9884',
#    'k m': 'ungrounded'}},
#  'LH': {'LH': {'luteinizing hormone': 'FPLX:LH',
#    'the lateral hypothalamus': 'ungrounded',
#    'learned helplessness': 'ungrounded',
#    'lutropin': 'FPLX:LH',
#    'lateral hypothalamic': 'ungrounded',
#    'left hemisphere': 'ungrounded',
#    'luteinizing': 'FPLX:LH',
#    'lysyl hydroxylase': 'ungrounded',
#    'hydrochloride': 'ungrounded',
#    'hypertensive': 'ungrounded'}},
#  'ER': {'ER': {'endoplasmic reticulum': 'GO:GO:0005783',
#    'estrogen receptor': 'HGNC:3467',
#    'estrogen': 'HGNC:3467',
#    'extended release': 'ungrounded',
#    'estrogen receptor α': 'HGNC:3467',
#    'estrogen receptor alpha': 'HGNC:3467',
#    'emergency room': 'ungrounded',
#    'energy restriction': 'ungrounded',
#    'emotion regulation': 'ungrounded',
#    'endoplasmic reticular': 'GO:GO:0005783',
#    'ca 2': 'ungrounded',
#    'er': 'ungrounded',
#    'rate': 'ungrounded',
#    'early repolarization': 'ungrounded',
#    'erecta': 'ungrounded',
#    'ratio': 'ungrounded',
#    'resistance': 'ungrounded',
#    'sniper': 'ungrounded',
#    'oestrogen': 'HGNC:3467',
#    'endoscopic resection': 'ungrounded',
#    'external rotation': 'ungrounded',
#    'enoyl reductase': 'ungrounded',
#    'calnexin': 'ungrounded',
#    'endoplasmic reticulum stress': 'GO:GO:0005783',
#    'erucin': 'ungrounded',
#    'esr1': 'HGNC:3467',
#    'ecosystem respiration': 'ungrounded'}},
#  'TF': {'TF': {'tissue factor': 'HGNC:3541',
#    'transferrin': 'HGNC:11740',
#    'tail flick': 'ungrounded',
#    'transmitted founder': 'ungrounded',
#    'theaflavin': 'CHEBI:CHEBI:136609',
#    'tolylfluanid': 'CHEBI:CHEBI:75182',
#    'thomsen friedenreich': 'ungrounded',
#    'time frequency': 'ungrounded',
#    'total flavonoids': 'ungrounded',
#    'ab': 'ungrounded',
#    'force': 'ungrounded',
#    'tibiofemoral': 'ungrounded',
#    'fat': 'ungrounded',
#    'telephone filtered': 'ungrounded',
#    'follicular': 'ungrounded',
#    'f3': 'ungrounded',
#    'serotransferrin': 'HGNC:11740'}},
#  'PGP': {'PGP': {'p glycoprotein': 'HGNC:40',
#    'plant growth promoting': 'ungrounded',
#    'proline glycine proline': 'ungrounded',
#    'phosphatidylglycerophosphate': 'CHEBI:CHEBI:17264',
#    'phosphatidylglycerolphosphate': 'CHEBI:CHEBI:17264',
#    'phosphate': 'ungrounded',
#    'pro gly pro': 'ungrounded'}},
#  'MCT': {'MCT': {'monocrotaline': 'CHEBI:CHEBI:6980',
#    'medium chain triglycerides': 'MESH:D014280',
#    'monocarboxylate transporter': 'HGNC:10922',
#    'mast cell tryptase': 'FPLX:Tryptase',
#    'medium chain triacylglycerols': 'MESH:D014280',
#    'mast cell tumor': 'ungrounded',
#    'medullary collecting tubule': 'ungrounded',
#    'muscle connective tissue': 'ungrounded',
#    'maximum capacity test': 'ungrounded',
#    'time': 'ungrounded'}},
#  'TG': {'TG': {'triglyceride': 'CHEBI:CHEBI:17855',
#    'thapsigargin': 'CHEBI:CHEBI:9516',
#    'triacylglycerol': 'CHEBI:CHEBI:17855',
#    'transgenic': 'ungrounded',
#    'trigeminal ganglion': 'ungrounded',
#    'trigeminal ganglia': 'ungrounded',
#    'thyroglobulin': 'HGNC:11764',
#    'thrombin generation': 'ungrounded',
#    'the': 'ungrounded',
#    'transglutaminase': 'ungrounded',
#    'log': 'ungrounded',
#    'transgenic mice': 'ungrounded',
#    'of': 'ungrounded',
#    'group': 'ungrounded',
#    'thioguanine': 'ungrounded',
#    'and': 'ungrounded',
#    'thioglycollate': 'ungrounded',
#    'triacylglyceride': 'CHEBI:CHEBI:17855',
#    'trophoblast giant': 'ungrounded',
#    'd': 'ungrounded',
#    'transplant glomerulopathy': 'ungrounded',
#    'ln': 'ungrounded',
#    'trigeminal': 'ungrounded',
#    'for': 'ungrounded',
#    'high risk': 'ungrounded',
#    'with': 'ungrounded',
#    'target gene': 'ungrounded',
#    'to': 'ungrounded',
#    'or': 'ungrounded',
#    'transglycosylation': 'ungrounded'}}}

# %%
BP_disamb = disambiguators['BP']
PS_disamb = disambiguators['PS']
PA_disamb = disambiguators['PA']
MB_disamb = disambiguators['MB']

# %%
BP_disamb.grounding_dict
# Out:
# {'BP': {'blood pressure': 'MESH:D001794',
#   'benzo a pyrene': 'CHEBI:29865',
#   'bullous pemphigoid': 'ungrounded',
#   'bisphosphonate': 'MESH:D004164',
#   'binding potential': 'ungrounded',
#   'bipolar disorder': 'ungrounded',
#   'n butylidenephthalide': 'ungrounded',
#   'black phosphorus': 'ungrounded',
#   'brevipedicellus': 'ungrounded',
#   'protein': 'ungrounded',
#   'bacterial production': 'ungrounded',
#   'benzophenone': 'ungrounded',
#   'rcas': 'ungrounded',
#   'bipolar': 'ungrounded',
#   'biological process': 'ungrounded',
#   'point': 'ungrounded',
#   'butylparaben': 'ungrounded',
#   'benzoyl peroxide': 'ungrounded',
#   'brachial plexus': 'ungrounded'}}

# %%
BP_disamb.modify_groundings(new_groundings={'CHEBI:29865': 'CHEBI:CHEBI:29865'})

# %%
BP_disamb.grounding_dict
# Out:
# {'BP': {'blood pressure': 'MESH:D001794',
#   'benzo a pyrene': 'CHEBI:CHEBI:29865',
#   'bullous pemphigoid': 'ungrounded',
#   'bisphosphonate': 'MESH:D004164',
#   'binding potential': 'ungrounded',
#   'bipolar disorder': 'ungrounded',
#   'n butylidenephthalide': 'ungrounded',
#   'black phosphorus': 'ungrounded',
#   'brevipedicellus': 'ungrounded',
#   'protein': 'ungrounded',
#   'bacterial production': 'ungrounded',
#   'benzophenone': 'ungrounded',
#   'rcas': 'ungrounded',
#   'bipolar': 'ungrounded',
#   'biological process': 'ungrounded',
#   'point': 'ungrounded',
#   'butylparaben': 'ungrounded',
#   'benzoyl peroxide': 'ungrounded',
#   'brachial plexus': 'ungrounded'}}

# %%
BP_disamb.names
# Out:
# {'CHEBI:CHEBI:29865': 'benzo[a]pyrene',
#  'MESH:D001794': 'Blood Pressure',
#  'MESH:D004164': 'Diphosphonates'}

# %%
BP_disamb.disambiguate('benzo benzo pyrene chemical wow')
# Out:
# ('CHEBI:CHEBI:29865',
#  'benzo[a]pyrene',
#  {'CHEBI:CHEBI:29865': 0.9875054329190245,
#   'MESH:D001794': 0.008616123995984281,
#   'MESH:D004164': 0.0025408888748896835,
#   'ungrounded': 0.001337554210101759})

# %%
model_to_s3(BP_disamb)

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
BP_disamb = load_disambiguator('BP')

# %%
grounding_map = MB_disamb.grounding_dict['MB']

# %%
[id_ for phrase, id_ in grounding_map.items() if id_.startswith('CHEBI')]
# Out:
# ['CHEBI:6872']

# %%
new_groundings = {'CHEBI:6872': 'CHEBI:CHEBI:6872'}

# %%
MB_disamb.modify_groundings(new_groundings=new_groundings)

# %%
MB_disamb.grounding_dict
# Out:
# {'MB': {'methylene blue': 'CHEBI:CHEBI:6872',
#   'medulloblastoma': 'ungrounded',
#   'mushroom body': 'ungrounded',
#   'microbubbles': 'ungrounded',
#   'molecular beacon': 'ungrounded',
#   'sio 2': 'ungrounded',
#   'myocardial bridge': 'ungrounded',
#   'maneb': 'ungrounded',
#   'multibacillary': 'ungrounded',
#   'mitochondrial biogenesis': 'ungrounded',
#   'myoblasts': 'ungrounded',
#   'multiband': 'ungrounded',
#   'b': 'ungrounded',
#   'hfc diet or the hfc diet supplemented with monobutyrin at 1 g kg diet 0 · 1 mb mb at 5 g kg diet': 'ungrounded',
#   'major bleeding': 'ungrounded',
#   'mibolerone': 'ungrounded',
#   'maternal behavior': 'ungrounded',
#   'midbrain': 'ungrounded',
#   'band': 'ungrounded',
#   'myoglobin': 'HGNC:6915',
#   'midbody': 'ungrounded'}}

# %%
model_to_s3(MB_disamb)

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
