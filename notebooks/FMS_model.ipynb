# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['FMS']
genes = ['CSF1R']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['FMS'].top()

# %%
top
# Out:
# [('fibromyalgia syndrome', 56.04347826086956),
#  ('fibromyalgia', 16.58823529411765),
#  ('with fibromyalgia syndrome', 4.285714285714286),
#  ('functional mesoporous silica', 4.0),
#  ('of fibromyalgia syndrome', 3.6),
#  ('skills', 3.0),
#  ('fluorous mixture synthesis', 3.0),
#  ('functional magnetic stimulation', 3.0),
#  ('model statistics assessing the association between fibromyalgia', 3.0),
#  ('patients with fibromyalgia syndrome', 2.5),
#  ('characteristics of a us adult population by fibromyalgia', 2.5),
#  ('fimasartan', 2.0),
#  ('1 fibromyalgia syndrome', 2.0),
#  ('and fibromyalgia syndrome', 2.0),
#  ('fundamental motor skills', 2.0),
#  ('fundamental movement skills', 2.0),
#  ('fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#   2.0),
#  ('dl c goals after fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#   2),
#  ('sterol ldl c by fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#   2),
#  ('magnetic stimulation', 1.6),
#  ('in functional mesoporous silica', 1.3333333333333333),
#  ('management system', 1.0),
#  ('synthesis of', 1),
#  ('as fibromyalgia syndrome', 1.0),
#  ('csf 1 receptor', 1.0),
#  ('fms fibromyalgia syndrome', 1.0),
#  ('for fibromyalgia syndrome', 1.0),
#  ('frequency modulation spectroscopy', 1),
#  ('in fibromyalgia syndrome', 1.0),
#  ('that fibromyalgia syndrome', 1.0),
#  ('the fibromyalgia syndrome', 1.0),
#  ('2 sulfo 9 fluorenylmethoxycarbonyl', 1.0),
#  ('fms patients fibromyalgia syndrome', 1.0),
#  ('pain from fibromyalgia syndrome', 1.0),
#  ('prevalence of fibromyalgia syndrome', 1.0),
#  ('use painless magnetic stimulation', 1),
#  ('a divergent fluorous mixture synthesis', 1),
#  ('association between fundamental movement skills', 1),
#  ('entrapped in functional mesoporous silica', 1.0),
#  ('mastery in fundamental motor skills', 1),
#  ('of patients with fibromyalgia syndrome', 1.0),
#  ('background widespread pain from fibromyalgia syndrome', 1),
#  ('the aetiopathogenesis of the fibromyalgia syndrome', 1),
#  ('we have previously shown that fibromyalgia', 1),
#  ('central sensitivity syndrome css include fibromyalgia syndrome', 1),
#  ('diversity oriented synthesis dos and fluorous mixture synthesis', 1),
#  ('glycolysis was study in people with fibromyalgia syndrome', 1),
#  ('to examine the factors association with fibromyalgia syndrome', 1),
#  ('health characteristics of a us adult population by fibromyalgia', 1.0),
#  ('pain sensitivity is a recognized feature of fibromyalgia syndrome', 1),
#  ('population experience chronic generalized musculoskeletal pain particularly fibromyalgia syndrome',
#   1),
#  ('this study assessing the ability of functional magnetic stimulation', 1),
#  ('to investigate pregnancy outcome of patients with fibromyalgia syndrome',
#   1),
#  ('this paper measures the impact of a freeway management system', 1),
#  ('to evaluate efficacy and safety of 60mg and 120mg fimasartan', 1),
#  ('all 34 public primary care clinics led by family medicine specialists', 1),
#  ('myofascial pain syndrome mpss from trigger points trps and fibromyalgia syndrome',
#   1),
#  ('organophosphorus hydrolase oph can be spontaneously entrapped in functional mesoporous silica',
#   1),
#  ('resistance and aerobic exercise patients education and behavioral therapies fibromyalgia syndrome',
#   1),
#  ('spread nonarticular musculoskeletal pain and generalized tender points 1 fibromyalgia syndrome',
#   1),
#  ('advantages and disadvantages for use in protein biocatalysis 11 functional mesoporous silica',
#   1),
#  ('disease was significantly and independently association with presence of fms fibromyalgia syndrome',
#   1),
#  ('es involved in neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#   1),
#  ('fatigue depression anxiety biomarkers and functional status in women with fibromyalgia syndrome',
#   1),
#  ('fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg', 1.0),
#  ('ith irritable bowel syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#   1),
#  ('rigger points trps between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#   1),
#  ('this study was conducted to stimulation respiratory muscle by functional magnetic stimulation',
#   1),
#  ('all findings that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#   1),
#  ('avioral interventions to address both symptoms and their biological markers over time fibromyalgia',
#   1),
#  ('dysregulation in thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#   1),
#  ('ed signaling pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#   1),
#  ('ency and broad substrate specificity the immobilization of oph in functional mesoporous silica',
#   1),
#  ('entamicin derivative with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#   1),
#  ('erum leptin level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#   1),
#  ('fatigue often accompanied by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#   1),
#  ('ffect on the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#   1),
#  ('gene may be predisposed to fms possibly trigger by environmental factors fibromyalgia syndrome',
#   1),
#  ('help determine patients subgroups in this population based on gene expression fibromyalgia syndrome',
#   1),
#  ('ncreased frequency of disturbance health characteristics of a us adult population by fibromyalgia',
#   1),
#  ('over the year study have demonstrate morphological changes in the brain of fibromyalgia',
#   1),
#  ('with hbot or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#   1),
#  ('16 our recent results have showed that the enzymes entrapped in functional mesoporous silica',
#   1),
#  ('acco use and current alcohol consumption characteristics of a us adult population by fibromyalgia',
#   1),
#  ('adduction and internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#   1),
#  ('as so that proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#   1),
#  ('ation with the other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#   1),
#  ('cantly rectify abnormal brain activity in pain relatively areas of fms patients fibromyalgia syndrome',
#   1),
#  ('ell as limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#   1),
#  ('f these factors was modest table 4 model statistics assessing the association between fibromyalgia',
#   1),
#  ('genetic and environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#   1),
#  ('ha2 ifnalpha2 at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#   1),
#  ('igation were to evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#   1),
#  ('igh risk of injury with fatigue identified as a contributing factors functional movement screening',
#   1),
#  ('k excretion of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#   1),
#  ('roughly half of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#   1),
#  ('s and for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#   1),
#  ('sical activity pa than children with typical development td pa and fundamental movement skills',
#   1),
#  ('so 4 activity silica and potassium silicate second column single use fluid management system',
#   1),
#  ('these factors are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#   1),
#  ('udy was to investigate the effect of a relatively novel technology functional magnetic stimulation',
#   1),
#  ('xamine the follow a the relationships among the latent constructs of fundamental motor skills',
#   1),
#  ('y in fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#   1),
#  ('a prospective margin directed institutional policy for rt boost dose based on final margin status',
#   1),
#  ('conditions with a single study has been discussed in the text prevalence of fibromyalgia syndrome',
#   1),
#  ('cular stem cell thus the chain cell formation was by analogy termed funicular migratory stream',
#   1),
#  ('e a simple and effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#   1),
#  ('ildhood maltreatments cms are considered to play a role in the etiology of fibromyalgia syndrome',
#   1),
#  ('l syndrome and endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#   1),
#  ('lassifications on the far left is shown the overlap of three major diagnostic groups fibromyalgia',
#   1),
#  ('of this study is to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#   1),
#  ('on and quality of life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#   1),
#  ('ral generations of fluorinated dendrimers in one pot use the so called fluorous mixture synthesis',
#   1),
#  ('s demonstrate that half among a small community based sample of patients with fibromyalgia syndrome',
#   1),
#  ('this last article in a three part series on approved medications for management fibromyalgia syndrome',
#   1),
#  ('traying from the treatment is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#   1),
#  ('wn but those with better outcome do more physical activity and use fewer medications fibromyalgia',
#   1),
#  ('1 co administration of fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg',
#   1),
#  ('by faccio et al has illustrated that m csf stimulation induces association between csf 1 receptor',
#   1),
#  ('hether the apolipoprotein e4 apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#   1),
#  ('nsiderable evidence exists to support the fact that growth factors receptor like the csf 1 receptor',
#   1),
#  ('s nerve fibers may be involved in ciu similar it has been postulated that fibromyalgia syndrome',
#   1),
#  ('ular joint disorder tmd average age 32 range 20 54 and 9 patients with fibromyalgia syndrome',
#   1),
#  ('ver 20 of adult experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#   1),
#  ('e r 2 = 037 r r 2 = 038 model statistics assessing the association between fibromyalgia',
#   1),
#  ('e r 2 = 041 r r 2 = 041 model statistics assessing the association between fibromyalgia',
#   1),
#  ('ided since fms often occurs when ra or sle is relatively mild the fact that fibromyalgia syndrome',
#   1),
#  ('is study aimed to assessing the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#   1),
#  ('says in the four cell lines figure 2a melanoma cell with the lowest level of cx43 expression',
#   1),
#  ('use in other model p = 084 table 1 characteristics of a us adult population by fibromyalgia',
#   1),
#  ('1 ci 1 06 2 16 disease table 2 health characteristics of a us adult population by fibromyalgia',
#   1),
#  ('37 39 hung et al showed that m csf potentiated lung cancer bone metastasis and that csf 1r',
#   1),
#  ('an incidence rate between 2 and 4 1 and a women men ratio 2 1 2 similar fibromyalgia',
#   1),
#  ('aor = 1 01 ci 1 00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#   1),
#  ('h age it is important to follow up these patients in later age for af risk fibromyalgia syndrome',
#   1),
#  ('nly before and 1 hour after the sham tms with mvc magnetic stimulation at the foramen magnum level',
#   1),
#  ('460 mg 0 243 mmol 81 g3 434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis',
#   1),
#  ('nd disease in case 5 a 45 year old caucasian woman with a history of ra and fibromyalgia syndrome',
#   1),
#  ('nts once daily for 8 weeks 1 fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg',
#   1),
#  ('1r', 0.0),
#  ('alone', 0.0),
#  ('expression', 0.0),
#  ('fluorenylmethoxycarbonyl', 0.0),
#  ('level', 0.0),
#  ('membrane', 0.0),
#  ('mg', 0.0),
#  ('of', 0.0),
#  ('oncogene', 0.0),
#  ('receptor', 0.0),
#  ('screening', 0.0),
#  ('silica', 0.0),
#  ('specialists', 0.0),
#  ('spectroscopy', 0.0),
#  ('status', 0.0),
#  ('stigma', 0.0),
#  ('stimulation', 0.0),
#  ('stream', 0.0),
#  ('syndrome', 0.0),
#  ('synthesis', 0.0),
#  ('system', 0.0),
#  ('1 receptor', 0.0),
#  ('120 mg', 0.0),
#  ('120mg fimasartan', 0.0),
#  ('2 fibromyalgia', 0.0),
#  ('9 fluorenylmethoxycarbonyl', 0.0),
#  ('allantochorion membrane', 0.0),
#  ('and fibromyalgia', 0.0),
#  ('between fibromyalgia', 0.0),
#  ('blockers fimasartan', 0.0),
#  ('by fibromyalgia', 0.0),
#  ('csf 1r', 0.0),
#  ('cx43 expression', 0.0),
#  ('groups fibromyalgia', 0.0),
#  ('magnum level', 0.0),
#  ('margin status', 0.0),
#  ('maydis stigma', 0.0),
#  ('medications fibromyalgia', 0.0),
#  ('medicine specialists', 0.0),
#  ('mesoporous silica', 0.0),
#  ('mg alone', 0.0),
#  ('migratory stream', 0.0),
#  ('mixture synthesis', 0.0),
#  ('modulation spectroscopy', 0.0),
#  ('motor skills', 0.0),
#  ('movement screening', 0.0),
#  ('movement skills', 0.0),
#  ('of fibromyalgia', 0.0),
#  ('or fibromyalgia', 0.0),
#  ('sarcoma oncogene', 0.0),
#  ('similar fibromyalgia', 0.0),
#  ('that fibromyalgia', 0.0),
#  ('time fibromyalgia', 0.0),
#  ('120 mg alone', 0.0),
#  ('2 similar fibromyalgia', 0.0),
#  ('and 120mg fimasartan', 0.0),
#  ('association between fibromyalgia', 0.0),
#  ('brain of fibromyalgia', 0.0),
#  ('cfs and fibromyalgia', 0.0),
#  ('diagnostic groups fibromyalgia', 0.0),
#  ('expression fibromyalgia syndrome', 0.0),
#  ('factors fibromyalgia syndrome', 0.0),
#  ('family medicine specialists', 0.0),
#  ('fewer medications fibromyalgia', 0.0),
#  ('fimasartan 120 mg', 0.0),
#  ('final margin status', 0.0),
#  ('fluid management system', 0.0),
#  ('foramen magnum level', 0.0),
#  ('forth 2 fibromyalgia', 0.0),
#  ('freeway management system', 0.0),
#  ('from fibromyalgia syndrome', 0.0),
#  ('from maydis stigma', 0.0),
#  ('functional movement screening', 0.0),
#  ('funicular migratory stream', 0.0),
#  ('groups fibromyalgia syndrome', 0.0),
#  ('include fibromyalgia syndrome', 0.0),
#  ('is fibromyalgia syndrome', 0.0),
#  ('management fibromyalgia syndrome', 0.0),
#  ('mcdonough sarcoma oncogene', 0.0),
#  ('of cx43 expression', 0.0),
#  ('over time fibromyalgia', 0.0),
#  ('painless magnetic stimulation', 0.0),
#  ('particularly fibromyalgia syndrome', 0.0),
#  ('patients fibromyalgia syndrome', 0.0),
#  ('peripheral fibromyalgia syndrome', 0.0),
#  ('population by fibromyalgia', 0.0),
#  ('receptor blockers fimasartan', 0.0),
#  ('regions fibromyalgia syndrome', 0.0),
#  ('risk fibromyalgia syndrome', 0.0),
#  ('shown that fibromyalgia', 0.0),
#  ('sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('symptoms fibromyalgia syndrome', 0.0),
#  ('that csf 1r', 0.0),
#  ('the allantochorion membrane', 0.0),
#  ('therapies fibromyalgia syndrome', 0.0),
#  ('tmd or fibromyalgia', 0.0),
#  ('1 2 similar fibromyalgia', 0.0),
#  ('11 functional mesoporous silica', 0.0),
#  ('2 fimasartan 120 mg', 0.0),
#  ('60mg and 120mg fimasartan', 0.0),
#  ('7 functional mesoporous silica', 0.0),
#  ('a fluorous mixture synthesis', 0.0),
#  ('a freeway management system', 0.0),
#  ('adult population by fibromyalgia', 0.0),
#  ('af risk fibromyalgia syndrome', 0.0),
#  ('and fluorous mixture synthesis', 0.0),
#  ('and fundamental movement skills', 0.0),
#  ('and that csf 1r', 0.0),
#  ('angiotensin receptor blockers fimasartan', 0.0),
#  ('association with fibromyalgia syndrome', 0.0),
#  ('bat is fibromyalgia syndrome', 0.0),
#  ('behavioral therapies fibromyalgia syndrome', 0.0),
#  ('between csf 1 receptor', 0.0),
#  ('between fundamental movement skills', 0.0),
#  ('brain regions fibromyalgia syndrome', 0.0),
#  ('by family medicine specialists', 0.0),
#  ('by functional magnetic stimulation', 0.0),
#  ('called fluorous mixture synthesis', 0.0),
#  ('criteria for fibromyalgia syndrome', 0.0),
#  ('css include fibromyalgia syndrome', 0.0),
#  ('disorder tmd or fibromyalgia', 0.0),
#  ('divergent fluorous mixture synthesis', 0.0),
#  ('either the allantochorion membrane', 0.0),
#  ('environmental factors fibromyalgia syndrome', 0.0),
#  ('etiology of fibromyalgia syndrome', 0.0),
#  ('etiopathology of fibromyalgia syndrome', 0.0),
#  ('extract from maydis stigma', 0.0),
#  ('fact that fibromyalgia syndrome', 0.0),
#  ('factors for fibromyalgia syndrome', 0.0),
#  ('factors functional movement screening', 0.0),
#  ('feature of fibromyalgia syndrome', 0.0),
#  ('feline mcdonough sarcoma oncogene', 0.0),
#  ('fimasartan 120 mg alone', 0.0),
#  ('fluid in fibromyalgia syndrome', 0.0),
#  ('for management fibromyalgia syndrome', 0.0),
#  ('gene expression fibromyalgia syndrome', 0.0),
#  ('in fundamental motor skills', 0.0),
#  ('invasive functional magnetic stimulation', 0.0),
#  ('known as fibromyalgia syndrome', 0.0),
#  ('level of cx43 expression', 0.0),
#  ('lives 1 fibromyalgia syndrome', 0.0),
#  ('major diagnostic groups fibromyalgia', 0.0),
#  ('markers over time fibromyalgia', 0.0),
#  ('of fms fibromyalgia syndrome', 0.0),
#  ('of functional magnetic stimulation', 0.0),
#  ('of fundamental motor skills', 0.0),
#  ('of the fibromyalgia syndrome', 0.0),
#  ('on final margin status', 0.0),
#  ('pain particularly fibromyalgia syndrome', 0.0),
#  ('partially peripheral fibromyalgia syndrome', 0.0),
#  ('patients groups fibromyalgia syndrome', 0.0),
#  ('people with fibromyalgia syndrome', 0.0),
#  ('points 1 fibromyalgia syndrome', 0.0),
#  ('postulated that fibromyalgia syndrome', 0.0),
#  ('previously shown that fibromyalgia', 0.0),
#  ('ra and fibromyalgia syndrome', 0.0),
#  ('risk in fibromyalgia syndrome', 0.0),
#  ('so forth 2 fibromyalgia', 0.0),
#  ('subsequent functional mesoporous silica', 0.0),
#  ('such as fibromyalgia syndrome', 0.0),
#  ('syndrome cfs and fibromyalgia', 0.0),
#  ('technology functional magnetic stimulation', 0.0),
#  ('termed funicular migratory stream', 0.0),
#  ('the association between fibromyalgia', 0.0),
#  ('the brain of fibromyalgia', 0.0),
#  ('the csf 1 receptor', 0.0),
#  ('the foramen magnum level', 0.0),
#  ('the symptoms fibromyalgia syndrome', 0.0),
#  ('tmd and fibromyalgia syndrome', 0.0),
#  ('treating fms fibromyalgia syndrome', 0.0),
#  ('trps and fibromyalgia syndrome', 0.0),
#  ('use fewer medications fibromyalgia', 0.0),
#  ('use fluid management system', 0.0),
#  ('women with fibromyalgia syndrome', 0.0),
#  ('1 7 functional mesoporous silica', 0.0),
#  ('2 1 2 similar fibromyalgia', 0.0),
#  ('9 patients with fibromyalgia syndrome', 0.0),
#  ('a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('ability of functional magnetic stimulation', 0.0),
#  ('aetiopathogenesis of the fibromyalgia syndrome', 0.0),
#  ('analogy termed funicular migratory stream', 0.0),
#  ('and behavioral therapies fibromyalgia syndrome', 0.0),
#  ('and so forth 2 fibromyalgia', 0.0),
#  ('and use fewer medications fibromyalgia', 0.0),
#  ('are partially peripheral fibromyalgia syndrome', 0.0),
#  ('arrhytmia risk in fibromyalgia syndrome', 0.0),
#  ('articular pain from fibromyalgia syndrome', 0.0),
#  ('assessing the association between fibromyalgia', 0.0),
#  ('association between csf 1 receptor', 0.0),
#  ('at the foramen magnum level', 0.0),
#  ('based on final margin status', 0.0),
2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('three major diagnostic groups fibromyalgia', 0.0),
#  ('treatment fimasartan 120 mg alone', 0.0),
#  ('undertaken prevalence of fibromyalgia syndrome', 0.0),
#  ('us adult population by fibromyalgia', 0.0),
#  ('widespread pain from fibromyalgia syndrome', 0.0),
#  ('115 inhibited feline mcdonough sarcoma oncogene', 0.0),
#  ('7 non invasive functional magnetic stimulation', 0.0),
#  ('a contributing factors functional movement screening', 0.0),
#  ('a recognized feature of fibromyalgia syndrome', 0.0),
#  ('a us adult population by fibromyalgia', 0.0),
#  ('activity and use fewer medications fibromyalgia', 0.0),
#  ('age for af risk fibromyalgia syndrome', 0.0),
#  ('and 9 patients with fibromyalgia syndrome', 0.0),
#  ('and the subsequent functional mesoporous silica', 0.0),
#  ('approved medications for management fibromyalgia syndrome', 0.0),
#  ('areas of fms patients fibromyalgia syndrome', 0.0),
#  ('awakening dormant brain regions fibromyalgia syndrome', 0.0),
#  ('based on gene expression fibromyalgia syndrome', 0.0),
#  ('be undertaken prevalence of fibromyalgia syndrome', 0.0),
#  ('bone metastasis and that csf 1r', 0.0),
#  ('by analogy termed funicular migratory stream', 0.0),
#  ('changes in the brain of fibromyalgia', 0.0),
#  ('chronic fatigue syndrome cfs and fibromyalgia', 0.0),
#  ('clinics led by family medicine specialists', 0.0),
#  ('column single use fluid management system', 0.0),
#  ('conditions a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('delivery 1 7 functional mesoporous silica', 0.0),
#  ('detection of either the allantochorion membrane', 0.0),
#  ('dose based on final margin status', 0.0),
#  ('education and behavioral therapies fibromyalgia syndrome', 0.0),
#  ('enzymes entrapped in functional mesoporous silica', 0.0),
#  ('exercise are partially peripheral fibromyalgia syndrome', 0.0),
#  ('flavonoid rich extract from maydis stigma', 0.0),
#  ('fms rsv 2 fimasartan 120 mg', 0.0),
#  ('generalized musculoskeletal pain particularly fibromyalgia syndrome', 0.0),
#  ('generalized tender points 1 fibromyalgia syndrome', 0.0),
#  ('genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('has been postulated that fibromyalgia syndrome', 0.0),
#  ('history of ra and fibromyalgia syndrome', 0.0),
#  ('impact of a freeway management system', 0.0),
#  ('in summary a fluorous mixture synthesis', 0.0),
#  ('in the etiology of fibromyalgia syndrome', 0.0),
#  ('in the etiopathology of fibromyalgia syndrome', 0.0),
#  ('in their lives 1 fibromyalgia syndrome', 0.0),
#  ('induces association between csf 1 receptor', 0.0),
#  ('latent constructs of fundamental motor skills', 0.0),
#  ('linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('markers in patients with fibromyalgia syndrome', 0.0),
#  ('mild the fact that fibromyalgia syndrome', 0.0),
#  ('myofascial temporomandibular disorder tmd or fibromyalgia', 0.0),
#  ('non articular pain from fibromyalgia syndrome', 0.0),
#  ('of cerebrospinal fluid in fibromyalgia syndrome', 0.0),
#  ('of oph in functional mesoporous silica', 0.0),
#  ('of three major diagnostic groups fibromyalgia', 0.0),
#  ('outcome of patients with fibromyalgia syndrome', 0.0),
#  ('pain conditions such as fibromyalgia syndrome', 0.0),
#  ('pain disorder tmd and fibromyalgia syndrome', 0.0),
#  ('pain involved bat is fibromyalgia syndrome', 0.0),
#  ('protein biocatalysis 11 functional mesoporous silica', 0.0),
#  ('ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('reappear of the symptoms fibromyalgia syndrome', 0.0),
#  ('receptor like the csf 1 receptor', 0.0),
#  ('relatively arrhytmia risk in fibromyalgia syndrome', 0.0),
#  ('relatively novel technology functional magnetic stimulation', 0.0),
#  ('respiratory muscle by functional magnetic stimulation', 0.0),
#  ('rsv treatment fimasartan 120 mg alone', 0.0),
#  ('safety of 60mg and 120mg fimasartan', 0.0),
#  ('sample of patients with fibromyalgia syndrome', 0.0),
#  ('sensitivity syndrome css include fibromyalgia syndrome', 0.0),
#  ('severity in fms patients fibromyalgia syndrome', 0.0),
#  ('spontaneously entrapped in functional mesoporous silica', 0.0),
#  ('statistics assessing the association between fibromyalgia', 0.0),
#  ('status in women with fibromyalgia syndrome', 0.0),
#  ('stimulation at the foramen magnum level', 0.0),
#  ('study in people with fibromyalgia syndrome', 0.0),
#  ('syndrome classically known as fibromyalgia syndrome', 0.0),
#  ('synergistic in treating fms fibromyalgia syndrome', 0.0),
#  ('synthesis dos and fluorous mixture synthesis', 0.0),
#  ('td pa and fundamental movement skills', 0.0),
#  ('test and so forth 2 fibromyalgia', 0.0),
#  ('that meets criteria for fibromyalgia syndrome', 0.0),
#  ('the ability of functional magnetic stimulation', 0.0),
#  ('the factors association with fibromyalgia syndrome', 0.0),
#  ('the lowest level of cx43 expression', 0.0),
#  ('the so called fluorous mixture synthesis', 0.0),
#  ('the text prevalence of fibromyalgia syndrome', 0.0),
#  ('their biological markers over time fibromyalgia', 0.0),
#  ('to other angiotensin receptor blockers fimasartan', 0.0),
#  ('trigger by environmental factors fibromyalgia syndrome', 0.0),
#  ('trigger points trps and fibromyalgia syndrome', 0.0),
#  ('with larger patients groups fibromyalgia syndrome', 0.0),
#  ('with presence of fms fibromyalgia syndrome', 0.0),
#  ('54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('71 in summary a fluorous mixture synthesis', 0.0),
#  ('a genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('a history of ra and fibromyalgia syndrome', 0.0),
#  ('a relatively novel technology functional magnetic stimulation', 0.0),
#  ('ams and the subsequent functional mesoporous silica', 0.0),
#  ('analysis of cerebrospinal fluid in fibromyalgia syndrome', 0.0),
#  ('and delivery 1 7 functional mesoporous silica', 0.0),
#  ('and generalized tender points 1 fibromyalgia syndrome', 0.0),
#  ('and safety of 60mg and 120mg fimasartan', 0.0),
#  ('and their biological markers over time fibromyalgia', 0.0),
#  ('anxiety relatively arrhytmia risk in fibromyalgia syndrome', 0.0),
#  ('as a contributing factors functional movement screening', 0.0),
#  ('assessing the ability of functional magnetic stimulation', 0.0),
#  ('association with presence of fms fibromyalgia syndrome', 0.0),
#  ('based sample of patients with fibromyalgia syndrome', 0.0),
#  ('be spontaneously entrapped in functional mesoporous silica', 0.0),
#  ('be synergistic in treating fms fibromyalgia syndrome', 0.0),
#  ('boost dose based on final margin status', 0.0),
#  ('by detection of either the allantochorion membrane', 0.0),
#  ('by linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  
#  ('role in the etiopathology of fibromyalgia syndrome', 0.0),
#  ('second column single use fluid management system', 0.0),
#  ('stimulation induces association between csf 1 receptor', 0.0),
#  ('stimulation respiratory muscle by functional magnetic stimulation', 0.0),
#  ('symptoms syndrome classically known as fibromyalgia syndrome', 0.0),
#  ('system pain conditions such as fibromyalgia syndrome', 0.0),
#  ('tas 115 inhibited feline mcdonough sarcoma oncogene', 0.0),
#  ('temporomandibular pain disorder tmd and fibromyalgia syndrome', 0.0),
#  ('the enzymes entrapped in functional mesoporous silica', 0.0),
#  ('the impact of a freeway management system', 0.0),
#  ('the latent constructs of fundamental motor skills', 0.0),
#  ('the reappear of the symptoms fibromyalgia syndrome', 0.0),
#  ('use the so called fluorous mixture synthesis', 0.0),
#  ('was by analogy termed funicular migratory stream', 0.0),
#  ('was study in people with fibromyalgia syndrome', 0.0),
#  ('widespread non articular pain from fibromyalgia syndrome', 0.0),
#  ('with myofascial temporomandibular disorder tmd or fibromyalgia', 0.0),
#  ('with the lowest level of cx43 expression', 0.0),
#  ('038 model statistics assessing the association between fibromyalgia', 0.0),
#  ('041 model statistics assessing the association between fibromyalgia', 0.0),
#  ('20 54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('20 mg fms rsv 2 fimasartan 120 mg', 0.0),
#  ('3 model statistics assessing the association between fibromyalgia', 0.0),
#  ('4 model statistics assessing the association between fibromyalgia', 0.0),
#  ('a role in the etiology of fibromyalgia syndrome', 0.0),
#  ('a role in the etiopathology of fibromyalgia syndrome', 0.0),
#  ('albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('among the latent constructs of fundamental motor skills', 0.0),
#  ('and anxiety relatively arrhytmia risk in fibromyalgia syndrome', 0.0),
#  ('and functional status in women with fibromyalgia syndrome', 0.0),
#  ('and inflammation markers in patients with fibromyalgia syndrome', 0.0),
#  ('assessing disease severity in fms patients fibromyalgia syndrome', 0.0),
#  ('be a genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('be performed with larger patients groups fibromyalgia syndrome', 0.0),
#  ('can be spontaneously entrapped in functional mesoporous silica', 0.0),
#  ('capable of awakening dormant brain regions fibromyalgia syndrome', 0.0),
#  ('cause the reappear of the symptoms fibromyalgia syndrome', 0.0),
#  ('cell with the lowest level of cx43 expression', 0.0),
#  ('chronic widespread non articular pain from fibromyalgia syndrome', 0.0),
#  ('community based sample of patients with fibromyalgia syndrome', 0.0),
#  ('csf stimulation induces association between csf 1 receptor', 0.0),
#  ('demonstrate morphological changes in the brain of fibromyalgia', 0.0),
#  ('diagnosis by detection of either the allantochorion membrane', 0.0),
#  ('diagnosis of chronic fatigue syndrome cfs and fibromyalgia', 0.0),
#  ('discussed in the text prevalence of fibromyalgia syndrome', 0.0),
#  ('effect of exercise are partially peripheral fibromyalgia syndrome', 0.0),
#  ('efficacy and safety of 60mg and 120mg fimasartan', 0.0),
#  ('exercise patients education and behavioral therapies fibromyalgia syndrome',
#   0.0),
#  ('experience chronic generalized musculoskeletal pain particularly fibromyalgia syndrome',
#   0.0),
#  ('fms possibly trigger by environmental factors fibromyalgia syndrome', 0.0),
#  ('formation was by analogy termed funicular migratory stream', 0.0),
#  ('growth factors receptor like the csf 1 receptor', 0.0),
#  ('ibs temporomandibular pain disorder tmd and fibromyalgia syndrome', 0.0),
#  ('identified as a contributing factors functional movement screening', 0.0),
#  ('in later age for af risk fibromyalgia syndrome', 0.0),
#  ('independently association with presence of fms fibromyalgia syndrome', 0.0),
#  ('investigate pregnancy outcome of patients with fibromyalgia syndrome', 0.0),
#  ('is relatively mild the fact that fibromyalgia syndrome', 0.0),
#  ('lower compared to other angiotensin receptor blockers fimasartan', 0.0),
#  ('lung cancer bone metastasis and that csf 1r', 0.0),
#  ('management can be undertaken prevalence of fibromyalgia syndrome', 0.0),
#  ('may be synergistic in treating fms fibromyalgia syndrome', 0.0),
#  ('measures the impact of a freeway management system', 0.0),
#  ('mg fms rsv treatment fimasartan 120 mg alone', 0.0),
#  ('mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('more physical activity and use fewer medications fibromyalgia', 0.0),
#  ('more system pain conditions such as fibromyalgia syndrome', 0.0),
#  ('moreover tas 115 inhibited feline mcdonough sarcoma oncogene', 0.0),
#  ('mpss from trigger points trps and fibromyalgia syndrome', 0.0),
#  ('multi symptoms syndrome classically known as fibromyalgia syndrome', 0.0),
#  ('muscle pain that meets criteria for fibromyalgia syndrome', 0.0),
#  ('mvc magnetic stimulation at the foramen magnum level', 0.0),
#  ('of a relatively novel technology functional magnetic stimulation', 0.0),
#  ('of ams and the subsequent functional mesoporous silica', 0.0),
#  ('pain and generalized tender points 1 fibromyalgia syndrome', 0.0),
#  ('pain relatively areas of fms patients fibromyalgia syndrome', 0.0),
#  ('pot use the so called fluorous mixture synthesis', 0.0),
#  ('primary care clinics led by family medicine specialists', 0.0),
#  ('processing of pain involved bat is fibromyalgia syndrome', 0.0),
#  ('release and delivery 1 7 functional mesoporous silica', 0.0),
#  ('rt boost dose based on final margin status', 0.0),
#  ('safety of flavonoid rich extract from maydis stigma', 0.0),
#  ('sensitivity is a recognized feature of fibromyalgia syndrome', 0.0),
#  ('series on approved medications for management fibromyalgia syndrome', 0.0),
#  ('sign freiberg test and so forth 2 fibromyalgia', 0.0),
#  ('silicate second column single use fluid management system', 0.0),
#  ('similar it has been postulated that fibromyalgia syndrome', 0.0),
#  ('some points in their lives 1 fibromyalgia syndrome', 0.0),
#  ('study assessing the ability of functional magnetic stimulation', 0.0),
#  ('symptoms and their biological markers over time fibromyalgia', 0.0),
#  ('synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome', 0.0),
#  ('that the enzymes entrapped in functional mesoporous silica', 0.0),
#  ('the immobilization of oph in functional mesoporous silica', 0.0),
#  ('the overlap of three major diagnostic groups fibromyalgia', 0.0),
#  ('this population based on gene expression fibromyalgia syndrome', 0.0),
#  ('to constipation 7 non invasive functional magnetic stimulation', 0.0),
#  ('to stimulation respiratory muscle by functional magnetic stimulation', 0.0),
#  ('typical development td pa and fundamental movement skills', 0.0),
#  ('under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('use in protein biocatalysis 11 functional mesoporous silica', 0.0),
#  ('with a history of ra and fibromyalgia syndrome', 0.0),
#  ('women men ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('women with myofascial temporomandibular disorder tmd or fibromyalgia', 0.0),
#  ('1 characteristics of a us adult population by fibromyalgia', 0.0),
#  ('142 mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('2 chronic widespread non articular pain from fibromyalgia syndrome', 0.0),
#  ('20 mg fms rsv treatment fimasartan 120 mg alone', 0.0),
#  ('= 038 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('= 041 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('a women men ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('activity and inflammation markers in patients with fibromyalgia syndrome',
#   0.0),
#  ('aerobic exercise patients education and behavioral therapies fibromyalgia syndrome',
#   0.0),
#  ('and independently association with presence of fms fibromyalgia syndrome',
#   0.0),
#  ('and management can be undertaken prevalence of fibromyalgia syndrome', 0.0),
#  ('and safety of flavonoid rich extract from maydis stigma', 0.0),
#  ('as more system pain conditions such as fibromyalgia syndrome', 0.0),
#  ('at some points in their lives 1 fibromyalgia syndrome', 0.0),
#  ('been discussed in the text prevalence of fibromyalgia syndrome', 0.0),
#  ('between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#   0.0),
#  ('biomarkers and functional status in women with fibromyalgia syndrome', 0.0),
#  ('both symptoms and their biological markers over time fibromyalgia', 0.0),
#  ('cell formation was by analogy termed funicular migratory stream', 0.0),
#  ('ciu similar it has been postulated that fibromyalgia syndrome', 0.0),
#  ('conducted to stimulation respiratory muscle by functional magnetic stimulation',
#   0.0),
#  ('consumption characteristics of a us adult population by fibromyalgia', 0.0),
#  ('controlled release and delivery 1 7 functional mesoporous silica', 0.0),
#  ('depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#   0.0),
#  ('do more physical activity and use fewer medications fibromyalgia', 0.0),
#  ('effect of a relatively novel technology functional magnetic stimulation',
#   0.0),
#  ('evaluate efficacy and safety of 60mg and 120mg fimasartan', 0.0),
#  ('fatigue identified as a contributing factors functional movement screening',
#   0.0),
#  ('for assessing disease severity in fms patients fibromyalgia syndrome', 0.0),
#  ('for rt boost dose based on final margin status', 0.0),
#  ('for use in protein biocatalysis 11 functional mesoporous silica', 0.0),
#  ('have demonstrate morphological changes in the brain of fibromyalgia', 0.0),
#  ('in pain relatively areas of fms patients fibromyalgia syndrome', 0.0),
#  ('in this population based on gene expression fibromyalgia syndrome', 0.0),
#  ('interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#   0.0),
#  ('lead to constipation 7 non invasive functional magnetic stimulation', 0.0),
#  ('m csf stimulation induces association between csf 1 receptor', 0.0),
#  ('may be a genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('medications may be synergistic in treating fms fibromyalgia syndrome', 0.0),
#  ('melanoma cell with the lowest level of cx43 expression', 0.0),
#  ('musculoskeletal pain and generalized tender points 1 fibromyalgia syndrome',
#   0.0),
#  ('neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#   0.0),
#  ('one pot use the so called fluorous mixture synthesis', 0.0),
#  ('oph can be spontaneously entrapped in functional mesoporous silica', 0.0),
#  ('osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#   0.0),
#  ('pace sign freiberg test and so forth 2 fibromyalgia', 0.0),
#  ('paper measures the impact of a freeway management system', 0.0),
#  ('part series on approved medications for management fibromyalgia syndrome',
#   0.0),
#  ('patients in later age for af risk fibromyalgia syndrome', 0.0),
#  ('play a role in the etiology of fibromyalgia syndrome', 0.0),
#  ('play a role in the etiopathology of fibromyalgia syndrome', 0.0),
#  ('potassium silicate second column single use fluid management system', 0.0),
#  ('potentiated lung cancer bone metastasis and that csf 1r', 0.0),
#  ('pregnancy diagnosis by detection of either the allantochorion membrane',
#   0.0),
#  ('public primary care clinics led by family medicine specialists', 0.0),
#  ('range 20 54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('relatively lower compared to other angiotensin receptor blockers fimasartan',
#   0.0),
#  ('relationships among the latent constructs of fundamental motor skills',
#   0.0),
#  ('rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg', 0.0),
#  ('should be performed with larger patients groups fibromyalgia syndrome',
#   0.0),
#  ('showed that the enzymes entrapped in functional mesoporous silica', 0.0),
#  ('shown the overlap of three major diagnostic groups fibromyalgia', 0.0),
#  ('sle is relatively mild the fact that fibromyalgia syndrome', 0.0),
#  ('small community based sample of patients with fibromyalgia syndrome', 0.0),
#  ('specificity the immobilization of oph in functional mesoporous silica',
#   0.0),
#  ('structure of ams and the subsequent functional mesoporous silica', 0.0),
#  ('syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#   0.0),
#  ('syndrome mpss from trigger points trps and fibromyalgia syndrome', 0.0),
#  ('table 3 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('table 4 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('that growth factors receptor like the csf 1 receptor', 0.0),
#  ('the diagnosis of chronic fatigue syndrome cfs and fibromyalgia', 0.0),
#  ('the effect of exercise are partially peripheral fibromyalgia syndrome',
#   0.0),
#  ('the multi symptoms syndrome classically known as fibromyalgia syndrome',
#   0.0),
#  ('the processing of pain involved bat is fibromyalgia syndrome', 0.0),
#  ('to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0),
#  ('to cause the reappear of the symptoms fibromyalgia syndrome', 0.0),
#  ('to fms possibly trigger by environmental factors fibromyalgia syndrome',
#   0.0),
#  ('widespread muscle pain that meets criteria for fibromyalgia syndrome', 0.0),
#  ('with mvc magnetic stimulation at the foramen magnum level', 0.0),
#  ('with typical development td pa and fundamental movement skills', 0.0),
#  ('woman with a history of ra and fibromyalgia syndrome', 0.0),
#  ('0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('01 table 3 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('1 2 chronic widespread non articular pain from fibromyalgia syndrome', 0.0),
#  ('2 = 038 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('2 = 041 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('2 health characteristics of a us adult population by fibromyalgia', 0.0),
#  ('2a melanoma cell with the lowest level of cx43 expression', 0.0),
#  ('32 range 20 54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('34 public primary care clinics led by family medicine specialists', 0.0),
#  ('a small community based sample of patients with fibromyalgia syndrome',
#   0.0),
#  ('activity in pain relatively areas of fms patients fibromyalgia syndrome',
#   0.0),
#  ('address both symptoms and their biological markers over time fibromyalgia',
#   0.0),
#  ('affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('alcohol consumption characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('allele may be a genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('and a women men ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('and aerobic exercise patients education and behavioral therapies fibromyalgia syndrome',
#   0.0),
#  ('and potassium silicate second column single use fluid management system',
#   0.0),
#  ('and the processing of pain involved bat is fibromyalgia syndrome', 0.0),
#  ('anxiety biomarkers and functional status in women with fibromyalgia syndrome',
#   0.0),
#  ('approved medications may be synergistic in treating fms fibromyalgia syndrome',
#   0.0),
#  ('bowel syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#   0.0),
#  ('by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#   0.0),
#  ('caucasian woman with a history of ra and fibromyalgia syndrome', 0.0),
#  ('chain cell formation was by analogy termed funicular migratory stream',
#   0.0),
#  ('children with typical development td pa and fundamental movement skills',
#   0.0),
#  ('csf potentiated lung cancer bone metastasis and that csf 1r', 0.0),
#  ('diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#   0.0),
#  ('disadvantages for use in protein biocatalysis 11 functional mesoporous silica',
#   0.0),
#  ('disease activity and inflammation markers in patients with fibromyalgia syndrome',
#   0.0),
#  ('disturbance health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#   0.0),
#  ('expected to cause the reappear of the symptoms fibromyalgia syndrome', 0.0),
#  ('fact that growth factors receptor like the csf 1 receptor', 0.0),
#  ('has been discussed in the text prevalence of fibromyalgia syndrome', 0.0),
#  ('have showed that the enzymes entrapped in functional mesoporous silica',
#   0.0),
# ...
#   0.0),
#  ('a three part series on approved medications for management fibromyalgia syndrome',
#   0.0),
#  ('accompanied by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#   0.0),
#  ('acute toxicity and safety of flavonoid rich extract from maydis stigma',
#   0.0),
#  ('additional research should be performed with larger patients groups fibromyalgia syndrome',
#   0.0),
#  ('age 32 range 20 54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('among a small community based sample of patients with fibromyalgia syndrome',
#   0.0),
#  ('and disadvantages for use in protein biocatalysis 11 functional mesoporous silica',
#   0.0),
#  ('as well as more system pain conditions such as fibromyalgia syndrome', 0.0),
#  ('association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#   0.0),
#  ('be predisposed to fms possibly trigger by environmental factors fibromyalgia syndrome',
#   0.0),
#  ('better outcome do more physical activity and use fewer medications fibromyalgia',
#   0.0),
#  ('brain activity in pain relatively areas of fms patients fibromyalgia syndrome',
#   0.0),
#  ('broad substrate specificity the immobilization of oph in functional mesoporous silica',
#   0.0),
#  ('chronic pain at some points in their lives 1 fibromyalgia syndrome', 0.0),
#  ('considered to play a role in the etiology of fibromyalgia syndrome', 0.0),
#  ('current alcohol consumption characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('dendrimers in one pot use the so called fluorous mixture synthesis', 0.0),
#  ('depression anxiety biomarkers and functional status in women with fibromyalgia syndrome',
#   0.0),
#  ('drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#   0.0),
#  ('e4 allele may be a genetic risk factors for fibromyalgia syndrome', 0.0),
#  ('effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#   0.0),
#  ('evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#   0.0),
#  ('factors may play a role in the etiopathology of fibromyalgia syndrome',
#   0.0),
#  ('figure 2a melanoma cell with the lowest level of cx43 expression', 0.0),
#  ('fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#   0.0),
#  ('illustrated that m csf stimulation induces association between csf 1 receptor',
#   0.0),
#  ('injury with fatigue identified as a contributing factors functional movement screening',
#   0.0),
#  ('institutional policy for rt boost dose based on final margin status', 0.0),
#  ('investigate the effect of a relatively novel technology functional magnetic stimulation',
#   0.0),
#  ('involved in ciu similar it has been postulated that fibromyalgia syndrome',
#   0.0),
#  ('involved in neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#   0.0),
#  ('irritable bowel syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#   0.0),
#  ('is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#   0.0),
#  ('left is shown the overlap of three major diagnostic groups fibromyalgia',
#   0.0),
#  ('level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#   0.0),
#  ('life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#   0.0),
#  ('m csf potentiated lung cancer bone metastasis and that csf 1r', 0.0),
#  ('mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone', 0.0),
#  ('of disturbance health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('old caucasian woman with a history of ra and fibromyalgia syndrome', 0.0),
#  ('or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#   0.0),
#  ('other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#   0.0),
#  ('pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#   0.0),
#  ('patients subgroups in this population based on gene expression fibromyalgia syndrome',
#   0.0),
#  ('patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#   0.0),
#  ('points trps between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#   0.0),
#  ('proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#   0.0),
#  ('r 2 = 038 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('r 2 = 041 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('ra or sle is relatively mild the fact that fibromyalgia syndrome', 0.0),
#  ('results have showed that the enzymes entrapped in functional mesoporous silica',
#   0.0),
#  ('rotation test pace sign freiberg test and so forth 2 fibromyalgia', 0.0),
#  ('sham tms with mvc magnetic stimulation at the foramen magnum level', 0.0),
#  ('silica and potassium silicate second column single use fluid management system',
#   0.0),
#  ('study has been discussed in the text prevalence of fibromyalgia syndrome',
#   0.0),
#  ('study was conducted to stimulation respiratory muscle by functional magnetic stimulation',
#   0.0),
#  ('table 2 health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('than children with typical development td pa and fundamental movement skills',
#   0.0),
#  ('that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#   0.0),
#  ('the chain cell formation was by analogy termed funicular migratory stream',
#   0.0),
#  ('the fact that growth factors receptor like the csf 1 receptor', 0.0),
#  ('the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#   0.0),
#  ('their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#   0.0),
#  ('thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#   0.0),
#  ('to address both symptoms and their biological markers over time fibromyalgia',
#   0.0),
#  ('to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#   0.0),
#  ('up these patients in later age for af risk fibromyalgia syndrome', 0.0),
#  ('was modest table 4 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('was significantly and independently association with presence of fms fibromyalgia syndrome',
#   0.0),
#  ('with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('year study have demonstrate morphological changes in the brain of fibromyalgia',
#   0.0),
#  ('00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone', 0.0),
#  ('4 1 and a women men ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('= 084 table 1 characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('abnormal brain activity in pain relatively areas of fms patients fibromyalgia syndrome',
#   0.0),
#  ('activity silica and potassium silicate second column single use fluid management system',
#   0.0),
#  ('and broad substrate specificity the immobilization of oph in functional mesoporous silica',
#   0.0),
#  ('and current alcohol consumption characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('and effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#   0.0),
#  ('apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#   0.0),
#  ('are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#   0.0),
#  ('are considered to play a role in the etiology of fibromyalgia syndrome',
#   0.0),
#  ('at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('average age 32 range 20 54 and 9 patients with fibromyalgia syndrome', 0.0),
#  ('be involved in ciu similar it has been postulated that fibromyalgia syndrome',
#   0.0),
#  ('derivative with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('determine patients subgroups in this population based on gene expression fibromyalgia syndrome',
#   0.0),
#  ('directed institutional policy for rt boost dose based on final margin status',
#   0.0),
#  ('disease table 2 health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#   0.0),
#  ('environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#   0.0),
#  ('experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#   0.0),
#  ('factors was modest table 4 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('far left is shown the overlap of three major diagnostic groups fibromyalgia',
#   0.0),
#  ('findings that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#   0.0),
#  ('fluorinated dendrimers in one pot use the so called fluorous mixture synthesis',
#   0.0),
#  ('fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#   0.0),
#  ('follow a the relationships among the latent constructs of fundamental motor skills',
#   0.0),
#  ('follow up these patients in later age for af risk fibromyalgia syndrome',
#   0.0),
#  ('for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#   0.0),
#  ('frequency of disturbance health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('half among a small community based sample of patients with fibromyalgia syndrome',
#   0.0),
#  ('has illustrated that m csf stimulation induces association between csf 1 receptor',
#   0.0),
#  ('hbot or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#   0.0),
#  ('in a three part series on approved medications for management fibromyalgia syndrome',
#   0.0),
#  ('in thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#   0.0),
#  ('internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#   0.0),
#  ('interventions to address both symptoms and their biological markers over time fibromyalgia',
#   0.0),
#  ('is to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#   0.0),
#  ('leptin level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#   0.0),
#  ('limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#   0.0),
#  ('lines figure 2a melanoma cell with the lowest level of cx43 expression',
#   0.0),
#  ('may be predisposed to fms possibly trigger by environmental factors fibromyalgia syndrome',
#   0.0),
#  ('of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#   0.0),
#  ('of injury with fatigue identified as a contributing factors functional movement screening',
#   0.0),
#  ('of life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#   0.0),
#  ('of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#   0.0),
#  ('often accompanied by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#   0.0),
#  ('on the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#   0.0),
#  ('pa than children with typical development td pa and fundamental movement skills',
#   0.0),
#  ('r r 2 = 038 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('r r 2 = 041 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('recent results have showed that the enzymes entrapped in functional mesoporous silica',
#   0.0),
#  ('signaling pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#   0.0),
#  ('single study has been discussed in the text prevalence of fibromyalgia syndrome',
#   0.0),
#  ('support the fact that growth factors receptor like the csf 1 receptor',
#   0.0),
#  ('that m csf potentiated lung cancer bone metastasis and that csf 1r', 0.0),
#  ('that proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#   0.0),
#  ('the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#   0.0),
#  ('the other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#   0.0),
#  ('the sham tms with mvc magnetic stimulation at the foramen magnum level',
#   0.0),
#  ('the year study have demonstrate morphological changes in the brain of fibromyalgia',
#   0.0),
#  ('thus the chain cell formation was by analogy termed funicular migratory stream',
#   0.0),
#  ('to evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#   0.0),
#  ('to investigate the effect of a relatively novel technology functional magnetic stimulation',
#   0.0),
#  ('treatment is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#   0.0),
#  ('when ra or sle is relatively mild the fact that fibromyalgia syndrome',
#   0.0),
#  ('with better outcome do more physical activity and use fewer medications fibromyalgia',
#   0.0),
#  ('year old caucasian woman with a history of ra and fibromyalgia syndrome',
#   0.0),
#  ('037 r r 2 = 038 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('041 r r 2 = 041 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('1 00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#   0.0),
#  ('1 fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg', 0.0),
#  ('16 disease table 2 health characteristics of a us adult population by fibromyalgia',
#   0.0),
#  ('4 activity silica and potassium silicate second column single use fluid management system',
#   0.0),
#  ('45 year old caucasian woman with a history of ra and fibromyalgia syndrome',
#   0.0),
#  ('a single study has been discussed in the text prevalence of fibromyalgia syndrome',
#   0.0),
#  ('activity pa than children with typical development td pa and fundamental movement skills',
#   0.0),
#  ('adult experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#   0.0),
#  ('after the sham tms with mvc magnetic stimulation at the foramen magnum level',
#   0.0),
#  ('al has illustrated that m csf stimulation induces association between csf 1 receptor',
#   0.0),
#  ('and 4 1 and a women men ratio 2 1 2 similar fibromyalgia', 0.0),
#  ('and endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#   0.0),
#  ('and environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#   0.0),
#  ('and for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#   0.0),
#  ('and internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#   0.0),
#  ('article in a three part series on approved medications for management fibromyalgia syndrome',
#   0.0),
#  ('as limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#   0.0),
#  ('assessing the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#   0.0),
#  ('cell lines figure 2a melanoma cell with the lowest level of cx43 expression',
#   0.0),
#  ('cell thus the chain cell formation was by analogy termed funicular migratory stream',
#   0.0),
#  ('cms are considered to play a role in the etiology of fibromyalgia syndrome',
#   0.0),
#  ('e4 apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#   0.0),
#  ('excretion of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#   0.0),
#  ('factors are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#   0.0),
#  ('g3 434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0),
#  ('half of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#   0.0),
#  ('ifnalpha2 at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#   0.0),
#  ('in fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#   0.0),
#  ...]

# %%
longforms0 = miners['FMS'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('fibromyalgia syndrome', 56.04347826086956)),
#  (1, ('fibromyalgia', 16.58823529411765)),
#  (2, ('functional mesoporous silica', 4.0)),
#  (3, ('skills', 3.0)),
#  (4, ('fluorous mixture synthesis', 3.0)),
#  (5, ('functional magnetic stimulation', 3.0)),
#  (6, ('fimasartan', 2.0)),
#  (7,
#   ('fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#    2.0))]

# %%
longforms0 = [(longform, score) for i, (longform, score) in enumerate(longforms0)
              if i not in [3, 7]]

# %%
list(enumerate(top))
# Out:
# [(0, ('fibromyalgia syndrome', 56.04347826086956)),
#  (1, ('fibromyalgia', 16.58823529411765)),
#  (2, ('with fibromyalgia syndrome', 4.285714285714286)),
#  (3, ('functional mesoporous silica', 4.0)),
#  (4, ('of fibromyalgia syndrome', 3.6)),
#  (5, ('skills', 3.0)),
#  (6, ('fluorous mixture synthesis', 3.0)),
#  (7, ('functional magnetic stimulation', 3.0)),
#  (8, ('model statistics assessing the association between fibromyalgia', 3.0)),
#  (9, ('patients with fibromyalgia syndrome', 2.5)),
#  (10, ('characteristics of a us adult population by fibromyalgia', 2.5)),
#  (11, ('fimasartan', 2.0)),
#  (12, ('1 fibromyalgia syndrome', 2.0)),
#  (13, ('and fibromyalgia syndrome', 2.0)),
#  (14, ('fundamental motor skills', 2.0)),
#  (15, ('fundamental movement skills', 2.0)),
#  (16,
#   ('fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#    2.0)),
#  (17,
#   ('dl c goals after fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#    2)),
#  (18,
#   ('sterol ldl c by fimasartan 120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#    2)),
#  (19, ('magnetic stimulation', 1.6)),
#  (20, ('in functional mesoporous silica', 1.3333333333333333)),
#  (21, ('management system', 1.0)),
#  (22, ('synthesis of', 1)),
#  (23, ('as fibromyalgia syndrome', 1.0)),
#  (24, ('csf 1 receptor', 1.0)),
#  (25, ('fms fibromyalgia syndrome', 1.0)),
#  (26, ('for fibromyalgia syndrome', 1.0)),
#  (27, ('frequency modulation spectroscopy', 1)),
#  (28, ('in fibromyalgia syndrome', 1.0)),
#  (29, ('that fibromyalgia syndrome', 1.0)),
#  (30, ('the fibromyalgia syndrome', 1.0)),
#  (31, ('2 sulfo 9 fluorenylmethoxycarbonyl', 1.0)),
#  (32, ('fms patients fibromyalgia syndrome', 1.0)),
#  (33, ('pain from fibromyalgia syndrome', 1.0)),
#  (34, ('prevalence of fibromyalgia syndrome', 1.0)),
#  (35, ('use painless magnetic stimulation', 1)),
#  (36, ('a divergent fluorous mixture synthesis', 1)),
#  (37, ('association between fundamental movement skills', 1)),
#  (38, ('entrapped in functional mesoporous silica', 1.0)),
#  (39, ('mastery in fundamental motor skills', 1)),
#  (40, ('of patients with fibromyalgia syndrome', 1.0)),
#  (41, ('background widespread pain from fibromyalgia syndrome', 1)),
#  (42, ('the aetiopathogenesis of the fibromyalgia syndrome', 1)),
#  (43, ('we have previously shown that fibromyalgia', 1)),
#  (44, ('central sensitivity syndrome css include fibromyalgia syndrome', 1)),
#  (45, ('diversity oriented synthesis dos and fluorous mixture synthesis', 1)),
#  (46, ('glycolysis was study in people with fibromyalgia syndrome', 1)),
#  (47, ('to examine the factors association with fibromyalgia syndrome', 1)),
#  (48,
#   ('health characteristics of a us adult population by fibromyalgia', 1.0)),
#  (49,
#   ('pain sensitivity is a recognized feature of fibromyalgia syndrome', 1)),
#  (50,
#   ('population experience chronic generalized musculoskeletal pain particularly fibromyalgia syndrome',
#    1)),
#  (51,
#   ('this study assessing the ability of functional magnetic stimulation', 1)),
#  (52,
#   ('to investigate pregnancy outcome of patients with fibromyalgia syndrome',
#    1)),
#  (53, ('this paper measures the impact of a freeway management system', 1)),
#  (54, ('to evaluate efficacy and safety of 60mg and 120mg fimasartan', 1)),
#  (55,
#   ('all 34 public primary care clinics led by family medicine specialists',
#    1)),
#  (56,
#   ('myofascial pain syndrome mpss from trigger points trps and fibromyalgia syndrome',
#    1)),
#  (57,
#   ('organophosphorus hydrolase oph can be spontaneously entrapped in functional mesoporous silica',
#    1)),
#  (58,
#   ('resistance and aerobic exercise patients education and behavioral therapies fibromyalgia syndrome',
#    1)),
#  (59,
#   ('spread nonarticular musculoskeletal pain and generalized tender points 1 fibromyalgia syndrome',
#    1)),
#  (60,
#   ('advantages and disadvantages for use in protein biocatalysis 11 functional mesoporous silica',
#    1)),
#  (61,
#   ('disease was significantly and independently association with presence of fms fibromyalgia syndrome',
#    1)),
#  (62,
#   ('es involved in neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#    1)),
#  (63,
#   ('fatigue depression anxiety biomarkers and functional status in women with fibromyalgia syndrome',
#    1)),
#  (64,
#   ('fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg', 1.0)),
#  (65,
#   ('ith irritable bowel syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#    1)),
#  (66,
#   ('rigger points trps between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#    1)),
#  (67,
#   ('this study was conducted to stimulation respiratory muscle by functional magnetic stimulation',
#    1)),
#  (68,
#   ('all findings that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#    1)),
#  (69,
#   ('avioral interventions to address both symptoms and their biological markers over time fibromyalgia',
#    1)),
#  (70,
#   ('dysregulation in thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#    1)),
#  (71,
#   ('ed signaling pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#    1)),
#  (72,
#   ('ency and broad substrate specificity the immobilization of oph in functional mesoporous silica',
#    1)),
#  (73,
#   ('entamicin derivative with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#    1)),
#  (74,
#   ('erum leptin level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#    1)),
#  (75,
#   ('fatigue often accompanied by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#    1)),
#  (76,
#   ('ffect on the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#    1)),
#  (77,
#   ('gene may be predisposed to fms possibly trigger by environmental factors fibromyalgia syndrome',
#    1)),
#  (78,
#   ('help determine patients subgroups in this population based on gene expression fibromyalgia syndrome',
#    1)),
#  (79,
#   ('ncreased frequency of disturbance health characteristics of a us adult population by fibromyalgia',
#    1)),
#  (80,
#   ('over the year study have demonstrate morphological changes in the brain of fibromyalgia',
#    1)),
#  (81,
#   ('with hbot or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#    1)),
#  (82,
#   ('16 our recent results have showed that the enzymes entrapped in functional mesoporous silica',
#    1)),
#  (83,
#   ('acco use and current alcohol consumption characteristics of a us adult population by fibromyalgia',
#    1)),
#  (84,
#   ('adduction and internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#    1)),
#  (85,
#   ('as so that proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#    1)),
#  (86,
#   ('ation with the other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#    1)),
#  (87,
#   ('cantly rectify abnormal brain activity in pain relatively areas of fms patients fibromyalgia syndrome',
#    1)),
#  (88,
#   ('ell as limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#    1)),
#  (89,
#   ('f these factors was modest table 4 model statistics assessing the association between fibromyalgia',
#    1)),
#  (90,
#   ('genetic and environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#    1)),
#  (91,
#   ('ha2 ifnalpha2 at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#    1)),
#  (92,
#   ('igation were to evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#    1)),
#  (93,
#   ('igh risk of injury with fatigue identified as a contributing factors functional movement screening',
#    1)),
#  (94,
#   ('k excretion of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#    1)),
#  (95,
#   ('roughly half of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#    1)),
#  (96,
#   ('s and for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#    1)),
#  (97,
#   ('sical activity pa than children with typical development td pa and fundamental movement skills',
#    1)),
#  (98,
#   ('so 4 activity silica and potassium silicate second column single use fluid management system',
#    1)),
#  (99,
#   ('these factors are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#    1)),
#  (100,
#   ('udy was to investigate the effect of a relatively novel technology functional magnetic stimulation',
#    1)),
#  (101,
#   ('xamine the follow a the relationships among the latent constructs of fundamental motor skills',
#    1)),
#  (102,
#   ('y in fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#    1)),
#  (103,
#   ('a prospective margin directed institutional policy for rt boost dose based on final margin status',
#    1)),
#  (104,
#   ('conditions with a single study has been discussed in the text prevalence of fibromyalgia syndrome',
#    1)),
#  (105,
#   ('cular stem cell thus the chain cell formation was by analogy termed funicular migratory stream',
#    1)),
#  (106,
#   ('e a simple and effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#    1)),
#  (107,
#   ('ildhood maltreatments cms are considered to play a role in the etiology of fibromyalgia syndrome',
#    1)),
#  (108,
#   ('l syndrome and endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#    1)),
#  (109,
#   ('lassifications on the far left is shown the overlap of three major diagnostic groups fibromyalgia',
#    1)),
#  (110,
#   ('of this study is to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#    1)),
#  (111,
#   ('on and quality of life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#    1)),
#  (112,
#   ('ral generations of fluorinated dendrimers in one pot use the so called fluorous mixture synthesis',
#    1)),
#  (113,
#   ('s demonstrate that half among a small community based sample of patients with fibromyalgia syndrome',
#    1)),
#  (114,
#   ('this last article in a three part series on approved medications for management fibromyalgia syndrome',
#    1)),
#  (115,
#   ('traying from the treatment is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#    1)),
#  (116,
#   ('wn but those with better outcome do more physical activity and use fewer medications fibromyalgia',
#    1)),
#  (117,
#   ('1 co administration of fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg',
#    1)),
#  (118,
#   ('by faccio et al has illustrated that m csf stimulation induces association between csf 1 receptor',
#    1)),
#  (119,
#   ('hether the apolipoprotein e4 apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#    1)),
#  (120,
#   ('nsiderable evidence exists to support the fact that growth factors receptor like the csf 1 receptor',
#    1)),
#  (121,
#   ('s nerve fibers may be involved in ciu similar it has been postulated that fibromyalgia syndrome',
#    1)),
#  (122,
#   ('ular joint disorder tmd average age 32 range 20 54 and 9 patients with fibromyalgia syndrome',
#    1)),
#  (123,
#   ('ver 20 of adult experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#    1)),
#  (124,
#   ('e r 2 = 037 r r 2 = 038 model statistics assessing the association between fibromyalgia',
#    1)),
#  (125,
#   ('e r 2 = 041 r r 2 = 041 model statistics assessing the association between fibromyalgia',
#    1)),
#  (126,
#   ('ided since fms often occurs when ra or sle is relatively mild the fact that fibromyalgia syndrome',
#    1)),
#  (127,
#   ('is study aimed to assessing the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#    1)),
#  (128,
#   ('says in the four cell lines figure 2a melanoma cell with the lowest level of cx43 expression',
#    1)),
#  (129,
#   ('use in other model p = 084 table 1 characteristics of a us adult population by fibromyalgia',
#    1)),
#  (130,
#   ('1 ci 1 06 2 16 disease table 2 health characteristics of a us adult population by fibromyalgia',
#    1)),
#  (131,
#   ('37 39 hung et al showed that m csf potentiated lung cancer bone metastasis and that csf 1r',
#    1)),
#  (132,
#   ('an incidence rate between 2 and 4 1 and a women men ratio 2 1 2 similar fibromyalgia',
#    1)),
#  (133,
#   ('aor = 1 01 ci 1 00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#    1)),
#  (134,
#   ('h age it is important to follow up these patients in later age for af risk fibromyalgia syndrome',
#    1)),
#  (135,
#   ('nly before and 1 hour after the sham tms with mvc magnetic stimulation at the foramen magnum level',
#    1)),
#  (136,
#   ('460 mg 0 243 mmol 81 g3 434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis',
#    1)),
#  (137,
#   ('nd disease in case 5 a 45 year old caucasian woman with a history of ra and fibromyalgia syndrome',
#    1)),
#  (138,
#   ('nts once daily for 8 weeks 1 fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg',
#    1)),
#  (139, ('1r', 0.0)),
#  (140, ('alone', 0.0)),
#  (141, ('expression', 0.0)),
#  (142, ('fluorenylmethoxycarbonyl', 0.0)),
#  (143, ('level', 0.0)),
#  (144, ('membrane', 0.0)),
#  (145, ('mg', 0.0)),
#  (146, ('of', 0.0)),
#  (147, ('oncogene', 0.0)),
#  (148, ('receptor', 0.0)),
#  (149, ('screening', 0.0)),
#  (150, ('silica', 0.0)),
#  (151, ('specialists', 0.0)),
#  (152, ('spectroscopy', 0.0)),
#  (153, ('status', 0.0)),
#  (154, ('stigma', 0.0)),
#  (155, ('stimulation', 0.0)),
#  (156, ('stream', 0.0)),
#  (157, ('syndrome', 0.0)),
#  (158, ('synthesis', 0.0)),
#  (159, ('system', 0.0)),
#  (160, ('1 receptor', 0.0)),
#  (161, ('120 mg', 0.0)),
#  (162, ('120mg fimasartan', 0.0)),
#  (163, ('2 fibromyalgia', 0.0)),
#  (164, ('9 fluorenylmethoxycarbonyl', 0.0)),
#  (165, ('allantochorion membrane', 0.0)),
#  (166, ('and fibromyalgia', 0.0)),
#  (167, ('between fibromyalgia', 0.0)),
#  (168, ('blockers fimasartan', 0.0)),
#  (169, ('by fibromyalgia', 0.0)),
#  (170, ('csf 1r', 0.0)),
#  (171, ('cx43 expression', 0.0)),
#  (172, ('groups fibromyalgia', 0.0)),
#  (173, ('magnum level', 0.0)),
#  (174, ('margin status', 0.0)),
#  (175, ('maydis stigma', 0.0)),
#  (176, ('medications fibromyalgia', 0.0)),
#  (177, ('medicine specialists', 0.0)),
#  (178, ('mesoporous silica', 0.0)),
#  (179, ('mg alone', 0.0)),
#  (180, ('migratory stream', 0.0)),
#  (181, ('mixture synthesis', 0.0)),
#  (182, ('modulation spectroscopy', 0.0)),
#  (183, ('motor skills', 0.0)),
#  (184, ('movement screening', 0.0)),
#  (185, ('movement skills', 0.0)),
#  (186, ('of fibromyalgia', 0.0)),
#  (187, ('or fibromyalgia', 0.0)),
#  (188, ('sarcoma oncogene', 0.0)),
#  (189, ('similar fibromyalgia', 0.0)),
#  (190, ('that fibromyalgia', 0.0)),
#  (191, ('time fibromyalgia', 0.0)),
#  (192, ('120 mg alone', 0.0)),
#  (193, ('2 similar fibromyalgia', 0.0)),
#  (194, ('and 120mg fimasartan', 0.0)),
#  (195, ('association between fibromyalgia', 0.0)),
#  (196, ('brain of fibromyalgia', 0.0)),
#  (197, ('cfs and fibromyalgia', 0.0)),
#  (198, ('diagnostic groups fibromyalgia', 0.0)),
#  (199, ('expression fibromyalgia syndrome', 0.0)),
#  (200, ('factors fibromyalgia syndrome', 0.0)),
#  (201, ('family medicine specialists', 0.0)),
#  (202, ('fewer medications fibromyalgia', 0.0)),
#  (203, ('fimasartan 120 mg', 0.0)),
#  (204, ('final margin status', 0.0)),
#  (205, ('fluid management system', 0.0)),
#  (206, ('foramen magnum level', 0.0)),
#  (207, ('forth 2 fibromyalgia', 0.0)),
#  (208, ('freeway management system', 0.0)),
#  (209, ('from fibromyalgia syndrome', 0.0)),
#  (210, ('from maydis stigma', 0.0)),
#  (211, ('functional movement screening', 0.0)),
#  (212, ('funicular migratory stream', 0.0)),
#  (213, ('groups fibromyalgia syndrome', 0.0)),
#  (214, ('include fibromyalgia syndrome', 0.0)),
#  (215, ('is fibromyalgia syndrome', 0.0)),
#  (216, ('management fibromyalgia syndrome', 0.0)),
#  (217, ('mcdonough sarcoma oncogene', 0.0)),
#  (218, ('of cx43 expression', 0.0)),
#  (219, ('over time fibromyalgia', 0.0)),
#  (220, ('painless magnetic stimulation', 0.0)),
#  (277, ('known as fibromyalgia syndrome', 0.0)),
#  (278, ('level of cx43 expression', 0.0)),
#  (279, ('lives 1 fibromyalgia syndrome', 0.0)),
#  (280, ('major diagnostic groups fibromyalgia', 0.0)),
#  (281, ('markers over time fibromyalgia', 0.0)),
#  (282, ('of fms fibromyalgia syndrome', 0.0)),
#  (283, ('of functional magnetic stimulation', 0.0)),
#  (284, ('of fundamental motor skills', 0.0)),
#  (285, ('of the fibromyalgia syndrome', 0.0)),
#  (286, ('on final margin status', 0.0)),
#  (287, ('pain particularly fibromyalgia syndrome', 0.0)),
#  (288, ('partially peripheral fibromyalgia syndrome', 0.0)),
#  (289, ('patients groups fibromyalgia syndrome', 0.0)),
#  (290, ('people with fibromyalgia syndrome', 0.0)),
#  (291, ('points 1 fibromyalgia syndrome', 0.0)),
#  (292, ('postulated that fibromyalgia syndrome', 0.0)),
#  (293, ('previously shown that fibromyalgia', 0.0)),
#  (294, ('ra and fibromyalgia syndrome', 0.0)),
#  (295, ('risk in fibromyalgia syndrome', 0.0)),
#  (296, ('so forth 2 fibromyalgia', 0.0)),
#  (297, ('subsequent functional mesoporous silica', 0.0)),
#  (298, ('such as fibromyalgia syndrome', 0.0)),
#  (299, ('syndrome cfs and fibromyalgia', 0.0)),
#  (300, ('technology functional magnetic stimulation', 0.0)),
#  (301, ('termed funicular migratory stream', 0.0)),
#  (302, ('the association between fibromyalgia', 0.0)),
#  (303, ('the brain of fibromyalgia', 0.0)),
#  (304, ('the csf 1 receptor', 0.0)),
#  (305, ('the foramen magnum level', 0.0)),
#  (306, ('the symptoms fibromyalgia syndrome', 0.0)),
#  (307, ('tmd and fibromyalgia syndrome', 0.0)),
#  (308, ('treating fms fibromyalgia syndrome', 0.0)),
#  (309, ('trps and fibromyalgia syndrome', 0.0)),
#  (310, ('use fewer medications fibromyalgia', 0.0)),
#  (311, ('use fluid management system', 0.0)),
#  (312, ('women with fibromyalgia syndrome', 0.0)),
#  (313, ('1 7 functional mesoporous silica', 0.0)),
#  (314, ('2 1 2 similar fibromyalgia', 0.0)),
#  (315, ('9 patients with fibromyalgia syndrome', 0.0)),
#  (316, ('a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (317, ('ability of functional magnetic stimulation', 0.0)),
#  (318, ('aetiopathogenesis of the fibromyalgia syndrome', 0.0)),
#  (319, ('analogy termed funicular migratory stream', 0.0)),
#  (320, ('and behavioral therapies fibromyalgia syndrome', 0.0)),
#  (321, ('and so forth 2 fibromyalgia', 0.0)),
#  (322, ('and use fewer medications fibromyalgia', 0.0)),
#  (323, ('are partially peripheral fibromyalgia syndrome', 0.0)),
#  (324, ('arrhytmia risk in fibromyalgia syndrome', 0.0)),
#  (325, ('articular pain from fibromyalgia syndrome', 0.0)),
#  (326, ('assessing the association between fibromyalgia', 0.0)),
#  (327, ('association between csf 1 receptor', 0.0)),
#  (328, ('at the foramen magnum level', 0.0)),
#  (329, ('based on final margin status', 0.0)),
#  (330, ('been postulated that fibromyalgia syndrome', 0.0)),
#  (331, ('biocatalysis 11 functional mesoporous silica', 0.0)),
#  (383, ('summary a fluorous mixture synthesis', 0.0)),
#  (384, ('syndrome css include fibromyalgia syndrome', 0.0)),
#  (385, ('temporomandibular disorder tmd or fibromyalgia', 0.0)),
#  (386, ('tender points 1 fibromyalgia syndrome', 0.0)),
#  (387, ('text prevalence of fibromyalgia syndrome', 0.0)),
#  (388, ('the etiology of fibromyalgia syndrome', 0.0)),
#  (389, ('the etiopathology of fibromyalgia syndrome', 0.0)),
#  (390, ('the fact that fibromyalgia syndrome', 0.0)),
#  (391, ('the subsequent functional mesoporous silica', 0.0)),
#  (392, ('their lives 1 fibromyalgia syndrome', 0.0)),
#  (393, ('three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (394, ('three major diagnostic groups fibromyalgia', 0.0)),
#  (395, ('treatment fimasartan 120 mg alone', 0.0)),
#  (396, ('undertaken prevalence of fibromyalgia syndrome', 0.0)),
#  (397, ('us adult population by fibromyalgia', 0.0)),
#  (398, ('widespread pain from fibromyalgia syndrome', 0.0)),
#  (399, ('115 inhibited feline mcdonough sarcoma oncogene', 0.0)),
#  (400, ('7 non invasive functional magnetic stimulation', 0.0)),
#  (401, ('a contributing factors functional movement screening', 0.0)),
#  (402, ('a recognized feature of fibromyalgia syndrome', 0.0)),
#  (403, ('a us adult population by fibromyalgia', 0.0)),
#  (404, ('activity and use fewer medications fibromyalgia', 0.0)),
#  (405, ('age for af risk fibromyalgia syndrome', 0.0)),
#  (406, ('and 9 patients with fibromyalgia syndrome', 0.0)),
#  (407, ('and the subsequent functional mesoporous silica', 0.0)),
#  (408, ('approved medications for management fibromyalgia syndrome', 0.0)),
#  (409, ('areas of fms patients fibromyalgia syndrome', 0.0)),
#  (410, ('awakening dormant brain regions fibromyalgia syndrome', 0.0)),
#  (411, ('based on gene expression fibromyalgia syndrome', 0.0)),
#  (412, ('be undertaken prevalence of fibromyalgia syndrome', 0.0)),
#  (413, ('bone metastasis and that csf 1r', 0.0)),
#  (414, ('by analogy termed funicular migratory stream', 0.0)),
#  (415, ('changes in the brain of fibromyalgia', 0.0)),
#  (416, ('chronic fatigue syndrome cfs and fibromyalgia', 0.0)),
#  (417, ('clinics led by family medicine specialists', 0.0)),
#  (418, ('column single use fluid management system', 0.0)),
#  (419, ('conditions a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (420, ('delivery 1 7 functional mesoporous silica', 0.0)),
#  (421, ('detection of either the allantochorion membrane', 0.0)),
#  (422, ('dose based on final margin status', 0.0)),
#  (423, ('education and behavioral therapies fibromyalgia syndrome', 0.0)),
#  (424, ('enzymes entrapped in functional mesoporous silica', 0.0)),
#  (425, ('exercise are partially peripheral fibromyalgia syndrome', 0.0)),
#  (426, ('flavonoid rich extract from maydis stigma', 0.0)),
#  (427, ('fms rsv 2 fimasartan 120 mg', 0.0)),
#  (428,
#   ('generalized musculoskeletal pain particularly fibromyalgia syndrome',
#    0.0)),
#  (429, ('generalized tender points 1 fibromyalgia syndrome', 0.0)),
#  (430, ('genetic risk factors for fibromyalgia syndrome', 0.0)),
#  (431, ('has been postulated that fibromyalgia syndrome', 0.0)),
#  (481, ('to other angiotensin receptor blockers fimasartan', 0.0)),
#  (482, ('trigger by environmental factors fibromyalgia syndrome', 0.0)),
#  (483, ('trigger points trps and fibromyalgia syndrome', 0.0)),
#  (484, ('with larger patients groups fibromyalgia syndrome', 0.0)),
#  (485, ('with presence of fms fibromyalgia syndrome', 0.0)),
#  (486, ('54 and 9 patients with fibromyalgia syndrome', 0.0)),
#  (487, ('71 in summary a fluorous mixture synthesis', 0.0)),
#  (488, ('a genetic risk factors for fibromyalgia syndrome', 0.0)),
#  (489, ('a history of ra and fibromyalgia syndrome', 0.0)),
#  (490, ('a relatively novel technology functional magnetic stimulation', 0.0)),
#  (491, ('ams and the subsequent functional mesoporous silica', 0.0)),
#  (492, ('analysis of cerebrospinal fluid in fibromyalgia syndrome', 0.0)),
#  (493, ('and delivery 1 7 functional mesoporous silica', 0.0)),
#  (494, ('and generalized tender points 1 fibromyalgia syndrome', 0.0)),
#  (495, ('and safety of 60mg and 120mg fimasartan', 0.0)),
#  (496, ('and their biological markers over time fibromyalgia', 0.0)),
#  (497, ('anxiety relatively arrhytmia risk in fibromyalgia syndrome', 0.0)),
#  (498, ('as a contributing factors functional movement screening', 0.0)),
#  (499, ('assessing the ability of functional magnetic stimulation', 0.0)),
#  (500, ('association with presence of fms fibromyalgia syndrome', 0.0)),
#  (501, ('based sample of patients with fibromyalgia syndrome', 0.0)),
#  (502, ('be spontaneously entrapped in functional mesoporous silica', 0.0)),
#  (503, ('be synergistic in treating fms fibromyalgia syndrome', 0.0)),
#  (504, ('boost dose based on final margin status', 0.0)),
#  (505, ('by detection of either the allantochorion membrane', 0.0)),
#  (506, ('by linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (507, ('can be undertaken prevalence of fibromyalgia syndrome', 0.0)),
#  (508, ('cancer bone metastasis and that csf 1r', 0.0)),
#  (509, ('care clinics led by family medicine specialists', 0.0)),
#  (510,
#   ('chronic generalized musculoskeletal pain particularly fibromyalgia syndrome',
#    0.0)),
#  (511, ('compared to other angiotensin receptor blockers fimasartan', 0.0)),
#  (512, ('constipation 7 non invasive functional magnetic stimulation', 0.0)),
#  (513, ('development td pa and fundamental movement skills', 0.0)),
#  (514, ('disease severity in fms patients fibromyalgia syndrome', 0.0)),
#  (515, ('examine the factors association with fibromyalgia syndrome', 0.0)),
#  (516, ('factors receptor like the csf 1 receptor', 0.0)),
#  (517, ('fms rsv treatment fimasartan 120 mg alone', 0.0)),
#  (518, ('freiberg test and so forth 2 fibromyalgia', 0.0)),
#  (519, ('from trigger points trps and fibromyalgia syndrome', 0.0)),
#  (520, ('functional status in women with fibromyalgia syndrome', 0.0)),
#  (521, ('immobilization of oph in functional mesoporous silica', 0.0)),
#  (522, ('in protein biocatalysis 11 functional mesoporous silica', 0.0)),
#  (523, ('in the text prevalence of fibromyalgia syndrome', 0.0)),
#  (524, ('inflammation markers in patients with fibromyalgia syndrome', 0.0)),
#  (525, ('is a recognized feature of fibromyalgia syndrome', 0.0)),
#  (526, ('it has been postulated that fibromyalgia syndrome', 0.0)),
#  (527, ('later age for af risk fibromyalgia syndrome', 0.0)),
#  (528, ('magnetic stimulation at the foramen magnum level', 0.0)),
#  (529, ('men ratio 2 1 2 similar fibromyalgia', 0.0)),
#  (530, ('mg fms rsv 2 fimasartan 120 mg', 0.0)),
#  (531, ('morphological changes in the brain of fibromyalgia', 0.0)),
#  (532, ('of a us adult population by fibromyalgia', 0.0)),
#  (533, ('of awakening dormant brain regions fibromyalgia syndrome', 0.0)),
#  (534, ('of chronic fatigue syndrome cfs and fibromyalgia', 0.0)),
#  (535, ('of exercise are partially peripheral fibromyalgia syndrome', 0.0)),
#  (536, ('of flavonoid rich extract from maydis stigma', 0.0)),
#  (537, ('of pain involved bat is fibromyalgia syndrome', 0.0)),
#  (538, ('on approved medications for management fibromyalgia syndrome', 0.0)),
#  (539, ('oriented synthesis dos and fluorous mixture synthesis', 0.0)),
#  (540, ('overlap of three major diagnostic groups fibromyalgia', 0.0)),
#  (541, ('pain that meets criteria for fibromyalgia syndrome', 0.0)),
#  (542,
#   ('patients education and behavioral therapies fibromyalgia syndrome', 0.0)),
#  (543, ('performed with larger patients groups fibromyalgia syndrome', 0.0)),
#  (544, ('physical activity and use fewer medications fibromyalgia', 0.0)),
#  (545, ('physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (546, ('points in their lives 1 fibromyalgia syndrome', 0.0)),
#  (547, ('population based on gene expression fibromyalgia syndrome', 0.0)),
#  (548,
#   ('possibly trigger by environmental factors fibromyalgia syndrome', 0.0)),
#  (549, ('pregnancy outcome of patients with fibromyalgia syndrome', 0.0)),
#  (550, ('relatively areas of fms patients fibromyalgia syndrome', 0.0)),
#  (551, ('relatively mild the fact that fibromyalgia syndrome', 0.0)),
#  (552, ('role in the etiology of fibromyalgia syndrome', 0.0)),
#  (553, ('role in the etiopathology of fibromyalgia syndrome', 0.0)),
#  (554, ('second column single use fluid management system', 0.0)),
#  (555, ('stimulation induces association between csf 1 receptor', 0.0)),
#  (556,
#   ('stimulation respiratory muscle by functional magnetic stimulation', 0.0)),
#  (557, ('symptoms syndrome classically known as fibromyalgia syndrome', 0.0)),
#  (558, ('system pain conditions such as fibromyalgia syndrome', 0.0)),
#  (559, ('tas 115 inhibited feline mcdonough sarcoma oncogene', 0.0)),
#  (560, ('temporomandibular pain disorder tmd and fibromyalgia syndrome', 0.0)),
#  (561, ('the enzymes entrapped in functional mesoporous silica', 0.0)),
#  (562, ('the impact of a freeway management system', 0.0)),
#  (563, ('the latent constructs of fundamental motor skills', 0.0)),
#  (564, ('the reappear of the symptoms fibromyalgia syndrome', 0.0)),
#  (565, ('use the so called fluorous mixture synthesis', 0.0)),
#  (566, ('was by analogy termed funicular migratory stream', 0.0)),
#  (567, ('was study in people with fibromyalgia syndrome', 0.0)),
#  (568, ('widespread non articular pain from fibromyalgia syndrome', 0.0)),
#  (569,
#   ('with myofascial temporomandibular disorder tmd or fibromyalgia', 0.0)),
#  (570, ('with the lowest level of cx43 expression', 0.0)),
#  (571,
#   ('038 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (572,
#   ('041 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (573, ('20 54 and 9 patients with fibromyalgia syndrome', 0.0)),
#  (574, ('20 mg fms rsv 2 fimasartan 120 mg', 0.0)),
#  (575,
#   ('3 model statistics assessing the association between fibromyalgia', 0.0)),
#  (576,
#   ('4 model statistics assessing the association between fibromyalgia', 0.0)),
#  (577, ('a role in the etiology of fibromyalgia syndrome', 0.0)),
#  (578, ('a role in the etiopathology of fibromyalgia syndrome', 0.0)),
#  (579, ('albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl', 0.0)),
#  (580, ('among the latent constructs of fundamental motor skills', 0.0)),
#  (581,
#   ('and anxiety relatively arrhytmia risk in fibromyalgia syndrome', 0.0)),
#  (582, ('and functional status in women with fibromyalgia syndrome', 0.0)),
#  (583,
#   ('and inflammation markers in patients with fibromyalgia syndrome', 0.0)),
#  (584,
#   ('assessing disease severity in fms patients fibromyalgia syndrome', 0.0)),
#  (585, ('be a genetic risk factors for fibromyalgia syndrome', 0.0)),
#  (586,
#   ('be performed with larger patients groups fibromyalgia syndrome', 0.0)),
#  (587,
#   ('can be spontaneously entrapped in functional mesoporous silica', 0.0)),
#  (588,
#   ('capable of awakening dormant brain regions fibromyalgia syndrome', 0.0)),
#  (589, ('cause the reappear of the symptoms fibromyalgia syndrome', 0.0)),
#  (590, ('cell with the lowest level of cx43 expression', 0.0)),
#  (591,
#   ('chronic widespread non articular pain from fibromyalgia syndrome', 0.0)),
#  (592, ('community based sample of patients with fibromyalgia syndrome', 0.0)),
#  (593, ('csf stimulation induces association between csf 1 receptor', 0.0)),
#  (594,
#   ('demonstrate morphological changes in the brain of fibromyalgia', 0.0)),
#  (595, ('diagnosis by detection of either the allantochorion membrane', 0.0)),
#  (596, ('diagnosis of chronic fatigue syndrome cfs and fibromyalgia', 0.0)),
#  (597, ('discussed in the text prevalence of fibromyalgia syndrome', 0.0)),
#  (598,
#   ('effect of exercise are partially peripheral fibromyalgia syndrome', 0.0)),
#  (599, ('efficacy and safety of 60mg and 120mg fimasartan', 0.0)),
#  (600,
#   ('exercise patients education and behavioral therapies fibromyalgia syndrome',
#    0.0)),
#  (601,
#   ('experience chronic generalized musculoskeletal pain particularly fibromyalgia syndrome',
#    0.0)),
#  (602,
#   ('fms possibly trigger by environmental factors fibromyalgia syndrome',
#    0.0)),
#  (603, ('formation was by analogy termed funicular migratory stream', 0.0)),
#  (604, ('growth factors receptor like the csf 1 receptor', 0.0)),
#  (605,
#   ('ibs temporomandibular pain disorder tmd and fibromyalgia syndrome', 0.0)),
#  (606,
#   ('identified as a contributing factors functional movement screening', 0.0)),
#  (607, ('in later age for af risk fibromyalgia syndrome', 0.0)),
#  (608,
#   ('independently association with presence of fms fibromyalgia syndrome',
#    0.0)),
#  (609,
#   ('investigate pregnancy outcome of patients with fibromyalgia syndrome',
#    0.0)),
#  (610, ('is relatively mild the fact that fibromyalgia syndrome', 0.0)),
#  (611,
#   ('lower compared to other angiotensin receptor blockers fimasartan', 0.0)),
#  (612, ('lung cancer bone metastasis and that csf 1r', 0.0)),
#  (613,
#   ('management can be undertaken prevalence of fibromyalgia syndrome', 0.0)),
#  (614, ('may be synergistic in treating fms fibromyalgia syndrome', 0.0)),
#  (615, ('measures the impact of a freeway management system', 0.0)),
#  (616, ('mg fms rsv treatment fimasartan 120 mg alone', 0.0)),
#  (617, ('mmol 71 in summary a fluorous mixture synthesis', 0.0)),
#  (618, ('more physical activity and use fewer medications fibromyalgia', 0.0)),
#  (619, ('more system pain conditions such as fibromyalgia syndrome', 0.0)),
#  (620, ('moreover tas 115 inhibited feline mcdonough sarcoma oncogene', 0.0)),
#  (621, ('mpss from trigger points trps and fibromyalgia syndrome', 0.0)),
#  (622,
#   ('multi symptoms syndrome classically known as fibromyalgia syndrome', 0.0)),
#  (623, ('muscle pain that meets criteria for fibromyalgia syndrome', 0.0)),
#  (624, ('mvc magnetic stimulation at the foramen magnum level', 0.0)),
#  (625,
#   ('of a relatively novel technology functional magnetic stimulation', 0.0)),
#  (626, ('of ams and the subsequent functional mesoporous silica', 0.0)),
#  (627, ('pain and generalized tender points 1 fibromyalgia syndrome', 0.0)),
#  (628, ('pain relatively areas of fms patients fibromyalgia syndrome', 0.0)),
#  (629, ('pot use the so called fluorous mixture synthesis', 0.0)),
#  (630, ('primary care clinics led by family medicine specialists', 0.0)),
#  (631, ('processing of pain involved bat is fibromyalgia syndrome', 0.0)),
#  (632, ('release and delivery 1 7 functional mesoporous silica', 0.0)),
#  (633, ('rt boost dose based on final margin status', 0.0)),
#  (634, ('safety of flavonoid rich extract from maydis stigma', 0.0)),
#  (635, ('sensitivity is a recognized feature of fibromyalgia syndrome', 0.0)),
#  (636,
#   ('series on approved medications for management fibromyalgia syndrome',
#    0.0)),
#  (637, ('sign freiberg test and so forth 2 fibromyalgia', 0.0)),
#  (638, ('silicate second column single use fluid management system', 0.0)),
#  (639, ('similar it has been postulated that fibromyalgia syndrome', 0.0)),
#  (640, ('some points in their lives 1 fibromyalgia syndrome', 0.0)),
#  (641,
#   ('study assessing the ability of functional magnetic stimulation', 0.0)),
#  (642, ('symptoms and their biological markers over time fibromyalgia', 0.0)),
#  (643,
#   ('synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome', 0.0)),
#  (644, ('that the enzymes entrapped in functional mesoporous silica', 0.0)),
#  (645, ('the immobilization of oph in functional mesoporous silica', 0.0)),
#  (646, ('the overlap of three major diagnostic groups fibromyalgia', 0.0)),
#  (647,
#   ('this population based on gene expression fibromyalgia syndrome', 0.0)),
#  (648,
#   ('to constipation 7 non invasive functional magnetic stimulation', 0.0)),
#  (649,
#   ('to stimulation respiratory muscle by functional magnetic stimulation',
#    0.0)),
#  (650, ('typical development td pa and fundamental movement skills', 0.0)),
#  (651,
#   ('under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#    0.0)),
#  (652, ('use in protein biocatalysis 11 functional mesoporous silica', 0.0)),
#  (653, ('with a history of ra and fibromyalgia syndrome', 0.0)),
#  (654, ('women men ratio 2 1 2 similar fibromyalgia', 0.0)),
#  (655,
#   ('women with myofascial temporomandibular disorder tmd or fibromyalgia',
#    0.0)),
#  (656, ('1 characteristics of a us adult population by fibromyalgia', 0.0)),
#  (657, ('142 mmol 71 in summary a fluorous mixture synthesis', 0.0)),
#  (658,
#   ('2 chronic widespread non articular pain from fibromyalgia syndrome', 0.0)),
#  (659, ('20 mg fms rsv treatment fimasartan 120 mg alone', 0.0)),
#  (660,
#   ('= 038 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (661,
#   ('= 041 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (662, ('a women men ratio 2 1 2 similar fibromyalgia', 0.0)),
#  (663,
#   ('activity and inflammation markers in patients with fibromyalgia syndrome',
#    0.0)),
#  (664,
#   ('aerobic exercise patients education and behavioral therapies fibromyalgia syndrome',
#    0.0)),
#  (665,
#   ('and independently association with presence of fms fibromyalgia syndrome',
#    0.0)),
#  (666,
#   ('and management can be undertaken prevalence of fibromyalgia syndrome',
#    0.0)),
#  (667, ('and safety of flavonoid rich extract from maydis stigma', 0.0)),
#  (668, ('as more system pain conditions such as fibromyalgia syndrome', 0.0)),
#  (669, ('at some points in their lives 1 fibromyalgia syndrome', 0.0)),
#  (670,
#   ('been discussed in the text prevalence of fibromyalgia syndrome', 0.0)),
#  (671,
#   ('between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#    0.0)),
#  (672,
#   ('biomarkers and functional status in women with fibromyalgia syndrome',
#    0.0)),
#  (673,
#   ('both symptoms and their biological markers over time fibromyalgia', 0.0)),
#  (674,
#   ('cell formation was by analogy termed funicular migratory stream', 0.0)),
#  (675, ('ciu similar it has been postulated that fibromyalgia syndrome', 0.0)),
#  (676,
#   ('conducted to stimulation respiratory muscle by functional magnetic stimulation',
#    0.0)),
#  (677,
#   ('consumption characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (678,
#   ('controlled release and delivery 1 7 functional mesoporous silica', 0.0)),
#  (679,
#   ('depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#    0.0)),
#  (680,
#   ('do more physical activity and use fewer medications fibromyalgia', 0.0)),
#  (681,
#   ('effect of a relatively novel technology functional magnetic stimulation',
#    0.0)),
#  (682, ('evaluate efficacy and safety of 60mg and 120mg fimasartan', 0.0)),
#  (683,
#   ('fatigue identified as a contributing factors functional movement screening',
#    0.0)),
#  (684,
#   ('for assessing disease severity in fms patients fibromyalgia syndrome',
#    0.0)),
#  (685, ('for rt boost dose based on final margin status', 0.0)),
#  (686,
#   ('for use in protein biocatalysis 11 functional mesoporous silica', 0.0)),
#  (687,
#   ('have demonstrate morphological changes in the brain of fibromyalgia',
#    0.0)),
#  (688,
#   ('in pain relatively areas of fms patients fibromyalgia syndrome', 0.0)),
#  (689,
#   ('in this population based on gene expression fibromyalgia syndrome', 0.0)),
#  (690,
#   ('interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#    0.0)),
#  (691,
#   ('lead to constipation 7 non invasive functional magnetic stimulation',
#    0.0)),
#  (692, ('m csf stimulation induces association between csf 1 receptor', 0.0)),
#  (693, ('may be a genetic risk factors for fibromyalgia syndrome', 0.0)),
#  (694,
#   ('medications may be synergistic in treating fms fibromyalgia syndrome',
#    0.0)),
#  (695, ('melanoma cell with the lowest level of cx43 expression', 0.0)),
#  (696,
#   ('musculoskeletal pain and generalized tender points 1 fibromyalgia syndrome',
#    0.0)),
#  (697,
#   ('neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#    0.0)),
#  (698, ('one pot use the so called fluorous mixture synthesis', 0.0)),
#  (699,
#   ('oph can be spontaneously entrapped in functional mesoporous silica', 0.0)),
#  (700,
#   ('osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#    0.0)),
#  (701, ('pace sign freiberg test and so forth 2 fibromyalgia', 0.0)),
#  (702, ('paper measures the impact of a freeway management system', 0.0)),
#  (703,
#   ('part series on approved medications for management fibromyalgia syndrome',
#    0.0)),
#  (704, ('patients in later age for af risk fibromyalgia syndrome', 0.0)),
#  (705, ('play a role in the etiology of fibromyalgia syndrome', 0.0)),
#  (706, ('play a role in the etiopathology of fibromyalgia syndrome', 0.0)),
#  (707,
#   ('potassium silicate second column single use fluid management system',
#    0.0)),
# ...
#  (845,
#   ('depression anxiety biomarkers and functional status in women with fibromyalgia syndrome',
#    0.0)),
#  (846,
#   ('drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#    0.0)),
#  (847,
#   ('e4 allele may be a genetic risk factors for fibromyalgia syndrome', 0.0)),
#  (848,
#   ('effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#    0.0)),
#  (849,
#   ('evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#    0.0)),
#  (850,
#   ('factors may play a role in the etiopathology of fibromyalgia syndrome',
#    0.0)),
#  (851,
#   ('figure 2a melanoma cell with the lowest level of cx43 expression', 0.0)),
#  (852,
#   ('fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#    0.0)),
#  (853,
#   ('illustrated that m csf stimulation induces association between csf 1 receptor',
#    0.0)),
#  (854,
#   ('injury with fatigue identified as a contributing factors functional movement screening',
#    0.0)),
#  (855,
#   ('institutional policy for rt boost dose based on final margin status',
#    0.0)),
#  (856,
#   ('investigate the effect of a relatively novel technology functional magnetic stimulation',
#    0.0)),
#  (857,
#   ('involved in ciu similar it has been postulated that fibromyalgia syndrome',
#    0.0)),
#  (858,
#   ('involved in neurotransmitter synthesis analysis of cerebrospinal fluid in fibromyalgia syndrome',
#    0.0)),
#  (859,
#   ('irritable bowel syndrome ibs temporomandibular pain disorder tmd and fibromyalgia syndrome',
#    0.0)),
#  (860,
#   ('is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#    0.0)),
#  (861,
#   ('left is shown the overlap of three major diagnostic groups fibromyalgia',
#    0.0)),
#  (862,
#   ('level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#    0.0)),
#  (863,
#   ('life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#    0.0)),
#  (864, ('m csf potentiated lung cancer bone metastasis and that csf 1r', 0.0)),
#  (865, ('mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0)),
#  (866,
#   ('mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone', 0.0)),
#  (867,
#   ('of disturbance health characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (868,
#   ('old caucasian woman with a history of ra and fibromyalgia syndrome', 0.0)),
#  (869,
#   ('or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#    0.0)),
#  (870,
#   ('other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#    0.0)),
#  (871,
#   ('pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#    0.0)),
#  (872,
#   ('patients subgroups in this population based on gene expression fibromyalgia syndrome',
#    0.0)),
#  (873,
#   ('patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#    0.0)),
#  (874,
#   ('points trps between women with myofascial temporomandibular disorder tmd or fibromyalgia',
#    0.0)),
#  (875,
#   ('proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#    0.0)),
#  (876,
#   ('r 2 = 038 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (877,
#   ('r 2 = 041 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (878,
#   ('ra or sle is relatively mild the fact that fibromyalgia syndrome', 0.0)),
#  (879,
#   ('results have showed that the enzymes entrapped in functional mesoporous silica',
#    0.0)),
#  (880,
#   ('rotation test pace sign freiberg test and so forth 2 fibromyalgia', 0.0)),
#  (881,
#   ('sham tms with mvc magnetic stimulation at the foramen magnum level', 0.0)),
#  (882,
#   ('silica and potassium silicate second column single use fluid management system',
#    0.0)),
#  (883,
#   ('study has been discussed in the text prevalence of fibromyalgia syndrome',
#    0.0)),
#  (884,
#   ('study was conducted to stimulation respiratory muscle by functional magnetic stimulation',
#    0.0)),
#  (885,
#   ('table 2 health characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (886,
#   ('than children with typical development td pa and fundamental movement skills',
#    0.0)),
#  (887,
#   ('that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#    0.0)),
#  (888,
#   ('the chain cell formation was by analogy termed funicular migratory stream',
#    0.0)),
#  (889, ('the fact that growth factors receptor like the csf 1 receptor', 0.0)),
#  (890,
#   ('the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#    0.0)),
#  (891,
#   ('their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#    0.0)),
#  (892,
#   ('thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#    0.0)),
#  (893,
#   ('to address both symptoms and their biological markers over time fibromyalgia',
#    0.0)),
#  (894,
#   ('to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#    0.0)),
#  (895,
#   ('up these patients in later age for af risk fibromyalgia syndrome', 0.0)),
#  (896,
#   ('was modest table 4 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (897,
#   ('was significantly and independently association with presence of fms fibromyalgia syndrome',
#    0.0)),
#  (898,
#   ('with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#    0.0)),
#  (899,
#   ('year study have demonstrate morphological changes in the brain of fibromyalgia',
#    0.0)),
#  (900,
#   ('00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (901,
#   ('120 mg rosuvastatin 20 mg fms rsv treatment fimasartan 120 mg alone',
#    0.0)),
#  (902, ('4 1 and a women men ratio 2 1 2 similar fibromyalgia', 0.0)),
#  (903, ('434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0)),
#  (904,
#   ('= 084 table 1 characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (905,
#   ('abnormal brain activity in pain relatively areas of fms patients fibromyalgia syndrome',
#    0.0)),
#  (906,
#   ('activity silica and potassium silicate second column single use fluid management system',
#    0.0)),
#  (907,
#   ('and broad substrate specificity the immobilization of oph in functional mesoporous silica',
#    0.0)),
#  (908,
#   ('and current alcohol consumption characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (909,
#   ('and effect tool for assessing disease severity in fms patients fibromyalgia syndrome',
#    0.0)),
#  (910,
#   ('apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#    0.0)),
#  (911,
#   ('are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#    0.0)),
#  (912,
#   ('are considered to play a role in the etiology of fibromyalgia syndrome',
#    0.0)),
#  (913,
#   ('at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#    0.0)),
#  (914,
#   ('average age 32 range 20 54 and 9 patients with fibromyalgia syndrome',
#    0.0)),
#  (915,
#   ('be involved in ciu similar it has been postulated that fibromyalgia syndrome',
#    0.0)),
#  (916,
#   ('derivative with affinity to albumin by linking three 2 sulfo 9 fluorenylmethoxycarbonyl',
#    0.0)),
#  (917,
#   ('determine patients subgroups in this population based on gene expression fibromyalgia syndrome',
#    0.0)),
#  (918,
#   ('directed institutional policy for rt boost dose based on final margin status',
#    0.0)),
#  (919,
#   ('disease table 2 health characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (920,
#   ('endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#    0.0)),
#  (921,
#   ('environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#    0.0)),
#  (922,
#   ('experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#    0.0)),
#  (923,
#   ('factors was modest table 4 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (924,
#   ('far left is shown the overlap of three major diagnostic groups fibromyalgia',
#    0.0)),
#  (925,
#   ('findings that suggest the effect of exercise are partially peripheral fibromyalgia syndrome',
#    0.0)),
#  (926,
#   ('fluorinated dendrimers in one pot use the so called fluorous mixture synthesis',
#    0.0)),
#  (927,
#   ('fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#    0.0)),
#  (928,
#   ('follow a the relationships among the latent constructs of fundamental motor skills',
#    0.0)),
#  (929,
#   ('follow up these patients in later age for af risk fibromyalgia syndrome',
#    0.0)),
#  (930,
#   ('for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#    0.0)),
#  (931,
#   ('frequency of disturbance health characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (932,
#   ('half among a small community based sample of patients with fibromyalgia syndrome',
#    0.0)),
#  (933,
#   ('has illustrated that m csf stimulation induces association between csf 1 receptor',
#    0.0)),
#  (934,
#   ('hbot or other interventions capable of awakening dormant brain regions fibromyalgia syndrome',
#    0.0)),
#  (935,
#   ('in a three part series on approved medications for management fibromyalgia syndrome',
#    0.0)),
#  (936,
#   ('in thermoregulation and the processing of pain involved bat is fibromyalgia syndrome',
#    0.0)),
#  (937,
#   ('internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#    0.0)),
#  (938,
#   ('interventions to address both symptoms and their biological markers over time fibromyalgia',
#    0.0)),
#  (939,
#   ('is to examine depression and anxiety relatively arrhytmia risk in fibromyalgia syndrome',
#    0.0)),
#  (940,
#   ('leptin level disease activity and inflammation markers in patients with fibromyalgia syndrome',
#    0.0)),
#  (941,
#   ('limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#    0.0)),
#  (942,
#   ('lines figure 2a melanoma cell with the lowest level of cx43 expression',
#    0.0)),
#  (943,
#   ('may be predisposed to fms possibly trigger by environmental factors fibromyalgia syndrome',
#    0.0)),
#  (944,
#   ('of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#    0.0)),
#  (945,
#   ('of injury with fatigue identified as a contributing factors functional movement screening',
#    0.0)),
#  (946,
#   ('of life 1 2 chronic widespread non articular pain from fibromyalgia syndrome',
#    0.0)),
#  (947,
#   ('of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#    0.0)),
#  (948,
#   ('often accompanied by widespread muscle pain that meets criteria for fibromyalgia syndrome',
#    0.0)),
#  (949,
#   ('on the intramesoporous structure of ams and the subsequent functional mesoporous silica',
#    0.0)),
#  (950,
#   ('pa than children with typical development td pa and fundamental movement skills',
#    0.0)),
#  (951,
#   ('r r 2 = 038 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (952,
#   ('r r 2 = 041 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (953,
#   ('recent results have showed that the enzymes entrapped in functional mesoporous silica',
#    0.0)),
#  (954,
#   ('signaling pathways in osteoclasts moreover tas 115 inhibited feline mcdonough sarcoma oncogene',
#    0.0)),
#  (955,
#   ('single study has been discussed in the text prevalence of fibromyalgia syndrome',
#    0.0)),
#  (956,
#   ('support the fact that growth factors receptor like the csf 1 receptor',
#    0.0)),
#  (957,
#   ('that m csf potentiated lung cancer bone metastasis and that csf 1r', 0.0)),
#  (958,
#   ('that proper diagnosis and management can be undertaken prevalence of fibromyalgia syndrome',
#    0.0)),
#  (959,
#   ('the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#    0.0)),
#  (960,
#   ('the other approved medications may be synergistic in treating fms fibromyalgia syndrome',
#    0.0)),
#  (961,
#   ('the sham tms with mvc magnetic stimulation at the foramen magnum level',
#    0.0)),
#  (962,
#   ('the year study have demonstrate morphological changes in the brain of fibromyalgia',
#    0.0)),
#  (963,
#   ('thus the chain cell formation was by analogy termed funicular migratory stream',
#    0.0)),
#  (964,
#   ('to evaluate the pregnancy diagnosis by detection of either the allantochorion membrane',
#    0.0)),
#  (965,
#   ('to investigate the effect of a relatively novel technology functional magnetic stimulation',
#    0.0)),
#  (966,
#   ('treatment is expected to cause the reappear of the symptoms fibromyalgia syndrome',
#    0.0)),
#  (967,
#   ('when ra or sle is relatively mild the fact that fibromyalgia syndrome',
#    0.0)),
#  (968,
#   ('with better outcome do more physical activity and use fewer medications fibromyalgia',
#    0.0)),
#  (969,
#   ('year old caucasian woman with a history of ra and fibromyalgia syndrome',
#    0.0)),
#  (970,
#   ('037 r r 2 = 038 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (971,
#   ('041 r r 2 = 041 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (972,
#   ('1 00 1 01 table 3 model statistics assessing the association between fibromyalgia',
#    0.0)),
#  (973,
#   ('1 fimasartan 120 mg rosuvastatin 20 mg fms rsv 2 fimasartan 120 mg', 0.0)),
#  (974,
#   ('16 disease table 2 health characteristics of a us adult population by fibromyalgia',
#    0.0)),
#  (975,
#   ('4 activity silica and potassium silicate second column single use fluid management system',
#    0.0)),
#  (976,
#   ('45 year old caucasian woman with a history of ra and fibromyalgia syndrome',
#    0.0)),
#  (977,
#   ('a single study has been discussed in the text prevalence of fibromyalgia syndrome',
#    0.0)),
#  (978,
#   ('activity pa than children with typical development td pa and fundamental movement skills',
#    0.0)),
#  (979,
#   ('adult experience chronic pain at some points in their lives 1 fibromyalgia syndrome',
#    0.0)),
#  (980,
#   ('after the sham tms with mvc magnetic stimulation at the foramen magnum level',
#    0.0)),
#  (981,
#   ('al has illustrated that m csf stimulation induces association between csf 1 receptor',
#    0.0)),
#  (982, ('and 4 1 and a women men ratio 2 1 2 similar fibromyalgia', 0.0)),
#  (983,
#   ('and endometriosis as well as more system pain conditions such as fibromyalgia syndrome',
#    0.0)),
#  (984,
#   ('and environmental factors may play a role in the etiopathology of fibromyalgia syndrome',
#    0.0)),
#  (985,
#   ('and for their subsequent controlled release and delivery 1 7 functional mesoporous silica',
#    0.0)),
#  (986,
#   ('and internal rotation test pace sign freiberg test and so forth 2 fibromyalgia',
#    0.0)),
#  (987,
#   ('article in a three part series on approved medications for management fibromyalgia syndrome',
#    0.0)),
#  (988,
#   ('as limiting drugs that lead to constipation 7 non invasive functional magnetic stimulation',
#    0.0)),
#  (989,
#   ('assessing the acute toxicity and safety of flavonoid rich extract from maydis stigma',
#    0.0)),
#  (990,
#   ('cell lines figure 2a melanoma cell with the lowest level of cx43 expression',
#    0.0)),
#  (991,
#   ('cell thus the chain cell formation was by analogy termed funicular migratory stream',
#    0.0)),
#  (992,
#   ('cms are considered to play a role in the etiology of fibromyalgia syndrome',
#    0.0)),
#  (993,
#   ('e4 apo e4 allele may be a genetic risk factors for fibromyalgia syndrome',
#    0.0)),
#  (994,
#   ('excretion of fms was relatively lower compared to other angiotensin receptor blockers fimasartan',
#    0.0)),
#  (995,
#   ('factors are association with the diagnosis of chronic fatigue syndrome cfs and fibromyalgia',
#    0.0)),
#  (996,
#   ('g3 434 mg 0 142 mmol 71 in summary a fluorous mixture synthesis', 0.0)),
#  (997,
#   ('half of patients with the multi symptoms syndrome classically known as fibromyalgia syndrome',
#    0.0)),
#  (998,
#   ('ifnalpha2 at a slow rate under physiological conditions a 2 sulfo 9 fluorenylmethoxycarbonyl',
#    0.0)),
#  (999,
#   ('in fms additional research should be performed with larger patients groups fibromyalgia syndrome',
#    0.0)),
#  ...]

# %%
longforms0.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [14, 15])

# %%
longforms = longforms0

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms)

# %%
longforms
# Out:
# ('fibromyalgia syndrome',
#  'fibromyalgia',
#  'functional mesoporous silica',
#  'fluorous mixture synthesis',
#  'functional magnetic stimulation',
#  'fimasartan',
#  'fundamental motor skills',
#  'fundamental movement skills')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'fibromyalgia': 'MESH:D005356', 'fimasartan': 'CHEBI:CHEBI:136044'}

# %%
names
# Out:
# {'MESH:D005356': 'Fibromyalgia', 'CHEBI:CHEBI:136044': 'fimasartan'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'fibromyalgia': 'MESH:D005356',
#   'fibromyalgia syndrome': 'MESH:D005356',
#   'fimasartan': 'CHEBI:CHEBI:136044',
#   'fluorous mixture synthesis': 'ungrounded',
#   'functional magnetic stimulation': 'MESH:D055909',
#   'functional mesoporous silica': 'ungrounded',
#   'fundamental motor skills': 'ungrounded',
#   'fundamental movement skills': 'ungrounded'},
#  {'MESH:D005356': 'Fibromyalgia',
#   'CHEBI:CHEBI:136044': 'fimasartan',
#   'MESH:D055909': 'Magnetic Field Therapy'},
#  ['CHEBI:CHEBI:136044', 'MESH:D005356', 'MESH:D055909'])

# %%
grounding_map, names, pos_labels = ({'fibromyalgia': 'MESH:D005356',
  'fibromyalgia syndrome': 'MESH:D005356',
  'fimasartan': 'CHEBI:CHEBI:136044',
  'fluorous mixture synthesis': 'ungrounded',
  'functional magnetic stimulation': 'MESH:D055909',
  'functional mesoporous silica': 'ungrounded',
  'fundamental motor skills': 'ungrounded',
  'fundamental movement skills': 'ungrounded'},
 {'MESH:D005356': 'Fibromyalgia',
  'CHEBI:CHEBI:136044': 'fimasartan',
  'MESH:D055909': 'Magnetic Field Therapy'},
 ['CHEBI:CHEBI:136044', 'MESH:D005356', 'MESH:D055909'])

# %%
names['HGNC:2433'] = 'CSF1R'

# %%
grounding_dict = {'FMS': grounding_map}

# %%
classifier = AdeftClassifier('FMS', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 16:25:03] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-27 16:25:20] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.875077399380805 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D005356': 47,
#   'MESH:D055909': 4,
#   'CHEBI:CHEBI:136044': 2,
#   'ungrounded': 12,
#   'HGNC:2433': 177},
#  'f1': {'mean': 0.875077399380805, 'std': 0.09671357324816807},
#  'precision': {'mean': 0.8790909090909091, 'std': 0.11590819964006711},
#  'recall': {'mean': 0.8732323232323231, 'std': 0.08463778552935038}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:2433']

# %%
a[2]
# Out:
# 'Approximately 25–40% of patients with lung cancer show bone metastasis. Bone modifying agents reduce skeletal-related events (SREs), but they do not significantly improve overall survival. Therefore, novel therapeutic approaches are urgently required. In this study, we investigated the anti-tumor effect of TAS-115, a VEGFRs and HGF receptor (MET)-targeted kinase inhibitor, in a tumor-induced bone disease model. A549-Luc-BM1 cells, an osteo-tropic clone of luciferase-transfected A549 human lung adenocarcinoma cells (A549-Luc), produced aggressive bone destruction associated with tumor progression after intra-tibial (IT) implantation into mice. TAS-115 significantly reduced IT tumor growth and bone destruction. Histopathological analysis showed a decrease in tumor vessels after TAS-115 treatment, which might be mediated through VEGFRs inhibition. Furthermore, the number of osteoclasts surrounding the tumor was decreased after TAS-115 treatment.  In vitro  studies demonstrated that TAS-115 inhibited HGF-, VEGF-, and macrophage-colony stimulating factor (M-CSF)-induced signaling pathways in osteoclasts. Moreover, TAS-115 inhibited Feline McDonough Sarcoma oncogene (FMS) kinase, as well as M-CSF and receptor activator of NF-κB ligand (RANKL)-induced osteoclast differentiation. Thus, VEGFRs/MET/FMS-triple inhibition in osteoclasts might contribute to the potent efficacy of TAS-115. The fact that concomitant dosing of sunitinib (VEGFRs/FMS inhibition) with crizotinib (MET inhibition) exerted comparable inhibitory efficacy for bone destruction to TAS-115 also supports this notion. In conclusion, TAS-115 inhibited tumor growth via VEGFR-kinase blockade, and also suppressed bone destruction possibly through VEGFRs/MET/FMS-kinase inhibition, which resulted in potent efficacy of TAS-115 in an A549-Luc-BM1 bone disease model. Thus, TAS-115 shows promise as a novel therapy for lung cancer patients with bone metastasis.\nHGF-MET and VEGF-VEGFR signaling pathways play important roles in bone metabolism. MET and VEGFR and their ligands, HGF and VEGF, respectively, are expressed in both osteoblasts and osteoclasts [ 6 ]. HGF-MET and VEGF-VEGFR signaling has been reported to engage in bone remodeling by promoting osteoclast differentiation/function and upregulating RANKL in osteoblasts [ 7 ,  8 ]. MET and VEGFR signaling also has pivotal roles in cancer progression and bone metastasis. Higher expression of MET was reported in bone metastasis patients [ 9 ,  10 ]. Plasma concentrations of VEGF were increased in patients with positive bone scans or histologic confirmation of cancer metastasis to pelvic lymph nodes [ 11 ]. VEGF-VEGFR signaling is well-known to play pivotal roles in tumor angiogenesis [ 12 ]. Cabozantinib, a small molecule VEGFRs and MET-targeted kinase inhibitor, has shown improvement in bone pain and reduction in narcotic use in patients with castration-resistant prostate cancer [ 13 ,  14 ]. These insights indicate that simultaneous inhibition of the VEGFR- and MET-axis is a reasonable therapeutic strategy for bone metastasis as targets for both tumor growth and abnormal bone metabolism. In addition to VEGFRs/MET signaling, FMS signaling is reported to have pivotal roles not only in bone metabolism but also in cancer bone metastasis. FMS, which was first discovered as the oncogene responsible for Feline McDonough Sarcoma, is a type III receptor tyrosine kinase that binds to the macrophage or monocyte colony-stimulating factor (M-CSF or CSF-1). Signal transduction as a result of that binding promotes the survival, proliferation, and differentiation of cells of the monocyte/macrophage lineage. Overexpression of CSF-1 and/or FMS has been implicated in a number of disease states such as in the growth and metastasis of certain types of cancer, in the promotion of osteoclast proliferation in bone osteolysis, and in many inflammatory disorders [ 15 ].\nTAS-115 is a potent VEGFRs and MET-targeted kinase inhibitor, and is currently in a  ...

# %%
disamb.dump('FMS', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('domain', 0.08492635500235372),
#  ('region', 0.0841391109644385),
#  ('nox', 0.08167855496471926),
#  ('bfgf', 0.07852529781557573),
#  ('glioma', 0.0754901259891954),
#  ('syk', 0.07470961043787495),
#  ('wasp', 0.0742950745186167),
#  ('oscc', 0.07402266033376588),
#  ('protein', 0.07386030185484761),
#  ('apoptotic', 0.07258466038676381),
#  ('neurons', 0.07164901466379286),
#  ('mapk', 0.0693512216241394),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
