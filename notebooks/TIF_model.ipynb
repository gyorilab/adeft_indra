# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['TIF']
genes = []
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['TIF'].top()

# %%
top
# Out:
# [('tubulointerstitial fibrosis', 39.07692307692308),
#  ('fibrosis', 10.734693877551024),
#  ('transoral incisionless fundoplication', 10.0),
#  ('telomere dysfunction induced foci', 9.83333333333333),
#  ('interstitial fluid', 9.222222222222221),
#  ('factor', 9.0),
#  ('renal tubulointerstitial fibrosis', 7.142857142857142),
#  ('tumor interstitial fluid', 6.4),
#  ('testicular interstitial fluid', 5.0),
#  ('the tumor interstitial fluid', 5.0),
#  ('fluid', 3.6000000000000014),
#  ('of tubulointerstitial fibrosis', 3.6),
#  ('the thalassaemia international federation', 3.6),
#  ('induced foci', 3.571428571428571),
#  ('interstitial fibrosis', 3.2),
#  ('transcription initiation factor', 3.0),
#  ('trypanosomal immunosuppressive factor', 3.0),
#  ('with tubulointerstitial fibrosis', 3.0),
#  ('tetraiodofluorescein', 2.0),
#  ('in renal tubulointerstitial fibrosis', 2.0),
#  ('of telomere dysfunction induced foci', 2.0),
#  ('53bp1 blue dapi right panels are magnified views of enlarged telomere dysfunction induced foci',
#   2),
#  ('totally impermeable film', 1.3333333333333333),
#  ('in tumor interstitial fluid', 1.3333333333333333),
#  ('enlarged telomere dysfunction induced foci', 1.3333333333333333),
#  ('interface fluid', 1.0),
#  ('and tubulointerstitial fibrosis', 1.0),
#  ('as tubulointerstitial fibrosis', 1),
#  ('chronic tubulointerstitial fibrosis', 1.0),
#  ('fibrosis tubulointerstitial fibrosis', 1.0),
#  ('is tubulointerstitial fibrosis', 1.0),
#  ('progression tubulointerstitial fibrosis', 1.0),
#  ('test information function', 1.0),
#  ('the dye tetraiodofluorescein', 1),
#  ('tissue interstitial fluid', 1),
#  ('tubular interstitial fibrosis', 1.0),
#  ('tubulo interstitial fibrosis', 1),
#  ('that tubule interstitial fibrosis', 1.0),
#  ('the types i fimbria', 1),
#  ('triton insoluble f actin', 1.0),
#  ('with totally impermeable film', 1.0),
#  ('a novel transoral incisionless fundoplication', 1),
#  ('as telomere dysfunction induced foci', 1.0),
#  ('the fundamental transcription initiation factor', 1),
#  ('the pathogenesis of tubulointerstitial fibrosis', 1.0),
#  ('and osteopontin in tumor interstitial fluid', 1.0),
#  ('magnetic sphincter augmentation msa transoral incisionless fundoplication',
#   1),
#  ('mild but significant glomerulosclerosis gs and tubulointerstitial fibrosis',
#   1),
#  ('the effects of alcohol on testicular interstitial fluid', 1),
#  ('to examine the associated between transient interface fluid', 1),
#  ('the hallmark of chronic kidney disease is tubulointerstitial fibrosis', 1),
#  ('ational organizations collaborated european project and the thalassaemia international federation',
#   1),
#  ('creased breakdown of the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#   1),
#  ('steroid resistant mesangial proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#   1),
#  ('tant tubulointerstitial inflammation and fibrosis the pathogenesis of tubulointerstitial fibrosis',
#   1),
#  ('tracellular matrix ecm production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#   1),
#  ('achieve resistant to tif without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#   1),
#  ('agc10 a t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#   1),
#  ('be endoflip technique might identified patients response to transoral incisionless fundoplication',
#   1),
#  ('d information and national registries wherever possible the thalassaemia international federation',
#   1),
#  ('ectively after six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#   1),
#  ('f soluble t cruzi immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#   1),
#  ('he mechanism of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   1),
#  ('it is not known whether t cruzi or trypanosomal immunosuppressive factor',
#   1),
#  ('ng against tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#   1),
#  ('phage production of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#   1),
#  ('2 at telomere under various shelterin perturbation conditions telomere dysfunction induced foci',
#   1),
#  ('atients and limited therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#   1),
#  ('by a protein spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#   1),
#  ('carrier rates and other figures were taken from the thalassaemia international federation',
#   1.0),
#  ('ce insertion 24 the esophyx device and the corresponding transoral incisionless fundoplication',
#   1),
#  ('erular injury caused by dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#   1),
#  ('ewer endoscopic approaches aimed to improve egj competence is transoral incisionless fundoplication',
#   1),
#  ('f telomere phenotypes were assessed qualitatively by imaging telomere deprotection induced foci',
#   1),
#  ('important for nuclear receptor activation including the src 1 transcription intermediary factor',
#   1),
#  ('moted tgf β induced epithelial mesenchymal transition emt and chronic tubulointerstitial fibrosis',
#   1),
#  ('n colonic microbiota and plasma metabolites and their relationship with tubulointerstitial fibrosis',
#   1),
#  ('nflammatory signaling pathway in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#   1),
#  ('ociated with the development of glomerulosclerosis and or progression tubular interstitial fibrosis',
#   1),
#  ('s with measurements of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#   1),
#  ('sease types 20 tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#   1),
#  ('shay 2015b telomere repeat amplification protocol trap and telomere dysfunction induced foci',
#   1),
#  ('6a hydroxymaackiain the proposed precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone',
#   1),
#  ('and gradually recovering during g1 progression we have shown that transcription initiation factor',
#   1),
#  ('been more extensively examine in the present stud ies in addition use tetraiodofluorescein',
#   1),
#  ('ellar fibrils we hypothesize that the presence of transient occult intraoperative interface fluid',
#   1),
#  ('elomere protection related function dysfunction telomere can be marked by telomere induced foci',
#   1),
#  ('eous injury pattern however the main pathology associated with aki is tubulointerstitial fibrosis',
#   1),
#  ('es events that contribute to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#   1),
#  ('ibrogenesis was evaluated the dose dependent biphasic effects of mk on tubulointerstitial fibrosis',
#   1),
#  ('ional solid fermentation production extract of trametes robiniophila murr huaier with radix isatidis',
#   1),
#  ('ips between a glomerulosclerosis and 16 week average systolic bp b tubulointerstitial fibrosis',
#   1),
#  ('marker of chronic kidney disease but also a crucial contributor to tubulointerstitial inflammation',
#   1),
#  ('nal fibrosis renal biopsy is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#   1),
#  ('nd losartan in a salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#   1),
#  ('nd the structural molecules comprising the extracellular matrix ecm the tumor interstitial fluid',
#   1),
#  ('onsistent with these observations nci h522 cells showed enlarged telomere dysfunction induced foci',
#   1),
#  ('or long termed outcomes and the occurrence of complications 4 transoral incisionless fundoplication',
#   1),
#  ('polymerase i binding to the eukaryotic ribosomal rna gene promoter transcription initiation factor',
#   1),
#  ('ssessed in the rat through measurements of serum testosterone levels testicular interstitial fluid',
#   1),
#  ('ssible carrier rates and other figures were taken from the thalassaemia international federation',
#   1),
#  ('t including tgfβ1 mmp9 timp2 and vimentin as important features of tubulointerstitial fibrosis',
#   1),
#  ('tives the fluorescence of 2 p toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein',
#   1),
#  ('were measurements at various time after initiation of these treatments testicular interstitial fluid',
#   1),
#  ('across gender was identified by wald test and expected score function test information function',
#   1),
#  ('as to examine the effects of imidazoles on testosterone secreted and testicular interstitial fluid',
#   1),
#  ('ata with histological subtype figo stage grade ca 125 concentration in tumor interstitial fluid',
#   1),
#  ('atterns we investigated the secreted glycome by profiling n glycans released from matched tumor',
#   1),
#  ('ave development a transgenic model of slowly development tgf beta 1 driven tubulointerstitial fibrosis',
#   1),
#  ('d cells with triciribine an akt specific inhibitor and analyzed telomere dysfunction induced foci',
#   1),
#  ('damage response factor and chromosome ends can be visualized as telomere dysfunction induced foci',
#   1),
#  ('e studies revealed that deletion of the smad3 gene protection against renal tubulointerstitial fibrosis',
#   1),
#  ('enal fibrosis remains unclear here we investigated the role of mdm2 in tubulointerstitial fibrosis',
#   1),
#  ('erstanding of cancer that is essential to design effects treatments the tumor interstitial fluid',
#   1),
#  ('et critically important factor of the tumor microenvironment tme is the tumor interstitial fluid',
#   1),
#  ('ional signaling events within the tumor stroma are implemented through the tumor interstitial fluid',
#   1),
#  ('item information function iif reliability of the scale was assessed by test information function',
#   1),
#  ('kly effects of rhuepo on csa induced renal injury were evaluated with tubulointerstitial fibrosis',
#   1),
#  ('n 5 carrier rates and other figures were taken from the thalassaemia international federation',
#   1),
#  ('n and representative a novel and promising therapeutic target for dn renal tubulointerstitial fibrosis',
#   1),
#  ('oxylin eosin h e periodic acid schiff pas and masson s trichrome tubulointerstitial fibrosis',
#   1),
#  ('progression and metastasis this studies focus on the contribute of the tumor interstitial fluid',
#   1),
#  ('rat by way of assessed of concentration of testosterone in serum testicular interstitial fluid',
#   1),
#  ('role and associated of these two distinct types of caspases in renal tubulointerstitial fibrosis',
#   1),
#  ('rowth factor hgf and monocyte chemotactic protein 1 mcp 1 in renal tubulointerstitial fibrosis',
#   1),
#  ('s generation in the kidney in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#   1),
#  ('saccharide lps induced expression of tnf alpha this activation termed tnf alpha inhibiting factor',
#   1),
#  ('signaling following injury plays a key role in the development of renal tubulointerstitial fibrosis',
#   1),
#  ('teasome and elongation factor 6 14 therefore may be generally important for up activation',
#   1),
#  ('telomere dna in hct116 cells revealed no significant change in telomere dysfunction induced foci',
#   1),
#  ('the limited dilution series allowed estimation of the csc number tumour initiation cells frequency',
#   1),
#  ('tly needed to address these problems in a systematic way the thalassaemia international federation',
#   1),
#  ('y contribute to the progression of dn however the pathogenic role of tubulointerstitial fibrosis',
#   1),
#  ('ach in the evolution of the surgical treatments of gerd is the transoral incisionless fundoplication',
#   1),
#  ('act gefv is not enough to exclude the diagnose of gerd 7 transoral incisionless fundoplication',
#   1),
#  ('ction after icl damage which is characterized by the presence of telomere dysfunction induced foci',
#   1),
#  ('h sigenome pool against loc283523 72 hrs post transfection gamma tubulin serves as loading control',
#   1),
#  ('hwestern for his assistance with the imaging and analysis part of telomere dysfunction induced foci',
#   1),
#  ('od1 it oligoubiquitinated forms and other unknown protein in the triton x 100 insoluble fraction',
#   1),
#  ('oes not change with temperature and is therefore referred to as the temperature independent factor',
#   1),
#  ('of kidney function over time a number of studies have indicated that tubule interstitial fibrosis',
#   1),
#  ('s been identified in diabetes but the pathogenesis of mir 27a in renal tubulointerstitial fibrosis',
#   1),
#  ('sent article reported a case of the safe and successful use of transoral incisionless fundoplication',
#   1),
#  ('ssue to plasma gradient quantification of ca 125 vegf and osteopontin in tumor interstitial fluid',
#   1),
#  ('the ability of rna polymerase i to read through a promoter bound transcription initiation factor',
#   1),
#  ('a number of renal disease in recent years it has been reported that tubule interstitial fibrosis',
#   1),
#  ('cancer and should be further explored ca 125 vegf a and osteopontin in tumor interstitial fluid',
#   1),
#  ('e the localization of ddr marker to telomere dna also known as telomere dysfunction induced foci',
#   1),
#  ('eir telomere integrity we first investigated the effects of ns depletion on the number of telomere',
#   1),
#  ('for transfection of sirnas in other than the 24 well format reagents were scale up accordingly',
#   1),
#  ('ig 3a or ar knockdown fig 3b f induced the format of telomere dysfunction induced foci',
#   1),
#  ('o ca usa and regularly tweet academic content to present and evaluated the twitter impact factor',
#   1),
#  ('orylation comparably to tef rnai this p38 activation required the p38 mapkk sek 1 right panels',
#   1),
#  ('pe baoding baoshuo plastic co ltd hebei province china and 0 04 mm totally impermeable film',
#   1),
#  ('s hypothesize to be 1000 to 1500 fold 4 the actual gradient between tumor interstitial fluid',
#   1),
#  ('sent review we focus on the interstitial fluid phase of solid tumor the tumor interstitial fluid',
#   1),
#  ('ses of death and has emerged as a crucial public health issue 1 renal tubulointerstitial fibrosis',
#   1),
#  ('ent description of distinct f actin pool coexisting with g actin in pmns triton insoluble f actin',
#   1),
#  ('in figures s2c all p < 0 05 comparably to control except where not significant is indicated by n',
#   1),
#  ('s can be visualized by the presence of foci referred to as t elomere dysfunction i nduced f oci',
#   1),
#  ('2 and pvha 6 dendra2 reported in animals exposed to control skn 1 eef 1a 1 tef or eif 1',
#   1),
#  ('bare soil 4 2 and 9 6 with polyethylene pe film 0 02 and 0 2 with totally impermeable film',
#   1),
#  ('is bound to the triton soluble f actin tsf pool and none is bound to the triton insoluble f actin',
#   1),
#  ('oil revealed that treatments of pic at the dose of 50 g m − 2 covered with totally impermeable film',
#   1),
#  ('re then centrifuged twice at 10000 × g at 4 ° c for 10 minutes to obtain triton x 100 resistant pellets',
#   1),
#  ('1', 0.0),
#  ('accordingly', 0.0),
#  ('actin', 0.0),
#  ('activation', 0.0),
#  ('control', 0.0),
#  ('federation', 0.0),
#  ('film', 0.0),
#  ('fimbria', 0.0),
#  ('foci', 0.0),
#  ('fraction', 0.0),
#  ('frequency', 0.0),
#  ('function', 0.0),
#  ('fundoplication', 0.0),
#  ('inflammation', 0.0),
#  ('isatidis', 0.0),
#  ('n', 0.0),
#  ('oci', 0.0),
#  ('panels', 0.0),
#  ('pellets', 0.0),
#  ('telomere', 0.0),
#  ('trihydroxyisoflavanone', 0.0),
#  ('tumor', 0.0),
#  ('4 trihydroxyisoflavanone', 0.0),
#  ('by n', 0.0),
#  ('cells frequency', 0.0),
#  ('dye tetraiodofluorescein', 0.0),
#  ('eif 1', 0.0),
#  ('f actin', 0.0),
#  ('f oci', 0.0),
#  ('i fimbria', 0.0),
#  ('immunosuppressive factor', 0.0),
#  ('impact factor', 0.0),
#  ('impermeable film', 0.0),
#  ('incisionless fundoplication', 0.0),
#  ('independent factor', 0.0),
#  ('information function', 0.0),
#  ('inhibiting factor', 0.0),
#  ('initiation factor', 0.0),
#  ('insoluble fraction', 0.0),
#  ('intermediary factor', 0.0),
#  ('international federation', 0.0),
#  ('loading control', 0.0),
#  ('matched tumor', 0.0),
#  ('of telomere', 0.0),
#  ('of tetraiodofluorescein', 0.0),
#  ('radix isatidis', 0.0),
#  ('resistant pellets', 0.0),
#  ('right panels', 0.0),
#  ('tubulointerstitial inflammation', 0.0),
#  ('tubulonterstitial fibrosis', 0.0),
#  ('up accordingly', 0.0),
#  ('up activation', 0.0),
#  ('use tetraiodofluorescein', 0.0),
#  ('1 right panels', 0.0),
#  ('100 insoluble fraction', 0.0),
#  ('100 resistant pellets', 0.0),
#  ('7 4 trihydroxyisoflavanone', 0.0),
#  ('addition use tetraiodofluorescein', 0.0),
#  ('alpha inhibiting factor', 0.0),
#  ('and of tetraiodofluorescein', 0.0),
#  ('and tubulonterstitial fibrosis', 0.0),
#  ('as loading control', 0.0),
#  ('b tubulointerstitial fibrosis', 0.0),
#  ('ccr tubulointerstitial fibrosis', 0.0),
#  ('deprotection induced foci', 0.0),
#  ('driven tubulointerstitial fibrosis', 0.0),
#  ('dysfunction induced foci', 0.0),
#  ('for up activation', 0.0),
#  ('from matched tumor', 0.0),
#  ('in tubulointerstitial fibrosis', 0.0),
#  ('indicated by n', 0.0),
#  ('initiation cells frequency', 0.0),
#  ('insoluble f actin', 0.0),
#  ('intraoperative interface fluid', 0.0),
#  ('nduced f oci', 0.0),
#  ('number of telomere', 0.0),
#  ('on tubulointerstitial fibrosis', 0.0),
#  ('or eif 1', 0.0),
#  ('scale up accordingly', 0.0),
#  ('striped tubulointerstitial fibrosis', 0.0),
#  ('telomere induced foci', 0.0),
#  ('temperature independent factor', 0.0),
#  ('thalassaemia international federation', 0.0),
#  ('tif tubulointerstitial fibrosis', 0.0),
#  ('to tubulointerstitial inflammation', 0.0),
#  ('toxicity tubulointerstitial fibrosis', 0.0),
#  ('transcription intermediary factor', 0.0),
#  ('transient interface fluid', 0.0),
#  ('trichrome tubulointerstitial fibrosis', 0.0),
#  ('tubule interstitial fibrosis', 0.0),
#  ('twitter impact factor', 0.0),
#  ('types i fimbria', 0.0),
#  ('with radix isatidis', 0.0),
#  ('without tubulointerstitial fibrosis', 0.0),
#  ('1 driven tubulointerstitial fibrosis', 0.0),
#  ('1 renal tubulointerstitial fibrosis', 0.0),
#  ('1 transcription intermediary factor', 0.0),
#  ('2 7 4 trihydroxyisoflavanone', 0.0),
#  ('4 transoral incisionless fundoplication', 0.0),
#  ('7 transoral incisionless fundoplication', 0.0),
#  ('against renal tubulointerstitial fibrosis', 0.0),
#  ('aki is tubulointerstitial fibrosis', 0.0),
#  ('and chronic tubulointerstitial fibrosis', 0.0),
#  ('and striped tubulointerstitial fibrosis', 0.0),
#  ('and testicular interstitial fluid', 0.0),
#  ('and tif tubulointerstitial fibrosis', 0.0),
#  ('and without tubulointerstitial fibrosis', 0.0),
#  ('associated chronic tubulointerstitial fibrosis', 0.0),
#  ('between transient interface fluid', 0.0),
#  ('between tumor interstitial fluid', 0.0),
#  ('both with tubulointerstitial fibrosis', 0.0),
#  ('bound transcription initiation factor', 0.0),
#  ('bp b tubulointerstitial fibrosis', 0.0),
#  ('by progression tubulointerstitial fibrosis', 0.0),
#  ('by telomere induced foci', 0.0),
#  ('by test information function', 0.0),
#  ('ckd and tubulonterstitial fibrosis', 0.0),
#  ('clearance ccr tubulointerstitial fibrosis', 0.0),
#  ('contributor to tubulointerstitial inflammation', 0.0),
#  ('corresponding transoral incisionless fundoplication', 0.0),
#  ('disease is tubulointerstitial fibrosis', 0.0),
#  ('dn renal tubulointerstitial fibrosis', 0.0),
#  ('evaluated with tubulointerstitial fibrosis', 0.0),
#  ('features of tubulointerstitial fibrosis', 0.0),
#  ('function test information function', 0.0),
#  ('fundamental transcription initiation factor', 0.0),
#  ('glomerulosclerosis and tubulointerstitial fibrosis', 0.0),
#  ('gs and tubulointerstitial fibrosis', 0.0),
#  ('hepatorenal toxicity tubulointerstitial fibrosis', 0.0),
#  ('huaier with radix isatidis', 0.0),
#  ('i nduced f oci', 0.0),
#  ('important for up activation', 0.0),
#  ('in addition use tetraiodofluorescein', 0.0),
#  ('is indicated by n', 0.0),
#  ('is transoral incisionless fundoplication', 0.0),
#  ('levels testicular interstitial fluid', 0.0),
#  ('mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('measurements fibrosis tubulointerstitial fibrosis', 0.0),
#  ('mk on tubulointerstitial fibrosis', 0.0),
#  ('mm totally impermeable film', 0.0),
#  ('msa transoral incisionless fundoplication', 0.0),
#  ('novel transoral incisionless fundoplication', 0.0),
#  ('occult intraoperative interface fluid', 0.0),
#  ('of renal tubulointerstitial fibrosis', 0.0),
#  ('of transoral incisionless fundoplication', 0.0),
#  ('on testicular interstitial fluid', 0.0),
#  ('or trypanosomal immunosuppressive factor', 0.0),
#  ('pathogenesis of tubulointerstitial fibrosis', 0.0),
#  ('photomicrographs of tubulointerstitial fibrosis', 0.0),
#  ('progression tubular interstitial fibrosis', 0.0),
#  ('promoter transcription initiation factor', 0.0),
#  ('rat with tubulointerstitial fibrosis', 0.0),
#  ('relationship with tubulointerstitial fibrosis', 0.0),
#  ('released from matched tumor', 0.0),
#  ('renal tubular interstitial fibrosis', 0.0),
#  ('role of tubulointerstitial fibrosis', 0.0),
#  ('s trichrome tubulointerstitial fibrosis', 0.0),
#  ('sek 1 right panels', 0.0),
#  ('serum testicular interstitial fluid', 0.0),
#  ('serves as loading control', 0.0),
#  ('tef or eif 1', 0.0),
#  ('telomere deprotection induced foci', 0.0),
#  ('termed trypanosomal immunosuppressive factor', 0.0),
#  ('testosterone testicular interstitial fluid', 0.0),
#  ('that transcription initiation factor', 0.0),
#  ('the number of telomere', 0.0),
#  ('the temperature independent factor', 0.0),
#  ('the transoral incisionless fundoplication', 0.0),
#  ('the trypanosomal immunosuppressive factor', 0.0),
#  ('the twitter impact factor', 0.0),
#  ('tnf alpha inhibiting factor', 0.0),
#  ('tns and of tetraiodofluorescein', 0.0),
#  ('to transoral incisionless fundoplication', 0.0),
#  ('treatments testicular interstitial fluid', 0.0),
#  ('tubulointerstitial fibrosis tubulointerstitial fibrosis', 0.0),
#  ('tumour initiation cells frequency', 0.0),
#  ('were scale up accordingly', 0.0),
#  ('with trypanosomal immunosuppressive factor', 0.0),
#  ('x 100 insoluble fraction', 0.0),
#  ('x 100 resistant pellets', 0.0),
#  ('04 mm totally impermeable film', 0.0),
#  ('1 in renal tubulointerstitial fibrosis', 0.0),
#  ('1 tef or eif 1', 0.0),
#  ('2 with totally impermeable film', 0.0),
#  ('27a in renal tubulointerstitial fibrosis', 0.0),
#  ('alcohol on testicular interstitial fluid', 0.0),
#  ('among rat with tubulointerstitial fibrosis', 0.0),
#  ('analyzed telomere dysfunction induced foci', 0.0),
#  ('and renal tubular interstitial fibrosis', 0.0),
#  ('and telomere dysfunction induced foci', 0.0),
#  ('and the thalassaemia international federation', 0.0),
#  ('as the temperature independent factor', 0.0),
#  ('assessed by test information function', 0.0),
#  ('associated between transient interface fluid', 0.0),
#  ('augmentation msa transoral incisionless fundoplication', 0.0),
#  ('beta 1 driven tubulointerstitial fibrosis', 0.0),
#  ('caspases in renal tubulointerstitial fibrosis', 0.0),
#  ('characterized by progression tubulointerstitial fibrosis', 0.0),
#  ('competence is transoral incisionless fundoplication', 0.0),
#  ('complications 4 transoral incisionless fundoplication', 0.0),
#  ('concentration in tumor interstitial fluid', 0.0),
#  ('conditions telomere dysfunction induced foci', 0.0),
#  ('correlated both with tubulointerstitial fibrosis', 0.0),
#  ('covered with totally impermeable film', 0.0),
#  ('creatinine clearance ccr tubulointerstitial fibrosis', 0.0),
#  ('crucial contributor to tubulointerstitial inflammation', 0.0),
#  ('cruzi or trypanosomal immunosuppressive factor', 0.0),
#  ('cyclosporin associated chronic tubulointerstitial fibrosis', 0.0),
#  ('development of renal tubulointerstitial fibrosis', 0.0),
#  ('disease ckd and tubulonterstitial fibrosis', 0.0),
#  ('dysfunction i nduced f oci', 0.0),
#  ('ecm the tumor interstitial fluid', 0.0),
#  ('ecm tubulointerstitial fibrosis tubulointerstitial fibrosis', 0.0),
#  ('emt and chronic tubulointerstitial fibrosis', 0.0),
#  ('evaluated the twitter impact factor', 0.0),
#  ('evident hepatorenal toxicity tubulointerstitial fibrosis', 0.0),
#  ('for dn renal tubulointerstitial fibrosis', 0.0),
#  ('for measurements fibrosis tubulointerstitial fibrosis', 0.0),
#  ('from the thalassaemia international federation', 0.0),
#  ('gene promoter transcription initiation factor', 0.0),
#  ('generally important for up activation', 0.0),
#  ('gerd 7 transoral incisionless fundoplication', 0.0),
#  ('glomerulosclerosis gs and tubulointerstitial fibrosis', 0.0),
#  ('glycans released from matched tumor', 0.0),
#  ('gradient between tumor interstitial fluid', 0.0),
#  ('ies in addition use tetraiodofluorescein', 0.0),
#  ('imaging telomere deprotection induced foci', 0.0),
#  ('important features of tubulointerstitial fibrosis', 0.0),
#  ('in glomerulosclerosis and tubulointerstitial fibrosis', 0.0),
#  ('in serum testicular interstitial fluid', 0.0),
#  ('in telomere dysfunction induced foci', 0.0),
#  ('including the trypanosomal immunosuppressive factor', 0.0),
#  ('indicated that tubule interstitial fibrosis', 0.0),
#  ('infiltration and striped tubulointerstitial fibrosis', 0.0),
#  ('inflammation and tif tubulointerstitial fibrosis', 0.0),
#  ('instead 2 7 4 trihydroxyisoflavanone', 0.0),
#  ('is the transoral incisionless fundoplication', 0.0),
#  ('is the tumor interstitial fluid', 0.0),
#  ('issue 1 renal tubulointerstitial fibrosis', 0.0),
#  ('kidney disease is tubulointerstitial fibrosis', 0.0),
#  ('mapkk sek 1 right panels', 0.0),
#  ('marked by telomere induced foci', 0.0),
#  ('masson s trichrome tubulointerstitial fibrosis', 0.0),
#  ('murr huaier with radix isatidis', 0.0),
#  ('nephrosis and without tubulointerstitial fibrosis', 0.0),
#  ('number tumour initiation cells frequency', 0.0),
#  ('of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('of mk on tubulointerstitial fibrosis', 0.0),
#  ('of the tumor interstitial fluid', 0.0),
#  ('on the number of telomere', 0.0),
#  ('or progression tubular interstitial fibrosis', 0.0),
#  ('osteopontin in tumor interstitial fluid', 0.0),
#  ('parasite termed trypanosomal immunosuppressive factor', 0.0),
#  ('pathogenic role of tubulointerstitial fibrosis', 0.0),
#  ('pmns triton insoluble f actin', 0.0),
#  ('possible the thalassaemia international federation', 0.0),
#  ('promoter bound transcription initiation factor', 0.0),
#  ('protection against renal tubulointerstitial fibrosis', 0.0),
#  ('reagents were scale up accordingly', 0.0),
#  ('reported that tubule interstitial fibrosis', 0.0),
#  ('representative photomicrographs of tubulointerstitial fibrosis', 0.0),
#  ('response to transoral incisionless fundoplication', 0.0),
#  ('score function test information function', 0.0),
#  ('secreted and testicular interstitial fluid', 0.0),
#  ('serum testosterone testicular interstitial fluid', 0.0),
#  ('shares with trypanosomal immunosuppressive factor', 0.0),
#  ('shown that transcription initiation factor', 0.0),
#  ('significant is indicated by n', 0.0),
#  ('src 1 transcription intermediary factor', 0.0),
#  ('sulfonate tns and of tetraiodofluorescein', 0.0),
#  ('systolic bp b tubulointerstitial fibrosis', 0.0),
#  ('termed tnf alpha inhibiting factor', 0.0),
#  ('testosterone levels testicular interstitial fluid', 0.0),
#  ('the corresponding transoral incisionless fundoplication', 0.0),
#  ('the triton insoluble f actin', 0.0),
#  ('their relationship with tubulointerstitial fibrosis', 0.0),
#  ('these treatments testicular interstitial fluid', 0.0),
#  ('through the tumor interstitial fluid', 0.0),
#  ('transient occult intraoperative interface fluid', 0.0),
#  ('treatments the tumor interstitial fluid', 0.0),
#  ('triton x 100 insoluble fraction', 0.0),
#  ('triton x 100 resistant pellets', 0.0),
#  ('tubulin serves as loading control', 0.0),
#  ('tumor the tumor interstitial fluid', 0.0),
#  ('use of transoral incisionless fundoplication', 0.0),
#  ('way the thalassaemia international federation', 0.0),
#  ('were evaluated with tubulointerstitial fibrosis', 0.0),
#  ('with aki is tubulointerstitial fibrosis', 0.0),
#  ('0 04 mm totally impermeable film', 0.0),
#  ('0 2 with totally impermeable film', 0.0),
#  ('125 concentration in tumor interstitial fluid', 0.0),
#  ('1a 1 tef or eif 1', 0.0),
#  ('2 covered with totally impermeable film', 0.0),
#  ('6 sulfonate tns and of tetraiodofluorescein', 0.0),
#  ('a crucial contributor to tubulointerstitial inflammation', 0.0),
#  ('a promoter bound transcription initiation factor', 0.0),
#  ('activation termed tnf alpha inhibiting factor', 0.0),
#  ('actual gradient between tumor interstitial fluid', 0.0),
#  ('and analyzed telomere dysfunction induced foci', 0.0),
#  ('and evaluated the twitter impact factor', 0.0),
#  ('and masson s trichrome tubulointerstitial fibrosis', 0.0),
#  ('and or progression tubular interstitial fibrosis', 0.0),
#  ('and the corresponding transoral incisionless fundoplication', 0.0),
#  ('and their relationship with tubulointerstitial fibrosis', 0.0),
#  ('as important features of tubulointerstitial fibrosis', 0.0),
#  ('associated with aki is tubulointerstitial fibrosis', 0.0),
#  ('average systolic bp b tubulointerstitial fibrosis', 0.0),
#  ('be generally important for up activation', 0.0),
#  ('be marked by telomere induced foci', 0.0),
#  ('been reported that tubule interstitial fibrosis', 0.0),
#  ('by imaging telomere deprotection induced foci', 0.0),
#  ('cells infiltration and striped tubulointerstitial fibrosis', 0.0),
#  ('change in telomere dysfunction induced foci', 0.0),
#  ('chronic kidney disease is tubulointerstitial fibrosis', 0.0),
#  ('component shares with trypanosomal immunosuppressive factor', 0.0),
#  ('contribute of the tumor interstitial fluid', 0.0),
#  ('csc number tumour initiation cells frequency', 0.0),
#  ('depletion on the number of telomere', 0.0),
#  ('effects of mk on tubulointerstitial fibrosis', 0.0),
#  ('effects treatments the tumor interstitial fluid', 0.0),
#  ('egj competence is transoral incisionless fundoplication', 0.0),
#  ('elomere dysfunction i nduced f oci', 0.0),
#  ('expected score function test information function', 0.0),
#  ('expression correlated both with tubulointerstitial fibrosis', 0.0),
#  ('fibrosis the pathogenesis of tubulointerstitial fibrosis', 0.0),
#  ('format of telomere dysfunction induced foci', 0.0),
#  ('format reagents were scale up accordingly', 0.0),
#  ('gamma tubulin serves as loading control', 0.0),
#  ('gene protection against renal tubulointerstitial fibrosis', 0.0),
#  ('gerd is the transoral incisionless fundoplication', 0.0),
#  ('glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('have indicated that tubule interstitial fibrosis', 0.0),
#  ('have shown that transcription initiation factor', 0.0),
#  ('health issue 1 renal tubulointerstitial fibrosis', 0.0),
#  ('hormone serum testosterone testicular interstitial fluid', 0.0),
#  ('implemented through the tumor interstitial fluid', 0.0),
#  ('in pmns triton insoluble f actin', 0.0),
#  ('injury representative photomicrographs of tubulointerstitial fibrosis',
#   0.0),
#  ('injury were evaluated with tubulointerstitial fibrosis', 0.0),
#  ('known as telomere dysfunction induced foci', 0.0),
#  ('kovacs the pathogenesis of tubulointerstitial fibrosis', 0.0),
#  ('matrix ecm the tumor interstitial fluid', 0.0),
#  ('mcp 1 in renal tubulointerstitial fibrosis', 0.0),
#  ('mesp nephrosis and without tubulointerstitial fibrosis', 0.0),
#  ('mir 27a in renal tubulointerstitial fibrosis', 0.0),
#  ('molecules including the trypanosomal immunosuppressive factor', 0.0),
#  ('n glycans released from matched tumor', 0.0),
#  ('nephrotoxicity and renal tubular interstitial fibrosis', 0.0),
#  ('nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   0.0),
#  ('not significant is indicated by n', 0.0),
#  ('obtain triton x 100 resistant pellets', 0.0),
#  ('of alcohol on testicular interstitial fluid', 0.0),
#  ('of caspases in renal tubulointerstitial fibrosis', 0.0),
#  ('of complications 4 transoral incisionless fundoplication', 0.0),
#  ('of cyclosporin associated chronic tubulointerstitial fibrosis', 0.0),
#  ('of enlarged telomere dysfunction induced foci', 0.0),
#  ('of gerd 7 transoral incisionless fundoplication', 0.0),
#  ('of inflammation and tif tubulointerstitial fibrosis', 0.0),
#  ('of these treatments testicular interstitial fluid', 0.0),
#  ('of transient occult intraoperative interface fluid', 0.0),
#  ('p38 mapkk sek 1 right panels', 0.0),
#  ('part of telomere dysfunction induced foci', 0.0),
#  ('patients response to transoral incisionless fundoplication', 0.0),
#  ('perturbation conditions telomere dysfunction induced foci', 0.0),
#  ('pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0),
#  ('presence of telomere dysfunction induced foci', 0.0),
#  ('project and the thalassaemia international federation', 0.0),
#  ('protein creatinine clearance ccr tubulointerstitial fibrosis', 0.0),
#  ('renal disease ckd and tubulonterstitial fibrosis', 0.0),
#  ('resulting in glomerulosclerosis and tubulointerstitial fibrosis', 0.0),
#  ('rna gene promoter transcription initiation factor', 0.0),
#  ('robiniophila murr huaier with radix isatidis', 0.0),
#  ('role of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('serum testosterone levels testicular interstitial fluid', 0.0),
#  ('showed enlarged telomere dysfunction induced foci', 0.0),
#  ('showed evident hepatorenal toxicity tubulointerstitial fibrosis', 0.0),
#  ('significant glomerulosclerosis gs and tubulointerstitial fibrosis', 0.0),
#  ('solid tumor the tumor interstitial fluid', 0.0),
#  ('sphincter augmentation msa transoral incisionless fundoplication', 0.0),
#  ('standard for measurements fibrosis tubulointerstitial fibrosis', 0.0),
#  ('stud ies in addition use tetraiodofluorescein', 0.0),
#  ('successful use of transoral incisionless fundoplication', 0.0),
#  ('systematic way the thalassaemia international federation', 0.0),
#  ('t cruzi or trypanosomal immunosuppressive factor', 0.0),
#  ('taken from the thalassaemia international federation', 0.0),
#  ('target for dn renal tubulointerstitial fibrosis', 0.0),
#  ('testosterone in serum testicular interstitial fluid', 0.0),
#  ('testosterone secreted and testicular interstitial fluid', 0.0),
#  ('tgf beta 1 driven tubulointerstitial fibrosis', 0.0),
#  ('the associated between transient interface fluid', 0.0),
#  ('the development of renal tubulointerstitial fibrosis', 0.0),
#  ('the pathogenic role of tubulointerstitial fibrosis', 0.0),
#  ('the src 1 transcription intermediary factor', 0.0),
#  ('the triton x 100 insoluble fraction', 0.0),
#  ('this parasite termed trypanosomal immunosuppressive factor', 0.0),
#  ('tissue among rat with tubulointerstitial fibrosis', 0.0),
#  ('tme is the tumor interstitial fluid', 0.0),
#  ('to as the temperature independent factor', 0.0),
#  ('to the triton insoluble f actin', 0.0),
#  ('transition emt and chronic tubulointerstitial fibrosis', 0.0),
#  ('trap and telomere dysfunction induced foci', 0.0),
#  ('visualized as telomere dysfunction induced foci', 0.0),
#  ('was assessed by test information function', 0.0),
#  ('wherever possible the thalassaemia international federation', 0.0),
#  ('+ pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0),
#  ('1 mcp 1 in renal tubulointerstitial fibrosis', 0.0),
#  ('a and osteopontin in tumor interstitial fluid', 0.0),
#  ('a systematic way the thalassaemia international federation', 0.0),
#  ('actin in pmns triton insoluble f actin', 0.0),
#  ('also a crucial contributor to tubulointerstitial inflammation', 0.0),
#  ('also known as telomere dysfunction induced foci', 0.0),
#  ('analysis part of telomere dysfunction induced foci', 0.0),
#  ('and 0 04 mm totally impermeable film', 0.0),
#  ('and 0 2 with totally impermeable film', 0.0),
#  ('and expected score function test information function', 0.0),
#  ('and fibrosis the pathogenesis of tubulointerstitial fibrosis', 0.0),
#  ('and successful use of transoral incisionless fundoplication', 0.0),
#  ('are implemented through the tumor interstitial fluid', 0.0),
#  ('be visualized as telomere dysfunction induced foci', 0.0),
#  ('biphasic effects of mk on tubulointerstitial fibrosis', 0.0),
#  ('bound to the triton insoluble f actin', 0.0),
#  ('but significant glomerulosclerosis gs and tubulointerstitial fibrosis',
#   0.0),
#  ('by this parasite termed trypanosomal immunosuppressive factor', 0.0),
#  ('ca 125 concentration in tumor interstitial fluid', 0.0),
#  ('can be marked by telomere induced foci', 0.0),
#  ('cells showed enlarged telomere dysfunction induced foci', 0.0),
#  ('chronic renal disease ckd and tubulonterstitial fibrosis', 0.0),
#  ('csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   0.0),
#  ('cytokines kovacs the pathogenesis of tubulointerstitial fibrosis', 0.0),
#  ('design effects treatments the tumor interstitial fluid', 0.0),
#  ('development tgf beta 1 driven tubulointerstitial fibrosis', 0.0),
#  ('device and the corresponding transoral incisionless fundoplication', 0.0),
#  ('diagnose of gerd 7 transoral incisionless fundoplication', 0.0),
#  ('eef 1a 1 tef or eif 1', 0.0),
#  ('effects of alcohol on testicular interstitial fluid', 0.0),
#  ('european project and the thalassaemia international federation', 0.0),
#  ('examine the associated between transient interface fluid', 0.0),
#  ('extracellular matrix ecm the tumor interstitial fluid', 0.0),
#  ('glomerulosclerosis and or progression tubular interstitial fibrosis', 0.0),
#  ('gold standard for measurements fibrosis tubulointerstitial fibrosis', 0.0),
#  ('has been reported that tubule interstitial fibrosis', 0.0),
#  ('however the pathogenic role of tubulointerstitial fibrosis', 0.0),
#  ('identified patients response to transoral incisionless fundoplication',
#   0.0),
#  ('immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#   0.0),
#  ('improve egj competence is transoral incisionless fundoplication', 0.0),
#  ('in the development of renal tubulointerstitial fibrosis', 0.0),
#  ('in the triton x 100 insoluble fraction', 0.0),
#  ('including the src 1 transcription intermediary factor', 0.0),
#  ('induced nephrotoxicity and renal tubular interstitial fibrosis', 0.0),
#  ('inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#   0.0),
#  ('inhibitor and analyzed telomere dysfunction induced foci', 0.0),
#  ('initiation of these treatments testicular interstitial fluid', 0.0),
#  ('kidney tissue among rat with tubulointerstitial fibrosis', 0.0),
#  ('luteinizing hormone serum testosterone testicular interstitial fluid', 0.0),
#  ('may be generally important for up activation', 0.0),
#  ('membrane component shares with trypanosomal immunosuppressive factor', 0.0),
#  ('mesenchymal transition emt and chronic tubulointerstitial fibrosis', 0.0),
#  ('metabolites and their relationship with tubulointerstitial fibrosis', 0.0),
#  ('microenvironment tme is the tumor interstitial fluid', 0.0),
#  ('model of cyclosporin associated chronic tubulointerstitial fibrosis', 0.0),
#  ('notch1 expression correlated both with tubulointerstitial fibrosis', 0.0),
#  ('ns depletion on the number of telomere', 0.0),
#  ('occurrence of complications 4 transoral incisionless fundoplication', 0.0),
#  ('of chronic kidney disease is tubulointerstitial fibrosis', 0.0),
#  ('of gerd is the transoral incisionless fundoplication', 0.0),
#  ('of mir 27a in renal tubulointerstitial fibrosis', 0.0),
#  ('of serum testosterone levels testicular interstitial fluid', 0.0),
#  ('of solid tumor the tumor interstitial fluid', 0.0),
#  ('of testosterone in serum testicular interstitial fluid', 0.0),
#  ('on testosterone secreted and testicular interstitial fluid', 0.0),
#  ('pas and masson s trichrome tubulointerstitial fibrosis', 0.0),
#  ('pathogenesis of inflammation and tif tubulointerstitial fibrosis', 0.0),
#  ('pathology associated with aki is tubulointerstitial fibrosis', 0.0),
#  ('presence of transient occult intraoperative interface fluid', 0.0),
#  ('present and evaluated the twitter impact factor', 0.0),
#  ('present stud ies in addition use tetraiodofluorescein', 0.0),
#  ('production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#   0.0),
#  ('profiling n glycans released from matched tumor', 0.0),
#  ('proliferative mesp nephrosis and without tubulointerstitial fibrosis', 0.0),
#  ('protocol trap and telomere dysfunction induced foci', 0.0),
#  ('public health issue 1 renal tubulointerstitial fibrosis', 0.0),
#  ('qualitatively by imaging telomere deprotection induced foci', 0.0),
#  ('referred to as the temperature independent factor', 0.0),
#  ('registries wherever possible the thalassaemia international federation',
#   0.0),
#  ('renal injury representative photomicrographs of tubulointerstitial fibrosis',
#   0.0),
#  ('renal injury were evaluated with tubulointerstitial fibrosis', 0.0),
#  ('ribosomal rna gene promoter transcription initiation factor', 0.0),
#  ('scale was assessed by test information function', 0.0),
#  ('shelterin perturbation conditions telomere dysfunction induced foci', 0.0),
#  ('significant change in telomere dysfunction induced foci', 0.0),
#  ('smad3 gene protection against renal tubulointerstitial fibrosis', 0.0),
#  ('studies have indicated that tubule interstitial fibrosis', 0.0),
#  ('t elomere dysfunction i nduced f oci', 0.0),
#  ('the actual gradient between tumor interstitial fluid', 0.0),
#  ('the contribute of the tumor interstitial fluid', 0.0),
#  ('the csc number tumour initiation cells frequency', 0.0),
#  ('the format of telomere dysfunction induced foci', 0.0),
#  ('the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('the p38 mapkk sek 1 right panels', 0.0),
#  ('the presence of telomere dysfunction induced foci', 0.0),
#  ('the role of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('therapeutic target for dn renal tubulointerstitial fibrosis', 0.0),
#  ('this activation termed tnf alpha inhibiting factor', 0.0),
#  ('through a promoter bound transcription initiation factor', 0.0),
#  ('to obtain triton x 100 resistant pellets', 0.0),
#  ('toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein', 0.0),
#  ('trametes robiniophila murr huaier with radix isatidis', 0.0),
#  ('transfection gamma tubulin serves as loading control', 0.0),
#  ('types of caspases in renal tubulointerstitial fibrosis', 0.0),
#  ('urinary protein creatinine clearance ccr tubulointerstitial fibrosis', 0.0),
#  ('vegf and osteopontin in tumor interstitial fluid', 0.0),
#  ('views of enlarged telomere dysfunction induced foci', 0.0),
#  ('vimentin as important features of tubulointerstitial fibrosis', 0.0),
#  ('we have shown that transcription initiation factor', 0.0),
#  ('week average systolic bp b tubulointerstitial fibrosis', 0.0),
#  ('well format reagents were scale up accordingly', 0.0),
#  ('were taken from the thalassaemia international federation', 0.0),
#  ('where not significant is indicated by n', 0.0),
#  ('whether t cruzi or trypanosomal immunosuppressive factor', 0.0),
#  ('without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#   0.0),
#  ('− 2 covered with totally impermeable film', 0.0),
#  ('02 and 0 2 with totally impermeable film', 0.0),
#  ('1 eef 1a 1 tef or eif 1', 0.0),
#  ('125 vegf and osteopontin in tumor interstitial fluid', 0.0),
#  ('16 week average systolic bp b tubulointerstitial fibrosis', 0.0),
#  ('24 well format reagents were scale up accordingly', 0.0),
#  ('4 the actual gradient between tumor interstitial fluid', 0.0),
#  ('activation including the src 1 transcription intermediary factor', 0.0),
#  ('after initiation of these treatments testicular interstitial fluid', 0.0),
#  ('alpha this activation termed tnf alpha inhibiting factor', 0.0),
#  ('amplification protocol trap and telomere dysfunction induced foci', 0.0),
#  ('and analysis part of telomere dysfunction induced foci', 0.0),
#  ('and vimentin as important features of tubulointerstitial fibrosis', 0.0),
#  ('as t elomere dysfunction i nduced f oci', 0.0),
#  ('assessed qualitatively by imaging telomere deprotection induced foci', 0.0),
#  ('but also a crucial contributor to tubulointerstitial inflammation', 0.0),
#  ('by profiling n glycans released from matched tumor', 0.0),
#  ('by the presence of telomere dysfunction induced foci', 0.0),
#  ('can be visualized as telomere dysfunction induced foci', 0.0),
#  ('china and 0 04 mm totally impermeable film', 0.0),
#  ('chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   0.0),
#  ('collaborated european project and the thalassaemia international federation',
#   0.0),
#  ('concentration of testosterone in serum testicular interstitial fluid', 0.0),
#  ('crucial public health issue 1 renal tubulointerstitial fibrosis', 0.0),
#  ('cruzi immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#   0.0),
#  ('cruzi membrane component shares with trypanosomal immunosuppressive factor',
#   0.0),
#  ('dependent biphasic effects of mk on tubulointerstitial fibrosis', 0.0),
#  ('dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#   0.0),
#  ('distinct types of caspases in renal tubulointerstitial fibrosis', 0.0),
#  ('dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#   0.0),
#  ('dn however the pathogenic role of tubulointerstitial fibrosis', 0.0),
#  ('dna also known as telomere dysfunction induced foci', 0.0),
#  ('ecm production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#   0.0),
#  ('epithelial mesenchymal transition emt and chronic tubulointerstitial fibrosis',
#   0.0),
#  ('esophyx device and the corresponding transoral incisionless fundoplication',
#   0.0),
#  ('eukaryotic ribosomal rna gene promoter transcription initiation factor',
#   0.0),
#  ('except where not significant is indicated by n', 0.0),
#  ('fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#   0.0),
#  ('figures were taken from the thalassaemia international federation', 0.0),
#  ('g actin in pmns triton insoluble f actin', 0.0),
#  ('grade ca 125 concentration in tumor interstitial fluid', 0.0),
#  ('h522 cells showed enlarged telomere dysfunction induced foci', 0.0),
#  ('hallmark of chronic kidney disease is tubulointerstitial fibrosis', 0.0),
#  ('imidazoles on testosterone secreted and testicular interstitial fluid',
#   0.0),
#  ('in a systematic way the thalassaemia international federation', 0.0),
#  ('induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#   0.0),
#  ('induced renal injury were evaluated with tubulointerstitial fibrosis', 0.0),
#  ('induced the format of telomere dysfunction induced foci', 0.0),
#  ('inflammation and fibrosis the pathogenesis of tubulointerstitial fibrosis',
#   0.0),
#  ('investigated the role of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('is bound to the triton insoluble f actin', 0.0),
#  ('it has been reported that tubule interstitial fibrosis', 0.0),
#  ('known whether t cruzi or trypanosomal immunosuppressive factor', 0.0),
#  ('m − 2 covered with totally impermeable film', 0.0),
#  ('magnified views of enlarged telomere dysfunction induced foci', 0.0),
#  ('main pathology associated with aki is tubulointerstitial fibrosis', 0.0),
#  ('measurements of serum testosterone levels testicular interstitial fluid',
#   0.0),
#  ('mesangial proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#   0.0),
#  ('might identified patients response to transoral incisionless fundoplication',
#   0.0),
#  ('minutes to obtain triton x 100 resistant pellets', 0.0),
#  ('national registries wherever possible the thalassaemia international federation',
#   0.0),
#  ('no significant change in telomere dysfunction induced foci', 0.0),
#  ('obstructed kidney tissue among rat with tubulointerstitial fibrosis', 0.0),
#  ('of glomerulosclerosis and or progression tubular interstitial fibrosis',
#   0.0),
#  ('of ns depletion on the number of telomere', 0.0),
#  ('of studies have indicated that tubule interstitial fibrosis', 0.0),
#  ('of the csc number tumour initiation cells frequency', 0.0),
#  ('of the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('of trametes robiniophila murr huaier with radix isatidis', 0.0),
#  ('on the contribute of the tumor interstitial fluid', 0.0),
#  ('options chronic renal disease ckd and tubulonterstitial fibrosis', 0.0),
#  ('p toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein', 0.0),
#  ('pathogenesis of mir 27a in renal tubulointerstitial fibrosis', 0.0),
#  ('phase of solid tumor the tumor interstitial fluid', 0.0),
#  ('plasma metabolites and their relationship with tubulointerstitial fibrosis',
#   0.0),
#  ('post transfection gamma tubulin serves as loading control', 0.0),
# ...
#  ('activation required the p38 mapkk sek 1 right panels', 0.0),
#  ('aimed to improve egj competence is transoral incisionless fundoplication',
#   0.0),
#  ('akt specific inhibitor and analyzed telomere dysfunction induced foci',
#   0.0),
#  ('and 16 week average systolic bp b tubulointerstitial fibrosis', 0.0),
#  ('and national registries wherever possible the thalassaemia international federation',
#   0.0),
#  ('and plasma metabolites and their relationship with tubulointerstitial fibrosis',
#   0.0),
#  ('and promising therapeutic target for dn renal tubulointerstitial fibrosis',
#   0.0),
#  ('and the occurrence of complications 4 transoral incisionless fundoplication',
#   0.0),
#  ('are magnified views of enlarged telomere dysfunction induced foci', 0.0),
#  ('breakdown of the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('by dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#   0.0),
#  ('ca 125 vegf and osteopontin in tumor interstitial fluid', 0.0),
#  ('characterized by the presence of telomere dysfunction induced foci', 0.0),
#  ('chemotactic protein 1 mcp 1 in renal tubulointerstitial fibrosis', 0.0),
#  ('comprising the extracellular matrix ecm the tumor interstitial fluid', 0.0),
#  ('content to present and evaluated the twitter impact factor', 0.0),
#  ('control except where not significant is indicated by n', 0.0),
#  ('csa induced renal injury were evaluated with tubulointerstitial fibrosis',
#   0.0),
#  ('development of glomerulosclerosis and or progression tubular interstitial fibrosis',
#   0.0),
#  ('disease but also a crucial contributor to tubulointerstitial inflammation',
#   0.0),
#  ('dose dependent biphasic effects of mk on tubulointerstitial fibrosis', 0.0),
#  ('dysfunction telomere can be marked by telomere induced foci', 0.0),
#  ('effects of ns depletion on the number of telomere', 0.0),
#  ('ends can be visualized as telomere dysfunction induced foci', 0.0),
#  ('essential to design effects treatments the tumor interstitial fluid', 0.0),
#  ('estimation of the csc number tumour initiation cells frequency', 0.0),
#  ('exclude the diagnose of gerd 7 transoral incisionless fundoplication', 0.0),
#  ('extract of trametes robiniophila murr huaier with radix isatidis', 0.0),
#  ('f induced the format of telomere dysfunction induced foci', 0.0),
#  ('fluid phase of solid tumor the tumor interstitial fluid', 0.0),
#  ('focus on the contribute of the tumor interstitial fluid', 0.0),
#  ('fold 4 the actual gradient between tumor interstitial fluid', 0.0),
#  ('g m − 2 covered with totally impermeable film', 0.0),
#  ('g1 progression we have shown that transcription initiation factor', 0.0),
#  ('glycome by profiling n glycans released from matched tumor', 0.0),
#  ('hrs post transfection gamma tubulin serves as loading control', 0.0),
#  ('imaging and analysis part of telomere dysfunction induced foci', 0.0),
#  ('in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#   0.0),
#  ('in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#   0.0),
#  ('in the present stud ies in addition use tetraiodofluorescein', 0.0),
#  ('induced epithelial mesenchymal transition emt and chronic tubulointerstitial fibrosis',
#   0.0),
#  ('is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('is therefore referred to as the temperature independent factor', 0.0),
#  ('key role in the development of renal tubulointerstitial fibrosis', 0.0),
#  ('matrix ecm production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#   0.0),
#  ('nci h522 cells showed enlarged telomere dysfunction induced foci', 0.0),
#  ('none is bound to the triton insoluble f actin', 0.0),
#  ('not known whether t cruzi or trypanosomal immunosuppressive factor', 0.0),
#  ('number of studies have indicated that tubule interstitial fibrosis', 0.0),
#  ('of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   0.0),
#  ('of concentration of testosterone in serum testicular interstitial fluid',
#   0.0),
#  ('of dn however the pathogenic role of tubulointerstitial fibrosis', 0.0),
#  ('of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#   0.0),
#  ('of imidazoles on testosterone secreted and testicular interstitial fluid',
#   0.0),
#  ('of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#   0.0),
#  ('of slowly development tgf beta 1 driven tubulointerstitial fibrosis', 0.0),
#  ('of the scale was assessed by test information function', 0.0),
#  ('of the smad3 gene protection against renal tubulointerstitial fibrosis',
#   0.0),
#  ('organizations collaborated european project and the thalassaemia international federation',
#   0.0),
#  ('other figures were taken from the thalassaemia international federation',
#   0.0),
#  ('precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0),
#  ('problems in a systematic way the thalassaemia international federation',
#   0.0),
#  ('province china and 0 04 mm totally impermeable film', 0.0),
#  ('receptor activation including the src 1 transcription intermediary factor',
#   0.0),
#  ('repeat amplification protocol trap and telomere dysfunction induced foci',
#   0.0),
#  ('resistant mesangial proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#   0.0),
#  ('revealed no significant change in telomere dysfunction induced foci', 0.0),
#  ('salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#   0.0),
#  ('six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#   0.0),
#  ('skn 1 eef 1a 1 tef or eif 1', 0.0),
#  ('spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#   0.0),
#  ('stage grade ca 125 concentration in tumor interstitial fluid', 0.0),
#  ('surgical treatments of gerd is the transoral incisionless fundoplication',
#   0.0),
#  ('t cruzi immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#   0.0),
#  ('t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#   0.0),
#  ('tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#   0.0),
#  ('technique might identified patients response to transoral incisionless fundoplication',
#   0.0),
#  ('telomere dna also known as telomere dysfunction induced foci', 0.0),
#  ('that the presence of transient occult intraoperative interface fluid', 0.0),
#  ('the 24 well format reagents were scale up accordingly', 0.0),
#  ('the esophyx device and the corresponding transoral incisionless fundoplication',
#   0.0),
#  ('the eukaryotic ribosomal rna gene promoter transcription initiation factor',
#   0.0),
#  ('the main pathology associated with aki is tubulointerstitial fibrosis',
#   0.0),
#  ('the pathogenesis of mir 27a in renal tubulointerstitial fibrosis', 0.0),
#  ('the safe and successful use of transoral incisionless fundoplication', 0.0),
#  ('the tumor microenvironment tme is the tumor interstitial fluid', 0.0),
#  ('therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#   0.0),
#  ('through measurements of serum testosterone levels testicular interstitial fluid',
#   0.0),
#  ('time after initiation of these treatments testicular interstitial fluid',
#   0.0),
#  ('timp2 and vimentin as important features of tubulointerstitial fibrosis',
#   0.0),
#  ('tnf alpha this activation termed tnf alpha inhibiting factor', 0.0),
#  ('to as t elomere dysfunction i nduced f oci', 0.0),
#  ('to read through a promoter bound transcription initiation factor', 0.0),
#  ('to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#   0.0),
#  ('to tif without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#   0.0),
#  ('tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#   0.0),
#  ('tubulointerstitial inflammation and fibrosis the pathogenesis of tubulointerstitial fibrosis',
#   0.0),
#  ('tumor stroma are implemented through the tumor interstitial fluid', 0.0),
#  ('two distinct types of caspases in renal tubulointerstitial fibrosis', 0.0),
#  ('under various shelterin perturbation conditions telomere dysfunction induced foci',
#   0.0),
#  ('unknown protein in the triton x 100 insoluble fraction', 0.0),
#  ('wald test and expected score function test information function', 0.0),
#  ('we investigated the role of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('were assessed qualitatively by imaging telomere deprotection induced foci',
#   0.0),
#  ('with g actin in pmns triton insoluble f actin', 0.0),
#  ('years it has been reported that tubule interstitial fibrosis', 0.0),
#  ('1500 fold 4 the actual gradient between tumor interstitial fluid', 0.0),
#  ('20 tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#   0.0),
#  ('24 the esophyx device and the corresponding transoral incisionless fundoplication',
#   0.0),
#  ('3b f induced the format of telomere dysfunction induced foci', 0.0),
#  ('50 g m − 2 covered with totally impermeable film', 0.0),
#  ('6 14 therefore may be generally important for up activation', 0.0),
#  ('72 hrs post transfection gamma tubulin serves as loading control', 0.0),
#  ('a key role in the development of renal tubulointerstitial fibrosis', 0.0),
#  ('a number of studies have indicated that tubule interstitial fibrosis', 0.0),
#  ('a salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#   0.0),
#  ('a t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#   0.0),
#  ('academic content to present and evaluated the twitter impact factor', 0.0),
#  ('after six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#   0.0),
#  ('against tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#   0.0),
#  ('allowed estimation of the csc number tumour initiation cells frequency',
#   0.0),
#  ('an akt specific inhibitor and analyzed telomere dysfunction induced foci',
#   0.0),
#  ('and is therefore referred to as the temperature independent factor', 0.0),
#  ('and none is bound to the triton insoluble f actin', 0.0),
#  ('and other figures were taken from the thalassaemia international federation',
#   0.0),
#  ('approaches aimed to improve egj competence is transoral incisionless fundoplication',
#   0.0),
#  ('as a crucial public health issue 1 renal tubulointerstitial fibrosis', 0.0),
#  ('assessed of concentration of testosterone in serum testicular interstitial fluid',
#   0.0),
#  ('biopsy is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#   0.0),
#  ('but the pathogenesis of mir 27a in renal tubulointerstitial fibrosis', 0.0),
#  ('by wald test and expected score function test information function', 0.0),
#  ('ca 125 vegf a and osteopontin in tumor interstitial fluid', 0.0),
#  ('caused by dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#   0.0),
#  ('cells revealed no significant change in telomere dysfunction induced foci',
#   0.0),
#  ('chromosome ends can be visualized as telomere dysfunction induced foci',
#   0.0),
#  ('coexisting with g actin in pmns triton insoluble f actin', 0.0),
#  ('contribute to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#   0.0),
#  ('control skn 1 eef 1a 1 tef or eif 1', 0.0),
#  ('deletion of the smad3 gene protection against renal tubulointerstitial fibrosis',
#   0.0),
#  ('during g1 progression we have shown that transcription initiation factor',
#   0.0),
#  ('effects of imidazoles on testosterone secreted and testicular interstitial fluid',
#   0.0),
#  ('endoflip technique might identified patients response to transoral incisionless fundoplication',
#   0.0),
#  ('examine in the present stud ies in addition use tetraiodofluorescein', 0.0),
#  ('figo stage grade ca 125 concentration in tumor interstitial fluid', 0.0),
#  ('film 0 02 and 0 2 with totally impermeable film', 0.0),
#  ('for 10 minutes to obtain triton x 100 resistant pellets', 0.0),
#  ('function dysfunction telomere can be marked by telomere induced foci', 0.0),
#  ('glomerulosclerosis and 16 week average systolic bp b tubulointerstitial fibrosis',
#   0.0),
#  ('hebei province china and 0 04 mm totally impermeable film', 0.0),
#  ('here we investigated the role of mdm2 in tubulointerstitial fibrosis', 0.0),
#  ('however the main pathology associated with aki is tubulointerstitial fibrosis',
#   0.0),
#  ('hypothesize that the presence of transient occult intraoperative interface fluid',
#   0.0),
#  ('i to read through a promoter bound transcription initiation factor', 0.0),
#  ('information and national registries wherever possible the thalassaemia international federation',
#   0.0),
#  ('interstitial fluid phase of solid tumor the tumor interstitial fluid', 0.0),
#  ('is characterized by the presence of telomere dysfunction induced foci',
#   0.0),
#  ('is essential to design effects treatments the tumor interstitial fluid',
#   0.0),
#  ('is not known whether t cruzi or trypanosomal immunosuppressive factor',
#   0.0),
#  ('kidney disease but also a crucial contributor to tubulointerstitial inflammation',
#   0.0),
#  ('kidney in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#   0.0),
#  ('limited therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#   0.0),
#  ('measurements of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#   0.0),
#  ('mechanism of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#   0.0),
#  ('microbiota and plasma metabolites and their relationship with tubulointerstitial fibrosis',
#   0.0),
#  ('mmp9 timp2 and vimentin as important features of tubulointerstitial fibrosis',
#   0.0),
#  ('model of slowly development tgf beta 1 driven tubulointerstitial fibrosis',
#   0.0),
#  ('molecules comprising the extracellular matrix ecm the tumor interstitial fluid',
#   0.0),
#  ('monocyte chemotactic protein 1 mcp 1 in renal tubulointerstitial fibrosis',
#   0.0),
#  ('novel and promising therapeutic target for dn renal tubulointerstitial fibrosis',
#   0.0),
#  ('nuclear receptor activation including the src 1 transcription intermediary factor',
#   0.0),
#  ('observations nci h522 cells showed enlarged telomere dysfunction induced foci',
#   0.0),
#  ('of 2 p toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein',
#   0.0),
#  ('of ca 125 vegf and osteopontin in tumor interstitial fluid', 0.0),
#  ('of the safe and successful use of transoral incisionless fundoplication',
#   0.0),
#  ('of the tumor microenvironment tme is the tumor interstitial fluid', 0.0),
#  ('of tnf alpha this activation termed tnf alpha inhibiting factor', 0.0),
#  ('on csa induced renal injury were evaluated with tubulointerstitial fibrosis',
#   0.0),
#  ('other unknown protein in the triton x 100 insoluble fraction', 0.0),
#  ('outcomes and the occurrence of complications 4 transoral incisionless fundoplication',
#   0.0),
#  ('p38 activation required the p38 mapkk sek 1 right panels', 0.0),
#  ('panels are magnified views of enlarged telomere dysfunction induced foci',
#   0.0),
#  ('pathway in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#   0.0),
#  ('periodic acid schiff pas and masson s trichrome tubulointerstitial fibrosis',
#   0.0),
#  ('phenotypes were assessed qualitatively by imaging telomere deprotection induced foci',
#   0.0),
#  ('production extract of trametes robiniophila murr huaier with radix isatidis',
#   0.0),
#  ('production of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#   0.0),
#  ('progression of dn however the pathogenic role of tubulointerstitial fibrosis',
#   0.0),
#  ('proposed precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0),
#  ('protein spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#   0.0),
#  ('rat through measurements of serum testosterone levels testicular interstitial fluid',
#   0.0),
#  ('recent years it has been reported that tubule interstitial fibrosis', 0.0),
#  ('referred to as t elomere dysfunction i nduced f oci', 0.0),
#  ('reliability of the scale was assessed by test information function', 0.0),
#  ...]

# %%
longforms0 = miners['TIF'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('tubulointerstitial fibrosis', 39.07692307692308)),
#  (1, ('transoral incisionless fundoplication', 10.0)),
#  (2, ('telomere dysfunction induced foci', 9.83333333333333)),
#  (3, ('interstitial fluid', 9.222222222222221)),
#  (4, ('factor', 9.0)),
#  (5, ('the thalassaemia international federation', 3.6)),
#  (6, ('tetraiodofluorescein', 2.0)),
#  (7, ('totally impermeable film', 1.3333333333333333))]

# %%
longforms0 = [(longform, score) for i, (longform, score) in enumerate(longforms0)
              if i not in [3, 4, 5]]

# %%
list(enumerate(top))
# Out:
# [(0, ('tubulointerstitial fibrosis', 39.07692307692308)),
#  (1, ('fibrosis', 10.734693877551024)),
#  (2, ('transoral incisionless fundoplication', 10.0)),
#  (3, ('telomere dysfunction induced foci', 9.83333333333333)),
#  (4, ('interstitial fluid', 9.222222222222221)),
#  (5, ('factor', 9.0)),
#  (6, ('renal tubulointerstitial fibrosis', 7.142857142857142)),
#  (7, ('tumor interstitial fluid', 6.4)),
#  (8, ('testicular interstitial fluid', 5.0)),
#  (9, ('the tumor interstitial fluid', 5.0)),
#  (10, ('fluid', 3.6000000000000014)),
#  (11, ('of tubulointerstitial fibrosis', 3.6)),
#  (12, ('the thalassaemia international federation', 3.6)),
#  (13, ('induced foci', 3.571428571428571)),
#  (14, ('interstitial fibrosis', 3.2)),
#  (15, ('transcription initiation factor', 3.0)),
#  (16, ('trypanosomal immunosuppressive factor', 3.0)),
#  (17, ('with tubulointerstitial fibrosis', 3.0)),
#  (18, ('tetraiodofluorescein', 2.0)),
#  (19, ('in renal tubulointerstitial fibrosis', 2.0)),
#  (20, ('of telomere dysfunction induced foci', 2.0)),
#  (21,
#   ('53bp1 blue dapi right panels are magnified views of enlarged telomere dysfunction induced foci',
#    2)),
#  (22, ('totally impermeable film', 1.3333333333333333)),
#  (23, ('in tumor interstitial fluid', 1.3333333333333333)),
#  (24, ('enlarged telomere dysfunction induced foci', 1.3333333333333333)),
#  (25, ('interface fluid', 1.0)),
#  (26, ('and tubulointerstitial fibrosis', 1.0)),
#  (27, ('as tubulointerstitial fibrosis', 1)),
#  (28, ('chronic tubulointerstitial fibrosis', 1.0)),
#  (29, ('fibrosis tubulointerstitial fibrosis', 1.0)),
#  (30, ('is tubulointerstitial fibrosis', 1.0)),
#  (31, ('progression tubulointerstitial fibrosis', 1.0)),
#  (32, ('test information function', 1.0)),
#  (33, ('the dye tetraiodofluorescein', 1)),
#  (34, ('tissue interstitial fluid', 1)),
#  (35, ('tubular interstitial fibrosis', 1.0)),
#  (36, ('tubulo interstitial fibrosis', 1)),
#  (37, ('that tubule interstitial fibrosis', 1.0)),
#  (38, ('the types i fimbria', 1)),
#  (39, ('triton insoluble f actin', 1.0)),
#  (40, ('with totally impermeable film', 1.0)),
#  (41, ('a novel transoral incisionless fundoplication', 1)),
#  (42, ('as telomere dysfunction induced foci', 1.0)),
#  (43, ('the fundamental transcription initiation factor', 1)),
#  (44, ('the pathogenesis of tubulointerstitial fibrosis', 1.0)),
#  (45, ('and osteopontin in tumor interstitial fluid', 1.0)),
#  (46,
#   ('magnetic sphincter augmentation msa transoral incisionless fundoplication',
#    1)),
#  (47,
#   ('mild but significant glomerulosclerosis gs and tubulointerstitial fibrosis',
#    1)),
#  (48, ('the effects of alcohol on testicular interstitial fluid', 1)),
#  (49, ('to examine the associated between transient interface fluid', 1)),
#  (50,
#   ('the hallmark of chronic kidney disease is tubulointerstitial fibrosis',
#    1)),
#  (51,
#   ('ational organizations collaborated european project and the thalassaemia international federation',
#    1)),
#  (52,
#   ('creased breakdown of the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#    1)),
#  (53,
#   ('steroid resistant mesangial proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#    1)),
#  (54,
#   ('tant tubulointerstitial inflammation and fibrosis the pathogenesis of tubulointerstitial fibrosis',
#    1)),
#  (55,
#   ('tracellular matrix ecm production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#    1)),
#  (56,
#   ('achieve resistant to tif without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#    1)),
#  (57,
#   ('agc10 a t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#    1)),
#  (58,
#   ('be endoflip technique might identified patients response to transoral incisionless fundoplication',
#    1)),
#  (59,
#   ('d information and national registries wherever possible the thalassaemia international federation',
#    1)),
#  (60,
#   ('ectively after six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#    1)),
#  (61,
#   ('f soluble t cruzi immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#    1)),
#  (62,
#   ('he mechanism of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#    1)),
#  (63,
#   ('it is not known whether t cruzi or trypanosomal immunosuppressive factor',
#    1)),
#  (64,
#   ('ng against tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#    1)),
#  (65,
#   ('phage production of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#    1)),
#  (66,
#   ('2 at telomere under various shelterin perturbation conditions telomere dysfunction induced foci',
#    1)),
#  (67,
#   ('atients and limited therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#    1)),
#  (68,
#   ('by a protein spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#    1)),
#  (69,
#   ('carrier rates and other figures were taken from the thalassaemia international federation',
#    1.0)),
#  (70,
#   ('ce insertion 24 the esophyx device and the corresponding transoral incisionless fundoplication',
#    1)),
#  (71,
#   ('erular injury caused by dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#    1)),
#  (72,
#   ('ewer endoscopic approaches aimed to improve egj competence is transoral incisionless fundoplication',
#    1)),
#  (73,
#   ('f telomere phenotypes were assessed qualitatively by imaging telomere deprotection induced foci',
#    1)),
#  (74,
#   ('important for nuclear receptor activation including the src 1 transcription intermediary factor',
#    1)),
#  (75,
#   ('moted tgf β induced epithelial mesenchymal transition emt and chronic tubulointerstitial fibrosis',
#    1)),
#  (76,
#   ('n colonic microbiota and plasma metabolites and their relationship with tubulointerstitial fibrosis',
#    1)),
#  (77,
#   ('nflammatory signaling pathway in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#    1)),
#  (78,
#   ('ociated with the development of glomerulosclerosis and or progression tubular interstitial fibrosis',
#    1)),
#  (79,
#   ('s with measurements of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#    1)),
#  (80,
#   ('sease types 20 tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#    1)),
#  (81,
#   ('shay 2015b telomere repeat amplification protocol trap and telomere dysfunction induced foci',
#    1)),
#  (82,
#   ('6a hydroxymaackiain the proposed precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone',
#    1)),
#  (83,
#   ('and gradually recovering during g1 progression we have shown that transcription initiation factor',
#    1)),
#  (84,
#   ('been more extensively examine in the present stud ies in addition use tetraiodofluorescein',
#    1)),
#  (85,
#   ('ellar fibrils we hypothesize that the presence of transient occult intraoperative interface fluid',
#    1)),
#  (86,
#   ('elomere protection related function dysfunction telomere can be marked by telomere induced foci',
#    1)),
#  (87,
#   ('eous injury pattern however the main pathology associated with aki is tubulointerstitial fibrosis',
#    1)),
#  (88,
#   ('es events that contribute to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#    1)),
#  (89,
#   ('ibrogenesis was evaluated the dose dependent biphasic effects of mk on tubulointerstitial fibrosis',
#    1)),
#  (90,
#   ('ional solid fermentation production extract of trametes robiniophila murr huaier with radix isatidis',
#    1)),
#  (91,
#   ('ips between a glomerulosclerosis and 16 week average systolic bp b tubulointerstitial fibrosis',
#    1)),
#  (92,
#   ('marker of chronic kidney disease but also a crucial contributor to tubulointerstitial inflammation',
#    1)),
#  (93,
#   ('nal fibrosis renal biopsy is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#    1)),
#  (94,
#   ('nd losartan in a salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#    1)),
#  (95,
#   ('nd the structural molecules comprising the extracellular matrix ecm the tumor interstitial fluid',
#    1)),
#  (96,
#   ('onsistent with these observations nci h522 cells showed enlarged telomere dysfunction induced foci',
#    1)),
#  (97,
#   ('or long termed outcomes and the occurrence of complications 4 transoral incisionless fundoplication',
#    1)),
#  (98,
#   ('polymerase i binding to the eukaryotic ribosomal rna gene promoter transcription initiation factor',
#    1)),
#  (99,
#   ('ssessed in the rat through measurements of serum testosterone levels testicular interstitial fluid',
#    1)),
#  (100,
#   ('ssible carrier rates and other figures were taken from the thalassaemia international federation',
#    1)),
#  (101,
#   ('t including tgfβ1 mmp9 timp2 and vimentin as important features of tubulointerstitial fibrosis',
#    1)),
#  (102,
#   ('tives the fluorescence of 2 p toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein',
#    1)),
#  (103,
#   ('were measurements at various time after initiation of these treatments testicular interstitial fluid',
#    1)),
#  (104,
#   ('across gender was identified by wald test and expected score function test information function',
#    1)),
#  (105,
#   ('as to examine the effects of imidazoles on testosterone secreted and testicular interstitial fluid',
#    1)),
#  (106,
#   ('ata with histological subtype figo stage grade ca 125 concentration in tumor interstitial fluid',
#    1)),
#  (107,
#   ('atterns we investigated the secreted glycome by profiling n glycans released from matched tumor',
#    1)),
#  (108,
#   ('ave development a transgenic model of slowly development tgf beta 1 driven tubulointerstitial fibrosis',
#    1)),
#  (109,
#   ('d cells with triciribine an akt specific inhibitor and analyzed telomere dysfunction induced foci',
#    1)),
#  (110,
#   ('damage response factor and chromosome ends can be visualized as telomere dysfunction induced foci',
#    1)),
#  (111,
#   ('e studies revealed that deletion of the smad3 gene protection against renal tubulointerstitial fibrosis',
#    1)),
#  (112,
#   ('enal fibrosis remains unclear here we investigated the role of mdm2 in tubulointerstitial fibrosis',
#    1)),
#  (113,
#   ('erstanding of cancer that is essential to design effects treatments the tumor interstitial fluid',
#    1)),
#  (114,
#   ('et critically important factor of the tumor microenvironment tme is the tumor interstitial fluid',
#    1)),
#  (115,
#   ('ional signaling events within the tumor stroma are implemented through the tumor interstitial fluid',
#    1)),
#  (116,
#   ('item information function iif reliability of the scale was assessed by test information function',
#    1)),
#  (117,
#   ('kly effects of rhuepo on csa induced renal injury were evaluated with tubulointerstitial fibrosis',
#    1)),
#  (118,
#   ('n 5 carrier rates and other figures were taken from the thalassaemia international federation',
#    1)),
#  (119,
#   ('n and representative a novel and promising therapeutic target for dn renal tubulointerstitial fibrosis',
#    1)),
#  (120,
#   ('oxylin eosin h e periodic acid schiff pas and masson s trichrome tubulointerstitial fibrosis',
#    1)),
#  (121,
#   ('progression and metastasis this studies focus on the contribute of the tumor interstitial fluid',
#    1)),
#  (122,
#   ('rat by way of assessed of concentration of testosterone in serum testicular interstitial fluid',
#    1)),
#  (123,
#   ('role and associated of these two distinct types of caspases in renal tubulointerstitial fibrosis',
#    1)),
#  (124,
#   ('rowth factor hgf and monocyte chemotactic protein 1 mcp 1 in renal tubulointerstitial fibrosis',
#    1)),
#  (125,
#   ('s generation in the kidney in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#    1)),
#  (126,
#   ('saccharide lps induced expression of tnf alpha this activation termed tnf alpha inhibiting factor',
#    1)),
#  (127,
#   ('signaling following injury plays a key role in the development of renal tubulointerstitial fibrosis',
#    1)),
#  (128,
#   ('teasome and elongation factor 6 14 therefore may be generally important for up activation',
#    1)),
#  (129,
#   ('telomere dna in hct116 cells revealed no significant change in telomere dysfunction induced foci',
#    1)),
#  (130,
#   ('the limited dilution series allowed estimation of the csc number tumour initiation cells frequency',
#    1)),
#  (131,
#   ('tly needed to address these problems in a systematic way the thalassaemia international federation',
#    1)),
#  (132,
#   ('y contribute to the progression of dn however the pathogenic role of tubulointerstitial fibrosis',
#    1)),
#  (133,
#   ('ach in the evolution of the surgical treatments of gerd is the transoral incisionless fundoplication',
#    1)),
#  (134,
#   ('act gefv is not enough to exclude the diagnose of gerd 7 transoral incisionless fundoplication',
#    1)),
#  (135,
#   ('ction after icl damage which is characterized by the presence of telomere dysfunction induced foci',
#    1)),
#  (136,
#   ('h sigenome pool against loc283523 72 hrs post transfection gamma tubulin serves as loading control',
#    1)),
#  (137,
#   ('hwestern for his assistance with the imaging and analysis part of telomere dysfunction induced foci',
#    1)),
#  (138,
#   ('od1 it oligoubiquitinated forms and other unknown protein in the triton x 100 insoluble fraction',
#    1)),
#  (139,
#   ('oes not change with temperature and is therefore referred to as the temperature independent factor',
#    1)),
#  (140,
#   ('of kidney function over time a number of studies have indicated that tubule interstitial fibrosis',
#    1)),
#  (141,
#   ('s been identified in diabetes but the pathogenesis of mir 27a in renal tubulointerstitial fibrosis',
#    1)),
#  (142,
#   ('sent article reported a case of the safe and successful use of transoral incisionless fundoplication',
#    1)),
#  (143,
#   ('ssue to plasma gradient quantification of ca 125 vegf and osteopontin in tumor interstitial fluid',
#    1)),
#  (144,
#   ('the ability of rna polymerase i to read through a promoter bound transcription initiation factor',
#    1)),
#  (145,
#   ('a number of renal disease in recent years it has been reported that tubule interstitial fibrosis',
#    1)),
#  (146,
#   ('cancer and should be further explored ca 125 vegf a and osteopontin in tumor interstitial fluid',
#    1)),
#  (147,
#   ('e the localization of ddr marker to telomere dna also known as telomere dysfunction induced foci',
#    1)),
#  (148,
#   ('eir telomere integrity we first investigated the effects of ns depletion on the number of telomere',
#    1)),
#  (149,
#   ('for transfection of sirnas in other than the 24 well format reagents were scale up accordingly',
#    1)),
#  (150,
#   ('ig 3a or ar knockdown fig 3b f induced the format of telomere dysfunction induced foci',
#    1)),
#  (151,
#   ('o ca usa and regularly tweet academic content to present and evaluated the twitter impact factor',
#    1)),
#  (152,
#   ('orylation comparably to tef rnai this p38 activation required the p38 mapkk sek 1 right panels',
#    1)),
#  (153,
#   ('pe baoding baoshuo plastic co ltd hebei province china and 0 04 mm totally impermeable film',
#    1)),
#  (154,
#   ('s hypothesize to be 1000 to 1500 fold 4 the actual gradient between tumor interstitial fluid',
#    1)),
#  (155,
#   ('sent review we focus on the interstitial fluid phase of solid tumor the tumor interstitial fluid',
#    1)),
#  (156,
#   ('ses of death and has emerged as a crucial public health issue 1 renal tubulointerstitial fibrosis',
#    1)),
#  (157,
#   ('ent description of distinct f actin pool coexisting with g actin in pmns triton insoluble f actin',
#    1)),
#  (158,
#   ('in figures s2c all p < 0 05 comparably to control except where not significant is indicated by n',
#    1)),
#  (159,
#   ('s can be visualized by the presence of foci referred to as t elomere dysfunction i nduced f oci',
#    1)),
#  (160,
#   ('2 and pvha 6 dendra2 reported in animals exposed to control skn 1 eef 1a 1 tef or eif 1',
#    1)),
#  (161,
#   ('bare soil 4 2 and 9 6 with polyethylene pe film 0 02 and 0 2 with totally impermeable film',
#    1)),
#  (162,
#   ('is bound to the triton soluble f actin tsf pool and none is bound to the triton insoluble f actin',
#    1)),
#  (163,
#   ('oil revealed that treatments of pic at the dose of 50 g m − 2 covered with totally impermeable film',
#    1)),
#  (164,
#   ('re then centrifuged twice at 10000 × g at 4 ° c for 10 minutes to obtain triton x 100 resistant pellets',
#    1)),
#  (165, ('1', 0.0)),
#  (166, ('accordingly', 0.0)),
#  (167, ('actin', 0.0)),
#  (168, ('activation', 0.0)),
#  (169, ('control', 0.0)),
#  (170, ('federation', 0.0)),
#  (171, ('film', 0.0)),
#  (172, ('fimbria', 0.0)),
#  (173, ('foci', 0.0)),
#  (174, ('fraction', 0.0)),
#  (175, ('frequency', 0.0)),
#  (176, ('function', 0.0)),
#  (177, ('fundoplication', 0.0)),
#  (178, ('inflammation', 0.0)),
#  (179, ('isatidis', 0.0)),
#  (180, ('n', 0.0)),
#  (181, ('oci', 0.0)),
#  (182, ('panels', 0.0)),
#  (183, ('pellets', 0.0)),
#  (184, ('telomere', 0.0)),
#  (185, ('trihydroxyisoflavanone', 0.0)),
#  (186, ('tumor', 0.0)),
#  (187, ('4 trihydroxyisoflavanone', 0.0)),
#  (188, ('by n', 0.0)),
#  (189, ('cells frequency', 0.0)),
#  (190, ('dye tetraiodofluorescein', 0.0)),
#  (191, ('eif 1', 0.0)),
#  (192, ('f actin', 0.0)),
#  (193, ('f oci', 0.0)),
#  (194, ('i fimbria', 0.0)),
#  (195, ('immunosuppressive factor', 0.0)),
#  (196, ('impact factor', 0.0)),
#  (197, ('impermeable film', 0.0)),
#  (198, ('incisionless fundoplication', 0.0)),
#  (199, ('independent factor', 0.0)),
#  (200, ('information function', 0.0)),
#  (201, ('inhibiting factor', 0.0)),
#  (202, ('initiation factor', 0.0)),
#  (203, ('insoluble fraction', 0.0)),
#  (204, ('intermediary factor', 0.0)),
#  (205, ('international federation', 0.0)),
#  (206, ('loading control', 0.0)),
#  (207, ('matched tumor', 0.0)),
#  (208, ('of telomere', 0.0)),
#  (209, ('of tetraiodofluorescein', 0.0)),
#  (210, ('radix isatidis', 0.0)),
#  (211, ('resistant pellets', 0.0)),
#  (212, ('right panels', 0.0)),
#  (213, ('tubulointerstitial inflammation', 0.0)),
#  (214, ('tubulonterstitial fibrosis', 0.0)),
#  (215, ('up accordingly', 0.0)),
#  (216, ('up activation', 0.0)),
#  (217, ('use tetraiodofluorescein', 0.0)),
#  (218, ('1 right panels', 0.0)),
#  (219, ('100 insoluble fraction', 0.0)),
#  (220, ('100 resistant pellets', 0.0)),
#  (221, ('7 4 trihydroxyisoflavanone', 0.0)),
#  (222, ('addition use tetraiodofluorescein', 0.0)),
#  (223, ('alpha inhibiting factor', 0.0)),
#  (224, ('and of tetraiodofluorescein', 0.0)),
#  (225, ('and tubulonterstitial fibrosis', 0.0)),
#  (226, ('as loading control', 0.0)),
#  (227, ('b tubulointerstitial fibrosis', 0.0)),
#  (228, ('ccr tubulointerstitial fibrosis', 0.0)),
#  (229, ('deprotection induced foci', 0.0)),
#  (230, ('driven tubulointerstitial fibrosis', 0.0)),
#  (231, ('dysfunction induced foci', 0.0)),
#  (232, ('for up activation', 0.0)),
#  (233, ('from matched tumor', 0.0)),
#  (234, ('in tubulointerstitial fibrosis', 0.0)),
#  (235, ('indicated by n', 0.0)),
#  (236, ('initiation cells frequency', 0.0)),
#  (237, ('insoluble f actin', 0.0)),
#  (238, ('intraoperative interface fluid', 0.0)),
#  (239, ('nduced f oci', 0.0)),
#  (240, ('number of telomere', 0.0)),
#  (241, ('on tubulointerstitial fibrosis', 0.0)),
#  (242, ('or eif 1', 0.0)),
#  (243, ('scale up accordingly', 0.0)),
#  (244, ('striped tubulointerstitial fibrosis', 0.0)),
#  (245, ('telomere induced foci', 0.0)),
#  (246, ('temperature independent factor', 0.0)),
#  (247, ('thalassaemia international federation', 0.0)),
#  (248, ('tif tubulointerstitial fibrosis', 0.0)),
#  (249, ('to tubulointerstitial inflammation', 0.0)),
#  (250, ('toxicity tubulointerstitial fibrosis', 0.0)),
#  (251, ('transcription intermediary factor', 0.0)),
#  (252, ('transient interface fluid', 0.0)),
#  (253, ('trichrome tubulointerstitial fibrosis', 0.0)),
#  (254, ('tubule interstitial fibrosis', 0.0)),
#  (255, ('twitter impact factor', 0.0)),
#  (256, ('types i fimbria', 0.0)),
#  (257, ('with radix isatidis', 0.0)),
#  (258, ('without tubulointerstitial fibrosis', 0.0)),
#  (259, ('1 driven tubulointerstitial fibrosis', 0.0)),
#  (260, ('1 renal tubulointerstitial fibrosis', 0.0)),
#  (261, ('1 transcription intermediary factor', 0.0)),
#  (262, ('2 7 4 trihydroxyisoflavanone', 0.0)),
#  (263, ('4 transoral incisionless fundoplication', 0.0)),
#  (264, ('7 transoral incisionless fundoplication', 0.0)),
#  (265, ('against renal tubulointerstitial fibrosis', 0.0)),
#  (266, ('aki is tubulointerstitial fibrosis', 0.0)),
#  (267, ('and chronic tubulointerstitial fibrosis', 0.0)),
#  (268, ('and striped tubulointerstitial fibrosis', 0.0)),
#  (269, ('and testicular interstitial fluid', 0.0)),
#  (270, ('and tif tubulointerstitial fibrosis', 0.0)),
#  (271, ('and without tubulointerstitial fibrosis', 0.0)),
#  (272, ('associated chronic tubulointerstitial fibrosis', 0.0)),
#  (273, ('between transient interface fluid', 0.0)),
#  (274, ('between tumor interstitial fluid', 0.0)),
#  (275, ('both with tubulointerstitial fibrosis', 0.0)),
#  (276, ('bound transcription initiation factor', 0.0)),
#  (277, ('bp b tubulointerstitial fibrosis', 0.0)),
#  (278, ('by progression tubulointerstitial fibrosis', 0.0)),
#  (279, ('by telomere induced foci', 0.0)),
#  (280, ('by test information function', 0.0)),
#  (281, ('ckd and tubulonterstitial fibrosis', 0.0)),
#  (282, ('clearance ccr tubulointerstitial fibrosis', 0.0)),
#  (283, ('contributor to tubulointerstitial inflammation', 0.0)),
#  (284, ('corresponding transoral incisionless fundoplication', 0.0)),
#  (285, ('disease is tubulointerstitial fibrosis', 0.0)),
#  (286, ('dn renal tubulointerstitial fibrosis', 0.0)),
#  (287, ('evaluated with tubulointerstitial fibrosis', 0.0)),
#  (288, ('features of tubulointerstitial fibrosis', 0.0)),
#  (289, ('function test information function', 0.0)),
#  (290, ('fundamental transcription initiation factor', 0.0)),
#  (291, ('glomerulosclerosis and tubulointerstitial fibrosis', 0.0)),
#  (292, ('gs and tubulointerstitial fibrosis', 0.0)),
#  (293, ('hepatorenal toxicity tubulointerstitial fibrosis', 0.0)),
#  (294, ('huaier with radix isatidis', 0.0)),
#  (295, ('i nduced f oci', 0.0)),
#  (296, ('important for up activation', 0.0)),
#  (297, ('in addition use tetraiodofluorescein', 0.0)),
#  (298, ('is indicated by n', 0.0)),
#  (299, ('is transoral incisionless fundoplication', 0.0)),
#  (300, ('levels testicular interstitial fluid', 0.0)),
#  (301, ('mdm2 in tubulointerstitial fibrosis', 0.0)),
#  (302, ('measurements fibrosis tubulointerstitial fibrosis', 0.0)),
#  (303, ('mk on tubulointerstitial fibrosis', 0.0)),
#  (304, ('mm totally impermeable film', 0.0)),
#  (305, ('msa transoral incisionless fundoplication', 0.0)),
#  (306, ('novel transoral incisionless fundoplication', 0.0)),
#  (307, ('occult intraoperative interface fluid', 0.0)),
#  (308, ('of renal tubulointerstitial fibrosis', 0.0)),
#  (309, ('of transoral incisionless fundoplication', 0.0)),
#  (310, ('on testicular interstitial fluid', 0.0)),
#  (311, ('or trypanosomal immunosuppressive factor', 0.0)),
#  (312, ('pathogenesis of tubulointerstitial fibrosis', 0.0)),
#  (313, ('photomicrographs of tubulointerstitial fibrosis', 0.0)),
#  (314, ('progression tubular interstitial fibrosis', 0.0)),
#  (315, ('promoter transcription initiation factor', 0.0)),
#  (316, ('rat with tubulointerstitial fibrosis', 0.0)),
#  (317, ('relationship with tubulointerstitial fibrosis', 0.0)),
#  (318, ('released from matched tumor', 0.0)),
#  (319, ('renal tubular interstitial fibrosis', 0.0)),
#  (320, ('role of tubulointerstitial fibrosis', 0.0)),
#  (321, ('s trichrome tubulointerstitial fibrosis', 0.0)),
#  (322, ('sek 1 right panels', 0.0)),
#  (323, ('serum testicular interstitial fluid', 0.0)),
#  (324, ('serves as loading control', 0.0)),
#  (325, ('tef or eif 1', 0.0)),
#  (326, ('telomere deprotection induced foci', 0.0)),
#  (327, ('termed trypanosomal immunosuppressive factor', 0.0)),
#  (328, ('testosterone testicular interstitial fluid', 0.0)),
#  (329, ('that transcription initiation factor', 0.0)),
#  (330, ('the number of telomere', 0.0)),
#  (331, ('the temperature independent factor', 0.0)),
#  (332, ('the transoral incisionless fundoplication', 0.0)),
#  (333, ('the trypanosomal immunosuppressive factor', 0.0)),
#  (334, ('the twitter impact factor', 0.0)),
#  (335, ('tnf alpha inhibiting factor', 0.0)),
#  (336, ('tns and of tetraiodofluorescein', 0.0)),
#  (337, ('to transoral incisionless fundoplication', 0.0)),
#  (338, ('treatments testicular interstitial fluid', 0.0)),
#  (339, ('tubulointerstitial fibrosis tubulointerstitial fibrosis', 0.0)),
#  (340, ('tumour initiation cells frequency', 0.0)),
#  (341, ('were scale up accordingly', 0.0)),
#  (342, ('with trypanosomal immunosuppressive factor', 0.0)),
#  (343, ('x 100 insoluble fraction', 0.0)),
#  (344, ('x 100 resistant pellets', 0.0)),
#  (345, ('04 mm totally impermeable film', 0.0)),
#  (346, ('1 in renal tubulointerstitial fibrosis', 0.0)),
#  (347, ('1 tef or eif 1', 0.0)),
#  (348, ('2 with totally impermeable film', 0.0)),
#  (349, ('27a in renal tubulointerstitial fibrosis', 0.0)),
#  (350, ('alcohol on testicular interstitial fluid', 0.0)),
#  (351, ('among rat with tubulointerstitial fibrosis', 0.0)),
#  (352, ('analyzed telomere dysfunction induced foci', 0.0)),
#  (353, ('and renal tubular interstitial fibrosis', 0.0)),
#  (354, ('and telomere dysfunction induced foci', 0.0)),
#  (355, ('and the thalassaemia international federation', 0.0)),
#  (356, ('as the temperature independent factor', 0.0)),
#  (357, ('assessed by test information function', 0.0)),
#  (358, ('associated between transient interface fluid', 0.0)),
#  (359, ('augmentation msa transoral incisionless fundoplication', 0.0)),
#  (360, ('beta 1 driven tubulointerstitial fibrosis', 0.0)),
#  (361, ('caspases in renal tubulointerstitial fibrosis', 0.0)),
#  (362, ('characterized by progression tubulointerstitial fibrosis', 0.0)),
#  (363, ('competence is transoral incisionless fundoplication', 0.0)),
#  (364, ('complications 4 transoral incisionless fundoplication', 0.0)),
#  (365, ('concentration in tumor interstitial fluid', 0.0)),
#  (366, ('conditions telomere dysfunction induced foci', 0.0)),
#  (367, ('correlated both with tubulointerstitial fibrosis', 0.0)),
#  (368, ('covered with totally impermeable film', 0.0)),
#  (369, ('creatinine clearance ccr tubulointerstitial fibrosis', 0.0)),
#  (370, ('crucial contributor to tubulointerstitial inflammation', 0.0)),
#  (371, ('cruzi or trypanosomal immunosuppressive factor', 0.0)),
#  (372, ('cyclosporin associated chronic tubulointerstitial fibrosis', 0.0)),
#  (373, ('development of renal tubulointerstitial fibrosis', 0.0)),
#  (374, ('disease ckd and tubulonterstitial fibrosis', 0.0)),
#  (375, ('dysfunction i nduced f oci', 0.0)),
#  (376, ('ecm the tumor interstitial fluid', 0.0)),
#  (377, ('ecm tubulointerstitial fibrosis tubulointerstitial fibrosis', 0.0)),
#  (378, ('emt and chronic tubulointerstitial fibrosis', 0.0)),
#  (379, ('evaluated the twitter impact factor', 0.0)),
#  (380, ('evident hepatorenal toxicity tubulointerstitial fibrosis', 0.0)),
#  (381, ('for dn renal tubulointerstitial fibrosis', 0.0)),
#  (382, ('for measurements fibrosis tubulointerstitial fibrosis', 0.0)),
#  (383, ('from the thalassaemia international federation', 0.0)),
#  (384, ('gene promoter transcription initiation factor', 0.0)),
#  (385, ('generally important for up activation', 0.0)),
#  (386, ('gerd 7 transoral incisionless fundoplication', 0.0)),
#  (387, ('glomerulosclerosis gs and tubulointerstitial fibrosis', 0.0)),
#  (388, ('glycans released from matched tumor', 0.0)),
#  (389, ('gradient between tumor interstitial fluid', 0.0)),
#  (390, ('ies in addition use tetraiodofluorescein', 0.0)),
#  (391, ('imaging telomere deprotection induced foci', 0.0)),
#  (392, ('important features of tubulointerstitial fibrosis', 0.0)),
#  (393, ('in glomerulosclerosis and tubulointerstitial fibrosis', 0.0)),
#  (394, ('in serum testicular interstitial fluid', 0.0)),
#  (395, ('in telomere dysfunction induced foci', 0.0)),
#  (396, ('including the trypanosomal immunosuppressive factor', 0.0)),
#  (397, ('indicated that tubule interstitial fibrosis', 0.0)),
#  (398, ('infiltration and striped tubulointerstitial fibrosis', 0.0)),
#  (399, ('inflammation and tif tubulointerstitial fibrosis', 0.0)),
#  (400, ('instead 2 7 4 trihydroxyisoflavanone', 0.0)),
#  (401, ('is the transoral incisionless fundoplication', 0.0)),
#  (402, ('is the tumor interstitial fluid', 0.0)),
#  (403, ('issue 1 renal tubulointerstitial fibrosis', 0.0)),
#  (404, ('kidney disease is tubulointerstitial fibrosis', 0.0)),
#  (405, ('mapkk sek 1 right panels', 0.0)),
#  (406, ('marked by telomere induced foci', 0.0)),
#  (407, ('masson s trichrome tubulointerstitial fibrosis', 0.0)),
#  (408, ('murr huaier with radix isatidis', 0.0)),
#  (409, ('nephrosis and without tubulointerstitial fibrosis', 0.0)),
#  (410, ('number tumour initiation cells frequency', 0.0)),
#  (411, ('of mdm2 in tubulointerstitial fibrosis', 0.0)),
#  (412, ('of mk on tubulointerstitial fibrosis', 0.0)),
#  (413, ('of the tumor interstitial fluid', 0.0)),
#  (414, ('on the number of telomere', 0.0)),
#  (415, ('or progression tubular interstitial fibrosis', 0.0)),
#  (416, ('osteopontin in tumor interstitial fluid', 0.0)),
#  (417, ('parasite termed trypanosomal immunosuppressive factor', 0.0)),
#  (418, ('pathogenic role of tubulointerstitial fibrosis', 0.0)),
#  (419, ('pmns triton insoluble f actin', 0.0)),
#  (420, ('possible the thalassaemia international federation', 0.0)),
#  (421, ('promoter bound transcription initiation factor', 0.0)),
#  (422, ('protection against renal tubulointerstitial fibrosis', 0.0)),
#  (423, ('reagents were scale up accordingly', 0.0)),
#  (424, ('reported that tubule interstitial fibrosis', 0.0)),
#  (425,
#   ('representative photomicrographs of tubulointerstitial fibrosis', 0.0)),
#  (426, ('response to transoral incisionless fundoplication', 0.0)),
#  (427, ('score function test information function', 0.0)),
#  (428, ('secreted and testicular interstitial fluid', 0.0)),
#  (429, ('serum testosterone testicular interstitial fluid', 0.0)),
#  (430, ('shares with trypanosomal immunosuppressive factor', 0.0)),
#  (431, ('shown that transcription initiation factor', 0.0)),
#  (432, ('significant is indicated by n', 0.0)),
#  (433, ('src 1 transcription intermediary factor', 0.0)),
#  (434, ('sulfonate tns and of tetraiodofluorescein', 0.0)),
#  (435, ('systolic bp b tubulointerstitial fibrosis', 0.0)),
#  (436, ('termed tnf alpha inhibiting factor', 0.0)),
#  (437, ('testosterone levels testicular interstitial fluid', 0.0)),
#  (438, ('the corresponding transoral incisionless fundoplication', 0.0)),
#  (439, ('the triton insoluble f actin', 0.0)),
#  (440, ('their relationship with tubulointerstitial fibrosis', 0.0)),
#  (441, ('these treatments testicular interstitial fluid', 0.0)),
#  (442, ('through the tumor interstitial fluid', 0.0)),
#  (443, ('transient occult intraoperative interface fluid', 0.0)),
#  (444, ('treatments the tumor interstitial fluid', 0.0)),
#  (445, ('triton x 100 insoluble fraction', 0.0)),
#  (446, ('triton x 100 resistant pellets', 0.0)),
#  (447, ('tubulin serves as loading control', 0.0)),
#  (448, ('tumor the tumor interstitial fluid', 0.0)),
#  (449, ('use of transoral incisionless fundoplication', 0.0)),
#  (450, ('way the thalassaemia international federation', 0.0)),
#  (451, ('were evaluated with tubulointerstitial fibrosis', 0.0)),
#  (452, ('with aki is tubulointerstitial fibrosis', 0.0)),
#  (453, ('0 04 mm totally impermeable film', 0.0)),
#  (454, ('0 2 with totally impermeable film', 0.0)),
#  (455, ('125 concentration in tumor interstitial fluid', 0.0)),
#  (456, ('1a 1 tef or eif 1', 0.0)),
#  (457, ('2 covered with totally impermeable film', 0.0)),
#  (458, ('6 sulfonate tns and of tetraiodofluorescein', 0.0)),
#  (459, ('a crucial contributor to tubulointerstitial inflammation', 0.0)),
#  (460, ('a promoter bound transcription initiation factor', 0.0)),
#  (461, ('activation termed tnf alpha inhibiting factor', 0.0)),
#  (462, ('actual gradient between tumor interstitial fluid', 0.0)),
#  (463, ('and analyzed telomere dysfunction induced foci', 0.0)),
#  (464, ('and evaluated the twitter impact factor', 0.0)),
#  (465, ('and masson s trichrome tubulointerstitial fibrosis', 0.0)),
#  (466, ('and or progression tubular interstitial fibrosis', 0.0)),
#  (467, ('and the corresponding transoral incisionless fundoplication', 0.0)),
#  (468, ('and their relationship with tubulointerstitial fibrosis', 0.0)),
#  (469, ('as important features of tubulointerstitial fibrosis', 0.0)),
#  (470, ('associated with aki is tubulointerstitial fibrosis', 0.0)),
#  (471, ('average systolic bp b tubulointerstitial fibrosis', 0.0)),
#  (472, ('be generally important for up activation', 0.0)),
#  (473, ('be marked by telomere induced foci', 0.0)),
#  (474, ('been reported that tubule interstitial fibrosis', 0.0)),
#  (475, ('by imaging telomere deprotection induced foci', 0.0)),
#  (476, ('cells infiltration and striped tubulointerstitial fibrosis', 0.0)),
#  (477, ('change in telomere dysfunction induced foci', 0.0)),
#  (478, ('chronic kidney disease is tubulointerstitial fibrosis', 0.0)),
#  (479, ('component shares with trypanosomal immunosuppressive factor', 0.0)),
#  (480, ('contribute of the tumor interstitial fluid', 0.0)),
#  (481, ('csc number tumour initiation cells frequency', 0.0)),
#  (482, ('depletion on the number of telomere', 0.0)),
#  (483, ('effects of mk on tubulointerstitial fibrosis', 0.0)),
#  (484, ('effects treatments the tumor interstitial fluid', 0.0)),
#  (485, ('egj competence is transoral incisionless fundoplication', 0.0)),
#  (486, ('elomere dysfunction i nduced f oci', 0.0)),
#  (487, ('expected score function test information function', 0.0)),
#  (488, ('expression correlated both with tubulointerstitial fibrosis', 0.0)),
#  (489, ('fibrosis the pathogenesis of tubulointerstitial fibrosis', 0.0)),
#  (490, ('format of telomere dysfunction induced foci', 0.0)),
#  (491, ('format reagents were scale up accordingly', 0.0)),
#  (492, ('gamma tubulin serves as loading control', 0.0)),
#  (493, ('gene protection against renal tubulointerstitial fibrosis', 0.0)),
#  (494, ('gerd is the transoral incisionless fundoplication', 0.0)),
#  (495,
#   ('glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#    0.0)),
#  (496, ('have indicated that tubule interstitial fibrosis', 0.0)),
#  (497, ('have shown that transcription initiation factor', 0.0)),
#  (498, ('health issue 1 renal tubulointerstitial fibrosis', 0.0)),
#  (499, ('hormone serum testosterone testicular interstitial fluid', 0.0)),
#  (500, ('implemented through the tumor interstitial fluid', 0.0)),
#  (501, ('in pmns triton insoluble f actin', 0.0)),
#  (502,
#   ('injury representative photomicrographs of tubulointerstitial fibrosis',
#    0.0)),
#  (503, ('injury were evaluated with tubulointerstitial fibrosis', 0.0)),
#  (504, ('known as telomere dysfunction induced foci', 0.0)),
#  (505, ('kovacs the pathogenesis of tubulointerstitial fibrosis', 0.0)),
#  (506, ('matrix ecm the tumor interstitial fluid', 0.0)),
#  (507, ('mcp 1 in renal tubulointerstitial fibrosis', 0.0)),
#  (508, ('mesp nephrosis and without tubulointerstitial fibrosis', 0.0)),
#  (509, ('mir 27a in renal tubulointerstitial fibrosis', 0.0)),
#  (510, ('molecules including the trypanosomal immunosuppressive factor', 0.0)),
#  (511, ('n glycans released from matched tumor', 0.0)),
#  (512, ('nephrotoxicity and renal tubular interstitial fibrosis', 0.0)),
#  (513,
#   ('nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#    0.0)),
#  (514, ('not significant is indicated by n', 0.0)),
#  (515, ('obtain triton x 100 resistant pellets', 0.0)),
#  (516, ('of alcohol on testicular interstitial fluid', 0.0)),
#  (517, ('of caspases in renal tubulointerstitial fibrosis', 0.0)),
#  (518, ('of complications 4 transoral incisionless fundoplication', 0.0)),
#  (519, ('of cyclosporin associated chronic tubulointerstitial fibrosis', 0.0)),
#  (520, ('of enlarged telomere dysfunction induced foci', 0.0)),
#  (521, ('of gerd 7 transoral incisionless fundoplication', 0.0)),
#  (522, ('of inflammation and tif tubulointerstitial fibrosis', 0.0)),
#  (523, ('of these treatments testicular interstitial fluid', 0.0)),
#  (524, ('of transient occult intraoperative interface fluid', 0.0)),
#  (525, ('p38 mapkk sek 1 right panels', 0.0)),
#  (526, ('part of telomere dysfunction induced foci', 0.0)),
#  (527, ('patients response to transoral incisionless fundoplication', 0.0)),
#  (528, ('perturbation conditions telomere dysfunction induced foci', 0.0)),
#  (529, ('pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0)),
#  (530, ('presence of telomere dysfunction induced foci', 0.0)),
#  (531, ('project and the thalassaemia international federation', 0.0)),
#  (532, ('protein creatinine clearance ccr tubulointerstitial fibrosis', 0.0)),
#  (533, ('renal disease ckd and tubulonterstitial fibrosis', 0.0)),
#  (534,
#   ('resulting in glomerulosclerosis and tubulointerstitial fibrosis', 0.0)),
#  (535, ('rna gene promoter transcription initiation factor', 0.0)),
#  (536, ('robiniophila murr huaier with radix isatidis', 0.0)),
#  (537, ('role of mdm2 in tubulointerstitial fibrosis', 0.0)),
#  (538, ('serum testosterone levels testicular interstitial fluid', 0.0)),
#  (539, ('showed enlarged telomere dysfunction induced foci', 0.0)),
#  (540,
#   ('showed evident hepatorenal toxicity tubulointerstitial fibrosis', 0.0)),
#  (541,
#   ('significant glomerulosclerosis gs and tubulointerstitial fibrosis', 0.0)),
#  (542, ('solid tumor the tumor interstitial fluid', 0.0)),
#  (543,
#   ('sphincter augmentation msa transoral incisionless fundoplication', 0.0)),
#  (544,
#   ('standard for measurements fibrosis tubulointerstitial fibrosis', 0.0)),
#  (545, ('stud ies in addition use tetraiodofluorescein', 0.0)),
#  (546, ('successful use of transoral incisionless fundoplication', 0.0)),
#  (547, ('systematic way the thalassaemia international federation', 0.0)),
#  (548, ('t cruzi or trypanosomal immunosuppressive factor', 0.0)),
#  (549, ('taken from the thalassaemia international federation', 0.0)),
#  (550, ('target for dn renal tubulointerstitial fibrosis', 0.0)),
#  (551, ('testosterone in serum testicular interstitial fluid', 0.0)),
#  (552, ('testosterone secreted and testicular interstitial fluid', 0.0)),
#  (553, ('tgf beta 1 driven tubulointerstitial fibrosis', 0.0)),
#  (554, ('the associated between transient interface fluid', 0.0)),
#  (555, ('the development of renal tubulointerstitial fibrosis', 0.0)),
#  (556, ('the pathogenic role of tubulointerstitial fibrosis', 0.0)),
#  (557, ('the src 1 transcription intermediary factor', 0.0)),
#  (558, ('the triton x 100 insoluble fraction', 0.0)),
#  (559, ('this parasite termed trypanosomal immunosuppressive factor', 0.0)),
#  (560, ('tissue among rat with tubulointerstitial fibrosis', 0.0)),
#  (561, ('tme is the tumor interstitial fluid', 0.0)),
#  (562, ('to as the temperature independent factor', 0.0)),
#  (563, ('to the triton insoluble f actin', 0.0)),
#  (564, ('transition emt and chronic tubulointerstitial fibrosis', 0.0)),
#  (565, ('trap and telomere dysfunction induced foci', 0.0)),
#  (566, ('visualized as telomere dysfunction induced foci', 0.0)),
#  (567, ('was assessed by test information function', 0.0)),
#  (568, ('wherever possible the thalassaemia international federation', 0.0)),
#  (569, ('+ pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0)),
#  (570, ('1 mcp 1 in renal tubulointerstitial fibrosis', 0.0)),
#  (571, ('a and osteopontin in tumor interstitial fluid', 0.0)),
#  (572, ('a systematic way the thalassaemia international federation', 0.0)),
#  (573, ('actin in pmns triton insoluble f actin', 0.0)),
#  (574, ('also a crucial contributor to tubulointerstitial inflammation', 0.0)),
#  (575, ('also known as telomere dysfunction induced foci', 0.0)),
#  (576, ('analysis part of telomere dysfunction induced foci', 0.0)),
#  (577, ('and 0 04 mm totally impermeable film', 0.0)),
#  (578, ('and 0 2 with totally impermeable film', 0.0)),
#  (579, ('and expected score function test information function', 0.0)),
#  (580, ('and fibrosis the pathogenesis of tubulointerstitial fibrosis', 0.0)),
#  (581, ('and successful use of transoral incisionless fundoplication', 0.0)),
#  (582, ('are implemented through the tumor interstitial fluid', 0.0)),
#  (583, ('be visualized as telomere dysfunction induced foci', 0.0)),
#  (584, ('biphasic effects of mk on tubulointerstitial fibrosis', 0.0)),
#  (585, ('bound to the triton insoluble f actin', 0.0)),
#  (586,
#   ('but significant glomerulosclerosis gs and tubulointerstitial fibrosis',
#    0.0)),
#  (587, ('by this parasite termed trypanosomal immunosuppressive factor', 0.0)),
#  (588, ('ca 125 concentration in tumor interstitial fluid', 0.0)),
#  (589, ('can be marked by telomere induced foci', 0.0)),
#  (590, ('cells showed enlarged telomere dysfunction induced foci', 0.0)),
#  (591, ('chronic renal disease ckd and tubulonterstitial fibrosis', 0.0)),
#  (592,
#   ('csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#    0.0)),
#  (593,
#   ('cytokines kovacs the pathogenesis of tubulointerstitial fibrosis', 0.0)),
#  (594, ('design effects treatments the tumor interstitial fluid', 0.0)),
#  (595, ('development tgf beta 1 driven tubulointerstitial fibrosis', 0.0)),
#  (596,
#   ('device and the corresponding transoral incisionless fundoplication', 0.0)),
#  (597, ('diagnose of gerd 7 transoral incisionless fundoplication', 0.0)),
#  (598, ('eef 1a 1 tef or eif 1', 0.0)),
#  (599, ('effects of alcohol on testicular interstitial fluid', 0.0)),
#  (600,
#   ('european project and the thalassaemia international federation', 0.0)),
#  (601, ('examine the associated between transient interface fluid', 0.0)),
#  (602, ('extracellular matrix ecm the tumor interstitial fluid', 0.0)),
#  (603,
#   ('glomerulosclerosis and or progression tubular interstitial fibrosis',
#    0.0)),
#  (604,
#   ('gold standard for measurements fibrosis tubulointerstitial fibrosis',
#    0.0)),
#  (605, ('has been reported that tubule interstitial fibrosis', 0.0)),
#  (606, ('however the pathogenic role of tubulointerstitial fibrosis', 0.0)),
#  (607,
#   ('identified patients response to transoral incisionless fundoplication',
#    0.0)),
#  (608,
#   ('immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#    0.0)),
#  (609,
#   ('improve egj competence is transoral incisionless fundoplication', 0.0)),
#  (610, ('in the development of renal tubulointerstitial fibrosis', 0.0)),
#  (611, ('in the triton x 100 insoluble fraction', 0.0)),
#  (612, ('including the src 1 transcription intermediary factor', 0.0)),
#  (613,
#   ('induced nephrotoxicity and renal tubular interstitial fibrosis', 0.0)),
#  (614,
#   ('inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#    0.0)),
#  (615, ('inhibitor and analyzed telomere dysfunction induced foci', 0.0)),
#  (616, ('initiation of these treatments testicular interstitial fluid', 0.0)),
#  (617, ('kidney tissue among rat with tubulointerstitial fibrosis', 0.0)),
#  (618,
#   ('luteinizing hormone serum testosterone testicular interstitial fluid',
#    0.0)),
#  (619, ('may be generally important for up activation', 0.0)),
#  (620,
#   ('membrane component shares with trypanosomal immunosuppressive factor',
#    0.0)),
#  (621,
#   ('mesenchymal transition emt and chronic tubulointerstitial fibrosis', 0.0)),
#  (622,
#   ('metabolites and their relationship with tubulointerstitial fibrosis',
#    0.0)),
#  (623, ('microenvironment tme is the tumor interstitial fluid', 0.0)),
#  (624,
#   ('model of cyclosporin associated chronic tubulointerstitial fibrosis',
#    0.0)),
#  (625,
#   ('notch1 expression correlated both with tubulointerstitial fibrosis', 0.0)),
#  (626, ('ns depletion on the number of telomere', 0.0)),
#  (627,
#   ('occurrence of complications 4 transoral incisionless fundoplication',
#    0.0)),
#  (628, ('of chronic kidney disease is tubulointerstitial fibrosis', 0.0)),
#  (629, ('of gerd is the transoral incisionless fundoplication', 0.0)),
#  (630, ('of mir 27a in renal tubulointerstitial fibrosis', 0.0)),
#  (631, ('of serum testosterone levels testicular interstitial fluid', 0.0)),
#  (632, ('of solid tumor the tumor interstitial fluid', 0.0)),
#  (633, ('of testosterone in serum testicular interstitial fluid', 0.0)),
#  (634, ('on testosterone secreted and testicular interstitial fluid', 0.0)),
#  (635, ('pas and masson s trichrome tubulointerstitial fibrosis', 0.0)),
#  (636,
#   ('pathogenesis of inflammation and tif tubulointerstitial fibrosis', 0.0)),
#  (637, ('pathology associated with aki is tubulointerstitial fibrosis', 0.0)),
#  (638, ('presence of transient occult intraoperative interface fluid', 0.0)),
#  (639, ('present and evaluated the twitter impact factor', 0.0)),
#  (640, ('present stud ies in addition use tetraiodofluorescein', 0.0)),
#  (641,
#   ('production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#    0.0)),
#  (642, ('profiling n glycans released from matched tumor', 0.0)),
#  (643,
#   ('proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#    0.0)),
#  (644, ('protocol trap and telomere dysfunction induced foci', 0.0)),
#  (645, ('public health issue 1 renal tubulointerstitial fibrosis', 0.0)),
#  (646, ('qualitatively by imaging telomere deprotection induced foci', 0.0)),
#  (647, ('referred to as the temperature independent factor', 0.0)),
#  (648,
#   ('registries wherever possible the thalassaemia international federation',
#    0.0)),
#  (649,
#   ('renal injury representative photomicrographs of tubulointerstitial fibrosis',
#    0.0)),
#  (650, ('renal injury were evaluated with tubulointerstitial fibrosis', 0.0)),
#  (651, ('ribosomal rna gene promoter transcription initiation factor', 0.0)),
#  (652, ('scale was assessed by test information function', 0.0)),
#  (653,
#   ('shelterin perturbation conditions telomere dysfunction induced foci',
#    0.0)),
#  (654, ('significant change in telomere dysfunction induced foci', 0.0)),
#  (655,
#   ('smad3 gene protection against renal tubulointerstitial fibrosis', 0.0)),
#  (656, ('studies have indicated that tubule interstitial fibrosis', 0.0)),
#  (657, ('t elomere dysfunction i nduced f oci', 0.0)),
#  (658, ('the actual gradient between tumor interstitial fluid', 0.0)),
#  (659, ('the contribute of the tumor interstitial fluid', 0.0)),
#  (660, ('the csc number tumour initiation cells frequency', 0.0)),
#  (661, ('the format of telomere dysfunction induced foci', 0.0)),
#  (662,
#   ('the glomerular ecm tubulointerstitial fibrosis tubulointerstitial fibrosis',
#    0.0)),
#  (663, ('the p38 mapkk sek 1 right panels', 0.0)),
#  (664, ('the presence of telomere dysfunction induced foci', 0.0)),
#  (665, ('the role of mdm2 in tubulointerstitial fibrosis', 0.0)),
#  (666, ('therapeutic target for dn renal tubulointerstitial fibrosis', 0.0)),
#  (667, ('this activation termed tnf alpha inhibiting factor', 0.0)),
#  (668, ('through a promoter bound transcription initiation factor', 0.0)),
#  (669, ('to obtain triton x 100 resistant pellets', 0.0)),
#  (670,
#   ('toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein', 0.0)),
#  (671, ('trametes robiniophila murr huaier with radix isatidis', 0.0)),
#  (672, ('transfection gamma tubulin serves as loading control', 0.0)),
#  (673, ('types of caspases in renal tubulointerstitial fibrosis', 0.0)),
#  (674,
#   ('urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#    0.0)),
#  (675, ('vegf and osteopontin in tumor interstitial fluid', 0.0)),
#  (676, ('views of enlarged telomere dysfunction induced foci', 0.0)),
#  (677, ('vimentin as important features of tubulointerstitial fibrosis', 0.0)),
#  (678, ('we have shown that transcription initiation factor', 0.0)),
#  (679, ('week average systolic bp b tubulointerstitial fibrosis', 0.0)),
#  (680, ('well format reagents were scale up accordingly', 0.0)),
#  (681, ('were taken from the thalassaemia international federation', 0.0)),
#  (682, ('where not significant is indicated by n', 0.0)),
#  (683, ('whether t cruzi or trypanosomal immunosuppressive factor', 0.0)),
#  (684,
#   ('without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#    0.0)),
#  (685, ('− 2 covered with totally impermeable film', 0.0)),
#  (686, ('02 and 0 2 with totally impermeable film', 0.0)),
#  (687, ('1 eef 1a 1 tef or eif 1', 0.0)),
#  (688, ('125 vegf and osteopontin in tumor interstitial fluid', 0.0)),
#  (689, ('16 week average systolic bp b tubulointerstitial fibrosis', 0.0)),
#  (690, ('24 well format reagents were scale up accordingly', 0.0)),
#  (691, ('4 the actual gradient between tumor interstitial fluid', 0.0)),
#  (692,
# ...
#    0.0)),
#  (827,
#   ('dose dependent biphasic effects of mk on tubulointerstitial fibrosis',
#    0.0)),
#  (828, ('dysfunction telomere can be marked by telomere induced foci', 0.0)),
#  (829, ('effects of ns depletion on the number of telomere', 0.0)),
#  (830, ('ends can be visualized as telomere dysfunction induced foci', 0.0)),
#  (831,
#   ('essential to design effects treatments the tumor interstitial fluid',
#    0.0)),
#  (832,
#   ('estimation of the csc number tumour initiation cells frequency', 0.0)),
#  (833,
#   ('exclude the diagnose of gerd 7 transoral incisionless fundoplication',
#    0.0)),
#  (834,
#   ('extract of trametes robiniophila murr huaier with radix isatidis', 0.0)),
#  (835, ('f induced the format of telomere dysfunction induced foci', 0.0)),
#  (836, ('fluid phase of solid tumor the tumor interstitial fluid', 0.0)),
#  (837, ('focus on the contribute of the tumor interstitial fluid', 0.0)),
#  (838, ('fold 4 the actual gradient between tumor interstitial fluid', 0.0)),
#  (839, ('g m − 2 covered with totally impermeable film', 0.0)),
#  (840,
#   ('g1 progression we have shown that transcription initiation factor', 0.0)),
#  (841, ('glycome by profiling n glycans released from matched tumor', 0.0)),
#  (842, ('hrs post transfection gamma tubulin serves as loading control', 0.0)),
#  (843,
#   ('imaging and analysis part of telomere dysfunction induced foci', 0.0)),
#  (844,
#   ('in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#    0.0)),
#  (845,
#   ('in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#    0.0)),
#  (846, ('in the present stud ies in addition use tetraiodofluorescein', 0.0)),
#  (847,
#   ('induced epithelial mesenchymal transition emt and chronic tubulointerstitial fibrosis',
#    0.0)),
#  (848,
#   ('is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#    0.0)),
#  (849,
#   ('is therefore referred to as the temperature independent factor', 0.0)),
#  (850,
#   ('key role in the development of renal tubulointerstitial fibrosis', 0.0)),
#  (851,
#   ('matrix ecm production resulting in glomerulosclerosis and tubulointerstitial fibrosis',
#    0.0)),
#  (852,
#   ('nci h522 cells showed enlarged telomere dysfunction induced foci', 0.0)),
#  (853, ('none is bound to the triton insoluble f actin', 0.0)),
#  (854,
#   ('not known whether t cruzi or trypanosomal immunosuppressive factor', 0.0)),
#  (855,
#   ('number of studies have indicated that tubule interstitial fibrosis', 0.0)),
#  (856,
#   ('of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#    0.0)),
#  (857,
#   ('of concentration of testosterone in serum testicular interstitial fluid',
#    0.0)),
#  (858,
#   ('of dn however the pathogenic role of tubulointerstitial fibrosis', 0.0)),
#  (859,
#   ('of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#    0.0)),
#  (860,
#   ('of imidazoles on testosterone secreted and testicular interstitial fluid',
#    0.0)),
#  (861,
#   ('of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#    0.0)),
#  (862,
#   ('of slowly development tgf beta 1 driven tubulointerstitial fibrosis',
#    0.0)),
#  (863, ('of the scale was assessed by test information function', 0.0)),
#  (864,
#   ('of the smad3 gene protection against renal tubulointerstitial fibrosis',
#    0.0)),
#  (865,
#   ('organizations collaborated european project and the thalassaemia international federation',
#    0.0)),
#  (866,
#   ('other figures were taken from the thalassaemia international federation',
#    0.0)),
#  (867, ('precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone', 0.0)),
#  (868,
#   ('problems in a systematic way the thalassaemia international federation',
#    0.0)),
#  (869, ('province china and 0 04 mm totally impermeable film', 0.0)),
#  (870,
#   ('receptor activation including the src 1 transcription intermediary factor',
#    0.0)),
#  (871,
#   ('repeat amplification protocol trap and telomere dysfunction induced foci',
#    0.0)),
#  (872,
#   ('resistant mesangial proliferative mesp nephrosis and without tubulointerstitial fibrosis',
#    0.0)),
#  (873,
#   ('revealed no significant change in telomere dysfunction induced foci',
#    0.0)),
#  (874,
#   ('salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#    0.0)),
#  (875,
#   ('six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#    0.0)),
#  (876, ('skn 1 eef 1a 1 tef or eif 1', 0.0)),
#  (877,
#   ('spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#    0.0)),
#  (878, ('stage grade ca 125 concentration in tumor interstitial fluid', 0.0)),
#  (879,
#   ('surgical treatments of gerd is the transoral incisionless fundoplication',
#    0.0)),
#  (880,
#   ('t cruzi immunomodulatory molecules including the trypanosomal immunosuppressive factor',
#    0.0)),
#  (881,
#   ('t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#    0.0)),
#  (882,
#   ('tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#    0.0)),
#  (883,
#   ('technique might identified patients response to transoral incisionless fundoplication',
#    0.0)),
#  (884, ('telomere dna also known as telomere dysfunction induced foci', 0.0)),
#  (885,
#   ('that the presence of transient occult intraoperative interface fluid',
#    0.0)),
#  (886, ('the 24 well format reagents were scale up accordingly', 0.0)),
#  (887,
#   ('the esophyx device and the corresponding transoral incisionless fundoplication',
#    0.0)),
#  (888,
#   ('the eukaryotic ribosomal rna gene promoter transcription initiation factor',
#    0.0)),
#  (889,
#   ('the main pathology associated with aki is tubulointerstitial fibrosis',
#    0.0)),
#  (890,
#   ('the pathogenesis of mir 27a in renal tubulointerstitial fibrosis', 0.0)),
#  (891,
#   ('the safe and successful use of transoral incisionless fundoplication',
#    0.0)),
#  (892,
#   ('the tumor microenvironment tme is the tumor interstitial fluid', 0.0)),
#  (893,
#   ('therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#    0.0)),
#  (894,
#   ('through measurements of serum testosterone levels testicular interstitial fluid',
#    0.0)),
#  (895,
#   ('time after initiation of these treatments testicular interstitial fluid',
#    0.0)),
#  (896,
#   ('timp2 and vimentin as important features of tubulointerstitial fibrosis',
#    0.0)),
#  (897, ('tnf alpha this activation termed tnf alpha inhibiting factor', 0.0)),
#  (898, ('to as t elomere dysfunction i nduced f oci', 0.0)),
#  (899,
#   ('to read through a promoter bound transcription initiation factor', 0.0)),
#  (900,
#   ('to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#    0.0)),
#  (901,
#   ('to tif without showed evident hepatorenal toxicity tubulointerstitial fibrosis',
#    0.0)),
#  (902,
#   ('tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#    0.0)),
#  (903,
#   ('tubulointerstitial inflammation and fibrosis the pathogenesis of tubulointerstitial fibrosis',
#    0.0)),
#  (904,
#   ('tumor stroma are implemented through the tumor interstitial fluid', 0.0)),
#  (905,
#   ('two distinct types of caspases in renal tubulointerstitial fibrosis',
#    0.0)),
#  (906,
#   ('under various shelterin perturbation conditions telomere dysfunction induced foci',
#    0.0)),
#  (907, ('unknown protein in the triton x 100 insoluble fraction', 0.0)),
#  (908,
#   ('wald test and expected score function test information function', 0.0)),
#  (909,
#   ('we investigated the role of mdm2 in tubulointerstitial fibrosis', 0.0)),
#  (910,
#   ('were assessed qualitatively by imaging telomere deprotection induced foci',
#    0.0)),
#  (911, ('with g actin in pmns triton insoluble f actin', 0.0)),
#  (912, ('years it has been reported that tubule interstitial fibrosis', 0.0)),
#  (913,
#   ('1500 fold 4 the actual gradient between tumor interstitial fluid', 0.0)),
#  (914,
#   ('20 tubule specific notch1 expression correlated both with tubulointerstitial fibrosis',
#    0.0)),
#  (915,
#   ('24 the esophyx device and the corresponding transoral incisionless fundoplication',
#    0.0)),
#  (916, ('3b f induced the format of telomere dysfunction induced foci', 0.0)),
#  (917, ('50 g m − 2 covered with totally impermeable film', 0.0)),
#  (918, ('6 14 therefore may be generally important for up activation', 0.0)),
#  (919,
#   ('72 hrs post transfection gamma tubulin serves as loading control', 0.0)),
#  (920,
#   ('a key role in the development of renal tubulointerstitial fibrosis', 0.0)),
#  (921,
#   ('a number of studies have indicated that tubule interstitial fibrosis',
#    0.0)),
#  (922,
#   ('a salt dependent model of cyclosporin associated chronic tubulointerstitial fibrosis',
#    0.0)),
#  (923,
#   ('a t cruzi membrane component shares with trypanosomal immunosuppressive factor',
#    0.0)),
#  (924,
#   ('academic content to present and evaluated the twitter impact factor',
#    0.0)),
#  (925,
#   ('after six week urinary protein creatinine clearance ccr tubulointerstitial fibrosis',
#    0.0)),
#  (926,
#   ('against tac induced renal injury representative photomicrographs of tubulointerstitial fibrosis',
#    0.0)),
#  (927,
#   ('allowed estimation of the csc number tumour initiation cells frequency',
#    0.0)),
#  (928,
#   ('an akt specific inhibitor and analyzed telomere dysfunction induced foci',
#    0.0)),
#  (929,
#   ('and is therefore referred to as the temperature independent factor', 0.0)),
#  (930, ('and none is bound to the triton insoluble f actin', 0.0)),
#  (931,
#   ('and other figures were taken from the thalassaemia international federation',
#    0.0)),
#  (932,
#   ('approaches aimed to improve egj competence is transoral incisionless fundoplication',
#    0.0)),
#  (933,
#   ('as a crucial public health issue 1 renal tubulointerstitial fibrosis',
#    0.0)),
#  (934,
#   ('assessed of concentration of testosterone in serum testicular interstitial fluid',
#    0.0)),
#  (935,
#   ('biopsy is the gold standard for measurements fibrosis tubulointerstitial fibrosis',
#    0.0)),
#  (936,
#   ('but the pathogenesis of mir 27a in renal tubulointerstitial fibrosis',
#    0.0)),
#  (937,
#   ('by wald test and expected score function test information function', 0.0)),
#  (938, ('ca 125 vegf a and osteopontin in tumor interstitial fluid', 0.0)),
#  (939,
#   ('caused by dm inflammatory cells infiltration and striped tubulointerstitial fibrosis',
#    0.0)),
#  (940,
#   ('cells revealed no significant change in telomere dysfunction induced foci',
#    0.0)),
#  (941,
#   ('chromosome ends can be visualized as telomere dysfunction induced foci',
#    0.0)),
#  (942, ('coexisting with g actin in pmns triton insoluble f actin', 0.0)),
#  (943,
#   ('contribute to the pathogenesis of inflammation and tif tubulointerstitial fibrosis',
#    0.0)),
#  (944, ('control skn 1 eef 1a 1 tef or eif 1', 0.0)),
#  (945,
#   ('deletion of the smad3 gene protection against renal tubulointerstitial fibrosis',
#    0.0)),
#  (946,
#   ('during g1 progression we have shown that transcription initiation factor',
#    0.0)),
#  (947,
#   ('effects of imidazoles on testosterone secreted and testicular interstitial fluid',
#    0.0)),
#  (948,
#   ('endoflip technique might identified patients response to transoral incisionless fundoplication',
#    0.0)),
#  (949,
#   ('examine in the present stud ies in addition use tetraiodofluorescein',
#    0.0)),
#  (950,
#   ('figo stage grade ca 125 concentration in tumor interstitial fluid', 0.0)),
#  (951, ('film 0 02 and 0 2 with totally impermeable film', 0.0)),
#  (952, ('for 10 minutes to obtain triton x 100 resistant pellets', 0.0)),
#  (953,
#   ('function dysfunction telomere can be marked by telomere induced foci',
#    0.0)),
#  (954,
#   ('glomerulosclerosis and 16 week average systolic bp b tubulointerstitial fibrosis',
#    0.0)),
#  (955, ('hebei province china and 0 04 mm totally impermeable film', 0.0)),
#  (956,
#   ('here we investigated the role of mdm2 in tubulointerstitial fibrosis',
#    0.0)),
#  (957,
#   ('however the main pathology associated with aki is tubulointerstitial fibrosis',
#    0.0)),
#  (958,
#   ('hypothesize that the presence of transient occult intraoperative interface fluid',
#    0.0)),
#  (959,
#   ('i to read through a promoter bound transcription initiation factor', 0.0)),
#  (960,
#   ('information and national registries wherever possible the thalassaemia international federation',
#    0.0)),
#  (961,
#   ('interstitial fluid phase of solid tumor the tumor interstitial fluid',
#    0.0)),
#  (962,
#   ('is characterized by the presence of telomere dysfunction induced foci',
#    0.0)),
#  (963,
#   ('is essential to design effects treatments the tumor interstitial fluid',
#    0.0)),
#  (964,
#   ('is not known whether t cruzi or trypanosomal immunosuppressive factor',
#    0.0)),
#  (965,
#   ('kidney disease but also a crucial contributor to tubulointerstitial inflammation',
#    0.0)),
#  (966,
#   ('kidney in obstructed kidney tissue among rat with tubulointerstitial fibrosis',
#    0.0)),
#  (967,
#   ('limited therapeutic options chronic renal disease ckd and tubulonterstitial fibrosis',
#    0.0)),
#  (968,
#   ('measurements of serum luteinizing hormone serum testosterone testicular interstitial fluid',
#    0.0)),
#  (969,
#   ('mechanism of chronic csa nephrotoxicity characterized by progression tubulointerstitial fibrosis',
#    0.0)),
#  (970,
#   ('microbiota and plasma metabolites and their relationship with tubulointerstitial fibrosis',
#    0.0)),
#  (971,
#   ('mmp9 timp2 and vimentin as important features of tubulointerstitial fibrosis',
#    0.0)),
#  (972,
#   ('model of slowly development tgf beta 1 driven tubulointerstitial fibrosis',
#    0.0)),
#  (973,
#   ('molecules comprising the extracellular matrix ecm the tumor interstitial fluid',
#    0.0)),
#  (974,
#   ('monocyte chemotactic protein 1 mcp 1 in renal tubulointerstitial fibrosis',
#    0.0)),
#  (975,
#   ('novel and promising therapeutic target for dn renal tubulointerstitial fibrosis',
#    0.0)),
#  (976,
#   ('nuclear receptor activation including the src 1 transcription intermediary factor',
#    0.0)),
#  (977,
#   ('observations nci h522 cells showed enlarged telomere dysfunction induced foci',
#    0.0)),
#  (978,
#   ('of 2 p toluidinylnaphthalene 6 sulfonate tns and of tetraiodofluorescein',
#    0.0)),
#  (979, ('of ca 125 vegf and osteopontin in tumor interstitial fluid', 0.0)),
#  (980,
#   ('of the safe and successful use of transoral incisionless fundoplication',
#    0.0)),
#  (981,
#   ('of the tumor microenvironment tme is the tumor interstitial fluid', 0.0)),
#  (982,
#   ('of tnf alpha this activation termed tnf alpha inhibiting factor', 0.0)),
#  (983,
#   ('on csa induced renal injury were evaluated with tubulointerstitial fibrosis',
#    0.0)),
#  (984, ('other unknown protein in the triton x 100 insoluble fraction', 0.0)),
#  (985,
#   ('outcomes and the occurrence of complications 4 transoral incisionless fundoplication',
#    0.0)),
#  (986, ('p38 activation required the p38 mapkk sek 1 right panels', 0.0)),
#  (987,
#   ('panels are magnified views of enlarged telomere dysfunction induced foci',
#    0.0)),
#  (988,
#   ('pathway in the induced nephrotoxicity and renal tubular interstitial fibrosis',
#    0.0)),
#  (989,
#   ('periodic acid schiff pas and masson s trichrome tubulointerstitial fibrosis',
#    0.0)),
#  (990,
#   ('phenotypes were assessed qualitatively by imaging telomere deprotection induced foci',
#    0.0)),
#  (991,
#   ('production extract of trametes robiniophila murr huaier with radix isatidis',
#    0.0)),
#  (992,
#   ('production of fibrogenic cytokines kovacs the pathogenesis of tubulointerstitial fibrosis',
#    0.0)),
#  (993,
#   ('progression of dn however the pathogenic role of tubulointerstitial fibrosis',
#    0.0)),
#  (994,
#   ('proposed precursor to + pisatin instead 2 7 4 trihydroxyisoflavanone',
#    0.0)),
#  (995,
#   ('protein spontaneously released by this parasite termed trypanosomal immunosuppressive factor',
#    0.0)),
#  (996,
#   ('rat through measurements of serum testosterone levels testicular interstitial fluid',
#    0.0)),
#  (997,
#   ('recent years it has been reported that tubule interstitial fibrosis',
#    0.0)),
#  (998, ('referred to as t elomere dysfunction i nduced f oci', 0.0)),
#  (999,
#   ('reliability of the scale was assessed by test information function', 0.0)),
#  ...]

# %%
longforms0.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [7, 8, 15, 16, 32, 34, 35, 36])

# %%
longforms0.append(('thalassaemia international federation', 3.6))

# %%
longforms = longforms0

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('tubulointerstitial fibrosis',
#  'transoral incisionless fundoplication',
#  'telomere dysfunction induced foci',
#  'tumor interstitial fluid',
#  'testicular interstitial fluid',
#  'thalassaemia international federation',
#  'transcription initiation factor',
#  'trypanosomal immunosuppressive factor',
#  'tetraiodofluorescein',
#  'totally impermeable film',
#  'test information function',
#  'tissue interstitial fluid',
#  'tubular interstitial fibrosis',
#  'tubulo interstitial fibrosis')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {}

# %%
names
# Out:
# {}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'telomere dysfunction induced foci': 'ungrounded',
#   'test information function': 'ungrounded',
#   'testicular interstitial fluid': 'ungrounded',
#   'tetraiodofluorescein': 'CHEBI:CHEBI:61000',
#   'thalassaemia international federation': 'ungrounded',
#   'tissue interstitial fluid': 'ungrounded',
#   'totally impermeable film': 'ungrounded',
#   'transcription initiation factor': 'MESH:D035165',
#   'transoral incisionless fundoplication': 'MESH:D018662',
#   'trypanosomal immunosuppressive factor': 'ungrounded',
#   'tubular interstitial fibrosis': 'MESH:D009395',
#   'tubulo interstitial fibrosis': 'MESH:D009395',
#   'tubulointerstitial fibrosis': 'MESH:D009395',
#   'tumor interstitial fluid': 'ungrounded'},
#  {'CHEBI:CHEBI:61000': 'erythrosin B',
#   'MESH:D035165': 'Transcription Factors, General',
#   'MESH:D018662': 'Fundoplication',
#   'MESH:D009395': 'Nephritis, Interstitial'},
#  ['CHEBI:CHEBI:61000', 'MESH:D009395', 'MESH:D018662', 'MESH:D035165'])

# %%
grounding_map, names, pos_labels = ({'telomere dysfunction induced foci': 'ungrounded',
  'test information function': 'ungrounded',
  'testicular interstitial fluid': 'ungrounded',
  'tetraiodofluorescein': 'CHEBI:CHEBI:61000',
  'thalassaemia international federation': 'ungrounded',
  'tissue interstitial fluid': 'ungrounded',
  'totally impermeable film': 'ungrounded',
  'transcription initiation factor': 'MESH:D035165',
  'transoral incisionless fundoplication': 'MESH:D018662',
  'trypanosomal immunosuppressive factor': 'ungrounded',
  'tubular interstitial fibrosis': 'MESH:D009395',
  'tubulo interstitial fibrosis': 'MESH:D009395',
  'tubulointerstitial fibrosis': 'MESH:D009395',
  'tumor interstitial fluid': 'ungrounded'},
 {'CHEBI:CHEBI:61000': 'erythrosin B',
  'MESH:D035165': 'Transcription Factors, General',
  'MESH:D018662': 'Fundoplication',
  'MESH:D009395': 'Nephritis, Interstitial'},
 ['CHEBI:CHEBI:61000', 'MESH:D009395', 'MESH:D018662', 'MESH:D035165'])

# %%
grounding_dict = {'TIF': grounding_map}

# %%
classifier = AdeftClassifier('TIF', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 12:58:56] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-27 12:59:37] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9833333333333332 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'ungrounded': 29,
#   'MESH:D009395': 36,
#   'MESH:D018662': 7,
#   'MESH:D035165': 4,
#   'CHEBI:CHEBI:61000': 2},
#  'f1': {'mean': 0.9833333333333332, 'std': 0.03333333333333335},
#  'precision': {'mean': 0.9833333333333332, 'std': 0.03333333333333335},
#  'recall': {'mean': 0.9833333333333332, 'std': 0.03333333333333335}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'MESH:D0093']

# %%
a[4]
# Out:
# 'A feature of the cascade regulation of herpes simplex virus 1 gene expression in productive infection is that the first genes to be expressed, the alpha genes, are transactivated by a structural component of the virion designated as the alpha transinducing factor (alpha TIF). In this study, we have tested the hypothesis that latent infection of sensory neurons results from the failure of alpha TIF, a tegument protein, to be transported from the nerve endings to the nucleus of the sensory neuron. Two viruses were constructed. The first recombinant virus (R6003) contained a second copy of the alpha TIF gene placed under the control of a metallothionein promoter. The second recombinant virus (R6004) is identical to R6003 except for the presence of a stop codon inserted at amino acid 70 of the second alpha TIF gene. The metallothionein promoter inserted into the viral genome was shown to be expressed, and alpha TIF mRNA was detected by in situ hybridization of sections of trigeminal ganglia of mice infected with R6003, both untreated and those given cadmium injections. In all experiments, there were no significant differences in the recovery of latent virus from mice infected with R6003 or R6004, whether injected with cadmium or not. Cadmium administration at the time of infection and at intervals thereafter did not preclude establishment of latency. In another series of experiments, transgenic mice expressing the metallothionein-driven alpha TIF did not differ from nontransgenic siblings with respect to the incidence of latent virus in trigeminal ganglia. We conclude that the absence of alpha TIF cannot alone account for the establishment of latency.\n'

# %%
disamb.dump('TIF', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('domain', 0.08492635500235372),
#  ('region', 0.0841391109644385),
#  ('nox', 0.08167855496471926),
#  ('bfgf', 0.07852529781557573),
#  ('glioma', 0.0754901259891954),
#  ('syk', 0.07470961043787495),
#  ('wasp', 0.0742950745186167),
#  ('oscc', 0.07402266033376588),
#  ('protein', 0.07386030185484761),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
