# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['PRK']
genes = ['PLK3']
families = {'PKN': ['PKN1', 'PKN2', 'PKN3']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['PRK'].top()

# %%
top
# Out:
# [('photorefractive keratectomy', 94.16),
#  ('phosphoribulokinase', 59.970588235294116),
#  ('and phosphoribulokinase', 15.52),
#  ('after photorefractive keratectomy', 14.625),
#  ('glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   11.307692307692307),
#  ('of photorefractive keratectomy', 7.777777777777778),
#  ('of phosphoribulokinase', 6.75),
#  ('pranlukast', 6.5),
#  ('kinase', 4.75),
#  ('cycle enzymes phosphoribulokinase', 4.25),
#  ('laser in situ keratomileusis lasik and photorefractive keratectomy', 4.0),
#  ('wavefront guided photorefractive keratectomy', 3.6),
#  ('and photorefractive keratectomy', 3.333333333333333),
#  ('with phosphoribulokinase', 3.0),
#  ('rubisco and phosphoribulokinase', 3.0),
#  ('excimer laser photorefractive keratectomy', 3.0),
#  ('treated with photorefractive keratectomy', 3.0),
#  ('calvin cycle enzymes phosphoribulokinase', 2.8),
#  ('following photorefractive keratectomy', 2.0),
#  ('in a photorefractive keratectomy', 2.0),
#  ('ribulose 5 phosphate kinase', 2.0),
#  ('protein kinase c related kinase', 2.0),
#  ('with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   2.0),
#  ('ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   2.0),
#  ('ation of a complex between glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   2),
#  ('to evaluate the long term outcomes of excimer laser myopic photorefractive keratectomy',
#   2),
#  ('enzymes phosphoribulokinase', 1.7777777777777777),
#  ('lasik and photorefractive keratectomy', 1.7142857142857144),
#  ('in situ keratomileusis lasik and photorefractive keratectomy',
#   1.666666666666667),
#  ('with photorefractive keratectomy', 1.6),
#  ('related kinase', 1.5),
#  ('bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase', 1.5),
#  ('cycle phosphoribulokinase', 1.3333333333333333),
#  ('diopter photorefractive keratectomy', 1.3333333333333333),
#  ('myopic photorefractive keratectomy', 1.3333333333333333),
#  ('lasik or photorefractive keratectomy', 1.3333333333333333),
#  ('such as photorefractive keratectomy', 1.3333333333333333),
#  ('the calvin cycle enzymes phosphoribulokinase', 1.3333333333333333),
#  ('enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1.3333333333333333),
#  ('prk', 1.0),
#  ('compounds pranlukast', 1.0),
#  ('9d photorefractive keratectomy', 1.0),
#  ('a heterologous phosphoribulokinase', 1.0),
#  ('calvin cycle phosphoribulokinase', 1.0),
#  ('post photorefractive keratectomy', 1.0),
#  ('rhodobacter sphaeroides phosphoribulokinase', 1.0),
#  ('transepithelial photorefractive keratectomy', 1.0),
#  ('underwent photorefractive keratectomy', 1.0),
#  ('9 diopter photorefractive keratectomy', 1.0),
#  ('haze after photorefractive keratectomy', 1.0),
#  ('healing after photorefractive keratectomy', 1.0),
#  ('the activity of phosphoribulokinase', 1.0),
#  ('to report photorefractive keratectomy', 1),
#  ('4 weeks after photorefractive keratectomy', 1.0),
#  ('chemical structures of a pranlukast', 1.0),
#  ('in the rhodobacter sphaeroides phosphoribulokinase', 1),
#  ('surgery such as photorefractive keratectomy', 1.0),
#  ('− 9 0d photorefractive keratectomy', 1.0),
#  ('corneal barrier functional following photorefractive keratectomy', 1),
#  ('the calvin benson cycle enzymes phosphoribulokinase', 1.0),
#  ('the n terminal region of phosphoribulokinase', 1),
#  ('a calvin cycle multiprotein complex included phosphoribulokinase', 1),
#  ('in situ keratomileusis lasik or photorefractive keratectomy', 1.0),
#  ('months after 9 diopter d photorefractive keratectomy', 1.0),
#  ('the efficacy and safety of photorefractive keratectomy', 1.0),
#  ('to compare the outcomes of photorefractive keratectomy', 1),
#  ('to report the results of photorefractive keratectomy', 1),
#  ('to report the using of photorefractive keratectomy', 1),
#  ('cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1.0),
#  ('functional expression of the calvin cycle enzymes phosphoribulokinase',
#   1.0),
#  ('between wavefront guided and non wavefront guided photorefractive keratectomy',
#   1.0),
#  ('complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1.0),
#  ('interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1.0),
#  ('to compare the efficacy and safety of photorefractive keratectomy', 1),
#  ('to evaluate the efficacy and safety of photorefractive keratectomy', 1),
#  ('assisted subepithelial keratectomy lasek and trans or subepithelial photorefractive keratectomy',
#   1),
#  ('calvin cycle enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1.0),
#  ('corneal morphology after laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#   1),
#  ('corneal neovascularization 42 in clinical practice excimer laser photorefractive keratectomy',
#   1),
#  ('ed qualitatively and quantitatively after traditional epithelial scrape photorefractive keratectomy',
#   1),
#  ('epithelium occur following refractive surgical procedures such as photorefractive keratectomy',
#   1),
#  ('g kg xylazine hydrochloride troy laboratories smithfield australia photorefractive keratectomy',
#   1),
#  ('l photorefractive keratectomy transprk compare with alcohol assisted photorefractive keratectomy',
#   1),
#  ('lcohol assisted laser epithelial keratomileusis lasek versus standard photorefractive keratectomy',
#   1),
#  ('njured epithelium occur following refractive surgical procedures like photorefractive keratectomy',
#   1),
#  ('opacity related myofibroblasts after opacity generating high correction photorefractive keratectomy',
#   1),
#  ('the perceived and report pain of patients receiving photorefractive keratectomy',
#   1),
#  ('to determinations whether visx s4 visx inc custom photorefractive keratectomy',
#   1),
#  ('aberrometric outcomes between wavefront guided and non wavefront guided photorefractive keratectomy',
#   1),
#  ('ale process for bioethanol product are characteristically co 2 saturated phosphoribulokinase',
#   1),
#  ('clear encoding chloroplast protein which in chloroplast is oligomerized with phosphoribulokinase',
#   1),
#  ('compare with control after epithelial scrape epithelial scrape and photorefractive keratectomy',
#   1),
#  ('e types of surface ablation phototherapeutic keratectomy ptk myopic photorefractive keratectomy',
#   1),
#  ('enzymes nad p dependent glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('g76560 cp12 3 at3g18780 actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060',
#   1),
#  ('hy keratorefractive surgery laser in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('light dark modulation of the higher plant calvin cycle enzymes phosphoribulokinase',
#   1),
#  ('nvestigating the proliferation and apoptosis of corneal cells following photorefractive keratectomy',
#   1),
#  ('o step reaction using ribulose bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   1),
#  ('pi 3 kinase signaling regulate the protein kinase c related protein', 1),
#  ('purpose to evaluate the safety efficacy and predictability of photorefractive keratectomy',
#   1),
#  ('r superficial keratectomy techniques should be considered for example photorefractive keratectomy',
#   1),
#  ('risk factor contributing to steroid induced ocular hypertension after photorefractive keratectomy',
#   1),
#  ('rotein that interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('se gapdh nadph ferredoxin nadp reductase fnr ascorbate peroxidase apx phosphoribulokinase',
#   1),
#  ('sphosphate carboxylase oxygenase rubisco responsible for co 2 fixation and phosphoribulokinase',
#   1),
#  ('unique enzymes ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   1),
#  ('5 kda cp12 interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('5 povidone iodine betadine alcon laboratories fort worth tx usa photorefractive keratectomy',
#   1),
#  ('ability in hyperopic astigmatic laser in situ keratomileusis lasik or photorefractive keratectomy',
#   1),
#  ('canning excimer laser van gelder 12 compare patients treated with photorefractive keratectomy',
#   1),
#  ('cceptor for nadh reoxidation functional expression of the calvin cycle enzymes phosphoribulokinase',
#   1),
#  ('ccurred 6 years previous following combined radial keratotomy rk and photorefractive keratectomy',
#   1),
#  ('corneas that underwent laser assisted in situ keratomileusis lasik or photorefractive keratectomy',
#   1),
#  ('dehydrogenase mdh in the presence of the proper thioredoxin deactivation of phosphoribulokinase',
#   1),
#  ('e fruste keratoconus 10 laser in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('er aberrations hoas between wavefront guided and non wavefront guided photorefractive keratectomy',
#   1),
#  ('eraldehyde 3 phosphate dehydrogenase seduheptulose 1 7 bisphosphatase ribulose 5 phosphate kinase',
#   1),
#  ('have homologs of ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   1),
#  ('he activity of glyceraldehyde 3 phosphate dehydrogenase gapdh embedded in the phosphoribulokinase',
#   1),
#  ('he contributing of corneal myofibroblasts to optical changes induced by photorefractive keratectomy',
#   1),
#  ('ical nodular subepithelial corneal scar that can occur after hyperopic photorefractive keratectomy',
#   1),
#  ('ing a ternary complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('ion was accomplished by co binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#   1),
#  ('n applanation tonometer gat noncontact tonometer and tono pen after photorefractive keratectomy',
#   1),
#  ('nflammation in keratocyte death which may influence corneal haze after photorefractive keratectomy',
#   1),
#  ('ntions are required to target mycobacterium tuberculosis mtb pathogenesis we report pranlukast',
#   1),
#  ('orms a stable complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('orneal topography early in the postoperative course after excimer laser photorefractive keratectomy',
#   1),
#  ('rredoxin thioredoxin reductase trx f activity the calvin benson cycle enzymes phosphoribulokinase',
#   1),
#  ('s the calvin cycle enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('schürmann and buchanan 2008 buchanan et al 2012 these enzymes were phosphoribulokinase',
#   1),
#  ('sminogen activity upa on the development of subepithelial haze after photorefractive keratectomy',
#   1),
#  ('ted by incorporating two sequential enzymes in the cyanobacterial calvin cycle phosphoribulokinase',
#   1),
#  ('thiel behnke corneal dystrophy using ptk following by wavefront guided photorefractive keratectomy',
#   1),
#  ('to assess the role of topical steroid following excimer laser photorefractive keratectomy',
#   1),
#  ('to compare 3 years changes in corneal sublayer thickness after photorefractive keratectomy',
#   1),
#  ('two enzymes of the cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('uctuations and foreign body sensation in patients undergoing lasik and photorefractive keratectomy',
#   1),
#  ('with at least two enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('with the cc enzymes nadph glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('00 schürmann and buchanan 2008 michelet et al 2013 the activity of phosphoribulokinase',
#   1),
#  ('ac inhibitor in the treatment of laser induced corneal haze following photorefractive keratectomy',
#   1),
#  ('and sorafenib srb from the library of 1 556 fda approved drugs pranlukast',
#   1),
#  ('anges in corneal power and aberrations in myopic patients randomized to photorefractive keratectomy',
#   1),
#  ('corneal fibrosis was induced in rabbit corneas using high diopter 9d photorefractive keratectomy',
#   1),
#  ('d laser in situ keratomileusis lasik and eye have wavefront guided photorefractive keratectomy',
#   1),
#  ('dentified by 2 de immunoblots from semi continuous culture samples table 1 phosphoribulokinase',
#   1),
#  ('e upregulation of calvin benson cycle enzymes e g rubisco rubisco activase phosphoribulokinase',
#   1),
#  ('eal haze formation and transforming growth factor beta tgf beta after photorefractive keratectomy',
#   1),
#  ('ent of myopic astigmatic with laser in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('eport the outcomes of laser assisted in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('herpes simplex virus serotype i hsv 1 and maintained in isolated photorefractive keratectomy',
#   1),
#  ('ields of ethanol and the undesired by product glycerol the spinacia oleracea phosphoribulokinase',
#   1),
#  ('in a previous study our group functional expression the calvin cycle enzymes phosphoribulokinase',
#   1),
#  ('issociation of the prk cp12 gapdh complex approximately 520 kda consisting of phosphoribulokinase',
#   1),
#  ('itive chloroplast protein that interacts with two enzymes of the calvin cycle phosphoribulokinase',
#   1),
#  ('last growth factor bfgf eye drops on corneal epithelial healing after photorefractive keratectomy',
#   1),
#  ('long term effects and safety of refractive surgery with lasik or photorefractive keratectomy',
#   1),
#  ('mented with co 2 this observation confirmed that expression of a heterologous phosphoribulokinase',
#   1),
#  ('mes of the cycle ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   1),
#  ('nic anhydrase ca chloroplast 23 kda polypeptide of photosystem ii psbp and phosphoribulokinase',
#   1),
#  ('nt in patients screened for corneal refractive surgery and treated with photorefractive keratectomy',
#   1),
#  ('of the calvin cycle enzymes ribulose 1 5 bisphosphate carboxylase rubisco and phosphoribulokinase',
#   1),
#  ('omas lungs and tissue associated histopathology spleen and liver we have identified pranlukast',
#   1),
#  ('on of enzymes frequencies showed that the stromal reaction catalyzed by atpase phosphoribulokinase',
#   1),
#  ('on the number of keratocyte and the proliferation of fibroblasts after photorefractive keratectomy',
#   1),
#  ('perative and the 12 months postoperative data since the introduction of photorefractive keratectomy',
#   1),
#  ('pression was compare in nonoperated control eye and eye treated with photorefractive keratectomy',
#   1),
#  ('r and corneal aspheric q in patients treated with aspheric profile photorefractive keratectomy',
#   1),
#  ('rom a large animal domestic cat following corneal wound created with photorefractive keratectomy',
#   1),
#  ('se 1 6 bis phosphatase fbpase sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase',
#   1),
#  ('some report have found that laser in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('t enzymes of the cb cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   1),
#  ('three different re treatment options were analyzed 3d re smile 3d photorefractive keratectomy',
#   1),
#  ('tic of the photosynthetic calvin benson cycle but apparently lack another one phosphoribulokinase',
#   1),
#  ('to compare the wound healing process in the rabbit corneas after photorefractive keratectomy',
#   1),
#  ('were detected by the conversion of phenylalanine into tyrosine the activity of phosphoribulokinase',
#   1),
#  ('were screened for study eligibility and patients who were treated with photorefractive keratectomy',
#   1),
#  ('xs in chloroplast however this postulate has not been rigorously test with phosphoribulokinase',
#   1),
#  ('8 9 many study 10 11 have report that performing excimer laser surface ablation',
#   1),
#  ('a 64 beaver blade bd biosciences franklin lakes nj and 9 diopter photorefractive keratectomy',
#   1),
#  ('acteria fix carbon dioxide to organic carbon with the calvin benson cb cycle phosphoribulokinase',
#   1),
#  ('atient with low risk of side effects the corneal wound results after photorefractive keratectomy',
#   1),
#  ('cin c mmc application on the corneal stroma of rabbit that underwent photorefractive keratectomy',
#   1),
#  ('d four genes encoding sucrose synthase 4 sus4 ras related protein ric2 rap phosphoribulokinase',
#   1),
#  ('e incidence of postoperative pain is a common and major challenge after photorefractive keratectomy',
#   1),
#  ('e with a blunt oscillating blade 3 in the late 1990s transepithelial photorefractive keratectomy',
#   1),
#  ('f the epithelial basement membrane ebm in rabbit corneas that had 9d photorefractive keratectomy',
#   1),
#  ('fety of aav5 smad7 target genes therapy in an established high diopter photorefractive keratectomy',
#   1),
#  ('ik the eye with the donut shaped flap was treated with transepithelial photorefractive keratectomy',
#   1),
#  ('iversity of algae that are poorly study the diversity of redox regulate of phosphoribulokinase',
#   1),
#  ('l 0 1 after prk topical corticosteroid drops are routinely using after photorefractive keratectomy',
#   1),
#  ('laser in situ keratomileusis lasik has led to a renewed interest in photorefractive keratectomy',
#   1),
#  ('le extraction in addition to the treatment group stated above 1 00d photorefractive keratectomy',
#   1),
#  ('mary culture of human corneal fibroblasts phcsfs and in vivo in a photorefractive keratectomy',
#   1),
#  ('mulated with tgfβ in vitro and abrogated clinical haze formation in a photorefractive keratectomy',
#   1),
#  ('n of the product of interest functional expression of the calvin cycle enzymes phosphoribulokinase',
#   1),
#  ('neal surface after ptk this study report the using of wavefront guided photorefractive keratectomy',
#   1),
#  ('on the safety and efficacy of laser in situ keratomileusis lasik and photorefractive keratectomy',
#   1),
#  ('ostoperatively except cycloplegic refractive fu included examinations at 1 days lasik to 5 days',
#   1),
#  ('perimental replicates n = 3 and two technical duplicates chemical structures of a pranlukast',
#   1),
#  ('pm there were no significant different in the activity of the other enzymes phosphoribulokinase',
#   1),
#  ('stricted to the residual stromal bed postoperative refractive changes correlate with changes in st',
#   1),
#  ('study the effects of endothelin 1 et1 on corneal wound healing after photorefractive keratectomy',
#   1),
#  ('t protein cp12 forms a multienzyme complex with the calvin benson cycle enzymes phosphoribulokinase',
#   1),
#  ('the two e coli chaperones groel and groes cells extraction for analysis of phosphoribulokinase',
#   1),
#  ('to reflect the improvements in surface ablation from the early days of photorefractive keratectomy',
#   1),
#  ('two enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh ec 1 2 1 13 and phosphoribulokinase',
#   1),
#  ('v5 smad7 delivered to the corneal stroma can inhibit corneal haze post photorefractive keratectomy',
#   1),
#  ('y ophthalmology also it is one of the most important complications of photorefractive keratectomy',
#   1),
#  ('yopia quantification of smooth muscle actin sma + cells 4 weeks after photorefractive keratectomy',
#   1),
#  ('activity protein kinase mapk b src family kinase sfk c protein kinase c related kinase',
#   1),
#  ('an inhibitor binding site the results lead to the identification of two lead compounds pranlukast',
#   1),
#  ('coding cp12 interacts protein the calvin cycle genes encoding gapdh gapa and gapb and prk',
#   1),
#  ('cp12 arabidopsis genes together with the genes encoding plastid gapdh gapa 1 and gapb prk',
#   1),
#  ('ed as a naive control haze in rabbit corneas was produced by performing photorefractive keratectomy',
#   1),
#  ('er than 12 years have refractive errors 1 laser eye surgery such as photorefractive keratectomy',
#   1),
#  ('es from 7 post laser in situ keratomileusis lasik patients and 1 post photorefractive keratectomy',
#   1),
#  ('ile we know much about the impact of anterior corneal surgery such as photorefractive keratectomy',
#   1),
#  ('l a c protein atp synthase a ribulose phosphate 3 epimerase rpe and a phosphoribulokinase',
#   1),
#  ('n well described that trx f and m reductively activity the cb cycle enzymes phosphoribulokinase',
#   1),
#  ('otein cp12 has been shown to regulate the activity of two calvin cycle enzymes phosphoribulokinase',
#   1),
#  ('rneas at two months three months and four months after 9 diopter d photorefractive keratectomy',
#   1),
#  ('se increased 7 15 and 5 8 fold respectively whereas rubisco small chain 1a phosphoribulokinase',
#   1),
#  ('th rubp to yield 3 phosphoglycerate 3 pga from which rubp is regenerated 3 phosphoribulokinase',
#   1),
#  ('the aim of this study was to compare the results of excimer laser photorefractive keratectomy',
#   1),
#  ('vdurd a high selective and potent anti herpes agent is phosphorylated by primary rabbit kidney',
#   1),
#  ('xperiments are shown fixation of co 2 via the calvin cycle enzymes rubisco and phosphoribulokinase',
#   1),
#  ('eriments are shown in appendix fig s8a and b these results demonstrate the potency of pranlukast',
#   1),
#  ('ffering only in a few step from the cbb cycle also employs rubisco along with phosphoribulokinase',
#   1),
#  ('he mt argj activity in vitro appendix table s4 a b chemical structures of a pranlukast',
#   1),
#  ('isolated from higher plant it forms part of a core complex of two dimers of phosphoribulokinase',
#   1),
#  ('lized in the chloroplast acting as a linker in the core complex of cbc protein phosphoribulokinase',
#   1),
#  ('pα and tpβ forms functional signaling complex with member of the protein kinase c related kinase',
#   1),
#  ('s possess phosphorylated forms of tpa insensitive atypical isotypes as well as a pkc related kinase',
#   1),
#  ('t argj activity the activity based screened led to the discovery of two potent compounds pranlukast',
#   1),
#  ('tatistics was calculated using one side anova following by tukey s hsd ribulose 5 phosphate kinase',
#   1),
#  ('troma human corneas with severe late haze at one and a half years after photorefractive keratectomy',
#   1),
#  ('ure of the ebm in rabbit corneas with and without corneal fibrosis in a photorefractive keratectomy',
#   1),
#  ('ury was performing in one corneas of each rabbit by applying a 9 diopter photorefractive keratectomy',
#   1),
#  ('ves different from cp12 and plant cbsx it does not forms a ternary complex with phosphoribulokinase',
#   1),
#  ('as that are unwounded and at 2 weeks and 1 months after 9 diopter d photorefractive keratectomy',
#   1),
#  ('cysteine rich protein to the s locus receptor kinase srk a member of the plant receptor kinase',
#   1),
#  ('h isoforms of the two kinase ribosomal s6 protein kinase rsk and protein kinase c related kinase',
#   1),
#  ('ndations confocal biomicroscopy images from wk 1 to 4 in a d − 9 0d photorefractive keratectomy',
#   1),
#  ('t vorinostat 25 μm collected a b 6 hours or c d 4 weeks after photorefractive keratectomy',
#   1),
#  ('viously 6 to test this rabbit corneas underwent − 9 0 diopter − 9 0d photorefractive keratectomy',
#   1),
#  ('6 + 1 70 d and a mean hyperopic cylinder of 2 20 + 0 80 d underwent photorefractive keratectomy',
#   1),
#  ('e time point 10 s data are mean ± sd from n ≥ 5 determinations b ribulose 5 phosphate kinase',
#   1),
#  ('ablation', 0.0),
#  ('at1g32060', 0.0),
#  ('days', 0.0),
#  ('keratectomy', 0.0),
#  ('kidney', 0.0),
#  ('protein', 0.0),
#  ('st', 0.0),
#  ('1 phosphoribulokinase', 0.0),
#  ('1a phosphoribulokinase', 0.0),
#  ('3 phosphoribulokinase', 0.0),
#  ('5 days', 0.0),
#  ('a phosphoribulokinase', 0.0),
#  ('a pranlukast', 0.0),
#  ('activase phosphoribulokinase', 0.0),
#  ('and at1g32060', 0.0),
#  ('and prk', 0.0),
#  ('apx phosphoribulokinase', 0.0),
#  ('atpase phosphoribulokinase', 0.0),
#  ('drugs pranlukast', 0.0),
#  ('gapb prk', 0.0),
#  ('heterologous phosphoribulokinase', 0.0),
#  ('identified pranlukast', 0.0),
#  ('in st', 0.0),
#  ('included phosphoribulokinase', 0.0),
#  ('of pranlukast', 0.0),
#  ('oleracea phosphoribulokinase', 0.0),
#  ('one phosphoribulokinase', 0.0),
#  ('phosphate kinase', 0.0),
#  ('protein phosphoribulokinase', 0.0),
#  ('rabbit kidney', 0.0),
#  ('rap phosphoribulokinase', 0.0),
#  ('receptor kinase', 0.0),
#  ('related protein', 0.0),
#  ('report pranlukast', 0.0),
#  ('saturated phosphoribulokinase', 0.0),
#  ('sphaeroides phosphoribulokinase', 0.0),
#  ('surface ablation', 0.0),
#  ('the phosphoribulokinase', 0.0),
#  ('were phosphoribulokinase', 0.0),
#  ('00d photorefractive keratectomy', 0.0),
#  ('0d photorefractive keratectomy', 0.0),
#  ('13 and phosphoribulokinase', 0.0),
#  ('2 saturated phosphoribulokinase', 0.0),
#  ('3d photorefractive keratectomy', 0.0),
#  ('5 phosphate kinase', 0.0),
#  ('a photorefractive keratectomy', 0.0),
#  ('activity of phosphoribulokinase', 0.0),
#  ('along with phosphoribulokinase', 0.0),
#  ('analysis of phosphoribulokinase', 0.0),
#  ('and a phosphoribulokinase', 0.0),
#  ('and gapb prk', 0.0),
#  ('another one phosphoribulokinase', 0.0),
#  ('approved drugs pranlukast', 0.0),
#  ('as photorefractive keratectomy', 0.0),
#  ('assisted photorefractive keratectomy', 0.0),
#  ('australia photorefractive keratectomy', 0.0),
#  ('by atpase phosphoribulokinase', 0.0),
#  ('by photorefractive keratectomy', 0.0),
#  ('c related kinase', 0.0),
#  ('c related protein', 0.0),
#  ('cb cycle phosphoribulokinase', 0.0),
#  ('cbc protein phosphoribulokinase', 0.0),
#  ('chain 1a phosphoribulokinase', 0.0),
#  ('changes in st', 0.0),
#  ('complex included phosphoribulokinase', 0.0),
#  ('complex with phosphoribulokinase', 0.0),
#  ('consisting of phosphoribulokinase', 0.0),
#  ('correction photorefractive keratectomy', 0.0),
#  ('custom photorefractive keratectomy', 0.0),
#  ('cyclophilin and at1g32060', 0.0),
#  ('d photorefractive keratectomy', 0.0),
#  ('deactivation of phosphoribulokinase', 0.0),
#  ('dimers of phosphoribulokinase', 0.0),
#  ('enzymes were phosphoribulokinase', 0.0),
#  ('example photorefractive keratectomy', 0.0),
#  ('fixation and phosphoribulokinase', 0.0),
#  ('gapb and prk', 0.0),
#  ('gapdh and phosphoribulokinase', 0.0),
#  ('guided photorefractive keratectomy', 0.0),
#  ('have identified pranlukast', 0.0),
#  ('hyperopic photorefractive keratectomy', 0.0),
#  ('in photorefractive keratectomy', 0.0),
#  ('in the phosphoribulokinase', 0.0),
#  ('isolated photorefractive keratectomy', 0.0),
#  ('laser photorefractive keratectomy', 0.0),
#  ('laser surface ablation', 0.0),
#  ('lead compounds pranlukast', 0.0),
#  ('like photorefractive keratectomy', 0.0),
#  ('of a pranlukast', 0.0),
#  ('oligomerized with phosphoribulokinase', 0.0),
#  ('or photorefractive keratectomy', 0.0),
#  ('other enzymes phosphoribulokinase', 0.0),
#  ('performing photorefractive keratectomy', 0.0),
#  ('peroxidase apx phosphoribulokinase', 0.0),
#  ('pkc related kinase', 0.0),
#  ('plant receptor kinase', 0.0),
#  ('potency of pranlukast', 0.0),
#  ('potent compounds pranlukast', 0.0),
#  ('pri and phosphoribulokinase', 0.0),
#  ('primary rabbit kidney', 0.0),
#  ('profile photorefractive keratectomy', 0.0),
#  ('psbp and phosphoribulokinase', 0.0),
#  ('receiving photorefractive keratectomy', 0.0),
#  ('regenerated 3 phosphoribulokinase', 0.0),
#  ('region of phosphoribulokinase', 0.0),
#  ('regulate of phosphoribulokinase', 0.0),
#  ('report photorefractive keratectomy', 0.0),
#  ('ric2 rap phosphoribulokinase', 0.0),
#  ('rubisco activase phosphoribulokinase', 0.0),
#  ('sbpase and phosphoribulokinase', 0.0),
#  ('scrape photorefractive keratectomy', 0.0),
#  ('spinacia oleracea phosphoribulokinase', 0.0),
#  ('standard photorefractive keratectomy', 0.0),
#  ('subepithelial photorefractive keratectomy', 0.0),
#  ('table 1 phosphoribulokinase', 0.0),
#  ('test with phosphoribulokinase', 0.0),
#  ('to 5 days', 0.0),
#  ('to photorefractive keratectomy', 0.0),
#  ('usa photorefractive keratectomy', 0.0),
#  ('versus photorefractive keratectomy', 0.0),
#  ('we report pranlukast', 0.0),
#  ('1 00d photorefractive keratectomy', 0.0),
#  ('1 13 and phosphoribulokinase', 0.0),
#  ('1 and gapb prk', 0.0),
#  ('1 post photorefractive keratectomy', 0.0),
#  ('1990s transepithelial photorefractive keratectomy', 0.0),
#  ('2 fixation and phosphoribulokinase', 0.0),
#  ('9 0d photorefractive keratectomy', 0.0),
#  ('a pkc related kinase', 0.0),
#  ('after hyperopic photorefractive keratectomy', 0.0),
#  ('alcohol assisted photorefractive keratectomy', 0.0),
#  ('and gapb and prk', 0.0),
#  ('ascorbate peroxidase apx phosphoribulokinase', 0.0),
#  ('aspheric profile photorefractive keratectomy', 0.0),
#  ('at2g29960 cyclophilin and at1g32060', 0.0),
#  ('benson cb cycle phosphoribulokinase', 0.0),
#  ('benson cycle enzymes phosphoribulokinase', 0.0),
#  ('beta after photorefractive keratectomy', 0.0),
#  ('bisphosphatase sbpase and phosphoribulokinase', 0.0),
#  ('by performing photorefractive keratectomy', 0.0),
#  ('by primary rabbit kidney', 0.0),
#  ('carboxylase rubisco and phosphoribulokinase', 0.0),
#  ('catalyzed by atpase phosphoribulokinase', 0.0),
#  ('cb cycle enzymes phosphoribulokinase', 0.0),
#  ('cells following photorefractive keratectomy', 0.0),
#  ('challenge after photorefractive keratectomy', 0.0),
#  ('co 2 saturated phosphoribulokinase', 0.0),
#  ('complications of photorefractive keratectomy', 0.0),
#  ('corneas after photorefractive keratectomy', 0.0),
#  ('created with photorefractive keratectomy', 0.0),
#  ('cyanobacterial calvin cycle phosphoribulokinase', 0.0),
#  ('d underwent photorefractive keratectomy', 0.0),
#  ('days of photorefractive keratectomy', 0.0),
#  ('dehydrogenase gapdh and phosphoribulokinase', 0.0),
#  ('diopter 9d photorefractive keratectomy', 0.0),
#  ('diopter d photorefractive keratectomy', 0.0),
#  ('embedded in the phosphoribulokinase', 0.0),
#  ('enzymes rubisco and phosphoribulokinase', 0.0),
#  ('epithelial scrape photorefractive keratectomy', 0.0),
#  ('excimer laser surface ablation', 0.0),
#  ('fda approved drugs pranlukast', 0.0),
#  ('fibroblasts after photorefractive keratectomy', 0.0),
#  ('for analysis of phosphoribulokinase', 0.0),
#  ('for example photorefractive keratectomy', 0.0),
#  ('functional following photorefractive keratectomy', 0.0),
#  ('had 9d photorefractive keratectomy', 0.0),
#  ('haze following photorefractive keratectomy', 0.0),
#  ('haze post photorefractive keratectomy', 0.0),
#  ('high correction photorefractive keratectomy', 0.0),
#  ('high diopter photorefractive keratectomy', 0.0),
#  ('hypertension after photorefractive keratectomy', 0.0),
#  ('ii psbp and phosphoribulokinase', 0.0),
#  ('in isolated photorefractive keratectomy', 0.0),
#  ('inc custom photorefractive keratectomy', 0.0),
#  ('induced by photorefractive keratectomy', 0.0),
#  ('interest in photorefractive keratectomy', 0.0),
#  ('introduction of photorefractive keratectomy', 0.0),
#  ('is oligomerized with phosphoribulokinase', 0.0),
#  ('is regenerated 3 phosphoribulokinase', 0.0),
#  ('kda consisting of phosphoribulokinase', 0.0),
#  ('kinase c related kinase', 0.0),
#  ('kinase c related protein', 0.0),
#  ('lack another one phosphoribulokinase', 0.0),
#  ('lasek versus photorefractive keratectomy', 0.0),
#  ('laser myopic photorefractive keratectomy', 0.0),
#  ('lasik to 5 days', 0.0),
#  ('multiprotein complex included phosphoribulokinase', 0.0),
#  ('of a heterologous phosphoribulokinase', 0.0),
#  ('of cbc protein phosphoribulokinase', 0.0),
#  ('or subepithelial photorefractive keratectomy', 0.0),
#  ('outcomes of photorefractive keratectomy', 0.0),
#  ('oxygenase rubisco and phosphoribulokinase', 0.0),
#  ('pathogenesis we report pranlukast', 0.0),
#  ('patients receiving photorefractive keratectomy', 0.0),
#  ('pen after photorefractive keratectomy', 0.0),
#  ('phosphoriboseisomerase pri and phosphoribulokinase', 0.0),
#  ('predictability of photorefractive keratectomy', 0.0),
#  ('procedures like photorefractive keratectomy', 0.0),
#  ('protein ric2 rap phosphoribulokinase', 0.0),
#  ('ptk myopic photorefractive keratectomy', 0.0),
#  ('randomized to photorefractive keratectomy', 0.0),
#  ('redox regulate of phosphoribulokinase', 0.0),
#  ('results after photorefractive keratectomy', 0.0),
#  ('results of photorefractive keratectomy', 0.0),
#  ('rigorously test with phosphoribulokinase', 0.0),
#  ('rk and photorefractive keratectomy', 0.0),
#  ('rpe and a phosphoribulokinase', 0.0),
#  ('rubisco along with phosphoribulokinase', 0.0),
#  ('rubisco rubisco activase phosphoribulokinase', 0.0),
#  ('safety of photorefractive keratectomy', 0.0),
#  ('samples table 1 phosphoribulokinase', 0.0),
#  ('scrape and photorefractive keratectomy', 0.0),
#  ('small chain 1a phosphoribulokinase', 0.0),
#  ('smile 3d photorefractive keratectomy', 0.0),
#  ('smithfield australia photorefractive keratectomy', 0.0),
#  ('structures of a pranlukast', 0.0),
#  ('terminal region of phosphoribulokinase', 0.0),
#  ('ternary complex with phosphoribulokinase', 0.0),
#  ('that underwent photorefractive keratectomy', 0.0),
#  ('the calvin cycle phosphoribulokinase', 0.0),
#  ('the other enzymes phosphoribulokinase', 0.0),
#  ('the plant receptor kinase', 0.0),
#  ('the potency of pranlukast', 0.0),
#  ('the rhodobacter sphaeroides phosphoribulokinase', 0.0),
#  ('the spinacia oleracea phosphoribulokinase', 0.0),
#  ('these enzymes were phosphoribulokinase', 0.0),
#  ('thickness after photorefractive keratectomy', 0.0),
#  ('thioredoxin deactivation of phosphoribulokinase', 0.0),
#  ('two dimers of phosphoribulokinase', 0.0),
#  ('two lead compounds pranlukast', 0.0),
#  ('two potent compounds pranlukast', 0.0),
#  ('tx usa photorefractive keratectomy', 0.0),
#  ('using after photorefractive keratectomy', 0.0),
#  ('using of photorefractive keratectomy', 0.0),
#  ('versus standard photorefractive keratectomy', 0.0),
#  ('we have identified pranlukast', 0.0),
#  ('weeks after photorefractive keratectomy', 0.0),
#  ('with changes in st', 0.0),
#  ('with transepithelial photorefractive keratectomy', 0.0),
#  ('years after photorefractive keratectomy', 0.0),
#  ('2 1 13 and phosphoribulokinase', 0.0),
#  ('2012 these enzymes were phosphoribulokinase', 0.0),
#  ('2013 the activity of phosphoribulokinase', 0.0),
#  ('520 kda consisting of phosphoribulokinase', 0.0),
#  ('556 fda approved drugs pranlukast', 0.0),
#  ('7 bisphosphatase sbpase and phosphoribulokinase', 0.0),
#  ('80 d underwent photorefractive keratectomy', 0.0),
#  ('9 diopter d photorefractive keratectomy', 0.0),
#  ('a 9 diopter photorefractive keratectomy', 0.0),
#  ('a ternary complex with phosphoribulokinase', 0.0),
#  ('above 1 00d photorefractive keratectomy', 0.0),
#  ('after excimer laser photorefractive keratectomy', 0.0),
#  ('and 1 post photorefractive keratectomy', 0.0),
#  ('and 9 diopter photorefractive keratectomy', 0.0),
#  ('and predictability of photorefractive keratectomy', 0.0),
#  ('and safety of photorefractive keratectomy', 0.0),
#  ('and treated with photorefractive keratectomy', 0.0),
#  ('apparently lack another one phosphoribulokinase', 0.0),
#  ('as a pkc related kinase', 0.0),
#  ('b ribulose 5 phosphate kinase', 0.0),
#  ('barrier functional following photorefractive keratectomy', 0.0),
#  ('been rigorously test with phosphoribulokinase', 0.0),
#  ('bisphosphate carboxylase rubisco and phosphoribulokinase', 0.0),
#  ('bisphosphatase ribulose 5 phosphate kinase', 0.0),
#  ('by wavefront guided photorefractive keratectomy', 0.0),
#  ('calvin benson cb cycle phosphoribulokinase', 0.0),
#  ('calvin benson cycle enzymes phosphoribulokinase', 0.0),
#  ('carboxylase oxygenase rubisco and phosphoribulokinase', 0.0),
#  ('changes induced by photorefractive keratectomy', 0.0),
#  ('characteristically co 2 saturated phosphoribulokinase', 0.0),
#  ('chloroplast is oligomerized with phosphoribulokinase', 0.0),
#  ('co 2 fixation and phosphoribulokinase', 0.0),
#  ('complex of cbc protein phosphoribulokinase', 0.0),
#  ('considered for example photorefractive keratectomy', 0.0),
#  ('corneal cells following photorefractive keratectomy', 0.0),
#  ('corneal haze after photorefractive keratectomy', 0.0),
#  ('corneal haze following photorefractive keratectomy', 0.0),
#  ('corneal haze post photorefractive keratectomy', 0.0),
#  ('correlate with changes in st', 0.0),
#  ('culture samples table 1 phosphoribulokinase', 0.0),
#  ('cycle enzymes rubisco and phosphoribulokinase', 0.0),
#  ('cycle multiprotein complex included phosphoribulokinase', 0.0),
#  ('days lasik to 5 days', 0.0),
#  ('demonstrate the potency of pranlukast', 0.0),
#  ('early days of photorefractive keratectomy', 0.0),
#  ('ef at2g29960 cyclophilin and at1g32060', 0.0),
#  ('employs rubisco along with phosphoribulokinase', 0.0),
#  ('enzymes phosphoriboseisomerase pri and phosphoribulokinase', 0.0),
#  ('epimerase rpe and a phosphoribulokinase', 0.0),
#  ('epithelial healing after photorefractive keratectomy', 0.0),
#  ('epithelial scrape and photorefractive keratectomy', 0.0),
#  ('established high diopter photorefractive keratectomy', 0.0),
#  ('excimer laser myopic photorefractive keratectomy', 0.0),
#  ('expression of a heterologous phosphoribulokinase', 0.0),
#  ('extraction for analysis of phosphoribulokinase', 0.0),
#  ('eye treated with photorefractive keratectomy', 0.0),
#  ('fibrosis in a photorefractive keratectomy', 0.0),
#  ('fnr ascorbate peroxidase apx phosphoribulokinase', 0.0),
#  ('following excimer laser photorefractive keratectomy', 0.0),
#  ('formation in a photorefractive keratectomy', 0.0),
#  ('g rubisco rubisco activase phosphoribulokinase', 0.0),
#  ('gapa 1 and gapb prk', 0.0),
#  ('gapa and gapb and prk', 0.0),
#  ('gapdh embedded in the phosphoribulokinase', 0.0),
#  ('generating high correction photorefractive keratectomy', 0.0),
#  ('glycerol the spinacia oleracea phosphoribulokinase', 0.0),
#  ('half years after photorefractive keratectomy', 0.0),
#  ('have wavefront guided photorefractive keratectomy', 0.0),
#  ('high diopter 9d photorefractive keratectomy', 0.0),
#  ('hsd ribulose 5 phosphate kinase', 0.0),
#  ('important complications of photorefractive keratectomy', 0.0),
#  ('keratectomy ptk myopic photorefractive keratectomy', 0.0),
#  ('keratomileusis lasek versus photorefractive keratectomy', 0.0),
#  ('keratomileusis lasik and photorefractive keratectomy', 0.0),
#  ('keratomileusis lasik or photorefractive keratectomy', 0.0),
#  ('keratotomy rk and photorefractive keratectomy', 0.0),
#  ('laboratories smithfield australia photorefractive keratectomy', 0.0),
#  ('lasek versus standard photorefractive keratectomy', 0.0),
#  ('late 1990s transepithelial photorefractive keratectomy', 0.0),
#  ('liver we have identified pranlukast', 0.0),
#  ('maintained in isolated photorefractive keratectomy', 0.0),
#  ('major challenge after photorefractive keratectomy', 0.0),
#  ('mtb pathogenesis we report pranlukast', 0.0),
#  ('n terminal region of phosphoribulokinase', 0.0),
#  ('non wavefront guided photorefractive keratectomy', 0.0),
#  ('occur after hyperopic photorefractive keratectomy', 0.0),
#  ('ocular hypertension after photorefractive keratectomy', 0.0),
#  ('of excimer laser photorefractive keratectomy', 0.0),
#  ('of fibroblasts after photorefractive keratectomy', 0.0),
#  ('of patients receiving photorefractive keratectomy', 0.0),
#  ('of redox regulate of phosphoribulokinase', 0.0),
#  ('of the calvin cycle phosphoribulokinase', 0.0),
#  ('of the other enzymes phosphoribulokinase', 0.0),
#  ('of the plant receptor kinase', 0.0),
#  ('of two dimers of phosphoribulokinase', 0.0),
#  ('of two lead compounds pranlukast', 0.0),
#  ('of two potent compounds pranlukast', 0.0),
#  ('of wavefront guided photorefractive keratectomy', 0.0),
#  ('patients randomized to photorefractive keratectomy', 0.0),
#  ('patients treated with photorefractive keratectomy', 0.0),
#  ('performing excimer laser surface ablation', 0.0),
#  ('phosphate dehydrogenase gapdh and phosphoribulokinase', 0.0),
#  ('phosphorylated by primary rabbit kidney', 0.0),
#  ('photosystem ii psbp and phosphoribulokinase', 0.0),
#  ('plant calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('practice excimer laser photorefractive keratectomy', 0.0),
#  ('procedures such as photorefractive keratectomy', 0.0),
#  ('produced by performing photorefractive keratectomy', 0.0),
#  ('proper thioredoxin deactivation of phosphoribulokinase', 0.0),
#  ('protein kinase c related protein', 0.0),
#  ('rabbit corneas after photorefractive keratectomy', 0.0),
#  ('rabbit that underwent photorefractive keratectomy', 0.0),
#  ('re smile 3d photorefractive keratectomy', 0.0),
#  ('reaction catalyzed by atpase phosphoribulokinase', 0.0),
#  ('related protein ric2 rap phosphoribulokinase', 0.0),
#  ('renewed interest in photorefractive keratectomy', 0.0),
#  ('routinely using after photorefractive keratectomy', 0.0),
#  ('rubisco small chain 1a phosphoribulokinase', 0.0),
#  ('rubp is regenerated 3 phosphoribulokinase', 0.0),
#  ('subepithelial haze after photorefractive keratectomy', 0.0),
#  ('sublayer thickness after photorefractive keratectomy', 0.0),
#  ('surgical procedures like photorefractive keratectomy', 0.0),
#  ('tgf beta after photorefractive keratectomy', 0.0),
#  ('that had 9d photorefractive keratectomy', 0.0),
#  ('the cb cycle enzymes phosphoribulokinase', 0.0),
#  ('the cyanobacterial calvin cycle phosphoribulokinase', 0.0),
#  ('the introduction of photorefractive keratectomy', 0.0),
#  ('the outcomes of photorefractive keratectomy', 0.0),
#  ('the results of photorefractive keratectomy', 0.0),
#  ('the using of photorefractive keratectomy', 0.0),
#  ('tono pen after photorefractive keratectomy', 0.0),
#  ('traditional epithelial scrape photorefractive keratectomy', 0.0),
#  ('trans or subepithelial photorefractive keratectomy', 0.0),
#  ('treated with transepithelial photorefractive keratectomy', 0.0),
#  ('two calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('tyrosine the activity of phosphoribulokinase', 0.0),
#  ('undergoing lasik and photorefractive keratectomy', 0.0),
#  ('visx inc custom photorefractive keratectomy', 0.0),
#  ('vivo in a photorefractive keratectomy', 0.0),
#  ('were treated with photorefractive keratectomy', 0.0),
#  ('with alcohol assisted photorefractive keratectomy', 0.0),
#  ('with aspheric profile photorefractive keratectomy', 0.0),
#  ('with lasik or photorefractive keratectomy', 0.0),
#  ('worth tx usa photorefractive keratectomy', 0.0),
#  ('wound created with photorefractive keratectomy', 0.0),
#  ('wound healing after photorefractive keratectomy', 0.0),
#  ('wound results after photorefractive keratectomy', 0.0),
#  ('0 80 d underwent photorefractive keratectomy', 0.0),
#  ('1 2 1 13 and phosphoribulokinase', 0.0),
#  ('1 556 fda approved drugs pranlukast', 0.0),
#  ('1 7 bisphosphatase sbpase and phosphoribulokinase', 0.0),
#  ('1 days lasik to 5 days', 0.0),
#  ('3 epimerase rpe and a phosphoribulokinase', 0.0),
#  ('3 phosphate dehydrogenase gapdh and phosphoribulokinase', 0.0),
#  ('3d re smile 3d photorefractive keratectomy', 0.0),
#  ('5 bisphosphate carboxylase rubisco and phosphoribulokinase', 0.0),
#  ('7 bisphosphatase ribulose 5 phosphate kinase', 0.0),
#  ('a half years after photorefractive keratectomy', 0.0),
#  ('a renewed interest in photorefractive keratectomy', 0.0),
#  ('activity of the other enzymes phosphoribulokinase', 0.0),
#  ('activity the cb cycle enzymes phosphoribulokinase', 0.0),
#  ('after 9 diopter d photorefractive keratectomy', 0.0),
#  ('after traditional epithelial scrape photorefractive keratectomy', 0.0),
#  ('al 2012 these enzymes were phosphoribulokinase', 0.0),
#  ('al 2013 the activity of phosphoribulokinase', 0.0),
#  ('also employs rubisco along with phosphoribulokinase', 0.0),
#  ('an established high diopter photorefractive keratectomy', 0.0),
#  ('and eye treated with photorefractive keratectomy', 0.0),
#  ('and liver we have identified pranlukast', 0.0),
#  ('and maintained in isolated photorefractive keratectomy', 0.0),
#  ('and major challenge after photorefractive keratectomy', 0.0),
#  ('and non wavefront guided photorefractive keratectomy', 0.0),
#  ('and protein kinase c related kinase', 0.0),
#  ('and tono pen after photorefractive keratectomy', 0.0),
#  ('and trans or subepithelial photorefractive keratectomy', 0.0),
#  ('applying a 9 diopter photorefractive keratectomy', 0.0),
#  ('approximately 520 kda consisting of phosphoribulokinase', 0.0),
#  ('are characteristically co 2 saturated phosphoribulokinase', 0.0),
#  ('are routinely using after photorefractive keratectomy', 0.0),
#  ('at1g07940 ef at2g29960 cyclophilin and at1g32060', 0.0),
#  ('b chemical structures of a pranlukast', 0.0),
#  ('be considered for example photorefractive keratectomy', 0.0),
#  ('beta tgf beta after photorefractive keratectomy', 0.0),
#  ('but apparently lack another one phosphoribulokinase', 0.0),
#  ('c protein kinase c related kinase', 0.0),
#  ('calvin cycle enzymes rubisco and phosphoribulokinase', 0.0),
#  ('calvin cycle multiprotein complex included phosphoribulokinase', 0.0),
#  ('can occur after hyperopic photorefractive keratectomy', 0.0),
#  ('cells 4 weeks after photorefractive keratectomy', 0.0),
#  ('cells extraction for analysis of phosphoribulokinase', 0.0),
#  ('changes correlate with changes in st', 0.0),
#  ('clinical practice excimer laser photorefractive keratectomy', 0.0),
#  ('compare patients treated with photorefractive keratectomy', 0.0),
#  ('compare the outcomes of photorefractive keratectomy', 0.0),
#  ('compare with alcohol assisted photorefractive keratectomy', 0.0),
#  ('complex of two dimers of phosphoribulokinase', 0.0),
#  ('continuous culture samples table 1 phosphoribulokinase', 0.0),
#  ('core complex of cbc protein phosphoribulokinase', 0.0),
#  ('corneas that had 9d photorefractive keratectomy', 0.0),
#  ('corneal epithelial healing after photorefractive keratectomy', 0.0),
#  ('corneal fibrosis in a photorefractive keratectomy', 0.0),
#  ('corneal sublayer thickness after photorefractive keratectomy', 0.0),
#  ('corneal surgery such as photorefractive keratectomy', 0.0),
#  ('corneal wound created with photorefractive keratectomy', 0.0),
#  ('corneal wound healing after photorefractive keratectomy', 0.0),
#  ('corneal wound results after photorefractive keratectomy', 0.0),
#  ('course after excimer laser photorefractive keratectomy', 0.0),
#  ('d 4 weeks after photorefractive keratectomy', 0.0),
#  ('d − 9 0d photorefractive keratectomy', 0.0),
#  ('dehydrogenase gapdh embedded in the phosphoribulokinase', 0.0),
#  ('determinations b ribulose 5 phosphate kinase', 0.0),
#  ('diopter − 9 0d photorefractive keratectomy', 0.0),
#  ('discovery of two potent compounds pranlukast', 0.0),
#  ('diversity of redox regulate of phosphoribulokinase', 0.0),
#  ('duplicates chemical structures of a pranlukast', 0.0),
#  ('e g rubisco rubisco activase phosphoribulokinase', 0.0),
#  ('efficacy and predictability of photorefractive keratectomy', 0.0),
#  ('efficacy and safety of photorefractive keratectomy', 0.0),
#  ('enzymes of the calvin cycle phosphoribulokinase', 0.0),
#  ('epithelial keratomileusis lasek versus photorefractive keratectomy', 0.0),
#  ('expression the calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('eye have wavefront guided photorefractive keratectomy', 0.0),
#  ('eye surgery such as photorefractive keratectomy', 0.0),
#  ('following by wavefront guided photorefractive keratectomy', 0.0),
#  ('for co 2 fixation and phosphoribulokinase', 0.0),
#  ('forms a ternary complex with phosphoribulokinase', 0.0),
#  ('fort worth tx usa photorefractive keratectomy', 0.0),
#  ('gapdh gapa 1 and gapb prk', 0.0),
#  ('gapdh gapa and gapb and prk', 0.0),
#  ('haze formation in a photorefractive keratectomy', 0.0),
#  ('higher plant calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('identification of two lead compounds pranlukast', 0.0),
#  ('in chloroplast is oligomerized with phosphoribulokinase', 0.0),
#  ('in the cyanobacterial calvin cycle phosphoribulokinase', 0.0),
#  ('in vivo in a photorefractive keratectomy', 0.0),
#  ('induced corneal haze following photorefractive keratectomy', 0.0),
#  ('induced ocular hypertension after photorefractive keratectomy', 0.0),
#  ('influence corneal haze after photorefractive keratectomy', 0.0),
#  ('inhibit corneal haze post photorefractive keratectomy', 0.0),
#  ('into tyrosine the activity of phosphoribulokinase', 0.0),
#  ('is phosphorylated by primary rabbit kidney', 0.0),
#  ('keratomileusis lasek versus standard photorefractive keratectomy', 0.0),
#  ('member of the plant receptor kinase', 0.0),
#  ('most important complications of photorefractive keratectomy', 0.0),
#  ('myopic patients randomized to photorefractive keratectomy', 0.0),
#  ('nj and 9 diopter photorefractive keratectomy', 0.0),
#  ('not been rigorously test with phosphoribulokinase', 0.0),
#  ('of corneal cells following photorefractive keratectomy', 0.0),
#  ('of excimer laser myopic photorefractive keratectomy', 0.0),
# ...
#  ('surgical procedures such as photorefractive keratectomy', 0.0),
#  ('that expression of a heterologous phosphoribulokinase', 0.0),
#  ('that performing excimer laser surface ablation', 0.0),
#  ('the calvin benson cb cycle phosphoribulokinase', 0.0),
#  ('the early days of photorefractive keratectomy', 0.0),
#  ('the enzymes phosphoriboseisomerase pri and phosphoribulokinase', 0.0),
#  ('the late 1990s transepithelial photorefractive keratectomy', 0.0),
#  ('the proper thioredoxin deactivation of phosphoribulokinase', 0.0),
#  ('the protein kinase c related kinase', 0.0),
#  ('the protein kinase c related protein', 0.0),
#  ('the rabbit corneas after photorefractive keratectomy', 0.0),
#  ('treated with aspheric profile photorefractive keratectomy', 0.0),
#  ('troy laboratories smithfield australia photorefractive keratectomy', 0.0),
#  ('tuberculosis mtb pathogenesis we report pranlukast', 0.0),
#  ('using high diopter 9d photorefractive keratectomy', 0.0),
#  ('using of wavefront guided photorefractive keratectomy', 0.0),
#  ('was produced by performing photorefractive keratectomy', 0.0),
#  ('was treated with transepithelial photorefractive keratectomy', 0.0),
#  ('well as a pkc related kinase', 0.0),
#  ('whereas rubisco small chain 1a phosphoribulokinase', 0.0),
#  ('which rubp is regenerated 3 phosphoribulokinase', 0.0),
#  ('who were treated with photorefractive keratectomy', 0.0),
#  ('+ 0 80 d underwent photorefractive keratectomy', 0.0),
#  ('+ cells 4 weeks after photorefractive keratectomy', 0.0),
#  ('0 diopter − 9 0d photorefractive keratectomy', 0.0),
#  ('1 5 bisphosphate carboxylase rubisco and phosphoribulokinase', 0.0),
#  ('1 7 bisphosphatase ribulose 5 phosphate kinase', 0.0),
#  ('1 and maintained in isolated photorefractive keratectomy', 0.0),
#  ('12 compare patients treated with photorefractive keratectomy', 0.0),
#  ('5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase', 0.0),
#  ('5 determinations b ribulose 5 phosphate kinase', 0.0),
#  ('a b chemical structures of a pranlukast', 0.0),
#  ('a d − 9 0d photorefractive keratectomy', 0.0),
#  ('a member of the plant receptor kinase', 0.0),
#  ('ablation phototherapeutic keratectomy ptk myopic photorefractive keratectomy',
#   0.0),
#  ('actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060', 0.0),
#  ('activity of two calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('activity the calvin benson cycle enzymes phosphoribulokinase', 0.0),
#  ('after opacity generating high correction photorefractive keratectomy', 0.0),
#  ('agent is phosphorylated by primary rabbit kidney', 0.0),
#  ('analyzed 3d re smile 3d photorefractive keratectomy', 0.0),
#  ('and a half years after photorefractive keratectomy', 0.0),
#  ('and eye have wavefront guided photorefractive keratectomy', 0.0),
#  ('and in vivo in a photorefractive keratectomy', 0.0),
#  ('anterior corneal surgery such as photorefractive keratectomy', 0.0),
#  ('apoptosis of corneal cells following photorefractive keratectomy', 0.0),
#  ('as well as a pkc related kinase', 0.0),
#  ('at 1 days lasik to 5 days', 0.0),
#  ('binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#   0.0),
#  ('by applying a 9 diopter photorefractive keratectomy', 0.0),
#  ('by product glycerol the spinacia oleracea phosphoribulokinase', 0.0),
#  ('c d 4 weeks after photorefractive keratectomy', 0.0),
#  ('can inhibit corneal haze post photorefractive keratectomy', 0.0),
#  ('clinical haze formation in a photorefractive keratectomy', 0.0),
#  ('combined radial keratotomy rk and photorefractive keratectomy', 0.0),
#  ('common and major challenge after photorefractive keratectomy', 0.0),
#  ('complex approximately 520 kda consisting of phosphoribulokinase', 0.0),
#  ('confirmed that expression of a heterologous phosphoribulokinase', 0.0),
#  ('core complex of two dimers of phosphoribulokinase', 0.0),
#  ('corneas using high diopter 9d photorefractive keratectomy', 0.0),
#  ('corneas was produced by performing photorefractive keratectomy', 0.0),
#  ('cycle also employs rubisco along with phosphoribulokinase', 0.0),
#  ('cycle but apparently lack another one phosphoribulokinase', 0.0),
#  ('data since the introduction of photorefractive keratectomy', 0.0),
#  ('development of subepithelial haze after photorefractive keratectomy', 0.0),
#  ('drops are routinely using after photorefractive keratectomy', 0.0),
#  ('ec 1 2 1 13 and phosphoribulokinase', 0.0),
#  ('encoding gapdh gapa and gapb and prk', 0.0),
#  ('enzymes e g rubisco rubisco activase phosphoribulokinase', 0.0),
#  ('enzymes in the cyanobacterial calvin cycle phosphoribulokinase', 0.0),
#  ('epithelial keratomileusis lasek versus standard photorefractive keratectomy',
#   0.0),
#  ('epithelial scrape epithelial scrape and photorefractive keratectomy', 0.0),
#  ('et al 2012 these enzymes were phosphoribulokinase', 0.0),
#  ('et al 2013 the activity of phosphoribulokinase', 0.0),
#  ('expression of the calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('eye and eye treated with photorefractive keratectomy', 0.0),
#  ('factor beta tgf beta after photorefractive keratectomy', 0.0),
#  ('flap was treated with transepithelial photorefractive keratectomy', 0.0),
#  ('following corneal wound created with photorefractive keratectomy', 0.0),
#  ('following refractive surgical procedures like photorefractive keratectomy',
#   0.0),
#  ('from the early days of photorefractive keratectomy', 0.0),
#  ('from which rubp is regenerated 3 phosphoribulokinase', 0.0),
#  ('functional expression the calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('groes cells extraction for analysis of phosphoribulokinase', 0.0),
#  ('group stated above 1 00d photorefractive keratectomy', 0.0),
#  ('guided and non wavefront guided photorefractive keratectomy', 0.0),
#  ('has not been rigorously test with phosphoribulokinase', 0.0),
#  ('hydrochloride troy laboratories smithfield australia photorefractive keratectomy',
#   0.0),
#  ('in an established high diopter photorefractive keratectomy', 0.0),
#  ('in clinical practice excimer laser photorefractive keratectomy', 0.0),
#  ('in corneal sublayer thickness after photorefractive keratectomy', 0.0),
#  ('in myopic patients randomized to photorefractive keratectomy', 0.0),
#  ('in patients undergoing lasik and photorefractive keratectomy', 0.0),
#  ('in the late 1990s transepithelial photorefractive keratectomy', 0.0),
#  ('in the rabbit corneas after photorefractive keratectomy', 0.0),
#  ('laboratories fort worth tx usa photorefractive keratectomy', 0.0),
#  ('lakes nj and 9 diopter photorefractive keratectomy', 0.0),
#  ('lasek and trans or subepithelial photorefractive keratectomy', 0.0),
#  ('laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#   0.0),
#  ('laser eye surgery such as photorefractive keratectomy', 0.0),
#  ('laser induced corneal haze following photorefractive keratectomy', 0.0),
#  ('lasik patients and 1 post photorefractive keratectomy', 0.0),
#  ('may influence corneal haze after photorefractive keratectomy', 0.0),
#  ('mycobacterium tuberculosis mtb pathogenesis we report pranlukast', 0.0),
#  ('nadp reductase fnr ascorbate peroxidase apx phosphoribulokinase', 0.0),
#  ('not forms a ternary complex with phosphoribulokinase', 0.0),
#  ('of 1 556 fda approved drugs pranlukast', 0.0),
#  ('of the proper thioredoxin deactivation of phosphoribulokinase', 0.0),
#  ('of the protein kinase c related kinase', 0.0),
#  ('on corneal epithelial healing after photorefractive keratectomy', 0.0),
#  ('on corneal wound healing after photorefractive keratectomy', 0.0),
#  ('outcomes of excimer laser myopic photorefractive keratectomy', 0.0),
#  ('patients treated with aspheric profile photorefractive keratectomy', 0.0),
#  ('patients who were treated with photorefractive keratectomy', 0.0),
#  ('phenylalanine into tyrosine the activity of phosphoribulokinase', 0.0),
#  ('phosphate 3 epimerase rpe and a phosphoribulokinase', 0.0),
#  ('phosphate dehydrogenase gapdh embedded in the phosphoribulokinase', 0.0),
#  ('plastid gapdh gapa 1 and gapb prk', 0.0),
#  ('polypeptide of photosystem ii psbp and phosphoribulokinase', 0.0),
#  ('postoperative course after excimer laser photorefractive keratectomy', 0.0),
#  ('product are characteristically co 2 saturated phosphoribulokinase', 0.0),
#  ('ptk following by wavefront guided photorefractive keratectomy', 0.0),
#  ('quantitatively after traditional epithelial scrape photorefractive keratectomy',
#   0.0),
#  ('rabbit corneas that had 9d photorefractive keratectomy', 0.0),
#  ('reductively activity the cb cycle enzymes phosphoribulokinase', 0.0),
#  ('refractive changes correlate with changes in st', 0.0),
#  ('refractive surgery and treated with photorefractive keratectomy', 0.0),
#  ('refractive surgery with lasik or photorefractive keratectomy', 0.0),
#  ('refractive surgical procedures such as photorefractive keratectomy', 0.0),
#  ('regulate the protein kinase c related protein', 0.0),
#  ('report pain of patients receiving photorefractive keratectomy', 0.0),
#  ('report that performing excimer laser surface ablation', 0.0),
#  ('respectively whereas rubisco small chain 1a phosphoribulokinase', 0.0),
#  ('responsible for co 2 fixation and phosphoribulokinase', 0.0),
#  ('ribulose bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   0.0),
#  ('rsk and protein kinase c related kinase', 0.0),
#  ('safety efficacy and predictability of photorefractive keratectomy', 0.0),
#  ('sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase', 0.0),
#  ('semi continuous culture samples table 1 phosphoribulokinase', 0.0),
#  ('sfk c protein kinase c related kinase', 0.0),
#  ('should be considered for example photorefractive keratectomy', 0.0),
#  ('spleen and liver we have identified pranlukast', 0.0),
#  ('steroid induced ocular hypertension after photorefractive keratectomy',
#   0.0),
#  ('stroma of rabbit that underwent photorefractive keratectomy', 0.0),
#  ('sus4 ras related protein ric2 rap phosphoribulokinase', 0.0),
#  ('technical duplicates chemical structures of a pranlukast', 0.0),
#  ('that can occur after hyperopic photorefractive keratectomy', 0.0),
#  ('the activity of the other enzymes phosphoribulokinase', 0.0),
#  ('the calvin cycle enzymes rubisco and phosphoribulokinase', 0.0),
#  ('the core complex of cbc protein phosphoribulokinase', 0.0),
#  ('the corneal wound results after photorefractive keratectomy', 0.0),
#  ('the discovery of two potent compounds pranlukast', 0.0),
#  ('the diversity of redox regulate of phosphoribulokinase', 0.0),
#  ('the higher plant calvin cycle enzymes phosphoribulokinase', 0.0),
#  ('the identification of two lead compounds pranlukast', 0.0),
#  ('the most important complications of photorefractive keratectomy', 0.0),
#  ('the proliferation of fibroblasts after photorefractive keratectomy', 0.0),
#  ('the results of excimer laser photorefractive keratectomy', 0.0),
#  ('the stromal reaction catalyzed by atpase phosphoribulokinase', 0.0),
#  ('the using of wavefront guided photorefractive keratectomy', 0.0),
#  ('these results demonstrate the potency of pranlukast', 0.0),
#  ('to a renewed interest in photorefractive keratectomy', 0.0),
#  ('to optical changes induced by photorefractive keratectomy', 0.0),
#  ('tonometer and tono pen after photorefractive keratectomy', 0.0),
#  ('topical steroid following excimer laser photorefractive keratectomy', 0.0),
#  ('transprk compare with alcohol assisted photorefractive keratectomy', 0.0),
#  ('tukey s hsd ribulose 5 phosphate kinase', 0.0),
#  ('two enzymes of the calvin cycle phosphoribulokinase', 0.0),
#  ('visx s4 visx inc custom photorefractive keratectomy', 0.0),
#  ('which in chloroplast is oligomerized with phosphoribulokinase', 0.0),
#  ('with the calvin benson cb cycle phosphoribulokinase', 0.0),
#  ('with the calvin benson cycle enzymes phosphoribulokinase', 0.0),
#  ('without corneal fibrosis in a photorefractive keratectomy', 0.0),
#  ('1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#   0.0),
#  ('1 laser eye surgery such as photorefractive keratectomy', 0.0),
#  ('1 months after 9 diopter d photorefractive keratectomy', 0.0),
#  ('20 + 0 80 d underwent photorefractive keratectomy', 0.0),
#  ('3 in the late 1990s transepithelial photorefractive keratectomy', 0.0),
#  ('3 phosphate dehydrogenase gapdh embedded in the phosphoribulokinase', 0.0),
#  ('4 sus4 ras related protein ric2 rap phosphoribulokinase', 0.0),
#  ('42 in clinical practice excimer laser photorefractive keratectomy', 0.0),
#  ('9 0 diopter − 9 0d photorefractive keratectomy', 0.0),
#  ('a common and major challenge after photorefractive keratectomy', 0.0),
#  ('a core complex of two dimers of phosphoribulokinase', 0.0),
#  ('aberrations in myopic patients randomized to photorefractive keratectomy',
#   0.0),
#  ('ablation from the early days of photorefractive keratectomy', 0.0),
#  ('abrogated clinical haze formation in a photorefractive keratectomy', 0.0),
#  ('after epithelial scrape epithelial scrape and photorefractive keratectomy',
#   0.0),
#  ('after laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#   0.0),
#  ('alcon laboratories fort worth tx usa photorefractive keratectomy', 0.0),
#  ('and apoptosis of corneal cells following photorefractive keratectomy', 0.0),
#  ('and groes cells extraction for analysis of phosphoribulokinase', 0.0),
#  ('and patients who were treated with photorefractive keratectomy', 0.0),
#  ('and quantitatively after traditional epithelial scrape photorefractive keratectomy',
#   0.0),
#  ('and report pain of patients receiving photorefractive keratectomy', 0.0),
#  ('and the proliferation of fibroblasts after photorefractive keratectomy',
#   0.0),
#  ('and without corneal fibrosis in a photorefractive keratectomy', 0.0),
#  ('assisted in situ keratomileusis lasik and photorefractive keratectomy',
#   0.0),
#  ('assisted in situ keratomileusis lasik or photorefractive keratectomy', 0.0),
#  ('at3g18780 actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060', 0.0),
#  ('b these results demonstrate the potency of pranlukast', 0.0),
#  ('benson cycle but apparently lack another one phosphoribulokinase', 0.0),
#  ('between glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   0.0),
#  ('bioethanol product are characteristically co 2 saturated phosphoribulokinase',
#   0.0),
#  ('buchanan et al 2012 these enzymes were phosphoribulokinase', 0.0),
#  ('by tukey s hsd ribulose 5 phosphate kinase', 0.0),
#  ('carbon with the calvin benson cb cycle phosphoribulokinase', 0.0),
#  ('cat following corneal wound created with photorefractive keratectomy', 0.0),
#  ('cbb cycle also employs rubisco along with phosphoribulokinase', 0.0),
#  ('changes in corneal sublayer thickness after photorefractive keratectomy',
#   0.0),
#  ('co binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#   0.0),
#  ('compare the efficacy and safety of photorefractive keratectomy', 0.0),
#  ('compare the results of excimer laser photorefractive keratectomy', 0.0),
#  ('complex with the calvin benson cycle enzymes phosphoribulokinase', 0.0),
#  ('control eye and eye treated with photorefractive keratectomy', 0.0),
#  ('corneal refractive surgery and treated with photorefractive keratectomy',
#   0.0),
#  ('corneal stroma of rabbit that underwent photorefractive keratectomy', 0.0),
#  ('corticosteroid drops are routinely using after photorefractive keratectomy',
#   0.0),
#  ('cycle enzymes e g rubisco rubisco activase phosphoribulokinase', 0.0),
#  ('dependent glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#   0.0),
#  ('does not forms a ternary complex with phosphoribulokinase', 0.0),
#  ('drops on corneal epithelial healing after photorefractive keratectomy',
#   0.0),
#  ('effects the corneal wound results after photorefractive keratectomy', 0.0),
#  ('encoding plastid gapdh gapa 1 and gapb prk', 0.0),
#  ('et1 on corneal wound healing after photorefractive keratectomy', 0.0),
#  ('evaluate the efficacy and safety of photorefractive keratectomy', 0.0),
#  ('examinations at 1 days lasik to 5 days', 0.0),
#  ('f activity the calvin benson cycle enzymes phosphoribulokinase', 0.0),
#  ('fbpase sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase',
#   0.0),
#  ...]

# %%
longforms0 = miners['PRK'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('photorefractive keratectomy', 94.16)),
#  (1, ('phosphoribulokinase', 59.970588235294116)),
#  (2, ('pranlukast', 6.5)),
#  (3, ('kinase', 4.75))]

# %%
longforms0 = [(longform, score) for i, (longform, score) in enumerate(longforms0)
              if i not in [3]]

# %%
list(enumerate(top))
# Out:
# [(0, ('photorefractive keratectomy', 94.16)),
#  (1, ('phosphoribulokinase', 59.970588235294116)),
#  (2, ('and phosphoribulokinase', 15.52)),
#  (3, ('after photorefractive keratectomy', 14.625)),
#  (4,
#   ('glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    11.307692307692307)),
#  (5, ('of photorefractive keratectomy', 7.777777777777778)),
#  (6, ('of phosphoribulokinase', 6.75)),
#  (7, ('pranlukast', 6.5)),
#  (8, ('kinase', 4.75)),
#  (9, ('cycle enzymes phosphoribulokinase', 4.25)),
#  (10,
#   ('laser in situ keratomileusis lasik and photorefractive keratectomy', 4.0)),
#  (11, ('wavefront guided photorefractive keratectomy', 3.6)),
#  (12, ('and photorefractive keratectomy', 3.333333333333333)),
#  (13, ('with phosphoribulokinase', 3.0)),
#  (14, ('rubisco and phosphoribulokinase', 3.0)),
#  (15, ('excimer laser photorefractive keratectomy', 3.0)),
#  (16, ('treated with photorefractive keratectomy', 3.0)),
#  (17, ('calvin cycle enzymes phosphoribulokinase', 2.8)),
#  (18, ('following photorefractive keratectomy', 2.0)),
#  (19, ('in a photorefractive keratectomy', 2.0)),
#  (20, ('ribulose 5 phosphate kinase', 2.0)),
#  (21, ('protein kinase c related kinase', 2.0)),
#  (22,
#   ('with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    2.0)),
#  (23,
#   ('ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    2.0)),
#  (24,
#   ('ation of a complex between glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    2)),
#  (25,
#   ('to evaluate the long term outcomes of excimer laser myopic photorefractive keratectomy',
#    2)),
#  (26, ('enzymes phosphoribulokinase', 1.7777777777777777)),
#  (27, ('lasik and photorefractive keratectomy', 1.7142857142857144)),
#  (28,
#   ('in situ keratomileusis lasik and photorefractive keratectomy',
#    1.666666666666667)),
#  (29, ('with photorefractive keratectomy', 1.6)),
#  (30, ('related kinase', 1.5)),
#  (31,
#   ('bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase', 1.5)),
#  (32, ('cycle phosphoribulokinase', 1.3333333333333333)),
#  (33, ('diopter photorefractive keratectomy', 1.3333333333333333)),
#  (34, ('myopic photorefractive keratectomy', 1.3333333333333333)),
#  (35, ('lasik or photorefractive keratectomy', 1.3333333333333333)),
#  (36, ('such as photorefractive keratectomy', 1.3333333333333333)),
#  (37, ('the calvin cycle enzymes phosphoribulokinase', 1.3333333333333333)),
#  (38,
#   ('enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1.3333333333333333)),
#  (39, ('prk', 1.0)),
#  (40, ('compounds pranlukast', 1.0)),
#  (41, ('9d photorefractive keratectomy', 1.0)),
#  (42, ('a heterologous phosphoribulokinase', 1.0)),
#  (43, ('calvin cycle phosphoribulokinase', 1.0)),
#  (44, ('post photorefractive keratectomy', 1.0)),
#  (45, ('rhodobacter sphaeroides phosphoribulokinase', 1.0)),
#  (46, ('transepithelial photorefractive keratectomy', 1.0)),
#  (47, ('underwent photorefractive keratectomy', 1.0)),
#  (48, ('9 diopter photorefractive keratectomy', 1.0)),
#  (49, ('haze after photorefractive keratectomy', 1.0)),
#  (50, ('healing after photorefractive keratectomy', 1.0)),
#  (51, ('the activity of phosphoribulokinase', 1.0)),
#  (52, ('to report photorefractive keratectomy', 1)),
#  (53, ('4 weeks after photorefractive keratectomy', 1.0)),
#  (54, ('chemical structures of a pranlukast', 1.0)),
#  (55, ('in the rhodobacter sphaeroides phosphoribulokinase', 1)),
#  (56, ('surgery such as photorefractive keratectomy', 1.0)),
#  (57, ('− 9 0d photorefractive keratectomy', 1.0)),
#  (58, ('corneal barrier functional following photorefractive keratectomy', 1)),
#  (59, ('the calvin benson cycle enzymes phosphoribulokinase', 1.0)),
#  (60, ('the n terminal region of phosphoribulokinase', 1)),
#  (61, ('a calvin cycle multiprotein complex included phosphoribulokinase', 1)),
#  (62, ('in situ keratomileusis lasik or photorefractive keratectomy', 1.0)),
#  (63, ('months after 9 diopter d photorefractive keratectomy', 1.0)),
#  (64, ('the efficacy and safety of photorefractive keratectomy', 1.0)),
#  (65, ('to compare the outcomes of photorefractive keratectomy', 1)),
#  (66, ('to report the results of photorefractive keratectomy', 1)),
#  (67, ('to report the using of photorefractive keratectomy', 1)),
#  (68,
#   ('cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1.0)),
#  (69,
#   ('functional expression of the calvin cycle enzymes phosphoribulokinase',
#    1.0)),
#  (70,
#   ('between wavefront guided and non wavefront guided photorefractive keratectomy',
#    1.0)),
#  (71,
#   ('complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1.0)),
#  (72,
#   ('interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1.0)),
#  (73,
#   ('to compare the efficacy and safety of photorefractive keratectomy', 1)),
#  (74,
#   ('to evaluate the efficacy and safety of photorefractive keratectomy', 1)),
#  (75,
#   ('assisted subepithelial keratectomy lasek and trans or subepithelial photorefractive keratectomy',
#    1)),
#  (76,
#   ('calvin cycle enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1.0)),
#  (77,
#   ('corneal morphology after laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#    1)),
#  (78,
#   ('corneal neovascularization 42 in clinical practice excimer laser photorefractive keratectomy',
#    1)),
#  (79,
#   ('ed qualitatively and quantitatively after traditional epithelial scrape photorefractive keratectomy',
#    1)),
#  (80,
#   ('epithelium occur following refractive surgical procedures such as photorefractive keratectomy',
#    1)),
#  (81,
#   ('g kg xylazine hydrochloride troy laboratories smithfield australia photorefractive keratectomy',
#    1)),
#  (82,
#   ('l photorefractive keratectomy transprk compare with alcohol assisted photorefractive keratectomy',
#    1)),
#  (83,
#   ('lcohol assisted laser epithelial keratomileusis lasek versus standard photorefractive keratectomy',
#    1)),
#  (84,
#   ('njured epithelium occur following refractive surgical procedures like photorefractive keratectomy',
#    1)),
#  (85,
#   ('opacity related myofibroblasts after opacity generating high correction photorefractive keratectomy',
#    1)),
#  (86,
#   ('the perceived and report pain of patients receiving photorefractive keratectomy',
#    1)),
#  (87,
#   ('to determinations whether visx s4 visx inc custom photorefractive keratectomy',
#    1)),
#  (88,
#   ('aberrometric outcomes between wavefront guided and non wavefront guided photorefractive keratectomy',
#    1)),
#  (89,
#   ('ale process for bioethanol product are characteristically co 2 saturated phosphoribulokinase',
#    1)),
#  (90,
#   ('clear encoding chloroplast protein which in chloroplast is oligomerized with phosphoribulokinase',
#    1)),
#  (91,
#   ('compare with control after epithelial scrape epithelial scrape and photorefractive keratectomy',
#    1)),
#  (92,
#   ('e types of surface ablation phototherapeutic keratectomy ptk myopic photorefractive keratectomy',
#    1)),
#  (93,
#   ('enzymes nad p dependent glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (94,
#   ('g76560 cp12 3 at3g18780 actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060',
#    1)),
#  (95,
#   ('hy keratorefractive surgery laser in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (96,
#   ('light dark modulation of the higher plant calvin cycle enzymes phosphoribulokinase',
#    1)),
#  (97,
#   ('nvestigating the proliferation and apoptosis of corneal cells following photorefractive keratectomy',
#    1)),
#  (98,
#   ('o step reaction using ribulose bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    1)),
#  (99,
#   ('pi 3 kinase signaling regulate the protein kinase c related protein', 1)),
#  (100,
#   ('purpose to evaluate the safety efficacy and predictability of photorefractive keratectomy',
#    1)),
#  (101,
#   ('r superficial keratectomy techniques should be considered for example photorefractive keratectomy',
#    1)),
#  (102,
#   ('risk factor contributing to steroid induced ocular hypertension after photorefractive keratectomy',
#    1)),
#  (103,
#   ('rotein that interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (104,
#   ('se gapdh nadph ferredoxin nadp reductase fnr ascorbate peroxidase apx phosphoribulokinase',
#    1)),
#  (105,
#   ('sphosphate carboxylase oxygenase rubisco responsible for co 2 fixation and phosphoribulokinase',
#    1)),
#  (106,
#   ('unique enzymes ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    1)),
#  (107,
#   ('5 kda cp12 interacts with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (108,
#   ('5 povidone iodine betadine alcon laboratories fort worth tx usa photorefractive keratectomy',
#    1)),
#  (109,
#   ('ability in hyperopic astigmatic laser in situ keratomileusis lasik or photorefractive keratectomy',
#    1)),
#  (110,
#   ('canning excimer laser van gelder 12 compare patients treated with photorefractive keratectomy',
#    1)),
#  (111,
#   ('cceptor for nadh reoxidation functional expression of the calvin cycle enzymes phosphoribulokinase',
#    1)),
#  (112,
#   ('ccurred 6 years previous following combined radial keratotomy rk and photorefractive keratectomy',
#    1)),
#  (113,
#   ('corneas that underwent laser assisted in situ keratomileusis lasik or photorefractive keratectomy',
#    1)),
#  (114,
#   ('dehydrogenase mdh in the presence of the proper thioredoxin deactivation of phosphoribulokinase',
#    1)),
#  (115,
#   ('e fruste keratoconus 10 laser in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (116,
#   ('er aberrations hoas between wavefront guided and non wavefront guided photorefractive keratectomy',
#    1)),
#  (117,
#   ('eraldehyde 3 phosphate dehydrogenase seduheptulose 1 7 bisphosphatase ribulose 5 phosphate kinase',
#    1)),
#  (118,
#   ('have homologs of ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    1)),
#  (119,
#   ('he activity of glyceraldehyde 3 phosphate dehydrogenase gapdh embedded in the phosphoribulokinase',
#    1)),
#  (120,
#   ('he contributing of corneal myofibroblasts to optical changes induced by photorefractive keratectomy',
#    1)),
#  (121,
#   ('ical nodular subepithelial corneal scar that can occur after hyperopic photorefractive keratectomy',
#    1)),
#  (122,
#   ('ing a ternary complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (123,
#   ('ion was accomplished by co binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#    1)),
#  (124,
#   ('n applanation tonometer gat noncontact tonometer and tono pen after photorefractive keratectomy',
#    1)),
#  (125,
#   ('nflammation in keratocyte death which may influence corneal haze after photorefractive keratectomy',
#    1)),
#  (126,
#   ('ntions are required to target mycobacterium tuberculosis mtb pathogenesis we report pranlukast',
#    1)),
#  (127,
#   ('orms a stable complex with glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (128,
#   ('orneal topography early in the postoperative course after excimer laser photorefractive keratectomy',
#    1)),
#  (129,
#   ('rredoxin thioredoxin reductase trx f activity the calvin benson cycle enzymes phosphoribulokinase',
#    1)),
#  (130,
#   ('s the calvin cycle enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (131,
#   ('schürmann and buchanan 2008 buchanan et al 2012 these enzymes were phosphoribulokinase',
#    1)),
#  (132,
#   ('sminogen activity upa on the development of subepithelial haze after photorefractive keratectomy',
#    1)),
#  (133,
#   ('ted by incorporating two sequential enzymes in the cyanobacterial calvin cycle phosphoribulokinase',
#    1)),
#  (134,
#   ('thiel behnke corneal dystrophy using ptk following by wavefront guided photorefractive keratectomy',
#    1)),
#  (135,
#   ('to assess the role of topical steroid following excimer laser photorefractive keratectomy',
#    1)),
#  (136,
#   ('to compare 3 years changes in corneal sublayer thickness after photorefractive keratectomy',
#    1)),
#  (137,
#   ('two enzymes of the cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (138,
#   ('uctuations and foreign body sensation in patients undergoing lasik and photorefractive keratectomy',
#    1)),
#  (139,
#   ('with at least two enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (140,
#   ('with the cc enzymes nadph glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (141,
#   ('00 schürmann and buchanan 2008 michelet et al 2013 the activity of phosphoribulokinase',
#    1)),
#  (142,
#   ('ac inhibitor in the treatment of laser induced corneal haze following photorefractive keratectomy',
#    1)),
#  (143,
#   ('and sorafenib srb from the library of 1 556 fda approved drugs pranlukast',
#    1)),
#  (144,
#   ('anges in corneal power and aberrations in myopic patients randomized to photorefractive keratectomy',
#    1)),
#  (145,
#   ('corneal fibrosis was induced in rabbit corneas using high diopter 9d photorefractive keratectomy',
#    1)),
#  (146,
#   ('d laser in situ keratomileusis lasik and eye have wavefront guided photorefractive keratectomy',
#    1)),
#  (147,
#   ('dentified by 2 de immunoblots from semi continuous culture samples table 1 phosphoribulokinase',
#    1)),
#  (148,
#   ('e upregulation of calvin benson cycle enzymes e g rubisco rubisco activase phosphoribulokinase',
#    1)),
#  (149,
#   ('eal haze formation and transforming growth factor beta tgf beta after photorefractive keratectomy',
#    1)),
#  (150,
#   ('ent of myopic astigmatic with laser in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (151,
#   ('eport the outcomes of laser assisted in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (152,
#   ('herpes simplex virus serotype i hsv 1 and maintained in isolated photorefractive keratectomy',
#    1)),
#  (153,
#   ('ields of ethanol and the undesired by product glycerol the spinacia oleracea phosphoribulokinase',
#    1)),
#  (154,
#   ('in a previous study our group functional expression the calvin cycle enzymes phosphoribulokinase',
#    1)),
#  (155,
#   ('issociation of the prk cp12 gapdh complex approximately 520 kda consisting of phosphoribulokinase',
#    1)),
#  (156,
#   ('itive chloroplast protein that interacts with two enzymes of the calvin cycle phosphoribulokinase',
#    1)),
#  (157,
#   ('last growth factor bfgf eye drops on corneal epithelial healing after photorefractive keratectomy',
#    1)),
#  (158,
#   ('long term effects and safety of refractive surgery with lasik or photorefractive keratectomy',
#    1)),
#  (159,
#   ('mented with co 2 this observation confirmed that expression of a heterologous phosphoribulokinase',
#    1)),
#  (160,
#   ('mes of the cycle ribulose 1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    1)),
#  (161,
#   ('nic anhydrase ca chloroplast 23 kda polypeptide of photosystem ii psbp and phosphoribulokinase',
#    1)),
#  (162,
#   ('nt in patients screened for corneal refractive surgery and treated with photorefractive keratectomy',
#    1)),
#  (163,
#   ('of the calvin cycle enzymes ribulose 1 5 bisphosphate carboxylase rubisco and phosphoribulokinase',
#    1)),
#  (164,
#   ('omas lungs and tissue associated histopathology spleen and liver we have identified pranlukast',
#    1)),
#  (165,
#   ('on of enzymes frequencies showed that the stromal reaction catalyzed by atpase phosphoribulokinase',
#    1)),
#  (166,
#   ('on the number of keratocyte and the proliferation of fibroblasts after photorefractive keratectomy',
#    1)),
#  (167,
#   ('perative and the 12 months postoperative data since the introduction of photorefractive keratectomy',
#    1)),
#  (168,
#   ('pression was compare in nonoperated control eye and eye treated with photorefractive keratectomy',
#    1)),
#  (169,
#   ('r and corneal aspheric q in patients treated with aspheric profile photorefractive keratectomy',
#    1)),
#  (170,
#   ('rom a large animal domestic cat following corneal wound created with photorefractive keratectomy',
#    1)),
#  (171,
#   ('se 1 6 bis phosphatase fbpase sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase',
#    1)),
#  (172,
#   ('some report have found that laser in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (173,
#   ('t enzymes of the cb cycle glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    1)),
#  (174,
#   ('three different re treatment options were analyzed 3d re smile 3d photorefractive keratectomy',
#    1)),
#  (175,
#   ('tic of the photosynthetic calvin benson cycle but apparently lack another one phosphoribulokinase',
#    1)),
#  (176,
#   ('to compare the wound healing process in the rabbit corneas after photorefractive keratectomy',
#    1)),
#  (177,
#   ('were detected by the conversion of phenylalanine into tyrosine the activity of phosphoribulokinase',
#    1)),
#  (178,
#   ('were screened for study eligibility and patients who were treated with photorefractive keratectomy',
#    1)),
#  (179,
#   ('xs in chloroplast however this postulate has not been rigorously test with phosphoribulokinase',
#    1)),
#  (180,
#   ('8 9 many study 10 11 have report that performing excimer laser surface ablation',
#    1)),
#  (181,
#   ('a 64 beaver blade bd biosciences franklin lakes nj and 9 diopter photorefractive keratectomy',
#    1)),
#  (182,
#   ('acteria fix carbon dioxide to organic carbon with the calvin benson cb cycle phosphoribulokinase',
#    1)),
#  (183,
#   ('atient with low risk of side effects the corneal wound results after photorefractive keratectomy',
#    1)),
#  (184,
#   ('cin c mmc application on the corneal stroma of rabbit that underwent photorefractive keratectomy',
#    1)),
#  (185,
#   ('d four genes encoding sucrose synthase 4 sus4 ras related protein ric2 rap phosphoribulokinase',
#    1)),
#  (186,
#   ('e incidence of postoperative pain is a common and major challenge after photorefractive keratectomy',
#    1)),
#  (187,
#   ('e with a blunt oscillating blade 3 in the late 1990s transepithelial photorefractive keratectomy',
#    1)),
#  (188,
#   ('f the epithelial basement membrane ebm in rabbit corneas that had 9d photorefractive keratectomy',
#    1)),
#  (189,
#   ('fety of aav5 smad7 target genes therapy in an established high diopter photorefractive keratectomy',
#    1)),
#  (190,
#   ('ik the eye with the donut shaped flap was treated with transepithelial photorefractive keratectomy',
#    1)),
#  (191,
#   ('iversity of algae that are poorly study the diversity of redox regulate of phosphoribulokinase',
#    1)),
#  (192,
#   ('l 0 1 after prk topical corticosteroid drops are routinely using after photorefractive keratectomy',
#    1)),
#  (193,
#   ('laser in situ keratomileusis lasik has led to a renewed interest in photorefractive keratectomy',
#    1)),
#  (194,
#   ('le extraction in addition to the treatment group stated above 1 00d photorefractive keratectomy',
#    1)),
#  (195,
#   ('mary culture of human corneal fibroblasts phcsfs and in vivo in a photorefractive keratectomy',
#    1)),
#  (196,
#   ('mulated with tgfβ in vitro and abrogated clinical haze formation in a photorefractive keratectomy',
#    1)),
#  (197,
#   ('n of the product of interest functional expression of the calvin cycle enzymes phosphoribulokinase',
#    1)),
#  (198,
#   ('neal surface after ptk this study report the using of wavefront guided photorefractive keratectomy',
#    1)),
#  (199,
#   ('on the safety and efficacy of laser in situ keratomileusis lasik and photorefractive keratectomy',
#    1)),
#  (200,
#   ('ostoperatively except cycloplegic refractive fu included examinations at 1 days lasik to 5 days',
#    1)),
#  (201,
#   ('perimental replicates n = 3 and two technical duplicates chemical structures of a pranlukast',
#    1)),
#  (202,
#   ('pm there were no significant different in the activity of the other enzymes phosphoribulokinase',
#    1)),
#  (203,
#   ('stricted to the residual stromal bed postoperative refractive changes correlate with changes in st',
#    1)),
#  (204,
#   ('study the effects of endothelin 1 et1 on corneal wound healing after photorefractive keratectomy',
#    1)),
#  (205,
#   ('t protein cp12 forms a multienzyme complex with the calvin benson cycle enzymes phosphoribulokinase',
#    1)),
#  (206,
#   ('the two e coli chaperones groel and groes cells extraction for analysis of phosphoribulokinase',
#    1)),
#  (207,
#   ('to reflect the improvements in surface ablation from the early days of photorefractive keratectomy',
#    1)),
#  (208,
#   ('two enzymes glyceraldehyde 3 phosphate dehydrogenase gapdh ec 1 2 1 13 and phosphoribulokinase',
#    1)),
#  (209,
#   ('v5 smad7 delivered to the corneal stroma can inhibit corneal haze post photorefractive keratectomy',
#    1)),
#  (210,
#   ('y ophthalmology also it is one of the most important complications of photorefractive keratectomy',
#    1)),
#  (211,
#   ('yopia quantification of smooth muscle actin sma + cells 4 weeks after photorefractive keratectomy',
#    1)),
#  (212,
#   ('activity protein kinase mapk b src family kinase sfk c protein kinase c related kinase',
#    1)),
#  (213,
#   ('an inhibitor binding site the results lead to the identification of two lead compounds pranlukast',
#    1)),
#  (214,
#   ('coding cp12 interacts protein the calvin cycle genes encoding gapdh gapa and gapb and prk',
#    1)),
#  (215,
#   ('cp12 arabidopsis genes together with the genes encoding plastid gapdh gapa 1 and gapb prk',
#    1)),
#  (216,
#   ('ed as a naive control haze in rabbit corneas was produced by performing photorefractive keratectomy',
#    1)),
#  (217,
#   ('er than 12 years have refractive errors 1 laser eye surgery such as photorefractive keratectomy',
#    1)),
#  (218,
#   ('es from 7 post laser in situ keratomileusis lasik patients and 1 post photorefractive keratectomy',
#    1)),
#  (219,
#   ('ile we know much about the impact of anterior corneal surgery such as photorefractive keratectomy',
#    1)),
#  (220,
#   ('l a c protein atp synthase a ribulose phosphate 3 epimerase rpe and a phosphoribulokinase',
#    1)),
#  (221,
#   ('n well described that trx f and m reductively activity the cb cycle enzymes phosphoribulokinase',
#    1)),
#  (222,
#   ('otein cp12 has been shown to regulate the activity of two calvin cycle enzymes phosphoribulokinase',
#    1)),
#  (223,
#   ('rneas at two months three months and four months after 9 diopter d photorefractive keratectomy',
#    1)),
#  (224,
#   ('se increased 7 15 and 5 8 fold respectively whereas rubisco small chain 1a phosphoribulokinase',
#    1)),
#  (225,
#   ('th rubp to yield 3 phosphoglycerate 3 pga from which rubp is regenerated 3 phosphoribulokinase',
#    1)),
#  (226,
#   ('the aim of this study was to compare the results of excimer laser photorefractive keratectomy',
#    1)),
#  (227,
#   ('vdurd a high selective and potent anti herpes agent is phosphorylated by primary rabbit kidney',
#    1)),
#  (228,
#   ('xperiments are shown fixation of co 2 via the calvin cycle enzymes rubisco and phosphoribulokinase',
#    1)),
#  (229,
#   ('eriments are shown in appendix fig s8a and b these results demonstrate the potency of pranlukast',
#    1)),
#  (230,
#   ('ffering only in a few step from the cbb cycle also employs rubisco along with phosphoribulokinase',
#    1)),
#  (231,
#   ('he mt argj activity in vitro appendix table s4 a b chemical structures of a pranlukast',
#    1)),
#  (232,
#   ('isolated from higher plant it forms part of a core complex of two dimers of phosphoribulokinase',
#    1)),
#  (233,
#   ('lized in the chloroplast acting as a linker in the core complex of cbc protein phosphoribulokinase',
#    1)),
#  (234,
#   ('pα and tpβ forms functional signaling complex with member of the protein kinase c related kinase',
#    1)),
#  (235,
#   ('s possess phosphorylated forms of tpa insensitive atypical isotypes as well as a pkc related kinase',
#    1)),
#  (236,
#   ('t argj activity the activity based screened led to the discovery of two potent compounds pranlukast',
#    1)),
#  (237,
#   ('tatistics was calculated using one side anova following by tukey s hsd ribulose 5 phosphate kinase',
#    1)),
#  (238,
#   ('troma human corneas with severe late haze at one and a half years after photorefractive keratectomy',
#    1)),
#  (239,
#   ('ure of the ebm in rabbit corneas with and without corneal fibrosis in a photorefractive keratectomy',
#    1)),
#  (240,
#   ('ury was performing in one corneas of each rabbit by applying a 9 diopter photorefractive keratectomy',
#    1)),
#  (241,
#   ('ves different from cp12 and plant cbsx it does not forms a ternary complex with phosphoribulokinase',
#    1)),
#  (242,
#   ('as that are unwounded and at 2 weeks and 1 months after 9 diopter d photorefractive keratectomy',
#    1)),
#  (243,
#   ('cysteine rich protein to the s locus receptor kinase srk a member of the plant receptor kinase',
#    1)),
#  (244,
#   ('h isoforms of the two kinase ribosomal s6 protein kinase rsk and protein kinase c related kinase',
#    1)),
#  (245,
#   ('ndations confocal biomicroscopy images from wk 1 to 4 in a d − 9 0d photorefractive keratectomy',
#    1)),
#  (246,
#   ('t vorinostat 25 μm collected a b 6 hours or c d 4 weeks after photorefractive keratectomy',
#    1)),
#  (247,
#   ('viously 6 to test this rabbit corneas underwent − 9 0 diopter − 9 0d photorefractive keratectomy',
#    1)),
#  (248,
#   ('6 + 1 70 d and a mean hyperopic cylinder of 2 20 + 0 80 d underwent photorefractive keratectomy',
#    1)),
#  (249,
#   ('e time point 10 s data are mean ± sd from n ≥ 5 determinations b ribulose 5 phosphate kinase',
#    1)),
#  (250, ('ablation', 0.0)),
#  (251, ('at1g32060', 0.0)),
#  (252, ('days', 0.0)),
#  (253, ('keratectomy', 0.0)),
#  (254, ('kidney', 0.0)),
#  (255, ('protein', 0.0)),
#  (256, ('st', 0.0)),
#  (257, ('1 phosphoribulokinase', 0.0)),
#  (258, ('1a phosphoribulokinase', 0.0)),
#  (259, ('3 phosphoribulokinase', 0.0)),
#  (260, ('5 days', 0.0)),
#  (261, ('a phosphoribulokinase', 0.0)),
#  (262, ('a pranlukast', 0.0)),
#  (263, ('activase phosphoribulokinase', 0.0)),
#  (264, ('and at1g32060', 0.0)),
#  (265, ('and prk', 0.0)),
#  (266, ('apx phosphoribulokinase', 0.0)),
#  (267, ('atpase phosphoribulokinase', 0.0)),
#  (268, ('drugs pranlukast', 0.0)),
#  (269, ('gapb prk', 0.0)),
#  (270, ('heterologous phosphoribulokinase', 0.0)),
#  (271, ('identified pranlukast', 0.0)),
#  (272, ('in st', 0.0)),
#  (273, ('included phosphoribulokinase', 0.0)),
#  (274, ('of pranlukast', 0.0)),
#  (275, ('oleracea phosphoribulokinase', 0.0)),
#  (276, ('one phosphoribulokinase', 0.0)),
#  (277, ('phosphate kinase', 0.0)),
#  (278, ('protein phosphoribulokinase', 0.0)),
#  (279, ('rabbit kidney', 0.0)),
#  (280, ('rap phosphoribulokinase', 0.0)),
#  (281, ('receptor kinase', 0.0)),
#  (282, ('related protein', 0.0)),
#  (283, ('report pranlukast', 0.0)),
#  (284, ('saturated phosphoribulokinase', 0.0)),
#  (285, ('sphaeroides phosphoribulokinase', 0.0)),
#  (286, ('surface ablation', 0.0)),
#  (287, ('the phosphoribulokinase', 0.0)),
#  (288, ('were phosphoribulokinase', 0.0)),
#  (289, ('00d photorefractive keratectomy', 0.0)),
#  (290, ('0d photorefractive keratectomy', 0.0)),
#  (291, ('13 and phosphoribulokinase', 0.0)),
#  (292, ('2 saturated phosphoribulokinase', 0.0)),
#  (293, ('3d photorefractive keratectomy', 0.0)),
#  (294, ('5 phosphate kinase', 0.0)),
#  (295, ('a photorefractive keratectomy', 0.0)),
#  (296, ('activity of phosphoribulokinase', 0.0)),
#  (297, ('along with phosphoribulokinase', 0.0)),
#  (298, ('analysis of phosphoribulokinase', 0.0)),
#  (299, ('and a phosphoribulokinase', 0.0)),
#  (300, ('and gapb prk', 0.0)),
#  (301, ('another one phosphoribulokinase', 0.0)),
#  (302, ('approved drugs pranlukast', 0.0)),
#  (303, ('as photorefractive keratectomy', 0.0)),
#  (304, ('assisted photorefractive keratectomy', 0.0)),
#  (305, ('australia photorefractive keratectomy', 0.0)),
#  (306, ('by atpase phosphoribulokinase', 0.0)),
#  (307, ('by photorefractive keratectomy', 0.0)),
#  (308, ('c related kinase', 0.0)),
#  (309, ('c related protein', 0.0)),
#  (310, ('cb cycle phosphoribulokinase', 0.0)),
#  (311, ('cbc protein phosphoribulokinase', 0.0)),
#  (312, ('chain 1a phosphoribulokinase', 0.0)),
#  (313, ('changes in st', 0.0)),
#  (314, ('complex included phosphoribulokinase', 0.0)),
#  (315, ('complex with phosphoribulokinase', 0.0)),
#  (316, ('consisting of phosphoribulokinase', 0.0)),
#  (317, ('correction photorefractive keratectomy', 0.0)),
#  (318, ('custom photorefractive keratectomy', 0.0)),
#  (319, ('cyclophilin and at1g32060', 0.0)),
#  (320, ('d photorefractive keratectomy', 0.0)),
#  (321, ('deactivation of phosphoribulokinase', 0.0)),
#  (322, ('dimers of phosphoribulokinase', 0.0)),
#  (323, ('enzymes were phosphoribulokinase', 0.0)),
#  (324, ('example photorefractive keratectomy', 0.0)),
#  (325, ('fixation and phosphoribulokinase', 0.0)),
#  (326, ('gapb and prk', 0.0)),
#  (327, ('gapdh and phosphoribulokinase', 0.0)),
#  (328, ('guided photorefractive keratectomy', 0.0)),
#  (329, ('have identified pranlukast', 0.0)),
#  (330, ('hyperopic photorefractive keratectomy', 0.0)),
#  (331, ('in photorefractive keratectomy', 0.0)),
#  (332, ('in the phosphoribulokinase', 0.0)),
#  (333, ('isolated photorefractive keratectomy', 0.0)),
#  (334, ('laser photorefractive keratectomy', 0.0)),
#  (335, ('laser surface ablation', 0.0)),
#  (336, ('lead compounds pranlukast', 0.0)),
#  (337, ('like photorefractive keratectomy', 0.0)),
#  (338, ('of a pranlukast', 0.0)),
#  (339, ('oligomerized with phosphoribulokinase', 0.0)),
#  (340, ('or photorefractive keratectomy', 0.0)),
#  (341, ('other enzymes phosphoribulokinase', 0.0)),
#  (342, ('performing photorefractive keratectomy', 0.0)),
#  (343, ('peroxidase apx phosphoribulokinase', 0.0)),
#  (344, ('pkc related kinase', 0.0)),
#  (345, ('plant receptor kinase', 0.0)),
#  (346, ('potency of pranlukast', 0.0)),
#  (347, ('potent compounds pranlukast', 0.0)),
#  (348, ('pri and phosphoribulokinase', 0.0)),
#  (349, ('primary rabbit kidney', 0.0)),
#  (350, ('profile photorefractive keratectomy', 0.0)),
#  (351, ('psbp and phosphoribulokinase', 0.0)),
#  (352, ('receiving photorefractive keratectomy', 0.0)),
#  (353, ('regenerated 3 phosphoribulokinase', 0.0)),
#  (354, ('region of phosphoribulokinase', 0.0)),
#  (355, ('regulate of phosphoribulokinase', 0.0)),
#  (356, ('report photorefractive keratectomy', 0.0)),
#  (357, ('ric2 rap phosphoribulokinase', 0.0)),
#  (358, ('rubisco activase phosphoribulokinase', 0.0)),
#  (359, ('sbpase and phosphoribulokinase', 0.0)),
#  (360, ('scrape photorefractive keratectomy', 0.0)),
#  (361, ('spinacia oleracea phosphoribulokinase', 0.0)),
#  (362, ('standard photorefractive keratectomy', 0.0)),
#  (363, ('subepithelial photorefractive keratectomy', 0.0)),
#  (364, ('table 1 phosphoribulokinase', 0.0)),
#  (365, ('test with phosphoribulokinase', 0.0)),
#  (366, ('to 5 days', 0.0)),
#  (367, ('to photorefractive keratectomy', 0.0)),
#  (368, ('usa photorefractive keratectomy', 0.0)),
#  (369, ('versus photorefractive keratectomy', 0.0)),
#  (370, ('we report pranlukast', 0.0)),
#  (371, ('1 00d photorefractive keratectomy', 0.0)),
#  (372, ('1 13 and phosphoribulokinase', 0.0)),
#  (373, ('1 and gapb prk', 0.0)),
#  (374, ('1 post photorefractive keratectomy', 0.0)),
#  (375, ('1990s transepithelial photorefractive keratectomy', 0.0)),
#  (376, ('2 fixation and phosphoribulokinase', 0.0)),
#  (377, ('9 0d photorefractive keratectomy', 0.0)),
#  (378, ('a pkc related kinase', 0.0)),
#  (379, ('after hyperopic photorefractive keratectomy', 0.0)),
#  (380, ('alcohol assisted photorefractive keratectomy', 0.0)),
#  (381, ('and gapb and prk', 0.0)),
#  (382, ('ascorbate peroxidase apx phosphoribulokinase', 0.0)),
#  (383, ('aspheric profile photorefractive keratectomy', 0.0)),
#  (384, ('at2g29960 cyclophilin and at1g32060', 0.0)),
#  (385, ('benson cb cycle phosphoribulokinase', 0.0)),
#  (386, ('benson cycle enzymes phosphoribulokinase', 0.0)),
#  (387, ('beta after photorefractive keratectomy', 0.0)),
#  (388, ('bisphosphatase sbpase and phosphoribulokinase', 0.0)),
#  (389, ('by performing photorefractive keratectomy', 0.0)),
#  (390, ('by primary rabbit kidney', 0.0)),
#  (391, ('carboxylase rubisco and phosphoribulokinase', 0.0)),
#  (392, ('catalyzed by atpase phosphoribulokinase', 0.0)),
#  (393, ('cb cycle enzymes phosphoribulokinase', 0.0)),
#  (394, ('cells following photorefractive keratectomy', 0.0)),
#  (395, ('challenge after photorefractive keratectomy', 0.0)),
#  (396, ('co 2 saturated phosphoribulokinase', 0.0)),
#  (397, ('complications of photorefractive keratectomy', 0.0)),
#  (398, ('corneas after photorefractive keratectomy', 0.0)),
#  (399, ('created with photorefractive keratectomy', 0.0)),
#  (400, ('cyanobacterial calvin cycle phosphoribulokinase', 0.0)),
#  (401, ('d underwent photorefractive keratectomy', 0.0)),
#  (402, ('days of photorefractive keratectomy', 0.0)),
#  (403, ('dehydrogenase gapdh and phosphoribulokinase', 0.0)),
#  (404, ('diopter 9d photorefractive keratectomy', 0.0)),
#  (405, ('diopter d photorefractive keratectomy', 0.0)),
#  (406, ('embedded in the phosphoribulokinase', 0.0)),
#  (407, ('enzymes rubisco and phosphoribulokinase', 0.0)),
#  (408, ('epithelial scrape photorefractive keratectomy', 0.0)),
#  (409, ('excimer laser surface ablation', 0.0)),
#  (410, ('fda approved drugs pranlukast', 0.0)),
#  (411, ('fibroblasts after photorefractive keratectomy', 0.0)),
#  (412, ('for analysis of phosphoribulokinase', 0.0)),
#  (413, ('for example photorefractive keratectomy', 0.0)),
#  (414, ('functional following photorefractive keratectomy', 0.0)),
#  (415, ('had 9d photorefractive keratectomy', 0.0)),
#  (416, ('haze following photorefractive keratectomy', 0.0)),
#  (417, ('haze post photorefractive keratectomy', 0.0)),
#  (418, ('high correction photorefractive keratectomy', 0.0)),
#  (419, ('high diopter photorefractive keratectomy', 0.0)),
#  (420, ('hypertension after photorefractive keratectomy', 0.0)),
#  (421, ('ii psbp and phosphoribulokinase', 0.0)),
#  (422, ('in isolated photorefractive keratectomy', 0.0)),
#  (423, ('inc custom photorefractive keratectomy', 0.0)),
#  (424, ('induced by photorefractive keratectomy', 0.0)),
#  (425, ('interest in photorefractive keratectomy', 0.0)),
#  (426, ('introduction of photorefractive keratectomy', 0.0)),
#  (427, ('is oligomerized with phosphoribulokinase', 0.0)),
#  (428, ('is regenerated 3 phosphoribulokinase', 0.0)),
#  (429, ('kda consisting of phosphoribulokinase', 0.0)),
#  (430, ('kinase c related kinase', 0.0)),
#  (431, ('kinase c related protein', 0.0)),
#  (432, ('lack another one phosphoribulokinase', 0.0)),
#  (433, ('lasek versus photorefractive keratectomy', 0.0)),
#  (434, ('laser myopic photorefractive keratectomy', 0.0)),
#  (435, ('lasik to 5 days', 0.0)),
#  (436, ('multiprotein complex included phosphoribulokinase', 0.0)),
#  (437, ('of a heterologous phosphoribulokinase', 0.0)),
#  (438, ('of cbc protein phosphoribulokinase', 0.0)),
#  (439, ('or subepithelial photorefractive keratectomy', 0.0)),
#  (440, ('outcomes of photorefractive keratectomy', 0.0)),
#  (441, ('oxygenase rubisco and phosphoribulokinase', 0.0)),
#  (442, ('pathogenesis we report pranlukast', 0.0)),
#  (443, ('patients receiving photorefractive keratectomy', 0.0)),
#  (444, ('pen after photorefractive keratectomy', 0.0)),
#  (445, ('phosphoriboseisomerase pri and phosphoribulokinase', 0.0)),
#  (446, ('predictability of photorefractive keratectomy', 0.0)),
#  (447, ('procedures like photorefractive keratectomy', 0.0)),
#  (448, ('protein ric2 rap phosphoribulokinase', 0.0)),
#  (449, ('ptk myopic photorefractive keratectomy', 0.0)),
#  (450, ('randomized to photorefractive keratectomy', 0.0)),
#  (451, ('redox regulate of phosphoribulokinase', 0.0)),
#  (452, ('results after photorefractive keratectomy', 0.0)),
#  (453, ('results of photorefractive keratectomy', 0.0)),
#  (454, ('rigorously test with phosphoribulokinase', 0.0)),
#  (455, ('rk and photorefractive keratectomy', 0.0)),
#  (456, ('rpe and a phosphoribulokinase', 0.0)),
#  (457, ('rubisco along with phosphoribulokinase', 0.0)),
#  (458, ('rubisco rubisco activase phosphoribulokinase', 0.0)),
#  (459, ('safety of photorefractive keratectomy', 0.0)),
#  (460, ('samples table 1 phosphoribulokinase', 0.0)),
#  (461, ('scrape and photorefractive keratectomy', 0.0)),
#  (462, ('small chain 1a phosphoribulokinase', 0.0)),
#  (463, ('smile 3d photorefractive keratectomy', 0.0)),
#  (464, ('smithfield australia photorefractive keratectomy', 0.0)),
#  (465, ('structures of a pranlukast', 0.0)),
#  (466, ('terminal region of phosphoribulokinase', 0.0)),
#  (467, ('ternary complex with phosphoribulokinase', 0.0)),
#  (468, ('that underwent photorefractive keratectomy', 0.0)),
#  (469, ('the calvin cycle phosphoribulokinase', 0.0)),
#  (470, ('the other enzymes phosphoribulokinase', 0.0)),
#  (471, ('the plant receptor kinase', 0.0)),
#  (472, ('the potency of pranlukast', 0.0)),
#  (473, ('the rhodobacter sphaeroides phosphoribulokinase', 0.0)),
#  (474, ('the spinacia oleracea phosphoribulokinase', 0.0)),
#  (475, ('these enzymes were phosphoribulokinase', 0.0)),
#  (476, ('thickness after photorefractive keratectomy', 0.0)),
#  (477, ('thioredoxin deactivation of phosphoribulokinase', 0.0)),
#  (478, ('two dimers of phosphoribulokinase', 0.0)),
#  (479, ('two lead compounds pranlukast', 0.0)),
#  (480, ('two potent compounds pranlukast', 0.0)),
#  (481, ('tx usa photorefractive keratectomy', 0.0)),
#  (482, ('using after photorefractive keratectomy', 0.0)),
#  (483, ('using of photorefractive keratectomy', 0.0)),
#  (484, ('versus standard photorefractive keratectomy', 0.0)),
#  (485, ('we have identified pranlukast', 0.0)),
#  (486, ('weeks after photorefractive keratectomy', 0.0)),
#  (487, ('with changes in st', 0.0)),
#  (488, ('with transepithelial photorefractive keratectomy', 0.0)),
#  (489, ('years after photorefractive keratectomy', 0.0)),
#  (490, ('2 1 13 and phosphoribulokinase', 0.0)),
#  (491, ('2012 these enzymes were phosphoribulokinase', 0.0)),
#  (492, ('2013 the activity of phosphoribulokinase', 0.0)),
#  (493, ('520 kda consisting of phosphoribulokinase', 0.0)),
#  (494, ('556 fda approved drugs pranlukast', 0.0)),
#  (495, ('7 bisphosphatase sbpase and phosphoribulokinase', 0.0)),
#  (496, ('80 d underwent photorefractive keratectomy', 0.0)),
#  (497, ('9 diopter d photorefractive keratectomy', 0.0)),
#  (498, ('a 9 diopter photorefractive keratectomy', 0.0)),
#  (499, ('a ternary complex with phosphoribulokinase', 0.0)),
#  (500, ('above 1 00d photorefractive keratectomy', 0.0)),
#  (501, ('after excimer laser photorefractive keratectomy', 0.0)),
#  (502, ('and 1 post photorefractive keratectomy', 0.0)),
#  (503, ('and 9 diopter photorefractive keratectomy', 0.0)),
#  (504, ('and predictability of photorefractive keratectomy', 0.0)),
#  (505, ('and safety of photorefractive keratectomy', 0.0)),
#  (506, ('and treated with photorefractive keratectomy', 0.0)),
#  (507, ('apparently lack another one phosphoribulokinase', 0.0)),
#  (508, ('as a pkc related kinase', 0.0)),
#  (509, ('b ribulose 5 phosphate kinase', 0.0)),
#  (510, ('barrier functional following photorefractive keratectomy', 0.0)),
#  (511, ('been rigorously test with phosphoribulokinase', 0.0)),
#  (512, ('bisphosphate carboxylase rubisco and phosphoribulokinase', 0.0)),
#  (513, ('bisphosphatase ribulose 5 phosphate kinase', 0.0)),
#  (514, ('by wavefront guided photorefractive keratectomy', 0.0)),
#  (515, ('calvin benson cb cycle phosphoribulokinase', 0.0)),
#  (516, ('calvin benson cycle enzymes phosphoribulokinase', 0.0)),
#  (517, ('carboxylase oxygenase rubisco and phosphoribulokinase', 0.0)),
#  (518, ('changes induced by photorefractive keratectomy', 0.0)),
#  (519, ('characteristically co 2 saturated phosphoribulokinase', 0.0)),
#  (520, ('chloroplast is oligomerized with phosphoribulokinase', 0.0)),
#  (521, ('co 2 fixation and phosphoribulokinase', 0.0)),
#  (522, ('complex of cbc protein phosphoribulokinase', 0.0)),
#  (523, ('considered for example photorefractive keratectomy', 0.0)),
#  (524, ('corneal cells following photorefractive keratectomy', 0.0)),
#  (525, ('corneal haze after photorefractive keratectomy', 0.0)),
#  (526, ('corneal haze following photorefractive keratectomy', 0.0)),
#  (527, ('corneal haze post photorefractive keratectomy', 0.0)),
#  (528, ('correlate with changes in st', 0.0)),
#  (529, ('culture samples table 1 phosphoribulokinase', 0.0)),
#  (530, ('cycle enzymes rubisco and phosphoribulokinase', 0.0)),
#  (531, ('cycle multiprotein complex included phosphoribulokinase', 0.0)),
#  (532, ('days lasik to 5 days', 0.0)),
#  (533, ('demonstrate the potency of pranlukast', 0.0)),
#  (534, ('early days of photorefractive keratectomy', 0.0)),
#  (535, ('ef at2g29960 cyclophilin and at1g32060', 0.0)),
#  (536, ('employs rubisco along with phosphoribulokinase', 0.0)),
#  (537, ('enzymes phosphoriboseisomerase pri and phosphoribulokinase', 0.0)),
#  (538, ('epimerase rpe and a phosphoribulokinase', 0.0)),
#  (539, ('epithelial healing after photorefractive keratectomy', 0.0)),
#  (540, ('epithelial scrape and photorefractive keratectomy', 0.0)),
#  (541, ('established high diopter photorefractive keratectomy', 0.0)),
#  (542, ('excimer laser myopic photorefractive keratectomy', 0.0)),
#  (543, ('expression of a heterologous phosphoribulokinase', 0.0)),
#  (544, ('extraction for analysis of phosphoribulokinase', 0.0)),
#  (545, ('eye treated with photorefractive keratectomy', 0.0)),
#  (546, ('fibrosis in a photorefractive keratectomy', 0.0)),
#  (547, ('fnr ascorbate peroxidase apx phosphoribulokinase', 0.0)),
#  (548, ('following excimer laser photorefractive keratectomy', 0.0)),
#  (549, ('formation in a photorefractive keratectomy', 0.0)),
#  (550, ('g rubisco rubisco activase phosphoribulokinase', 0.0)),
#  (551, ('gapa 1 and gapb prk', 0.0)),
#  (552, ('gapa and gapb and prk', 0.0)),
#  (553, ('gapdh embedded in the phosphoribulokinase', 0.0)),
#  (554, ('generating high correction photorefractive keratectomy', 0.0)),
#  (555, ('glycerol the spinacia oleracea phosphoribulokinase', 0.0)),
#  (556, ('half years after photorefractive keratectomy', 0.0)),
#  (557, ('have wavefront guided photorefractive keratectomy', 0.0)),
#  (558, ('high diopter 9d photorefractive keratectomy', 0.0)),
#  (559, ('hsd ribulose 5 phosphate kinase', 0.0)),
#  (560, ('important complications of photorefractive keratectomy', 0.0)),
#  (561, ('keratectomy ptk myopic photorefractive keratectomy', 0.0)),
#  (562, ('keratomileusis lasek versus photorefractive keratectomy', 0.0)),
#  (563, ('keratomileusis lasik and photorefractive keratectomy', 0.0)),
#  (564, ('keratomileusis lasik or photorefractive keratectomy', 0.0)),
#  (565, ('keratotomy rk and photorefractive keratectomy', 0.0)),
#  (566, ('laboratories smithfield australia photorefractive keratectomy', 0.0)),
#  (567, ('lasek versus standard photorefractive keratectomy', 0.0)),
#  (568, ('late 1990s transepithelial photorefractive keratectomy', 0.0)),
#  (569, ('liver we have identified pranlukast', 0.0)),
#  (570, ('maintained in isolated photorefractive keratectomy', 0.0)),
#  (571, ('major challenge after photorefractive keratectomy', 0.0)),
#  (572, ('mtb pathogenesis we report pranlukast', 0.0)),
#  (573, ('n terminal region of phosphoribulokinase', 0.0)),
#  (574, ('non wavefront guided photorefractive keratectomy', 0.0)),
#  (575, ('occur after hyperopic photorefractive keratectomy', 0.0)),
#  (576, ('ocular hypertension after photorefractive keratectomy', 0.0)),
#  (577, ('of excimer laser photorefractive keratectomy', 0.0)),
#  (578, ('of fibroblasts after photorefractive keratectomy', 0.0)),
#  (579, ('of patients receiving photorefractive keratectomy', 0.0)),
#  (580, ('of redox regulate of phosphoribulokinase', 0.0)),
#  (581, ('of the calvin cycle phosphoribulokinase', 0.0)),
#  (582, ('of the other enzymes phosphoribulokinase', 0.0)),
#  (583, ('of the plant receptor kinase', 0.0)),
#  (584, ('of two dimers of phosphoribulokinase', 0.0)),
#  (585, ('of two lead compounds pranlukast', 0.0)),
#  (586, ('of two potent compounds pranlukast', 0.0)),
#  (587, ('of wavefront guided photorefractive keratectomy', 0.0)),
#  (588, ('patients randomized to photorefractive keratectomy', 0.0)),
#  (589, ('patients treated with photorefractive keratectomy', 0.0)),
#  (590, ('performing excimer laser surface ablation', 0.0)),
#  (591, ('phosphate dehydrogenase gapdh and phosphoribulokinase', 0.0)),
#  (592, ('phosphorylated by primary rabbit kidney', 0.0)),
#  (593, ('photosystem ii psbp and phosphoribulokinase', 0.0)),
#  (594, ('plant calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (595, ('practice excimer laser photorefractive keratectomy', 0.0)),
#  (596, ('procedures such as photorefractive keratectomy', 0.0)),
#  (597, ('produced by performing photorefractive keratectomy', 0.0)),
#  (598, ('proper thioredoxin deactivation of phosphoribulokinase', 0.0)),
#  (599, ('protein kinase c related protein', 0.0)),
#  (600, ('rabbit corneas after photorefractive keratectomy', 0.0)),
#  (601, ('rabbit that underwent photorefractive keratectomy', 0.0)),
#  (602, ('re smile 3d photorefractive keratectomy', 0.0)),
#  (603, ('reaction catalyzed by atpase phosphoribulokinase', 0.0)),
#  (604, ('related protein ric2 rap phosphoribulokinase', 0.0)),
#  (605, ('renewed interest in photorefractive keratectomy', 0.0)),
#  (606, ('routinely using after photorefractive keratectomy', 0.0)),
#  (607, ('rubisco small chain 1a phosphoribulokinase', 0.0)),
#  (608, ('rubp is regenerated 3 phosphoribulokinase', 0.0)),
#  (609, ('subepithelial haze after photorefractive keratectomy', 0.0)),
#  (610, ('sublayer thickness after photorefractive keratectomy', 0.0)),
#  (611, ('surgical procedures like photorefractive keratectomy', 0.0)),
#  (612, ('tgf beta after photorefractive keratectomy', 0.0)),
#  (613, ('that had 9d photorefractive keratectomy', 0.0)),
#  (614, ('the cb cycle enzymes phosphoribulokinase', 0.0)),
#  (615, ('the cyanobacterial calvin cycle phosphoribulokinase', 0.0)),
#  (616, ('the introduction of photorefractive keratectomy', 0.0)),
#  (617, ('the outcomes of photorefractive keratectomy', 0.0)),
#  (618, ('the results of photorefractive keratectomy', 0.0)),
#  (619, ('the using of photorefractive keratectomy', 0.0)),
#  (620, ('tono pen after photorefractive keratectomy', 0.0)),
#  (621, ('traditional epithelial scrape photorefractive keratectomy', 0.0)),
#  (622, ('trans or subepithelial photorefractive keratectomy', 0.0)),
#  (623, ('treated with transepithelial photorefractive keratectomy', 0.0)),
#  (624, ('two calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (625, ('tyrosine the activity of phosphoribulokinase', 0.0)),
#  (626, ('undergoing lasik and photorefractive keratectomy', 0.0)),
#  (627, ('visx inc custom photorefractive keratectomy', 0.0)),
#  (628, ('vivo in a photorefractive keratectomy', 0.0)),
#  (629, ('were treated with photorefractive keratectomy', 0.0)),
#  (630, ('with alcohol assisted photorefractive keratectomy', 0.0)),
#  (631, ('with aspheric profile photorefractive keratectomy', 0.0)),
#  (632, ('with lasik or photorefractive keratectomy', 0.0)),
#  (633, ('worth tx usa photorefractive keratectomy', 0.0)),
#  (634, ('wound created with photorefractive keratectomy', 0.0)),
#  (635, ('wound healing after photorefractive keratectomy', 0.0)),
#  (636, ('wound results after photorefractive keratectomy', 0.0)),
#  (637, ('0 80 d underwent photorefractive keratectomy', 0.0)),
#  (638, ('1 2 1 13 and phosphoribulokinase', 0.0)),
#  (639, ('1 556 fda approved drugs pranlukast', 0.0)),
#  (640, ('1 7 bisphosphatase sbpase and phosphoribulokinase', 0.0)),
#  (641, ('1 days lasik to 5 days', 0.0)),
#  (642, ('3 epimerase rpe and a phosphoribulokinase', 0.0)),
#  (643, ('3 phosphate dehydrogenase gapdh and phosphoribulokinase', 0.0)),
#  (644, ('3d re smile 3d photorefractive keratectomy', 0.0)),
#  (645, ('5 bisphosphate carboxylase rubisco and phosphoribulokinase', 0.0)),
#  (646, ('7 bisphosphatase ribulose 5 phosphate kinase', 0.0)),
#  (647, ('a half years after photorefractive keratectomy', 0.0)),
#  (648, ('a renewed interest in photorefractive keratectomy', 0.0)),
#  (649, ('activity of the other enzymes phosphoribulokinase', 0.0)),
#  (650, ('activity the cb cycle enzymes phosphoribulokinase', 0.0)),
#  (651, ('after 9 diopter d photorefractive keratectomy', 0.0)),
#  (652,
#   ('after traditional epithelial scrape photorefractive keratectomy', 0.0)),
#  (653, ('al 2012 these enzymes were phosphoribulokinase', 0.0)),
#  (654, ('al 2013 the activity of phosphoribulokinase', 0.0)),
#  (655, ('also employs rubisco along with phosphoribulokinase', 0.0)),
#  (656, ('an established high diopter photorefractive keratectomy', 0.0)),
# ...
#  (798, ('1 and maintained in isolated photorefractive keratectomy', 0.0)),
#  (799, ('12 compare patients treated with photorefractive keratectomy', 0.0)),
#  (800,
#   ('5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    0.0)),
#  (801, ('5 determinations b ribulose 5 phosphate kinase', 0.0)),
#  (802, ('a b chemical structures of a pranlukast', 0.0)),
#  (803, ('a d − 9 0d photorefractive keratectomy', 0.0)),
#  (804, ('a member of the plant receptor kinase', 0.0)),
#  (805,
#   ('ablation phototherapeutic keratectomy ptk myopic photorefractive keratectomy',
#    0.0)),
#  (806, ('actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060', 0.0)),
#  (807, ('activity of two calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (808, ('activity the calvin benson cycle enzymes phosphoribulokinase', 0.0)),
#  (809,
#   ('after opacity generating high correction photorefractive keratectomy',
#    0.0)),
#  (810, ('agent is phosphorylated by primary rabbit kidney', 0.0)),
#  (811, ('analyzed 3d re smile 3d photorefractive keratectomy', 0.0)),
#  (812, ('and a half years after photorefractive keratectomy', 0.0)),
#  (813, ('and eye have wavefront guided photorefractive keratectomy', 0.0)),
#  (814, ('and in vivo in a photorefractive keratectomy', 0.0)),
#  (815, ('anterior corneal surgery such as photorefractive keratectomy', 0.0)),
#  (816,
#   ('apoptosis of corneal cells following photorefractive keratectomy', 0.0)),
#  (817, ('as well as a pkc related kinase', 0.0)),
#  (818, ('at 1 days lasik to 5 days', 0.0)),
#  (819,
#   ('binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#    0.0)),
#  (820, ('by applying a 9 diopter photorefractive keratectomy', 0.0)),
#  (821, ('by product glycerol the spinacia oleracea phosphoribulokinase', 0.0)),
#  (822, ('c d 4 weeks after photorefractive keratectomy', 0.0)),
#  (823, ('can inhibit corneal haze post photorefractive keratectomy', 0.0)),
#  (824, ('clinical haze formation in a photorefractive keratectomy', 0.0)),
#  (825, ('combined radial keratotomy rk and photorefractive keratectomy', 0.0)),
#  (826, ('common and major challenge after photorefractive keratectomy', 0.0)),
#  (827,
#   ('complex approximately 520 kda consisting of phosphoribulokinase', 0.0)),
#  (828,
#   ('confirmed that expression of a heterologous phosphoribulokinase', 0.0)),
#  (829, ('core complex of two dimers of phosphoribulokinase', 0.0)),
#  (830, ('corneas using high diopter 9d photorefractive keratectomy', 0.0)),
#  (831,
#   ('corneas was produced by performing photorefractive keratectomy', 0.0)),
#  (832, ('cycle also employs rubisco along with phosphoribulokinase', 0.0)),
#  (833, ('cycle but apparently lack another one phosphoribulokinase', 0.0)),
#  (834, ('data since the introduction of photorefractive keratectomy', 0.0)),
#  (835,
#   ('development of subepithelial haze after photorefractive keratectomy',
#    0.0)),
#  (836, ('drops are routinely using after photorefractive keratectomy', 0.0)),
#  (837, ('ec 1 2 1 13 and phosphoribulokinase', 0.0)),
#  (838, ('encoding gapdh gapa and gapb and prk', 0.0)),
#  (839, ('enzymes e g rubisco rubisco activase phosphoribulokinase', 0.0)),
#  (840,
#   ('enzymes in the cyanobacterial calvin cycle phosphoribulokinase', 0.0)),
#  (841,
#   ('epithelial keratomileusis lasek versus standard photorefractive keratectomy',
#    0.0)),
#  (842,
#   ('epithelial scrape epithelial scrape and photorefractive keratectomy',
#    0.0)),
#  (843, ('et al 2012 these enzymes were phosphoribulokinase', 0.0)),
#  (844, ('et al 2013 the activity of phosphoribulokinase', 0.0)),
#  (845, ('expression of the calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (846, ('eye and eye treated with photorefractive keratectomy', 0.0)),
#  (847, ('factor beta tgf beta after photorefractive keratectomy', 0.0)),
#  (848,
#   ('flap was treated with transepithelial photorefractive keratectomy', 0.0)),
#  (849,
#   ('following corneal wound created with photorefractive keratectomy', 0.0)),
#  (850,
#   ('following refractive surgical procedures like photorefractive keratectomy',
#    0.0)),
#  (851, ('from the early days of photorefractive keratectomy', 0.0)),
#  (852, ('from which rubp is regenerated 3 phosphoribulokinase', 0.0)),
#  (853,
#   ('functional expression the calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (854, ('groes cells extraction for analysis of phosphoribulokinase', 0.0)),
#  (855, ('group stated above 1 00d photorefractive keratectomy', 0.0)),
#  (856, ('guided and non wavefront guided photorefractive keratectomy', 0.0)),
#  (857, ('has not been rigorously test with phosphoribulokinase', 0.0)),
#  (858,
#   ('hydrochloride troy laboratories smithfield australia photorefractive keratectomy',
#    0.0)),
#  (859, ('in an established high diopter photorefractive keratectomy', 0.0)),
#  (860,
#   ('in clinical practice excimer laser photorefractive keratectomy', 0.0)),
#  (861,
#   ('in corneal sublayer thickness after photorefractive keratectomy', 0.0)),
#  (862, ('in myopic patients randomized to photorefractive keratectomy', 0.0)),
#  (863, ('in patients undergoing lasik and photorefractive keratectomy', 0.0)),
#  (864, ('in the late 1990s transepithelial photorefractive keratectomy', 0.0)),
#  (865, ('in the rabbit corneas after photorefractive keratectomy', 0.0)),
#  (866, ('laboratories fort worth tx usa photorefractive keratectomy', 0.0)),
#  (867, ('lakes nj and 9 diopter photorefractive keratectomy', 0.0)),
#  (868, ('lasek and trans or subepithelial photorefractive keratectomy', 0.0)),
#  (869,
#   ('laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#    0.0)),
#  (870, ('laser eye surgery such as photorefractive keratectomy', 0.0)),
#  (871,
#   ('laser induced corneal haze following photorefractive keratectomy', 0.0)),
#  (872, ('lasik patients and 1 post photorefractive keratectomy', 0.0)),
#  (873, ('may influence corneal haze after photorefractive keratectomy', 0.0)),
#  (874,
#   ('mycobacterium tuberculosis mtb pathogenesis we report pranlukast', 0.0)),
#  (875,
#   ('nadp reductase fnr ascorbate peroxidase apx phosphoribulokinase', 0.0)),
#  (876, ('not forms a ternary complex with phosphoribulokinase', 0.0)),
#  (877, ('of 1 556 fda approved drugs pranlukast', 0.0)),
#  (878, ('of the proper thioredoxin deactivation of phosphoribulokinase', 0.0)),
#  (879, ('of the protein kinase c related kinase', 0.0)),
#  (880,
#   ('on corneal epithelial healing after photorefractive keratectomy', 0.0)),
#  (881, ('on corneal wound healing after photorefractive keratectomy', 0.0)),
#  (882, ('outcomes of excimer laser myopic photorefractive keratectomy', 0.0)),
#  (883,
#   ('patients treated with aspheric profile photorefractive keratectomy', 0.0)),
#  (884, ('patients who were treated with photorefractive keratectomy', 0.0)),
#  (885,
#   ('phenylalanine into tyrosine the activity of phosphoribulokinase', 0.0)),
#  (886, ('phosphate 3 epimerase rpe and a phosphoribulokinase', 0.0)),
#  (887,
#   ('phosphate dehydrogenase gapdh embedded in the phosphoribulokinase', 0.0)),
#  (888, ('plastid gapdh gapa 1 and gapb prk', 0.0)),
#  (889, ('polypeptide of photosystem ii psbp and phosphoribulokinase', 0.0)),
#  (890,
#   ('postoperative course after excimer laser photorefractive keratectomy',
#    0.0)),
#  (891,
#   ('product are characteristically co 2 saturated phosphoribulokinase', 0.0)),
#  (892, ('ptk following by wavefront guided photorefractive keratectomy', 0.0)),
#  (893,
#   ('quantitatively after traditional epithelial scrape photorefractive keratectomy',
#    0.0)),
#  (894, ('rabbit corneas that had 9d photorefractive keratectomy', 0.0)),
#  (895, ('reductively activity the cb cycle enzymes phosphoribulokinase', 0.0)),
#  (896, ('refractive changes correlate with changes in st', 0.0)),
#  (897,
#   ('refractive surgery and treated with photorefractive keratectomy', 0.0)),
#  (898, ('refractive surgery with lasik or photorefractive keratectomy', 0.0)),
#  (899,
#   ('refractive surgical procedures such as photorefractive keratectomy', 0.0)),
#  (900, ('regulate the protein kinase c related protein', 0.0)),
#  (901, ('report pain of patients receiving photorefractive keratectomy', 0.0)),
#  (902, ('report that performing excimer laser surface ablation', 0.0)),
#  (903,
#   ('respectively whereas rubisco small chain 1a phosphoribulokinase', 0.0)),
#  (904, ('responsible for co 2 fixation and phosphoribulokinase', 0.0)),
#  (905,
#   ('ribulose bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    0.0)),
#  (906, ('rsk and protein kinase c related kinase', 0.0)),
#  (907,
#   ('safety efficacy and predictability of photorefractive keratectomy', 0.0)),
#  (908,
#   ('sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase', 0.0)),
#  (909, ('semi continuous culture samples table 1 phosphoribulokinase', 0.0)),
#  (910, ('sfk c protein kinase c related kinase', 0.0)),
#  (911, ('should be considered for example photorefractive keratectomy', 0.0)),
#  (912, ('spleen and liver we have identified pranlukast', 0.0)),
#  (913,
#   ('steroid induced ocular hypertension after photorefractive keratectomy',
#    0.0)),
#  (914, ('stroma of rabbit that underwent photorefractive keratectomy', 0.0)),
#  (915, ('sus4 ras related protein ric2 rap phosphoribulokinase', 0.0)),
#  (916, ('technical duplicates chemical structures of a pranlukast', 0.0)),
#  (917, ('that can occur after hyperopic photorefractive keratectomy', 0.0)),
#  (918, ('the activity of the other enzymes phosphoribulokinase', 0.0)),
#  (919, ('the calvin cycle enzymes rubisco and phosphoribulokinase', 0.0)),
#  (920, ('the core complex of cbc protein phosphoribulokinase', 0.0)),
#  (921, ('the corneal wound results after photorefractive keratectomy', 0.0)),
#  (922, ('the discovery of two potent compounds pranlukast', 0.0)),
#  (923, ('the diversity of redox regulate of phosphoribulokinase', 0.0)),
#  (924, ('the higher plant calvin cycle enzymes phosphoribulokinase', 0.0)),
#  (925, ('the identification of two lead compounds pranlukast', 0.0)),
#  (926,
#   ('the most important complications of photorefractive keratectomy', 0.0)),
#  (927,
#   ('the proliferation of fibroblasts after photorefractive keratectomy', 0.0)),
#  (928, ('the results of excimer laser photorefractive keratectomy', 0.0)),
#  (929, ('the stromal reaction catalyzed by atpase phosphoribulokinase', 0.0)),
#  (930, ('the using of wavefront guided photorefractive keratectomy', 0.0)),
#  (931, ('these results demonstrate the potency of pranlukast', 0.0)),
#  (932, ('to a renewed interest in photorefractive keratectomy', 0.0)),
#  (933, ('to optical changes induced by photorefractive keratectomy', 0.0)),
#  (934, ('tonometer and tono pen after photorefractive keratectomy', 0.0)),
#  (935,
#   ('topical steroid following excimer laser photorefractive keratectomy',
#    0.0)),
#  (936,
#   ('transprk compare with alcohol assisted photorefractive keratectomy', 0.0)),
#  (937, ('tukey s hsd ribulose 5 phosphate kinase', 0.0)),
#  (938, ('two enzymes of the calvin cycle phosphoribulokinase', 0.0)),
#  (939, ('visx s4 visx inc custom photorefractive keratectomy', 0.0)),
#  (940, ('which in chloroplast is oligomerized with phosphoribulokinase', 0.0)),
#  (941, ('with the calvin benson cb cycle phosphoribulokinase', 0.0)),
#  (942, ('with the calvin benson cycle enzymes phosphoribulokinase', 0.0)),
#  (943, ('without corneal fibrosis in a photorefractive keratectomy', 0.0)),
#  (944,
#   ('1 5 bisphosphate carboxylase oxygenase rubisco and phosphoribulokinase',
#    0.0)),
#  (945, ('1 laser eye surgery such as photorefractive keratectomy', 0.0)),
#  (946, ('1 months after 9 diopter d photorefractive keratectomy', 0.0)),
#  (947, ('20 + 0 80 d underwent photorefractive keratectomy', 0.0)),
#  (948,
#   ('3 in the late 1990s transepithelial photorefractive keratectomy', 0.0)),
#  (949,
#   ('3 phosphate dehydrogenase gapdh embedded in the phosphoribulokinase',
#    0.0)),
#  (950, ('4 sus4 ras related protein ric2 rap phosphoribulokinase', 0.0)),
#  (951,
#   ('42 in clinical practice excimer laser photorefractive keratectomy', 0.0)),
#  (952, ('9 0 diopter − 9 0d photorefractive keratectomy', 0.0)),
#  (953,
#   ('a common and major challenge after photorefractive keratectomy', 0.0)),
#  (954, ('a core complex of two dimers of phosphoribulokinase', 0.0)),
#  (955,
#   ('aberrations in myopic patients randomized to photorefractive keratectomy',
#    0.0)),
#  (956, ('ablation from the early days of photorefractive keratectomy', 0.0)),
#  (957,
#   ('abrogated clinical haze formation in a photorefractive keratectomy', 0.0)),
#  (958,
#   ('after epithelial scrape epithelial scrape and photorefractive keratectomy',
#    0.0)),
#  (959,
#   ('after laser epithelial keratomileusis lasek versus photorefractive keratectomy',
#    0.0)),
#  (960,
#   ('alcon laboratories fort worth tx usa photorefractive keratectomy', 0.0)),
#  (961,
#   ('and apoptosis of corneal cells following photorefractive keratectomy',
#    0.0)),
#  (962,
#   ('and groes cells extraction for analysis of phosphoribulokinase', 0.0)),
#  (963,
#   ('and patients who were treated with photorefractive keratectomy', 0.0)),
#  (964,
#   ('and quantitatively after traditional epithelial scrape photorefractive keratectomy',
#    0.0)),
#  (965,
#   ('and report pain of patients receiving photorefractive keratectomy', 0.0)),
#  (966,
#   ('and the proliferation of fibroblasts after photorefractive keratectomy',
#    0.0)),
#  (967, ('and without corneal fibrosis in a photorefractive keratectomy', 0.0)),
#  (968,
#   ('assisted in situ keratomileusis lasik and photorefractive keratectomy',
#    0.0)),
#  (969,
#   ('assisted in situ keratomileusis lasik or photorefractive keratectomy',
#    0.0)),
#  (970,
#   ('at3g18780 actin2 at1g07940 ef at2g29960 cyclophilin and at1g32060', 0.0)),
#  (971, ('b these results demonstrate the potency of pranlukast', 0.0)),
#  (972,
#   ('benson cycle but apparently lack another one phosphoribulokinase', 0.0)),
#  (973,
#   ('between glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    0.0)),
#  (974,
#   ('bioethanol product are characteristically co 2 saturated phosphoribulokinase',
#    0.0)),
#  (975, ('buchanan et al 2012 these enzymes were phosphoribulokinase', 0.0)),
#  (976, ('by tukey s hsd ribulose 5 phosphate kinase', 0.0)),
#  (977, ('carbon with the calvin benson cb cycle phosphoribulokinase', 0.0)),
#  (978,
#   ('cat following corneal wound created with photorefractive keratectomy',
#    0.0)),
#  (979, ('cbb cycle also employs rubisco along with phosphoribulokinase', 0.0)),
#  (980,
#   ('changes in corneal sublayer thickness after photorefractive keratectomy',
#    0.0)),
#  (981,
#   ('co binding the enzymes phosphoriboseisomerase pri and phosphoribulokinase',
#    0.0)),
#  (982,
#   ('compare the efficacy and safety of photorefractive keratectomy', 0.0)),
#  (983,
#   ('compare the results of excimer laser photorefractive keratectomy', 0.0)),
#  (984,
#   ('complex with the calvin benson cycle enzymes phosphoribulokinase', 0.0)),
#  (985, ('control eye and eye treated with photorefractive keratectomy', 0.0)),
#  (986,
#   ('corneal refractive surgery and treated with photorefractive keratectomy',
#    0.0)),
#  (987,
#   ('corneal stroma of rabbit that underwent photorefractive keratectomy',
#    0.0)),
#  (988,
#   ('corticosteroid drops are routinely using after photorefractive keratectomy',
#    0.0)),
#  (989,
#   ('cycle enzymes e g rubisco rubisco activase phosphoribulokinase', 0.0)),
#  (990,
#   ('dependent glyceraldehyde 3 phosphate dehydrogenase gapdh and phosphoribulokinase',
#    0.0)),
#  (991, ('does not forms a ternary complex with phosphoribulokinase', 0.0)),
#  (992,
#   ('drops on corneal epithelial healing after photorefractive keratectomy',
#    0.0)),
#  (993,
#   ('effects the corneal wound results after photorefractive keratectomy',
#    0.0)),
#  (994, ('encoding plastid gapdh gapa 1 and gapb prk', 0.0)),
#  (995,
#   ('et1 on corneal wound healing after photorefractive keratectomy', 0.0)),
#  (996,
#   ('evaluate the efficacy and safety of photorefractive keratectomy', 0.0)),
#  (997, ('examinations at 1 days lasik to 5 days', 0.0)),
#  (998,
#   ('f activity the calvin benson cycle enzymes phosphoribulokinase', 0.0)),
#  (999,
#   ('fbpase sedoheptulose 1 7 bisphosphatase sbpase and phosphoribulokinase',
#    0.0)),
#  ...]

# %%
longforms0.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [20, 21])

# %%
longforms = longforms0

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('photorefractive keratectomy',
#  'phosphoribulokinase',
#  'pranlukast',
#  'ribulose 5 phosphate kinase',
#  'protein kinase c related kinase')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'photorefractive keratectomy': 'MESH:D018903'}

# %%
names
# Out:
# {'MESH:D018903': 'Photorefractive Keratectomy'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'phosphoribulokinase': 'UP:P25697',
#   'photorefractive keratectomy': 'MESH:D018903',
#   'pranlukast': 'CHEBI:CHEBI:94810',
#   'protein kinase c related kinase': 'FPLX:PKN',
#   'ribulose 5 phosphate kinase': 'UP:P25697'},
#  {'UP:P25697': 'Phosphoribulokinase, chloroplastic',
#   'MESH:D018903': 'Photorefractive Keratectomy',
#   'CHEBI:CHEBI:94810': 'N-[4-oxo-2-(2H-tetrazol-5-yl)-1-benzopyran-8-yl]-4-(4-phenylbutoxy)benzamide',
#   'FPLX:PKN': 'PKN'},
#  ['CHEBI:CHEBI:94810', 'FPLX:PKN', 'MESH:D018903', 'UP:P25697'])

# %%
grounding_map, names, pos_labels = ({'phosphoribulokinase': 'UP:P25697',
  'photorefractive keratectomy': 'MESH:D018903',
  'pranlukast': 'CHEBI:CHEBI:94810',
  'protein kinase c related kinase': 'FPLX:PKN',
  'ribulose 5 phosphate kinase': 'UP:P25697'},
 {'UP:P25697': 'Phosphoribulokinase, chloroplastic',
  'MESH:D018903': 'Photorefractive Keratectomy',
  'CHEBI:CHEBI:94810': 'N-[4-oxo-2-(2H-tetrazol-5-yl)-1-benzopyran-8-yl]-4-(4-phenylbutoxy)benzamide',
  'FPLX:PKN': 'PKN'},
 ['CHEBI:CHEBI:94810', 'FPLX:PKN', 'MESH:D018903', 'UP:P25697'])

# %%
names['HGNC:2154'] = 'PLK3'
pos_labels.append('HGNC:2154')

# %%
grounding_dict = {'PRK': grounding_map}

# %%
classifier = AdeftClassifier('PRK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 13:28:46] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-27 13:29:40] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9440341359057196 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D018903': 74,
#   'UP:P25697': 57,
#   'FPLX:PKN': 101,
#   'CHEBI:CHEBI:94810': 1,
#   'HGNC:2154': 60},
#  'f1': {'mean': 0.9440341359057196, 'std': 0.0457767160315519},
#  'precision': {'mean': 0.94624301218765, 'std': 0.04849600734277527},
#  'recall': {'mean': 0.9460027967034602, 'std': 0.04302491807337236}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:2154']

# %%
a[0]
# Out:
# 'PLK3/PRK, a conserved polo family protein serine/threonine kinase, plays a significant role at the onset of mitosis and mitotic progression. Recently, PLK3/PRK has been shown to induce apoptosis when overexpressed in cell lines and is also implicated in cell proliferation and tumor development. Forty lung tumor cell lines were used for single-strand confirmation polymorphism (SSCP) analysis and DNA sequencing to examine the mutational status of PLK3/PRK. No missense or nonsense mutations were revealed in the lung carcinoma cell lines examined. However, three polymorphisms were identified as: a G to A at position 720, an A to G at 1053, and a G to C at 1275. Intron/exon boundaries were determined by amplification of genomic DNA with PLK3/PRK exon-specific primers. The amplification products with increased size relative to the cDNA were sequenced. Fifteen exons throughout the open reading frame were characterized. None of the introns were exceptionally large, typically ranging from 100-300 basepairs in length. These results suggest that although PLK3/PRK expression is downregulated in a majority of lung carcinoma samples, mutational inactivation of the coding sequence of the PLK3/PRK gene appears to be a rare event in lung cancer.\n'

# %%
disamb.dump('PRK', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('enrichment', 0.0010042797351243191),
#  ('gtpase activating', 0.0009997082407178493),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
