# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['CLK']
genes = ['CLOCK']
families = {'CLK': ['CLK1', 'CLK2', 'CLK3', 'CLK4']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['CLOCK', 'CLK1', 'CLK2', 'CLK3', 'CLK4']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['CLK'].top()

# %%
top
# Out:
# [('clock', 89.51428571428572),
#  ('transcription factors clock', 22.756756756756758),
#  ('the transcription factors clock', 19.476190476190474),
#  ('the clock', 9.09090909090909),
#  ('cdc2 like kinase', 6.0),
#  ('the transcription activators clock', 5.5),
#  ('and clock', 4.666666666666667),
#  ('of clock', 4.0),
#  ('of the transcription factors clock', 4.0),
#  ('kidney', 3.0),
#  ('the proteins clock', 3.0),
#  ('two transcription factors clock', 3.0),
#  ('bhlh pas transcription factors clock', 2.5),
#  ('of the transcription activators clock', 2.5),
#  ('contralateral kidney', 2.0),
#  ('by the transcription factors clock', 2.0),
#  ('activators clock', 1.8000000000000007),
#  ('transcription activators clock', 1.7777777777777777),
#  ('like kinase', 1.75),
#  ('proteins clock', 1.6),
#  ('timeless tim clock', 1.5),
#  ('by clock', 1.3333333333333333),
#  ('by the clock', 1.3333333333333333),
#  ('contra lateral kidney', 1.3333333333333333),
#  ('per timeless tim clock', 1.3333333333333333),
#  ('drosophila the transcription factors clock', 1.3333333333333333),
#  ('contra lateral', 1.0),
#  ('tfs clock', 1.0),
#  ('e g clock', 1.0),
#  ('impaired contralateral kidney', 1),
#  ('loop the clock', 1.0),
#  ('of the clock', 1.0),
#  ('and contra lateral kidney', 1.0),
#  ('domain transcription factors clock', 1.0),
#  ('heterodimer formed by clock', 1.0),
#  ('in drosophila melanogaster clock', 1.0),
#  ('in mammals and clock', 1.0),
#  ('the positive elements clock', 1),
#  ('is activators by the clock', 1.0),
#  ('period per timeless tim clock', 1.0),
#  ('the circadian transcription factors clock', 1.0),
#  ('in drosophila the transcription factors clock', 1.0),
#  ('post translational regulated of the transcription factors clock', 1),
#  ('the heterodimeric complex of the transcription factors clock', 1),
#  ('in mammals a complex formed by the proteins clock', 1),
#  ('in drosophila the activators is a heterodimeric complex of clock', 1),
#  ('the core feedback loop consists of the transcription activators clock',
#   1.0),
#  ('ock transcription translational feedback loop in drosophila the transcription factors clock',
#   1),
#  ('similarly to srpk1 2 full length clones encoding cdc2 like kinase', 1),
#  ('a transcription translational feedback loop consists of transcription activators e g clock',
#   1),
#  ('autoregulate their expression by inhibit activators of their transcription activators the clock',
#   1),
#  ('ila melanogaster molecular biological studies have shown that the transcription activators clock',
#   1),
#  ('imeless tim transcription figure 1 in the per tim loop the clock', 1),
#  ('as dexamethasone dex reduces concanavalin a con a induced product of chemotactic lymphokines',
#   1),
#  ('briefly in drosophila the core molecular oscillator consists of two transcription factors clock',
#   1),
#  ('chung 2010 hardin 2011 in drosophila the bhlh pas transcription factors heterodimer clock',
#   1),
#  ('hardin 2011 in drosophila several transcription loop are interconnected by the tfs clock',
#   1),
#  ('lar oscillator e75 repress expression of the genes encoding the transcription activators clock',
#   1),
#  ('nal feedback loop underlies animal circadian rhythms in drosophila the transcription factors clock',
#   1),
#  ('o keep temporal order and anticipate daily environmental changes in drosophila melanogaster clock',
#   1),
#  ('rotein oscillator in constant darkness dd these rhythms require the transcription factors clock',
#   1),
#  ('tional translational feedback loop ttfl in the drosophila ttfl the transcription factors clock',
#   1),
#  ('ts control the transcription of the negative elements briefly the transcription activators clock',
#   1),
#  ('two basic helix loop helix per arnt sim bhlh pas transcription factors clock',
#   1.0),
#  ('activators the expression of their own inhibitors in the drosophila circadian oscillator the clock',
#   1),
#  ('al 2003 within the nucleus per repress the activators of the transcription activators clock',
#   1),
#  ('and tissues in drosophila the core feedback loop consists of the transcription activators clock',
#   1),
#  ('anism relies on transcription activators and repressor that constitute a feedback loop the clock',
#   1),
#  ('circadian pacemaker this molecular clock dependent on the activators of the transcription factors clock',
#   1),
#  ('ck genes that formed intracellular molecular clock in these clock two transcription factors clock',
#   1),
#  ('clock clk and cycle cyc and their product proteins period per timeless tim clock',
#   1),
#  ('clock genes cryptochrome 2 cry2 which encoding the main transcription repressor of the clock',
#   1),
#  ('cription translational feedback loop they include in flies four major proteins timeless tim clock',
#   1),
#  ('cxcr4 expression in c ardiosphere derived l in − c k it + progenitor', 1.0),
#  ('e core feedback loop period per and timeless tim transcription are activators when clock',
#   1),
#  ('especially for myc driven cancer patients member of the evolutionarily conserved cdc2 like kinase',
#   1),
#  ('h include transcription negative feedback loop that are conserved from insects to mammals clock',
#   1),
#  ('ila circadian oscillator is comprised of transcription feedback loop that are activators by clock',
#   1),
#  ('it relies on a negative transcription feedback loop that involves the transcription factors clock',
#   1),
#  ('kinase is necessary for the phosphorylation of period per a transcription repressor and clock',
#   1),
#  ('left and medullary right fibrosis were quantified from trichrome staining in sham contra lateral',
#   1),
#  ('lock genes in the three neurons clusters mentioned above the circadian transcription factors clock',
#   1),
#  ('one of the clock neurons show per immunoreactivity c representative staining results of clock',
#   1),
#  ('ore of the circadian pathway is a transcription feedback loop in drosophila melanogaster clock',
#   1),
#  ('phila the major loop involves a positive limb which include the transcription activators clock',
#   1),
#  ('se phosphorylation and destabilizes the period per and timeless tim proteins which inhibit clock',
#   1),
#  ('sensitive proteins and negative feedback loop figure 1 26 the heterodimer formed by clock',
#   1),
#  ('tablish circadian rhythms in physiology and behavior in this species putative daphnia pulex clock',
#   1),
#  ('the flies clock consists of a transcription feedback loop whereby the transcription factors clock',
#   1),
#  ('these feedback loop are both positive and negative with positive factors e g clock',
#   1),
#  ('uclear rnps hnrnps cleavage and polyadenylation factors proteins kinase such as cdc like kinase',
#   1),
#  ('we identified inhibitors with surprising isoform specificity for clk1 over clk3 cdc2 like kinase',
#   1),
#  ('1 a simplified version of the core feedback loop consists of the transcription activators clock',
#   1),
#  ('20 per and tim repress their own expression by binding to their transcription activators clock',
#   1),
#  ('activators of brm functions to recruit repress factors to limit the transcription output of clock',
#   1),
#  ('as in vertebrates in the core feedback loop of the drosophila clock transcription factors clock',
#   1),
#  ('brief the core clock of d melanogaster consists of an interactions feedback loop involves clock',
#   1),
#  ('chanism of dysfunction of regulatory b cells is unclear the circadian locomotor output cycle kaput',
#   1),
#  ('e important to their survival central to drosophila clockwork is a key transcription factors clock',
#   1),
#  ('en the pseudo diffusivity and tubular injury score d stenotic kidney stk contra lateral kidney',
#   1),
#  ('enes formed two distinct heterodimer period per and timeless tim formed one heterodimer and clock',
#   1),
#  ('enes that underlie self sustained 24 hour feedback loop in flies two transcription factors clock',
#   1),
#  ('example in vertebrates the basic helix loop helix per arnt sim domain transcription factors clock',
#   1),
#  ('in the clock circuit of the fruit flies drosophila melanogaster a heterodimer consists of clock',
#   1),
#  ('ional feedback loop that are highly conserved between flies and mammals in drosophila the clock',
#   1),
#  ('is highly analog to it counterpart in mammalian cells in flies the transcription factors clock',
#   1),
#  ('ker figure 1 for review see for example 2 17 the circadian transcription factors clock',
#   1),
#  ('lecular clock in the pacemaker neurons in the brain of drosophila the transcription factors clock',
#   1),
#  ('ls in clock neurons in drosophila this clock is composed of the transcription activators clock',
#   1),
#  ('malian molecular clock 2 30 in the drosophila core feedback loop the clock proteins clock',
#   1),
#  ('ngly supportive of calfi clk being a true clock family member putative calanus finmarchicus clock',
#   1),
#  ('ock clk and cycle cyc 1 2 clk and cyc encoding the transcription factors clock',
#   1),
#  ('ophila melanogaster two basic helix loop helix per arnt sim bhlh pas transcription factors clock',
#   1),
#  ('or brain and muscle aryl hydrocarbon receptor nuclear translocator like proteins 1 bmal1 and clock',
#   1),
#  ('oung and kay 2001 zheng and sehgal 2012 in drosophila period per timeless tim clock',
#   1),
#  ('per and timeless tim genes their proteins per and tim and the transcription factors clock',
#   1),
#  ('r clock in drosophila consists of an autoregulatory loop in which the transcription factors clock',
#   1),
#  ('re several because atherogenic factors exacerbate damage in both the stk and the contralateral kidney',
#   1),
#  ('rfering with formation of the clk pl bmal1 complex a immunoprecipitation ip of endogenous clock',
#   1),
#  ('s by phosphorylation of clock components 43 in mammals gsk3 is proposed to phosphorylation clock',
#   1),
#  ('s often mediate proteins proteins interactions and the same region in the drosophila clock ortholog',
#   1),
#  ('scription of the clock components period per and timeless tim is activators by the clock',
#   1),
#  ('se dependent stimulates the release of pgs from both the hnk and unobstructed contralateral kidney',
#   1),
#  ('tified the brahma brm complex as a regulated of the drosophila clock in drosophila clock',
#   1),
#  ('toreceptor cells occurs 47 the positive elements of the mammalian clock are the proteins clock',
#   1),
#  ('transcription translational feedback loop ttfl at the core of the system are the activators clock',
#   1),
#  ('ukaryotic mrna these phosphorylation events are dependent on sr proteins srpk and cdc2 like kinase',
#   1),
#  ('via one or more transcription feedback loop 1 in drosophila a heterodimer formed by clock',
#   1),
#  ('well known inhibitors for a number of different kinase cyclin dependent kinase cdc2 like kinase',
#   1),
#  ('ylation sites indicates that o glcnacylation at per s942 reduces interactions between per and clock',
#   1),
#  ('32 p phosphate into clk 32 p was analyzed by autoradiography and total clk proteins levels',
#   1.0),
#  ('ar clock mechanism in this species include period d rosophila per d per timeless tim clock',
#   1),
#  ('bhlh pas transcription factors called clock and bmal1 or it homologue npas2 in mammals and clock',
#   1),
#  ('brates the circadian clock is composed of an integral set of proteins include period per clock',
#   1),
#  ('clock and an output pathway 7 the clock itself is comprised of the transcription factors clock',
#   1),
#  ('core clock genes the expression of per and tim is regulated by the transcription factors clock',
#   1),
#  ('ed to the same two positive basic helix loop helix bhlh pas containing transcription factors clock',
#   1),
#  ('ent review see 1 the flies clock is composed of intracellular feedback loop the proteins clock',
#   1),
#  ('es their activators and subcellular availability we here show that inhibit of the cdc2 like kinase',
#   1),
#  ('gative feedback loop figure 1 at the center of these loop are the transcription factors clock',
#   1),
#  ('in part of two interconnected feedback loop 3 in the period timeless per tim loop clock',
#   1),
#  ('l repressor we found that rna levels of genes directly activators by the transcription factors clock',
#   1),
#  ('lating activators of the circadian clock is formed by a heterodimer of the transcription factors clock',
#   1),
#  ('of the principal loop is composed of a heterodimeric complex of the two transcription factors clock',
#   1),
#  ('olecular clock a recently review by allada and chung 2010 a heterodimer formed by the clock',
#   1),
#  ('preconditioning increased cxcr4 expression in c ardiosphere derived l in − c k it + progenitor',
#   1),
#  ('ptional feedback loop in mammals the transcription factors bmal1 acts as a dimer with either clock',
#   1),
#  ('sivity correlated with distal tubular mtt in the stenotic kidney stk a and contra lateral kidney',
#   1),
#  ('tions in the negative limb of the clockwork by presumably binding to the transcription factors clock',
#   1),
#  ('were derived from cardiosphere cultures and were defined by as cardiosphere derived c kit + lin',
#   1),
#  ('aily oscillator of the clock genes expression at mrna and proteins levels in the evening the clock',
#   1),
#  ('cription of the per and tim genes is initiated during mid day by the transcription factors clock',
#   1),
#  ('ction f p were calculated in cortex and medulla of the stenotic stk and contra lateral kidney',
#   1),
#  ('kloss et al 1998 price et al 1998 he et al 2017 in mammals the proteins clock',
#   1),
#  ('nd consists of a two arm negative feedback loop the positive arm proteins in drosophila are clock',
#   1),
#  ('nto the early part of the night two basic helix loop helix bhlh pas transcription factors clock',
#   1),
#  ('on with local tfs networks a prime example is the circadian clock although the conserved tfs clock',
#   1),
#  ('oops in which the basic helix loop helix per arnt sim bhlh pas domain transcription factors clock',
#   1),
#  ('orated 32 p phosphate into clk 32 p was analyzed by autoradiography and total clk proteins levels',
#   1),
#  ('rated 32 p phosphate into clk 32 p was analyzed by autoradiography and total clk proteins levels',
#   1),
#  ('scription of period per and timeless tim in the evening per and tim proteins then repress clock',
#   1),
#  ('step in control the speed of the clock 40 dbt is also require for phosphorylation of clock',
#   1),
#  ('zoni et al 2005 in the drosophila clock per and tim expression is activators by the clock',
#   1),
#  ('ck2α and anti ha were used to reveal clk and ck2α respectively left western blots for clk alone',
#   1),
#  ('dence that hypoxia induced cxcr4 expression in c ardiosphere derived l in − c k it + progenitor',
#   1),
#  ('e positive limb of this loop is driven by a heterodimer of two bhlh pas transcription factors clock',
#   1),
#  ('enous cycle 1 3 6 two basic helix loop helix per arnt sim bhlh pas transcription factors clock',
#   1),
#  ('lk4 phosphorylation the ser 28 of a truncated gflb3 with a deleted rs motif nδ21 cdc2 like kinase',
#   1),
#  ('ock has one positive and two negative loop that interconnected at clk cyc a heterodimer of the clock',
#   1),
#  ('eters in the cortex a d and medulla e h of sham stenotic stk and non stenotic contra lateral',
#   1),
#  ('iour to the 24h day in flies as in mammals the oscillator operates in cells that co expression clock',
#   1),
#  ('on at the heart of the molecular clock clock or it analog npas2 and bmal1 in mammals and clock',
#   1),
#  ('on as an input pin tgout input from the das while rb1 rb2 rb3 and rb4 are output pin for clock',
#   1),
#  ('alone', 0.0),
#  ('kaput', 0.0),
#  ('kinase', 0.0),
#  ('lateral', 0.0),
#  ('levels', 0.0),
#  ('lin', 0.0),
#  ('lymphokines', 0.0),
#  ('ortholog', 0.0),
#  ('progenitor', 0.0),
#  ('+ lin', 0.0),
#  ('+ progenitor', 0.0),
#  ('are clock', 0.0),
#  ('chemotactic lymphokines', 0.0),
#  ('clk alone', 0.0),
#  ('clock ortholog', 0.0),
#  ('cycle kaput', 0.0),
#  ('drosophila clock', 0.0),
#  ('either clock', 0.0),
#  ('elements clock', 0.0),
#  ('endogenous clock', 0.0),
#  ('expression clock', 0.0),
#  ('factors clock', 0.0),
#  ('finmarchicus clock', 0.0),
#  ('for clock', 0.0),
#  ('g clock', 0.0),
#  ('heterodimer clock', 0.0),
#  ('inhibit clock', 0.0),
#  ('involves clock', 0.0),
#  ('lateral kidney', 0.0),
#  ('loop clock', 0.0),
#  ('mammals clock', 0.0),
#  ('melanogaster clock', 0.0),
#  ('per clock', 0.0),
#  ('phosphorylation clock', 0.0),
#  ('proteins levels', 0.0),
#  ('pulex clock', 0.0),
#  ('repress clock', 0.0),
#  ('tim clock', 0.0),
#  ('when clock', 0.0),
#  ('activators by clock', 0.0),
#  ('activators the clock', 0.0),
#  ('activators when clock', 0.0),
#  ('bmal1 and clock', 0.0),
#  ('calanus finmarchicus clock', 0.0),
#  ('cdc like kinase', 0.0),
#  ('clk proteins levels', 0.0),
#  ('clock proteins clock', 0.0),
#  ('co expression clock', 0.0),
#  ('complex of clock', 0.0),
#  ('conserved tfs clock', 0.0),
#  ('consists of clock', 0.0),
#  ('daphnia pulex clock', 0.0),
#  ('drosophila are clock', 0.0),
#  ('drosophila clock ortholog', 0.0),
#  ('drosophila melanogaster clock', 0.0),
#  ('drosophila the clock', 0.0),
#  ('evening the clock', 0.0),
#  ('factors heterodimer clock', 0.0),
#  ('for clk alone', 0.0),
#  ('formed by clock', 0.0),
#  ('heterodimer and clock', 0.0),
#  ('in drosophila clock', 0.0),
#  ('it + progenitor', 0.0),
#  ('kit + lin', 0.0),
#  ('loop involves clock', 0.0),
#  ('mammals and clock', 0.0),
#  ('of chemotactic lymphokines', 0.0),
#  ('of endogenous clock', 0.0),
#  ('oscillator the clock', 0.0),
#  ('output cycle kaput', 0.0),
#  ('output of clock', 0.0),
#  ('per and clock', 0.0),
#  ('period per clock', 0.0),
#  ('phosphorylation of clock', 0.0),
#  ('pin for clock', 0.0),
#  ('positive elements clock', 0.0),
#  ('repressor and clock', 0.0),
#  ('results of clock', 0.0),
#  ('sham contra lateral', 0.0),
#  ('stenotic contra lateral', 0.0),
#  ('the activators clock', 0.0),
#  ('the contralateral kidney', 0.0),
#  ('the tfs clock', 0.0),
#  ('then repress clock', 0.0),
#  ('tim loop clock', 0.0),
#  ('to mammals clock', 0.0),
#  ('to phosphorylation clock', 0.0),
#  ('unobstructed contralateral kidney', 0.0),
#  ('which inhibit clock', 0.0),
#  ('with either clock', 0.0),
#  ('1 bmal1 and clock', 0.0),
#  ('activators by the clock', 0.0),
#  ('activators e g clock', 0.0),
#  ('and cdc2 like kinase', 0.0),
#  ('and the contralateral kidney', 0.0),
#  ('and unobstructed contralateral kidney', 0.0),
#  ('are activators by clock', 0.0),
#  ('are activators when clock', 0.0),
#  ('are the activators clock', 0.0),
#  ('are the proteins clock', 0.0),
#  ('as cdc like kinase', 0.0),
#  ('between per and clock', 0.0),
#  ('blots for clk alone', 0.0),
#  ('by the proteins clock', 0.0),
#  ('by the tfs clock', 0.0),
#  ('c kit + lin', 0.0),
#  ('circadian oscillator the clock', 0.0),
#  ('circadian transcription factors clock', 0.0),
#  ('clk3 cdc2 like kinase', 0.0),
#  ('clock in drosophila clock', 0.0),
#  ('clock transcription factors clock', 0.0),
#  ('conserved cdc2 like kinase', 0.0),
#  ('containing transcription factors clock', 0.0),
#  ('dimer with either clock', 0.0),
#  ('encoding cdc2 like kinase', 0.0),
#  ('factors e g clock', 0.0),
#  ('feedback loop involves clock', 0.0),
#  ('feedback loop the clock', 0.0),
#  ('for phosphorylation of clock', 0.0),
#  ('formed by the clock', 0.0),
#  ('heterodimer consists of clock', 0.0),
#  ('heterodimer of the clock', 0.0),
#  ('heterodimeric complex of clock', 0.0),
#  ('in drosophila are clock', 0.0),
#  ('in drosophila the clock', 0.0),
#  ('in sham contra lateral', 0.0),
#  ('include period per clock', 0.0),
#  ('insects to mammals clock', 0.0),
#  ('ip of endogenous clock', 0.0),
#  ('k it + progenitor', 0.0),
#  ('key transcription factors clock', 0.0),
#  ('kinase cdc2 like kinase', 0.0),
#  ('locomotor output cycle kaput', 0.0),
#  ('loop the proteins clock', 0.0),
#  ('mammals the proteins clock', 0.0),
#  ('non stenotic contra lateral', 0.0),
#  ('nδ21 cdc2 like kinase', 0.0),
#  ('one heterodimer and clock', 0.0),
#  ('output pin for clock', 0.0),
#  ('pas transcription factors clock', 0.0),
#  ('per tim loop clock', 0.0),
#  ('product of chemotactic lymphokines', 0.0),
#  ('proposed to phosphorylation clock', 0.0),
#  ('proteins then repress clock', 0.0),
#  ('proteins timeless tim clock', 0.0),
#  ('proteins which inhibit clock', 0.0),
#  ('putative calanus finmarchicus clock', 0.0),
#  ('putative daphnia pulex clock', 0.0),
#  ('repressor of the clock', 0.0),
#  ('staining results of clock', 0.0),
#  ('stk contra lateral kidney', 0.0),
#  ('that co expression clock', 0.0),
#  ('the cdc2 like kinase', 0.0),
#  ('the clock proteins clock', 0.0),
#  ('the conserved tfs clock', 0.0),
#  ('the drosophila clock ortholog', 0.0),
#  ('the evening the clock', 0.0),
#  ('their transcription activators clock', 0.0),
#  ('tim loop the clock', 0.0),
#  ('total clk proteins levels', 0.0),
#  ('transcription activators the clock', 0.0),
#  ('transcription factors heterodimer clock', 0.0),
#  ('transcription output of clock', 0.0),
#  ('transcription repressor and clock', 0.0),
#  ('a and contra lateral kidney', 0.0),
#  ('a dimer with either clock', 0.0),
#  ('a feedback loop the clock', 0.0),
#  ('a heterodimer consists of clock', 0.0),
#  ('a heterodimer formed by clock', 0.0),
#  ('a heterodimer of the clock', 0.0),
#  ('a heterodimeric complex of clock', 0.0),
#  ('a key transcription factors clock', 0.0),
#  ('a transcription repressor and clock', 0.0),
#  ('although the conserved tfs clock', 0.0),
#  ('and non stenotic contra lateral', 0.0),
#  ('and the transcription factors clock', 0.0),
#  ('and total clk proteins levels', 0.0),
#  ('are output pin for clock', 0.0),
#  ('are the transcription factors clock', 0.0),
#  ('bmal1 in mammals and clock', 0.0),
#  ('briefly the transcription activators clock', 0.0),
#  ('c k it + progenitor', 0.0),
#  ('cells that co expression clock', 0.0),
#  ('changes in drosophila melanogaster clock', 0.0),
#  ('circadian locomotor output cycle kaput', 0.0),
#  ('clock are the proteins clock', 0.0),
#  ('clock two transcription factors clock', 0.0),
#  ('clones encoding cdc2 like kinase', 0.0),
#  ('d per timeless tim clock', 0.0),
#  ('dependent kinase cdc2 like kinase', 0.0),
#  ('derived c kit + lin', 0.0),
#  ('drosophila circadian oscillator the clock', 0.0),
#  ('drosophila clock in drosophila clock', 0.0),
#  ('drosophila clock transcription factors clock', 0.0),
#  ('encoding the transcription activators clock', 0.0),
#  ('encoding the transcription factors clock', 0.0),
#  ('evolutionarily conserved cdc2 like kinase', 0.0),
#  ('feedback loop the proteins clock', 0.0),
#  ('flies the transcription factors clock', 0.0),
#  ('flies two transcription factors clock', 0.0),
#  ('formed by the proteins clock', 0.0),
#  ('formed one heterodimer and clock', 0.0),
#  ('from insects to mammals clock', 0.0),
#  ('heterodimer formed by the clock', 0.0),
#  ('hnk and unobstructed contralateral kidney', 0.0),
#  ('immunoprecipitation ip of endogenous clock', 0.0),
#  ('in mammals the proteins clock', 0.0),
#  ('in the drosophila clock ortholog', 0.0),
#  ('in the evening the clock', 0.0),
#  ('include the transcription activators clock', 0.0),
#  ('induced product of chemotactic lymphokines', 0.0),
#  ('interactions between per and clock', 0.0),
#  ('interactions feedback loop involves clock', 0.0),
#  ('interconnected by the tfs clock', 0.0),
#  ('involves the transcription factors clock', 0.0),
#  ('is proposed to phosphorylation clock', 0.0),
#  ('kidney stk contra lateral kidney', 0.0),
#  ('loop in drosophila melanogaster clock', 0.0),
#  ('loop the clock proteins clock', 0.0),
#  ('major proteins timeless tim clock', 0.0),
#  ('mammals in drosophila the clock', 0.0),
#  ('member putative calanus finmarchicus clock', 0.0),
#  ('motif nδ21 cdc2 like kinase', 0.0),
#  ('npas2 in mammals and clock', 0.0),
#  ('of the cdc2 like kinase', 0.0),
#  ('of two transcription factors clock', 0.0),
#  ('over clk3 cdc2 like kinase', 0.0),
#  ('pas containing transcription factors clock', 0.0),
#  ('pas domain transcription factors clock', 0.0),
#  ('pas transcription factors heterodimer clock', 0.0),
#  ('per tim loop the clock', 0.0),
#  ('positive factors e g clock', 0.0),
#  ('proteins 1 bmal1 and clock', 0.0),
#  ('proteins in drosophila are clock', 0.0),
#  ('proteins include period per clock', 0.0),
#  ('representative staining results of clock', 0.0),
#  ('require for phosphorylation of clock', 0.0),
#  ('require the transcription factors clock', 0.0),
#  ('sim domain transcription factors clock', 0.0),
#  ('species putative daphnia pulex clock', 0.0),
#  ('srpk and cdc2 like kinase', 0.0),
#  ('staining in sham contra lateral', 0.0),
#  ('stk and contra lateral kidney', 0.0),
#  ('stk and the contralateral kidney', 0.0),
#  ('such as cdc like kinase', 0.0),
#  ('system are the activators clock', 0.0),
#  ('that are activators by clock', 0.0),
#  ('that the transcription activators clock', 0.0),
#  ('the heterodimer formed by clock', 0.0),
#  ('the transcription output of clock', 0.0),
#  ('the two transcription factors clock', 0.0),
#  ('their transcription activators the clock', 0.0),
#  ('tim proteins then repress clock', 0.0),
#  ('tim proteins which inhibit clock', 0.0),
#  ('timeless per tim loop clock', 0.0),
#  ('to the transcription factors clock', 0.0),
#  ('to their transcription activators clock', 0.0),
#  ('transcription activators e g clock', 0.0),
#  ('transcription are activators when clock', 0.0),
#  ('transcription repressor of the clock', 0.0),
#  ('ttfl the transcription factors clock', 0.0),
#  ('western blots for clk alone', 0.0),
#  ('whereby the transcription factors clock', 0.0),
#  ('which the transcription factors clock', 0.0),
#  ('17 the circadian transcription factors clock', 0.0),
#  ('2017 in mammals the proteins clock', 0.0),
#  ('26 the heterodimer formed by clock', 0.0),
#  ('a heterodimer formed by the clock', 0.0),
#  ('a immunoprecipitation ip of endogenous clock', 0.0),
#  ('a induced product of chemotactic lymphokines', 0.0),
#  ('above the circadian transcription factors clock', 0.0),
#  ('activators by the transcription factors clock', 0.0),
#  ('activators of the transcription activators clock', 0.0),
#  ('activators of the transcription factors clock', 0.0),
#  ('also require for phosphorylation of clock', 0.0),
#  ('an interactions feedback loop involves clock', 0.0),
#  ('and bmal1 in mammals and clock', 0.0),
#  ('and mammals in drosophila the clock', 0.0),
#  ('and tim proteins then repress clock', 0.0),
#  ('are interconnected by the tfs clock', 0.0),
#  ('arm proteins in drosophila are clock', 0.0),
#  ('arnt sim domain transcription factors clock', 0.0),
#  ('as a dimer with either clock', 0.0),
#  ('autoradiography and total clk proteins levels', 0.0),
#  ('bhlh pas containing transcription factors clock', 0.0),
#  ('bhlh pas domain transcription factors clock', 0.0),
#  ('bhlh pas transcription factors heterodimer clock', 0.0),
#  ('binding to the transcription factors clock', 0.0),
#  ('binding to their transcription activators clock', 0.0),
#  ('c representative staining results of clock', 0.0),
#  ('cardiosphere derived c kit + lin', 0.0),
#  ('clk1 over clk3 cdc2 like kinase', 0.0),
#  ('clock although the conserved tfs clock', 0.0),
#  ('complex formed by the proteins clock', 0.0),
#  ('complex of the transcription factors clock', 0.0),
#  ('composed of the transcription activators clock', 0.0),
#  ('comprised of the transcription factors clock', 0.0),
#  ('conserved from insects to mammals clock', 0.0),
#  ('consists of the transcription activators clock', 0.0),
#  ('consists of two transcription factors clock', 0.0),
#  ('constitute a feedback loop the clock', 0.0),
#  ('cyc a heterodimer of the clock', 0.0),
#  ('cyc encoding the transcription factors clock', 0.0),
#  ('cyclin dependent kinase cdc2 like kinase', 0.0),
#  ('day by the transcription factors clock', 0.0),
#  ('drosophila a heterodimer formed by clock', 0.0),
#  ('drosophila period per timeless tim clock', 0.0),
#  ('drosophila ttfl the transcription factors clock', 0.0),
#  ('elements briefly the transcription activators clock', 0.0),
#  ('environmental changes in drosophila melanogaster clock', 0.0),
#  ('expression is activators by the clock', 0.0),
#  ('family member putative calanus finmarchicus clock', 0.0),
#  ('feedback loop in drosophila melanogaster clock', 0.0),
#  ('feedback loop the clock proteins clock', 0.0),
#  ('four major proteins timeless tim clock', 0.0),
#  ('genes encoding the transcription activators clock', 0.0),
#  ('gsk3 is proposed to phosphorylation clock', 0.0),
#  ('helix bhlh pas transcription factors clock', 0.0),
#  ('heterodimer of the transcription factors clock', 0.0),
#  ('homologue npas2 in mammals and clock', 0.0),
#  ('in cells that co expression clock', 0.0),
#  ('in flies the transcription factors clock', 0.0),
#  ('in flies two transcription factors clock', 0.0),
#  ('in which the transcription factors clock', 0.0),
#  ('inhibit of the cdc2 like kinase', 0.0),
#  ('intracellular feedback loop the proteins clock', 0.0),
#  ('is a heterodimeric complex of clock', 0.0),
#  ('is a key transcription factors clock', 0.0),
#  ('kinase such as cdc like kinase', 0.0),
#  ('left western blots for clk alone', 0.0),
#  ('length clones encoding cdc2 like kinase', 0.0),
#  ('levels in the evening the clock', 0.0),
#  ('like proteins 1 bmal1 and clock', 0.0),
#  ('limit the transcription output of clock', 0.0),
#  ('loop are the transcription factors clock', 0.0),
#  ('loop that are activators by clock', 0.0),
#  ('loop whereby the transcription factors clock', 0.0),
#  ('main transcription repressor of the clock', 0.0),
#  ('mammalian clock are the proteins clock', 0.0),
#  ('melanogaster a heterodimer consists of clock', 0.0),
#  ('of drosophila the transcription factors clock', 0.0),
#  ('of proteins include period per clock', 0.0),
#  ('of the two transcription factors clock', 0.0),
#  ('of their transcription activators the clock', 0.0),
#  ('of transcription activators e g clock', 0.0),
#  ('per a transcription repressor and clock', 0.0),
#  ('per d per timeless tim clock', 0.0),
#  ('period timeless per tim loop clock', 0.0),
#  ('proteins period per timeless tim clock', 0.0),
#  ('proteins srpk and cdc2 like kinase', 0.0),
#  ('rb4 are output pin for clock', 0.0),
#  ('reduces interactions between per and clock', 0.0),
#  ('region in the drosophila clock ortholog', 0.0),
#  ('regulated by the transcription factors clock', 0.0),
#  ('regulated of the transcription factors clock', 0.0),
#  ('rhythms require the transcription factors clock', 0.0),
#  ('rs motif nδ21 cdc2 like kinase', 0.0),
#  ('shown that the transcription activators clock', 0.0),
#  ('sim bhlh pas transcription factors clock', 0.0),
#  ('stenotic kidney stk contra lateral kidney', 0.0),
#  ('stenotic stk and contra lateral kidney', 0.0),
#  ('stk a and contra lateral kidney', 0.0),
#  ('stk and non stenotic contra lateral', 0.0),
#  ('that involves the transcription factors clock', 0.0),
#  ('the circadian locomotor output cycle kaput', 0.0),
#  ('the drosophila circadian oscillator the clock', 0.0),
#  ('the drosophila clock in drosophila clock', 0.0),
#  ('the drosophila clock transcription factors clock', 0.0),
#  ('the evolutionarily conserved cdc2 like kinase', 0.0),
#  ('the hnk and unobstructed contralateral kidney', 0.0),
#  ('the per tim loop the clock', 0.0),
#  ('the stk and the contralateral kidney', 0.0),
#  ('the system are the activators clock', 0.0),
#  ('these clock two transcription factors clock', 0.0),
#  ('this species putative daphnia pulex clock', 0.0),
#  ('tim and the transcription factors clock', 0.0),
#  ('tim formed one heterodimer and clock', 0.0),
#  ('tim is activators by the clock', 0.0),
#  ('tim transcription are activators when clock', 0.0),
#  ('timeless tim proteins which inhibit clock', 0.0),
#  ('trichrome staining in sham contra lateral', 0.0),
#  ('two bhlh pas transcription factors clock', 0.0),
#  ('which include the transcription activators clock', 0.0),
#  ('with positive factors e g clock', 0.0),
#  ('− c k it + progenitor', 0.0),
#  ('1 26 the heterodimer formed by clock', 0.0),
#  ('2 17 the circadian transcription factors clock', 0.0),
#  ('2010 a heterodimer formed by the clock', 0.0),
#  ('a complex formed by the proteins clock', 0.0),
#  ('a heterodimer of the transcription factors clock', 0.0),
#  ('acts as a dimer with either clock', 0.0),
#  ('activators is a heterodimeric complex of clock', 0.0),
#  ('activators of their transcription activators the clock', 0.0),
#  ('al 2017 in mammals the proteins clock', 0.0),
#  ('and cyc encoding the transcription factors clock', 0.0),
#  ('and rb4 are output pin for clock', 0.0),
#  ('and tim and the transcription factors clock', 0.0),
#  ('and timeless tim proteins which inhibit clock', 0.0),
#  ('are conserved from insects to mammals clock', 0.0),
#  ('arnt sim bhlh pas transcription factors clock', 0.0),
#  ('as cardiosphere derived c kit + lin', 0.0),
#  ('both the hnk and unobstructed contralateral kidney', 0.0),
#  ('both the stk and the contralateral kidney', 0.0),
#  ('brain of drosophila the transcription factors clock', 0.0),
#  ('by autoradiography and total clk proteins levels', 0.0),
#  ('by binding to their transcription activators clock', 0.0),
#  ('cells in flies the transcription factors clock', 0.0),
#  ('circadian clock although the conserved tfs clock', 0.0),
#  ('clk cyc a heterodimer of the clock', 0.0),
#  ('clock family member putative calanus finmarchicus clock', 0.0),
#  ('clockwork is a key transcription factors clock', 0.0),
#  ('complex a immunoprecipitation ip of endogenous clock', 0.0),
#  ('complex of the two transcription factors clock', 0.0),
#  ('con a induced product of chemotactic lymphokines', 0.0),
#  ('consists of transcription activators e g clock', 0.0),
#  ('core feedback loop the clock proteins clock', 0.0),
#  ('d stenotic kidney stk contra lateral kidney', 0.0),
#  ('daily environmental changes in drosophila melanogaster clock', 0.0),
#  ('deleted rs motif nδ21 cdc2 like kinase', 0.0),
#  ('directly activators by the transcription factors clock', 0.0),
#  ('drosophila melanogaster a heterodimer consists of clock', 0.0),
#  ('feedback loop that are activators by clock', 0.0),
#  ('feedback loop whereby the transcription factors clock', 0.0),
#  ('flies and mammals in drosophila the clock', 0.0),
#  ('flies four major proteins timeless tim clock', 0.0),
#  ('for clk1 over clk3 cdc2 like kinase', 0.0),
#  ('from trichrome staining in sham contra lateral', 0.0),
#  ('full length clones encoding cdc2 like kinase', 0.0),
#  ('have shown that the transcription activators clock', 0.0),
#  ('helix bhlh pas containing transcription factors clock', 0.0),
#  ('heterodimeric complex of the transcription factors clock', 0.0),
#  ('immunoreactivity c representative staining results of clock', 0.0),
#  ('in drosophila a heterodimer formed by clock', 0.0),
#  ('in drosophila period per timeless tim clock', 0.0),
#  ('in the drosophila circadian oscillator the clock', 0.0),
#  ('in the per tim loop the clock', 0.0),
#  ('in these clock two transcription factors clock', 0.0),
#  ('in this species putative daphnia pulex clock', 0.0),
#  ('in − c k it + progenitor', 0.0),
#  ('is also require for phosphorylation of clock', 0.0),
#  ('is composed of the transcription activators clock', 0.0),
#  ('is comprised of the transcription factors clock', 0.0),
#  ('is regulated by the transcription factors clock', 0.0),
#  ('it homologue npas2 in mammals and clock', 0.0),
#  ('kidney stk a and contra lateral kidney', 0.0),
#  ('kinase cyclin dependent kinase cdc2 like kinase', 0.0),
#  ('limb which include the transcription activators clock', 0.0),
#  ('loop are interconnected by the tfs clock', 0.0),
#  ('loop consists of the transcription activators clock', 0.0),
#  ('loop helix bhlh pas transcription factors clock', 0.0),
#  ('loop in drosophila the transcription factors clock', 0.0),
#  ('loop in flies two transcription factors clock', 0.0),
#  ('loop in which the transcription factors clock', 0.0),
#  ('loop that involves the transcription factors clock', 0.0),
#  ('mammals gsk3 is proposed to phosphorylation clock', 0.0),
#  ('mentioned above the circadian transcription factors clock', 0.0),
#  ('mid day by the transcription factors clock', 0.0),
#  ('negative elements briefly the transcription activators clock', 0.0),
#  ('negative with positive factors e g clock', 0.0),
#  ('npas2 and bmal1 in mammals and clock', 0.0),
#  ('of an interactions feedback loop involves clock', 0.0),
#  ('of intracellular feedback loop the proteins clock', 0.0),
#  ('of the drosophila clock in drosophila clock', 0.0),
#  ('of the drosophila clock transcription factors clock', 0.0),
#  ('of the evolutionarily conserved cdc2 like kinase', 0.0),
#  ('of the system are the activators clock', 0.0),
#  ('of two bhlh pas transcription factors clock', 0.0),
#  ('operates in cells that co expression clock', 0.0),
#  ('oscillator consists of two transcription factors clock', 0.0),
#  ('per and tim proteins then repress clock', 0.0),
#  ('per arnt sim domain transcription factors clock', 0.0),
#  ('period per a transcription repressor and clock', 0.0),
#  ('positive arm proteins in drosophila are clock', 0.0),
#  ('presumably binding to the transcription factors clock', 0.0),
#  ('product proteins period per timeless tim clock', 0.0),
#  ('proteins kinase such as cdc like kinase', 0.0),
#  ('proteins levels in the evening the clock', 0.0),
#  ('respectively left western blots for clk alone', 0.0),
#  ('rhythms in drosophila the transcription factors clock', 0.0),
#  ('rosophila per d per timeless tim clock', 0.0),
#  ('s942 reduces interactions between per and clock', 0.0),
#  ('same region in the drosophila clock ortholog', 0.0),
#  ('set of proteins include period per clock', 0.0),
#  ('sim bhlh pas domain transcription factors clock', 0.0),
#  ('sr proteins srpk and cdc2 like kinase', 0.0),
#  ('stenotic stk and non stenotic contra lateral', 0.0),
#  ('that constitute a feedback loop the clock', 0.0),
#  ('that inhibit of the cdc2 like kinase', 0.0),
#  ('the activators of the transcription activators clock', 0.0),
#  ('the activators of the transcription factors clock', 0.0),
#  ('the bhlh pas transcription factors heterodimer clock', 0.0),
#  ('the drosophila ttfl the transcription factors clock', 0.0),
#  ('the genes encoding the transcription activators clock', 0.0),
#  ('the main transcription repressor of the clock', 0.0),
#  ('the mammalian clock are the proteins clock', 0.0),
#  ('the period timeless per tim loop clock', 0.0),
#  ('the stenotic stk and contra lateral kidney', 0.0),
#  ('these loop are the transcription factors clock', 0.0),
#  ('these rhythms require the transcription factors clock', 0.0),
#  ('tim expression is activators by the clock', 0.0),
#  ('timeless tim formed one heterodimer and clock', 0.0),
#  ('timeless tim is activators by the clock', 0.0),
#  ('timeless tim transcription are activators when clock', 0.0),
#  ('to limit the transcription output of clock', 0.0),
#  ('transcription feedback loop in drosophila melanogaster clock', 0.0),
#  ('translational regulated of the transcription factors clock', 0.0),
#  ('translocator like proteins 1 bmal1 and clock', 0.0),
#  ('unclear the circadian locomotor output cycle kaput', 0.0),
#  ('1 in drosophila a heterodimer formed by clock', 0.0),
#  ('1 in the per tim loop the clock', 0.0),
#  ('2 full length clones encoding cdc2 like kinase', 0.0),
#  ('2012 in drosophila period per timeless tim clock', 0.0),
#  ('a con a induced product of chemotactic lymphokines', 0.0),
#  ('a deleted rs motif nδ21 cdc2 like kinase', 0.0),
#  ('a transcription feedback loop in drosophila melanogaster clock', 0.0),
#  ('analog npas2 and bmal1 in mammals and clock', 0.0),
#  ('analyzed by autoradiography and total clk proteins levels', 0.0),
#  ('and negative with positive factors e g clock', 0.0),
#  ('and proteins levels in the evening the clock', 0.0),
#  ('and tim expression is activators by the clock', 0.0),
#  ('and timeless tim formed one heterodimer and clock', 0.0),
#  ('and timeless tim is activators by the clock', 0.0),
#  ('and timeless tim transcription are activators when clock', 0.0),
#  ('anticipate daily environmental changes in drosophila melanogaster clock',
#   0.0),
#  ('arnt sim bhlh pas domain transcription factors clock', 0.0),
#  ('at clk cyc a heterodimer of the clock', 0.0),
#  ('autoregulatory loop in which the transcription factors clock', 0.0),
#  ('behavior in this species putative daphnia pulex clock', 0.0),
#  ('between flies and mammals in drosophila the clock', 0.0),
#  ('bmal1 acts as a dimer with either clock', 0.0),
#  ('bmal1 complex a immunoprecipitation ip of endogenous clock', 0.0),
#  ('by a heterodimer of the transcription factors clock', 0.0),
#  ('by as cardiosphere derived c kit + lin', 0.0),
#  ('by presumably binding to the transcription factors clock', 0.0),
#  ('chung 2010 a heterodimer formed by the clock', 0.0),
#  ('circadian rhythms in drosophila the transcription factors clock', 0.0),
#  ('ck2α respectively left western blots for clk alone', 0.0),
#  ('clk and cyc encoding the transcription factors clock', 0.0),
#  ('clock in these clock two transcription factors clock', 0.0),
#  ('clock is composed of the transcription activators clock', 0.0),
#  ('clusters mentioned above the circadian transcription factors clock', 0.0),
#  ('composed of intracellular feedback loop the proteins clock', 0.0),
#  ('consists of an interactions feedback loop involves clock', 0.0),
#  ('core of the system are the activators clock', 0.0),
#  ('d rosophila per d per timeless tim clock', 0.0),
#  ('dbt is also require for phosphorylation of clock', 0.0),
#  ('dd these rhythms require the transcription factors clock', 0.0),
#  ('different kinase cyclin dependent kinase cdc2 like kinase', 0.0),
#  ('drosophila clockwork is a key transcription factors clock', 0.0),
#  ('drosophila core feedback loop the clock proteins clock', 0.0),
#  ('drosophila the bhlh pas transcription factors heterodimer clock', 0.0),
#  ('during mid day by the transcription factors clock', 0.0),
#  ('encoding the main transcription repressor of the clock', 0.0),
#  ('et al 2017 in mammals the proteins clock', 0.0),
#  ('evening per and tim proteins then repress clock', 0.0),
#  ('example 2 17 the circadian transcription factors clock', 0.0),
#  ('expression by binding to their transcription activators clock', 0.0),
#  ('factors proteins kinase such as cdc like kinase', 0.0),
#  ('factors to limit the transcription output of clock', 0.0),
#  ('feedback loop consists of the transcription activators clock', 0.0),
#  ('feedback loop in drosophila the transcription factors clock', 0.0),
#  ('feedback loop in flies two transcription factors clock', 0.0),
#  ('feedback loop that involves the transcription factors clock', 0.0),
#  ('figure 1 26 the heterodimer formed by clock', 0.0),
#  ('flies drosophila melanogaster a heterodimer consists of clock', 0.0),
#  ('from both the hnk and unobstructed contralateral kidney', 0.0),
#  ('genes directly activators by the transcription factors clock', 0.0),
#  ('helix loop helix bhlh pas transcription factors clock', 0.0),
#  ('helix per arnt sim domain transcription factors clock', 0.0),
#  ('heterodimer of two bhlh pas transcription factors clock', 0.0),
#  ('heterodimeric complex of the two transcription factors clock', 0.0),
#  ('in both the stk and the contralateral kidney', 0.0),
#  ('in flies four major proteins timeless tim clock', 0.0),
#  ('in mammals gsk3 is proposed to phosphorylation clock', 0.0),
#  ('in the drosophila ttfl the transcription factors clock', 0.0),
#  ('in the period timeless per tim loop clock', 0.0),
#  ('inhibit activators of their transcription activators the clock', 0.0),
#  ('inhibitors in the drosophila circadian oscillator the clock', 0.0),
#  ('integral set of proteins include period per clock', 0.0),
#  ('is unclear the circadian locomotor output cycle kaput', 0.0),
#  ('itself is comprised of the transcription factors clock', 0.0),
#  ('l in − c k it + progenitor', 0.0),
#  ('loop consists of transcription activators e g clock', 0.0),
#  ('loop helix bhlh pas containing transcription factors clock', 0.0),
#  ('loop of the drosophila clock transcription factors clock', 0.0),
#  ('mammals a complex formed by the proteins clock', 0.0),
#  ('mammalian cells in flies the transcription factors clock', 0.0),
#  ('member of the evolutionarily conserved cdc2 like kinase', 0.0),
#  ('molecular oscillator consists of two transcription factors clock', 0.0),
#  ('nuclear translocator like proteins 1 bmal1 and clock', 0.0),
#  ('of period per a transcription repressor and clock', 0.0),
#  ('of the genes encoding the transcription activators clock', 0.0),
#  ('of the mammalian clock are the proteins clock', 0.0),
#  ('of the stenotic stk and contra lateral kidney', 0.0),
#  ('of these loop are the transcription factors clock', 0.0),
#  ('on sr proteins srpk and cdc2 like kinase', 0.0),
#  ('on the activators of the transcription factors clock', 0.0),
#  ('or it homologue npas2 in mammals and clock', 0.0),
#  ('oscillator operates in cells that co expression clock', 0.0),
#  ('per and tim and the transcription factors clock', 0.0),
#  ('per and timeless tim proteins which inhibit clock', 0.0),
#  ('per arnt sim bhlh pas transcription factors clock', 0.0),
#  ('per immunoreactivity c representative staining results of clock', 0.0),
#  ('per s942 reduces interactions between per and clock', 0.0),
#  ('positive limb which include the transcription activators clock', 0.0),
#  ('quantified from trichrome staining in sham contra lateral', 0.0),
#  ('rb3 and rb4 are output pin for clock', 0.0),
#  ('regulated of the drosophila clock in drosophila clock', 0.0),
#  ('repress the activators of the transcription activators clock', 0.0),
#  ('repressor that constitute a feedback loop the clock', 0.0),
#  ('score d stenotic kidney stk contra lateral kidney', 0.0),
#  ('sham stenotic stk and non stenotic contra lateral', 0.0),
#  ('show that inhibit of the cdc2 like kinase', 0.0),
#  ('specificity for clk1 over clk3 cdc2 like kinase', 0.0),
#  ('stenotic kidney stk a and contra lateral kidney', 0.0),
#  ('studies have shown that the transcription activators clock', 0.0),
#  ('that are conserved from insects to mammals clock', 0.0),
#  ('the activators is a heterodimeric complex of clock', 0.0),
#  ('the brain of drosophila the transcription factors clock', 0.0),
#  ('the circadian clock although the conserved tfs clock', 0.0),
#  ('the negative elements briefly the transcription activators clock', 0.0),
#  ('the positive arm proteins in drosophila are clock', 0.0),
#  ('the same region in the drosophila clock ortholog', 0.0),
#  ('their product proteins period per timeless tim clock', 0.0),
#  ('tim is regulated by the transcription factors clock', 0.0),
#  ('transcription feedback loop that are activators by clock', 0.0),
#  ('transcription feedback loop whereby the transcription factors clock', 0.0),
#  ('transcription loop are interconnected by the tfs clock', 0.0),
#  ('true clock family member putative calanus finmarchicus clock', 0.0),
#  ('2 clk and cyc encoding the transcription factors clock', 0.0),
#  ('3 in the period timeless per tim loop clock', 0.0),
#  ('40 dbt is also require for phosphorylation of clock', 0.0),
#  ('43 in mammals gsk3 is proposed to phosphorylation clock', 0.0),
#  ('a heterodimer of two bhlh pas transcription factors clock', 0.0),
#  ('a heterodimeric complex of the two transcription factors clock', 0.0),
#  ('a positive limb which include the transcription activators clock', 0.0),
#  ('a regulated of the drosophila clock in drosophila clock', 0.0),
#  ('a transcription feedback loop whereby the transcription factors clock',
#   0.0),
#  ('a true clock family member putative calanus finmarchicus clock', 0.0),
#  ('an autoregulatory loop in which the transcription factors clock', 0.0),
#  ('an integral set of proteins include period per clock', 0.0),
#  ('and anticipate daily environmental changes in drosophila melanogaster clock',
#   0.0),
#  ('and behavior in this species putative daphnia pulex clock', 0.0),
#  ('and chung 2010 a heterodimer formed by the clock', 0.0),
#  ('and ck2α respectively left western blots for clk alone', 0.0),
#  ('and repressor that constitute a feedback loop the clock', 0.0),
#  ('and the same region in the drosophila clock ortholog', 0.0),
#  ('and their product proteins period per timeless tim clock', 0.0),
#  ('and tim is regulated by the transcription factors clock', 0.0),
#  ('animal circadian rhythms in drosophila the transcription factors clock',
#   0.0),
#  ('at per s942 reduces interactions between per and clock', 0.0),
#  ('basic helix loop helix bhlh pas transcription factors clock', 0.0),
#  ('biological studies have shown that the transcription activators clock',
#   0.0),
#  ('bmal1 or it homologue npas2 in mammals and clock', 0.0),
#  ('by inhibit activators of their transcription activators the clock', 0.0),
#  ('cells is unclear the circadian locomotor output cycle kaput', 0.0),
#  ('center of these loop are the transcription factors clock', 0.0),
#  ('clock itself is comprised of the transcription factors clock', 0.0),
#  ('clockwork by presumably binding to the transcription factors clock', 0.0),
#  ('concanavalin a con a induced product of chemotactic lymphokines', 0.0),
#  ('conserved between flies and mammals in drosophila the clock', 0.0),
#  ('core feedback loop consists of the transcription activators clock', 0.0),
#  ('core molecular oscillator consists of two transcription factors clock',
#   0.0),
#  ('damage in both the stk and the contralateral kidney', 0.0),
#  ('darkness dd these rhythms require the transcription factors clock', 0.0),
#  ('defined by as cardiosphere derived c kit + lin', 0.0),
#  ('dependent on sr proteins srpk and cdc2 like kinase', 0.0),
#  ('dependent on the activators of the transcription factors clock', 0.0),
#  ('derived l in − c k it + progenitor', 0.0),
#  ('drosophila the activators is a heterodimeric complex of clock', 0.0),
#  ('elements of the mammalian clock are the proteins clock', 0.0),
#  ('expression of the genes encoding the transcription activators clock', 0.0),
#  ('factors bmal1 acts as a dimer with either clock', 0.0),
#  ('feedback loop consists of transcription activators e g clock', 0.0),
#  ('feedback loop of the drosophila clock transcription factors clock', 0.0),
#  ('figure 1 in the per tim loop the clock', 0.0),
#  ('for example 2 17 the circadian transcription factors clock', 0.0),
#  ('formed by a heterodimer of the transcription factors clock', 0.0),
#  ('fruit flies drosophila melanogaster a heterodimer consists of clock', 0.0),
#  ('he et al 2017 in mammals the proteins clock', 0.0),
#  ('helix loop helix bhlh pas containing transcription factors clock', 0.0),
#  ('helix per arnt sim bhlh pas transcription factors clock', 0.0),
#  ('here show that inhibit of the cdc2 like kinase', 0.0),
#  ('hour feedback loop in flies two transcription factors clock', 0.0),
#  ('in drosophila the bhlh pas transcription factors heterodimer clock', 0.0),
#  ('in mammalian cells in flies the transcription factors clock', 0.0),
#  ('in the brain of drosophila the transcription factors clock', 0.0),
#  ('include in flies four major proteins timeless tim clock', 0.0),
#  ('initiated during mid day by the transcription factors clock', 0.0),
#  ('injury score d stenotic kidney stk contra lateral kidney', 0.0),
#  ('interconnected at clk cyc a heterodimer of the clock', 0.0),
#  ('is a transcription feedback loop in drosophila melanogaster clock', 0.0),
#  ('is composed of intracellular feedback loop the proteins clock', 0.0),
#  ('is the circadian clock although the conserved tfs clock', 0.0),
#  ('isoform specificity for clk1 over clk3 cdc2 like kinase', 0.0),
#  ('it analog npas2 and bmal1 in mammals and clock', 0.0),
#  ('loop 1 in drosophila a heterodimer formed by clock', 0.0),
#  ('loop figure 1 26 the heterodimer formed by clock', 0.0),
#  ('loop helix per arnt sim domain transcription factors clock', 0.0),
#  ('loop that are conserved from insects to mammals clock', 0.0),
#  ('loop the positive arm proteins in drosophila are clock', 0.0),
#  ('medulla of the stenotic stk and contra lateral kidney', 0.0),
#  ('melanogaster consists of an interactions feedback loop involves clock',
#   0.0),
#  ('molecular clock in these clock two transcription factors clock', 0.0),
#  ('mrna and proteins levels in the evening the clock', 0.0),
#  ('neurons clusters mentioned above the circadian transcription factors clock',
#   0.0),
#  ('of different kinase cyclin dependent kinase cdc2 like kinase', 0.0),
#  ('of genes directly activators by the transcription factors clock', 0.0),
#  ('of sham stenotic stk and non stenotic contra lateral', 0.0),
#  ('of the negative elements briefly the transcription activators clock', 0.0),
#  ('of transcription feedback loop that are activators by clock', 0.0),
#  ('own expression by binding to their transcription activators clock', 0.0),
#  ('own inhibitors in the drosophila circadian oscillator the clock', 0.0),
#  ('patients member of the evolutionarily conserved cdc2 like kinase', 0.0),
#  ('per and tim expression is activators by the clock', 0.0),
#  ('per and timeless tim formed one heterodimer and clock', 0.0),
#  ('per and timeless tim is activators by the clock', 0.0),
#  ('per and timeless tim transcription are activators when clock', 0.0),
#  ('per arnt sim bhlh pas domain transcription factors clock', 0.0),
#  ('per repress the activators of the transcription activators clock', 0.0),
#  ('period d rosophila per d per timeless tim clock', 0.0),
#  ('period per and timeless tim proteins which inhibit clock', 0.0),
#  ('pgs from both the hnk and unobstructed contralateral kidney', 0.0),
#  ('phosphorylation of period per a transcription repressor and clock', 0.0),
#  ('pl bmal1 complex a immunoprecipitation ip of endogenous clock', 0.0),
#  ('polyadenylation factors proteins kinase such as cdc like kinase', 0.0),
#  ('positive and negative with positive factors e g clock', 0.0),
#  ('proteins per and tim and the transcription factors clock', 0.0),
#  ('rb2 rb3 and rb4 are output pin for clock', 0.0),
#  ('receptor nuclear translocator like proteins 1 bmal1 and clock', 0.0),
#  ('repress factors to limit the transcription output of clock', 0.0),
#  ('sehgal 2012 in drosophila period per timeless tim clock', 0.0),
#  ('several transcription loop are interconnected by the tfs clock', 0.0),
#  ('show per immunoreactivity c representative staining results of clock', 0.0),
#  ('srpk1 2 full length clones encoding cdc2 like kinase', 0.0),
#  ('the core of the system are the activators clock', 0.0),
#  ('the drosophila core feedback loop the clock proteins clock', 0.0),
#  ('the evening per and tim proteins then repress clock', 0.0),
#  ('the oscillator operates in cells that co expression clock', 0.0),
#  ('the stenotic kidney stk a and contra lateral kidney', 0.0),
#  ('this clock is composed of the transcription activators clock', 0.0),
#  ('to drosophila clockwork is a key transcription factors clock', 0.0),
#  ('transcription feedback loop that involves the transcription factors clock',
#   0.0),
#  ('translational feedback loop in drosophila the transcription factors clock',
#   0.0),
#  ('ttfl in the drosophila ttfl the transcription factors clock', 0.0),
#  ('was analyzed by autoradiography and total clk proteins levels', 0.0),
#  ('were quantified from trichrome staining in sham contra lateral', 0.0),
#  ('which encoding the main transcription repressor of the clock', 0.0),
#  ('with a deleted rs motif nδ21 cdc2 like kinase', 0.0),
#  ('1 2 clk and cyc encoding the transcription factors clock', 0.0),
#  ('1998 he et al 2017 in mammals the proteins clock', 0.0),
#  ('2011 in drosophila the bhlh pas transcription factors heterodimer clock',
#   0.0),
#  ('24 hour feedback loop in flies two transcription factors clock', 0.0),
#  ('activators and repressor that constitute a feedback loop the clock', 0.0),
#  ('allada and chung 2010 a heterodimer formed by the clock', 0.0),
#  ('and bmal1 or it homologue npas2 in mammals and clock', 0.0),
#  ('and medulla of the stenotic stk and contra lateral kidney', 0.0),
#  ('and polyadenylation factors proteins kinase such as cdc like kinase', 0.0),
#  ('and sehgal 2012 in drosophila period per timeless tim clock', 0.0),
#  ('ardiosphere derived l in − c k it + progenitor', 0.0),
#  ('are dependent on sr proteins srpk and cdc2 like kinase', 0.0),
#  ('as a regulated of the drosophila clock in drosophila clock', 0.0),
#  ('at mrna and proteins levels in the evening the clock', 0.0),
#  ('at the core of the system are the activators clock', 0.0),
#  ('b cells is unclear the circadian locomotor output cycle kaput', 0.0),
#  ('basic helix loop helix bhlh pas containing transcription factors clock',
#   0.0),
#  ('being a true clock family member putative calanus finmarchicus clock', 0.0),
#  ('both positive and negative with positive factors e g clock', 0.0),
#  ('by a heterodimer of two bhlh pas transcription factors clock', 0.0),
#  ('cancer patients member of the evolutionarily conserved cdc2 like kinase',
#   0.0),
#  ('central to drosophila clockwork is a key transcription factors clock', 0.0),
#  ('clk and ck2α respectively left western blots for clk alone', 0.0),
#  ('clk pl bmal1 complex a immunoprecipitation ip of endogenous clock', 0.0),
#  ('clock 40 dbt is also require for phosphorylation of clock', 0.0),
#  ('clock dependent on the activators of the transcription factors clock', 0.0),
#  ('clock is composed of intracellular feedback loop the proteins clock', 0.0),
#  ('clock per and tim expression is activators by the clock', 0.0),
#  ('components 43 in mammals gsk3 is proposed to phosphorylation clock', 0.0),
#  ('comprised of transcription feedback loop that are activators by clock',
#   0.0),
#  ('constant darkness dd these rhythms require the transcription factors clock',
#   0.0),
#  ('core feedback loop of the drosophila clock transcription factors clock',
#   0.0),
#  ('counterpart in mammalian cells in flies the transcription factors clock',
#   0.0),
#  ('cry2 which encoding the main transcription repressor of the clock', 0.0),
#  ('cyc and their product proteins period per timeless tim clock', 0.0),
#  ('d melanogaster consists of an interactions feedback loop involves clock',
#   0.0),
#  ('drosophila several transcription loop are interconnected by the tfs clock',
#   0.0),
#  ('drosophila this clock is composed of the transcription activators clock',
#   0.0),
#  ('exacerbate damage in both the stk and the contralateral kidney', 0.0),
#  ('example is the circadian clock although the conserved tfs clock', 0.0),
#  ('expression by inhibit activators of their transcription activators the clock',
#   0.0),
#  ('feedback loop 1 in drosophila a heterodimer formed by clock', 0.0),
#  ('feedback loop figure 1 26 the heterodimer formed by clock', 0.0),
#  ('feedback loop that are conserved from insects to mammals clock', 0.0),
#  ('feedback loop the positive arm proteins in drosophila are clock', 0.0),
#  ('fibrosis were quantified from trichrome staining in sham contra lateral',
#   0.0),
#  ('gflb3 with a deleted rs motif nδ21 cdc2 like kinase', 0.0),
#  ('glcnacylation at per s942 reduces interactions between per and clock', 0.0),
#  ('h of sham stenotic stk and non stenotic contra lateral', 0.0),
#  ('helix loop helix per arnt sim domain transcription factors clock', 0.0),
#  ('helix per arnt sim bhlh pas domain transcription factors clock', 0.0),
#  ('highly conserved between flies and mammals in drosophila the clock', 0.0),
#  ('hydrocarbon receptor nuclear translocator like proteins 1 bmal1 and clock',
#   0.0),
#  ('in the drosophila core feedback loop the clock proteins clock', 0.0),
#  ('in the evening per and tim proteins then repress clock', 0.0),
#  ('in the stenotic kidney stk a and contra lateral kidney', 0.0),
#  ('include period d rosophila per d per timeless tim clock', 0.0),
#  ('interactions and the same region in the drosophila clock ortholog', 0.0),
#  ('intracellular molecular clock in these clock two transcription factors clock',
#   0.0),
#  ('involves a positive limb which include the transcription activators clock',
#   0.0),
#  ('is formed by a heterodimer of the transcription factors clock', 0.0),
#  ('is initiated during mid day by the transcription factors clock', 0.0),
#  ('levels of genes directly activators by the transcription factors clock',
#   0.0),
#  ('loop 3 in the period timeless per tim loop clock', 0.0),
#  ('loop helix per arnt sim bhlh pas transcription factors clock', 0.0),
#  ('loop ttfl in the drosophila ttfl the transcription factors clock', 0.0),
#  ('mammals the oscillator operates in cells that co expression clock', 0.0),
#  ('molecular biological studies have shown that the transcription activators clock',
#   0.0),
#  ('negative transcription feedback loop that involves the transcription factors clock',
#   0.0),
#  ('neurons in the brain of drosophila the transcription factors clock', 0.0),
#  ('neurons show per immunoreactivity c representative staining results of clock',
#   0.0),
#  ('nucleus per repress the activators of the transcription activators clock',
#   0.0),
#  ('number of different kinase cyclin dependent kinase cdc2 like kinase', 0.0),
#  ('of a heterodimeric complex of the two transcription factors clock', 0.0),
#  ('of a transcription feedback loop whereby the transcription factors clock',
#   0.0),
#  ('of an autoregulatory loop in which the transcription factors clock', 0.0),
#  ('of an integral set of proteins include period per clock', 0.0),
#  ('of pgs from both the hnk and unobstructed contralateral kidney', 0.0),
#  ...]

# %%
longforms = miners['CLK'].get_longforms(abs_decay_param=0.001)

# %%
longforms
# Out:
# [('clock', 106, 0.9246367609300921),
#  ('cdc2 like kinase', 7, 0.9975062395963412),
#  ('contra lateral kidney', 3, 0.9981129987413702),
#  ('contralateral kidney', 3, 0.8827786327110382),
#  ('contra lateral', 2, 0.7457923787155183),
#  ('clk proteins levels', 2, 0.637207331456189),
#  ('cdc like kinase', 1, 0.9990628514746259),
#  ('cycle kaput', 1, 0.9434263027606444),
#  ('chemotactic lymphokines', 1, 0.8842122898223528),
#  ('c kit + lin', 1, 0.846736156908713),
#  ('clk alone', 1, 0.7494061755245505),
#  ('clock ortholog', 1, 0.7086398896955698)]

# %%
longforms
# Out:
# [('clock', 106, 0.9246367609300921),
#  ('cdc2 like kinase', 7, 0.9975062395963412),
#  ('contra lateral kidney', 3, 0.9981129987413702),
#  ('contralateral kidney', 3, 0.8827786327110382),
#  ('contra lateral', 2, 0.7457923787155183),
#  ('clk proteins levels', 2, 0.637207331456189),
#  ('cdc like kinase', 1, 0.9990628514746259),
#  ('cycle kaput', 1, 0.9434263027606444),
#  ('chemotactic lymphokines', 1, 0.8842122898223528),
#  ('c kit + lin', 1, 0.846736156908713),
#  ('clk alone', 1, 0.7494061755245505),
#  ('clock ortholog', 1, 0.7086398896955698)]

# %%
from adeft.ground import AdeftGrounder
grounder = AdeftGrounder()

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0, 1]]

# %%
longforms0
# Out:
# [('clock', 86.3921568627451), ('cdc2 like kinase', 6.0)]

# %%
longforms0.extend([(longform, score) for i, (longform, score) in enumerate(top)
                   if i in [13]])

# %%
longforms0
# Out:
# [('clock', 86.3921568627451),
#  ('cdc2 like kinase', 6.0),
#  ('contralateral kidney', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('clock', 'cdc2 like kinase', 'contralateral kidney')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'clock': 'HGNC:2082'}

# %%
names
# Out:
# {'HGNC:2082': 'CLOCK'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names
# Out:
# {'FPLX:CLK': 'CLK', 'HGNC:2082': 'CLOCK'}

# %%
grounding_map
# Out:
# {'cdc2 like kinase': 'FPLX:CLK',
#  'clock': 'HGNC:2082',
#  'contralateral kidney': 'ungrounded'}

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'cdc2 like kinase': 'FPLX:CLK',
#   'clock': 'HGNC:2082',
#   'contralateral kidney': 'ungrounded'},
#  {'FPLX:CLK': 'CLK', 'HGNC:2082': 'CLOCK'},
#  ['FPLX:CLK', 'HGNC:2082'])

# %%
grounding_map, names, pos_labels = ({'cdc2 like kinase': 'FPLX:CLK',
  'clock': 'HGNC:2082',
  'contralateral kidney': 'ungrounded'},
 {'FPLX:CLK': 'CLK', 'HGNC:2082': 'CLOCK'},
 ['FPLX:CLK', 'HGNC:2082'])

# %%
grounding_dict = {'CLK': grounding_map}

# %%
classifier = AdeftClassifier('CLK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-17 14:31:29] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-17 14:31:34] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9507457227323768 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'ungrounded': 3, 'HGNC:2082': 295, 'FPLX:CLK': 49},
#  'f1': {'mean': 0.9507457227323768, 'std': 0.029135992296673168},
#  'precision': {'mean': 0.947456159148541, 'std': 0.03093001570141328},
#  'recall': {'mean': 0.9564791133844842, 'std': 0.02587786533592789}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [(text, pred) for pred, text in zip(d, shortform_texts)if pred[0].startswith('ung')]

# %%
len(a)
# Out:
# 3

# %%
a
# Out:
# [('Unilateral ureteral obstruction (UUO) results in increased renal resistance as well as in exaggerated prostaglandin (PG) release from the obstructed hydronephrotic kidney (HNK). We have reported previously that platelet-activating factor (PAF) dose-dependently stimulates the release of PGs from both the HNK and unobstructed contralateral kidney (CLK), with CLK release being 10% that of the HNK. In the present report, we studied the interaction of PAF with its receptor by examining the effects of PAF-receptor antagonists on the release of PGs from the isolated perfused rabbit HNK and CLK stimulated by PAF; angiotensin II (AII), and bradykinin (BK) were also used as agonists. In the HNK, kadsurenone (3 microM) inhibited PAF-stimulated PGE2 and thromboxane B2 (TxB2) release by 28.2 and 62.5% respectively. CV-3988 (20 microM) and triazolam (5 microM) also preferentially diminished PAF-stimulated TxB2 release. In addition, all three drugs significantly diminished BK- and AII-stimulated TxB2 release, while CV-3988 was the only antagonist to affect peptide-stimulated PGE2 release. While effective against agonist-stimulated PG synthesis, these drugs had no direct effect on arachidonic acid metabolism to PGs. Furthermore, in the CLK, CV-3988 had no effect on BK- or AII-stimulated PGE2 release, whereas it totally inhibited PAF-stimulated release of PGE2. These results show that PAF-receptor antagonists in the HNK preferentially inhibit TxB2 release whether stimulated by PAF, AII or BK; in the CLK only PAF-stimulated PG release is affected. This biochemical difference may be of physiological significance and explain some of the functional differences between the HNK and CLK. Therefore, PAF may be an important mediator of some of the biochemical and functional changes associated with UUO.\n',
#   ('ungrounded',
#    None,
#    {'FPLX:CLK': 0.0, 'ungrounded': 1.0, 'HGNC:2082': 0.0})),
#  ('Domestic pigs divided into three groups (n=6–7 each) were studied for 16 weeks. Unilateral RAS was induced in two groups, of which one was fed with a high cholesterol diet to induce early atherosclerosis (ARAS), while the other (RAS) consumed regular diet. The third group included normal pigs which served as control sham. Renal function, hemodynamics, tubular function and morphology were assessed using multi-detector computed tomography (MDCT) and histology. Diffusion-weighted MR images were acquired at 3T and analyzed using mono and bi-exponential models. ADC and IVIM parameters (Diffusivity (D t ), flow-dependent pseudo-diffusivity (D p ), and fluid fraction (f p )) were calculated in cortex and medulla of the stenotic (STK) and contra-lateral kidneys (CLK). Results were analyzed using ANOVA, student t-test, and regression analysis.\nIn both RAS and ARAS the STK shrank and the CLK underwent hypertrophy. GFR and renal blood flow declined in STKs, and CLKs manifested hyperfiltration. Additionally, ARAS kidneys showed reduced mean transit time in distal tubular segments. ADC and diffusivity both decreased in STK of RAS and ARAS. D p  and f p  were elevated in both the STK and CLK of RAS and more prominently in ARAS. STK cortical ADC and D t  correlated inversely with the degree of fibrosis, and directly with GFR. Furthermore, D p  correlated with tubular injury score in all kidneys.\nRenal artery stenosis (RAS) is a vascular disorder, which may result in chronic kidney disease (CKD) and lead to end stage renal failure 1 . Significant RAS compromises renal blood flow (RBF), induces renovascular hypertension, impairs glomerular filtration rate (GFR), and induces interstitial fibrosis in the post-stenotic kidney (STK). While in the Western world atherosclerotic RAS (ARAS) is the predominant etiology in adults, RAS may be caused by other causes like fibromuscular dysplasia 1 . Renal injury in ARAS is more severe because atherogenic factors exacerbate damage in both the STK and the contralateral kidney (CLK) 2 , 3 . Early diagnosis and effective treatment may potentially slow further deterioration of renal function. Different imaging techniques and modalities have been used to detect and investigate mechanisms of renal functional and hemodynamic deterioration, yet assessment of tissue injury and morphological changes in the kidney is difficult without invasive methods 4 – 7 .\nWe hypothesize that functional and morphological alterations in the swine STK and CLK, illustrated by multi-detector computed tomography (MDCT) and histology, would be accompanied by corresponding changes in DWI-derived diffusivity and pseudo-diffusivity calculated using the IVIM model. We further hypothesize that DWI-derived parameters would depict greater renal impairment in pigs with ARAS compared to RAS.\nResults are presented as mean±SEM. ANOVA was used for STK/CLK comparison and among groups, followed by unpaired t-test. Regression analysis was performed using the least square method, in some cases on a compiled set of corresponding kidneys from all three groups of RAS, ARAS and Sham. For p values ≤ 0.05, results were considered significant.\nTen weeks after RAS induction the degree of stenosis in the RAS and ARAS groups were comparable and MAP was similarly elevated ( Table. 1 ). The cortical and medullary regions of the STKs underwent atrophy and a decrease in RBF, whereas in the CLKs, the cortex showed hypertrophy, and medullary volumes remained unchanged. MDCT-derived GFR was reduced in the STKs and elevated in the CLKs compared to the sham group. Cortical vascular and proximal tubular MTT values were similar among all groups, whereas distal MTT was significantly shorter in the ARAS STK and CLK, and tended to be shorter in RAS as well (p=0.063 and p=0.072 in the STK and CLK, respectively). Cortical perfusion and FBV remained unchanged, while medullary perfusion and FBV declined in all STKs.\nThe degree of fibrosis was significantly higher in the c ...
#   ('ungrounded',
#    None,
#    {'FPLX:CLK': 0.0, 'ungrounded': 1.0, 'HGNC:2082': 0.0})),
#  ('Impaired contralateral kidney (CLK) function is important in the maintenance of hypertension in the two-kidney, one-clip (2K, 1C) Goldblatt rat model. Since glomerular filtration rate (GFR) is influenced by the products of arachidonic acid metabolism, we investigated the potential role of eicosanoids as mediators of impaired CLK pressure-volume regulation. At 4 wk following right renal artery clipping, GFR of hypertensive rats was significantly reduced. This decrease was due to the fixed reduction in GFR of the clipped kidney and failure of the CLK to increase its GFR. Thromboxane (Tx) production by isolated perfused CLK was significantly elevated, whereas prostacyclin production remained unchanged. Furthermore, CLK GFR was inversely proportional to Tx production. Treatment of 4-wk hypertensive animals with either the Tx synthase inhibitor UK-38,485 or the Tx receptor antagonist GR 32191 produced a significant increase in CLK GFR. In addition, treatment with either the Tx synthase inhibitor or the Tx receptor antagonist significantly reduced systemic blood pressure. Thus, in this 2K, 1C model of hypertension, increased renal Tx production prevents functional hypertrophy of the contralateral kidney. As a result, CLK pressure-volume regulation is impaired and systemic hypertension is maintained. Furthermore, Tx antagonists restore CLK function and acutely lower systemic blood pressure. Therefore, increased renal Tx production by the CLK appears to be an important mediator of hypertension in the 2K, 1C model.\n',
#   ('ungrounded',
#    None,
#    {'FPLX:CLK': 0.0, 'ungrounded': 1.0, 'HGNC:2082': 0.0}))]

# %%
disamb.dump('CLK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
