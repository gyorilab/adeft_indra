# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator, load_disambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['HIR']
genes = ['KCNJ4', 'INSR']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['HIR'].top()

# %%
longforms0 = miners['HIR'].get_longforms()

# %%
top
# Out:
# [('hepatic ischemia reperfusion', 16.666666666666664),
#  ('the human insulin receptor', 12.0),
#  ('human insulin receptor', 10.0),
#  ('mab against the human insulin receptor', 9.23076923076923),
#  ('reperfusion', 6.916666666666668),
#  ('response', 6.363636363636363),
#  ('risk', 4.444444444444445),
#  ('monoclonal antibody mab against the human insulin receptor',
#   3.6666666666666665),
#  ('high intermediate risk', 3.6),
#  ('high irradiation response', 3.2),
#  ('hepatic irradiation', 3.0),
#  ('high infertility risk', 3.0),
#  ('hypoxia induced relaxation', 3.0),
#  ('of human insulin receptor', 3.0),
#  ('e abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   3),
#  ('histone regulatory', 2.8),
#  ('geissoschizine methyl ether gm hirsuteine hte hirsutine', 2.8),
#  ('hypersensitive induced reaction', 2.5),
#  ('preparative hepatic irradiation', 2.333333333333333),
#  ('regulator', 2.0),
#  ('hepatic ischaemia reperfusion', 2.0),
#  ('high immune response', 2.0),
#  ('the histone regulatory', 2.0),
#  ('a heat induced radiolabeling', 2.0),
#  ('during hepatic ischemia reperfusion', 2.0),
#  ('in hepatic ischemia reperfusion', 2.0),
#  ('chimeric monoclonal antibody mab to the human insulin receptor', 2.0),
#  ('protein with a genetically engineered monoclonal antibody mab against the human insulin receptor',
#   2),
#  ('r curves for event free survival efs analysis of breast cancer patients with high immune response',
#   2),
#  ('ure 4 a and in c2 and c3 gse21653 low immune response lir n = 70 high immune response',
#   2),
#  ('ischemia reperfusion', 1.8999999999999986),
#  ('immune response', 1.6),
#  ('reconstruction', 1.5),
#  ('heat induced radiolabeling', 1.5),
#  ('high intensity running', 1.3333333333333333),
#  ('hybrid iterative reconstruction', 1.3333333333333333),
#  ('induced by hepatic ischemia reperfusion', 1.3333333333333333),
#  ('engineered monoclonal antibody mab against the human insulin receptor',
#   1.3333333333333333),
#  ('hirudin', 1),
#  ('ir', 1.0),
#  ('histone regulator', 1.0),
#  ('internal rotation', 1.0),
#  ('reperfusion injury', 1.0),
#  ('hepatic insulin resistance', 1),
#  ('hindlimb ischemia reperfusion', 1),
#  ('reduced by 40', 1.0),
#  ('a high irradiation response', 1.0),
#  ('an immunoglobulin l chain', 1),
#  ('in high intensity running', 1.0),
#  ('of heavy ion radiation', 1.0),
#  ('of hepatic ischemia reperfusion', 1.0),
#  ('of hybrid iterative reconstruction', 1.0),
#  ('the high irradiation response', 1.0),
#  ('the histone information regulator', 1.0),
#  ('the hypersensitive induced reaction', 1.0),
#  ('to assess the performance of hybrid', 1),
#  ('we hypothesized that preparative hepatic irradiation', 1.0),
#  ('were deemed as high intermediate risk', 1.0),
#  ('least squares means for haploid induction rate', 1.0),
#  ('lung injury induced by hepatic ischemia reperfusion', 1.0),
#  ('the mab against the human insulin receptor', 1.0),
#  ('to assess the effect of hybrid iterative reconstruction', 1),
#  ('a genetically engineered mab against the human insulin receptor', 1.0),
#  ('octreotide exerts a protect effect in hepatic ischemia reperfusion', 1),
#  ('2 e multilocularis emir d melanogaster dmir and homo sapiens', 1.0),
#  ('a chimeric monoclonal antibody mab to the human insulin receptor', 1.0),
#  ('antidiabetic and antihyperlipidemic effect of hemidesmus indicus linn r root',
#   1),
#  ('chinese hamster ovary cho cells overexpress the human insulin receptor', 1),
#  ('h the hypersensitive response hr pgsc0003dmg400025335 hypersensitive induced reaction protein',
#   1),
#  ('hydrogen sulfide h2s can protect against hepatic ischemia reperfusion injury',
#   1),
#  ('in rabbits animals were randomized into two experimental group 1st', 1),
#  ('initially we constructed a rat model of hepatic ischemia reperfusion', 1),
#  ('is a monoclonal antibody mab against the human insulin receptor', 1.0),
#  ('seven regions of the alpha subunit of human insulin receptor', 1),
#  ('the chimeric monoclonal antibody mab to the human insulin receptor', 1.0),
#  ('molecular trojan horse is a mab against the human insulin receptor', 1.0),
#  ('ocorynoxeine icx corynoxeine cx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   1),
#  ('rynoxeine cx isocorynoxeine icx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   1),
#  ('this paper investigate the mechanism of action of heavy ion radiation', 1),
#  ('e identified through genetically screen these include the evolutionarily conserved histone regulatory',
#   1),
#  ('ely increase antioxidant ability to combat against hepatocyte damage hepatic ischemia reperfusion',
#   1),
#  ('fh s superparamagnetism by fluorescence click attachment of fluorochromes and by radioactivity',
#   1),
#  ('nanoparticles nps whereby feraheme fh nanoparticles nps undergo a heat induced radiolabeling',
#   1),
#  ('reduced hepatic oxidative stress and hepatocyte death and attenuate hepatic ischaemia reperfusion',
#   1),
#  ('these of multimodal targeted nanoparticles nps is present whereby heat induced radiolabeling',
#   1),
#  ('2 group was significantly increase compared to baseline figure 5 hypoxia induced relaxation',
#   1),
#  ('alkaloids we have pursued an alternative approach that consists of preparative hepatic irradiation',
#   1),
#  ('chromatin remodeling complexes in nrf2 ho 1 pathway active during hepatic ischemia reperfusion',
#   1),
#  ('cular response there was no statistically significantly difference in the hypoxia induced relaxation',
#   1),
#  ('en binding properties and liver oxidative damage was determine during hepatic ischemia reperfusion',
#   1),
#  ('hypersensitive dh to microbial cells and suppresses the development of humoral immune response',
#   1),
#  ('ize low kilovoltage kv computed tomography ct protocols using a hybrid iterative reconstruction',
#   1),
#  ('m of ischemic preconditioning ipc was investigate in rabbits during hepatic ischemia reperfusion',
#   1),
#  ('potential side effect limit their clinical application to investigate the effect of hirsutenone',
#   1),
#  ('probably not suitable for translation to clinical application we have explored hepatic irradiation',
#   1),
#  ('rate preferentially over the host liver cells we hypothesized that preparative hepatic irradiation',
#   1),
#  ('a result ja seems to restrict cells death processes associated with hypersensitive induced reaction',
#   1),
#  ('ars represent low infertility risk lir untreated testes red bars represent high infertility risk',
#   1),
#  ('ated transcription in addition we demonstrate a direct role for the histone information regulator',
#   1),
#  ('d reduction of kidney inflammation and apoptosis after hir hepatic ischemia and reperfusion injury',
#   1),
#  ('gin six non disease shoulders from four cadavers were assess in hyperextended internal rotation',
#   1),
#  ('glutathione reductase gr here we investigate the role of idh2 in hepatic ischemia reperfusion',
#   1),
#  ('insulin binding have been the subject of extensive investigate 15 the human insulin receptor',
#   1),
#  ('isease internal federation of gynecology and obstetrics stage ≥ ii and high intermediate risk',
#   1),
#  ('ive stimuli offered by a preparative regimen we have earlier demonstrate that hepatic irradiation',
#   1),
#  ('l culture caused induction of extra rounds of chromosome replication this heat induced replication',
#   1),
#  ('mansoni smir 1 and 2 e multilocularis emir d melanogaster dmir and homo sapiens',
#   1),
#  ('ol nucleolar size furthermore we characterized a direct role of the histone information regulator',
#   1),
#  ('ontrol group surgery with no hepatic ischemia ctr hepatic reperfusion group with no intervention',
#   1),
#  ('surgery to treat patients with end stage liver disease the result hepatic ischemia reperfusion',
#   1),
#  ('t or single photon emission computed tomography spect image using a heat induced radiolabeling',
#   1),
#  ('the aim of the study was to determine the effect of heavy ion radiation',
#   1),
#  ('ucture homology model recovered the conserved structure between the sjirs and homo sapiens ir',
#   1),
#  ('variables on overall and progression free survival patients were deemed as high intermediate risk',
#   1),
#  ('were identified by genetically screen in s cerevisiae these include the four histone regulatory',
#   1),
#  ('6 given that numerous risk factor are involved in ali induced by hepatic ischemia reperfusion',
#   1),
#  ('653461 this gene encodes a putative protein that is similar to the hypersensitive induced reaction',
#   1),
#  ('a monoclonal antibody mab against an endogenous bbb receptor such as the human insulin receptor',
#   1),
#  ('a single small dose of ketamine could attenuate lung injury induced by hepatic ischemia reperfusion',
#   1),
#  ('botto et al 2000 phya also operates to inhibit germination via the high irradiation response',
#   1),
#  ('cells secretory performance in 12 low insulin responders lir and in eight high insulin responders',
#   1),
#  ('designed to study the effect of quinapril qp and lycopene lyc on hepatic ischemia reperfusion',
#   1),
#  ('en with endometrial cancer this benefit was shown in stage patients with high intermediate risk',
#   1),
#  ('ermined exactly so far we study potential functions of serine residues in human insulin receptor',
#   1),
#  ('eviously shown in rat 1 fibroblasts which stably overexpress high levels of human insulin receptor',
#   1),
#  ('fluence response vlfr initially by extreme low amounts of light and the high irradiation response',
#   1),
#  ('immune igg was obtained from a patients s serum with autoantibodies against human insulin receptor',
#   1),
#  ('may be a potential therapy to alleviate remote lung injury after hir hepatic ischemia reperfusion',
#   1),
#  ('mdjaz2 as bait to screen through an apple fruit peel cdna library hypersensitive induced reaction',
#   1),
#  ('nt of liver disease and ex vivo gene therapy we hypothesized that preparative hepatic irradiation',
#   1),
#  ('oup compared to the norm se group was restored by tempol administration hypoxia induced relaxation',
#   1),
#  ('r whilst their absence or low levels below a critical threshold indicated high infertility risk',
#   1),
#  ('re divided into four group i control group con ii high intensity resistance exercise group',
#   1),
#  ('sed expecting that this would result in reduced h3k9ac steady state levels the histone regulatory',
#   1),
#  ('soni smir 1 and smir 2 e multilocularis emir d melanogaster dmir and homo sapiens',
#   1),
#  ('tein in living cells initially we followed the folding and trafficking of human insulin receptor',
#   1),
#  ('th sedentary control sed group a significantly higher bmd was observation in high intensity running',
#   1),
#  ('tion in many organs include the liver heart brain and kidney 1 hepatic ischaemia reperfusion',
#   1),
#  ('to the decreased bioavailability of no in rat aortas the mechanism of hypoxia induced relaxation',
#   1),
#  ('umans these observation are reflected by the observation that the testes of high infertility risk',
#   1),
#  ('xidative stress and inflammation play a key role in the development of hepatic ischemia reperfusion',
#   1),
#  ('acteristic allowing us to distinguish between the two basal like enriched clusters c2 lir and c3',
#   1),
#  ('adiations for 3h enabled cells division in dark arrested g2 cells evoking a high irradiation response',
#   1),
#  ('ait to screen a cdna library using the yeast two hybrid method the hypersensitive induced reaction',
#   1),
#  ('d transport the most active mth is a genetically engineered mab against the human insulin receptor',
#   1),
#  ('ed as a fusion protein with a chimeric monoclonal antibody mab against the human insulin receptor',
#   1),
#  ('ed group vasorelaxation of aortic rings in response to acetylcholine achir and to reduced po 2',
#   1),
#  ('eered as a fusion protein with the chimeric monoclonal antibody mab to the human insulin receptor',
#   1),
#  ('ents and in patients who met hir risk criteria versus hir negative patients high intermediate risk',
#   1),
#  ('fore we designed the present study to investigate the role of h2s in hepatic ischemia reperfusion',
#   1),
#  ('h4 caused the deregulated expression of ~ 25 of yeast gene 77 deleting the histone regulatory',
#   1),
#  ('in to the carboxyl terminus of the chimeric monoclonal antibody mab to the human insulin receptor',
#   1),
#  ('ineered as a fusion protein with a chimeric monoclonal antibody mab to the human insulin receptor',
#   1),
#  ('into a 5 mm thick image slices with filtered back projection fbp and hybrid image reconstruction',
#   1),
#  ('ion protein where the igg domain is a monoclonal antibody mab against the human insulin receptor',
#   1),
#  ('n assembly are specific complexes such as chromatin assembly factor 1 caf 1 and histone regulator',
#   1),
#  ('n living cells we have examined the folding assembly and transport of the human insulin receptor',
#   1),
#  ('n of brahma related gene 1 brg1 can alleviate lung injury induced by hepatic ischemia reperfusion',
#   1),
#  ('n1 ubinuclein 1 and cabin1 and interacts with asf1a to be orthologous to yeast histone regulator',
#   1),
#  ('oxyl terminus of the heavy chain of a genetically engineered mab against the human insulin receptor',
#   1),
#  ('s of each heavy chain of an engineered monoclonal antibody mab against the human insulin receptor',
#   1),
#  ('t for more than 75 of refereeing active weston et al 2007 instead high intensity running',
#   1),
#  ('the most active bbb trojan horse is a monoclonal antibody mab against the human insulin receptor',
#   1),
#  ('the objective of our study was to attempt to optimize the levels of hybrid iterative reconstruction',
#   1),
#  ('the original score scale kar is shown in percent least squares means for haploid induction rate',
#   1),
#  ('urther validated this concept in a subgroup of patients who were deemed as high intermediate risk',
#   1),
#  ('ved from individual f 2 genotype classes table 4 least squares means for haploid induction rate',
#   1),
#  ('while trabecular bone became more plate like and denser with higher bmd in high intensity running',
#   1),
#  ('+ littermates were subject to 60 min of partial hepatic ischemia followed by 5 h of reperfusion',
#   1),
#  ('d in non evaluable image ct radiation dose for urolithiasis detection can be safely reduced by 40',
#   1),
#  ('e a marker for low infertility risk lir the ad spermatogonia are absent in high infertility risk',
#   1),
#  ('l terminus of the heavy chain of a chimeric monoclonal antibody mab to the human insulin receptor',
#   1),
#  ('leu986 and leu987 have recently been shown to take part in the control of human insulin receptor',
#   1),
#  ('light supplemented with fr light this response of phya is due to the fr high irradiation response',
#   1),
#  ('p in 17 healthy subject nine with low insulin response lir and eight with high insulin response',
#   1),
#  ('port system the most potent bbb molecular trojan horse is a mab against the human insulin receptor',
#   1),
#  ('s compared to mri synthesis of hir fh and cy5 5 fh nanoparticles a heat induced radiolabeling',
#   1),
#  ('s during the same period showing that the antagonistic effect of frc is a high irradiation response',
#   1),
#  ('sion protein with a bbb molecular trojan horse such as the mab against the human insulin receptor',
#   1),
#  ('te this in conclusion the radiation dose for the assess of urolithiasis can be reduced by 40',
#   1),
#  ('the bbb 11 the most potent molecular trojan horse is a mab against the human insulin receptor',
#   1),
#  ('and image quality 7 10 the purpose of this study was to assess the performance of hybrid ir',
#   1),
#  ('peptide of ad was re engineered as a fusion protein with the mab against the human insulin receptor',
#   1),
#  ('ua to the carboxyl terminus of the heavy chain of a chimeric mab against the human insulin receptor',
#   1),
#  ('of 22 60 had a jones fracture in their non dominant leg the means range of hip internal rotation',
#   1),
#  ('1st', 0.0),
#  ('2', 0.0),
#  ('40', 0.0),
#  ('c3', 0.0),
#  ('chain', 0.0),
#  ('group', 0.0),
#  ('hirsutenone', 0.0),
#  ('hirsutine', 0.0),
#  ('hybrid', 0.0),
#  ('injury', 0.0),
#  ('intervention', 0.0),
#  ('irradiation', 0.0),
#  ('protein', 0.0),
#  ('radiation', 0.0),
#  ('radioactivity', 0.0),
#  ('radiolabeling', 0.0),
#  ('rate', 0.0),
#  ('reaction', 0.0),
#  ('receptor', 0.0),
#  ('regulatory', 0.0),
#  ('relaxation', 0.0),
#  ('replication', 0.0),
#  ('resistance', 0.0),
#  ('responders', 0.0),
#  ('root', 0.0),
#  ('rotation', 0.0),
#  ('running', 0.0),
#  ('sapiens', 0.0),
#  ('and c3', 0.0),
#  ('by 40', 0.0),
#  ('by radioactivity', 0.0),
#  ('exercise group', 0.0),
#  ('group 1st', 0.0),
#  ('homo sapiens', 0.0),
#  ('hte hirsutine', 0.0),
#  ('hybrid ir', 0.0),
#  ('image reconstruction', 0.0),
#  ('induced radiolabeling', 0.0),
#  ('induced reaction', 0.0),
#  ('induced relaxation', 0.0),
#  ('induced replication', 0.0),
#  ('induction rate', 0.0),
#  ('infertility risk', 0.0),
#  ('information regulator', 0.0),
#  ('insulin receptor', 0.0),
#  ('insulin resistance', 0.0),
#  ('insulin responders', 0.0),
#  ('insulin response', 0.0),
#  ('intensity running', 0.0),
#  ('intermediate risk', 0.0),
#  ('ion radiation', 0.0),
#  ('irradiation response', 0.0),
#  ('ischaemia reperfusion', 0.0),
#  ('iterative reconstruction', 0.0),
#  ('l chain', 0.0),
#  ('no intervention', 0.0),
#  ('of hirsutenone', 0.0),
#  ('of hybrid', 0.0),
#  ('of reperfusion', 0.0),
#  ('po 2', 0.0),
#  ('r root', 0.0),
#  ('reaction protein', 0.0),
#  ('sapiens ir', 0.0),
#  ('and by radioactivity', 0.0),
#  ('and histone regulator', 0.0),
#  ('and homo sapiens', 0.0),
#  ('and reperfusion injury', 0.0),
#  ('conserved histone regulatory', 0.0),
#  ('effect of hirsutenone', 0.0),
#  ('experimental group 1st', 0.0),
#  ('explored hepatic irradiation', 0.0),
#  ('four histone regulatory', 0.0),
#  ('h of reperfusion', 0.0),
#  ('haploid induction rate', 0.0),
#  ('heat induced replication', 0.0),
#  ('heavy ion radiation', 0.0),
#  ('high insulin responders', 0.0),
#  ('high insulin response', 0.0),
#  ('hip internal rotation', 0.0),
#  ('hirsuteine hte hirsutine', 0.0),
#  ('histone information regulator', 0.0),
#  ('homo sapiens ir', 0.0),
#  ('humoral immune response', 0.0),
#  ('hybrid image reconstruction', 0.0),
#  ('hyperextended internal rotation', 0.0),
#  ('immunoglobulin l chain', 0.0),
#  ('induced reaction protein', 0.0),
#  ('ischemia reperfusion injury', 0.0),
#  ('linn r root', 0.0),
#  ('lir and c3', 0.0),
#  ('of hybrid ir', 0.0),
#  ('performance of hybrid', 0.0),
#  ('reduced po 2', 0.0),
#  ('resistance exercise group', 0.0),
#  ('that hepatic irradiation', 0.0),
#  ('with no intervention', 0.0),
#  ('yeast histone regulator', 0.0),
#  ('1 and histone regulator', 0.0),
#  ('1 hepatic ischaemia reperfusion', 0.0),
#  ('5 h of reperfusion', 0.0),
#  ('5 hypoxia induced relaxation', 0.0),
#  ('70 high immune response', 0.0),
#  ('a hybrid iterative reconstruction', 0.0),
#  ('administration hypoxia induced relaxation', 0.0),
#  ('against human insulin receptor', 0.0),
#  ('and high intermediate risk', 0.0),
#  ('and homo sapiens ir', 0.0),
#  ('and hybrid image reconstruction', 0.0),
#  ('as high intermediate risk', 0.0),
#  ('attenuate hepatic ischaemia reperfusion', 0.0),
#  ('be reduced by 40', 0.0),
#  ('by hepatic ischemia reperfusion', 0.0),
#  ('c2 lir and c3', 0.0),
#  ('damage hepatic ischemia reperfusion', 0.0),
#  ('deleting the histone regulatory', 0.0),
#  ('demonstrate that hepatic irradiation', 0.0),
#  ('dmir and homo sapiens', 0.0),
#  ('eight high insulin responders', 0.0),
#  ('evolutionarily conserved histone regulatory', 0.0),
#  ('fluorochromes and by radioactivity', 0.0),
#  ('for haploid induction rate', 0.0),
#  ('fr high irradiation response', 0.0),
#  ('gm hirsuteine hte hirsutine', 0.0),
#  ('group with no intervention', 0.0),
#  ('have explored hepatic irradiation', 0.0),
#  ('hepatic ischemia reperfusion injury', 0.0),
#  ('hir hepatic ischemia reperfusion', 0.0),
#  ('hypersensitive induced reaction protein', 0.0),
#  ('in high infertility risk', 0.0),
#  ('in human insulin receptor', 0.0),
#  ('in hyperextended internal rotation', 0.0),
#  ('indicated high infertility risk', 0.0),
#  ('indicus linn r root', 0.0),
#  ('instead high intensity running', 0.0),
#  ('intensity resistance exercise group', 0.0),
#  ('ischemia and reperfusion injury', 0.0),
#  ('levels the histone regulatory', 0.0),
#  ('library hypersensitive induced reaction', 0.0),
#  ('of high infertility risk', 0.0),
#  ('of hip internal rotation', 0.0),
#  ('of humoral immune response', 0.0),
#  ('of hypoxia induced relaxation', 0.0),
#  ('of preparative hepatic irradiation', 0.0),
#  ('on hepatic ischemia reperfusion', 0.0),
#  ('patients high intermediate risk', 0.0),
#  ('performance of hybrid ir', 0.0),
#  ('represent high infertility risk', 0.0),
#  ('result hepatic ischemia reperfusion', 0.0),
#  ('safely reduced by 40', 0.0),
#  ('that preparative hepatic irradiation', 0.0),
#  ('the effect of hirsutenone', 0.0),
#  ('the four histone regulatory', 0.0),
#  ('the hypoxia induced relaxation', 0.0),
#  ('the performance of hybrid', 0.0),
#  ('this heat induced replication', 0.0),
#  ('to reduced po 2', 0.0),
#  ('to yeast histone regulator', 0.0),
#  ('two experimental group 1st', 0.0),
#  ('whereby heat induced radiolabeling', 0.0),
#  ('with high immune response', 0.0),
#  ('with high insulin response', 0.0),
#  ('with high intermediate risk', 0.0),
#  ('with hypersensitive induced reaction', 0.0),
#  ('15 the human insulin receptor', 0.0),
#  ('2007 instead high intensity running', 0.0),
#  ('77 deleting the histone regulatory', 0.0),
#  ('= 70 high immune response', 0.0),
#  ('absent in high infertility risk', 0.0),
#  ('action of heavy ion radiation', 0.0),
#  ('active during hepatic ischemia reperfusion', 0.0),
#  ('after hir hepatic ischemia reperfusion', 0.0),
#  ('against hepatic ischemia reperfusion injury', 0.0),
#  ('against the human insulin receptor', 0.0),
#  ('and attenuate hepatic ischaemia reperfusion', 0.0),
#  ('and the high irradiation response', 0.0),
#  ('and to reduced po 2', 0.0),
#  ('as the human insulin receptor', 0.0),
#  ('assess in hyperextended internal rotation', 0.0),
#  ('assess the performance of hybrid', 0.0),
#  ('associated with hypersensitive induced reaction', 0.0),
#  ('autoantibodies against human insulin receptor', 0.0),
#  ('bars represent high infertility risk', 0.0),
#  ('be safely reduced by 40', 0.0),
#  ('bmd in high intensity running', 0.0),
#  ('by 5 h of reperfusion', 0.0),
#  ('caf 1 and histone regulator', 0.0),
#  ('can be reduced by 40', 0.0),
#  ('cdna library hypersensitive induced reaction', 0.0),
#  ('clusters c2 lir and c3', 0.0),
#  ('consists of preparative hepatic irradiation', 0.0),
#  ('control of human insulin receptor', 0.0),
#  ('deemed as high intermediate risk', 0.0),
#  ('determine during hepatic ischemia reperfusion', 0.0),
#  ('development of hepatic ischemia reperfusion', 0.0),
#  ('development of humoral immune response', 0.0),
#  ('earlier demonstrate that hepatic irradiation', 0.0),
#  ('effect in hepatic ischemia reperfusion', 0.0),
#  ('effect of heavy ion radiation', 0.0),
#  ('effect of hybrid iterative reconstruction', 0.0),
#  ('eight with high insulin response', 0.0),
#  ('ether gm hirsuteine hte hirsutine', 0.0),
#  ('evoking a high irradiation response', 0.0),
#  ('fbp and hybrid image reconstruction', 0.0),
#  ('figure 5 hypoxia induced relaxation', 0.0),
#  ('for the histone information regulator', 0.0),
#  ('h2s in hepatic ischemia reperfusion', 0.0),
#  ('hemidesmus indicus linn r root', 0.0),
#  ('hepatic ischemia and reperfusion injury', 0.0),
#  ('hepatocyte damage hepatic ischemia reperfusion', 0.0),
#  ('high intensity resistance exercise group', 0.0),
#  ('hypothesized that preparative hepatic irradiation', 0.0),
#  ('idh2 in hepatic ischemia reperfusion', 0.0),
#  ('ii and high intermediate risk', 0.0),
#  ('in eight high insulin responders', 0.0),
#  ('in the hypoxia induced relaxation', 0.0),
#  ('include the four histone regulatory', 0.0),
#  ('into two experimental group 1st', 0.0),
#  ('investigate the effect of hirsutenone', 0.0),
#  ('is a high irradiation response', 0.0),
#  ('kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('levels of human insulin receptor', 0.0),
#  ('levels of hybrid iterative reconstruction', 0.0),
#  ('lyc on hepatic ischemia reperfusion', 0.0),
#  ('means for haploid induction rate', 0.0),
#  ('mechanism of hypoxia induced relaxation', 0.0),
#  ('melanogaster dmir and homo sapiens', 0.0),
#  ('method the hypersensitive induced reaction', 0.0),
#  ('model of hepatic ischemia reperfusion', 0.0),
#  ('nanoparticles a heat induced radiolabeling', 0.0),
#  ('negative patients high intermediate risk', 0.0),
#  ('observation in high intensity running', 0.0),
#  ('of fluorochromes and by radioactivity', 0.0),
#  ('of the histone information regulator', 0.0),
#  ('of the human insulin receptor', 0.0),
#  ('orthologous to yeast histone regulator', 0.0),
#  ('overexpress the human insulin receptor', 0.0),
#  ('patients with high immune response', 0.0),
#  ('patients with high intermediate risk', 0.0),
#  ('pgsc0003dmg400025335 hypersensitive induced reaction protein', 0.0),
#  ('present whereby heat induced radiolabeling', 0.0),
#  ('rabbits during hepatic ischemia reperfusion', 0.0),
#  ('range of hip internal rotation', 0.0),
#  ('reperfusion group with no intervention', 0.0),
#  ('replication this heat induced replication', 0.0),
#  ('residues in human insulin receptor', 0.0),
#  ('sjirs and homo sapiens ir', 0.0),
#  ('state levels the histone regulatory', 0.0),
#  ('subunit of human insulin receptor', 0.0),
#  ('tempol administration hypoxia induced relaxation', 0.0),
#  ('testes of high infertility risk', 0.0),
#  ('the evolutionarily conserved histone regulatory', 0.0),
#  ('the fr high irradiation response', 0.0),
#  ('the performance of hybrid ir', 0.0),
#  ('the result hepatic ischemia reperfusion', 0.0),
#  ('threshold indicated high infertility risk', 0.0),
#  ('to the human insulin receptor', 0.0),
#  ('to the hypersensitive induced reaction', 0.0),
#  ('trafficking of human insulin receptor', 0.0),
#  ('undergo a heat induced radiolabeling', 0.0),
#  ('using a heat induced radiolabeling', 0.0),
#  ('using a hybrid iterative reconstruction', 0.0),
#  ('via the high irradiation response', 0.0),
#  ('we have explored hepatic irradiation', 0.0),
#  ('1 caf 1 and histone regulator', 0.0),
#  ('achir and to reduced po 2', 0.0),
#  ('against hepatocyte damage hepatic ischemia reperfusion', 0.0),
#  ('al 2007 instead high intensity running', 0.0),
#  ('ali induced by hepatic ischemia reperfusion', 0.0),
#  ('alpha subunit of human insulin receptor', 0.0),
#  ('and eight with high insulin response', 0.0),
#  ('and in eight high insulin responders', 0.0),
#  ('and kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('and trafficking of human insulin receptor', 0.0),
#  ('application we have explored hepatic irradiation', 0.0),
#  ('are absent in high infertility risk', 0.0),
#  ('assess the performance of hybrid ir', 0.0),
#  ('attachment of fluorochromes and by radioactivity', 0.0),
#  ('baseline figure 5 hypoxia induced relaxation', 0.0),
#  ('be orthologous to yeast histone regulator', 0.0),
#  ('by tempol administration hypoxia induced relaxation', 0.0),
#  ('can be safely reduced by 40', 0.0),
#  ('cancer patients with high immune response', 0.0),
#  ('cells evoking a high irradiation response', 0.0),
#  ('cells overexpress the human insulin receptor', 0.0),
#  ('chromosome replication this heat induced replication', 0.0),
#  ('critical threshold indicated high infertility risk', 0.0),
#  ('d melanogaster dmir and homo sapiens', 0.0),
#  ('death and attenuate hepatic ischaemia reperfusion', 0.0),
#  ('difference in the hypoxia induced relaxation', 0.0),
#  ('disease the result hepatic ischemia reperfusion', 0.0),
#  ('enriched clusters c2 lir and c3', 0.0),
#  ('fh nanoparticles a heat induced radiolabeling', 0.0),
#  ('followed by 5 h of reperfusion', 0.0),
#  ('frc is a high irradiation response', 0.0),
#  ('gene 77 deleting the histone regulatory', 0.0),
#  ('germination via the high irradiation response', 0.0),
#  ('have earlier demonstrate that hepatic irradiation', 0.0),
#  ('hepatic reperfusion group with no intervention', 0.0),
#  ('high levels of human insulin receptor', 0.0),
#  ('higher bmd in high intensity running', 0.0),
#  ('hir hepatic ischemia and reperfusion injury', 0.0),
#  ('hir negative patients high intermediate risk', 0.0),
#  ('hr pgsc0003dmg400025335 hypersensitive induced reaction protein', 0.0),
#  ('hybrid method the hypersensitive induced reaction', 0.0),
#  ('ii high intensity resistance exercise group', 0.0),
#  ('image using a heat induced radiolabeling', 0.0),
#  ('in rabbits during hepatic ischemia reperfusion', 0.0),
#  ('include the evolutionarily conserved histone regulatory', 0.0),
#  ('injury after hir hepatic ischemia reperfusion', 0.0),
#  ('injury induced by hepatic ischemia reperfusion', 0.0),
#  ('investigate 15 the human insulin receptor', 0.0),
#  ('is present whereby heat induced radiolabeling', 0.0),
#  ('light and the high irradiation response', 0.0),
#  ('lycopene lyc on hepatic ischemia reperfusion', 0.0),
#  ('mab to the human insulin receptor', 0.0),
#  ('means range of hip internal rotation', 0.0),
#  ('methyl ether gm hirsuteine hte hirsutine', 0.0),
#  ('n = 70 high immune response', 0.0),
#  ('nps undergo a heat induced radiolabeling', 0.0),
#  ('of action of heavy ion radiation', 0.0),
#  ('of h2s in hepatic ischemia reperfusion', 0.0),
#  ('of hemidesmus indicus linn r root', 0.0),
#  ('of idh2 in hepatic ischemia reperfusion', 0.0),
#  ('pathway active during hepatic ischemia reperfusion', 0.0),
#  ('peel cdna library hypersensitive induced reaction', 0.0),
#  ('processes associated with hypersensitive induced reaction', 0.0),
#  ('projection fbp and hybrid image reconstruction', 0.0),
#  ('protect against hepatic ischemia reperfusion injury', 0.0),
#  ('protect effect in hepatic ischemia reperfusion', 0.0),
#  ('protocols using a hybrid iterative reconstruction', 0.0),
#  ('randomized into two experimental group 1st', 0.0),
#  ('rat model of hepatic ischemia reperfusion', 0.0),
#  ('red bars represent high infertility risk', 0.0),
#  ('role for the histone information regulator', 0.0),
#  ('role of the histone information regulator', 0.0),
#  ('serine residues in human insulin receptor', 0.0),
#  ('similar to the hypersensitive induced reaction', 0.0),
#  ('squares means for haploid induction rate', 0.0),
#  ('stage patients with high intermediate risk', 0.0),
#  ('steady state levels the histone regulatory', 0.0),
#  ('such as the human insulin receptor', 0.0),
#  ('that consists of preparative hepatic irradiation', 0.0),
#  ('the control of human insulin receptor', 0.0),
#  ('the development of hepatic ischemia reperfusion', 0.0),
#  ('the development of humoral immune response', 0.0),
#  ('the effect of heavy ion radiation', 0.0),
#  ('the effect of hybrid iterative reconstruction', 0.0),
#  ('the levels of hybrid iterative reconstruction', 0.0),
#  ('the mechanism of hypoxia induced relaxation', 0.0),
#  ('the sjirs and homo sapiens ir', 0.0),
#  ('the testes of high infertility risk', 0.0),
#  ('these include the four histone regulatory', 0.0),
#  ('to investigate the effect of hirsutenone', 0.0),
#  ('to the fr high irradiation response', 0.0),
#  ('transport of the human insulin receptor', 0.0),
#  ('urolithiasis can be reduced by 40', 0.0),
#  ('was determine during hepatic ischemia reperfusion', 0.0),
#  ('was observation in high intensity running', 0.0),
#  ('were assess in hyperextended internal rotation', 0.0),
#  ('with autoantibodies against human insulin receptor', 0.0),
#  ('≥ ii and high intermediate risk', 0.0),
#  ('1 pathway active during hepatic ischemia reperfusion', 0.0),
#  ('5 fh nanoparticles a heat induced radiolabeling', 0.0),
#  ('a critical threshold indicated high infertility risk', 0.0),
#  ('a mab against the human insulin receptor', 0.0),
#  ('a protect effect in hepatic ischemia reperfusion', 0.0),
#  ('a rat model of hepatic ischemia reperfusion', 0.0),
#  ('acetylcholine achir and to reduced po 2', 0.0),
#  ('after hir hepatic ischemia and reperfusion injury', 0.0),
#  ('and lycopene lyc on hepatic ischemia reperfusion', 0.0),
#  ('and transport of the human insulin receptor', 0.0),
#  ('antibody mab against the human insulin receptor', 0.0),
#  ('antibody mab to the human insulin receptor', 0.0),
#  ('aortas the mechanism of hypoxia induced relaxation', 0.0),
#  ('application to investigate the effect of hirsutenone', 0.0),
#  ('approach that consists of preparative hepatic irradiation', 0.0),
#  ('assess the effect of hybrid iterative reconstruction', 0.0),
#  ('back projection fbp and hybrid image reconstruction', 0.0),
#  ('between the sjirs and homo sapiens ir', 0.0),
#  ('bmd was observation in high intensity running', 0.0),
#  ('brain and kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('breast cancer patients with high immune response', 0.0),
#  ('cadavers were assess in hyperextended internal rotation', 0.0),
#  ('can protect against hepatic ischemia reperfusion injury', 0.0),
#  ('cells we hypothesized that preparative hepatic irradiation', 0.0),
#  ('cerevisiae these include the four histone regulatory', 0.0),
#  ('chimeric mab against the human insulin receptor', 0.0),
#  ('cho cells overexpress the human insulin receptor', 0.0),
#  ('click attachment of fluorochromes and by radioactivity', 0.0),
#  ('clinical application we have explored hepatic irradiation', 0.0),
#  ('combat against hepatocyte damage hepatic ischemia reperfusion', 0.0),
#  ('con ii high intensity resistance exercise group', 0.0),
#  ('ct protocols using a hybrid iterative reconstruction', 0.0),
#  ('ctr hepatic reperfusion group with no intervention', 0.0),
#  ('damage was determine during hepatic ischemia reperfusion', 0.0),
#  ('death processes associated with hypersensitive induced reaction', 0.0),
#  ('detection can be safely reduced by 40', 0.0),
#  ('determine the effect of heavy ion radiation', 0.0),
#  ('direct role for the histone information regulator', 0.0),
#  ('direct role of the histone information regulator', 0.0),
#  ('due to the fr high irradiation response', 0.0),
#  ('effect of hemidesmus indicus linn r root', 0.0),
#  ('emir d melanogaster dmir and homo sapiens', 0.0),
#  ('engineered mab against the human insulin receptor', 0.0),
#  ('et al 2007 instead high intensity running', 0.0),
#  ('extensive investigate 15 the human insulin receptor', 0.0),
#  ('factor 1 caf 1 and histone regulator', 0.0),
#  ('folding and trafficking of human insulin receptor', 0.0),
#  ('fruit peel cdna library hypersensitive induced reaction', 0.0),
#  ('g2 cells evoking a high irradiation response', 0.0),
#  ('h3k9ac steady state levels the histone regulatory', 0.0),
#  ('hepatocyte death and attenuate hepatic ischaemia reperfusion', 0.0),
#  ('in ali induced by hepatic ischemia reperfusion', 0.0),
#  ('in stage patients with high intermediate risk', 0.0),
#  ('in the control of human insulin receptor', 0.0),
#  ('in the development of hepatic ischemia reperfusion', 0.0),
#  ('inhibit germination via the high irradiation response', 0.0),
#  ('investigate in rabbits during hepatic ischemia reperfusion', 0.0),
#  ('is similar to the hypersensitive induced reaction', 0.0),
#  ('ischemia followed by 5 h of reperfusion', 0.0),
#  ('like enriched clusters c2 lir and c3', 0.0),
#  ('lir and eight with high insulin response', 0.0),
#  ('lir and in eight high insulin responders', 0.0),
#  ('lir n = 70 high immune response', 0.0),
#  ('liver disease the result hepatic ischemia reperfusion', 0.0),
#  ('lung injury after hir hepatic ischemia reperfusion', 0.0),
#  ('mechanism of action of heavy ion radiation', 0.0),
#  ('nanoparticles nps undergo a heat induced radiolabeling', 0.0),
#  ('nps is present whereby heat induced radiolabeling', 0.0),
#  ('of chromosome replication this heat induced replication', 0.0),
#  ('of frc is a high irradiation response', 0.0),
#  ('of light and the high irradiation response', 0.0),
#  ('of serine residues in human insulin receptor', 0.0),
#  ('of urolithiasis can be reduced by 40', 0.0),
#  ('optimize the levels of hybrid iterative reconstruction', 0.0),
#  ('overexpress high levels of human insulin receptor', 0.0),
#  ('patients were deemed as high intermediate risk', 0.0),
#  ('receptor such as the human insulin receptor', 0.0),
#  ('response hr pgsc0003dmg400025335 hypersensitive induced reaction protein',
#   0.0),
#  ('restored by tempol administration hypoxia induced relaxation', 0.0),
#  ('role of h2s in hepatic ischemia reperfusion', 0.0),
#  ('role of idh2 in hepatic ischemia reperfusion', 0.0),
#  ('serum with autoantibodies against human insulin receptor', 0.0),
#  ('significantly difference in the hypoxia induced relaxation', 0.0),
#  ('spect image using a heat induced radiolabeling', 0.0),
#  ('spermatogonia are absent in high infertility risk', 0.0),
#  ('stage ≥ ii and high intermediate risk', 0.0),
#  ('suppresses the development of humoral immune response', 0.0),
#  ('testes red bars represent high infertility risk', 0.0),
#  ('that the testes of high infertility risk', 0.0),
#  ('the alpha subunit of human insulin receptor', 0.0),
#  ('the means range of hip internal rotation', 0.0),
#  ('therapy we hypothesized that preparative hepatic irradiation', 0.0),
#  ('these include the evolutionarily conserved histone regulatory', 0.0),
#  ('to assess the performance of hybrid ir', 0.0),
#  ('to baseline figure 5 hypoxia induced relaxation', 0.0),
#  ('to be orthologous to yeast histone regulator', 0.0),
#  ('two hybrid method the hypersensitive induced reaction', 0.0),
#  ('versus hir negative patients high intermediate risk', 0.0),
#  ('we have earlier demonstrate that hepatic irradiation', 0.0),
#  ('were randomized into two experimental group 1st', 0.0),
#  ('who were deemed as high intermediate risk', 0.0),
#  ('with higher bmd in high intensity running', 0.0),
#  ('yeast gene 77 deleting the histone regulatory', 0.0),
#  ('4 least squares means for haploid induction rate', 0.0),
#  ('a chimeric mab against the human insulin receptor', 0.0),
#  ('a direct role for the histone information regulator', 0.0),
#  ('a direct role of the histone information regulator', 0.0),
#  ('ad spermatogonia are absent in high infertility risk', 0.0),
#  ('alleviate lung injury induced by hepatic ischemia reperfusion', 0.0),
#  ('alternative approach that consists of preparative hepatic irradiation',
#   0.0),
#  ('amounts of light and the high irradiation response', 0.0),
#  ('and hepatocyte death and attenuate hepatic ischaemia reperfusion', 0.0),
#  ('and suppresses the development of humoral immune response', 0.0),
#  ('animals were randomized into two experimental group 1st', 0.0),
#  ('antihyperlipidemic effect of hemidesmus indicus linn r root', 0.0),
#  ('apoptosis after hir hepatic ischemia and reperfusion injury', 0.0),
#  ('apple fruit peel cdna library hypersensitive induced reaction', 0.0),
#  ('arrested g2 cells evoking a high irradiation response', 0.0),
#  ('as the mab against the human insulin receptor', 0.0),
#  ('asf1a to be orthologous to yeast histone regulator', 0.0),
#  ('assembly and transport of the human insulin receptor', 0.0),
#  ('assembly factor 1 caf 1 and histone regulator', 0.0),
#  ('assess of urolithiasis can be reduced by 40', 0.0),
#  ('attenuate lung injury induced by hepatic ischemia reperfusion', 0.0),
#  ('basal like enriched clusters c2 lir and c3', 0.0),
#  ('bbb receptor such as the human insulin receptor', 0.0),
#  ('below a critical threshold indicated high infertility risk', 0.0),
#  ('cells death processes associated with hypersensitive induced reaction',
#   0.0),
#  ('clinical application to investigate the effect of hirsutenone', 0.0),
#  ('compared to baseline figure 5 hypoxia induced relaxation', 0.0),
#  ('constructed a rat model of hepatic ischemia reperfusion', 0.0),
#  ('criteria versus hir negative patients high intermediate risk', 0.0),
#  ('cx geissoschizine methyl ether gm hirsuteine hte hirsutine', 0.0),
#  ('cy5 5 fh nanoparticles a heat induced radiolabeling', 0.0),
#  ('denser with higher bmd in high intensity running', 0.0),
#  ('effect of frc is a high irradiation response', 0.0),
#  ('exerts a protect effect in hepatic ischemia reperfusion', 0.0),
#  ('fh nanoparticles nps undergo a heat induced radiolabeling', 0.0),
#  ('filtered back projection fbp and hybrid image reconstruction', 0.0),
#  ('fluorescence click attachment of fluorochromes and by radioactivity', 0.0),
#  ('four cadavers were assess in hyperextended internal rotation', 0.0),
#  ('functions of serine residues in human insulin receptor', 0.0),
#  ('gc geissoschizine methyl ether gm hirsuteine hte hirsutine', 0.0),
#  ('gene therapy we hypothesized that preparative hepatic irradiation', 0.0),
#  ('genetically engineered mab against the human insulin receptor', 0.0),
#  ('group con ii high intensity resistance exercise group', 0.0),
#  ('h2s can protect against hepatic ischemia reperfusion injury', 0.0),
#  ('heart brain and kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('hepatic ischemia followed by 5 h of reperfusion', 0.0),
#  ('higher bmd was observation in high intensity running', 0.0),
#  ('ho 1 pathway active during hepatic ischemia reperfusion', 0.0),
#  ('hypersensitive response hr pgsc0003dmg400025335 hypersensitive induced reaction protein',
#   0.0),
#  ('icx geissoschizine methyl ether gm hirsuteine hte hirsutine', 0.0),
#  ('involved in ali induced by hepatic ischemia reperfusion', 0.0),
#  ('is a mab against the human insulin receptor', 0.0),
#  ('is due to the fr high irradiation response', 0.0),
#  ('ischemia ctr hepatic reperfusion group with no intervention', 0.0),
#  ('leg the means range of hip internal rotation', 0.0),
#  ('liver cells we hypothesized that preparative hepatic irradiation', 0.0),
#  ('monoclonal antibody mab to the human insulin receptor', 0.0),
#  ('multilocularis emir d melanogaster dmir and homo sapiens', 0.0),
#  ('nanoparticles nps is present whereby heat induced radiolabeling', 0.0),
#  ('observation that the testes of high infertility risk', 0.0),
#  ('obstetrics stage ≥ ii and high intermediate risk', 0.0),
#  ('of breast cancer patients with high immune response', 0.0),
#  ('of extensive investigate 15 the human insulin receptor', 0.0),
#  ('of the alpha subunit of human insulin receptor', 0.0),
#  ('of yeast gene 77 deleting the histone regulatory', 0.0),
#  ('ovary cho cells overexpress the human insulin receptor', 0.0),
#  ('oxidative damage was determine during hepatic ischemia reperfusion', 0.0),
#  ('part in the control of human insulin receptor', 0.0),
#  ('patients who were deemed as high intermediate risk', 0.0),
#  ('percent least squares means for haploid induction rate', 0.0),
#  ('qp and lycopene lyc on hepatic ischemia reperfusion', 0.0),
#  ('rat aortas the mechanism of hypoxia induced relaxation', 0.0),
#  ('reduced h3k9ac steady state levels the histone regulatory', 0.0),
#  ('regimen we have earlier demonstrate that hepatic irradiation', 0.0),
#  ('remote lung injury after hir hepatic ischemia reperfusion', 0.0),
#  ('responders lir and in eight high insulin responders', 0.0),
#  ('response lir and eight with high insulin response', 0.0),
#  ('response lir n = 70 high immune response', 0.0),
#  ('role in the development of hepatic ischemia reperfusion', 0.0),
#  ('rounds of chromosome replication this heat induced replication', 0.0),
#  ('s cerevisiae these include the four histone regulatory', 0.0),
#  ('s serum with autoantibodies against human insulin receptor', 0.0),
#  ('screen these include the evolutionarily conserved histone regulatory', 0.0),
#  ('shown in stage patients with high intermediate risk', 0.0),
#  ('stably overexpress high levels of human insulin receptor', 0.0),
#  ('stage liver disease the result hepatic ischemia reperfusion', 0.0),
#  ('statistically significantly difference in the hypoxia induced relaxation',
#   0.0),
#  ('structure between the sjirs and homo sapiens ir', 0.0),
#  ('survival patients were deemed as high intermediate risk', 0.0),
#  ('that is similar to the hypersensitive induced reaction', 0.0),
#  ('the folding and trafficking of human insulin receptor', 0.0),
#  ('the mechanism of action of heavy ion radiation', 0.0),
#  ('the role of h2s in hepatic ischemia reperfusion', 0.0),
#  ('the role of idh2 in hepatic ischemia reperfusion', 0.0),
#  ('to acetylcholine achir and to reduced po 2', 0.0),
#  ('to clinical application we have explored hepatic irradiation', 0.0),
#  ('to combat against hepatocyte damage hepatic ischemia reperfusion', 0.0),
#  ('to determine the effect of heavy ion radiation', 0.0),
#  ('to inhibit germination via the high irradiation response', 0.0),
#  ('to optimize the levels of hybrid iterative reconstruction', 0.0),
#  ('tomography ct protocols using a hybrid iterative reconstruction', 0.0),
#  ('tomography spect image using a heat induced radiolabeling', 0.0),
#  ('untreated testes red bars represent high infertility risk', 0.0),
#  ('urolithiasis detection can be safely reduced by 40', 0.0),
#  ('was investigate in rabbits during hepatic ischemia reperfusion', 0.0),
#  ('was restored by tempol administration hypoxia induced relaxation', 0.0),
#  ('was to assess the performance of hybrid ir', 0.0),
#  ('weston et al 2007 instead high intensity running', 0.0),
#  ('with the mab against the human insulin receptor', 0.0),
#  ('yeast two hybrid method the hypersensitive induced reaction', 0.0),
#  ('25 of yeast gene 77 deleting the histone regulatory', 0.0),
#  ('a monoclonal antibody mab against the human insulin receptor', 0.0),
#  ('ability to combat against hepatocyte damage hepatic ischemia reperfusion',
#   0.0),
#  ('active weston et al 2007 instead high intensity running', 0.0),
#  ('alleviate remote lung injury after hir hepatic ischemia reperfusion', 0.0),
#  ('an alternative approach that consists of preparative hepatic irradiation',
#   0.0),
#  ('an apple fruit peel cdna library hypersensitive induced reaction', 0.0),
#  ('analysis of breast cancer patients with high immune response', 0.0),
#  ('and antihyperlipidemic effect of hemidesmus indicus linn r root', 0.0),
#  ('and apoptosis after hir hepatic ischemia and reperfusion injury', 0.0),
#  ('and cy5 5 fh nanoparticles a heat induced radiolabeling', 0.0),
#  ('and denser with higher bmd in high intensity running', 0.0),
#  ('and obstetrics stage ≥ ii and high intermediate risk', 0.0),
#  ('antagonistic effect of frc is a high irradiation response', 0.0),
#  ('are involved in ali induced by hepatic ischemia reperfusion', 0.0),
#  ('attempt to optimize the levels of hybrid iterative reconstruction', 0.0),
#  ('by fluorescence click attachment of fluorochromes and by radioactivity',
#   0.0),
#  ('can alleviate lung injury induced by hepatic ischemia reperfusion', 0.0),
#  ('cells and suppresses the development of humoral immune response', 0.0),
#  ('characterized a direct role of the histone information regulator', 0.0),
#  ('chimeric monoclonal antibody mab against the human insulin receptor', 0.0),
#  ('chromatin assembly factor 1 caf 1 and histone regulator', 0.0),
#  ('computed tomography ct protocols using a hybrid iterative reconstruction',
#   0.0),
#  ('computed tomography spect image using a heat induced radiolabeling', 0.0),
#  ('conserved structure between the sjirs and homo sapiens ir', 0.0),
#  ('control group con ii high intensity resistance exercise group', 0.0),
#  ('corynoxeine cx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('could attenuate lung injury induced by hepatic ischemia reperfusion', 0.0),
#  ('dark arrested g2 cells evoking a high irradiation response', 0.0),
#  ('demonstrate a direct role for the histone information regulator', 0.0),
#  ('dominant leg the means range of hip internal rotation', 0.0),
#  ('e multilocularis emir d melanogaster dmir and homo sapiens', 0.0),
#  ('end stage liver disease the result hepatic ischemia reperfusion', 0.0),
#  ('endogenous bbb receptor such as the human insulin receptor', 0.0),
#  ('extra rounds of chromosome replication this heat induced replication', 0.0),
#  ('feraheme fh nanoparticles nps undergo a heat induced radiolabeling', 0.0),
#  ('folding assembly and transport of the human insulin receptor', 0.0),
#  ('followed the folding and trafficking of human insulin receptor', 0.0),
#  ('for urolithiasis detection can be safely reduced by 40', 0.0),
#  ('free survival patients were deemed as high intermediate risk', 0.0),
#  ('from four cadavers were assess in hyperextended internal rotation', 0.0),
#  ('genetically screen these include the evolutionarily conserved histone regulatory',
#   0.0),
#  ('glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('group was restored by tempol administration hypoxia induced relaxation',
#   0.0),
#  ('hamster ovary cho cells overexpress the human insulin receptor', 0.0),
#  ('hepatic ischemia ctr hepatic reperfusion group with no intervention', 0.0),
#  ('horse is a mab against the human insulin receptor', 0.0),
#  ('host liver cells we hypothesized that preparative hepatic irradiation',
#   0.0),
#  ('immune response lir n = 70 high immune response', 0.0),
#  ('in percent least squares means for haploid induction rate', 0.0),
#  ('in rat aortas the mechanism of hypoxia induced relaxation', 0.0),
#  ('in reduced h3k9ac steady state levels the histone regulatory', 0.0),
#  ('in s cerevisiae these include the four histone regulatory', 0.0),
#  ('increase compared to baseline figure 5 hypoxia induced relaxation', 0.0),
#  ('insulin responders lir and in eight high insulin responders', 0.0),
#  ('insulin response lir and eight with high insulin response', 0.0),
#  ('investigate the mechanism of action of heavy ion radiation', 0.0),
#  ('investigate the role of h2s in hepatic ischemia reperfusion', 0.0),
#  ('investigate the role of idh2 in hepatic ischemia reperfusion', 0.0),
#  ('ipc was investigate in rabbits during hepatic ischemia reperfusion', 0.0),
#  ('isocorynoxeine icx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('key role in the development of hepatic ischemia reperfusion', 0.0),
#  ('levels below a critical threshold indicated high infertility risk', 0.0),
#  ('lir untreated testes red bars represent high infertility risk', 0.0),
#  ('liver heart brain and kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('liver oxidative damage was determine during hepatic ischemia reperfusion',
#   0.0),
#  ('low amounts of light and the high irradiation response', 0.0),
#  ('no statistically significantly difference in the hypoxia induced relaxation',
#   0.0),
#  ('nrf2 ho 1 pathway active during hepatic ischemia reperfusion', 0.0),
#  ('of a chimeric mab against the human insulin receptor', 0.0),
#  ('of patients who were deemed as high intermediate risk', 0.0),
#  ('operates to inhibit germination via the high irradiation response', 0.0),
#  ('partial hepatic ischemia followed by 5 h of reperfusion', 0.0),
#  ('patients s serum with autoantibodies against human insulin receptor', 0.0),
#  ('phya is due to the fr high irradiation response', 0.0),
#  ('potential functions of serine residues in human insulin receptor', 0.0),
#  ('preparative regimen we have earlier demonstrate that hepatic irradiation',
#   0.0),
#  ('protein that is similar to the hypersensitive induced reaction', 0.0),
#  ('protein with the mab against the human insulin receptor', 0.0),
#  ('quinapril qp and lycopene lyc on hepatic ischemia reperfusion', 0.0),
#  ('rabbits animals were randomized into two experimental group 1st', 0.0),
#  ('regions of the alpha subunit of human insulin receptor', 0.0),
#  ('response to acetylcholine achir and to reduced po 2', 0.0),
#  ('restrict cells death processes associated with hypersensitive induced reaction',
#   0.0),
#  ('risk criteria versus hir negative patients high intermediate risk', 0.0),
#  ('significantly higher bmd was observation in high intensity running', 0.0),
#  ('stress and hepatocyte death and attenuate hepatic ischaemia reperfusion',
#   0.0),
#  ('study was to assess the performance of hybrid ir', 0.0),
#  ('subject of extensive investigate 15 the human insulin receptor', 0.0),
#  ('such as the mab against the human insulin receptor', 0.0),
#  ('sulfide h2s can protect against hepatic ischemia reperfusion injury', 0.0),
#  ('table 4 least squares means for haploid induction rate', 0.0),
#  ('take part in the control of human insulin receptor', 0.0),
#  ('targeted nanoparticles nps is present whereby heat induced radiolabeling',
#   0.0),
#  ('the ad spermatogonia are absent in high infertility risk', 0.0),
#  ('the assess of urolithiasis can be reduced by 40', 0.0),
#  ('the hypersensitive response hr pgsc0003dmg400025335 hypersensitive induced reaction protein',
#   0.0),
#  ('the observation that the testes of high infertility risk', 0.0),
#  ('the yeast two hybrid method the hypersensitive induced reaction', 0.0),
#  ('their clinical application to investigate the effect of hirsutenone', 0.0),
#  ('translation to clinical application we have explored hepatic irradiation',
#   0.0),
#  ('two basal like enriched clusters c2 lir and c3', 0.0),
#  ('vivo gene therapy we hypothesized that preparative hepatic irradiation',
#   0.0),
#  ('was shown in stage patients with high intermediate risk', 0.0),
#  ('was to determine the effect of heavy ion radiation', 0.0),
#  ('we constructed a rat model of hepatic ischemia reperfusion', 0.0),
#  ('which stably overexpress high levels of human insulin receptor', 0.0),
#  ('with asf1a to be orthologous to yeast histone regulator', 0.0),
#  ('with filtered back projection fbp and hybrid image reconstruction', 0.0),
#  ('a chimeric monoclonal antibody mab against the human insulin receptor',
#   0.0),
#  ('a key role in the development of hepatic ischemia reperfusion', 0.0),
#  ('a patients s serum with autoantibodies against human insulin receptor',
#   0.0),
#  ('a preparative regimen we have earlier demonstrate that hepatic irradiation',
#   0.0),
#  ('a significantly higher bmd was observation in high intensity running', 0.0),
#  ('abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('also operates to inhibit germination via the high irradiation response',
#   0.0),
#  ('an endogenous bbb receptor such as the human insulin receptor', 0.0),
#  ('an engineered monoclonal antibody mab against the human insulin receptor',
#   0.0),
#  ('and liver oxidative damage was determine during hepatic ischemia reperfusion',
#   0.0),
#  ('antioxidant ability to combat against hepatocyte damage hepatic ischemia reperfusion',
#   0.0),
#  ('as chromatin assembly factor 1 caf 1 and histone regulator', 0.0),
#  ('benefit was shown in stage patients with high intermediate risk', 0.0),
#  ('brg1 can alleviate lung injury induced by hepatic ischemia reperfusion',
#   0.0),
#  ('by the observation that the testes of high infertility risk', 0.0),
#  ('chain of a chimeric mab against the human insulin receptor', 0.0),
#  ('classes table 4 least squares means for haploid induction rate', 0.0),
#  ('cx isocorynoxeine icx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('dose for urolithiasis detection can be safely reduced by 40', 0.0),
#  ('efs analysis of breast cancer patients with high immune response', 0.0),
#  ('emission computed tomography spect image using a heat induced radiolabeling',
#   0.0),
#  ('ex vivo gene therapy we hypothesized that preparative hepatic irradiation',
#   0.0),
#  ('extreme low amounts of light and the high irradiation response', 0.0),
#  ('factor are involved in ali induced by hepatic ischemia reperfusion', 0.0),
#  ('fh and cy5 5 fh nanoparticles a heat induced radiolabeling', 0.0),
#  ('fibroblasts which stably overexpress high levels of human insulin receptor',
#   0.0),
#  ('for the assess of urolithiasis can be reduced by 40', 0.0),
#  ('for translation to clinical application we have explored hepatic irradiation',
#   0.0),
#  ('fusion protein with the mab against the human insulin receptor', 0.0),
#  ('genetically engineered monoclonal antibody mab against the human insulin receptor',
#   0.0),
#  ('gynecology and obstetrics stage ≥ ii and high intermediate risk', 0.0),
#  ('hir risk criteria versus hir negative patients high intermediate risk',
#   0.0),
#  ('horse such as the mab against the human insulin receptor', 0.0),
#  ('i control group con ii high intensity resistance exercise group', 0.0),
#  ('icx corynoxeine cx geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   0.0),
#  ('in dark arrested g2 cells evoking a high irradiation response', 0.0),
#  ('in nrf2 ho 1 pathway active during hepatic ischemia reperfusion', 0.0),
#  ('in response to acetylcholine achir and to reduced po 2', 0.0),
#  ('inflammation and apoptosis after hir hepatic ischemia and reperfusion injury',
#   0.0),
#  ('interacts with asf1a to be orthologous to yeast histone regulator', 0.0),
#  ('is a genetically engineered mab against the human insulin receptor', 0.0),
#  ('ketamine could attenuate lung injury induced by hepatic ischemia reperfusion',
#   0.0),
#  ('kv computed tomography ct protocols using a hybrid iterative reconstruction',
#   0.0),
#  ('like and denser with higher bmd in high intensity running', 0.0),
#  ('limit their clinical application to investigate the effect of hirsutenone',
#   0.0),
#  ('lir the ad spermatogonia are absent in high infertility risk', 0.0),
#  ('low immune response lir n = 70 high immune response', 0.0),
#  ('low insulin responders lir and in eight high insulin responders', 0.0),
#  ('low insulin response lir and eight with high insulin response', 0.0),
#  ('low levels below a critical threshold indicated high infertility risk',
#   0.0),
#  ('microbial cells and suppresses the development of humoral immune response',
#   0.0),
#  ('multimodal targeted nanoparticles nps is present whereby heat induced radiolabeling',
#   0.0),
#  ('no hepatic ischemia ctr hepatic reperfusion group with no intervention',
#   0.0),
#  ('no in rat aortas the mechanism of hypoxia induced relaxation', 0.0),
#  ('non dominant leg the means range of hip internal rotation', 0.0),
#  ('of a genetically engineered mab against the human insulin receptor', 0.0),
#  ('of extra rounds of chromosome replication this heat induced replication',
#   0.0),
#  ('of partial hepatic ischemia followed by 5 h of reperfusion', 0.0),
#  ('of phya is due to the fr high irradiation response', 0.0),
#  ('of quinapril qp and lycopene lyc on hepatic ischemia reperfusion', 0.0),
#  ('oxidative stress and hepatocyte death and attenuate hepatic ischaemia reperfusion',
#   0.0),
#  ('paper investigate the mechanism of action of heavy ion radiation', 0.0),
#  ('preconditioning ipc was investigate in rabbits during hepatic ischemia reperfusion',
#   0.0),
#  ('progression free survival patients were deemed as high intermediate risk',
#   0.0),
#  ('pursued an alternative approach that consists of preparative hepatic irradiation',
#   0.0),
#  ('putative protein that is similar to the hypersensitive induced reaction',
#   0.0),
#  ('refereeing active weston et al 2007 instead high intensity running', 0.0),
#  ('result in reduced h3k9ac steady state levels the histone regulatory', 0.0),
#  ('risk lir untreated testes red bars represent high infertility risk', 0.0),
#  ('screen in s cerevisiae these include the four histone regulatory', 0.0),
#  ('se group was restored by tempol administration hypoxia induced relaxation',
#   0.0),
#  ('shoulders from four cadavers were assess in hyperextended internal rotation',
#   0.0),
#  ('shown in percent least squares means for haploid induction rate', 0.0),
#  ('significantly increase compared to baseline figure 5 hypoxia induced relaxation',
#   0.0),
#  ('slices with filtered back projection fbp and hybrid image reconstruction',
#   0.0),
#  ('study potential functions of serine residues in human insulin receptor',
#   0.0),
#  ('study was to determine the effect of heavy ion radiation', 0.0),
#  ('subgroup of patients who were deemed as high intermediate risk', 0.0),
#  ('superparamagnetism by fluorescence click attachment of fluorochromes and by radioactivity',
#   0.0),
#  ('the antagonistic effect of frc is a high irradiation response', 0.0),
#  ('the conserved structure between the sjirs and homo sapiens ir', 0.0),
#  ('the folding assembly and transport of the human insulin receptor', 0.0),
#  ('the host liver cells we hypothesized that preparative hepatic irradiation',
#   0.0),
#  ('the liver heart brain and kidney 1 hepatic ischaemia reperfusion', 0.0),
#  ('the subject of extensive investigate 15 the human insulin receptor', 0.0),
#  ('the two basal like enriched clusters c2 lir and c3', 0.0),
#  ('this study was to assess the performance of hybrid ir', 0.0),
#  ('through an apple fruit peel cdna library hypersensitive induced reaction',
#   0.0),
#  ('through genetically screen these include the evolutionarily conserved histone regulatory',
#   0.0),
#  ('to alleviate remote lung injury after hir hepatic ischemia reperfusion',
#   0.0),
#  ('to attempt to optimize the levels of hybrid iterative reconstruction', 0.0),
#  ('to investigate the role of h2s in hepatic ischemia reperfusion', 0.0),
#  ('to restrict cells death processes associated with hypersensitive induced reaction',
#   0.0),
#  ('to take part in the control of human insulin receptor', 0.0),
#  ('trojan horse is a mab against the human insulin receptor', 0.0),
#  ('using the yeast two hybrid method the hypersensitive induced reaction',
#   0.0),
#  ('was no statistically significantly difference in the hypoxia induced relaxation',
#   0.0),
#  ('we characterized a direct role of the histone information regulator', 0.0),
#  ('we demonstrate a direct role for the histone information regulator', 0.0),
#  ('we followed the folding and trafficking of human insulin receptor', 0.0),
#  ('we investigate the role of idh2 in hepatic ischemia reperfusion', 0.0),
#  ('whereby feraheme fh nanoparticles nps undergo a heat induced radiolabeling',
#   0.0),
#  ('with end stage liver disease the result hepatic ischemia reperfusion', 0.0),
#  ('~ 25 of yeast gene 77 deleting the histone regulatory', 0.0),
#  ('1 brg1 can alleviate lung injury induced by hepatic ischemia reperfusion',
#   0.0),
#  ('1 fibroblasts which stably overexpress high levels of human insulin receptor',
#   0.0),
#  ('12 low insulin responders lir and in eight high insulin responders', 0.0),
#  ('a fusion protein with the mab against the human insulin receptor', 0.0),
#  ('a genetically engineered monoclonal antibody mab against the human insulin receptor',
#   0.0),
#  ('a putative protein that is similar to the hypersensitive induced reaction',
#   0.0),
#  ('a subgroup of patients who were deemed as high intermediate risk', 0.0),
#  ('addition we demonstrate a direct role for the histone information regulator',
#   0.0),
#  ('against an endogenous bbb receptor such as the human insulin receptor',
#   0.0),
#  ('and 2 e multilocularis emir d melanogaster dmir and homo sapiens', 0.0),
#  ('and ex vivo gene therapy we hypothesized that preparative hepatic irradiation',
#   0.0),
#  ('and interacts with asf1a to be orthologous to yeast histone regulator',
#   0.0),
#  ('and progression free survival patients were deemed as high intermediate risk',
#   0.0),
#  ('been the subject of extensive investigate 15 the human insulin receptor',
#   0.0),
#  ('between the two basal like enriched clusters c2 lir and c3', 0.0),
#  ('by a preparative regimen we have earlier demonstrate that hepatic irradiation',
#   0.0),
#  ('by extreme low amounts of light and the high irradiation response', 0.0),
#  ('chain of a genetically engineered mab against the human insulin receptor',
#   0.0),
#  ('complexes in nrf2 ho 1 pathway active during hepatic ischemia reperfusion',
#   0.0),
#  ('disease shoulders from four cadavers were assess in hyperextended internal rotation',
#   0.0),
#  ('division in dark arrested g2 cells evoking a high irradiation response',
#   0.0),
#  ('domain is a monoclonal antibody mab against the human insulin receptor',
#   0.0),
#  ('dose for the assess of urolithiasis can be reduced by 40', 0.0),
#  ('effect limit their clinical application to investigate the effect of hirsutenone',
#   0.0),
#  ('effect of quinapril qp and lycopene lyc on hepatic ischemia reperfusion',
#   0.0),
#  ('examined the folding assembly and transport of the human insulin receptor',
#   0.0),
#  ('from a patients s serum with autoantibodies against human insulin receptor',
#   0.0),
#  ('furthermore we characterized a direct role of the histone information regulator',
#   0.0),
#  ...]

# %%
longforms0
# Out:
# [('hepatic ischemia reperfusion', 16.666666666666664),
#  ('the human insulin receptor', 12.0),
#  ('response', 6.363636363636363),
#  ('risk', 4.444444444444445),
#  ('hepatic irradiation', 3.0),
#  ('hypoxia induced relaxation', 3.0),
#  ('e abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   3),
#  ('histone regulatory', 2.8),
#  ('hypersensitive induced reaction', 2.5),
#  ('regulator', 2.0),
#  ('a heat induced radiolabeling', 2.0),
#  ('reconstruction', 1.5),
#  ('high intensity running', 1.3333333333333333)]

# %%
longforms = [l for i, l in enumerate(longforms0) if i not in [1]]

# %%
longforms.extend([top[i] for i in [2]])

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms
# Out:
# [('hepatic ischemia reperfusion', 16.666666666666664),
#  ('human insulin receptor', 10.0),
#  ('response', 6.363636363636363),
#  ('risk', 4.444444444444445),
#  ('hepatic irradiation', 3.0),
#  ('hypoxia induced relaxation', 3.0),
#  ('e abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine',
#   3),
#  ('histone regulatory', 2.8),
#  ('hypersensitive induced reaction', 2.5),
#  ('regulator', 2.0),
#  ('a heat induced radiolabeling', 2.0),
#  ('reconstruction', 1.5),
#  ('high intensity running', 1.3333333333333333)]

# %%
longforms, scores = zip(*longforms)

# %%
grounding_map = {}
for longform in longforms:
    try:
        grounding = gilda_ground(longform)
    except Exception:
        print(longform)
        continue
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'

# %%
HIR_disamb = load_disambiguator('HIR', path='../results')
# Out:
# WARNING: [2019-12-19 14:41:29] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
HIR_disamb.names
# Out:
# {'MESH:D015427': 'Reperfusion Injury', 'HGNC:6091': 'INSR'}

# %%
result = ground_with_gui(longforms, scores, grounding_map=HIR_disamb.grounding_dict['HIR'],
                         names=HIR_disamb.names)

# %%
grounding_map, names, pos_labels = result

# %%
names['HGNC:6265'] = 'KCNJ4'

# %%
pos_labels.append('HGNC:6265')

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'a heat induced radiolabeling': 'ungrounded',
#   'e abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine': 'ungrounded',
#   'hepatic irradiation': 'ungrounded',
#   'hepatic ischemia reperfusion': 'MESH:D015427',
#   'high intensity running': 'ungrounded',
#   'histone regulatory': 'ungrounded',
#   'human insulin receptor': 'HGNC:6091',
#   'hypersensitive induced reaction': 'ungrounded',
#   'hypoxia induced relaxation': 'ungrounded',
#   'reconstruction': 'ungrounded',
#   'regulator': 'ungrounded',
#   'response': 'ungrounded',
#   'risk': 'ungrounded'},
#  {'MESH:D015427': 'Reperfusion Injury',
#   'HGNC:6091': 'INSR',
#   'HGNC:6265': 'KCNJ4'},
#  ['HGNC:6091', 'MESH:D015427', 'HGNC:6265'])

# %%
grounding_map, names, pos_labels = \
 ({'a heat induced radiolabeling': 'ungrounded',
  'e abbreviations glycycoumarin gc geissoschizine methyl ether gm hirsuteine hte hirsutine': 'ungrounded',
  'hepatic irradiation': 'ungrounded',
  'hepatic ischemia reperfusion': 'MESH:D015427',
  'high intensity running': 'ungrounded',
  'histone regulatory': 'ungrounded',
  'human insulin receptor': 'HGNC:6091',
  'hypersensitive induced reaction': 'ungrounded',
  'hypoxia induced relaxation': 'ungrounded',
  'reconstruction': 'ungrounded',
  'regulator': 'ungrounded',
  'response': 'ungrounded',
  'risk': 'ungrounded'},
 {'MESH:D015427': 'Reperfusion Injury',
  'HGNC:6091': 'INSR',
  'HGNC:6265': 'KCNJ4'},
 ['HGNC:6091', 'MESH:D015427', 'HGNC:6265'])

# %%
grounding_dict = {'HIR': grounding_map}

# %%
classifier = AdeftClassifier('HIR', pos_labels)

# %%
param_grid = {'C': [10.0, 100.0], 'max_features': [1000, 10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2019-12-19 14:45:42] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [10.0, 100.0], 'max_features': [1000, 10000]}
# INFO: [2019-12-19 14:46:30] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.975740189131273 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 1000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'HGNC:6091': 593,
#   'ungrounded': 36,
#   'MESH:D015427': 15,
#   'HGNC:6265': 36},
#  'f1': {'mean': 0.975740189131273, 'std': 0.012512247371838816},
#  'precision': {'mean': 0.9799997587377456, 'std': 0.004034874113382134},
#  'recall': {'mean': 0.9737022957662493, 'std': 0.022027914431823326}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
preds = disamb.disambiguate(shortform_texts)

# %%
a = [text for text, pred in zip(shortform_texts, preds) if pred[0] == 'HGNC:6265']

# %%
a[1]
# Out:
# 'The effects of different extracellular cations or organic Ca(2+)-channel modulators on complement-induced changes in intracellular Ca2+ and cell death have been investigated in the transfected NIH-3T3 HIR 3.5 cell line, which overexpresses the human insulin receptor. Cells were incubated with mouse anti-(human insulin receptor) monoclonal antibodies before exposure to rabbit or human serum (sources of heterologous complement). Changes in intracellular Ca2+ were complement-dependent (measured by influx of 45Ca), as was cytotoxicity (monitored by leakage of lactate dehydrogenase into the culture supernatant). Addition of a dihydropyridine Ca(2+)-channel antagonist (nifedipine) or some bivalent inorganic cations caused inhibition of 45Ca entry via a novel channel distinct from endogenous voltage-gated Ca2+ channels. Nifedipine decreased, but conversely the addition of a phenylalkylamine Ca(2+)-channel antagonist (verapamil) or the inorganic Ca2+ agonists Ba2+ and Sr+ increased, complement-induced cytotoxicity. These agents had no effect on cell viability at the studied concentrations, in the absence of complement. It is concluded that complement-induced cytotoxicity is mediated by Ca2+ influx through novel specific transmembrane channels which are sensitive to the Ca(2+)-channel antagonist nifedipine, but otherwise show little resemblance to L- or T-type voltage-gated Ca2+ channels.\n'

# %%
model_to_s3(disamb)

# %%
disamb.dump('GARP', '../results')

# %%
model_to_s3(disamb)

# %%
d = load_disambiguator('GARP', '../results')

# %%
preds = disamb.disambiguate(shortform_texts)

# %%
a = [text for text, pred in zip(shortform_texts, preds) if pred[0] == 'HGNC:2151']

# %%
len(a)
# Out:
# 8

# %%
a[2]
# Out:
# "Other support for this stabilizing hypothesis comes from studies on the beta-subunit of the rod cyclic nucleotide gated channel (CNG). It has been shown that PRPH2/RDS can bind to the beta subunit of rod CNG, as well as two other non-membrane bound isoforms also coded for by the  Cngb1  gene called glutamic acid rich proteins (GARP1/2) ( Poetsch et\xa0al., 2001; Ritter et\xa0al., 2011 ). The interactions between GARP and PRPH2/RDS were found to be strongest when PRPH2/RDS was in disulfide linked oligomers suggesting the larger PRPH2/RDS complexes might mediate this interaction ( Poetsch et\xa0al., 2001 ). Given the localization of CNGB1 on the plasma membrane, PRPH2/RDS on the disc rim, and GARP1/2 as free cytosolic forms in between, it has been hypothesized that interactions between PRPH2/RDS and GARP could serve as a mechanism by which PRPH2/RDS could regulate the sizing and orientation of the rod discs. In support of this, elimination of GARP in rods causes disorganization in disc sizing and orientation ( Zhang et\xa0al., 2009 ).\nWork assessing the localization of PRPH2/RDS complexes in the photoreceptor cells found that the higher-order PRPH2/RDS oligomers likely don't form until after trafficking to the OS ( Chakraborty et\xa0al., 2008; Poetsch et\xa0al., 2001 ). Since covalently linked PRPH2/RDS has a higher affinity for GARP than non-covalently linked PRPH2/RDS, the assembly of large PRPH2/RDS oligomers in the OS could potentially play a role in spatially or temporally regulating the RDS/GARP interaction, and thus disc size and orientation. This idea is supported by experiments that utilized GFP chimeric proteins to map the subcellular compartments where RDS/CNGB1/GARP interactions took place and showed that while PRPH2/RDS and CNGB1 interact during trafficking, PRPH2/RDS and GARP only interacted in the OS ( Ritter et\xa0al., 2011 ).\nInteractions with GARP are another example of differing roles/function of PRPH2/RDS in rods vs. cones. The cone CNGB subunit does not have a GARP region or free GARP isoforms and PRPH2/RDS does not interact with the cone CNGB channel ( Conley et\xa0al., 2010a ). The precise role of PRPH2/RDS interactions with other proteins, such as GARP, to OS organization is not clearly established, however the model that these interactions play an important role in OS organization is well-supported. In addition, tetraspanins are frequently organizers of membrane domains that can mediate interactions with signaling molecules and cellular structural components in other tissues, so a role for PRPH2/RDS in similar functions is consistent with its larger superfamily ( Andreu and Yanez-Mo, 2014 ).\nThe PRPH2/RDS protein is a critical component for normal vision through its role as a structural protein important for the proper formation of both rod and cone photoreceptor cells. While this is clearly established there is still considerable debate about how exactly PRPH2/RDS is able to fulfill its critical functions. A central remaining question is what the relative functions of the various PRPH2/RDS complexes are. When viewed as a whole, the body of work on the PRPH2/RDS protein strongly suggests that the protein is able to play a complex role in OS formation due to variations in binding affinity for other OS proteins and the relative concentration of the various PRPH2/RDS complexes, which each may possess intrinsic membrane curvature/fusion properties. For example, it is hypothetically possible that large PRPH2/RDS homomeric complexes are core structural components responsible for helping mediate and maintain the curvature of the rim region while smaller and intermediate RDS/ROM-1 complexes are responsible for mediating membrane fusion or organizing protein domains with interacting partners such as GARP to stabilize and properly structure the OS. While ample evidence discussed above would suggest that the PRPH2/RDS complexes have some level of distinct functional importance, no current evidence can adequatel ...

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
i = 2
j = 4

# %%
i |= j

# %%
i = i | j
# Out:
# 4

# %%
i
# Out:
# 6

# %%
d = load_disambiguator('SNS', path='../results/')
# Out:
# WARNING: [2019-12-19 14:21:25] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.grounding_dict
# Out:
# {'SNS': {'sacral nerve stimulation': 'ungrounded',
#   'secondary neurospheres': 'ungrounded',
#   'serevent nationwide surveillance': 'ungrounded',
#   'short nascent dna strands': 'ungrounded',
#   'sini san': 'ungrounded',
#   'sinisan': 'ungrounded',
#   'social networking sites': 'ungrounded',
#   'sympathetic': 'MESH:D013564',
#   'sympathetic nerve stimulation': 'MESH:D013564',
#   'sympathetic nerve system': 'MESH:D013564',
#   'sympathetic nervous system': 'MESH:D013564'}}
