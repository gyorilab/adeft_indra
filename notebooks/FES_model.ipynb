# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['FES']
genes = ['FES']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['FES']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['FES'].top()

# %%
top
# Out:
# [('functional electrical stimulation', 175.17391304347825),
#  ('fat embolism syndrome', 25.368421052631575),
#  ('syndrome', 13.5),
#  ('of functional electrical stimulation', 12.25),
#  ('and functional electrical stimulation', 11.846153846153847),
#  ('first episode schizophrenia', 10.83333333333333),
#  ('electrical stimulation', 7.858695652173907),
#  ('floppy eyelid syndrome', 7.5),
#  ('schizophrenia', 6.470588235294118),
#  ('fluoroestradiol', 6.0),
#  ('effects of functional electrical stimulation', 5.142857142857142),
#  ('free energy surface', 5.0),
#  ('with functional electrical stimulation', 5.0),
#  ('as functional electrical stimulation', 3.6666666666666665),
#  ('that functional electrical stimulation', 3.6),
#  ('through functional electrical stimulation', 3.6),
#  ('estradiol', 3.142857142857143),
#  ('by functional electrical stimulation', 3.0),
#  ('during functional electrical stimulation', 3.0),
#  ('induced by functional electrical stimulation', 3.0),
#  ('patients with first episode schizophrenia', 3.0),
#  ('control functional electrical stimulation', 2.5),
#  ('17β estradiol', 2.4),
#  ('18 f fluoroestradiol', 2.0),
#  ('field electrical stimulation', 2.0),
#  ('fluoro 17β estradiol', 2.0),
#  ('exercise functional electrical stimulation', 2.0),
#  ('first episode of schizophrenia', 2.0),
#  ('for functional electrical stimulation', 2.0),
#  ('include functional electrical stimulation', 2.0),
#  ('the fat embolism syndrome', 2.0),
#  ('the functional electrical stimulation', 2.0),
#  ('such as functional electrical stimulation', 2.0),
#  ('l range of rupert especially for patients with flaccid paralysis functional electrical stimulation',
#   2),
#  ('a functional electrical stimulation', 1.3333333333333333),
#  ('movements functional electrical stimulation', 1.3333333333333333),
#  ('paralysis functional electrical stimulation', 1.3333333333333333),
#  ('the effects of functional electrical stimulation', 1.3333333333333333),
#  ('activation of daily living functional electrical stimulation',
#   1.3333333333333333),
#  ('fluorestradiol', 1.0),
#  ('kinase', 1.0),
#  ('feline sarcoma', 1.0),
#  ('feline sarcoma oncogene', 1.0),
#  ('18f flouro 17β estradiol', 1.0),
#  ('3 functional electrical stimulation', 1.0),
#  ('evaluate 18 f fluoroestradiol', 1),
#  ('f 18 16a fluoroestradiol', 1.0),
#  ('fluorine 18 16α fluoroestradiol', 1),
#  ('in first episode schizophrenia', 1.0),
#  ('injury functional electrical stimulation', 1.0),
#  ('of floppy eyelid syndrome', 1.0),
#  ('or functional electrical stimulation', 1.0),
#  ('over functional electrical stimulation', 1.0),
#  ('term functional electrical stimulation', 1.0),
#  ('today functional electrical stimulation', 1),
#  ('triggered functional electrical stimulation', 1.0),
#  ('use functional electrical stimulation', 1.0),
#  ('without functional electrical stimulation', 1.0),
#  ('brain control functional electrical stimulation', 1.0),
#  ('coexisted with floppy eyelid syndrome', 1.0),
#  ('known as functional electrical stimulation', 1.0),
#  ('of a fat embolism syndrome', 1.0),
#  ('reaching movements functional electrical stimulation', 1.0),
#  ('robotic and functional electrical stimulation', 1),
#  ('showed that functional electrical stimulation', 1.0),
#  ('stimulation and functional electrical stimulation', 1.0),
#  ('the feline sarcoma oncogene protein', 1.0),
#  ('cycling induced by functional electrical stimulation', 1),
#  ('fat embolism and fat embolism syndrome', 1.0),
#  ('muscle contraction through functional electrical stimulation', 1.0),
#  ('of an implanted functional electrical stimulation', 1.0),
#  ('the use of functional electrical stimulation', 1.0),
#  ('to complement exercise functional electrical stimulation', 1),
#  ('to control a functional electrical stimulation', 1.0),
#  ('rapid muscle fatigue during functional electrical stimulation', 1),
#  ('the occurrence of a fat embolism syndrome', 1),
#  ('tritium release evoked by field electrical stimulation', 1),
#  ('16 α 18 f fluoro 17 β oestradiol', 1.0),
#  ('to assess the effects of functional electrical stimulation', 1),
#  ('to examine the related between family ethnic social', 1),
#  ('a patients driven control strategies for functional electrical stimulation',
#   1),
#  ('fat embolism fe and the consequent fat embolism syndrome', 1.0),
#  ('severely ill patients with first episode schizophrenia spectrum disorders',
#   1.0),
#  ('the closed related non receptor tyrosine kinase feline sarcoma', 1),
#  ('to performed activation of daily living functional electrical stimulation',
#   1.0),
#  ('was to determine the effects of functional electrical stimulation', 1.0),
#  ('we have prepared three analogues of 16 alpha fluoroestradiol', 1),
#  ('we have recent demonstrated that c fes protooncogene product', 1),
#  ('de intramuscular electrodes with percutaneous connections during functional electrical stimulation',
#   1),
#  ('in this study two aspects of hybrid functional electrical stimulation', 1),
#  ('may enhance spontaneous regeneration after neurological injury functional electrical stimulation',
#   1),
#  ('on technique neurophysiological and motor learning approach functional electrical stimulation',
#   1),
#  ('ore these include transcutaneous electrical stimulation tens functional electrical stimulation',
#   1),
#  ('passive cycling ergometry quadriceps electrical stimulation and functional electrical stimulation',
#   1),
#  ('previous study have shown beneficial effects of functional electrical stimulation',
#   1),
#  ('reducing stimulation artifacts in intracortical recordings during functional electrical stimulation',
#   1),
#  ('the influence of the addition of a flavour enhance solution', 1),
#  ('the pendulum test was applied to evaluate functional electrical stimulation',
#   1),
#  ('99 lehmann 1993 lehmann condon price delateur 1987 functional electrical stimulation',
#   1),
#  ('a process publication review as a neuroprosthetic technique functional electrical stimulation',
#   1),
#  ('and induced plasticity in supraspinal network brain control functional electrical stimulation',
#   1),
#  ('ankle control after repetitive stimulation were not demonstrated functional electrical stimulation',
#   1),
#  ('arm 5 12 other activation rehabilitation treatment include functional electrical stimulation',
#   1),
#  ('controversial findings are report about the relationship between floppy eyelid syndrome',
#   1),
#  ('dysfunction ed affected approximately 150 million men worldwide functional electrical stimulation',
#   1),
#  ('g paradigms classical visual feedback auditory stimulation and functional electrical stimulation',
#   1),
#  ('he right recurrent laryngeal nerve rln unilateral stimulation functional electrical stimulation',
#   1),
#  ('hwestern university feinberg school of medicine brain control functional electrical stimulation',
#   1),
#  ('improve hand functional and increasing corticomotor excitability are functional electrical stimulation',
#   1),
#  ('individuals with hemiparesis following stroke 2 since 1960 functional electrical stimulation',
#   1),
#  ('ineffective in some patients anecdotal observations suggest that functional electrical stimulation',
#   1),
#  ('m a representative microelectrode channel during single electrodes functional electrical stimulation',
#   1),
#  ('magnetic resonance diffusion tensor imaging dti technology and functional electrical stimulation',
#   1),
#  ('occupational therapy incorporating an actuation modality such as functional electrical stimulation',
#   1),
#  ('ovement clinical system that achieve muscle contraction through functional electrical stimulation',
#   1),
#  ('ranscutaneous electrical nerve stimulation tens group tg and functional electrical stimulation',
#   1),
#  ('reference β actin f gcaaatgcttctaggcggact r caatctcatctcgttttctgcg 84 feline sarcoma oncogene',
#   1),
#  ('result total muscle activation level fatigue phenomena under functional electrical stimulation',
#   1),
#  ('roencephalogram based brain computer interface system to modulate functional electrical stimulation',
#   1),
#  ('the primary goal was to determine whether repetitive functional electrical stimulation',
#   1),
#  ('to summarize the ocular and system associated of floppy eyelid syndrome',
#   1),
#  ('activation movements passive movements and the movements induced by functional electrical stimulation',
#   1),
#  ('adami et al 2007 after denervation the early initiation functional electrical stimulation',
#   1),
#  ('adjunct method of analgesia in postoperative patients 11 and functional electrical stimulation',
#   1),
#  ('ctuations by increasing the trunk stiffness during quiet sitting functional electrical stimulation',
#   1),
#  ('e learning and retaining of normative muscle activation pattern functional electrical stimulation',
#   1),
#  ('e various interventions in stroke patients with neglect syndrome functional electrical stimulation',
#   1),
#  ('egies and assistive technology to facilitate their daily task functional electrical stimulation',
#   1),
#  ('electrical stimulation of peripheral muscle and nerve known as functional electrical stimulation',
#   1),
#  ('en repeated intervals of isometric muscle contraction induced by functional electrical stimulation',
#   1),
#  ('ermore when healthy seniors are exposed to regular neuromuscular functional electrical stimulation',
#   1),
#  ('estive of autonomic dysreflexia ad have been documented during functional electrical stimulation',
#   1),
#  ('even though there are numerous study evaluate effects of functional electrical stimulation',
#   1),
#  ('grasping movements required for many activation of daily living functional electrical stimulation',
#   1),
#  ('ication a tetraplegia through a percutaneous intramuscular i m functional electrical stimulation',
#   1),
#  ('ign that consist of three sessions voluntary contraction only functional electrical stimulation',
#   1),
#  ('linumtoxina injection and task practice training with or without functional electrical stimulation',
#   1),
#  ('mented during the rehabilitation process these consist main of functional electrical stimulation',
#   1),
#  ('mmi is generally introduced by use electromyography emg for functional electrical stimulation',
#   1),
#  ('mprove quality of life brain computer interface bci control functional electrical stimulation',
#   1),
#  ('nction in individuals with hemiparesis following stroke an ideal functional electrical stimulation',
#   1),
#  ('ntervention method for stimulation motor and sensory nerve 3 functional electrical stimulation',
#   1),
#  ('onisation in similar frequency range motor imagination mi and functional electrical stimulation',
#   1),
#  ('ord injury sci previous research showed that neuromuscular or functional electrical stimulation',
#   1),
#  ('passive robotic leg exercise pe and simultaneous provision of functional electrical stimulation',
#   1),
#  ('platelet values increasing erythrocyte sedimentation rate fat embolism and fat embolism syndrome',
#   1),
#  ('provide functional control of paralyzed muscle which is called functional electrical stimulation',
#   1),
#  ('rcise forced exercise and involuntary muscle movements cause by functional electrical stimulation',
#   1),
#  ('recovery progress as well integrating upper limb exoskeleton and functional electrical stimulation',
#   1),
#  ('retinal vein occlusion rvo central serous chorioretinopathy csr and floppy eyelid syndrome',
#   1),
#  ('rolonged p300 latency occurs in patients with schizophrenia especially first episode schizophrenia',
#   1),
#  ('s in knee instability optimisation of muscle contraction through functional electrical stimulation',
#   1),
#  ('scale an alternative technology for generating joint movements is functional electrical stimulation',
#   1),
#  ('the purpose of this study was to develop a functional electrical stimulation',
#   1),
#  ('the study purpose was to determine the effects of functional electrical stimulation',
#   1),
#  ('this is particularly evidence in bci based therapy incorporating functional electrical stimulation',
#   1),
#  ('this work present a low cost system based on flame emission spectroscopy',
#   1),
#  ('= 0 009 demographic and clinical characteristics among patients with first episode schizophrenia',
#   1),
#  ('athophysiological changes these changes result in a clinical syndrome called fat embolism syndrome',
#   1),
#  ('b ul muscle is crucial to achieve proper reaching movements functional electrical stimulation',
#   1),
#  ('ble with and without the assistive of robotic and functional neuromuscular electrical stimulation',
#   1),
#  ('cal spinal cord lesion activation of the abdominal muscle use functional electrical stimulation',
#   1),
#  ('ditional pharmacodynamic analysis in mcf7 xenografts we next monitored tumor 18 f fluoroestradiol',
#   1),
#  ('e exerted while still eliciting effects reaching and hand opening functional electrical stimulation',
#   1),
#  ('e g sip and puff head joysticks brain computer interface functional electrical stimulation',
#   1),
#  ('eason considerable effort has been devoted to the develop of functional electrical stimulation',
#   1),
#  ('ed by a prior successful randomized control trial showed that functional electrical stimulation',
#   1),
#  ('ed into long term rehabilitation to achieve these goal include functional electrical stimulation',
#   1),
#  ('educes exercise capacity our recent work showed that when ad functional electrical stimulation',
#   1),
#  ('future work towards a top down approach for gait rehabilitation functional electrical stimulation',
#   1),
#  ('ic response of leg skeletal muscle during functional electrical stimulation driven unloaded cycling',
#   1),
#  ('ies with limited benefits as compared with leg exercise training functional electrical stimulation',
#   1),
#  ('itation in aging study effects of physical exercise induced by functional electrical stimulation',
#   1),
#  ('ker in situ or other implanted electrical devices were excluded functional electrical stimulation',
#   1),
#  ('le channel odfs pace odstock uk provide heel switch triggered functional electrical stimulation',
#   1),
#  ('le option it might be more therapeutic beneficial to include functional electrical stimulation',
#   1),
#  ('major trauma and cardiopulmonary resuscitation in medical patients 2 5 fat embolism syndrome',
#   1),
#  ('means of reciprocating gait orthosis rgo use with and without functional electrical stimulation',
#   1),
#  ('motor neurones and muscle innervation below the level of injury functional electrical stimulation',
#   1),
#  ('n which the volunteers performed no imagery movements but instead functional electrical stimulation',
#   1),
#  ('nce and may have great potential in future clinical application functional electrical stimulation',
#   1),
#  ('nce of alternative means to impart physical therapy for example functional electrical stimulation',
#   1),
#  ('new treatment hadlock and cheney 2008 include the use of functional electrical stimulation',
#   1),
#  ('ng arm and hand functional in individuals with extension paralysis functional electrical stimulation',
#   1),
#  ('nger and thumb to demonstrated that following c5 c6 tetraplegia functional electrical stimulation',
#   1),
#  ('of central or peripheral origin can potential be treated use functional electrical stimulation',
#   1),
#  ('ollowing stroke evidence supports the use of robotic therapy and functional electrical stimulation',
#   1),
#  ('onal or performed gains nmes has often been characterized as functional electrical stimulation',
#   1),
#  ('or exercise on the visual perception of spatial neglect patients functional electrical stimulation',
#   1),
#  ('osed but the related contribution of each mechanical is unknown functional electrical stimulation',
#   1),
#  ('owever the functional dysconnectivity pattern of sn remains unclear in first episode schizophrenia',
#   1),
#  ('paired gait and balance as well as decreased functional mobility functional electrical stimulation',
#   1),
#  ('period poses diagnostic and therapeutic challenges to the treated physician fat embolism syndrome',
#   1),
#  ('presence of circulation fat globules in circulation and pulmonary parenchyma fat embolism syndrome',
#   1),
#  ('recovery of upper limb functional following stroke see 1 5 functional electrical stimulation',
#   1),
#  ('s from caregivers and reducing economical social cost 2 3 functional electrical stimulation',
#   1),
#  ('ssistance may enable user to performed activation of daily living functional electrical stimulation',
#   1),
#  ('status 44 48 the most successful estrogen radiopharmaceutical 16α 18 f fluoroestradiol 17β',
#   1),
#  ('stimulation electrodes placed on the forearm and it effects over functional electrical stimulation',
#   1),
#  ('terone level than other group some involuntary exercise such as functional electrical stimulation',
#   1),
#  ('th a soft wearable robotic that applied biomechanical loads through functional electrical stimulation',
#   1),
#  ('the clinical outcomes of severely ill patients with first episode schizophrenia spectrum disorders',
#   1),
#  ('tics whether similar abnormalities are also present in medical free first episode schizophrenia',
#   1),
#  ('to study the utility and functional benefits of an implanted functional electrical stimulation',
#   1),
#  ('ttempts 2 manually assistive cough and 3 cough attempts with functional electrical stimulation',
#   1),
#  ('uals with tetraplegia following sci more than 75 indicated that functional electrical stimulation',
#   1),
#  ('ubjects during level walking with and without the application of functional electrical stimulation',
#   1),
#  ('uring oral and maxillofacial radiology omr undergraduate lectures and on final examine scores',
#   1),
#  ('ve normal upper extremity functional 3 months later 2 period functional electrical stimulation',
#   1),
#  ('we develop an electroencephalogram eeg based bci to control a functional electrical stimulation',
#   1),
#  ('with motor impaired of the ul has improve reaching movements functional electrical stimulation',
#   1),
#  ('y use the latest reciprocating gait orthosis rgo combined with functional electrical stimulation',
#   1),
#  ('after sci include the use of robotic exoskeleton 3 4 and functional electrical stimulation',
#   1),
#  ('al cord injury sci the author report that the implanted of functional electrical stimulation',
#   1),
#  ('as a therapeutic tool and to restore lost or damaged functional functional electrical stimulation',
#   1),
#  ('astus lateralis and rectus femoris kim et al 15 showed that functional electrical stimulation',
#   1),
#  ('ble surface area solvation and linear interaction energy lie to strict free energy simulation',
#   1),
#  ('blood clearance and labeled metabolites for the estrogen receptor tracer f 18 16a fluorestradiol',
#   1),
#  ('both greater reaching and the largest hand opening response to fes functional electrical stimulation',
#   1),
#  ('d by electromyography emg of the received s arm which triggered functional electrical stimulation',
#   1),
#  ('d toe clearance while walking 2 short term effects of bilateral functional electrical stimulation',
#   1),
#  ('distress syndrome ards or mechanical obstruction to pulmonary artery flow by massive fat embolism',
#   1),
#  ('ear this study examine the effects of passive limb activation by functional electrical stimulation',
#   1),
#  ('ecystokinin octapeptide did not influence the basal release of 3h da field electrical stimulation',
#   1),
#  ('eful in a top down approach these are assistive robotic devices functional electrical stimulation',
#   1),
#  ('exercise such as cycling or walking wherein it is often term functional electrical stimulation',
#   1),
#  ('g adults and often leads to functional deficits in motor control functional electrical stimulation',
#   1),
#  ('g and blindness this study investigated the utility of closed loop functional electrical stimulation',
#   1),
#  ('hr individuals 26 ultra high risk uhr individuals 58 patients with first episode schizophrenia',
#   1),
#  ('ior work has shown that activation muscle crossing the knee with functional electrical stimulation',
#   1),
#  ('is problem many study have been performed on gait analysis and functional electrical stimulation',
#   1),
#  ('it an individuals s ability to performed activation of daily living functional electrical stimulation',
#   1),
#  ('l diagnoses in a patients present with altered sensorium following surgery fat embolism syndrome',
#   1),
#  ('larger number of patients with sci or stroke have benefits from functional electrical stimulation',
#   1),
#  ('line sample before one of three interventions fasting rest saline frs fasting exercise saline',
#   1),
#  ('m the quadriceps were use to derive knee torque during prolonged functional electrical stimulation',
#   1),
#  ('maximum ankle dorsiflexion in swing in both the barefoot bf and functional electrical stimulation',
#   1),
#  ('n alternative to orthoses in children with spastic cp effects of functional electrical stimulation',
#   1),
#  ('of the impaired motor functional 3 example are bci control of functional electrical stimulation',
#   1),
#  ('on of nuclear medicine university of washington seattle wa abstract f 18 16a fluoroestradiol',
#   1),
#  ('or of acute akathisia in severely ill patients with first episode schizophrenia spectrum disorders',
#   1),
#  ('purpose of this study was to determine the therapeutic effects of functional electrical stimulation',
#   1),
#  ('rapeutic target and use prognostic factor for such patients the feline sarcoma oncogene protein',
#   1),
#  ('rent a technique that has widespread clinical use under the term functional electrical stimulation',
#   1),
#  ('report a case of superficial punctate keratopathy spk which coexisted with floppy eyelid syndrome',
#   1),
#  ('ressure to the abdominal region and or leg upper bodied exercise functional electrical stimulation',
#   1),
#  ('rrent research evidence on response in patients suffering from their first episode of schizophrenia',
#   1),
#  ('severely ways through the use of an exoskeletal robotic or through functional electrical stimulation',
#   1),
#  ('six able bodied subjects and the effects of this technique over functional electrical stimulation',
#   1),
#  ('t study was to determine whether eye movements in conjunction with functional electrical stimulation',
#   1),
#  ('the purpose of this study was to examine the impact of functional electrical stimulation',
#   1),
#  ('tional connections rsfc of the triple network was investigated in 55 first episode schizophrenia',
#   1),
#  ('treatment for foot drop include an ankle foot orthosis afo or functional electrical stimulation',
#   1),
#  ('+ tdcs as add on interventions to training of wrist extension with functional electrical stimulation',
#   1),
#  ('adl as one of the popular ways to induced passive limb movements functional electrical stimulation',
#   1),
#  ('d the response of strip from the lower esophageal sphincter les to field electrical stimulation',
#   1),
#  ('e formation of an internal hydrogen bonding structural analysis of nelfinavir in solution along 100',
#   1),
#  ('e study examine the rate of remission in individuals experiencing a first episode of schizophrenia',
#   1),
#  ('each measured time point for the more affected side on which the functional electrical stimulation',
#   1),
#  ('ects at ultrahigh risk for psychosis uhr 16 drug naïve patients with first episode schizophrenia',
#   1),
#  ('effects protection in the same model fat embolism fe and the consequent fat embolism syndrome',
#   1),
#  ('effects upon the fcr h reflex some study 57 have shown that functional electrical stimulation',
#   1),
#  ('eir subtype b counterparts free energy surface for nelfinavir bound to prs free energy surface',
#   1),
#  ('eletal ultrasound imaging was performed to examine muscle architecture of the ta the more affected',
#   1),
#  ('eroids heparin alcohol and dextran have been found to be ineffective the fat embolism syndrome',
#   1),
#  ('f this study was to identified the effects of oculo motor exercise functional electrical stimulation',
#   1),
#  ('g the purpose of this experiment was to determine the effects of functional electrical stimulation',
#   1),
#  ('g while also be feasible for a unilateral user of an implanted functional electrical stimulation',
#   1),
#  ('he aim of this study is to systematically review the evidence for functional electrical stimulation',
#   1),
#  ('l scanning calorimetry dsc to a one dimensional representation of the folding free energy surface',
#   1),
#  ('linical suspicion is the cornerstone in early diagnosis and treatment of fes fat embolism syndrome',
#   1),
#  ('motor imagery based bci to attain linear control of an upper limb functional electrical stimulation',
#   1),
#  ('n as well as to control devices such as neuroprosthesis based on functional electrical stimulation',
#   1),
#  ('n functional is intact however in the clinical the substantial physical benefits of resistive activation',
#   1),
#  ('of aquaporin1 aqp1 in the pathologic process of pulmonary edema induced by fat embolism syndrome',
#   1),
#  ('on jeannerod 2001 mulder 2007 bci can be use to control a functional electrical stimulation',
#   1),
#  ('ople during transfer nmes use as a functional ways is known as functional electrical stimulation',
#   1),
#  ('pture system and the footswitch were 100 hz block diagram of the functional electrical stimulation',
#   1),
#  ('reluctant to do it and other strategies should be applied such as functional electrical stimulation',
#   1),
#  ('sd for tissue composition and spectral quality in the mpfc region in first episode schizophrenia',
#   1),
#  ('see figure s4 free energy surface for different prs bound to nelfinavir free energy surface',
#   1),
#  ('study of infant and young child feeding 6 23 months behavior beliefs contexts and environments',
#   1),
#  ('t 22 further study on the ultrahigh risk for psychosis uhr and first episode schizophrenia',
#   1),
#  ('the 18 f fes produced by this method met all specifications for human injection fluoroestradiol',
#   1),
#  ('the most successful er imaging radiopharmaceutical to date has been 16α 18f flouro 17β estradiol',
#   1),
#  ('time ctt in hours before and after six weeks of treatment with functional electrical stimulation',
#   1),
#  ('tion and behavior associated with sz in the present study forty three first episode schizophrenia',
#   1),
#  ('veloped a novel method to quantitatively obtain the fret efficiency by fitting the emission spectra',
#   1),
#  ('26 08 ± 2 29 years were recruited and underwent normal gait and functional electrical stimulation',
#   1),
#  ('an imaging agent for blvd st louis mo 63134 u s a estrogen receptor ^ fifluoroestradiol',
#   1),
#  ('are needed to determine whether osas is an independent risk factor for fes floppy eyelid syndrome',
#   1),
#  ('atient develop fes over 150 years ago zenker described the first case of fat embolism syndrome',
#   1),
#  ('ceptor imaging agent to date is the er imaging radiopharmaceutical 16α 18 f fluoro 17β estradiol',
#   1),
#  ('even death after reaching the system circulation we report the case of a fat embolism syndrome',
#   1),
#  ('fes can strengthen weaker muscle and is frequently use in clinical practice 7 8 cyclic fes',
#   1),
#  ('fferent conformations adopted and to sample low energy poses of the drug use free energy surface',
#   1),
#  ('herapy and in vivo determine of estrogen receptor concentration with f ^ a fluoroestradiol n i',
#   1),
#  ('ided into two group before 30 weeks pregnancy 42 case in traditional food exchange serving group',
#   1),
#  ('ion particularly the triad of skin brain and lung dysfunction known as the fat embolism syndrome',
#   1),
#  ('lse inhibition of the startle reflex ppi and p50 in the patients with first episode schizophrenia',
#   1),
#  ('ly identified here we described a case of childhood spk that coexisted with floppy eyelid syndrome',
#   1),
#  ('na expression of oxt oxtr avp avpr1a and cd38 in hc and first episode unmedicated schizophrenia',
#   1),
#  ('of receptor blockade in other trial of estrogen block drug 72 example of 18 f fluorestradiol',
#   1),
#  ('ole brain this study aim to assess the abnormalities in the brain of first episode schizophrenia',
#   1),
#  ('ot exclusively in males and associated with obesity has been defined as the floppy eyelid syndrome',
#   1),
#  ('rs described earlier are the cause of dmd patients s predisposition to develop fat embolism syndrome',
#   1),
#  ('s could also be use to recouple the brain to the muscle through functional electrical stimulation',
#   1),
#  ('th t2 and c4 include cd9 discs large homolog associated protein 1 dlgap1 and feline sarcoma',
#   1),
#  ('tion it is unlikely nf κb regulates it transcription in response to lps feline sarcoma oncogene',
#   1),
#  ('tumor response to hormonal agent such as tamoxifen 26 the pet tracer f 18 16a fluoroestradiol',
#   1),
#  ('ve p dup in water extracts of broiler litter treated with aluminum sulfate al ferrous sulfate',
#   1),
#  ('with ad were identified e g protein tyrosine kinase 6 ptk6 brk feline sarcoma oncogene kinase',
#   1),
#  ('and later tarsal strip by two surgeons hbl and wrn for the treatment of floppy eyelid syndrome',
#   1),
#  ('digm to evaluate the role of the vlpfc for self reflectiveness in 25 first episode of schizophrenia',
#   1),
#  ('e of motion p < 0 05 during the first three weeks of therapy functional electrical stimulation',
#   1),
#  ('es positron emission tomography imaging with the novel tracer 16 α 18 f fluoro 17 β oestradiol',
#   1),
#  ('havior of the drug we performed a 100 ns simulation of nelfinavir in solution free energy surface',
#   1),
#  ('mission tomography pet and computer tomography pet ct with 16 α 18 f fluoro 17 β oestradiol',
#   1),
#  ('nd lung parenchyma most often after a long bone fracture or major trauma the fat embolism syndrome',
#   1),
#  ('o a greater extent than rpss alone tdcs alone or sham rpss + tdcs functional electrical stimulation',
#   1),
#  ('ould be treated with inhaled no therapy prior to the onset of rv dysfunction fat embolism syndrome',
#   1),
#  ('transfer the main goal of this study is to verify if the use of functional electrical stimulation',
#   1),
#  ('unctionally suited imaging of the er has been most successful use 16 α 18f flouro 17β estradiol',
#   1),
#  ('validity of the result positron emission tomography pet use 16 α f 18 fluoro 17 β estradiol',
#   1),
#  ('ts this may be the dose of maximal er suppression in this manuscript we use 18 f fluoroestradiol',
#   1),
#  ('at are not known to be linked to ad were identified e g ptk6 brk feline sarcoma tyrosine kinase',
#   1),
#  ('can and 6 15 239 had 3 or more scanning the synthesis procedure 16α f 18 fluoro 17β estradiol',
#   1),
#  ('= 0 69 for atp1 trajectory for example the fig s11 a showed an example of a free energy surface',
#   1),
#  ('o 63110 u s a received i march 1993 we have measured in vivo the uptake of 16a f estradiol',
#   1),
#  ('or phase ii in part due to decreased in fes suv achieve in phase i 16α 18f fluoro 17β estradiol',
#   1),
#  ('100', 0.0),
#  ('17β', 0.0),
#  ('activation', 0.0),
#  ('affected', 0.0),
#  ('cycling', 0.0),
#  ('disorders', 0.0),
#  ('embolism', 0.0),
#  ('environments', 0.0),
#  ('fes', 0.0),
#  ('fifluoroestradiol', 0.0),
#  ('group', 0.0),
#  ('i', 0.0),
#  ('oestradiol', 0.0),
#  ('oncogene', 0.0),
#  ('product', 0.0),
#  ('protein', 0.0),
#  ('saline', 0.0),
#  ('sarcoma', 0.0),
#  ('scores', 0.0),
#  ('simulation', 0.0),
#  ('social', 0.0),
#  ('solution', 0.0),
#  ('spectra', 0.0),
#  ('spectroscopy', 0.0),
#  ('stimulation', 0.0),
#  ('sulfate', 0.0),
#  ('surface', 0.0),
#  ('16a fluorestradiol', 0.0),
#  ('16a fluoroestradiol', 0.0),
#  ('16α fluoroestradiol', 0.0),
#  ('^ fifluoroestradiol', 0.0),
#  ('along 100', 0.0),
#  ('alpha fluoroestradiol', 0.0),
#  ('and environments', 0.0),
#  ('cyclic fes', 0.0),
#  ('embolism syndrome', 0.0),
#  ('emission spectra', 0.0),
#  ('emission spectroscopy', 0.0),
#  ('energy simulation', 0.0),
#  ('energy surface', 0.0),
#  ('enhance solution', 0.0),
#  ('episode schizophrenia', 0.0),
#  ('ethnic social', 0.0),
#  ('examine scores', 0.0),
#  ('exercise saline', 0.0),
#  ('eyelid syndrome', 0.0),
#  ('f estradiol', 0.0),
#  ('f fluorestradiol', 0.0),
#  ('f fluoroestradiol', 0.0),
#  ('fat embolism', 0.0),
#  ('ferrous sulfate', 0.0),
#  ('fluoroestradiol 17β', 0.0),
#  ('injection fluoroestradiol', 0.0),
#  ('more affected', 0.0),
#  ('n i', 0.0),
#  ('of schizophrenia', 0.0),
#  ('oncogene kinase', 0.0),
#  ('oncogene protein', 0.0),
#  ('protooncogene product', 0.0),
#  ('resistive activation', 0.0),
#  ('sarcoma oncogene', 0.0),
#  ('serving group', 0.0),
#  ('spectrum disorders', 0.0),
#  ('tyrosine kinase', 0.0),
#  ('unloaded cycling', 0.0),
#  ('unmedicated schizophrenia', 0.0),
#  ('β estradiol', 0.0),
#  ('β oestradiol', 0.0),
#  ('16 alpha fluoroestradiol', 0.0),
#  ('16a f estradiol', 0.0),
#  ('17 β estradiol', 0.0),
#  ('17 β oestradiol', 0.0),
#  ('18 16a fluorestradiol', 0.0),
#  ('18 16a fluoroestradiol', 0.0),
#  ('18 16α fluoroestradiol', 0.0),
#  ('18 f fluorestradiol', 0.0),
#  ('8 cyclic fes', 0.0),
#  ('al ferrous sulfate', 0.0),
#  ('and feline sarcoma', 0.0),
#  ('contexts and environments', 0.0),
#  ('driven unloaded cycling', 0.0),
#  ('episode of schizophrenia', 0.0),
#  ('episode unmedicated schizophrenia', 0.0),
#  ('exchange serving group', 0.0),
#  ('f fluoroestradiol 17β', 0.0),
#  ('family ethnic social', 0.0),
#  ('fasting exercise saline', 0.0),
#  ('fes protooncogene product', 0.0),
#  ('final examine scores', 0.0),
#  ('flame emission spectroscopy', 0.0),
#  ('flavour enhance solution', 0.0),
#  ('flouro 17β estradiol', 0.0),
#  ('fluoroestradiol n i', 0.0),
#  ('free energy simulation', 0.0),
#  ('human injection fluoroestradiol', 0.0),
#  ('kinase feline sarcoma', 0.0),
#  ('massive fat embolism', 0.0),
#  ('neuromuscular electrical stimulation', 0.0),
#  ('of resistive activation', 0.0),
#  ('receptor ^ fifluoroestradiol', 0.0),
#  ('sarcoma oncogene kinase', 0.0),
#  ('sarcoma oncogene protein', 0.0),
#  ('sarcoma tyrosine kinase', 0.0),
#  ('schizophrenia spectrum disorders', 0.0),
#  ('solution along 100', 0.0),
#  ('the emission spectra', 0.0),
#  ('the more affected', 0.0),
#  ('18 f fluoroestradiol 17β', 0.0),
#  ('18 fluoro 17β estradiol', 0.0),
#  ('18f fluoro 17β estradiol', 0.0),
#  ('1960 functional electrical stimulation', 0.0),
#  ('1987 functional electrical stimulation', 0.0),
#  ('5 fat embolism syndrome', 0.0),
#  ('5 functional electrical stimulation', 0.0),
#  ('55 first episode schizophrenia', 0.0),
#  ('7 8 cyclic fes', 0.0),
#  ('84 feline sarcoma oncogene', 0.0),
#  ('a fat embolism syndrome', 0.0),
#  ('a flavour enhance solution', 0.0),
#  ('a fluoroestradiol n i', 0.0),
#  ('a free energy surface', 0.0),
#  ('ad functional electrical stimulation', 0.0),
#  ('and fat embolism syndrome', 0.0),
#  ('and first episode schizophrenia', 0.0),
#  ('and floppy eyelid syndrome', 0.0),
#  ('application functional electrical stimulation', 0.0),
#  ('approach functional electrical stimulation', 0.0),
#  ('are functional electrical stimulation', 0.0),
#  ('beliefs contexts and environments', 0.0),
#  ('benefits of resistive activation', 0.0),
#  ('between family ethnic social', 0.0),
#  ('between floppy eyelid syndrome', 0.0),
#  ('bilateral functional electrical stimulation', 0.0),
#  ('by fat embolism syndrome', 0.0),
#  ('by field electrical stimulation', 0.0),
#  ('by massive fat embolism', 0.0),
#  ('c fes protooncogene product', 0.0),
#  ('called fat embolism syndrome', 0.0),
#  ('called functional electrical stimulation', 0.0),
#  ('consequent fat embolism syndrome', 0.0),
#  ('da field electrical stimulation', 0.0),
#  ('demonstrated functional electrical stimulation', 0.0),
#  ('develop fat embolism syndrome', 0.0),
#  ('devices functional electrical stimulation', 0.0),
#  ('dlgap1 and feline sarcoma', 0.0),
#  ('dysfunction fat embolism syndrome', 0.0),
#  ('electrodes functional electrical stimulation', 0.0),
#  ('episode schizophrenia spectrum disorders', 0.0),
#  ('especially first episode schizophrenia', 0.0),
#  ('estrogen receptor ^ fifluoroestradiol', 0.0),
#  ('evaluate functional electrical stimulation', 0.0),
#  ('example functional electrical stimulation', 0.0),
#  ('excluded functional electrical stimulation', 0.0),
#  ('f 18 16a fluorestradiol', 0.0),
#  ('f fluoro 17β estradiol', 0.0),
#  ('feline sarcoma oncogene kinase', 0.0),
#  ('feline sarcoma oncogene protein', 0.0),
#  ('feline sarcoma tyrosine kinase', 0.0),
#  ('fes fat embolism syndrome', 0.0),
#  ('fes floppy eyelid syndrome', 0.0),
#  ('fes functional electrical stimulation', 0.0),
#  ('first episode unmedicated schizophrenia', 0.0),
#  ('fitting the emission spectra', 0.0),
#  ('fluoro 17 β estradiol', 0.0),
#  ('fluoro 17 β oestradiol', 0.0),
#  ('folding free energy surface', 0.0),
#  ('food exchange serving group', 0.0),
#  ('for human injection fluoroestradiol', 0.0),
#  ('free first episode schizophrenia', 0.0),
#  ('from functional electrical stimulation', 0.0),
#  ('frs fasting exercise saline', 0.0),
#  ('functional functional electrical stimulation', 0.0),
#  ('functional neuromuscular electrical stimulation', 0.0),
#  ('hybrid functional electrical stimulation', 0.0),
#  ('ideal functional electrical stimulation', 0.0),
#  ('implanted functional electrical stimulation', 0.0),
#  ('in solution along 100', 0.0),
#  ('incorporating functional electrical stimulation', 0.0),
#  ('initiation functional electrical stimulation', 0.0),
#  ('instead functional electrical stimulation', 0.0),
#  ('interface functional electrical stimulation', 0.0),
#  ('is functional electrical stimulation', 0.0),
#  ('limb functional electrical stimulation', 0.0),
#  ('living functional electrical stimulation', 0.0),
#  ('loop functional electrical stimulation', 0.0),
#  ('lps feline sarcoma oncogene', 0.0),
#  ('m functional electrical stimulation', 0.0),
#  ('mobility functional electrical stimulation', 0.0),
#  ('modulate functional electrical stimulation', 0.0),
#  ('nelfinavir free energy surface', 0.0),
#  ('neuromuscular functional electrical stimulation', 0.0),
#  ('of 16 alpha fluoroestradiol', 0.0),
#  ('of 16a f estradiol', 0.0),
#  ('of 18 f fluorestradiol', 0.0),
#  ('of fat embolism syndrome', 0.0),
#  ('of first episode schizophrenia', 0.0),
#  ('on final examine scores', 0.0),
#  ('on flame emission spectroscopy', 0.0),
#  ('on functional electrical stimulation', 0.0),
#  ('only functional electrical stimulation', 0.0),
#  ('opening functional electrical stimulation', 0.0),
#  ('parenchyma fat embolism syndrome', 0.0),
#  ('patients functional electrical stimulation', 0.0),
#  ('pattern functional electrical stimulation', 0.0),
#  ('period functional electrical stimulation', 0.0),
#  ('physician fat embolism syndrome', 0.0),
#  ('prolonged functional electrical stimulation', 0.0),
#  ('prs free energy surface', 0.0),
#  ('rehabilitation functional electrical stimulation', 0.0),
#  ('repetitive functional electrical stimulation', 0.0),
#  ('sitting functional electrical stimulation', 0.0),
#  ('solution free energy surface', 0.0),
#  ('stimulation driven unloaded cycling', 0.0),
#  ('stimulation functional electrical stimulation', 0.0),
#  ('strict free energy simulation', 0.0),
#  ('sulfate al ferrous sulfate', 0.0),
#  ('surgery fat embolism syndrome', 0.0),
#  ('syndrome functional electrical stimulation', 0.0),
#  ('ta the more affected', 0.0),
#  ('task functional electrical stimulation', 0.0),
#  ('tdcs functional electrical stimulation', 0.0),
#  ('technique functional electrical stimulation', 0.0),
#  ('tens functional electrical stimulation', 0.0),
#  ('tetraplegia functional electrical stimulation', 0.0),
#  ('the floppy eyelid syndrome', 0.0),
#  ('therapy functional electrical stimulation', 0.0),
#  ('three first episode schizophrenia', 0.0),
#  ('to field electrical stimulation', 0.0),
#  ('training functional electrical stimulation', 0.0),
#  ('tumor 18 f fluoroestradiol', 0.0),
#  ('tyrosine kinase feline sarcoma', 0.0),
#  ('under functional electrical stimulation', 0.0),
#  ('unknown functional electrical stimulation', 0.0),
#  ('use 18 f fluoroestradiol', 0.0),
#  ('use free energy surface', 0.0),
#  ('with first episode schizophrenia', 0.0),
#  ('with floppy eyelid syndrome', 0.0),
#  ('worldwide functional electrical stimulation', 0.0),
#  ('+ tdcs functional electrical stimulation', 0.0),
#  ('1 5 functional electrical stimulation', 0.0),
#  ('1 dlgap1 and feline sarcoma', 0.0),
#  ('11 and functional electrical stimulation', 0.0),
#  ('16α 18 f fluoroestradiol 17β', 0.0),
#  ('16α 18f flouro 17β estradiol', 0.0),
#  ('16α 18f fluoro 17β estradiol', 0.0),
#  ('18 f fluoro 17β estradiol', 0.0),
#  ('18 fluoro 17 β estradiol', 0.0),
#  ('2 3 functional electrical stimulation', 0.0),
#  ('2 5 fat embolism syndrome', 0.0),
#  ('2 period functional electrical stimulation', 0.0),
#  ('25 first episode of schizophrenia', 0.0),
#  ('3h da field electrical stimulation', 0.0),
#  ('4 and functional electrical stimulation', 0.0),
#  ('^ a fluoroestradiol n i', 0.0),
#  ('a estrogen receptor ^ fifluoroestradiol', 0.0),
#  ('a first episode of schizophrenia', 0.0),
#  ('abstract f 18 16a fluoroestradiol', 0.0),
#  ('activation by functional electrical stimulation', 0.0),
#  ('activation pattern functional electrical stimulation', 0.0),
#  ('afo or functional electrical stimulation', 0.0),
#  ('aluminum sulfate al ferrous sulfate', 0.0),
#  ('an ideal functional electrical stimulation', 0.0),
#  ('an implanted functional electrical stimulation', 0.0),
#  ('analogues of 16 alpha fluoroestradiol', 0.0),
#  ('analysis and functional electrical stimulation', 0.0),
#  ('and first episode unmedicated schizophrenia', 0.0),
#  ('and functional neuromuscular electrical stimulation', 0.0),
#  ('and on final examine scores', 0.0),
#  ('and without functional electrical stimulation', 0.0),
#  ('application of functional electrical stimulation', 0.0),
#  ('as the fat embolism syndrome', 0.0),
#  ('as the floppy eyelid syndrome', 0.0),
#  ('associated of floppy eyelid syndrome', 0.0),
#  ('attempts with functional electrical stimulation', 0.0),
#  ('based on flame emission spectroscopy', 0.0),
#  ('based on functional electrical stimulation', 0.0),
#  ('bci control functional electrical stimulation', 0.0),
#  ('behavior beliefs contexts and environments', 0.0),
#  ('benefits from functional electrical stimulation', 0.0),
#  ('bf and functional electrical stimulation', 0.0),
#  ('bodied exercise functional electrical stimulation', 0.0),
#  ('brain of first episode schizophrenia', 0.0),
#  ('brk feline sarcoma oncogene kinase', 0.0),
#  ('brk feline sarcoma tyrosine kinase', 0.0),
#  ('but instead functional electrical stimulation', 0.0),
#  ('by fitting the emission spectra', 0.0),
#  ('c6 tetraplegia functional electrical stimulation', 0.0),
#  ('caatctcatctcgttttctgcg 84 feline sarcoma oncogene', 0.0),
#  ('case of fat embolism syndrome', 0.0),
#  ('cause by functional electrical stimulation', 0.0),
#  ('characterized as functional electrical stimulation', 0.0),
#  ('clinical application functional electrical stimulation', 0.0),
#  ('closed loop functional electrical stimulation', 0.0),
#  ('combined with functional electrical stimulation', 0.0),
#  ('complement exercise functional electrical stimulation', 0.0),
#  ('computer interface functional electrical stimulation', 0.0),
#  ('conjunction with functional electrical stimulation', 0.0),
#  ('connections during functional electrical stimulation', 0.0),
#  ('contraction only functional electrical stimulation', 0.0),
#  ('contraction through functional electrical stimulation', 0.0),
#  ('control a functional electrical stimulation', 0.0),
#  ('control of functional electrical stimulation', 0.0),
#  ('csr and floppy eyelid syndrome', 0.0),
#  ('daily living functional electrical stimulation', 0.0),
#  ('daily task functional electrical stimulation', 0.0),
#  ('damaged functional functional electrical stimulation', 0.0),
#  ('delateur 1987 functional electrical stimulation', 0.0),
#  ('develop a functional electrical stimulation', 0.0),
#  ('develop of functional electrical stimulation', 0.0),
#  ('documented during functional electrical stimulation', 0.0),
#  ('drug use free energy surface', 0.0),
#  ('during prolonged functional electrical stimulation', 0.0),
#  ('early initiation functional electrical stimulation', 0.0),
#  ('effects over functional electrical stimulation', 0.0),
#  ('electrical stimulation driven unloaded cycling', 0.0),
#  ('embolism and fat embolism syndrome', 0.0),
#  ('emg for functional electrical stimulation', 0.0),
#  ('evidence for functional electrical stimulation', 0.0),
#  ('evoked by field electrical stimulation', 0.0),
#  ('example of 18 f fluorestradiol', 0.0),
#  ('excitability are functional electrical stimulation', 0.0),
#  ('exercise training functional electrical stimulation', 0.0),
#  ('exoskeleton and functional electrical stimulation', 0.0),
#  ('extension paralysis functional electrical stimulation', 0.0),
#  ('extension with functional electrical stimulation', 0.0),
#  ('f 18 fluoro 17β estradiol', 0.0),
#  ('f fluoro 17 β oestradiol', 0.0),
#  ('fatigue during functional electrical stimulation', 0.0),
#  ('first episode schizophrenia spectrum disorders', 0.0),
#  ('flaccid paralysis functional electrical stimulation', 0.0),
#  ('flow by massive fat embolism', 0.0),
#  ('following surgery fat embolism syndrome', 0.0),
#  ('for example functional electrical stimulation', 0.0),
#  ('for fes floppy eyelid syndrome', 0.0),
#  ('forty three first episode schizophrenia', 0.0),
#  ('functional mobility functional electrical stimulation', 0.0),
#  ('gait and functional electrical stimulation', 0.0),
#  ('gait rehabilitation functional electrical stimulation', 0.0),
#  ('goal include functional electrical stimulation', 0.0),
#  ('hand opening functional electrical stimulation', 0.0),
#  ('i m functional electrical stimulation', 0.0),
#  ('impact of functional electrical stimulation', 0.0),
#  ('implanted of functional electrical stimulation', 0.0),
#  ('in 55 first episode schizophrenia', 0.0),
#  ('in solution free energy surface', 0.0),
#  ('indicated that functional electrical stimulation', 0.0),
#  ('induced by fat embolism syndrome', 0.0),
#  ('ineffective the fat embolism syndrome', 0.0),
#  ('is called functional electrical stimulation', 0.0),
#  ('is unknown functional electrical stimulation', 0.0),
#  ('knee with functional electrical stimulation', 0.0),
#  ('learning approach functional electrical stimulation', 0.0),
#  ('les to field electrical stimulation', 0.0),
#  ('limb movements functional electrical stimulation', 0.0),
#  ('loads through functional electrical stimulation', 0.0),
#  ('main of functional electrical stimulation', 0.0),
#  ('medical free first episode schizophrenia', 0.0),
#  ('men worldwide functional electrical stimulation', 0.0),
#  ('mi and functional electrical stimulation', 0.0),
#  ('monitored tumor 18 f fluoroestradiol', 0.0),
#  ('motor control functional electrical stimulation', 0.0),
#  ('motor exercise functional electrical stimulation', 0.0),
#  ('movements is functional electrical stimulation', 0.0),
#  ('muscle through functional electrical stimulation', 0.0),
#  ('muscle use functional electrical stimulation', 0.0),
#  ('neglect patients functional electrical stimulation', 0.0),
#  ('neglect syndrome functional electrical stimulation', 0.0),
#  ('nelfinavir in solution along 100', 0.0),
#  ('nerve 3 functional electrical stimulation', 0.0),
#  ('neurological injury functional electrical stimulation', 0.0),
#  ('neuromuscular or functional electrical stimulation', 0.0),
#  ('neuroprosthetic technique functional electrical stimulation', 0.0),
#  ('not demonstrated functional electrical stimulation', 0.0),
#  ('of a flavour enhance solution', 0.0),
#  ('of a free energy surface', 0.0),
#  ('of bilateral functional electrical stimulation', 0.0),
#  ('of fes fat embolism syndrome', 0.0),
#  ('of hybrid functional electrical stimulation', 0.0),
#  ('of injury functional electrical stimulation', 0.0),
#  ('of the functional electrical stimulation', 0.0),
#  ('of therapy functional electrical stimulation', 0.0),
#  ('often term functional electrical stimulation', 0.0),
#  ('or through functional electrical stimulation', 0.0),
#  ('or without functional electrical stimulation', 0.0),
#  ('phenomena under functional electrical stimulation', 0.0),
#  ('physical benefits of resistive activation', 0.0),
#  ('practice 7 8 cyclic fes', 0.0),
#  ('provision of functional electrical stimulation', 0.0),
#  ('pulmonary parenchyma fat embolism syndrome', 0.0),
#  ('quiet sitting functional electrical stimulation', 0.0),
#  ('receptor tyrosine kinase feline sarcoma', 0.0),
#  ('recordings during functional electrical stimulation', 0.0),
#  ('region in first episode schizophrenia', 0.0),
#  ('regular neuromuscular functional electrical stimulation', 0.0),
#  ('related between family ethnic social', 0.0),
#  ('relationship between floppy eyelid syndrome', 0.0),
#  ('robotic devices functional electrical stimulation', 0.0),
#  ('rv dysfunction fat embolism syndrome', 0.0),
#  ('saline frs fasting exercise saline', 0.0),
#  ('schizophrenia especially first episode schizophrenia', 0.0),
#  ('shown that functional electrical stimulation', 0.0),
#  ('since 1960 functional electrical stimulation', 0.0),
#  ('single electrodes functional electrical stimulation', 0.0),
#  ('specifications for human injection fluoroestradiol', 0.0),
#  ('stimulation tens functional electrical stimulation', 0.0),
#  ('strategies for functional electrical stimulation', 0.0),
#  ('suggest that functional electrical stimulation', 0.0),
#  ('switch triggered functional electrical stimulation', 0.0),
#  ('syndrome called fat embolism syndrome', 0.0),
#  ('technique over functional electrical stimulation', 0.0),
#  ('technology and functional electrical stimulation', 0.0),
#  ('tg and functional electrical stimulation', 0.0),
#  ('that c fes protooncogene product', 0.0),
#  ('the consequent fat embolism syndrome', 0.0),
#  ('the folding free energy surface', 0.0),
#  ('the ta the more affected', 0.0),
#  ('the term functional electrical stimulation', 0.0),
#  ('their first episode of schizophrenia', 0.0),
#  ('therapy and functional electrical stimulation', 0.0),
#  ('therapy incorporating functional electrical stimulation', 0.0),
#  ('to develop fat embolism syndrome', 0.0),
#  ('to evaluate functional electrical stimulation', 0.0),
#  ('to fes functional electrical stimulation', 0.0),
#  ('to include functional electrical stimulation', 0.0),
#  ('to lps feline sarcoma oncogene', 0.0),
#  ('to modulate functional electrical stimulation', 0.0),
#  ('to nelfinavir free energy surface', 0.0),
#  ('to prs free energy surface', 0.0),
#  ('to strict free energy simulation', 0.0),
#  ('tracer f 18 16a fluorestradiol', 0.0),
#  ('tracer f 18 16a fluoroestradiol', 0.0),
#  ('traditional food exchange serving group', 0.0),
#  ('trauma the fat embolism syndrome', 0.0),
#  ('treated physician fat embolism syndrome', 0.0),
#  ('treated use functional electrical stimulation', 0.0),
#  ('treatment include functional electrical stimulation', 0.0),
#  ('treatment of floppy eyelid syndrome', 0.0),
#  ('treatment with functional electrical stimulation', 0.0),
#  ('uhr and first episode schizophrenia', 0.0),
#  ('unclear in first episode schizophrenia', 0.0),
#  ('unilateral stimulation functional electrical stimulation', 0.0),
#  ('upper limb functional electrical stimulation', 0.0),
#  ('uptake of 16a f estradiol', 0.0),
#  ('use of functional electrical stimulation', 0.0),
#  ('we use 18 f fluoroestradiol', 0.0),
#  ('were excluded functional electrical stimulation', 0.0),
#  ('when ad functional electrical stimulation', 0.0),
#  ('whether repetitive functional electrical stimulation', 0.0),
#  ('which the functional electrical stimulation', 0.0),
#  ('which triggered functional electrical stimulation', 0.0),
#  ('α 18f flouro 17β estradiol', 0.0),
#  ('15 showed that functional electrical stimulation', 0.0),
#  ('16 α 18f flouro 17β estradiol', 0.0),
#  ('16α 18 f fluoro 17β estradiol', 0.0),
#  ('16α f 18 fluoro 17β estradiol', 0.0),
#  ('18 f fluoro 17 β oestradiol', 0.0),
#  ('2 since 1960 functional electrical stimulation', 0.0),
#  ('3 4 and functional electrical stimulation', 0.0),
#  ('58 patients with first episode schizophrenia', 0.0),
#  ('72 example of 18 f fluorestradiol', 0.0),
#  ('75 indicated that functional electrical stimulation', 0.0),
#  ('a neuroprosthetic technique functional electrical stimulation', 0.0),
#  ('abdominal muscle use functional electrical stimulation', 0.0),
#  ('addition of a flavour enhance solution', 0.0),
#  ('after neurological injury functional electrical stimulation', 0.0),
#  ('all specifications for human injection fluoroestradiol', 0.0),
#  ('among patients with first episode schizophrenia', 0.0),
#  ('an upper limb functional electrical stimulation', 0.0),
#  ('and hand opening functional electrical stimulation', 0.0),
#  ('and pulmonary parenchyma fat embolism syndrome', 0.0),
#  ('and the consequent fat embolism syndrome', 0.0),
#  ('applied such as functional electrical stimulation', 0.0),
#  ('applied to evaluate functional electrical stimulation', 0.0),
#  ('arm which triggered functional electrical stimulation', 0.0),
#  ('artery flow by massive fat embolism', 0.0),
#  ('aspects of hybrid functional electrical stimulation', 0.0),
#  ('assistive robotic devices functional electrical stimulation', 0.0),
#  ('auditory stimulation and functional electrical stimulation', 0.0),
#  ('barefoot bf and functional electrical stimulation', 0.0),
#  ('based therapy incorporating functional electrical stimulation', 0.0),
#  ('bci control of functional electrical stimulation', 0.0),
#  ('be ineffective the fat embolism syndrome', 0.0),
#  ('be treated use functional electrical stimulation', 0.0),
#  ('been 16α 18f flouro 17β estradiol', 0.0),
#  ('been characterized as functional electrical stimulation', 0.0),
#  ('been documented during functional electrical stimulation', 0.0),
#  ('beneficial effects of functional electrical stimulation', 0.0),
#  ('beneficial to include functional electrical stimulation', 0.0),
#  ('biomechanical loads through functional electrical stimulation', 0.0),
#  ('bound to nelfinavir free energy surface', 0.0),
#  ('bound to prs free energy surface', 0.0),
#  ('brain computer interface functional electrical stimulation', 0.0),
#  ('c5 c6 tetraplegia functional electrical stimulation', 0.0),
#  ('case of a fat embolism syndrome', 0.0),
#  ('chorioretinopathy csr and floppy eyelid syndrome', 0.0),
#  ('clinical practice 7 8 cyclic fes', 0.0),
#  ('clinical syndrome called fat embolism syndrome', 0.0),
#  ('consist main of functional electrical stimulation', 0.0),
#  ('contraction induced by functional electrical stimulation', 0.0),
#  ('control strategies for functional electrical stimulation', 0.0),
#  ('corticomotor excitability are functional electrical stimulation', 0.0),
#  ('cost 2 3 functional electrical stimulation', 0.0),
#  ('cough attempts with functional electrical stimulation', 0.0),
#  ('cp effects of functional electrical stimulation', 0.0),
#  ('decreased functional mobility functional electrical stimulation', 0.0),
#  ('defined as the floppy eyelid syndrome', 0.0),
#  ('demonstrated that c fes protooncogene product', 0.0),
#  ('determine whether repetitive functional electrical stimulation', 0.0),
#  ('devices were excluded functional electrical stimulation', 0.0),
#  ('diagram of the functional electrical stimulation', 0.0),
#  ('dti technology and functional electrical stimulation', 0.0),
#  ('during quiet sitting functional electrical stimulation', 0.0),
#  ('during single electrodes functional electrical stimulation', 0.0),
#  ('edema induced by fat embolism syndrome', 0.0),
#  ('effects of bilateral functional electrical stimulation', 0.0),
#  ('efficiency by fitting the emission spectra', 0.0),
#  ('electrical stimulation and functional electrical stimulation', 0.0),
#  ('electrical stimulation tens functional electrical stimulation', 0.0),
#  ('electromyography emg for functional electrical stimulation', 0.0),
#  ('evaluate effects of functional electrical stimulation', 0.0),
#  ('example of a free energy surface', 0.0),
#  ('exercise induced by functional electrical stimulation', 0.0),
#  ('exercise such as functional electrical stimulation', 0.0),
#  ('experiencing a first episode of schizophrenia', 0.0),
#  ('f 18 fluoro 17 β estradiol', 0.0),
#  ('f ^ a fluoroestradiol n i', 0.0),
#  ('factor for fes floppy eyelid syndrome', 0.0),
#  ('fatigue phenomena under functional electrical stimulation', 0.0),
#  ('first case of fat embolism syndrome', 0.0),
#  ('for gait rehabilitation functional electrical stimulation', 0.0),
#  ('from their first episode of schizophrenia', 0.0),
#  ('functional electrical stimulation driven unloaded cycling', 0.0),
#  ('future clinical application functional electrical stimulation', 0.0),
#  ('gait analysis and functional electrical stimulation', 0.0),
#  ('group tg and functional electrical stimulation', 0.0),
#  ('have benefits from functional electrical stimulation', 0.0),
#  ('have shown that functional electrical stimulation', 0.0),
#  ('hc and first episode unmedicated schizophrenia', 0.0),
#  ('heel switch triggered functional electrical stimulation', 0.0),
#  ('i 16α 18f fluoro 17β estradiol', 0.0),
#  ('imagination mi and functional electrical stimulation', 0.0),
#  ('improve reaching movements functional electrical stimulation', 0.0),
#  ('in 25 first episode of schizophrenia', 0.0),
#  ('in conjunction with functional electrical stimulation', 0.0),
#  ('in medical free first episode schizophrenia', 0.0),
#  ('in motor control functional electrical stimulation', 0.0),
#  ('in traditional food exchange serving group', 0.0),
#  ('interface bci control functional electrical stimulation', 0.0),
#  ('intracortical recordings during functional electrical stimulation', 0.0),
#  ('intramuscular i m functional electrical stimulation', 0.0),
#  ('investigated in 55 first episode schizophrenia', 0.0),
#  ('is known as functional electrical stimulation', 0.0),
#  ('is often term functional electrical stimulation', 0.0),
#  ('it effects over functional electrical stimulation', 0.0),
#  ('joint movements is functional electrical stimulation', 0.0),
#  ('known as the fat embolism syndrome', 0.0),
#  ('later 2 period functional electrical stimulation', 0.0),
#  ('lectures and on final examine scores', 0.0),
#  ('leg exercise training functional electrical stimulation', 0.0),
#  ('level of injury functional electrical stimulation', 0.0),
#  ('lie to strict free energy simulation', 0.0),
#  ('limb activation by functional electrical stimulation', 0.0),
#  ('limb exoskeleton and functional electrical stimulation', 0.0),
#  ('major trauma the fat embolism syndrome', 0.0),
#  ('manuscript we use 18 f fluoroestradiol', 0.0),
#  ('mechanical is unknown functional electrical stimulation', 0.0),
#  ('medicine brain control functional electrical stimulation', 0.0),
#  ('million men worldwide functional electrical stimulation', 0.0),
#  ('modality such as functional electrical stimulation', 0.0),
#  ('months behavior beliefs contexts and environments', 0.0),
#  ('motor learning approach functional electrical stimulation', 0.0),
#  ('movements but instead functional electrical stimulation', 0.0),
#  ('movements cause by functional electrical stimulation', 0.0),
#  ('movements induced by functional electrical stimulation', 0.0),
#  ('mpfc region in first episode schizophrenia', 0.0),
#  ('muscle activation pattern functional electrical stimulation', 0.0),
#  ('muscle fatigue during functional electrical stimulation', 0.0),
#  ('naïve patients with first episode schizophrenia', 0.0),
#  ('nelfinavir in solution free energy surface', 0.0),
#  ('nerve known as functional electrical stimulation', 0.0),
#  ('network brain control functional electrical stimulation', 0.0),
#  ('neuroprosthesis based on functional electrical stimulation', 0.0),
#  ('next monitored tumor 18 f fluoroestradiol', 0.0),
#  ('non receptor tyrosine kinase feline sarcoma', 0.0),
#  ('normal gait and functional electrical stimulation', 0.0),
#  ('observations suggest that functional electrical stimulation', 0.0),
#  ('occurrence of a fat embolism syndrome', 0.0),
#  ('oculo motor exercise functional electrical stimulation', 0.0),
#  ('of 3h da field electrical stimulation', 0.0),
#  ('of closed loop functional electrical stimulation', 0.0),
#  ('of daily living functional electrical stimulation', 0.0),
#  ('of nelfinavir in solution along 100', 0.0),
#  ('of rv dysfunction fat embolism syndrome', 0.0),
#  ('of the folding free energy surface', 0.0),
#  ('of the ta the more affected', 0.0),
#  ('of treatment with functional electrical stimulation', 0.0),
#  ('on which the functional electrical stimulation', 0.0),
#  ('or damaged functional functional electrical stimulation', 0.0),
#  ('orthosis afo or functional electrical stimulation', 0.0),
#  ('passive limb movements functional electrical stimulation', 0.0),
#  ('patients 11 and functional electrical stimulation', 0.0),
#  ('patients 2 5 fat embolism syndrome', 0.0),
#  ('patients the feline sarcoma oncogene protein', 0.0),
#  ('percutaneous connections during functional electrical stimulation', 0.0),
#  ('pet tracer f 18 16a fluoroestradiol', 0.0),
#  ('predisposition to develop fat embolism syndrome', 0.0),
#  ('price delateur 1987 functional electrical stimulation', 0.0),
#  ('proper reaching movements functional electrical stimulation', 0.0),
#  ('protein 1 dlgap1 and feline sarcoma', 0.0),
#  ('psychosis uhr and first episode schizophrenia', 0.0),
#  ('ptk6 brk feline sarcoma oncogene kinase', 0.0),
#  ('ptk6 brk feline sarcoma tyrosine kinase', 0.0),
#  ('r caatctcatctcgttttctgcg 84 feline sarcoma oncogene', 0.0),
#  ('radiopharmaceutical 16α 18 f fluoroestradiol 17β', 0.0),
#  ('receptor tracer f 18 16a fluorestradiol', 0.0),
#  ('rehabilitation treatment include functional electrical stimulation', 0.0),
#  ('release evoked by field electrical stimulation', 0.0),
#  ('remains unclear in first episode schizophrenia', 0.0),
#  ('response to fes functional electrical stimulation', 0.0),
#  ('response to lps feline sarcoma oncogene', 0.0),
#  ('rest saline frs fasting exercise saline', 0.0),
#  ('rgo combined with functional electrical stimulation', 0.0),
#  ('rln unilateral stimulation functional electrical stimulation', 0.0),
#  ('robotic and functional neuromuscular electrical stimulation', 0.0),
#  ('robotic or through functional electrical stimulation', 0.0),
#  ('robotic therapy and functional electrical stimulation', 0.0),
#  ('rpss + tdcs functional electrical stimulation', 0.0),
#  ('s a estrogen receptor ^ fifluoroestradiol', 0.0),
#  ('see 1 5 functional electrical stimulation', 0.0),
#  ('sensory nerve 3 functional electrical stimulation', 0.0),
#  ('sensorium following surgery fat embolism syndrome', 0.0),
#  ('simultaneous provision of functional electrical stimulation', 0.0),
#  ('spatial neglect patients functional electrical stimulation', 0.0),
#  ('sphincter les to field electrical stimulation', 0.0),
#  ('stroke an ideal functional electrical stimulation', 0.0),
#  ('study forty three first episode schizophrenia', 0.0),
#  ('substantial physical benefits of resistive activation', 0.0),
#  ('system associated of floppy eyelid syndrome', 0.0),
#  ('system based on flame emission spectroscopy', 0.0),
#  ('system to modulate functional electrical stimulation', 0.0),
#  ('that coexisted with floppy eyelid syndrome', 0.0),
#  ('that neuromuscular or functional electrical stimulation', 0.0),
#  ('that when ad functional electrical stimulation', 0.0),
#  ('the application of functional electrical stimulation', 0.0),
#  ('the brain of first episode schizophrenia', 0.0),
#  ('the develop of functional electrical stimulation', 0.0),
#  ('the drug use free energy surface', 0.0),
#  ('the early initiation functional electrical stimulation', 0.0),
#  ('the evidence for functional electrical stimulation', 0.0),
#  ('the impact of functional electrical stimulation', 0.0),
#  ('the implanted of functional electrical stimulation', 0.0),
#  ('the knee with functional electrical stimulation', 0.0),
#  ('the muscle through functional electrical stimulation', 0.0),
#  ('the patients with first episode schizophrenia', 0.0),
#  ('the related between family ethnic social', 0.0),
#  ('the relationship between floppy eyelid syndrome', 0.0),
#  ('the treated physician fat embolism syndrome', 0.0),
#  ('the treatment of floppy eyelid syndrome', 0.0),
#  ('the uptake of 16a f estradiol', 0.0),
#  ('their daily task functional electrical stimulation', 0.0),
#  ('therapeutic effects of functional electrical stimulation', 0.0),
#  ('therapy for example functional electrical stimulation', 0.0),
#  ('these goal include functional electrical stimulation', 0.0),
#  ('this technique over functional electrical stimulation', 0.0),
#  ('three analogues of 16 alpha fluoroestradiol', 0.0),
#  ('to develop a functional electrical stimulation', 0.0),
#  ('to regular neuromuscular functional electrical stimulation', 0.0),
#  ('torque during prolonged functional electrical stimulation', 0.0),
#  ('treatment of fes fat embolism syndrome', 0.0),
#  ('trial showed that functional electrical stimulation', 0.0),
#  ...]

# %%
longforms0 = miners['FES'].get_longforms()

# %%
longforms0
# Out:
# [('functional electrical stimulation', 175.17391304347825),
#  ('fat embolism syndrome', 25.368421052631575),
#  ('first episode schizophrenia', 10.83333333333333),
#  ('fluoroestradiol', 6.0),
#  ('free energy surface', 5.0),
#  ('estradiol', 3.142857142857143)]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0, 1]]

# %%
longforms0
# Out:
# [('clock', 86.3921568627451), ('cdc2 like kinase', 6.0)]

# %%
longforms0.extend([(longform, score) for i, (longform, score) in enumerate(top)
                   if i in [13]])

# %%
longforms0
# Out:
# [('clock', 86.3921568627451),
#  ('cdc2 like kinase', 6.0),
#  ('contralateral kidney', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('functional electrical stimulation',
#  'fat embolism syndrome',
#  'first episode schizophrenia',
#  'fluoroestradiol',
#  'free energy surface',
#  'estradiol')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'estradiol': 'CHEBI:CHEBI:23965'}

# %%
names
# Out:
# {'CHEBI:CHEBI:23965': 'estradiol'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names
# Out:
# {'PUBCHEM:10869981': 'Fluoroestradiol F-18',
#  'MESH:D004620': 'Embolism, Fat',
#  'MESH:D004599': 'Electric Stimulation Therapy'}

# %%
grounding_map
# Out:
# {'estradiol': 'PUBCHEM:10869981',
#  'fat embolism syndrome': 'MESH:D004620',
#  'first episode schizophrenia': 'ungrounded',
#  'fluoroestradiol': 'PUBCHEM:10869981',
#  'free energy surface': 'ungrounded',
#  'functional electrical stimulation': 'MESH:D004599'}

# %%
names['HGNC:3657'] = 'FES'
pos_labels.append('HGNC:3657')

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'estradiol': 'PUBCHEM:10869981',
#   'fat embolism syndrome': 'MESH:D004620',
#   'first episode schizophrenia': 'ungrounded',
#   'fluoroestradiol': 'PUBCHEM:10869981',
#   'free energy surface': 'ungrounded',
#   'functional electrical stimulation': 'MESH:D004599'},
#  {'PUBCHEM:10869981': 'Fluoroestradiol F-18',
#   'MESH:D004620': 'Embolism, Fat',
#   'MESH:D004599': 'Electric Stimulation Therapy',
#   'HGNC:3657': 'FES'},
#  ['MESH:D004599', 'MESH:D004620', 'PUBCHEM:10869981', 'HGNC:3657'])

# %%
grounding_map, names, pos_labels = ({'estradiol': 'PUBCHEM:10869981',
  'fat embolism syndrome': 'MESH:D004620',
  'first episode schizophrenia': 'ungrounded',
  'fluoroestradiol': 'PUBCHEM:10869981',
  'free energy surface': 'ungrounded',
  'functional electrical stimulation': 'MESH:D004599'},
 {'PUBCHEM:10869981': 'Fluoroestradiol F-18',
  'MESH:D004620': 'Embolism, Fat',
  'MESH:D004599': 'Electric Stimulation Therapy',
  'HGNC:3657': 'FES'},
 ['MESH:D004599', 'MESH:D004620', 'PUBCHEM:10869981', 'HGNC:3657'])

# %%
grounding_dict = {'FES': grounding_map}

# %%
classifier = AdeftClassifier('FES', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-21 09:41:58] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-21 09:42:03] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9754195047836213 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D004599': 115,
#   'MESH:D004620': 17,
#   'ungrounded': 12,
#   'PUBCHEM:10869981': 10,
#   'HGNC:3657': 87},
#  'f1': {'mean': 0.9754195047836213, 'std': 0.013901984206467233},
#  'precision': {'mean': 0.9635044143060567, 'std': 0.015031648051337746},
#  'recall': {'mean': 0.9911111111111112, 'std': 0.010886621079036362}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [(text, pred) for pred, text in zip(d, shortform_texts)if pred[0].startswith('HGNC')]

# %%
len(a)
# Out:
# 38

# %%
a[5]
# Out:
# ('To report a case of superficial punctate keratopathy (SPK) which coexisted with floppy eyelid syndrome (FES) and presented as intermittent red eye and blurred vision in an 11-year-old boy who slept in the prone position. His condition did not improve despite treatment with topical antibiotics (levofloxacin, tobramycin), steroid eye drops (prednisolone), and artificial tears. The patient was diagnosed with tonsil hypertrophy and nasopharyngeal adenoid hypertrophy and obstructive sleep apnea syndrome (OSAS). He underwent tonsillectomy and adenoidectomy. Then he started sleeping in the supine position postoperatively. The SPK, red eye and blurred vision completely resolved after surgery without additional treatment. The corneal sensation also recovered gradually during the next 7 years. However, the floppy eyelid did not resolve.\nKnown causes of superficial punctate keratopathy (SPK) in children include entropion, keratoconjunctivitis, and eye-drop toxicity [ 1 – 3 ]. However, there are some cases of SPK where the cause is not clearly identified. Here, we describe a case of childhood SPK that coexisted with floppy eyelid syndrome (FES) and presented as intermittent red eye and blurred vision which was diagnosed with tonsil hypertrophy and nasopharyngeal adenoid hypertrophy and rehabilitated by a surgical approach.\nIt is known that OSAS leads to FES because chronic hypoxia at night leads to degradation of elastin and collagen in the eyelid [ 5 ,  6 ]. The association between FES and OSAS is well known, as is that between FES and keratopathy. However, FES, OSAS and related keratopathy are reported to happen in obese adults who snore at night [ 12 – 14 ] but rarely seen in pediatric patients. The unusual complaints, clinical findings and its association with rhinopharyngeal abnormalities in this case were easily neglected by both ophthalmologists and pediatricians.\nIt has been reported that chronic rhinitis in children is related to adenoid hypertrophy, thereby causing upper airway obstruction leading to OSAS, especially at night [ 15 ,  16 ]. When the patient was in the supine position the retro-displacement of the tongue root worsened the upper airway obstruction and hence, the child resorted to the prone position during sleeping. As a result of the easy upper eyelid eversion in FES, the right-sided prone position caused the right eyelid to move away from the eyeball, leading to dryness of the ocular surface and subsequent corneal lesion and edema in the morning that manifested as redness and blurred vision. Once the patient was awake, the eyelid returned to the normal position, the conjunctival congestion disappeared, and the corneal edema resolved. Subsequently, the patient’s vision became clearer and the corneal lesion also decreased over time. However, the punctate lesion remained. The severity of the symptoms depended on the sleeping conditions and presented intermittently over the week.\n',
#  ('HGNC:3657',
#   'FES',
#   {'HGNC:3657': 0.38795343849299413,
#    'MESH:D004599': 0.3795718511421205,
#    'MESH:D004620': 0.06627415722407053,
#    'PUBCHEM:10869981': 0.05935090596066601,
#    'ungrounded': 0.10684964718014876}))

# %%
disamb.dump('FES', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('FES', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
