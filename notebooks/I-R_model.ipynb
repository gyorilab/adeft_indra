# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['DGK']
genes = ['FLT1']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['FLT1']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['DGK'].top()

# %%
top
# Out:
# [('diacylglycerol kinase', 132.88888888888889),
#  ('kinase', 65.5195530726257),
#  ('dag kinase', 20.64),
#  ('of diacylglycerol kinase', 15.411764705882353),
#  ('by diacylglycerol kinase', 12.0),
#  ('and diacylglycerol kinase', 8.833333333333334),
#  ('dg kinase', 7.0),
#  ('diacylglycerol dag kinase', 6.0),
#  ('by dag kinase', 5.428571428571429),
#  ('the diacylglycerol kinase', 5.0),
#  ('a diacylglycerol kinase', 3.0),
#  ('diacylglycerol dg kinase', 3),
#  ('that diacylglycerol kinase', 3.0),
#  ('phospholipase d pld and diacylglycerol kinase', 2.5),
#  ('for diacylglycerol kinase', 2.0),
#  ('mammalian diacylglycerol kinase', 2.0),
#  ('is catalyzed by diacylglycerol kinase', 2.0),
#  ('plc and diacylglycerol kinase', 1.5),
#  ('pa by diacylglycerol kinase', 1.3333333333333333),
#  ('role of diacylglycerol kinase', 1.3333333333333333),
#  ('phospholipase c plc and diacylglycerol kinase', 1.3333333333333333),
#  ('diacyglycerol kinase', 1.0),
#  ('by dg kinase', 1.0),
#  ('cycle diacylglycerol kinase', 1.0),
#  ('dn diacylglycerol kinase', 1.0),
#  ('with diacylglycerol kinase', 1.0),
#  ('activity of diacylglycerol kinase', 1.0),
#  ('dag by dag kinase', 1.0),
#  ('diacylglycerol by diacylglycerol kinase', 1.0),
#  ('ten mammalian diacylglycerol kinase', 1),
#  ('10 isoforms of diacylglycerol kinase', 1.0),
#  ('of the enzyme diacylglycerol kinase', 1.0),
#  ('the role of diacylglycerol kinase', 1.0),
#  ('to pa by dag kinase', 1.0),
#  ('dag to pa by diacylglycerol kinase', 1.0),
#  ('we recently report that diacylglycerol kinase', 1),
#  ('by phospholipase d pld and diacylglycerol kinase', 1.0),
#  ('in this study we identified diacylglycerol kinase', 1),
#  ('of phospholipase c plc and diacylglycerol kinase', 1.0),
#  ('physiological role of e coli diacylglycerol kinase', 1),
#  ('protein kinase c pkc and diacylglycerol kinase', 1.0),
#  ('ps enhance the metabolism activity of diacylglycerol kinase', 1),
#  ('phosphorylated of dag to pa is catalyzed by diacylglycerol kinase', 1),
#  ('atalyzes the hydrolysis of phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   1),
#  ('ated hydrolysis of glycosylphosphatidylinositol 13 14 and second diacylglycerol dag kinase',
#   1),
#  ('esult of increase diacylglycerol dg production in diabetic hyperglycaemia diacylglycerol kinase',
#   1),
#  ('in mammals there are at least 10 isoforms of diacylglycerol kinase', 1),
#  ('porcine thymus cytosol contains two immunologically distinct forms of diacylglycerol kinase',
#   1),
#  ('toward dg molecular species introduction in agonist stimulated cell diacylglycerol kinase',
#   1),
#  ('uding 4 aminobutyrate aminotransferase gabat eye specific diacylglycerol kinase isoforms x3',
#   1),
#  ('cellular signal lipid is generated by phosphorylated of diacylglycerol by diacylglycerol kinase',
#   1),
#  ('erridge and irvine 1984 subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   1),
#  ('gosine action introduction in the cellular signal transduction process diacyl glycerol kinase',
#   1),
#  ('hydrolysis of a phospholipids most like phosphatidylcholine ptdcho c a diacylglycerol kinase',
#   1),
#  ('iana suspension cell phosphoinositide depend phospholipase c pi plc and diacylglycerol kinase',
#   1),
#  ('independent pathway in an attempt to investigated differential function of diacylglycerol kinase',
#   1),
#  ('isoforms may represent a novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   1),
#  ('known the enzyme acyl coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   1),
#  ('organs especially in the process of spermatogenesis and oocyte maturation diacylglycerol kinase',
#   1),
#  ('pocket concomitantly activity of the acth camp pathway increase nuclear diacylglycerol kinase',
#   1),
#  ('1 stearoyl 2 arachidonoylglycerol the precursor of the endocannabinoid 2 ag diacylglycerol kinase',
#   1),
#  ('by phospholipase d pld and the phosphorylated of diacylglycerol dag by diacylglycerol kinase',
#   1),
#  ('conjugated linoleic acid cla was associated with the upregulation of diacylglycerol dag kinase',
#   1),
#  ('d phosphatidic we have focused on elucidate the molecular properties of diacylglycerol kinase',
#   1),
#  ('echanism leading to cardiac dysfunction and remodeling in diabetic 2 4 diacylglycerol kinase',
#   1),
#  ('function 5 6 37 39 protein kinase c pkc diacylglycerol dag diacylglycerol kinase',
#   1),
#  ('hosphatidic acid synthesis by activity both of the two alternative pathway diacyglycerol kinase',
#   1),
#  ('i 5 respectively and nonselective cation channel trpc6 and 3 6 diacylglycerol kinase',
#   1),
#  ('inal dysfunction is of utmost importance the present study demonstrated that diacylglycerol kinase',
#   1),
#  ('ling lipid produced at synapses during synaptic transmission is regulation by diacylglycerol kinase',
#   1),
#  ('of uv b treatment meanwhile two degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase',
#   1),
#  ('pis to diacylglycerol dag that is subsequently phosphorylated to ptdoh by diacylglycerol kinase',
#   1),
#  ('regulation the physiological and isotype specific function of pkc like pkc diacylglycerol kinase',
#   1),
#  ('right for translating our understanding of dgk function to helping patients diacylglycerol kinase',
#   1),
#  ('the intracellular level of phosphatidic acid primarily through the action of diacylglycerol kinase',
#   1),
#  ('vestigated prb binding to another lipid kinase in the phosphoinositide cycle diacylglycerol kinase',
#   1),
#  ('we have investigated protein kinase c pkc tyrosine protein kinase tpk diacylglycerol kinase',
#   1),
#  ('and pi3k pathway a complementing review by krishna and zhong discusses how diacylglycerol kinase',
#   1),
#  ('as been implicated in the pathogenesis of a number of diabetic complications diacylglycerol kinase',
#   1),
#  ('as hypertension which dgks may reveal itself as a novel therapeutic target diacylglycerol kinase',
#   1),
#  ('atidic acid pa by blocking plc activity however phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('cyl phosphate probe 10 μm 30 min first function proteomic annotated of diacylglycerol kinase',
#   1),
#  ('deoxy delta12 14 prostaglandin j2 15d pgj2 were capable of activity diacylglycerol dag kinase',
#   1),
#  ('e could constitute a treatment strategy for aggressive forms of cancer the diacylglycerol kinase',
#   1),
#  ('erk cascade is phosphatidic acid pa generated by phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('for pa production induced via phospholipase c plc in concerted action with diacylglycerol kinase',
#   1),
#  ('ian ollerenshaw collins and heagerty 1990 j biol chem 265 8921 8928 diacylglycerol kinase',
#   1),
#  ('in a fast evolving field this research topic illustrates the contribution of diacylglycerol kinase',
#   1),
#  ('itself is also subject to negative feedback regulation pkc can interact with diacylglycerol kinase',
#   1),
#  ('ive conditions to this end we examined the subunit dissociation kinetics of diacylglycerol kinase',
#   1),
#  ('lysis of structural phospholipids or 3 via phosphorylated of diacylglycerol dag by dag kinase',
#   1),
#  ('m of diacylglycerol dag and phosphatidic acid pa had been proposed since diacylglycerol kinase',
#   1),
#  ('r of second messengers diacylglycerol dg and inositol 1 4 5 trisphosphate diacylglycerol kinase',
#   1),
#  ('roliferation and survival pa is mainly produced by phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('signal pathway including diacylglycerol dag and pkc are involved in this process dag kinase',
#   1),
#  ('survival stimulated by hgf and other growth factors and cytokine depend on diacylglycerol kinase',
#   1),
#  ('that there may be structural similarities between protein kinase c pkc and diacylglycerol kinase',
#   1),
#  ('uced indirectly via the sequential action of phospholipase c plc and diacylglycerol dag kinase',
#   1),
#  ('udies indicate that the signal pa generated from phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('zed those leading to negative regulation of signal generated remain largely undefined dag kinase',
#   1),
#  ('a plc which generated diacylglycerol dag that is subsequently phosphorylated to pa by dag kinase',
#   1),
#  ('activity of plc which generated diacylglycerol dag that is phosphorylated to pa via dag kinase',
#   1),
#  ('acylglycerol dg and inositol 1 4 5 trisphosphate 1 2 in this system diacylglycerol kinase',
#   1),
#  ('and another is a sequence of reaction catalyzed by phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('another key enzyme in the generated of a bioactive lipid study was the diacylglycerol kinase',
#   1),
#  ('ay be related with the protein degradation machinery to date 10 isoforms of diacylglycerol kinase',
#   1),
#  ('cardiomyocytes caveolae or 2 α 1 ars increase dag but a locally activity diacyglycerol kinase',
#   1),
#  ('d by endothelin 1 et 1 and other galphaq protein coupled receptor agonist diacylglycerol kinase',
#   1),
#  ('de cycle plays a pivotal role in neuronal signal transduction in this cycle diacylglycerol kinase',
#   1),
#  ('els of these second messengers recently we have shown an obligatory role of diacylglycerol kinase',
#   1),
#  ('erentiation of cd8 t cell we report here that simultaneous deletion of both diacylglycerol kinase',
#   1),
#  ('for degradation in our present study we examined the effect of r59949 the diacylglycerol kinase',
#   1),
#  ('g oxidative stress induced intestinal epithelial cell injury however the exact role of dag kinase',
#   1),
#  ('gnaling can be generated via the combined action of phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('gnaling dg metabolism this reaction is catalyzed by an enzyme referred to as diacylglycerol kinase',
#   1),
#  ('h other synaptic protein the conversion of dag to phosphatidic acid pa by diacylglycerol kinase',
#   1),
#  ('hp 1 showed increase effector t cell activity 48 the second candidate was diacylglycerol kinase',
#   1),
#  ('ing those effect remain unknown in this study we characterized the role of diacylglycerol kinase',
#   1),
#  ('l 2014 or 2 through the combined activity of phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('l dag but not inositol triphosphate suggesting a blockade at the level of diacylglycerol kinase',
#   1),
#  ('ly to prevent neutrophil activity by ancas we have investigated a role for diacylglycerol kinase',
#   1),
#  ('lycerol dg production in diabetic hyperglycemia is one of the causes of dn diacylglycerol kinase',
#   1),
#  ('n in vivo suggesting that dgkα is an attractive therapeutic target for dn diacylglycerol kinase',
#   1),
#  ('of this signal is it conversion to phosphatidic acid which is catalyzed by diacylglycerol kinase',
#   1),
#  ('of total lipid in mammalian cell it can be produced from diacylglycerol by diacylglycerol kinase',
#   1),
#  ('olysis of membrane phospholipids by phospholipase d pld the phosphorylated of dag by dag kinase',
#   1),
#  ('on of the structural and function properties of protein kinase c pkc and diacylglycerol kinase',
#   1),
#  ('p and inhibitor binding in the poorly annotated activity site of the mammalian diacylglycerol kinase',
#   1),
#  ('ptdinsp 5 kinase independent of gtp here we report the identification of a diacylglycerol kinase',
#   1),
#  ('rade them 17 18 ftsh degradation a misfolded variant of the membrane protein diacylglycerol kinase',
#   1),
#  ('rough target protein phosphorylated dag level must be strictly controlled in the cell dag kinase',
#   1),
#  ('t and function the importance of pa mediated signal remain less clear the diacylglycerol kinase',
#   1),
#  ('to activity rasgrp to be more spatially precise because both the production plc and inactivation',
#   1),
#  ('to elucidate the molecular properties of these enzyme and first succeeded in purifying dg kinase',
#   1),
#  ('y associated with the er function one enzyme responsible for pa synthesis is diacylglycerol kinase',
#   1),
#  ('β and by the upregulation of intrinsic negative regulation such as pd1 and diacylglycerol kinase',
#   1),
#  ('ber et al 4 and zeng et al 5 have consecutively showed that dgkh diacylglycerol kinase',
#   1),
#  ('ctivation of dag that is mediated by dgk the findings that the inhibition of diacylglycerol kinase',
#   1),
#  ('e other hand mass measurement of ceramide in the cell has been performed by diacylglycerol kinase',
#   1),
#  ('ely an intermediate metabolite for tg metabolism it also serves as a signal molecule dg kinase',
#   1),
#  ('f ef hand motifs recently detected in the primary structural of porcine 80 kda diacylglycerol kinase',
#   1),
#  ('function as a potent activity of protein kinase c pkc and is catalyzed by diacylglycerol kinase',
#   1),
#  ('ing the activity and or level of either phospholipase d pld1 and pld2 or diacylglycerol kinase',
#   1),
#  ('ion in cultured and intact skeletal muscle we determined the effect of a pan diacylglycerol kinase',
#   1),
#  ('n of dag into the inactive phosphatidic acid a reaction that is mediated by diacylglycerol kinase',
#   1),
#  ('ng t cell function recently work from our group and other has indicate that diacylglycerol kinase',
#   1),
#  ('obulin ig e bound fcεri receptor in this study we determined the role of diacylglycerol kinase',
#   1),
#  ('of t cell anergy has been poorly understood used the key anergy target gene diacylglycerol kinase',
#   1),
#  ('of the t cell repertoire expression of the dag effector rasgrp1 and the dag metabolism enzyme',
#   1),
#  ('pase however an addition possibility is that 2 ag is also a substrate for diacylglycerol kinase',
#   1),
#  ('pkc plays a critical role in the development of cardiac hypertrophy and heart failure dag kinase',
#   1),
#  ('potential cation channel c trpc 4 and both conventional and novel pkcs 5 6 dg kinase',
#   1),
#  ('sing protein rasgrp chimerins and unc 13 then the generated dg is phosphorylated by dg kinase',
#   1),
#  ('that relays the tcr signal to multiple downstream signal cascade dag is terminated by dag kinase',
#   1),
#  ('tly associated with membrane dg is produced transiently as it is rapidly metabolism by dg kinase',
#   1),
#  ('tor of mtor here we explored the contribution to this pathway of the enzyme diacylglycerol kinase',
#   1),
#  ('we determined if the monoglycerides 2 ag or 2 oleoyl glycerol 2 og affected diacylglycerol kinase',
#   1),
#  ('with rac 12 the associated is gtp independent we have now found that a diacylglycerol kinase',
#   1),
#  ('1 domains of dgkα is the key event that regulation the activity of the enzyme diacylglycerol kinase',
#   1),
#  ('e dagl 1 mutation may enhance tor signal by converted more dag to pa by diacylglycerol kinase',
#   1),
#  ('enerates diacylglycerol dag as the first production and dag is rapidly converted to pa by dag kinase',
#   1),
#  ('has no inhibitory effect on pld had no effect on lc3 associated with ldcvs normally dag kinase',
#   1),
#  ('it metabolite 1 o hexadecyl 2 o methyl sn glycerol amg on the activity of diacylglycerol kinase',
#   1),
#  ('lck and zap70 19 ubiquitin ligases i e cbl b 20 and kinase i e diacylglycerol kinase',
#   1),
#  ('ligand stimulated cme of egfr in addition to pld pa can also be produced by diacylglyercol kinase',
#   1),
#  ('mer activity protein kinase c and the latter mobilizes ca 2 + from intracellular store dag kinase',
#   1),
#  ('n animals is lacking from plant genomes 5 in plant dag can be phosphorylated by dag kinase',
#   1),
#  ('n we have reveal by cdna cloning the presence of a novel enzyme family of diacylglycerol kinase',
#   1),
#  ('ras activity in cytokine stimulated t all cell to test this hypothesis we used the dag kinase',
#   1),
#  ('the heart of transgenic mice g alpha q tg induced cardiac hypertrophy and lethal hf dag kinase',
#   1),
#  ('those of dgkη1 and that they plays role in the testis in a different manner diacylglycerol kinase',
#   1),
#  ('uding growth factors and hormones the dag produced serves as a substrate for the enzyme dag kinase',
#   1),
#  ('xicity in a mouse hd striatal cell model hdh 111q 111q cell we found that diacylglycerol kinase',
#   1),
#  ('l dag athenstaedt and daum 1999 the latter can be used as a substrate for the cognate kinase',
#   1),
#  ('olyzed by dag lipase dagl to become 2 arachidonoyl sn glycerol 2 ag or modified by dag kinase',
#   1),
#  ('t the most probable mechanism of dag action is the conversion of dag to pa by diacylglycerol kinase',
#   1),
#  ('induced a significant increase of 36 1 36 2 40 5 and 40 6 diacyl pa a diacylglycerol kinase',
#   1),
#  ('enzyme', 0.0),
#  ('inactivation', 0.0),
#  ('x3', 0.0),
#  ('and inactivation', 0.0),
#  ('cognate kinase', 0.0),
#  ('diacylglyercol kinase', 0.0),
#  ('glycerol kinase', 0.0),
#  ('isoforms x3', 0.0),
#  ('metabolism enzyme', 0.0),
#  ('4 diacylglycerol kinase', 0.0),
#  ('6 dg kinase', 0.0),
#  ('6 diacylglycerol kinase', 0.0),
#  ('8928 diacylglycerol kinase', 0.0),
#  ('acid diacylglycerol kinase', 0.0),
#  ('activity diacyglycerol kinase', 0.0),
#  ('affected diacylglycerol kinase', 0.0),
#  ('ag diacylglycerol kinase', 0.0),
#  ('agonist diacylglycerol kinase', 0.0),
#  ('as diacylglycerol kinase', 0.0),
#  ('both diacylglycerol kinase', 0.0),
#  ('by diacylglyercol kinase', 0.0),
#  ('cell dag kinase', 0.0),
#  ('cell diacylglycerol kinase', 0.0),
#  ('coli diacylglycerol kinase', 0.0),
#  ('complications diacylglycerol kinase', 0.0),
#  ('dag diacylglycerol kinase', 0.0),
#  ('dag metabolism enzyme', 0.0),
#  ('dgkh diacylglycerol kinase', 0.0),
#  ('diacyl glycerol kinase', 0.0),
#  ('dysfunction diacylglycerol kinase', 0.0),
#  ('e diacylglycerol kinase', 0.0),
#  ('enzyme dag kinase', 0.0),
#  ('enzyme diacylglycerol kinase', 0.0),
#  ('failure dag kinase', 0.0),
#  ('gene diacylglycerol kinase', 0.0),
#  ('hf dag kinase', 0.0),
#  ('how diacylglycerol kinase', 0.0),
#  ('hyperglycaemia diacylglycerol kinase', 0.0),
#  ('identified diacylglycerol kinase', 0.0),
#  ('is diacylglycerol kinase', 0.0),
#  ('kda diacylglycerol kinase', 0.0),
#  ('kinase isoforms x3', 0.0),
#  ('manner diacylglycerol kinase', 0.0),
#  ('maturation diacylglycerol kinase', 0.0),
#  ('molecule dg kinase', 0.0),
#  ('normally dag kinase', 0.0),
#  ('nuclear diacylglycerol kinase', 0.0),
#  ('of dag kinase', 0.0),
#  ('on diacylglycerol kinase', 0.0),
#  ('or diacylglycerol kinase', 0.0),
#  ('pan diacylglycerol kinase', 0.0),
#  ('pathway diacyglycerol kinase', 0.0),
#  ('patients diacylglycerol kinase', 0.0),
#  ('pkc diacylglycerol kinase', 0.0),
#  ('plc and inactivation', 0.0),
#  ('process dag kinase', 0.0),
#  ('protein diacylglycerol kinase', 0.0),
#  ('purifying dg kinase', 0.0),
#  ('since diacylglycerol kinase', 0.0),
#  ('store dag kinase', 0.0),
#  ('system diacylglycerol kinase', 0.0),
#  ('target diacylglycerol kinase', 0.0),
#  ('the cognate kinase', 0.0),
#  ('the dag kinase', 0.0),
#  ('tpk diacylglycerol kinase', 0.0),
#  ('trisphosphate diacylglycerol kinase', 0.0),
#  ('undefined dag kinase', 0.0),
#  ('via dag kinase', 0.0),
#  ('was diacylglycerol kinase', 0.0),
#  ('2 4 diacylglycerol kinase', 0.0),
#  ('2 ag diacylglycerol kinase', 0.0),
#  ('3 6 diacylglycerol kinase', 0.0),
#  ('5 6 dg kinase', 0.0),
#  ('5 trisphosphate diacylglycerol kinase', 0.0),
#  ('80 kda diacylglycerol kinase', 0.0),
#  ('8921 8928 diacylglycerol kinase', 0.0),
#  ('a pan diacylglycerol kinase', 0.0),
#  ('action of diacylglycerol kinase', 0.0),
#  ('action with diacylglycerol kinase', 0.0),
#  ('activity diacylglycerol dag kinase', 0.0),
#  ('alternative pathway diacyglycerol kinase', 0.0),
#  ('and diacylglycerol dag kinase', 0.0),
#  ('annotated of diacylglycerol kinase', 0.0),
#  ('c a diacylglycerol kinase', 0.0),
#  ('cancer the diacylglycerol kinase', 0.0),
#  ('candidate was diacylglycerol kinase', 0.0),
#  ('catalyzed by diacylglycerol kinase', 0.0),
#  ('clear the diacylglycerol kinase', 0.0),
#  ('contribution of diacylglycerol kinase', 0.0),
#  ('dag by diacylglycerol kinase', 0.0),
#  ('demonstrated that diacylglycerol kinase', 0.0),
#  ('depend on diacylglycerol kinase', 0.0),
#  ('dgat and diacylglycerol kinase', 0.0),
#  ('diabetic complications diacylglycerol kinase', 0.0),
#  ('diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('diacylglycerol kinase isoforms x3', 0.0),
#  ('different manner diacylglycerol kinase', 0.0),
#  ('discusses how diacylglycerol kinase', 0.0),
#  ('e coli diacylglycerol kinase', 0.0),
#  ('family of diacylglycerol kinase', 0.0),
#  ('for dn diacylglycerol kinase', 0.0),
#  ('for the cognate kinase', 0.0),
#  ('forms of diacylglycerol kinase', 0.0),
#  ('found that diacylglycerol kinase', 0.0),
#  ('function of diacylglycerol kinase', 0.0),
#  ('glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('heart failure dag kinase', 0.0),
#  ('helping patients diacylglycerol kinase', 0.0),
#  ('i e diacylglycerol kinase', 0.0),
#  ('in purifying dg kinase', 0.0),
#  ('increase nuclear diacylglycerol kinase', 0.0),
#  ('indicate that diacylglycerol kinase', 0.0),
#  ('inhibition of diacylglycerol kinase', 0.0),
#  ('interact with diacylglycerol kinase', 0.0),
#  ('intracellular store dag kinase', 0.0),
#  ('isoforms of diacylglycerol kinase', 0.0),
#  ('kinase tpk diacylglycerol kinase', 0.0),
#  ('kinetics of diacylglycerol kinase', 0.0),
#  ('largely undefined dag kinase', 0.0),
#  ('ldcvs normally dag kinase', 0.0),
#  ('lethal hf dag kinase', 0.0),
#  ('level of diacylglycerol kinase', 0.0),
#  ('like pkc diacylglycerol kinase', 0.0),
#  ('locally activity diacyglycerol kinase', 0.0),
#  ('mediated by diacylglycerol kinase', 0.0),
#  ('membrane protein diacylglycerol kinase', 0.0),
#  ('metabolism by dg kinase', 0.0),
#  ('modified by dag kinase', 0.0),
#  ('of a diacylglycerol kinase', 0.0),
#  ('of both diacylglycerol kinase', 0.0),
#  ('of diacylglycerol dag kinase', 0.0),
#  ('of dn diacylglycerol kinase', 0.0),
#  ('og affected diacylglycerol kinase', 0.0),
#  ('oocyte maturation diacylglycerol kinase', 0.0),
#  ('pa a diacylglycerol kinase', 0.0),
#  ('pa by dag kinase', 0.0),
#  ('pa via dag kinase', 0.0),
#  ('pd1 and diacylglycerol kinase', 0.0),
#  ('performed by diacylglycerol kinase', 0.0),
#  ('phosphatidic acid diacylglycerol kinase', 0.0),
#  ('phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('phosphorylated by dag kinase', 0.0),
#  ('phosphorylated by dg kinase', 0.0),
#  ('phosphorylated by diacylglycerol kinase', 0.0),
#  ('pkc and diacylglycerol kinase', 0.0),
#  ('pld and diacylglycerol kinase', 0.0),
#  ('pld2 or diacylglycerol kinase', 0.0),
#  ('process diacyl glycerol kinase', 0.0),
#  ('produced by diacylglyercol kinase', 0.0),
#  ('production plc and inactivation', 0.0),
#  ('properties of diacylglycerol kinase', 0.0),
#  ('proposed since diacylglycerol kinase', 0.0),
#  ('ptdoh by diacylglycerol kinase', 0.0),
#  ('r59949 the diacylglycerol kinase', 0.0),
#  ('receptor agonist diacylglycerol kinase', 0.0),
#  ('regulation by diacylglycerol kinase', 0.0),
#  ('report that diacylglycerol kinase', 0.0),
#  ('role for diacylglycerol kinase', 0.0),
#  ('role of dag kinase', 0.0),
#  ('second diacylglycerol dag kinase', 0.0),
#  ('signal molecule dg kinase', 0.0),
#  ('stimulated cell diacylglycerol kinase', 0.0),
#  ('substrate for diacylglycerol kinase', 0.0),
#  ('synthesis is diacylglycerol kinase', 0.0),
#  ('target gene diacylglycerol kinase', 0.0),
#  ('terminated by dag kinase', 0.0),
#  ('that a diacylglycerol kinase', 0.0),
#  ('that dgkh diacylglycerol kinase', 0.0),
#  ('the cell dag kinase', 0.0),
#  ('the dag metabolism enzyme', 0.0),
#  ('the enzyme dag kinase', 0.0),
#  ('the enzyme diacylglycerol kinase', 0.0),
#  ('the mammalian diacylglycerol kinase', 0.0),
#  ('therapeutic target diacylglycerol kinase', 0.0),
#  ('this cycle diacylglycerol kinase', 0.0),
#  ('this process dag kinase', 0.0),
#  ('this system diacylglycerol kinase', 0.0),
#  ('to as diacylglycerol kinase', 0.0),
#  ('used the dag kinase', 0.0),
#  ('vascular dysfunction diacylglycerol kinase', 0.0),
#  ('was the diacylglycerol kinase', 0.0),
#  ('we identified diacylglycerol kinase', 0.0),
#  ('2 og affected diacylglycerol kinase', 0.0),
#  ('265 8921 8928 diacylglycerol kinase', 0.0),
#  ('4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('a different manner diacylglycerol kinase', 0.0),
#  ('a locally activity diacyglycerol kinase', 0.0),
#  ('a role for diacylglycerol kinase', 0.0),
#  ('a signal molecule dg kinase', 0.0),
#  ('a substrate for diacylglycerol kinase', 0.0),
#  ('acid pa by diacylglycerol kinase', 0.0),
#  ('acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('and 3 6 diacylglycerol kinase', 0.0),
#  ('and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('and heart failure dag kinase', 0.0),
#  ('and lethal hf dag kinase', 0.0),
#  ('and oocyte maturation diacylglycerol kinase', 0.0),
#  ('and pld2 or diacylglycerol kinase', 0.0),
#  ('and second diacylglycerol dag kinase', 0.0),
#  ('and the dag metabolism enzyme', 0.0),
#  ('anergy target gene diacylglycerol kinase', 0.0),
#  ('as pd1 and diacylglycerol kinase', 0.0),
#  ('be phosphorylated by dag kinase', 0.0),
#  ('be produced by diacylglyercol kinase', 0.0),
#  ('been performed by diacylglycerol kinase', 0.0),
#  ('been proposed since diacylglycerol kinase', 0.0),
#  ('c pkc and diacylglycerol kinase', 0.0),
#  ('c plc and diacylglycerol kinase', 0.0),
#  ('can interact with diacylglycerol kinase', 0.0),
#  ('causes of dn diacylglycerol kinase', 0.0),
#  ('concerted action with diacylglycerol kinase', 0.0),
#  ('coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('cytokine depend on diacylglycerol kinase', 0.0),
#  ('d pld and diacylglycerol kinase', 0.0),
#  ('deletion of both diacylglycerol kinase', 0.0),
#  ('diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('diacyl pa a diacylglycerol kinase', 0.0),
#  ('diacylglycerol dag by dag kinase', 0.0),
#  ('diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('differential function of diacylglycerol kinase', 0.0),
#  ('dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('distinct forms of diacylglycerol kinase', 0.0),
#  ('endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('enzyme family of diacylglycerol kinase', 0.0),
#  ('exact role of dag kinase', 0.0),
#  ('for the enzyme dag kinase', 0.0),
#  ('found that a diacylglycerol kinase', 0.0),
#  ('from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('from intracellular store dag kinase', 0.0),
#  ('generated phosphatidic acid diacylglycerol kinase', 0.0),
#  ('has indicate that diacylglycerol kinase', 0.0),
#  ('identification of a diacylglycerol kinase', 0.0),
#  ('immediately phosphorylated by diacylglycerol kinase', 0.0),
#  ('in diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('in the cell dag kinase', 0.0),
#  ('in this cycle diacylglycerol kinase', 0.0),
#  ('in this process dag kinase', 0.0),
#  ('in this system diacylglycerol kinase', 0.0),
#  ('in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('is mediated by diacylglycerol kinase', 0.0),
#  ('is phosphorylated by dg kinase', 0.0),
#  ('is regulation by diacylglycerol kinase', 0.0),
#  ('is terminated by dag kinase', 0.0),
#  ('kinase i e diacylglycerol kinase', 0.0),
#  ('less clear the diacylglycerol kinase', 0.0),
#  ('metabolism activity of diacylglycerol kinase', 0.0),
#  ('molecular properties of diacylglycerol kinase', 0.0),
#  ('novel therapeutic target diacylglycerol kinase', 0.0),
#  ('obligatory role of diacylglycerol kinase', 0.0),
#  ('of a pan diacylglycerol kinase', 0.0),
#  ('of activity diacylglycerol dag kinase', 0.0),
#  ('of cancer the diacylglycerol kinase', 0.0),
#  ('of dag by dag kinase', 0.0),
#  ('of diabetic complications diacylglycerol kinase', 0.0),
#  ('of diacylglycerol by diacylglycerol kinase', 0.0),
#  ('of e coli diacylglycerol kinase', 0.0),
#  ('of r59949 the diacylglycerol kinase', 0.0),
#  ('of the mammalian diacylglycerol kinase', 0.0),
#  ('or modified by dag kinase', 0.0),
#  ('pa synthesis is diacylglycerol kinase', 0.0),
#  ('pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('pi plc and diacylglycerol kinase', 0.0),
#  ('pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('pkc like pkc diacylglycerol kinase', 0.0),
#  ('pkcs 5 6 dg kinase', 0.0),
#  ('plc and diacylglycerol dag kinase', 0.0),
#  ('porcine 80 kda diacylglycerol kinase', 0.0),
#  ('protein kinase tpk diacylglycerol kinase', 0.0),
#  ('proteomic annotated of diacylglycerol kinase', 0.0),
#  ('ptdcho c a diacylglycerol kinase', 0.0),
#  ('rapidly metabolism by dg kinase', 0.0),
#  ('recently report that diacylglycerol kinase', 0.0),
#  ('referred to as diacylglycerol kinase', 0.0),
#  ('remain largely undefined dag kinase', 0.0),
#  ('second candidate was diacylglycerol kinase', 0.0),
#  ('showed that dgkh diacylglycerol kinase', 0.0),
#  ('specific diacylglycerol kinase isoforms x3', 0.0),
#  ('study demonstrated that diacylglycerol kinase', 0.0),
#  ('study was the diacylglycerol kinase', 0.0),
#  ('study we identified diacylglycerol kinase', 0.0),
#  ('substrate for the cognate kinase', 0.0),
#  ('succeeded in purifying dg kinase', 0.0),
#  ('target for dn diacylglycerol kinase', 0.0),
#  ('the action of diacylglycerol kinase', 0.0),
#  ('the activity of diacylglycerol kinase', 0.0),
#  ('the contribution of diacylglycerol kinase', 0.0),
#  ('the inhibition of diacylglycerol kinase', 0.0),
#  ('the level of diacylglycerol kinase', 0.0),
#  ('the membrane protein diacylglycerol kinase', 0.0),
#  ('the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('the production plc and inactivation', 0.0),
#  ('to helping patients diacylglycerol kinase', 0.0),
#  ('to pa by diacylglycerol kinase', 0.0),
#  ('to pa via dag kinase', 0.0),
#  ('to ptdoh by diacylglycerol kinase', 0.0),
#  ('transduction process diacyl glycerol kinase', 0.0),
#  ('two alternative pathway diacyglycerol kinase', 0.0),
#  ('upregulation of diacylglycerol dag kinase', 0.0),
#  ('we found that diacylglycerol kinase', 0.0),
#  ('we used the dag kinase', 0.0),
#  ('with ldcvs normally dag kinase', 0.0),
#  ('zhong discusses how diacylglycerol kinase', 0.0),
#  ('+ from intracellular store dag kinase', 0.0),
#  ('1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('14 and second diacylglycerol dag kinase', 0.0),
#  ('2 in this system diacylglycerol kinase', 0.0),
#  ('6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('a substrate for the cognate kinase', 0.0),
#  ('activity of the enzyme diacylglycerol kinase', 0.0),
#  ('ag or modified by dag kinase', 0.0),
#  ('also a substrate for diacylglycerol kinase', 0.0),
#  ('also be produced by diacylglyercol kinase', 0.0),
#  ('an obligatory role of diacylglycerol kinase', 0.0),
#  ('and cytokine depend on diacylglycerol kinase', 0.0),
#  ('and is catalyzed by diacylglycerol kinase', 0.0),
#  ('and kinase i e diacylglycerol kinase', 0.0),
#  ('and zhong discusses how diacylglycerol kinase', 0.0),
#  ('approach in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('as a signal molecule dg kinase', 0.0),
#  ('associated with ldcvs normally dag kinase', 0.0),
#  ('at the level of diacylglycerol kinase', 0.0),
#  ('both the production plc and inactivation', 0.0),
#  ('but a locally activity diacyglycerol kinase', 0.0),
#  ('c pi plc and diacylglycerol kinase', 0.0),
#  ('c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('c plc and diacylglycerol dag kinase', 0.0),
#  ('camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('can be phosphorylated by dag kinase', 0.0),
#  ('capable of activity diacylglycerol dag kinase', 0.0),
#  ('cell we found that diacylglycerol kinase', 0.0),
#  ('characterized the role of diacylglycerol kinase', 0.0),
#  ('chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('controlled in the cell dag kinase', 0.0),
#  ('converted to pa by dag kinase', 0.0),
#  ('dag is terminated by dag kinase', 0.0),
#  ('date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('determined the role of diacylglycerol kinase', 0.0),
#  ('dg is phosphorylated by dg kinase', 0.0),
#  ('diacylglycerol acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('effect of a pan diacylglycerol kinase', 0.0),
#  ('effect of r59949 the diacylglycerol kinase', 0.0),
#  ('enzyme referred to as diacylglycerol kinase', 0.0),
#  ('eye specific diacylglycerol kinase isoforms x3', 0.0),
#  ('first succeeded in purifying dg kinase', 0.0),
#  ('for pa synthesis is diacylglycerol kinase', 0.0),
#  ('forms of cancer the diacylglycerol kinase', 0.0),
#  ('function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('function to helping patients diacylglycerol kinase', 0.0),
#  ('generated remain largely undefined dag kinase', 0.0),
#  ('glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('had been proposed since diacylglycerol kinase', 0.0),
#  ('has been performed by diacylglycerol kinase', 0.0),
#  ('hypertrophy and heart failure dag kinase', 0.0),
#  ('hypertrophy and lethal hf dag kinase', 0.0),
#  ('hypothesis we used the dag kinase', 0.0),
#  ('illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('in a different manner diacylglycerol kinase', 0.0),
#  ('in agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('in concerted action with diacylglycerol kinase', 0.0),
#  ('in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('investigated a role for diacylglycerol kinase', 0.0),
#  ('investigated differential function of diacylglycerol kinase', 0.0),
#  ('involved in this process dag kinase', 0.0),
#  ('is immediately phosphorylated by diacylglycerol kinase', 0.0),
#  ('is rapidly metabolism by dg kinase', 0.0),
#  ('key anergy target gene diacylglycerol kinase', 0.0),
#  ('kinase c pkc and diacylglycerol kinase', 0.0),
#  ('least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('lipid study was the diacylglycerol kinase', 0.0),
#  ('novel enzyme family of diacylglycerol kinase', 0.0),
#  ('novel pkcs 5 6 dg kinase', 0.0),
#  ('now found that a diacylglycerol kinase', 0.0),
#  ('number of diabetic complications diacylglycerol kinase', 0.0),
#  ('of diacylglycerol dag by dag kinase', 0.0),
#  ('of diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('of pkc like pkc diacylglycerol kinase', 0.0),
#  ('of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('of the membrane protein diacylglycerol kinase', 0.0),
#  ('on the activity of diacylglycerol kinase', 0.0),
#  ('other has indicate that diacylglycerol kinase', 0.0),
#  ('pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('phosphatidylcholine ptdcho c a diacylglycerol kinase', 0.0),
#  ('phosphorylated of dag by dag kinase', 0.0),
#  ('phosphorylated of diacylglycerol by diacylglycerol kinase', 0.0),
#  ('phosphorylated to pa by dag kinase', 0.0),
#  ('phosphorylated to pa via dag kinase', 0.0),
#  ('phosphorylated to ptdoh by diacylglycerol kinase', 0.0),
#  ('pkc can interact with diacylglycerol kinase', 0.0),
#  ('pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('present study demonstrated that diacylglycerol kinase', 0.0),
#  ('produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('production in diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('protein coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('remain less clear the diacylglycerol kinase', 0.0),
#  ('role of e coli diacylglycerol kinase', 0.0),
#  ('signal transduction process diacyl glycerol kinase', 0.0),
#  ('simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('site of the mammalian diacylglycerol kinase', 0.0),
#  ('spermatogenesis and oocyte maturation diacylglycerol kinase', 0.0),
#  ('substrate for the enzyme dag kinase', 0.0),
#  ('subunit dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('such as pd1 and diacylglycerol kinase', 0.0),
#  ('that is mediated by diacylglycerol kinase', 0.0),
#  ('that the inhibition of diacylglycerol kinase', 0.0),
#  ('the causes of dn diacylglycerol kinase', 0.0),
#  ('the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('the exact role of dag kinase', 0.0),
#  ('the identification of a diacylglycerol kinase', 0.0),
#  ('the metabolism activity of diacylglycerol kinase', 0.0),
#  ('the molecular properties of diacylglycerol kinase', 0.0),
#  ('the second candidate was diacylglycerol kinase', 0.0),
#  ('the two alternative pathway diacyglycerol kinase', 0.0),
#  ('the upregulation of diacylglycerol dag kinase', 0.0),
#  ('therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('this study we identified diacylglycerol kinase', 0.0),
#  ('through the action of diacylglycerol kinase', 0.0),
#  ('to generated phosphatidic acid diacylglycerol kinase', 0.0),
#  ('transduction in this cycle diacylglycerol kinase', 0.0),
#  ('transmission is regulation by diacylglycerol kinase', 0.0),
#  ('trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('which is catalyzed by diacylglycerol kinase', 0.0),
#  ('1 2 in this system diacylglycerol kinase', 0.0),
#  ('111q cell we found that diacylglycerol kinase', 0.0),
#  ('13 14 and second diacylglycerol dag kinase', 0.0),
#  ('2 + from intracellular store dag kinase', 0.0),
#  ('2 ag or modified by dag kinase', 0.0),
#  ('20 and kinase i e diacylglycerol kinase', 0.0),
#  ('40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('48 the second candidate was diacylglycerol kinase', 0.0),
#  ('a diacylglycerol acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('a novel enzyme family of diacylglycerol kinase', 0.0),
#  ('a number of diabetic complications diacylglycerol kinase', 0.0),
#  ('a substrate for the enzyme dag kinase', 0.0),
#  ('acid which is catalyzed by diacylglycerol kinase', 0.0),
#  ('acth camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('activity site of the mammalian diacylglycerol kinase', 0.0),
#  ('aggressive forms of cancer the diacylglycerol kinase', 0.0),
#  ('amg on the activity of diacylglycerol kinase', 0.0),
#  ('an enzyme referred to as diacylglycerol kinase', 0.0),
#  ('and first succeeded in purifying dg kinase', 0.0),
#  ('and novel pkcs 5 6 dg kinase', 0.0),
#  ('and other has indicate that diacylglycerol kinase', 0.0),
#  ('are involved in this process dag kinase', 0.0),
#  ('as a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('as a substrate for the cognate kinase', 0.0),
#  ('at least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('attractive therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('be produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('because both the production plc and inactivation', 0.0),
#  ('bioactive lipid study was the diacylglycerol kinase', 0.0),
#  ('biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('blockade at the level of diacylglycerol kinase', 0.0),
#  ('by phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('by phosphorylated of diacylglycerol by diacylglycerol kinase', 0.0),
#  ('can also be produced by diacylglyercol kinase', 0.0),
#  ('cardiac hypertrophy and heart failure dag kinase', 0.0),
#  ('cardiac hypertrophy and lethal hf dag kinase', 0.0),
#  ('cascade dag is terminated by dag kinase', 0.0),
#  ('cell has been performed by diacylglycerol kinase', 0.0),
#  ('cellular signal transduction process diacyl glycerol kinase', 0.0),
#  ('channel trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('d pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('dag but a locally activity diacyglycerol kinase', 0.0),
#  ('dag can be phosphorylated by dag kinase', 0.0),
#  ('degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('dg is immediately phosphorylated by diacylglycerol kinase', 0.0),
#  ('dg production in diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('dgk function to helping patients diacylglycerol kinase', 0.0),
#  ('effector rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('elucidate the molecular properties of diacylglycerol kinase', 0.0),
#  ('enhance the metabolism activity of diacylglycerol kinase', 0.0),
#  ('factors and cytokine depend on diacylglycerol kinase', 0.0),
#  ('findings that the inhibition of diacylglycerol kinase', 0.0),
#  ('first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('from phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('function of pkc like pkc diacylglycerol kinase', 0.0),
#  ('gabat eye specific diacylglycerol kinase isoforms x3', 0.0),
#  ('galphaq protein coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('generated dg is phosphorylated by dg kinase', 0.0),
#  ('have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('have investigated a role for diacylglycerol kinase', 0.0),
#  ('have now found that a diacylglycerol kinase', 0.0),
#  ('however phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('however the exact role of dag kinase', 0.0),
#  ('inositol 1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('introduction in agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('is also a substrate for diacylglycerol kinase', 0.0),
#  ('is phosphorylated to pa via dag kinase', 0.0),
#  ('it is rapidly metabolism by dg kinase', 0.0),
#  ('kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('kinase in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('krishna and zhong discusses how diacylglycerol kinase', 0.0),
#  ('lc3 associated with ldcvs normally dag kinase', 0.0),
#  ('like phosphatidylcholine ptdcho c a diacylglycerol kinase', 0.0),
#  ('more dag to pa by diacylglycerol kinase', 0.0),
#  ('of dag to pa by diacylglycerol kinase', 0.0),
#  ('of spermatogenesis and oocyte maturation diacylglycerol kinase', 0.0),
#  ('of the causes of dn diacylglycerol kinase', 0.0),
#  ('of the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('oleoyl glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('pa had been proposed since diacylglycerol kinase', 0.0),
#  ('phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   0.0),
#  ('phospholipase c pi plc and diacylglycerol kinase', 0.0),
#  ('phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('phosphorylated of diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('pkc and is catalyzed by diacylglycerol kinase', 0.0),
#  ('pkc tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('plc in concerted action with diacylglycerol kinase', 0.0),
#  ('primarily through the action of diacylglycerol kinase', 0.0),
#  ('rapidly converted to pa by dag kinase', 0.0),
#  ('reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('regulation pkc can interact with diacylglycerol kinase', 0.0),
#  ('regulation such as pd1 and diacylglycerol kinase', 0.0),
#  ('remodeling in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('report the identification of a diacylglycerol kinase', 0.0),
#  ('responsible for pa synthesis is diacylglycerol kinase', 0.0),
#  ('serves as a signal molecule dg kinase', 0.0),
#  ('shown an obligatory role of diacylglycerol kinase', 0.0),
#  ('signal generated remain largely undefined dag kinase', 0.0),
#  ('signal remain less clear the diacylglycerol kinase', 0.0),
#  ('signal transduction in this cycle diacylglycerol kinase', 0.0),
#  ('strictly controlled in the cell dag kinase', 0.0),
#  ('structural of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('subsequently phosphorylated to pa by dag kinase', 0.0),
#  ('subsequently phosphorylated to ptdoh by diacylglycerol kinase', 0.0),
#  ('synaptic transmission is regulation by diacylglycerol kinase', 0.0),
#  ('testis in a different manner diacylglycerol kinase', 0.0),
#  ('that simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('the activity of the enzyme diacylglycerol kinase', 0.0),
#  ('the effect of a pan diacylglycerol kinase', 0.0),
#  ('the effect of r59949 the diacylglycerol kinase', 0.0),
#  ('the key anergy target gene diacylglycerol kinase', 0.0),
#  ('the phosphorylated of dag by dag kinase', 0.0),
#  ('the present study demonstrated that diacylglycerol kinase', 0.0),
#  ('the subunit dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('therapeutic approach in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('this hypothesis we used the dag kinase', 0.0),
#  ('this pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('to date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('to investigated differential function of diacylglycerol kinase', 0.0),
#  ('to pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('to phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('topic illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('two immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('we characterized the role of diacylglycerol kinase', 0.0),
#  ('we determined the role of diacylglycerol kinase', 0.0),
#  ('were capable of activity diacylglycerol dag kinase', 0.0),
#  ('with the upregulation of diacylglycerol dag kinase', 0.0),
#  ('111q 111q cell we found that diacylglycerol kinase', 0.0),
#  ('2 oleoyl glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('5 have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('a bioactive lipid study was the diacylglycerol kinase', 0.0),
#  ('a blockade at the level of diacylglycerol kinase', 0.0),
#  ('a reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('acid pa had been proposed since diacylglycerol kinase', 0.0),
#  ('acid primarily through the action of diacylglycerol kinase', 0.0),
#  ('action of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('activity 48 the second candidate was diacylglycerol kinase', 0.0),
#  ('activity however phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('activity of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('ag is also a substrate for diacylglycerol kinase', 0.0),
#  ('also serves as a signal molecule dg kinase', 0.0),
#  ('aminotransferase gabat eye specific diacylglycerol kinase isoforms x3',
#   0.0),
#  ('an attractive therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('and 40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('and inositol 1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('and remodeling in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('annotated activity site of the mammalian diacylglycerol kinase', 0.0),
#  ('are at least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('as a substrate for the enzyme dag kinase', 0.0),
#  ('as it is rapidly metabolism by dg kinase', 0.0),
#  ('associated with the upregulation of diacylglycerol dag kinase', 0.0),
#  ('attempt to investigated differential function of diacylglycerol kinase',
#   0.0),
#  ('b 20 and kinase i e diacylglycerol kinase', 0.0),
#  ('be strictly controlled in the cell dag kinase', 0.0),
#  ('between protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('both of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('by an enzyme referred to as diacylglycerol kinase', 0.0),
#  ('by krishna and zhong discusses how diacylglycerol kinase', 0.0),
#  ('c pkc and is catalyzed by diacylglycerol kinase', 0.0),
#  ('c pkc tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('c plc in concerted action with diacylglycerol kinase', 0.0),
#  ('ca 2 + from intracellular store dag kinase', 0.0),
#  ('can be produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('catalyzed by phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('cation channel trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   0.0),
#  ('contains two immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('conventional and novel pkcs 5 6 dg kinase', 0.0),
#  ('conversion of dag to pa by diacylglycerol kinase', 0.0),
#  ('converted more dag to pa by diacylglycerol kinase', 0.0),
#  ('dag effector rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('dag to pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('dag to phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('depend phospholipase c pi plc and diacylglycerol kinase', 0.0),
#  ('determined the effect of a pan diacylglycerol kinase', 0.0),
#  ('diacylglycerol dg production in diabetic hyperglycaemia diacylglycerol kinase',
#   0.0),
#  ('during synaptic transmission is regulation by diacylglycerol kinase', 0.0),
#  ('enzyme and first succeeded in purifying dg kinase', 0.0),
#  ('enzyme responsible for pa synthesis is diacylglycerol kinase', 0.0),
#  ('examined the effect of r59949 the diacylglycerol kinase', 0.0),
#  ('examined the subunit dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('feedback regulation pkc can interact with diacylglycerol kinase', 0.0),
#  ('for aggressive forms of cancer the diacylglycerol kinase', 0.0),
#  ('generated by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('generated by phosphorylated of diacylglycerol by diacylglycerol kinase',
#   0.0),
#  ('generated from phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('glycerol 2 ag or modified by dag kinase', 0.0),
#  ('glycerol amg on the activity of diacylglycerol kinase', 0.0),
#  ('glycosylphosphatidylinositol 13 14 and second diacylglycerol dag kinase',
#   0.0),
#  ('group and other has indicate that diacylglycerol kinase', 0.0),
#  ('growth factors and cytokine depend on diacylglycerol kinase', 0.0),
#  ('have shown an obligatory role of diacylglycerol kinase', 0.0),
#  ('here that simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('importance the present study demonstrated that diacylglycerol kinase', 0.0),
#  ('increase dag but a locally activity diacyglycerol kinase', 0.0),
#  ('induced cardiac hypertrophy and lethal hf dag kinase', 0.0),
#  ('injury however the exact role of dag kinase', 0.0),
#  ('is rapidly converted to pa by dag kinase', 0.0),
#  ('is subsequently phosphorylated to pa by dag kinase', 0.0),
#  ('is subsequently phosphorylated to ptdoh by diacylglycerol kinase', 0.0),
#  ('itself as a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('j biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('lipid kinase in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('machinery to date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('mediated signal remain less clear the diacylglycerol kinase', 0.0),
#  ('min first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('misfolded variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('most like phosphatidylcholine ptdcho c a diacylglycerol kinase', 0.0),
#  ('negative regulation such as pd1 and diacylglycerol kinase', 0.0),
#  ('neuronal signal transduction in this cycle diacylglycerol kinase', 0.0),
#  ('novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   0.0),
#  ('of a novel enzyme family of diacylglycerol kinase', 0.0),
#  ('of a number of diabetic complications diacylglycerol kinase', 0.0),
#  ('of cardiac hypertrophy and heart failure dag kinase', 0.0),
#  ('of dgk function to helping patients diacylglycerol kinase', 0.0),
#  ('of phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   0.0),
#  ('of phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('of protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('of signal generated remain largely undefined dag kinase', 0.0),
#  ('on elucidate the molecular properties of diacylglycerol kinase', 0.0),
#  ('on lc3 associated with ldcvs normally dag kinase', 0.0),
#  ('one of the causes of dn diacylglycerol kinase', 0.0),
#  ('other galphaq protein coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('pa can also be produced by diacylglyercol kinase', 0.0),
#  ('pgj2 were capable of activity diacylglycerol dag kinase', 0.0),
#  ('phosphatidic acid which is catalyzed by diacylglycerol kinase', 0.0),
#  ('phospholipase d pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('pkc are involved in this process dag kinase', 0.0),
#  ('plant dag can be phosphorylated by dag kinase', 0.0),
#  ('pld the phosphorylated of dag by dag kinase', 0.0),
#  ('precise because both the production plc and inactivation', 0.0),
#  ('precursor of the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('primary structural of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('process of spermatogenesis and oocyte maturation diacylglycerol kinase',
#   0.0),
#  ('produced by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('protein kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('regulation the activity of the enzyme diacylglycerol kinase', 0.0),
#  ('research topic illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('signal cascade dag is terminated by dag kinase', 0.0),
#  ('species introduction in agonist stimulated cell diacylglycerol kinase',
#   0.0),
#  ('specific function of pkc like pkc diacylglycerol kinase', 0.0),
#  ('study we characterized the role of diacylglycerol kinase', 0.0),
#  ('study we determined the role of diacylglycerol kinase', 0.0),
#  ('subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   0.0),
#  ('test this hypothesis we used the dag kinase', 0.0),
#  ('that is phosphorylated to pa via dag kinase', 0.0),
#  ('the acth camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('the cell has been performed by diacylglycerol kinase', 0.0),
#  ('the cellular signal transduction process diacyl glycerol kinase', 0.0),
#  ('the findings that the inhibition of diacylglycerol kinase', 0.0),
#  ('the generated dg is phosphorylated by dg kinase', 0.0),
#  ('the phosphorylated of diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('the testis in a different manner diacylglycerol kinase', 0.0),
#  ('to this pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('trisphosphate 1 2 in this system diacylglycerol kinase', 0.0),
#  ('two degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('used as a substrate for the cognate kinase', 0.0),
#  ('used the key anergy target gene diacylglycerol kinase', 0.0),
#  ('via phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('we have investigated a role for diacylglycerol kinase', 0.0),
#  ('we have now found that a diacylglycerol kinase', 0.0),
#  ('we report the identification of a diacylglycerol kinase', 0.0),
#  ('15d pgj2 were capable of activity diacylglycerol dag kinase', 0.0),
#  ('1984 subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   0.0),
#  ('1990 j biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('2 ag is also a substrate for diacylglycerol kinase', 0.0),
#  ('3 via phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('30 min first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('39 protein kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('5 and 40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('5 trisphosphate 1 2 in this system diacylglycerol kinase', 0.0),
#  ('a misfolded variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('a novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   0.0),
#  ('acid a reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('action of phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('activity both of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('acyl coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   0.0),
#  ('al 5 have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('aminobutyrate aminotransferase gabat eye specific diacylglycerol kinase isoforms x3',
#   0.0),
#  ('an attempt to investigated differential function of diacylglycerol kinase',
#   0.0),
#  ('ancas we have investigated a role for diacylglycerol kinase', 0.0),
#  ('and other galphaq protein coupled receptor agonist diacylglycerol kinase',
#   0.0),
#  ('and pkc are involved in this process dag kinase', 0.0),
#  ('and the phosphorylated of diacylglycerol dag by diacylglycerol kinase',
#   0.0),
#  ('another lipid kinase in the phosphoinositide cycle diacylglycerol kinase',
#   0.0),
#  ('ars increase dag but a locally activity diacyglycerol kinase', 0.0),
#  ('be used as a substrate for the cognate kinase', 0.0),
#  ('both conventional and novel pkcs 5 6 dg kinase', 0.0),
#  ('by converted more dag to pa by diacylglycerol kinase', 0.0),
#  ('catalyzed by an enzyme referred to as diacylglycerol kinase', 0.0),
#  ('cbl b 20 and kinase i e diacylglycerol kinase', 0.0),
#  ('cell activity 48 the second candidate was diacylglycerol kinase', 0.0),
#  ('cell injury however the exact role of dag kinase', 0.0),
#  ('combined action of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('combined activity of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('contribution to this pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('cytosol contains two immunologically distinct forms of diacylglycerol kinase',
#   0.0),
#  ('d pld the phosphorylated of dag by dag kinase', 0.0),
#  ('dag is rapidly converted to pa by dag kinase', 0.0),
#  ('dag that is phosphorylated to pa via dag kinase', 0.0),
#  ('degradation machinery to date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('development of cardiac hypertrophy and heart failure dag kinase', 0.0),
#  ('dg and inositol 1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('dgk the findings that the inhibition of diacylglycerol kinase', 0.0),
#  ('downstream signal cascade dag is terminated by dag kinase', 0.0),
#  ('dysfunction and remodeling in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('effect on lc3 associated with ldcvs normally dag kinase', 0.0),
#  ('either phospholipase d pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('focused on elucidate the molecular properties of diacylglycerol kinase',
#   0.0),
#  ('hdh 111q 111q cell we found that diacylglycerol kinase', 0.0),
#  ('here we report the identification of a diacylglycerol kinase', 0.0),
#  ('hydrolysis of phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   0.0),
#  ('in neuronal signal transduction in this cycle diacylglycerol kinase', 0.0),
#  ('in plant dag can be phosphorylated by dag kinase', 0.0),
#  ('in the cell has been performed by diacylglycerol kinase', 0.0),
#  ('in the cellular signal transduction process diacyl glycerol kinase', 0.0),
#  ('in the testis in a different manner diacylglycerol kinase', 0.0),
#  ('increase diacylglycerol dg production in diabetic hyperglycaemia diacylglycerol kinase',
#   0.0),
#  ('independent we have now found that a diacylglycerol kinase', 0.0),
#  ('intrinsic negative regulation such as pd1 and diacylglycerol kinase', 0.0),
#  ('is an attractive therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('is generated by phosphorylated of diacylglycerol by diacylglycerol kinase',
#   0.0),
#  ('is one of the causes of dn diacylglycerol kinase', 0.0),
#  ('isotype specific function of pkc like pkc diacylglycerol kinase', 0.0),
#  ('it also serves as a signal molecule dg kinase', 0.0),
#  ('it can be produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('kinase c pkc and is catalyzed by diacylglycerol kinase', 0.0),
#  ('kinase c pkc tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('mainly produced by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('meanwhile two degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase',
#   0.0),
#  ('mobilizes ca 2 + from intracellular store dag kinase', 0.0),
#  ('molecular species introduction in agonist stimulated cell diacylglycerol kinase',
#   0.0),
#  ('must be strictly controlled in the cell dag kinase', 0.0),
#  ('negative feedback regulation pkc can interact with diacylglycerol kinase',
#   0.0),
#  ('nonselective cation channel trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('of a bioactive lipid study was the diacylglycerol kinase', 0.0),
#  ('of dag to pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('of dag to phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('of glycosylphosphatidylinositol 13 14 and second diacylglycerol dag kinase',
#   0.0),
#  ('of the acth camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('one enzyme responsible for pa synthesis is diacylglycerol kinase', 0.0),
#  ('or 2 oleoyl glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('other growth factors and cytokine depend on diacylglycerol kinase', 0.0),
#  ('our group and other has indicate that diacylglycerol kinase', 0.0),
#  ('pa generated by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('pa generated from phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('pa mediated signal remain less clear the diacylglycerol kinase', 0.0),
#  ('pathogenesis of a number of diabetic complications diacylglycerol kinase',
#   0.0),
#  ('phosphatidic acid pa had been proposed since diacylglycerol kinase', 0.0),
#  ('phosphatidic acid primarily through the action of diacylglycerol kinase',
#   0.0),
#  ('phosphoinositide depend phospholipase c pi plc and diacylglycerol kinase',
#   0.0),
#  ('phospholipase c plc in concerted action with diacylglycerol kinase', 0.0),
#  ('phospholipids most like phosphatidylcholine ptdcho c a diacylglycerol kinase',
#   0.0),
#  ('plc activity however phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('pld pa can also be produced by diacylglyercol kinase', 0.0),
#  ('poorly annotated activity site of the mammalian diacylglycerol kinase',
#   0.0),
#  ('presence of a novel enzyme family of diacylglycerol kinase', 0.0),
#  ('properties of protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('reaction catalyzed by phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('regulation of signal generated remain largely undefined dag kinase', 0.0),
#  ('report here that simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('reveal itself as a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('review by krishna and zhong discusses how diacylglycerol kinase', 0.0),
#  ('serves as a substrate for the enzyme dag kinase', 0.0),
#  ('similarities between protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('sn glycerol 2 ag or modified by dag kinase', 0.0),
#  ('sn glycerol amg on the activity of diacylglycerol kinase', 0.0),
#  ('spatially precise because both the production plc and inactivation', 0.0),
#  ('strategy for aggressive forms of cancer the diacylglycerol kinase', 0.0),
#  ('suggesting a blockade at the level of diacylglycerol kinase', 0.0),
#  ('synapses during synaptic transmission is regulation by diacylglycerol kinase',
#   0.0),
#  ('tg induced cardiac hypertrophy and lethal hf dag kinase', 0.0),
#  ('that is subsequently phosphorylated to pa by dag kinase', 0.0),
#  ('that is subsequently phosphorylated to ptdoh by diacylglycerol kinase',
#   0.0),
#  ('that regulation the activity of the enzyme diacylglycerol kinase', 0.0),
#  ('the conversion of dag to pa by diacylglycerol kinase', 0.0),
#  ('the dag effector rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('the precursor of the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('the primary structural of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('the process of spermatogenesis and oocyte maturation diacylglycerol kinase',
#   0.0),
#  ('then the generated dg is phosphorylated by dg kinase', 0.0),
#  ('there are at least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('these enzyme and first succeeded in purifying dg kinase', 0.0),
#  ('this research topic illustrates the contribution of diacylglycerol kinase',
#   0.0),
#  ('this study we characterized the role of diacylglycerol kinase', 0.0),
#  ('this study we determined the role of diacylglycerol kinase', 0.0),
#  ('to phosphatidic acid which is catalyzed by diacylglycerol kinase', 0.0),
#  ('to test this hypothesis we used the dag kinase', 0.0),
#  ...]

# %%
longforms0 = miners['FRT'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('the female reproductive tract', 31.72340425531915)),
#  (1, ('target', 22.941176470588236)),
#  (2, ('rat thyroid', 12.32)),
#  (3, ('time', 3.2)),
#  (4, ('site', 2.0)),
#  (5, ('free running type', 2.0)),
#  (6, ('fischer rat thyroid cells', 2.0)),
#  (7, ('therapy', 1.3333333333333333)),
#  (8, ('rosa roxburghii tratt', 1.3333333333333333))]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i not in [0, 1, 2, 3, 4, 7]]

# %%
list(enumerate(top))
# Out:
# [(0, ('the female reproductive tract', 31.72340425531915)),
#  (1, ('in the female reproductive tract', 23.12)),
#  (2, ('target', 22.941176470588236)),
#  (3, ('female reproductive tract', 22.459016393442624)),
#  (4, ('rat thyroid', 12.32)),
#  (5, ('fischer rat thyroid', 12.142857142857142)),
#  (6, ('recognition target', 10.0)),
#  (7, ('of the female reproductive tract', 9.818181818181818)),
#  (8, ('fisher rat thyroid', 9.4)),
#  (9, ('flp recognition target', 5.555555555555555)),
#  (10, ('the human female reproductive tract', 4.6)),
#  (11, ('flippase recognition target', 4.333333333333333)),
#  (12, ('flp recombination target', 3.6)),
#  (13, ('folate receptor target', 3.5)),
#  (14, ('time', 3.2)),
#  (15, ('recombinase target', 3.2)),
#  (16, ('the flp recognition target', 3.2)),
#  (17, ('in fischer rat thyroid', 3.0)),
#  (18, ('immune system in the female reproductive tract', 2.5)),
#  (19, ('site', 2.0)),
#  (20, ('free running type', 2.0)),
#  (21, ('fischer rat thyroid cells', 2.0)),
#  (22, ('in fisher rat thyroid', 2.0)),
#  (23, ('cells in the female reproductive tract', 2.0)),
#  (24,
#   ('from saccharomyces cerevisiae induces dna bending upon interaction with the flp recognition target',
#    2)),
#  (25, ('recombination target', 1.666666666666667)),
#  (26, ('thyroid cells', 1.5)),
#  (27, ('therapy', 1.3333333333333333)),
#  (28, ('rosa roxburghii tratt', 1.3333333333333333)),
#  (29, ('from the female reproductive tract', 1.3333333333333333)),
#  (30, ('ferritin', 1.0)),
#  (31, ('rise time', 1.0)),
#  (32, ('flip recombinase target', 1.0)),
#  (33, ('flp recombinase target', 1.0)),
#  (34, ('forelimb retraction time', 1.0)),
#  (35, ('fractionated radiation therapy', 1.0)),
#  (36, ('and female reproductive tract', 1.0)),
#  (37, ('of flp recognition target', 1.0)),
#  (38, ('the flexion rotation test', 1.0)),
#  (39, ('the flippase recognition target', 1.0)),
#  (40, ('the flp recombination target', 1.0)),
#  (41, ('upper female reproductive tract', 1.0)),
#  (42, ('flavonoids of rosa roxburghii tratt', 1.0)),
#  (43, ('the mouse female reproductive tract', 1)),
#  (44, ('to the female reproductive tract', 1.0)),
#  (45, ('when the flp recombination target', 1)),
#  (46, ('and carboplatin loaded folate receptor target', 1.0)),
#  (47, ('binding to the flp recognition target', 1.0)),
#  (48, ('expression in the female reproductive tract', 1.0)),
#  (49, ('in the human female reproductive tract', 1.0)),
#  (50, ('pain from the female reproductive tract', 1)),
#  (51, ('t rm in the female reproductive tract', 1.0)),
#  (52, ('that containing a single flippase recognition target', 1.0)),
#  (53, ('the mucosa of the female reproductive tract', 1)),
#  (54,
#   ('both stereotactic radiosurgery srs and fractionated radiation therapy',
#    1)),
#  (55, ('dendritic cells dcs throughout the female reproductive tract', 1)),
#  (56, ('the immune system in the female reproductive tract', 1.0)),
#  (57, ('the mucosal surface of the female reproductive tract', 1.0)),
#  (58, ('the primary function of the female reproductive tract', 1)),
#  (59, ('or ~ 32 aco2 and entropic contributions increased ~ 39', 1)),
#  (60, ('the mucosa and overlying fluid of the female reproductive tract', 1)),
#  (61,
#   ('post immune and lymphocytes were isolated from the female reproductive tract',
#    1.0)),
#  (62,
#   ('a tetracycline driven bi directly expression plasmid containing the flippase recognition target',
#    1)),
#  (63,
#   ('carboplatin loaded nontargeted nt liposomes red and carboplatin loaded folate receptor target',
#    1)),
#  (64,
#   ('lore mechanisms associated with essential pathways of epithelial morphogenesis fischer rat thyroid',
#    1)),
#  (65,
#   ('omologous recombination mediated gene target with the flippase flp flippase recognition target',
#    1)),
#  (66,
#   ('therapy we encapsulated the most cytotoxic complex into biomacromolecular protein cage apoferritin',
#    1)),
#  (67,
#   ('tin carboplatin loaded nontargeted nt liposomes and carboplatin loaded folate receptor target',
#    1)),
#  (68,
#   ('al ion rna complex involve both electrostatic and coordination complex interaction the ferritin',
#    1)),
#  (69,
#   ('by p element mediated transformation as the target vector comprises flp recombination target',
#    1)),
#  (70,
#   ('despite extensive study of the mucosal immune system in the female reproductive tract',
#    1)),
#  (71,
#   ('ein breeder associated anafi table 1 fertility traits included the aggregate fertility index',
#    1)),
#  (72,
#   ('ethidium bromide staining amplified products were confirmed by dna sequence fisher rat thyroid',
#    1)),
#  (73,
#   ('flippase recombination enzyme into hek293 cells that containing a single flippase recognition target',
#    1)),
#  (74,
#   ('ging information from the physiology endocrinology and immunology of the female reproductive tract',
#    1)),
#  (75,
#   ('hgf secretion facilitates epithelial cells growth and developed in the female reproductive tract',
#    1)),
#  (76,
#   ('ithout drug related toxicities a cellular accumulation of dii labeled folate receptor target',
#    1)),
#  (77,
#   ('t interaction with the canopy under observation we using the fluorescence reflectance transmittance',
#    1)),
#  (78,
#   ('the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#    1.0)),
#  (79,
#   ('the risk of edema when using stereotactic radiosurgery srs versus fractionated radiation therapy',
#    1)),
#  (80,
#   ('we have investigated the mechanisms of prp c endocytosis in fischer rat thyroid',
#    1)),
#  (81,
#   ('acketed by short sequence for site specific recombination such as the flippase recognition target',
#    1)),
#  (82,
#   ('and tissue in particular we performed a comprehensive analysis of the female reproductive tract',
#    1)),
#  (83,
#   ('antify the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#    1)),
#  (84,
#   ('ation across the vaginal epithelial barrier in vivo neutrophils in the female reproductive tract',
#    1)),
#  (85,
#   ('ction these directly or indirectly impact pathogens that enter the upper female reproductive tract',
#    1)),
#  (86,
#   ('d caught herring pacific herring produce distinctive bursts of pulses termed fast repetitive tick',
#    1)),
#  (87,
#   ('driven by the phosphoglycerate kinase pgk gene promoter and flanked by flip recombinase target',
#    1)),
#  (88,
#   ('fp figure 1a flippase activity regulated by the rn2 promoter induces flip recombinase target',
#    1)),
#  (89,
#   ('has a growth inhibitory effect on s cerevisiae when overexpressed 14 flp recombinase target',
#    1)),
#  (90,
#   ('iene education however successful treatment method has not been established in free running type',
#    1)),
#  (91,
#   ('lins complement factor and bacteria 1 3 semen deposition in the female reproductive tract',
#    1)),
#  (92,
#   ('n harboring the native splice acceptor sa ii introduction of flp recombinase recognition site',
#    1)),
#  (93,
#   ('o exposure to diethylstilbestrol des leads to patterning defects in the female reproductive tract',
#    1)),
#  (94,
#   ('obial recognition and immune defense in the reproductive tract the human female reproductive tract',
#    1)),
#  (95,
#   ('of the orthopedic surgeon in the management of these problems lifelong factor replaced therapy',
#    1)),
#  (96,
#   ('ossessed channel activity fig 7 constructs were expression stably in fischer rat thyroid cells',
#    1)),
#  (97,
#   ('persist in tissue reservoirs such as the gastrointestinal gi tract and female reproductive tract',
#    1)),
#  (98,
#   ('prophylactic approaches designed to halt the transmission of hiv in the female reproductive tract',
#    1)),
#  (99,
#   ('removed initially the marker was removed by recombination of the flanked flp recognition target',
#    1)),
#  (100,
#   ('retention in the ectocervix and fornix epithelium cd47 expression in the female reproductive tract',
#    1)),
#  (101,
#   ('rmined by the dosimetric calibration outlined above similarly the effect of daily fractionated rt',
#    1)),
#  (102,
#   ('s we established three dimensional 3d epithelial culture model system using fischer rat thyroid',
#    1)),
#  (103,
#   ('side effect of radiotherapy the radioprotective effect of the flavonoids of rosa roxburghii tratt',
#    1)),
#  (104,
#   ('virus hpv generated of antigen specific cells mediated immune in the female reproductive tract',
#    1)),
#  (105,
#   ('3 enhancer to initially replication at an ectopic location we insertion a flp recombination target',
#    1)),
#  (106,
#   ('actions and their role in caveolar formation in polarized epithelial cells in fischer rat thyroid',
#    1)),
#  (107,
#   ('adverse side effect in this study ip administration was coupled with a folate receptor target',
#    1)),
#  (108,
#   ('ake and in some cells both iron acquisition and endosomal iron release ii cytoplasmic ferritin',
#    1)),
#  (109,
#   ('alysis and understand of the innate and adaptive immune system in the female reproductive tract',
#    1)),
#  (110,
#   ('and differentially many actions of hgf are mirrored by estradiol in the female reproductive tract',
#    1)),
#  (111,
#   ('at intravaginal deposition of zikv can cause tgt hormonal changes in the female reproductive tract',
#    1)),
#  (112,
#   ('binase flp1p and containing a pair of inverted repeats 599 bp containing flp1p recombinase target',
#    1)),
#  (113,
#   ('bsequently the forelimb in the holes hind limb retraction time hrt and forelimb retraction time',
#    1)),
#  (114,
#   ('c a mascia l nitsch cells polarized and morphogenetic properties of fischer rat thyroid cells',
#    1)),
#  (115,
#   ('c12 activity to restore stimulated nf κb transcription fig 1a bottom a fisher rat thyroid',
#    1)),
#  (116,
#   ('ced on day seven post immune and lymphocytes were isolated from the female reproductive tract',
#    1)),
#  (117,
#   ('cretion of mucins which provide an additional layer of protection to the female reproductive tract',
#    1)),
#  (118,
#   ('current method would also allow the insertion of certain dna sequence like flp recombinase target',
#    1)),
#  (119,
#   ('d cystic fibrosis bronchial epithelial cells cfbe41o − human airway cells and fisher rat thyroid',
#    1)),
#  (120,
#   ('d expression of both flp recombinase gene and gin11 flanked by flp recombinase recognition target',
#    1)),
#  (121,
#   ('ein e g matrix ma and nucleocapsid nc allow efficient excision of flp recognition target',
#    1)),
#  (122,
#   ('eir entry into the vaginal lumen during ovulation cd44 expression in the female reproductive tract',
#    1)),
#  (123,
#   ('ell population was selected 48 h post transfection using hygromycin 150μg ml fischer rat thyroid',
#    1)),
#  (124,
#   ('f protection against a broad range of potential pathogens that infection the female reproductive tract',
#    1)),
#  (125,
#   ('genic bacterial population 1 bv is the most common infection of the female reproductive tract',
#    1)),
#  (126,
#   ('gle nucleotide polymorphisms in circadian clock gene in 182 dspt individuals 67 free running type',
#    1)),
#  (127,
#   ('ies target protection antigen specific cd8 + t cells responses to the female reproductive tract',
#    1)),
#  (128,
#   ('ized mice were mock or candida albicans inoculated in the vagina a female reproductive tract',
#    1)),
#  (129,
#   ('l lumen has been somewhat characterize 10 how they migrate into the female reproductive tract',
#    1)),
#  (130,
#   ('lop these strategies it will be evermore importance to understand how the female reproductive tract',
#    1)),
#  (131,
#   ('lp recombinase of the 2 microns plasmid of saccharomyces cerevisiae binding to it recognition target',
#    1)),
#  (132,
#   ('ng technology to deliver carboplatin into ovarian cancer cells the authors developed a fr target',
#    1)),
#  (133,
#   ('not be directly involve in these processes the polarized epithelial cells line fischer rat thyroid',
#    1)),
#  (134,
#   ('nts of the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#    1)),
#  (135,
#   ('on is replaced by a cloramphenicol resistance cat cassette flanked by two flp recombinase site',
#    1)),
#  (136,
#   ('on strategies generated large numbers of antigen specific t cells in the female reproductive tract',
#    1)),
#  (137,
#   ('ore this hypothesis we study cftr mediated transepithelial cl − current in fischer rat thyroid',
#    1)),
#  (138,
#   ('orldwide unaids world aids day report 2011 the earliest events in the female reproductive tract',
#    1)),
#  (139,
#   ('ows one strategies using for identification of cftr inhibitor the assay utilizes fischer rat thyroid',
#    1)),
#  (140,
#   ('quantification of the mmp9 expression in ly6g + neutrophils from the lower female reproductive tract',
#    1)),
#  (141,
#   ('r study was to assess the radioprotective effect of flavonoids extracted from rosa roxburghii tratt',
#    1)),
#  (142,
#   ('ration and camp dependent regulated this is of particular importance since the fisher rat thyroid',
#    1)),
#  (143,
#   ('rich in the cholesterol binding protein caveolin vip21 in the golgi apparatus fischer rat thyroid',
#    1)),
#  (144,
#   ('rificed on day 7 post immune and lymphocytes were isolated from the female reproductive tract',
#    1)),
#  (145,
#   ('rta and rtc respectively were also measured finally cutaneous red blood cells flux recovery time',
#    1)),
#  (146,
#   ('subtypes advanced sleep phase type aspt delayed sleep phase type dspt and free running type',
#    1)),
#  (147,
#   ('t study evaluated the protection effect of the natural compound flavonoids of rosa roxburghii tratt',
#    1)),
#  (148,
#   ('the interface of the external environment and the mucosal surface of the female reproductive tract',
#    1)),
#  (149,
#   ('tipsychotic efficacy of the drug these data open the perspective that the forelimb retraction time',
#    1)),
#  (150,
#   ('tissue our aims were to characterize the short and long termed effect of fractionated radiotherapy',
#    1)),
#  (151,
#   ('to established a model for observation dynamic t cells behavior in the female reproductive tract',
#    1)),
#  (152,
#   ('ushroom body which can be combined with a dna insertion carrying flippase recognition target site',
#    1)),
#  (153,
#   ('v 1 sexual transmission occurs main via mucosal semen exposure in the female reproductive tract',
#    1)),
#  (154,
#   ('yces cerevisiae and it recognizes a specific 34 bp dna sequence termed flippase recognition target',
#    1)),
#  (155,
#   ('3b and 3c tq416 thus acts rapidly to prevent c12 mediated cellular responses fisher rat thyroid',
#    1)),
#  (156,
#   ('anti hiv 1 mechanisms of actions of cationic peptides and peptides of the female reproductive tract',
#    1)),
#  (157,
#   ('asing evidence that the first contact between hiv and immune cells in the female reproductive tract',
#    1)),
#  (158,
#   ('flp protein is a site specific recombinase that recognizes and binding to the flp recognition target',
#    1)),
#  (159,
#   ('host cells at a specific genomic location 21 in the fcho cells a flippase recombination target',
#    1)),
#  (160,
#   ('in this review we will examine the complex and unique innervation of the female reproductive tract',
#    1)),
#  (161,
#   ('ith engineered self organized tendon constructs sot or segments of adult art or fetal rat tail',
#    1)),
#  (162,
#   ('late wild type wt and δf508 mutant cftr channel activity in cftr expression fischer rat thyroid',
#    1)),
#  (163,
#   ('mined genomic locus this makes using of cells line that containing a single flippase recognition target',
#    1)),
#  (164,
#   ('n overcomes the epithelial barrier 2 to reach immune target cells in the female reproductive tract',
#    1)),
#  (165,
#   ('n the using of the yeast site specific recombinase flipase flp and it recognition target sequence',
#    1)),
#  (166,
#   ('niques to study cells expression recombination human cftr thf increased i sc in fischer rat thyroid',
#    1)),
#  (167,
#   ('o hiv infection or abort the infection before it spreads even though the female reproductive tract',
#    1)),
#  (168,
#   ('or tissue in the secretory phase the mucosal immune system of the human female reproductive tract',
#    1)),
#  (169,
#   ('percentage of cd4 + human t cells levels in the gastrointestinal gi and female reproductive tract',
#    1)),
#  (170,
#   ('s a critical role in determined the outcome of virus transmission in the female reproductive tract',
#    1)),
#  (171,
#   ('t has been report that expression of these receptor are altered in the female reproductive tract',
#    1)),
#  (172,
#   ('ted gel forming mucins responses for the main structure of mucus in the female reproductive tract',
#    1)),
#  (173,
#   ('the effect of dqa on cftr function and cells viability were investigated in fisher rat thyroid',
#    1)),
#  (174,
#   ('the pcdna5 frt vector containing the gene of interest into the genomic via flp recombination target',
#    1)),
#  (175,
#   ('v 434 hela 229 cells were obtained from the american type culture collection fischer rat thyroid',
#    1)),
#  (176,
#   ('w for example the combined effect of ire irp interaction decrease iron efflux fpn and storage',
#    1)),
#  (177,
#   ('y f0 onset and steady state formant frequencies f1 f2 f3 vowel duration formant rise time',
#    1)),
#  (178,
#   ('0 was shown to potential fsk stimulated and cftr mediated i sc in recombination fisher rat thyroid',
#    1)),
#  (179,
#   ('21 kda peptides containing a site specific dna binding domain that binding to the flp recognition target',
#    1)),
#  (180,
#   ('frt with in immune the frequencies of antigen specific cd8 + t cells present in both mucosal',
#    1)),
#  (181,
#   ('he possible role of il 36γ in host defense against pathogens in the human female reproductive tract',
#    1)),
#  (182,
#   ('he semen ascends across the cervix into the lumen of the uterus and upper female reproductive tract',
#    1)),
#  (183,
#   ('ing specific to each of three 13 base pair bp symmetry element of the flp recognition target',
#    1)),
#  (184,
#   ('l gfp infection of cd4 + t cells fig 4a hiv transmission through the female reproductive tract',
#    1)),
#  (185,
#   ('like small molecules was performed using a cells base assay of iodide influx in fisher rat thyroid',
#    1)),
#  (186,
#   ('lish an antiviral state 49 51 fig 3 lcmv specific t rm in the female reproductive tract',
#    1)),
#  (187,
#   ('men to women little attention is be paid to the immune system in the female reproductive tract',
#    1)),
#  (188,
#   ('nt study have shown a high incidence of c1 c2 dysfunction evaluated by the flexion rotation test',
#    1)),
#  (189,
#   ('serum fbs 10 penicillin streptomycin 1 and zeocin 100μg ml at 37 ° c fisher rat thyroid',
#    1)),
#  (190,
#   ('ting tlrs in the hu man frt infection within the upper regions of the female reproductive tract',
#    1)),
#  (191,
#   ('vaccination with an attenuated strain of hsv generated cd4 + t rm in the female reproductive tract',
#    1)),
#  (192,
#   ('a cftr inhibitor with potency of 20 μm as determined by halide influx assay in fisher rat thyroid',
#    1)),
#  (193,
#   ('and hek293t cells were maintained in dmem supplemented with 3 7 g l nahco 3 fischer rat thyroid',
#    1)),
#  (194,
#   ('he frt and differentially regulated by poly i c gc and hiv 1 the human female reproductive tract',
#    1)),
#  (195,
#   ('icated in etx binding and activity here we study the effect of etx on fischer rat thyroid cells',
#    1)),
#  (196,
#   ('mulus in this study we proposed a new dimension for comparing the ldf signals the flux rise time',
#    1)),
#  (197,
#   ('r processes the effect of cch on ca 2 + i was examine in nondifferentiated fischer rat thyroid',
#    1)),
#  (198,
#   ('terminus leaving a 5 hydroxyl group at the site of the nick we have using flp recognition target',
#    1)),
#  (199,
#   ('ele harboring both a pair of loxp site flanked apc exon 14 and a pair of flp recognition target',
#    1)),
#  (200,
#   ('n of the pcdna5 frt abcb1 2677g t a vector flp in 293 cells have the flp recombination target',
#    1)),
#  (201,
#   ('ng k d 12 fold frt ire rna or 6 fold aco2 ire rna enthalpic contributions decrease ~ 61',
#    1)),
#  (202,
#   ('prr nod 1 nod 2 rig 1 and mda5 have not been elucidated in the human female reproductive tract',
#    1)),
#  (203,
#   ('pwt ≤ 8 0 s brushing paw withdrawal latency pwl ≤ 0 16 g von frey flinching responses threshold',
#    1)),
#  (204,
#   ('ted in a normal rat thyroid cells line frtl 5 but not in a dedifferentiated line of thyroid cells',
#    1)),
#  (205,
#   ('sis of human peripheral blood pmns culture at basal 37 ° c and febrile range 39 5 ° c temperatures',
#    1)),
#  (206,
#   ('sis of kpn i swa i digested dna of pcv21 dr in e coli left pretransformed and a pcv21 dr',
#    1)),
#  (207,
#   ('ted plasmid dna of a pcv21 tn 5 1 in e coli left pretransformed and a pcv21 tn 5 1',
#    1)),
#  (208, ('1', 0.0)),
#  (209, ('39', 0.0)),
#  (210, ('61', 0.0)),
#  (211, ('apoferritin', 0.0)),
#  (212, ('cells', 0.0)),
#  (213, ('dr', 0.0)),
#  (214, ('index', 0.0)),
#  (215, ('mucosal', 0.0)),
#  (216, ('radiotherapy', 0.0)),
#  (217, ('rt', 0.0)),
#  (218, ('sequence', 0.0)),
#  (219, ('storage', 0.0)),
#  (220, ('tail', 0.0)),
#  (221, ('temperatures', 0.0)),
#  (222, ('test', 0.0)),
#  (223, ('thickness', 0.0)),
#  (224, ('threshold', 0.0)),
#  (225, ('thyroid', 0.0)),
#  (226, ('tick', 0.0)),
#  (227, ('tract', 0.0)),
#  (228, ('transmittance', 0.0)),
#  (229, ('tratt', 0.0)),
#  (230, ('type', 0.0)),
#  (231, ('5 1', 0.0)),
#  (232, ('and storage', 0.0)),
#  (233, ('both mucosal', 0.0)),
#  (234, ('c temperatures', 0.0)),
#  (235, ('cage apoferritin', 0.0)),
#  (236, ('cytoplasmic ferritin', 0.0)),
#  (237, ('fertility index', 0.0)),
#  (238, ('fr target', 0.0)),
#  (239, ('fractionated radiotherapy', 0.0)),
#  (240, ('fractionated rt', 0.0)),
#  (241, ('pcv21 dr', 0.0)),
#  (242, ('radiation therapy', 0.0)),
#  (243, ('rat tail', 0.0)),
#  (244, ('receptor target', 0.0)),
#  (245, ('recognition site', 0.0)),
#  (246, ('recombinase site', 0.0)),
#  (247, ('recovery time', 0.0)),
#  (248, ('reflectance transmittance', 0.0)),
#  (249, ('repetitive tick', 0.0)),
#  (250, ('replaced therapy', 0.0)),
#  (251, ('reproductive tract', 0.0)),
#  (252, ('responses threshold', 0.0)),
#  (253, ('retinal thickness', 0.0)),
#  (254, ('retraction time', 0.0)),
#  (255, ('rotation test', 0.0)),
#  (256, ('roxburghii tratt', 0.0)),
#  (257, ('running type', 0.0)),
#  (258, ('target sequence', 0.0)),
#  (259, ('target site', 0.0)),
#  (260, ('the ferritin', 0.0)),
#  (261, ('~ 39', 0.0)),
#  (262, ('~ 61', 0.0)),
#  (263, ('a fr target', 0.0)),
#  (264, ('a pcv21 dr', 0.0)),
#  (265, ('aggregate fertility index', 0.0)),
#  (266, ('daily fractionated rt', 0.0)),
#  (267, ('decrease ~ 61', 0.0)),
#  (268, ('factor replaced therapy', 0.0)),
#  (269, ('fast repetitive tick', 0.0)),
#  (270, ('fetal rat tail', 0.0)),
#  (271, ('flexion rotation test', 0.0)),
#  (272, ('flinching responses threshold', 0.0)),
#  (273, ('flippase recombination target', 0.0)),
#  (274, ('flp recombinase site', 0.0)),
#  (275, ('flp1p recombinase target', 0.0)),
#  (276, ('fluorescence reflectance transmittance', 0.0)),
#  (277, ('flux recovery time', 0.0)),
#  (278, ('flux rise time', 0.0)),
#  (279, ('formant rise time', 0.0)),
#  (280, ('fpn and storage', 0.0)),
#  (281, ('full retinal thickness', 0.0)),
#  (282, ('ii cytoplasmic ferritin', 0.0)),
#  (283, ('in both mucosal', 0.0)),
#  (284, ('increased ~ 39', 0.0)),
#  (285, ('interaction the ferritin', 0.0)),
#  (286, ('it recognition target', 0.0)),
#  (287, ('of fractionated radiotherapy', 0.0)),
#  (288, ('of thyroid cells', 0.0)),
#  (289, ('protein cage apoferritin', 0.0)),
#  (290, ('rat thyroid cells', 0.0)),
#  (291, ('recognition target sequence', 0.0)),
#  (292, ('recognition target site', 0.0)),
#  (293, ('recombinase recognition site', 0.0)),
#  (294, ('recombinase recognition target', 0.0)),
#  (295, ('tn 5 1', 0.0)),
#  (296, ('° c temperatures', 0.0)),
#  (297, ('14 flp recombinase target', 0.0)),
#  (298, ('3 fischer rat thyroid', 0.0)),
#  (299, ('5 ° c temperatures', 0.0)),
#  (300, ('67 free running type', 0.0)),
#  (301, ('a female reproductive tract', 0.0)),
#  (302, ('a fisher rat thyroid', 0.0)),
#  (303, ('a flippase recombination target', 0.0)),
#  (304, ('a flp recombination target', 0.0)),
#  (305, ('a folate receptor target', 0.0)),
#  (306, ('and a pcv21 dr', 0.0)),
#  (307, ('and fisher rat thyroid', 0.0)),
#  (308, ('and forelimb retraction time', 0.0)),
#  (309, ('and fractionated radiation therapy', 0.0)),
#  (310, ('and free running type', 0.0)),
#  (311, ('and full retinal thickness', 0.0)),
#  (312, ('apparatus fischer rat thyroid', 0.0)),
#  (313, ('biomacromolecular protein cage apoferritin', 0.0)),
#  (314, ('by flip recombinase target', 0.0)),
#  (315, ('c fisher rat thyroid', 0.0)),
#  (316, ('cells flux recovery time', 0.0)),
#  (317, ('collection fischer rat thyroid', 0.0)),
#  (318, ('complex interaction the ferritin', 0.0)),
#  (319, ('comprises flp recombination target', 0.0)),
#  (320, ('containing flp1p recombinase target', 0.0)),
#  (321, ('contributions decrease ~ 61', 0.0)),
#  (322, ('contributions increased ~ 39', 0.0)),
#  (323, ('developed a fr target', 0.0)),
#  (324, ('duration formant rise time', 0.0)),
#  (325, ('effect of fractionated radiotherapy', 0.0)),
#  (326, ('efflux fpn and storage', 0.0)),
#  (327, ('expression fischer rat thyroid', 0.0)),
#  (328, ('flanked flp recognition target', 0.0)),
#  (329, ('flippase recognition target site', 0.0)),
#  (330, ('flp flippase recognition target', 0.0)),
#  (331, ('flp recombinase recognition site', 0.0)),
#  (332, ('flp recombinase recognition target', 0.0)),
#  (333, ('frey flinching responses threshold', 0.0)),
#  (334, ('from rosa roxburghii tratt', 0.0)),
#  (335, ('human female reproductive tract', 0.0)),
#  (336, ('in free running type', 0.0)),
#  (337, ('induces flip recombinase target', 0.0)),
#  (338, ('it recognition target sequence', 0.0)),
#  (339, ('labeled folate receptor target', 0.0)),
#  (340, ('lifelong factor replaced therapy', 0.0)),
#  (341, ('like flp recombinase target', 0.0)),
#  (342, ('line fischer rat thyroid', 0.0)),
#  (343, ('line of thyroid cells', 0.0)),
#  (344, ('loaded folate receptor target', 0.0)),
#  (345, ('lower female reproductive tract', 0.0)),
#  (346, ('ml fischer rat thyroid', 0.0)),
#  (347, ('morphogenesis fischer rat thyroid', 0.0)),
#  (348, ('mouse female reproductive tract', 0.0)),
#  (349, ('nondifferentiated fischer rat thyroid', 0.0)),
#  (350, ('of daily fractionated rt', 0.0)),
#  (351, ('of rosa roxburghii tratt', 0.0)),
#  (352, ('or fetal rat tail', 0.0)),
#  (353, ('pcv21 tn 5 1', 0.0)),
#  (354, ('present in both mucosal', 0.0)),
#  (355, ('recombination fisher rat thyroid', 0.0)),
#  (356, ('release ii cytoplasmic ferritin', 0.0)),
#  (357, ('responses fisher rat thyroid', 0.0)),
#  (358, ('sequence fisher rat thyroid', 0.0)),
#  (359, ('single flippase recognition target', 0.0)),
#  (360, ('termed fast repetitive tick', 0.0)),
#  (361, ('termed flippase recognition target', 0.0)),
#  (362, ('the aggregate fertility index', 0.0)),
#  (363, ('the fisher rat thyroid', 0.0)),
#  (364, ('the fluorescence reflectance transmittance', 0.0)),
#  (365, ('the flux rise time', 0.0)),
#  (366, ('the forelimb retraction time', 0.0)),
#  (367, ('to it recognition target', 0.0)),
#  (368, ('two flp recombinase site', 0.0)),
#  (369, ('using fischer rat thyroid', 0.0)),
#  (370, ('using flp recognition target', 0.0)),
#  (371, ('utilizes fischer rat thyroid', 0.0)),
#  (372, ('versus fractionated radiation therapy', 0.0)),
#  (373, ('via flp recombination target', 0.0)),
#  (374, ('150μg ml fischer rat thyroid', 0.0)),
#  (375, ('39 5 ° c temperatures', 0.0)),
#  (376, ('a pcv21 tn 5 1', 0.0)),
#  (377, ('a single flippase recognition target', 0.0)),
#  (378, ('and it recognition target sequence', 0.0)),
#  (379, ('and upper female reproductive tract', 0.0)),
#  (380, ('art or fetal rat tail', 0.0)),
#  (381, ('as the flippase recognition target', 0.0)),
#  (382, ('assay in fisher rat thyroid', 0.0)),
#  (383, ('assay utilizes fischer rat thyroid', 0.0)),
#  (384, ('authors developed a fr target', 0.0)),
#  (385, ('binding to it recognition target', 0.0)),
#  (386, ('blood cells flux recovery time', 0.0)),
#  (387, ('bottom a fisher rat thyroid', 0.0)),
#  (388, ('bp containing flp1p recombinase target', 0.0)),
#  (389, ('by flp recombinase recognition target', 0.0)),
#  (390, ('by the flexion rotation test', 0.0)),
#  (391, ('by two flp recombinase site', 0.0)),
#  (392, ('carboplatin loaded folate receptor target', 0.0)),
#  (393, ('carrying flippase recognition target site', 0.0)),
#  (394, ('cells a flippase recombination target', 0.0)),
#  (395, ('cells and fisher rat thyroid', 0.0)),
#  (396, ('cells in fischer rat thyroid', 0.0)),
#  (397, ('cells line fischer rat thyroid', 0.0)),
#  (398, ('cells present in both mucosal', 0.0)),
#  (399, ('cellular responses fisher rat thyroid', 0.0)),
#  (400, ('cftr expression fischer rat thyroid', 0.0)),
#  (401, ('containing the flippase recognition target', 0.0)),
#  (402, ('coordination complex interaction the ferritin', 0.0)),
#  (403, ('culture collection fischer rat thyroid', 0.0)),
#  (404, ('current in fischer rat thyroid', 0.0)),
#  (405, ('dedifferentiated line of thyroid cells', 0.0)),
#  (406, ('dii labeled folate receptor target', 0.0)),
#  (407, ('dna sequence fisher rat thyroid', 0.0)),
#  (408, ('dspt and free running type', 0.0)),
#  (409, ('effect of daily fractionated rt', 0.0)),
#  (410, ('endocytosis in fischer rat thyroid', 0.0)),
#  (411, ('enthalpic contributions decrease ~ 61', 0.0)),
#  (412, ('entropic contributions increased ~ 39', 0.0)),
#  (413, ('epithelial morphogenesis fischer rat thyroid', 0.0)),
#  (414, ('established in free running type', 0.0)),
#  (415, ('excision of flp recognition target', 0.0)),
#  (416, ('extracted from rosa roxburghii tratt', 0.0)),
#  (417, ('flanked by flip recombinase target', 0.0)),
#  (418, ('flippase flp flippase recognition target', 0.0)),
#  (419, ('genomic via flp recombination target', 0.0)),
#  (420, ('gi and female reproductive tract', 0.0)),
#  (421, ('golgi apparatus fischer rat thyroid', 0.0)),
#  (422, ('have the flp recombination target', 0.0)),
#  (423, ('have using flp recognition target', 0.0)),
#  (424, ('how the female reproductive tract', 0.0)),
#  (425, ('hrt and forelimb retraction time', 0.0)),
#  (426, ('in fischer rat thyroid cells', 0.0)),
#  (427, ('in nondifferentiated fischer rat thyroid', 0.0)),
#  (428, ('in recombination fisher rat thyroid', 0.0)),
#  (429, ('included the aggregate fertility index', 0.0)),
#  (430, ('individuals 67 free running type', 0.0)),
#  (431, ('infection the female reproductive tract', 0.0)),
#  (432, ('influx in fisher rat thyroid', 0.0)),
#  (433, ('insertion a flp recombination target', 0.0)),
#  (434, ('into biomacromolecular protein cage apoferritin', 0.0)),
#  (435, ('into the female reproductive tract', 0.0)),
#  (436, ('investigated in fisher rat thyroid', 0.0)),
#  (437, ('iron efflux fpn and storage', 0.0)),
#  (438, ('iron release ii cytoplasmic ferritin', 0.0)),
#  (439, ('nahco 3 fischer rat thyroid', 0.0)),
#  (440, ('of fischer rat thyroid cells', 0.0)),
#  (441, ('of flp recombinase recognition site', 0.0)),
#  (442, ('of the flp recognition target', 0.0)),
#  (443, ('on fischer rat thyroid cells', 0.0)),
#  (444, ('ort and full retinal thickness', 0.0)),
#  (445, ('overexpressed 14 flp recombinase target', 0.0)),
#  (446, ('pair of flp recognition target', 0.0)),
#  (447, ('pretransformed and a pcv21 dr', 0.0)),
#  (448, ('problems lifelong factor replaced therapy', 0.0)),
#  (449, ('promoter induces flip recombinase target', 0.0)),
#  (450, ('pulses termed fast repetitive tick', 0.0)),
#  (451, ('sc in fischer rat thyroid', 0.0)),
#  (452, ('sequence like flp recombinase target', 0.0)),
#  (453, ('sequence termed flippase recognition target', 0.0)),
#  (454, ('signals the flux rise time', 0.0)),
#  (455, ('since the fisher rat thyroid', 0.0)),
#  (456, ('srs and fractionated radiation therapy', 0.0)),
#  (457, ('srs versus fractionated radiation therapy', 0.0)),
#  (458, ('system using fischer rat thyroid', 0.0)),
#  (459, ('termed effect of fractionated radiotherapy', 0.0)),
#  (460, ('that the forelimb retraction time', 0.0)),
#  (461, ('the flanked flp recognition target', 0.0)),
#  (462, ('the lower female reproductive tract', 0.0)),
#  (463, ('the upper female reproductive tract', 0.0)),
#  (464, ('though the female reproductive tract', 0.0)),
#  (465, ('through the female reproductive tract', 0.0)),
#  (466, ('throughout the female reproductive tract', 0.0)),
#  (467, ('to the flp recognition target', 0.0)),
#  (468, ('tract and female reproductive tract', 0.0)),
#  (469, ('using the fluorescence reflectance transmittance', 0.0)),
#  (470, ('vagina a female reproductive tract', 0.0)),
#  (471, ('vector comprises flp recombination target', 0.0)),
#  (472, ('von frey flinching responses threshold', 0.0)),
#  (473, ('vowel duration formant rise time', 0.0)),
#  (474, ('with a folate receptor target', 0.0)),
#  (475, ('with the flp recognition target', 0.0)),
#  (476, ('° c fisher rat thyroid', 0.0)),
#  (477, ('1 the human female reproductive tract', 0.0)),
#  (478, ('1a bottom a fisher rat thyroid', 0.0)),
#  (479, ('37 ° c fisher rat thyroid', 0.0)),
#  (480, ('599 bp containing flp1p recombinase target', 0.0)),
#  (481, ('a dedifferentiated line of thyroid cells', 0.0)),
#  (482, ('a pair of flp recognition target', 0.0)),
#  (483, ('adult art or fetal rat tail', 0.0)),
#  (484, ('airway cells and fisher rat thyroid', 0.0)),
#  (485, ('altered in the female reproductive tract', 0.0)),
#  (486, ('analysis of the female reproductive tract', 0.0)),
#  (487, ('and a pcv21 tn 5 1', 0.0)),
#  (488, ('and coordination complex interaction the ferritin', 0.0)),
#  (489, ('and entropic contributions increased ~ 39', 0.0)),
#  (490, ('and flanked by flip recombinase target', 0.0)),
#  (491, ('been established in free running type', 0.0)),
#  (492, ('behavior in the female reproductive tract', 0.0)),
#  (493, ('by dna sequence fisher rat thyroid', 0.0)),
#  (494, ('c endocytosis in fischer rat thyroid', 0.0)),
#  (495, ('cells have the flp recombination target', 0.0)),
#  (496, ('cerevisiae binding to it recognition target', 0.0)),
#  (497, ('changes in the female reproductive tract', 0.0)),
#  (498, ('complex into biomacromolecular protein cage apoferritin', 0.0)),
#  (499, ('compound flavonoids of rosa roxburghii tratt', 0.0)),
#  (500, ('containing a single flippase recognition target', 0.0)),
#  (501, ('coupled with a folate receptor target', 0.0)),
#  (502, ('dcs throughout the female reproductive tract', 0.0)),
#  (503, ('decrease iron efflux fpn and storage', 0.0)),
#  (504, ('defects in the female reproductive tract', 0.0)),
#  (505, ('deposition in the female reproductive tract', 0.0)),
#  (506, ('developed in the female reproductive tract', 0.0)),
#  (507, ('dna sequence like flp recombinase target', 0.0)),
#  (508, ('dna sequence termed flippase recognition target', 0.0)),
#  (509, ('dspt individuals 67 free running type', 0.0)),
#  (510, ('efficient excision of flp recognition target', 0.0)),
#  (511, ('element of the flp recognition target', 0.0)),
#  (512, ('endosomal iron release ii cytoplasmic ferritin', 0.0)),
#  (513, ('enter the upper female reproductive tract', 0.0)),
#  (514, ('epithelial cells in fischer rat thyroid', 0.0)),
#  (515, ('epithelial cells line fischer rat thyroid', 0.0)),
#  (516, ('estradiol in the female reproductive tract', 0.0)),
#  (517, ('etx on fischer rat thyroid cells', 0.0)),
#  (518, ('evaluated by the flexion rotation test', 0.0)),
#  (519, ('even though the female reproductive tract', 0.0)),
#  (520, ('events in the female reproductive tract', 0.0)),
#  (521, ('examine in nondifferentiated fischer rat thyroid', 0.0)),
#  (522, ('exposure in the female reproductive tract', 0.0)),
#  (523, ('f3 vowel duration formant rise time', 0.0)),
#  (524, ('fcho cells a flippase recombination target', 0.0)),
#  (525, ('flanked by flp recombinase recognition target', 0.0)),
#  (526, ('flanked by two flp recombinase site', 0.0)),
#  (527, ('flavonoids extracted from rosa roxburghii tratt', 0.0)),
#  (528, ('flp and it recognition target sequence', 0.0)),
#  (529, ('fluid of the female reproductive tract', 0.0)),
#  (530, ('from the lower female reproductive tract', 0.0)),
#  (531, ('function of the female reproductive tract', 0.0)),
#  (532, ('g von frey flinching responses threshold', 0.0)),
#  (533, ('gastrointestinal gi and female reproductive tract', 0.0)),
#  (534, ('gi tract and female reproductive tract', 0.0)),
#  (535, ('hiv in the female reproductive tract', 0.0)),
#  (536, ('hygromycin 150μg ml fischer rat thyroid', 0.0)),
#  (537, ('i sc in fischer rat thyroid', 0.0)),
#  (538, ('immune in the female reproductive tract', 0.0)),
#  (539, ('immunology of the female reproductive tract', 0.0)),
#  (540, ('importance since the fisher rat thyroid', 0.0)),
#  (541, ('in cftr expression fischer rat thyroid', 0.0)),
#  (542, ('infection of the female reproductive tract', 0.0)),
#  (543, ('influx assay in fisher rat thyroid', 0.0)),
#  (544, ('innervation of the female reproductive tract', 0.0)),
#  (545, ('insertion carrying flippase recognition target site', 0.0)),
#  (546, ('interaction with the flp recognition target', 0.0)),
#  (547, ('introduction of flp recombinase recognition site', 0.0)),
#  (548, ('iodide influx in fisher rat thyroid', 0.0)),
#  (549, ('isolated from the female reproductive tract', 0.0)),
#  (550, ('l nahco 3 fischer rat thyroid', 0.0)),
#  (551, ('ldf signals the flux rise time', 0.0)),
#  (552, ('left pretransformed and a pcv21 dr', 0.0)),
#  (553, ('long termed effect of fractionated radiotherapy', 0.0)),
#  (554, ('mediated cellular responses fisher rat thyroid', 0.0)),
#  (555, ('migrate into the female reproductive tract', 0.0)),
#  (556, ('model system using fischer rat thyroid', 0.0)),
#  (557, ('mucosa of the female reproductive tract', 0.0)),
#  (558, ('mucus in the female reproductive tract', 0.0)),
#  (559, ('neutrophils in the female reproductive tract', 0.0)),
#  (560, ('of dii labeled folate receptor target', 0.0)),
#  (561, ('of epithelial morphogenesis fischer rat thyroid', 0.0)),
#  (562, ('of pulses termed fast repetitive tick', 0.0)),
#  (563, ('of the flanked flp recognition target', 0.0)),
#  (564, ('of the human female reproductive tract', 0.0)),
#  (565, ('peptides of the female reproductive tract', 0.0)),
#  (566, ('perspective that the forelimb retraction time', 0.0)),
#  (567, ('plasmid containing the flippase recognition target', 0.0)),
#  (568, ('properties of fischer rat thyroid cells', 0.0)),
#  (569, ('protection to the female reproductive tract', 0.0)),
#  (570, ('radiosurgery srs and fractionated radiation therapy', 0.0)),
#  (571, ('radiosurgery srs versus fractionated radiation therapy', 0.0)),
#  (572, ('range 39 5 ° c temperatures', 0.0)),
#  (573, ('red blood cells flux recovery time', 0.0)),
#  (574, ('regions of the female reproductive tract', 0.0)),
#  (575, ('responses to the female reproductive tract', 0.0)),
#  (576, ('rm in the female reproductive tract', 0.0)),
#  (577, ('rn2 promoter induces flip recombinase target', 0.0)),
#  (578, ('rna enthalpic contributions decrease ~ 61', 0.0)),
#  (579, ('sc in recombination fisher rat thyroid', 0.0)),
#  (580, ('stably in fischer rat thyroid cells', 0.0)),
#  (581, ('such as the flippase recognition target', 0.0)),
#  (582, ('surface of the female reproductive tract', 0.0)),
#  (583, ('system in the female reproductive tract', 0.0)),
#  (584, ('t cells present in both mucosal', 0.0)),
#  (585, ('target vector comprises flp recombination target', 0.0)),
#  (586, ('that infection the female reproductive tract', 0.0)),
#  (587, ('the assay utilizes fischer rat thyroid', 0.0)),
#  (588, ('the authors developed a fr target', 0.0)),
#  (589, ('the effect of daily fractionated rt', 0.0)),
#  (590, ('the flavonoids of rosa roxburghii tratt', 0.0)),
#  (591, ('the flippase flp flippase recognition target', 0.0)),
#  (592, ('the genomic via flp recombination target', 0.0)),
#  (593, ('the golgi apparatus fischer rat thyroid', 0.0)),
#  (594, ('the vagina a female reproductive tract', 0.0)),
#  (595, ('these problems lifelong factor replaced therapy', 0.0)),
#  (596, ('thickness ort and full retinal thickness', 0.0)),
#  (597, ('time hrt and forelimb retraction time', 0.0)),
#  (598, ('tract the human female reproductive tract', 0.0)),
#  (599, ('traits included the aggregate fertility index', 0.0)),
#  (600, ('transmission in the female reproductive tract', 0.0)),
#  (601, ('transmission through the female reproductive tract', 0.0)),
#  (602, ('type culture collection fischer rat thyroid', 0.0)),
#  (603, ('type dspt and free running type', 0.0)),
#  (604, ('understand how the female reproductive tract', 0.0)),
#  (605, ('uterus and upper female reproductive tract', 0.0)),
#  (606, ('we have using flp recognition target', 0.0)),
#  (607, ('we insertion a flp recombination target', 0.0)),
#  (608, ('we using the fluorescence reflectance transmittance', 0.0)),
#  (609, ('were investigated in fisher rat thyroid', 0.0)),
#  (610, ('when overexpressed 14 flp recombinase target', 0.0)),
#  (611, ('− current in fischer rat thyroid', 0.0)),
#  (612, ('+ t cells present in both mucosal', 0.0)),
#  (613, ('16 g von frey flinching responses threshold', 0.0)),
#  (614, ('182 dspt individuals 67 free running type', 0.0)),
#  (615, ('293 cells have the flp recombination target', 0.0)),
#  (616, ('accumulation of dii labeled folate receptor target', 0.0)),
#  (617, ('aco2 and entropic contributions increased ~ 39', 0.0)),
#  (618, ('activity in cftr expression fischer rat thyroid', 0.0)),
#  (619, ('allow efficient excision of flp recognition target', 0.0)),
#  (620, ('american type culture collection fischer rat thyroid', 0.0)),
#  (621, ('and a pair of flp recognition target', 0.0)),
#  (622, ('and binding to the flp recognition target', 0.0)),
#  (623, ('and developed in the female reproductive tract', 0.0)),
#  (624, ('and endosomal iron release ii cytoplasmic ferritin', 0.0)),
#  (625, ('and immunology of the female reproductive tract', 0.0)),
#  (626, ('and long termed effect of fractionated radiotherapy', 0.0)),
#  (627, ('and peptides of the female reproductive tract', 0.0)),
#  (628, ('are altered in the female reproductive tract', 0.0)),
#  (629, ('at 37 ° c fisher rat thyroid', 0.0)),
#  (630, ('bp dna sequence termed flippase recognition target', 0.0)),
#  (631, ('bursts of pulses termed fast repetitive tick', 0.0)),
#  (632, ('by estradiol in the female reproductive tract', 0.0)),
#  (633, ('c12 mediated cellular responses fisher rat thyroid', 0.0)),
#  (634, ('cassette flanked by two flp recombinase site', 0.0)),
#  (635, ('cd44 expression in the female reproductive tract', 0.0)),
#  (636, ('cd47 expression in the female reproductive tract', 0.0)),
#  (637, ('cells behavior in the female reproductive tract', 0.0)),
#  (638, ('cells dcs throughout the female reproductive tract', 0.0)),
#  (639, ('cells responses to the female reproductive tract', 0.0)),
#  (640, ('cells the authors developed a fr target', 0.0)),
#  (641, ('cerevisiae when overexpressed 14 flp recombinase target', 0.0)),
#  (642, ('certain dna sequence like flp recombinase target', 0.0)),
#  (643, ('cl − current in fischer rat thyroid', 0.0)),
#  (644, ('coli left pretransformed and a pcv21 dr', 0.0)),
#  (645, ('common infection of the female reproductive tract', 0.0)),
#  (646, ('comprehensive analysis of the female reproductive tract', 0.0)),
#  (647, ('confirmed by dna sequence fisher rat thyroid', 0.0)),
#  (648, ('culture model system using fischer rat thyroid', 0.0)),
#  (649, ('cutaneous red blood cells flux recovery time', 0.0)),
#  (650,
#   ('cytotoxic complex into biomacromolecular protein cage apoferritin', 0.0)),
#  (651, ('dna insertion carrying flippase recognition target site', 0.0)),
#  (652, ('dysfunction evaluated by the flexion rotation test', 0.0)),
#  (653, ('earliest events in the female reproductive tract', 0.0)),
#  (654,
#   ('electrostatic and coordination complex interaction the ferritin', 0.0)),
#  (655, ('elucidated in the human female reproductive tract', 0.0)),
#  (656, ('expression plasmid containing the flippase recognition target', 0.0)),
#  (657, ('expression stably in fischer rat thyroid cells', 0.0)),
#  (658, ('f2 f3 vowel duration formant rise time', 0.0)),
#  (659, ('febrile range 39 5 ° c temperatures', 0.0)),
#  (660, ('fertility traits included the aggregate fertility index', 0.0)),
#  (661, ('fig 1a bottom a fisher rat thyroid', 0.0)),
#  (662, ('flipase flp and it recognition target sequence', 0.0)),
#  (663, ('g l nahco 3 fischer rat thyroid', 0.0)),
#  (664, ('gastrointestinal gi tract and female reproductive tract', 0.0)),
#  (665, ('gin11 flanked by flp recombinase recognition target', 0.0)),
#  (666, ('halide influx assay in fisher rat thyroid', 0.0)),
#  (667, ('hiv 1 the human female reproductive tract', 0.0)),
#  (668, ('hiv transmission through the female reproductive tract', 0.0)),
#  (669, ('hormonal changes in the female reproductive tract', 0.0)),
#  (670, ('human airway cells and fisher rat thyroid', 0.0)),
#  (671, ('i sc in recombination fisher rat thyroid', 0.0)),
#  (672, ('ii introduction of flp recombinase recognition site', 0.0)),
#  (673, ('immune cells in the female reproductive tract', 0.0)),
#  (674, ('in a dedifferentiated line of thyroid cells', 0.0)),
#  (675, ('in the golgi apparatus fischer rat thyroid', 0.0)),
#  (676, ('in the vagina a female reproductive tract', 0.0)),
#  (677, ('increased i sc in fischer rat thyroid', 0.0)),
#  (678, ('inhibitor the assay utilizes fischer rat thyroid', 0.0)),
#  (679, ('interaction decrease iron efflux fpn and storage', 0.0)),
#  (680, ('into the genomic via flp recombination target', 0.0)),
#  (681, ('ire rna enthalpic contributions decrease ~ 61', 0.0)),
#  (682, ('liposomes and carboplatin loaded folate receptor target', 0.0)),
#  (683, ('location we insertion a flp recombination target', 0.0)),
#  (684, ('mediated immune in the female reproductive tract', 0.0)),
#  (685, ('morphogenetic properties of fischer rat thyroid cells', 0.0)),
#  (686, ('mucosal surface of the female reproductive tract', 0.0)),
#  (687, ('natural compound flavonoids of rosa roxburghii tratt', 0.0)),
#  (688, ('neutrophils from the lower female reproductive tract', 0.0)),
#  (689, ('nick we have using flp recognition target', 0.0)),
#  (690, ('not been established in free running type', 0.0)),
#  (691,
#   ('observation we using the fluorescence reflectance transmittance', 0.0)),
#  (692, ('of adult art or fetal rat tail', 0.0)),
#  (693, ('of etx on fischer rat thyroid cells', 0.0)),
#  (694, ('of flavonoids extracted from rosa roxburghii tratt', 0.0)),
#  (695, ('of hiv in the female reproductive tract', 0.0)),
#  (696, ('of iodide influx in fisher rat thyroid', 0.0)),
#  (697, ('of mucus in the female reproductive tract', 0.0)),
#  (698, ('of protection to the female reproductive tract', 0.0)),
#  (699, ('of the flavonoids of rosa roxburghii tratt', 0.0)),
#  (700, ('of these problems lifelong factor replaced therapy', 0.0)),
#  (701, ('overlying fluid of the female reproductive tract', 0.0)),
#  (702, ('particular importance since the fisher rat thyroid', 0.0)),
#  (703, ('pathogens in the human female reproductive tract', 0.0)),
#  (704, ('pathogens that infection the female reproductive tract', 0.0)),
#  (705, ('pathways of epithelial morphogenesis fischer rat thyroid', 0.0)),
#  (706, ('patterning defects in the female reproductive tract', 0.0)),
#  (707, ('phase type dspt and free running type', 0.0)),
#  (708, ('polarized epithelial cells in fischer rat thyroid', 0.0)),
#  (709, ('polarized epithelial cells line fischer rat thyroid', 0.0)),
#  (710, ('pretransformed and a pcv21 tn 5 1', 0.0)),
#  (711, ('primary function of the female reproductive tract', 0.0)),
#  (712, ('promoter and flanked by flip recombinase target', 0.0)),
#  (713, ('prp c endocytosis in fischer rat thyroid', 0.0)),
#  (714, ('recombination of the flanked flp recognition target', 0.0)),
#  (715, ('recombination such as the flippase recognition target', 0.0)),
#  (716, ('red and carboplatin loaded folate receptor target', 0.0)),
#  (717, ('repeats 599 bp containing flp1p recombinase target', 0.0)),
#  (718, ('reproductive tract the human female reproductive tract', 0.0)),
#  (719, ('retinal thickness ort and full retinal thickness', 0.0)),
#  (720, ('retraction time hrt and forelimb retraction time', 0.0)),
#  (721, ('saccharomyces cerevisiae binding to it recognition target', 0.0)),
#  (722, ('semen deposition in the female reproductive tract', 0.0)),
#  (723, ('semen exposure in the female reproductive tract', 0.0)),
#  (724, ('similarly the effect of daily fractionated rt', 0.0)),
#  (725, ('spreads even though the female reproductive tract', 0.0)),
#  (726,
#   ('stereotactic radiosurgery srs and fractionated radiation therapy', 0.0)),
#  (727,
#   ('stereotactic radiosurgery srs versus fractionated radiation therapy',
#    0.0)),
#  (728, ('symmetry element of the flp recognition target', 0.0)),
# ...
#  (786, ('by recombination of the flanked flp recognition target', 0.0)),
#  (787, ('by the rn2 promoter induces flip recombinase target', 0.0)),
#  (788, ('c2 dysfunction evaluated by the flexion rotation test', 0.0)),
#  (789, ('cancer cells the authors developed a fr target', 0.0)),
#  (790, ('cat cassette flanked by two flp recombinase site', 0.0)),
#  (791, ('cd8 + t cells present in both mucosal', 0.0)),
#  (792, ('cells mediated immune in the female reproductive tract', 0.0)),
#  (793, ('cells that containing a single flippase recognition target', 0.0)),
#  (794, ('cells viability were investigated in fisher rat thyroid', 0.0)),
#  (795, ('cellular accumulation of dii labeled folate receptor target', 0.0)),
#  (796, ('cftr inhibitor the assay utilizes fischer rat thyroid', 0.0)),
#  (797, ('channel activity in cftr expression fischer rat thyroid', 0.0)),
#  (798, ('comparing the ldf signals the flux rise time', 0.0)),
#  (799,
#   ('directly expression plasmid containing the flippase recognition target',
#    0.0)),
#  (800, ('distinctive bursts of pulses termed fast repetitive tick', 0.0)),
#  (801, ('domain that binding to the flp recognition target', 0.0)),
#  (802, ('e coli left pretransformed and a pcv21 dr', 0.0)),
#  (803, ('ectopic location we insertion a flp recombination target', 0.0)),
#  (804, ('effect of etx on fischer rat thyroid cells', 0.0)),
#  (805, ('effect of flavonoids extracted from rosa roxburghii tratt', 0.0)),
#  (806, ('effect of the flavonoids of rosa roxburghii tratt', 0.0)),
#  (807, ('endocrinology and immunology of the female reproductive tract', 0.0)),
#  (808, ('epithelial culture model system using fischer rat thyroid', 0.0)),
#  (809, ('epithelium cd47 expression in the female reproductive tract', 0.0)),
#  (810,
#   ('essential pathways of epithelial morphogenesis fischer rat thyroid', 0.0)),
#  (811, ('f1 f2 f3 vowel duration formant rise time', 0.0)),
#  (812, ('finally cutaneous red blood cells flux recovery time', 0.0)),
#  (813, ('gene promoter and flanked by flip recombinase target', 0.0)),
#  (814, ('growth and developed in the female reproductive tract', 0.0)),
#  (815, ('has not been established in free running type', 0.0)),
#  (816, ('how they migrate into the female reproductive tract', 0.0)),
#  (817, ('i was examine in nondifferentiated fischer rat thyroid', 0.0)),
#  (818, ('immune system of the human female reproductive tract', 0.0)),
#  (819, ('immune target cells in the female reproductive tract', 0.0)),
#  (820, ('importance to understand how the female reproductive tract', 0.0)),
#  (821, ('in 182 dspt individuals 67 free running type', 0.0)),
#  (822, ('in 293 cells have the flp recombination target', 0.0)),
#  (823, ('in polarized epithelial cells in fischer rat thyroid', 0.0)),
#  (824, ('in the fcho cells a flippase recombination target', 0.0)),
#  (825, ('in the gastrointestinal gi and female reproductive tract', 0.0)),
#  (826, ('in vivo neutrophils in the female reproductive tract', 0.0)),
#  (827, ('inoculated in the vagina a female reproductive tract', 0.0)),
#  (828, ('interest into the genomic via flp recombination target', 0.0)),
#  (829, ('inverted repeats 599 bp containing flp1p recombinase target', 0.0)),
#  (830, ('irp interaction decrease iron efflux fpn and storage', 0.0)),
#  (831, ('it spreads even though the female reproductive tract', 0.0)),
#  (832, ('layer of protection to the female reproductive tract', 0.0)),
#  (833, ('left pretransformed and a pcv21 tn 5 1', 0.0)),
#  (834, ('limb retraction time hrt and forelimb retraction time', 0.0)),
#  (835, ('line that containing a single flippase recognition target', 0.0)),
#  (836, ('liposomes red and carboplatin loaded folate receptor target', 0.0)),
#  (837, ('lymphocytes were isolated from the female reproductive tract', 0.0)),
#  (838, ('management of these problems lifelong factor replaced therapy', 0.0)),
#  (839, ('mediated i sc in recombination fisher rat thyroid', 0.0)),
#  (840, ('mirrored by estradiol in the female reproductive tract', 0.0)),
#  (841, ('ml at 37 ° c fisher rat thyroid', 0.0)),
#  (842, ('most common infection of the female reproductive tract', 0.0)),
#  (843,
#   ('most cytotoxic complex into biomacromolecular protein cage apoferritin',
#    0.0)),
#  (844, ('mucosal immune system in the female reproductive tract', 0.0)),
#  (845, ('mucosal semen exposure in the female reproductive tract', 0.0)),
#  (846, ('nc allow efficient excision of flp recognition target', 0.0)),
#  (847, ('not in a dedifferentiated line of thyroid cells', 0.0)),
#  (848, ('nt liposomes and carboplatin loaded folate receptor target', 0.0)),
#  (849, ('of certain dna sequence like flp recombinase target', 0.0)),
#  (850, ('of particular importance since the fisher rat thyroid', 0.0)),
#  (851, ('of prp c endocytosis in fischer rat thyroid', 0.0)),
#  (852, ('of saccharomyces cerevisiae binding to it recognition target', 0.0)),
#  (853, ('of the uterus and upper female reproductive tract', 0.0)),
#  (854, ('of virus transmission in the female reproductive tract', 0.0)),
#  (855, ('open the perspective that the forelimb retraction time', 0.0)),
#  (856, ('outer retinal thickness ort and full retinal thickness', 0.0)),
#  (857, ('ovulation cd44 expression in the female reproductive tract', 0.0)),
#  (858, ('pathogens that enter the upper female reproductive tract', 0.0)),
#  (859, ('peptides and peptides of the female reproductive tract', 0.0)),
#  (860,
#   ('potential pathogens that infection the female reproductive tract', 0.0)),
#  (861, ('prevent c12 mediated cellular responses fisher rat thyroid', 0.0)),
#  (862, ('receptor are altered in the female reproductive tract', 0.0)),
#  (863, ('recognizes and binding to the flp recognition target', 0.0)),
#  (864, ('recombinase flipase flp and it recognition target sequence', 0.0)),
#  (865, ('s cerevisiae when overexpressed 14 flp recombinase target', 0.0)),
#  (866, ('sa ii introduction of flp recombinase recognition site', 0.0)),
#  (867, ('segments of adult art or fetal rat tail', 0.0)),
#  (868, ('short and long termed effect of fractionated radiotherapy', 0.0)),
#  (869, ('sleep phase type dspt and free running type', 0.0)),
#  (870,
#   ('specific recombination such as the flippase recognition target', 0.0)),
#  (871, ('specific t cells in the female reproductive tract', 0.0)),
#  (872, ('specific t rm in the female reproductive tract', 0.0)),
#  (873, ('structure of mucus in the female reproductive tract', 0.0)),
#  (874, ('t cells behavior in the female reproductive tract', 0.0)),
#  (875, ('t cells responses to the female reproductive tract', 0.0)),
#  (876, ('target with the flippase flp flippase recognition target', 0.0)),
#  (877, ('tgt hormonal changes in the female reproductive tract', 0.0)),
#  (878, ('the american type culture collection fischer rat thyroid', 0.0)),
#  (879, ('the earliest events in the female reproductive tract', 0.0)),
#  (880, ('the gastrointestinal gi tract and female reproductive tract', 0.0)),
#  (881, ('the natural compound flavonoids of rosa roxburghii tratt', 0.0)),
#  (882, ('the nick we have using flp recognition target', 0.0)),
#  (883, ('the polarized epithelial cells line fischer rat thyroid', 0.0)),
#  (884, ('the reproductive tract the human female reproductive tract', 0.0)),
#  (885, ('the upper regions of the female reproductive tract', 0.0)),
#  (886, ('thf increased i sc in fischer rat thyroid', 0.0)),
#  (887, ('to patterning defects in the female reproductive tract', 0.0)),
#  (888, ('transcription fig 1a bottom a fisher rat thyroid', 0.0)),
#  (889, ('transepithelial cl − current in fischer rat thyroid', 0.0)),
#  (890, ('transfection using hygromycin 150μg ml fischer rat thyroid', 0.0)),
#  (891, ('transmission of hiv in the female reproductive tract', 0.0)),
#  (892,
#   ('under observation we using the fluorescence reflectance transmittance',
#    0.0)),
#  (893,
#   ('using stereotactic radiosurgery srs versus fractionated radiation therapy',
#    0.0)),
#  (894, ('vip21 in the golgi apparatus fischer rat thyroid', 0.0)),
#  (895, ('were confirmed by dna sequence fisher rat thyroid', 0.0)),
#  (896, ('were expression stably in fischer rat thyroid cells', 0.0)),
#  (897, ('− human airway cells and fisher rat thyroid', 0.0)),
#  (898, ('+ i was examine in nondifferentiated fischer rat thyroid', 0.0)),
#  (899, ('+ t cells responses to the female reproductive tract', 0.0)),
#  (900, ('1 3 semen deposition in the female reproductive tract', 0.0)),
#  (901, ('10 how they migrate into the female reproductive tract', 0.0)),
#  (902, ('100μg ml at 37 ° c fisher rat thyroid', 0.0)),
#  (903, ('2011 the earliest events in the female reproductive tract', 0.0)),
#  (904, ('21 in the fcho cells a flippase recombination target', 0.0)),
#  (905, ('3 7 g l nahco 3 fischer rat thyroid', 0.0)),
#  (906, ('3d epithelial culture model system using fischer rat thyroid', 0.0)),
#  (907, ('a cellular accumulation of dii labeled folate receptor target', 0.0)),
#  (908,
#   ('acceptor sa ii introduction of flp recombinase recognition site', 0.0)),
#  (909,
#   ('additional layer of protection to the female reproductive tract', 0.0)),
#  (910, ('albicans inoculated in the vagina a female reproductive tract', 0.0)),
#  (911, ('an ectopic location we insertion a flp recombination target', 0.0)),
#  (912, ('and adaptive immune system in the female reproductive tract', 0.0)),
#  (913, ('and cells viability were investigated in fisher rat thyroid', 0.0)),
#  (914,
#   ('and lymphocytes were isolated from the female reproductive tract', 0.0)),
#  (915, ('and the mucosal surface of the female reproductive tract', 0.0)),
#  (916, ('antigen specific t cells in the female reproductive tract', 0.0)),
#  (917, ('are mirrored by estradiol in the female reproductive tract', 0.0)),
#  (918,
#   ('as the gastrointestinal gi tract and female reproductive tract', 0.0)),
#  (919, ('barrier in vivo neutrophils in the female reproductive tract', 0.0)),
#  (920, ('base assay of iodide influx in fisher rat thyroid', 0.0)),
#  (921, ('before it spreads even though the female reproductive tract', 0.0)),
#  (922,
#   ('bi directly expression plasmid containing the flippase recognition target',
#    0.0)),
#  (923, ('binding domain that binding to the flp recognition target', 0.0)),
#  (924, ('but not in a dedifferentiated line of thyroid cells', 0.0)),
#  (925, ('c and febrile range 39 5 ° c temperatures', 0.0)),
#  (926, ('c1 c2 dysfunction evaluated by the flexion rotation test', 0.0)),
#  (927,
#   ('canopy under observation we using the fluorescence reflectance transmittance',
#    0.0)),
#  (928,
#   ('cationic peptides and peptides of the female reproductive tract', 0.0)),
#  (929, ('cause tgt hormonal changes in the female reproductive tract', 0.0)),
#  (930, ('caveolin vip21 in the golgi apparatus fischer rat thyroid', 0.0)),
#  (931, ('cd4 + t rm in the female reproductive tract', 0.0)),
#  (932, ('cells growth and developed in the female reproductive tract', 0.0)),
#  (933,
#   ('cells line that containing a single flippase recognition target', 0.0)),
#  (934, ('cfbe41o − human airway cells and fisher rat thyroid', 0.0)),
#  (935, ('cftr channel activity in cftr expression fischer rat thyroid', 0.0)),
#  (936, ('cftr mediated i sc in recombination fisher rat thyroid', 0.0)),
#  (937, ('cftr thf increased i sc in fischer rat thyroid', 0.0)),
#  (938, ('coli left pretransformed and a pcv21 tn 5 1', 0.0)),
#  (939,
#   ('complex and unique innervation of the female reproductive tract', 0.0)),
#  (940,
#   ('constructs were expression stably in fischer rat thyroid cells', 0.0)),
#  (941, ('data open the perspective that the forelimb retraction time', 0.0)),
#  (942,
#   ('defense against pathogens in the human female reproductive tract', 0.0)),
#  (943, ('delayed sleep phase type dspt and free running type', 0.0)),
#  (944, ('determined by halide influx assay in fisher rat thyroid', 0.0)),
#  (945, ('dna bending upon interaction with the flp recognition target', 0.0)),
#  (946,
#   ('during ovulation cd44 expression in the female reproductive tract', 0.0)),
#  (947, ('dynamic t cells behavior in the female reproductive tract', 0.0)),
#  (948,
#   ('evermore importance to understand how the female reproductive tract',
#    0.0)),
#  (949, ('exon 14 and a pair of flp recognition target', 0.0)),
#  (950, ('fig 4a hiv transmission through the female reproductive tract', 0.0)),
#  (951, ('flp in 293 cells have the flp recombination target', 0.0)),
#  (952, ('fold aco2 ire rna enthalpic contributions decrease ~ 61', 0.0)),
#  (953, ('for comparing the ldf signals the flux rise time', 0.0)),
#  (954,
#   ('formation in polarized epithelial cells in fischer rat thyroid', 0.0)),
#  (955,
#   ('fornix epithelium cd47 expression in the female reproductive tract', 0.0)),
#  (956, ('frequencies f1 f2 f3 vowel duration formant rise time', 0.0)),
#  (957, ('from the american type culture collection fischer rat thyroid', 0.0)),
#  (958, ('gc and hiv 1 the human female reproductive tract', 0.0)),
#  (959, ('gene and gin11 flanked by flp recombinase recognition target', 0.0)),
#  (960, ('gene in 182 dspt individuals 67 free running type', 0.0)),
#  (961, ('gene target with the flippase flp flippase recognition target', 0.0)),
#  (962,
#   ('hek293 cells that containing a single flippase recognition target', 0.0)),
#  (963, ('hind limb retraction time hrt and forelimb retraction time', 0.0)),
#  (964, ('hiv and immune cells in the female reproductive tract', 0.0)),
#  (965,
#   ('impact pathogens that enter the upper female reproductive tract', 0.0)),
#  (966, ('in e coli left pretransformed and a pcv21 dr', 0.0)),
#  (967, ('in the reproductive tract the human female reproductive tract', 0.0)),
#  (968, ('insertion of certain dna sequence like flp recombinase target', 0.0)),
#  (969,
#   ('involve both electrostatic and coordination complex interaction the ferritin',
#    0.0)),
#  (970, ('ip administration was coupled with a folate receptor target', 0.0)),
#  (971, ('ire irp interaction decrease iron efflux fpn and storage', 0.0)),
#  (972,
#   ('iron acquisition and endosomal iron release ii cytoplasmic ferritin',
#    0.0)),
#  (973, ('irt outer retinal thickness ort and full retinal thickness', 0.0)),
#  (974, ('is of particular importance since the fisher rat thyroid', 0.0)),
#  (975, ('lcmv specific t rm in the female reproductive tract', 0.0)),
#  (976, ('leads to patterning defects in the female reproductive tract', 0.0)),
#  (977,
#   ('levels in the gastrointestinal gi and female reproductive tract', 0.0)),
#  (978, ('lumen of the uterus and upper female reproductive tract', 0.0)),
#  (979, ('ly6g + neutrophils from the lower female reproductive tract', 0.0)),
#  (980, ('main structure of mucus in the female reproductive tract', 0.0)),
#  (981, ('measured finally cutaneous red blood cells flux recovery time', 0.0)),
#  (982, ('mechanisms of prp c endocytosis in fischer rat thyroid', 0.0)),
#  (983, ('mediated transepithelial cl − current in fischer rat thyroid', 0.0)),
#  (984, ('method has not been established in free running type', 0.0)),
#  (985, ('mucosal immune system of the human female reproductive tract', 0.0)),
#  (986, ('mucosa and overlying fluid of the female reproductive tract', 0.0)),
#  (987,
#   ('nontargeted nt liposomes and carboplatin loaded folate receptor target',
#    0.0)),
#  (988, ('not been elucidated in the human female reproductive tract', 0.0)),
#  (989,
#   ('nt liposomes red and carboplatin loaded folate receptor target', 0.0)),
#  (990,
#   ('nucleocapsid nc allow efficient excision of flp recognition target', 0.0)),
#  (991, ('of cftr inhibitor the assay utilizes fischer rat thyroid', 0.0)),
#  (992, ('of interest into the genomic via flp recombination target', 0.0)),
#  (993,
#   ('of inverted repeats 599 bp containing flp1p recombinase target', 0.0)),
#  (994,
#   ('of potential pathogens that infection the female reproductive tract',
#    0.0)),
#  (995, ('of the natural compound flavonoids of rosa roxburghii tratt', 0.0)),
#  (996, ('of the nick we have using flp recognition target', 0.0)),
#  (997, ('on s cerevisiae when overexpressed 14 flp recombinase target', 0.0)),
#  (998, ('or segments of adult art or fetal rat tail', 0.0)),
#  (999,
#   ('outcome of virus transmission in the female reproductive tract', 0.0)),
#  ...]

# %%
longforms0.extend([(longform, score) for i, (longform, score) in enumerate(top)
                   if i in [3, 5, 8, 9, 11, 12, 13, 32, 33, 35]])

# %%
longforms0
# Out:
# [('free running type', 2.0),
#  ('fischer rat thyroid cells', 2.0),
#  ('rosa roxburghii tratt', 1.3333333333333333),
#  ('female reproductive tract', 22.459016393442624),
#  ('fischer rat thyroid', 12.142857142857142),
#  ('fisher rat thyroid', 9.4),
#  ('flp recognition target', 5.555555555555555),
#  ('flippase recognition target', 4.333333333333333),
#  ('flp recombination target', 3.6),
#  ('folate receptor target', 3.5),
#  ('flip recombinase target', 1.0),
#  ('flp recombinase target', 1.0),
#  ('fractionated radiation therapy', 1.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('female reproductive tract',
#  'fischer rat thyroid',
#  'fisher rat thyroid',
#  'flp recognition target',
#  'flippase recognition target',
#  'flp recombination target',
#  'folate receptor target',
#  'free running type',
#  'fischer rat thyroid cells',
#  'rosa roxburghii tratt',
#  'flip recombinase target',
#  'flp recombinase target',
#  'fractionated radiation therapy')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {}

# %%
names
# Out:
# {}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names
# Out:
# {'CHEBI:CHEBI:17593': 'maltooligosaccharide',
#  'CHEBI:CHEBI:25174': 'mannooligosaccharide',
#  'MESH:D018384': 'Oxidative Stress',
#  'CHEBI:CHEBI:31867': 'Mosapride citrate'}

# %%
grounding_map
# Out:
# {'main olfactory system': 'ungrounded',
#  'maltooligosaccharides': 'CHEBI:CHEBI:17593',
#  'mannan oligosaccharide': 'CHEBI:CHEBI:25174',
#  'mannanoligosaccharides': 'CHEBI:CHEBI:25174',
#  'mannooligosaccharides': 'CHEBI:CHEBI:25174',
#  'margin of stability': 'ungrounded',
#  'metal oxidative semiconductor': 'ungrounded',
#  'mitochondrial oxidative stress': 'MESH:D018384',
#  'mosapride citrate': 'CHEBI:CHEBI:31867',
#  'motor optimality score': 'ungrounded',
#  'occlusal splint': 'ungrounded',
#  'swimming': 'ungrounded'}

# %%
names['HGNC:7199'] = 'MOS'
names['HGNC:18234'] = 'MOCOS'
pos_labels.extend(['HGNC:7199', 'HGNC:18234'])

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'female reproductive tract': 'ungrounded',
#   'fischer rat thyroid': 'ungrounded',
#   'fischer rat thyroid cells': 'ungrounded',
#   'fisher rat thyroid': 'ungrounded',
#   'flip recombinase target': 'ungrounded',
#   'flippase recognition target': 'ungrounded',
#   'flp recognition target': 'ungrounded',
#   'flp recombinase target': 'ungrounded',
#   'flp recombination target': 'ungrounded',
#   'folate receptor target': 'ungrounded',
#   'fractionated radiation therapy': 'ungrounded',
#   'free running type': 'ungrounded',
#   'rosa roxburghii tratt': 'ungrounded'},
#  {},
#  [])

# %%
grounding_map, names, pos_labels = ({'female reproductive tract': 'ungrounded',
  'fischer rat thyroid': 'ungrounded',
  'fischer rat thyroid cells': 'ungrounded',
  'fisher rat thyroid': 'ungrounded',
  'flip recombinase target': 'ungrounded',
  'flippase recognition target': 'ungrounded',
  'flp recognition target': 'ungrounded',
  'flp recombinase target': 'ungrounded',
  'flp recombination target': 'ungrounded',
  'folate receptor target': 'ungrounded',
  'fractionated radiation therapy': 'ungrounded',
  'free running type': 'ungrounded',
  'rosa roxburghii tratt': 'ungrounded'},
 {},
 [])

# %%
names['HGNC:3763'] = 'FLT1'
pos_labels.append('HGNC:3763')

# %%
grounding_dict = {'FRT': grounding_map}

# %%
classifier = AdeftClassifier('FRT', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-21 12:02:24] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-21 12:02:31] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9931913660727221 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'ungrounded': 84, 'HGNC:3763': 585},
#  'f1': {'mean': 0.9931913660727221, 'std': 0.0034044710713760622},
#  'precision': {'mean': 0.9898585075055664, 'std': 0.006273519191442433},
#  'recall': {'mean': 0.9965811965811966, 'std': 0.004187161953475503}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [(text, pred) for pred, text in zip(d, shortform_texts)if pred[0].startswith('HGNC')]

# %%
a[4]
# Out:
# ('In this study, we have analyzed the presence and subsets of NK cells throughout the tissues of the FRT. We demonstrate that there are NK cells in the various FRT tissues and that their phenotype and regulation are largely dependent upon the FRT tissue where they reside. NK cells in the Fallopian tube, endometrium, cervix, and ectocervix expressed CD9 while blood NK cells did not. We have also found that unique subsets of NK cells are in specific locations of the FRT. The NK cells in the lower reproductive tract did not express CD94, but they did express CD16. In contrast, NK cells in the upper FRT express high amounts of CD94 and CD69, but few NK cells expressed CD16. All of these FRT NK cells were able to produce IFN-gamma upon stimulation with cytokines. Furthermore, the number of NK cells varied with the menstrual cycle in the endometrium but not in the cervix or ectocervix. These data suggest that unique characteristics of the tissues may account of specific localization of different NK cell subsets.\n',
#  ('HGNC:3763',
#   'FLT1',
#   {'HGNC:3763': 0.5831269893089842, 'ungrounded': 0.4168730106910158}))

# %%
a[1]
# Out:
# ('Interestingly, this potent kinase signaling pathway that regulates oocyte maturation is the mitogen-activated protein kinase (MAPK) pathway. At the top of the cascade is MOS, an oocyte-specific mitogen-activated protein kinase (Mek) kinase similar to Raf ( Fig. 1 ).  Mos  mRNA is present in immature oocytes, but essentially none is translated into stable MOS protein. Steroid-triggered reductions in cAMP lead to increased polyadenylation of  Mos  mRNA in a process that involves interactions of regulatory proteins EG2 and cytoplasmic polyadenylation element-binding protein (CPEB) with the 3′ untranslated region of  Mos  mRNA [ 21 – 26 ]. Increased polyadenylation of  Mos  mRNA leads to increased MOS protein expression. Once present, MOS protein is constitutively active and activates Mek1 [ 27 ], which in turn activates extracellular signaling-regulated kinase 2 (Erk2, or p42), and finally cycle-dependent kinase 1 (CDK1). Activated Erk2 then feeds back to promote further increases in MOS protein expression and activity, thus markedly enhancing the signaling cascade in a feed-forward fashion [ 28 – 30 ].\nWhile this unusual positive feedback loop was originally described in the 1960s and 1970s [ 10 ,  31 – 33 ], the description of regulatory factors that mediate this signaling pathway did not occur until nearly 30 years later, when paxillin was discovered to be an important component of steroid-triggered oocyte maturation. In retrospect, an association of paxillin with oocyte maturation makes sense, as, in somatic cells, paxillin is known to interact with and regulate the activity of several components of the MAPK signaling cascade, including Raf, MEK, and Erk [ 6 ,  34 ]. Since the same MOS/Mek/Erk pathway is crucial for steroid-triggered oocyte maturation, one might anticipate that paxillin would be involved. In fact, knockdown of paxillin expression in  Xenopus laevis  oocytes using either antisense oligonucleotides or siRNA almost completely abrogates androgen-induced maturation [ 35 ]. In addition, paxillin knockdown markedly attenuates androgen-triggered MOS protein expression and downstream Erk activation. In contrast, androgen-triggered polyadenylation of mRNA is unaffected by paxillin knockdown. Together, these results demonstrate that paxillin functions downstream of  Mos  mRNA modification and upstream of MOS translation to regulate nongenomic androgen-triggered oocyte maturation in  Xenopus laevis  oocytes ( Fig. 1 ).\nSurprisingly, in addition to this important upstream role in regulating activation of the MOS/Mek/Erk pathway, paxillin is also regulating important maturation-related processes downstream of the MAPK pathway. As mentioned earlier, paxillin contains serine residues that are targets for Erk-dependent phosphorylation. Interestingly, while re-expression of wild-type paxillin rescues steroid-triggered maturation in paxillin-knockdown oocytes, rescue with a paxillin protein containing alanine substitutions on serine residues 107 and 111 is ineffective at rescuing maturation. MOS and Erk activation are still intact in the presence of this mutated paxillin, though at significantly lower levels [ 35 ]. These data, plus others, suggest that paxillin subserves two separate functions doing androgen-triggered oocyte maturation. First, it regulates activation of the MAPK pathway, most likely by upregulating MOS protein expression and then possibly serving as a scaffold for Mek and Erk signaling. Second, after Erk-dependent phosphorylation on serine residues, phosphoserine-paxillin regulates downstream processes that are still not yet known to regulate oocyte maturation. In fact, since MOS expression and Erk activation are slightly reduced in the absence of phosphoserine-paxillin, it is possible that one of the functions of phosphoserine-paxillin is to enhance the aforementioned positive feedback loop in MAPK signaling that is critical for normal oocyte maturation ( Fig. 1 ). Further studies will help elucidate how  ...
#  ('HGNC:7199',
#   'MOS',
#   {'CHEBI:CHEBI:17593': 0.0024951505883109766,
#    'CHEBI:CHEBI:25174': 0.005309936673627085,
#    'CHEBI:CHEBI:31867': 0.0041298207091438255,
#    'HGNC:18234': 0.006718774908011465,
#    'HGNC:7199': 0.9741503031659994,
#    'MESH:D018384': 0.003693503289775186,
#    'ungrounded': 0.00350251066513202}))

# %%
disamb.dump('MOS', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('FES', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
