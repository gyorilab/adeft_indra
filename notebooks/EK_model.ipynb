# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['EK']
genes = ['TMPRSS15', 'CHKA']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['TMPRSS15', 'CHKA']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['EK'].top()

# %%
top
# Out:
# [('enterokinase', 6.428571428571429),
#  ('electrokinetic', 6.0),
#  ('enkephalin', 5.428571428571429),
#  ('epidermal keratinocytes', 3.6),
#  ('ethanolamine kinase', 3.6),
#  ('enteropeptidase', 2.0),
#  ('endothelial keratoplasty', 2.0),
#  ('iib x 417 wt 407', 2),
#  ('iia 1 898 wt 1 980', 2),
#  ('iib x 1 965 wt 2 323', 2),
#  ('number of individual fibers in edl measured iia 612 wt 505', 2),
#  ('ach genotype were analyzed number of individual fibers in soleus measured type i 980 wt 1 116',
#   2),
#  ('enamel knot', 1.5),
#  ('the enamel knot', 1.3333333333333333),
#  ('erythrokeratoderma', 1),
#  ('knowledge', 1.0),
#  ('and enterokinase', 1.0),
#  ('by enterokinase', 1.0),
#  ('euphorbia kansui', 1),
#  ('exposure keratopathy', 1.0),
#  ('mammalian enterokinase', 1),
#  ('met enkephalin', 1.0),
#  ('of enkephalin', 1.0),
#  ('k + equilibrium potential', 1.0),
#  ('the production of enkephalin', 1),
#  ('cultured normal human epidermal keratinocytes', 1.0),
#  ('escherichia coli and klebsiella species', 1.0),
#  ('ethyl acetate extract of kurosu', 1.0),
#  ('the subcellular distribution of enkephalin', 1),
#  ('this study investigated the electrokinetic', 1),
#  ('choline kinase ck and ethanolamine kinase', 1.0),
#  ('the interrelationship between trypsin trypsinogen and enterokinase', 1),
#  ('of the tooth signalling centre the enamel knot', 1.0),
#  ('the effects of the ethyl acetate extract of kurosu', 1),
#  ('to compare the incidence of fungal infected after endothelial keratoplasty',
#   1),
#  ('immunosuppressive properties the known antiproliferative effects of csa on epidermal keratinocytes',
#   1),
#  ('the modifying effects of administrating an ethyl acetate extract of kurosu',
#   1),
#  ('the remediation of cr vi contaminated soil was investigated by electrokinetic',
#   1),
#  ('uter simulation 1 introduction the conformationally flexible peptide hormone met enkephalin',
#   1),
#  ('contains two endogenous variables perception of air pollution pap and environmental knowledge',
#   1),
#  ('of the first release modulating compound the selective kappa receptor agonist ethylketocyclazocine',
#   1),
#  ('phosphocholine pcho and phosphoethanolamine petn by choline kinase ck and ethanolamine kinase',
#   1),
#  ('due to extended spectrum beta lactamase esbl producing escherichia coli or klebsiella pneumoniae',
#   1),
#  ('e further demonstrate the rational design of additional covert molecules response to enterokinase',
#   1),
#  ('ical processes such as psoriasis through the release of chemokine il8 epidermal keratinocytes',
#   1),
#  ('irrhosis patients 1 gram negative bacilli such as escherichia coli and klebsiella species',
#   1),
#  ('ntaminated zone because hydraulic advection is not practical for delivery in clays electrokinetic',
#   1),
#  ('nts with spontaneous bacterial peritonitis sbp due to escherichia coli and klebsiella species',
#   1),
#  ('onal protease targets we design covert molecules that are specific activated by enterokinase',
#   1),
#  ('phosphoethanolamine p etn via atp dependent phosphorylation by the action of ethanolamine kinase',
#   1),
#  ('rexpression and increased activated of choline kinase ck and less frequently ethanolamine kinase',
#   1),
#  ('ate the possibility of direct interaction of trm with cultured normal human epidermal keratinocytes',
#   1),
#  ('d thus hamper biodegradation of organics in this study the benefits of integrating electrokinetic',
#   1),
#  ('e deae cellulose in a batch procedure followed by column chromatography was called erythrokinase',
#   1),
#  ('h and 5 bromo 2 deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   1),
#  ('mechanisms that lead to an increased risk of ocular surface diseases including exposure keratopathy',
#   1),
#  ('odeno pancreatic reflux of lumenal secretions it has been postulated that trypsin and enterokinase',
#   1),
#  ('are indicated corin has one n glycosylation site that is also present in testisin enteropeptidase',
#   1),
#  ('ential gene because in certain arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel',
#   1),
#  ('he only route for de novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   1),
#  ('is unclear which signalling regulate the establishment of the tooth signalling centre the enamel knot',
#   1),
#  ('lating agent 7 9 10 electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   1),
#  ('rt of these reagents from the injection wells to the contaminated zone 6 10 electrokinetic',
#   1),
#  ('that is a latest iterant in ek is described along with our experiences endothelial keratoplasty',
#   1),
#  ('to replace the corin activated sequence rmnkr at residues 797 801 with a specific enteropeptidase',
#   1),
#  ('a2 + i response of differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   1),
#  ('choline and 1 2 13 c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   1),
#  ('densed mesenchyme at the bud stage and in the inner enamel epithelium iee including enamel knot',
#   1),
#  ('diversion of pancreatic biliary pb secretions in rats for 23 days led to loss of enterokinase',
#   1),
#  ('nd epithelial cells csa can inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   1),
#  ('of ek and is not recommended different methods are use for the prevention of exposure keratopathy',
#   1),
#  ('ted for ctl to eiav infected cells by use noninfected and eiav infected autologous equine kidney',
#   1),
#  ('y could reduce the tail pressure pain threshold the pain threshold was increased by met enkephalin',
#   1),
#  ('ch was accompanied by an increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   1),
#  ('d the use of humic acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   1),
#  ('hikv replicon with a noncytotoxic phenotype in bhk 21 cells combinations of pg and either an e116k',
#   1),
#  ('is function of αe catenin is required for formation of the tooth signalling centre the enamel knot',
#   1),
#  ('o trp is the inactive zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   1),
#  ('r some express by school age 4 5 in this paper we defined children s emotion knowledge',
#   1),
#  ('eased 1 6 and 24 h after cavity formation at the neck of incisor we have reported that enkephalin',
#   1),
#  ('the epithelium a key event at the bud stage is the formation of a structure called the enamel knot',
#   1),
#  ('att gtc tg 3 for mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   1),
#  ('d diet chow high fat diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   1),
#  ('y ach 3 x 10 6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   1),
#  ('20 4 + 2 6 pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   1),
#  ('116', 0.0),
#  ('323', 0.0),
#  ('407', 0.0),
#  ('505', 0.0),
#  ('980', 0.0),
#  ('e116k', 0.0),
#  ('erythrokinase', 0.0),
#  ('ethylketocyclazocine', 0.0),
#  ('evelknievel', 0.0),
#  ('kansui', 0.0),
#  ('keratinocytes', 0.0),
#  ('keratopathy', 0.0),
#  ('keratoplasty', 0.0),
#  ('kidney', 0.0),
#  ('kinase', 0.0),
#  ('knot', 0.0),
#  ('kurosu', 0.0),
#  ('pneumoniae', 0.0),
#  ('potential', 0.0),
#  ('species', 0.0),
#  ('tea', 0.0),
#  ('1 116', 0.0),
#  ('1 980', 0.0),
#  ('10 electrokinetic', 0.0),
#  ('13 electrokinetic', 0.0),
#  ('2 323', 0.0),
#  ('agonist ethylketocyclazocine', 0.0),
#  ('an e116k', 0.0),
#  ('an enteropeptidase', 0.0),
#  ('by electrokinetic', 0.0),
#  ('called erythrokinase', 0.0),
#  ('clays electrokinetic', 0.0),
#  ('emotion knowledge', 0.0),
#  ('environmental knowledge', 0.0),
#  ('equilibrium potential', 0.0),
#  ('equine kidney', 0.0),
#  ('improve electrokinetic', 0.0),
#  ('integrating electrokinetic', 0.0),
#  ('klebsiella pneumoniae', 0.0),
#  ('klebsiella species', 0.0),
#  ('kuding tea', 0.0),
#  ('leucine enkephalin', 0.0),
#  ('of enterokinase', 0.0),
#  ('of kurosu', 0.0),
#  ('specific enteropeptidase', 0.0),
#  ('testisin enteropeptidase', 0.0),
#  ('that enkephalin', 0.0),
#  ('the electrokinetic', 0.0),
#  ('the evelknievel', 0.0),
#  ('to enkephalin', 0.0),
#  ('to enterokinase', 0.0),
#  ('wt 407', 0.0),
#  ('wt 505', 0.0),
#  ('+ equilibrium potential', 0.0),
#  ('12 13 electrokinetic', 0.0),
#  ('417 wt 407', 0.0),
#  ('6 10 electrokinetic', 0.0),
#  ('612 wt 505', 0.0),
#  ('a specific enteropeptidase', 0.0),
#  ('activated by enterokinase', 0.0),
#  ('after endothelial keratoplasty', 0.0),
#  ('and environmental knowledge', 0.0),
#  ('and ethanolamine kinase', 0.0),
#  ('and klebsiella species', 0.0),
#  ('autologous equine kidney', 0.0),
#  ('by ethanolamine kinase', 0.0),
#  ('by met enkephalin', 0.0),
#  ('by the evelknievel', 0.0),
#  ('cells to enkephalin', 0.0),
#  ('ddddk by enterokinase', 0.0),
#  ('distribution of enkephalin', 0.0),
#  ('either an e116k', 0.0),
#  ('experiences endothelial keratoplasty', 0.0),
#  ('extract of kurosu', 0.0),
#  ('frequently ethanolamine kinase', 0.0),
#  ('hormone met enkephalin', 0.0),
#  ('human epidermal keratinocytes', 0.0),
#  ('i leucine enkephalin', 0.0),
#  ('il8 epidermal keratinocytes', 0.0),
#  ('in clays electrokinetic', 0.0),
#  ('in testisin enteropeptidase', 0.0),
#  ('including enamel knot', 0.0),
#  ('including exposure keratopathy', 0.0),
#  ('investigated by electrokinetic', 0.0),
#  ('investigated the electrokinetic', 0.0),
#  ('loss of enterokinase', 0.0),
#  ('of epidermal keratinocytes', 0.0),
#  ('of ethanolamine kinase', 0.0),
#  ('of exposure keratopathy', 0.0),
#  ('of integrating electrokinetic', 0.0),
#  ('of kuding tea', 0.0),
#  ('on epidermal keratinocytes', 0.0),
#  ('or klebsiella pneumoniae', 0.0),
#  ('production of enkephalin', 0.0),
#  ('receptor agonist ethylketocyclazocine', 0.0),
#  ('reported that enkephalin', 0.0),
#  ('response to enterokinase', 0.0),
#  ('s emotion knowledge', 0.0),
#  ('to improve electrokinetic', 0.0),
#  ('trypsin and enterokinase', 0.0),
#  ('trypsinogen and enterokinase', 0.0),
#  ('was called erythrokinase', 0.0),
#  ('with an enteropeptidase', 0.0),
#  ('wt 1 116', 0.0),
#  ('wt 1 980', 0.0),
#  ('wt 2 323', 0.0),
#  ('+ i leucine enkephalin', 0.0),
#  ('15 cells to enkephalin', 0.0),
#  ('898 wt 1 980', 0.0),
#  ('965 wt 2 323', 0.0),
#  ('980 wt 1 116', 0.0),
#  ('acetate extract of kurosu', 0.0),
#  ('action of ethanolamine kinase', 0.0),
#  ('agent to improve electrokinetic', 0.0),
#  ('and either an e116k', 0.0),
#  ('benefits of integrating electrokinetic', 0.0),
#  ('called the enamel knot', 0.0),
#  ('centre the enamel knot', 0.0),
#  ('chemokine il8 epidermal keratinocytes', 0.0),
#  ('children s emotion knowledge', 0.0),
#  ('chromatography was called erythrokinase', 0.0),
#  ('ck and ethanolamine kinase', 0.0),
#  ('coli and klebsiella species', 0.0),
#  ('coli or klebsiella pneumoniae', 0.0),
#  ('csa on epidermal keratinocytes', 0.0),
#  ('delivery in clays electrokinetic', 0.0),
#  ('diseases including exposure keratopathy', 0.0),
#  ('disrupted by the evelknievel', 0.0),
#  ('ek with an enteropeptidase', 0.0),
#  ('ethanolamine by ethanolamine kinase', 0.0),
#  ('extract of kuding tea', 0.0),
#  ('have reported that enkephalin', 0.0),
#  ('iee including enamel knot', 0.0),
#  ('iia 612 wt 505', 0.0),
#  ('increased by met enkephalin', 0.0),
#  ('infected after endothelial keratoplasty', 0.0),
#  ('infected autologous equine kidney', 0.0),
#  ('kappa receptor agonist ethylketocyclazocine', 0.0),
#  ('less frequently ethanolamine kinase', 0.0),
#  ('molecules response to enterokinase', 0.0),
#  ('normal human epidermal keratinocytes', 0.0),
#  ('our experiences endothelial keratoplasty', 0.0),
#  ('pap and environmental knowledge', 0.0),
#  ('peptide hormone met enkephalin', 0.0),
#  ('present in testisin enteropeptidase', 0.0),
#  ('prevention of exposure keratopathy', 0.0),
#  ('propeptide ddddk by enterokinase', 0.0),
#  ('specific activated by enterokinase', 0.0),
#  ('study investigated the electrokinetic', 0.0),
#  ('subcellular distribution of enkephalin', 0.0),
#  ('synthesis of epidermal keratinocytes', 0.0),
#  ('that trypsin and enterokinase', 0.0),
#  ('to loss of enterokinase', 0.0),
#  ('treatment 12 13 electrokinetic', 0.0),
#  ('trypsin trypsinogen and enterokinase', 0.0),
#  ('was investigated by electrokinetic', 0.0),
#  ('with a specific enteropeptidase', 0.0),
#  ('x 417 wt 407', 0.0),
#  ('zone 6 10 electrokinetic', 0.0),
#  ('1 898 wt 1 980', 0.0),
#  ('1 965 wt 2 323', 0.0),
#  ('801 with a specific enteropeptidase', 0.0),
#  ('also present in testisin enteropeptidase', 0.0),
#  ('and less frequently ethanolamine kinase', 0.0),
#  ('are specific activated by enterokinase', 0.0),
#  ('between trypsin trypsinogen and enterokinase', 0.0),
#  ('ca2 + i leucine enkephalin', 0.0),
#  ('calculated k + equilibrium potential', 0.0),
#  ('chelating agent to improve electrokinetic', 0.0),
#  ('column chromatography was called erythrokinase', 0.0),
#  ('contaminated zone 6 10 electrokinetic', 0.0),
#  ('covert molecules response to enterokinase', 0.0),
#  ('defined children s emotion knowledge', 0.0),
#  ('dna synthesis of epidermal keratinocytes', 0.0),
#  ('eiav infected autologous equine kidney', 0.0),
#  ('epithelium iee including enamel knot', 0.0),
#  ('escherichia coli or klebsiella pneumoniae', 0.0),
#  ('ethanol extract of kuding tea', 0.0),
#  ('flexible peptide hormone met enkephalin', 0.0),
#  ('for delivery in clays electrokinetic', 0.0),
#  ('fungal infected after endothelial keratoplasty', 0.0),
#  ('i 980 wt 1 116', 0.0),
#  ('is disrupted by the evelknievel', 0.0),
#  ('kinase ck and ethanolamine kinase', 0.0),
#  ('led to loss of enterokinase', 0.0),
#  ('measured iia 612 wt 505', 0.0),
#  ('ng108 15 cells to enkephalin', 0.0),
#  ('of chemokine il8 epidermal keratinocytes', 0.0),
#  ('of csa on epidermal keratinocytes', 0.0),
#  ('of ethanolamine by ethanolamine kinase', 0.0),
#  ('p ek with an enteropeptidase', 0.0),
#  ('pg and either an e116k', 0.0),
#  ('pollution pap and environmental knowledge', 0.0),
#  ('postulated that trypsin and enterokinase', 0.0),
#  ('selective kappa receptor agonist ethylketocyclazocine', 0.0),
#  ('signalling centre the enamel knot', 0.0),
#  ('sludge treatment 12 13 electrokinetic', 0.0),
#  ('soil was investigated by electrokinetic', 0.0),
#  ('structure called the enamel knot', 0.0),
#  ('surface diseases including exposure keratopathy', 0.0),
#  ('the action of ethanolamine kinase', 0.0),
#  ('the benefits of integrating electrokinetic', 0.0),
#  ('the k + equilibrium potential', 0.0),
#  ('the prevention of exposure keratopathy', 0.0),
#  ('the propeptide ddddk by enterokinase', 0.0),
#  ('was increased by met enkephalin', 0.0),
#  ('we have reported that enkephalin', 0.0),
#  ('with our experiences endothelial keratoplasty', 0.0),
#  ('05 ethanol extract of kuding tea', 0.0),
#  ('797 801 with a specific enteropeptidase', 0.0),
#  ('a structure called the enamel knot', 0.0),
#  ('acidified sludge treatment 12 13 electrokinetic', 0.0),
#  ('additional covert molecules response to enterokinase', 0.0),
#  ('air pollution pap and environmental knowledge', 0.0),
#  ('along with our experiences endothelial keratoplasty', 0.0),
#  ('an ethyl acetate extract of kurosu', 0.0),
#  ('and eiav infected autologous equine kidney', 0.0),
#  ('as chelating agent to improve electrokinetic', 0.0),
#  ('as escherichia coli and klebsiella species', 0.0),
#  ('at the k + equilibrium potential', 0.0),
#  ('been postulated that trypsin and enterokinase', 0.0),
#  ('by column chromatography was called erythrokinase', 0.0),
#  ('by cultured normal human epidermal keratinocytes', 0.0),
#  ('by the action of ethanolamine kinase', 0.0),
#  ('cells ng108 15 cells to enkephalin', 0.0),
#  ('ck and less frequently ethanolamine kinase', 0.0),
#  ('concentration ca2 + i leucine enkephalin', 0.0),
#  ('conformationally flexible peptide hormone met enkephalin', 0.0),
#  ('contaminated soil was investigated by electrokinetic', 0.0),
#  ('days led to loss of enterokinase', 0.0),
#  ('edl measured iia 612 wt 505', 0.0),
#  ('effects of csa on epidermal keratinocytes', 0.0),
#  ('enamel epithelium iee including enamel knot', 0.0),
#  ('for the prevention of exposure keratopathy', 0.0),
#  ('gene is disrupted by the evelknievel', 0.0),
#  ('i p ek with an enteropeptidase', 0.0),
#  ('incisor we have reported that enkephalin', 0.0),
#  ('interrelationship between trypsin trypsinogen and enterokinase', 0.0),
#  ('is also present in testisin enteropeptidase', 0.0),
#  ('ocular surface diseases including exposure keratopathy', 0.0),
#  ('of fungal infected after endothelial keratoplasty', 0.0),
#  ('of pg and either an e116k', 0.0),
#  ('of the propeptide ddddk by enterokinase', 0.0),
#  ('phosphorylation of ethanolamine by ethanolamine kinase', 0.0),
#  ('practical for delivery in clays electrokinetic', 0.0),
#  ('producing escherichia coli or klebsiella pneumoniae', 0.0),
#  ('release of chemokine il8 epidermal keratinocytes', 0.0),
#  ('study the benefits of integrating electrokinetic', 0.0),
#  ('that are specific activated by enterokinase', 0.0),
#  ('the calculated k + equilibrium potential', 0.0),
#  ('the contaminated zone 6 10 electrokinetic', 0.0),
#  ('the ethyl acetate extract of kurosu', 0.0),
#  ('the selective kappa receptor agonist ethylketocyclazocine', 0.0),
#  ('threshold was increased by met enkephalin', 0.0),
#  ('to escherichia coli and klebsiella species', 0.0),
#  ('tooth signalling centre the enamel knot', 0.0),
#  ('type i 980 wt 1 116', 0.0),
#  ('vitro dna synthesis of epidermal keratinocytes', 0.0),
#  ('we defined children s emotion knowledge', 0.0),
#  ('with cultured normal human epidermal keratinocytes', 0.0),
#  ('x 1 965 wt 2 323', 0.0),
#  ('+ concentration ca2 + i leucine enkephalin', 0.0),
#  ('0 05 ethanol extract of kuding tea', 0.0),
#  ('23 days led to loss of enterokinase', 0.0),
#  ('administrating an ethyl acetate extract of kurosu', 0.0),
#  ('and acidified sludge treatment 12 13 electrokinetic', 0.0),
#  ('and i p ek with an enteropeptidase', 0.0),
#  ('antiproliferative effects of csa on epidermal keratinocytes', 0.0),
#  ('by choline kinase ck and ethanolamine kinase', 0.0),
#  ('cmt1 gene is disrupted by the evelknievel', 0.0),
#  ('combinations of pg and either an e116k', 0.0),
#  ('compound the selective kappa receptor agonist ethylketocyclazocine', 0.0),
#  ('described along with our experiences endothelial keratoplasty', 0.0),
#  ('due to escherichia coli and klebsiella species', 0.0),
#  ('esbl producing escherichia coli or klebsiella pneumoniae', 0.0),
#  ('fas as chelating agent to improve electrokinetic', 0.0),
#  ('followed by column chromatography was called erythrokinase', 0.0),
#  ('has been postulated that trypsin and enterokinase', 0.0),
#  ('hybrid cells ng108 15 cells to enkephalin', 0.0),
#  ('in edl measured iia 612 wt 505', 0.0),
#  ('in vitro dna synthesis of epidermal keratinocytes', 0.0),
#  ('incidence of fungal infected after endothelial keratoplasty', 0.0),
#  ('incorporation by cultured normal human epidermal keratinocytes', 0.0),
#  ('inner enamel epithelium iee including enamel knot', 0.0),
#  ('kinase ck and less frequently ethanolamine kinase', 0.0),
#  ('measured type i 980 wt 1 116', 0.0),
#  ('molecules that are specific activated by enterokinase', 0.0),
#  ('noninfected and eiav infected autologous equine kidney', 0.0),
#  ('not practical for delivery in clays electrokinetic', 0.0),
#  ('of a structure called the enamel knot', 0.0),
#  ('of additional covert molecules response to enterokinase', 0.0),
#  ('of air pollution pap and environmental knowledge', 0.0),
#  ('of choline kinase ck and ethanolamine kinase', 0.0),
#  ('of incisor we have reported that enkephalin', 0.0),
#  ('of ocular surface diseases including exposure keratopathy', 0.0),
#  ('of the ethyl acetate extract of kurosu', 0.0),
#  ('pain threshold was increased by met enkephalin', 0.0),
#  ('paper we defined children s emotion knowledge', 0.0),
#  ('pe phosphorylation of ethanolamine by ethanolamine kinase', 0.0),
#  ('phosphorylation by the action of ethanolamine kinase', 0.0),
#  ('removal of the propeptide ddddk by enterokinase', 0.0),
#  ('residues 797 801 with a specific enteropeptidase', 0.0),
#  ('reversed at the k + equilibrium potential', 0.0),
#  ('such as escherichia coli and klebsiella species', 0.0),
#  ('than the calculated k + equilibrium potential', 0.0),
#  ('that is also present in testisin enteropeptidase', 0.0),
#  ('the conformationally flexible peptide hormone met enkephalin', 0.0),
#  ('the release of chemokine il8 epidermal keratinocytes', 0.0),
#  ('the tooth signalling centre the enamel knot', 0.0),
#  ('this study the benefits of integrating electrokinetic', 0.0),
#  ('to the contaminated zone 6 10 electrokinetic', 0.0),
#  ('trm with cultured normal human epidermal keratinocytes', 0.0),
#  ('use for the prevention of exposure keratopathy', 0.0),
#  ('vi contaminated soil was investigated by electrokinetic', 0.0),
#  ('11 and acidified sludge treatment 12 13 electrokinetic', 0.0),
#  ('acids fas as chelating agent to improve electrokinetic', 0.0),
#  ('activated of choline kinase ck and ethanolamine kinase', 0.0),
#  ('and in vitro dna synthesis of epidermal keratinocytes', 0.0),
#  ('are use for the prevention of exposure keratopathy', 0.0),
#  ('at residues 797 801 with a specific enteropeptidase', 0.0),
#  ('bacilli such as escherichia coli and klebsiella species', 0.0),
#  ('brdu incorporation by cultured normal human epidermal keratinocytes', 0.0),
#  ('by removal of the propeptide ddddk by enterokinase', 0.0),
#  ('ca2 + concentration ca2 + i leucine enkephalin', 0.0),
#  ('cells combinations of pg and either an e116k', 0.0),
#  ('choline kinase ck and less frequently ethanolamine kinase', 0.0),
#  ('covert molecules that are specific activated by enterokinase', 0.0),
#  ('cr vi contaminated soil was investigated by electrokinetic', 0.0),
#  ('current reversed at the k + equilibrium potential', 0.0),
#  ('dependent phosphorylation by the action of ethanolamine kinase', 0.0),
#  ('design of additional covert molecules response to enterokinase', 0.0),
#  ('effects of the ethyl acetate extract of kurosu', 0.0),
#  ('ek and i p ek with an enteropeptidase', 0.0),
#  ('fibers in edl measured iia 612 wt 505', 0.0),
#  ('for 23 days led to loss of enterokinase', 0.0),
#  ('formation of a structure called the enamel knot', 0.0),
#  ('glioma hybrid cells ng108 15 cells to enkephalin', 0.0),
#  ('in this study the benefits of integrating electrokinetic', 0.0),
#  ('introduction the conformationally flexible peptide hormone met enkephalin',
#   0.0),
#  ('is described along with our experiences endothelial keratoplasty', 0.0),
#  ('is not practical for delivery in clays electrokinetic', 0.0),
#  ('it has been postulated that trypsin and enterokinase', 0.0),
#  ('known antiproliferative effects of csa on epidermal keratinocytes', 0.0),
#  ('lactamase esbl producing escherichia coli or klebsiella pneumoniae', 0.0),
#  ('modulating compound the selective kappa receptor agonist ethylketocyclazocine',
#   0.0),
#  ('neck of incisor we have reported that enkephalin', 0.0),
#  ('of administrating an ethyl acetate extract of kurosu', 0.0),
#  ('of pe phosphorylation of ethanolamine by ethanolamine kinase', 0.0),
#  ('of trm with cultured normal human epidermal keratinocytes', 0.0),
#  ('perception of air pollution pap and environmental knowledge', 0.0),
#  ('petn by choline kinase ck and ethanolamine kinase', 0.0),
#  ('positive than the calculated k + equilibrium potential', 0.0),
#  ('procedure followed by column chromatography was called erythrokinase', 0.0),
#  ('risk of ocular surface diseases including exposure keratopathy', 0.0),
#  ('sbp due to escherichia coli and klebsiella species', 0.0),
#  ('site that is also present in testisin enteropeptidase', 0.0),
#  ('soleus measured type i 980 wt 1 116', 0.0),
#  ('the cmt1 gene is disrupted by the evelknievel', 0.0),
#  ('the incidence of fungal infected after endothelial keratoplasty', 0.0),
#  ('the inner enamel epithelium iee including enamel knot', 0.0),
#  ('the pain threshold was increased by met enkephalin', 0.0),
#  ('this paper we defined children s emotion knowledge', 0.0),
#  ('through the release of chemokine il8 epidermal keratinocytes', 0.0),
#  ('use noninfected and eiav infected autologous equine kidney', 0.0),
#  ('wells to the contaminated zone 6 10 electrokinetic', 0.0),
#  ('with 0 05 ethanol extract of kuding tea', 0.0),
#  ('1 introduction the conformationally flexible peptide hormone met enkephalin',
#   0.0),
#  ('21 cells combinations of pg and either an e116k', 0.0),
#  ('6 11 and acidified sludge treatment 12 13 electrokinetic', 0.0),
#  ('activated by removal of the propeptide ddddk by enterokinase', 0.0),
#  ('advection is not practical for delivery in clays electrokinetic', 0.0),
#  ('atp dependent phosphorylation by the action of ethanolamine kinase', 0.0),
#  ('batch procedure followed by column chromatography was called erythrokinase',
#   0.0),
#  ('beta lactamase esbl producing escherichia coli or klebsiella pneumoniae',
#   0.0),
#  ('by use noninfected and eiav infected autologous equine kidney', 0.0),
#  ('compare the incidence of fungal infected after endothelial keratoplasty',
#   0.0),
#  ('cytosolic ca2 + concentration ca2 + i leucine enkephalin', 0.0),
#  ('deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   0.0),
#  ('design covert molecules that are specific activated by enterokinase', 0.0),
#  ('ecotypes the cmt1 gene is disrupted by the evelknievel', 0.0),
#  ('effects of administrating an ethyl acetate extract of kurosu', 0.0),
#  ('ek is described along with our experiences endothelial keratoplasty', 0.0),
#  ('establishment of the tooth signalling centre the enamel knot', 0.0),
#  ('formation of the tooth signalling centre the enamel knot', 0.0),
#  ('fulvic acids fas as chelating agent to improve electrokinetic', 0.0),
#  ('glycosylation site that is also present in testisin enteropeptidase', 0.0),
#  ('in soleus measured type i 980 wt 1 116', 0.0),
#  ('in the inner enamel epithelium iee including enamel knot', 0.0),
#  ('in this paper we defined children s emotion knowledge', 0.0),
#  ('increased risk of ocular surface diseases including exposure keratopathy',
#   0.0),
#  ('individual fibers in edl measured iia 612 wt 505', 0.0),
#  ('induced current reversed at the k + equilibrium potential', 0.0),
#  ('injection wells to the contaminated zone 6 10 electrokinetic', 0.0),
#  ('interaction of trm with cultured normal human epidermal keratinocytes',
#   0.0),
#  ('methods are use for the prevention of exposure keratopathy', 0.0),
#  ('mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('more positive than the calculated k + equilibrium potential', 0.0),
#  ('negative bacilli such as escherichia coli and klebsiella species', 0.0),
#  ('of choline kinase ck and less frequently ethanolamine kinase', 0.0),
#  ('of cr vi contaminated soil was investigated by electrokinetic', 0.0),
#  ('organics in this study the benefits of integrating electrokinetic', 0.0),
#  ('peritonitis sbp due to escherichia coli and klebsiella species', 0.0),
#  ('phosphoethanolamine petn by choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('psoriasis through the release of chemokine il8 epidermal keratinocytes',
#   0.0),
#  ('rats for 23 days led to loss of enterokinase', 0.0),
#  ('rational design of additional covert molecules response to enterokinase',
#   0.0),
#  ('release modulating compound the selective kappa receptor agonist ethylketocyclazocine',
#   0.0),
#  ('rmnkr at residues 797 801 with a specific enteropeptidase', 0.0),
#  ('secretions it has been postulated that trypsin and enterokinase', 0.0),
#  ('synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('the activated of choline kinase ck and ethanolamine kinase', 0.0),
#  ('the formation of a structure called the enamel knot', 0.0),
#  ('the known antiproliferative effects of csa on epidermal keratinocytes',
#   0.0),
#  ('the neck of incisor we have reported that enkephalin', 0.0),
#  ('threshold the pain threshold was increased by met enkephalin', 0.0),
#  ('variables perception of air pollution pap and environmental knowledge',
#   0.0),
#  ('vivo and in vitro dna synthesis of epidermal keratinocytes', 0.0),
#  ('wt ek and i p ek with an enteropeptidase', 0.0),
#  ('x glioma hybrid cells ng108 15 cells to enkephalin', 0.0),
#  ('2 deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   0.0),
#  ('5 in this paper we defined children s emotion knowledge', 0.0),
#  ('a batch procedure followed by column chromatography was called erythrokinase',
#   0.0),
#  ('activated of choline kinase ck and less frequently ethanolamine kinase',
#   0.0),
#  ('an increased risk of ocular surface diseases including exposure keratopathy',
#   0.0),
#  ('and fulvic acids fas as chelating agent to improve electrokinetic', 0.0),
#  ('and in the inner enamel epithelium iee including enamel knot', 0.0),
#  ('and phosphoethanolamine petn by choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('ar induced current reversed at the k + equilibrium potential', 0.0),
#  ('arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel', 0.0),
#  ('as psoriasis through the release of chemokine il8 epidermal keratinocytes',
#   0.0),
#  ('at the neck of incisor we have reported that enkephalin', 0.0),
#  ('bacterial peritonitis sbp due to escherichia coli and klebsiella species',
#   0.0),
#  ('bhk 21 cells combinations of pg and either an e116k', 0.0),
#  ('cells by use noninfected and eiav infected autologous equine kidney', 0.0),
#  ('diet mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('different methods are use for the prevention of exposure keratopathy', 0.0),
#  ('direct interaction of trm with cultured normal human epidermal keratinocytes',
#   0.0),
#  ('electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   0.0),
#  ('endogenous variables perception of air pollution pap and environmental knowledge',
#   0.0),
#  ('ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('fibers in soleus measured type i 980 wt 1 116', 0.0),
#  ('first release modulating compound the selective kappa receptor agonist ethylketocyclazocine',
#   0.0),
#  ('for formation of the tooth signalling centre the enamel knot', 0.0),
#  ('gram negative bacilli such as escherichia coli and klebsiella species',
#   0.0),
#  ('hydraulic advection is not practical for delivery in clays electrokinetic',
#   0.0),
#  ('in ek is described along with our experiences endothelial keratoplasty',
#   0.0),
#  ('in rats for 23 days led to loss of enterokinase', 0.0),
#  ('in vivo and in vitro dna synthesis of epidermal keratinocytes', 0.0),
#  ('is activated by removal of the propeptide ddddk by enterokinase', 0.0),
#  ('is the formation of a structure called the enamel knot', 0.0),
#  ('lumenal secretions it has been postulated that trypsin and enterokinase',
#   0.0),
#  ('modifying effects of administrating an ethyl acetate extract of kurosu',
#   0.0),
#  ('mv more positive than the calculated k + equilibrium potential', 0.0),
#  ('n glycosylation site that is also present in testisin enteropeptidase',
#   0.0),
#  ('neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin', 0.0),
#  ('novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('of individual fibers in edl measured iia 612 wt 505', 0.0),
#  ('of organics in this study the benefits of integrating electrokinetic', 0.0),
#  ('pain threshold the pain threshold was increased by met enkephalin', 0.0),
#  ('properties the known antiproliferative effects of csa on epidermal keratinocytes',
#   0.0),
#  ('proteins wt ek and i p ek with an enteropeptidase', 0.0),
#  ('remediation of cr vi contaminated soil was investigated by electrokinetic',
#   0.0),
#  ('sequence rmnkr at residues 797 801 with a specific enteropeptidase', 0.0),
#  ('simulation 1 introduction the conformationally flexible peptide hormone met enkephalin',
#   0.0),
#  ('spectrum beta lactamase esbl producing escherichia coli or klebsiella pneumoniae',
#   0.0),
#  ('the cytosolic ca2 + concentration ca2 + i leucine enkephalin', 0.0),
#  ('the establishment of the tooth signalling centre the enamel knot', 0.0),
#  ('the injection wells to the contaminated zone 6 10 electrokinetic', 0.0),
#  ('the rational design of additional covert molecules response to enterokinase',
#   0.0),
#  ('via atp dependent phosphorylation by the action of ethanolamine kinase',
#   0.0),
#  ('we design covert molecules that are specific activated by enterokinase',
#   0.0),
#  ('1 gram negative bacilli such as escherichia coli and klebsiella species',
#   0.0),
#  ('10 electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   0.0),
#  ('2 ar induced current reversed at the k + equilibrium potential', 0.0),
#  ('20 mv more positive than the calculated k + equilibrium potential', 0.0),
#  ('4 5 in this paper we defined children s emotion knowledge', 0.0),
#  ('activated sequence rmnkr at residues 797 801 with a specific enteropeptidase',
#   0.0),
#  ('because hydraulic advection is not practical for delivery in clays electrokinetic',
#   0.0),
#  ('biodegradation of organics in this study the benefits of integrating electrokinetic',
#   0.0),
#  ('bromo 2 deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   0.0),
#  ('c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('certain arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel',
#   0.0),
#  ('corin proteins wt ek and i p ek with an enteropeptidase', 0.0),
#  ('de novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('demonstrate the rational design of additional covert molecules response to enterokinase',
#   0.0),
#  ('differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   0.0),
#  ('etn via atp dependent phosphorylation by the action of ethanolamine kinase',
#   0.0),
#  ('extended spectrum beta lactamase esbl producing escherichia coli or klebsiella pneumoniae',
#   0.0),
#  ('fat diet mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('formation at the neck of incisor we have reported that enkephalin', 0.0),
#  ('from the injection wells to the contaminated zone 6 10 electrokinetic',
#   0.0),
#  ('has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('in a batch procedure followed by column chromatography was called erythrokinase',
#   0.0),
#  ('in bhk 21 cells combinations of pg and either an e116k', 0.0),
#  ('in the cytosolic ca2 + concentration ca2 + i leucine enkephalin', 0.0),
#  ('increased activated of choline kinase ck and less frequently ethanolamine kinase',
#   0.0),
#  ('individual fibers in soleus measured type i 980 wt 1 116', 0.0),
#  ('infected cells by use noninfected and eiav infected autologous equine kidney',
#   0.0),
#  ('inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   0.0),
#  ('iterant in ek is described along with our experiences endothelial keratoplasty',
#   0.0),
#  ('of direct interaction of trm with cultured normal human epidermal keratinocytes',
#   0.0),
#  ('of lumenal secretions it has been postulated that trypsin and enterokinase',
#   0.0),
#  ('one n glycosylation site that is also present in testisin enteropeptidase',
#   0.0),
#  ('pcho and phosphoethanolamine petn by choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('pressure pain threshold the pain threshold was increased by met enkephalin',
#   0.0),
#  ('recommended different methods are use for the prevention of exposure keratopathy',
#   0.0),
#  ('regulate the establishment of the tooth signalling centre the enamel knot',
#   0.0),
#  ('required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('secretions in rats for 23 days led to loss of enterokinase', 0.0),
#  ('spontaneous bacterial peritonitis sbp due to escherichia coli and klebsiella species',
#   0.0),
#  ('stage and in the inner enamel epithelium iee including enamel knot', 0.0),
#  ('stage is the formation of a structure called the enamel knot', 0.0),
#  ('such as psoriasis through the release of chemokine il8 epidermal keratinocytes',
#   0.0),
#  ('targets we design covert molecules that are specific activated by enterokinase',
#   0.0),
#  ('that is activated by removal of the propeptide ddddk by enterokinase', 0.0),
#  ('the first release modulating compound the selective kappa receptor agonist ethylketocyclazocine',
#   0.0),
#  ('to an increased risk of ocular surface diseases including exposure keratopathy',
#   0.0),
#  ('two endogenous variables perception of air pollution pap and environmental knowledge',
#   0.0),
#  ('13 c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('5 bromo 2 deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   0.0),
#  ('9 10 electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   0.0),
#  ('about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('age 4 5 in this paper we defined children s emotion knowledge', 0.0),
#  ('alpha 2 ar induced current reversed at the k + equilibrium potential', 0.0),
#  ('and increased activated of choline kinase ck and less frequently ethanolamine kinase',
#   0.0),
#  ('bud stage and in the inner enamel epithelium iee including enamel knot',
#   0.0),
#  ('bud stage is the formation of a structure called the enamel knot', 0.0),
#  ('can inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   0.0),
#  ('cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('cellulose in a batch procedure followed by column chromatography was called erythrokinase',
#   0.0),
#  ('corin activated sequence rmnkr at residues 797 801 with a specific enteropeptidase',
#   0.0),
#  ('eiav infected cells by use noninfected and eiav infected autologous equine kidney',
#   0.0),
#  ('express corin proteins wt ek and i p ek with an enteropeptidase', 0.0),
#  ('for de novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('further demonstrate the rational design of additional covert molecules response to enterokinase',
#   0.0),
#  ('hamper biodegradation of organics in this study the benefits of integrating electrokinetic',
#   0.0),
#  ('has one n glycosylation site that is also present in testisin enteropeptidase',
#   0.0),
#  ('high fat diet mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('in certain arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel',
#   0.0),
#  ('increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   0.0),
#  ('is required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('latest iterant in ek is described along with our experiences endothelial keratoplasty',
#   0.0),
#  ('lead to an increased risk of ocular surface diseases including exposure keratopathy',
#   0.0),
#  ('not recommended different methods are use for the prevention of exposure keratopathy',
#   0.0),
#  ('of differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   0.0),
#  ('of individual fibers in soleus measured type i 980 wt 1 116', 0.0),
#  ('p etn via atp dependent phosphorylation by the action of ethanolamine kinase',
#   0.0),
#  ('patients 1 gram negative bacilli such as escherichia coli and klebsiella species',
#   0.0),
#  ('pb secretions in rats for 23 days led to loss of enterokinase', 0.0),
#  ('phenotype in bhk 21 cells combinations of pg and either an e116k', 0.0),
#  ('possibility of direct interaction of trm with cultured normal human epidermal keratinocytes',
#   0.0),
#  ('processes such as psoriasis through the release of chemokine il8 epidermal keratinocytes',
#   0.0),
#  ('protease targets we design covert molecules that are specific activated by enterokinase',
#   0.0),
#  ('reagents from the injection wells to the contaminated zone 6 10 electrokinetic',
#   0.0),
#  ('reflux of lumenal secretions it has been postulated that trypsin and enterokinase',
#   0.0),
#  ('signalling regulate the establishment of the tooth signalling centre the enamel knot',
#   0.0),
#  ('tail pressure pain threshold the pain threshold was increased by met enkephalin',
#   0.0),
#  ('to extended spectrum beta lactamase esbl producing escherichia coli or klebsiella pneumoniae',
#   0.0),
#  ('with spontaneous bacterial peritonitis sbp due to escherichia coli and klebsiella species',
#   0.0),
#  ('zone because hydraulic advection is not practical for delivery in clays electrokinetic',
#   0.0),
#  ('zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   0.0),
#  ('2 13 c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('7 9 10 electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   0.0),
#  ('a latest iterant in ek is described along with our experiences endothelial keratoplasty',
#   0.0),
#  ('after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('an increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   0.0),
#  ('and 5 bromo 2 deoxyuridine brdu incorporation by cultured normal human epidermal keratinocytes',
#   0.0),
#  ('and high fat diet mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('because in certain arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel',
#   0.0),
#  ('biliary pb secretions in rats for 23 days led to loss of enterokinase',
#   0.0),
#  ('catenin is required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('corin has one n glycosylation site that is also present in testisin enteropeptidase',
#   0.0),
#  ('csa can inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   0.0),
#  ('deae cellulose in a batch procedure followed by column chromatography was called erythrokinase',
#   0.0),
#  ('humic acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('inactive zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   0.0),
#  ('is not recommended different methods are use for the prevention of exposure keratopathy',
#   0.0),
#  ('noncytotoxic phenotype in bhk 21 cells combinations of pg and either an e116k',
#   0.0),
#  ('number of individual fibers in soleus measured type i 980 wt 1 116', 0.0),
#  ('pancreatic reflux of lumenal secretions it has been postulated that trypsin and enterokinase',
#   0.0),
#  ('response of differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   0.0),
#  ('route for de novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('school age 4 5 in this paper we defined children s emotion knowledge', 0.0),
#  ('that lead to an increased risk of ocular surface diseases including exposure keratopathy',
#   0.0),
#  ('the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('the bud stage and in the inner enamel epithelium iee including enamel knot',
#   0.0),
#  ('the bud stage is the formation of a structure called the enamel knot', 0.0),
#  ('the corin activated sequence rmnkr at residues 797 801 with a specific enteropeptidase',
#   0.0),
#  ('the possibility of direct interaction of trm with cultured normal human epidermal keratinocytes',
#   0.0),
#  ('the tail pressure pain threshold the pain threshold was increased by met enkephalin',
#   0.0),
#  ('these reagents from the injection wells to the contaminated zone 6 10 electrokinetic',
#   0.0),
#  ('thus hamper biodegradation of organics in this study the benefits of integrating electrokinetic',
#   0.0),
#  ('to eiav infected cells by use noninfected and eiav infected autologous equine kidney',
#   0.0),
#  ('to express corin proteins wt ek and i p ek with an enteropeptidase', 0.0),
#  ('was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('which signalling regulate the establishment of the tooth signalling centre the enamel knot',
#   0.0),
#  ('1 2 13 c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('a noncytotoxic phenotype in bhk 21 cells combinations of pg and either an e116k',
#   0.0),
#  ('agent 7 9 10 electrokinetic 6 11 and acidified sludge treatment 12 13 electrokinetic',
#   0.0),
#  ('analyzed number of individual fibers in soleus measured type i 980 wt 1 116',
#   0.0),
#  ('and is not recommended different methods are use for the prevention of exposure keratopathy',
#   0.0),
#  ('at the bud stage and in the inner enamel epithelium iee including enamel knot',
#   0.0),
#  ('at the bud stage is the formation of a structure called the enamel knot',
#   0.0),
#  ('by an increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   0.0),
#  ('by school age 4 5 in this paper we defined children s emotion knowledge',
#   0.0),
#  ('cells csa can inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   0.0),
#  ('ctl to eiav infected cells by use noninfected and eiav infected autologous equine kidney',
#   0.0),
#  ('gene because in certain arabidopsis ecotypes the cmt1 gene is disrupted by the evelknievel',
#   0.0),
#  ('h after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('hf and high fat diet mixed with 0 05 ethanol extract of kuding tea', 0.0),
#  ('i response of differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   0.0),
#  ('indicated corin has one n glycosylation site that is also present in testisin enteropeptidase',
#   0.0),
#  ('is a latest iterant in ek is described along with our experiences endothelial keratoplasty',
#   0.0),
#  ('l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('of humic acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('of these reagents from the injection wells to the contaminated zone 6 10 electrokinetic',
#   0.0),
#  ('only route for de novo synthesis of pe phosphorylation of ethanolamine by ethanolamine kinase',
#   0.0),
#  ('pancreatic biliary pb secretions in rats for 23 days led to loss of enterokinase',
#   0.0),
#  ('q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('reduce the tail pressure pain threshold the pain threshold was increased by met enkephalin',
#   0.0),
#  ('replace the corin activated sequence rmnkr at residues 797 801 with a specific enteropeptidase',
#   0.0),
#  ('the inactive zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   0.0),
#  ('unclear which signalling regulate the establishment of the tooth signalling centre the enamel knot',
#   0.0),
#  ('αe catenin is required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('+ i response of differentiated neuroblastoma x glioma hybrid cells ng108 15 cells to enkephalin',
#   0.0),
#  ('24 h after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('= 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('accompanied by an increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   0.0),
#  ('and 1 2 13 c ethanolamine the activated of choline kinase ck and ethanolamine kinase',
#   0.0),
#  ('could reduce the tail pressure pain threshold the pain threshold was increased by met enkephalin',
#   0.0),
#  ('diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   0.0),
#  ('ek and is not recommended different methods are use for the prevention of exposure keratopathy',
#   0.0),
#  ('epithelial cells csa can inhibit in vivo and in vitro dna synthesis of epidermal keratinocytes',
#   0.0),
#  ('event at the bud stage is the formation of a structure called the enamel knot',
#   0.0),
#  ('express by school age 4 5 in this paper we defined children s emotion knowledge',
#   0.0),
#  ('for ctl to eiav infected cells by use noninfected and eiav infected autologous equine kidney',
#   0.0),
#  ('is the inactive zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   0.0),
#  ('mesenchyme at the bud stage and in the inner enamel epithelium iee including enamel knot',
#   0.0),
#  ('mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('of pancreatic biliary pb secretions in rats for 23 days led to loss of enterokinase',
#   0.0),
#  ('of αe catenin is required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('use of humic acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('were analyzed number of individual fibers in soleus measured type i 980 wt 1 116',
#   0.0),
#  ('with a noncytotoxic phenotype in bhk 21 cells combinations of pg and either an e116k',
#   0.0),
#  ('6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('and 24 h after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('fat diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   0.0),
#  ('for mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('function of αe catenin is required for formation of the tooth signalling centre the enamel knot',
#   0.0),
#  ('genotype were analyzed number of individual fibers in soleus measured type i 980 wt 1 116',
#   0.0),
#  ('key event at the bud stage is the formation of a structure called the enamel knot',
#   0.0),
#  ('n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('replicon with a noncytotoxic phenotype in bhk 21 cells combinations of pg and either an e116k',
#   0.0),
#  ('some express by school age 4 5 in this paper we defined children s emotion knowledge',
#   0.0),
#  ('the use of humic acids has and fulvic acids fas as chelating agent to improve electrokinetic',
#   0.0),
#  ('trp is the inactive zymogen that is activated by removal of the propeptide ddddk by enterokinase',
#   0.0),
#  ('was accompanied by an increased in the cytosolic ca2 + concentration ca2 + i leucine enkephalin',
#   0.0),
#  ('10 6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('3 for mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('6 and 24 h after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('a key event at the bud stage is the formation of a structure called the enamel knot',
#   0.0),
#  ('high fat diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   0.0),
#  ('pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('1 6 and 24 h after cavity formation at the neck of incisor we have reported that enkephalin',
#   0.0),
#  ('6 pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('chow high fat diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   0.0),
#  ('epithelium a key event at the bud stage is the formation of a structure called the enamel knot',
#   0.0),
#  ('tg 3 for mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('x 10 6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('2 6 pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('3 x 10 6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('diet chow high fat diet hf and high fat diet mixed with 0 05 ethanol extract of kuding tea',
#   0.0),
#  ('gtc tg 3 for mutant q568p to express corin proteins wt ek and i p ek with an enteropeptidase',
#   0.0),
#  ('+ 2 6 pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0),
#  ('ach 3 x 10 6 mol l was about 20 mv more positive than the calculated k + equilibrium potential',
#   0.0),
#  ('4 + 2 6 pa n = 28 the alpha 2 ar induced current reversed at the k + equilibrium potential',
#   0.0)]

# %%
longforms0 = miners['EK'].get_longforms(scale=True)

# %%
longforms0
# Out:
# [('electrokinetic', 0.5),
#  ('enterokinase', 0.4935064935064935),
#  ('enkephalin', 0.4428571428571429),
#  ('ethanolamine kinase', 0.325),
#  ('epidermal keratinocytes', 0.325),
#  ('iib x 417 wt 407', 0.2),
#  ('iia 1 898 wt 1 980', 0.2),
#  ('iib x 1 965 wt 2 323', 0.2),
#  ('number of individual fibers in edl measured iia 612 wt 505', 0.2),
#  ('ach genotype were analyzed number of individual fibers in soleus measured type i 980 wt 1 116',
#   0.2),
#  ('enteropeptidase', 0.16666666666666666),
#  ('endothelial keratoplasty', 0.16666666666666666),
#  ('enamel knot', 0.07142857142857142)]

# %%
longforms0 = longforms0[:6]

# %%
longforms0
# Out:
# [('enterokinase', 6.428571428571429),
#  ('electrokinetic', 6.0),
#  ('enkephalin', 5.428571428571429),
#  ('ethanolamine kinase', 3.6),
#  ('epidermal keratinocytes', 3.6),
#  ('enteropeptidase', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('enterokinase',
#  'electrokinetic',
#  'enkephalin',
#  'ethanolamine kinase',
#  'epidermal keratinocytes',
#  'enteropeptidase')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'enterokinase': 'HGNC:9490',
#  'enkephalin': 'MESH:D004745',
#  'ethanolamine kinase': 'HGNC:1937',
#  'enteropeptidase': 'HGNC:9490'}

# %%
names
# Out:
# {'HGNC:9490': 'TMPRSS15', 'MESH:D004745': 'Enkephalins', 'HGNC:1937': 'CHKA'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names
# Out:
# {'MESH:D004745': 'Enkephalins', 'HGNC:9490': 'TMPRSS15', 'HGNC:1937': 'CHKA'}

# %%
grounding_map
# Out:
# {'electrokinetic': 'ungrounded',
#  'enkephalin': 'MESH:D004745',
#  'enterokinase': 'HGNC:9490',
#  'enteropeptidase': 'HGNC:9490',
#  'epidermal keratinocytes': 'ungrounded',
#  'ethanolamine kinase': 'FPLX:CHK'}

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'electrokinetic': 'ungrounded',
#   'enkephalin': 'MESH:D004745',
#   'enterokinase': 'HGNC:9490',
#   'enteropeptidase': 'HGNC:9490',
#   'epidermal keratinocytes': 'ungrounded',
#   'ethanolamine kinase': 'HGNC:1937'},
#  {'MESH:D004745': 'Enkephalins', 'HGNC:9490': 'TMPRSS15', 'HGNC:1937': 'CHKA'},
#  ['HGNC:1937', 'HGNC:9490', 'MESH:D004745'])

# %%
grounding_map, names, pos_labels = ({'electrokinetic': 'ungrounded',
  'enkephalin': 'MESH:D004745',
  'enterokinase': 'HGNC:9490',
  'enteropeptidase': 'HGNC:9490',
  'epidermal keratinocytes': 'ungrounded',
  'ethanolamine kinase': 'HGNC:1937'},
 {'MESH:D004745': 'Enkephalins', 'HGNC:9490': 'TMPRSS15', 'HGNC:1937': 'CHKA'},
 ['HGNC:1937', 'HGNC:9490', 'MESH:D004745'])

# %%
grounding_dict = {'EK': grounding_map}

# %%
classifier = AdeftClassifier('EK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-16 15:41:27] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-16 15:41:30] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.8012468805469674 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'ungrounded': 11,
#   'HGNC:9490': 30,
#   'MESH:D004745': 7,
#   'FPLX:CHK': 58},
#  'f1': {'mean': 0.8133311951206688, 'std': 0.04073679018039223},
#  'precision': {'mean': 0.8343876357560568, 'std': 0.04378480128192264},
#  'recall': {'mean': 0.8423391812865498, 'std': 0.04507797165586637}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'FPLX:CHK']

# %%
a[2]
# Out:
# '1. Extracellular K+ activity and transmembrane potential were simultaneously monitored with a K+-selective micro-electrode placed in the extracellular space and a standard KCl-filled micro-electrode in the intracellular space of the frog ventricular muscle. 2. K+ was found to accumulate during activity and had the approximate magnitude and time course to account for the measured membrane depolarization. 3. The magnitude of the K+ accumulation depended on the frequency of stimulation, diameter of the muscle and temperature of the bathing solution. 4. The time constants of accumulation and decay were dependent only on the diameter and the temperature of the strip. A Q10 of 2 was measured for the decay of accumulated K+. 5. Double barrelled K+-electrodes were used to monitor the change in K+ activity accompanying a single action potential, since the reference barrel allowed for rapid compensation of the electrical potential fluctuations encountered in the subendothelial space. 6. K+ accumulated continuously during the plateau to a level which increased external K concentration by about 1 mM. This increase in the subendothelial space corresponds to about 1-3 muA/cm2 or 10-30 pmole/cm2-sec-1 of net K+ efflux. These values are at least an order of magnitude larger than required to discharge the membrane capacitance. 7. There is no direct relation between action potential duration and rate of development or magnitude of K+ accumulation during that action potential. 8. Increase in the external K concentration, while shortening the action potential and depolarizing the membrane, does not lead to an increased rate of accumulation of K+. The presence of Ni2+, on the other hand, prolongs the action potential and decreases the rate of K+ accumulation. 9. The results suggest that there is a substantial and continuous efflux of K+ during the action potential, which sums during rapid beating, resulting in membrane depolarization and alteration of action potential duration. The change in action potential duration in response to rate may be caused by alteration of EK in the local micro-environments.\n'

# %%
a[16]
# Out:
# 'The OsPCS2 exhibits root- and shoot-specific differential ratios of alternatively spliced transcripts in indica rice under Cd stress, and plays role in Cd and As stress tolerance and accumulation. Enzymatic activity of phytochelatin synthase (PCS) in plant produces phytochelatins, which help in sequestration of heavy metal(loid)s inside the cell vacuole to alleviate toxicity. Here we report that among the two PCS genes-OsPCS1 and OsPCS2 in indica rice (Oryza sativa) cultivar, the OsPCS2 produces an alternatively spliced OsPCS2b transcript that bears the unusual premature termination codon besides the canonically spliced OsPCS2a transcript. Root- and shoot-specific differential ratios of alternatively spliced OsPCS2a and OsPCS2b transcript expressions were observed under cadmium stress. Saccharomyces cerevisiae cells transformed with OsPCS2a exhibited increased cadmium (Cd) and arsenic (As) tolerance and accumulation, unlike the OsPCS2b transformed yeast cells. An intron-containing hairpin RNA-mediated gene silencing was carried out in endosperm-specific manner for efficient down-regulation of OsPCS genes in rice grains. Analysis of the transgenic rice lines grown under metal(loid) stress revealed almost complete absence of both OsPCS1 and OsPCS2 transcripts in the developing seeds coupled with the significant reduction in the content of Cd (~51%) and As (~35%) in grains compared with the non-transgenic plant. Taken together, the findings indicate towards a crucial role played by the tissue-specific alternative splicing and relative abundance of the OsPCS2 gene during heavy metal(loid) stress mitigation in rice plant.\n'

# %%
disamb.dump('EK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
