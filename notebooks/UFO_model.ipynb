# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground
# Out:
# INFO: [2020-01-13 09:45:49] /Users/albertsteppi/adeft/adeft/recognize.py - OneShotRecognizer not available. AdeftLongformScorer has not been built successfully.

# %%
shortforms = ['ALK']
genes = ['ALK']
families = {'RSTK1': ['ACVRL1', 'ACVR1', 'ACVR1B', 'ACVR1C', 'BMPR1A',
                      'BMPR1B', 'TGFBR1']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['ALK'].top()

# %%
top
# Out:
# [('anaplastic lymphoma kinase', 948.8728813559322),
#  ('the anaplastic lymphoma kinase', 185.81188118811886),
#  ('of anaplastic lymphoma kinase', 109.87826086956522),
#  ('kinase', 92.91263940520446),
#  ('and anaplastic lymphoma kinase', 64.29729729729729),
#  ('of the anaplastic lymphoma kinase', 62.833333333333336),
#  ('in anaplastic lymphoma kinase', 26.96551724137931),
#  ('patients with anaplastic lymphoma kinase', 22.652173913043477),
#  ('activin receptor like kinase', 20.454545454545453),
#  ('rearrangements of the anaplastic lymphoma kinase', 20.0),
#  ('an anaplastic lymphoma kinase', 19.909090909090914),
#  ('with anaplastic lymphoma kinase', 19.63157894736842),
#  ('for anaplastic lymphoma kinase', 18.5),
#  ('in the anaplastic lymphoma kinase', 14.545454545454547),
#  ('epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   13.733333333333334),
#  ('or anaplastic lymphoma kinase', 13.0),
#  ('echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   12.705882352941178),
#  ('and the anaplastic lymphoma kinase', 12.533333333333333),
#  ('involving the anaplastic lymphoma kinase', 12.0),
#  ('translocations involving the anaplastic lymphoma kinase',
#   10.923076923076923),
#  ('epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   10.833333333333334),
#  ('anaplastic lymphoma receptor tyrosine kinase', 10.166666666666666),
#  ('activation anaplastic lymphoma kinase', 10.0),
#  ('rearrangements in the anaplastic lymphoma kinase', 9.500000000000002),
#  ('like kinase', 9.428571428571427),
#  ('activation of anaplastic lymphoma kinase', 9.272727272727273),
#  ('inhibitor of anaplastic lymphoma kinase', 8.727272727272727),
#  ('the receptor tyrosine kinase anaplastic lymphoma kinase', 8.5),
#  ('npm anaplastic lymphoma kinase', 7.714285714285714),
#  ('nucleophosmin npm anaplastic lymphoma kinase', 7.555555555555555),
#  ('rearrangements of anaplastic lymphoma kinase', 7.5),
#  ('is anaplastic lymphoma kinase', 7.333333333333333),
#  ('alkaline phosphatase', 6.75),
#  ('expression of anaplastic lymphoma kinase', 6.75),
#  ('mutations anaplastic lymphoma kinase', 6.666666666666667),
#  ('kinase gene', 6.428571428571429),
#  ('target anaplastic lymphoma kinase', 6.428571428571429),
#  ('the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   6.142857142857142),
#  ('harboring anaplastic lymphoma kinase', 6.0),
#  ('lymphoma kinase', 5.982490272373525),
#  ('generation anaplastic lymphoma kinase', 5.818181818181818),
#  ('receptor anaplastic lymphoma kinase', 5.714285714285714),
#  ('to anaplastic lymphoma kinase', 5.714285714285714),
#  ('epidermal growth factor receptor egfr anaplastic lymphoma kinase', 5.5),
#  ('second generation anaplastic lymphoma kinase', 5.428571428571429),
#  ('echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   5.333333333333334),
#  ('mutations and anaplastic lymphoma kinase', 5.294117647058824),
#  ('alcl anaplastic lymphoma kinase', 5.142857142857142),
#  ('activin like kinase', 5.0),
#  ('1 anaplastic lymphoma kinase', 5.0),
#  ('in patients with anaplastic lymphoma kinase', 5.0),
#  ('the discovery of anaplastic lymphoma kinase', 5.0),
#  ('tyrosine kinase', 4.800000000000001),
#  ('tyrosine kinase anaplastic lymphoma kinase', 4.800000000000001),
#  ('anaplastic lymphoma kinase gene', 4.666666666666667),
#  ('the anaplastic lymphoma kinase gene', 4.666666666666667),
#  ('mutations in the anaplastic lymphoma kinase', 4.666666666666667),
#  ('chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   4.666666666666667),
#  ('of the receptor tyrosine kinase anaplastic lymphoma kinase',
#   4.666666666666667),
#  ('metastatic anaplastic lymphoma kinase', 4.0),
#  ('patients anaplastic lymphoma kinase', 4.0),
#  ('is the anaplastic lymphoma kinase', 4.0),
#  ('epidermal growth factor receptor egfr or anaplastic lymphoma kinase', 4.0),
#  ('h factor receptor egfr alk + patients bearing a rearrangements of the anaplastic lymphoma kinase',
#   4),
#  ('mutations or anaplastic lymphoma kinase', 3.6666666666666665),
#  ('egfr and anaplastic lymphoma kinase', 3.6470588235294112),
#  ('nsclc anaplastic lymphoma kinase', 3.6),
#  ('mutations in anaplastic lymphoma kinase', 3.6),
#  ('domain of the anaplastic lymphoma kinase', 3.6),
#  ('advanced anaplastic lymphoma kinase', 3.5),
#  ('the identification of anaplastic lymphoma kinase', 3.333333333333333),
#  ('2p23', 3.2),
#  ('oral anaplastic lymphoma kinase', 3.0),
#  ('that anaplastic lymphoma kinase', 3.0),
#  ('therapy anaplastic lymphoma kinase', 3.0),
#  ('activation of the anaplastic lymphoma kinase', 3.0),
#  ('target inhibition of anaplastic lymphoma kinase', 3.0),
#  ('a rearrangements of the anaplastic lymphoma kinase', 3.0),
#  ('chromosomal rearrangements of the anaplastic lymphoma kinase', 3.0),
#  ('chromosomal translocations involving the anaplastic lymphoma kinase', 3.0),
#  ('the echinoderm microtubule associated protein like 4 eml4 gene and the anaplastic lymphoma kinase',
#   3),
#  ('human anaplastic lymphoma kinase', 2.5),
#  ('inhibition anaplastic lymphoma kinase', 2.5),
#  ('full length anaplastic lymphoma kinase', 2.5),
#  ('such as anaplastic lymphoma kinase', 2.5),
#  ('fusion of the anaplastic lymphoma kinase', 2.5),
#  ('of patients with anaplastic lymphoma kinase', 2.5),
#  ('tyrosine kinase including anaplastic lymphoma kinase', 2.5),
#  ('tyrosine kinase inhibitor of anaplastic lymphoma kinase', 2.5),
#  ('the epidermal growth factor receptor egfr anaplastic lymphoma kinase', 2.5),
#  ('between echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   2.5),
#  ('of echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   2.5),
#  ('receptor tyrosine kinase gene', 2.4),
#  ('translocations of the anaplastic lymphoma kinase', 2.333333333333333),
#  ('anaplastic lymphomakinase', 2.0),
#  ('expression anaplastic lymphoma kinase', 2.0),
#  ('most anaplastic lymphoma kinase', 2),
#  ('nucleophosmin anaplastic lymphoma kinase', 2.0),
#  ('on anaplastic lymphoma kinase', 2.0),
#  ('rtks anaplastic lymphoma kinase', 2.0),
#  ('alterations in anaplastic lymphoma kinase', 2.0),
#  ('or an anaplastic lymphoma kinase', 2.0),
#  ('the anaplastic lymphoma tyrosine kinase', 2),
#  ('the oncogenic anaplastic lymphoma kinase', 2.0),
#  ('translocations of anaplastic lymphoma kinase', 2.0),
#  ('with an anaplastic lymphoma kinase', 2.0),
#  ('anaplastic lymphoma receptor tyrosine kinase gene', 2.0),
#  ('for patients with anaplastic lymphoma kinase', 2.0),
#  ('the anaplastic lymphoma receptor tyrosine kinase', 2.0),
#  ('aberrant form of the anaplastic lymphoma kinase', 2),
#  ('molecular target is the anaplastic lymphoma kinase', 2.0),
#  ('patients with nucleophosmin npm anaplastic lymphoma kinase', 2),
#  ('the expression of the anaplastic lymphoma kinase', 2.0),
#  ('anaplastic large cell lymphoma alcl anaplastic lymphoma kinase', 2.0),
#  ('rearrangements of the gene encoding anaplastic lymphoma kinase', 2.0),
#  ('epidermal growth factor receptor egfr gene mutations or anaplastic lymphoma kinase',
#   2.0),
#  ('factor receptor signaling epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   2),
#  ('herwise specified ptcl nos angioimmunoblastic t cell lymphoma aitl anaplastic lymphoma kinase',
#   2),
#  ('hope for nsclc patients harboring oncogenic translocations involving the anaplastic lymphoma kinase',
#   2),
#  ('of the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   2.0),
#  ('ceritinib ldk378 is a second generation tyrosine kinase inhibitor of anaplastic lymphoma kinase',
#   2),
#  ('factor receptor egfr gene mutations and positive or negative for anaplastic lymphoma kinase',
#   2),
#  ('sion between echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   2),
#  ('joined to the entire cytoplasmic portion of the receptor tyrosine kinase anaplastic lymphoma kinase',
#   2),
#  ('n protein of echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   2),
#  ('otubule associated protein like 4 eml4 and the intracellular domain of anaplastic lymphoma kinase',
#   2),
#  ('ree survival of patients in the epidermal growth factor receptor egfr anaplastic lymphoma kinase',
#   2),
#  ('selective for therapy with an epidermal growth factor receptor egfr or anaplastic lymphoma kinase',
#   2),
#  ('zotinib in the treatment of patients with locally advanced or metastatic anaplastic lymphoma kinase',
#   2),
#  ('derm microtubule associated protein like 4 eml4 gene is fused to the anaplastic lymphoma kinase',
#   2),
#  ('ients with molecular diagnosis of non small cell lung cancer nsclc and anaplastic lymphoma kinase',
#   2),
#  ('ocally advanced or metastatic non small cell lung cancer nsclc that is anaplastic lymphoma kinase',
#   2),
#  ('x subsequently recruits a dimer of the type i receptor tgfβ can bind activin receptor like kinase',
#   2),
#  ('eml4 anaplastic lymphoma kinase', 1.8888888888888893),
#  ('egfr mutations and anaplastic lymphoma kinase', 1.8571428571428577),
#  ('growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1.8461538461538467),
#  ('eml4 and anaplastic lymphoma kinase', 1.8000000000000007),
#  ('egfr anaplastic lymphoma kinase', 1.7777777777777777),
#  ('egfr or anaplastic lymphoma kinase', 1.7142857142857144),
#  ('rearrangements involving the anaplastic lymphoma kinase',
#   1.7142857142857144),
#  ('encoding anaplastic lymphoma kinase', 1.666666666666667),
#  ('identification of anaplastic lymphoma kinase', 1.666666666666667),
#  ('as anaplastic lymphoma kinase', 1.6),
#  ('including anaplastic lymphoma kinase', 1.6),
#  ('gene encoding anaplastic lymphoma kinase', 1.6),
#  ('inhibition of anaplastic lymphoma kinase', 1.6),
#  ('gene and the anaplastic lymphoma kinase', 1.6),
#  ('oncogenic anaplastic lymphoma kinase', 1.5),
#  ('domain of anaplastic lymphoma kinase', 1.5),
#  ('expression of the anaplastic lymphoma kinase', 1.5),
#  ('of the gene encoding anaplastic lymphoma kinase', 1.5),
#  ('echinoderm microtubule associated protein like 4 eml4 gene and the anaplastic lymphoma kinase',
#   1.5),
#  ('receptor', 1.3333333333333333),
#  ('anaplastic lymphoma tyrosine kinase', 1.3333333333333333),
#  ('identified anaplastic lymphoma kinase', 1.3333333333333333),
#  ('inhibitor anaplastic lymphoma kinase', 1.3333333333333333),
#  ('rtk anaplastic lymphoma kinase', 1.3333333333333333),
#  ('anaplastic large cell lymphoma kinase', 1.3333333333333333),
#  ('fusion of anaplastic lymphoma kinase', 1.3333333333333333),
#  ('is an anaplastic lymphoma kinase', 1.3333333333333333),
#  ('met and anaplastic lymphoma kinase', 1.3333333333333333),
#  ('negative for anaplastic lymphoma kinase', 1.3333333333333333),
#  ('nsclc harboring anaplastic lymphoma kinase', 1.3333333333333333),
#  ('nsclc with anaplastic lymphoma kinase', 1.3333333333333333),
#  ('of activin receptor like kinase', 1.3333333333333333),
#  ('overexpression of anaplastic lymphoma kinase', 1.3333333333333333),
#  ('to the anaplastic lymphoma kinase', 1.3333333333333333),
#  ('alterations of the anaplastic lymphoma kinase', 1.3333333333333333),
#  ('in which the anaplastic lymphoma kinase', 1.3333333333333333),
#  ('nsclc that is anaplastic lymphoma kinase', 1.3333333333333333),
#  ('patients with advanced anaplastic lymphoma kinase', 1.3333333333333333),
#  ('the tyrosine kinase anaplastic lymphoma kinase', 1.3333333333333333),
#  ('locally advanced or metastatic anaplastic lymphoma kinase',
#   1.3333333333333333),
#  ('an epidermal growth factor receptor egfr or anaplastic lymphoma kinase',
#   1.3333333333333333),
#  ('alkannin', 1.0),
#  ('hydrophobic', 1.0),
#  ('kinase receptor', 1.0),
#  ('of alkannin', 1.0),
#  ('receptor kinase', 1.0),
#  ('used 2p23', 1.0),
#  ('sgpt alkaline phosphatase', 1.0),
#  ('3 anaplastic lymphoma kinase', 1.0),
#  ('4 anaplastic lymphoma kinase', 1.0),
#  ('5 anaplastic lymphoma kinase', 1.0),
#  ('7 anaplastic lymphoma kinase', 1.0),
#  ('80 anaplastic lymphoma kinase', 1.0),
#  ('against anaplastic lymphoma kinase', 1.0),
#  ('although anaplastic lymphoma kinase', 1),
#  ('anaplastic lymphoma kinase rearrangements', 1.0),
#  ('anti anaplastic lymphoma kinase', 1),
#  ('are anaplastic lymphoma kinase', 1.0),
#  ('because anaplastic lymphoma kinase', 1),
#  ('between anaplastic lymphoma kinase', 1.0),
#  ('carry anaplastic lymphoma kinase', 1.0),
#  ('ceritinib anaplastic lymphoma kinase', 1.0),
#  ('constitutive anaplastic lymphoma kinase', 1.0),
#  ('crizotinib anaplastic lymphoma kinase', 1.0),
#  ('decreased anaplastic lymphoma kinase', 1.0),
#  ('malignancies anaplastic lymphoma kinase', 1.0),
#  ('mutant anaplastic lymphoma kinase', 1.0),
#  ('no anaplastic lymphoma kinase', 1.0),
#  ('secondary anaplastic lymphoma kinase', 1),
#  ('selective anaplastic lymphoma kinase', 1.0),
#  ('shown anaplastic lymphoma kinase', 1.0),
#  ('spectrum orange labeled 2p23', 1.0),
#  ('ζ anaplastic lymphoma kinase', 1.0),
#  ('1 the anaplastic lymphoma kinase', 1.0),
#  ('activation the anaplastic lymphoma kinase', 1.0),
#  ('alk inhibitor anaplastic lymphoma kinase', 1.0),
#  ('alk receptor tyrosine kinase gene', 1.0),
#  ('and an anaplastic lymphoma kinase', 1.0),
#  ('associated with anaplastic lymphoma kinase', 1.0),
#  ('chemotherapy regimens anaplastic lymphoma kinase', 1.0),
#  ('clinical trials anaplastic lymphoma kinase', 1.0),
#  ('complication of anaplastic lymphoma kinase', 1.0),
#  ('detection of anaplastic lymphoma kinase', 1.0),
#  ('efficacy of anaplastic lymphoma kinase', 1.0),
#  ('features of anaplastic lymphoma kinase', 1.0),
#  ('first generation anaplastic lymphoma kinase', 1.0),
#  ('for detection anaplastic lymphoma kinase', 1.0),
#  ('fused the anaplastic lymphoma kinase', 1.0),
#  ('harboring an anaplastic lymphoma kinase', 1.0),
#  ('malignancies the anaplastic lymphoma kinase', 1.0),
#  ('next generation anaplastic lymphoma kinase', 1.0),
#  ('of an anaplastic lymphoma kinase', 1.0),
#  ('of npm anaplastic lymphoma kinase', 1.0),
#  ('related to anaplastic lymphoma kinase', 1.0),
#  ('significant of anaplastic lymphoma kinase', 1.0),
#  ('specific for anaplastic lymphoma kinase', 1.0),
#  ('structure of anaplastic lymphoma kinase', 1.0),
#  ('that inhibition anaplastic lymphoma kinase', 1.0),
#  ('the activin receptor like kinase', 1.0),
#  ('the influence of metabolic alkalosis', 1),
#  ('the intracellular anaplastic lymphoma kinase', 1),
#  ('therapy in anaplastic lymphoma kinase', 1.0),
#  ('therapy the anaplastic lymphoma kinase', 1.0),
#  ('those with anaplastic lymphoma kinase', 1.0),
#  ('which target anaplastic lymphoma kinase', 1.0),
#  ('who harboring anaplastic lymphoma kinase', 1.0),
#  ('with the anaplastic lymphoma kinase', 1.0),
#  ('a patients with anaplastic lymphoma kinase', 1.0),
#  ('a second generation anaplastic lymphoma kinase', 1.0),
#  ('aberrant activation of anaplastic lymphoma kinase', 1.0),
#  ('abnormal expression of anaplastic lymphoma kinase', 1),
#  ('alectinib is an anaplastic lymphoma kinase', 1),
#  ('alk rearrangements nsclc anaplastic lymphoma kinase', 1.0),
#  ('an inhibitor of anaplastic lymphoma kinase', 1.0),
#  ('c met and anaplastic lymphoma kinase', 1.0),
#  ('chromosomal rearrangements of anaplastic lymphoma kinase', 1.0),
#  ('clinical outcome of anaplastic lymphoma kinase', 1),
#  ('concomitant inhibition of anaplastic lymphoma kinase', 1),
#  ('crizotinib is an anaplastic lymphoma kinase', 1.0),
#  ('egfr mutations or anaplastic lymphoma kinase', 1.0),
#  ('gene rearrangements of anaplastic lymphoma kinase', 1.0),
#  ('gene such as anaplastic lymphoma kinase', 1.0),
#  ('identification of the anaplastic lymphoma kinase', 1.0),
#  ('in recent years anaplastic lymphoma kinase', 1.0),
#  ('in this study anaplastic lymphoma kinase', 1),
#  ('in this study effective of aliskiren', 1),
#  ('inhibitor of activin receptor like kinase', 1.0),
#  ('mutations activation of anaplastic lymphoma kinase', 1.0),
#  ('mutations of the anaplastic lymphoma kinase', 1.0),
#  ('of anaplastic lymphoma receptor tyrosine kinase', 1.0),
#  ('of the anaplastic lymphoma kinase gene', 1.0),
#  ('oncogenic activation of anaplastic lymphoma kinase', 1.0),
#  ('oncogenic fusion of anaplastic lymphoma kinase', 1.0),
#  ('portion of the anaplastic lymphoma kinase', 1.0),
#  ('pretreated patients with anaplastic lymphoma kinase', 1.0),
#  ('right detection of anaplastic lymphoma kinase', 1),
#  ('signaling pathways in anaplastic lymphoma kinase', 1.0),
#  ('since 2007 when anaplastic lymphoma kinase', 1),
#  ('the anaplastic large cell lymphoma kinase', 1.0),
#  ('the demonstrated of anaplastic lymphoma kinase', 1),
#  ('the development of anaplastic lymphoma kinase', 1),
#  ('the efficacy of anaplastic lymphoma kinase', 1),
#  ('the expression of anaplastic lymphoma kinase', 1.0),
#  ('the nucleophosmin npm anaplastic lymphoma kinase', 1.0),
#  ('the presence of anaplastic lymphoma kinase', 1.0),
#  ('the second generation anaplastic lymphoma kinase', 1.0),
#  ('the treatment of anaplastic lymphoma kinase', 1.0),
#  ('treated patients with anaplastic lymphoma kinase', 1.0),
#  ('tumorigenic rearrangements in anaplastic lymphoma kinase', 1),
#  ('with anaplastic lymphoma receptor tyrosine kinase', 1.0),
#  ('a mutations in the anaplastic lymphoma kinase', 1.0),
#  ('activation gene rearrangements of anaplastic lymphoma kinase', 1),
#  ('activation mutations in the anaplastic lymphoma kinase', 1),
#  ('alectinib an inhibitor of anaplastic lymphoma kinase', 1),
#  ('alectinib the second generation anaplastic lymphoma kinase', 1),
#  ('carry rearrangements of the anaplastic lymphoma kinase', 1.0),
#  ('chromosomal rearrangements in the anaplastic lymphoma kinase', 1.0),
#  ('crizotinib a drug for anaplastic lymphoma kinase', 1),
#  ('crizotinib a first generation anaplastic lymphoma kinase', 1),
#  ('crizotinib an inhibitor of anaplastic lymphoma kinase', 1),
#  ('genetic alterations of the anaplastic lymphoma kinase', 1.0),
#  ('genetic rearrangements of the anaplastic lymphoma kinase', 1),
#  ('genomic alterations in the anaplastic lymphoma kinase', 1.0),
#  ('genomic rearrangements in the anaplastic lymphoma kinase', 1.0),
#  ('in patients with advanced anaplastic lymphoma kinase', 1.0),
#  ('investigated in japan identified anaplastic lymphoma kinase', 1.0),
#  ('lung cancer patients with anaplastic lymphoma kinase', 1),
#  ('of the tyrosine kinase anaplastic lymphoma kinase', 1.0),
#  ('rearrangements of the anaplastic large cell kinase', 1.0),
#  ('receptor tyrosine kinase including anaplastic lymphoma kinase', 1.0),
#  ('resulting in overexpression of anaplastic lymphoma kinase', 1.0),
#  ('somatic rearrangements of the anaplastic lymphoma kinase', 1),
#  ('the fusion of the anaplastic lymphoma kinase', 1.0),
#  ('the gene coding for anaplastic lymphoma kinase', 1.0),
#  ('the intracellular domain of anaplastic lymphoma kinase', 1.0),
#  ('the mutations activation of anaplastic lymphoma kinase', 1),
#  ('the prognostic value of anaplastic lymphoma kinase', 1),
#  ('the rate of the anaplastic lymphoma kinase', 1),
#  ('the therapeutic target of anaplastic lymphoma kinase', 1),
#  ('the translocations of the anaplastic lymphoma kinase', 1.0),
#  ('the tyrosine kinase receptor anaplastic lymphoma kinase', 1.0),
#  ('therapy the identification of anaplastic lymphoma kinase', 1.0),
#  ('tyrosine kinase inhibitor target anaplastic lymphoma kinase', 1.0),
#  ('abnormal expression of constitutive activation anaplastic lymphoma kinase',
#   1),
#  ('activation mutations in full length anaplastic lymphoma kinase', 1.0),
#  ('alectinib is a second generation anaplastic lymphoma kinase', 1),
#  ('enrolled patients had alk receptor tyrosine kinase gene', 1),
#  ('gain of function mutations in anaplastic lymphoma kinase', 1.0),
#  ('gene are the most dominant anaplastic lymphoma kinase', 1),
#  ('it has been reported that anaplastic lymphoma kinase', 1),
#  ('lorlatinib a novel generation oral anaplastic lymphoma kinase', 1),
#  ('of chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1.0),
#  ('oncogenic receptor tyrosine kinase including anaplastic lymphoma kinase',
#   1),
#  ('overall survival os with the anaplastic lymphoma kinase', 1),
#  ('patients with lung cancer harboring anaplastic lymphoma kinase', 1),
#  ('resulting in constitutive activation of anaplastic lymphoma kinase', 1.0),
#  ('sed anticancer drug development the anaplastic lymphoma kinase', 1),
#  ('several second generation inhibitor of anaplastic lymphoma kinase', 1),
#  ('the catalytic domain of the anaplastic lymphoma kinase', 1.0),
#  ('the efficacy of crizotinib for anaplastic lymphoma kinase', 1),
#  ('the receptor tyrosine kinase rtk anaplastic lymphoma kinase', 1.0),
#  ('the treatment of patients with anaplastic lymphoma kinase', 1.0),
#  ('accumulating evidence indicate that expression of anaplastic lymphoma kinase',
#   1),
#  ('crizotinib is an oral small molecule anaplastic lymphoma kinase', 1),
#  ('development of inhibitor for the tyrosine anaplastic lymphoma kinase', 1.0),
#  ('epidermal growth factor receptor egfr mutations anaplastic lymphoma kinase',
#   1.0),
#  ('f more than one inhibitor the anaplastic lymphoma kinase', 1),
#  ('in a patients who had metastatic anaplastic lymphoma kinase', 1),
#  ('in anaplastic large cell lymphoma alcl anaplastic lymphoma kinase', 1),
#  ('in clinical trials of patients with anaplastic lymphoma kinase', 1),
#  ('ligand induced membrane trafficking of the anaplastic lymphoma kinase', 1),
#  ('one of the characteristics features of anaplastic lymphoma kinase', 1),
#  ('tgf β superfamily type i activin receptor like kinase', 1.0),
#  ('the present study aimed to investigated anaplastic lymphoma kinase', 1),
#  ('we reported an anaplastic lymphoma receptor tyrosine kinase gene', 1),
#  ('alectinib is a highly selective next generation anaplastic lymphoma kinase',
#   1),
#  ('although anaplastic large cell lymphoma alcl carry anaplastic lymphoma kinase',
#   1),
#  ('although crizotinib show marked antitumor activation in anaplastic lymphoma kinase',
#   1),
#  ('among the many oncogenic variants of the anaplastic lymphoma kinase', 1),
#  ('another oncogenic protein linked to p130cas is anaplastic lymphoma kinase',
#   1),
#  ('epidermal growth factor receptor egfr gene and anaplastic lymphoma kinase',
#   1.0),
#  ('feration differentiation and survival during embryonic neurogenesis anaplastic lymphoma kinase',
#   1),
#  ('human epidermal growth factor receptor 2 her2 anaplastic lymphoma kinase',
#   1.0),
#  ('lorlatinib pf 06463922 is a promising oral anaplastic lymphoma kinase', 1),
#  ('neuroblastoma nbs harboring activation point mutations in anaplastic lymphoma kinase',
#   1),
#  ('non small cell lung cancer nsclc harboring anaplastic lymphoma kinase',
#   1.0),
#  ('non small cell lung cancer nsclcs harboring anaplastic lymphoma kinase', 1),
#  ('nsclc with de novo anaplastic lymphoma receptor tyrosine kinase gene', 1),
#  ('numerous mutations have been observed in the anaplastic lymphoma kinase',
#   1),
#  ('oncogenic fusion gene consisting of eml4 and anaplastic lymphoma kinase',
#   1),
#  ('orrelation between echinodermmicro tubule associated protein like 4 eml4 anaplasticlymphomakinase',
#   1),
#  ('oxaloacetic transaminase sgot sermn glutamic pyruvic transaminase sgpt alkaline phosphatase',
#   1),
#  ('patients with lung cancer harboring an activation anaplastic lymphoma kinase',
#   1),
#  ('the development of inhibitor for the tyrosine anaplastic lymphoma kinase',
#   1),
#  ('the identification of chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('affect protein activation while preserving response to crizotinib anaplastic lymphoma kinase',
#   1),
#  ('ancer characterized by alk rearrangements translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('as brigatinib was development as a next generation anaplastic lymphoma kinase',
#   1),
#  ('before differentiation induction expression levels of anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('crizotinib and foretinib are multi target tki inhibition anaplastic lymphoma kinase',
#   1),
#  ('crizotinib has demonstrated promising efficacy in patients with anaplastic lymphoma kinase',
#   1),
#  ('crizotinib is an effective drug for patients with anaplastic lymphoma kinase',
#   1),
#  ('despite the benefit of first and second generation anaplastic lymphoma kinase',
#   1),
#  ('eage frequent associated with chromosomal translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('emoglobin hgb prostate specific antigen psa lactate dehydrogenase ldh alkaline phosphatase',
#   1),
#  ('en malignancies distinct microrna mirna signatures differentiation in anaplastic lymphoma kinase',
#   1),
#  ('eveloping brain metastases during crizotinib treatment rearrangements of anaplastic lymphoma kinase',
#   1),
#  ('immature mesenchymal cell committed to skeletal muscle differentiation anaplastic lymphoma kinase',
#   1),
#  ('in radiotherapy demographic and clinicopathologic characteristics of 80 anaplastic lymphoma kinase',
#   1),
#  ('inhibitor in the post crizotinib set efficacy of anaplastic lymphoma kinase',
#   1),
#  ('inhibitor tkis gefitinib erlotinib afatinib and osimertinib and anaplastic lymphoma kinase',
#   1),
#  ('iptase inss international neuroblastoma stage systemic associated of anaplastic lymphoma kinase',
#   1),
#  ('it had been shown that approximately 80 of anaplastic lymphoma kinase', 1),
#  ('lung cancer driven by oncogenic rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('lung carcinoma nsclc carry chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('neuroblastoma is frequent driven by oncogenic activation of anaplastic lymphoma kinase',
#   1),
#  ('opic muscle ossification of fibrodysplasia ossificans progressiva constitutive activin like kinase',
#   1),
#  ('or by transdifferentiation from prostate adenocarcinoma alterations in anaplastic lymphoma kinase',
#   1),
#  ('other treatment the development of pharmacologic strategies target anaplastic lymphoma kinase',
#   1),
#  ('over the past few decades several techniques of anterior lamellar keratoplasty',
#   1),
#  ('ping effective therapeutic strategies chromosomal rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('r patients stratification recent tyrosine kinase inhibitor target anaplastic lymphoma kinase',
#   1),
#  ('rapies oncogenic rearrangements resulting in constitutive activation of anaplastic lymphoma kinase',
#   1),
#  ('s including syndecan integrins protein tyrosine phosphatase ζ ptpζ anaplastic lymphomakinase',
#   1),
#  ('several function linked receptor tyrosine kinase rtks including anaplastic lymphoma kinase',
#   1),
#  ('subsequently echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('such as epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   1.0),
#  ('target therapy for distinct patients molecular subgroup activation anaplastic lymphoma kinase',
#   1),
#  ('the oncogenic function of gene translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('this study aimed to elucidate clinical significant of anaplastic lymphoma kinase',
#   1),
#  ('with crizotinib administered following multi line chemotherapy regimens anaplastic lymphoma kinase',
#   1),
#  ('ymphocytes this genomic rearrangements generation the nucleophosmin npm anaplastic lymphoma kinase',
#   1),
#  ('ymphomas nhl characterized by chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('2016 revised world health organization who lymphoma classification 1 anaplastic lymphoma kinase',
#   1),
#  ('5 the discovery of recurrent chromosomal translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('a c2c12 myoblasts were reprogrammed into cell expression osteogenic markers alkaline phosphatase',
#   1),
#  ('a subset of lung cancer is dependent on the anaplastic lymphoma kinase', 1),
#  ('acquired drug resistance 3 4 especially for patients carry anaplastic lymphoma kinase',
#   1),
#  ('alectinib a highly selective central nervous systemic cns activation anaplastic lymphoma kinase',
#   1),
#  ('alectinib alecensa ® is a potent and highly selective anaplastic lymphoma kinase',
#   1),
#  ('and diagnosed with action mutations for example anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('and the potential of exacerbated toxicities with combination therapy anaplastic lymphoma kinase',
#   1),
#  ('and water h2o4 beads solid line and the hydrophilic palc and hydrophobic',
#   1),
#  ('another example of drug resistance in lung cancer is anaplastic lymphoma kinase',
#   1),
#  ('ard cytotoxic chemotherapy and target therapy the identification of anaplastic lymphoma kinase',
#   1),
#  ('around a bisanilinopyrimidine scaffold with potent activation against the anaplastic lymphoma kinase',
#   1),
#  ('atypical rearrangements containing within these may otherwise be missed anaplastic lymphoma kinase',
#   1),
#  ('because phosphorylation of smad1 5 8 occur through activin receptor like kinase',
#   1),
#  ('bservations the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('cancer harboring epidermal growth factor receptor egfr mutations or anaplastic lymphoma kinase',
#   1),
#  ('catalytic subunit alpha pik3ca phosphatase and tensin homologue akt anaplastic lymphoma kinase',
#   1),
#  ('cell surface receptor protein tyrosine phosphatase receptor rptpβ ζ anaplastic lymphoma kinase',
#   1),
#  ('cell type serve as vehicles of intercellular communication rearrangements anaplastic lymphoma kinase',
#   1),
#  ('ceritinib is a second generation selective and potent oral anaplastic lymphoma kinase',
#   1),
#  ('chromosomal rearrangements and mutations that leading to overactivation of anaplastic lymphoma kinase',
#   1),
#  ('ctor receptor egfr vascular endothelial growth factor vegf and anaplastic lymphoma kinase',
#   1),
#  ('d drug administration fda intriguingly ceritinib zykadia a potent anaplastic lymphoma kinase',
#   1),
#  ('density lipoprotein cholesterol ldl c very low density lipoprotein vldl alkaline phosphatase',
#   1),
#  ('diaminopyrimidine class of kinase inhibitor were identified that target anaplastic lymphoma kinase',
#   1),
#  ('directed toward epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('discovered mutations within the epidermal growth factor receptor egfr anaplastic lymphoma kinase',
#   1),
#  ('disease who have progression on crizotinib chromosomal rearrangements of anaplastic lymphoma kinase',
#   1),
#  ('drug have produced substantial clinical response here we established anaplastic lymphoma kinase',
#   1),
#  ('eak apart rearrangements probe abbott molecular histology features of anaplastic lymphoma kinase',
#   1),
#  ('echinoderm microtubule associated protein like 4 eml4 and the anaplastic lymphoma kinase',
#   1.0),
#  ('ed therapy study reported autophagy induction following therapy in anaplastic lymphoma kinase',
#   1),
#  ('elanoma and present potential therapeutic target translocations of the anaplastic lymphoma kinase',
#   1),
#  ('ell lymphoma chromosomal translocations involving the kinase domain of anaplastic lymphoma kinase',
#   1),
#  ('ell transforming cause by the oncogenic chimeric nucleophosmin npm anaplastic lymphoma kinase',
#   1),
#  ('epresentative blot and quantitation from duplicate experience is shown anaplastic lymphoma kinase',
#   1),
#  ('erapeutic option for alectinib resistance alk positive nsclc patients anaplastic lymphoma kinase',
#   1),
#  ('esis that may represent significant regulatory target for glioblastoma anaplastic lymphoma kinase',
#   1),
#  ('gs target epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('has significant improved patients outcome similarly inhibitor of the anaplastic lymphoma kinase',
#   1),
#  ('highlights an important new treatment option for neuroblastoma patients anaplastic lymphoma kinase',
#   1),
#  ('hough the ventana immunohistochemistry ihc platform for detection anaplastic lymphoma kinase gene',
#   1),
#  ('iable fragment scfv on pleiotrophin ptn signaling through endogenous anaplastic lymphoma kinase',
#   1),
#  ('ibitors tkis recent the discovery of translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('ienced clinical and radiographic improved with target inhibition of anaplastic lymphoma kinase',
#   1),
#  ('important predictors of the biological behavior of lung adenocarcinoma anaplastic lymphoma kinase',
#   1),
#  ('including epidermal growth factor receptor egfr mutations fusion in anaplastic lymphoma kinase',
#   1),
#  ('inhibitor tkis are excellent example of personalized alternations 3 anaplastic lymphoma kinase',
#   1),
#  ('itor crizotinib echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('k rearrangements positive advanced solid tumors and nsclc respectively anaplastic lymphoma kinase',
#   1),
#  ('kis and other target therapy are required immunohistochemistry for anaplastic lymphoma kinase',
#   1),
#  ('l is characterized by recurrent chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('linicaltrials gov number nct01283516 genetic alterations in the anaplastic lymphoma kinase gene',
#   1),
#  ('lung cancer echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('may be effective at overcome resistance chromosomal translocations of anaplastic lymphoma kinase',
#   1),
#  ('monds and the target atomistic simulation solid line interaction potential between hydrophobic',
#   1),
#  ('nclear perez pinera and colleagues demonstrated that phosphorylation of anaplastic lymphoma kinase',
#   1),
#  ('ncogene addicted lung cancer tumors compared with sequential strategies anaplastic lymphoma kinase',
#   1),
#  ('ncogene braf and erbb2 her2 mutations rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('ne hit compound isoliquiritigenin has been previously reported to upregulate alkaline phosphatase',
#   1),
#  ('nefits especially for genetic defined patients populations 2 the anaplastic lymphoma kinase',
#   1),
#  ('nhanced and reduces cellular sensitive to doxorubicin ptn upregulate anaplastic lymphoma kinase',
#   1),
#  ('nit specific individual antigen bind motifs scfv specific for anaplastic lymphoma kinase',
#   1),
#  ('non small cell lung cancer nsclc harboring the anaplastic lymphoma kinase gene',
#   1),
#  ('non small cell lung cancer nsclcs harboring translocations in anaplastic lymphoma kinase',
#   1),
#  ('ns epidermal growth factor receptor mutations egfr and anaplastic lymphoma kinase rearrangements',
#   1),
#  ('numerous clinical trials show crizotinib has promising efficacy for anaplastic lymphoma kinase',
#   1),
#  ('ocarcinoma cell harboring oncogenic rearrangements of the gene encoding anaplastic lymphoma kinase',
#   1),
#  ('of patients 11 moreover patients with translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('of success target therapy and have changed treatment guidelines anaplastic lymphoma kinase',
#   1),
#  ('omas dramatically 2 epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   1),
#  ('optical density single chain variable fragment scfv interaction with anaplastic lymphoma kinase',
#   1),
#  ('ovide improved survival after recist defined progression on crizotinib anaplastic lymphoma kinase',
#   1),
#  ('ow evolutionary conservation of this important interaction mutations in anaplastic lymphoma kinase',
#   1),
#  ('patients with echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('patients with non small cell lung cancer nsclc with anaplastic lymphoma kinase',
#   1.0),
#  ('pectrum of clinical present and behavior early identification of anaplastic lymphoma kinase',
#   1),
#  ('potent small molecule inhibitor of multiple tyrosine kinase including anaplastic lymphoma kinase',
#   1),
#  ('present underway to clinical overcome acquired drug resistance the anaplastic lymphoma kinase',
#   1),
#  ('proliferation migration and angiogenesis of cancer cell 7 the anaplastic lymphoma kinase',
#   1),
#  ('ptn signaling through three cell surface receptor syndecan 3 anaplastic lymphoma kinase',
#   1),
#  ('re deviation rmsd analysis of crizotinib lorlatinib associated mutations anaplastic lymphoma kinase',
#   1),
#  ('rent variants among systemic alcl patients harboring translocations of anaplastic lymphoma kinase',
#   1),
#  ('res significant homolog with fellow insulin receptor superfamily member anaplastic lymphoma kinase',
#   1),
#  ('rmalities named epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('roliferation of large pleomorphic lymphoma cell abnormal activation of anaplastic lymphoma kinase',
#   1),
#  ('romosomal rearrangements of alk gene encoding the continuously activation anaplastic lymphoma kinase',
#   1),
#  ('rrangements in echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('since the initial discovery of chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('some pathways according to their intracellular locally full length anaplastic lymphoma kinase',
#   1),
#  ('step toward nb development mycn overexpression combination with activation anaplastic lymphoma kinase',
#   1),
#  ('strated for different diagnostic techniques versus a biological true anaplastic lymphoma kinase',
#   1),
#  ('such as epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1.0),
#  ('tae 684 is a small molecule inhibitor of activation anaplastic lymphoma kinase',
#   1),
#  ('that somatic acquired activation mutations and amplification of the anaplastic lymphoma kinase',
#   1),
#  ('the current study was designed to investigated the protective role of alkannin',
#   1),
#  ('the discovery of the transforming fusion gene of the anaplastic lymphoma kinase',
#   1),
#  ('therapeutic target for these otherwise refractory tumors expression of anaplastic lymphoma kinase',
#   1),
#  ('therapy with drug target epidermal growth factor receptor egfr anaplastic lymphoma kinase',
#   1),
#  ('tients harboring epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('tients meanwhile epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('titutive oncogenic signaling pathways in the tumour cell constitutive anaplastic lymphoma kinase',
#   1),
#  ('tization for chemotherapeutics is associated with aberrant activation of anaplastic lymphoma kinase',
#   1),
#  ('toma remain unsatisfactory several recent find have positive the anaplastic lymphoma kinase',
#   1),
#  ('unohistochemistry and fluorescence in situ hybridization analyses of the anaplastic lymphoma kinase',
#   1),
#  ('vel combination therapy strategies for treated alk driven neuroblastoma anaplastic lymphoma kinase',
#   1),
#  ('ver gene alternations including epidermal growth factor receptor egfr anaplastic lymphoma kinase',
#   1),
#  ('vo validated echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('was demonstrated between variants treated with crizotinib or ceritinib anaplastic lymphoma kinase',
#   1),
#  ('wnstream of epidemiologically relevant oncogenic 4 one tk receptor anaplastic lymphoma kinase',
#   1),
#  ('xcised through the endolaryngeal route histopathology was suggest of anaplastic lymphoma kinase',
#   1),
#  ('11 previously several small sample size study have reported no anaplastic lymphoma kinase',
#   1),
#  ('15 16 and afatinib 17 19 and translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('2 3 years similarly patients with tumors containing anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('3 4 more recent target therapy directed at nsclc harboring anaplastic lymphoma kinase',
#   1),
#  ('acy of ceritinib the rapid development of target therapeutic against anaplastic lymphoma kinase',
#   1),
#  ('advanced non small cell lung cancer nsclc patients who harboring anaplastic lymphoma kinase',
#   1),
#  ('an activation epidermal growth factor receptor egfr gene mutations or anaplastic lymphoma kinase',
#   1),
#  ('analyses to detection epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('and a concomitant epithelial growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('ansducer and activation of transcription 3 stat3 phospho stat3 y705 anaplastic lymphoma kinase',
#   1),
#  ('approximately 5 6 of nsclc have chromosomal rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('ar signaling and transcription machinery required for such changed are anaplastic lymphoma kinase',
#   1),
#  ('arcinoma histology the most recent identified molecular target is the anaplastic lymphoma kinase',
#   1),
#  ('arcinoma scc skarda et al 2008 chromosomal rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('arge cell lymphoma alcl carry chromosomal translocations in which the anaplastic lymphoma kinase',
#   1),
#  ('argetable molecular lesions with the exception of mutations in anaplastic lymphoma receptor kinase',
#   1),
#  ('arrangements alk + typically become resistance to the first generation anaplastic lymphoma kinase',
#   1),
#  ('artis present a topic titled zykadia ceritinib a second generation anaplastic lymphoma kinase',
#   1),
#  ('at baseline abbreviations m months nm no alk resistance mutations anaplastic lymphoma kinase',
#   1),
#  ('atinib alunbrig alk egfr wildype and mutant t790m protein metastatic anaplastic lymphoma kinase',
#   1),
#  ('atory infiltrate approximately half of imt carry rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('b in tumorigenesis and provide mechanistic insight into alk regulation anaplastic lymphoma kinase',
#   1),
#  ('been recognized as important drivers across many cancer 1 wherein anaplastic lymphoma kinase',
#   1),
#  ('bind to pd l1 promoter mutations of oncogenic chimeric nucleophosmin anaplastic lymphoma kinase',
#   1),
#  ('bnormal fusion gene eml4 alk resulting in constitutive activation of anaplastic lymphoma kinase',
#   1),
#  ('can pathologist and the european society of medical oncologists indicate anaplastic lymphoma kinase',
#   1),
#  ('cations in the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('ce and received carboplatin pemetrexed and maintenance pemetrexed as an anaplastic lymphoma kinase',
#   1),
#  ('ced malignancies that ultimately must be overcome for tumors development anaplastic lymphoma kinase',
#   1),
#  ('ceptors the protein tyrosine phosphatase receptor zeta ptprz1 and the anaplastic lymphoma kinase',
#   1),
#  ('characterized of alk y1278s a ribbon diagram of the inactive anaplastic lymphoma kinase',
#   1),
#  ('clc who progression on alectinib trials registration no nct 02450903 anaplastic lymphoma kinase',
#   1),
#  ('clinical features of these neoplasms most important the discovery of anaplastic lymphoma kinase',
#   1),
#  ('co occurrence of epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('compared the progression free survival pfs of chinese patients with anaplastic lymphoma kinase',
#   1),
#  ('criptase polymerase chain reaction abbreviations alk + positive for an anaplastic lymphoma kinase',
#   1),
#  ('crizotinib is an oral small molecule tyrosine kinase inhibitor target anaplastic lymphoma kinase',
#   1),
#  ('ctor receptor egfr kirsten rat sarcoma viral oncogenic homolog kras anaplastic lymphoma kinase',
#   1),
#  ('dependent prognostic factor for the outcome activation mutations of the anaplastic lymphoma kinase',
#   1),
#  ('dermal growth factor receptor tyrosine kinase inhibitor egfr tkis and anaplastic lymphoma kinase',
#   1),
#  ('described the therapeutic achieved in the treatment of patients with anaplastic lymphoma kinase',
#   1),
#  ('discovery of an echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('discovery of the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('distinct molecular subtype of non small cell lung cancer nsclc anaplastic lymphoma kinase',
#   1),
#  ('drivers such as epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('e alterations such as epidermal growth factor receptor egfr mutations anaplastic lymphoma kinase',
#   1),
#  ('e crizotinib resistance and prolong survival genomic alterations in the anaplastic lymphoma kinase',
#   1),
#  ('e dct the matrix metallopeptidase 8 mmp8 fig 1e addition anaplastic lymphoma kinase',
#   1),
#  ('e inhibitor egfr tkis erlotinib gefitinib and afatinib and anaplastic lymphoma kinase gene',
#   1),
#  ('e innovative training network grant 675712 a domain structure of anaplastic lymphoma kinase',
#   1),
#  ('e th mycn transgenic mouse model whereas mutations alterations in anaplastic lymphoma kinase',
#   1),
#  ('e the diagnostic value of ventana immunohistochemistry ihc assay for anaplastic lymphoma kinase',
#   1),
#  ('ears study have demonstrated the occurrence of autophagy in different anaplastic lymphoma kinase',
#   1),
#  ('ecule receptor tyrosine kinase inhibitor development to antagonize met and anaplastic lymphoma kinase',
#   1),
#  ('efforts to development alk target cancer therapy for these malignancies anaplastic lymphoma kinase',
#   1),
#  ('ell lymphoma patients exception for anaplastic large cell lymphoma alcl anaplastic lymphoma kinase',
#   1),
#  ('eport our experience of ceritinib in crizotinib pretreated patients with anaplastic lymphoma kinase',
#   1),
#  ('er nsclc is transforming clinical care genomic rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('ered between echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   1),
#  ('etween echinoderm microtubule associated protein like 4 eml4 and the anaplastic lymphoma kinase',
#   1),
#  ('expression and aberrant mir497hg promoter methylation in alcl cell npm anaplastic lymphoma kinase',
#   1),
#  ('factor receptor egfr human epidermal growth factor receptor 2 her2 anaplastic lymphoma kinase',
#   1),
#  ('fr alterations received egfr target therapy 6 whereas those with anaplastic lymphoma kinase',
#   1),
#  ('fr vascular endothelial growth factor vegf and it receptor vegfr anaplastic lymphoma kinase',
#   1),
#  ('from the abnormal differentiation of the sympathetic nervous systemic the anaplastic lymphoma kinase',
#   1),
#  ('from the specific chromosomal translocations that fused the anaplastic large cell lymphoma kinase',
#   1),
#  ('gene between echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   1),
#  ('generation by lpl significant increased the phosphorylation of the rtks anaplastic lymphoma kinase',
#   1),
#  ('genetic and biochemical data indicate that the receptor tyrosine kinase anaplastic lymphoma kinase',
#   1),
#  ('group epidermal growth factor receptor egfr target therapy or an anaplastic lymphoma kinase',
#   1),
#  ('growth factor receptor egfr or translocations in alk which encoding anaplastic lymphoma kinase',
#   1),
#  ('h alterations in neovascularization and cell proliferation in gbms the anaplastic lymphoma kinase',
#   1),
#  ('h mutant epidermal growth factor receptor egfr and anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('haracteristics several oncogenic drivers mutations such as those of the anaplastic lymphoma kinase',
#   1),
#  ('hase protein arrays revealed activation of the receptor tyrosine kinase anaplastic lymphoma kinase',
#   1),
#  ('have identified activation point mutations in the anaplastic lymphoma receptor tyrosine kinase gene',
#   1),
#  ('he epidermal growth factor receptor egfr and crizotinib which target anaplastic lymphoma kinase',
#   1),
#  ('he mechanisms of cell transforming mediated by the nucleophosmin npm anaplastic lymphoma kinase',
#   1),
#  ('he mechanisms of malignancies cell transforming mediated by the oncogenic anaplastic lymphoma kinase',
#   1),
#  ('herapeutic outcome of patients with mutant alk driven malignancies the anaplastic lymphoma kinase',
#   1),
#  ('ibitors tkis which target epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   1),
#  ('ication of echinoderm microtubule associated protein like 4 eml4 and anaplastic lymphoma kinase',
#   1),
#  ('ication of the echinoderm microtubule associated protein like 4 eml4 anaplastic lymphoma kinase',
#   1),
#  ('ies for such tumors harboring secondary mutations rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('immunological activation and may contribute to the pathogenesis of sepsis anaplastic lymphoma kinase',
#   1),
# ...
#   1),
#  ('one mutations in particular is the rearrangements of the anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('onsored trials 27 bars for crizotinib represent orrs in patients with anaplastic lymphoma kinase',
#   1),
#  ('ood non hodgkin lymphoma nhl systemic alcl is highly associated with anaplastic lymphoma kinase',
#   1),
#  ('osine kinase rtks have also been implicated in oncogenesis 1 4 anaplastic lymphoma kinase',
#   1),
#  ('osomal translocations and the fusion of nucleophomin npm and anaplastic large cell lymphoma kinase',
#   1),
#  ('owth factor receptor 2 vegfr2 inhibitor two egfr target drug one anaplastic lymphoma kinase',
#   1),
#  ('panel a show the various treatment the patients received for metastatic anaplastic lymphoma kinase',
#   1),
#  ('positive and fish negative may still respond to crizotinib therapy the anaplastic lymphoma kinase',
#   1),
#  ('qpcr was performed in triplets the related expression levels of mouse anaplastic lymphoma kinase',
#   1),
#  ('r mutations in addition tkis that target the receptor tyrosine kinase anaplastic lymphoma kinase',
#   1),
#  ('r1275q and c1156y the fast development of inhibitor for the tyrosine anaplastic lymphoma kinase',
#   1),
#  ('raf proto oncogenic serine threonine kinase braf mutations as well as anaplastic lymphoma kinase',
#   1),
#  ('re also discussed just 3 years later investigated in japan identified anaplastic lymphoma kinase',
#   1),
#  ('rearrangements crizotinib pf 02341066 is one of the tkis that inhibition anaplastic lymphoma kinase',
#   1),
#  ('reases in cpac tumors mrna expression and receptor phosphorylation of the anaplastic lymphoma kinase',
#   1),
#  ('related deaths in children a germline mutations in the anaplastic lymphoma receptor tyrosine kinase',
#   1),
#  ('resistance we rationally designed a novel kind of bridge inhibitor of anaplastic lymphoma kinase',
#   1),
#  ('resulting in nb like tumors mycn cooperates with mutations activation of anaplastic lymphoma kinase',
#   1),
#  ('rosine kinase inhibitor tkis 5 7 and rearrangements of the anaplastic lymphoma kinase gene',
#   1),
#  ('rted cases described a higher recurrent rate in imt overexpression the anaplastic lymphoma kinase',
#   1),
#  ('s a novel third generation tyrosine kinase inhibitor tki which target anaplastic lymphoma kinase',
#   1),
#  ('s and pemetrexed based treatment efficacy from 170 nsclc patients with anaplastic lymphoma kinase',
#   1),
#  ('s but different in clinical present and prognosis the recognition of anaplastic lymphoma kinase',
#   1),
#  ('s of glial cell derived neurotrophic factor gdnf 55 and neuron anaplastic lymphoma kinase',
#   1),
#  ('s schematic illustrates a possible 2 tier testing strategies for detection anaplastic lymphoma kinase',
#   1),
#  ('s were testing for epidermal growth factor receptor egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('second line therapy after pd had occur on first line chemotherapy anaplastic lymphoma kinase',
#   1),
#  ('sion free survival pfs b with pemetrexed in patients with advanced anaplastic lymphoma kinase',
#   1),
#  ('st common mutations gene like kras epidermal growth factor egfr and anaplastic lymphoma kinase',
#   1),
#  ('study of ldk378 in pediatric malignancies with a genetic alterations in anaplastic lymphoma kinase',
#   1),
#  ('success on treatment with egfr tyrosine kinase inhibitor egfr tkis or anaplastic lymphoma kinase',
#   1),
#  ('such as the epidermal growth factor receptor egfr mutations and the anaplastic lymphoma kinase',
#   1),
#  ('systemic cns and non cns progression in alectinib treated patients with anaplastic lymphoma kinase',
#   1),
#  ('t are not usually observed with cytotoxic chemotherapy for example the anaplastic lymphoma kinase',
#   1),
#  ('t decision after the emerged of resistance in alk dependent disease anaplastic lymphoma kinase',
#   1),
#  ('t soft tissue tumour in children and adolescents aberrant expression of anaplastic lymphoma kinase',
#   1),
#  ('tage lung cancer harboring an epidermal growth factor receptor egfr or anaplastic lymphoma kinase',
#   1),
#  ('tely 5 6 of nsclc cases harboring chromosomal rearrangements involving the anaplastic lymphoma kinase',
#   1),
#  ('tes the involving of the pi3k akt pathways 88 similarly constitutive anaplastic lymphoma kinase',
#   1),
#  ('the current success and challenges of target alk the discovery of anaplastic lymphoma kinase',
#   1),
#  ('the npm alk fusion oncoprotein of anaplastic large cell lymphoma alcl anaplastic lymphoma kinase',
#   1),
#  ('the used of fish testing for alk rearrangements genetic aberrant in anaplastic lymphoma kinase',
#   1),
#  ('tients s salivary gland adenoid cystic carcinoma acc was performed and anaplastic lymphoma kinase',
#   1),
#  ('tion of echinoderm microtubule associated protein like 4 eml4 and the anaplastic lymphoma kinase',
#   1),
#  ('tive 36 the recent development of antibody against the anaplastic large cell lymphoma kinase',
#   1),
#  ('to elicit three growth triggering pathways the first pathways activation the generation of alkaloid',
#   1),
#  ('tor egfr such as gefitinib erlotinib or afatinib and drug target anaplastic lymphoma kinase',
#   1),
#  ('tor receptor egfr hepatocyte growth factor receptor hgfr c met and anaplastic lymphoma kinase',
#   1),
#  ('translocations it is applied here to detection of rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('ttention 6 7 the epidermal growth factor receptor egfr gene and anaplastic lymphoma kinase',
#   1),
#  ('tting we hypothesized that bnp7787 might interaction with and modified human anaplastic lymphoma kinase',
#   1),
#  ('tudied since 2007 when soda et al 1 discovered rearrangements of anaplastic lymphoma kinase',
#   1),
#  ('tumors containing translocations that resulting in the over expression of the anaplastic lymphoma kinase',
#   1),
#  ('ulted in unsatisfactory patients outcome with the exception of low risk anaplastic lymphoma kinase',
#   1),
#  ('uration of following up nsclc harboring a chromosomal rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('used in advanced lung cancer epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   1),
#  ('usions of the echinoderm microtubule associated protein like 4 eml4 to anaplastic lymphoma kinase',
#   1),
#  ('ut sensitive to alk tki brigatinib alunbrig uchibori et al 2017 anaplastic lymphoma kinase',
#   1),
#  ('variants in patients alk6 alk14 and alk16 characteristics of the five anaplastic lymphoma kinase',
#   1),
#  ('ve in the world health organization classification alcl is divided into anaplastic lymphoma kinase',
#   1),
#  ('ve subtype of alcl is defined by different translocations involving the anaplastic lymphoma kinase',
#   1),
#  ('velop new treatment strategies in recent years rearrangements of the anaplastic large cell kinase',
#   1),
#  ('when overactivation in a number of cancer including lung cancer 33 anaplastic lymphoma kinase',
#   1),
#  ('with carboplatin pemetrexed and notably did not received therapy with an anaplastic lymphoma kinase',
#   1),
#  ('with target agents led by epidermal growth factor receptor egfr and anaplastic lymphoma kinase',
#   1),
#  ('wth a distinct pathologic entity characterized by the expression of the anaplastic lymphoma kinase',
#   1),
#  ('wth factor pleiotrophin ptn which bind to it cell surface receptor anaplastic lymphoma kinase',
#   1),
#  ('y for these subset of nsclc patients chromosomal rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('1 day cycle adaptive dose escalations were guided by a bayesian model anaplastic lymphoma kinase',
#   1),
#  ('1 more than half of all alcl cases harboring an nucleophosmin npm anaplastic lymphoma kinase',
#   1),
#  ('1 ros1 which has a kinase domain that is physiologically related to anaplastic lymphoma kinase',
#   1),
#  ('3 to 5 of lung adenocarcinoma patients carry the translocations of the anaplastic lymphoma kinase',
#   1),
#  ('5 resulting in the fusion of the nucleophosmin npm gene and the anaplastic lymphoma kinase',
#   1),
#  ('a number of gene target including various kinase encoding gene 1 the anaplastic lymphoma kinase',
#   1),
#  ('a viral oncogenic homolog b braf were examined by directed sequencing and anaplastic lymphoma kinase',
#   1),
#  ('ack the unique network activation by the fusion of the tyrosine kinase anaplastic lymphoma kinase',
#   1),
#  ('al development of dual alk igf 1r inhibitor genomic alterations in the anaplastic lymphoma kinase',
#   1),
#  ('al first discovered that a translocations could resulting in fusion of the anaplastic lymphoma kinase',
#   1),
#  ('al growth factor receptor egfr gene 4 6 and rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('al growth factor receptor egfr gene mutations 11 5 48 416 had anaplastic lymphoma kinase',
#   1),
#  ('al pfs a and overall survival os b in patients with advanced anaplastic lymphoma kinase',
#   1),
#  ('alk fusion gene may become a potential target for anti alk therapy anaplastic lymphoma kinase',
#   1),
#  ('all cell lung cancer nsclc the phylogenetic proximity of the ros1 and anaplastic lymphoma kinase',
#   1),
#  ('ancer 4 pf 2341066 also has been reported to inhibition the nucleophosmin anaplastic lymphoma kinase',
#   1),
#  ('and indicate that mir503hg is a potential markers in alk negative alcl anaplastic lymphoma kinase',
#   1),
#  ('and plasma cell approximately half of imt have a rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('arch terms used were non small cell lung cancer nsclc cancer tumors anaplastic lymphoma kinase',
#   1),
#  ('arcomas than for tumour expression wild type alk the expression of the anaplastic lymphoma kinase',
#   1),
#  ('are characterized as non small cell lung cancer nsclc cases 2 and anaplastic lymphoma kinase',
#   1),
#  ('arge cell lymphoma alcl represent a subset of lymphoma in which the anaplastic lymphoma kinase',
#   1),
#  ('associated protein like 4 eml4 gene with the signaling portion of the anaplastic lymphoma kinase',
#   1),
#  ('associated with highly mortality as a member of the second generation of anaplastic lymphoma kinase',
#   1),
#  ('atinib are promising most probably due to target of igf1r and src anaplastic lymphoma kinase',
#   1),
#  ('ave specific addressed the role of mdk and ptn signaling through the anaplastic lymphoma kinase',
#   1),
#  ('be very important for the oncogenic activation of eml4 alk methylation of anaplastic lymphoma kinase',
#   1),
#  ('borative testing with ihc or ngs may be beneficial rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('bset of patients with nsclc who may be candidates for target therapy anaplastic lymphoma kinase',
#   1),
#  ('by cancer in north america a decades ago genomic rearrangements in the anaplastic lymphoma kinase',
#   1),
#  ('c subtype of systemic peripheral t cell lymphoma 1 the presence of anaplastic lymphoma kinase',
#   1),
#  ('c target of alk with a particular focus on alk rearrangements nsclc anaplastic lymphoma kinase',
#   1),
#  ('c was recent approved by the us food and drug administration fda anaplastic lymphoma kinase',
#   1),
#  ('cal application of alk inhibitor in patients with nsclc in 1994 the anaplastic lymphoma kinase',
#   1),
#  ('ccess and failure could be of great value for surgeons and pathologist anaplastic lymphoma kinase',
#   1),
#  ('ceptors upon ligand ligation there are seven type i receptor named activin receptor like kinase',
#   1),
#  ('chemistry ihc has been reported as a potential method in screening for anaplastic lymphoma kinase',
#   1),
#  ('chromosomal aberrant t 2 5 p23 q35 resulting in the juxtaposition of anaplastic lymphoma kinase',
#   1),
#  ('d l1 upregulate has been observed in patients with nsclc harboring the anaplastic lymphoma kinase',
#   1),
#  ('d not cause a significant different in overall survival forest plot of anaplastic lymphoma kinase',
#   1),
#  ('d other chemotherapy regimens as a first line treatment in patients with anaplastic lymphoma kinase',
#   1),
#  ('d that suppressor of cytokines signaling 3 socs3 is highly expression in anaplastic lymphoma kinase',
#   1),
#  ('d with early onset and less differentiation carcinoma the fusion of the anaplastic lymphoma kinase',
#   1),
#  ('dolescents carry a reciprocal translocations t 2 5 p23 q35 fused the anaplastic lymphoma kinase',
#   1),
#  ('during crizotinib therapy hr s from vital sign data for patients with anaplastic lymphoma kinase',
#   1),
#  ('e fda approved agents for hnscc the combination of egfr inhibitor with anaplastic lymphoma kinase',
#   1),
#  ('e first ever alk inhibitor for the treatment of alk rearrangements nsclc anaplastic lymphoma kinase',
#   1),
#  ('e hari and the concentra tion of total serum bilirubin tbili sgot sgpt alkaline phosphatase',
#   1),
#  ('e into further clinical improved in the near future the discovery of anaplastic lymphoma kinase',
#   1),
#  ('e mitogenesis in cell that expression the receptor for this growth factor anaplastic lymphoma kinase',
#   1),
#  ('e positive correlated with sox11 n myc twist1 and bcl2 scores the anaplastic lymphoma kinase',
#   1),
#  ('ence or absence of translocations that leading to the ectopic expression of anaplastic lymphoma kinase',
#   1),
#  ('ene driven lung cancer e g egfr progression free survival pfs of anaplastic lymphoma kinase',
#   1),
#  ('ene new molecular target agents prior to their used in clinical trials anaplastic lymphoma kinase',
#   1),
#  ('entified in a variety of solid tumors among these rearrangements of the anaplastic lymphoma kinase',
#   1),
#  ('eralded the era of molecular target therapy in nsclc the discovery of anaplastic lymphoma kinase',
#   1),
#  ('erapies are effective in subset of lung cancer with egfr mutations and anaplastic lymphoma kinase',
#   1),
#  ('eristics diagnosis and treatment of eml4 alk nsclc the fusion of the anaplastic lymphoma kinase',
#   1),
#  ('es can great assist in the interpretation of these tumors table 1 anaplastic lymphoma kinase',
#   1),
#  ('esistant melanoma cell were shown to activation a novel truncated form of anaplastic lymphoma kinase',
#   1),
#  ('esults from the reciprocal translocations t 2 5 p23 q35 involving the anaplastic lymphoma kinase',
#   1),
#  ('et for novel therapy a putative target for various malignancies is the anaplastic lymphoma kinase',
#   1),
#  ('evidence of it drugability as a new molecular target in crc activation anaplastic lymphoma kinase',
#   1),
#  ('f them remain obscure in terms of their biochemistry and native function anaplastic lymphoma kinase',
#   1),
#  ('f this study was to evaluated the relationships between the resistance of anaplastic lymphoma kinase',
#   1),
#  ('gies in patients with treatment failure a novel molecular target is the anaplastic lymphoma kinase',
#   1),
#  ('h limited therapeutic option we provide evidence to support a role for anaplastic lymphoma kinase',
#   1),
#  ('h silence of cdk6 ccne1 and e2f3 gene reduces cell proliferation in anaplastic lymphoma kinase',
#   1),
#  ('h we suggest that the action of palbiciclib is only cdk6 dependent anaplastic lymphoma kinase',
#   1),
#  ('hesized that ethanol engagement mdk and the activation of it receptor the anaplastic lymphoma kinase',
#   1),
#  ('ial nb cases are associated with germline gain of function mutations in anaplastic lymphoma kinase',
#   1),
#  ('idine 3 4 diol and piperidine 3 ol derived pyrrolotriazine inhibitor of anaplastic lymphoma kinase',
#   1),
#  ('ight be used as a novel therapeutic drug for treated pancreatic cancer anaplastic lymphoma kinase',
#   1),
#  ('in and bone matrices 6 7 8 ptn has three known receptor anaplastic lymphoma kinase',
#   1),
#  ('in approximately 5 of nsclc patients an activation fusion protein of the anaplastic lymphoma kinase',
#   1),
#  ('in failure of migration we find that py gsk3 phosphorylation dependent on anaplastic lymphoma kinase',
#   1),
#  ('inferior os in alk + nsclc compared to primary tp53 mutations cases anaplastic lymphoma kinase',
#   1),
#  ('ing mutations in the epidermal growth factor receptor egfr gene or an anaplastic lymphoma kinase',
#   1),
#  ('ing shh pathways molecule may be a potential treatment for bcc patients anaplastic lymphoma kinase',
#   1),
#  ('is divided into two systemic disease according to the expression of the anaplastic lymphoma kinase',
#   1),
#  ...]

# %%
longforms0 = miners['ALK'].get_longforms()

# %%
longforms0
# Out:
# [('anaplastic lymphoma kinase', 948.8728813559322),
#  ('alkaline phosphatase', 6.75),
#  ('kinase gene', 6.428571428571429),
#  ('2p23', 3.2),
#  ('anaplastic lymphomakinase', 2.0),
#  ('receptor', 1.3333333333333333)]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0, 1, 3, 4]]

# %%
top[8]
# Out:
# ('activin receptor like kinase', 20.454545454545453)

# %%
longforms0.extend([x for i, x in enumerate(top) if i in [8]])

# %%
longforms0
# Out:
# [('anaplastic lymphoma kinase', 948.8728813559322),
#  ('alkaline phosphatase', 6.75),
#  ('2p23', 3.2),
#  ('anaplastic lymphomakinase', 2.0),
#  ('activin receptor like kinase', 20.454545454545453)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('anaplastic lymphoma kinase',
#  'activin receptor like kinase',
#  'alkaline phosphatase',
#  '2p23',
#  'anaplastic lymphomakinase')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map

# %%
names

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names.update({f'HGNC:{get_hgnc_id(gene)}': gene for gene in genes})
pos_labels = list(set(pos_labels) | set(f'HGNC:{get_hgnc_id(gene)}' for gene in genes))

# %%
result = (grounding_map, names, pos_labels)

# %%
result

# %%
grounding_map, names, pos_labels = ({'2p23': 'HGNC:427',
  'activin receptor like kinase': 'FPLX:RSTK1',
  'alkaline phosphatase': 'MESH:D000469',
  'anaplastic lymphoma kinase': 'HGNC:427',
  'anaplastic lymphomakinase': 'HGNC:427'},
 {'HGNC:427': 'ALK',
  'MESH:D000469': 'Alkaline Phosphatase',
  'FPLX:RSTK1': 'RSTK1'},
 ['FPLX:RSTK1', 'HGNC:427', 'MESH:D000469'])

# %%
grounding_dict = {'ALK': grounding_map}

# %%
classifier = AdeftClassifier('ALK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-13 09:51:54] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-13 09:52:40] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.974932693929812 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'HGNC:427': 1181,
#   'MESH:D000469': 6,
#   'FPLX:RSTK1': 155},
#  'f1': {'mean': 0.974932693929812, 'std': 0.011692411541541438},
#  'precision': {'mean': 0.9736705272228592, 'std': 0.010918668748222329},
#  'recall': {'mean': 0.9776727473742399, 'std': 0.010176447404917046}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'FPLX:RSTK1']

# %%
len(a)
# Out:
# 53

# %%
a[1]
# Out:
# 'The fully reprogrammed pluripotency can be sorted into ICM-like state (naïve) and post-implantation epiblasts state (primed) 23 . Dissections of each pluripotent state indicated that the naïve state was dependent on JAK/STAT signaling that was activated by LIF, and the primed state was dependent on PI3K/AKT and ALK/SMADs signaling that was activated by b-FGF and transforming growth factor-β1 (TGF-β1)/Activin A. The primed state pluripotency in human and mouse PSCs showed similar gene expression profiles and culture requirements 24 – 26 ; however, the naïve pluripotency was different between the two species, which required different stimulations 24 , 27 – 30 . Unfortunately, both defined states were illusive in pig since none of the above conditions were capable of deriving fully reprogrammed porcine ESCs 31 . The species-related regulatory signaling pathway as reported in mouse and human PSCs is likely to be applied in pig and other animals 32 , in which PI3K/AKT and TGF-beta signaling pathways, instead of LIF and b-FGF signaling pathways, may play key roles in maintaining porcine stem cell pluripotency 33 , 34 . Consequently, a composition of different stimulations may be required for the derivation of porcine PSCs that meet all the criteria of authentic pluripotency.\n'

# %%
disamb.dump('ALK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
