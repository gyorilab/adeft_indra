# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['SAK']
genes = ['PLK4']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['SAK'].top()

# %%
top
# Out:
# [('staphylokinase', 51.8),
#  ('of staphylokinase', 3.6),
#  ('and staphylokinase', 2.5),
#  ('plasminogen activation staphylokinase', 2.0),
#  ('ies selectivity and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#   2),
#  ('e mmp 2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   2),
#  ('activation staphylokinase', 1.5),
#  ('staphylokinsae', 1),
#  ('although staphylokianse', 1.0),
#  ('chips staphylokinase', 1.0),
#  ('historically staphylokinase', 1),
#  ('that staphylokinase', 1.0),
#  ('of recombinant staphylokinase', 1.0),
#  ('bacterial staphylokinase production staphylokinase', 1.0),
#  ('streptokinase sk and staphylokinase', 1.0),
#  ('the plasminogen activation staphylokinase', 1),
#  ('stretch activation k + currents', 1.0),
#  ('we investigated the effect of staphylokinase', 1),
#  ('based bacterial friendly multifunctional recombinant protein srh staphylokinase',
#   1),
#  ('we compared the fibrinolytic properties of recombinant staphylokinase', 1),
#  ('when the extent of plasminogen activation by staphylokinase', 1),
#  ('a gene coding for the bacterial plasminogen activation staphylokinase', 1),
#  ('s aureus strain are included as controls bacterial staphylokinase production staphylokinase',
#   1),
#  ('that form proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#   1),
#  ('37 also occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   1),
#  ('adaptation to human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#   1),
#  ('l complement inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#   1),
#  ('n causing of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#   1),
#  ('o eliminate opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#   1),
#  ('thereby inhibit their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#   1),
#  ('through cleavage of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#   1),
#  ('asma protein plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#   1),
#  ('asminogen activation to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#   1),
#  ('ated dextrans 70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#   1),
#  ('beta or betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#   1),
#  ('g activation and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#   1),
#  ('randomly selectivity out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#   1),
#  ('stretch activation nonselective cation currents sac in contrast stretch activation k + currents',
#   1),
#  ('t activation of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#   1),
#  ('3 in contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#   1),
#  ('e of sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   1),
#  ('ence of excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#   1),
#  ('inding site in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#   1),
#  ('is of the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   1),
#  ('lular matrix and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#   1),
#  ('more potent frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#   1),
#  ('oduce pas that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#   1),
#  ('rmation 3 6 most s aureus strain causing infection in human also produce staphylokinase',
#   1),
#  ('ting phage ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#   1),
#  ('as performed to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#   1),
#  ('ed platelet aggregation from the clot debris in order to minimize these problems a staphylokinase',
#   1),
#  ('ith sak regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#   1),
#  ('um salt hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   1),
#  ('by used site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#   1),
#  ('channels play a major role in mechano electrical feedback since the stretch activation k + currents',
#   1),
#  ('knowledge and belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#   1),
#  ('ll involved in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#   1),
#  ('on of a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#   1),
#  ('vity against the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#   1),
#  ('arinic acid ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#   1),
#  ('o acid was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#   1),
#  ('ak a polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#   1),
#  ('fect b + c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   1),
#  ('currents', 0.0),
#  ('gene', 0.0),
#  ('k', 0.0),
#  ('killer', 0.0),
#  ('kinase', 0.0),
#  ('staphylokianse', 0.0),
#  ('+ currents', 0.0),
#  ('69 staphylokinase', 0.0),
#  ('99 staphylokinase', 0.0),
#  ('a staphylokinase', 0.0),
#  ('acid k', 0.0),
#  ('akin kinase', 0.0),
#  ('augmented killer', 0.0),
#  ('by staphylokinase', 0.0),
#  ('degradation staphylokinase', 0.0),
#  ('introduction staphylokinase', 0.0),
#  ('or staphylokinase', 0.0),
#  ('pa staphylokinase', 0.0),
#  ('produce staphylokinase', 0.0),
#  ('production staphylokinase', 0.0),
#  ('prokaryotic staphylokinase', 0.0),
#  ('recombinant staphylokinase', 0.0),
#  ('response staphylokinase', 0.0),
#  ('sak gene', 0.0),
#  ('sk staphylokinase', 0.0),
#  ('spectrophotometry staphylokinase', 0.0),
#  ('srh staphylokinase', 0.0),
#  ('staphylococcal staphylokinase', 0.0),
#  ('streptococci staphylokinase', 0.0),
#  ('the staphylokinase', 0.0),
#  ('tissue staphylokinase', 0.0),
#  ('truncated staphylokinase', 0.0),
#  ('were staphylokinase', 0.0),
#  ('which staphylokinase', 0.0),
#  ('with staphylokinase', 0.0),
#  ('1 introduction staphylokinase', 0.0),
#  ('3 although staphylokianse', 0.0),
#  ('56 staphylococcal staphylokinase', 0.0),
#  ('a truncated staphylokinase', 0.0),
#  ('activation by staphylokinase', 0.0),
#  ('activation of staphylokinase', 0.0),
#  ('agent 99 staphylokinase', 0.0),
#  ('also produce staphylokinase', 0.0),
#  ('aureus chips staphylokinase', 0.0),
#  ('binding activation staphylokinase', 0.0),
#  ('by which staphylokinase', 0.0),
#  ('containing 69 staphylokinase', 0.0),
#  ('effect of staphylokinase', 0.0),
#  ('for streptococci staphylokinase', 0.0),
#  ('found that staphylokinase', 0.0),
#  ('heart tissue staphylokinase', 0.0),
#  ('immune response staphylokinase', 0.0),
#  ('in the staphylokinase', 0.0),
#  ('incubation with staphylokinase', 0.0),
#  ('investigated were staphylokinase', 0.0),
#  ('k + currents', 0.0),
#  ('mature sak gene', 0.0),
#  ('mutant of staphylokinase', 0.0),
#  ('plasmin and staphylokinase', 0.0),
#  ('plk akin kinase', 0.0),
#  ('problems a staphylokinase', 0.0),
#  ('protein chips staphylokinase', 0.0),
#  ('protein srh staphylokinase', 0.0),
#  ('proteolytic degradation staphylokinase', 0.0),
#  ('prothrombin and staphylokinase', 0.0),
#  ('reported that staphylokinase', 0.0),
#  ('salvianolic acid k', 0.0),
#  ('selectivity of staphylokinase', 0.0),
#  ('sk and staphylokinase', 0.0),
#  ('staphylococcal pa staphylokinase', 0.0),
#  ('staphylokinase production staphylokinase', 0.0),
#  ('streptokinase sk staphylokinase', 0.0),
#  ('superantigen augmented killer', 0.0),
#  ('the prokaryotic staphylokinase', 0.0),
#  ('upa or staphylokinase', 0.0),
#  ('via spectrophotometry staphylokinase', 0.0),
#  ('a plasminogen activation staphylokinase', 0.0),
#  ('activation 1 introduction staphylokinase', 0.0),
#  ('activation containing 69 staphylokinase', 0.0),
#  ('activation k + currents', 0.0),
#  ('after incubation with staphylokinase', 0.0),
#  ('as streptokinase sk staphylokinase', 0.0),
#  ('bacterial plasminogen activation staphylokinase', 0.0),
#  ('by proteolytic degradation staphylokinase', 0.0),
#  ('by upa or staphylokinase', 0.0),
#  ('catalytic activation of staphylokinase', 0.0),
#  ('coli mature sak gene', 0.0),
#  ('concentrations of recombinant staphylokinase', 0.0),
#  ('crevices 56 staphylococcal staphylokinase', 0.0),
#  ('describe for streptococci staphylokinase', 0.0),
#  ('engineered in the staphylokinase', 0.0),
#  ('host prothrombin and staphylokinase', 0.0),
#  ('human also produce staphylokinase', 0.0),
#  ('inhibitory protein chips staphylokinase', 0.0),
#  ('innate immune response staphylokinase', 0.0),
#  ('lysis 3 although staphylokianse', 0.0),
#  ('mechanism by which staphylokinase', 0.0),
#  ('novel mutant of staphylokinase', 0.0),
#  ('of superantigen augmented killer', 0.0),
#  ('of the prokaryotic staphylokinase', 0.0),
#  ('plasminogen activation by staphylokinase', 0.0),
#  ('plasminogen binding activation staphylokinase', 0.0),
#  ('produce salvianolic acid k', 0.0),
#  ('properties of recombinant staphylokinase', 0.0),
#  ('quantified via spectrophotometry staphylokinase', 0.0),
#  ('recombinant protein srh staphylokinase', 0.0),
#  ('s aureus chips staphylokinase', 0.0),
#  ('snk plk akin kinase', 0.0),
#  ('species selectivity of staphylokinase', 0.0),
#  ('the effect of staphylokinase', 0.0),
#  ('the staphylococcal pa staphylokinase', 0.0),
#  ('these problems a staphylokinase', 0.0),
#  ('thrombolytic agent 99 staphylokinase', 0.0),
#  ('thrombolytic investigated were staphylokinase', 0.0),
#  ('to heart tissue staphylokinase', 0.0),
#  ('used a truncated staphylokinase', 0.0),
#  ('we found that staphylokinase', 0.0),
#  ('we reported that staphylokinase', 0.0),
#  ('with plasmin and staphylokinase', 0.0),
#  ('1 bacterial staphylokinase production staphylokinase', 0.0),
#  ('2 the staphylococcal pa staphylokinase', 0.0),
#  ('a mechanism by which staphylokinase', 0.0),
#  ('a novel mutant of staphylokinase', 0.0),
#  ('a species selectivity of staphylokinase', 0.0),
#  ('also produce salvianolic acid k', 0.0),
#  ('as streptokinase sk and staphylokinase', 0.0),
#  ('c by upa or staphylokinase', 0.0),
#  ('chemotaxis inhibitory protein chips staphylokinase', 0.0),
#  ('clot lysis 3 although staphylokianse', 0.0),
#  ('controls bacterial staphylokinase production staphylokinase', 0.0),
#  ('degree of superantigen augmented killer', 0.0),
#  ('e coli mature sak gene', 0.0),
#  ('expression a plasminogen activation staphylokinase', 0.0),
#  ('expression of the prokaryotic staphylokinase', 0.0),
#  ('extract after incubation with staphylokinase', 0.0),
#  ('fibrinolytic properties of recombinant staphylokinase', 0.0),
#  ('flow to heart tissue staphylokinase', 0.0),
#  ('gingival crevices 56 staphylococcal staphylokinase', 0.0),
#  ('hemorrhages we found that staphylokinase', 0.0),
#  ('human innate immune response staphylokinase', 0.0),
#  ('in human also produce staphylokinase', 0.0),
#  ('investigated the effect of staphylokinase', 0.0),
#  ('minimize these problems a staphylokinase', 0.0),
#  ('multifunctional recombinant protein srh staphylokinase', 0.0),
#  ('of activation 1 introduction staphylokinase', 0.0),
#  ('of plasminogen activation by staphylokinase', 0.0),
#  ('of s aureus chips staphylokinase', 0.0),
#  ('pg activation containing 69 staphylokinase', 0.0),
#  ('plasminogen with plasmin and staphylokinase', 0.0),
#  ('predominantly describe for streptococci staphylokinase', 0.0),
#  ('protein streptokinase sk and staphylokinase', 0.0),
#  ('recently we reported that staphylokinase', 0.0),
#  ('such as streptokinase sk staphylokinase', 0.0),
#  ('surface by proteolytic degradation staphylokinase', 0.0),
#  ('target snk plk akin kinase', 0.0),
#  ('the bacterial plasminogen activation staphylokinase', 0.0),
#  ('the catalytic activation of staphylokinase', 0.0),
#  ('the plasminogen binding activation staphylokinase', 0.0),
#  ('the thrombolytic investigated were staphylokinase', 0.0),
#  ('various concentrations of recombinant staphylokinase', 0.0),
#  ('vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('was engineered in the staphylokinase', 0.0),
#  ('was quantified via spectrophotometry staphylokinase', 0.0),
#  ('we used a truncated staphylokinase', 0.0),
#  ('with host prothrombin and staphylokinase', 0.0),
#  ('1 2 the staphylococcal pa staphylokinase', 0.0),
#  ('27 recently we reported that staphylokinase', 0.0),
#  ('and expression a plasminogen activation staphylokinase', 0.0),
#  ('as controls bacterial staphylokinase production staphylokinase', 0.0),
#  ('bacterial surface by proteolytic degradation staphylokinase', 0.0),
#  ('blood flow to heart tissue staphylokinase', 0.0),
#  ('bound protein streptokinase sk and staphylokinase', 0.0),
#  ('by various concentrations of recombinant staphylokinase', 0.0),
#  ('complexes with host prothrombin and staphylokinase', 0.0),
#  ('contrast stretch activation k + currents', 0.0),
#  ('could also produce salvianolic acid k', 0.0),
#  ('describe a mechanism by which staphylokinase', 0.0),
#  ('drug target snk plk akin kinase', 0.0),
#  ('efb c by upa or staphylokinase', 0.0),
#  ('encodes chemotaxis inhibitory protein chips staphylokinase', 0.0),
#  ('extent of plasminogen activation by staphylokinase', 0.0),
#  ('figure 1 bacterial staphylokinase production staphylokinase', 0.0),
#  ('for clot lysis 3 although staphylokianse', 0.0),
#  ('for the bacterial plasminogen activation staphylokinase', 0.0),
#  ('friendly multifunctional recombinant protein srh staphylokinase', 0.0),
#  ('in vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('increased the catalytic activation of staphylokinase', 0.0),
#  ('infection gingival crevices 56 staphylococcal staphylokinase', 0.0),
#  ('infection in human also produce staphylokinase', 0.0),
#  ('major hemorrhages we found that staphylokinase', 0.0),
#  ('motif was engineered in the staphylokinase', 0.0),
#  ('of plasminogen with plasmin and staphylokinase', 0.0),
#  ('phase of activation 1 introduction staphylokinase', 0.0),
#  ('plasma the thrombolytic investigated were staphylokinase', 0.0),
#  ('protein extract after incubation with staphylokinase', 0.0),
#  ('protein of s aureus chips staphylokinase', 0.0),
#  ('release was quantified via spectrophotometry staphylokinase', 0.0),
#  ('sak a novel mutant of staphylokinase', 0.0),
#  ('staphylokinase a species selectivity of staphylokinase', 0.0),
#  ('staphylokinase we used a truncated staphylokinase', 0.0),
#  ('stretegies predominantly describe for streptococci staphylokinase', 0.0),
#  ('subfamilies such as streptokinase sk staphylokinase', 0.0),
#  ('such as streptokinase sk and staphylokinase', 0.0),
#  ('the degree of superantigen augmented killer', 0.0),
#  ('the e coli mature sak gene', 0.0),
#  ('the expression of the prokaryotic staphylokinase', 0.0),
#  ('the fibrinolytic properties of recombinant staphylokinase', 0.0),
#  ('the human innate immune response staphylokinase', 0.0),
#  ('the pg activation containing 69 staphylokinase', 0.0),
#  ('the stretch activation k + currents', 0.0),
#  ('to minimize these problems a staphylokinase', 0.0),
#  ('to the plasminogen binding activation staphylokinase', 0.0),
#  ('26 27 recently we reported that staphylokinase', 0.0),
#  ('activation of plasminogen with plasmin and staphylokinase', 0.0),
#  ('addition to the plasminogen binding activation staphylokinase', 0.0),
#  ('an in vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('and efb c by upa or staphylokinase', 0.0),
#  ('and release was quantified via spectrophotometry staphylokinase', 0.0),
#  ('bacterial friendly multifunctional recombinant protein srh staphylokinase',
#   0.0),
#  ('by staphylokinase we used a truncated staphylokinase', 0.0),
#  ('c3 stretegies predominantly describe for streptococci staphylokinase', 0.0),
#  ('cancer drug target snk plk akin kinase', 0.0),
#  ('causing infection in human also produce staphylokinase', 0.0),
#  ('causing major hemorrhages we found that staphylokinase', 0.0),
#  ('coding for the bacterial plasminogen activation staphylokinase', 0.0),
#  ('compared the fibrinolytic properties of recombinant staphylokinase', 0.0),
#  ('gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   0.0),
#  ('human plasma the thrombolytic investigated were staphylokinase', 0.0),
#  ('in contrast stretch activation k + currents', 0.0),
#  ('in subfamilies such as streptokinase sk staphylokinase', 0.0),
#  ('in the e coli mature sak gene', 0.0),
#  ('included as controls bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('inhibitory protein of s aureus chips staphylokinase', 0.0),
#  ('lag phase of activation 1 introduction staphylokinase', 0.0),
#  ('locus encodes chemotaxis inhibitory protein chips staphylokinase', 0.0),
#  ('model figure 1 bacterial staphylokinase production staphylokinase', 0.0),
#  ('of staphylokinase a species selectivity of staphylokinase', 0.0),
#  ('of the expression of the prokaryotic staphylokinase', 0.0),
#  ('of the human innate immune response staphylokinase', 0.0),
#  ('order to minimize these problems a staphylokinase', 0.0),
#  ('origins such as streptokinase sk and staphylokinase', 0.0),
#  ('plasmin for clot lysis 3 although staphylokianse', 0.0),
#  ('plasminogen by various concentrations of recombinant staphylokinase', 0.0),
#  ('procoagulant complexes with host prothrombin and staphylokinase', 0.0),
#  ('protein the pg activation containing 69 staphylokinase', 0.0),
#  ('raji the degree of superantigen augmented killer', 0.0),
#  ('rgd motif was engineered in the staphylokinase', 0.0),
#  ('rgd sak a novel mutant of staphylokinase', 0.0),
#  ('root could also produce salvianolic acid k', 0.0),
#  ('see 1 2 the staphylococcal pa staphylokinase', 0.0),
#  ('since the stretch activation k + currents', 0.0),
#  ('sk increased the catalytic activation of staphylokinase', 0.0),
#  ('surface and expression a plasminogen activation staphylokinase', 0.0),
#  ('surface bound protein streptokinase sk and staphylokinase', 0.0),
#  ('the bacterial surface by proteolytic degradation staphylokinase', 0.0),
#  ('the blood flow to heart tissue staphylokinase', 0.0),
#  ('the extent of plasminogen activation by staphylokinase', 0.0),
#  ('tissue protein extract after incubation with staphylokinase', 0.0),
#  ('we describe a mechanism by which staphylokinase', 0.0),
#  ('activation by staphylokinase we used a truncated staphylokinase', 0.0),
#  ('activation procoagulant complexes with host prothrombin and staphylokinase',
#   0.0),
#  ('and c3 stretegies predominantly describe for streptococci staphylokinase',
#   0.0),
#  ('and raji the degree of superantigen augmented killer', 0.0),
#  ('appealing cancer drug target snk plk akin kinase', 0.0),
#  ('are included as controls bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('as an in vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('asp rgd motif was engineered in the staphylokinase', 0.0),
#  ('b and efb c by upa or staphylokinase', 0.0),
#  ('bacterial origins such as streptokinase sk and staphylokinase', 0.0),
#  ('chemotaxis inhibitory protein of s aureus chips staphylokinase', 0.0),
#  ('classification in subfamilies such as streptokinase sk staphylokinase',
#   0.0),
#  ('examples of the expression of the prokaryotic staphylokinase', 0.0),
#  ('feedback since the stretch activation k + currents', 0.0),
#  ('from the bacterial surface by proteolytic degradation staphylokinase', 0.0),
#  ('gene coding for the bacterial plasminogen activation staphylokinase', 0.0),
#  ('hairy root could also produce salvianolic acid k', 0.0),
#  ('here we describe a mechanism by which staphylokinase', 0.0),
#  ('iec locus encodes chemotaxis inhibitory protein chips staphylokinase', 0.0),
#  ('in addition to the plasminogen binding activation staphylokinase', 0.0),
#  ('in order to minimize these problems a staphylokinase', 0.0),
#  ('infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('initial lag phase of activation 1 introduction staphylokinase', 0.0),
#  ('its surface and expression a plasminogen activation staphylokinase', 0.0),
#  ('loaded and release was quantified via spectrophotometry staphylokinase',
#   0.0),
#  ('lys plasminogen by various concentrations of recombinant staphylokinase',
#   0.0),
#  ('modulators of the human innate immune response staphylokinase', 0.0),
#  ('obstructing the blood flow to heart tissue staphylokinase', 0.0),
#  ('occasionally causing major hemorrhages we found that staphylokinase', 0.0),
#  ('of rgd sak a novel mutant of staphylokinase', 0.0),
#  ('or human plasma the thrombolytic investigated were staphylokinase', 0.0),
#  ('or surface bound protein streptokinase sk and staphylokinase', 0.0),
#  ('p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   0.0),
#  ('properties 26 27 recently we reported that staphylokinase', 0.0),
#  ('protein in the e coli mature sak gene', 0.0),
#  ('regulatory protein the pg activation containing 69 staphylokinase', 0.0),
#  ('reviews see 1 2 the staphylococcal pa staphylokinase', 0.0),
#  ('sac in contrast stretch activation k + currents', 0.0),
#  ('specificity of staphylokinase a species selectivity of staphylokinase',
#   0.0),
#  ('strain causing infection in human also produce staphylokinase', 0.0),
#  ('streptokinase sk increased the catalytic activation of staphylokinase',
#   0.0),
#  ('subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('the activation of plasminogen with plasmin and staphylokinase', 0.0),
#  ('to plasmin for clot lysis 3 although staphylokianse', 0.0),
#  ('19534 regulatory protein the pg activation containing 69 staphylokinase',
#   0.0),
#  ('2003 in addition to the plasminogen binding activation staphylokinase',
#   0.0),
#  ('30 and raji the degree of superantigen augmented killer', 0.0),
#  ('4 or human plasma the thrombolytic investigated were staphylokinase', 0.0),
#  ('an appealing cancer drug target snk plk akin kinase', 0.0),
#  ('and lys plasminogen by various concentrations of recombinant staphylokinase',
#   0.0),
#  ('and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('aureus strain causing infection in human also produce staphylokinase', 0.0),
#  ('currents sac in contrast stretch activation k + currents', 0.0),
#  ('debris in order to minimize these problems a staphylokinase', 0.0),
#  ('electrical feedback since the stretch activation k + currents', 0.0),
#  ('few examples of the expression of the prokaryotic staphylokinase', 0.0),
#  ('fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#   0.0),
#  ('fibrinolytic properties 26 27 recently we reported that staphylokinase',
#   0.0),
#  ('for reviews see 1 2 the staphylococcal pa staphylokinase', 0.0),
#  ('function as an in vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('fusion protein in the e coli mature sak gene', 0.0),
#  ('gly asp rgd motif was engineered in the staphylokinase', 0.0),
#  ('hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#   0.0),
#  ('igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#   0.0),
#  ('immune here we describe a mechanism by which staphylokinase', 0.0),
#  ('in obstructing the blood flow to heart tissue staphylokinase', 0.0),
#  ('in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   0.0),
#  ('molecules from the bacterial surface by proteolytic degradation staphylokinase',
#   0.0),
#  ('of bacterial origins such as streptokinase sk and staphylokinase', 0.0),
#  ('of streptokinase sk increased the catalytic activation of staphylokinase',
#   0.0),
#  ('on the activation of plasminogen with plasmin and staphylokinase', 0.0),
#  ('plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   0.0),
#  ('plasminogen to plasmin for clot lysis 3 although staphylokianse', 0.0),
#  ('properties of rgd sak a novel mutant of staphylokinase', 0.0),
#  ('proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#   0.0),
#  ('sbi b and efb c by upa or staphylokinase', 0.0),
#  ('scin chemotaxis inhibitory protein of s aureus chips staphylokinase', 0.0),
#  ('secreted or surface bound protein streptokinase sk and staphylokinase',
#   0.0),
#  ('skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('strain are included as controls bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('sub classification in subfamilies such as streptokinase sk staphylokinase',
#   0.0),
#  ('the hairy root could also produce salvianolic acid k', 0.0),
#  ('the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#   0.0),
#  ('the initial lag phase of activation 1 introduction staphylokinase', 0.0),
#  ('the modulators of the human innate immune response staphylokinase', 0.0),
#  ('to its surface and expression a plasminogen activation staphylokinase',
#   0.0),
#  ('were loaded and release was quantified via spectrophotometry staphylokinase',
#   0.0),
#  ('7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   0.0),
#  ('a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('activation of bacterial origins such as streptokinase sk and staphylokinase',
#   0.0),
#  ('al 2003 in addition to the plasminogen binding activation staphylokinase',
#   0.0),
#  ('and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#   0.0),
#  ('arg gly asp rgd motif was engineered in the staphylokinase', 0.0),
#  ('as an appealing cancer drug target snk plk akin kinase', 0.0),
#  ('aureus strain are included as controls bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('cation currents sac in contrast stretch activation k + currents', 0.0),
#  ('clot debris in order to minimize these problems a staphylokinase', 0.0),
#  ('convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#   0.0),
#  ('domains of streptokinase sk increased the catalytic activation of staphylokinase',
#   0.0),
#  ('either secreted or surface bound protein streptokinase sk and staphylokinase',
#   0.0),
#  ('encodes the modulators of the human innate immune response staphylokinase',
#   0.0),
#  ('form proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#   0.0),
#  ('function properties of rgd sak a novel mutant of staphylokinase', 0.0),
#  ('glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#   0.0),
#  ('human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#   0.0),
#  ('inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#   0.0),
#  ('innate immune here we describe a mechanism by which staphylokinase', 0.0),
#  ('kda were loaded and release was quantified via spectrophotometry staphylokinase',
#   0.0),
#  ('mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('mel 30 and raji the degree of superantigen augmented killer', 0.0),
#  ('membranes for reviews see 1 2 the staphylococcal pa staphylokinase', 0.0),
#  ('occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   0.0),
#  ('of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#   0.0),
#  ('of few examples of the expression of the prokaryotic staphylokinase', 0.0),
#  ('of fusion protein in the e coli mature sak gene', 0.0),
#  ('of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#   0.0),
#  ('of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#   0.0),
#  ('of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   0.0),
#  ('opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#   0.0),
#  ('plg to its surface and expression a plasminogen activation staphylokinase',
#   0.0),
#  ('prolonged the initial lag phase of activation 1 introduction staphylokinase',
#   0.0),
#  ('results in obstructing the blood flow to heart tissue staphylokinase', 0.0),
#  ('s aureus strain causing infection in human also produce staphylokinase',
#   0.0),
#  ('sab the hairy root could also produce salvianolic acid k', 0.0),
#  ('skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('structures on the activation of plasminogen with plasmin and staphylokinase',
#   0.0),
#  ('their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#   0.0),
#  ('their sub classification in subfamilies such as streptokinase sk staphylokinase',
#   0.0),
#  ('to function as an in vivo thrombolytic agent 99 staphylokinase', 0.0),
#  ('to sbi b and efb c by upa or staphylokinase', 0.0),
#  ('70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#   0.0),
#  ('ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#   0.0),
#  ('also occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#   0.0),
#  ('an arg gly asp rgd motif was engineered in the staphylokinase', 0.0),
#  ('and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#   0.0),
#  ('are either secreted or surface bound protein streptokinase sk and staphylokinase',
#   0.0),
#  ('b sab the hairy root could also produce salvianolic acid k', 0.0),
#  ('basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#   0.0),
#  ('betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#   0.0),
#  ('bound to sbi b and efb c by upa or staphylokinase', 0.0),
#  ('causing of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#   0.0),
#  ('cleavage of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#   0.0),
#  ('complement inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#   0.0),
#  ('eliminate opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#   0.0),
#  ('et al 2003 in addition to the plasminogen binding activation staphylokinase',
#   0.0),
#  ('expression of fusion protein in the e coli mature sak gene', 0.0),
#  ('in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('in mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('inhibit their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#   0.0),
#  ('kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#   0.0),
#  ('mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   0.0),
#  ('member as an appealing cancer drug target snk plk akin kinase', 0.0),
#  ('most s aureus strain causing infection in human also produce staphylokinase',
#   0.0),
#  ('murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('nonselective cation currents sac in contrast stretch activation k + currents',
#   0.0),
#  ('of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#   0.0),
#  ('of innate immune here we describe a mechanism by which staphylokinase',
#   0.0),
#  ('one of few examples of the expression of the prokaryotic staphylokinase',
#   0.0),
#  ('out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#   0.0),
#  ('pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#   0.0),
#  ('ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   0.0),
#  ('plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#   0.0),
#  ('sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#   0.0),
#  ('selectivity and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#   0.0),
#  ('target mel 30 and raji the degree of superantigen augmented killer', 0.0),
#  ('that results in obstructing the blood flow to heart tissue staphylokinase',
#   0.0),
#  ('the clot debris in order to minimize these problems a staphylokinase', 0.0),
#  ('the function properties of rgd sak a novel mutant of staphylokinase', 0.0),
#  ('to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#   0.0),
#  ('to human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#   0.0),
#  ('which encodes the modulators of the human innate immune response staphylokinase',
#   0.0),
#  ('6 most s aureus strain causing infection in human also produce staphylokinase',
#   0.0),
#  ('acid b sab the hairy root could also produce salvianolic acid k', 0.0),
#  ('activation and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#   0.0),
#  ('activation nonselective cation currents sac in contrast stretch activation k + currents',
#   0.0),
#  ('activation of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#   0.0),
#  ('activation to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#   0.0),
#  ('and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#   0.0),
#  ('buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   0.0),
#  ('characterize the function properties of rgd sak a novel mutant of staphylokinase',
#   0.0),
#  ('clot that results in obstructing the blood flow to heart tissue staphylokinase',
#   0.0),
#  ('contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#   0.0),
#  ('cytosolic expression of fusion protein in the e coli mature sak gene', 0.0),
#  ('dextrans 70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#   0.0),
#  ('evasion of innate immune here we describe a mechanism by which staphylokinase',
#   0.0),
#  ('excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#   0.0),
#  ('family member as an appealing cancer drug target snk plk akin kinase', 0.0),
#  ('frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#   0.0),
#  ('from the clot debris in order to minimize these problems a staphylokinase',
#   0.0),
#  ('in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#   0.0),
#  ('in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('is one of few examples of the expression of the prokaryotic staphylokinase',
#   0.0),
#  ('its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#   0.0),
#  ('mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#   0.0),
#  ('or betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#   0.0),
#  ('plasminogen bound to sbi b and efb c by upa or staphylokinase', 0.0),
#  ('protein plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#   0.0),
#  ('resistant target mel 30 and raji the degree of superantigen augmented killer',
#   0.0),
#  ('role in mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('selectivity out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#   0.0),
#  ('that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#   0.0),
#  ('the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   0.0),
#  ('ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#   0.0),
#  ('2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('3 6 most s aureus strain causing infection in human also produce staphylokinase',
#   0.0),
#  ('aggregation from the clot debris in order to minimize these problems a staphylokinase',
#   0.0),
#  ('directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#   0.0),
#  ('for cytosolic expression of fusion protein in the e coli mature sak gene',
#   0.0),
#  ('hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   0.0),
#  ('in contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#   0.0),
#  ('its is one of few examples of the expression of the prokaryotic staphylokinase',
#   0.0),
#  ('major role in mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('matrix and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#   0.0),
#  ('nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#   0.0),
#  ('of excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#   0.0),
#  ('of plasminogen bound to sbi b and efb c by upa or staphylokinase', 0.0),
#  ('of sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#   0.0),
#  ('of the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#   0.0),
#  ('pas that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#   0.0),
#  ('pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#   0.0),
#  ('phage ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#   0.0),
#  ('plk family member as an appealing cancer drug target snk plk akin kinase',
#   0.0),
#  ('potent frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#   0.0),
#  ('regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#   0.0),
#  ('salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#   0.0),
#  ('site in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#   0.0),
#  ('the evasion of innate immune here we describe a mechanism by which staphylokinase',
#   0.0),
#  ('to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#   0.0),
#  ('a major role in mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#   0.0),
#  ('and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#   0.0),
#  ('belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#   0.0),
#  ('considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#   0.0),
#  ('generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   0.0),
#  ('in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#   0.0),
#  ('kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#   0.0),
#  ('mmp 2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#   0.0),
#  ('performed to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#   0.0),
#  ('platelet aggregation from the clot debris in order to minimize these problems a staphylokinase',
#   0.0),
#  ('sak regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#   0.0),
#  ('salt hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#   0.0),
#  ('site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#   0.0),
#  ('the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#   0.0),
#  ('against the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#   0.0),
#  ('and belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#   0.0),
#  ('involved in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#   0.0),
#  ('like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#   0.0),
#  ('of a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#   0.0),
#  ('plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   0.0),
#  ('play a major role in mechano electrical feedback since the stretch activation k + currents',
#   0.0),
#  ('ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#   0.0),
#  ('used site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#   0.0),
#  ('was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#   0.0),
#  ('acid ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#   0.0),
#  ('acid was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#   0.0),
#  ('c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   0.0),
#  ('polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#   0.0),
#  ('+ c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   0.0),
#  ('a polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#   0.0),
#  ('b + c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#   0.0)]

# %%
longforms0 = miners['SAK'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('staphylokinase', 51.8))]

# %%
longforms0 = [(longform, score) for i, (longform, score) in enumerate(longforms0)
              if i not in [2]]

# %%
list(enumerate(top))
# Out:
# [(0, ('staphylokinase', 51.8)),
#  (1, ('of staphylokinase', 3.6)),
#  (2, ('and staphylokinase', 2.5)),
#  (3, ('plasminogen activation staphylokinase', 2.0)),
#  (4,
#   ('ies selectivity and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#    2)),
#  (5,
#   ('e mmp 2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    2)),
#  (6, ('activation staphylokinase', 1.5)),
#  (7, ('staphylokinsae', 1)),
#  (8, ('although staphylokianse', 1.0)),
#  (9, ('chips staphylokinase', 1.0)),
#  (10, ('historically staphylokinase', 1)),
#  (11, ('that staphylokinase', 1.0)),
#  (12, ('of recombinant staphylokinase', 1.0)),
#  (13, ('bacterial staphylokinase production staphylokinase', 1.0)),
#  (14, ('streptokinase sk and staphylokinase', 1.0)),
#  (15, ('the plasminogen activation staphylokinase', 1)),
#  (16, ('stretch activation k + currents', 1.0)),
#  (17, ('we investigated the effect of staphylokinase', 1)),
#  (18,
#   ('based bacterial friendly multifunctional recombinant protein srh staphylokinase',
#    1)),
#  (19,
#   ('we compared the fibrinolytic properties of recombinant staphylokinase',
#    1)),
#  (20, ('when the extent of plasminogen activation by staphylokinase', 1)),
#  (21,
#   ('a gene coding for the bacterial plasminogen activation staphylokinase',
#    1)),
#  (22,
#   ('s aureus strain are included as controls bacterial staphylokinase production staphylokinase',
#    1)),
#  (23,
#   ('that form proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#    1)),
#  (24,
#   ('37 also occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    1)),
#  (25,
#   ('adaptation to human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#    1)),
#  (26,
#   ('l complement inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#    1)),
#  (27,
#   ('n causing of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#    1)),
#  (28,
#   ('o eliminate opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#    1)),
#  (29,
#   ('thereby inhibit their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#    1)),
#  (30,
#   ('through cleavage of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#    1)),
#  (31,
#   ('asma protein plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#    1)),
#  (32,
#   ('asminogen activation to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#    1)),
#  (33,
#   ('ated dextrans 70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#    1)),
#  (34,
#   ('beta or betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#    1)),
#  (35,
#   ('g activation and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#    1)),
#  (36,
#   ('randomly selectivity out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#    1)),
#  (37,
#   ('stretch activation nonselective cation currents sac in contrast stretch activation k + currents',
#    1)),
#  (38,
#   ('t activation of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#    1)),
#  (39,
#   ('3 in contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#    1)),
#  (40,
#   ('e of sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    1)),
#  (41,
#   ('ence of excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#    1)),
#  (42,
#   ('inding site in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#    1)),
#  (43,
#   ('is of the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    1)),
#  (44,
#   ('lular matrix and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#    1)),
#  (45,
#   ('more potent frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#    1)),
#  (46,
#   ('oduce pas that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#    1)),
#  (47,
#   ('rmation 3 6 most s aureus strain causing infection in human also produce staphylokinase',
#    1)),
#  (48,
#   ('ting phage ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#    1)),
#  (49,
#   ('as performed to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#    1)),
#  (50,
#   ('ed platelet aggregation from the clot debris in order to minimize these problems a staphylokinase',
#    1)),
#  (51,
#   ('ith sak regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#    1)),
#  (52,
#   ('um salt hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    1)),
#  (53,
#   ('by used site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#    1)),
#  (54,
#   ('channels play a major role in mechano electrical feedback since the stretch activation k + currents',
#    1)),
#  (55,
#   ('knowledge and belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#    1)),
#  (56,
#   ('ll involved in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#    1)),
#  (57,
#   ('on of a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#    1)),
#  (58,
#   ('vity against the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#    1)),
#  (59,
#   ('arinic acid ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#    1)),
#  (60,
#   ('o acid was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#    1)),
#  (61,
#   ('ak a polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#    1)),
#  (62,
#   ('fect b + c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    1)),
#  (63, ('currents', 0.0)),
#  (64, ('gene', 0.0)),
#  (65, ('k', 0.0)),
#  (66, ('killer', 0.0)),
#  (67, ('kinase', 0.0)),
#  (68, ('staphylokianse', 0.0)),
#  (69, ('+ currents', 0.0)),
#  (70, ('69 staphylokinase', 0.0)),
#  (71, ('99 staphylokinase', 0.0)),
#  (72, ('a staphylokinase', 0.0)),
#  (73, ('acid k', 0.0)),
#  (74, ('akin kinase', 0.0)),
#  (75, ('augmented killer', 0.0)),
#  (76, ('by staphylokinase', 0.0)),
#  (77, ('degradation staphylokinase', 0.0)),
#  (78, ('introduction staphylokinase', 0.0)),
#  (79, ('or staphylokinase', 0.0)),
#  (80, ('pa staphylokinase', 0.0)),
#  (81, ('produce staphylokinase', 0.0)),
#  (82, ('production staphylokinase', 0.0)),
#  (83, ('prokaryotic staphylokinase', 0.0)),
#  (84, ('recombinant staphylokinase', 0.0)),
#  (85, ('response staphylokinase', 0.0)),
#  (86, ('sak gene', 0.0)),
#  (87, ('sk staphylokinase', 0.0)),
#  (88, ('spectrophotometry staphylokinase', 0.0)),
#  (89, ('srh staphylokinase', 0.0)),
#  (90, ('staphylococcal staphylokinase', 0.0)),
#  (91, ('streptococci staphylokinase', 0.0)),
#  (92, ('the staphylokinase', 0.0)),
#  (93, ('tissue staphylokinase', 0.0)),
#  (94, ('truncated staphylokinase', 0.0)),
#  (95, ('were staphylokinase', 0.0)),
#  (96, ('which staphylokinase', 0.0)),
#  (97, ('with staphylokinase', 0.0)),
#  (98, ('1 introduction staphylokinase', 0.0)),
#  (99, ('3 although staphylokianse', 0.0)),
#  (100, ('56 staphylococcal staphylokinase', 0.0)),
#  (101, ('a truncated staphylokinase', 0.0)),
#  (102, ('activation by staphylokinase', 0.0)),
#  (103, ('activation of staphylokinase', 0.0)),
#  (104, ('agent 99 staphylokinase', 0.0)),
#  (105, ('also produce staphylokinase', 0.0)),
#  (106, ('aureus chips staphylokinase', 0.0)),
#  (107, ('binding activation staphylokinase', 0.0)),
#  (108, ('by which staphylokinase', 0.0)),
#  (109, ('containing 69 staphylokinase', 0.0)),
#  (110, ('effect of staphylokinase', 0.0)),
#  (111, ('for streptococci staphylokinase', 0.0)),
#  (112, ('found that staphylokinase', 0.0)),
#  (113, ('heart tissue staphylokinase', 0.0)),
#  (114, ('immune response staphylokinase', 0.0)),
#  (115, ('in the staphylokinase', 0.0)),
#  (116, ('incubation with staphylokinase', 0.0)),
#  (117, ('investigated were staphylokinase', 0.0)),
#  (118, ('k + currents', 0.0)),
#  (119, ('mature sak gene', 0.0)),
#  (120, ('mutant of staphylokinase', 0.0)),
#  (121, ('plasmin and staphylokinase', 0.0)),
#  (122, ('plk akin kinase', 0.0)),
#  (123, ('problems a staphylokinase', 0.0)),
#  (124, ('protein chips staphylokinase', 0.0)),
#  (125, ('protein srh staphylokinase', 0.0)),
#  (126, ('proteolytic degradation staphylokinase', 0.0)),
#  (127, ('prothrombin and staphylokinase', 0.0)),
#  (128, ('reported that staphylokinase', 0.0)),
#  (129, ('salvianolic acid k', 0.0)),
#  (130, ('selectivity of staphylokinase', 0.0)),
#  (131, ('sk and staphylokinase', 0.0)),
#  (132, ('staphylococcal pa staphylokinase', 0.0)),
#  (133, ('staphylokinase production staphylokinase', 0.0)),
#  (134, ('streptokinase sk staphylokinase', 0.0)),
#  (135, ('superantigen augmented killer', 0.0)),
#  (136, ('the prokaryotic staphylokinase', 0.0)),
#  (137, ('upa or staphylokinase', 0.0)),
#  (138, ('via spectrophotometry staphylokinase', 0.0)),
#  (139, ('a plasminogen activation staphylokinase', 0.0)),
#  (140, ('activation 1 introduction staphylokinase', 0.0)),
#  (141, ('activation containing 69 staphylokinase', 0.0)),
#  (142, ('activation k + currents', 0.0)),
#  (143, ('after incubation with staphylokinase', 0.0)),
#  (144, ('as streptokinase sk staphylokinase', 0.0)),
#  (145, ('bacterial plasminogen activation staphylokinase', 0.0)),
#  (146, ('by proteolytic degradation staphylokinase', 0.0)),
#  (147, ('by upa or staphylokinase', 0.0)),
#  (148, ('catalytic activation of staphylokinase', 0.0)),
#  (149, ('coli mature sak gene', 0.0)),
#  (150, ('concentrations of recombinant staphylokinase', 0.0)),
#  (151, ('crevices 56 staphylococcal staphylokinase', 0.0)),
#  (152, ('describe for streptococci staphylokinase', 0.0)),
#  (153, ('engineered in the staphylokinase', 0.0)),
#  (154, ('host prothrombin and staphylokinase', 0.0)),
#  (155, ('human also produce staphylokinase', 0.0)),
#  (156, ('inhibitory protein chips staphylokinase', 0.0)),
#  (157, ('innate immune response staphylokinase', 0.0)),
#  (158, ('lysis 3 although staphylokianse', 0.0)),
#  (159, ('mechanism by which staphylokinase', 0.0)),
#  (160, ('novel mutant of staphylokinase', 0.0)),
#  (161, ('of superantigen augmented killer', 0.0)),
#  (162, ('of the prokaryotic staphylokinase', 0.0)),
#  (163, ('plasminogen activation by staphylokinase', 0.0)),
#  (164, ('plasminogen binding activation staphylokinase', 0.0)),
#  (165, ('produce salvianolic acid k', 0.0)),
#  (166, ('properties of recombinant staphylokinase', 0.0)),
#  (167, ('quantified via spectrophotometry staphylokinase', 0.0)),
#  (168, ('recombinant protein srh staphylokinase', 0.0)),
#  (169, ('s aureus chips staphylokinase', 0.0)),
#  (170, ('snk plk akin kinase', 0.0)),
#  (171, ('species selectivity of staphylokinase', 0.0)),
#  (172, ('the effect of staphylokinase', 0.0)),
#  (173, ('the staphylococcal pa staphylokinase', 0.0)),
#  (174, ('these problems a staphylokinase', 0.0)),
#  (175, ('thrombolytic agent 99 staphylokinase', 0.0)),
#  (176, ('thrombolytic investigated were staphylokinase', 0.0)),
#  (177, ('to heart tissue staphylokinase', 0.0)),
#  (178, ('used a truncated staphylokinase', 0.0)),
#  (179, ('we found that staphylokinase', 0.0)),
#  (180, ('we reported that staphylokinase', 0.0)),
#  (181, ('with plasmin and staphylokinase', 0.0)),
#  (182, ('1 bacterial staphylokinase production staphylokinase', 0.0)),
#  (183, ('2 the staphylococcal pa staphylokinase', 0.0)),
#  (184, ('a mechanism by which staphylokinase', 0.0)),
#  (185, ('a novel mutant of staphylokinase', 0.0)),
#  (186, ('a species selectivity of staphylokinase', 0.0)),
#  (187, ('also produce salvianolic acid k', 0.0)),
#  (188, ('as streptokinase sk and staphylokinase', 0.0)),
#  (189, ('c by upa or staphylokinase', 0.0)),
#  (190, ('chemotaxis inhibitory protein chips staphylokinase', 0.0)),
#  (191, ('clot lysis 3 although staphylokianse', 0.0)),
#  (192, ('controls bacterial staphylokinase production staphylokinase', 0.0)),
#  (193, ('degree of superantigen augmented killer', 0.0)),
#  (194, ('e coli mature sak gene', 0.0)),
#  (195, ('expression a plasminogen activation staphylokinase', 0.0)),
#  (196, ('expression of the prokaryotic staphylokinase', 0.0)),
#  (197, ('extract after incubation with staphylokinase', 0.0)),
#  (198, ('fibrinolytic properties of recombinant staphylokinase', 0.0)),
#  (199, ('flow to heart tissue staphylokinase', 0.0)),
#  (200, ('gingival crevices 56 staphylococcal staphylokinase', 0.0)),
#  (201, ('hemorrhages we found that staphylokinase', 0.0)),
#  (202, ('human innate immune response staphylokinase', 0.0)),
#  (203, ('in human also produce staphylokinase', 0.0)),
#  (204, ('investigated the effect of staphylokinase', 0.0)),
#  (205, ('minimize these problems a staphylokinase', 0.0)),
#  (206, ('multifunctional recombinant protein srh staphylokinase', 0.0)),
#  (207, ('of activation 1 introduction staphylokinase', 0.0)),
#  (208, ('of plasminogen activation by staphylokinase', 0.0)),
#  (209, ('of s aureus chips staphylokinase', 0.0)),
#  (210, ('pg activation containing 69 staphylokinase', 0.0)),
#  (211, ('plasminogen with plasmin and staphylokinase', 0.0)),
#  (212, ('predominantly describe for streptococci staphylokinase', 0.0)),
#  (213, ('protein streptokinase sk and staphylokinase', 0.0)),
#  (214, ('recently we reported that staphylokinase', 0.0)),
#  (215, ('such as streptokinase sk staphylokinase', 0.0)),
#  (216, ('surface by proteolytic degradation staphylokinase', 0.0)),
#  (217, ('target snk plk akin kinase', 0.0)),
#  (218, ('the bacterial plasminogen activation staphylokinase', 0.0)),
#  (219, ('the catalytic activation of staphylokinase', 0.0)),
#  (220, ('the plasminogen binding activation staphylokinase', 0.0)),
#  (221, ('the thrombolytic investigated were staphylokinase', 0.0)),
#  (222, ('various concentrations of recombinant staphylokinase', 0.0)),
#  (223, ('vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (224, ('was engineered in the staphylokinase', 0.0)),
#  (225, ('was quantified via spectrophotometry staphylokinase', 0.0)),
#  (226, ('we used a truncated staphylokinase', 0.0)),
#  (227, ('with host prothrombin and staphylokinase', 0.0)),
#  (228, ('1 2 the staphylococcal pa staphylokinase', 0.0)),
#  (229, ('27 recently we reported that staphylokinase', 0.0)),
#  (230, ('and expression a plasminogen activation staphylokinase', 0.0)),
#  (231,
#   ('as controls bacterial staphylokinase production staphylokinase', 0.0)),
#  (232, ('bacterial surface by proteolytic degradation staphylokinase', 0.0)),
#  (233, ('blood flow to heart tissue staphylokinase', 0.0)),
#  (234, ('bound protein streptokinase sk and staphylokinase', 0.0)),
#  (235, ('by various concentrations of recombinant staphylokinase', 0.0)),
#  (236, ('complexes with host prothrombin and staphylokinase', 0.0)),
#  (237, ('contrast stretch activation k + currents', 0.0)),
#  (238, ('could also produce salvianolic acid k', 0.0)),
#  (239, ('describe a mechanism by which staphylokinase', 0.0)),
#  (240, ('drug target snk plk akin kinase', 0.0)),
#  (241, ('efb c by upa or staphylokinase', 0.0)),
#  (242, ('encodes chemotaxis inhibitory protein chips staphylokinase', 0.0)),
#  (243, ('extent of plasminogen activation by staphylokinase', 0.0)),
#  (244, ('figure 1 bacterial staphylokinase production staphylokinase', 0.0)),
#  (245, ('for clot lysis 3 although staphylokianse', 0.0)),
#  (246, ('for the bacterial plasminogen activation staphylokinase', 0.0)),
#  (247,
#   ('friendly multifunctional recombinant protein srh staphylokinase', 0.0)),
#  (248, ('in vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (249, ('increased the catalytic activation of staphylokinase', 0.0)),
#  (250, ('infection gingival crevices 56 staphylococcal staphylokinase', 0.0)),
#  (251, ('infection in human also produce staphylokinase', 0.0)),
#  (252, ('major hemorrhages we found that staphylokinase', 0.0)),
#  (253, ('motif was engineered in the staphylokinase', 0.0)),
#  (254, ('of plasminogen with plasmin and staphylokinase', 0.0)),
#  (255, ('phase of activation 1 introduction staphylokinase', 0.0)),
#  (256, ('plasma the thrombolytic investigated were staphylokinase', 0.0)),
#  (257, ('protein extract after incubation with staphylokinase', 0.0)),
#  (258, ('protein of s aureus chips staphylokinase', 0.0)),
#  (259, ('release was quantified via spectrophotometry staphylokinase', 0.0)),
#  (260, ('sak a novel mutant of staphylokinase', 0.0)),
#  (261, ('staphylokinase a species selectivity of staphylokinase', 0.0)),
#  (262, ('staphylokinase we used a truncated staphylokinase', 0.0)),
#  (263,
#   ('stretegies predominantly describe for streptococci staphylokinase', 0.0)),
#  (264, ('subfamilies such as streptokinase sk staphylokinase', 0.0)),
#  (265, ('such as streptokinase sk and staphylokinase', 0.0)),
#  (266, ('the degree of superantigen augmented killer', 0.0)),
#  (267, ('the e coli mature sak gene', 0.0)),
#  (268, ('the expression of the prokaryotic staphylokinase', 0.0)),
#  (269, ('the fibrinolytic properties of recombinant staphylokinase', 0.0)),
#  (270, ('the human innate immune response staphylokinase', 0.0)),
#  (271, ('the pg activation containing 69 staphylokinase', 0.0)),
#  (272, ('the stretch activation k + currents', 0.0)),
#  (273, ('to minimize these problems a staphylokinase', 0.0)),
#  (274, ('to the plasminogen binding activation staphylokinase', 0.0)),
#  (275, ('26 27 recently we reported that staphylokinase', 0.0)),
#  (276, ('activation of plasminogen with plasmin and staphylokinase', 0.0)),
#  (277, ('addition to the plasminogen binding activation staphylokinase', 0.0)),
#  (278, ('an in vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (279, ('and efb c by upa or staphylokinase', 0.0)),
#  (280,
#   ('and release was quantified via spectrophotometry staphylokinase', 0.0)),
#  (281,
#   ('bacterial friendly multifunctional recombinant protein srh staphylokinase',
#    0.0)),
#  (282, ('by staphylokinase we used a truncated staphylokinase', 0.0)),
#  (283,
#   ('c3 stretegies predominantly describe for streptococci staphylokinase',
#    0.0)),
#  (284, ('cancer drug target snk plk akin kinase', 0.0)),
#  (285, ('causing infection in human also produce staphylokinase', 0.0)),
#  (286, ('causing major hemorrhages we found that staphylokinase', 0.0)),
#  (287,
#   ('coding for the bacterial plasminogen activation staphylokinase', 0.0)),
#  (288,
#   ('compared the fibrinolytic properties of recombinant staphylokinase', 0.0)),
#  (289,
#   ('gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    0.0)),
#  (290,
#   ('human plasma the thrombolytic investigated were staphylokinase', 0.0)),
#  (291, ('in contrast stretch activation k + currents', 0.0)),
#  (292, ('in subfamilies such as streptokinase sk staphylokinase', 0.0)),
#  (293, ('in the e coli mature sak gene', 0.0)),
#  (294,
#   ('included as controls bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (295, ('inhibitory protein of s aureus chips staphylokinase', 0.0)),
#  (296, ('lag phase of activation 1 introduction staphylokinase', 0.0)),
#  (297,
#   ('locus encodes chemotaxis inhibitory protein chips staphylokinase', 0.0)),
#  (298,
#   ('model figure 1 bacterial staphylokinase production staphylokinase', 0.0)),
#  (299, ('of staphylokinase a species selectivity of staphylokinase', 0.0)),
#  (300, ('of the expression of the prokaryotic staphylokinase', 0.0)),
#  (301, ('of the human innate immune response staphylokinase', 0.0)),
#  (302, ('order to minimize these problems a staphylokinase', 0.0)),
#  (303, ('origins such as streptokinase sk and staphylokinase', 0.0)),
#  (304, ('plasmin for clot lysis 3 although staphylokianse', 0.0)),
#  (305,
#   ('plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (306,
#   ('procoagulant complexes with host prothrombin and staphylokinase', 0.0)),
#  (307, ('protein the pg activation containing 69 staphylokinase', 0.0)),
#  (308, ('raji the degree of superantigen augmented killer', 0.0)),
#  (309, ('rgd motif was engineered in the staphylokinase', 0.0)),
#  (310, ('rgd sak a novel mutant of staphylokinase', 0.0)),
#  (311, ('root could also produce salvianolic acid k', 0.0)),
#  (312, ('see 1 2 the staphylococcal pa staphylokinase', 0.0)),
#  (313, ('since the stretch activation k + currents', 0.0)),
#  (314, ('sk increased the catalytic activation of staphylokinase', 0.0)),
#  (315,
#   ('surface and expression a plasminogen activation staphylokinase', 0.0)),
#  (316, ('surface bound protein streptokinase sk and staphylokinase', 0.0)),
#  (317,
#   ('the bacterial surface by proteolytic degradation staphylokinase', 0.0)),
#  (318, ('the blood flow to heart tissue staphylokinase', 0.0)),
#  (319, ('the extent of plasminogen activation by staphylokinase', 0.0)),
#  (320, ('tissue protein extract after incubation with staphylokinase', 0.0)),
#  (321, ('we describe a mechanism by which staphylokinase', 0.0)),
#  (322,
#   ('activation by staphylokinase we used a truncated staphylokinase', 0.0)),
#  (323,
#   ('activation procoagulant complexes with host prothrombin and staphylokinase',
#    0.0)),
#  (324,
#   ('and c3 stretegies predominantly describe for streptococci staphylokinase',
#    0.0)),
#  (325, ('and raji the degree of superantigen augmented killer', 0.0)),
#  (326, ('appealing cancer drug target snk plk akin kinase', 0.0)),
#  (327,
#   ('are included as controls bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (328, ('as an in vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (329, ('asp rgd motif was engineered in the staphylokinase', 0.0)),
#  (330, ('b and efb c by upa or staphylokinase', 0.0)),
#  (331, ('bacterial origins such as streptokinase sk and staphylokinase', 0.0)),
#  (332,
#   ('chemotaxis inhibitory protein of s aureus chips staphylokinase', 0.0)),
#  (333,
#   ('classification in subfamilies such as streptokinase sk staphylokinase',
#    0.0)),
#  (334, ('examples of the expression of the prokaryotic staphylokinase', 0.0)),
#  (335, ('feedback since the stretch activation k + currents', 0.0)),
#  (336,
#   ('from the bacterial surface by proteolytic degradation staphylokinase',
#    0.0)),
#  (337,
#   ('gene coding for the bacterial plasminogen activation staphylokinase',
#    0.0)),
#  (338, ('hairy root could also produce salvianolic acid k', 0.0)),
#  (339, ('here we describe a mechanism by which staphylokinase', 0.0)),
#  (340,
#   ('iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#    0.0)),
#  (341,
#   ('in addition to the plasminogen binding activation staphylokinase', 0.0)),
#  (342, ('in order to minimize these problems a staphylokinase', 0.0)),
#  (343,
#   ('infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (344, ('initial lag phase of activation 1 introduction staphylokinase', 0.0)),
#  (345,
#   ('its surface and expression a plasminogen activation staphylokinase', 0.0)),
#  (346,
#   ('loaded and release was quantified via spectrophotometry staphylokinase',
#    0.0)),
#  (347,
#   ('lys plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (348, ('modulators of the human innate immune response staphylokinase', 0.0)),
#  (349, ('obstructing the blood flow to heart tissue staphylokinase', 0.0)),
#  (350,
#   ('occasionally causing major hemorrhages we found that staphylokinase',
#    0.0)),
#  (351, ('of rgd sak a novel mutant of staphylokinase', 0.0)),
#  (352,
#   ('or human plasma the thrombolytic investigated were staphylokinase', 0.0)),
#  (353, ('or surface bound protein streptokinase sk and staphylokinase', 0.0)),
#  (354,
#   ('p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    0.0)),
#  (355, ('properties 26 27 recently we reported that staphylokinase', 0.0)),
#  (356, ('protein in the e coli mature sak gene', 0.0)),
#  (357,
#   ('regulatory protein the pg activation containing 69 staphylokinase', 0.0)),
#  (358, ('reviews see 1 2 the staphylococcal pa staphylokinase', 0.0)),
#  (359, ('sac in contrast stretch activation k + currents', 0.0)),
#  (360,
#   ('specificity of staphylokinase a species selectivity of staphylokinase',
#    0.0)),
#  (361, ('strain causing infection in human also produce staphylokinase', 0.0)),
#  (362,
#   ('streptokinase sk increased the catalytic activation of staphylokinase',
#    0.0)),
#  (363,
#   ('subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (364, ('the activation of plasminogen with plasmin and staphylokinase', 0.0)),
#  (365, ('to plasmin for clot lysis 3 although staphylokianse', 0.0)),
#  (366,
#   ('19534 regulatory protein the pg activation containing 69 staphylokinase',
#    0.0)),
#  (367,
#   ('2003 in addition to the plasminogen binding activation staphylokinase',
#    0.0)),
#  (368, ('30 and raji the degree of superantigen augmented killer', 0.0)),
#  (369,
#   ('4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (370, ('an appealing cancer drug target snk plk akin kinase', 0.0)),
#  (371,
#   ('and lys plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (372,
#   ('and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (373,
#   ('aureus strain causing infection in human also produce staphylokinase',
#    0.0)),
#  (374, ('currents sac in contrast stretch activation k + currents', 0.0)),
#  (375, ('debris in order to minimize these problems a staphylokinase', 0.0)),
#  (376, ('electrical feedback since the stretch activation k + currents', 0.0)),
#  (377,
#   ('few examples of the expression of the prokaryotic staphylokinase', 0.0)),
#  (378,
#   ('fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#    0.0)),
#  (379,
#   ('fibrinolytic properties 26 27 recently we reported that staphylokinase',
#    0.0)),
#  (380, ('for reviews see 1 2 the staphylococcal pa staphylokinase', 0.0)),
#  (381, ('function as an in vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (382, ('fusion protein in the e coli mature sak gene', 0.0)),
#  (383, ('gly asp rgd motif was engineered in the staphylokinase', 0.0)),
#  (384,
#   ('hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#    0.0)),
#  (385,
#   ('igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#    0.0)),
#  (386, ('immune here we describe a mechanism by which staphylokinase', 0.0)),
#  (387, ('in obstructing the blood flow to heart tissue staphylokinase', 0.0)),
#  (388,
#   ('in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    0.0)),
#  (389,
#   ('molecules from the bacterial surface by proteolytic degradation staphylokinase',
#    0.0)),
#  (390,
#   ('of bacterial origins such as streptokinase sk and staphylokinase', 0.0)),
#  (391,
#   ('of streptokinase sk increased the catalytic activation of staphylokinase',
#    0.0)),
#  (392,
#   ('on the activation of plasminogen with plasmin and staphylokinase', 0.0)),
#  (393,
#   ('plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    0.0)),
#  (394,
#   ('plasminogen to plasmin for clot lysis 3 although staphylokianse', 0.0)),
#  (395, ('properties of rgd sak a novel mutant of staphylokinase', 0.0)),
#  (396,
#   ('proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#    0.0)),
#  (397, ('sbi b and efb c by upa or staphylokinase', 0.0)),
#  (398,
#   ('scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#    0.0)),
#  (399,
#   ('secreted or surface bound protein streptokinase sk and staphylokinase',
#    0.0)),
#  (400,
#   ('skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (401,
#   ('strain are included as controls bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (402,
#   ('sub classification in subfamilies such as streptokinase sk staphylokinase',
#    0.0)),
#  (403, ('the hairy root could also produce salvianolic acid k', 0.0)),
#  (404,
#   ('the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#    0.0)),
#  (405,
#   ('the initial lag phase of activation 1 introduction staphylokinase', 0.0)),
#  (406,
#   ('the modulators of the human innate immune response staphylokinase', 0.0)),
#  (407,
#   ('to its surface and expression a plasminogen activation staphylokinase',
#    0.0)),
#  (408,
#   ('were loaded and release was quantified via spectrophotometry staphylokinase',
#    0.0)),
#  (409,
#   ('7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (410,
#   ('a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (411,
#   ('activation of bacterial origins such as streptokinase sk and staphylokinase',
#    0.0)),
#  (412,
#   ('al 2003 in addition to the plasminogen binding activation staphylokinase',
#    0.0)),
#  (413,
#   ('and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#    0.0)),
#  (414, ('arg gly asp rgd motif was engineered in the staphylokinase', 0.0)),
#  (415, ('as an appealing cancer drug target snk plk akin kinase', 0.0)),
#  (416,
#   ('aureus strain are included as controls bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (417,
#   ('cation currents sac in contrast stretch activation k + currents', 0.0)),
#  (418,
#   ('clot debris in order to minimize these problems a staphylokinase', 0.0)),
#  (419,
#   ('convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#    0.0)),
#  (420,
#   ('domains of streptokinase sk increased the catalytic activation of staphylokinase',
#    0.0)),
#  (421,
#   ('either secreted or surface bound protein streptokinase sk and staphylokinase',
#    0.0)),
#  (422,
#   ('encodes the modulators of the human innate immune response staphylokinase',
#    0.0)),
#  (423,
#   ('form proteolytic activation procoagulant complexes with host prothrombin and staphylokinase',
#    0.0)),
#  (424,
#   ('function properties of rgd sak a novel mutant of staphylokinase', 0.0)),
#  (425,
#   ('glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (426,
#   ('human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#    0.0)),
#  (427,
#   ('inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#    0.0)),
#  (428,
#   ('innate immune here we describe a mechanism by which staphylokinase', 0.0)),
#  (429,
#   ('kda were loaded and release was quantified via spectrophotometry staphylokinase',
#    0.0)),
#  (430,
#   ('mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (431, ('mel 30 and raji the degree of superantigen augmented killer', 0.0)),
#  (432,
#   ('membranes for reviews see 1 2 the staphylococcal pa staphylokinase', 0.0)),
#  (433,
#   ('occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    0.0)),
#  (434,
#   ('of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#    0.0)),
#  (435,
#   ('of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (436, ('of fusion protein in the e coli mature sak gene', 0.0)),
#  (437,
#   ('of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#    0.0)),
#  (438,
#   ('of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#    0.0)),
#  (439,
#   ('of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    0.0)),
#  (440,
#   ('opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#    0.0)),
#  (441,
#   ('plg to its surface and expression a plasminogen activation staphylokinase',
#    0.0)),
#  (442,
#   ('prolonged the initial lag phase of activation 1 introduction staphylokinase',
#    0.0)),
#  (443,
#   ('results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (444,
#   ('s aureus strain causing infection in human also produce staphylokinase',
#    0.0)),
#  (445, ('sab the hairy root could also produce salvianolic acid k', 0.0)),
#  (446,
#   ('skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (447,
#   ('structures on the activation of plasminogen with plasmin and staphylokinase',
#    0.0)),
#  (448,
#   ('their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#    0.0)),
#  (449,
#   ('their sub classification in subfamilies such as streptokinase sk staphylokinase',
#    0.0)),
#  (450,
#   ('to function as an in vivo thrombolytic agent 99 staphylokinase', 0.0)),
#  (451, ('to sbi b and efb c by upa or staphylokinase', 0.0)),
#  (452,
#   ('70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#    0.0)),
#  (453,
#   ('ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#    0.0)),
#  (454,
#   ('also occurs in p gingivalis infection gingival crevices 56 staphylococcal staphylokinase',
#    0.0)),
#  (455, ('an arg gly asp rgd motif was engineered in the staphylokinase', 0.0)),
#  (456,
#   ('and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#    0.0)),
#  (457,
#   ('are either secreted or surface bound protein streptokinase sk and staphylokinase',
#    0.0)),
#  (458, ('b sab the hairy root could also produce salvianolic acid k', 0.0)),
#  (459,
#   ('basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#    0.0)),
#  (460,
#   ('betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#    0.0)),
#  (461, ('bound to sbi b and efb c by upa or staphylokinase', 0.0)),
#  (462,
#   ('causing of hyperfibrinolysis occasionally causing major hemorrhages we found that staphylokinase',
#    0.0)),
#  (463,
#   ('cleavage of igg and c3 stretegies predominantly describe for streptococci staphylokinase',
#    0.0)),
#  (464,
#   ('complement inhibitor scin chemotaxis inhibitory protein of s aureus chips staphylokinase',
#    0.0)),
#  (465,
#   ('eliminate opsonic molecules from the bacterial surface by proteolytic degradation staphylokinase',
#    0.0)),
#  (466,
#   ('et al 2003 in addition to the plasminogen binding activation staphylokinase',
#    0.0)),
#  (467, ('expression of fusion protein in the e coli mature sak gene', 0.0)),
#  (468,
#   ('in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (469,
#   ('in mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (470,
#   ('inhibit their fibrinolytic properties 26 27 recently we reported that staphylokinase',
#    0.0)),
#  (471,
#   ('kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#    0.0)),
#  (472,
#   ('mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    0.0)),
#  (473, ('member as an appealing cancer drug target snk plk akin kinase', 0.0)),
#  (474,
#   ('most s aureus strain causing infection in human also produce staphylokinase',
#    0.0)),
#  (475,
#   ('murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (476,
#   ('nonselective cation currents sac in contrast stretch activation k + currents',
#    0.0)),
#  (477,
#   ('of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (478,
#   ('of innate immune here we describe a mechanism by which staphylokinase',
#    0.0)),
#  (479,
#   ('one of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (480,
#   ('out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#    0.0)),
#  (481,
#   ('pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#    0.0)),
#  (482,
#   ('ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (483,
#   ('plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#    0.0)),
#  (484,
#   ('sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#    0.0)),
#  (485,
#   ('selectivity and fibrin specificity of staphylokinase a species selectivity of staphylokinase',
#    0.0)),
#  (486,
#   ('target mel 30 and raji the degree of superantigen augmented killer', 0.0)),
#  (487,
#   ('that results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (488,
#   ('the clot debris in order to minimize these problems a staphylokinase',
#    0.0)),
#  (489,
#   ('the function properties of rgd sak a novel mutant of staphylokinase',
#    0.0)),
#  (490,
#   ('to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#    0.0)),
#  (491,
#   ('to human the iec locus encodes chemotaxis inhibitory protein chips staphylokinase',
#    0.0)),
#  (492,
#   ('which encodes the modulators of the human innate immune response staphylokinase',
#    0.0)),
#  (493,
#   ('6 most s aureus strain causing infection in human also produce staphylokinase',
#    0.0)),
#  (494,
#   ('acid b sab the hairy root could also produce salvianolic acid k', 0.0)),
#  (495,
#   ('activation and their sub classification in subfamilies such as streptokinase sk staphylokinase',
#    0.0)),
#  (496,
#   ('activation nonselective cation currents sac in contrast stretch activation k + currents',
#    0.0)),
#  (497,
#   ('activation of glu and lys plasminogen by various concentrations of recombinant staphylokinase',
#    0.0)),
#  (498,
#   ('activation to convert plasminogen to plasmin for clot lysis 3 although staphylokianse',
#    0.0)),
#  (499,
#   ('and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#    0.0)),
#  (500,
#   ('buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (501,
#   ('characterize the function properties of rgd sak a novel mutant of staphylokinase',
#    0.0)),
#  (502,
#   ('clot that results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (503,
#   ('contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#    0.0)),
#  (504,
#   ('cytosolic expression of fusion protein in the e coli mature sak gene',
#    0.0)),
#  (505,
#   ('dextrans 70 kda were loaded and release was quantified via spectrophotometry staphylokinase',
#    0.0)),
#  (506,
#   ('evasion of innate immune here we describe a mechanism by which staphylokinase',
#    0.0)),
#  (507,
#   ('excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#    0.0)),
#  (508,
#   ('family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (509,
#   ('frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#    0.0)),
#  (510,
#   ('from the clot debris in order to minimize these problems a staphylokinase',
#    0.0)),
#  (511,
#   ('in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#    0.0)),
#  (512,
#   ('in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (513,
#   ('is one of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (514,
#   ('its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#    0.0)),
#  (515,
#   ('mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#    0.0)),
#  (516,
#   ('or betagamma domains of streptokinase sk increased the catalytic activation of staphylokinase',
#    0.0)),
#  (517, ('plasminogen bound to sbi b and efb c by upa or staphylokinase', 0.0)),
#  (518,
#   ('protein plasminogen plg to its surface and expression a plasminogen activation staphylokinase',
#    0.0)),
#  (519,
#   ('resistant target mel 30 and raji the degree of superantigen augmented killer',
#    0.0)),
#  (520,
#   ('role in mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (521,
#   ('sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (522,
#   ('selectivity out of 19534 regulatory protein the pg activation containing 69 staphylokinase',
#    0.0)),
#  (523,
#   ('that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#    0.0)),
#  (524,
#   ('the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    0.0)),
#  (525,
#   ('ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#    0.0)),
#  (526,
#   ('2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (527,
#   ('3 6 most s aureus strain causing infection in human also produce staphylokinase',
#    0.0)),
#  (528,
#   ('aggregation from the clot debris in order to minimize these problems a staphylokinase',
#    0.0)),
#  (529,
#   ('directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#    0.0)),
#  (530,
#   ('for cytosolic expression of fusion protein in the e coli mature sak gene',
#    0.0)),
#  (531,
#   ('hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (532,
#   ('in contrast pg activation of bacterial origins such as streptokinase sk and staphylokinase',
#    0.0)),
#  (533,
#   ('its is one of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (534,
#   ('major role in mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (535,
#   ('matrix and basement membranes for reviews see 1 2 the staphylococcal pa staphylokinase',
#    0.0)),
#  (536,
#   ('nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#    0.0)),
#  (537,
#   ('of excess sak prolonged the initial lag phase of activation 1 introduction staphylokinase',
#    0.0)),
#  (538,
#   ('of plasminogen bound to sbi b and efb c by upa or staphylokinase', 0.0)),
#  (539,
#   ('of sak in a skin infection model figure 1 bacterial staphylokinase production staphylokinase',
#    0.0)),
#  (540,
#   ('of the mechanism of plasminogen activation by staphylokinase we used a truncated staphylokinase',
#    0.0)),
#  (541,
#   ('pas that are either secreted or surface bound protein streptokinase sk and staphylokinase',
#    0.0)),
#  (542,
#   ('pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (543,
#   ('phage ϕsa3 which encodes the modulators of the human innate immune response staphylokinase',
#    0.0)),
#  (544,
#   ('plk family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (545,
#   ('potent frick et al 2003 in addition to the plasminogen binding activation staphylokinase',
#    0.0)),
#  (546,
#   ('regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#    0.0)),
#  (547,
#   ('salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#    0.0)),
#  (548,
#   ('site in kringle structures on the activation of plasminogen with plasmin and staphylokinase',
#    0.0)),
#  (549,
#   ('the evasion of innate immune here we describe a mechanism by which staphylokinase',
#    0.0)),
#  (550,
#   ('to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#    0.0)),
#  (551,
#   ('a major role in mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (552,
#   ('a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (553,
#   ('and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#    0.0)),
#  (554,
#   ('belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (555,
#   ('considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#    0.0)),
#  (556,
#   ('generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    0.0)),
#  (557,
#   ('in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#    0.0)),
#  (558,
#   ('kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (559,
#   ('mmp 2 in murine skin and subcutaneous tissue protein extract after incubation with staphylokinase',
#    0.0)),
#  (560,
#   ('performed to characterize the function properties of rgd sak a novel mutant of staphylokinase',
#    0.0)),
#  (561,
#   ('platelet aggregation from the clot debris in order to minimize these problems a staphylokinase',
#    0.0)),
#  (562,
#   ('sak regarding its ability to function as an in vivo thrombolytic agent 99 staphylokinase',
#    0.0)),
#  (563,
#   ('salt hepes buffer ph 7 4 or human plasma the thrombolytic investigated were staphylokinase',
#    0.0)),
#  (564,
#   ('site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#    0.0)),
#  (565,
#   ('the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#    0.0)),
#  (566,
#   ('against the nk resistant target mel 30 and raji the degree of superantigen augmented killer',
#    0.0)),
#  (567,
#   ('and belief its is one of few examples of the expression of the prokaryotic staphylokinase',
#    0.0)),
#  (568,
#   ('involved in the evasion of innate immune here we describe a mechanism by which staphylokinase',
#    0.0)),
#  (569,
#   ('like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (570,
#   ('of a pathologic clot that results in obstructing the blood flow to heart tissue staphylokinase',
#    0.0)),
#  (571,
#   ('plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    0.0)),
#  (572,
#   ('play a major role in mechano electrical feedback since the stretch activation k + currents',
#    0.0)),
#  (573,
#   ('ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#    0.0)),
#  (574,
#   ('used site directed mutagenesis an arg gly asp rgd motif was engineered in the staphylokinase',
#    0.0)),
#  (575,
#   ('was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#    0.0)),
#  (576,
#   ('acid ra and salvianolic acid b sab the hairy root could also produce salvianolic acid k',
#    0.0)),
#  (577,
#   ('acid was considered for cytosolic expression of fusion protein in the e coli mature sak gene',
#    0.0)),
#  (578,
#   ('c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    0.0)),
#  (579,
#   ('polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (580,
#   ('+ c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    0.0)),
#  (581,
#   ('a polo like kinase plk family member as an appealing cancer drug target snk plk akin kinase',
#    0.0)),
#  (582,
#   ('b + c plasmin generation of plasminogen bound to sbi b and efb c by upa or staphylokinase',
#    0.0))]

# %%
longforms0.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [5, 8, 15, 32, 33, 34])

# %%
longforms = longforms0

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('staphylokinase',)

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {}

# %%
names
# Out:
# {}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'staphylokinase': 'UP:C3VIQK'},
#  {'UP:C3VIQK': 'Staphylokinase'},
#  ['UP:C3VIQK'])

# %%
grounding_map, names, pos_labels = ({'staphylokinase': 'UP:C3VIQK'},
 {'UP:C3VIQK': 'Staphylokinase'},
 ['UP:C3VIQK'])

# %%
grounding_dict = {'SAK': grounding_map}

# %%
classifier = AdeftClassifier('SAK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 15:37:28] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-27 15:37:31] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9866666666666667 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'UP:C3VIQK': 39, 'HGNC:11397': 77},
#  'f1': {'mean': 0.9866666666666667, 'std': 0.02666666666666666},
#  'precision': {'mean': 1.0, 'std': 0.0},
#  'recall': {'mean': 0.975, 'std': 0.049999999999999996}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:11397']

# %%
a[6]
# Out:
# 'The p53 tumor suppressor gene plays a key role in prevention of tumor formation through transcriptional dependent and independent mechanisms. Transcriptional-dependent mechanisms are mainly mediated by p53 regulation of downstream targets, leading to growth arrest and apoptosis. Mutational inactivation of the p53 gene is detected in more than 50% of human cancers. Mutation of p53 renders cancer cells more resistant to current cancer therapies due to lack of p53-mediated apoptosis. Extensive studies have been conducted to identify small molecules that manipulate p53, including restoration of mutant p53 conformation to wild-type, disruption of murine double minute-2 (Mdm2)-p53 binding to increase p53 level and inhibition of Mdm2 E3 ubiquitin ligase activity to prevent p53 degradation. Another approach was to identify and validate "drugable" target(s) in p53 signaling pathways that modulate p53-induced apoptosis. We profiled a p53 temperature-sensitive lung cancer cell model with the Affymetrix human HG-U133 GeneChip, covering the entire human transcriptome. We identified thousands of unique genes that were either induced or repressed in response to p53-induced apoptosis. A follow-up study characterized a p53-repressed gene, SAK, a polo-like kinase (PLK) family member, as an appealing cancer drug target. Snk/Plk-akin kinase (SAK) silencing via small interfering RNA (siRNA) induced apoptosis, whereas SAK overexpression attenuated p53-induced apoptosis. Thus, SAK repression by p53 contributes to p53-induced apoptosis. Future work is directed at determining the normal cell response to SAK silencing. If a therapeutic window is obtained, a SAK inhibitor identified from high throughput screening (HTS) could serve as a lead compound for development of a novel class of apoptosis-inducing anticancer drugs.\n'

# %%
disamb.dump('SAK', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('domain', 0.08492635500235372),
#  ('region', 0.0841391109644385),
#  ('nox', 0.08167855496471926),
#  ('bfgf', 0.07852529781557573),
#  ('glioma', 0.0754901259891954),
#  ('syk', 0.07470961043787495),
#  ('wasp', 0.0742950745186167),
#  ('oscc', 0.07402266033376588),
#  ('protein', 0.07386030185484761),
#  ('apoptotic', 0.07258466038676381),
#  ('neurons', 0.07164901466379286),
#  ('mapk', 0.0693512216241394),
#  ('methylation', 0.06882298766794948),
#  ('rac1 activation', 0.06832338117403505),
#  ('integrin', 0.06827423774405098),
#  ('gef', 0.0671435194882063),
#  ('active', 0.06693609445326244),
#  ('p75', 0.06570119946407436),
#  ('cases', 0.06567364135565414),
#  ('tcr', 0.06475739947254273),
#  ('icam', 0.06340546963244698),
#  ('hep3b', 0.06316817405048261),
#  ('fa', 0.0628753619339119),
#  ('mediated', 0.06285616023878235),
#  ('egf', 0.06277717335021338),
#  ('infection', 0.061523518414123436),
#  ('sf', 0.06134784459551271),
#  ('entry', 0.06038857487458122),
#  ('pak', 0.05939391436218462),
#  ('wound', 0.05923859060302146),
#  ('copd', 0.05877579744260618),
#  ('elmo', 0.05828459190699769),
#  ('p130cas', 0.057815560886065924),
#  ('clathrin', 0.05707426720261616),
#  ('hace1', 0.05649835189408671),
#  ('oxidase', 0.05547714037120707),
#  ('lfa', 0.05546906527374801),
#  ('dc', 0.05508546159211082),
#  ('p47 phox', 0.05504661883696745),
#  ('ms', 0.05436964547326225),
#  ('chromosome', 0.054334210304795176),
#  ('overexpression', 0.054090065566761096),
#  ('p47', 0.05394496787681315),
#  ('hiv', 0.05352750703541026),
#  ('ii', 0.05309105229204692),
#  ('akt2', 0.05278459426546419),
#  ('yb', 0.052064051340956596),
#  ('neurite', 0.05171860077695334),
#  ('irs', 0.0513599511009117),
#  ('nox1', 0.050645783645603654),
#  ('cpla', 0.05042931079704418),
#  ('pca', 0.04934272353939055),
#  ('wave', 0.04896364243055747),
#  ('nsc23766', 0.048853677395395534),
#  ('arsenic', 0.04876212336508516),
#  ('sirna', 0.04811302518877607),
#  ('adiponectin', 0.04803720510287865),
#  ('truncated', 0.047884870201109216),
#  ('lung cancer', 0.04721719270549104),
#  ('atp', 0.04714578002416112),
#  ('migration', 0.04666477190667146),
#  ('dock3', 0.04484063405112551),
#  ('terminal', 0.044794618757841104),
#  ('gap', 0.04468352203269657),
#  ('small gtpases', 0.0444759550998171),
#  ('tsp2', 0.043942530073612804),
#  ('rhogdi2', 0.043000969005224494),
#  ('1α', 0.04242678125949959),
#  ('nucleotide', 0.042141427379211734),
#  ('sequence', 0.04214039492422873),
#  ('fak', 0.04202138999956006),
#  ('innate', 0.04198221223898748),
#  ('formation', 0.041507813802964574),
#  ('collagen', 0.04135087372525645),
#  ('atrial', 0.04128688190453292),
#  ('cdk2', 0.04125860734487443),
#  ('mt1 mmp', 0.04070912463676751),
#  ('itsn', 0.010340955497256997),
#  ('aggregation', 0.010325087730043358),
#  ('invade', 0.010323009884665045),
#  ('activate', 0.01026647575165933),
#  ('oxide', 0.010202498580515041),
#  ('events', 0.010183453374917379),
#  ('sp cells', 0.010177153565380221),
#  ('epidermal', 0.010158248991947663),
#  ('marrow', 0.010091815472868158),
#  ('propose', 0.010079823316107222),
#  ('endogenous', 0.010055064462566373),
#  ('healing', 0.009992289429142409),
#  ('prenylation', 0.009974117845307235),
#  ('resulting', 0.009969482696193839),
#  ('maps', 0.009946798727518828),
#  ('dhl', 0.009902729773324624),
#  ('residues', 0.009874830985182164),
#  ('impaired', 0.009769718135422946),
#  ('vasp', 0.00972034444703042),
#  ('cdc42 rac1', 0.009685963193646016),
#  ('initiated', 0.009672555683135728),
#  ('cell receptor', 0.009672493356258598),
#  ('nucleotide exchange', 0.009656005232409951),
#  ('cell adhesion', 0.009655175188563268),
#  ('junctional', 0.00964425248825214),
#  ('ha', 0.009594460457510386),
#  ('elicited', 0.00946431064723462),
#  ('mcak', 0.009458291835982317),
#  ('platelet', 0.0094239118708518),
#  ('bile', 0.00942362673904087),
#  ('tumor cells', 0.009415545736463424),
#  ('β2', 0.009374492350895944),
#  ('rac1 signaling', 0.009332686441934603),
#  ('recruited', 0.00931923924128352),
#  ('sas', 0.009255873100387413),
#  ('mln4924', 0.009211894865947003),
#  ('unlike', 0.00919013464068777),
#  ('membranes', 0.009182285800317462),
#  ('innate immune', 0.00917263273912276),
#  ('effector', 0.009136523685329941),
#  ('barrier function', 0.00911178833197133),
#  ('dendritic', 0.009050679934256994),
#  ('carboxyl', 0.009050442080494036),
#  ('ccn2', 0.009000855524193637),
#  ('adhesion kinase', 0.009000792452400166),
#  ('hek293', 0.008997152917478182),
#  ('artery', 0.008983927021474422),
#  ('immune', 0.008981167518695569),
#  ('coding', 0.00895740952064868),
#  ('highly', 0.008944532142112969),
#  ('elongation', 0.008936789997669175),
#  ('oxygen species', 0.008904844361351529),
#  ('specifically', 0.008843726881632201),
#  ('spanning', 0.008830332723827872),
#  ('dependent activation', 0.00878041500193981),
#  ('leukocytes', 0.008733659671460038),
#  ('gtp bound', 0.008710928203253443),
#  ('mmp3', 0.008681902436463785),
#  ('enhancement', 0.008667630714871808),
#  ('resveratrol', 0.008629053596286603),
#  ('current', 0.008606144523083436),
#  ('gmp', 0.008602512042958338),
#  ('rich', 0.008599571221074985),
#  ('taken', 0.008584619283767305),
#  ('mb 231', 0.008562911491998247),
#  ('fbab', 0.00855487278984958),
#  ('epithelium', 0.008548383258229755),
#  ('physical', 0.008527461985876884),
#  ('driven', 0.008503768201737332),
#  ('115', 0.008478431651918106),
#  ('coronary artery', 0.008435062333719698),
#  ('cell polarity', 0.008432160288610055),
#  ('beads', 0.008424334441047768),
#  ('tagged', 0.008405528267810318),
#  ('targeting', 0.008326884214279644),
#  ('binding domain', 0.008279765202792529),
#  ('respiratory', 0.008269541247013021),
#  ('supplemental figure', 0.008072166365680325),
#  ('somatic', 0.0080674139720082),
#  ('molecular mechanisms', 0.008064265915050661),
#  ('cd34 cells', 0.0018065851477302682),
#  ('cell motility', 0.0017730299184850723),
#  ('prc2', 0.0017670604659660535),
#  ('accumulate', 0.0017648876521940342),
#  ('gap activity', 0.0017619215596028977),
#  ('tg mice', 0.0017421293613266637),
#  ('computational', 0.001718341844745325),
#  ('acini', 0.0016837317043615556),
#  ('bias', 0.001679335276788265),
#  ('tract', 0.0016768391282356956),
#  ('10 nm', 0.0016686423025255063),
#  ('nih', 0.0016600026674318845),
#  ('primarily', 0.0016334901957943378),
#  ('free', 0.001633095368968019),
#  ('drosophila', 0.001632059878931662),
#  ('consistently', 0.0016074640092012614),
#  ('regulation cell', 0.001593194032487206),
#  ('122', 0.0015851794022037076),
#  ('org', 0.0015815793588850192),
#  ('speed', 0.0015538209831334015),
#  ('similar', 0.0015484272543345948),
#  ('polarized', 0.0015423757921221675),
#  ('sufficient', 0.0015364345138062885),
#  ('nef mediated', 0.0015343464675582612),
#  ('btz', 0.0015139523525440973),
#  ('poor', 0.0015114074362315075),
#  ('long', 0.0015003542046306503),
#  ('cos', 0.001498601792119749),
#  ('keratinocyte', 0.0014976736236310818),
#  ('depend', 0.0014773617977301068),
#  ('structurally', 0.0014491726186032525),
#  ('figures', 0.0014377814748537813),
#  ('terminal kinase', 0.0014361158507965417),
#  ('forced', 0.0014262514895394777),
#  ('stress fibers', 0.0014136424401912943),
#  ('gtp levels', 0.0014045893550220271),
#  ('http www', 0.001400662742870137),
#  ('constitute', 0.0013847501095176986),
#  ('correlates', 0.001369935214639086),
#  ('bacterial', 0.0013642322615670115),
#  ('lymph node', 0.0013335407699094147),
#  ('isolated', 0.001323811398459816),
#  ('extensive', 0.0013226730118904525),
#  ('required activation', 0.0013197737912688597),
#  ('58', 0.0013141559461475587),
#  ('nmr', 0.001306937842581011),
#  ('depleted', 0.0012903072537006044),
#  ('mammals', 0.0012702016022548464),
#  ('released', 0.0012652732264462352),
#  ('hcc cell', 0.0012594994919302661),
#  ('basement', 0.0012518869954071575),
#  ('101', 0.00123504916963941),
#  ('trans', 0.0012301377075536557),
#  ('pkcι', 0.0012264666011846362),
#  ('heterogeneous', 0.001222948155486682),
#  ('negative rac1', 0.0012105078877033412),
#  ('generate', 0.0012101502636323205),
#  ('lifetime', 0.0012071362921252094),
#  ('calmodulin', 0.0012066364853404571),
#  ('vesicle', 0.0011892819563656617),
#  ('nm', 0.001188215693767789),
#  ('cos cells', 0.0011740720697546365),
#  ('protein expression', 0.001170686518324222),
#  ('retroviruses', 0.0011687624569236418),
#  ('crl', 0.0011505650463955826),
#  ('ruffles', 0.0011480796192660672),
#  ('drive', 0.0011419143176276045),
#  ('cancer institute', 0.0011183052808775025),
#  ('67', 0.0010737540075197954),
#  ('gmr', 0.0010730314391936902),
#  ('caspase activation', 0.0010666893479688092),
#  ('genetic variation', 0.001056046926990383),
#  ('reveal', 0.0010552131145286768),
#  ('epha2', 0.0010510078687096037),
#  ('armus', 0.0010396359831100128),
#  ('gmr gal4', 0.0010376435255460572),
#  ('lit', 0.0010286327602783783),
#  ('generating', 0.001026011834877848),
#  ('enrichment', 0.0010042797351243191),
#  ('gtpase activating', 0.0009997082407178493),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
