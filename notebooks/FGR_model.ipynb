# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['FGR']
genes = ['FGR']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['FGR'].top()

# %%
top
# Out:
# [('fetal growth restriction', 192.85142857142858),
#  ('of fetal growth restriction', 26.275862068965512),
#  ('and fetal growth restriction', 17.81818181818182),
#  ('growth restriction', 17.427230046948353),
#  ('with fetal growth restriction', 9.23076923076923),
#  ('fluorescence guided resection', 7.0),
#  ('induced fetal growth restriction', 6.5),
#  ('to fetal growth restriction', 5.25),
#  ('functional group richness', 5.142857142857142),
#  ('foetal growth restriction', 5.0),
#  ('in fetal growth restriction', 5.0),
#  ('preeclampsia pe and fetal growth restriction', 5.0),
#  ('fgr fetal growth restriction', 4.857142857142858),
#  ('by fetal growth restriction', 4.444444444444445),
#  ('fetal growth retardation', 4.0),
#  ('associated with fetal growth restriction', 4.0),
#  ('causes of fetal growth restriction', 4.0),
#  ('such as fetal growth restriction', 3.6666666666666665),
#  ('or fetal growth restriction', 3.6),
#  ('pe and fetal growth restriction', 3.25),
#  ('including fetal growth restriction', 3.0),
#  ('complications by fetal growth restriction', 3.0),
#  ('leads to fetal growth restriction', 3.0),
#  ('pregnancy complications by fetal growth restriction', 2.5),
#  ('mean functional group richness', 2.0),
#  ('pregnancy fetal growth restriction', 2.0),
#  ('severe fetal growth restriction', 2.0),
#  ('for fgr fetal growth restriction', 2.0),
#  ('preeclampsia and fetal growth restriction', 2.0),
#  ('pregnancy with fetal growth restriction', 2.0),
#  ('increased risk of fetal growth restriction', 2.0),
#  ('pre eclampsia and fetal growth restriction', 2.0),
#  ('iated vasodilatory responses in placentas from pregnancy associated with fetal growth restriction',
#   2),
#  ('plot showing differentially methylation positions in umbilical cord blood between growth restriction',
#   2),
#  ('saponins from actinidia arguta radix saa total flavonoids from glycyrrhizae radix et rhizoma',
#   2),
#  ('risk of fetal growth restriction', 1.6),
#  ('ratio', 1.3333333333333333),
#  ('outcomes is fetal growth restriction', 1.3333333333333333),
#  ('study of fetal growth restriction', 1.3333333333333333),
#  ('outcomes such as fetal growth restriction', 1.3333333333333333),
#  ('pregnancy associated with fetal growth restriction', 1.3333333333333333),
#  ('total flavonoids from glycyrrhizae radix et rhizoma', 1.3333333333333333),
#  ('recirculation', 1.0),
#  ('gain ratio', 1.0),
#  ('1 fetal growth restriction', 1.0),
#  ('development fetal growth restriction', 1.0),
#  ('for fetal growth restriction', 1.0),
#  ('the fetal growth restriction', 1.0),
#  ('tyrosine protein kinase fgr', 1.0),
#  ('affected by fetal growth restriction', 1.0),
#  ('and or fetal growth restriction', 1.0),
#  ('cases of fetal growth restriction', 1.0),
#  ('development and fetal growth restriction', 1.0),
#  ('due to fetal growth restriction', 1.0),
#  ('exposure induced fetal growth restriction', 1.0),
#  ('model of fetal growth restriction', 1.0),
#  ('with fgr fetal growth restriction', 1.0),
#  ('a hallmark of fetal growth restriction', 1),
#  ('i r induced fetal growth restriction', 1.0),
#  ('preterm birth ptb fetal growth restriction', 1.0),
#  ('although the etiology of fetal growth restriction', 1),
#  ('in pregnancy complications by fetal growth restriction', 1.0),
#  ('maternal cadmium exposure induced fetal growth restriction', 1),
#  ('perinatal outcomes such as fetal growth restriction', 1.0),
#  ('pregnancy complications such as fetal growth restriction', 1.0),
#  ('species richness sr and functional group richness', 1),
#  ('with increased risk of fetal growth restriction', 1.0),
#  ('excluding fetal anomalies after prematurity fetal growth restriction', 1),
#  ('model for the study of fetal growth restriction', 1.0),
#  ('we investigate the effects of fetal growth restriction', 1),
#  ('eurological deficits pulmonary artery dysfunction atherosclerosis and fetal growth restriction',
#   1),
#  ('pregnancy disorders such as preterm birth ptb fetal growth restriction', 1),
#  ('a cohort study including 81 children with birthweight < 10th centile', 1),
#  ('analyses investigate the contribute of antenatal factors particularly fetal growth restriction',
#   1),
#  ('cadmium cd is a developmental toxicant that induced fetal growth restriction',
#   1),
#  ('cadmium cd is linked with increased risk of fetal growth restriction', 1),
#  ('nd perinatal complications associated with abnormal maternal inflammation fetal growth restriction',
#   1),
#  ('omplications of fetal growth restriction placental insufficiency mediated fetal growth restriction',
#   1),
#  ('tcomes particularly those results from placental dysfunction including fetal growth restriction',
#   1),
#  ('vitamin d deficiency in pregnancy is associated to fetal growth restriction',
#   1),
#  ('we test the hypothesis that women with idiopathic fetal growth restriction',
#   1),
#  ('astfeeding and postnatal nutrition on cardiovascular remodeling induced by fetal growth restriction',
#   1),
#  ('cd exposure during pregnancy and the increased risk of fetal growth restriction',
#   1.0),
#  ('chromosomal abnormal which would impact clinical management for fgr fetal growth restriction',
#   1),
#  ('educed umbilical artery glutamate concentrations in human fgr pregnancy fetal growth restriction',
#   1),
#  ('eness of the combination of intraoperative photodynamic diagnosis and fluorescence guided resection',
#   1),
#  ('haemodynamics in normotensive women with pregnancy complications by severe fetal growth restriction',
#   1),
#  ('lity in functional group abundance declined significantly with increased functional group richness',
#   1),
#  ('maternal nutrient restriction mnr is a widespread causes of fetal growth restriction',
#   1),
#  ('modulated by maternal fetal placental and environmental factors 1 fetal growth restriction',
#   1),
#  ('nancy complications by severe early onset preeclampsia placental abruption fetal growth restriction',
#   1),
#  ('p including preeclampsia or gestational hypertension are associated with fetal growth restriction',
#   1),
#  ('pathophysiology of chronic nitric oxide synthase nos inhibition induced fetal growth restriction',
#   1),
#  ('th restriction with compromised umbilical artery end diastolic velocities fetal growth restriction',
#   1),
#  ('there is no proven therapy to reverse or ameliorate fetal growth restriction',
#   1),
#  ('three combustion modes including direct combustion staged combustion and flue gas recirculation',
#   1),
#  ('to investigate the incidence and high risk factors of fetal growth restriction',
#   1),
#  ('well as other fluorescence imaging applications 10 11 including fluorescence guided resection',
#   1),
#  ('00 000 infant death annually 3 4 infant undernutrition including fetal growth restriction',
#   1),
#  ('administration of lps induced a systemic and local inflammatory responses fetal growth restriction',
#   1),
#  ('al microarray analysis cma to investigate the genetic characteristic of fetal growth restriction',
#   1),
#  ('apan taking advantage of ala induced ppix fluorescence or fluorescein fluorescence guided resection',
#   1),
#  ('aturation 1 however excess glucocorticoid exposure in utero leads to fetal growth restriction',
#   1),
#  ('d maternal obesity are serious complications of pregnancy associated with fetal growth restriction',
#   1),
#  ('erine fetal death iufd preeclampsia pe placental abruption pa and fetal growth restriction',
#   1),
#  ('fetoprotein afp on second trimester screening and development early onset fetal growth restriction',
#   1),
#  ('fficiency results in impaired feto placental exchange and subsequent in fetal growth restriction',
#   1),
#  ('fpr2 and trophoblast and endothelial functional in pregnancy affected by fetal growth restriction',
#   1),
#  ('free beta hcg fβhcg increased levels and pregnancy complications pc foetal growth restriction',
#   1),
#  ('h3k27ac occupancy in healthy placentas and placentas from pregnancy with fetal growth restriction',
#   1),
#  ('he importance of fmvd regulation in normal and dysfunction placental fetal growth restriction',
#   1),
#  ('icantly adverse effects on fetal neonatal health and cognitive development fetal growth restriction',
#   1),
#  ('increased in placentas from pregnancy complications by pre eclampsia pe fetal growth restriction',
#   1),
#  ('increased prevalence of low birthweight lbw delivery primarily due to fetal growth restriction',
#   1),
#  ('lasting consequences for mother and baby two key pregnancy complications fetal growth restriction',
#   1),
#  ('ly hydrocephalus agenesis of the corpus callosum choroid plexus cysts foetal growth restriction',
#   1),
#  ('matically decrease rna replication in hcv replicon cells harboring subgenomic sgr or fullgenomic',
#   1),
#  ('methylation patterns of syn1 and syn2 from pregnancy complications by fetal growth restriction',
#   1),
#  ('mong glioma treatment strategy 5 aminolevulinic acid 5 ala based fluorescence guided resection',
#   1),
#  ('n similarly with antenatal hypoxic exposure rodents also demonstrate the fetal growth restriction',
#   1),
#  ('nd its receptor in modulated fetal growth requires further investigate fetal growth restriction',
#   1),
#  ('pathological sga is known as intrauterine growth restriction iugr or fetal growth restriction',
#   1),
#  ('placental insufficiency is a major causes of antepartum stillbirth and fetal growth restriction',
#   1),
#  ('rapeutic strategy to improve uteroplacental blood flow in pregnancy with fetal growth restriction',
#   1),
#  ('raphic findings ultrasound scan after 25 weeks of pregnancy revealed foetal growth restriction',
#   1),
#  ('regnant women development serious complications such as preeclampsia pe and fetal growth restriction',
#   1),
#  ('seq in healthy placentas and placentas from pathological pregnancy with fetal growth restriction',
#   1),
#  ('telomerase activated levels on the placental pathological associated with fgr fetal growth restriction',
#   1),
#  ('th weight in uncomplicated pregnancy up and pregnancy complications by fetal growth restriction',
#   1),
#  ('the cardiac consequences of maternal malnutrition a predominant causes of fetal growth restriction',
#   1),
#  ('the pathological of the pregnancy complications pre eclampsia pe and fetal growth restriction',
#   1),
#  ('tive therapeutic strategy for inflammation induced fgr in late pregnancy fetal growth restriction',
#   1),
#  ('underwent elective cesarean section with large for gestational age lga fetal growth restriction',
#   1),
#  ('we determinant brain to liver weight ratio blwr thresholds for fetal growth restriction',
#   1),
#  ('acental igf2 dna methylation the associated were much more evidence in fetal growth restriction',
#   1),
#  ('al leptin levels can indicate changes in color doppler sonographic indicate fetal growth restriction',
#   1),
#  ('and has shown promising results in increased extent of resection in fluorescence guided resection',
#   1),
#  ('antepartum bleeding of unknown origin increased the risk of pm 18 fetal growth retardation',
#   1),
#  ('caucasian women were including as cases when an ultrasound scan identified fetal growth restriction',
#   1),
#  ('d fetoplacental blood flow are putative aetiologies in the pathogenesis of fetal growth restriction',
#   1),
#  ('d to explore plasma mirnas as potential biomarker for placental diseases fetal growth restriction',
#   1),
#  ('en environmental stress low stress medium stress high stress and mean functional group richness',
#   1),
#  ('esses associated with pe can restriction fetal growth and impaired development fetal growth restriction',
#   1),
#  ('f aryl hydrocarbon interacting protein aip g ppid and h tyrosine protein kinase fgr',
#   1),
#  ('f eor is 5 aminolevulinic acid ala induced protoporphyrin ix ppix fluorescence guided resection',
#   1),
#  ('f the candidates in the progression of preeclampsia often associated with fetal growth restriction',
#   1),
#  ('gpr30 in pregnancy or in pregnancy complications such as preeclampsia and fetal growth restriction',
#   1),
#  ('iction iugr surrogates iugr small for gestational age birth sga and fetal growth restriction',
#   1),
#  ('in decidual tissue from pregnancy complications by pre eclampsia and or fetal growth restriction',
#   1),
#  ('ined whether maternal nutrient restriction mnr in guinea pigs leads to fetal growth restriction',
#   1),
#  ('l age and birth weight severe antenatal factors predicted cld including fetal growth restriction',
#   1),
#  ('l dysfunction under major obstetric diseases such as pre eclampsia and fetal growth restriction',
#   1),
#  ('lampsia eope are used in predicted adverse perinatal outcomes such as fetal growth restriction',
#   1),
#  ('lgf are one of the hallmark of human pregnancy complications including fetal growth restriction',
#   1),
#  ('lling is an early characteristic of common pregnancy complications such as fetal growth restriction',
#   1),
#  ('long term consequences of such genes expression alter in fetal life fetal growth restriction',
#   1),
#  ('maternal cadmium cd exposure during pregnancy and the increased risk of fetal growth restriction',
#   1),
#  ('maternal obesity is associated with macrosomia or on the contrary with fetal growth restriction',
#   1),
#  ('n placental structure in clinical conditions related to stillbirth such as fetal growth restriction',
#   1),
#  ('n vesicle study suggest impaired placental amino acid transport in human fetal growth restriction',
#   1),
#  ('of what has been term the great obstetric syndromes pre eclampsia fetal growth restriction',
#   1),
#  ('ording used in multiple sub populations of individuals present with fgr fetal growth restriction',
#   1),
#  ('p between maternal serum ferritin and concentrations and specific types of fetal growth restriction',
#   1),
#  ('plied to placental tissue from live birth and stillbirth associated with fetal growth restriction',
#   1),
#  ('pregnancy in women of advanced maternal age ama are susceptible to fetal growth restriction',
#   1),
#  ('pressure in pe but results in preventable preterm delivery and correcting fetal growth restriction',
#   1),
#  ('rn pharmacology research has also reported that the flavonoids from glycyrrhizae radix et rhizome',
#   1),
#  ('ronment failure of this interplay leads to poor placental development and fetal growth restriction',
#   1),
#  ('rtisol s permissive effects denoted by the blue bold line whereas cortisol glucocorticoid receptor',
#   1),
#  ('se control study within the prospective wenzhou birth cohort including 130 fetal growth retardation',
#   1),
#  ('that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#   1.0),
#  ('the pathogenesis of pe and associated adverse pregnancy outcomes such as fetal growth restriction',
#   1),
#  ('tic modalities for learning and memory abilities impaired causes by fgr fetal growth restriction',
#   1),
#  ('timate the associated between hyperemesis gravidarum hg and the risk of fetal growth restriction',
#   1),
#  ('tory cytokine has been implicated in the pathogenesis of preeclampsia and fetal growth restriction',
#   1),
#  ('vailability appears to be an attractive strategy for improve outcomes in fetal growth restriction',
#   1),
#  ('vascular effects of nitric oxide no donors in pregnancy complications by fetal growth restriction',
#   1),
#  ('vasoactive peptides cgrp adm and adm2 in pregnancy complications such as fetal growth restriction',
#   1),
#  ('y assist in assessing possible mechanisms of action preeclampsia pe and fetal growth restriction',
#   1),
#  ('y predispose to placental mediated diseases such as pre eclampsia pet fetal growth restriction',
#   1),
#  ('adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#   1.0),
#  ('ally relevant mouse model of human pregnancy complications such as pe and fetal growth restriction',
#   1),
#  ('and prognosis of fetus diagnosed with fgr before 32 weeks of gestational fetal growth restriction',
#   1),
#  ('ant emissions when the charging rate or composition of any waste is varying fluegas recirculation',
#   1),
#  ('during pregnancy remains one of the most common and preventable causes of fetal growth restriction',
#   1),
#  ('ese optimal birth weight standard by gestational age 34 the diagnosis of fetal growth restriction',
#   1),
#  ('ethylation of 2 growth related genes igf2 and ahrr in placentas from fetal growth restriction',
#   1),
#  ('ex peptidylprolyl isomerase d ppid also known as cyclophilin d and tyrosine protein kinase fgr',
#   1),
#  ('ficance of endothelin 1 et 1 in platelet activated factors paf induced fetal growth restriction',
#   1),
#  ('from study on autophagy in the placentas from women with preeclampsia and fetal growth restriction',
#   1),
#  ('fter the stimulation as shown in figure 1 total flavonoids from glycyrrhizae radix et rhizoma',
#   1),
#  ('h in normal pregnancy failure of this adaptation might contribute to fgr fetal growth restriction',
#   1),
#  ('he effects of other vasoactive agents 9 fifty nine pregnant women with fetal growth restriction',
#   1),
#  ('ing of delivery placental insufficiency is one of the commonest causes of fetal growth restriction',
#   1),
#  ('l cadmium exposure via the environment and or cigarette smoking leads to fetal growth restriction',
#   1),
#  ('lar flow is at least in part responses for placental insufficiency and fetal growth retardation',
#   1),
#  ('lf of pathological society of great britain and ireland pre eclampsia and fetal growth restriction',
#   1),
#  ('medium stress but not under low or high stress relationship between mean functional group richness',
#   1),
#  ('min intervention on insulin resistance during catch up growth in mice with fetal growth restriction',
#   1),
#  ('mitogen activated protein kinase phosphatase 1 mkp 1 of fetal rat with fetal growth restriction',
#   1),
#  ('mor imaging recent study suggest that the used of ala ppix mediated fluorescence guided resection',
#   1),
#  ('ned in pregnant dams reduced folate and choline status results in severe fetal growth restriction',
#   1),
#  ('nsulin resistance and coronary heart diseases during adulthood 1 2 3 4 foetal growth restriction',
#   1),
#  ('olymorphism apo was defined as one of the following preterm birth ptb fetal growth restriction',
#   1),
#  ('on between maternal cd exposure during pregnancy and the increased risk of fetal growth restriction',
#   1),
#  ('pm can leads to poor neonatal outcomes including low birthweight due to fetal growth restriction',
#   1),
#  ('potential as a therapeutic strategy for pe and fgr preeclampsia pe and fetal growth restriction',
#   1),
#  ('releasing factors crf and urocortin are elevated in preterm labour and or fetal growth restriction',
#   1),
#  ('revealed that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#   1),
#  ('rters gluts has been poor characterized in the etiology of cd induced fetal growth restriction',
#   1),
#  ('s c jejuni and c fetus infections results in impaired development and fetal growth restriction',
#   1),
#  ('se or between preeclamptic pregnancy that are or are not complications by fetal growth restriction',
#   1),
#  ('size all analyses were conducted in statistica v 6 0 31 community functional group richness',
#   1),
#  ('the rat were randomly assigned into 3 group normal group model group fetal growth restriction',
#   1),
#  ('this test to evaluate placental gas exchange capacity in pre eclampsia and fetal growth restriction',
#   1),
#  ('tion of reduced fetal movements rfm is associated with increased risk of fetal growth restriction',
#   1),
#  ('toll like receptor 4 tlr4 in uterine ischemia reperfusion i r induced fetal growth restriction',
#   1),
#  ('was to examine the role of hereditary thrombophilia in the development of fetal growth retardation',
#   1),
#  ('y onset fgr summary of treatment strategy used in preclinical model of fetal growth restriction',
#   1),
#  ('a clinical severe subgroup of women with early onset of the diseases and fetal growth restriction',
#   1),
#  ('ast cancer and analyzed these four study together to account for the higher familial genetic risk',
#   1),
#  ('ation a decrease in water volume would alter the effects of increased in functional group richness',
#   1),
#  ('cts of placental restriction of fetal growth pr on size at birth neonatal fractional growth rate',
#   1),
#  ('e regarding the up or down regulation of no in pregnancy complications by fetal growth restriction',
#   1),
#  ('ed an excess of fetal death in cases of pregnancy related hypertension and fetal growth restriction',
#   1),
#  ('egfr 1 and vegfr 2 receptor the placentas of pregnancy whose outcomes is fetal growth restriction',
#   1),
#  ('esistance was measured in normal placentas n = 10 open symbols a or fetal growth restriction',
#   1),
#  ('estored pup weight in the present study we aim to further investigate if fetal growth restriction',
#   1),
#  ('etween placental amino acid aa transport and fetal aa demand in an ovine fetal growth restriction',
#   1),
#  ('evt cells isolated by tric in women who later development pre eclampsia or fetal growth restriction',
#   1),
#  ('ey found that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#   1),
#  ('hy appropriately grown baby at term is the primary goal in any pregnancy fetal growth restriction',
#   1),
#  ('ic events repeated miscarriage fetal loss and is a major risk factors for fetal growth restriction',
#   1),
#  ('in ginseng root and ginseng berry compare the effects of crude saponins from fermented ginseng root',
#   1),
#  ('incidence of lbw in bangladesh is 21 6 3 predominant the results of fetal growth restriction',
#   1),
#  ('induction and 7929 96 2 were spontaneous preterm delivery p < 0 001 fetal growth restriction',
#   1),
#  ('ive birth and there were three pregnancy loss there were no cases of fetal growth restriction',
#   1),
#  ('l factors leads to fgr and subsequent insults to the deve loping organs fetal growth restriction',
#   1),
#  ('loci that could act as markers for poor fetal growth 52 notably placentas from growth restriction',
#   1),
#  ('m is associated with an increased risk of poor perinatal outcomes such as fetal growth restriction',
#   1),
#  ('n and secretion of vcam 1 from normal pregnancy and those complications by fetal growth restriction',
#   1),
#  ('onment is known to be a critical determinant of adult health for example fetal growth restriction',
#   1),
#  ('pahs during the first trimester was associated with the largest decrement in the fetal growth ratio',
#   1),
#  ('ports further work on the possible of melatonin as a treatment for fgr fetal growth restriction',
#   1),
#  ('r more effects fgr of brain tumors the ala glioma study group used fluorescence guided resection',
#   1),
#  ('res et al 1992 in foetus a11454 agenesis of the corpus callosum and foetal growth restriction',
#   1),
#  ('rmine if these methylation changes could be used as a biomarker for fgr fetal growth restriction',
#   1),
#  ('rowth factors receptor 1 sflt 1 and placental growth factors plgf in the fetal growth restriction',
#   1),
#  ('sulting in aberrant blood flow has been implicated as a possible causes of fetal growth restriction',
#   1),
#  ('they reduced blood supply to the placentas and fetus which could leads to fetal growth restriction',
#   1),
#  ('which may be related to the upregulation of nri subunit of nmda receptor fetal growth restriction',
#   1),
#  ('> 2 fold changes we found that cord blood from newborn offspring affected by fetal growth restriction',
#   1),
#  ('a d medium stress b e and high stress c f treatment for mean functional group richness',
#   1),
#  ('d that these mice may provide a relevant model of human pe with associated fetal growth restriction',
#   1),
#  ('ediated sp a induction and lung maturity of the fetus are ttf 1 dependent fetal growth restriction',
#   1),
#  ('een the development of fgr and the expression of pappa pappa2 and plac 1 fetal growth restriction',
#   1),
#  ('ia and fgr our findings suggest that the stox genes are associated with a severe fetal phenotype',
#   1),
#  ('ity into adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#   1),
#  ('keleton 17 18 19 20 21 22 while mid and late gestational exposure induced fetal growth restriction',
#   1),
#  ('knockouts leu 27 igf ii s effects on fetal weight variation and no of fetal growth restriction',
#   1),
#  ('later in adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#   1),
#  ('observed now we provide new evidence that il 10 is also able to improve fetal growth restriction',
#   1),
#  ('pregnant women as part of a large scale study to identified risk factors for fetal growth retardation',
#   1),
#  ('r with il 6 and igfbp 2 concentrations in placental lysates most cases of fetal growth restriction',
#   1),
#  ('refers to an infant born with a birth weight less than the 10th centile fetal growth restriction',
#   1),
#  ('s fd water consumption wc body weight average daily weight gain adg and feed to gain ratio',
#   1),
#  ('stigate the effects of vitamin d vd on the learning and memory abilities of fetal growth restriction',
#   1),
#  ('the cytokine and igf systemic have been shown in placentas and cord serum of fetal growth restriction',
#   1),
#  ('7 5 cells harboring either an hcv subgenomic rna replicon sgr or an hcv full genomic rna replicon',
#   1),
#  ('a human igf ii analog that binds the igf ii clearance receptor igf iir in fetal growth restriction',
#   1),
#  ('baby with a blwr of less than 5 0 to confirm fgr causes of pathological fetal growth restriction',
#   1),
#  ('cle and ebv for adg lean cuts lc backfat thickness bft ham weight hw and feed gain ratio',
#   1),
#  ('e alveolus area and improve the maturity of fetal lung in a rat model of fetal growth restriction',
#   1),
#  ('e ischemia reperfusion i r in rodents is a common model for the study of fetal growth restriction',
#   1),
#  ('ewal of stb and fgr that are common to pe and maternal obesity study of fetal growth restriction',
#   1),
#  ('g cm 3 for each newborn in order to test our main hypothesis we chose fetal growth restriction',
#   1),
#  ('ide new targets via mir 141 in diagnosis and therapy of fgr in the future fetal growth restriction',
#   1),
#  ('iencies in nutrient such as folic acid and vitamin b12 may play a role in fetal growth restriction',
#   1),
#  ('inhibition in the pregnant rat has been used as a model for the study of fetal growth restriction',
#   1),
#  ('ion i r protocols to establish and refine a murine model of i r induced fetal growth restriction',
#   1),
#  ('centile', 0.0),
#  ('fgr', 0.0),
#  ('fullgenomic', 0.0),
#  ('homolog', 0.0),
#  ('phenotype', 0.0),
#  ('rate', 0.0),
#  ('receptor', 0.0),
#  ('replicon', 0.0),
#  ('resection', 0.0),
#  ('restriction', 0.0),
#  ('retardation', 0.0),
#  ('rhizome', 0.0),
#  ('rhizoma', 0.0),
#  ('richness', 0.0),
#  ('risk', 0.0),
#  ('root', 0.0),
#  ('10th centile', 0.0),
#  ('et rhizome', 0.0),
#  ('et rhizoma', 0.0),
#  ('fetal phenotype', 0.0),
#  ('fluegas recirculation', 0.0),
#  ('gas recirculation', 0.0),
#  ('genetic risk', 0.0),
#  ('ginseng root', 0.0),
#  ('glucocorticoid receptor', 0.0),
#  ('group richness', 0.0),
#  ('growth rate', 0.0),
#  ('growth ratio', 0.0),
#  ('growth retardation', 0.0),
#  ('guided resection', 0.0),
#  ('kinase fgr', 0.0),
#  ('oncogene homolog', 0.0),
#  ('or fullgenomic', 0.0),
#  ('rna replicon', 0.0),
#  ('< 10th centile', 0.0),
#  ('between growth restriction', 0.0),
#  ('cortisol glucocorticoid receptor', 0.0),
#  ('familial genetic risk', 0.0),
#  ('feed gain ratio', 0.0),
#  ('fermented ginseng root', 0.0),
#  ('fetal growth ratio', 0.0),
#  ('fgr oncogene homolog', 0.0),
#  ('flue gas recirculation', 0.0),
#  ('fractional growth rate', 0.0),
#  ('from growth restriction', 0.0),
#  ('genomic rna replicon', 0.0),
#  ('protein kinase fgr', 0.0),
#  ('radix et rhizome', 0.0),
#  ('radix et rhizoma', 0.0),
#  ('severe fetal phenotype', 0.0),
#  ('sgr or fullgenomic', 0.0),
#  ('to gain ratio', 0.0),
#  ('varying fluegas recirculation', 0.0),
#  ('001 fetal growth restriction', 0.0),
#  ('130 fetal growth retardation', 0.0),
#  ('18 fetal growth retardation', 0.0),
#  ('4 foetal growth restriction', 0.0),
#  ('a severe fetal phenotype', 0.0),
#  ('abruption fetal growth restriction', 0.0),
#  ('ameliorate fetal growth restriction', 0.0),
#  ('and feed gain ratio', 0.0),
#  ('and fetal growth retardation', 0.0),
#  ('and flue gas recirculation', 0.0),
#  ('and fluorescence guided resection', 0.0),
#  ('and foetal growth restriction', 0.0),
#  ('and functional group richness', 0.0),
#  ('as fetal growth restriction', 0.0),
#  ('associated fetal growth restriction', 0.0),
#  ('based fluorescence guided resection', 0.0),
#  ('birthweight < 10th centile', 0.0),
#  ('blood between growth restriction', 0.0),
#  ('centile fetal growth restriction', 0.0),
#  ('chose fetal growth restriction', 0.0),
#  ('community functional group richness', 0.0),
#  ('complications fetal growth restriction', 0.0),
#  ('correcting fetal growth restriction', 0.0),
#  ('cysts foetal growth restriction', 0.0),
#  ('dependent fetal growth restriction', 0.0),
#  ('diseases fetal growth restriction', 0.0),
#  ('eclampsia fetal growth restriction', 0.0),
#  ('example fetal growth restriction', 0.0),
#  ('feed to gain ratio', 0.0),
#  ('fluorescein fluorescence guided resection', 0.0),
#  ('for fetal growth retardation', 0.0),
#  ('from fermented ginseng root', 0.0),
#  ('from fetal growth restriction', 0.0),
#  ('full genomic rna replicon', 0.0),
#  ('future fetal growth restriction', 0.0),
#  ('gestational fetal growth restriction', 0.0),
#  ('glycyrrhizae radix et rhizome', 0.0),
#  ('glycyrrhizae radix et rhizoma', 0.0),
#  ('group fetal growth restriction', 0.0),
#  ('higher familial genetic risk', 0.0),
#  ('human fetal growth restriction', 0.0),
#  ('identified fetal growth restriction', 0.0),
#  ('idiopathic fetal growth restriction', 0.0),
#  ('if fetal growth restriction', 0.0),
#  ('improve fetal growth restriction', 0.0),
#  ('in fluorescence guided resection', 0.0),
#  ('in functional group richness', 0.0),
#  ('including fluorescence guided resection', 0.0),
#  ('increased functional group richness', 0.0),
#  ('indicate fetal growth restriction', 0.0),
#  ('inflammation fetal growth restriction', 0.0),
#  ('investigate fetal growth restriction', 0.0),
#  ('is fetal growth restriction', 0.0),
#  ('is varying fluegas recirculation', 0.0),
#  ('lga fetal growth restriction', 0.0),
#  ('life fetal growth restriction', 0.0),
#  ('mediated fetal growth restriction', 0.0),
#  ('mediated fluorescence guided resection', 0.0),
#  ('neonatal fractional growth rate', 0.0),
#  ('of fetal growth retardation', 0.0),
#  ('onset fetal growth restriction', 0.0),
#  ('organs fetal growth restriction', 0.0),
#  ('ovine fetal growth restriction', 0.0),
#  ('particularly fetal growth restriction', 0.0),
#  ('pathological fetal growth restriction', 0.0),
#  ('pc foetal growth restriction', 0.0),
#  ('pe fetal growth restriction', 0.0),
#  ('pet fetal growth restriction', 0.0),
#  ('placental fetal growth restriction', 0.0),
#  ('placentas from growth restriction', 0.0),
#  ('ppix fluorescence guided resection', 0.0),
#  ('prematurity fetal growth restriction', 0.0),
#  ('ptb fetal growth restriction', 0.0),
#  ('receptor fetal growth restriction', 0.0),
#  ('responses fetal growth restriction', 0.0),
#  ('revealed foetal growth restriction', 0.0),
#  ('subgenomic sgr or fullgenomic', 0.0),
#  ('the fetal growth ratio', 0.0),
#  ('used fluorescence guided resection', 0.0),
#  ('v fgr oncogene homolog', 0.0),
#  ('velocities fetal growth restriction', 0.0),
#  ('whereas cortisol glucocorticoid receptor', 0.0),
#  ('0 001 fetal growth restriction', 0.0),
#  ('1 dependent fetal growth restriction', 0.0),
#  ('10th centile fetal growth restriction', 0.0),
#  ('11 including fluorescence guided resection', 0.0),
#  ('3 4 foetal growth restriction', 0.0),
#  ('31 community functional group richness', 0.0),
#  ('a or fetal growth restriction', 0.0),
#  ('abilities of fetal growth restriction', 0.0),
#  ('after prematurity fetal growth restriction', 0.0),
#  ('age lga fetal growth restriction', 0.0),
#  ('ala based fluorescence guided resection', 0.0),
#  ('an ovine fetal growth restriction', 0.0),
#  ('and correcting fetal growth restriction', 0.0),
#  ('and feed to gain ratio', 0.0),
#  ('and mean functional group richness', 0.0),
#  ('and tyrosine protein kinase fgr', 0.0),
#  ('any pregnancy fetal growth restriction', 0.0),
#  ('associated to fetal growth restriction', 0.0),
#  ('atherosclerosis and fetal growth restriction', 0.0),
#  ('between mean functional group richness', 0.0),
#  ('birth neonatal fractional growth rate', 0.0),
#  ('birth ptb fetal growth restriction', 0.0),
#  ('by fgr fetal growth restriction', 0.0),
#  ('by severe fetal growth restriction', 0.0),
#  ('callosum and foetal growth restriction', 0.0),
#  ('cd induced fetal growth restriction', 0.0),
#  ('characteristic of fetal growth restriction', 0.0),
#  ('cld including fetal growth restriction', 0.0),
#  ('cognitive development fetal growth restriction', 0.0),
#  ('combustion and flue gas recirculation', 0.0),
#  ('complications including fetal growth restriction', 0.0),
#  ('complications pc foetal growth restriction', 0.0),
#  ('contrary with fetal growth restriction', 0.0),
#  ('cord blood between growth restriction', 0.0),
#  ('demonstrate the fetal growth restriction', 0.0),
#  ('development of fetal growth retardation', 0.0),
#  ('diagnosis and fluorescence guided resection', 0.0),
#  ('diagnosis of fetal growth restriction', 0.0),
#  ('diastolic velocities fetal growth restriction', 0.0),
#  ('diseases and fetal growth restriction', 0.0),
#  ('dysfunction including fetal growth restriction', 0.0),
#  ('dysfunction placental fetal growth restriction', 0.0),
#  ('early onset fetal growth restriction', 0.0),
#  ('eclampsia and fetal growth restriction', 0.0),
#  ('eclampsia or fetal growth restriction', 0.0),
#  ('eclampsia pe fetal growth restriction', 0.0),
#  ('eclampsia pet fetal growth restriction', 0.0),
#  ('effects of fetal growth restriction', 0.0),
#  ('etiology of fetal growth restriction', 0.0),
#  ('evidence in fetal growth restriction', 0.0),
#  ('factors 1 fetal growth restriction', 0.0),
#  ('factors for fetal growth restriction', 0.0),
#  ('factors for fetal growth retardation', 0.0),
#  ('factors of fetal growth restriction', 0.0),
#  ('factors particularly fetal growth restriction', 0.0),
#  ('fetal life fetal growth restriction', 0.0),
#  ('fgr pregnancy fetal growth restriction', 0.0),
#  ('for example fetal growth restriction', 0.0),
#  ('for mean functional group richness', 0.0),
#  ('from glycyrrhizae radix et rhizome', 0.0),
#  ('from glycyrrhizae radix et rhizoma', 0.0),
#  ('further investigate fetal growth restriction', 0.0),
#  ('group used fluorescence guided resection', 0.0),
#  ('h tyrosine protein kinase fgr', 0.0),
#  ('hallmark of fetal growth restriction', 0.0),
#  ('harboring subgenomic sgr or fullgenomic', 0.0),
#  ('hcv full genomic rna replicon', 0.0),
#  ('hw and feed gain ratio', 0.0),
#  ('hypertension and fetal growth restriction', 0.0),
#  ('iir in fetal growth restriction', 0.0),
#  ('impaired development fetal growth restriction', 0.0),
#  ('in human fetal growth restriction', 0.0),
#  ('in severe fetal growth restriction', 0.0),
#  ('in the fetal growth ratio', 0.0),
#  ('in the fetal growth restriction', 0.0),
#  ('including 130 fetal growth retardation', 0.0),
#  ('increased in functional group richness', 0.0),
#  ('induced by fetal growth restriction', 0.0),
#  ('inflammatory responses fetal growth restriction', 0.0),
#  ('inhibition induced fetal growth restriction', 0.0),
#  ('insufficiency and fetal growth retardation', 0.0),
#  ('insufficiency mediated fetal growth restriction', 0.0),
#  ('investigate if fetal growth restriction', 0.0),
#  ('iugr or fetal growth restriction', 0.0),
#  ('ix ppix fluorescence guided resection', 0.0),
#  ('late pregnancy fetal growth restriction', 0.0),
#  ('line whereas cortisol glucocorticoid receptor', 0.0),
#  ('loping organs fetal growth restriction', 0.0),
#  ('maternal inflammation fetal growth restriction', 0.0),
#  ('mice with fetal growth restriction', 0.0),
#  ('model group fetal growth restriction', 0.0),
#  ('nmda receptor fetal growth restriction', 0.0),
#  ('no of fetal growth restriction', 0.0),
#  ('notably placentas from growth restriction', 0.0),
#  ('of gestational fetal growth restriction', 0.0),
#  ('of pathological fetal growth restriction', 0.0),
#  ('or ameliorate fetal growth restriction', 0.0),
#  ('or fluorescein fluorescence guided resection', 0.0),
#  ('outcomes in fetal growth restriction', 0.0),
#  ('pa and fetal growth restriction', 0.0),
#  ('paf induced fetal growth restriction', 0.0),
#  ('pathogenesis of fetal growth restriction', 0.0),
#  ('plac 1 fetal growth restriction', 0.0),
#  ('placental abruption fetal growth restriction', 0.0),
#  ('placental diseases fetal growth restriction', 0.0),
#  ('placentas from fetal growth restriction', 0.0),
#  ('plexus cysts foetal growth restriction', 0.0),
#  ('pm 18 fetal growth retardation', 0.0),
#  ('ppix mediated fluorescence guided resection', 0.0),
#  ('pre eclampsia fetal growth restriction', 0.0),
#  ('pregnancy complications fetal growth restriction', 0.0),
#  ('pregnancy revealed foetal growth restriction', 0.0),
#  ('r induced fetal growth restriction', 0.0),
#  ('rat with fetal growth restriction', 0.0),
#  ('resection in fluorescence guided resection', 0.0),
#  ('results of fetal growth restriction', 0.0),
#  ('role in fetal growth restriction', 0.0),
#  ('saponins from fermented ginseng root', 0.0),
#  ('scan identified fetal growth restriction', 0.0),
#  ('serum of fetal growth restriction', 0.0),
#  ('sga and fetal growth restriction', 0.0),
#  ('sonographic indicate fetal growth restriction', 0.0),
#  ('sr and functional group richness', 0.0),
#  ('stillbirth and fetal growth restriction', 0.0),
#  ('subsequent in fetal growth restriction', 0.0),
#  ('susceptible to fetal growth restriction', 0.0),
#  ('that induced fetal growth restriction', 0.0),
#  ('the future fetal growth restriction', 0.0),
#  ('the higher familial genetic risk', 0.0),
#  ('thresholds for fetal growth restriction', 0.0),
#  ('to fgr fetal growth restriction', 0.0),
#  ('to improve fetal growth restriction', 0.0),
#  ('types of fetal growth restriction', 0.0),
#  ('undernutrition including fetal growth restriction', 0.0),
#  ('viral v fgr oncogene homolog', 0.0),
#  ('waste is varying fluegas recirculation', 0.0),
#  ('we chose fetal growth restriction', 0.0),
#  ('with a severe fetal phenotype', 0.0),
#  ('with associated fetal growth restriction', 0.0),
#  ('with birthweight < 10th centile', 0.0),
#  ('with idiopathic fetal growth restriction', 0.0),
#  ('with increased functional group richness', 0.0),
#  ('women with fetal growth restriction', 0.0),
#  ('0 31 community functional group richness', 0.0),
#  ('10 11 including fluorescence guided resection', 0.0),
#  ('2 3 4 foetal growth restriction', 0.0),
#  ('5 ala based fluorescence guided resection', 0.0),
#  ('52 notably placentas from growth restriction', 0.0),
#  ('< 0 001 fetal growth restriction', 0.0),
#  ('a role in fetal growth restriction', 0.0),
#  ('able to improve fetal growth restriction', 0.0),
#  ('abnormal maternal inflammation fetal growth restriction', 0.0),
#  ('abruption pa and fetal growth restriction', 0.0),
#  ('adg and feed to gain ratio', 0.0),
#  ('ala ppix mediated fluorescence guided resection', 0.0),
#  ('also demonstrate the fetal growth restriction', 0.0),
#  ('an hcv full genomic rna replicon', 0.0),
#  ('and cognitive development fetal growth restriction', 0.0),
#  ('and dysfunction placental fetal growth restriction', 0.0),
#  ('and h tyrosine protein kinase fgr', 0.0),
#  ('and impaired development fetal growth restriction', 0.0),
#  ('and no of fetal growth restriction', 0.0),
#  ('and plac 1 fetal growth restriction', 0.0),
#  ('and subsequent in fetal growth restriction', 0.0),
#  ('any waste is varying fluegas recirculation', 0.0),
#  ('anomalies after prematurity fetal growth restriction', 0.0),
#  ('antenatal factors particularly fetal growth restriction', 0.0),
#  ('antepartum stillbirth and fetal growth restriction', 0.0),
#  ('are associated with fetal growth restriction', 0.0),
#  ('are susceptible to fetal growth restriction', 0.0),
#  ('as pe and fetal growth restriction', 0.0),
#  ('as preeclampsia and fetal growth restriction', 0.0),
#  ('associated with a severe fetal phenotype', 0.0),
#  ('associated with fgr fetal growth restriction', 0.0),
#  ('at birth neonatal fractional growth rate', 0.0),
#  ('biomarker for fgr fetal growth restriction', 0.0),
#  ('birth sga and fetal growth restriction', 0.0),
#  ('birthweight due to fetal growth restriction', 0.0),
#  ('blwr thresholds for fetal growth restriction', 0.0),
#  ('bold line whereas cortisol glucocorticoid receptor', 0.0),
#  ('cadmium exposure induced fetal growth restriction', 0.0),
#  ('causes by fgr fetal growth restriction', 0.0),
#  ('causes of pathological fetal growth restriction', 0.0),
#  ('cells harboring subgenomic sgr or fullgenomic', 0.0),
#  ('children with birthweight < 10th centile', 0.0),
#  ('choroid plexus cysts foetal growth restriction', 0.0),
#  ('cohort including 130 fetal growth retardation', 0.0),
#  ('commonest causes of fetal growth restriction', 0.0),
#  ('complications by severe fetal growth restriction', 0.0),
#  ('complications such as fetal growth restriction', 0.0),
#  ('contribute to fgr fetal growth restriction', 0.0),
#  ('cord serum of fetal growth restriction', 0.0),
#  ('corpus callosum and foetal growth restriction', 0.0),
#  ('could leads to fetal growth restriction', 0.0),
#  ('crude saponins from fermented ginseng root', 0.0),
#  ('d and tyrosine protein kinase fgr', 0.0),
#  ('decrement in the fetal growth ratio', 0.0),
#  ('delivery and correcting fetal growth restriction', 0.0),
#  ('deve loping organs fetal growth restriction', 0.0),
#  ('development early onset fetal growth restriction', 0.0),
#  ('doppler sonographic indicate fetal growth restriction', 0.0),
#  ('dysfunction atherosclerosis and fetal growth restriction', 0.0),
#  ('eclampsia and or fetal growth restriction', 0.0),
#  ('eclampsia pe and fetal growth restriction', 0.0),
#  ('end diastolic velocities fetal growth restriction', 0.0),
#  ('environmental factors 1 fetal growth restriction', 0.0),
#  ('factors paf induced fetal growth restriction', 0.0),
#  ('fetal rat with fetal growth restriction', 0.0),
#  ('flavonoids from glycyrrhizae radix et rhizome', 0.0),
#  ('flavonoids from glycyrrhizae radix et rhizoma', 0.0),
#  ('fluorescence or fluorescein fluorescence guided resection', 0.0),
#  ('for placental diseases fetal growth restriction', 0.0),
#  ('for the higher familial genetic risk', 0.0),
#  ('from pregnancy with fetal growth restriction', 0.0),
#  ('further investigate if fetal growth restriction', 0.0),
#  ('genetic characteristic of fetal growth restriction', 0.0),
#  ('gestational age lga fetal growth restriction', 0.0),
#  ('gestational exposure induced fetal growth restriction', 0.0),
#  ('group model group fetal growth restriction', 0.0),
#  ('health for example fetal growth restriction', 0.0),
#  ('human fgr pregnancy fetal growth restriction', 0.0),
#  ('hypothesis we chose fetal growth restriction', 0.0),
#  ('igf iir in fetal growth restriction', 0.0),
#  ('impaired development and fetal growth restriction', 0.0),
#  ('improve outcomes in fetal growth restriction', 0.0),
#  ('in an ovine fetal growth restriction', 0.0),
#  ('in any pregnancy fetal growth restriction', 0.0),
#  ('in fetal life fetal growth restriction', 0.0),
#  ('in late pregnancy fetal growth restriction', 0.0),
#  ('in mice with fetal growth restriction', 0.0),
#  ('in placentas from fetal growth restriction', 0.0),
#  ('in pregnancy with fetal growth restriction', 0.0),
#  ('in the future fetal growth restriction', 0.0),
#  ('infant undernutrition including fetal growth restriction', 0.0),
#  ('is associated to fetal growth restriction', 0.0),
#  ('key pregnancy complications fetal growth restriction', 0.0),
#  ('labour and or fetal growth restriction', 0.0),
#  ('local inflammatory responses fetal growth restriction', 0.0),
#  ('management for fgr fetal growth restriction', 0.0),
#  ('memory abilities of fetal growth restriction', 0.0),
#  ('more evidence in fetal growth restriction', 0.0),
#  ('most cases of fetal growth restriction', 0.0),
#  ('no cases of fetal growth restriction', 0.0),
#  ('nos inhibition induced fetal growth restriction', 0.0),
#  ('not complications by fetal growth restriction', 0.0),
#  ('obesity study of fetal growth restriction', 0.0),
#  ('of cd induced fetal growth restriction', 0.0),
#  ('of increased in functional group richness', 0.0),
#  ('of nmda receptor fetal growth restriction', 0.0),
#  ('of pm 18 fetal growth retardation', 0.0),
#  ('of preeclampsia and fetal growth restriction', 0.0),
#  ('of pregnancy revealed foetal growth restriction', 0.0),
#  ('of resection in fluorescence guided resection', 0.0),
#  ('offspring affected by fetal growth restriction', 0.0),
#  ('often associated with fetal growth restriction', 0.0),
#  ('pathological pregnancy with fetal growth restriction', 0.0),
#  ('pe with associated fetal growth restriction', 0.0),
#  ('photodynamic diagnosis and fluorescence guided resection', 0.0),
#  ('pigs leads to fetal growth restriction', 0.0),
#  ('placental development and fetal growth restriction', 0.0),
#  ('placental dysfunction including fetal growth restriction', 0.0),
#  ('placental insufficiency and fetal growth retardation', 0.0),
#  ('placental insufficiency mediated fetal growth restriction', 0.0),
#  ('plgf in the fetal growth restriction', 0.0),
#  ('possible causes of fetal growth restriction', 0.0),
#  ('pre eclampsia or fetal growth restriction', 0.0),
#  ('pre eclampsia pe fetal growth restriction', 0.0),
#  ('pre eclampsia pet fetal growth restriction', 0.0),
#  ('preclinical model of fetal growth restriction', 0.0),
#  ('predicted cld including fetal growth restriction', 0.0),
#  ('predominant causes of fetal growth restriction', 0.0),
#  ('preeclampsia placental abruption fetal growth restriction', 0.0),
#  ('pregnancy affected by fetal growth restriction', 0.0),
#  ('pregnancy complications including fetal growth restriction', 0.0),
#  ('pregnancy complications pc foetal growth restriction', 0.0),
#  ('pregnancy outcomes is fetal growth restriction', 0.0),
#  ('pregnant women with fetal growth restriction', 0.0),
#  ('present with fgr fetal growth restriction', 0.0),
#  ('preventable causes of fetal growth restriction', 0.0),
#  ('primarily due to fetal growth restriction', 0.0),
#  ('protoporphyrin ix ppix fluorescence guided resection', 0.0),
#  ('rat model of fetal growth restriction', 0.0),
#  ('related hypertension and fetal growth restriction', 0.0),
#  ('relationship between mean functional group richness', 0.0),
#  ('remodeling induced by fetal growth restriction', 0.0),
#  ('requires further investigate fetal growth restriction', 0.0),
#  ('restriction iugr or fetal growth restriction', 0.0),
#  ('results in severe fetal growth restriction', 0.0),
#  ('reverse or ameliorate fetal growth restriction', 0.0),
#  ('richness sr and functional group richness', 0.0),
#  ('risk factors for fetal growth restriction', 0.0),
#  ('risk factors for fetal growth retardation', 0.0),
#  ('risk factors of fetal growth restriction', 0.0),
#  ('sarcoma viral v fgr oncogene homolog', 0.0),
#  ('significantly with increased functional group richness', 0.0),
#  ('smoking leads to fetal growth restriction', 0.0),
#  ('specific types of fetal growth restriction', 0.0),
#  ('staged combustion and flue gas recirculation', 0.0),
#  ('stillbirth associated with fetal growth restriction', 0.0),
#  ('stillbirth such as fetal growth restriction', 0.0),
#  ('stress and mean functional group richness', 0.0),
#  ('study group used fluorescence guided resection', 0.0),
#  ('symbols a or fetal growth restriction', 0.0),
#  ('syndromes pre eclampsia fetal growth restriction', 0.0),
#  ('the 10th centile fetal growth restriction', 0.0),
#  ('the contrary with fetal growth restriction', 0.0),
#  ('the development of fetal growth retardation', 0.0),
#  ('the diagnosis of fetal growth restriction', 0.0),
#  ('the diseases and fetal growth restriction', 0.0),
#  ('the effects of fetal growth restriction', 0.0),
#  ('the etiology of fetal growth restriction', 0.0),
#  ('the pathogenesis of fetal growth restriction', 0.0),
#  ('the results of fetal growth restriction', 0.0),
#  ('the risk of fetal growth restriction', 0.0),
#  ('the study of fetal growth restriction', 0.0),
#  ('those complications by fetal growth restriction', 0.0),
#  ('toxicant that induced fetal growth restriction', 0.0),
#  ('transport in human fetal growth restriction', 0.0),
#  ('treatment for fgr fetal growth restriction', 0.0),
#  ('treatment for mean functional group richness', 0.0),
# ...
#  ('34 the diagnosis of fetal growth restriction', 0.0),
#  ('4 infant undernutrition including fetal growth restriction', 0.0),
#  ('6 0 31 community functional group richness', 0.0),
#  ('81 children with birthweight < 10th centile', 0.0),
#  ('a biomarker for fgr fetal growth restriction', 0.0),
#  ('a possible causes of fetal growth restriction', 0.0),
#  ('a predominant causes of fetal growth restriction', 0.0),
#  ('a rat model of fetal growth restriction', 0.0),
#  ('a treatment for fgr fetal growth restriction', 0.0),
#  ('a widespread causes of fetal growth restriction', 0.0),
#  ('account for the higher familial genetic risk', 0.0),
#  ('acid 5 ala based fluorescence guided resection', 0.0),
#  ('acid transport in human fetal growth restriction', 0.0),
#  ('action preeclampsia pe and fetal growth restriction', 0.0),
#  ('activated factors paf induced fetal growth restriction', 0.0),
#  ('adult health for example fetal growth restriction', 0.0),
#  ('adverse pregnancy outcomes is fetal growth restriction', 0.0),
#  ('age birth sga and fetal growth restriction', 0.0),
#  ('ahrr in placentas from fetal growth restriction', 0.0),
#  ('also able to improve fetal growth restriction', 0.0),
#  ('alter in fetal life fetal growth restriction', 0.0),
#  ('ama are susceptible to fetal growth restriction', 0.0),
#  ('an ultrasound scan identified fetal growth restriction', 0.0),
#  ('and cord serum of fetal growth restriction', 0.0),
#  ('and development early onset fetal growth restriction', 0.0),
#  ('and environmental factors 1 fetal growth restriction', 0.0),
#  ('and local inflammatory responses fetal growth restriction', 0.0),
#  ('and memory abilities of fetal growth restriction', 0.0),
#  ('and pregnancy complications by fetal growth restriction', 0.0),
#  ('and pregnancy complications pc foetal growth restriction', 0.0),
#  ('and preventable causes of fetal growth restriction', 0.0),
#  ('and specific types of fetal growth restriction', 0.0),
#  ('and stillbirth associated with fetal growth restriction', 0.0),
#  ('and the risk of fetal growth restriction', 0.0),
#  ('and those complications by fetal growth restriction', 0.0),
#  ('applications 10 11 including fluorescence guided resection', 0.0),
#  ('are associated with a severe fetal phenotype', 0.0),
#  ('are not complications by fetal growth restriction', 0.0),
#  ('are ttf 1 dependent fetal growth restriction', 0.0),
#  ('artery dysfunction atherosclerosis and fetal growth restriction', 0.0),
#  ('artery end diastolic velocities fetal growth restriction', 0.0),
#  ('as pre eclampsia and fetal growth restriction', 0.0),
#  ('as pre eclampsia pet fetal growth restriction', 0.0),
#  ('as preeclampsia pe and fetal growth restriction', 0.0),
#  ('as preterm birth ptb fetal growth restriction', 0.0),
#  ('biomarker for placental diseases fetal growth restriction', 0.0),
#  ('birth cohort including 130 fetal growth retardation', 0.0),
#  ('blue bold line whereas cortisol glucocorticoid receptor', 0.0),
#  ('by pre eclampsia pe fetal growth restriction', 0.0),
#  ('callosum choroid plexus cysts foetal growth restriction', 0.0),
#  ('cardiovascular remodeling induced by fetal growth restriction', 0.0),
#  ('cigarette smoking leads to fetal growth restriction', 0.0),
#  ('clinical management for fgr fetal growth restriction', 0.0),
#  ('color doppler sonographic indicate fetal growth restriction', 0.0),
#  ('combustion staged combustion and flue gas recirculation', 0.0),
#  ('cyclophilin d and tyrosine protein kinase fgr', 0.0),
#  ('declined significantly with increased functional group richness', 0.0),
#  ('delivery primarily due to fetal growth restriction', 0.0),
#  ('demand in an ovine fetal growth restriction', 0.0),
#  ('development pre eclampsia or fetal growth restriction', 0.0),
#  ('developmental toxicant that induced fetal growth restriction', 0.0),
#  ('effects of increased in functional group richness', 0.0),
#  ('etiology of cd induced fetal growth restriction', 0.0),
#  ('exchange and subsequent in fetal growth restriction', 0.0),
#  ('extent of resection in fluorescence guided resection', 0.0),
#  ('f treatment for mean functional group richness', 0.0),
#  ('factors plgf in the fetal growth restriction', 0.0),
#  ('factors predicted cld including fetal growth restriction', 0.0),
#  ('feline sarcoma viral v fgr oncogene homolog', 0.0),
#  ('fetal anomalies after prematurity fetal growth restriction', 0.0),
#  ('fgr causes of pathological fetal growth restriction', 0.0),
#  ('fgr in late pregnancy fetal growth restriction', 0.0),
#  ('fgr in the future fetal growth restriction', 0.0),
#  ('fgr preeclampsia pe and fetal growth restriction', 0.0),
#  ('flow in pregnancy with fetal growth restriction', 0.0),
#  ('following preterm birth ptb fetal growth restriction', 0.0),
#  ('for gestational age lga fetal growth restriction', 0.0),
#  ('for improve outcomes in fetal growth restriction', 0.0),
#  ('for placental insufficiency and fetal growth retardation', 0.0),
#  ('for the study of fetal growth restriction', 0.0),
#  ('from pathological pregnancy with fetal growth restriction', 0.0),
#  ('from placental dysfunction including fetal growth restriction', 0.0),
#  ('from pregnancy associated with fetal growth restriction', 0.0),
#  ('from pregnancy complications by fetal growth restriction', 0.0),
#  ('gain adg and feed to gain ratio', 0.0),
#  ('glioma study group used fluorescence guided resection', 0.0),
#  ('goal in any pregnancy fetal growth restriction', 0.0),
#  ('growth 52 notably placentas from growth restriction', 0.0),
#  ('growth and impaired development fetal growth restriction', 0.0),
#  ('growth in mice with fetal growth restriction', 0.0),
#  ('growth requires further investigate fetal growth restriction', 0.0),
#  ('growth restriction iugr or fetal growth restriction', 0.0),
#  ('guinea pigs leads to fetal growth restriction', 0.0),
#  ('ham weight hw and feed gain ratio', 0.0),
#  ('health and cognitive development fetal growth restriction', 0.0),
#  ('high risk factors of fetal growth restriction', 0.0),
#  ('high stress and mean functional group richness', 0.0),
#  ('human pe with associated fetal growth restriction', 0.0),
#  ('human pregnancy complications including fetal growth restriction', 0.0),
#  ('hypertension are associated with fetal growth restriction', 0.0),
#  ('identified risk factors for fetal growth retardation', 0.0),
#  ('impaired causes by fgr fetal growth restriction', 0.0),
#  ('in human fgr pregnancy fetal growth restriction', 0.0),
#  ('in impaired development and fetal growth restriction', 0.0),
#  ('in pre eclampsia and fetal growth restriction', 0.0),
#  ('in preclinical model of fetal growth restriction', 0.0),
#  ('in pregnancy affected by fetal growth restriction', 0.0),
#  ('in the development of fetal growth retardation', 0.0),
#  ('in the pathogenesis of fetal growth restriction', 0.0),
#  ('in umbilical cord blood between growth restriction', 0.0),
#  ('in utero leads to fetal growth restriction', 0.0),
#  ('individuals present with fgr fetal growth restriction', 0.0),
#  ('induced protoporphyrin ix ppix fluorescence guided resection', 0.0),
#  ('intraoperative photodynamic diagnosis and fluorescence guided resection',
#   0.0),
#  ('investigate the effects of fetal growth restriction', 0.0),
#  ('ireland pre eclampsia and fetal growth restriction', 0.0),
#  ('largest decrement in the fetal growth ratio', 0.0),
#  ('late gestational exposure induced fetal growth restriction', 0.0),
#  ('low birthweight due to fetal growth restriction', 0.0),
#  ('lysates most cases of fetal growth restriction', 0.0),
#  ('main hypothesis we chose fetal growth restriction', 0.0),
#  ('major risk factors for fetal growth restriction', 0.0),
#  ('maternal obesity study of fetal growth restriction', 0.0),
#  ('might contribute to fgr fetal growth restriction', 0.0),
#  ('much more evidence in fetal growth restriction', 0.0),
#  ('newborn offspring affected by fetal growth restriction', 0.0),
#  ('nine pregnant women with fetal growth restriction', 0.0),
#  ('normal and dysfunction placental fetal growth restriction', 0.0),
#  ('normal group model group fetal growth restriction', 0.0),
#  ('obstetric syndromes pre eclampsia fetal growth restriction', 0.0),
#  ('of ala ppix mediated fluorescence guided resection', 0.0),
#  ('of any waste is varying fluegas recirculation', 0.0),
#  ('of antenatal factors particularly fetal growth restriction', 0.0),
#  ('of antepartum stillbirth and fetal growth restriction', 0.0),
#  ('of crude saponins from fermented ginseng root', 0.0),
#  ('of fetal rat with fetal growth restriction', 0.0),
#  ('of i r induced fetal growth restriction', 0.0),
#  ('of pregnancy associated with fetal growth restriction', 0.0),
#  ('of the diseases and fetal growth restriction', 0.0),
#  ('on the contrary with fetal growth restriction', 0.0),
#  ('onset preeclampsia placental abruption fetal growth restriction', 0.0),
#  ('open symbols a or fetal growth restriction', 0.0),
#  ('or an hcv full genomic rna replicon', 0.0),
#  ('p < 0 001 fetal growth restriction', 0.0),
#  ('pappa2 and plac 1 fetal growth restriction', 0.0),
#  ('pathogenesis of preeclampsia and fetal growth restriction', 0.0),
#  ('pathological associated with fgr fetal growth restriction', 0.0),
#  ('placental abruption pa and fetal growth restriction', 0.0),
#  ('placentas from pregnancy with fetal growth restriction', 0.0),
#  ('play a role in fetal growth restriction', 0.0),
#  ('poor placental development and fetal growth restriction', 0.0),
#  ('ppid and h tyrosine protein kinase fgr', 0.0),
#  ('ppix fluorescence or fluorescein fluorescence guided resection', 0.0),
#  ('pre eclampsia and or fetal growth restriction', 0.0),
#  ('pre eclampsia pe and fetal growth restriction', 0.0),
#  ('predominant the results of fetal growth restriction', 0.0),
#  ('preeclampsia often associated with fetal growth restriction', 0.0),
#  ('pregnancy complications by severe fetal growth restriction', 0.0),
#  ('pregnancy is associated to fetal growth restriction', 0.0),
#  ('pregnancy outcomes such as fetal growth restriction', 0.0),
#  ('pregnancy related hypertension and fetal growth restriction', 0.0),
#  ('pregnancy whose outcomes is fetal growth restriction', 0.0),
#  ('preterm delivery and correcting fetal growth restriction', 0.0),
#  ('preterm labour and or fetal growth restriction', 0.0),
#  ('ratio blwr thresholds for fetal growth restriction', 0.0),
#  ('receptor igf iir in fetal growth restriction', 0.0),
#  ('reperfusion i r induced fetal growth restriction', 0.0),
#  ('replicon cells harboring subgenomic sgr or fullgenomic', 0.0),
#  ('restriction placental insufficiency mediated fetal growth restriction',
#   0.0),
#  ('risk of pm 18 fetal growth retardation', 0.0),
#  ('rodents also demonstrate the fetal growth restriction', 0.0),
#  ('size at birth neonatal fractional growth rate', 0.0),
#  ('status results in severe fetal growth restriction', 0.0),
#  ('stress relationship between mean functional group richness', 0.0),
#  ('subunit of nmda receptor fetal growth restriction', 0.0),
#  ('such as pe and fetal growth restriction', 0.0),
#  ('such as preeclampsia and fetal growth restriction', 0.0),
#  ('synthase nos inhibition induced fetal growth restriction', 0.0),
#  ('than the 10th centile fetal growth restriction', 0.0),
#  ('that women with idiopathic fetal growth restriction', 0.0),
#  ('the commonest causes of fetal growth restriction', 0.0),
#  ('the corpus callosum and foetal growth restriction', 0.0),
#  ('the deve loping organs fetal growth restriction', 0.0),
#  ('the flavonoids from glycyrrhizae radix et rhizome', 0.0),
#  ('the genetic characteristic of fetal growth restriction', 0.0),
#  ('the increased risk of fetal growth restriction', 0.0),
#  ('to further investigate if fetal growth restriction', 0.0),
#  ('to reverse or ameliorate fetal growth restriction', 0.0),
#  ('to stillbirth such as fetal growth restriction', 0.0),
#  ('two key pregnancy complications fetal growth restriction', 0.0),
#  ('variation and no of fetal growth restriction', 0.0),
#  ('weeks of pregnancy revealed foetal growth restriction', 0.0),
#  ('were no cases of fetal growth restriction', 0.0),
#  ('which could leads to fetal growth restriction', 0.0),
#  ('with abnormal maternal inflammation fetal growth restriction', 0.0),
#  ('women with preeclampsia and fetal growth restriction', 0.0),
#  ('1 of fetal rat with fetal growth restriction', 0.0),
#  ('1 total flavonoids from glycyrrhizae radix et rhizoma', 0.0),
#  ('10 open symbols a or fetal growth restriction', 0.0),
#  ('25 weeks of pregnancy revealed foetal growth restriction', 0.0),
#  ('3 4 infant undernutrition including fetal growth restriction', 0.0),
#  ('3 predominant the results of fetal growth restriction', 0.0),
#  ('a developmental toxicant that induced fetal growth restriction', 0.0),
#  ('a major risk factors for fetal growth restriction', 0.0),
#  ('aa demand in an ovine fetal growth restriction', 0.0),
#  ('abilities impaired causes by fgr fetal growth restriction', 0.0),
#  ('abundance declined significantly with increased functional group richness',
#   0.0),
#  ('adaptation might contribute to fgr fetal growth restriction', 0.0),
#  ('adulthood 1 2 3 4 foetal growth restriction', 0.0),
#  ('adverse perinatal outcomes such as fetal growth restriction', 0.0),
#  ('adverse pregnancy outcomes such as fetal growth restriction', 0.0),
#  ('aetiologies in the pathogenesis of fetal growth restriction', 0.0),
#  ('age 34 the diagnosis of fetal growth restriction', 0.0),
#  ('age ama are susceptible to fetal growth restriction', 0.0),
#  ('aim to further investigate if fetal growth restriction', 0.0),
#  ('ala glioma study group used fluorescence guided resection', 0.0),
#  ('ala induced protoporphyrin ix ppix fluorescence guided resection', 0.0),
#  ('amino acid transport in human fetal growth restriction', 0.0),
#  ('aminolevulinic acid 5 ala based fluorescence guided resection', 0.0),
#  ('and ahrr in placentas from fetal growth restriction', 0.0),
#  ('and fgr preeclampsia pe and fetal growth restriction', 0.0),
#  ('and high risk factors of fetal growth restriction', 0.0),
#  ('and ireland pre eclampsia and fetal growth restriction', 0.0),
#  ('and late gestational exposure induced fetal growth restriction', 0.0),
#  ('and maternal obesity study of fetal growth restriction', 0.0),
#  ('and placentas from pregnancy with fetal growth restriction', 0.0),
#  ('and the increased risk of fetal growth restriction', 0.0),
#  ('antenatal factors predicted cld including fetal growth restriction', 0.0),
#  ('as a biomarker for fgr fetal growth restriction', 0.0),
#  ('as a possible causes of fetal growth restriction', 0.0),
#  ('as a treatment for fgr fetal growth restriction', 0.0),
#  ('as cyclophilin d and tyrosine protein kinase fgr', 0.0),
#  ('associated with abnormal maternal inflammation fetal growth restriction',
#   0.0),
#  ('associated with increased risk of fetal growth restriction', 0.0),
#  ('baby two key pregnancy complications fetal growth restriction', 0.0),
#  ('before 32 weeks of gestational fetal growth restriction', 0.0),
#  ('bft ham weight hw and feed gain ratio', 0.0),
#  ('birth and stillbirth associated with fetal growth restriction', 0.0),
#  ('blood flow in pregnancy with fetal growth restriction', 0.0),
#  ('by pre eclampsia and or fetal growth restriction', 0.0),
#  ('c f treatment for mean functional group richness', 0.0),
#  ('capacity in pre eclampsia and fetal growth restriction', 0.0),
#  ('causes of antepartum stillbirth and fetal growth restriction', 0.0),
#  ('choline status results in severe fetal growth restriction', 0.0),
#  ('clearance receptor igf iir in fetal growth restriction', 0.0),
#  ('common and preventable causes of fetal growth restriction', 0.0),
#  ('common pregnancy complications such as fetal growth restriction', 0.0),
#  ('complications by pre eclampsia pe fetal growth restriction', 0.0),
#  ('complications of pregnancy associated with fetal growth restriction', 0.0),
#  ('complications pre eclampsia pe and fetal growth restriction', 0.0),
#  ('complications such as pe and fetal growth restriction', 0.0),
#  ('complications such as preeclampsia and fetal growth restriction', 0.0),
#  ('composition of any waste is varying fluegas recirculation', 0.0),
#  ...]

# %%
longforms0 = miners['FGR'].get_longforms()

# %%
longforms0
# Out:
# [('fetal growth restriction', 192.85142857142858),
#  ('fluorescence guided resection', 7.0),
#  ('functional group richness', 5.142857142857142),
#  ('fetal growth retardation', 4.0),
#  ('saponins from actinidia arguta radix saa total flavonoids from glycyrrhizae radix et rhizoma',
#   2),
#  ('ratio', 1.3333333333333333)]

# %%
longforms = longforms0[:-2]

# %%
list(enumerate(top))
# Out:
# [(0, ('fetal growth restriction', 192.85142857142858)),
#  (1, ('of fetal growth restriction', 26.275862068965512)),
#  (2, ('and fetal growth restriction', 17.81818181818182)),
#  (3, ('growth restriction', 17.427230046948353)),
#  (4, ('with fetal growth restriction', 9.23076923076923)),
#  (5, ('fluorescence guided resection', 7.0)),
#  (6, ('induced fetal growth restriction', 6.5)),
#  (7, ('to fetal growth restriction', 5.25)),
#  (8, ('functional group richness', 5.142857142857142)),
#  (9, ('foetal growth restriction', 5.0)),
#  (10, ('in fetal growth restriction', 5.0)),
#  (11, ('preeclampsia pe and fetal growth restriction', 5.0)),
#  (12, ('fgr fetal growth restriction', 4.857142857142858)),
#  (13, ('by fetal growth restriction', 4.444444444444445)),
#  (14, ('fetal growth retardation', 4.0)),
#  (15, ('associated with fetal growth restriction', 4.0)),
#  (16, ('causes of fetal growth restriction', 4.0)),
#  (17, ('such as fetal growth restriction', 3.6666666666666665)),
#  (18, ('or fetal growth restriction', 3.6)),
#  (19, ('pe and fetal growth restriction', 3.25)),
#  (20, ('including fetal growth restriction', 3.0)),
#  (21, ('complications by fetal growth restriction', 3.0)),
#  (22, ('leads to fetal growth restriction', 3.0)),
#  (23, ('pregnancy complications by fetal growth restriction', 2.5)),
#  (24, ('mean functional group richness', 2.0)),
#  (25, ('pregnancy fetal growth restriction', 2.0)),
#  (26, ('severe fetal growth restriction', 2.0)),
#  (27, ('for fgr fetal growth restriction', 2.0)),
#  (28, ('preeclampsia and fetal growth restriction', 2.0)),
#  (29, ('pregnancy with fetal growth restriction', 2.0)),
#  (30, ('increased risk of fetal growth restriction', 2.0)),
#  (31, ('pre eclampsia and fetal growth restriction', 2.0)),
#  (32,
#   ('iated vasodilatory responses in placentas from pregnancy associated with fetal growth restriction',
#    2)),
#  (33,
#   ('plot showing differentially methylation positions in umbilical cord blood between growth restriction',
#    2)),
#  (34,
#   ('saponins from actinidia arguta radix saa total flavonoids from glycyrrhizae radix et rhizoma',
#    2)),
#  (35, ('risk of fetal growth restriction', 1.6)),
#  (36, ('ratio', 1.3333333333333333)),
#  (37, ('outcomes is fetal growth restriction', 1.3333333333333333)),
#  (38, ('study of fetal growth restriction', 1.3333333333333333)),
#  (39, ('outcomes such as fetal growth restriction', 1.3333333333333333)),
#  (40,
#   ('pregnancy associated with fetal growth restriction', 1.3333333333333333)),
#  (41,
#   ('total flavonoids from glycyrrhizae radix et rhizoma', 1.3333333333333333)),
#  (42, ('recirculation', 1.0)),
#  (43, ('gain ratio', 1.0)),
#  (44, ('1 fetal growth restriction', 1.0)),
#  (45, ('development fetal growth restriction', 1.0)),
#  (46, ('for fetal growth restriction', 1.0)),
#  (47, ('the fetal growth restriction', 1.0)),
#  (48, ('tyrosine protein kinase fgr', 1.0)),
#  (49, ('affected by fetal growth restriction', 1.0)),
#  (50, ('and or fetal growth restriction', 1.0)),
#  (51, ('cases of fetal growth restriction', 1.0)),
#  (52, ('development and fetal growth restriction', 1.0)),
#  (53, ('due to fetal growth restriction', 1.0)),
#  (54, ('exposure induced fetal growth restriction', 1.0)),
#  (55, ('model of fetal growth restriction', 1.0)),
#  (56, ('with fgr fetal growth restriction', 1.0)),
#  (57, ('a hallmark of fetal growth restriction', 1)),
#  (58, ('i r induced fetal growth restriction', 1.0)),
#  (59, ('preterm birth ptb fetal growth restriction', 1.0)),
#  (60, ('although the etiology of fetal growth restriction', 1)),
#  (61, ('in pregnancy complications by fetal growth restriction', 1.0)),
#  (62, ('maternal cadmium exposure induced fetal growth restriction', 1)),
#  (63, ('perinatal outcomes such as fetal growth restriction', 1.0)),
#  (64, ('pregnancy complications such as fetal growth restriction', 1.0)),
#  (65, ('species richness sr and functional group richness', 1)),
#  (66, ('with increased risk of fetal growth restriction', 1.0)),
#  (67,
#   ('excluding fetal anomalies after prematurity fetal growth restriction', 1)),
#  (68, ('model for the study of fetal growth restriction', 1.0)),
#  (69, ('we investigate the effects of fetal growth restriction', 1)),
#  (70,
#   ('eurological deficits pulmonary artery dysfunction atherosclerosis and fetal growth restriction',
#    1)),
#  (71,
#   ('pregnancy disorders such as preterm birth ptb fetal growth restriction',
#    1)),
#  (72,
#   ('a cohort study including 81 children with birthweight < 10th centile', 1)),
#  (73,
#   ('analyses investigate the contribute of antenatal factors particularly fetal growth restriction',
#    1)),
#  (74,
#   ('cadmium cd is a developmental toxicant that induced fetal growth restriction',
#    1)),
#  (75,
#   ('cadmium cd is linked with increased risk of fetal growth restriction', 1)),
#  (76,
#   ('nd perinatal complications associated with abnormal maternal inflammation fetal growth restriction',
#    1)),
#  (77,
#   ('omplications of fetal growth restriction placental insufficiency mediated fetal growth restriction',
#    1)),
#  (78,
#   ('tcomes particularly those results from placental dysfunction including fetal growth restriction',
#    1)),
#  (79,
#   ('vitamin d deficiency in pregnancy is associated to fetal growth restriction',
#    1)),
#  (80,
#   ('we test the hypothesis that women with idiopathic fetal growth restriction',
#    1)),
#  (81,
#   ('astfeeding and postnatal nutrition on cardiovascular remodeling induced by fetal growth restriction',
#    1)),
#  (82,
#   ('cd exposure during pregnancy and the increased risk of fetal growth restriction',
#    1.0)),
#  (83,
#   ('chromosomal abnormal which would impact clinical management for fgr fetal growth restriction',
#    1)),
#  (84,
#   ('educed umbilical artery glutamate concentrations in human fgr pregnancy fetal growth restriction',
#    1)),
#  (85,
#   ('eness of the combination of intraoperative photodynamic diagnosis and fluorescence guided resection',
#    1)),
#  (86,
#   ('haemodynamics in normotensive women with pregnancy complications by severe fetal growth restriction',
#    1)),
#  (87,
#   ('lity in functional group abundance declined significantly with increased functional group richness',
#    1)),
#  (88,
#   ('maternal nutrient restriction mnr is a widespread causes of fetal growth restriction',
#    1)),
#  (89,
#   ('modulated by maternal fetal placental and environmental factors 1 fetal growth restriction',
#    1)),
#  (90,
#   ('nancy complications by severe early onset preeclampsia placental abruption fetal growth restriction',
#    1)),
#  (91,
#   ('p including preeclampsia or gestational hypertension are associated with fetal growth restriction',
#    1)),
#  (92,
#   ('pathophysiology of chronic nitric oxide synthase nos inhibition induced fetal growth restriction',
#    1)),
#  (93,
#   ('th restriction with compromised umbilical artery end diastolic velocities fetal growth restriction',
#    1)),
#  (94,
#   ('there is no proven therapy to reverse or ameliorate fetal growth restriction',
#    1)),
#  (95,
#   ('three combustion modes including direct combustion staged combustion and flue gas recirculation',
#    1)),
#  (96,
#   ('to investigate the incidence and high risk factors of fetal growth restriction',
#    1)),
#  (97,
#   ('well as other fluorescence imaging applications 10 11 including fluorescence guided resection',
#    1)),
#  (98,
#   ('00 000 infant death annually 3 4 infant undernutrition including fetal growth restriction',
#    1)),
#  (99,
#   ('administration of lps induced a systemic and local inflammatory responses fetal growth restriction',
#    1)),
#  (100,
#   ('al microarray analysis cma to investigate the genetic characteristic of fetal growth restriction',
#    1)),
#  (101,
#   ('apan taking advantage of ala induced ppix fluorescence or fluorescein fluorescence guided resection',
#    1)),
#  (102,
#   ('aturation 1 however excess glucocorticoid exposure in utero leads to fetal growth restriction',
#    1)),
#  (103,
#   ('d maternal obesity are serious complications of pregnancy associated with fetal growth restriction',
#    1)),
#  (104,
#   ('erine fetal death iufd preeclampsia pe placental abruption pa and fetal growth restriction',
#    1)),
#  (105,
#   ('fetoprotein afp on second trimester screening and development early onset fetal growth restriction',
#    1)),
#  (106,
#   ('fficiency results in impaired feto placental exchange and subsequent in fetal growth restriction',
#    1)),
#  (107,
#   ('fpr2 and trophoblast and endothelial functional in pregnancy affected by fetal growth restriction',
#    1)),
#  (108,
#   ('free beta hcg fβhcg increased levels and pregnancy complications pc foetal growth restriction',
#    1)),
#  (109,
#   ('h3k27ac occupancy in healthy placentas and placentas from pregnancy with fetal growth restriction',
#    1)),
#  (110,
#   ('he importance of fmvd regulation in normal and dysfunction placental fetal growth restriction',
#    1)),
#  (111,
#   ('icantly adverse effects on fetal neonatal health and cognitive development fetal growth restriction',
#    1)),
#  (112,
#   ('increased in placentas from pregnancy complications by pre eclampsia pe fetal growth restriction',
#    1)),
#  (113,
#   ('increased prevalence of low birthweight lbw delivery primarily due to fetal growth restriction',
#    1)),
#  (114,
#   ('lasting consequences for mother and baby two key pregnancy complications fetal growth restriction',
#    1)),
#  (115,
#   ('ly hydrocephalus agenesis of the corpus callosum choroid plexus cysts foetal growth restriction',
#    1)),
#  (116,
#   ('matically decrease rna replication in hcv replicon cells harboring subgenomic sgr or fullgenomic',
#    1)),
#  (117,
#   ('methylation patterns of syn1 and syn2 from pregnancy complications by fetal growth restriction',
#    1)),
#  (118,
#   ('mong glioma treatment strategy 5 aminolevulinic acid 5 ala based fluorescence guided resection',
#    1)),
#  (119,
#   ('n similarly with antenatal hypoxic exposure rodents also demonstrate the fetal growth restriction',
#    1)),
#  (120,
#   ('nd its receptor in modulated fetal growth requires further investigate fetal growth restriction',
#    1)),
#  (121,
#   ('pathological sga is known as intrauterine growth restriction iugr or fetal growth restriction',
#    1)),
#  (122,
#   ('placental insufficiency is a major causes of antepartum stillbirth and fetal growth restriction',
#    1)),
#  (123,
#   ('rapeutic strategy to improve uteroplacental blood flow in pregnancy with fetal growth restriction',
#    1)),
#  (124,
#   ('raphic findings ultrasound scan after 25 weeks of pregnancy revealed foetal growth restriction',
#    1)),
#  (125,
#   ('regnant women development serious complications such as preeclampsia pe and fetal growth restriction',
#    1)),
#  (126,
#   ('seq in healthy placentas and placentas from pathological pregnancy with fetal growth restriction',
#    1)),
#  (127,
#   ('telomerase activated levels on the placental pathological associated with fgr fetal growth restriction',
#    1)),
#  (128,
#   ('th weight in uncomplicated pregnancy up and pregnancy complications by fetal growth restriction',
#    1)),
#  (129,
#   ('the cardiac consequences of maternal malnutrition a predominant causes of fetal growth restriction',
#    1)),
#  (130,
#   ('the pathological of the pregnancy complications pre eclampsia pe and fetal growth restriction',
#    1)),
#  (131,
#   ('tive therapeutic strategy for inflammation induced fgr in late pregnancy fetal growth restriction',
#    1)),
#  (132,
#   ('underwent elective cesarean section with large for gestational age lga fetal growth restriction',
#    1)),
#  (133,
#   ('we determinant brain to liver weight ratio blwr thresholds for fetal growth restriction',
#    1)),
#  (134,
#   ('acental igf2 dna methylation the associated were much more evidence in fetal growth restriction',
#    1)),
#  (135,
#   ('al leptin levels can indicate changes in color doppler sonographic indicate fetal growth restriction',
#    1)),
#  (136,
#   ('and has shown promising results in increased extent of resection in fluorescence guided resection',
#    1)),
#  (137,
#   ('antepartum bleeding of unknown origin increased the risk of pm 18 fetal growth retardation',
#    1)),
#  (138,
#   ('caucasian women were including as cases when an ultrasound scan identified fetal growth restriction',
#    1)),
#  (139,
#   ('d fetoplacental blood flow are putative aetiologies in the pathogenesis of fetal growth restriction',
#    1)),
#  (140,
#   ('d to explore plasma mirnas as potential biomarker for placental diseases fetal growth restriction',
#    1)),
#  (141,
#   ('en environmental stress low stress medium stress high stress and mean functional group richness',
#    1)),
#  (142,
#   ('esses associated with pe can restriction fetal growth and impaired development fetal growth restriction',
#    1)),
#  (143,
#   ('f aryl hydrocarbon interacting protein aip g ppid and h tyrosine protein kinase fgr',
#    1)),
#  (144,
#   ('f eor is 5 aminolevulinic acid ala induced protoporphyrin ix ppix fluorescence guided resection',
#    1)),
#  (145,
#   ('f the candidates in the progression of preeclampsia often associated with fetal growth restriction',
#    1)),
#  (146,
#   ('gpr30 in pregnancy or in pregnancy complications such as preeclampsia and fetal growth restriction',
#    1)),
#  (147,
#   ('iction iugr surrogates iugr small for gestational age birth sga and fetal growth restriction',
#    1)),
#  (148,
#   ('in decidual tissue from pregnancy complications by pre eclampsia and or fetal growth restriction',
#    1)),
#  (149,
#   ('ined whether maternal nutrient restriction mnr in guinea pigs leads to fetal growth restriction',
#    1)),
#  (150,
#   ('l age and birth weight severe antenatal factors predicted cld including fetal growth restriction',
#    1)),
#  (151,
#   ('l dysfunction under major obstetric diseases such as pre eclampsia and fetal growth restriction',
#    1)),
#  (152,
#   ('lampsia eope are used in predicted adverse perinatal outcomes such as fetal growth restriction',
#    1)),
#  (153,
#   ('lgf are one of the hallmark of human pregnancy complications including fetal growth restriction',
#    1)),
#  (154,
#   ('lling is an early characteristic of common pregnancy complications such as fetal growth restriction',
#    1)),
#  (155,
#   ('long term consequences of such genes expression alter in fetal life fetal growth restriction',
#    1)),
#  (156,
#   ('maternal cadmium cd exposure during pregnancy and the increased risk of fetal growth restriction',
#    1)),
#  (157,
#   ('maternal obesity is associated with macrosomia or on the contrary with fetal growth restriction',
#    1)),
#  (158,
#   ('n placental structure in clinical conditions related to stillbirth such as fetal growth restriction',
#    1)),
#  (159,
#   ('n vesicle study suggest impaired placental amino acid transport in human fetal growth restriction',
#    1)),
#  (160,
#   ('of what has been term the great obstetric syndromes pre eclampsia fetal growth restriction',
#    1)),
#  (161,
#   ('ording used in multiple sub populations of individuals present with fgr fetal growth restriction',
#    1)),
#  (162,
#   ('p between maternal serum ferritin and concentrations and specific types of fetal growth restriction',
#    1)),
#  (163,
#   ('plied to placental tissue from live birth and stillbirth associated with fetal growth restriction',
#    1)),
#  (164,
#   ('pregnancy in women of advanced maternal age ama are susceptible to fetal growth restriction',
#    1)),
#  (165,
#   ('pressure in pe but results in preventable preterm delivery and correcting fetal growth restriction',
#    1)),
#  (166,
#   ('rn pharmacology research has also reported that the flavonoids from glycyrrhizae radix et rhizome',
#    1)),
#  (167,
#   ('ronment failure of this interplay leads to poor placental development and fetal growth restriction',
#    1)),
#  (168,
#   ('rtisol s permissive effects denoted by the blue bold line whereas cortisol glucocorticoid receptor',
#    1)),
#  (169,
#   ('se control study within the prospective wenzhou birth cohort including 130 fetal growth retardation',
#    1)),
#  (170,
#   ('that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#    1.0)),
#  (171,
#   ('the pathogenesis of pe and associated adverse pregnancy outcomes such as fetal growth restriction',
#    1)),
#  (172,
#   ('tic modalities for learning and memory abilities impaired causes by fgr fetal growth restriction',
#    1)),
#  (173,
#   ('timate the associated between hyperemesis gravidarum hg and the risk of fetal growth restriction',
#    1)),
#  (174,
#   ('tory cytokine has been implicated in the pathogenesis of preeclampsia and fetal growth restriction',
#    1)),
#  (175,
#   ('vailability appears to be an attractive strategy for improve outcomes in fetal growth restriction',
#    1)),
#  (176,
#   ('vascular effects of nitric oxide no donors in pregnancy complications by fetal growth restriction',
#    1)),
#  (177,
#   ('vasoactive peptides cgrp adm and adm2 in pregnancy complications such as fetal growth restriction',
#    1)),
#  (178,
#   ('y assist in assessing possible mechanisms of action preeclampsia pe and fetal growth restriction',
#    1)),
#  (179,
#   ('y predispose to placental mediated diseases such as pre eclampsia pet fetal growth restriction',
#    1)),
#  (180,
#   ('adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#    1.0)),
#  (181,
#   ('ally relevant mouse model of human pregnancy complications such as pe and fetal growth restriction',
#    1)),
#  (182,
#   ('and prognosis of fetus diagnosed with fgr before 32 weeks of gestational fetal growth restriction',
#    1)),
#  (183,
#   ('ant emissions when the charging rate or composition of any waste is varying fluegas recirculation',
#    1)),
#  (184,
#   ('during pregnancy remains one of the most common and preventable causes of fetal growth restriction',
#    1)),
#  (185,
#   ('ese optimal birth weight standard by gestational age 34 the diagnosis of fetal growth restriction',
#    1)),
#  (186,
#   ('ethylation of 2 growth related genes igf2 and ahrr in placentas from fetal growth restriction',
#    1)),
#  (187,
#   ('ex peptidylprolyl isomerase d ppid also known as cyclophilin d and tyrosine protein kinase fgr',
#    1)),
#  (188,
#   ('ficance of endothelin 1 et 1 in platelet activated factors paf induced fetal growth restriction',
#    1)),
#  (189,
#   ('from study on autophagy in the placentas from women with preeclampsia and fetal growth restriction',
#    1)),
#  (190,
#   ('fter the stimulation as shown in figure 1 total flavonoids from glycyrrhizae radix et rhizoma',
#    1)),
#  (191,
#   ('h in normal pregnancy failure of this adaptation might contribute to fgr fetal growth restriction',
#    1)),
#  (192,
#   ('he effects of other vasoactive agents 9 fifty nine pregnant women with fetal growth restriction',
#    1)),
#  (193,
#   ('ing of delivery placental insufficiency is one of the commonest causes of fetal growth restriction',
#    1)),
#  (194,
#   ('l cadmium exposure via the environment and or cigarette smoking leads to fetal growth restriction',
#    1)),
#  (195,
#   ('lar flow is at least in part responses for placental insufficiency and fetal growth retardation',
#    1)),
#  (196,
#   ('lf of pathological society of great britain and ireland pre eclampsia and fetal growth restriction',
#    1)),
#  (197,
#   ('medium stress but not under low or high stress relationship between mean functional group richness',
#    1)),
#  (198,
#   ('min intervention on insulin resistance during catch up growth in mice with fetal growth restriction',
#    1)),
#  (199,
#   ('mitogen activated protein kinase phosphatase 1 mkp 1 of fetal rat with fetal growth restriction',
#    1)),
#  (200,
#   ('mor imaging recent study suggest that the used of ala ppix mediated fluorescence guided resection',
#    1)),
#  (201,
#   ('ned in pregnant dams reduced folate and choline status results in severe fetal growth restriction',
#    1)),
#  (202,
#   ('nsulin resistance and coronary heart diseases during adulthood 1 2 3 4 foetal growth restriction',
#    1)),
#  (203,
#   ('olymorphism apo was defined as one of the following preterm birth ptb fetal growth restriction',
#    1)),
#  (204,
#   ('on between maternal cd exposure during pregnancy and the increased risk of fetal growth restriction',
#    1)),
#  (205,
#   ('pm can leads to poor neonatal outcomes including low birthweight due to fetal growth restriction',
#    1)),
#  (206,
#   ('potential as a therapeutic strategy for pe and fgr preeclampsia pe and fetal growth restriction',
#    1)),
#  (207,
#   ('releasing factors crf and urocortin are elevated in preterm labour and or fetal growth restriction',
#    1)),
#  (208,
#   ('revealed that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#    1)),
#  (209,
#   ('rters gluts has been poor characterized in the etiology of cd induced fetal growth restriction',
#    1)),
#  (210,
#   ('s c jejuni and c fetus infections results in impaired development and fetal growth restriction',
#    1)),
#  (211,
#   ('se or between preeclamptic pregnancy that are or are not complications by fetal growth restriction',
#    1)),
#  (212,
#   ('size all analyses were conducted in statistica v 6 0 31 community functional group richness',
#    1)),
#  (213,
#   ('the rat were randomly assigned into 3 group normal group model group fetal growth restriction',
#    1)),
#  (214,
#   ('this test to evaluate placental gas exchange capacity in pre eclampsia and fetal growth restriction',
#    1)),
#  (215,
#   ('tion of reduced fetal movements rfm is associated with increased risk of fetal growth restriction',
#    1)),
#  (216,
#   ('toll like receptor 4 tlr4 in uterine ischemia reperfusion i r induced fetal growth restriction',
#    1)),
#  (217,
#   ('was to examine the role of hereditary thrombophilia in the development of fetal growth retardation',
#    1)),
#  (218,
#   ('y onset fgr summary of treatment strategy used in preclinical model of fetal growth restriction',
#    1)),
#  (219,
#   ('a clinical severe subgroup of women with early onset of the diseases and fetal growth restriction',
#    1)),
#  (220,
#   ('ast cancer and analyzed these four study together to account for the higher familial genetic risk',
#    1)),
#  (221,
#   ('ation a decrease in water volume would alter the effects of increased in functional group richness',
#    1)),
#  (222,
#   ('cts of placental restriction of fetal growth pr on size at birth neonatal fractional growth rate',
#    1)),
#  (223,
#   ('e regarding the up or down regulation of no in pregnancy complications by fetal growth restriction',
#    1)),
#  (224,
#   ('ed an excess of fetal death in cases of pregnancy related hypertension and fetal growth restriction',
#    1)),
#  (225,
#   ('egfr 1 and vegfr 2 receptor the placentas of pregnancy whose outcomes is fetal growth restriction',
#    1)),
#  (226,
#   ('esistance was measured in normal placentas n = 10 open symbols a or fetal growth restriction',
#    1)),
#  (227,
#   ('estored pup weight in the present study we aim to further investigate if fetal growth restriction',
#    1)),
#  (228,
#   ('etween placental amino acid aa transport and fetal aa demand in an ovine fetal growth restriction',
#    1)),
#  (229,
#   ('evt cells isolated by tric in women who later development pre eclampsia or fetal growth restriction',
#    1)),
#  (230,
#   ('ey found that the src tyrosine kinase gardner rasheed feline sarcoma viral v fgr oncogene homolog',
#    1)),
#  (231,
#   ('hy appropriately grown baby at term is the primary goal in any pregnancy fetal growth restriction',
#    1)),
#  (232,
#   ('ic events repeated miscarriage fetal loss and is a major risk factors for fetal growth restriction',
#    1)),
#  (233,
#   ('in ginseng root and ginseng berry compare the effects of crude saponins from fermented ginseng root',
#    1)),
#  (234,
#   ('incidence of lbw in bangladesh is 21 6 3 predominant the results of fetal growth restriction',
#    1)),
#  (235,
#   ('induction and 7929 96 2 were spontaneous preterm delivery p < 0 001 fetal growth restriction',
#    1)),
#  (236,
#   ('ive birth and there were three pregnancy loss there were no cases of fetal growth restriction',
#    1)),
#  (237,
#   ('l factors leads to fgr and subsequent insults to the deve loping organs fetal growth restriction',
#    1)),
#  (238,
#   ('loci that could act as markers for poor fetal growth 52 notably placentas from growth restriction',
#    1)),
#  (239,
#   ('m is associated with an increased risk of poor perinatal outcomes such as fetal growth restriction',
#    1)),
#  (240,
#   ('n and secretion of vcam 1 from normal pregnancy and those complications by fetal growth restriction',
#    1)),
#  (241,
#   ('onment is known to be a critical determinant of adult health for example fetal growth restriction',
#    1)),
#  (242,
#   ('pahs during the first trimester was associated with the largest decrement in the fetal growth ratio',
#    1)),
#  (243,
#   ('ports further work on the possible of melatonin as a treatment for fgr fetal growth restriction',
#    1)),
#  (244,
#   ('r more effects fgr of brain tumors the ala glioma study group used fluorescence guided resection',
#    1)),
#  (245,
#   ('res et al 1992 in foetus a11454 agenesis of the corpus callosum and foetal growth restriction',
#    1)),
#  (246,
#   ('rmine if these methylation changes could be used as a biomarker for fgr fetal growth restriction',
#    1)),
#  (247,
#   ('rowth factors receptor 1 sflt 1 and placental growth factors plgf in the fetal growth restriction',
#    1)),
#  (248,
#   ('sulting in aberrant blood flow has been implicated as a possible causes of fetal growth restriction',
#    1)),
#  (249,
#   ('they reduced blood supply to the placentas and fetus which could leads to fetal growth restriction',
#    1)),
#  (250,
#   ('which may be related to the upregulation of nri subunit of nmda receptor fetal growth restriction',
#    1)),
#  (251,
#   ('> 2 fold changes we found that cord blood from newborn offspring affected by fetal growth restriction',
#    1)),
#  (252,
#   ('a d medium stress b e and high stress c f treatment for mean functional group richness',
#    1)),
#  (253,
#   ('d that these mice may provide a relevant model of human pe with associated fetal growth restriction',
#    1)),
#  (254,
#   ('ediated sp a induction and lung maturity of the fetus are ttf 1 dependent fetal growth restriction',
#    1)),
#  (255,
#   ('een the development of fgr and the expression of pappa pappa2 and plac 1 fetal growth restriction',
#    1)),
#  (256,
#   ('ia and fgr our findings suggest that the stox genes are associated with a severe fetal phenotype',
#    1)),
#  (257,
#   ('ity into adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#    1)),
#  (258,
#   ('keleton 17 18 19 20 21 22 while mid and late gestational exposure induced fetal growth restriction',
#    1)),
#  (259,
#   ('knockouts leu 27 igf ii s effects on fetal weight variation and no of fetal growth restriction',
#    1)),
#  (260,
#   ('later in adult life one of the key causes of adverse pregnancy outcomes is fetal growth restriction',
#    1)),
#  (261,
#   ('observed now we provide new evidence that il 10 is also able to improve fetal growth restriction',
#    1)),
#  (262,
#   ('pregnant women as part of a large scale study to identified risk factors for fetal growth retardation',
#    1)),
#  (263,
#   ('r with il 6 and igfbp 2 concentrations in placental lysates most cases of fetal growth restriction',
#    1)),
#  (264,
#   ('refers to an infant born with a birth weight less than the 10th centile fetal growth restriction',
#    1)),
#  (265,
#   ('s fd water consumption wc body weight average daily weight gain adg and feed to gain ratio',
#    1)),
#  (266,
#   ('stigate the effects of vitamin d vd on the learning and memory abilities of fetal growth restriction',
#    1)),
#  (267,
#   ('the cytokine and igf systemic have been shown in placentas and cord serum of fetal growth restriction',
#    1)),
#  (268,
#   ('7 5 cells harboring either an hcv subgenomic rna replicon sgr or an hcv full genomic rna replicon',
#    1)),
#  (269,
#   ('a human igf ii analog that binds the igf ii clearance receptor igf iir in fetal growth restriction',
#    1)),
#  (270,
#   ('baby with a blwr of less than 5 0 to confirm fgr causes of pathological fetal growth restriction',
#    1)),
#  (271,
#   ('cle and ebv for adg lean cuts lc backfat thickness bft ham weight hw and feed gain ratio',
#    1)),
#  (272,
#   ('e alveolus area and improve the maturity of fetal lung in a rat model of fetal growth restriction',
#    1)),
#  (273,
#   ('e ischemia reperfusion i r in rodents is a common model for the study of fetal growth restriction',
#    1)),
#  (274,
#   ('ewal of stb and fgr that are common to pe and maternal obesity study of fetal growth restriction',
#    1)),
#  (275,
#   ('g cm 3 for each newborn in order to test our main hypothesis we chose fetal growth restriction',
#    1)),
#  (276,
#   ('ide new targets via mir 141 in diagnosis and therapy of fgr in the future fetal growth restriction',
#    1)),
#  (277,
#   ('iencies in nutrient such as folic acid and vitamin b12 may play a role in fetal growth restriction',
#    1)),
#  (278,
#   ('inhibition in the pregnant rat has been used as a model for the study of fetal growth restriction',
#    1)),
#  (279,
#   ('ion i r protocols to establish and refine a murine model of i r induced fetal growth restriction',
#    1)),
#  (280, ('centile', 0.0)),
#  (281, ('fgr', 0.0)),
#  (282, ('fullgenomic', 0.0)),
#  (283, ('homolog', 0.0)),
#  (284, ('phenotype', 0.0)),
#  (285, ('rate', 0.0)),
#  (286, ('receptor', 0.0)),
#  (287, ('replicon', 0.0)),
#  (288, ('resection', 0.0)),
#  (289, ('restriction', 0.0)),
#  (290, ('retardation', 0.0)),
#  (291, ('rhizome', 0.0)),
#  (292, ('rhizoma', 0.0)),
#  (293, ('richness', 0.0)),
#  (294, ('risk', 0.0)),
#  (295, ('root', 0.0)),
#  (296, ('10th centile', 0.0)),
#  (297, ('et rhizome', 0.0)),
#  (298, ('et rhizoma', 0.0)),
#  (299, ('fetal phenotype', 0.0)),
#  (300, ('fluegas recirculation', 0.0)),
#  (301, ('gas recirculation', 0.0)),
#  (302, ('genetic risk', 0.0)),
#  (303, ('ginseng root', 0.0)),
#  (304, ('glucocorticoid receptor', 0.0)),
#  (305, ('group richness', 0.0)),
#  (306, ('growth rate', 0.0)),
#  (307, ('growth ratio', 0.0)),
#  (308, ('growth retardation', 0.0)),
#  (309, ('guided resection', 0.0)),
#  (310, ('kinase fgr', 0.0)),
#  (311, ('oncogene homolog', 0.0)),
#  (312, ('or fullgenomic', 0.0)),
#  (313, ('rna replicon', 0.0)),
#  (314, ('< 10th centile', 0.0)),
#  (315, ('between growth restriction', 0.0)),
#  (316, ('cortisol glucocorticoid receptor', 0.0)),
#  (317, ('familial genetic risk', 0.0)),
#  (318, ('feed gain ratio', 0.0)),
#  (319, ('fermented ginseng root', 0.0)),
#  (320, ('fetal growth ratio', 0.0)),
#  (321, ('fgr oncogene homolog', 0.0)),
#  (322, ('flue gas recirculation', 0.0)),
#  (323, ('fractional growth rate', 0.0)),
#  (324, ('from growth restriction', 0.0)),
#  (325, ('genomic rna replicon', 0.0)),
#  (326, ('protein kinase fgr', 0.0)),
#  (327, ('radix et rhizome', 0.0)),
#  (328, ('radix et rhizoma', 0.0)),
#  (329, ('severe fetal phenotype', 0.0)),
#  (330, ('sgr or fullgenomic', 0.0)),
#  (331, ('to gain ratio', 0.0)),
#  (332, ('varying fluegas recirculation', 0.0)),
#  (333, ('001 fetal growth restriction', 0.0)),
#  (334, ('130 fetal growth retardation', 0.0)),
#  (335, ('18 fetal growth retardation', 0.0)),
#  (336, ('4 foetal growth restriction', 0.0)),
#  (337, ('a severe fetal phenotype', 0.0)),
#  (338, ('abruption fetal growth restriction', 0.0)),
#  (339, ('ameliorate fetal growth restriction', 0.0)),
#  (340, ('and feed gain ratio', 0.0)),
#  (341, ('and fetal growth retardation', 0.0)),
#  (342, ('and flue gas recirculation', 0.0)),
#  (343, ('and fluorescence guided resection', 0.0)),
#  (344, ('and foetal growth restriction', 0.0)),
#  (345, ('and functional group richness', 0.0)),
#  (346, ('as fetal growth restriction', 0.0)),
#  (347, ('associated fetal growth restriction', 0.0)),
#  (348, ('based fluorescence guided resection', 0.0)),
#  (349, ('birthweight < 10th centile', 0.0)),
#  (350, ('blood between growth restriction', 0.0)),
#  (351, ('centile fetal growth restriction', 0.0)),
#  (352, ('chose fetal growth restriction', 0.0)),
#  (353, ('community functional group richness', 0.0)),
#  (354, ('complications fetal growth restriction', 0.0)),
#  (355, ('correcting fetal growth restriction', 0.0)),
#  (356, ('cysts foetal growth restriction', 0.0)),
#  (357, ('dependent fetal growth restriction', 0.0)),
#  (358, ('diseases fetal growth restriction', 0.0)),
#  (359, ('eclampsia fetal growth restriction', 0.0)),
#  (360, ('example fetal growth restriction', 0.0)),
#  (361, ('feed to gain ratio', 0.0)),
#  (362, ('fluorescein fluorescence guided resection', 0.0)),
#  (363, ('for fetal growth retardation', 0.0)),
#  (364, ('from fermented ginseng root', 0.0)),
#  (365, ('from fetal growth restriction', 0.0)),
#  (366, ('full genomic rna replicon', 0.0)),
#  (367, ('future fetal growth restriction', 0.0)),
#  (368, ('gestational fetal growth restriction', 0.0)),
#  (369, ('glycyrrhizae radix et rhizome', 0.0)),
#  (370, ('glycyrrhizae radix et rhizoma', 0.0)),
#  (371, ('group fetal growth restriction', 0.0)),
#  (372, ('higher familial genetic risk', 0.0)),
#  (373, ('human fetal growth restriction', 0.0)),
#  (374, ('identified fetal growth restriction', 0.0)),
#  (375, ('idiopathic fetal growth restriction', 0.0)),
#  (376, ('if fetal growth restriction', 0.0)),
#  (377, ('improve fetal growth restriction', 0.0)),
#  (378, ('in fluorescence guided resection', 0.0)),
#  (379, ('in functional group richness', 0.0)),
#  (380, ('including fluorescence guided resection', 0.0)),
#  (381, ('increased functional group richness', 0.0)),
#  (382, ('indicate fetal growth restriction', 0.0)),
#  (383, ('inflammation fetal growth restriction', 0.0)),
#  (384, ('investigate fetal growth restriction', 0.0)),
#  (385, ('is fetal growth restriction', 0.0)),
#  (386, ('is varying fluegas recirculation', 0.0)),
#  (387, ('lga fetal growth restriction', 0.0)),
#  (388, ('life fetal growth restriction', 0.0)),
#  (389, ('mediated fetal growth restriction', 0.0)),
#  (390, ('mediated fluorescence guided resection', 0.0)),
#  (391, ('neonatal fractional growth rate', 0.0)),
#  (392, ('of fetal growth retardation', 0.0)),
#  (393, ('onset fetal growth restriction', 0.0)),
#  (394, ('organs fetal growth restriction', 0.0)),
#  (395, ('ovine fetal growth restriction', 0.0)),
#  (396, ('particularly fetal growth restriction', 0.0)),
#  (397, ('pathological fetal growth restriction', 0.0)),
#  (398, ('pc foetal growth restriction', 0.0)),
#  (399, ('pe fetal growth restriction', 0.0)),
#  (400, ('pet fetal growth restriction', 0.0)),
#  (401, ('placental fetal growth restriction', 0.0)),
#  (402, ('placentas from growth restriction', 0.0)),
#  (403, ('ppix fluorescence guided resection', 0.0)),
#  (404, ('prematurity fetal growth restriction', 0.0)),
#  (405, ('ptb fetal growth restriction', 0.0)),
#  (406, ('receptor fetal growth restriction', 0.0)),
#  (407, ('responses fetal growth restriction', 0.0)),
#  (408, ('revealed foetal growth restriction', 0.0)),
#  (409, ('subgenomic sgr or fullgenomic', 0.0)),
#  (410, ('the fetal growth ratio', 0.0)),
#  (411, ('used fluorescence guided resection', 0.0)),
#  (412, ('v fgr oncogene homolog', 0.0)),
#  (413, ('velocities fetal growth restriction', 0.0)),
#  (414, ('whereas cortisol glucocorticoid receptor', 0.0)),
#  (415, ('0 001 fetal growth restriction', 0.0)),
#  (416, ('1 dependent fetal growth restriction', 0.0)),
#  (417, ('10th centile fetal growth restriction', 0.0)),
#  (418, ('11 including fluorescence guided resection', 0.0)),
#  (419, ('3 4 foetal growth restriction', 0.0)),
#  (420, ('31 community functional group richness', 0.0)),
#  (421, ('a or fetal growth restriction', 0.0)),
#  (422, ('abilities of fetal growth restriction', 0.0)),
#  (423, ('after prematurity fetal growth restriction', 0.0)),
#  (424, ('age lga fetal growth restriction', 0.0)),
#  (425, ('ala based fluorescence guided resection', 0.0)),
#  (426, ('an ovine fetal growth restriction', 0.0)),
#  (427, ('and correcting fetal growth restriction', 0.0)),
#  (428, ('and feed to gain ratio', 0.0)),
#  (429, ('and mean functional group richness', 0.0)),
#  (430, ('and tyrosine protein kinase fgr', 0.0)),
#  (431, ('any pregnancy fetal growth restriction', 0.0)),
#  (432, ('associated to fetal growth restriction', 0.0)),
#  (433, ('atherosclerosis and fetal growth restriction', 0.0)),
#  (434, ('between mean functional group richness', 0.0)),
#  (435, ('birth neonatal fractional growth rate', 0.0)),
#  (436, ('birth ptb fetal growth restriction', 0.0)),
#  (437, ('by fgr fetal growth restriction', 0.0)),
#  (438, ('by severe fetal growth restriction', 0.0)),
#  (439, ('callosum and foetal growth restriction', 0.0)),
#  (440, ('cd induced fetal growth restriction', 0.0)),
#  (441, ('characteristic of fetal growth restriction', 0.0)),
#  (442, ('cld including fetal growth restriction', 0.0)),
#  (443, ('cognitive development fetal growth restriction', 0.0)),
#  (444, ('combustion and flue gas recirculation', 0.0)),
#  (445, ('complications including fetal growth restriction', 0.0)),
#  (446, ('complications pc foetal growth restriction', 0.0)),
#  (447, ('contrary with fetal growth restriction', 0.0)),
#  (448, ('cord blood between growth restriction', 0.0)),
#  (449, ('demonstrate the fetal growth restriction', 0.0)),
#  (450, ('development of fetal growth retardation', 0.0)),
#  (451, ('diagnosis and fluorescence guided resection', 0.0)),
#  (452, ('diagnosis of fetal growth restriction', 0.0)),
#  (453, ('diastolic velocities fetal growth restriction', 0.0)),
#  (454, ('diseases and fetal growth restriction', 0.0)),
#  (455, ('dysfunction including fetal growth restriction', 0.0)),
#  (456, ('dysfunction placental fetal growth restriction', 0.0)),
#  (457, ('early onset fetal growth restriction', 0.0)),
#  (458, ('eclampsia and fetal growth restriction', 0.0)),
#  (459, ('eclampsia or fetal growth restriction', 0.0)),
#  (460, ('eclampsia pe fetal growth restriction', 0.0)),
#  (461, ('eclampsia pet fetal growth restriction', 0.0)),
#  (462, ('effects of fetal growth restriction', 0.0)),
#  (463, ('etiology of fetal growth restriction', 0.0)),
#  (464, ('evidence in fetal growth restriction', 0.0)),
#  (465, ('factors 1 fetal growth restriction', 0.0)),
#  (466, ('factors for fetal growth restriction', 0.0)),
#  (467, ('factors for fetal growth retardation', 0.0)),
#  (468, ('factors of fetal growth restriction', 0.0)),
#  (469, ('factors particularly fetal growth restriction', 0.0)),
#  (470, ('fetal life fetal growth restriction', 0.0)),
#  (471, ('fgr pregnancy fetal growth restriction', 0.0)),
#  (472, ('for example fetal growth restriction', 0.0)),
#  (473, ('for mean functional group richness', 0.0)),
#  (474, ('from glycyrrhizae radix et rhizome', 0.0)),
#  (475, ('from glycyrrhizae radix et rhizoma', 0.0)),
#  (476, ('further investigate fetal growth restriction', 0.0)),
#  (477, ('group used fluorescence guided resection', 0.0)),
#  (478, ('h tyrosine protein kinase fgr', 0.0)),
#  (479, ('hallmark of fetal growth restriction', 0.0)),
#  (480, ('harboring subgenomic sgr or fullgenomic', 0.0)),
#  (481, ('hcv full genomic rna replicon', 0.0)),
#  (482, ('hw and feed gain ratio', 0.0)),
#  (483, ('hypertension and fetal growth restriction', 0.0)),
#  (484, ('iir in fetal growth restriction', 0.0)),
#  (485, ('impaired development fetal growth restriction', 0.0)),
#  (486, ('in human fetal growth restriction', 0.0)),
#  (487, ('in severe fetal growth restriction', 0.0)),
#  (488, ('in the fetal growth ratio', 0.0)),
#  (489, ('in the fetal growth restriction', 0.0)),
#  (490, ('including 130 fetal growth retardation', 0.0)),
#  (491, ('increased in functional group richness', 0.0)),
#  (492, ('induced by fetal growth restriction', 0.0)),
#  (493, ('inflammatory responses fetal growth restriction', 0.0)),
#  (494, ('inhibition induced fetal growth restriction', 0.0)),
#  (495, ('insufficiency and fetal growth retardation', 0.0)),
#  (496, ('insufficiency mediated fetal growth restriction', 0.0)),
#  (497, ('investigate if fetal growth restriction', 0.0)),
#  (498, ('iugr or fetal growth restriction', 0.0)),
#  (499, ('ix ppix fluorescence guided resection', 0.0)),
#  (500, ('late pregnancy fetal growth restriction', 0.0)),
#  (501, ('line whereas cortisol glucocorticoid receptor', 0.0)),
#  (502, ('loping organs fetal growth restriction', 0.0)),
#  (503, ('maternal inflammation fetal growth restriction', 0.0)),
#  (504, ('mice with fetal growth restriction', 0.0)),
#  (505, ('model group fetal growth restriction', 0.0)),
#  (506, ('nmda receptor fetal growth restriction', 0.0)),
#  (507, ('no of fetal growth restriction', 0.0)),
#  (508, ('notably placentas from growth restriction', 0.0)),
#  (509, ('of gestational fetal growth restriction', 0.0)),
#  (510, ('of pathological fetal growth restriction', 0.0)),
#  (511, ('or ameliorate fetal growth restriction', 0.0)),
#  (512, ('or fluorescein fluorescence guided resection', 0.0)),
#  (513, ('outcomes in fetal growth restriction', 0.0)),
#  (514, ('pa and fetal growth restriction', 0.0)),
#  (515, ('paf induced fetal growth restriction', 0.0)),
#  (516, ('pathogenesis of fetal growth restriction', 0.0)),
#  (517, ('plac 1 fetal growth restriction', 0.0)),
#  (518, ('placental abruption fetal growth restriction', 0.0)),
#  (519, ('placental diseases fetal growth restriction', 0.0)),
#  (520, ('placentas from fetal growth restriction', 0.0)),
#  (521, ('plexus cysts foetal growth restriction', 0.0)),
#  (522, ('pm 18 fetal growth retardation', 0.0)),
#  (523, ('ppix mediated fluorescence guided resection', 0.0)),
#  (524, ('pre eclampsia fetal growth restriction', 0.0)),
#  (525, ('pregnancy complications fetal growth restriction', 0.0)),
#  (526, ('pregnancy revealed foetal growth restriction', 0.0)),
#  (527, ('r induced fetal growth restriction', 0.0)),
#  (528, ('rat with fetal growth restriction', 0.0)),
#  (529, ('resection in fluorescence guided resection', 0.0)),
#  (530, ('results of fetal growth restriction', 0.0)),
#  (531, ('role in fetal growth restriction', 0.0)),
#  (532, ('saponins from fermented ginseng root', 0.0)),
#  (533, ('scan identified fetal growth restriction', 0.0)),
#  (534, ('serum of fetal growth restriction', 0.0)),
#  (535, ('sga and fetal growth restriction', 0.0)),
#  (536, ('sonographic indicate fetal growth restriction', 0.0)),
#  (537, ('sr and functional group richness', 0.0)),
#  (538, ('stillbirth and fetal growth restriction', 0.0)),
#  (539, ('subsequent in fetal growth restriction', 0.0)),
#  (540, ('susceptible to fetal growth restriction', 0.0)),
#  (541, ('that induced fetal growth restriction', 0.0)),
#  (542, ('the future fetal growth restriction', 0.0)),
#  (543, ('the higher familial genetic risk', 0.0)),
#  (544, ('thresholds for fetal growth restriction', 0.0)),
#  (545, ('to fgr fetal growth restriction', 0.0)),
#  (546, ('to improve fetal growth restriction', 0.0)),
#  (547, ('types of fetal growth restriction', 0.0)),
#  (548, ('undernutrition including fetal growth restriction', 0.0)),
#  (549, ('viral v fgr oncogene homolog', 0.0)),
#  (550, ('waste is varying fluegas recirculation', 0.0)),
#  (551, ('we chose fetal growth restriction', 0.0)),
#  (552, ('with a severe fetal phenotype', 0.0)),
#  (553, ('with associated fetal growth restriction', 0.0)),
#  (554, ('with birthweight < 10th centile', 0.0)),
#  (555, ('with idiopathic fetal growth restriction', 0.0)),
#  (556, ('with increased functional group richness', 0.0)),
#  (557, ('women with fetal growth restriction', 0.0)),
#  (558, ('0 31 community functional group richness', 0.0)),
#  (559, ('10 11 including fluorescence guided resection', 0.0)),
#  (560, ('2 3 4 foetal growth restriction', 0.0)),
#  (561, ('5 ala based fluorescence guided resection', 0.0)),
#  (562, ('52 notably placentas from growth restriction', 0.0)),
#  (563, ('< 0 001 fetal growth restriction', 0.0)),
#  (564, ('a role in fetal growth restriction', 0.0)),
#  (565, ('able to improve fetal growth restriction', 0.0)),
#  (566, ('abnormal maternal inflammation fetal growth restriction', 0.0)),
#  (567, ('abruption pa and fetal growth restriction', 0.0)),
#  (568, ('adg and feed to gain ratio', 0.0)),
#  (569, ('ala ppix mediated fluorescence guided resection', 0.0)),
#  (570, ('also demonstrate the fetal growth restriction', 0.0)),
#  (571, ('an hcv full genomic rna replicon', 0.0)),
#  (572, ('and cognitive development fetal growth restriction', 0.0)),
#  (573, ('and dysfunction placental fetal growth restriction', 0.0)),
#  (574, ('and h tyrosine protein kinase fgr', 0.0)),
#  (575, ('and impaired development fetal growth restriction', 0.0)),
#  (576, ('and no of fetal growth restriction', 0.0)),
#  (577, ('and plac 1 fetal growth restriction', 0.0)),
#  (578, ('and subsequent in fetal growth restriction', 0.0)),
#  (579, ('any waste is varying fluegas recirculation', 0.0)),
#  (580, ('anomalies after prematurity fetal growth restriction', 0.0)),
#  (581, ('antenatal factors particularly fetal growth restriction', 0.0)),
#  (582, ('antepartum stillbirth and fetal growth restriction', 0.0)),
#  (583, ('are associated with fetal growth restriction', 0.0)),
#  (584, ('are susceptible to fetal growth restriction', 0.0)),
#  (585, ('as pe and fetal growth restriction', 0.0)),
#  (586, ('as preeclampsia and fetal growth restriction', 0.0)),
#  (587, ('associated with a severe fetal phenotype', 0.0)),
#  (588, ('associated with fgr fetal growth restriction', 0.0)),
#  (589, ('at birth neonatal fractional growth rate', 0.0)),
#  (590, ('biomarker for fgr fetal growth restriction', 0.0)),
#  (591, ('birth sga and fetal growth restriction', 0.0)),
#  (592, ('birthweight due to fetal growth restriction', 0.0)),
#  (593, ('blwr thresholds for fetal growth restriction', 0.0)),
#  (594, ('bold line whereas cortisol glucocorticoid receptor', 0.0)),
#  (595, ('cadmium exposure induced fetal growth restriction', 0.0)),
#  (596, ('causes by fgr fetal growth restriction', 0.0)),
#  (597, ('causes of pathological fetal growth restriction', 0.0)),
#  (598, ('cells harboring subgenomic sgr or fullgenomic', 0.0)),
#  (599, ('children with birthweight < 10th centile', 0.0)),
#  (600, ('choroid plexus cysts foetal growth restriction', 0.0)),
#  (601, ('cohort including 130 fetal growth retardation', 0.0)),
#  (602, ('commonest causes of fetal growth restriction', 0.0)),
#  (603, ('complications by severe fetal growth restriction', 0.0)),
#  (604, ('complications such as fetal growth restriction', 0.0)),
#  (605, ('contribute to fgr fetal growth restriction', 0.0)),
#  (606, ('cord serum of fetal growth restriction', 0.0)),
#  (607, ('corpus callosum and foetal growth restriction', 0.0)),
#  (608, ('could leads to fetal growth restriction', 0.0)),
#  (609, ('crude saponins from fermented ginseng root', 0.0)),
#  (610, ('d and tyrosine protein kinase fgr', 0.0)),
#  (611, ('decrement in the fetal growth ratio', 0.0)),
#  (612, ('delivery and correcting fetal growth restriction', 0.0)),
#  (613, ('deve loping organs fetal growth restriction', 0.0)),
#  (614, ('development early onset fetal growth restriction', 0.0)),
#  (615, ('doppler sonographic indicate fetal growth restriction', 0.0)),
#  (616, ('dysfunction atherosclerosis and fetal growth restriction', 0.0)),
#  (617, ('eclampsia and or fetal growth restriction', 0.0)),
#  (618, ('eclampsia pe and fetal growth restriction', 0.0)),
#  (619, ('end diastolic velocities fetal growth restriction', 0.0)),
#  (620, ('environmental factors 1 fetal growth restriction', 0.0)),
#  (621, ('factors paf induced fetal growth restriction', 0.0)),
#  (622, ('fetal rat with fetal growth restriction', 0.0)),
#  (623, ('flavonoids from glycyrrhizae radix et rhizome', 0.0)),
#  (624, ('flavonoids from glycyrrhizae radix et rhizoma', 0.0)),
#  (625, ('fluorescence or fluorescein fluorescence guided resection', 0.0)),
#  (626, ('for placental diseases fetal growth restriction', 0.0)),
#  (627, ('for the higher familial genetic risk', 0.0)),
#  (628, ('from pregnancy with fetal growth restriction', 0.0)),
#  (629, ('further investigate if fetal growth restriction', 0.0)),
#  (630, ('genetic characteristic of fetal growth restriction', 0.0)),
#  (631, ('gestational age lga fetal growth restriction', 0.0)),
#  (632, ('gestational exposure induced fetal growth restriction', 0.0)),
#  (633, ('group model group fetal growth restriction', 0.0)),
#  (634, ('health for example fetal growth restriction', 0.0)),
#  (635, ('human fgr pregnancy fetal growth restriction', 0.0)),
#  (636, ('hypothesis we chose fetal growth restriction', 0.0)),
#  (637, ('igf iir in fetal growth restriction', 0.0)),
#  (638, ('impaired development and fetal growth restriction', 0.0)),
#  (639, ('improve outcomes in fetal growth restriction', 0.0)),
#  (640, ('in an ovine fetal growth restriction', 0.0)),
#  (641, ('in any pregnancy fetal growth restriction', 0.0)),
#  (642, ('in fetal life fetal growth restriction', 0.0)),
#  (643, ('in late pregnancy fetal growth restriction', 0.0)),
#  (644, ('in mice with fetal growth restriction', 0.0)),
# ...
#  (774, ('and memory abilities of fetal growth restriction', 0.0)),
#  (775, ('and pregnancy complications by fetal growth restriction', 0.0)),
#  (776, ('and pregnancy complications pc foetal growth restriction', 0.0)),
#  (777, ('and preventable causes of fetal growth restriction', 0.0)),
#  (778, ('and specific types of fetal growth restriction', 0.0)),
#  (779, ('and stillbirth associated with fetal growth restriction', 0.0)),
#  (780, ('and the risk of fetal growth restriction', 0.0)),
#  (781, ('and those complications by fetal growth restriction', 0.0)),
#  (782, ('applications 10 11 including fluorescence guided resection', 0.0)),
#  (783, ('are associated with a severe fetal phenotype', 0.0)),
#  (784, ('are not complications by fetal growth restriction', 0.0)),
#  (785, ('are ttf 1 dependent fetal growth restriction', 0.0)),
#  (786,
#   ('artery dysfunction atherosclerosis and fetal growth restriction', 0.0)),
#  (787, ('artery end diastolic velocities fetal growth restriction', 0.0)),
#  (788, ('as pre eclampsia and fetal growth restriction', 0.0)),
#  (789, ('as pre eclampsia pet fetal growth restriction', 0.0)),
#  (790, ('as preeclampsia pe and fetal growth restriction', 0.0)),
#  (791, ('as preterm birth ptb fetal growth restriction', 0.0)),
#  (792, ('biomarker for placental diseases fetal growth restriction', 0.0)),
#  (793, ('birth cohort including 130 fetal growth retardation', 0.0)),
#  (794, ('blue bold line whereas cortisol glucocorticoid receptor', 0.0)),
#  (795, ('by pre eclampsia pe fetal growth restriction', 0.0)),
#  (796, ('callosum choroid plexus cysts foetal growth restriction', 0.0)),
#  (797, ('cardiovascular remodeling induced by fetal growth restriction', 0.0)),
#  (798, ('cigarette smoking leads to fetal growth restriction', 0.0)),
#  (799, ('clinical management for fgr fetal growth restriction', 0.0)),
#  (800, ('color doppler sonographic indicate fetal growth restriction', 0.0)),
#  (801, ('combustion staged combustion and flue gas recirculation', 0.0)),
#  (802, ('cyclophilin d and tyrosine protein kinase fgr', 0.0)),
#  (803,
#   ('declined significantly with increased functional group richness', 0.0)),
#  (804, ('delivery primarily due to fetal growth restriction', 0.0)),
#  (805, ('demand in an ovine fetal growth restriction', 0.0)),
#  (806, ('development pre eclampsia or fetal growth restriction', 0.0)),
#  (807, ('developmental toxicant that induced fetal growth restriction', 0.0)),
#  (808, ('effects of increased in functional group richness', 0.0)),
#  (809, ('etiology of cd induced fetal growth restriction', 0.0)),
#  (810, ('exchange and subsequent in fetal growth restriction', 0.0)),
#  (811, ('extent of resection in fluorescence guided resection', 0.0)),
#  (812, ('f treatment for mean functional group richness', 0.0)),
#  (813, ('factors plgf in the fetal growth restriction', 0.0)),
#  (814, ('factors predicted cld including fetal growth restriction', 0.0)),
#  (815, ('feline sarcoma viral v fgr oncogene homolog', 0.0)),
#  (816, ('fetal anomalies after prematurity fetal growth restriction', 0.0)),
#  (817, ('fgr causes of pathological fetal growth restriction', 0.0)),
#  (818, ('fgr in late pregnancy fetal growth restriction', 0.0)),
#  (819, ('fgr in the future fetal growth restriction', 0.0)),
#  (820, ('fgr preeclampsia pe and fetal growth restriction', 0.0)),
#  (821, ('flow in pregnancy with fetal growth restriction', 0.0)),
#  (822, ('following preterm birth ptb fetal growth restriction', 0.0)),
#  (823, ('for gestational age lga fetal growth restriction', 0.0)),
#  (824, ('for improve outcomes in fetal growth restriction', 0.0)),
#  (825, ('for placental insufficiency and fetal growth retardation', 0.0)),
#  (826, ('for the study of fetal growth restriction', 0.0)),
#  (827, ('from pathological pregnancy with fetal growth restriction', 0.0)),
#  (828, ('from placental dysfunction including fetal growth restriction', 0.0)),
#  (829, ('from pregnancy associated with fetal growth restriction', 0.0)),
#  (830, ('from pregnancy complications by fetal growth restriction', 0.0)),
#  (831, ('gain adg and feed to gain ratio', 0.0)),
#  (832, ('glioma study group used fluorescence guided resection', 0.0)),
#  (833, ('goal in any pregnancy fetal growth restriction', 0.0)),
#  (834, ('growth 52 notably placentas from growth restriction', 0.0)),
#  (835, ('growth and impaired development fetal growth restriction', 0.0)),
#  (836, ('growth in mice with fetal growth restriction', 0.0)),
#  (837, ('growth requires further investigate fetal growth restriction', 0.0)),
#  (838, ('growth restriction iugr or fetal growth restriction', 0.0)),
#  (839, ('guinea pigs leads to fetal growth restriction', 0.0)),
#  (840, ('ham weight hw and feed gain ratio', 0.0)),
#  (841, ('health and cognitive development fetal growth restriction', 0.0)),
#  (842, ('high risk factors of fetal growth restriction', 0.0)),
#  (843, ('high stress and mean functional group richness', 0.0)),
#  (844, ('human pe with associated fetal growth restriction', 0.0)),
#  (845,
#   ('human pregnancy complications including fetal growth restriction', 0.0)),
#  (846, ('hypertension are associated with fetal growth restriction', 0.0)),
#  (847, ('identified risk factors for fetal growth retardation', 0.0)),
#  (848, ('impaired causes by fgr fetal growth restriction', 0.0)),
#  (849, ('in human fgr pregnancy fetal growth restriction', 0.0)),
#  (850, ('in impaired development and fetal growth restriction', 0.0)),
#  (851, ('in pre eclampsia and fetal growth restriction', 0.0)),
#  (852, ('in preclinical model of fetal growth restriction', 0.0)),
#  (853, ('in pregnancy affected by fetal growth restriction', 0.0)),
#  (854, ('in the development of fetal growth retardation', 0.0)),
#  (855, ('in the pathogenesis of fetal growth restriction', 0.0)),
#  (856, ('in umbilical cord blood between growth restriction', 0.0)),
#  (857, ('in utero leads to fetal growth restriction', 0.0)),
#  (858, ('individuals present with fgr fetal growth restriction', 0.0)),
#  (859, ('induced protoporphyrin ix ppix fluorescence guided resection', 0.0)),
#  (860,
#   ('intraoperative photodynamic diagnosis and fluorescence guided resection',
#    0.0)),
#  (861, ('investigate the effects of fetal growth restriction', 0.0)),
#  (862, ('ireland pre eclampsia and fetal growth restriction', 0.0)),
#  (863, ('largest decrement in the fetal growth ratio', 0.0)),
#  (864, ('late gestational exposure induced fetal growth restriction', 0.0)),
#  (865, ('low birthweight due to fetal growth restriction', 0.0)),
#  (866, ('lysates most cases of fetal growth restriction', 0.0)),
#  (867, ('main hypothesis we chose fetal growth restriction', 0.0)),
#  (868, ('major risk factors for fetal growth restriction', 0.0)),
#  (869, ('maternal obesity study of fetal growth restriction', 0.0)),
#  (870, ('might contribute to fgr fetal growth restriction', 0.0)),
#  (871, ('much more evidence in fetal growth restriction', 0.0)),
#  (872, ('newborn offspring affected by fetal growth restriction', 0.0)),
#  (873, ('nine pregnant women with fetal growth restriction', 0.0)),
#  (874, ('normal and dysfunction placental fetal growth restriction', 0.0)),
#  (875, ('normal group model group fetal growth restriction', 0.0)),
#  (876, ('obstetric syndromes pre eclampsia fetal growth restriction', 0.0)),
#  (877, ('of ala ppix mediated fluorescence guided resection', 0.0)),
#  (878, ('of any waste is varying fluegas recirculation', 0.0)),
#  (879, ('of antenatal factors particularly fetal growth restriction', 0.0)),
#  (880, ('of antepartum stillbirth and fetal growth restriction', 0.0)),
#  (881, ('of crude saponins from fermented ginseng root', 0.0)),
#  (882, ('of fetal rat with fetal growth restriction', 0.0)),
#  (883, ('of i r induced fetal growth restriction', 0.0)),
#  (884, ('of pregnancy associated with fetal growth restriction', 0.0)),
#  (885, ('of the diseases and fetal growth restriction', 0.0)),
#  (886, ('on the contrary with fetal growth restriction', 0.0)),
#  (887,
#   ('onset preeclampsia placental abruption fetal growth restriction', 0.0)),
#  (888, ('open symbols a or fetal growth restriction', 0.0)),
#  (889, ('or an hcv full genomic rna replicon', 0.0)),
#  (890, ('p < 0 001 fetal growth restriction', 0.0)),
#  (891, ('pappa2 and plac 1 fetal growth restriction', 0.0)),
#  (892, ('pathogenesis of preeclampsia and fetal growth restriction', 0.0)),
#  (893, ('pathological associated with fgr fetal growth restriction', 0.0)),
#  (894, ('placental abruption pa and fetal growth restriction', 0.0)),
#  (895, ('placentas from pregnancy with fetal growth restriction', 0.0)),
#  (896, ('play a role in fetal growth restriction', 0.0)),
#  (897, ('poor placental development and fetal growth restriction', 0.0)),
#  (898, ('ppid and h tyrosine protein kinase fgr', 0.0)),
#  (899,
#   ('ppix fluorescence or fluorescein fluorescence guided resection', 0.0)),
#  (900, ('pre eclampsia and or fetal growth restriction', 0.0)),
#  (901, ('pre eclampsia pe and fetal growth restriction', 0.0)),
#  (902, ('predominant the results of fetal growth restriction', 0.0)),
#  (903, ('preeclampsia often associated with fetal growth restriction', 0.0)),
#  (904, ('pregnancy complications by severe fetal growth restriction', 0.0)),
#  (905, ('pregnancy is associated to fetal growth restriction', 0.0)),
#  (906, ('pregnancy outcomes such as fetal growth restriction', 0.0)),
#  (907, ('pregnancy related hypertension and fetal growth restriction', 0.0)),
#  (908, ('pregnancy whose outcomes is fetal growth restriction', 0.0)),
#  (909, ('preterm delivery and correcting fetal growth restriction', 0.0)),
#  (910, ('preterm labour and or fetal growth restriction', 0.0)),
#  (911, ('ratio blwr thresholds for fetal growth restriction', 0.0)),
#  (912, ('receptor igf iir in fetal growth restriction', 0.0)),
#  (913, ('reperfusion i r induced fetal growth restriction', 0.0)),
#  (914, ('replicon cells harboring subgenomic sgr or fullgenomic', 0.0)),
#  (915,
#   ('restriction placental insufficiency mediated fetal growth restriction',
#    0.0)),
#  (916, ('risk of pm 18 fetal growth retardation', 0.0)),
#  (917, ('rodents also demonstrate the fetal growth restriction', 0.0)),
#  (918, ('size at birth neonatal fractional growth rate', 0.0)),
#  (919, ('status results in severe fetal growth restriction', 0.0)),
#  (920, ('stress relationship between mean functional group richness', 0.0)),
#  (921, ('subunit of nmda receptor fetal growth restriction', 0.0)),
#  (922, ('such as pe and fetal growth restriction', 0.0)),
#  (923, ('such as preeclampsia and fetal growth restriction', 0.0)),
#  (924, ('synthase nos inhibition induced fetal growth restriction', 0.0)),
#  (925, ('than the 10th centile fetal growth restriction', 0.0)),
#  (926, ('that women with idiopathic fetal growth restriction', 0.0)),
#  (927, ('the commonest causes of fetal growth restriction', 0.0)),
#  (928, ('the corpus callosum and foetal growth restriction', 0.0)),
#  (929, ('the deve loping organs fetal growth restriction', 0.0)),
#  (930, ('the flavonoids from glycyrrhizae radix et rhizome', 0.0)),
#  (931, ('the genetic characteristic of fetal growth restriction', 0.0)),
#  (932, ('the increased risk of fetal growth restriction', 0.0)),
#  (933, ('to further investigate if fetal growth restriction', 0.0)),
#  (934, ('to reverse or ameliorate fetal growth restriction', 0.0)),
#  (935, ('to stillbirth such as fetal growth restriction', 0.0)),
#  (936, ('two key pregnancy complications fetal growth restriction', 0.0)),
#  (937, ('variation and no of fetal growth restriction', 0.0)),
#  (938, ('weeks of pregnancy revealed foetal growth restriction', 0.0)),
#  (939, ('were no cases of fetal growth restriction', 0.0)),
#  (940, ('which could leads to fetal growth restriction', 0.0)),
#  (941, ('with abnormal maternal inflammation fetal growth restriction', 0.0)),
#  (942, ('women with preeclampsia and fetal growth restriction', 0.0)),
#  (943, ('1 of fetal rat with fetal growth restriction', 0.0)),
#  (944, ('1 total flavonoids from glycyrrhizae radix et rhizoma', 0.0)),
#  (945, ('10 open symbols a or fetal growth restriction', 0.0)),
#  (946, ('25 weeks of pregnancy revealed foetal growth restriction', 0.0)),
#  (947, ('3 4 infant undernutrition including fetal growth restriction', 0.0)),
#  (948, ('3 predominant the results of fetal growth restriction', 0.0)),
#  (949,
#   ('a developmental toxicant that induced fetal growth restriction', 0.0)),
#  (950, ('a major risk factors for fetal growth restriction', 0.0)),
#  (951, ('aa demand in an ovine fetal growth restriction', 0.0)),
#  (952, ('abilities impaired causes by fgr fetal growth restriction', 0.0)),
#  (953,
#   ('abundance declined significantly with increased functional group richness',
#    0.0)),
#  (954, ('adaptation might contribute to fgr fetal growth restriction', 0.0)),
#  (955, ('adulthood 1 2 3 4 foetal growth restriction', 0.0)),
#  (956, ('adverse perinatal outcomes such as fetal growth restriction', 0.0)),
#  (957, ('adverse pregnancy outcomes such as fetal growth restriction', 0.0)),
#  (958, ('aetiologies in the pathogenesis of fetal growth restriction', 0.0)),
#  (959, ('age 34 the diagnosis of fetal growth restriction', 0.0)),
#  (960, ('age ama are susceptible to fetal growth restriction', 0.0)),
#  (961, ('aim to further investigate if fetal growth restriction', 0.0)),
#  (962, ('ala glioma study group used fluorescence guided resection', 0.0)),
#  (963,
#   ('ala induced protoporphyrin ix ppix fluorescence guided resection', 0.0)),
#  (964, ('amino acid transport in human fetal growth restriction', 0.0)),
#  (965, ('aminolevulinic acid 5 ala based fluorescence guided resection', 0.0)),
#  (966, ('and ahrr in placentas from fetal growth restriction', 0.0)),
#  (967, ('and fgr preeclampsia pe and fetal growth restriction', 0.0)),
#  (968, ('and high risk factors of fetal growth restriction', 0.0)),
#  (969, ('and ireland pre eclampsia and fetal growth restriction', 0.0)),
#  (970,
#   ('and late gestational exposure induced fetal growth restriction', 0.0)),
#  (971, ('and maternal obesity study of fetal growth restriction', 0.0)),
#  (972, ('and placentas from pregnancy with fetal growth restriction', 0.0)),
#  (973, ('and the increased risk of fetal growth restriction', 0.0)),
#  (974,
#   ('antenatal factors predicted cld including fetal growth restriction', 0.0)),
#  (975, ('as a biomarker for fgr fetal growth restriction', 0.0)),
#  (976, ('as a possible causes of fetal growth restriction', 0.0)),
#  (977, ('as a treatment for fgr fetal growth restriction', 0.0)),
#  (978, ('as cyclophilin d and tyrosine protein kinase fgr', 0.0)),
#  (979,
#   ('associated with abnormal maternal inflammation fetal growth restriction',
#    0.0)),
#  (980, ('associated with increased risk of fetal growth restriction', 0.0)),
#  (981, ('baby two key pregnancy complications fetal growth restriction', 0.0)),
#  (982, ('before 32 weeks of gestational fetal growth restriction', 0.0)),
#  (983, ('bft ham weight hw and feed gain ratio', 0.0)),
#  (984, ('birth and stillbirth associated with fetal growth restriction', 0.0)),
#  (985, ('blood flow in pregnancy with fetal growth restriction', 0.0)),
#  (986, ('by pre eclampsia and or fetal growth restriction', 0.0)),
#  (987, ('c f treatment for mean functional group richness', 0.0)),
#  (988, ('capacity in pre eclampsia and fetal growth restriction', 0.0)),
#  (989, ('causes of antepartum stillbirth and fetal growth restriction', 0.0)),
#  (990, ('choline status results in severe fetal growth restriction', 0.0)),
#  (991, ('clearance receptor igf iir in fetal growth restriction', 0.0)),
#  (992, ('common and preventable causes of fetal growth restriction', 0.0)),
#  (993,
#   ('common pregnancy complications such as fetal growth restriction', 0.0)),
#  (994, ('complications by pre eclampsia pe fetal growth restriction', 0.0)),
#  (995,
#   ('complications of pregnancy associated with fetal growth restriction',
#    0.0)),
#  (996, ('complications pre eclampsia pe and fetal growth restriction', 0.0)),
#  (997, ('complications such as pe and fetal growth restriction', 0.0)),
#  (998,
#   ('complications such as preeclampsia and fetal growth restriction', 0.0)),
#  (999, ('composition of any waste is varying fluegas recirculation', 0.0)),
#  ...]

# %%
longforms.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [9])

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms)

# %%
longforms
# Out:
# ('fetal growth restriction',
#  'fluorescence guided resection',
#  'functional group richness',
#  'foetal growth restriction',
#  'fetal growth retardation')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'fetal growth restriction': 'MESH:D005317',
#  'fetal growth retardation': 'MESH:D005317'}

# %%
names
# Out:
# {'MESH:D005317': 'Fetal Growth Retardation'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'fetal growth restriction': 'MESH:D005317',
#   'fetal growth retardation': 'MESH:D005317',
#   'fluorescence guided resection': 'ungrounded',
#   'foetal growth restriction': 'MESH:D005317',
#   'functional group richness': 'ungrounded'},
#  {'MESH:D005317': 'Fetal Growth Retardation'},
#  ['MESH:D005317'])

# %%
grounding_map, names, pos_labels = ({'fetal growth restriction': 'MESH:D005317',
  'fetal growth retardation': 'MESH:D005317',
  'fluorescence guided resection': 'ungrounded',
  'foetal growth restriction': 'MESH:D005317',
  'functional group richness': 'ungrounded'},
 {'MESH:D005317': 'Fetal Growth Retardation'},
 ['MESH:D005317'])

# %%
names['HGNC:3697'] = 'FGR'
pos_labels.append('HGNC:3697')

# %%
grounding_dict = {'FGR': grounding_map}

# %%
classifier = AdeftClassifier('FGR', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 12:30:41] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-27 12:30:45] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9939967916548713 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D005317': 150, 'ungrounded': 8, 'HGNC:3697': 93},
#  'f1': {'mean': 0.9939967916548713, 'std': 0.00799643508150585},
#  'precision': {'mean': 0.9882225148123766, 'std': 0.015673297062414965},
#  'recall': {'mean': 1.0, 'std': 0.0}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:3697']

# %%
a[0]
# Out:
# 'We next sought to determine whether specimens harboring mutant  CSF3R  show in vitro sensitivity to small-molecule inhibitors of kinases or siRNA directed against kinases that become dysregulated downstream of mutant CSF3R. Analysis of cells from Patient 3, who had CNL with the  CSF3R  S783fs mutation ( Table S3 and Fig. S2 in the Supplementary Appendix ), revealed dramatic sensitivity to the multikinase inhibitor dasatinib (Sprycel, Bristol-Myers Squibb) but no sensitivity to inhibitors of JAK family kinases ( Fig. 1B ). Further interrogation with our panel of tyrosine kinase– specific siRNAs revealed sensitivity to silencing of tyrosine kinase nonreceptor 2 (TNK2) and an SRC family kinase, FGR, both of which are potently inhibited by dasatinib  36  ( Fig. 1C ). We also performed drug-sensitivity profiling on samples from two patients with the  CSF3R  T618I mutation (one with CNL and one with ETP-T-ALL). In contrast to the drug-sensitivity pattern in the patients with truncation mutations, both samples showed sensitivity to inhibitors that target JAK family kinases (including ruxolitinib [Jakafi, Incyte]) but resistance to dasatinib ( Fig. 1D , and  Fig. S3D and S3E in the Supplementary Appendix ). Taken together, the functional genomic data on the samples from these three patients suggest that there are two different classes of  CSF3R  mutations: truncation mutations, which result in dysregulation of SRC family–TNK2 kinases, and membrane proximal mutations, which result in dysregulation of JAK family kinases. The data also suggest that truncation mutations confer sensitivity to dasatinib but not to JAK kinase inhibitors, where-as the reverse is true for membrane proximal mutant cells.\nOnce we confirmed the transformation capacity of the  CSF3R  mutations, we investigated the differential signaling and drug sensitivity suggested by our functional screening of samples of  CSF3R  mutant leukemia. Ba/F3 cells expressing the T618I or S783fs mutation before or after interleukin-3–independent transformation, along with cells expressing wild-type CSF3R or parental control cells, were starved of the interleukin-3 growth factor, and cell lysates were analyzed by means of immunoblotting. The cells with the S783fs mutation showed higher expression of CSF3R than did the cells with the wild-type allele ( Fig. 1F ), and this difference was magnified after long-term culture in the absence of interleukin-3, a finding consistent with results of previous studies showing disruption of receptor internalization in the context of truncation mutations. 22 – 24 , 37  After withdrawal of interleukin-3, Ba/F3 cells with  CSF3R  mutations expressed high levels of endogenous TNK2 and increased phosphorylation of SRC family kinases, providing validation of the initial TNK2 and FGR siRNA sensitivities observed in samples obtained from a patient with a  CSF3R  truncation mutation ( Fig. 1C ) and suggesting that TNK2 is a previously unrecognized downstream mediator of CSF3R signaling.\nPanel A shows the location and recurrence of  CSF3R  mutations found in samples from 16 of 27 patients with chronic neutrophilic leukemia (CNL) or atypical chronic myeloid leukemia (CML), along with samples from patients with other types of leukemia. The mutation locations and number of observations are indicated by black circles. The Q741X mutation was found in a sample obtained from a patient with acute myeloid leukemia (AML), and one of the T618I mutations was found in a sample from a patient with early T-cell precursor T-cell acute lymphoblastic leukemia (ETP-T-ALL). Five patients with CNL or atypical CML had both membrane proximal and truncation mutations. (For details, see  Table S3 in the Supplementary Appendix .) Two additional  CSF3R  mutations (Q739X and T618I, which are not shown) have been reported in AML specimens sequenced by the Cancer Genome Atlas. 21 \n CSF3R  coordinates are numbered according to the conventions of the Ensembl genome browser, a numbering s ...

# %%
disamb.dump('FGR', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('enrichment', 0.0010042797351243191),
#  ('gtpase activating', 0.0009997082407178493),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
