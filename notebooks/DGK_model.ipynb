# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['DGK']
genes = ['DGUOK']
families = {'DGK': ['DGKA', 'DGKB', 'DGKD', 'DGKG', 'DGKH', 'DGKQ', 'DGKZ', 'DGKE',
                    'DGKI', 'DGKK']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['DGK'].top()

# %%
top
# Out:
# [('diacylglycerol kinase', 145.79661016949152),
#  ('kinase', 74.41624365482234),
#  ('dag kinase', 20.08),
#  ('of diacylglycerol kinase', 15.411764705882353),
#  ('by diacylglycerol kinase', 12.666666666666666),
#  ('and diacylglycerol kinase', 9.999999999999998),
#  ('dg kinase', 7.666666666666666),
#  ('the diacylglycerol kinase', 7.0),
#  ('by dag kinase', 6.5),
#  ('diacylglycerol dag kinase', 6.0),
#  ('a diacylglycerol kinase', 3.0),
#  ('diacylglycerol dg kinase', 3),
#  ('phospholipase d pld and diacylglycerol kinase', 2.5),
#  ('by dg kinase', 2.0),
#  ('for diacylglycerol kinase', 2.0),
#  ('mammalian diacylglycerol kinase', 2.0),
#  ('that diacylglycerol kinase', 2.0),
#  ('is catalyzed by diacylglycerol kinase', 2.0),
#  ('pa by diacylglycerol kinase', 1.5),
#  ('plc and diacylglycerol kinase', 1.5),
#  ('role of diacylglycerol kinase', 1.3333333333333333),
#  ('to pa by diacylglycerol kinase', 1.3333333333333333),
#  ('phospholipase c plc and diacylglycerol kinase', 1.3333333333333333),
#  ('diacyglycerol kinase', 1.0),
#  ('diglyceride kinase', 1.0),
#  ('cycle diacylglycerol kinase', 1.0),
#  ('diacyl glycerol kinase', 1.0),
#  ('dn diacylglycerol kinase', 1.0),
#  ('with diacylglycerol kinase', 1.0),
#  ('activity of diacylglycerol kinase', 1.0),
#  ('dag by dag kinase', 1.0),
#  ('diacylglycerol by diacylglycerol kinase', 1.0),
#  ('ten mammalian diacylglycerol kinase', 1),
#  ('10 isoforms of diacylglycerol kinase', 1.0),
#  ('of the enzyme diacylglycerol kinase', 1.0),
#  ('the role of diacylglycerol kinase', 1.0),
#  ('to pa by dag kinase', 1.0),
#  ('dag to pa by diacylglycerol kinase', 1.0),
#  ('by phospholipase d pld and diacylglycerol kinase', 1.0),
#  ('in this study we identified diacylglycerol kinase', 1),
#  ('of phospholipase c plc and diacylglycerol kinase', 1.0),
#  ('physiological role of e coli diacylglycerol kinase', 1),
#  ('protein kinase c pkc and diacylglycerol kinase', 1.0),
#  ('ps enhance the metabolism activity of diacylglycerol kinase', 1),
#  ('phosphorylated of dag to pa is catalyzed by diacylglycerol kinase', 1),
#  ('catalyzed the hydrolysis of phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   1),
#  ('iated hydrolysis of glycosylphosphatidylinositol 13 14 and second diacylglycerol dag kinase',
#   1),
#  ('in mammals there are at least 10 isoforms of diacylglycerol kinase', 1),
#  ('in vitro kinase assays the activity of cerk and diacylglycerol kinase', 1),
#  ('porcine thymus cytosol contains two immunologically distinct forms of diacylglycerol kinase',
#   1),
#  ('result of increase diacylglycerol dg production in diabetic hyperglycaemia diacylglycerol kinase',
#   1),
#  ('toward dg molecular species introduction in agonist stimulated cell diacylglycerol kinase',
#   1),
#  ('acellular signaling lipid is generated by phosphorylated of diacylglycerol by diacylglycerol kinase',
#   1),
#  ('berridge and irvine 1984 subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   1),
#  ('independent pathway in an attempt to investigated differential function of diacylglycerol kinase',
#   1),
#  ('liana suspension cell phosphoinositide depend phospholipase c pi plc and diacylglycerol kinase',
#   1),
#  ('ngosine action introduction in the cellular signaling transduction process diacyl glycerol kinase',
#   1),
#  ('nknown the enzyme acyl coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   1),
#  ('organs especially in the process of spermatogenesis and oocyte maturation diacylglycerol kinase',
#   1),
#  ('ring in stimulated lymphocytes 1 introduction 2 materials and methods diacylglycerol kinase',
#   1),
#  ('1 stearoyl 2 arachidonoylglycerol the precursor of the endocannabinoid 2 ag diacylglycerol kinase',
#   1),
#  ('aling lipid produced at synapses during synaptic transmission is regulated by diacylglycerol kinase',
#   1),
#  ('bright for translating our understanding of dgk function to helping patients diacylglycerol kinase',
#   1),
#  ('by phospholipase d pld and the phosphorylated of diacylglycerol dag by diacylglycerol kinase',
#   1),
#  ('conjugated linoleic acid cla was associated with the upregulation of diacylglycerol dag kinase',
#   1),
#  ('d hydrolysis of a phospholipids most like phosphatidylcholine ptdcho c a diacylglycerol kinase',
#   1),
#  ('fi 5 respectively and nonselective cation channel trpc6 and 3 6 diacylglycerol kinase',
#   1),
#  ('g pocket concomitantly activity of the acth camp pathway increase nuclear diacylglycerol kinase',
#   1),
#  ('k isoforms may represent a novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   1),
#  ('mechanism leading to cardiac dysfunction and remodeling in diabetic 2 4 diacylglycerol kinase',
#   1),
#  ('nd phosphatidic we have focused on elucidate the molecular properties of diacylglycerol kinase',
#   1),
#  ('nvestigated prb binding to another lipid kinase in the phosphoinositide cycle diacylglycerol kinase',
#   1),
#  ('phosphatidic acid synthesis by activity both of the two alternative pathway diacyglycerol kinase',
#   1),
#  ('ppis to diacylglycerol dag that is subsequently phosphorylated to ptdoh by diacylglycerol kinase',
#   1),
#  ('several methods for ceramide study and analysis have been developed the diacylglycerol kinase',
#   1),
#  ('tinal dysfunction is of utmost importance the present study demonstrated that diacylglycerol kinase',
#   1),
#  ('acyl phosphate probe 10 μm 30 min first function proteomic annotated of diacylglycerol kinase',
#   1),
#  ('and pi3k pathway a complementing review by krishna and zhong discusses how diacylglycerol kinase',
#   1),
#  ('duced indirectly via the sequential action of phospholipase c plc and diacylglycerol dag kinase',
#   1),
#  ('has been implicated in the pathogenesis of a number of diabetic complications diacylglycerol kinase',
#   1),
#  ('hatidic acid pa by blocking plc activity however phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('in a fast evolving field this research topic illustrates the contribution of diacylglycerol kinase',
#   1),
#  ('ir of second messengers diacylglycerol dg and inositol 1 4 5 trisphosphate diacylglycerol kinase',
#   1),
#  ('itself is also subject to negative feedback regulated pkc can interact with diacylglycerol kinase',
#   1),
#  ('june 1996 revised version received 18 july 1996 abstract the cytosol ~ diacylglycerol kinase',
#   1),
#  ('n regulated the physiological and isotype specific function of pkc like pkc diacylglycerol kinase',
#   1),
#  ('nian ollerenshaw collins and heagerty 1990 j biol chem 265 8921 8928 diacylglycerol kinase',
#   1),
#  ('olysis of structural phospholipids or 3 via phosphorylated of diacylglycerol dag by dag kinase',
#   1),
#  ('proliferation and survival pa is mainly produced by phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('properties and the mitogenic response 8 10 much evidence reveal that the diacylglycerol kinase',
#   1),
#  ('r function 5 6 37 39 protein kinase c pkc diacylglycerol dag diacylglycerol kinase',
#   1),
#  ('s the intracellular level of phosphatidic acid primarily through the action of diacylglycerol kinase',
#   1),
#  ('se could constitute a treatment strategy for aggressive forms of cancer the diacylglycerol kinase',
#   1),
#  ('signaling pathway including diacylglycerol dag and pkc are involved in this process dag kinase',
#   1),
#  ('sm of diacylglycerol dag and phosphatidic acid pa had been proposed since diacylglycerol kinase',
#   1),
#  ('t of uv b treatment meanwhile two degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase',
#   1),
#  ('t we have investigated protein kinase c pkc tyrosine protein kinase tpk diacylglycerol kinase',
#   1),
#  ('that there may be structural similarities between protein kinase c pkc and diacylglycerol kinase',
#   1),
#  ('tive conditions to this end we examined the subunit dissociation kinetics of diacylglycerol kinase',
#   1),
#  ('tudies indicate that the signaling pa generated from phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('activity of plc which generated diacylglycerol dag that is phosphorylated to pa via dag kinase',
#   1),
#  ('al 2014 or 2 through the combined activity of phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('and another is a sequence of reaction catalyzed by phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('another key enzyme in the generated of a bioactive lipid study was the diacylglycerol kinase',
#   1),
#  ('d survival stimulated by hgf and other growth factors and cytokine depend on diacylglycerol kinase',
#   1),
#  ('dn in vivo suggesting that dgkα is an attractive therapeutic target for dn diacylglycerol kinase',
#   1),
#  ('ed by endothelin 1 et 1 and other galphaq protein coupled receptor agonist diacylglycerol kinase',
#   1),
#  ('ferentiation of cd8 t cell we report here that simultaneous deletion of both diacylglycerol kinase',
#   1),
#  ('ftsh degradation we asked whether that was also true for membrane protein diacyl glycerol kinase',
#   1),
#  ('glycerol dg production in diabetic hyperglycemia is one of the causes of dn diacylglycerol kinase',
#   1),
#  ('grade them 17 18 ftsh degradation a misfolded variant of the membrane protein diacylglycerol kinase',
#   1),
#  ('h as hypertension which dgk may reveal itself as a novel therapeutic target diacylglycerol kinase',
#   1),
#  ('hrough target protein phosphorylated dag level must be strictly controlled in the cell dag kinase',
#   1),
#  ('ia plc which generated diacylglycerol dag that is subsequently phosphorylated to pa by dag kinase',
#   1),
#  ('iacylglycerol dg and inositol 1 4 5 trisphosphate 1 2 in this system diacylglycerol kinase',
#   1),
#  ('ide cycle plays a pivotal role in neuronal signaling transduction in this cycle diacylglycerol kinase',
#   1),
#  ('ignaling can be generated via the combined action of phospholipase c plc and diacylglycerol kinase',
#   1),
#  ('ignaling dg metabolism this reaction is catalyzed by an enzyme referred to as diacylglycerol kinase',
#   1),
#  ('l for pa production induced via phospholipase c plc in concerted action with diacylglycerol kinase',
#   1),
#  ('lly to prevent neutrophil activity by ancas we have investigated a role for diacylglycerol kinase',
#   1),
#  ('ly associated with the er function one enzyme response for pa synthesis is diacylglycerol kinase',
#   1),
#  ('may be related with the protein degradation machinery to date 10 isoforms of diacylglycerol kinase',
#   1),
#  ('nce of phon another potential candidate for kinase 1 is a membrane associated diacylglycerol kinase',
#   1),
#  ('ng oxidative stress induced intestinal epithelial cell injury however the exact role of dag kinase',
#   1),
#  ('nt and function the importance of pa mediated signaling remain less clear the diacylglycerol kinase',
#   1),
#  ('of total lipid in mammalian cell its can be produced from diacylglycerol by diacylglycerol kinase',
#   1),
#  ('ol dag but not inositol triphosphate suggesting a blockade at the level of diacylglycerol kinase',
#   1),
#  ('ptdinsp 5 kinase independent of gtp here we report the identification of a diacylglycerol kinase',
#   1),
#  ('rations of ethanol in the medium delayed or abolished nuclear breakdown 3 5 diacylglycerol kinase',
#   1),
#  ('rived from either a pld that hydrolyzes phosphatidylcholine 4 7 or a diacylglycerol dag kinase',
#   1),
#  ('rolysis of membrane phospholipids by phospholipase d pld the phosphorylated of dag by dag kinase',
#   1),
#  ('s erk cascade is phosphatidic acid pa generated by phospholipase d pld and diacylglycerol kinase',
#   1),
#  ('s have been found to inhibited the pkc mediated regulatory pathway by activity diacylglycerol kinase',
#   1),
#  ('shp 1 showed increase effector t cell activity 48 the second candidate was diacylglycerol kinase',
#   1),
#  ('son of the structural and function properties of protein kinase c pkc and diacylglycerol kinase',
#   1),
#  ('ternatively the conversion of pa to dag was inhibited by propranolol 6 diacylglyc erol kinase',
#   1),
#  ('th other synaptic protein the conversion of dag to phosphatidic acid pa by diacylglycerol kinase',
#   1),
#  ('to activity rasgrp to be more spatially precise because both the production plc and inactivation',
#   1),
#  ('tp and inhibitor binding in the poorly annotated activity site of the mammalian diacylglycerol kinase',
#   1),
#  ('vation 32 dag activity is inhibited by its phosphorylated into phosphatidic acid by dag kinase',
#   1),
#  ('vels of these second messengers recently we have shown an obligatory role of diacylglycerol kinase',
#   1),
#  ('ying those effect remain unknown in this study we characterized the role of diacylglycerol kinase',
#   1),
#  ('β and by the upregulation of intrinsic negative regulated such as pd1 and diacylglycerol kinase',
#   1),
#  ('a and sphingomyelin sm in the amphibian oocyte 1 2 dag is phosphorylated by diglyceride kinase',
#   1),
#  ('activity of dag that is mediated by dgk the findings that the inhibited of diacylglycerol kinase',
#   1),
#  ('asing protein rasgrp chimerins and unc 13 then the generated dg is phosphorylated by dg kinase',
#   1),
#  ('ators of mtor here we explored the contribution to this pathway of the enzyme diacylglycerol kinase',
#   1),
#  ('eber et al 4 and zeng et al 5 have consecutively showed that dgkh diacylglycerol kinase',
#   1),
#  ('function as a potent activity of protein kinase c pkc and is catalyzed by diacylglycerol kinase',
#   1),
#  ('g to elucidate the molecular properties of these enzyme and first succeeded in purifying dg kinase',
#   1),
#  ('he other hand mass measurement of ceramide in the cell has been performed by diacylglycerol kinase',
#   1),
#  ('htly associated with membrane dg is produced transiently as its is rapidly metabolism by dg kinase',
#   1),
#  ('including protein kinase c pkc almena and mérida 2011 dg signaling is terminated by dg kinase',
#   1),
#  ('ing t cell function recently work from our group and other has indicate that diacylglycerol kinase',
#   1),
#  ('ipase however an addition possibility is that 2 ag is also a substrate for diacylglycerol kinase',
#   1),
#  ('lobulin ig e bound fcεri receptor in this study we determined the role of diacylglycerol kinase',
#   1),
#  ('n cardiomyocytes caveolae or 2 α 1 ars increase dag but a locally activity diacyglycerol kinase',
#   1),
#  ('n of this signaling is its conversion to phosphatidic acid which is catalyzed by diacylglycerol kinase',
#   1),
#  ('of ef hand motifs recently detected in the primary structural of porcine 80 kda diacylglycerol kinase',
#   1),
#  ('of t cell anergy has been poorly understood used the key anergy target gene diacylglycerol kinase',
#   1),
#  ('of the t cell repertoire expression of the dag effector rasgrp1 and the dag metabolism enzyme',
#   1),
#  ('ological role of dgkƞ and even less the pathophysiological role of dgkƞ in bd diacylglycerol kinase',
#   1),
#  ('on of dag into the inactive phosphatidic acid a reaction that is mediated by diacylglycerol kinase',
#   1),
#  ('pholipase c leading to the production of dg which is phosphorylated to pa by diacylglycerol kinase',
#   1),
#  ('pkc plays a critical role in the developed of cardiac hypertrophy and heart failure dag kinase',
#   1),
#  ('rely an intermediate metabolite for tg metabolism its also serves as a signaling molecule dg kinase',
#   1),
#  ('such as phosphatidylinositol specific phospholipase c pi plc e c 3 1 4 11 diacylglycerol kinase',
#   1),
#  ('ting the activity and or level of either phospholipase d pld1 and pld2 or diacylglycerol kinase',
#   1),
#  ('ting to a role for ceramide in apoptosis they questioned the reliability of the diglyceride kinase',
#   1),
#  ('tion in cultured and intact skeletal muscle we determined the effect of a pan diacylglycerol kinase',
#   1),
#  ('we determined if the monoglycerides 2 ag or 2 oleoyl glycerol 2 og affected diacylglycerol kinase',
#   1),
#  ('y its conversion to phosphatidic acid pa a reaction that is catalyzed by diacylglycerol kinase s',
#   1),
#  ('α for degradation in our present study we examined the effect of r59949 the diacylglycerol kinase',
#   1),
#  ('c1 domains of dgkα is the key event that regulated the activity of the enzyme diacylglycerol kinase',
#   1),
#  ('ce dagl 1 mutation may enhance tor signaling by converted more dag to pa by diacylglycerol kinase',
#   1),
#  ('generated diacylglycerol dag as the first production and dag is rapidly converted to pa by dag kinase',
#   1),
#  ('in animals is lacking from plant genomes 5 in plant dag can be phosphorylated by dag kinase',
#   1),
#  ('ligand stimulated cme of egfr in addition to pld pa can also be produced by diacylglyercol kinase',
#   1),
#  ('luding growth factors and hormones the dag produced serves as a substrate for the enzyme dag kinase',
#   1),
#  ('oxicity in a mouse hd striatal cell model hdh 111q 111q cell we found that diacylglycerol kinase',
#   1),
#  ('r potential cation channel c trpc 4 and both conventional and novel pkc 5 6 dg kinase',
#   1),
#  ('r that relays the tcr signaling to multiple downstream signaling cascade dag is terminated by dag kinase',
#   1),
#  ('rmer activity protein kinase c and the latter mobilizes ca 2 + from intracellular store dag kinase',
#   1),
#  ('wn we have reveal by cdna cloning the presence of a novel enzyme family of diacylglycerol kinase',
#   1),
#  ('y with rac 12 the associated is gtp independent we have now found that a diacylglycerol kinase',
#   1),
#  ('at the most probable mechanism of dag action is the conversion of dag to pa by diacylglycerol kinase',
#   1),
#  ('d its metabolite 1 o hexadecyl 2 o methyl sn glycerol amg on the activity of diacylglycerol kinase',
#   1),
#  ('m those of dgkη1 and that they plays role in the testis in a different manner diacylglycerol kinase',
#   1),
#  ('n the heart of transgenic mice g alpha q tg induced cardiac hypertrophy and lethal hf dag kinase',
#   1),
#  ('ol dag athenstaedt and daum 1999 the latter can be used as a substrate for the cognate kinase',
#   1),
#  ('rolyzed by dag lipase dagl to become 2 arachidonoyl sn glycerol 2 ag or modified by dag kinase',
#   1),
#  ('s lck and zap70 19 ubiquitin ligases i e cbl b 20 and kinase i e diacylglycerol kinase',
#   1),
#  ('t has no inhibitory effect on pld had no effect on lc3 associated with ldcvs normally dag kinase',
#   1),
#  ('t ras activity in cytokine stimulated t all cell to test this hypothesis we used the dag kinase',
#   1),
#  ('2 induced a significant increase of 36 1 36 2 40 5 and 40 6 diacyl pa a diacylglycerol kinase',
#   1),
#  ('enzyme', 0.0),
#  ('inactivation', 0.0),
#  ('s', 0.0),
#  ('and inactivation', 0.0),
#  ('cognate kinase', 0.0),
#  ('diacylglyercol kinase', 0.0),
#  ('erol kinase', 0.0),
#  ('glycerol kinase', 0.0),
#  ('kinase s', 0.0),
#  ('metabolism enzyme', 0.0),
#  ('11 diacylglycerol kinase', 0.0),
#  ('4 diacylglycerol kinase', 0.0),
#  ('5 diacylglycerol kinase', 0.0),
#  ('6 dg kinase', 0.0),
#  ('6 diacylglycerol kinase', 0.0),
#  ('8928 diacylglycerol kinase', 0.0),
#  ('acid diacylglycerol kinase', 0.0),
#  ('activity diacyglycerol kinase', 0.0),
#  ('activity diacylglycerol kinase', 0.0),
#  ('affected diacylglycerol kinase', 0.0),
#  ('ag diacylglycerol kinase', 0.0),
#  ('agonist diacylglycerol kinase', 0.0),
#  ('as diacylglycerol kinase', 0.0),
#  ('associated diacylglycerol kinase', 0.0),
#  ('bd diacylglycerol kinase', 0.0),
#  ('both diacylglycerol kinase', 0.0),
#  ('by diacylglyercol kinase', 0.0),
#  ('by diglyceride kinase', 0.0),
#  ('cell dag kinase', 0.0),
#  ('cell diacylglycerol kinase', 0.0),
#  ('coli diacylglycerol kinase', 0.0),
#  ('complications diacylglycerol kinase', 0.0),
#  ('dag diacylglycerol kinase', 0.0),
#  ('dag metabolism enzyme', 0.0),
#  ('dgkh diacylglycerol kinase', 0.0),
#  ('diacylglyc erol kinase', 0.0),
#  ('diacylglycerol kinase s', 0.0),
#  ('dysfunction diacylglycerol kinase', 0.0),
#  ('e diacylglycerol kinase', 0.0),
#  ('enzyme dag kinase', 0.0),
#  ('enzyme diacylglycerol kinase', 0.0),
#  ('failure dag kinase', 0.0),
#  ('gene diacylglycerol kinase', 0.0),
#  ('hf dag kinase', 0.0),
#  ('how diacylglycerol kinase', 0.0),
#  ('hyperglycaemia diacylglycerol kinase', 0.0),
#  ('identified diacylglycerol kinase', 0.0),
#  ('is diacylglycerol kinase', 0.0),
#  ('kda diacylglycerol kinase', 0.0),
#  ('manner diacylglycerol kinase', 0.0),
#  ('maturation diacylglycerol kinase', 0.0),
#  ('methods diacylglycerol kinase', 0.0),
#  ('molecule dg kinase', 0.0),
#  ('normally dag kinase', 0.0),
#  ('nuclear diacylglycerol kinase', 0.0),
#  ('of dag kinase', 0.0),
#  ('on diacylglycerol kinase', 0.0),
#  ('or diacylglycerol kinase', 0.0),
#  ('pan diacylglycerol kinase', 0.0),
#  ('pathway diacyglycerol kinase', 0.0),
#  ('patients diacylglycerol kinase', 0.0),
#  ('pkc diacylglycerol kinase', 0.0),
#  ('plc and inactivation', 0.0),
#  ('process dag kinase', 0.0),
#  ('protein diacylglycerol kinase', 0.0),
#  ('purifying dg kinase', 0.0),
#  ('since diacylglycerol kinase', 0.0),
#  ('store dag kinase', 0.0),
#  ('system diacylglycerol kinase', 0.0),
#  ('target diacylglycerol kinase', 0.0),
#  ('the cognate kinase', 0.0),
#  ('the dag kinase', 0.0),
#  ('the diglyceride kinase', 0.0),
#  ('tpk diacylglycerol kinase', 0.0),
#  ('trisphosphate diacylglycerol kinase', 0.0),
#  ('via dag kinase', 0.0),
#  ('was diacylglycerol kinase', 0.0),
#  ('~ diacylglycerol kinase', 0.0),
#  ('2 4 diacylglycerol kinase', 0.0),
#  ('2 ag diacylglycerol kinase', 0.0),
#  ('3 5 diacylglycerol kinase', 0.0),
#  ('3 6 diacylglycerol kinase', 0.0),
#  ('4 11 diacylglycerol kinase', 0.0),
#  ('5 6 dg kinase', 0.0),
#  ('5 trisphosphate diacylglycerol kinase', 0.0),
#  ('6 diacylglyc erol kinase', 0.0),
#  ('80 kda diacylglycerol kinase', 0.0),
#  ('8921 8928 diacylglycerol kinase', 0.0),
#  ('a diacylglycerol dag kinase', 0.0),
#  ('a pan diacylglycerol kinase', 0.0),
#  ('acid by dag kinase', 0.0),
#  ('action of diacylglycerol kinase', 0.0),
#  ('action with diacylglycerol kinase', 0.0),
#  ('alternative pathway diacyglycerol kinase', 0.0),
#  ('and diacylglycerol dag kinase', 0.0),
#  ('and methods diacylglycerol kinase', 0.0),
#  ('annotated of diacylglycerol kinase', 0.0),
#  ('by activity diacylglycerol kinase', 0.0),
#  ('by diacylglycerol kinase s', 0.0),
#  ('c a diacylglycerol kinase', 0.0),
#  ('cancer the diacylglycerol kinase', 0.0),
#  ('candidate was diacylglycerol kinase', 0.0),
#  ('catalyzed by diacylglycerol kinase', 0.0),
#  ('cerk and diacylglycerol kinase', 0.0),
#  ('clear the diacylglycerol kinase', 0.0),
#  ('contribution of diacylglycerol kinase', 0.0),
#  ('cytosol ~ diacylglycerol kinase', 0.0),
#  ('dag by diacylglycerol kinase', 0.0),
#  ('demonstrated that diacylglycerol kinase', 0.0),
#  ('depend on diacylglycerol kinase', 0.0),
#  ('developed the diacylglycerol kinase', 0.0),
#  ('dgat and diacylglycerol kinase', 0.0),
#  ('diabetic complications diacylglycerol kinase', 0.0),
#  ('diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('different manner diacylglycerol kinase', 0.0),
#  ('discusses how diacylglycerol kinase', 0.0),
#  ('e coli diacylglycerol kinase', 0.0),
#  ('family of diacylglycerol kinase', 0.0),
#  ('for dn diacylglycerol kinase', 0.0),
#  ('for the cognate kinase', 0.0),
#  ('forms of diacylglycerol kinase', 0.0),
#  ('found that diacylglycerol kinase', 0.0),
#  ('function of diacylglycerol kinase', 0.0),
#  ('glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('heart failure dag kinase', 0.0),
#  ('helping patients diacylglycerol kinase', 0.0),
#  ('i e diacylglycerol kinase', 0.0),
#  ('in bd diacylglycerol kinase', 0.0),
#  ('in purifying dg kinase', 0.0),
#  ('increase nuclear diacylglycerol kinase', 0.0),
#  ('indicate that diacylglycerol kinase', 0.0),
#  ('inhibited of diacylglycerol kinase', 0.0),
#  ('interact with diacylglycerol kinase', 0.0),
#  ('intracellular store dag kinase', 0.0),
#  ('isoforms of diacylglycerol kinase', 0.0),
#  ('kinase tpk diacylglycerol kinase', 0.0),
#  ('kinetics of diacylglycerol kinase', 0.0),
#  ('ldcvs normally dag kinase', 0.0),
#  ('lethal hf dag kinase', 0.0),
#  ('level of diacylglycerol kinase', 0.0),
#  ('like pkc diacylglycerol kinase', 0.0),
#  ('locally activity diacyglycerol kinase', 0.0),
#  ('mediated by diacylglycerol kinase', 0.0),
#  ('membrane associated diacylglycerol kinase', 0.0),
#  ('membrane protein diacylglycerol kinase', 0.0),
#  ('metabolism by dg kinase', 0.0),
#  ('modified by dag kinase', 0.0),
#  ('of a diacylglycerol kinase', 0.0),
#  ('of both diacylglycerol kinase', 0.0),
#  ('of diacylglycerol dag kinase', 0.0),
#  ('of dn diacylglycerol kinase', 0.0),
#  ('of the diglyceride kinase', 0.0),
#  ('og affected diacylglycerol kinase', 0.0),
#  ('oocyte maturation diacylglycerol kinase', 0.0),
#  ('pa a diacylglycerol kinase', 0.0),
#  ('pa by dag kinase', 0.0),
#  ('pa via dag kinase', 0.0),
#  ('pd1 and diacylglycerol kinase', 0.0),
#  ('performed by diacylglycerol kinase', 0.0),
#  ('phosphatidic acid diacylglycerol kinase', 0.0),
#  ('phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('phosphorylated by dag kinase', 0.0),
#  ('phosphorylated by dg kinase', 0.0),
#  ('phosphorylated by diacylglycerol kinase', 0.0),
#  ('phosphorylated by diglyceride kinase', 0.0),
#  ('pkc and diacylglycerol kinase', 0.0),
#  ('pld and diacylglycerol kinase', 0.0),
#  ('pld2 or diacylglycerol kinase', 0.0),
#  ('process diacyl glycerol kinase', 0.0),
#  ('produced by diacylglyercol kinase', 0.0),
#  ('production plc and inactivation', 0.0),
#  ('properties of diacylglycerol kinase', 0.0),
#  ('proposed since diacylglycerol kinase', 0.0),
#  ('protein diacyl glycerol kinase', 0.0),
#  ('ptdoh by diacylglycerol kinase', 0.0),
#  ('r59949 the diacylglycerol kinase', 0.0),
#  ('receptor agonist diacylglycerol kinase', 0.0),
#  ('regulated by diacylglycerol kinase', 0.0),
#  ('role for diacylglycerol kinase', 0.0),
#  ('role of dag kinase', 0.0),
#  ('second diacylglycerol dag kinase', 0.0),
#  ('signaling molecule dg kinase', 0.0),
#  ('stimulated cell diacylglycerol kinase', 0.0),
#  ('substrate for diacylglycerol kinase', 0.0),
#  ('synthesis is diacylglycerol kinase', 0.0),
#  ('target gene diacylglycerol kinase', 0.0),
#  ('terminated by dag kinase', 0.0),
#  ('terminated by dg kinase', 0.0),
#  ('that a diacylglycerol kinase', 0.0),
#  ('that dgkh diacylglycerol kinase', 0.0),
#  ('that the diacylglycerol kinase', 0.0),
#  ('the cell dag kinase', 0.0),
#  ('the dag metabolism enzyme', 0.0),
#  ('the enzyme dag kinase', 0.0),
#  ('the enzyme diacylglycerol kinase', 0.0),
#  ('the mammalian diacylglycerol kinase', 0.0),
#  ('therapeutic target diacylglycerol kinase', 0.0),
#  ('this cycle diacylglycerol kinase', 0.0),
#  ('this process dag kinase', 0.0),
#  ('this system diacylglycerol kinase', 0.0),
#  ('to as diacylglycerol kinase', 0.0),
#  ('used the dag kinase', 0.0),
#  ('vascular dysfunction diacylglycerol kinase', 0.0),
#  ('was the diacylglycerol kinase', 0.0),
#  ('we identified diacylglycerol kinase', 0.0),
#  ('1 4 11 diacylglycerol kinase', 0.0),
#  ('2 og affected diacylglycerol kinase', 0.0),
#  ('265 8921 8928 diacylglycerol kinase', 0.0),
#  ('4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('a different manner diacylglycerol kinase', 0.0),
#  ('a locally activity diacyglycerol kinase', 0.0),
#  ('a membrane associated diacylglycerol kinase', 0.0),
#  ('a role for diacylglycerol kinase', 0.0),
#  ('a signaling molecule dg kinase', 0.0),
#  ('a substrate for diacylglycerol kinase', 0.0),
#  ('acid pa by diacylglycerol kinase', 0.0),
#  ('acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('and 3 6 diacylglycerol kinase', 0.0),
#  ('and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('and heart failure dag kinase', 0.0),
#  ('and lethal hf dag kinase', 0.0),
#  ('and oocyte maturation diacylglycerol kinase', 0.0),
#  ('and pld2 or diacylglycerol kinase', 0.0),
#  ('and second diacylglycerol dag kinase', 0.0),
#  ('and the dag metabolism enzyme', 0.0),
#  ('anergy target gene diacylglycerol kinase', 0.0),
#  ('as pd1 and diacylglycerol kinase', 0.0),
#  ('be phosphorylated by dag kinase', 0.0),
#  ('be produced by diacylglyercol kinase', 0.0),
#  ('been developed the diacylglycerol kinase', 0.0),
#  ('been performed by diacylglycerol kinase', 0.0),
#  ('been proposed since diacylglycerol kinase', 0.0),
#  ('breakdown 3 5 diacylglycerol kinase', 0.0),
#  ('c pkc and diacylglycerol kinase', 0.0),
#  ('c plc and diacylglycerol kinase', 0.0),
#  ('can interact with diacylglycerol kinase', 0.0),
#  ('catalyzed by diacylglycerol kinase s', 0.0),
#  ('causes of dn diacylglycerol kinase', 0.0),
#  ('concerted action with diacylglycerol kinase', 0.0),
#  ('coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('cytokine depend on diacylglycerol kinase', 0.0),
#  ('d pld and diacylglycerol kinase', 0.0),
#  ('deletion of both diacylglycerol kinase', 0.0),
#  ('dgkƞ in bd diacylglycerol kinase', 0.0),
#  ('diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('diacyl pa a diacylglycerol kinase', 0.0),
#  ('diacylglycerol dag by dag kinase', 0.0),
#  ('diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('differential function of diacylglycerol kinase', 0.0),
#  ('dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('distinct forms of diacylglycerol kinase', 0.0),
#  ('endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('enzyme family of diacylglycerol kinase', 0.0),
#  ('exact role of dag kinase', 0.0),
#  ('for the enzyme dag kinase', 0.0),
#  ('found that a diacylglycerol kinase', 0.0),
#  ('from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('from intracellular store dag kinase', 0.0),
#  ('generated phosphatidic acid diacylglycerol kinase', 0.0),
#  ('has indicate that diacylglycerol kinase', 0.0),
#  ('identification of a diacylglycerol kinase', 0.0),
#  ('immediately phosphorylated by diacylglycerol kinase', 0.0),
#  ('in diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('in the cell dag kinase', 0.0),
#  ('in this cycle diacylglycerol kinase', 0.0),
#  ('in this process dag kinase', 0.0),
#  ('in this system diacylglycerol kinase', 0.0),
#  ('in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('is mediated by diacylglycerol kinase', 0.0),
#  ('is phosphorylated by dg kinase', 0.0),
#  ('is phosphorylated by diglyceride kinase', 0.0),
#  ('is regulated by diacylglycerol kinase', 0.0),
#  ('is terminated by dag kinase', 0.0),
#  ('is terminated by dg kinase', 0.0),
#  ('kinase i e diacylglycerol kinase', 0.0),
#  ('less clear the diacylglycerol kinase', 0.0),
#  ('materials and methods diacylglycerol kinase', 0.0),
#  ('membrane protein diacyl glycerol kinase', 0.0),
#  ('metabolism activity of diacylglycerol kinase', 0.0),
#  ('molecular properties of diacylglycerol kinase', 0.0),
#  ('novel therapeutic target diacylglycerol kinase', 0.0),
#  ('obligatory role of diacylglycerol kinase', 0.0),
#  ('of a pan diacylglycerol kinase', 0.0),
#  ('of cancer the diacylglycerol kinase', 0.0),
#  ('of cerk and diacylglycerol kinase', 0.0),
#  ('of dag by dag kinase', 0.0),
#  ('of diabetic complications diacylglycerol kinase', 0.0),
#  ('of diacylglycerol by diacylglycerol kinase', 0.0),
#  ('of e coli diacylglycerol kinase', 0.0),
#  ('of r59949 the diacylglycerol kinase', 0.0),
#  ('of the mammalian diacylglycerol kinase', 0.0),
#  ('or a diacylglycerol dag kinase', 0.0),
#  ('or modified by dag kinase', 0.0),
#  ('pa synthesis is diacylglycerol kinase', 0.0),
#  ('pathway by activity diacylglycerol kinase', 0.0),
#  ('pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('phosphatidic acid by dag kinase', 0.0),
#  ('pi plc and diacylglycerol kinase', 0.0),
#  ('pkc 5 6 dg kinase', 0.0),
#  ('pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('pkc like pkc diacylglycerol kinase', 0.0),
#  ('plc and diacylglycerol dag kinase', 0.0),
#  ('porcine 80 kda diacylglycerol kinase', 0.0),
#  ('propranolol 6 diacylglyc erol kinase', 0.0),
#  ('protein kinase tpk diacylglycerol kinase', 0.0),
#  ('proteomic annotated of diacylglycerol kinase', 0.0),
#  ('ptdcho c a diacylglycerol kinase', 0.0),
#  ('rapidly metabolism by dg kinase', 0.0),
#  ('referred to as diacylglycerol kinase', 0.0),
#  ('reliability of the diglyceride kinase', 0.0),
#  ('reveal that the diacylglycerol kinase', 0.0),
#  ('second candidate was diacylglycerol kinase', 0.0),
#  ('showed that dgkh diacylglycerol kinase', 0.0),
#  ('study demonstrated that diacylglycerol kinase', 0.0),
#  ('study was the diacylglycerol kinase', 0.0),
#  ('study we identified diacylglycerol kinase', 0.0),
#  ('substrate for the cognate kinase', 0.0),
#  ('succeeded in purifying dg kinase', 0.0),
#  ('target for dn diacylglycerol kinase', 0.0),
#  ('the action of diacylglycerol kinase', 0.0),
#  ('the activity of diacylglycerol kinase', 0.0),
#  ('the contribution of diacylglycerol kinase', 0.0),
#  ('the cytosol ~ diacylglycerol kinase', 0.0),
#  ('the inhibited of diacylglycerol kinase', 0.0),
#  ('the level of diacylglycerol kinase', 0.0),
#  ('the membrane protein diacylglycerol kinase', 0.0),
#  ('the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('the production plc and inactivation', 0.0),
#  ('to helping patients diacylglycerol kinase', 0.0),
#  ('to pa via dag kinase', 0.0),
#  ('to ptdoh by diacylglycerol kinase', 0.0),
#  ('transduction process diacyl glycerol kinase', 0.0),
#  ('two alternative pathway diacyglycerol kinase', 0.0),
#  ('upregulation of diacylglycerol dag kinase', 0.0),
#  ('we found that diacylglycerol kinase', 0.0),
#  ('we used the dag kinase', 0.0),
#  ('with ldcvs normally dag kinase', 0.0),
#  ('zhong discusses how diacylglycerol kinase', 0.0),
#  ('+ from intracellular store dag kinase', 0.0),
#  ('1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('14 and second diacylglycerol dag kinase', 0.0),
#  ('2 in this system diacylglycerol kinase', 0.0),
#  ('2 materials and methods diacylglycerol kinase', 0.0),
#  ('3 1 4 11 diacylglycerol kinase', 0.0),
#  ('6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('7 or a diacylglycerol dag kinase', 0.0),
#  ('a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('a substrate for the cognate kinase', 0.0),
#  ('abstract the cytosol ~ diacylglycerol kinase', 0.0),
#  ('activity of cerk and diacylglycerol kinase', 0.0),
#  ('activity of the enzyme diacylglycerol kinase', 0.0),
#  ('ag or modified by dag kinase', 0.0),
#  ('also a substrate for diacylglycerol kinase', 0.0),
#  ('also be produced by diacylglyercol kinase', 0.0),
#  ('an obligatory role of diacylglycerol kinase', 0.0),
#  ('and cytokine depend on diacylglycerol kinase', 0.0),
#  ('and is catalyzed by diacylglycerol kinase', 0.0),
#  ('and kinase i e diacylglycerol kinase', 0.0),
#  ('and zhong discusses how diacylglycerol kinase', 0.0),
#  ('approach in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('as a signaling molecule dg kinase', 0.0),
#  ('associated with ldcvs normally dag kinase', 0.0),
#  ('at the level of diacylglycerol kinase', 0.0),
#  ('both the production plc and inactivation', 0.0),
#  ('but a locally activity diacyglycerol kinase', 0.0),
#  ('by propranolol 6 diacylglyc erol kinase', 0.0),
#  ('c pi plc and diacylglycerol kinase', 0.0),
#  ('c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('c plc and diacylglycerol dag kinase', 0.0),
#  ('camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('can be phosphorylated by dag kinase', 0.0),
#  ('cell we found that diacylglycerol kinase', 0.0),
#  ('characterized the role of diacylglycerol kinase', 0.0),
#  ('chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('controlled in the cell dag kinase', 0.0),
#  ('converted to pa by dag kinase', 0.0),
#  ('dag is phosphorylated by diglyceride kinase', 0.0),
#  ('dag is terminated by dag kinase', 0.0),
#  ('date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('determined the role of diacylglycerol kinase', 0.0),
#  ('dg is phosphorylated by dg kinase', 0.0),
#  ('diacylglycerol acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('effect of a pan diacylglycerol kinase', 0.0),
#  ('effect of r59949 the diacylglycerol kinase', 0.0),
#  ('enzyme referred to as diacylglycerol kinase', 0.0),
#  ('evidence reveal that the diacylglycerol kinase', 0.0),
#  ('first succeeded in purifying dg kinase', 0.0),
#  ('for membrane protein diacyl glycerol kinase', 0.0),
#  ('for pa synthesis is diacylglycerol kinase', 0.0),
#  ('forms of cancer the diacylglycerol kinase', 0.0),
#  ('function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('function to helping patients diacylglycerol kinase', 0.0),
#  ('glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('had been proposed since diacylglycerol kinase', 0.0),
#  ('has been performed by diacylglycerol kinase', 0.0),
#  ('have been developed the diacylglycerol kinase', 0.0),
#  ('hypertrophy and heart failure dag kinase', 0.0),
#  ('hypertrophy and lethal hf dag kinase', 0.0),
#  ('hypothesis we used the dag kinase', 0.0),
#  ('illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('in a different manner diacylglycerol kinase', 0.0),
#  ('in agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('in concerted action with diacylglycerol kinase', 0.0),
#  ('in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  
#  ('the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('the exact role of dag kinase', 0.0),
#  ('the identification of a diacylglycerol kinase', 0.0),
#  ('the metabolism activity of diacylglycerol kinase', 0.0),
#  ('the molecular properties of diacylglycerol kinase', 0.0),
#  ('the reliability of the diglyceride kinase', 0.0),
#  ('the second candidate was diacylglycerol kinase', 0.0),
#  ('the two alternative pathway diacyglycerol kinase', 0.0),
#  ('the upregulation of diacylglycerol dag kinase', 0.0),
#  ('therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('this study we identified diacylglycerol kinase', 0.0),
#  ('through the action of diacylglycerol kinase', 0.0),
#  ('to generated phosphatidic acid diacylglycerol kinase', 0.0),
#  ('transduction in this cycle diacylglycerol kinase', 0.0),
#  ('transmission is regulated by diacylglycerol kinase', 0.0),
#  ('trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('which is catalyzed by diacylglycerol kinase', 0.0),
#  ('1 2 in this system diacylglycerol kinase', 0.0),
#  ('1 is a membrane associated diacylglycerol kinase', 0.0),
#  ('111q cell we found that diacylglycerol kinase', 0.0),
#  ('13 14 and second diacylglycerol dag kinase', 0.0),
#  ('1996 abstract the cytosol ~ diacylglycerol kinase', 0.0),
#  ('2 + from intracellular store dag kinase', 0.0),
#  ('2 ag or modified by dag kinase', 0.0),
#  ('2 dag is phosphorylated by diglyceride kinase', 0.0),
#  ('20 and kinase i e diacylglycerol kinase', 0.0),
#  ('4 7 or a diacylglycerol dag kinase', 0.0),
#  ('40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('48 the second candidate was diacylglycerol kinase', 0.0),
#  ('a diacylglycerol acyltransferase dgat and diacylglycerol kinase', 0.0),
#  ('a novel enzyme family of diacylglycerol kinase', 0.0),
#  ('a number of diabetic complications diacylglycerol kinase', 0.0),
#  ('a substrate for the enzyme dag kinase', 0.0),
#  ('abolished nuclear breakdown 3 5 diacylglycerol kinase', 0.0),
#  ('acid which is catalyzed by diacylglycerol kinase', 0.0),
#  ('acth camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('activity site of the mammalian diacylglycerol kinase', 0.0),
#  ('aggressive forms of cancer the diacylglycerol kinase', 0.0),
#  ('amg on the activity of diacylglycerol kinase', 0.0),
#  ('an enzyme referred to as diacylglycerol kinase', 0.0),
#  ('analysis have been developed the diacylglycerol kinase', 0.0),
#  ('and first succeeded in purifying dg kinase', 0.0),
#  ('and novel pkc 5 6 dg kinase', 0.0),
#  ('and other has indicate that diacylglycerol kinase', 0.0),
#  ('are involved in this process dag kinase', 0.0),
#  ('as a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('as a substrate for the cognate kinase', 0.0),
#  ('at least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('attractive therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('be produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('because both the production plc and inactivation', 0.0),
#  ('bioactive lipid study was the diacylglycerol kinase', 0.0),
#  ('biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('blockade at the level of diacylglycerol kinase', 0.0),
#  ('by phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('by phosphorylated of diacylglycerol by diacylglycerol kinase', 0.0),
#  ('c 3 1 4 11 diacylglycerol kinase', 0.0),
#  ('can also be produced by diacylglyercol kinase', 0.0),
#  ('cardiac hypertrophy and heart failure dag kinase', 0.0),
#  ('cardiac hypertrophy and lethal hf dag kinase', 0.0),
#  ('cascade dag is terminated by dag kinase', 0.0),
#  ('cell has been performed by diacylglycerol kinase', 0.0),
#  ('cellular signaling transduction process diacyl glycerol kinase', 0.0),
#  ('channel trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('d pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('dag but a locally activity diacyglycerol kinase', 0.0),
#  ('dag can be phosphorylated by dag kinase', 0.0),
#  ('degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('dg is immediately phosphorylated by diacylglycerol kinase', 0.0),
#  ('dg production in diabetic hyperglycaemia diacylglycerol kinase', 0.0),
#  ('dg signaling is terminated by dg kinase', 0.0),
#  ('dgk function to helping patients diacylglycerol kinase', 0.0),
#  ('effector rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('elucidate the molecular properties of diacylglycerol kinase', 0.0),
#  ('enhance the metabolism activity of diacylglycerol kinase', 0.0),
#  ('factors and cytokine depend on diacylglycerol kinase', 0.0),
#  ('findings that the inhibited of diacylglycerol kinase', 0.0),
#  ('first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('from phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('function of pkc like pkc diacylglycerol kinase', 0.0),
#  ('galphaq protein coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('generated dg is phosphorylated by dg kinase', 0.0),
#  ('have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('have investigated a role for diacylglycerol kinase', 0.0),
#  ('have now found that a diacylglycerol kinase', 0.0),
#  ('however phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('however the exact role of dag kinase', 0.0),
#  ('inhibited by propranolol 6 diacylglyc erol kinase', 0.0),
#  ('inositol 1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('introduction 2 materials and methods diacylglycerol kinase', 0.0),
#  ('introduction in agonist stimulated cell diacylglycerol kinase', 0.0),
#  ('is also a substrate for diacylglycerol kinase', 0.0),
#  ('is phosphorylated to pa by diacylglycerol kinase', 0.0),
#  ('is phosphorylated to pa via dag kinase', 0.0),
#  ('its is rapidly metabolism by dg kinase', 0.0),
#  ('kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('kinase in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('krishna and zhong discusses how diacylglycerol kinase', 0.0),
#  ('lc3 associated with ldcvs normally dag kinase', 0.0),
#  ('like phosphatidylcholine ptdcho c a diacylglycerol kinase', 0.0),
#  ('mediated regulatory pathway by activity diacylglycerol kinase', 0.0),
#  ('more dag to pa by diacylglycerol kinase', 0.0),
#  ('much evidence reveal that the diacylglycerol kinase', 0.0),
#  ('of dag to pa by diacylglycerol kinase', 0.0),
#  ('of spermatogenesis and oocyte maturation diacylglycerol kinase', 0.0),
#  ('of the causes of dn diacylglycerol kinase', 0.0),
#  ('of the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('oleoyl glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('pa had been proposed since diacylglycerol kinase', 0.0),
#  ('phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   0.0),
#  ('phospholipase c pi plc and diacylglycerol kinase', 0.0),
#  ('phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('phosphorylated into phosphatidic acid by dag kinase', 0.0),
#  ('phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('phosphorylated of diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('pkc and is catalyzed by diacylglycerol kinase', 0.0),
#  ('pkc tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('plc in concerted action with diacylglycerol kinase', 0.0),
#  ('primarily through the action of diacylglycerol kinase', 0.0),
#  ('questioned the reliability of the diglyceride kinase', 0.0),
#  ('rapidly converted to pa by dag kinase', 0.0),
#  ('reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('regulated pkc can interact with diacylglycerol kinase', 0.0),
#  ('regulated such as pd1 and diacylglycerol kinase', 0.0),
#  ('remodeling in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('report the identification of a diacylglycerol kinase', 0.0),
#  ('response for pa synthesis is diacylglycerol kinase', 0.0),
#  ('role of dgkƞ in bd diacylglycerol kinase', 0.0),
#  ('serves as a signaling molecule dg kinase', 0.0),
#  ('shown an obligatory role of diacylglycerol kinase', 0.0),
#  ('signaling remain less clear the diacylglycerol kinase', 0.0),
#  ('signaling transduction in this cycle diacylglycerol kinase', 0.0),
#  ('strictly controlled in the cell dag kinase', 0.0),
#  ('structural of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('subsequently phosphorylated to pa by dag kinase', 0.0),
#  ('subsequently phosphorylated to ptdoh by diacylglycerol kinase', 0.0),
#  ('synaptic transmission is regulated by diacylglycerol kinase', 0.0),
#  ('testis in a different manner diacylglycerol kinase', 0.0),
#  ('that is catalyzed by diacylglycerol kinase s', 0.0),
#  ('that simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('the activity of cerk and diacylglycerol kinase', 0.0),
#  ('the activity of the enzyme diacylglycerol kinase', 0.0),
#  ('the effect of a pan diacylglycerol kinase', 0.0),
#  ('the effect of r59949 the diacylglycerol kinase', 0.0),
#  ('the key anergy target gene diacylglycerol kinase', 0.0),
#  ('the phosphorylated of dag by dag kinase', 0.0),
#  ('the present study demonstrated that diacylglycerol kinase', 0.0),
#  ('the subunit dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('therapeutic approach in vascular dysfunction diacylglycerol kinase', 0.0),
#  ('this hypothesis we used the dag kinase', 0.0),
#  ('this pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('to date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('to investigated differential function of diacylglycerol kinase', 0.0),
#  ('to pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('to phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('topic illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('true for membrane protein diacyl glycerol kinase', 0.0),
#  ('two immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('we characterized the role of diacylglycerol kinase', 0.0),
#  ('we determined the role of diacylglycerol kinase', 0.0),
#  ('with the upregulation of diacylglycerol dag kinase', 0.0),
#  ('1 2 dag is phosphorylated by diglyceride kinase', 0.0),
#  ('1 introduction 2 materials and methods diacylglycerol kinase', 0.0),
#  ('10 much evidence reveal that the diacylglycerol kinase', 0.0),
#  ('111q 111q cell we found that diacylglycerol kinase', 0.0),
#  ('2 oleoyl glycerol 2 og affected diacylglycerol kinase', 0.0),
#  ('2011 dg signaling is terminated by dg kinase', 0.0),
#  ('5 have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('a bioactive lipid study was the diacylglycerol kinase', 0.0),
#  ('a blockade at the level of diacylglycerol kinase', 0.0),
#  ('a reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('acid pa had been proposed since diacylglycerol kinase', 0.0),
#  ('acid primarily through the action of diacylglycerol kinase', 0.0),
#  ('action of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('activity 48 the second candidate was diacylglycerol kinase', 0.0),
#  ('activity however phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('activity of phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('ag is also a substrate for diacylglycerol kinase', 0.0),
#  ('also serves as a signaling molecule dg kinase', 0.0),
#  ('also true for membrane protein diacyl glycerol kinase', 0.0),
#  ('an attractive therapeutic target for dn diacylglycerol kinase', 0.0),
#  ('and 40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('and analysis have been developed the diacylglycerol kinase', 0.0),
#  ('and inositol 1 4 5 trisphosphate diacylglycerol kinase', 0.0),
#  ('and remodeling in diabetic 2 4 diacylglycerol kinase', 0.0),
#  ('annotated activity site of the mammalian diacylglycerol kinase', 0.0),
#  ('are at least 10 isoforms of diacylglycerol kinase', 0.0),
#  ('as a substrate for the enzyme dag kinase', 0.0),
#  ('as its is rapidly metabolism by dg kinase', 0.0),
#  ('assays the activity of cerk and diacylglycerol kinase', 0.0),
#  ('associated with the upregulation of diacylglycerol dag kinase', 0.0),
#  ('attempt to investigated differential function of diacylglycerol kinase',
#   0.0),
#  ('b 20 and kinase i e diacylglycerol kinase', 0.0),
#  ('be strictly controlled in the cell dag kinase', 0.0),
#  ('between protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('both of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('by an enzyme referred to as diacylglycerol kinase', 0.0),
#  ('by krishna and zhong discusses how diacylglycerol kinase', 0.0),
#  ('c pkc and is catalyzed by diacylglycerol kinase', 0.0),
#  ('c pkc tyrosine protein kinase tpk diacylglycerol kinase', 0.0),
#  ('c plc in concerted action with diacylglycerol kinase', 0.0),
#  ('ca 2 + from intracellular store dag kinase', 0.0),
#  ('can be produced from diacylglycerol by diacylglycerol kinase', 0.0),
#  ('catalyzed by phospholipase c plc and diacylglycerol kinase', 0.0),
#  ('cation channel trpc6 and 3 6 diacylglycerol kinase', 0.0),
#  ('coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   0.0),
#  ('contains two immunologically distinct forms of diacylglycerol kinase', 0.0),
#  ('conventional and novel pkc 5 6 dg kinase', 0.0),
#  ('conversion of dag to pa by diacylglycerol kinase', 0.0),
#  ('converted more dag to pa by diacylglycerol kinase', 0.0),
#  ('dag effector rasgrp1 and the dag metabolism enzyme', 0.0),
#  ('dag to pa is catalyzed by diacylglycerol kinase', 0.0),
#  ('dag to phosphatidic acid pa by diacylglycerol kinase', 0.0),
#  ('depend phospholipase c pi plc and diacylglycerol kinase', 0.0),
#  ('determined the effect of a pan diacylglycerol kinase', 0.0),
#  ('diacylglycerol dg production in diabetic hyperglycaemia diacylglycerol kinase',
#   0.0),
#  ('during synaptic transmission is regulated by diacylglycerol kinase', 0.0),
#  ('e c 3 1 4 11 diacylglycerol kinase', 0.0),
#  ('enzyme and first succeeded in purifying dg kinase', 0.0),
#  ('enzyme response for pa synthesis is diacylglycerol kinase', 0.0),
#  ('examined the effect of r59949 the diacylglycerol kinase', 0.0),
#  ('examined the subunit dissociation kinetics of diacylglycerol kinase', 0.0),
#  ('feedback regulated pkc can interact with diacylglycerol kinase', 0.0),
#  ('for aggressive forms of cancer the diacylglycerol kinase', 0.0),
#  ('generated by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('generated by phosphorylated of diacylglycerol by diacylglycerol kinase',
#   0.0),
#  ('generated from phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('glycerol 2 ag or modified by dag kinase', 0.0),
#  ('glycerol amg on the activity of diacylglycerol kinase', 0.0),
#  ('glycosylphosphatidylinositol 13 14 and second diacylglycerol dag kinase',
#   0.0),
#  ('group and other has indicate that diacylglycerol kinase', 0.0),
#  ('growth factors and cytokine depend on diacylglycerol kinase', 0.0),
#  ('have shown an obligatory role of diacylglycerol kinase', 0.0),
#  ('here that simultaneous deletion of both diacylglycerol kinase', 0.0),
#  ('importance the present study demonstrated that diacylglycerol kinase', 0.0),
#  ('increase dag but a locally activity diacyglycerol kinase', 0.0),
#  ('induced cardiac hypertrophy and lethal hf dag kinase', 0.0),
#  ('injury however the exact role of dag kinase', 0.0),
#  ('is rapidly converted to pa by dag kinase', 0.0),
#  ('is subsequently phosphorylated to pa by dag kinase', 0.0),
#  ('is subsequently phosphorylated to ptdoh by diacylglycerol kinase', 0.0),
#  ('its phosphorylated into phosphatidic acid by dag kinase', 0.0),
#  ('itself as a novel therapeutic target diacylglycerol kinase', 0.0),
#  ('j biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('july 1996 abstract the cytosol ~ diacylglycerol kinase', 0.0),
#  ('kinase 1 is a membrane associated diacylglycerol kinase', 0.0),
#  ('lipid kinase in the phosphoinositide cycle diacylglycerol kinase', 0.0),
#  ('machinery to date 10 isoforms of diacylglycerol kinase', 0.0),
#  ('mediated signaling remain less clear the diacylglycerol kinase', 0.0),
#  ('min first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('misfolded variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('most like phosphatidylcholine ptdcho c a diacylglycerol kinase', 0.0),
#  ('negative regulated such as pd1 and diacylglycerol kinase', 0.0),
#  ('neuronal signaling transduction in this cycle diacylglycerol kinase', 0.0),
#  ('novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   0.0),
#  ('of a novel enzyme family of diacylglycerol kinase', 0.0),
#  ('of a number of diabetic complications diacylglycerol kinase', 0.0),
#  ('of cardiac hypertrophy and heart failure dag kinase', 0.0),
#  ('of dgk function to helping patients diacylglycerol kinase', 0.0),
#  ('of phosphatidylcholine to generated phosphatidic acid diacylglycerol kinase',
#   0.0),
#  ('of phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('of protein kinase c pkc and diacylglycerol kinase', 0.0),
#  ('on elucidate the molecular properties of diacylglycerol kinase', 0.0),
#  ('on lc3 associated with ldcvs normally dag kinase', 0.0),
#  ('one of the causes of dn diacylglycerol kinase', 0.0),
#  ('or abolished nuclear breakdown 3 5 diacylglycerol kinase', 0.0),
#  ('other galphaq protein coupled receptor agonist diacylglycerol kinase', 0.0),
#  ('pa can also be produced by diacylglyercol kinase', 0.0),
#  ('pathophysiological role of dgkƞ in bd diacylglycerol kinase', 0.0),
#  ('phosphatidic acid which is catalyzed by diacylglycerol kinase', 0.0),
#  ('phosphatidylcholine 4 7 or a diacylglycerol dag kinase', 0.0),
#  ('phospholipase d pld1 and pld2 or diacylglycerol kinase', 0.0),
#  ('pkc are involved in this process dag kinase', 0.0),
#  ('pkc mediated regulatory pathway by activity diacylglycerol kinase', 0.0),
#  ('plant dag can be phosphorylated by dag kinase', 0.0),
#  ('pld the phosphorylated of dag by dag kinase', 0.0),
#  ('precise because both the production plc and inactivation', 0.0),
#  ('precursor of the endocannabinoid 2 ag diacylglycerol kinase', 0.0),
#  ('primary structural of porcine 80 kda diacylglycerol kinase', 0.0),
#  ('process of spermatogenesis and oocyte maturation diacylglycerol kinase',
#   0.0),
#  ('produced by phospholipase d pld and diacylglycerol kinase', 0.0),
#  ('protein kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('reaction that is catalyzed by diacylglycerol kinase s', 0.0),
#  ('regulated the activity of the enzyme diacylglycerol kinase', 0.0),
#  ('research topic illustrates the contribution of diacylglycerol kinase', 0.0),
#  ('signaling cascade dag is terminated by dag kinase', 0.0),
#  ('species introduction in agonist stimulated cell diacylglycerol kinase',
#   0.0),
#  ('specific function of pkc like pkc diacylglycerol kinase', 0.0),
#  ('study we characterized the role of diacylglycerol kinase', 0.0),
#  ('study we determined the role of diacylglycerol kinase', 0.0),
#  ('subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   0.0),
#  ('test this hypothesis we used the dag kinase', 0.0),
#  ('that is phosphorylated to pa via dag kinase', 0.0),
#  ('the acth camp pathway increase nuclear diacylglycerol kinase', 0.0),
#  ('the cell has been performed by diacylglycerol kinase', 0.0),
#  ('the cellular signaling transduction process diacyl glycerol kinase', 0.0),
#  ('the findings that the inhibited of diacylglycerol kinase', 0.0),
#  ('the generated dg is phosphorylated by dg kinase', 0.0),
#  ('the phosphorylated of diacylglycerol dag by diacylglycerol kinase', 0.0),
#  ('the testis in a different manner diacylglycerol kinase', 0.0),
#  ('they questioned the reliability of the diglyceride kinase', 0.0),
#  ('to this pathway of the enzyme diacylglycerol kinase', 0.0),
#  ('trisphosphate 1 2 in this system diacylglycerol kinase', 0.0),
#  ('two degs glyma17g08510 and glyma06g39760 for diacylglycerol kinase', 0.0),
#  ('used as a substrate for the cognate kinase', 0.0),
#  ('used the key anergy target gene diacylglycerol kinase', 0.0),
#  ('via phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('was inhibited by propranolol 6 diacylglyc erol kinase', 0.0),
#  ('we have investigated a role for diacylglycerol kinase', 0.0),
#  ('we have now found that a diacylglycerol kinase', 0.0),
#  ('we report the identification of a diacylglycerol kinase', 0.0),
#  ('which is phosphorylated to pa by diacylglycerol kinase', 0.0),
#  ('18 july 1996 abstract the cytosol ~ diacylglycerol kinase', 0.0),
#  ('1984 subsequently dg is immediately phosphorylated by diacylglycerol kinase',
#   0.0),
#  ('1990 j biol chem 265 8921 8928 diacylglycerol kinase', 0.0),
#  ('2 ag is also a substrate for diacylglycerol kinase', 0.0),
#  ('3 via phosphorylated of diacylglycerol dag by dag kinase', 0.0),
#  ('30 min first function proteomic annotated of diacylglycerol kinase', 0.0),
#  ('39 protein kinase c pkc diacylglycerol dag diacylglycerol kinase', 0.0),
#  ('5 and 40 6 diacyl pa a diacylglycerol kinase', 0.0),
#  ('5 trisphosphate 1 2 in this system diacylglycerol kinase', 0.0),
#  ('8 10 much evidence reveal that the diacylglycerol kinase', 0.0),
#  ('a misfolded variant of the membrane protein diacylglycerol kinase', 0.0),
#  ('a novel therapeutic approach in vascular dysfunction diacylglycerol kinase',
#   0.0),
#  ('a reaction that is catalyzed by diacylglycerol kinase s', 0.0),
#  ('acid a reaction that is mediated by diacylglycerol kinase', 0.0),
#  ('action of phospholipase c plc and diacylglycerol dag kinase', 0.0),
#  ('activity both of the two alternative pathway diacyglycerol kinase', 0.0),
#  ('acyl coenzyme a diacylglycerol acyltransferase dgat and diacylglycerol kinase',
#   0.0),
#  ('al 5 have consecutively showed that dgkh diacylglycerol kinase', 0.0),
#  ('an attempt to investigated differential function of diacylglycerol kinase',
#   0.0),
#  ('ancas we have investigated a role for diacylglycerol kinase', 0.0),
#  ('and other galphaq protein coupled receptor agonist diacylglycerol kinase',
#   0.0),
#  ('and pkc are involved in this process dag kinase', 0.0),
#  ('and the phosphorylated of diacylglycerol dag by diacylglycerol kinase',
#   0.0),
#  ('another lipid kinase in the phosphoinositide cycle diacylglycerol kinase',
#   0.0),
#  ...]

# %%
longforms0 = miners['DGK'].get_longforms()

# %%
longforms0
# Out:
# [('diacylglycerol kinase', 153, 0.9178480832694187),
#  ('dag kinase', 25, 0.8197686543937565),
#  ('dg kinase', 10, 0.7466214775824778),
#  ('diacyl glycerol kinase', 2, 0.47990724345877034),
#  ('diglyceride kinase', 2, 0.46536259029351856),
#  ('diacyglycerol kinase', 2, 0.4324463613461819),
#  ('diacylglycerol kinase s', 1, 0.7518306787959074),
#  ('dag metabolism enzyme', 1, 0.45667871256010617),
#  ('diacylglyercol kinase', 1, 0.2943166935057051),
#  ('diacylglyc erol kinase', 1, 0.2307857994733727)]

# %%
longforms0
# Out:
# [('diacylglycerol kinase', 153, 0.8901396723238695),
#  ('dag kinase', 25, 0.9492877035169986),
#  ('dg kinase', 10, 0.9655144982530459),
#  ('diacyl glycerol kinase', 2, 0.9292139700983575),
#  ('diglyceride kinase', 2, 0.9010520802840223),
#  ('diacyglycerol kinase', 2, 0.8373184730136229),
#  ('diacylglyercol kinase', 1, 0.8039259047601771),
#  ('diacylglycerol kinase s', 1, 0.7518306787959074),
#  ('diacylglyc erol kinase', 1, 0.6809150624102774),
#  ('dag metabolism enzyme', 1, 0.45667871256010617)]

# %%
longforms = longforms0[:-2]

# %%
longforms, scores = zip(*longforms)

# %%
longforms
# Out:
# ('raclopride',
#  'radial alveolar count',
#  'ractopamine',
#  'ribosome associated complex',
#  'regenerated amorphous cellulose',
#  'ractopamine hydrochloride',
#  'relative area change',
#  'renal artery calcium',
#  'right auditory cortex',
#  'rabbit articular chondrocytes',
#  'ractopamine hcl',
#  'renal artery calcification',
#  'regional anticoagulation with citrate',
#  'ras relative c3 botulinum toxin substrate')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
gilda_ground('raclopride')
# Out:
# ('MESH', 'D020891', 'Raclopride')

# %%
grounding_map
# Out:
# {'raclopride': 'MESH:D020891', 'ractopamine': 'CHEBI:CHEBI:82644'}

# %%
names
# Out:
# {'MESH:D020891': 'Raclopride', 'CHEBI:CHEBI:82644': 'ractopamine'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names, pos_labels=pos_labels)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'rabbit articular chondrocytes': 'ungrounded',
#   'raclopride': 'MESH:D020891',
#   'ractopamine': 'CHEBI:CHEBI:82644',
#   'ractopamine hcl': 'CHEBI:CHEBI:82644',
#   'ractopamine hydrochloride': 'CHEBI:CHEBI:82644',
#   'radial alveolar count': 'radial alveolar count',
#   'ras relative c3 botulinum toxin substrate': 'FPLX:RAC',
#   'regenerated amorphous cellulose': 'ungrounded',
#   'regional anticoagulation with citrate': 'ungrounded',
#   'relative area change': 'ungrounded',
#   'renal artery calcification': 'ungrounded',
#   'renal artery calcium': 'ungrounded',
#   'ribosome associated complex': 'ungrounded',
#   'right auditory cortex': 'ungrounded'},
#  {'MESH:D020891': 'Raclopride',
#   'CHEBI:CHEBI:82644': 'ractopamine',
#   'radial alveolar count': 'radial alveolar count',
#   'FPLX:RAC': 'RAC'},
#  ['CHEBI:CHEBI:82644', 'FPLX:RAC', 'MESH:D020891'])

# %%
grounding_map, names, pos_labels = ({'rabbit articular chondrocytes': 'ungrounded',
  'raclopride': 'MESH:D020891',
  'ractopamine': 'CHEBI:CHEBI:82644',
  'ractopamine hcl': 'CHEBI:CHEBI:82644',
  'ractopamine hydrochloride': 'CHEBI:CHEBI:82644',
  'radial alveolar count': 'radial alveolar count',
  'ras relative c3 botulinum toxin substrate': 'FPLX:RAC',
  'regenerated amorphous cellulose': 'ungrounded',
  'regional anticoagulation with citrate': 'ungrounded',
  'relative area change': 'ungrounded',
  'renal artery calcification': 'ungrounded',
  'renal artery calcium': 'ungrounded',
  'ribosome associated complex': 'ungrounded',
  'right auditory cortex': 'ungrounded'},
 {'MESH:D020891': 'Raclopride',
  'CHEBI:CHEBI:82644': 'ractopamine',
  'radial alveolar count': 'radial alveolar count',
  'FPLX:RAC': 'RAC'},
 ['CHEBI:CHEBI:82644', 'FPLX:RAC', 'MESH:D020891'])

# %%
names['HGNC:391'] = 'AKT1'
pos_labels.append('HGNC:391')

# %%
grounding_dict = {'RAC': grounding_map}

# %%
classifier = AdeftClassifier('RAC', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-24 10:40:37] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-24 10:41:43] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9491480221449358 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'radial alveolar count': 10,
#   'CHEBI:CHEBI:82644': 31,
#   'FPLX:RAC': 950,
#   'ungrounded': 32,
#   'MESH:D020891': 19,
#   'HGNC:391': 2636},
#  'f1': {'mean': 0.9491480221449358, 'std': 0.005321067717975318},
#  'precision': {'mean': 0.9472554921097684, 'std': 0.005037114274819043},
#  'recall': {'mean': 0.9518640618177944, 'std': 0.006001817426961046}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:391']

# %%
a[1]
# Out:
# 'The influence of inositol phosphates and phosphoinositides on the alpha isoform of the RAC-protein kinase B (RAC/PKB) was studied using purified wild type and mutant kinase preparations and a recombinant pleckstrin homology (PH) domain. Binding of inositol phosphates and phosphoinositides to the PH domain was measured as the quenching of intrinsic tryptophan fluorescence. Inositol phosphates and D3-phosphorylated phosphoinositides bound with affinities of 1-10 microM and 0.5 microM, respectively. Similar values were obtained using RAC/PKB expressed and purified from baculovirus-infected Sf9 cells in the fluorescence assay. The influence of synthetic dioctanoyl derivatives of phosphatidylinositol 3,4-bisphosphate and phosphatidylinositol 3,4,5-trisphosphate on the activity of RAC/PKB purified from transfected COS-1 cells was studied. Phosphatidylinositol 3,4,5-trisphosphate was found to inhibit the RAC/PKB kinase activity with half-maximal inhibition at 2.5 microM. In contrast, phosphatidylinositol 3, 4-bisphosphate stimulated kinase activity (half-maximal stimulation at 2.5 microM). A mutant RAC/PKB protein lacking the PH domain was not affected by D3-phosphorylated phosphoinositides. These results demonstrate that the PH domain of RAC/PKB binds inositol phosphates and phosphoinositides with high affinity, and suggest that the products of the phosphatidylinositide 3-kinase can act as both a membrane anchor and modulator of RAC/PKB activity. The data also provide further evidence for a link between phosphatidylinositide 3-kinase and RAC/PKB regulation.\n'

# %%
disamb.dump('RAC', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/EK/')

# %%
d.info()
# Out:
# 'Disambiguation model for EK\n\nProduces the disambiguations:\n\tCHK*\tFPLX:CHK\n\tEnkephalins*\tMESH:D004745\n\tTMPRSS15*\tHGNC:9490\n\nTraining data had class balance:\n\tCHK*\t58\n\tTMPRSS15*\t30\n\tUngrounded\t11\n\tEnkephalins*\t7\n\nClassification Metrics:\n\tF1 score:\t0.81333\n\tPrecision:\t0.83439\n\tRecall:\t\t0.84234\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
model_to_s3(d)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('domain', 0.08492635500235372),
#  ('region', 0.0841391109644385),
#  ('nox', 0.08167855496471926),
#  ('bfgf', 0.07852529781557573),
#  ('glioma', 0.0754901259891954),
#  ('syk', 0.07470961043787495),
#  ('gene transcription', 0.0026340110283227633),
#  ('immune response', 0.002630769075503361),
#  ('keratinocytes', 0.002612622375149208),
#  ('r2', 0.0025957701912281157),
#  ('million', 0.0025915510722136245),
#  ('depth', 0.002580671786522798),
#  ('mechanistically', 0.002537360278662078),
#  ('internalized', 0.002519838456831727),
#  ('negative', 0.0025156938069693427),
#  ('subject', 0.0025090285177655804),
#  ('constitutively active', 0.0024972706277744715),
#  ('apc', 0.002477451362742979),
#  ('slowly', 0.0024437550842130156),
#  ('induce', 0.002442456183943361),
#  ('disease progression', 0.0024271600494600912),
#  ('dimensional', 0.0024064034857451864),
#  ('gpcr', 0.0023995615350814723),
#  ('hiv infected', 0.0023947875173693646),
#  ('related proteins', 0.002370511591909401),
#  ('improve', 0.002349119410950688),
#  ('transactivation', 0.0023392322324918263),
#  ('proteome', 0.0023366813591017333),
#  ('embryo', 0.002323944560501788),
#  ('mir 23b', 0.0023213746379011145),
#  ('ups', 0.002310541351097159),
#  ('rna sirna', 0.00230952894736003),
#  ('actin stress', 0.002305643309104253),
#  ('www', 0.002305246868990212),
#  ('concordance', 0.002295478408414917),
#  ('phosphatidylinositol trisphosphate', 0.002284000970278403),
#  ('al 2000', 0.0022762253505495215),
#  ('coupled receptors', 0.0022760973985635705),
#  ('occurs', 0.002268762362325606),
#  ('mt growth', 0.002259818832226123),
#  ('comparisons', 0.002214916443753755),
#  ('mdck cells', 0.0022088971986984063),
#  ('report', 0.0022010896811818846),
#  ('ras related', 0.0021960055640703677),
#  ('healthy controls', 0.002185704688407782),
#  ('mapks', 0.0021852036409092035),
#  ('variations', 0.002184805337859339),
#  ('rt pcr', 0.0021687414258417894),
#  ('clusters', 0.002168711659795307),
#  ('migrating', 0.002145644573375307),
#  ('ketorolac', 0.0021394273083780915),
#  ('overexpressing cells', 0.0021194373828616157),
#  ('advances', 0.0021172079508826646),
#  ('platelet aggregation', 0.0020838154536074347),
#  ('pi3k activation', 0.002080551608819154),
#  ('global', 0.0020708170522329714),
#  ('characterization', 0.002069156363858708),
#  ('factor receptor', 0.002068259764256092),
#  ('protein protein', 0.0020681113400694623),
#  ('clones', 0.0020622850963533685),
#  ('quality', 0.002050398855044074),
#  ('actin filaments', 0.0020499675562639153),
#  ('doxycycline', 0.00204677192326688),
#  ('genotyped', 0.002044098345626217),
#  ('kda', 0.0020357585888912126),
#  ('leading activation', 0.002032362572755158),
#  ('mechanisms underlying', 0.002028824150714053),
#  ('node metastasis', 0.0020016937255670705),
#  ('p85α', 0.0019999398304480784),
#  ('general', 0.0019996719614774894),
#  ('adhesion migration', 0.0019673618877314512),
#  ('nucleotides', 0.0019341227749842796),
#  ('gal4', 0.001933046049572754),
#  ('bar', 0.0019320696931873103),
#  ('il 23', 0.0019236563045347994),
#  ('able', 0.0018651225526654816),
#  ('triggered', 0.0018513405639057601),
#  ('activate pi3k', 0.0018414276060765553),
#  ('invading', 0.0018220323254759256),
#  ('cd34 cells', 0.0018065851477302682),
#  ('cell motility', 0.0017730299184850723),
#  ('prc2', 0.0017670604659660535),
#  ('accumulate', 0.0017648876521940342),
#  ('gap activity', 0.0017619215596028977),
#  ('tg mice', 0.0017421293613266637),
#  ('computational', 0.001718341844745325),
#  ('acini', 0.0016837317043615556),
#  ('bias', 0.001679335276788265),
#  ('tract', 0.0016768391282356956),
#  ('10 nm', 0.0016686423025255063),
#  ('nih', 0.0016600026674318845),
#  ('primarily', 0.0016334901957943378),
#  ('free', 0.001633095368968019),
#  ('drosophila', 0.001632059878931662),
#  ('consistently', 0.0016074640092012614),
#  ('regulation cell', 0.001593194032487206),
#  ('122', 0.0015851794022037076),
#  ('org', 0.0015815793588850192),
#  ('speed', 0.0015538209831334015),
#  ('similar', 0.0015484272543345948),
#  ('polarized', 0.0015423757921221675),
#  ('sufficient', 0.0015364345138062885),
#  ('nef mediated', 0.0015343464675582612),
#  ('btz', 0.0015139523525440973),
#  ('poor', 0.0015114074362315075),
#  ('long', 0.0015003542046306503),
#  ('cos', 0.001498601792119749),
#  ('keratinocyte', 0.0014976736236310818),
#  ('depend', 0.0014773617977301068),
#  ('structurally', 0.0014491726186032525),
#  ('figures', 0.0014377814748537813),
#  ('terminal kinase', 0.0014361158507965417),
#  ('forced', 0.0014262514895394777),
#  ('stress fibers', 0.0014136424401912943),
#  ('gtp levels', 0.0014045893550220271),
#  ('http www', 0.001400662742870137),
#  ('constitute', 0.0013847501095176986),
#  ('correlates', 0.001369935214639086),
#  ('bacterial', 0.0013642322615670115),
#  ('lymph node', 0.0013335407699094147),
#  ('isolated', 0.001323811398459816),
#  ('extensive', 0.0013226730118904525),
#  ('required activation', 0.0013197737912688597),
#  ('58', 0.0013141559461475587),
#  ('nmr', 0.001306937842581011),
#  ('depleted', 0.0012903072537006044),
#  ('mammals', 0.0012702016022548464),
#  ('released', 0.0012652732264462352),
#  ('hcc cell', 0.0012594994919302661),
#  ('basement', 0.0012518869954071575),
#  ('101', 0.00123504916963941),
#  ('trans', 0.0012301377075536557),
#  ('pkcι', 0.0012264666011846362),
#  ('heterogeneous', 0.001222948155486682),
#  ('negative rac1', 0.0012105078877033412),
#  ('generate', 0.0012101502636323205),
#  ('lifetime', 0.0012071362921252094),
#  ('calmodulin', 0.0012066364853404571),
#  ('vesicle', 0.0011892819563656617),
#  ('nm', 0.001188215693767789),
#  ('cos cells', 0.0011740720697546365),
#  ('protein expression', 0.001170686518324222),
#  ('retroviruses', 0.0011687624569236418),
#  ('crl', 0.0011505650463955826),
#  ('ruffles', 0.0011480796192660672),
#  ('drive', 0.0011419143176276045),
#  ('cancer institute', 0.0011183052808775025),
#  ('67', 0.0010737540075197954),
#  ('gmr', 0.0010730314391936902),
#  ('caspase activation', 0.0010666893479688092),
#  ('genetic variation', 0.001056046926990383),
#  ('reveal', 0.0010552131145286768),
#  ('epha2', 0.0010510078687096037),
#  ('armus', 0.0010396359831100128),
#  ('gmr gal4', 0.0010376435255460572),
#  ('lit', 0.0010286327602783783),
#  ('generating', 0.001026011834877848),
#  ('enrichment', 0.0010042797351243191),
#  ('gtpase activating', 0.0009997082407178493),
#  ('generated', 0.000993851413177679),
#  ('national cancer', 0.000989916070391823),
#  ('distributed', 0.0009730749000416528),
#  ('ecm', 0.0009706890159439986),
#  ('estimated', 0.0009695631010071959),
#  ('previously demonstrated', 0.0009554759769811339),
#  ('irs 58', 0.000954797862102126),
#  ('ct', 0.0009469276356233916),
#  ('subsequently', 0.000944581365728863),
#  ('data shown', 0.0009438237408699296),
#  ('translocate', 0.0009278463464143314),
#  ('lysine', 0.0009263729645421186),
#  ('species', 0.0008982062345607147),
#  ('length', 0.0008805014816108636),
#  ('lysosome', 0.0008783885121699345),
#  ('cellular signaling', 0.0008749500098327759),
#  ('matrix ecm', 0.000864806411168055),
#  ('contribution', 0.0008579903992322249),
#  ('maintenance', 0.0008469696554932863),
#  ('fibroblasts', 0.0008461510935831209),
#  ('lysates', 0.0008441775342110156),
#  ('filaments', 0.0008422746066604947),
#  ...]

# %%
d = load_disambiguator('ALK', '../results')
# Out:
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
