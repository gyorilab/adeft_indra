# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['RK']
genes = ['GRK1', 'RBKS']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['GRK1', 'RBKS']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['RK'].top()

# %%
top
# Out:
# [('raspberry ketone', 26.85714285714286),
#  ('rhodopsin kinase', 23.923076923076923),
#  ('kinase', 13.37142857142857),
#  ('radial keratotomy', 7.777777777777778),
#  ('remnant kidney', 6.25),
#  ('by rhodopsin kinase', 4.857142857142858),
#  ('kernels', 4.2),
#  ('rye bread with kernels', 4.0),
#  ('arabinoxylan ax bread β glucan bg bread dark ground rye gr bread and rye bread with kernels',
#   4),
#  ('ribokinase', 3.5),
#  ('kidney', 3.2),
#  ('sence and presence of microtubule obstacles two concentrations of a tau or b rigor kinesin',
#   3),
#  ('reactivating kinase', 2.8),
#  ('lysine', 2.0),
#  ('rapid kindling', 2.0),
#  ('red kohlrabi', 2.0),
#  ('of raspberry ketone', 2.0),
#  ('phosphorylation by rhodopsin kinase', 2.0),
#  ('upon illumination rhodopsin kinase', 2),
#  ('yoni trapped per week when supplemented pre release as immatures 2 3 days with raspberry ketone',
#   2),
#  ('oxylan bread ax ○ β glucan bread bg + dark ground rye bread gr □ rye bread with kernels',
#   2),
#  ('rigor kinesin', 1.5),
#  ('rye kernels', 1.3333333333333333),
#  ('by raspberry ketone', 1.3333333333333333),
#  ('rats remnant kidney', 1.3333333333333333),
#  ('with raspberry ketone', 1.3333333333333333),
#  ('termed the reactivating kinase', 1.3333333333333333),
#  ('0 mm rhododendrol rd raspberry ketone', 1.3333333333333333),
#  ('domain', 1.0),
#  ('grk1', 1.0),
#  ('veillonellaceae', 1.0),
#  ('rabbit kidney', 1.0),
#  ('rocket kerosene', 1),
#  ('although raspberry ketone', 1.0),
#  ('e coli ribokinase', 1.0),
#  ('enzyme rhodopsin kinase', 1.0),
#  ('human rhodopsin kinase', 1.0),
#  ('intact rye kernels', 1.0),
#  ('of rhodopsin kinase', 1.0),
#  ('rhodiola kirilowii crassulaceae', 1),
#  ('to rhodopsin kinase', 1.0),
#  ('assess of replenishment kinetics', 1),
#  ('by inhibition rhodopsin kinase', 1.0),
#  ('rho by rhodopsin kinase', 1.0),
#  ('with previous radial keratotomy', 1.0),
#  ('effect of feeding raspberry ketone', 1.0),
#  ('homologue termed the reactivating kinase', 1.0),
#  ('melanogenesis inhibition by raspberry ketone', 1),
#  ('methylation of arginine and lysine', 1),
#  ('of the rats remnant kidney', 1.0),
#  ('the primary structure of bovine rhodopsin kinase', 1),
#  ('to investigate the mechanism of radix kansui', 1),
#  ('the comparative advantages of pre release raspberry ketone', 1.0),
#  ('the phosphorylation of bleached rhodopsin rho by rhodopsin kinase', 1),
#  ('on intracellular reactivating oxygen species ros induced by raspberry ketone',
#   1.0),
#  ('phosphate and fgf 23 levels in control remnant kidney rats', 1.0),
#  ('were treated with 5 0 mm rhododendrol rd raspberry ketone', 1.0),
#  ('dependent receptor phosphorylation and desensitization of the receptor mammalian rhodopsin kinase',
#   1),
#  ('survival of sterile male b tryoni when fed a raspberry ketone', 1.0),
#  ('phosphorylation of light activation rhodopsin by the retina specific enzyme rhodopsin kinase',
#   1),
#  ('re selected for more detailed analysis mitochondrial aldehyde dehydrogenase maldh and ribokinase',
#   1),
#  ('selected to assess phytochemical characteristics between the two kohlrabi cultivar red kohlrabi',
#   1),
#  ('this study aim to determination the anti obesity effect of raspberry ketone',
#   1),
#  ('to record visual and refractive data in eyes with previous radial keratotomy',
#   1),
#  ('acetate dihydrate edta on intracellular reactivating oxygen species ros induced by raspberry ketone',
#   1),
#  ('brown like characteristics is a promising approach for obesity treatment although raspberry ketone',
#   1),
#  ('ciation sequester the covalently attached myristoyl group and disrupt binding to rhodopsin kinase',
#   1),
#  ('cific cytotoxicities to melanocytes for instance raspberry ketone 4 4 hydroxyphenyl 2 butanone',
#   1),
#  ('commercial names are sundbrød hvede toast wf mørkt rugbrød gr and levebrød multikernerugbrød',
#   1),
#  ('constructive repair such as corneal trauma past laser ablation decentration and radial keratotomy',
#   1),
#  ('determination of intraocular lens iol power in cataract patients with previous radial keratotomy',
#   1),
#  ('management of postoperative hyperopia and astigmatism in patients with history of radial keratotomy',
#   1),
#  ('nly a few negatively associated bacteria including highly connected members of the veillonellaceae',
#   1),
#  ('owing isomerization a molecule undergoes a random number of phosphorylation by rhodopsin kinase',
#   1),
#  ('rom freshly dissected bovine retina as described previous 14 recoverin and rhodopsin kinase',
#   1),
#  ('transducin gt desensitization begins with phosphorylation of the c terminus by rhodopsin kinase',
#   1),
#  ('umination simulation of experimental conditions in which the expression levels of rhodospin kinase',
#   1),
#  ('upon the terminal of rho signaling the protein undergoes phosphorylation via rhodopsin kinase',
#   1),
#  ('001 indicate significant different from the lps stimulate control group effect of red kohlrabi',
#   1),
#  ('a class of pyridinyl imidazoles inhibition the map kinase homologue termed here reactivating kinase',
#   1),
#  ('a consequence of seizure exposure important animals that undergoes the kindling or rapid kindling',
#   1),
#  ('activation the visual pigment rhodopsin rho > rho phosphorylation of rho by rhodopsin kinase',
#   1),
#  ('cellular reactivating oxygen species ros levels in b16f10 melanoma cells treated with raspberry ketone',
#   1),
#  ('coverin prolongs the lifetime of light excited rhodopsin 33 35 by inhibition rhodopsin kinase',
#   1),
#  ('e of traumatic corneal rupture that occurred 6 years previous followed combined radial keratotomy',
#   1),
#  ('ese cellular stresses stimulate a distinct map ki nase homologue termed the reactivating kinase',
#   1),
#  ('gen cross linking in the management of keratoconic corneal ectasia exacerbated by radial keratotomy',
#   1),
#  ('hosphodiesterase interestingly lower levels of mrna expression of α a crystalline and rho kinase',
#   1),
#  ('instability regardless of their choice on the laser method of vision correction radial keratotomy',
#   1),
#  ('its participates in light adaptation via calcium dependent inhibition of the enzyme rhodopsin kinase',
#   1),
#  ('map kinase activation protein mapkap kinase 2 is activation in vivo by reactivating kinase',
#   1),
#  ('nt effect of tyrosinase on intracellular reactivating oxygen species ros induced by raspberry ketone',
#   1),
#  ('o olfactory signaling by revealing an as yet unknown excitatory signaling pathway raspberry ketone',
#   1),
#  ('orylation is an important post translational modification that is known to regulate receptor kinase',
#   1),
#  ('other nontransport processes to increased and altered metabolic activation of the rats remnant kidney',
#   1),
#  ('ptides corresponding to the c terminal sequence of rhodopsin are phosphorylation by rhodopsin kinase',
#   1),
#  ('ssion of wild b tryoni populations the comparative advantages of pre release raspberry ketone',
#   1),
#  ('3ld uk received 13 march 1995 abstract a map kinase homologue termed the reactivating kinase',
#   1),
#  ('acceptable component of winter salads dependent on the cultivar kohlrabi stems may be purple red',
#   1),
#  ('activation on ckd by used prolyl hydroxylase phd inhibitor l mimosine rats with remnant kidney',
#   1),
#  ('bohydrate wheat bread with concentrations arabinoxylan ax or β glucan bg rye bread with kernels',
#   1),
#  ('by rd or rk chemical structure of phenolic compounds a rhododendrol rd b raspberry ketone',
#   1),
#  ('e rats received right uninephrectomy they were then random assigned to either the remnant kidney',
#   1),
#  ('eral brain structure unlike the classic or slow kindling protocols sk the rapid kindling type',
#   1),
#  ('exerted through recoverin rec a protein which binding and regulate the action of rhodopsin kinase',
#   1),
#  ('guannylyl cyclase activation protein gcap to release its ca 2 + and separate from rhodopsinkinase',
#   1),
#  ('he scheme of a simple irreversible enzyme reaction for the r phosphorylation by rhodopsin kinase',
#   1),
#  ('ile flies required for release figure 3 the comparative advantages of pre release raspberry ketone',
#   1),
#  ('industry the sterile insect technique sit and cue lure a synthetic analogue of raspberry ketone',
#   1),
#  ('ing human red opsin redo 28 29 human rhodopsin rho 29 30 human rhodopsin kinase',
#   1),
#  ('ion fig 1a notably just prior to the highly conservative homeodomain resides an arginine lysine',
#   1),
#  ('ipl1 isoform 1 replaced gene control by a promoter derived from the human rhodopsin kinase',
#   1),
#  ('ive accumulation of body fat and is closely related to complex metabolic disease raspberry ketone',
#   1),
#  ('keratinocytes b16f10 and hacat cells were treated with 5 0 mm rhododendrol rd raspberry ketone',
#   1),
#  ('lying mechanism by which gtps affect renal function remains unclear both normal and remnant kidney',
#   1),
#  ('n kawamura 1993 erickson et al 1998 makino et al 2004 by inhibition rhodopsin kinase',
#   1),
#  ('nd other male attractants are known for b tryoni including cue lure melolure raspberry ketone',
#   1),
#  ('of d pentoses into nucleosides of 2 chloroadenine catalyzed by the recombinant e coli ribokinase',
#   1),
#  ('olecular structure of ncs target complex have been solved for recoverin bound to rhodopsin kinase',
#   1),
#  ('or recoverin previous attempts to study the ability of calmodulin to regulate grks including grk1',
#   1),
#  ('ound in the literature the state diagram of the ctmc described deactivation by rhodopsin kinase',
#   1),
#  ('rotein structure analysis and in vitro enzymatic activation of wild type af ugma with conservative',
#   1),
#  ('six subtypes of grk have been report so far group into three subfamilies rhodopsin kinase',
#   1),
#  ('the transglycosylation reaction and in the cascade one pot synthesis by used e coli ribokinase',
#   1),
#  ('tion of tryptophan residues in monoclonal immunoglobulin m igm by 2 hydroxy 5 nitrobenzyl bromide',
#   1),
#  ('afugma residues r182 and r327 were important for its function in vivo with even conservative amino',
#   1),
#  ('any cells reviewed in 1 recently a bomologue of p42 p44 mapk termed the reactivating kinase',
#   1),
#  ('ansgenes mutated in the proline rich gads binding region δ20 or the carboxyl terminal sh2 domain',
#   1),
#  ('ar to have highly potential for used in the cosmetics industry chemical structure of raspberry ketone',
#   1),
#  ('at are commonly used as biomarkers are mean kurtosis mk axial kurtosis ak and radial kurtosis',
#   1),
#  ('cascade one pot synthesis under the consecutive action of three e coli enzyme i e ribokinase',
#   1),
#  ('cular lens iol power recommendation in a cataract patients with history of 8 cut radial keratotomy',
#   1),
#  ('energy dispersive x ray spectrometry was used to quantify and localize iron in rats remnant kidney',
#   1),
#  ('enin et al 1997 weiergräber et al 2006 zernii et al 2011 while retina specific grk1',
#   1),
#  ('ensor branch of the ef hand superfamily serves as a calcium sensor that regulate rhodopsin kinase',
#   1),
#  ('genetic activation of pv cells in the hippocampus we show that seizure induced by rapid kindling',
#   1),
#  ('however the role of hmgb1 in ethanol induced gastric ulcer is not yet elucidated raspberry ketone',
#   1),
#  ('inocytes after b16f10 and hacat cells were treated with 1 0 mm rhododendrol rd raspberry ketone',
#   1),
#  ('lines for isolation and propagation of the virus the mammalian cells lines used were rabbit kidney',
#   1),
#  ('liorates renal injury in the rats remnant kidney model sprague dawley rats received 5 6 nephrectomy',
#   1),
#  ('lls and b hacat keratinocytes which were treated with 5 0 mm rhododendrol rd raspberry ketone',
#   1),
#  ('nhibitory post synaptic currents ipscs are decreased in dentate gc 4 6 week after rapid kindling',
#   1),
#  ('not significant n d not determination phosphate and fgf 23 levels in control remnant kidney rats',
#   1),
#  ('nt taxa for all bcs group figure 7 show the connected of these four taxa veillonellaceae',
#   1),
#  ('ros and hydrogen peroxide h 2 o 2 levels in b16f10 cells furthermore although raspberry ketone',
#   1),
#  ('side while the opposite side of recoverin interacts with the n terminal helix of rhodopsin kinase',
#   1),
#  ('tor i igf i production through activation of sensory neurons in mice and human raspberry ketone',
#   1),
#  ('by the same letter are not significant different p > 0 05 effect of feeding raspberry ketone',
#   1),
#  ('h with endosperm or whole grain rye bread with and without lactic acids boiled whole grain rye',
#   1),
#  ('he field solid circle in fig 2c the scatter plot in fig 4e indicate that residues kriging',
#   1),
#  ('nificantly different p > 0 05 survival of sterile male b tryoni when fed a raspberry ketone',
#   1),
#  ('re tested whether the latent positive phosphate balance at an early stage of the rats remnant kidney',
#   1),
#  ('study absolute ethanol 7 5 ml kg was used to induced gastric ulcer in rats raspberry ketone',
#   1),
#  ('to report a case of presumed epithelial inclusion cyst of the iris 7 years after radial keratotomy',
#   1),
#  ('aim of this study was to investigate the role of ala in the disease progression of remnant kidney',
#   1),
#  ('ent inhibition of mlcp activation untreated and thio phosphorylation wt dee > qqq dee and rk > qq',
#   1),
#  ('f wild type rhodopsin in transducin assays and only one tenth that of wild type in rhodopsin kinase',
#   1),
#  ('he treatment of dm as well as its complications effect of green kohlrabi gk a and red kohlrabi',
#   1),
#  ('levels of b16f10 melanoma cells after b16f10 cells were treated with 5 0 mm rd and raspberry ketone',
#   1),
#  ('s pr virus was obtained from dr r haff in a suspension of infected mouse brain rabbit kidney',
#   1),
#  ('0 min also correlated with lower ei r = 0 34 the wholegrain wheat kernels wk and rye kernels',
#   1),
#  ('ds the tmb consists of the hydrophobic tm domain followed by two basic amino acids in the b domain',
#   1),
#  ('etween the neck and coil 1 of the rod domain see section above table s1 summary of rigor kinesin',
#   1),
#  ('i sham operated n = 6 group ii sham operated + npc31169 n = 6 group iii remnant kidney',
#   1),
#  ('n of slp76 were deleted δ20 and a mutant in which arginine 448 of slp76 was replaced by lysine',
#   1),
#  ('at ax or concentrations oat bg a dark ground rye gr bread and a rye bread with intact rye kernels',
#   1),
#  ('ite wheat bread with wheat ax or oat bg two rye bread with ground rye gr or intact rye kernels',
#   1),
#  ('ol p < 0 05 fig 1b figure 1 survival of sterile male b tryoni when fed a raspberry ketone',
#   1),
#  ('p < 0 01 versus rk at 8 week figure 1 phosphate and fgf 23 levels in control remnant kidney rats',
#   1),
#  ('tracts to scavenge authentic onoo − was similar with respective ic 50 values of 116 79 ± 0 13 μg ml',
#   1),
#  ('nd control male f 1 10 = 2 71 p = 0 131 fig 2 figure 2 effect of feeding raspberry ketone',
#   1),
#  ('2 the two cooh terminal amino acids in the b domain of bcl 2 are his lys h k instead of arg lys',
#   1),
#  ('mg kg body weight b w rosi 3 75 mg kg b w 7 5 mg kg b w and 15 mg kg b w or rosi and krg',
#   1),
#  ('amino', 0.0),
#  ('bromide', 0.0),
#  ('butanone', 0.0),
#  ('conservative', 0.0),
#  ('crassulaceae', 0.0),
#  ('kansui', 0.0),
#  ('keratotomy', 0.0),
#  ('kerosene', 0.0),
#  ('ketone', 0.0),
#  ('kindling', 0.0),
#  ('kinesin', 0.0),
#  ('kinetics', 0.0),
#  ('kohlrabi', 0.0),
#  ('krg', 0.0),
#  ('kriging', 0.0),
#  ('kurtosis', 0.0),
#  ('lys', 0.0),
#  ('ml', 0.0),
#  ('multikernerugbrød', 0.0),
#  ('nephrectomy', 0.0),
#  ('qq', 0.0),
#  ('rats', 0.0),
#  ('red', 0.0),
#  ('rhodopsinkinase', 0.0),
#  ('rye', 0.0),
#  ('type', 0.0),
#  ('2 butanone', 0.0),
#  ('6 nephrectomy', 0.0),
#  ('> qq', 0.0),
#  ('and krg', 0.0),
#  ('and lysine', 0.0),
#  ('and ribokinase', 0.0),
#  ('arg lys', 0.0),
#  ('arginine lysine', 0.0),
#  ('b domain', 0.0),
#  ('by lysine', 0.0),
#  ('coli ribokinase', 0.0),
#  ('conservative amino', 0.0),
#  ('e ribokinase', 0.0),
#  ('from rhodopsinkinase', 0.0),
#  ('grain rye', 0.0),
#  ('including grk1', 0.0),
#  ('kidney rats', 0.0),
#  ('kindling type', 0.0),
#  ('kirilowii crassulaceae', 0.0),
#  ('levebrød multikernerugbrød', 0.0),
#  ('nitrobenzyl bromide', 0.0),
#  ('purple red', 0.0),
#  ('radial kurtosis', 0.0),
#  ('radix kansui', 0.0),
#  ('receptor kinase', 0.0),
#  ('replenishment kinetics', 0.0),
#  ('residues kriging', 0.0),
#  ('rho kinase', 0.0),
#  ('rhodospin kinase', 0.0),
#  ('sh2 domain', 0.0),
#  ('specific grk1', 0.0),
#  ('taxa veillonellaceae', 0.0),
#  ('the veillonellaceae', 0.0),
#  ('with conservative', 0.0),
#  ('with kernels', 0.0),
#  ('μg ml', 0.0),
#  ('13 μg ml', 0.0),
#  ('5 6 nephrectomy', 0.0),
#  ('5 nitrobenzyl bromide', 0.0),
#  ('a raspberry ketone', 0.0),
#  ('after radial keratotomy', 0.0),
#  ('after rapid kindling', 0.0),
#  ('an arginine lysine', 0.0),
#  ('and levebrød multikernerugbrød', 0.0),
#  ('and radial keratotomy', 0.0),
#  ('and radial kurtosis', 0.0),
#  ('and raspberry ketone', 0.0),
#  ('and red kohlrabi', 0.0),
#  ('and remnant kidney', 0.0),
#  ('and rho kinase', 0.0),
#  ('and rhodopsin kinase', 0.0),
#  ('and rye kernels', 0.0),
#  ('arginine and lysine', 0.0),
#  ('b raspberry ketone', 0.0),
#  ('b rigor kinesin', 0.0),
#  ('be purple red', 0.0),
#  ('bovine rhodopsin kinase', 0.0),
#  ('brain rabbit kidney', 0.0),
#  ('bread with kernels', 0.0),
#  ('by radial keratotomy', 0.0),
#  ('by rapid kindling', 0.0),
#  ('by reactivating kinase', 0.0),
#  ('combined radial keratotomy', 0.0),
#  ('correction radial keratotomy', 0.0),
#  ('cultivar red kohlrabi', 0.0),
#  ('cut radial keratotomy', 0.0),
#  ('disease raspberry ketone', 0.0),
#  ('elucidated raspberry ketone', 0.0),
#  ('even conservative amino', 0.0),
#  ('feeding raspberry ketone', 0.0),
#  ('four taxa veillonellaceae', 0.0),
#  ('grks including grk1', 0.0),
#  ('here reactivating kinase', 0.0),
#  ('human raspberry ketone', 0.0),
#  ('hydroxyphenyl 2 butanone', 0.0),
#  ('i e ribokinase', 0.0),
#  ('iii remnant kidney', 0.0),
#  ('illumination rhodopsin kinase', 0.0),
#  ('in rhodopsin kinase', 0.0),
#  ('inhibition rhodopsin kinase', 0.0),
#  ('maldh and ribokinase', 0.0),
#  ('mammalian rhodopsin kinase', 0.0),
#  ('melolure raspberry ketone', 0.0),
#  ('of arg lys', 0.0),
#  ('of radial keratotomy', 0.0),
#  ('of radix kansui', 0.0),
#  ('of red kohlrabi', 0.0),
#  ('of remnant kidney', 0.0),
#  ('of replenishment kinetics', 0.0),
#  ('of rhodospin kinase', 0.0),
#  ('of rigor kinesin', 0.0),
#  ('of the veillonellaceae', 0.0),
#  ('or rapid kindling', 0.0),
#  ('pathway raspberry ketone', 0.0),
#  ('previous radial keratotomy', 0.0),
#  ('rapid kindling type', 0.0),
#  ('rats raspberry ketone', 0.0),
#  ('rd raspberry ketone', 0.0),
#  ('regulate receptor kinase', 0.0),
#  ('regulate rhodopsin kinase', 0.0),
#  ('release raspberry ketone', 0.0),
#  ('remnant kidney rats', 0.0),
#  ('replaced by lysine', 0.0),
#  ('retina specific grk1', 0.0),
#  ('rk > qq', 0.0),
#  ('rosi and krg', 0.0),
#  ('separate from rhodopsinkinase', 0.0),
#  ('subfamilies rhodopsin kinase', 0.0),
#  ('terminal sh2 domain', 0.0),
#  ('that residues kriging', 0.0),
#  ('the b domain', 0.0),
#  ('the reactivating kinase', 0.0),
#  ('the remnant kidney', 0.0),
#  ('ugma with conservative', 0.0),
#  ('via rhodopsin kinase', 0.0),
#  ('were rabbit kidney', 0.0),
#  ('whole grain rye', 0.0),
#  ('with remnant kidney', 0.0),
#  ('0 13 μg ml', 0.0),
#  ('30 human rhodopsin kinase', 0.0),
#  ('4 hydroxyphenyl 2 butanone', 0.0),
#  ('8 cut radial keratotomy', 0.0),
#  ('a and red kohlrabi', 0.0),
#  ('action of rhodopsin kinase', 0.0),
#  ('af ugma with conservative', 0.0),
#  ('ak and radial kurtosis', 0.0),
#  ('analogue of raspberry ketone', 0.0),
#  ('and human raspberry ketone', 0.0),
#  ('and rk > qq', 0.0),
#  ('and separate from rhodopsinkinase', 0.0),
#  ('binding to rhodopsin kinase', 0.0),
#  ('boiled whole grain rye', 0.0),
#  ('bound to rhodopsin kinase', 0.0),
#  ('carboxyl terminal sh2 domain', 0.0),
#  ('control remnant kidney rats', 0.0),
#  ('crystalline and rho kinase', 0.0),
#  ('days with raspberry ketone', 0.0),
#  ('deactivation by rhodopsin kinase', 0.0),
#  ('decentration and radial keratotomy', 0.0),
#  ('dehydrogenase maldh and ribokinase', 0.0),
#  ('effect of raspberry ketone', 0.0),
#  ('effect of red kohlrabi', 0.0),
#  ('either the remnant kidney', 0.0),
#  ('enzyme i e ribokinase', 0.0),
#  ('exacerbated by radial keratotomy', 0.0),
#  ('fed a raspberry ketone', 0.0),
#  ('followed combined radial keratotomy', 0.0),
#  ('furthermore although raspberry ketone', 0.0),
#  ('gr and levebrød multikernerugbrød', 0.0),
#  ('group iii remnant kidney', 0.0),
#  ('helix of rhodopsin kinase', 0.0),
#  ('history of radial keratotomy', 0.0),
#  ('hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('in rats raspberry ketone', 0.0),
#  ('in rats remnant kidney', 0.0),
#  ('in the b domain', 0.0),
#  ('indicate that residues kriging', 0.0),
#  ('induced by rapid kindling', 0.0),
#  ('induced by raspberry ketone', 0.0),
#  ('inhibition by raspberry ketone', 0.0),
#  ('instead of arg lys', 0.0),
#  ('kindling or rapid kindling', 0.0),
#  ('kohlrabi cultivar red kohlrabi', 0.0),
#  ('levels of rhodospin kinase', 0.0),
#  ('lure melolure raspberry ketone', 0.0),
#  ('may be purple red', 0.0),
#  ('mechanism of radix kansui', 0.0),
#  ('members of the veillonellaceae', 0.0),
#  ('metabolic disease raspberry ketone', 0.0),
#  ('mouse brain rabbit kidney', 0.0),
#  ('normal and remnant kidney', 0.0),
#  ('of arginine and lysine', 0.0),
#  ('of bovine rhodopsin kinase', 0.0),
#  ('of feeding raspberry ketone', 0.0),
#  ('or b rigor kinesin', 0.0),
#  ('or intact rye kernels', 0.0),
#  ('or rosi and krg', 0.0),
#  ('phosphorylation via rhodopsin kinase', 0.0),
#  ('pre release raspberry ketone', 0.0),
#  ('progression of remnant kidney', 0.0),
#  ('rats with remnant kidney', 0.0),
#  ('rd and raspberry ketone', 0.0),
#  ('rd b raspberry ketone', 0.0),
#  ('received 5 6 nephrectomy', 0.0),
#  ('receptor mammalian rhodopsin kinase', 0.0),
#  ('recombinant e coli ribokinase', 0.0),
#  ('recoverin and rhodopsin kinase', 0.0),
#  ('regulate grks including grk1', 0.0),
#  ('resides an arginine lysine', 0.0),
#  ('rhododendrol rd raspberry ketone', 0.0),
#  ('signaling pathway raspberry ketone', 0.0),
#  ('specific enzyme rhodopsin kinase', 0.0),
#  ('structure of raspberry ketone', 0.0),
#  ('summary of rigor kinesin', 0.0),
#  ('termed here reactivating kinase', 0.0),
#  ('terminus by rhodopsin kinase', 0.0),
#  ('that regulate rhodopsin kinase', 0.0),
#  ('the enzyme rhodopsin kinase', 0.0),
#  ('the human rhodopsin kinase', 0.0),
#  ('the rapid kindling type', 0.0),
#  ('the rats remnant kidney', 0.0),
#  ('these four taxa veillonellaceae', 0.0),
#  ('three subfamilies rhodopsin kinase', 0.0),
#  ('to regulate receptor kinase', 0.0),
#  ('treated with raspberry ketone', 0.0),
#  ('treatment although raspberry ketone', 0.0),
#  ('type in rhodopsin kinase', 0.0),
#  ('used e coli ribokinase', 0.0),
#  ('used were rabbit kidney', 0.0),
#  ('vision correction radial keratotomy', 0.0),
#  ('vivo by reactivating kinase', 0.0),
#  ('was replaced by lysine', 0.0),
#  ('week after rapid kindling', 0.0),
#  ('while retina specific grk1', 0.0),
#  ('with even conservative amino', 0.0),
#  ('with intact rye kernels', 0.0),
#  ('wk and rye kernels', 0.0),
#  ('years after radial keratotomy', 0.0),
#  ('yet elucidated raspberry ketone', 0.0),
#  ('+ and separate from rhodopsinkinase', 0.0),
#  ('14 recoverin and rhodopsin kinase', 0.0),
#  ('2 hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('2004 by inhibition rhodopsin kinase', 0.0),
#  ('2011 while retina specific grk1', 0.0),
#  ('29 30 human rhodopsin kinase', 0.0),
#  ('3 days with raspberry ketone', 0.0),
#  ('35 by inhibition rhodopsin kinase', 0.0),
#  ('4 4 hydroxyphenyl 2 butanone', 0.0),
#  ('4e indicate that residues kriging', 0.0),
#  ('6 group iii remnant kidney', 0.0),
#  ('6 week after rapid kindling', 0.0),
#  ('7 years after radial keratotomy', 0.0),
#  ('a crystalline and rho kinase', 0.0),
#  ('ablation decentration and radial keratotomy', 0.0),
#  ('acids boiled whole grain rye', 0.0),
#  ('acids in the b domain', 0.0),
#  ('aldehyde dehydrogenase maldh and ribokinase', 0.0),
#  ('and rye bread with kernels', 0.0),
#  ('are phosphorylation by rhodopsin kinase', 0.0),
#  ('bg rye bread with kernels', 0.0),
#  ('both normal and remnant kidney', 0.0),
#  ('bread with intact rye kernels', 0.0),
#  ('by used e coli ribokinase', 0.0),
#  ('c terminus by rhodopsin kinase', 0.0),
#  ('cells furthermore although raspberry ketone', 0.0),
#  ('cells treated with raspberry ketone', 0.0),
#  ('chemical structure of raspberry ketone', 0.0),
#  ('coli enzyme i e ribokinase', 0.0),
#  ('complex metabolic disease raspberry ketone', 0.0),
#  ('connected members of the veillonellaceae', 0.0),
#  ('cue lure melolure raspberry ketone', 0.0),
#  ('dee and rk > qq', 0.0),
#  ('described deactivation by rhodopsin kinase', 0.0),
#  ('disease progression of remnant kidney', 0.0),
#  ('disrupt binding to rhodopsin kinase', 0.0),
#  ('ectasia exacerbated by radial keratotomy', 0.0),
#  ('excitatory signaling pathway raspberry ketone', 0.0),
#  ('expression levels of rhodospin kinase', 0.0),
#  ('eyes with previous radial keratotomy', 0.0),
#  ('from the human rhodopsin kinase', 0.0),
#  ('gk a and red kohlrabi', 0.0),
#  ('gr or intact rye kernels', 0.0),
#  ('group effect of red kohlrabi', 0.0),
#  ('homeodomain resides an arginine lysine', 0.0),
#  ('homologue termed here reactivating kinase', 0.0),
#  ('in control remnant kidney rats', 0.0),
#  ('in vivo by reactivating kinase', 0.0),
#  ('infected mouse brain rabbit kidney', 0.0),
#  ('into three subfamilies rhodopsin kinase', 0.0),
#  ('iron in rats remnant kidney', 0.0),
#  ('k instead of arg lys', 0.0),
#  ('kernels wk and rye kernels', 0.0),
#  ('known to regulate receptor kinase', 0.0),
#  ('kurtosis ak and radial kurtosis', 0.0),
#  ('lines used were rabbit kidney', 0.0),
#  ('mapk termed the reactivating kinase', 0.0),
#  ('mice and human raspberry ketone', 0.0),
#  ('mimosine rats with remnant kidney', 0.0),
#  ('mm rd and raspberry ketone', 0.0),
#  ('mm rhododendrol rd raspberry ketone', 0.0),
#  ('not yet elucidated raspberry ketone', 0.0),
#  ('obesity effect of raspberry ketone', 0.0),
#  ('obesity treatment although raspberry ketone', 0.0),
#  ('of 8 cut radial keratotomy', 0.0),
#  ('of phosphorylation by rhodopsin kinase', 0.0),
#  ('of pre release raspberry ketone', 0.0),
#  ('of rho by rhodopsin kinase', 0.0),
#  ('of the enzyme rhodopsin kinase', 0.0),
#  ('of these four taxa veillonellaceae', 0.0),
#  ('of vision correction radial keratotomy', 0.0),
#  ('patients with previous radial keratotomy', 0.0),
#  ('previous followed combined radial keratotomy', 0.0),
#  ('r phosphorylation by rhodopsin kinase', 0.0),
#  ('rats received 5 6 nephrectomy', 0.0),
#  ('recoverin bound to rhodopsin kinase', 0.0),
#  ('retina specific enzyme rhodopsin kinase', 0.0),
#  ('rhododendrol rd b raspberry ketone', 0.0),
#  ('rhodopsin rho by rhodopsin kinase', 0.0),
#  ('ros induced by raspberry ketone', 0.0),
#  ('rugbrød gr and levebrød multikernerugbrød', 0.0),
#  ('s1 summary of rigor kinesin', 0.0),
#  ('seizure induced by rapid kindling', 0.0),
#  ('sensor that regulate rhodopsin kinase', 0.0),
#  ('sk the rapid kindling type', 0.0),
#  ('slp76 was replaced by lysine', 0.0),
#  ('stems may be purple red', 0.0),
#  ('structure of bovine rhodopsin kinase', 0.0),
#  ('synthetic analogue of raspberry ketone', 0.0),
#  ('tau or b rigor kinesin', 0.0),
#  ('terminal helix of rhodopsin kinase', 0.0),
#  ('the action of rhodopsin kinase', 0.0),
#  ('the carboxyl terminal sh2 domain', 0.0),
#  ('the kindling or rapid kindling', 0.0),
#  ('the mechanism of radix kansui', 0.0),
#  ('the receptor mammalian rhodopsin kinase', 0.0),
#  ('the recombinant e coli ribokinase', 0.0),
#  ('to either the remnant kidney', 0.0),
#  ('to regulate grks including grk1', 0.0),
#  ('two kohlrabi cultivar red kohlrabi', 0.0),
#  ('type af ugma with conservative', 0.0),
#  ('ulcer in rats raspberry ketone', 0.0),
#  ('undergoes phosphorylation via rhodopsin kinase', 0.0),
#  ('vivo with even conservative amino', 0.0),
#  ('w or rosi and krg', 0.0),
#  ('when fed a raspberry ketone', 0.0),
#  ('wild type in rhodopsin kinase', 0.0),
#  ('with history of radial keratotomy', 0.0),
#  ('± 0 13 μg ml', 0.0),
#  ('□ rye bread with kernels', 0.0),
#  ('0 mm rd and raspberry ketone', 0.0),
#  ('05 effect of feeding raspberry ketone', 0.0),
#  ('2 + and separate from rhodopsinkinase', 0.0),
#  ('2 3 days with raspberry ketone', 0.0),
#  ('2 effect of feeding raspberry ketone', 0.0),
#  ('33 35 by inhibition rhodopsin kinase', 0.0),
#  ('4 6 week after rapid kindling', 0.0),
#  ('79 ± 0 13 μg ml', 0.0),
#  ('= 6 group iii remnant kidney', 0.0),
#  ('a rhododendrol rd b raspberry ketone', 0.0),
#  ('a synthetic analogue of raspberry ketone', 0.0),
#  ('a tau or b rigor kinesin', 0.0),
#  ('activation in vivo by reactivating kinase', 0.0),
#  ('activation of the rats remnant kidney', 0.0),
#  ('advantages of pre release raspberry ketone', 0.0),
#  ('al 2004 by inhibition rhodopsin kinase', 0.0),
#  ('al 2011 while retina specific grk1', 0.0),
#  ('amino acids in the b domain', 0.0),
#  ('and disrupt binding to rhodopsin kinase', 0.0),
#  ('anti obesity effect of raspberry ketone', 0.0),
#  ('assigned to either the remnant kidney', 0.0),
#  ('axial kurtosis ak and radial kurtosis', 0.0),
#  ('b w or rosi and krg', 0.0),
#  ('b16f10 cells furthermore although raspberry ketone', 0.0),
#  ('bleached rhodopsin rho by rhodopsin kinase', 0.0),
#  ('bread and rye bread with kernels', 0.0),
#  ('by 2 hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('by the recombinant e coli ribokinase', 0.0),
#  ('calcium sensor that regulate rhodopsin kinase', 0.0),
#  ('calmodulin to regulate grks including grk1', 0.0),
#  ('cataract patients with previous radial keratotomy', 0.0),
#  ('cells lines used were rabbit kidney', 0.0),
#  ('connected of these four taxa veillonellaceae', 0.0),
#  ('conservative homeodomain resides an arginine lysine', 0.0),
#  ('control group effect of red kohlrabi', 0.0),
#  ('corneal ectasia exacerbated by radial keratotomy', 0.0),
#  ('ctmc described deactivation by rhodopsin kinase', 0.0),
#  ('dawley rats received 5 6 nephrectomy', 0.0),
#  ('derived from the human rhodopsin kinase', 0.0),
#  ('e coli enzyme i e ribokinase', 0.0),
#  ('fig 4e indicate that residues kriging', 0.0),
#  ('for obesity treatment although raspberry ketone', 0.0),
#  ('for recoverin bound to rhodopsin kinase', 0.0),
#  ('gastric ulcer in rats raspberry ketone', 0.0),
#  ('glucan bg rye bread with kernels', 0.0),
#  ('gr □ rye bread with kernels', 0.0),
#  ('group into three subfamilies rhodopsin kinase', 0.0),
#  ('h k instead of arg lys', 0.0),
#  ('highly connected members of the veillonellaceae', 0.0),
#  ('history of 8 cut radial keratotomy', 0.0),
#  ('in eyes with previous radial keratotomy', 0.0),
#  ('in mice and human raspberry ketone', 0.0),
#  ('in vivo with even conservative amino', 0.0),
#  ('including cue lure melolure raspberry ketone', 0.0),
#  ('industry chemical structure of raspberry ketone', 0.0),
#  ('inhibition of the enzyme rhodopsin kinase', 0.0),
#  ('investigate the mechanism of radix kansui', 0.0),
#  ('iris 7 years after radial keratotomy', 0.0),
#  ('is known to regulate receptor kinase', 0.0),
#  ('is not yet elucidated raspberry ketone', 0.0),
#  ('ketone 4 4 hydroxyphenyl 2 butanone', 0.0),
#  ('kinase homologue termed here reactivating kinase', 0.0),
#  ('kinase homologue termed the reactivating kinase', 0.0),
#  ('kohlrabi gk a and red kohlrabi', 0.0),
#  ('kohlrabi stems may be purple red', 0.0),
#  ('l mimosine rats with remnant kidney', 0.0),
#  ('lactic acids boiled whole grain rye', 0.0),
#  ('laser ablation decentration and radial keratotomy', 0.0),
#  ('levels in control remnant kidney rats', 0.0),
#  ('localize iron in rats remnant kidney', 0.0),
#  ('melanoma cells treated with raspberry ketone', 0.0),
#  ('method of vision correction radial keratotomy', 0.0),
#  ('mitochondrial aldehyde dehydrogenase maldh and ribokinase', 0.0),
#  ('mørkt rugbrød gr and levebrød multikernerugbrød', 0.0),
#  ('n terminal helix of rhodopsin kinase', 0.0),
#  ('nase homologue termed the reactivating kinase', 0.0),
#  ('number of phosphorylation by rhodopsin kinase', 0.0),
#  ('of infected mouse brain rabbit kidney', 0.0),
#  ('of slp76 was replaced by lysine', 0.0),
#  ('of the receptor mammalian rhodopsin kinase', 0.0),
#  ('of wild type in rhodopsin kinase', 0.0),
#  ('or the carboxyl terminal sh2 domain', 0.0),
#  ('p44 mapk termed the reactivating kinase', 0.0),
#  ('patients with history of radial keratotomy', 0.0),
#  ('phosphorylation of rho by rhodopsin kinase', 0.0),
#  ('previous 14 recoverin and rhodopsin kinase', 0.0),
#  ('primary structure of bovine rhodopsin kinase', 0.0),
#  ('protein undergoes phosphorylation via rhodopsin kinase', 0.0),
#  ('protocols sk the rapid kindling type', 0.0),
#  ('qqq dee and rk > qq', 0.0),
#  ('regulate the action of rhodopsin kinase', 0.0),
#  ('rho 29 30 human rhodopsin kinase', 0.0),
#  ('rhodopsin are phosphorylation by rhodopsin kinase', 0.0),
#  ('rye bread with intact rye kernels', 0.0),
#  ('rye gr or intact rye kernels', 0.0),
#  ('species ros induced by raspberry ketone', 0.0),
#  ('stage of the rats remnant kidney', 0.0),
#  ('synthesis by used e coli ribokinase', 0.0),
#  ('table s1 summary of rigor kinesin', 0.0),
#  ('that seizure induced by rapid kindling', 0.0),
#  ('the c terminus by rhodopsin kinase', 0.0),
#  ('the disease progression of remnant kidney', 0.0),
#  ('the expression levels of rhodospin kinase', 0.0),
#  ('the r phosphorylation by rhodopsin kinase', 0.0),
#  ('the retina specific enzyme rhodopsin kinase', 0.0),
#  ('the two kohlrabi cultivar red kohlrabi', 0.0),
#  ('to complex metabolic disease raspberry ketone', 0.0),
#  ('tryoni when fed a raspberry ketone', 0.0),
#  ('unclear both normal and remnant kidney', 0.0),
#  ('undergoes the kindling or rapid kindling', 0.0),
#  ('unknown excitatory signaling pathway raspberry ketone', 0.0),
#  ('wheat kernels wk and rye kernels', 0.0),
#  ('wild type af ugma with conservative', 0.0),
#  ('years previous followed combined radial keratotomy', 0.0),
#  ('α a crystalline and rho kinase', 0.0),
#  ('0 05 effect of feeding raspberry ketone', 0.0),
#  ('1 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('116 79 ± 0 13 μg ml', 0.0),
#  ('23 levels in control remnant kidney rats', 0.0),
#  ('448 of slp76 was replaced by lysine', 0.0),
#  ('5 0 mm rd and raspberry ketone', 0.0),
#  ('5 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('6 years previous followed combined radial keratotomy', 0.0),
#  ('> qqq dee and rk > qq', 0.0),
#  ('a calcium sensor that regulate rhodopsin kinase', 0.0),
#  ('a rye bread with intact rye kernels', 0.0),
#  ('above table s1 summary of rigor kinesin', 0.0),
#  ('analysis mitochondrial aldehyde dehydrogenase maldh and ribokinase', 0.0),
#  ('and localize iron in rats remnant kidney', 0.0),
#  ('and regulate the action of rhodopsin kinase', 0.0),
#  ('approach for obesity treatment although raspberry ketone', 0.0),
#  ('b tryoni when fed a raspberry ketone', 0.0),
#  ('b16f10 melanoma cells treated with raspberry ketone', 0.0),
#  ('basic amino acids in the b domain', 0.0),
#  ('between the two kohlrabi cultivar red kohlrabi', 0.0),
#  ('bread gr □ rye bread with kernels', 0.0),
#  ('by the retina specific enzyme rhodopsin kinase', 0.0),
#  ('ca 2 + and separate from rhodopsinkinase', 0.0),
#  ('catalyzed by the recombinant e coli ribokinase', 0.0),
#  ('comparative advantages of pre release raspberry ketone', 0.0),
#  ('compounds a rhododendrol rd b raspberry ketone', 0.0),
#  ('cosmetics industry chemical structure of raspberry ketone', 0.0),
#  ('cultivar kohlrabi stems may be purple red', 0.0),
#  ('data in eyes with previous radial keratotomy', 0.0),
#  ('dependent inhibition of the enzyme rhodopsin kinase', 0.0),
#  ('described previous 14 recoverin and rhodopsin kinase', 0.0),
#  ('desensitization of the receptor mammalian rhodopsin kinase', 0.0),
#  ('early stage of the rats remnant kidney', 0.0),
#  ('et al 2004 by inhibition rhodopsin kinase', 0.0),
#  ('et al 2011 while retina specific grk1', 0.0),
#  ('far group into three subfamilies rhodopsin kinase', 0.0),
#  ('figure 2 effect of feeding raspberry ketone', 0.0),
#  ('for the r phosphorylation by rhodopsin kinase', 0.0),
#  ('function in vivo with even conservative amino', 0.0),
#  ('gc 4 6 week after rapid kindling', 0.0),
#  ('gr bread and rye bread with kernels', 0.0),
#  ('green kohlrabi gk a and red kohlrabi', 0.0),
#  ('ground rye gr or intact rye kernels', 0.0),
#  ('group and disrupt binding to rhodopsin kinase', 0.0),
#  ('highly conservative homeodomain resides an arginine lysine', 0.0),
#  ('igm by 2 hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('immatures 2 3 days with raspberry ketone', 0.0),
#  ('in b16f10 cells furthermore although raspberry ketone', 0.0),
#  ('in cataract patients with previous radial keratotomy', 0.0),
#  ('in fig 4e indicate that residues kriging', 0.0),
#  ('in patients with history of radial keratotomy', 0.0),
#  ('in the disease progression of remnant kidney', 0.0),
#  ('including highly connected members of the veillonellaceae', 0.0),
#  ('induced gastric ulcer in rats raspberry ketone', 0.0),
#  ('inhibitor l mimosine rats with remnant kidney', 0.0),
#  ('is activation in vivo by reactivating kinase', 0.0),
#  ('keratoconic corneal ectasia exacerbated by radial keratotomy', 0.0),
#  ('kg b w or rosi and krg', 0.0),
#  ('ki nase homologue termed the reactivating kinase', 0.0),
#  ('kindling protocols sk the rapid kindling type', 0.0),
#  ('laser method of vision correction radial keratotomy', 0.0),
#  ('lure a synthetic analogue of raspberry ketone', 0.0),
#  ('lys h k instead of arg lys', 0.0),
#  ('mammalian cells lines used were rabbit kidney', 0.0),
#  ('map kinase homologue termed here reactivating kinase', 0.0),
#  ('map kinase homologue termed the reactivating kinase', 0.0),
#  ('metabolic activation of the rats remnant kidney', 0.0),
#  ('mk axial kurtosis ak and radial kurtosis', 0.0),
#  ('n = 6 group iii remnant kidney', 0.0),
#  ('neurons in mice and human raspberry ketone', 0.0),
#  ('of a tau or b rigor kinesin', 0.0),
#  ('of bleached rhodopsin rho by rhodopsin kinase', 0.0),
#  ('of calmodulin to regulate grks including grk1', 0.0),
#  ('of rhodopsin are phosphorylation by rhodopsin kinase', 0.0),
#  ('of the c terminus by rhodopsin kinase', 0.0),
#  ('of wild type af ugma with conservative', 0.0),
#  ('of α a crystalline and rho kinase', 0.0),
#  ('oxygen species ros induced by raspberry ketone', 0.0),
#  ('p42 p44 mapk termed the reactivating kinase', 0.0),
#  ('past laser ablation decentration and radial keratotomy', 0.0),
#  ('pot synthesis by used e coli ribokinase', 0.0),
#  ('promoter derived from the human rhodopsin kinase', 0.0),
#  ('random assigned to either the remnant kidney', 0.0),
#  ('random number of phosphorylation by rhodopsin kinase', 0.0),
#  ('raspberry ketone 4 4 hydroxyphenyl 2 butanone', 0.0),
#  ('related to complex metabolic disease raspberry ketone', 0.0),
#  ('remains unclear both normal and remnant kidney', 0.0),
#  ('rho phosphorylation of rho by rhodopsin kinase', 0.0),
#  ('rhodopsin 33 35 by inhibition rhodopsin kinase', 0.0),
#  ('rhodopsin rho 29 30 human rhodopsin kinase', 0.0),
#  ('show that seizure induced by rapid kindling', 0.0),
#  ('solved for recoverin bound to rhodopsin kinase', 0.0),
#  ('sprague dawley rats received 5 6 nephrectomy', 0.0),
#  ('stimulate control group effect of red kohlrabi', 0.0),
#  ('suspension of infected mouse brain rabbit kidney', 0.0),
#  ('that is known to regulate receptor kinase', 0.0),
#  ('that of wild type in rhodopsin kinase', 0.0),
#  ('that undergoes the kindling or rapid kindling', 0.0),
#  ('the anti obesity effect of raspberry ketone', 0.0),
#  ('the connected of these four taxa veillonellaceae', 0.0),
#  ('the ctmc described deactivation by rhodopsin kinase', 0.0),
#  ('the iris 7 years after radial keratotomy', 0.0),
#  ('the n terminal helix of rhodopsin kinase', 0.0),
#  ('the protein undergoes phosphorylation via rhodopsin kinase', 0.0),
#  ('three e coli enzyme i e ribokinase', 0.0),
#  ('tryoni including cue lure melolure raspberry ketone', 0.0),
#  ('ulcer is not yet elucidated raspberry ketone', 0.0),
#  ('wf mørkt rugbrød gr and levebrød multikernerugbrød', 0.0),
#  ('which the expression levels of rhodospin kinase', 0.0),
#  ('wholegrain wheat kernels wk and rye kernels', 0.0),
#  ('with history of 8 cut radial keratotomy', 0.0),
#  ('without lactic acids boiled whole grain rye', 0.0),
#  ('yet unknown excitatory signaling pathway raspberry ketone', 0.0),
#  ('β glucan bg rye bread with kernels', 0.0),
#  ('δ20 or the carboxyl terminal sh2 domain', 0.0),
#  ('2 figure 2 effect of feeding raspberry ketone', 0.0),
#  ('2 is activation in vivo by reactivating kinase', 0.0),
#  ('> 0 05 effect of feeding raspberry ketone', 0.0),
#  ('> rho phosphorylation of rho by rhodopsin kinase', 0.0),
#  ('a map kinase homologue termed the reactivating kinase', 0.0),
#  ('a promoter derived from the human rhodopsin kinase', 0.0),
#  ('a random number of phosphorylation by rhodopsin kinase', 0.0),
#  ('a suspension of infected mouse brain rabbit kidney', 0.0),
#  ('ability of calmodulin to regulate grks including grk1', 0.0),
#  ('activation of wild type af ugma with conservative', 0.0),
#  ('ala in the disease progression of remnant kidney', 0.0),
#  ('altered metabolic activation of the rats remnant kidney', 0.0),
#  ('an early stage of the rats remnant kidney', 0.0),
#  ('and a rye bread with intact rye kernels', 0.0),
#  ('and desensitization of the receptor mammalian rhodopsin kinase', 0.0),
#  ('and without lactic acids boiled whole grain rye', 0.0),
#  ('animals that undergoes the kindling or rapid kindling', 0.0),
#  ('arginine 448 of slp76 was replaced by lysine', 0.0),
#  ('as a calcium sensor that regulate rhodopsin kinase', 0.0),
#  ('as described previous 14 recoverin and rhodopsin kinase', 0.0),
#  ('as immatures 2 3 days with raspberry ketone', 0.0),
#  ('as yet unknown excitatory signaling pathway raspberry ketone', 0.0),
#  ('astigmatism in patients with history of radial keratotomy', 0.0),
#  ('b tryoni including cue lure melolure raspberry ketone', 0.0),
#  ('bacteria including highly connected members of the veillonellaceae', 0.0),
#  ('been solved for recoverin bound to rhodopsin kinase', 0.0),
#  ('binding and regulate the action of rhodopsin kinase', 0.0),
#  ('calcium dependent inhibition of the enzyme rhodopsin kinase', 0.0),
#  ('characteristics between the two kohlrabi cultivar red kohlrabi', 0.0),
#  ('chloroadenine catalyzed by the recombinant e coli ribokinase', 0.0),
#  ('closely related to complex metabolic disease raspberry ketone', 0.0),
#  ('concentrations of a tau or b rigor kinesin', 0.0),
#  ('cue lure a synthetic analogue of raspberry ketone', 0.0),
#  ('dee > qqq dee and rk > qq', 0.0),
#  ('dentate gc 4 6 week after rapid kindling', 0.0),
#  ('detailed analysis mitochondrial aldehyde dehydrogenase maldh and ribokinase',
#   0.0),
#  ('determination the anti obesity effect of raspberry ketone', 0.0),
#  ('excited rhodopsin 33 35 by inhibition rhodopsin kinase', 0.0),
#  ('expression of α a crystalline and rho kinase', 0.0),
#  ('fgf 23 levels in control remnant kidney rats', 0.0),
#  ('function remains unclear both normal and remnant kidney', 0.0),
#  ('gastric ulcer is not yet elucidated raspberry ketone', 0.0),
#  ('his lys h k instead of arg lys', 0.0),
#  ('human rhodopsin rho 29 30 human rhodopsin kinase', 0.0),
#  ('in b16f10 melanoma cells treated with raspberry ketone', 0.0),
#  ('in which the expression levels of rhodospin kinase', 0.0),
#  ('instance raspberry ketone 4 4 hydroxyphenyl 2 butanone', 0.0),
#  ('its ca 2 + and separate from rhodopsinkinase', 0.0),
#  ('its function in vivo with even conservative amino', 0.0),
#  ('kurtosis mk axial kurtosis ak and radial kurtosis', 0.0),
#  ('levels in b16f10 cells furthermore although raspberry ketone', 0.0),
#  ('lps stimulate control group effect of red kohlrabi', 0.0),
#  ('m igm by 2 hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('makino et al 2004 by inhibition rhodopsin kinase', 0.0),
#  ('male b tryoni when fed a raspberry ketone', 0.0),
#  ('map ki nase homologue termed the reactivating kinase', 0.0),
#  ('mg kg b w or rosi and krg', 0.0),
#  ('model sprague dawley rats received 5 6 nephrectomy', 0.0),
#  ('modification that is known to regulate receptor kinase', 0.0),
#  ('myristoyl group and disrupt binding to rhodopsin kinase', 0.0),
#  ('npc31169 n = 6 group iii remnant kidney', 0.0),
#  ('occurred 6 years previous followed combined radial keratotomy', 0.0),
#  ('of 116 79 ± 0 13 μg ml', 0.0),
#  ('of green kohlrabi gk a and red kohlrabi', 0.0),
#  ('of keratoconic corneal ectasia exacerbated by radial keratotomy', 0.0),
#  ('of p42 p44 mapk termed the reactivating kinase', 0.0),
#  ('of the ctmc described deactivation by rhodopsin kinase', 0.0),
#  ('of the iris 7 years after radial keratotomy', 0.0),
#  ('of three e coli enzyme i e ribokinase', 0.0),
#  ('one pot synthesis by used e coli ribokinase', 0.0),
#  ('or β glucan bg rye bread with kernels', 0.0),
#  ('patients with history of 8 cut radial keratotomy', 0.0),
#  ('phd inhibitor l mimosine rats with remnant kidney', 0.0),
#  ('phenolic compounds a rhododendrol rd b raspberry ketone', 0.0),
#  ('phosphorylation of bleached rhodopsin rho by rhodopsin kinase', 0.0),
#  ('phosphorylation of the c terminus by rhodopsin kinase', 0.0),
#  ('plot in fig 4e indicate that residues kriging', 0.0),
#  ('power in cataract patients with previous radial keratotomy', 0.0),
#  ('promising approach for obesity treatment although raspberry ketone', 0.0),
#  ('quantify and localize iron in rats remnant kidney', 0.0),
#  ('reaction for the r phosphorylation by rhodopsin kinase', 0.0),
#  ('reactivating oxygen species ros induced by raspberry ketone', 0.0),
#  ('refractive data in eyes with previous radial keratotomy', 0.0),
#  ('region δ20 or the carboxyl terminal sh2 domain', 0.0),
#  ('rhodopsin by the retina specific enzyme rhodopsin kinase', 0.0),
#  ('rye bread gr □ rye bread with kernels', 0.0),
#  ('rye gr bread and rye bread with kernels', 0.0),
#  ('section above table s1 summary of rigor kinesin', 0.0),
#  ('sensory neurons in mice and human raspberry ketone', 0.0),
#  ('sequence of rhodopsin are phosphorylation by rhodopsin kinase', 0.0),
#  ('show the connected of these four taxa veillonellaceae', 0.0),
#  ('signaling the protein undergoes phosphorylation via rhodopsin kinase', 0.0),
#  ('slow kindling protocols sk the rapid kindling type', 0.0),
#  ('so far group into three subfamilies rhodopsin kinase', 0.0),
#  ('tenth that of wild type in rhodopsin kinase', 0.0),
#  ('the cosmetics industry chemical structure of raspberry ketone', 0.0),
#  ('the cultivar kohlrabi stems may be purple red', 0.0),
#  ('the highly conservative homeodomain resides an arginine lysine', 0.0),
#  ('the laser method of vision correction radial keratotomy', 0.0),
#  ('the mammalian cells lines used were rabbit kidney', 0.0),
#  ('the map kinase homologue termed here reactivating kinase', 0.0),
#  ('the wholegrain wheat kernels wk and rye kernels', 0.0),
#  ('then random assigned to either the remnant kidney', 0.0),
#  ('to induced gastric ulcer in rats raspberry ketone', 0.0),
#  ('toast wf mørkt rugbrød gr and levebrød multikernerugbrød', 0.0),
#  ('trauma past laser ablation decentration and radial keratotomy', 0.0),
#  ('two basic amino acids in the b domain', 0.0),
#  ('we show that seizure induced by rapid kindling', 0.0),
#  ('with 1 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('with 5 0 mm rd and raspberry ketone', 0.0),
#  ('with 5 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('with ground rye gr or intact rye kernels', 0.0),
#  ('with the n terminal helix of rhodopsin kinase', 0.0),
#  ('zernii et al 2011 while retina specific grk1', 0.0),
#  ('+ npc31169 n = 6 group iii remnant kidney', 0.0),
#  ('15 mg kg b w or rosi and krg', 0.0),
#  ('1998 makino et al 2004 by inhibition rhodopsin kinase', 0.0),
#  ('2 chloroadenine catalyzed by the recombinant e coli ribokinase', 0.0),
#  ('2 levels in b16f10 cells furthermore although raspberry ketone', 0.0),
#  ('2006 zernii et al 2011 while retina specific grk1', 0.0),
#  ('29 human rhodopsin rho 29 30 human rhodopsin kinase', 0.0),
#  ('3 the comparative advantages of pre release raspberry ketone', 0.0),
#  ('34 the wholegrain wheat kernels wk and rye kernels', 0.0),
#  ('7 show the connected of these four taxa veillonellaceae', 0.0),
#  ('a promising approach for obesity treatment although raspberry ketone', 0.0),
#  ('abstract a map kinase homologue termed the reactivating kinase', 0.0),
#  ('action of three e coli enzyme i e ribokinase', 0.0),
#  ('activation rhodopsin by the retina specific enzyme rhodopsin kinase', 0.0),
#  ('an as yet unknown excitatory signaling pathway raspberry ketone', 0.0),
#  ('and altered metabolic activation of the rats remnant kidney', 0.0),
#  ('and astigmatism in patients with history of radial keratotomy', 0.0),
#  ('and cue lure a synthetic analogue of raspberry ketone', 0.0),
#  ('and fgf 23 levels in control remnant kidney rats', 0.0),
#  ('and refractive data in eyes with previous radial keratotomy', 0.0),
#  ('are his lys h k instead of arg lys', 0.0),
#  ('associated bacteria including highly connected members of the veillonellaceae',
#   0.0),
#  ('at an early stage of the rats remnant kidney', 0.0),
#  ('attached myristoyl group and disrupt binding to rhodopsin kinase', 0.0),
#  ('ax or β glucan bg rye bread with kernels', 0.0),
#  ('binding region δ20 or the carboxyl terminal sh2 domain', 0.0),
#  ('bomologue of p42 p44 mapk termed the reactivating kinase', 0.0),
#  ('bread and a rye bread with intact rye kernels', 0.0),
#  ('bread with ground rye gr or intact rye kernels', 0.0),
#  ('by a promoter derived from the human rhodopsin kinase', 0.0),
#  ('by two basic amino acids in the b domain', 0.0),
#  ('cascade one pot synthesis by used e coli ribokinase', 0.0),
#  ('cataract patients with history of 8 cut radial keratotomy', 0.0),
#  ('conditions in which the expression levels of rhodospin kinase', 0.0),
#  ('corneal trauma past laser ablation decentration and radial keratotomy',
#   0.0),
#  ('cyst of the iris 7 years after radial keratotomy', 0.0),
#  ('diagram of the ctmc described deactivation by rhodopsin kinase', 0.0),
#  ('distinct map ki nase homologue termed the reactivating kinase', 0.0),
#  ('effect of green kohlrabi gk a and red kohlrabi', 0.0),
#  ('enzyme reaction for the r phosphorylation by rhodopsin kinase', 0.0),
#  ('enzymatic activation of wild type af ugma with conservative', 0.0),
#  ('fig 2 figure 2 effect of feeding raspberry ketone', 0.0),
#  ('for b tryoni including cue lure melolure raspberry ketone', 0.0),
#  ('for instance raspberry ketone 4 4 hydroxyphenyl 2 butanone', 0.0),
#  ('for its function in vivo with even conservative amino', 0.0),
#  ('ground rye bread gr □ rye bread with kernels', 0.0),
#  ('ground rye gr bread and rye bread with kernels', 0.0),
#  ('have been solved for recoverin bound to rhodopsin kinase', 0.0),
#  ('hippocampus we show that seizure induced by rapid kindling', 0.0),
#  ('hvede toast wf mørkt rugbrød gr and levebrød multikernerugbrød', 0.0),
#  ('hydroxylase phd inhibitor l mimosine rats with remnant kidney', 0.0),
#  ('immunoglobulin m igm by 2 hydroxy 5 nitrobenzyl bromide', 0.0),
#  ('important animals that undergoes the kindling or rapid kindling', 0.0),
#  ('in a suspension of infected mouse brain rabbit kidney', 0.0),
#  ('in dentate gc 4 6 week after rapid kindling', 0.0),
#  ('in the cosmetics industry chemical structure of raspberry ketone', 0.0),
#  ('induced gastric ulcer is not yet elucidated raspberry ketone', 0.0),
#  ('inhibition the map kinase homologue termed here reactivating kinase', 0.0),
#  ('interacts with the n terminal helix of rhodopsin kinase', 0.0),
#  ('intracellular reactivating oxygen species ros induced by raspberry ketone',
#   0.0),
#  ('iol power in cataract patients with previous radial keratotomy', 0.0),
#  ('is closely related to complex metabolic disease raspberry ketone', 0.0),
#  ('kidney model sprague dawley rats received 5 6 nephrectomy', 0.0),
#  ('kinase 2 is activation in vivo by reactivating kinase', 0.0),
#  ('levels in b16f10 melanoma cells treated with raspberry ketone', 0.0),
#  ('light excited rhodopsin 33 35 by inhibition rhodopsin kinase', 0.0),
#  ('management of keratoconic corneal ectasia exacerbated by radial keratotomy',
#   0.0),
#  ('mean kurtosis mk axial kurtosis ak and radial kurtosis', 0.0),
#  ('more detailed analysis mitochondrial aldehyde dehydrogenase maldh and ribokinase',
#   0.0),
#  ('mrna expression of α a crystalline and rho kinase', 0.0),
#  ('of ala in the disease progression of remnant kidney', 0.0),
#  ('of phenolic compounds a rhododendrol rd b raspberry ketone', 0.0),
#  ('of sensory neurons in mice and human raspberry ketone', 0.0),
#  ('on the cultivar kohlrabi stems may be purple red', 0.0),
#  ('on the laser method of vision correction radial keratotomy', 0.0),
#  ('one tenth that of wild type in rhodopsin kinase', 0.0),
#  ('or slow kindling protocols sk the rapid kindling type', 0.0),
#  ('p > 0 05 effect of feeding raspberry ketone', 0.0),
#  ('phosphorylation and desensitization of the receptor mammalian rhodopsin kinase',
#   0.0),
#  ('phytochemical characteristics between the two kohlrabi cultivar red kohlrabi',
#   0.0),
#  ('populations the comparative advantages of pre release raspberry ketone',
#   0.0),
#  ('release as immatures 2 3 days with raspberry ketone', 0.0),
#  ('release its ca 2 + and separate from rhodopsinkinase', 0.0),
#  ('renal function remains unclear both normal and remnant kidney', 0.0),
#  ('report so far group into three subfamilies rhodopsin kinase', 0.0),
#  ('retina as described previous 14 recoverin and rhodopsin kinase', 0.0),
#  ('rho > rho phosphorylation of rho by rhodopsin kinase', 0.0),
#  ('rho signaling the protein undergoes phosphorylation via rhodopsin kinase',
#   0.0),
#  ('scatter plot in fig 4e indicate that residues kriging', 0.0),
#  ('see section above table s1 summary of rigor kinesin', 0.0),
#  ('serves as a calcium sensor that regulate rhodopsin kinase', 0.0),
#  ('sterile male b tryoni when fed a raspberry ketone', 0.0),
#  ('terminal sequence of rhodopsin are phosphorylation by rhodopsin kinase',
#   0.0),
#  ('that occurred 6 years previous followed combined radial keratotomy', 0.0),
#  ('the ability of calmodulin to regulate grks including grk1', 0.0),
#  ('the lps stimulate control group effect of red kohlrabi', 0.0),
#  ('to determination the anti obesity effect of raspberry ketone', 0.0),
#  ('to quantify and localize iron in rats remnant kidney', 0.0),
#  ('to the highly conservative homeodomain resides an arginine lysine', 0.0),
#  ('translational modification that is known to regulate receptor kinase', 0.0),
#  ('treated with 1 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('treated with 5 0 mm rd and raspberry ketone', 0.0),
#  ('treated with 5 0 mm rhododendrol rd raspberry ketone', 0.0),
#  ('two concentrations of a tau or b rigor kinesin', 0.0),
#  ('undergoes a random number of phosphorylation by rhodopsin kinase', 0.0),
#  ('used to induced gastric ulcer in rats raspberry ketone', 0.0),
#  ('values of 116 79 ± 0 13 μg ml', 0.0),
#  ('via calcium dependent inhibition of the enzyme rhodopsin kinase', 0.0),
#  ('virus the mammalian cells lines used were rabbit kidney', 0.0),
#  ('were then random assigned to either the remnant kidney', 0.0),
#  ('which arginine 448 of slp76 was replaced by lysine', 0.0),
#  ('which binding and regulate the action of rhodopsin kinase', 0.0),
#  ('with and without lactic acids boiled whole grain rye', 0.0),
#  ('with phosphorylation of the c terminus by rhodopsin kinase', 0.0),
#  ('wt dee > qqq dee and rk > qq', 0.0),
#  ('0 34 the wholegrain wheat kernels wk and rye kernels', 0.0),
#  ('131 fig 2 figure 2 effect of feeding raspberry ketone', 0.0),
#  ('1995 abstract a map kinase homologue termed the reactivating kinase', 0.0),
#  ('2 are his lys h k instead of arg lys', 0.0),
#  ('28 29 human rhodopsin rho 29 30 human rhodopsin kinase', 0.0),
#  ('50 values of 116 79 ± 0 13 μg ml', 0.0),
#  ('a bomologue of p42 p44 mapk termed the reactivating kinase', 0.0),
#  ('a cataract patients with history of 8 cut radial keratotomy', 0.0),
#  ('a distinct map ki nase homologue termed the reactivating kinase', 0.0),
#  ('activation of sensory neurons in mice and human raspberry ketone', 0.0),
#  ('adaptation via calcium dependent inhibition of the enzyme rhodopsin kinase',
#   0.0),
#  ('affect renal function remains unclear both normal and remnant kidney', 0.0),
#  ('aim to determination the anti obesity effect of raspberry ketone', 0.0),
#  ...]

# %%
longforms0 = miners['RK'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('raspberry ketone', 26.85714285714286)),
#  (1, ('rhodopsin kinase', 23.923076923076923)),
#  (2, ('radial keratotomy', 7.777777777777778)),
#  (3, ('remnant kidney', 6.25)),
#  (4, ('kernels', 4.2)),
#  (5, ('ribokinase', 3.5)),
#  (6,
#   ('sence and presence of microtubule obstacles two concentrations of a tau or b rigor kinesin',
#    3)),
#  (7, ('lysine', 2.0)),
#  (8, ('red kohlrabi', 2.0)),
#  (9, ('rapid kindling', 2.0))]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i not in [6]]

# %%
longforms0
# Out:
# [('raspberry ketone', 26.85714285714286),
#  ('rhodopsin kinase', 23.923076923076923),
#  ('radial keratotomy', 7.777777777777778),
#  ('remnant kidney', 6.25),
#  ('kernels', 4.2),
#  ('ribokinase', 3.5),
#  ('lysine', 2.0),
#  ('red kohlrabi', 2.0),
#  ('rapid kindling', 2.0)]

# %%
longforms0.extend([(longform, score) for i, (longform, score) in enumerate(top)
                   if i in [13]])

# %%
longforms0
# Out:
# [('clock', 86.3921568627451),
#  ('cdc2 like kinase', 6.0),
#  ('contralateral kidney', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('raspberry ketone',
#  'rhodopsin kinase',
#  'radial keratotomy',
#  'remnant kidney',
#  'kernels',
#  'ribokinase',
#  'lysine',
#  'red kohlrabi',
#  'rapid kindling')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'raspberry ketone': 'CHEBI:CHEBI:68656',
#  'rhodopsin kinase': 'MESH:D051606',
#  'radial keratotomy': 'MESH:D007646',
#  'ribokinase': 'HGNC:30325',
#  'lysine': 'CHEBI:CHEBI:25094'}

# %%
names
# Out:
# {'CHEBI:CHEBI:68656': 'raspberry ketone',
#  'MESH:D051606': 'G-Protein-Coupled Receptor Kinase 1',
#  'MESH:D007646': 'Keratotomy, Radial',
#  'HGNC:30325': 'RBKS',
#  'CHEBI:CHEBI:25094': 'lysine'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)
# Out:
# ERROR: [2020-01-21 09:57:25] werkzeug - Error on request:
# Traceback (most recent call last):
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/werkzeug/serving.py", line 302, in run_wsgi
#     execute(self.server.app)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/werkzeug/serving.py", line 293, in execute
#     write(data)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/werkzeug/serving.py", line 274, in write
#     self.wfile.write(data)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socketserver.py", line 799, in write
#     self._sock.sendall(b)
# OSError: [Errno 41] Protocol wrong type for socket

# %%
names
# Out:
# {'PUBCHEM:10869981': 'Fluoroestradiol F-18',
#  'MESH:D004620': 'Embolism, Fat',
#  'MESH:D004599': 'Electric Stimulation Therapy'}

# %%
grounding_map
# Out:
# {'estradiol': 'PUBCHEM:10869981',
#  'fat embolism syndrome': 'MESH:D004620',
#  'first episode schizophrenia': 'ungrounded',
#  'fluoroestradiol': 'PUBCHEM:10869981',
#  'free energy surface': 'ungrounded',
#  'functional electrical stimulation': 'MESH:D004599'}

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'kernels': 'ungrounded',
#   'lysine': 'ungrounded',
#   'radial keratotomy': 'MESH:D007646',
#   'rapid kindling': 'ungrounded',
#   'raspberry ketone': 'CHEBI:CHEBI:68656',
#   'red kohlrabi': 'ungrounded',
#   'remnant kidney': 'ungrounded',
#   'rhodopsin kinase': 'MESH:D051606',
#   'ribokinase': 'HGNC:30325'},
#  {'MESH:D007646': 'Keratotomy, Radial',
#   'CHEBI:CHEBI:68656': 'raspberry ketone',
#   'MESH:D051606': 'G-Protein-Coupled Receptor Kinase 1',
#   'HGNC:30325': 'RBKS'},
#  ['CHEBI:CHEBI:68656', 'HGNC:30325', 'MESH:D007646', 'MESH:D051606'])

# %%
grounding_map, names, pos_labels = ({'kernels': 'ungrounded',
  'lysine': 'ungrounded',
  'radial keratotomy': 'MESH:D007646',
  'rapid kindling': 'ungrounded',
  'raspberry ketone': 'CHEBI:CHEBI:68656',
  'red kohlrabi': 'ungrounded',
  'remnant kidney': 'ungrounded',
  'rhodopsin kinase': 'MESH:D051606',
  'ribokinase': 'HGNC:30325'},
 {'MESH:D007646': 'Keratotomy, Radial',
  'CHEBI:CHEBI:68656': 'raspberry ketone',
  'MESH:D051606': 'G-Protein-Coupled Receptor Kinase 1',
  'HGNC:30325': 'RBKS'},
 ['CHEBI:CHEBI:68656', 'HGNC:30325', 'MESH:D007646', 'MESH:D051606'])

# %%
grounding_dict = {'RK': grounding_map}

# %%
classifier = AdeftClassifier('RK', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-21 09:59:22] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-21 09:59:44] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.7337845992391446 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'CHEBI:CHEBI:68656': 10,
#   'MESH:D051606': 24,
#   'HGNC:30325': 14,
#   'ungrounded': 15,
#   'MESH:D007646': 7,
#   'HGNC:10013': 42},
#  'f1': {'mean': 0.7337845992391446, 'std': 0.13323452134462177},
#  'precision': {'mean': 0.8299242424242423, 'std': 0.10772177930463969},
#  'recall': {'mean': 0.6989898989898989, 'std': 0.17001083288315097}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [(text, pred) for pred, text in zip(d, shortform_texts)if pred[0].startswith('HGNC')]

# %%
len(a)
# Out:
# 88

# %%
a[40]
# Out:
# ('PDF to Text Batch Convert Multiple Files Software - Please purchase\npersonal license.  Pergamon    Psychoneuroendocrinology,Vol. 22. No.\n1, pp. 1-11, ]997 Copyright 1997 Elsevier Science Ltd. All rights\nreserved Printed in Great Britain 0306-4530/97 $1%00+ .00 P I h\nS0306-4530(96)00042-X    CENTRAL MEDIATION OF THE EFFECTS OF\nINTERLEUKIN-1 O N S O C I A L E X P L O R A T I O N A N D B O D Y W E\nI G H T IN M I C E Rose-Marie Bluth61, Robert Dantzer 1 and Keith W.\nKelley e  IINRA-INSERM U394, Domaine de Carreire, Rue Camille Saint-\nSa~ns, 33077 Bordeaux Cedex, France; and 2Laboratory of\nImmunophysiology, University of Illinois, Urbana, Illinois, USA\n(Received 2 July 1996; in final form 19 September 1996)    SUMMARY  To\nstudy the role of central IL-1 receptors in the effects of recombinant\nhuman IL-1B (1L-lfl) on behavior and body weight,\nintracerebroventricular (ICV) injection of the specific antagonist of\nIL-1 receptors, IL-lra, was administered to mice injected\nintraperitoneally (IP) and ICV with various doses of IL-lfl. Doses of\n500 ng IP IL-lfl and 900 pg ICV IL-lfl induced a comparable decrease\nin social behavior and loss of body weight. Pretreatment with IL-lra\n(1.8/zg/mouse, ICV) blocked the effects of ICV IL-lfl (900 pg/mouse)\non social behavior. ICV IL-lra (3.6 ,ug/mouse) also attenuated the\neffects of IP IL-lfl (500 ng/mouse) on social behavior and change in\nbody weight, suggesting that the effects of peripheral IL-lfl are\ncentrally mediated. 1997 Elsevier Science Ltd. All rights reserved.\nKeywords---Interleukin-1; Interleukin-1 receptor antagonist; Receptor;\nSocial behavior; Body weight; Mouse.    INTRODUCTION Interleukin-lfl\n(IL-lfl) is released locally from macrophages and monocytes during the\ncourse of an infection. It mediates the acute phase response and acts\non immune cells and distant target organs (Dinarello, 1996).\nPeripheral and central injections of IL-lfl induce behavioral changes\nthat are reminiscent of sickness (Dantzer et al., 1991, 1993). These\nchanges include hypersomnia (Krueger et al., 1990; Obal et al., 1990;\nOpp & Krueger, 1991), decrease in social activities (Bluth6 et al.,\n1991, 1995, 1996; Dantzer et al., 1991), alteration o f investigation\no f a novel environment (Spadaro & Dunn, 1990) and anorexia (Bluth6 et\nal., 1989). IL-lfl acts on specific receptors that have been\ncharacterized on peripheral immune targets and are encoded by two\ndifferent genes. A 80-kDa membrane receptor that binds both I L - I ~\nand I L - l f l with a similar affinity has been described on T cells\nand fibroblasts and is called Address correspondence and reprint\nrequests to: Ms Rose-Marie Bluthr, INRA-INSERM U394, Domaine de\nCarreire, Rue Camille Saint-SaEns, 33077 Bordeaux Cedex, France (Tel:\n33 5 57 57 37 16; Fax: 33 5 57 57 37 16; E-mail: rose-\nmarie.bluthe@bordeaux.inserm.fr).    2    R.-M. Bluth6 et al.    the\n\'type I IL-1 receptor\' (Dripps et al., 1991a; Hannum et al., 1990;\nMclntyre et al., 1991). The type II receptor is a 68-kDa binding\nprotein that was originally identified on B cells, and has a higher\naffinity for IL-lfl than for IL-l~t (Dripps et al., 1991b; McMahan et\nal., 1991). Type I IL-1 receptor mRNA has been identified in the brain\nand anterior pituitary by in-situ hybridization techniques (Cunningham\net al., 1992) and RT-PCR (Parnet et al., 1993, 1994). Although the\ndistribution of type II IL-1 receptors in the mouse brain has not yet\nbeen fully described, there is evidence that it is present in the\npituitary and in the brain (Parnet et al., 1993, 1994). The difference\nbetween the two receptors is the short cytoplasmic domain of 29 amino-\nacids for the type II IL-1 receptor that is believed to account for\nthe lack of biological activity of IL-1 binding on this receptor\n(McMahan et al., 1991; Sims et al., 1988, 1989). Type II IL-1 receptor\nis released from the membrane as a soluble protein and inhibits the\nactivity of IL-1 by acting as a deco ...
#  ('HGNC:10013',
#   None,
#   {'CHEBI:CHEBI:68656': 0.12774208780283045,
#    'HGNC:10013': 0.35188223080008757,
#    'HGNC:30325': 0.11156349577977472,
#    'MESH:D007646': 0.05277067088579557,
#    'MESH:D051606': 0.11880465762414115,
#    'ungrounded': 0.23723685710737055}))

# %%
disamb.dump('RK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('FES', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
