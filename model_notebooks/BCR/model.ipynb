# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['BCR']
genes = ['BCR']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
len(shortform_texts)
# Out:
# 3732

# %% [markdown]
# ### top = miners['BCR'].top()

# %%
# %time miners['BCR'].compute_alignment_scores()
# Out:
# CPU times: user 3.94 s, sys: 176 ms, total: 4.11 s
# Wall time: 4.17 s

# %%
# Out:
# [('b cell receptor', 1533.7325648414985),
#  ('receptor', 1022.0161943319838),
#  ('the b cell receptor', 569.7206611570248),
#  ('b cell antigen receptor', 392.6581352833638),
#  ('biochemical recurrence', 277.2733333333333),
#  ('the b cell antigen receptor', 268.8085106382979),
#  ('of the b cell receptor', 163.02923976608187),
#  ('of b cell receptor', 146.0),
#  ('of the b cell antigen receptor', 85.91397849462368),
#  ('and b cell receptor', 70.25974025974025),
#  ('antigen receptor', 64.01322314049582),
#  ('of biochemical recurrence', 54.57575757575758),
#  ('through the b cell receptor', 45.24590163934426),
#  ('in b cell receptor', 42.666666666666664),
#  ('b cell ag receptor', 35.2),
#  ('to the b cell receptor', 34.59090909090909),
#  ('through the b cell antigen receptor', 32.97560975609756),
#  ('by b cell receptor', 32.628571428571426),
#  ('by the b cell receptor', 30.12121212121212),
#  ('to b cell receptor', 28.952380952380953),
#  ('and biochemical recurrence', 28.333333333333332),
#  ('signaling through the b cell receptor', 27.68),
#  ('of b cell antigen receptor', 27.333333333333332),
#  ('with the b cell receptor', 27.333333333333332),
#  ('for b cell receptor', 26.571428571428573),
#  ('breakpoint cluster region', 25.515151515151516),
#  ('a b cell receptor', 22.4),
#  ('the b cell ag receptor', 20.75),
#  ('with b cell receptor', 19.81818181818182),
#  ('with biochemical recurrence', 19.08333333333334),
#  ('upon b cell receptor', 18.952380952380953),
#  ('specific b cell receptor', 18.692307692307693),
#  ('engagement of the b cell receptor', 18.647058823529413),
#  ('risk of biochemical recurrence', 18.64),
#  ('and the b cell receptor', 16.666666666666668),
#  ('their b cell receptor', 16.400000000000002),
#  ('that b cell receptor', 15.176470588235293),
#  ('by the b cell antigen receptor', 15.157894736842106),
#  ('for biochemical recurrence', 15.052631578947368),
#  ('signaling through the b cell antigen receptor', 14.5),
#  ('after b cell receptor', 14.375),
#  ('in b cell antigen receptor', 14.375),
#  ('t cell receptor tcr and b cell receptor', 14.25),
#  ('activation b cell receptor', 14.222222222222221),
#  ('in response to b cell receptor', 13.875),
#  ('components of the b cell receptor', 13.846153846153847),
#  ('via the b cell receptor', 13.777777777777779),
#  ('in the b cell receptor', 13.333333333333334),
#  ('engagement of the b cell antigen receptor', 12.75),
#  ('through b cell receptor', 12.571428571428571),
#  ('activation of the b cell receptor', 12.285714285714286),
#  ('following b cell receptor', 11.692307692307692),
#  ('on biochemical recurrence', 11.538461538461538),
#  ('including the b cell receptor', 11.538461538461538),
#  ('response to b cell receptor', 11.478260869565217),
#  ('inhibition b cell receptor', 11.23076923076923),
#  ('antigen specific b cell receptor', 11.076923076923077),
#  ('signaling from the b cell receptor', 11.0),
#  ('cluster region', 10.76923076923077),
#  ('ligation of the b cell antigen receptor', 10.714285714285714),
#  ('cross linking of the b cell antigen receptor', 10.666666666666666),
#  ('regulation of b cell receptor', 10.538461538461538),
#  ('via b cell receptor', 10.153846153846153),
#  ('and b cell antigen receptor', 9.999999999999996),
#  ('the breakpoint cluster region', 9.857142857142858),
#  ('predict biochemical recurrence', 9.833333333333334),
#  ('including b cell receptor', 9.636363636363637),
#  ('of the b cell ag receptor', 9.454545454545455),
#  ('from the b cell receptor', 9.444444444444445),
#  ('a function b cell receptor', 9.363636363636363),
#  ('experience biochemical recurrence', 9.333333333333334),
#  ('surface b cell receptor', 9.272727272727273),
#  ('the biochemical recurrence', 9.11111111111111),
#  ('pre b cell receptor', 9.076923076923077),
#  ('as the b cell receptor', 8.90909090909091),
#  ('stimulation of the b cell receptor', 8.8),
#  ('the risk of biochemical recurrence', 8.727272727272727),
#  ('downstream of the b cell receptor', 8.727272727272723),
#  ('associated with biochemical recurrence', 8.6),
#  ('binding of antigen to the b cell receptor', 8.538461538461538),
#  ('ligation of the b cell receptor', 8.500000000000002),
#  ('on b cell receptor', 8.199999999999998),
#  ('as b cell receptor', 8.181818181818182),
#  ('recurrence', 7.927868852459028),
#  ('to the b cell antigen receptor', 7.857142857142857),
#  ('or b cell receptor', 7.6923076923076925),
#  ('block b cell receptor', 7.555555555555555),
#  ('their b cell antigen receptor', 7.555555555555555),
#  ('to b cell antigen receptor', 7.272727272727273),
#  ('target the b cell receptor', 7.111111111111111),
#  ('tcr and b cell receptor', 7.0),
#  ('antigen binding to the b cell receptor', 7.0),
#  ('upon b cell antigen receptor', 6.777777777777778),
#  ('function b cell receptor', 6.75),
#  ('by b cell antigen receptor', 6.75),
#  ('t cell receptor tcr or b cell receptor', 6.75),
#  ('both b cell receptor', 6.714285714285714),
#  ('to biochemical recurrence', 6.5),
#  ('activation of b cell receptor', 6.5),
#  ('for b cell antigen receptor', 6.5),
#  ('b cell immunoglobulin receptor', 6.25),
#  ('regulation b cell receptor', 6.142857142857142),
#  ('impaired b cell receptor', 6.0),
#  ('components of b cell receptor', 6.0),
#  ('of the breakpoint cluster region', 6.0),
#  ('that b cell antigen receptor', 6.0),
#  ('and the b cell antigen receptor', 6.0),
#  ('from the b cell antigen receptor', 6.0),
#  ('signaling by the b cell antigen receptor', 6.0),
#  ('aberrant b cell receptor', 5.714285714285714),
#  ('cell b cell receptor', 5.714285714285714),
#  ('chronic activation b cell receptor', 5.714285714285714),
#  ('associated with the b cell receptor', 5.714285714285714),
#  ('in the b cell antigen receptor', 5.714285714285714),
#  ('signaling via the b cell receptor', 5.666666666666667),
#  ('region', 5.571428571428569),
#  ('antigen through the b cell receptor', 5.5),
#  ('via the b cell antigen receptor', 5.428571428571429),
#  ('b lymphocytes antigen receptor', 5.333333333333333),
#  ('antigen to the b cell receptor', 5.294117647058824),
#  ('rate', 5.25),
#  ('factor for biochemical recurrence', 5.25),
#  ('unique b cell receptor', 5.25),
#  ('inhibition of b cell receptor', 5.142857142857142),
#  ('receptor complex', 5.090909090909091),
#  ('activation by b cell receptor', 5.0),
#  ('role in b cell receptor', 5.0),
#  ('activation of the b cell antigen receptor', 5.0),
#  ('signaling from the b cell antigen receptor', 5.0),
#  ('biochemical relapse', 4.666666666666667),
#  ('a biochemical recurrence', 4.666666666666667),
#  ('activation the b cell receptor', 4.666666666666667),
#  ('cd40 and b cell receptor', 4.666666666666667),
#  ('stimulation through the b cell antigen receptor', 4.666666666666667),
#  ('the binding of antigen to the b cell receptor', 4.6),
#  ('antigen binding to the b cell antigen receptor', 4.5),
#  ('mediated b cell receptor', 4.333333333333333),
#  ('on b cell antigen receptor', 4.333333333333333),
#  ('that the b cell receptor', 4.333333333333333),
#  ('negative regulation of b cell receptor', 4.333333333333333),
#  ('bulbocavernosus reflex', 4.285714285714286),
#  ('igm b cell receptor', 4.285714285714286),
#  ('the b cell antigen receptor complex', 4.285714285714286),
#  ('b cell receptor for antigen', 4.25),
#  ('target b cell receptor', 4.142857142857142),
#  ('benefit cost ratio', 4.0),
#  ('because b cell receptor', 4.0),
#  ('between b cell receptor', 4.0),
#  ('cll b cell receptor', 4.0),
#  ('reactive b cell receptor', 4.0),
#  ('activation upon b cell receptor', 4.0),
#  ('activation via b cell receptor', 4.0),
#  ('associated with b cell receptor', 4.0),
#  ('form the b cell receptor', 4.0),
#  ('function b cell antigen receptor', 4.0),
#  ('high affinity b cell receptor', 4.0),
#  ('of their b cell receptor', 4.0),
#  ('or the b cell receptor', 4.0),
#  ('the pre b cell receptor', 4.0),
#  ('both the b cell antigen receptor', 4.0),
#  ('crosslinking of the b cell receptor', 4.0),
#  ('signaling by the b cell receptor', 4.0),
#  ('components of the b cell antigen receptor', 4.0),
#  ('in response to b cell antigen receptor', 4.0),
#  ('cell receptor', 3.9966499162478613),
#  ('reductase', 3.6666666666666665),
#  ('stimulation of the b cell antigen receptor', 3.6666666666666665),
#  ('b cell', 3.6),
#  ('as biochemical recurrence', 3.6),
#  ('the antigen receptor', 3.6),
#  ('autoreactive b cell receptor', 3.6),
#  ('enhanced b cell receptor', 3.6),
#  ('downstream of b cell receptor', 3.6),
#  ('in b cell ag receptor', 3.6),
#  ('involved in b cell receptor', 3.6),
#  ('such as b cell receptor', 3.6),
#  ('the b cell receptor for antigen', 3.6),
#  ('the role of the b cell receptor', 3.6),
#  ('receptor such as the b cell antigen receptor', 3.6),
#  ('expression of the b cell antigen receptor', 3.5),
#  ('binding to the b cell receptor', 3.4000000000000004),
#  ('affinity b cell receptor', 3.25),
#  ('blastocoel roof', 3.2),
#  ('shorter biochemical recurrence', 3.2),
#  ('kaplan meier curves of biochemical recurrence', 3.2),
#  ('antigen to the b cell antigen receptor', 3.142857142857143),
#  ('such as the b cell antigen receptor', 3.142857142857143),
#  ('reflex', 3.1111111111111107),
#  ('igm', 3.0),
#  ('pca biochemical recurrence', 3.0),
#  ('their antigen receptor', 3.0),
#  ('5 year biochemical recurrence', 3.0),
#  ('altered b cell receptor', 3.0),
#  ('antigen b cell receptor', 3.0),
#  ('igd b cell receptor', 3.0),
#  ('increased b cell receptor', 3.0),
#  ('involved b cell receptor', 3.0),
#  ('modulates b cell receptor', 3.0),
#  ('rearrangement b cell receptor', 3.0),
#  ('signaling b cell receptor', 3.0),
#  ('to predict biochemical recurrence', 3.0),
#  ('tonic b cell receptor', 3.0),
#  ('both the b cell receptor', 3.0),
#  ('expression of b cell receptor', 3.0),
#  ('expression the b cell receptor', 3.0),
#  ('following b cell antigen receptor', 3.0),
#  ('for the b cell receptor', 3.0),
#  ('receptor the b cell receptor', 3.0),
#  ('regulation the b cell receptor', 3.0),
#  ('antigen through their b cell receptor', 3.0),
#  ('antigen via the b cell receptor', 3.0),
#  ('engagement of b cell antigen receptor', 3.0),
#  ('function of the b cell receptor', 3.0),
#  ('inhibitors of the b cell receptor', 3.0),
#  ('stimulation through the b cell receptor', 3.0),
#  ('signaling downstream of the b cell receptor', 3.0),
#  ('b cell in response to b cell receptor', 3.0),
#  ('bromocriptine', 2.8),
#  ('predictor of biochemical recurrence', 2.8),
#  ('increased risk of biochemical recurrence', 2.8),
#  ('regulation b cell antigen receptor', 2.8),
#  ('required for b cell receptor', 2.8),
#  ('role of b cell receptor', 2.8),
#  ('phosphorylation upon b cell antigen receptor', 2.8),
#  ('development biochemical recurrence', 2.5),
#  ('expression b cell receptor', 2.5),
#  ('ige b cell receptor', 2.5),
#  ('predict of biochemical recurrence', 2.5),
#  ('reduced b cell receptor', 2.5),
#  ('as a b cell receptor', 2.5),
#  ('important of b cell receptor', 2.5),
#  ('is the b cell receptor', 2.5),
#  ('of a b cell receptor', 2.5),
#  ('to b cell ag receptor', 2.5),
#  ('via their b cell receptor', 2.5),
#  ('antigen by the b cell receptor', 2.5),
#  ('kaplan meier estimates of biochemical recurrence', 2.5),
#  ('receptor the b cell antigen receptor', 2.5),
#  ('recognition by the b cell receptor', 2.5),
#  ('tcr and b cell antigen receptor', 2.5),
#  ('to the b cell ag receptor', 2.5),
#  ('negative regulation of b cell antigen receptor', 2.5),
#  ('of the b cell antigen receptor complex', 2.5),
#  ('binding of antigen to the b cell antigen receptor', 2.5),
#  ('by the binding of antigen to the b cell receptor', 2.5),
#  ('cell the b cell receptor', 2.4),
#  ('that target b cell receptor', 2.4),
#  ('biochemical recurrence rate', 2.0),
#  ('including biochemical recurrence', 2.0),
#  ('overall biochemical recurrence', 2.0),
#  ('postoperative biochemical recurrence', 2.0),
#  ('b cell receptor signaling', 2.0),
#  ('break point cluster region', 2.0),
#  ('from b cell receptor', 2.0),
#  ('mature b cell receptor', 2.0),
#  ('of the bulbocavernosus reflex', 2.0),
#  ('polyreactive b cell receptor', 2.0),
#  ('prostate cancer biochemical recurrence', 2.0),
#  ('proximal b cell receptor', 2.0),
#  ('therapy b cell receptor', 2.0),
#  ('will experience biochemical recurrence', 2.0),
#  ('a b cell antigen receptor', 2.0),
#  ('a pre b cell receptor', 2.0),
#  ('after b cell antigen receptor', 2.0),
#  ('antigen the b cell receptor', 2.0),
#  ('between the b cell receptor', 2.0),
#  ('both b cell antigen receptor', 2.0),
#  ('cell and b cell receptor', 2.0),
#  ('driven by b cell receptor', 2.0),
#  ('in cll b cell receptor', 2.0),
#  ('indicate that b cell receptor', 2.0),
#  ('inhibition the b cell receptor', 2.0),
#  ('levels of b cell receptor', 2.0),
#  ('ligation of b cell receptor', 2.0),
#  ('mediated by b cell receptor', 2.0),
#  ('negative regulation b cell receptor', 2.0),
#  ('prognostic factor for biochemical recurrence', 2.0),
#  ('rely on b cell receptor', 2.0),
#  ('risk factor for biochemical recurrence', 2.0),
#  ('the b cell receptor complex', 2.0),
#  ('through b cell antigen receptor', 2.0),
#  ('to inhibition b cell receptor', 2.0),
#  ('with b cell antigen receptor', 2.0),
#  ('a role for b cell receptor', 2.0),
#  ('activation through the b cell receptor', 2.0),
#  ('and the risk of biochemical recurrence', 2.0),
#  ('b cell b cell antigen receptor', 2.0),
#  ('b cell the b cell receptor', 2.0),
#  ('demonstrated that b cell antigen receptor', 2.0),
#  ('expression a function b cell receptor', 2.0),
#  ('inhibitors target the b cell receptor', 2.0),
#  ('involved in b cell antigen receptor', 2.0),
#  ('is required for b cell receptor', 2.0),
#  ('ligation of b cell antigen receptor', 2.0),
#  ('linking the b cell antigen receptor', 2.0),
#  ('mediated by the b cell receptor', 2.0),
#  ('negative regulation b cell antigen receptor', 2.0),
#  ('of the igm b cell receptor', 2.0),
#  ('of the pre b cell receptor', 2.0),
#  ('part of the b cell receptor', 2.0),
#  ('pharmacological inhibition of b cell receptor', 2.0),
#  ('stimulation of b cell antigen receptor', 2),
#  ('such as the b cell receptor', 2.0),
#  ('the engagement of b cell receptor', 2.0),
#  ('the role of b cell receptor', 2.0),
#  ('the strength of b cell receptor', 2.0),
#  ('the threshold of b cell receptor', 2.0),
#  ('triggered of the b cell receptor', 2.0),
#  ('with the b cell antigen receptor', 2.0),
#  ('year and annually thereafter biochemical recurrence', 2.0),
#  ('b cell expression a b cell receptor', 2.0),
#  ('b cell through the b cell receptor', 2.0),
#  ('cross linking of the b cell receptor', 2.0),
#  ('kinase inhibitors that target b cell receptor', 2.0),
#  ('proliferation in response to b cell receptor', 2.0),
#  ('recognize antigen through the b cell receptor', 2.0),
#  ('stimulation of the b cell ag receptor', 2),
#  ('the strength of b cell antigen receptor', 2.0),
#  ('antigen stimulation of the b cell antigen receptor', 2.0),
#  ('b cell expression a unique b cell receptor', 2.0),
#  ('proliferation in response to b cell antigen receptor', 2.0),
#  ('signaling downstream of the b cell antigen receptor', 2.0),
#  ('signaling generation through the b cell antigen receptor', 2.0),
#  ('signaling transduced by the b cell antigen receptor', 2.0),
#  ('signaling transduction through the b cell antigen receptor', 2.0),
#  ('in t cell receptor tcr and b cell receptor', 2.0),
#  ('the t cell receptor tcr and b cell receptor', 2.0),
#  ('the binding of antigen to the b cell antigen receptor', 2.0),
#  ('the t cell receptor tcr or the b cell receptor', 2.0),
#  ('as2 rs6542993 on prostate cancer progression kaplan meier estimates of a biochemical recurrence',
#   2),
#  ('ased proliferation rate stimulation of different receptor signaling pathways like b cell receptor',
#   2),
#  ('structure consistently of repeating epitopes that extensively crosslinking ag specific b cell receptor',
#   2),
#  ('t compared the distribution of somatic mutations frequency across b cell immunoglobulin receptor',
#   2),
#  ('transformation the next generation sequencing reads into error corrected b cell immunoglobulin receptor',
#   2),
#  ('ficant lower mrna expression levels of npas2 c kaplan meier curves of biochemical recurrence',
#   2),
#  ('inflammatory cell influx and mediated response following repetitive ode exposure in b cell receptor',
#   2),
#  ('ng an increased prostate specific antigen psa levels a conditions known as biochemical recurrence',
#   2),
#  ('vivo using lncap cell induced tumor xenografts a kaplan meier analyses of biochemical recurrence',
#   2),
#  ('and co receptor michael reth the multimeric nature of the b cell antigen receptor complex',
#   2),
#  ('plan meier estimates of bcr in all patients a kaplan meier estimates of biochemical recurrence',
#   2),
#  ('am of the b cell receptor signaling cascade show important events downstream of b cell receptor',
#   2),
#  ('improved outcome in most instance cll is an incurable disorders signaling via the b cell receptor',
#   2),
#  ('ceptor tyrosine based activation motif itam and py motif lmp2a is abl to block b cell receptor',
#   2),
#  ('r of nuclear factor kappa b ligand rankl expression in ra activation via a b cell receptor',
#   2),
#  ('tumor cell kill independent of mhc class i status b cell activation of the b cell receptor',
#   2),
#  ('earranging and combined v d and j mini gene pre b cell expression the pre b cell antigen receptor',
#   2),
#  ('e into b1 b2 progenitor bc pro bc b1 b2 precursor bc pre bc with assembly pre b cell receptor',
#   2),
#  ('from a rag2 deficient pro b cell lines were retrovirally transduced with μhc b1 8 hc or μhc + λlc',
#   2),
#  ('n et al 2012 nur77 gfp mice have thus emerged as a using tool to studies b cell antigen receptor',
#   2),
#  ('cell antigen receptor', 1.9965034965034647),
#  ('ag receptor', 1.96153846153846),
#  ('complex', 1.833333333333334),
#  ('antigen', 1.8000000000000007),
#  ('immunoglobulin receptor', 1.7777777777777777),
#  ('receptor for antigen', 1.7777777777777777),
#  ('ratio', 1.7142857142857144),
#  ('relapse', 1.7142857142857144),
#  ('cost ratio', 1.666666666666667),
#  ('role of the b cell receptor', 1.666666666666667),
#  ('year biochemical recurrence', 1.6),
#  ('estimates of biochemical recurrence', 1.6),
#  ('through their b cell receptor', 1.6),
#  ('regulation of b cell antigen receptor', 1.6),
#  ('signaling', 1.5),
#  ('specific receptor', 1.5),
#  ('thereafter biochemical recurrence', 1.5),
#  ('b cell receptor complex', 1.5),
#  ('patients experience biochemical recurrence', 1.5),
#  ('a unique b cell receptor', 1.5),
#  ('engagement of b cell receptor', 1.5),
#  ('expression a b cell receptor', 1.5),
#  ('role for b cell receptor', 1.5),
#  ('the igm b cell receptor', 1.5),
#  ('cell through the b cell receptor', 1.5),
#  ('gene encoding the b cell receptor', 1.5),
#  ('of a function b cell receptor', 1.5),
#  ('receptor of the b cell receptor', 1.5),
#  ('downstream of the b cell antigen receptor', 1.5),
#  ('protein', 1.3333333333333333),
#  ('agonist bromocriptine', 1.3333333333333333),
#  ('coa reductase', 1.3333333333333333),
#  ('control region', 1.3333333333333333),
#  ('blood clearance rate', 1.3333333333333333),
#  ('from biochemical recurrence', 1.3333333333333333),
#  ('analysis of biochemical recurrence', 1.3333333333333333),
#  ('bound b cell receptor', 1.3333333333333333),
#  ('features and biochemical recurrence', 1.3333333333333333),
#  ('like b cell receptor', 1.3333333333333333),
#  ('linking b cell receptor', 1.3333333333333333),
#  ('marker of biochemical recurrence', 1.3333333333333333),
#  ('on the biochemical recurrence', 1.3333333333333333),
#  ('psm and biochemical recurrence', 1.3333333333333333),
#  ('response b cell receptor', 1.3333333333333333),
#  ('tcr b cell receptor', 1.3333333333333333),
#  ('using on biochemical recurrence', 1.3333333333333333),
#  ('which b cell receptor', 1.3333333333333333),
#  ('ag specific b cell receptor', 1.3333333333333333),
#  ('and after b cell receptor', 1.3333333333333333),
#  ('constitutive activation b cell receptor', 1.3333333333333333),
#  ('critical for b cell receptor', 1.3333333333333333),
#  ('disease the b cell receptor', 1.3333333333333333),
#  ('independent predictor of biochemical recurrence', 1.3333333333333333),
#  ('mimics the b cell receptor', 1.3333333333333333),
#  ('of patients experience biochemical recurrence', 1.3333333333333333),
#  ('receptor and b cell receptor', 1.3333333333333333),
#  ('regulation in b cell receptor', 1.3333333333333333),
#  ('stimulation the b cell receptor', 1.3333333333333333),
#  ('the surface b cell receptor', 1.3333333333333333),
#  ('tlr7 and b cell receptor', 1.3333333333333333),
#  ('tlr9 and b cell receptor', 1.3333333333333333),
#  ('a high affinity b cell receptor', 1.3333333333333333),
#  ('a self reactive b cell receptor', 1.3333333333333333),
#  ('affinity of the b cell receptor', 1.3333333333333333),
#  ('an increased risk of biochemical recurrence', 1.3333333333333333),
#  ('cell the b cell antigen receptor', 1.3333333333333333),
#  ('expression of the b cell receptor', 1.3333333333333333),
#  ('fusion of the breakpoint cluster region', 1.3333333333333333),
#  ('generation by the b cell receptor', 1.3333333333333333),
#  ('including the b cell antigen receptor', 1.3333333333333333),
#  ('involved in the b cell receptor', 1.3333333333333333),
#  ('pathways including the b cell receptor', 1.3333333333333333),
#  ('tcr and the b cell receptor', 1.3333333333333333),
#  ('the antigen specific b cell receptor', 1.3333333333333333),
#  ('the human b cell antigen receptor', 1.3333333333333333),
#  ('the pre b cell antigen receptor', 1.3333333333333333),
#  ('with the risk of biochemical recurrence', 1.3333333333333333),
#  ('antigen by the b cell antigen receptor', 1.3333333333333333),
#  ('antigen by the b cell specific receptor', 1.3333333333333333),
#  ('by activation of the b cell receptor', 1.3333333333333333),
#  ('cell through the b cell antigen receptor', 1.3333333333333333),
#  ('co receptor of the b cell receptor', 1.3333333333333333),
#  ('expression of a function b cell receptor', 1.3333333333333333),
#  ('the gene encoding the b cell receptor', 1.3333333333333333),
#  ('tyrosine phosphorylation upon b cell antigen receptor', 1.3333333333333333),
#  ('activation by antigen through the b cell receptor', 1.3333333333333333),
#  ('adaptive', 1.0),
#  ('analysis', 1.0),
#  ('igd', 1.0),
#  ('no', 1.0),
#  ('proliferation', 1.0),
#  ('retain', 1.0),
#  ('bzcoa reductase', 1.0),
#  ('cross linking', 1.0),
#  ('membrane receptor', 1.0),
#  ('surface ig', 1.0),
#  ('1 biochemical recurrence', 1.0),
#  ('benzoyl coa reductase', 1.0),
#  ('biochemical complete remission', 1.0),
#  ('breast cancer recurrence', 1.0),
#  ('btb cul3 rbx1', 1.0),
#  ('cluster region gene', 1.0),
#  ('early biochemical recurrence', 1.0),
#  ('ectodermal blastocoel roof', 1.0),
#  ('igm antigen receptor', 1.0),
#  ('of antigen receptor', 1.0),
#  ('reduced biochemical recurrence', 1.0),
#  ('s antigen receptor', 1.0),
#  ('termed biochemical recurrence', 1.0),
#  ('the blastocoel roof', 1.0),
#  ('the bulbocavernosus reflex', 1.0),
#  ('therapy biochemical recurrence', 1.0),
#  ('was biochemical recurrence', 1.0),
#  ('with biochemical relapse', 1.0),
#  ('10 μg ml m4', 1.0),
#  ('2 b cell receptor', 1.0),
#  ('ag receptor of b', 1.0),
#  ('although b cell receptor', 1.0),
#  ('anti b cell receptor', 1.0),
#  ('b cell receptor proliferation', 1.0),
#  ('b cell surface receptor', 1.0),
#  ('b1 b cell receptor', 1.0),
#  ('breakpoint cluster region protein', 1.0),
#  ('by breakpoint cluster region', 1.0),
#  ('characteristics and biochemical recurrence', 1.0),
#  ('chronic b cell receptor', 1.0),
#  ('constitutive b cell receptor', 1.0),
#  ('dependent b cell receptor', 1.0),
#  ('driven b cell receptor', 1.0),
#  ('dual b cell receptor', 1.0),
#  ('during b cell receptor', 1.0),
#  ('e14a3 breakpoint cluster region', 1),
#  ('either b cell receptor', 1.0),
#  ('encoding b cell receptor', 1.0),
#  ('endogenous b cell receptor', 1.0),
#  ('eventually experience biochemical recurrence', 1.0),
#  ('for predict biochemical recurrence', 1.0),
#  ('freedom from biochemical recurrence', 1.0),
#  ('furthermore b cell receptor', 1.0),
#  ('human b cell receptor', 1.0),
#  ('initiated b cell receptor', 1.0),
#  ('interestingly b cell receptor', 1.0),
#  ('is b cell receptor', 1.0),
#  ('it b cell receptor', 1.0),
#  ('kb breakpoint cluster region', 1.0),
#  ('ligation b cell receptor', 1.0),
#  ('limited b cell receptor', 1.0),
#  ('linking to biochemical recurrence', 1.0),
#  ('metastasis and biochemical recurrence', 1.0),
#  ('microenvironment b cell receptor', 1.0),
#  ('patients development biochemical recurrence', 1.0),
#  ('patients experienced biochemical recurrence', 1.0),
#  ('patients with biochemical recurrence', 1.0),
#  ('predict the biochemical recurrence', 1.0),
#  ('promote b cell receptor', 1.0),
#  ('rate of biochemical recurrence', 1.0),
#  ('receptor on b cell', 1.0),
#  ('record balance classification rate', 1.0),
#  ('status and biochemical recurrence', 1.0),
#  ('status with biochemical recurrence', 1.0),
#  ('stimulation b cell receptor', 1.0),
#  ('strong b cell receptor', 1.0),
#  ('subsequent b cell receptor', 1.0),
#  ('survival signaling and glycolysis', 1),
#  ('synergistic b cell receptor', 1.0),
#  ('the bladder cooling reflex', 1.0),
#  ('the blood clearance rate', 1.0),
#  ('the dopamine agonist bromocriptine', 1.0),
#  ('this b cell receptor', 1.0),
#  ('transgenic b cell receptor', 1.0),
#  ('using b cell receptor', 1.0),
#  ('we defined biochemical recurrence', 1),
#  ('weak b cell receptor', 1.0),
#  ('with poor biochemical recurrence', 1.0),
#  ('with the antigen receptor', 1.0),
#  ('1 the b cell receptor', 1.0),
#  ('2 the b cell receptor', 1.0),
#  ('a diverse b cell receptor', 1.0),
#  ('activation after b cell receptor', 1.0),
#  ('activation through b cell receptor', 1.0),
#  ('affinity of b cell receptor', 1.0),
#  ('altered in b cell receptor', 1.0),
#  ('an antibody b cell receptor', 1.0),
#  ('and a brain control region', 1.0),
#  ('and risk of biochemical recurrence', 1.0),
#  ('and with b cell receptor', 1.0),
#  ('antigen induced b cell receptor', 1.0),
#  ('antigen mediated b cell receptor', 1.0),
#  ('apoptosis after b cell receptor', 1.0),
#  ('associated with shorter biochemical recurrence', 1.0),
#  ('b cell b cell receptor', 1.0),
#  ('basis of b cell receptor', 1.0),
#  ('by aberrant b cell receptor', 1.0),
#  ('by b cell ag receptor', 1.0),
#  ('called the b cell receptor', 1.0),
#  ('cell activation b cell receptor', 1.0),
#  ('cell expression b cell receptor', 1.0),
#  ('cell surface b cell receptor', 1.0),
#  ('combined with b cell receptor', 1.0),
#  ('cross linking b cell receptor', 1.0),
#  ('crosslinking of b cell receptor', 1),
#  ('demonstrated that b cell receptor', 1.0),
#  ('dependent on b cell receptor', 1.0),
#  ('during b cell antigen receptor', 1.0),
#  ('dysregulation of b cell receptor', 1.0),
#  ('effector of b cell receptor', 1.0),
#  ('events following b cell receptor', 1.0),
#  ('exhibit reduced b cell receptor', 1.0),
#  ('expression have shorter biochemical recurrence', 1.0),
#  ('expression on the biochemical recurrence', 1.0),
#  ('following by b cell receptor', 1.0),
#  ('for example b cell receptor', 1.0),
#  ('from b cell antigen receptor', 1.0),
#  ('hel specific b cell receptor', 1.0),
#  ('hyper response b cell receptor', 1.0),
#  ('igd b cell antigen receptor', 1.0),
#  ('in a b cell receptor', 1.0),
#  ('in mediated b cell receptor', 1.0),
#  ('in which b cell receptor', 1.0),
#  ('increased following b cell receptor', 1.0),
#  ('induced by b cell receptor', 1.0),
#  ('inhibitors of b cell receptor', 1.0),
#  ('interfering with b cell receptor', 1.0),
#  ('into the b cell receptor', 1.0),
#  ('involved b cell antigen receptor', 1.0),
#  ('is associated with biochemical recurrence', 1.0),
#  ('linking the b cell receptor', 1.0),
#  ('lmp2a block b cell receptor', 1.0),
#  ('lmp2a inhibition b cell receptor', 1.0),
#  ('membrane bound b cell receptor', 1.0),
#  ('microenvironment and b cell receptor', 1.0),
#  ('modulates of b cell receptor', 1.0),
#  ('number of b cell receptor', 1.0),
#  ('of b cell ag receptor', 1.0),
#  ('of b lymphocytes antigen receptor', 1.0),
#  ('of both b cell receptor', 1.0),
#  ('of psm and biochemical recurrence', 1.0),
#  ('of unique b cell receptor', 1.0),
#  ('or b cell antigen receptor', 1.0),
#  ('pathological features and biochemical recurrence', 1.0),
#  ('receptor including b cell receptor', 1.0),
#  ('recognition by b cell receptor', 1.0),
#  ('regulation for b cell receptor', 1.0),
#  ('show that b cell receptor', 1.0),
#  ('shown that b cell receptor', 1.0),
#  ('signaling through b cell receptor', 1.0),
#  ('signaling via b cell receptor', 1.0),
#  ('statin using on biochemical recurrence', 1.0),
#  ('stimulation of b cell receptor', 1.0),
#  ('studies the b cell receptor', 1.0),
#  ('suggest that b cell receptor', 1.0),
#  ('survival analysis of biochemical recurrence', 1.0),
#  ('target of b cell receptor', 1.0),
#  ('that inhibition b cell receptor', 1.0),
#  ('the b lymphocytes antigen receptor', 1.0),
#  ('the predict of biochemical recurrence', 1.0),
#  ('the time to biochemical recurrence', 1.0),
#  ('to enhanced b cell receptor', 1.0),
#  ('to the breakpoint cluster region', 1.0),
#  ('tolerance through b cell receptor', 1.0),
#  ('unique b cell antigen receptor', 1.0),
#  ('was associated with biochemical recurrence', 1.0),
#  ('whereas b cell ag receptor', 1.0),
#  ('which the b cell receptor', 1.0),
#  ('while b cell antigen receptor', 1.0),
#  ('20 of patients experience biochemical recurrence', 1.0),
#  ('a predict factor for biochemical recurrence', 1.0),
#  ('aberrant inhibition of b cell receptor', 1),
#  ('activation by b cell antigen receptor', 1.0),
#  ('activation via the b cell receptor', 1.0),
#  ('agents that target b cell receptor', 1.0),
#  ('although the b cell antigen receptor', 1),
#  ('an independent predictor of biochemical recurrence', 1.0),
#  ('and b cell receptor for antigen', 1.0),
#  ('antigen binding to b cell receptor', 1),
#  ('antigen specific b cell antigen receptor', 1.0),
#  ('antigen via their b cell receptor', 1.0),
#  ('antigen with the b cell receptor', 1.0),
#  ('apoptosis induced by b cell receptor', 1),
#  ('autoimmune disease the b cell receptor', 1.0),
#  ('b cell including b cell receptor', 1.0),
#  ('before and after b cell receptor', 1.0),
#  ('bound to the b cell receptor', 1.0),
#  ('cell via the b cell receptor', 1.0),
#  ('cluster of b cell antigen receptor', 1.0),
#  ('cluster of the b cell receptor', 1.0),
#  ('coligation to the b cell receptor', 1.0),
#  ('commitment to such b cell receptor', 1.0),
#  ('constitutive activation of b cell receptor', 1.0),
#  ('cross linking of b cell receptor', 1.0),
#  ('demonstrated that the b cell receptor', 1.0),
#  ('dependent on b cell antigen receptor', 1.0),
#  ('during prolonged stimulation b cell receptor', 1),
#  ('early events of b cell receptor', 1.0),
#  ('emanating from the b cell receptor', 1.0),
#  ('expression of a b cell receptor', 1.0),
#  ('features of the b cell receptor', 1.0),
#  ('following antigen recognition b cell receptor', 1),
#  ('for the b cell antigen receptor', 1.0),
#  ('function as a b cell receptor', 1.0),
#  ('function the b cell antigen receptor', 1.0),
#  ('how the b cell antigen receptor', 1),
#  ('ibrutinib and idelalisib b cell receptor', 1),
#  ('important for b cell antigen receptor', 1.0),
#  ('in which b cell antigen receptor', 1.0),
#  ('increased the risk of biochemical recurrence', 1.0),
#  ('incubated with rabbit anti igd pab', 1.0),
#  ('induced by the b cell receptor', 1.0),
#  ('interactions with the b cell receptor', 1.0),
#  ('intrinsic and b cell antigen receptor', 1),
#  ('introduction the b cell antigen receptor', 1.0),
#  ('investigate of the b cell receptor', 1),
#  ('is critical for b cell receptor', 1.0),
#  ('is the b cell antigen receptor', 1.0),
#  ('kinase in the b cell receptor', 1.0),
#  ('kinase involved in b cell receptor', 1.0),
#  ('known as the b cell receptor', 1.0),
#  ('levels of b cell antigen receptor', 1.0),
#  ('linking to the b cell receptor', 1.0),
#  ('microenvironment through the b cell receptor', 1.0),
#  ('modulates of the b cell receptor', 1.0),
#  ('more recently novel b cell receptor', 1),
#  ('notch2 and b cell antigen receptor', 1),
#  ('of cd40 and b cell receptor', 1.0),
#  ('of the ige b cell receptor', 1.0),
#  ('on the b cell antigen receptor', 1.0),
#  ('or the b cell antigen receptor', 1.0),
#  ('originating from the b cell receptor', 1.0),
#  ('overall survival a f biochemical recurrence', 1.0),
#  ('parallel studies using b cell receptor', 1),
#  ('participates in b cell antigen receptor', 1.0),
#  ('polyreactive and autoreactive b cell receptor', 1.0),
#  ('positive surgical margin psm biochemical recurrence', 1.0),
#  ('prolonged or uncontrolled b cell receptor', 1),
#  ('protein in b cell antigen receptor', 1.0),
#  ('receptor such as b cell receptor', 1.0),
#  ('regulation by the b cell receptor', 1.0),
#  ('related to the b cell receptor', 1.0),
#  ('role in b cell ag receptor', 1.0),
#  ('sequencing of the b cell receptor', 1.0),
#  ('serve as the b cell receptor', 1.0),
#  ('show that b cell antigen receptor', 1.0),
#  ('suggest that the b cell receptor', 1.0),
#  ('surface expression b cell antigen receptor', 1.0),
#  ('t cell the b cell receptor', 1.0),
#  ('target the b cell antigen receptor', 1.0),
#  ('that stimulation the b cell receptor', 1.0),
#  ('that target the b cell receptor', 1.0),
#  ('that the b cell antigen receptor', 1.0),
#  ('the activation of b cell receptor', 1.0),
#  ('the ag specific b cell receptor', 1),
#  ('the antigen dependent b cell receptor', 1),
#  ('the constitutive activation b cell receptor', 1.0),
#  ('the effect of b cell receptor', 1.0),
#  ('the important of b cell receptor', 1.0),
#  ('the initiated of b cell receptor', 1.0),
#  ('the latency of the bulbocavernosus reflex', 1),
#  ('the mechanisms of b cell receptor', 1.0),
#  ('the regulation of b cell receptor', 1.0),
#  ('their antigen specific b cell receptor', 1.0),
#  ('this report evaluate whether biochemical recurrence', 1),
#  ('those of the b cell receptor', 1.0),
#  ('through the b cell ag receptor', 1.0),
#  ('through their b cell antigen receptor', 1.0),
#  ('tlr7 tlr9 and b cell receptor', 1.0),
#  ('to activation the b cell receptor', 1.0),
#  ('to analyses the b cell receptor', 1.0),
#  ('up regulation in b cell receptor', 1.0),
#  ('upregulated of the b cell receptor', 1.0),
#  ('using chronic activation b cell receptor', 1.0),
#  ('via their b cell antigen receptor', 1.0),
#  ('which mimics the b cell receptor', 1.0),
#  ('with the b cell ag receptor', 1.0),
#  ('within the b cell antigen receptor', 1.0),
#  ('a kaplan meier curves of biochemical recurrence', 1.0),
#  ('a negative regulation of b cell receptor', 1.0),
#  ('aberrant activation of the b cell receptor', 1),
#  ('an independent prognostic marker of biochemical recurrence', 1.0),
#  ('antigen activation of the b cell receptor', 1),
#  ('antigen engagement of the b cell receptor', 1.0),
#  ('antigen receptor the b cell antigen receptor', 1.0),
#  ('antigen recognition by the b cell receptor', 1.0),
#  ('antigen that binding b cell antigen receptor', 1),
#  ('as well as the b cell receptor', 1.0),
#  ('associated with the risk of biochemical recurrence', 1.0),
#  ('b cell activation through b cell receptor', 1),
#  ('b cell is the b cell receptor', 1.0),
#  ('b cell the b cell antigen receptor', 1.0),
#  ('by engagement of the b cell receptor', 1.0),
#  ('by ligation of the b cell receptor', 1.0),
#  ('calcineurin is required for b cell receptor', 1),
#  ('cell engagement of the b cell receptor', 1.0),
#  ('cluster of the b cell antigen receptor', 1.0),
#  ('co ligation of the b cell receptor', 1.0),
#  ('co receptor for b cell antigen receptor', 1.0),
#  ('cross linking the b cell ag receptor', 1),
#  ('during the initiated of b cell receptor', 1),
#  ('engagement of the b cell ag receptor', 1),
#  ('engagement of the b cell receptor antigen', 1),
#  ('enzyme in the b cell antigen receptor', 1.0),
#  ('expression a high affinity b cell receptor', 1.0),
#  ('following the binding of b cell receptor', 1),
#  ('in b cell b cell antigen receptor', 1),
#  ('in negative regulation of b cell receptor', 1.0),
#  ('in response to b cell ag receptor', 1.0),
#  ('kinase inhibitors target the b cell receptor', 1),
#  ('ligation of the b cell ag receptor', 1.0),
#  ('nf kappab activation through b cell receptor', 1),
#  ('of a self reactive b cell receptor', 1.0),
#  ('of antigen by the b cell receptor', 1.0),
#  ('of the b cell receptor for antigen', 1.0),
#  ('of the human b cell antigen receptor', 1.0),
#  ('pathways downstream of the b cell receptor', 1.0),
#  ('physically associated with the b cell receptor', 1.0),
#  ('protein involved in the b cell receptor', 1.0),
#  ('receptor including the b cell antigen receptor', 1.0),
#  ('recombination antibody represent the b cell receptor', 1.0),
#  ('role of the b cell antigen receptor', 1.0),
#  ('several components of the b cell receptor', 1.0),
#  ('several features of the b cell receptor', 1),
#  ('signaling emanating from the b cell receptor', 1),
#  ('signaling generation by the b cell receptor', 1.0),
#  ('signaling pathways including the b cell receptor', 1.0),
#  ('signaling through the b cell ag receptor', 1),
#  ('signaling via the b cell antigen receptor', 1.0),
#  ('stimulation via the b cell antigen receptor', 1.0),
#  ('surface expression of the b cell receptor', 1.0),
#  ('sustained engagement of the b cell receptor', 1),
#  ('synergistic engagement of the b cell receptor', 1),
#  ('t cell receptor and b cell receptor', 1.0),
#  ('t cell receptor tcr b cell receptor', 1.0),
#  ('that signaling through the b cell receptor', 1.0),
#  ('that stimulation of the b cell receptor', 1.0),
#  ('the aberrant regulation of b cell receptor', 1),
#  ('the activation of the b cell receptor', 1),
#  ('the associated between pni and biochemical recurrence', 1.0),
#  ('the clinical successful of b cell receptor', 1),
#  ('the cross linking of b cell receptor', 1),
#  ('the effect of the dopamine agonist bromocriptine', 1),
#  ('the identification of biomarkers of biochemical recurrence', 1),
#  ('the molecular basis of b cell receptor', 1),
#  ('the repertoire of b cell antigen receptor', 1),
#  ('the structure of the breakpoint cluster region', 1.0),
#  ('the tcr and b cell antigen receptor', 1.0),
#  ('through the antigen specific b cell receptor', 1.0),
#  ('tightly control of b cell antigen receptor', 1),
#  ('to microenvironmental stimuli via b cell receptor', 1.0),
#  ('triggered of the b cell antigen receptor', 1.0),
#  ('we previously show that b cell receptor', 1),
#  ('which signaling through the b cell receptor', 1.0),
#  ('wild type wt and b cell receptor', 1.0),
#  ('a clonal rearrangement antigen specific b cell receptor', 1.0),
#  ('an intact and function b cell antigen receptor', 1),
#  ('and signaling through the b cell antigen receptor', 1.0),
#  ('antigen epitopes specific recognition by b cell receptor', 1),
#  ('antigen mediated cluster of b cell antigen receptor', 1),
#  ('antigen stimulation through the b cell antigen receptor', 1.0),
#  ('b 1 cell response to b cell receptor', 1.0),
#  ('b cell activation via the b cell receptor', 1),
#  ('b cell expression both clonal rearrangement antigen receptor', 1),
#  ('b cell signaling through the b cell receptor', 1.0),
#  ('be taken up by the b cell receptor', 1.0),
#  ('cd22 a regulation of the b cell receptor', 1),
#  ('characterized by activation of the b cell receptor', 1.0),
#  ('co ligation of the b cell antigen receptor', 1.0),
#  ('cross linking of the b cell ag receptor', 1.0),
#  ('diverse cellular signaling events including b cell receptor', 1),
#  ('dual toll like receptor tlr b cell receptor', 1.0),
#  ('given that 55 75 of b cell receptor', 1),
#  ('in contrast to other b cell antigen receptor', 1),
#  ('in normal b cell b cell antigen receptor', 1),
#  ('inhibitory co receptor of the b cell receptor', 1.0),
#  ('integrin mediated adhesion and b cell antigen receptor', 1),
#  ('interleukin 21 il 21 and b cell receptor', 1.0),
#  ('is tyrosine phosphorylation upon b cell antigen receptor', 1.0),
#  ('microenvironment mediated upregulated of the b cell receptor', 1),
#  ('non competitive nmdar antagonists impaired b cell receptor', 1),
#  ('of negative regulation of b cell antigen receptor', 1.0),
#  ('of pd 1 with the b cell receptor', 1.0),
#  ('of the role of the b cell receptor', 1.0),
#  ('on the affinity of the b cell receptor', 1.0),
#  ('previously we have shown that b cell receptor', 1),
#  ('regulation signaling through the b cell antigen receptor', 1.0),
#  ('rp have an overall risk of biochemical recurrence', 1.0),
#  ('sequential engagement of the b cell antigen receptor', 1.0),
#  ('signaling process through the b cell antigen receptor', 1),
#  ('signaling transduced through the b cell ag receptor', 1),
#  ('signaling transduction initiated by b cell ag receptor', 1),
#  ('stimulation of b lymphocytes through their antigen receptor', 1),
#  ('the antigen binding to the b cell receptor', 1),
#  ('the antigen mediated triggered of b cell receptor', 1),
#  ('the engagement of the b cell antigen receptor', 1),
#  ('the expression of a function b cell receptor', 1.0),
#  ('the function relevant of the b cell receptor', 1.0),
#  ('the impact of statin using on biochemical recurrence', 1),
#  ('the journey from a germline b cell receptor', 1),
#  ('the strength and duration of b cell receptor', 1),
#  ('to investigate the mechanisms of b cell receptor', 1),
#  ('to revealed a predict factor for biochemical recurrence', 1),
#  ('toll like receptor tlr and b cell receptor', 1.0),
#  ('upon ligation with antigen b cell antigen receptor', 1),
#  ('antigen stimulation of the cell surface b cell receptor', 1),
#  ('approximately 15 to 20 of patients experience biochemical recurrence', 1),
#  ('b cell have high affinity to b cell receptor', 1),
#  ('b cell sense microenvironment through the b cell receptor', 1),
#  ('b cell signaling through both the b cell receptor', 1),
#  ('b cell signaling through the b cell antigen receptor', 1.0),
#  ('b cell stimulation of the b cell antigen receptor', 1.0),
#  ('bcl6 represses several components of the b cell receptor', 1),
#  ('both t cell receptor tcr and b cell receptor', 1),
#  ('by antigen binding to the b cell antigen receptor', 1.0),
#  ('cd19 is rapidly phosphorylation upon b cell antigen receptor', 1),
#  ('cd20 function couples with the b cell antigen receptor', 1),
#  ('cd5 is a negative regulation of b cell receptor', 1),
#  ('certain malignant b cell rely on b cell receptor', 1),
#  ('characteristics of 394 prostate cancer cases by biochemical recurrence',
#   1.0),
#  ('chronic or recurrence stimulation of the b cell receptor', 1),
#  ('co ligation of cr2 with the b cell receptor', 1.0),
#  ('different in the quality of b cell antigen receptor', 1),
#  ('gene signatures indicate activation of the b cell receptor', 1.0),
#  ('immune receptor such as the b cell antigen receptor', 1.0),
#  ('immunoglobulin ig α and igβ initiated b cell receptor', 1),
#  ('in the absence of costimulating signaling b cell receptor', 1),
#  ('inhibitory effect of hm71224 on b cell antigen receptor', 1.0),
#  ('is a key node in the b cell receptor', 1.0),
#  ('is associated with an increased risk of biochemical recurrence', 1.0),
#  ('it is become increased evidence that b cell receptor', 1),
#  ('leads to the fusion of the breakpoint cluster region', 1.0),
#  ('most pretreatment risk assessed model to predict biochemical recurrence',
#   1),
#  ('peripheral b lymphocytes survival required the b cell receptor', 1),
#  ('plcgamma2 plays a critical role in b cell receptor', 1),
#  ('rearrangement of the gene encoding the b cell receptor', 1.0),
#  ('recognition of antigen by the b cell antigen receptor', 1.0),
#  ('shc protein is tyrosine phosphorylation upon b cell receptor', 1),
#  ('signaling by ag to the b cell ag receptor', 1),
#  ('signaling transduced elements of the b cell antigen receptor', 1.0),
#  ('signaling transduction through the constitutive activation b cell receptor',
#   1),
#  ('stimulation of the tcr and b cell antigen receptor', 1),
#  ('the associated of the gene signatures with biochemical recurrence', 1),
#  ('the cross linking of the b cell ag receptor', 1),
#  ('the related role of btk dependent b cell receptor', 1),
#  ('the surface expression of the b cell antigen receptor', 1.0),
#  ('to segregate the many contribute that b cell receptor', 1),
#  ('toll like receptor 7 tlr7 and b cell receptor', 1.0),
#  ('we evaluate the prognosis of patients with biochemical recurrence', 1),
#  ('accumulate evidence support the critical role of b cell receptor', 1),
#  ('among the various signaling from the microenvironment b cell receptor', 1),
#  ('antigen recognition by b cell through the b cell receptor', 1),
#  ('b cell activation is regulation by b cell antigen receptor', 1),
#  ('bruton s tyrosine kinase btk regulation the b cell receptor', 1),
#  ('bruton tyrosine kinase btk linking the b cell antigen receptor', 1),
#  ('btk is a critical molecules in b cell antigen receptor', 1),
#  ('cross linking of surface igm or igd b cell receptor', 1),
#  ('early events of b cell activation after b cell receptor', 1),
#  ('few studies have investigate predict risk factor of biochemical recurrence',
#   1),
#  ('in b lymphocytes signaling through the b cell antigen receptor', 1),
#  ('in the dt40 b cell lines b cell antigen receptor', 1),
#  ('initiated by ag binding to the b cell ag receptor', 1.0),
#  ('lmp2a is a function homology of the b cell receptor', 1),
#  ('lymphocytes antigen receptor such as the b cell antigen receptor', 1),
#  ('methylation marked routine clinicopathological parameters erg status and biochemical recurrence',
#   1),
#  ('normal b lymphocytes received signaling from b cell antigen receptor', 1),
#  ('obesity is associated with an increased risk of biochemical recurrence', 1),
#  ('ostic factor and immunoprofile the clinicopathological features including biochemical recurrence',
#   1),
#  ('phosphoinositide 3 kinase pi3k is a central b cell receptor', 1),
#  ('positive and negative signaling derived from the b cell receptor', 1),
#  ('preoperative predict the probability of prostate cancer pca biochemical recurrence',
#   1),
#  ('recognition of an antigen by the b cell specific receptor', 1.0),
#  ('small molecules drug that target the b cell antigen receptor', 1),
#  ('somatic assembly of t cell receptor and b cell receptor', 1),
#  ('stimulation of b cell through the b cell antigen receptor', 1.0),
#  ('the inhibitory coreceptor cd22 and cd72 downmodulate b cell receptor', 1),
#  ('the initiated components for signaling by b cell antigen receptor', 1),
#  ('the protein tyrosine kinase syk couples the b cell receptor', 1),
#  ('the t cell receptor tcr and the b cell receptor', 1.0),
#  ('to dissect intracellular pathways involved in b cell ag receptor', 1),
#  ('to evaluate the temporal relationship between intervals to biochemical recurrence',
#   1),
#  ('to identified changes in the regulation of b cell receptor', 1),
#  ('triggered by binding of antigen to the b cell receptor', 1.0),
#  ('we have previously shown that the b cell ag receptor', 1),
#  ('we recently found that stimulation of the b cell receptor', 1),
#  ('when b lymphocytes encounter antigen bearing surface b cell receptor', 1),
#  ('activation of akt by multiple stimuli including b cell antigen receptor',
#   1),
#  ('asians potential associated between gst polymorphisms and prostate cancer biochemical recurrence',
#   1),
#  ('asion lymph node metastasis angiolymphatic invasion higher gleason score biochemical recurrence',
#   1),
#  ('b cell are activation by antigen through the b cell receptor', 1.0),
#  ('b cell detected foreign antigen through their b cell antigen receptor', 1),
#  ('b lymphocytes binding antigen via a membrane bound b cell receptor', 1),
#  ('compared to naïve b cell nbcs both b cell antigen receptor', 1),
#  ('desensitization signaling transduction tyrosine phosphorylation 1 summary b cell antigen receptor',
#   1),
#  ('during b lymphoid ontogeny assembly of the pre b cell receptor', 1),
#  ('elationship between postoperative prostate specific antigen psa levels and biochemical recurrence',
#   1),
#  ('february 2009 were assessed multivariate cox regression model predict biochemical recurrence',
#   1),
#  ('hether lvi was associated with either clinicopathological characteristics or biochemical recurrence',
#   1),
#  ('high 5hmc immunoreactivity was significant associated with post operates biochemical recurrence',
#   1),
#  ('in b cell antigen driving the formation of b cell receptor', 1),
#  ('in b cell antigen stimulation of the b cell antigen receptor', 1),
#  ('in b lymphocytes antigen mediated stimulation of the b cell receptor', 1),
#  ('in mammalian b lymphocytes engagement of the b cell antigen receptor', 1),
#  ('in the cases of b lymphocytes the b cell antigen receptor', 1),
#  ('in the xenopus gastrula mesoderm translocation across the ectodermal blastocoel roof',
#   1),
#  ('interactions of cll cell occurs via the surface b cell receptor', 1.0),
#  ('it is now clear that signaling through the b cell receptor', 1),
#  ('lmp 1 and lmp 2a mimics cd40 and b cell receptor', 1),
#  ('low meis2 transcription expression was significant associated with poor biochemical recurrence',
#   1),
#  ('mantle cell lymphoma mcl is characterized by increased b cell receptor', 1),
#  ('mature b cell are constantly instructed by the b cell receptor', 1),
#  ('mediated by microenvironmental elements interestingly macitentan interferes with b cell receptor',
#   1),
#  ('mined whether lvi is associated with clinicopathological characteristics and biochemical recurrence',
#   1),
#  ('ncer patients population however approximately 20 of patients experience biochemical recurrence',
#   1),
#  ('ndrome mets obesity hypertension diabetes mellitus and dyslipidemia on biochemical recurrence',
#   1),
#  ('ng ml we retrospectively compared clinico pathological characteristics and biochemical recurrence',
#   1),
#  ('o rp would eventually need addition treatment certain postoperative biochemical recurrence',
#   1),
#  ('pathogenesis of chronic lymphocytes leukaemia cll is contingent upon antigen receptor',
#   1),
#  ('positive surgical margin psm has classical been associated with biochemical recurrence',
#   1),
#  ('rmal adjacent prostate epithelium were significant associated with shorter biochemical recurrence',
#   1),
#  ('scnp was using to quantify modulates signaling of b cell receptor', 1),
#  ('signaling through a variety of antigen receptor including b cell receptor',
#   1),
#  ('significant proportion of patients undergo salvage radiotherapy rt for biochemical recurrence',
#   1),
#  ('static adenocarcinoma pca morphologies to determine their associated with biochemical recurrence',
#   1),
#  ('syk is a protein tyrosine kinase that couples b cell receptor', 1),
#  ('the aim of this studies was to evaluate the biochemical recurrence', 1),
#  ('the associated of dclk1 expression with clinicopathological parameters and biochemical recurrence',
#   1),
#  ('the associated of survivin expression with clinicopathological features and biochemical recurrence',
#   1),
#  ('the balance translocation of 5 segment of the breakpoint cluster region',
#   1),
#  ('the critical role of the tissue microenvironment and b cell receptor', 1),
#  ('the degree of chronic lymphocytes leukemia cll b cell antigen receptor', 1),
#  ('the key receptor in b cell is the b cell receptor', 1),
#  ('to comprehensive analyzed the gene involved in b cell antigen receptor', 1),
#  ('to demonstrated the feasibility of intraoperative monitoring of the bulbocavernosus reflex',
#   1),
#  ('to investigate the effect of postoperative statin using on biochemical recurrence',
#   1),
#  ('tyrosine kinase inhibitors tkis target signaling molecules downstream b cell receptor',
#   1),
#  ('tyrosine phosphorylation of shc in response to b cell ag receptor', 1),
#  ('unfortunately approximately 30 of prostate cancer patients will suffer biochemical recurrence',
#   1),
#  ('we explore the role of antigen valency in b cell receptor', 1),
#  ('about one third of patients undergo radical prostatectomy will experience biochemical recurrence',
#   1),
#  ('activation dependent manner stk38 kinase inactivation abrogates apoptosis following b cell receptor',
#   1),
#  ('alized prostate cancer is curative nevertheless many patients suffer from biochemical recurrence',
#   1),
#  ('although b cell development required expression of the b cell antigen receptor',
#   1),
#  ('an overview of repertoire sequencing data production the b cell immunoglobulin receptor',
#   1.0),
#  ('antigen receptor the t cell receptor tcr or the b cell receptor', 1),
#  ('apoptosis induced by the cross linking of the b cell antigen receptor',
#   1.0),
#  ('apoptosis of b cell upon ligation of the b cell antigen receptor', 1),
#  ('apoptotic cell death induced through activation of the b cell antigen receptor',
#   1),
#  ('autoimmune disease their survival dependent upon tonic signaling transduced by surface immunoglobulin',
#   1),
#  ('b cell integral antigen specific signaling transduced via the b cell receptor',
#   1),
#  ('bank1 acts as an important adaptor molecular to linking b cell receptor',
#   1),
#  ('characterized by impaired signaling and activation following aggregation of their antigen receptor',
#   1),
#  ('co receptor on the b cell surface regulation b cell antigen receptor', 1),
#  ('cteristics and treatment outcome were collected from their medical record biochemical recurrence',
#   1),
#  ('d pc specific mortality pcsm primary outcome secondary outcome including biochemical recurrence',
#   1),
#  ...]

# %%
top[14]
# Out:
# ('b cell ag receptor', 35.2)

# %%
longforms0 = miners['BCR'].get_longforms()

# %%
longforms0
# Out:
# [('b cell receptor', 1532.3416041546452),
#  ('biochemical recurrence', 277.2733333333333),
#  ('breakpoint cluster region', 25.515151515151516),
#  ('rate', 5.25),
#  ('receptor complex', 5.090909090909091),
#  ('biochemical relapse', 4.666666666666667),
#  ('bulbocavernosus reflex', 4.285714285714286),
#  ('b cell receptor for antigen', 4.25),
#  ('benefit cost ratio', 4.0),
#  ('reductase', 3.6666666666666665),
#  ('b cell', 3.6),
#  ('blastocoel roof', 3.2),
#  ('igm', 3.0),
#  ('bromocriptine', 2.8),
#  ('b cell receptor signaling', 2.0),
#  ('from a rag2 deficient pro b cell lines were retrovirally transduced with μhc b1 8 hc or μhc + λlc',
#   2),
#  ('protein', 1.3333333333333333)]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0, 1, 2, 5, 6, 7, 8, 10, 11, 12, 13, 14]]

# %%
longforms0
# Out:
# [('b cell receptor', 1532.3416041546452),
#  ('biochemical recurrence', 277.2733333333333),
#  ('breakpoint cluster region', 25.515151515151516),
#  ('biochemical relapse', 4.666666666666667),
#  ('bulbocavernosus reflex', 4.285714285714286),
#  ('b cell receptor for antigen', 4.25),
#  ('benefit cost ratio', 4.0),
#  ('b cell', 3.6),
#  ('blastocoel roof', 3.2),
#  ('igm', 3.0),
#  ('bromocriptine', 2.8),
#  ('b cell receptor signaling', 2.0)]

# %%
longforms0.extend([x for i, x in enumerate(top) if i in [3, 14, ]])

# %%
longforms0
# Out:
# [('b cell receptor', 1532.3416041546452),
#  ('biochemical recurrence', 277.2733333333333),
#  ('breakpoint cluster region', 25.515151515151516),
#  ('biochemical relapse', 4.666666666666667),
#  ('bulbocavernosus reflex', 4.285714285714286),
#  ('b cell receptor for antigen', 4.25),
#  ('benefit cost ratio', 4.0),
#  ('b cell', 3.6),
#  ('blastocoel roof', 3.2),
#  ('igm', 3.0),
#  ('bromocriptine', 2.8),
#  ('b cell receptor signaling', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('b cell receptor',
#  'biochemical recurrence',
#  'breakpoint cluster region',
#  'biochemical relapse',
#  'bulbocavernosus reflex',
#  'b cell receptor for antigen',
#  'benefit cost ratio',
#  'b cell',
#  'blastocoel roof',
#  'igm',
#  'bromocriptine',
#  'b cell receptor signaling')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'b cell': 'MESH:D011947',
#  'b cell receptor': 'MESH:D011947',
#  'b cell receptor for antigen': 'MESH:D011947',
#  'b cell receptor signaling': 'MESH:D011947',
#  'benefit cost ratio': 'ungrounded',
#  'biochemical recurrence': 'ungrounded',
#  'biochemical relapse': 'ungrounded',
#  'blastocoel roof': 'ungrounded',
#  'breakpoint cluster region': 'HGNC:1014',
#  'bromocriptine': 'CHEBI:CHEBI:3181',
#  'bulbocavernosus reflex': 'ungrounded',
#  'igm': 'MESH:D011947'}

# %%
names
# Out:
# {'MESH:D011947': 'Receptors, Antigen, B-Cell',
#  'HGNC:1014': 'BCR',
#  'CHEBI:CHEBI:3181': 'bromocriptine'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names.update({f'HGNC:{get_hgnc_id(gene)}': gene for gene in genes})
pos_labels = list(set(pos_labels) | set(f'HGNC:{get_hgnc_id(gene)}' for gene in genes))

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'b cell': 'MESH:D011947',
#   'b cell receptor': 'MESH:D011947',
#   'b cell receptor for antigen': 'MESH:D011947',
#   'b cell receptor signaling': 'MESH:D011947',
#   'benefit cost ratio': 'ungrounded',
#   'biochemical recurrence': 'ungrounded',
#   'biochemical relapse': 'ungrounded',
#   'blastocoel roof': 'ungrounded',
#   'breakpoint cluster region': 'HGNC:1014',
#   'bromocriptine': 'CHEBI:CHEBI:3181',
#   'bulbocavernosus reflex': 'ungrounded',
#   'igm': 'MESH:D011947'},
#  {'MESH:D011947': 'Receptors, Antigen, B-Cell',
#   'HGNC:1014': 'BCR',
#   'CHEBI:CHEBI:3181': 'bromocriptine'},
#  ['CHEBI:CHEBI:3181', 'HGNC:1014', 'MESH:D011947'])

# %%
grounding_map, names, pos_labels = ({'b cell': 'MESH:D011947',
  'b cell receptor': 'MESH:D011947',
  'b cell receptor for antigen': 'MESH:D011947',
  'b cell receptor signaling': 'MESH:D011947',
  'benefit cost ratio': 'ungrounded',
  'biochemical recurrence': 'ungrounded',
  'biochemical relapse': 'ungrounded',
  'blastocoel roof': 'ungrounded',
  'breakpoint cluster region': 'HGNC:1014',
  'bromocriptine': 'CHEBI:CHEBI:3181',
  'bulbocavernosus reflex': 'ungrounded',
  'igm': 'MESH:D011947'},
 {'MESH:D011947': 'Receptors, Antigen, B-Cell',
  'HGNC:1014': 'BCR',
  'CHEBI:CHEBI:3181': 'bromocriptine'},
 ['CHEBI:CHEBI:3181', 'HGNC:1014', 'MESH:D011947'])

# %%
grounding_dict = {'BCR': grounding_map}

# %%
classifier = AdeftClassifier('BCR', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-13 10:58:17] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-13 10:59:01] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9751167595458782 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D011947': 1442,
#   'ungrounded': 211,
#   'HGNC:1014': 415,
#   'CHEBI:CHEBI:3181': 4},
#  'f1': {'mean': 0.9751167595458782, 'std': 0.007950771506375473},
#  'precision': {'mean': 0.9737699556189972, 'std': 0.008757750168350295},
#  'recall': {'mean': 0.9769032789548782, 'std': 0.0068867432080245445}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC']

# %%
len(a)
# Out:
# 539

# %%
a[0]
# Out:
# 'The development of drug resistance in ALL cells as occurs  in vivo  can be modeled by coculture of ALL cells in the presence of irradiated stromal cells during drug exposure. We have shown previously that this allows for the outgrowth of drug-insensitive leukemic cells (e.g. Zhang  et al 5 ), in a process that has been named environmental-mediated drug resistance. Microarray analysis on precursor B-lineage (pre-B) ALL cells from a  BCR/ABL  transgenic mouse model for Ph-positive ALL undergoing environmental-mediated drug resistance showed significantly increased expression of mRNAs related to stress and inflammation. 6  Among others, we found that transcript levels of the  Galectin-3  gene ( Lgals3 ) were significantly increased upon development of resistance to the Bcr/Abl-targeted tyrosine kinase inhibitor nilotinib, and this was also seen in pre-B ALL cells isolated from the BM of  BCR/ABL  transgenic mice that had been treated with nilotinib for 8 days. 6\n'

# %%
disamb.dump('LAK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('../results/light_kinase_scores_improved.csv', sep=',')
df2 = pd.read_csv('../results/light_kinase_scores_improved2.csv', sep=',')

# %%
df = pd.concat([df1, df2])

# %%
df[(df.gene_name == 'CSNK1A1') & (df.num_stmts == 3) & (df.num_entrez == 135)]
# Out:
#      gene_name              agent_text  num_stmts  num_entrez  CI_lower  \
# 9313   CSNK1A1           GSK-3 and CK1          3         135  0.000000
# 9334   CSNK1A1          CK1α and GSK3β          3         135  0.399942
# 9351   CSNK1A1  GSK3β, CK1α and Dyrk1A          3         135  0.000000
# 9429   CSNK1A1           GRK2 and CK1α          3         135  0.000000
#
#       CI_upper  adeft_lower  adeft_upper  theta_lower  theta_upper
# 9313       1.0          0.0          1.0     0.480360     0.519640
# 9334       1.0          0.0          1.0     0.924739     0.939923
# 9351       1.0          0.0          1.0     0.000000     1.000000
# 9429       1.0          0.0          1.0     0.000000     1.000000
