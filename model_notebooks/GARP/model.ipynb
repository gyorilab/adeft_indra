# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['GARP']
genes = ['LRRC32', 'CNGB1']
families = {'GARP': ['VSP51', 'VSP52', 'VSP53', 'VSP54']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['GARP'].top()

# %%
top
# Out:
# [('glycoprotein a repetitions predominant', 40.95348837209302),
#  ('the golgi associated retrograde protein', 22.5),
#  ('protein', 22.0),
#  ('golgi associated retrograde protein', 12.242424242424242),
#  ('a repetitions predominant', 8.979591836734691),
#  ('glycoprotein a repetitions predominant protein', 6.0),
#  ('recently glycoprotein a repetitions predominant', 6.0),
#  ('of the golgi associated retrograde protein', 5.5),
#  ('glycophorin a repetitions predominant', 3.6),
#  ('receptor glycoprotein a repetitions predominant', 3.0),
#  ('rich protein', 2.6666666666666665),
#  ('glutamic acid alanine rich protein', 2.0),
#  ('protein glycoprotein a repetitions predominant', 2.0),
#  ('component of the golgi associated retrograde protein', 2.0),
#  ('subunits of the golgi associated retrograde protein', 2.0),
#  ('tgfβ docking receptor glycoprotein a repetitions predominant', 2.0),
#  ('alanine rich protein', 1.5),
#  ('docking receptor glycoprotein a repetitions predominant', 1.5),
#  ('glutamic acid rich protein', 1.0),
#  ('and glycoprotein a repetitions predominant', 1.0),
#  ('gzmb glycoprotein a repetitions predominant', 1.0),
#  ('of glycoprotein a repetitions predominant', 1.0),
#  ('the glycoprotein a repetitions predominant', 1.0),
#  ('by the golgi associated retrograde protein', 1.0),
#  ('complex the golgi associated retrograde protein', 1.0),
#  ('genetic algorithm for rule set prediction', 1.0),
#  ('known as glycoprotein a repetitions predominant', 1.0),
#  ('recently the glycoprotein a repetitions predominant protein', 1),
#  ('function characterization of the golgi associated retrograde protein', 1),
#  ('heterotetrameric tethering factor named golgi associated retrograde protein',
#   1.0),
#  ('latency associated peptide lap and glycophorin a repetitions predominant',
#   1.0),
#  ('migration differentiation and immunomodulation recently glycoprotein a repetitions predominant',
#   1),
#  ('fter sufficient function activation 10 more recently glycoprotein a repetitions predominant',
#   1),
#  ('in migration differentiation and immunomodulation of mscs glycoprotein a repetitions predominant',
#   1),
#  ('integrin proteases and thrombospondin 1 14 recently glycoprotein a repetitions predominant',
#   1),
#  ('regulatory t cells treg phenotypically and function glycoprotein a repetitions predominant',
#   1),
#  ('al 2007 the multisubunit tethering complex mtc golgi associated retrograde transport protein',
#   1),
#  ('ent through constitutive expression of tgfβ docking receptor glycoprotein a repetitions predominant',
#   1),
#  ('f β associated molecules latency associated peptide lap glycophorin a repetitions predominant',
#   1),
#  ('genic differentiation in mscs recently studies show that glycoprotein a repetitions predominant',
#   1),
#  ('however specific markers for treg are lack recently glycoprotein a repetitions predominant',
#   1),
#  ('ic lupus erythematosus colitis and diabetes 24 30 glycoprotein a repetitions predominant',
#   1),
#  ('ifferent leukocytes used a whole genome microarray glycoprotein a repetitions predominant protein',
#   1),
#  ('ncludes dsl1 complex conserved oligomeric golgi cog complex golgi associated retrograde protein',
#   1),
#  ('nstitutively expression a non signaling tgfβ docking receptor glycoprotein a repetitions predominant',
#   1),
#  ('respectively of transport vesicles with target membrane the golgi associated retrograde protein',
#   1),
#  ('rg1 capping protein gelsolin like capg granzyme gzmb glycoprotein a repetitions predominant',
#   1),
#  ('suppress immune responses this production is regulated by glycoprotein a repetitions predominant',
#   1),
#  ('vet hops complex the heterotetrameric tethering factor named golgi associated retrograde protein',
#   1),
#  ('9 ccr10 klrg1 capping protein gelsolin like capg gzmb glycoprotein a repetitions predominant',
#   1),
#  ('a novel immunotherapy of cancer is also highlighted glycoprotein a repetitions predominant protein',
#   1),
#  ('aximum entropy species distribution modeling maxent and genetic algorithm for rule set prediction',
#   1),
#  ('containing helical rods they usually comprise of either four golgi associated retrograde protein',
#   1),
#  ('cture and function of a heterotetrameric tethering factor named golgi associated retrograde protein',
#   1),
#  ('e still many obstacles in therapeutic applications of treg glycoprotein a repetitions predominant',
#   1),
#  ('earp that is structure related to the previously described golgi associated retrograde protein',
#   1),
#  ('exocyst the conserved oligomeric golgi cog complex and the golgi associated retrograde protein',
#   1),
#  ('he characterization as well as function of treg recently glycoprotein a repetitions predominant',
#   1),
#  ('ive function of treg andersson et al 2008 recently glycoprotein a repetitions predominant',
#   1),
#  ('lgi is coordinated by two multisubunit tethering complex the golgi associated retrograde protein',
#   1),
#  ('microenvironment by expression of the tgf β docking receptor glycoprotein a repetitions predominant',
#   1),
#  ('of acid hydrolase sorting lysosome function and autophagy the golgi associated retrograde protein',
#   1),
#  ('ostasis however the number and the suppress function of glycoprotein a repetitions predominant',
#   1),
#  ('regulated of cd 73 latency associated peptide lap and glycophorin a repetitions predominant',
#   1),
#  ('related protein 6 lrp6 the latent tgfβ docking receptor glycoprotein a repetitions predominant',
#   1),
#  ('tigote forms of trypanosoma congolense expression an immunodominant glutamic acid alanine rich protein',
#   1),
#  ('value of garp in treg definition and cancer immunotherapy glycoprotein a repetitions predominant',
#   1),
#  ('vated regulatory t treg cells expression the surface receptor glycoprotein a repetitions predominant',
#   1),
#  ('3 is co expression with latency associated peptide lap and glycophorin a repetitions predominant',
#   1),
#  ('46 after activation via tcr foxp3 + t cells expression glycoprotein a repetitions predominant',
#   1),
#  ('any role in hsc mediated t cells suppress remain unclear glycoprotein a repetitions predominant',
#   1),
#  ('attaches 10 the protein which was named t congolense glutamic acid alanine rich protein',
#   1),
#  ('chromosome 2q13 included acoxl and bcl2l11 b chromosome 12q24 12 included c11orf30 and lrcc32',
#   1),
#  ('construct designed to disrupt the prediction α helical structure by replacing glutamine with proline',
#   1),
#  ('dosome derived retrograde transport carriers and the tgn is the golgi associated retrograde protein',
#   1),
#  ('e cells surface by the transmembrane orphan toll like receptor glycophorin a repetitions predominant',
#   1),
#  ('e expression of cytotoxic t lymphocyte antigen 4 ctla4 and glycoprotein a repetitions predominant',
#   1),
#  ('ein transport in human haploid cells identified subunits of the golgi associated retrograde protein',
#   1),
#  ('eports in human treg studies have described a novel protein glycoprotein a repetitions predominant',
#   1),
#  ('erves as an essential chaperone for the cells surface protein glycoprotein a repetitions predominant',
#   1),
#  ('he modeling remain speculative however a series of alternatively spliced glutamic acid rich protein',
#   1),
#  ('he secretory pathway the catchr family the dsl1 complex the golgi associated retrograde protein',
#   1),
#  ('ity chromatography methods we find that arl5 interacts with the golgi associated retrograde protein',
#   1),
#  ('lap + treg and the expression of the transmembrane protein glycoprotein a repetitions predominant',
#   1),
#  ('le leucine rich repeat containing 32 lrrc32 also known as glycoprotein a repetitions predominant',
#   1),
#  ('ns such as conserved oligomeric golgi complex cog and golgi associated retrograde protein complex',
#   1),
#  ('ns such as liver fibrosis that involve hsc secreted tgfβ1 glycoprotein a repetitions predominant',
#   1),
#  ('ntenance of this cycling requires the function of the mammalian golgi associated retrograde protein',
#   1),
#  ('oteins such as the latency associated peptide lap and the glycoprotein a repetitions predominant',
#   1),
#  ('son test representative histograms b and dot plots c of glycophorin a repetitions predominant',
#   1),
#  ('tion current find suggest that a novel protein known as glycoprotein a repetitions predominant',
#   1),
#  ('vps54 vacuolar protein sorting 54 is a component of the golgi associated retrograde protein',
#   1),
#  ('y upregulating the expression of garp on regulatory t cells glycoprotein a repetitions predominant',
#   1),
#  ('38 40 41 42 vps53 is a subunits of both the golgi associated retrograde protein',
#   1),
#  ('and low expression of il 7 receptor cd127 33 35 and glycoprotein a repetitions predominant',
#   1),
#  ('can be bound to the outer cells membrane through the receptor glycoprotein a repetitions predominant',
#   1),
#  ('d to the surface of t cells through associated with glycoprotein a repetitions predominant protein',
#   1),
#  ('eld which separate activation tgf β from it receptor ② glycoprotein a repetitions predominant protein',
#   1),
#  ('f gpi aps and thereby identified gene encoding subunits of the golgi associated retrograde protein',
#   1),
#  ('gulation of the fusion event through actions on the snares the golgi associated retrograde protein',
#   1),
#  ('ibody figs 3 4 a and b fibrosis stage 1b recently glycoprotein a repetitions predominant',
#   1),
#  ('idic repetitions protein parp 75 76 in t brucei and glutamic acid alanine rich protein',
#   1),
#  ('n of cd103 in addition to cd103 the upregulating of cd141 glycoprotein a repetitions predominant',
#   1),
#  ('n of markers such as latency associated peptide lap and or glycoprotein a repetitions predominant',
#   1),
#  ('nd garp and gog complex show function overlap in yeast the golgi associated retrograde protein',
#   1),
#  ('network tgn and to the plasma membrane is facilitated by the golgi associated retrograde protein',
#   1),
#  ('o found arl1 and ypt6 participate in autophagy by target the golgi associated retrograde protein',
#   1),
#  ('ration patterns 2 the procyclin of t congolense is the glutamic and alanine rich protein',
#   1),
#  ('terification in the er moreover the depletion of a subunits of golgi associated retrograde protein',
#   1),
#  ('was also shown to interacts with vps53 vps54 component of the golgi associated retrograde protein',
#   1),
#  ('y t cells treg was dependent on the treg activation markers glycoprotein a repetitions predominant',
#   1),
#  ('e processing of latent tgf β1 from the latent tgf β1 glycoprotein a repetitions predominant protein',
#   1),
#  ('ed treg cells has recently been shown to be regulated by the glycoprotein a repetitions predominant',
#   1),
#  ('een shown by co immunoprecipitation that in rods rds interacts with the glutamic acid rich protein',
#   1),
#  ('gf β1 is coupled to a distinct ltgf β bind protein termed glycoprotein a repetitions predominant',
#   1),
#  ('gfp neo1 alp exhibited significantly reduced colocalization with sec7 in snx3 ∆ arl1 ∆ vps51 ∆',
#   1),
#  ('ng 53 vps53 gene depletion of vps53 or other subunits of the golgi associated retrograde protein',
#   1),
#  ('oligomeric golgi 6 cog6 of the cog complex and vps52 of the golgi associated retrograde protein',
#   1),
#  ('re when cells lack both arl1 and ypt6 we hypothesized that the golgi associated retrograde protein',
#   1),
#  ('so be achieved by the co expression of cd39 cd73 and glycoprotein a repetitions predominant protein',
#   1),
#  ('the protein ang2 is shown to be a conserved component of the golgi associated retrograde protein',
#   1),
#  ('9 21 as well as in golgi to endosome transport 22 23 the golgi associated retrograde protein',
#   1),
#  ('be involve in the release of activation tgf β from latent tgf β glycoprotein a repetitions predominant',
#   1),
#  ('bi prism7900ht used the kapa probe fast universal qpcr kit and taqman probe for gapdh and lrrc32',
#   1),
#  ('ent distribution gc pressure causes increase in levels of four amino acid coded by gc rich codons',
#   1),
#  ('n modeling maxent and one of the most commonly used is genetic algorithm for rule set prediction',
#   1),
#  ('ome or back to the plasma membrane may reach the tgn where the golgi associated retrograde protein',
#   1),
#  ('onsists of 33 exon and has a bipartite structure comprise of an amino terminal glutamic acid rich',
#   1),
#  ('r function of treg cells 56 mir 142 3p target the mrna of glycoprotein a repetitions predominant',
#   1),
#  ('that nrp1 can activation latent tgf β1 after it attaches to either αvβ3 integrin or another receptor',
#   1),
#  ('protein eipr 1 and the vps 52 and vps 53 subunits shared by the golgi associated retrograde protein',
#   1),
#  ('the role of t reg in il 2 induced toxicity we used an anti glycoprotein a repetitions predominant',
#   1),
#  ('se mice containing loxp sites within 3 and 5 introns of exon 4 of the itgb8 gene lrrc32 fl fl',
#   1),
#  ('the eh 1 motif so it can not bind grg4 a6 39 or disrupt the c terminal α helical structure',
#   1),
#  ('codons', 0.0),
#  ('complex', 0.0),
#  ('fl', 0.0),
#  ('lrcc32', 0.0),
#  ('lrrc32', 0.0),
#  ('prediction', 0.0),
#  ('predominant', 0.0),
#  ('proline', 0.0),
#  ('receptor', 0.0),
#  ('rich', 0.0),
#  ('structure', 0.0),
#  ('∆', 0.0),
#  ('acid rich', 0.0),
#  ('and lrcc32', 0.0),
#  ('and lrrc32', 0.0),
#  ('another receptor', 0.0),
#  ('fl fl', 0.0),
#  ('helical structure', 0.0),
#  ('predominant protein', 0.0),
#  ('protein complex', 0.0),
#  ('repetitions predominant', 0.0),
#  ('retrograde protein', 0.0),
#  ('rich codons', 0.0),
#  ('set prediction', 0.0),
#  ('transport protein', 0.0),
#  ('vps51 ∆', 0.0),
#  ('with proline', 0.0),
#  ('acid rich protein', 0.0),
#  ('associated retrograde protein', 0.0),
#  ('c11orf30 and lrcc32', 0.0),
#  ('gapdh and lrrc32', 0.0),
#  ('gc rich codons', 0.0),
#  ('glutamic acid rich', 0.0),
#  ('glutamine with proline', 0.0),
#  ('lrrc32 fl fl', 0.0),
#  ('or another receptor', 0.0),
#  ('repetitions predominant protein', 0.0),
#  ('retrograde protein complex', 0.0),
#  ('retrograde transport protein', 0.0),
#  ('rule set prediction', 0.0),
#  ('α helical structure', 0.0),
#  ('∆ vps51 ∆', 0.0),
#  ('a repetitions predominant protein', 0.0),
#  ('acid alanine rich protein', 0.0),
#  ('and alanine rich protein', 0.0),
#  ('arl1 ∆ vps51 ∆', 0.0),
#  ('associated retrograde protein complex', 0.0),
#  ('associated retrograde transport protein', 0.0),
#  ('by gc rich codons', 0.0),
#  ('for gapdh and lrrc32', 0.0),
#  ('for rule set prediction', 0.0),
#  ('gene lrrc32 fl fl', 0.0),
#  ('included c11orf30 and lrcc32', 0.0),
#  ('integrin or another receptor', 0.0),
#  ('replacing glutamine with proline', 0.0),
#  ('terminal glutamic acid rich', 0.0),
#  ('terminal α helical structure', 0.0),
#  ('12 included c11orf30 and lrcc32', 0.0),
#  ('30 glycoprotein a repetitions predominant', 0.0),
#  ('algorithm for rule set prediction', 0.0),
#  ('amino terminal glutamic acid rich', 0.0),
#  ('and glycophorin a repetitions predominant', 0.0),
#  ('anti glycoprotein a repetitions predominant', 0.0),
#  ('as glycoprotein a repetitions predominant', 0.0),
#  ('by glycoprotein a repetitions predominant', 0.0),
#  ('by replacing glutamine with proline', 0.0),
#  ('c terminal α helical structure', 0.0),
#  ('cd141 glycoprotein a repetitions predominant', 0.0),
#  ('cells glycoprotein a repetitions predominant', 0.0),
#  ('coded by gc rich codons', 0.0),
#  ('complex golgi associated retrograde protein', 0.0),
#  ('described golgi associated retrograde protein', 0.0),
#  ('expression glycoprotein a repetitions predominant', 0.0),
#  ('four golgi associated retrograde protein', 0.0),
#  ('function glycoprotein a repetitions predominant', 0.0),
#  ('glutamic and alanine rich protein', 0.0),
#  ('golgi associated retrograde protein complex', 0.0),
#  ('golgi associated retrograde transport protein', 0.0),
#  ('immunotherapy glycoprotein a repetitions predominant', 0.0),
#  ('itgb8 gene lrrc32 fl fl', 0.0),
#  ('lap glycophorin a repetitions predominant', 0.0),
#  ('mammalian golgi associated retrograde protein', 0.0),
#  ('markers glycoprotein a repetitions predominant', 0.0),
#  ('mscs glycoprotein a repetitions predominant', 0.0),
#  ('named golgi associated retrograde protein', 0.0),
#  ('of glycophorin a repetitions predominant', 0.0),
#  ('of golgi associated retrograde protein', 0.0),
#  ('or glycoprotein a repetitions predominant', 0.0),
#  ('probe for gapdh and lrrc32', 0.0),
#  ('receptor glycophorin a repetitions predominant', 0.0),
#  ('spliced glutamic acid rich protein', 0.0),
#  ('termed glycoprotein a repetitions predominant', 0.0),
#  ('tgfβ1 glycoprotein a repetitions predominant', 0.0),
#  ('that glycoprotein a repetitions predominant', 0.0),
#  ('the glutamic acid rich protein', 0.0),
#  ('treg glycoprotein a repetitions predominant', 0.0),
#  ('unclear glycoprotein a repetitions predominant', 0.0),
#  ('αvβ3 integrin or another receptor', 0.0),
#  ('β glycoprotein a repetitions predominant', 0.0),
#  ('∆ arl1 ∆ vps51 ∆', 0.0),
#  ('12q24 12 included c11orf30 and lrcc32', 0.0),
#  ('14 recently glycoprotein a repetitions predominant', 0.0),
#  ('1b recently glycoprotein a repetitions predominant', 0.0),
#  ('2008 recently glycoprotein a repetitions predominant', 0.0),
#  ('23 the golgi associated retrograde protein', 0.0),
#  ('24 30 glycoprotein a repetitions predominant', 0.0),
#  ('35 and glycoprotein a repetitions predominant', 0.0),
#  ('acid coded by gc rich codons', 0.0),
#  ('activation markers glycoprotein a repetitions predominant', 0.0),
#  ('alternatively spliced glutamic acid rich protein', 0.0),
#  ('an amino terminal glutamic acid rich', 0.0),
#  ('an anti glycoprotein a repetitions predominant', 0.0),
#  ('and function glycoprotein a repetitions predominant', 0.0),
#  ('and glutamic acid alanine rich protein', 0.0),
#  ('and glycoprotein a repetitions predominant protein', 0.0),
#  ('and golgi associated retrograde protein complex', 0.0),
#  ('and or glycoprotein a repetitions predominant', 0.0),
#  ('and the glycoprotein a repetitions predominant', 0.0),
#  ('and the golgi associated retrograde protein', 0.0),
#  ('autophagy the golgi associated retrograde protein', 0.0),
#  ('both the golgi associated retrograde protein', 0.0),
#  ('by the glycoprotein a repetitions predominant', 0.0),
#  ('c of glycophorin a repetitions predominant', 0.0),
#  ('cancer immunotherapy glycoprotein a repetitions predominant', 0.0),
#  ('capg gzmb glycoprotein a repetitions predominant', 0.0),
#  ('cells expression glycoprotein a repetitions predominant', 0.0),
#  ('cog complex golgi associated retrograde protein', 0.0),
#  ('congolense glutamic acid alanine rich protein', 0.0),
#  ('ctla4 and glycoprotein a repetitions predominant', 0.0),
#  ('either four golgi associated retrograde protein', 0.0),
#  ('either αvβ3 integrin or another receptor', 0.0),
#  ('factor named golgi associated retrograde protein', 0.0),
#  ('function of glycoprotein a repetitions predominant', 0.0),
#  ('granzyme gzmb glycoprotein a repetitions predominant', 0.0),
#  ('highlighted glycoprotein a repetitions predominant protein', 0.0),
#  ('immunodominant glutamic acid alanine rich protein', 0.0),
#  ('immunomodulation recently glycoprotein a repetitions predominant', 0.0),
#  ('is the golgi associated retrograde protein', 0.0),
#  ('lack recently glycoprotein a repetitions predominant', 0.0),
#  ('lap and glycophorin a repetitions predominant', 0.0),
#  ('like receptor glycophorin a repetitions predominant', 0.0),
#  ('membrane the golgi associated retrograde protein', 0.0),
#  ('microarray glycoprotein a repetitions predominant protein', 0.0),
#  ('more recently glycoprotein a repetitions predominant', 0.0),
#  ('mrna of glycoprotein a repetitions predominant', 0.0),
#  ('mtc golgi associated retrograde transport protein', 0.0),
#  ('novel protein glycoprotein a repetitions predominant', 0.0),
#  ('of cd141 glycoprotein a repetitions predominant', 0.0),
#  ('of mscs glycoprotein a repetitions predominant', 0.0),
#  ('of treg glycoprotein a repetitions predominant', 0.0),
#  ('peptide lap glycophorin a repetitions predominant', 0.0),
#  ('previously described golgi associated retrograde protein', 0.0),
#  ('protein termed glycoprotein a repetitions predominant', 0.0),
#  ('regulated by glycoprotein a repetitions predominant', 0.0),
#  ('remain unclear glycoprotein a repetitions predominant', 0.0),
#  ('secreted tgfβ1 glycoprotein a repetitions predominant', 0.0),
#  ('show that glycoprotein a repetitions predominant', 0.0),
#  ('snares the golgi associated retrograde protein', 0.0),
#  ('snx3 ∆ arl1 ∆ vps51 ∆', 0.0),
#  ('structure by replacing glutamine with proline', 0.0),
#  ('subunits of golgi associated retrograde protein', 0.0),
#  ('surface protein glycoprotein a repetitions predominant', 0.0),
#  ('surface receptor glycoprotein a repetitions predominant', 0.0),
#  ('t cells glycoprotein a repetitions predominant', 0.0),
#  ('taqman probe for gapdh and lrrc32', 0.0),
#  ('target the golgi associated retrograde protein', 0.0),
#  ('tgf β glycoprotein a repetitions predominant', 0.0),
#  ('that the golgi associated retrograde protein', 0.0),
#  ('the c terminal α helical structure', 0.0),
#  ('the glutamic and alanine rich protein', 0.0),
#  ('the glycoprotein a repetitions predominant protein', 0.0),
#  ('the itgb8 gene lrrc32 fl fl', 0.0),
#  ('the mammalian golgi associated retrograde protein', 0.0),
#  ('the receptor glycoprotein a repetitions predominant', 0.0),
#  ('transmembrane protein glycoprotein a repetitions predominant', 0.0),
#  ('treg recently glycoprotein a repetitions predominant', 0.0),
#  ('where the golgi associated retrograde protein', 0.0),
#  ('with glycoprotein a repetitions predominant protein', 0.0),
#  ('with the glutamic acid rich protein', 0.0),
#  ('with the golgi associated retrograde protein', 0.0),
#  ('yeast the golgi associated retrograde protein', 0.0),
#  ('β1 glycoprotein a repetitions predominant protein', 0.0),
#  ('② glycoprotein a repetitions predominant protein', 0.0),
#  ('1 14 recently glycoprotein a repetitions predominant', 0.0),
#  ('10 more recently glycoprotein a repetitions predominant', 0.0),
#  ('22 23 the golgi associated retrograde protein', 0.0),
#  ('33 35 and glycoprotein a repetitions predominant', 0.0),
#  ('4 ctla4 and glycoprotein a repetitions predominant', 0.0),
#  ('a novel protein glycoprotein a repetitions predominant', 0.0),
#  ('a subunits of golgi associated retrograde protein', 0.0),
#  ('al 2008 recently glycoprotein a repetitions predominant', 0.0),
#  ('also highlighted glycoprotein a repetitions predominant protein', 0.0),
#  ('also known as glycoprotein a repetitions predominant', 0.0),
#  ('amino acid coded by gc rich codons', 0.0),
#  ('an immunodominant glutamic acid alanine rich protein', 0.0),
#  ('and autophagy the golgi associated retrograde protein', 0.0),
#  ('and cancer immunotherapy glycoprotein a repetitions predominant', 0.0),
#  ('and genetic algorithm for rule set prediction', 0.0),
#  ('and immunomodulation recently glycoprotein a repetitions predominant', 0.0),
#  ('and taqman probe for gapdh and lrrc32', 0.0),
#  ('applications of treg glycoprotein a repetitions predominant', 0.0),
#  ('are lack recently glycoprotein a repetitions predominant', 0.0),
#  ('associated peptide lap glycophorin a repetitions predominant', 0.0),
#  ('associated with glycoprotein a repetitions predominant protein', 0.0),
#  ('bind protein termed glycoprotein a repetitions predominant', 0.0),
#  ('brucei and glutamic acid alanine rich protein', 0.0),
#  ('by target the golgi associated retrograde protein', 0.0),
#  ('capg granzyme gzmb glycoprotein a repetitions predominant', 0.0),
#  ('cd73 and glycoprotein a repetitions predominant protein', 0.0),
#  ('cells surface protein glycoprotein a repetitions predominant', 0.0),
#  ('characterization of the golgi associated retrograde protein', 0.0),
#  ('chromosome 12q24 12 included c11orf30 and lrcc32', 0.0),
#  ('cog and golgi associated retrograde protein complex', 0.0),
#  ('complex and the golgi associated retrograde protein', 0.0),
#  ('complex mtc golgi associated retrograde transport protein', 0.0),
#  ('diabetes 24 30 glycoprotein a repetitions predominant', 0.0),
#  ('disrupt the c terminal α helical structure', 0.0),
#  ('dsl1 complex the golgi associated retrograde protein', 0.0),
#  ('facilitated by the golgi associated retrograde protein', 0.0),
#  ('genome microarray glycoprotein a repetitions predominant protein', 0.0),
#  ('golgi cog complex golgi associated retrograde protein', 0.0),
#  ('helical structure by replacing glutamine with proline', 0.0),
#  ('hsc secreted tgfβ1 glycoprotein a repetitions predominant', 0.0),
#  ('hypothesized that the golgi associated retrograde protein', 0.0),
#  ('immunomodulation of mscs glycoprotein a repetitions predominant', 0.0),
#  ('in snx3 ∆ arl1 ∆ vps51 ∆', 0.0),
#  ('in yeast the golgi associated retrograde protein', 0.0),
#  ('interacts with the glutamic acid rich protein', 0.0),
#  ('interacts with the golgi associated retrograde protein', 0.0),
#  ('is genetic algorithm for rule set prediction', 0.0),
#  ('is regulated by glycoprotein a repetitions predominant', 0.0),
#  ('is the glutamic and alanine rich protein', 0.0),
#  ('lap and or glycoprotein a repetitions predominant', 0.0),
#  ('lap and the glycoprotein a repetitions predominant', 0.0),
#  ('latent tgf β glycoprotein a repetitions predominant', 0.0),
#  ('like capg gzmb glycoprotein a repetitions predominant', 0.0),
#  ('of alternatively spliced glutamic acid rich protein', 0.0),
#  ('of an amino terminal glutamic acid rich', 0.0),
#  ('of both the golgi associated retrograde protein', 0.0),
#  ('of either four golgi associated retrograde protein', 0.0),
#  ('of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('of the mammalian golgi associated retrograde protein', 0.0),
#  ('of treg recently glycoprotein a repetitions predominant', 0.0),
#  ('peptide lap and glycophorin a repetitions predominant', 0.0),
#  ('phenotypically and function glycoprotein a repetitions predominant', 0.0),
#  ('plots c of glycophorin a repetitions predominant', 0.0),
#  ('protein known as glycoprotein a repetitions predominant', 0.0),
#  ('receptor ② glycoprotein a repetitions predominant protein', 0.0),
#  ('regulated by the glycoprotein a repetitions predominant', 0.0),
#  ('regulatory t cells glycoprotein a repetitions predominant', 0.0),
#  ('shared by the golgi associated retrograde protein', 0.0),
#  ('stage 1b recently glycoprotein a repetitions predominant', 0.0),
#  ('studies show that glycoprotein a repetitions predominant', 0.0),
#  ('suppress function of glycoprotein a repetitions predominant', 0.0),
#  ('suppress remain unclear glycoprotein a repetitions predominant', 0.0),
#  ('t cells expression glycoprotein a repetitions predominant', 0.0),
#  ('t congolense glutamic acid alanine rich protein', 0.0),
#  ('target membrane the golgi associated retrograde protein', 0.0),
#  ('tethering complex the golgi associated retrograde protein', 0.0),
#  ('tethering factor named golgi associated retrograde protein', 0.0),
#  ('tgf β1 glycoprotein a repetitions predominant protein', 0.0),
#  ('tgn is the golgi associated retrograde protein', 0.0),
#  ('tgn where the golgi associated retrograde protein', 0.0),
#  ('the mrna of glycoprotein a repetitions predominant', 0.0),
#  ('the previously described golgi associated retrograde protein', 0.0),
#  ('the snares the golgi associated retrograde protein', 0.0),
#  ('the surface receptor glycoprotein a repetitions predominant', 0.0),
#  ('the transmembrane protein glycoprotein a repetitions predominant', 0.0),
#  ('through the receptor glycoprotein a repetitions predominant', 0.0),
#  ('to either αvβ3 integrin or another receptor', 0.0),
#  ('toll like receptor glycophorin a repetitions predominant', 0.0),
#  ('treg activation markers glycoprotein a repetitions predominant', 0.0),
#  ('upregulating of cd141 glycoprotein a repetitions predominant', 0.0),
#  ('used an anti glycoprotein a repetitions predominant', 0.0),
#  ('vps52 of the golgi associated retrograde protein', 0.0),
#  ('β docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('+ t cells expression glycoprotein a repetitions predominant', 0.0),
#  ('4 of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('a component of the golgi associated retrograde protein', 0.0),
#  ('activation 10 more recently glycoprotein a repetitions predominant', 0.0),
#  ('and diabetes 24 30 glycoprotein a repetitions predominant', 0.0),
#  ('and immunomodulation of mscs glycoprotein a repetitions predominant', 0.0),
#  ('and vps52 of the golgi associated retrograde protein', 0.0),
#  ('antigen 4 ctla4 and glycoprotein a repetitions predominant', 0.0),
#  ('arl5 interacts with the golgi associated retrograde protein', 0.0),
#  ('associated peptide lap and glycophorin a repetitions predominant', 0.0),
#  ('attaches to either αvβ3 integrin or another receptor', 0.0),
#  ('autophagy by target the golgi associated retrograde protein', 0.0),
#  ('b chromosome 12q24 12 included c11orf30 and lrcc32', 0.0),
#  ('be regulated by the glycoprotein a repetitions predominant', 0.0),
#  ('cd127 33 35 and glycoprotein a repetitions predominant', 0.0),
#  ('cd39 cd73 and glycoprotein a repetitions predominant protein', 0.0),
#  ('cells suppress remain unclear glycoprotein a repetitions predominant', 0.0),
#  ('cog complex and the golgi associated retrograde protein', 0.0),
#  ('complex cog and golgi associated retrograde protein complex', 0.0),
#  ('comprise of an amino terminal glutamic acid rich', 0.0),
#  ('comprise of either four golgi associated retrograde protein', 0.0),
#  ('congolense is the glutamic and alanine rich protein', 0.0),
#  ('conserved component of the golgi associated retrograde protein', 0.0),
#  ('definition and cancer immunotherapy glycoprotein a repetitions predominant',
#   0.0),
#  ('described a novel protein glycoprotein a repetitions predominant', 0.0),
#  ('differentiation and immunomodulation recently glycoprotein a repetitions predominant',
#   0.0),
#  ('dot plots c of glycophorin a repetitions predominant', 0.0),
#  ('encoding subunits of the golgi associated retrograde protein', 0.0),
#  ('et al 2008 recently glycoprotein a repetitions predominant', 0.0),
#  ('expression an immunodominant glutamic acid alanine rich protein', 0.0),
#  ('expression the surface receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('fibrosis stage 1b recently glycoprotein a repetitions predominant', 0.0),
#  ('four amino acid coded by gc rich codons', 0.0),
#  ('from latent tgf β glycoprotein a repetitions predominant', 0.0),
#  ('function and autophagy the golgi associated retrograde protein', 0.0),
#  ('function of the mammalian golgi associated retrograde protein', 0.0),
#  ('function of treg recently glycoprotein a repetitions predominant', 0.0),
#  ('gelsolin like capg gzmb glycoprotein a repetitions predominant', 0.0),
#  ('identified subunits of the golgi associated retrograde protein', 0.0),
#  ('involve hsc secreted tgfβ1 glycoprotein a repetitions predominant', 0.0),
#  ('is also highlighted glycoprotein a repetitions predominant protein', 0.0),
#  ('is facilitated by the golgi associated retrograde protein', 0.0),
#  ('it receptor ② glycoprotein a repetitions predominant protein', 0.0),
#  ('kit and taqman probe for gapdh and lrrc32', 0.0),
#  ('latency associated peptide lap glycophorin a repetitions predominant', 0.0),
#  ('latent tgf β1 glycoprotein a repetitions predominant protein', 0.0),
#  ('latent tgfβ docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('like capg granzyme gzmb glycoprotein a repetitions predominant', 0.0),
#  ('lrrc32 also known as glycoprotein a repetitions predominant', 0.0),
#  ('maxent and genetic algorithm for rule set prediction', 0.0),
#  ('membrane through the receptor glycoprotein a repetitions predominant', 0.0),
#  ('multisubunit tethering complex the golgi associated retrograde protein',
#   0.0),
#  ('named t congolense glutamic acid alanine rich protein', 0.0),
#  ('novel protein known as glycoprotein a repetitions predominant', 0.0),
#  ('of a subunits of golgi associated retrograde protein', 0.0),
#  ('of tgfβ docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('of the transmembrane protein glycoprotein a repetitions predominant', 0.0),
#  ('oligomeric golgi cog complex golgi associated retrograde protein', 0.0),
#  ('on regulatory t cells glycoprotein a repetitions predominant', 0.0),
#  ('on the snares the golgi associated retrograde protein', 0.0),
#  ('or disrupt the c terminal α helical structure', 0.0),
#  ('orphan toll like receptor glycophorin a repetitions predominant', 0.0),
#  ('other subunits of the golgi associated retrograde protein', 0.0),
#  ('overlap in yeast the golgi associated retrograde protein', 0.0),
#  ('peptide lap and or glycoprotein a repetitions predominant', 0.0),
#  ('peptide lap and the glycoprotein a repetitions predominant', 0.0),
#  ('production is regulated by glycoprotein a repetitions predominant', 0.0),
#  ('rds interacts with the glutamic acid rich protein', 0.0),
#  ('recently studies show that glycoprotein a repetitions predominant', 0.0),
#  ('sec7 in snx3 ∆ arl1 ∆ vps51 ∆', 0.0),
#  ('series of alternatively spliced glutamic acid rich protein', 0.0),
#  ('signaling tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('subunits of both the golgi associated retrograde protein', 0.0),
#  ('subunits shared by the golgi associated retrograde protein', 0.0),
#  ('t brucei and glutamic acid alanine rich protein', 0.0),
#  ('target the mrna of glycoprotein a repetitions predominant', 0.0),
#  ('tethering complex mtc golgi associated retrograde transport protein', 0.0),
#  ('tgf β docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('the cells surface protein glycoprotein a repetitions predominant', 0.0),
#  ('the dsl1 complex the golgi associated retrograde protein', 0.0),
#  ('the suppress function of glycoprotein a repetitions predominant', 0.0),
#  ('the tgn is the golgi associated retrograde protein', 0.0),
#  ('the tgn where the golgi associated retrograde protein', 0.0),
#  ('the treg activation markers glycoprotein a repetitions predominant', 0.0),
#  ('the upregulating of cd141 glycoprotein a repetitions predominant', 0.0),
#  ('therapeutic applications of treg glycoprotein a repetitions predominant',
#   0.0),
#  ('thrombospondin 1 14 recently glycoprotein a repetitions predominant', 0.0),
#  ('through associated with glycoprotein a repetitions predominant protein',
#   0.0),
#  ('to the previously described golgi associated retrograde protein', 0.0),
#  ('transport 22 23 the golgi associated retrograde protein', 0.0),
#  ('treg are lack recently glycoprotein a repetitions predominant', 0.0),
#  ('treg phenotypically and function glycoprotein a repetitions predominant',
#   0.0),
#  ('used is genetic algorithm for rule set prediction', 0.0),
#  ('vps54 component of the golgi associated retrograde protein', 0.0),
#  ('we hypothesized that the golgi associated retrograde protein', 0.0),
#  ('we used an anti glycoprotein a repetitions predominant', 0.0),
#  ('whole genome microarray glycoprotein a repetitions predominant protein',
#   0.0),
#  ('with target membrane the golgi associated retrograde protein', 0.0),
#  ('α helical structure by replacing glutamine with proline', 0.0),
#  ('β bind protein termed glycoprotein a repetitions predominant', 0.0),
#  ('32 lrrc32 also known as glycoprotein a repetitions predominant', 0.0),
#  ('39 or disrupt the c terminal α helical structure', 0.0),
#  ('3p target the mrna of glycoprotein a repetitions predominant', 0.0),
#  ('53 subunits shared by the golgi associated retrograde protein', 0.0),
#  ('a conserved component of the golgi associated retrograde protein', 0.0),
#  ('a heterotetrameric tethering factor named golgi associated retrograde protein',
#   0.0),
#  ('a novel protein known as glycoprotein a repetitions predominant', 0.0),
#  ('a series of alternatively spliced glutamic acid rich protein', 0.0),
#  ('a subunits of both the golgi associated retrograde protein', 0.0),
#  ('a whole genome microarray glycoprotein a repetitions predominant protein',
#   0.0),
#  ('actions on the snares the golgi associated retrograde protein', 0.0),
#  ('and dot plots c of glycophorin a repetitions predominant', 0.0),
#  ('and the suppress function of glycoprotein a repetitions predominant', 0.0),
#  ('and the tgn is the golgi associated retrograde protein', 0.0),
#  ('and thrombospondin 1 14 recently glycoprotein a repetitions predominant',
#   0.0),
#  ('andersson et al 2008 recently glycoprotein a repetitions predominant', 0.0),
#  ('as function of treg recently glycoprotein a repetitions predominant', 0.0),
#  ('associated peptide lap and or glycoprotein a repetitions predominant', 0.0),
#  ('associated peptide lap and the glycoprotein a repetitions predominant',
#   0.0),
#  ('b fibrosis stage 1b recently glycoprotein a repetitions predominant', 0.0),
#  ('bcl2l11 b chromosome 12q24 12 included c11orf30 and lrcc32', 0.0),
#  ('cancer is also highlighted glycoprotein a repetitions predominant protein',
#   0.0),
#  ('cd103 the upregulating of cd141 glycoprotein a repetitions predominant',
#   0.0),
#  ('cells expression the surface receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('cells identified subunits of the golgi associated retrograde protein', 0.0),
#  ('cells membrane through the receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('cells through associated with glycoprotein a repetitions predominant protein',
#   0.0),
#  ('cells treg phenotypically and function glycoprotein a repetitions predominant',
#   0.0),
#  ('colitis and diabetes 24 30 glycoprotein a repetitions predominant', 0.0),
#  ('commonly used is genetic algorithm for rule set prediction', 0.0),
#  ('complex and vps52 of the golgi associated retrograde protein', 0.0),
#  ('congolense expression an immunodominant glutamic acid alanine rich protein',
#   0.0),
#  ('conserved oligomeric golgi cog complex golgi associated retrograde protein',
#   0.0),
#  ('depletion of a subunits of golgi associated retrograde protein', 0.0),
#  ('differentiation and immunomodulation of mscs glycoprotein a repetitions predominant',
#   0.0),
#  ('endosome transport 22 23 the golgi associated retrograde protein', 0.0),
#  ('exon 4 of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('expression of tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('expression of the transmembrane protein glycoprotein a repetitions predominant',
#   0.0),
#  ('family the dsl1 complex the golgi associated retrograde protein', 0.0),
#  ('for the cells surface protein glycoprotein a repetitions predominant', 0.0),
#  ('for treg are lack recently glycoprotein a repetitions predominant', 0.0),
#  ('foxp3 + t cells expression glycoprotein a repetitions predominant', 0.0),
#  ('from it receptor ② glycoprotein a repetitions predominant protein', 0.0),
#  ('function activation 10 more recently glycoprotein a repetitions predominant',
#   0.0),
#  ('function overlap in yeast the golgi associated retrograde protein', 0.0),
#  ('garp on regulatory t cells glycoprotein a repetitions predominant', 0.0),
#  ('gelsolin like capg granzyme gzmb glycoprotein a repetitions predominant',
#   0.0),
#  ('gene encoding subunits of the golgi associated retrograde protein', 0.0),
#  ('golgi cog complex and the golgi associated retrograde protein', 0.0),
#  ('golgi complex cog and golgi associated retrograde protein complex', 0.0),
#  ('have described a novel protein glycoprotein a repetitions predominant',
#   0.0),
#  ('in autophagy by target the golgi associated retrograde protein', 0.0),
#  ('in t brucei and glutamic acid alanine rich protein', 0.0),
#  ('in therapeutic applications of treg glycoprotein a repetitions predominant',
#   0.0),
#  ('is a component of the golgi associated retrograde protein', 0.0),
#  ('it attaches to either αvβ3 integrin or another receptor', 0.0),
#  ('ltgf β bind protein termed glycoprotein a repetitions predominant', 0.0),
#  ('lymphocyte antigen 4 ctla4 and glycoprotein a repetitions predominant',
#   0.0),
#  ('lysosome function and autophagy the golgi associated retrograde protein',
#   0.0),
#  ('membrane is facilitated by the golgi associated retrograde protein', 0.0),
#  ('modeling maxent and genetic algorithm for rule set prediction', 0.0),
#  ('molecules latency associated peptide lap glycophorin a repetitions predominant',
#   0.0),
#  ('mscs recently studies show that glycoprotein a repetitions predominant',
#   0.0),
#  ('multisubunit tethering complex mtc golgi associated retrograde transport protein',
#   0.0),
#  ('non signaling tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('of cd39 cd73 and glycoprotein a repetitions predominant protein', 0.0),
#  ('of four amino acid coded by gc rich codons', 0.0),
#  ('on the treg activation markers glycoprotein a repetitions predominant',
#   0.0),
#  ('or other subunits of the golgi associated retrograde protein', 0.0),
#  ('prediction α helical structure by replacing glutamine with proline', 0.0),
#  ('protein gelsolin like capg gzmb glycoprotein a repetitions predominant',
#   0.0),
#  ('qpcr kit and taqman probe for gapdh and lrrc32', 0.0),
#  ('reach the tgn where the golgi associated retrograde protein', 0.0),
#  ('receptor cd127 33 35 and glycoprotein a repetitions predominant', 0.0),
#  ('related to the previously described golgi associated retrograde protein',
#   0.0),
#  ('rods rds interacts with the glutamic acid rich protein', 0.0),
#  ('structure comprise of an amino terminal glutamic acid rich', 0.0),
#  ('t cells suppress remain unclear glycoprotein a repetitions predominant',
#   0.0),
#  ('t congolense is the glutamic and alanine rich protein', 0.0),
#  ('that arl5 interacts with the golgi associated retrograde protein', 0.0),
#  ('that involve hsc secreted tgfβ1 glycoprotein a repetitions predominant',
#   0.0),
#  ('the function of the mammalian golgi associated retrograde protein', 0.0),
#  ('the heterotetrameric tethering factor named golgi associated retrograde protein',
#   0.0),
#  ('the latent tgf β1 glycoprotein a repetitions predominant protein', 0.0),
#  ('the latent tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('the tgf β docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('this production is regulated by glycoprotein a repetitions predominant',
#   0.0),
#  ('to be regulated by the glycoprotein a repetitions predominant', 0.0),
#  ('toxicity we used an anti glycoprotein a repetitions predominant', 0.0),
#  ('transmembrane orphan toll like receptor glycophorin a repetitions predominant',
#   0.0),
#  ('treg definition and cancer immunotherapy glycoprotein a repetitions predominant',
#   0.0),
#  ('two multisubunit tethering complex the golgi associated retrograde protein',
#   0.0),
#  ('usually comprise of either four golgi associated retrograde protein', 0.0),
#  ('vesicles with target membrane the golgi associated retrograde protein',
#   0.0),
#  ('vps53 vps54 component of the golgi associated retrograde protein', 0.0),
#  ('was named t congolense glutamic acid alanine rich protein', 0.0),
#  ('with sec7 in snx3 ∆ arl1 ∆ vps51 ∆', 0.0),
#  ('ypt6 we hypothesized that the golgi associated retrograde protein', 0.0),
#  ('β from latent tgf β glycoprotein a repetitions predominant', 0.0),
#  ('142 3p target the mrna of glycoprotein a repetitions predominant', 0.0),
#  ('54 is a component of the golgi associated retrograde protein', 0.0),
#  ('7 receptor cd127 33 35 and glycoprotein a repetitions predominant', 0.0),
#  ('73 latency associated peptide lap and glycophorin a repetitions predominant',
#   0.0),
#  ('76 in t brucei and glutamic acid alanine rich protein', 0.0),
#  ('a non signaling tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('a6 39 or disrupt the c terminal α helical structure', 0.0),
#  ('after it attaches to either αvβ3 integrin or another receptor', 0.0),
#  ('and b fibrosis stage 1b recently glycoprotein a repetitions predominant',
#   0.0),
#  ('and bcl2l11 b chromosome 12q24 12 included c11orf30 and lrcc32', 0.0),
#  ('and ypt6 we hypothesized that the golgi associated retrograde protein',
#   0.0),
#  ('associated molecules latency associated peptide lap glycophorin a repetitions predominant',
#   0.0),
#  ('b and dot plots c of glycophorin a repetitions predominant', 0.0),
#  ('be a conserved component of the golgi associated retrograde protein', 0.0),
#  ('bipartite structure comprise of an amino terminal glutamic acid rich', 0.0),
#  ('by two multisubunit tethering complex the golgi associated retrograde protein',
#   0.0),
#  ('capping protein gelsolin like capg gzmb glycoprotein a repetitions predominant',
#   0.0),
#  ('carriers and the tgn is the golgi associated retrograde protein', 0.0),
#  ('catchr family the dsl1 complex the golgi associated retrograde protein',
#   0.0),
#  ('chaperone for the cells surface protein glycoprotein a repetitions predominant',
#   0.0),
#  ('cog complex and vps52 of the golgi associated retrograde protein', 0.0),
#  ('colocalization with sec7 in snx3 ∆ arl1 ∆ vps51 ∆', 0.0),
#  ('complex conserved oligomeric golgi cog complex golgi associated retrograde protein',
#   0.0),
#  ('complex the heterotetrameric tethering factor named golgi associated retrograde protein',
#   0.0),
#  ('constitutive expression of tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('containing 32 lrrc32 also known as glycoprotein a repetitions predominant',
#   0.0),
#  ('dependent on the treg activation markers glycoprotein a repetitions predominant',
#   0.0),
#  ('distinct ltgf β bind protein termed glycoprotein a repetitions predominant',
#   0.0),
#  ('distribution modeling maxent and genetic algorithm for rule set prediction',
#   0.0),
#  ('erythematosus colitis and diabetes 24 30 glycoprotein a repetitions predominant',
#   0.0),
#  ('expression of cd39 cd73 and glycoprotein a repetitions predominant protein',
#   0.0),
#  ('fibrosis that involve hsc secreted tgfβ1 glycoprotein a repetitions predominant',
#   0.0),
#  ('find that arl5 interacts with the golgi associated retrograde protein',
#   0.0),
#  ('from the latent tgf β1 glycoprotein a repetitions predominant protein',
#   0.0),
#  ('haploid cells identified subunits of the golgi associated retrograde protein',
#   0.0),
#  ('however a series of alternatively spliced glutamic acid rich protein', 0.0),
#  ('identified gene encoding subunits of the golgi associated retrograde protein',
#   0.0),
#  ('in mscs recently studies show that glycoprotein a repetitions predominant',
#   0.0),
#  ('in rods rds interacts with the glutamic acid rich protein', 0.0),
#  ('in treg definition and cancer immunotherapy glycoprotein a repetitions predominant',
#   0.0),
#  ('induced toxicity we used an anti glycoprotein a repetitions predominant',
#   0.0),
#  ('is a subunits of both the golgi associated retrograde protein', 0.0),
#  ('latency associated peptide lap and or glycoprotein a repetitions predominant',
#   0.0),
#  ('latency associated peptide lap and the glycoprotein a repetitions predominant',
#   0.0),
#  ('levels of four amino acid coded by gc rich codons', 0.0),
#  ('lrp6 the latent tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('markers for treg are lack recently glycoprotein a repetitions predominant',
#   0.0),
#  ('may reach the tgn where the golgi associated retrograde protein', 0.0),
#  ('mediated t cells suppress remain unclear glycoprotein a repetitions predominant',
#   0.0),
#  ('migration differentiation and immunomodulation of mscs glycoprotein a repetitions predominant',
#   0.0),
#  ('most commonly used is genetic algorithm for rule set prediction', 0.0),
#  ('number and the suppress function of glycoprotein a repetitions predominant',
#   0.0),
#  ('obstacles in therapeutic applications of treg glycoprotein a repetitions predominant',
#   0.0),
#  ('of a heterotetrameric tethering factor named golgi associated retrograde protein',
#   0.0),
#  ('of cancer is also highlighted glycoprotein a repetitions predominant protein',
#   0.0),
#  ('of exon 4 of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('of garp on regulatory t cells glycoprotein a repetitions predominant', 0.0),
#  ('of t congolense is the glutamic and alanine rich protein', 0.0),
#  ('of the tgf β docking receptor glycoprotein a repetitions predominant', 0.0),
#  ('oligomeric golgi cog complex and the golgi associated retrograde protein',
#   0.0),
#  ('oligomeric golgi complex cog and golgi associated retrograde protein complex',
#   0.0),
#  ('outer cells membrane through the receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('participate in autophagy by target the golgi associated retrograde protein',
#   0.0),
#  ('plasma membrane is facilitated by the golgi associated retrograde protein',
#   0.0),
# ...
#   0.0),
#  ('fusion event through actions on the snares the golgi associated retrograde protein',
#   0.0),
#  ('gog complex show function overlap in yeast the golgi associated retrograde protein',
#   0.0),
#  ('has a bipartite structure comprise of an amino terminal glutamic acid rich',
#   0.0),
#  ('helical rods they usually comprise of either four golgi associated retrograde protein',
#   0.0),
#  ('however the number and the suppress function of glycoprotein a repetitions predominant',
#   0.0),
#  ('human treg studies have described a novel protein glycoprotein a repetitions predominant',
#   0.0),
#  ('il 2 induced toxicity we used an anti glycoprotein a repetitions predominant',
#   0.0),
#  ('immunoprecipitation that in rods rds interacts with the glutamic acid rich protein',
#   0.0),
#  ('in addition to cd103 the upregulating of cd141 glycoprotein a repetitions predominant',
#   0.0),
#  ('in golgi to endosome transport 22 23 the golgi associated retrograde protein',
#   0.0),
#  ('in hsc mediated t cells suppress remain unclear glycoprotein a repetitions predominant',
#   0.0),
#  ('in human haploid cells identified subunits of the golgi associated retrograde protein',
#   0.0),
#  ('included acoxl and bcl2l11 b chromosome 12q24 12 included c11orf30 and lrcc32',
#   0.0),
#  ('increase in levels of four amino acid coded by gc rich codons', 0.0),
#  ('is coordinated by two multisubunit tethering complex the golgi associated retrograde protein',
#   0.0),
#  ('methods we find that arl5 interacts with the golgi associated retrograde protein',
#   0.0),
#  ('novel immunotherapy of cancer is also highlighted glycoprotein a repetitions predominant protein',
#   0.0),
#  ('of activation tgf β from latent tgf β glycoprotein a repetitions predominant',
#   0.0),
#  ('of cd 73 latency associated peptide lap and glycophorin a repetitions predominant',
#   0.0),
#  ('of cytotoxic t lymphocyte antigen 4 ctla4 and glycoprotein a repetitions predominant',
#   0.0),
#  ('of garp in treg definition and cancer immunotherapy glycoprotein a repetitions predominant',
#   0.0),
#  ('of il 7 receptor cd127 33 35 and glycoprotein a repetitions predominant',
#   0.0),
#  ('of the cog complex and vps52 of the golgi associated retrograde protein',
#   0.0),
#  ('of the most commonly used is genetic algorithm for rule set prediction',
#   0.0),
#  ('parp 75 76 in t brucei and glutamic acid alanine rich protein', 0.0),
#  ('pathway the catchr family the dsl1 complex the golgi associated retrograde protein',
#   0.0),
#  ('plasma membrane may reach the tgn where the golgi associated retrograde protein',
#   0.0),
#  ('probe fast universal qpcr kit and taqman probe for gapdh and lrrc32', 0.0),
#  ('protein 6 lrp6 the latent tgfβ docking receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('protein sorting 54 is a component of the golgi associated retrograde protein',
#   0.0),
#  ('recently been shown to be regulated by the glycoprotein a repetitions predominant',
#   0.0),
#  ('regulatory t treg cells expression the surface receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('remain speculative however a series of alternatively spliced glutamic acid rich protein',
#   0.0),
#  ('representative histograms b and dot plots c of glycophorin a repetitions predominant',
#   0.0),
#  ('retrograde transport carriers and the tgn is the golgi associated retrograde protein',
#   0.0),
#  ('rich repeat containing 32 lrrc32 also known as glycoprotein a repetitions predominant',
#   0.0),
#  ('shown to be a conserved component of the golgi associated retrograde protein',
#   0.0),
#  ('significantly reduced colocalization with sec7 in snx3 ∆ arl1 ∆ vps51 ∆',
#   0.0),
#  ('still many obstacles in therapeutic applications of treg glycoprotein a repetitions predominant',
#   0.0),
#  ('such as latency associated peptide lap and or glycoprotein a repetitions predominant',
#   0.0),
#  ('surface by the transmembrane orphan toll like receptor glycophorin a repetitions predominant',
#   0.0),
#  ('surface of t cells through associated with glycoprotein a repetitions predominant protein',
#   0.0),
#  ('tgf β1 after it attaches to either αvβ3 integrin or another receptor', 0.0),
#  ('tgf β1 from the latent tgf β1 glycoprotein a repetitions predominant protein',
#   0.0),
#  ('that is structure related to the previously described golgi associated retrograde protein',
#   0.0),
#  ('the co expression of cd39 cd73 and glycoprotein a repetitions predominant protein',
#   0.0),
#  ('the conserved oligomeric golgi cog complex and the golgi associated retrograde protein',
#   0.0),
#  ('the expression of garp on regulatory t cells glycoprotein a repetitions predominant',
#   0.0),
#  ('the procyclin of t congolense is the glutamic and alanine rich protein',
#   0.0),
#  ('the protein which was named t congolense glutamic acid alanine rich protein',
#   0.0),
#  ('this cycling requires the function of the mammalian golgi associated retrograde protein',
#   0.0),
#  ('to a distinct ltgf β bind protein termed glycoprotein a repetitions predominant',
#   0.0),
#  ('to disrupt the prediction α helical structure by replacing glutamine with proline',
#   0.0),
#  ('to interacts with vps53 vps54 component of the golgi associated retrograde protein',
#   0.0),
#  ('to the outer cells membrane through the receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('to the plasma membrane is facilitated by the golgi associated retrograde protein',
#   0.0),
#  ('treg and the expression of the transmembrane protein glycoprotein a repetitions predominant',
#   0.0),
#  ('treg was dependent on the treg activation markers glycoprotein a repetitions predominant',
#   0.0),
#  ('+ treg and the expression of the transmembrane protein glycoprotein a repetitions predominant',
#   0.0),
#  ('10 the protein which was named t congolense glutamic acid alanine rich protein',
#   0.0),
#  ('2 the procyclin of t congolense is the glutamic and alanine rich protein',
#   0.0),
#  ('2q13 included acoxl and bcl2l11 b chromosome 12q24 12 included c11orf30 and lrcc32',
#   0.0),
#  ('3 4 a and b fibrosis stage 1b recently glycoprotein a repetitions predominant',
#   0.0),
#  ('41 42 vps53 is a subunits of both the golgi associated retrograde protein',
#   0.0),
#  ('after activation via tcr foxp3 + t cells expression glycoprotein a repetitions predominant',
#   0.0),
#  ('and 5 introns of exon 4 of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('and gog complex show function overlap in yeast the golgi associated retrograde protein',
#   0.0),
#  ('and has a bipartite structure comprise of an amino terminal glutamic acid rich',
#   0.0),
#  ('and to the plasma membrane is facilitated by the golgi associated retrograde protein',
#   0.0),
#  ('aps and thereby identified gene encoding subunits of the golgi associated retrograde protein',
#   0.0),
#  ('arl1 and ypt6 participate in autophagy by target the golgi associated retrograde protein',
#   0.0),
#  ('as an essential chaperone for the cells surface protein glycoprotein a repetitions predominant',
#   0.0),
#  ('as in golgi to endosome transport 22 23 the golgi associated retrograde protein',
#   0.0),
#  ('bound to the outer cells membrane through the receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('by the co expression of cd39 cd73 and glycoprotein a repetitions predominant protein',
#   0.0),
#  ('causes increase in levels of four amino acid coded by gc rich codons', 0.0),
#  ('cd103 in addition to cd103 the upregulating of cd141 glycoprotein a repetitions predominant',
#   0.0),
#  ('cells 56 mir 142 3p target the mrna of glycoprotein a repetitions predominant',
#   0.0),
#  ('cells surface by the transmembrane orphan toll like receptor glycophorin a repetitions predominant',
#   0.0),
#  ('cells treg was dependent on the treg activation markers glycoprotein a repetitions predominant',
#   0.0),
#  ('chromatography methods we find that arl5 interacts with the golgi associated retrograde protein',
#   0.0),
#  ('co immunoprecipitation that in rods rds interacts with the glutamic acid rich protein',
#   0.0),
#  ('cog6 of the cog complex and vps52 of the golgi associated retrograde protein',
#   0.0),
#  ('coupled to a distinct ltgf β bind protein termed glycoprotein a repetitions predominant',
#   0.0),
#  ('current find suggest that a novel protein known as glycoprotein a repetitions predominant',
#   0.0),
#  ('derived retrograde transport carriers and the tgn is the golgi associated retrograde protein',
#   0.0),
#  ('designed to disrupt the prediction α helical structure by replacing glutamine with proline',
#   0.0),
#  ('exhibited significantly reduced colocalization with sec7 in snx3 ∆ arl1 ∆ vps51 ∆',
#   0.0),
#  ('expression of cytotoxic t lymphocyte antigen 4 ctla4 and glycoprotein a repetitions predominant',
#   0.0),
#  ('expression of il 7 receptor cd127 33 35 and glycoprotein a repetitions predominant',
#   0.0),
#  ('gene depletion of vps53 or other subunits of the golgi associated retrograde protein',
#   0.0),
#  ('has recently been shown to be regulated by the glycoprotein a repetitions predominant',
#   0.0),
#  ('in human treg studies have described a novel protein glycoprotein a repetitions predominant',
#   0.0),
#  ('in il 2 induced toxicity we used an anti glycoprotein a repetitions predominant',
#   0.0),
#  ('is co expression with latency associated peptide lap and glycophorin a repetitions predominant',
#   0.0),
#  ('is shown to be a conserved component of the golgi associated retrograde protein',
#   0.0),
#  ('kapa probe fast universal qpcr kit and taqman probe for gapdh and lrrc32',
#   0.0),
#  ('lack both arl1 and ypt6 we hypothesized that the golgi associated retrograde protein',
#   0.0),
#  ('latent tgf β1 after it attaches to either αvβ3 integrin or another receptor',
#   0.0),
#  ('latent tgf β1 from the latent tgf β1 glycoprotein a repetitions predominant protein',
#   0.0),
#  ('leucine rich repeat containing 32 lrrc32 also known as glycoprotein a repetitions predominant',
#   0.0),
#  ('markers such as latency associated peptide lap and or glycoprotein a repetitions predominant',
#   0.0),
#  ('modeling remain speculative however a series of alternatively spliced glutamic acid rich protein',
#   0.0),
#  ('not bind grg4 a6 39 or disrupt the c terminal α helical structure', 0.0),
#  ('of this cycling requires the function of the mammalian golgi associated retrograde protein',
#   0.0),
#  ('one of the most commonly used is genetic algorithm for rule set prediction',
#   0.0),
#  ('protein parp 75 76 in t brucei and glutamic acid alanine rich protein',
#   0.0),
#  ('release of activation tgf β from latent tgf β glycoprotein a repetitions predominant',
#   0.0),
#  ('role in hsc mediated t cells suppress remain unclear glycoprotein a repetitions predominant',
#   0.0),
#  ('secretory pathway the catchr family the dsl1 complex the golgi associated retrograde protein',
#   0.0),
#  ('separate activation tgf β from it receptor ② glycoprotein a repetitions predominant protein',
#   0.0),
#  ('shown to interacts with vps53 vps54 component of the golgi associated retrograde protein',
#   0.0),
#  ('such as conserved oligomeric golgi complex cog and golgi associated retrograde protein complex',
#   0.0),
#  ('such as liver fibrosis that involve hsc secreted tgfβ1 glycoprotein a repetitions predominant',
#   0.0),
#  ('such as the latency associated peptide lap and the glycoprotein a repetitions predominant',
#   0.0),
#  ('test representative histograms b and dot plots c of glycophorin a repetitions predominant',
#   0.0),
#  ('the er moreover the depletion of a subunits of golgi associated retrograde protein',
#   0.0),
#  ('the fusion event through actions on the snares the golgi associated retrograde protein',
#   0.0),
#  ('the plasma membrane may reach the tgn where the golgi associated retrograde protein',
#   0.0),
#  ('the surface of t cells through associated with glycoprotein a repetitions predominant protein',
#   0.0),
#  ('transport in human haploid cells identified subunits of the golgi associated retrograde protein',
#   0.0),
#  ('upregulating the expression of garp on regulatory t cells glycoprotein a repetitions predominant',
#   0.0),
#  ('vacuolar protein sorting 54 is a component of the golgi associated retrograde protein',
#   0.0),
#  ('vps 52 and vps 53 subunits shared by the golgi associated retrograde protein',
#   0.0),
#  ('3 and 5 introns of exon 4 of the itgb8 gene lrrc32 fl fl', 0.0),
#  ('40 41 42 vps53 is a subunits of both the golgi associated retrograde protein',
#   0.0),
#  ('6 cog6 of the cog complex and vps52 of the golgi associated retrograde protein',
#   0.0),
#  ('achieved by the co expression of cd39 cd73 and glycoprotein a repetitions predominant protein',
#   0.0),
#  ('activation latent tgf β1 after it attaches to either αvβ3 integrin or another receptor',
#   0.0),
#  ('alp exhibited significantly reduced colocalization with sec7 in snx3 ∆ arl1 ∆ vps51 ∆',
#   0.0),
#  ('also shown to interacts with vps53 vps54 component of the golgi associated retrograde protein',
#   0.0),
#  ('and one of the most commonly used is genetic algorithm for rule set prediction',
#   0.0),
#  ('ang2 is shown to be a conserved component of the golgi associated retrograde protein',
#   0.0),
#  ('be bound to the outer cells membrane through the receptor glycoprotein a repetitions predominant',
#   0.0),
#  ('by co immunoprecipitation that in rods rds interacts with the glutamic acid rich protein',
#   0.0),
#  ('can not bind grg4 a6 39 or disrupt the c terminal α helical structure',
#   0.0),
#  ('cells has recently been shown to be regulated by the glycoprotein a repetitions predominant',
#   0.0),
#  ('cells lack both arl1 and ypt6 we hypothesized that the golgi associated retrograde protein',
#   0.0),
#  ('exon and has a bipartite structure comprise of an amino terminal glutamic acid rich',
#   0.0),
#  ('figs 3 4 a and b fibrosis stage 1b recently glycoprotein a repetitions predominant',
#   0.0),
#  ('found arl1 and ypt6 participate in autophagy by target the golgi associated retrograde protein',
#   0.0),
#  ('garp and gog complex show function overlap in yeast the golgi associated retrograde protein',
#   0.0),
#  ('gpi aps and thereby identified gene encoding subunits of the golgi associated retrograde protein',
#   0.0),
#  ('in the er moreover the depletion of a subunits of golgi associated retrograde protein',
#   0.0),
#  ('is coupled to a distinct ltgf β bind protein termed glycoprotein a repetitions predominant',
#   0.0),
#  ('low expression of il 7 receptor cd127 33 35 and glycoprotein a repetitions predominant',
#   0.0),
#  ('of cd103 in addition to cd103 the upregulating of cd141 glycoprotein a repetitions predominant',
#   0.0),
#  ('of latent tgf β1 from the latent tgf β1 glycoprotein a repetitions predominant protein',
#   0.0),
#  ('of markers such as latency associated peptide lap and or glycoprotein a repetitions predominant',
#   0.0),
#  ('of the fusion event through actions on the snares the golgi associated retrograde protein',
#   0.0),
#  ('patterns 2 the procyclin of t congolense is the glutamic and alanine rich protein',
#   0.0),
#  ('pressure causes increase in levels of four amino acid coded by gc rich codons',
#   0.0),
#  ('reg in il 2 induced toxicity we used an anti glycoprotein a repetitions predominant',
#   0.0),
#  ('repetitions protein parp 75 76 in t brucei and glutamic acid alanine rich protein',
#   0.0),
#  ('t cells treg was dependent on the treg activation markers glycoprotein a repetitions predominant',
#   0.0),
#  ('tgn and to the plasma membrane is facilitated by the golgi associated retrograde protein',
#   0.0),
#  ('the kapa probe fast universal qpcr kit and taqman probe for gapdh and lrrc32',
#   0.0),
#  ('the release of activation tgf β from latent tgf β glycoprotein a repetitions predominant',
#   0.0),
#  ('the vps 52 and vps 53 subunits shared by the golgi associated retrograde protein',
#   0.0),
#  ('to the plasma membrane may reach the tgn where the golgi associated retrograde protein',
#   0.0),
#  ('to the surface of t cells through associated with glycoprotein a repetitions predominant protein',
#   0.0),
#  ('treg cells 56 mir 142 3p target the mrna of glycoprotein a repetitions predominant',
#   0.0),
#  ('vps53 gene depletion of vps53 or other subunits of the golgi associated retrograde protein',
#   0.0),
#  ...]

# %%
longforms0 = miners['GARP'].get_longforms()

# %%
longforms = longforms0 + [('glutamic acid rich protein', 1.0)]

# %%
longforms
# Out:
# [('glycoprotein a repetitions predominant', 40.95348837209302),
#  ('the golgi associated retrograde protein', 22.5),
#  ('glutamic acid rich protein', 1.0)]

# %%
longforms, scores = zip(*longforms)

# %%
grounding_map = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'

# %%
grounding_map
# Out:
# {'glycoprotein a repetitions predominant': 'HGNC:4161'}

# %%
result = ground_with_gui(longforms, scores, grounding_map=grounding_map)

# %%
result
# Out:
# ({'glutamic acid rich protein': 'HGNC:2151',
#   'glycoprotein a repetitions predominant': 'HGNC:4161',
#   'the golgi associated retrograde protein': 'FPLX:GARP'},
#  {'HGNC:2151': 'CNGB1', 'HGNC:4161': 'LRRC32', 'FPLX:GARP': 'GARP'},
#  ['FPLX:GARP', 'HGNC:2151', 'HGNC:4161'])

# %%
grounding_map, names, pos_labels = \
    ({'glutamic acid rich protein': 'HGNC:2151',
      'glycoprotein a repetitions predominant': 'HGNC:4161',
      'the golgi associated retrograde protein': 'FPLX:GARP'},
     {'HGNC:2151': 'CNGB1', 'HGNC:4161': 'LRRC32', 'FPLX:GARP': 'GARP'},
     ['FPLX:GARP', 'HGNC:2151', 'HGNC:4161'])

# %%
grounding_dict = {'GARP': grounding_map}

# %%
classifier = AdeftClassifier('GARP', pos_labels)

# %%
param_grid = {'C': [10.0, 100.0], 'max_features': [1000, 10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2019-12-19 12:22:18] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [10.0, 100.0], 'max_features': [1000, 10000]}
# INFO: [2019-12-19 12:23:01] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9256037270620888 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 1000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'HGNC:4161': 66, 'FPLX:GARP': 19, 'HGNC:2151': 30},
#  'f1': {'mean': 0.9256037270620888, 'std': 0.06414141547348061},
#  'precision': {'mean': 0.9353599661208356, 'std': 0.0561687741217047},
#  'recall': {'mean': 0.9292490118577075, 'std': 0.060234871783553336}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
disamb.disambiguate(texts[0])
# Out:
# ('HGNC:4161',
#  'LRRC32',
#  {'FPLX:GARP': 0.04563332106023921, 'HGNC:4161': 0.9543666789397608})

# %%
texts[2]
# Out:
# 'Mesenchymal stem cells (MSCs), which have multipotential differentiation and self-renewal potential, are possible cells for tissue engineering. Transforming growth factor β1 (TGFβ1) can be produced by MSCs in an inactive form, and the activation of TGFβ1 functions as an important regulator of osteogenic differentiation in MSCs. Recently, studies showed that GARP participated in the activation of latent TGFβ1, but the interaction between GARP and TGFβ1 is still undefined. In our study, we successfully isolated the MSCs from bone marrow of rats, and showed that GARP was detected in bone mesenchymal stem cells (BMSCs). During the osteogenic differentiation of BMSCs, GARP expression was increased over time. To elucidate the interaction between GARP and TGFβ1, we downregulated GARP expression in BMSCs to examine the level of active TGFβ1. We then verified that the downregulation of GARP decreased the secretion of active TGFβ1. Furthermore, osteogenic differentiation experiments, alkaline phosphatase (ALP) activity analyses and Alizarin Red S staining experiments were performed to evaluate the osteogenic capacity. After the downregulation of GARP, ALP activity and Alizarin Red S staining significantly declined and the osteogenic indicators, ALP, Runx2, and OPN, also decreased, both at the mRNA and protein levels. These results demonstrated that downregulated GARP expression resulted in the reduction of TGFβ1 and the attenuation of osteoblast differentiation of BMSCs in vitro .'

# %%
disamb.dump('GARP', '../results')

# %%
model_to_s3(disamb)

# %%
d = load_disambiguator('GARP', '../results')

# %%
preds = disamb.disambiguate(shortform_texts)

# %%
a = [text for text, pred in zip(shortform_texts, preds) if pred[0] == 'HGNC:2151']

# %%
len(a)
# Out:
# 8

# %%
a[2]
# Out:
# "Other support for this stabilizing hypothesis comes from studies on the beta-subunit of the rod cyclic nucleotide gated channel (CNG). It has been shown that PRPH2/RDS can bind to the beta subunit of rod CNG, as well as two other non-membrane bound isoforms also coded for by the  Cngb1  gene called glutamic acid rich proteins (GARP1/2) ( Poetsch et\xa0al., 2001; Ritter et\xa0al., 2011 ). The interactions between GARP and PRPH2/RDS were found to be strongest when PRPH2/RDS was in disulfide linked oligomers suggesting the larger PRPH2/RDS complexes might mediate this interaction ( Poetsch et\xa0al., 2001 ). Given the localization of CNGB1 on the plasma membrane, PRPH2/RDS on the disc rim, and GARP1/2 as free cytosolic forms in between, it has been hypothesized that interactions between PRPH2/RDS and GARP could serve as a mechanism by which PRPH2/RDS could regulate the sizing and orientation of the rod discs. In support of this, elimination of GARP in rods causes disorganization in disc sizing and orientation ( Zhang et\xa0al., 2009 ).\nWork assessing the localization of PRPH2/RDS complexes in the photoreceptor cells found that the higher-order PRPH2/RDS oligomers likely don't form until after trafficking to the OS ( Chakraborty et\xa0al., 2008; Poetsch et\xa0al., 2001 ). Since covalently linked PRPH2/RDS has a higher affinity for GARP than non-covalently linked PRPH2/RDS, the assembly of large PRPH2/RDS oligomers in the OS could potentially play a role in spatially or temporally regulating the RDS/GARP interaction, and thus disc size and orientation. This idea is supported by experiments that utilized GFP chimeric proteins to map the subcellular compartments where RDS/CNGB1/GARP interactions took place and showed that while PRPH2/RDS and CNGB1 interact during trafficking, PRPH2/RDS and GARP only interacted in the OS ( Ritter et\xa0al., 2011 ).\nInteractions with GARP are another example of differing roles/function of PRPH2/RDS in rods vs. cones. The cone CNGB subunit does not have a GARP region or free GARP isoforms and PRPH2/RDS does not interact with the cone CNGB channel ( Conley et\xa0al., 2010a ). The precise role of PRPH2/RDS interactions with other proteins, such as GARP, to OS organization is not clearly established, however the model that these interactions play an important role in OS organization is well-supported. In addition, tetraspanins are frequently organizers of membrane domains that can mediate interactions with signaling molecules and cellular structural components in other tissues, so a role for PRPH2/RDS in similar functions is consistent with its larger superfamily ( Andreu and Yanez-Mo, 2014 ).\nThe PRPH2/RDS protein is a critical component for normal vision through its role as a structural protein important for the proper formation of both rod and cone photoreceptor cells. While this is clearly established there is still considerable debate about how exactly PRPH2/RDS is able to fulfill its critical functions. A central remaining question is what the relative functions of the various PRPH2/RDS complexes are. When viewed as a whole, the body of work on the PRPH2/RDS protein strongly suggests that the protein is able to play a complex role in OS formation due to variations in binding affinity for other OS proteins and the relative concentration of the various PRPH2/RDS complexes, which each may possess intrinsic membrane curvature/fusion properties. For example, it is hypothetically possible that large PRPH2/RDS homomeric complexes are core structural components responsible for helping mediate and maintain the curvature of the rim region while smaller and intermediate RDS/ROM-1 complexes are responsible for mediating membrane fusion or organizing protein domains with interacting partners such as GARP to stabilize and properly structure the OS. While ample evidence discussed above would suggest that the PRPH2/RDS complexes have some level of distinct functional importance, no current evidence can adequatel ...

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
i = 2
j = 4

# %%
i |= j

# %%
i = i | j
# Out:
# 4

# %%
i
# Out:
# 6

# %%
'10 | 100 = 110'
