# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground
# Out:
# INFO: [2020-01-13 11:03:42] /Users/albertsteppi/adeft/adeft/recognize.py - OneShotRecognizer not available. AdeftLongformScorer has not been built successfully.

# %%
shortforms = ['PCS']
genes = []
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['PCS'].top()

# %%
top
# Out:
# [('physical component summary', 82.6315789473684),
#  ('score', 35.193548387096776),
#  ('the physical component summary', 29.548387096774192),
#  ('sulfate', 29.0188679245283),
#  ('physical component score', 26.967741935483872),
#  ('p cresyl sulfate', 25.82758620689655),
#  ('physical', 23.379310344827587),
#  ('scale', 18.064516129032256),
#  ('phytochelatin synthase', 16.705882352941178),
#  ('physical component summary score', 14.666666666666666),
#  ('summary', 13.057692307692307),
#  ('portacaval shunt', 11.571428571428571),
#  ('p cresol sulfate', 10.736842105263158),
#  ('pain catastrophizing scale', 10.666666666666668),
#  ('the pain catastrophizing scale', 9.555555555555557),
#  ('the physical', 9.454545454545453),
#  ('syndrome', 8.625),
#  ('post concussive syndrome', 8.333333333333334),
#  ('the physical component score', 8.0),
#  ('posterior circulation stroke', 7.25),
#  ('component score', 7.085714285714285),
#  ('indoxyl sulfate is and p cresyl sulfate', 6.666666666666667),
#  ('post concussive symptoms', 6.25),
#  ('indoxyl sulfate is and p cresol sulfate', 6.0),
#  ('a physical component summary', 5.714285714285714),
#  ('physical composite summary', 5.428571428571429),
#  ('porous calcium silicate', 5.428571428571429),
#  ('physical component scale', 5.25),
#  ('premature chromatid separation', 5.0),
#  ('the physical component summary score', 5.0),
#  ('physical health', 4.666666666666667),
#  ('psoralea corylifolia seeds', 4.666666666666667),
#  ('symptoms', 4.363636363636363),
#  ('sf 36 physical component summary', 4.333333333333333),
#  ('and physical', 4.0),
#  ('and physical component summary', 4.0),
#  ('component summary', 3.9381443298969003),
#  ('synthase', 3.7142857142857153),
#  ('treated with indoxyl sulfate is and p cresol sulfate', 3.6666666666666665),
#  ('shunt', 3.625),
#  ('component summary score', 3.6000000000000014),
#  ('primary cytoreductive surgery', 3.6),
#  ('and p cresol sulfate', 3.5),
#  ('by phytochelatin synthase', 3.0),
#  ('of p cresyl sulfate', 3.0),
#  ('the physical component scale', 3.0),
#  ('sf 36 physical component score', 3.0),
#  ('the physical health component score', 3.0),
#  ('surgery', 2.8571428571428568),
#  ('composite score', 2.6666666666666665),
#  ('postconcussion syndrome', 2.5),
#  ('of portacaval shunt', 2.5),
#  ('physical composite score', 2.5),
#  ('into physical component summary', 2.5),
#  ('of physical component summary', 2.5),
#  ('catastrophizing', 2.4),
#  ('pain catastrophizing', 2.0),
#  ('postconcussion symptoms', 2.0),
#  ('12 physical component score', 2.0),
#  ('is p cresyl sulfate', 2.0),
#  ('of post concussive symptoms', 2.0),
#  ('of post concussive syndrome', 2.0),
#  ('rats with portacaval shunt', 2.0),
#  ('a physical component summary score', 2.0),
#  ('of physical component summary score', 2.0),
#  ('two summary score physical component summary', 2.0),
#  ('score displayed a significant inverse linear correlation with the physical component summary scale',
#   2),
#  ('ent factors in box behnken design and responses of resveratrol rvt loaded porous calcium silicate',
#   2),
#  ('e 3 carboxy 4 methyl 5 propyl 2 furanpropionic acid cmpf indoxyl sulfate is p cresol sulfate',
#   2),
#  ('n bodily pain and general health score in the cpap group the change in physical component summary',
#   2),
#  ('stroke', 1.8000000000000007),
#  ('and p cresyl sulfate', 1.7777777777777777),
#  ('health', 1.7142857142857144),
#  ('seeds', 1.7142857142857144),
#  ('chromatid separation', 1.7142857142857144),
#  ('sites', 1.3333333333333333),
#  ('paracresyl sulfate', 1.3333333333333333),
#  ('mcs and physical component summary', 1.3333333333333333),
#  ('the physical component summary scale', 1.3333333333333333),
#  ('indoxyl sulfate is p cresol sulfate', 1.3333333333333333),
#  ('mental component summary mcs physical component summary',
#   1.3333333333333333),
#  ('post error slowing pes and post conflict slowing', 1.3333333333333333),
#  ('mice treated with indoxyl sulfate is and p cresol sulfate',
#   1.3333333333333333),
#  ('stress', 1.0),
#  ('synthetase', 1.0),
#  ('bdi catastrophizing', 1.0),
#  ('both physical', 1.0),
#  ('collagen synthesis', 1.0),
#  ('with physical', 1.0),
#  ('and paracresyl sulfate', 1.0),
#  ('and the physical', 1.0),
#  ('is phytochelatin synthase', 1.0),
#  ('of phytochelatin synthase', 1.0),
#  ('phosphatidylcholine synthase gene', 1),
#  ('population carrier screen', 1),
#  ('post cataract surgery', 1.0),
#  ('post craniotomy seizures', 1.0),
#  ('potato common scab', 1.0),
#  ('protease cleavage sites', 1.0),
#  ('pseudo cushing syndrome', 1),
#  ('to postnatal corticosteroid', 1.0),
#  ('using the physical', 1.0),
#  ('with the physical', 1.0),
#  ('12 physical component summary', 1.0),
#  ('a physical component scale', 1.0),
#  ('and pain catastrophizing scale', 1.0),
#  ('both physical component summary', 1.0),
#  ('caretaker physical component score', 1),
#  ('effects of portacaval shunt', 1.0),
#  ('elevation of plasma corticosterone', 1),
#  ('of posterior circulation stroke', 1.0),
#  ('pepsin soluble collagen sponge', 1.0),
#  ('physical health composite score', 1.0),
#  ('recent p cresyl sulfate', 1),
#  ('score physical component score', 1.0),
#  ('the enzyme phytochelatin synthase', 1.0),
#  ('the physical composite scale', 1.0),
#  ('with primary cytoreductive surgery', 1.0),
#  ('women physical component summary', 1.0),
#  ('by the enzyme phytochelatin synthase', 1.0),
#  ('by the physical component summary', 1.0),
#  ('calculated the physical component summary', 1.0),
#  ('for the physical component summary', 1.0),
#  ('gathered into physical component summary', 1.0),
#  ('into a physical composite summary', 1.0),
#  ('into the physical component summary', 1.0),
#  ('mhe due to portacaval shunt', 1.0),
#  ('patients with posterior circulation stroke', 1.0),
#  ('peripheral ca 2 + sparks', 1.0),
#  ('physical health component summary score', 1.0),
#  ('s post operative physical health', 1.0),
#  ('the aetiology of postconcussion syndrome', 1),
#  ('the effects of portacaval shunt', 1),
#  ('the patterns of care study', 1.0),
#  ('to determine whether postconcussion syndrome', 1),
#  ('using the pain catastrophizing scale', 1.0),
#  ('with the pain catastrophizing scale', 1.0),
#  ('with the physical component summary', 1.0),
#  ('association of localization posterior circulation stroke', 1.0),
#  ('background and purpose posterior circulation stroke', 1),
#  ('mental mcs and physical component summary', 1.0),
#  ('norm by quartiles physical component summary', 1),
#  ('p cresol or p cresyl sulfate', 1.0),
#  ('physical functioning pf physical component summary', 1.0),
#  ('phytochelatin pcs catalyzed by phytochelatin synthase', 1),
#  ('summary score the physical component summary', 1.0),
#  ('the 13 item pain catastrophizing scale', 1.0),
#  ('the accumulation of p cresyl sulfate', 1),
#  ('the sf 36 physical component summary', 1.0),
#  ('p cresol pc and p cresyl sulfate', 1),
#  ('the structures of six psoralea corylifolia seeds', 1.0),
#  ('mental component score mcs and physical component score', 1.0),
#  ('mental composite score mcs and physical composite score', 1.0),
#  ('mental composite summary mcs and physical composite summary', 1.0),
#  ('to evaluate the differential effects of portacaval shunt', 1),
#  ('to investigated the occurrence of post concussive symptoms', 1),
#  ('unadjusted mean sd sf 36 physical component summary', 1.0),
#  ('background aims previous study have reported p cresyl sulfate', 1),
#  ('bodily pain bp and the physical component summary score', 1),
#  ('molecular mechanisms and pathological features of p cresyl sulfate', 1),
#  ('of post error slowing pes and post conflict slowing', 1.0),
#  ('previous study have shown that prostacyclin pgi 2 synthase', 1),
#  ('sf 36 mental component summary mcs physical component summary', 1.0),
#  ('uremic toxins indoxyl sulfate is and p cresyl sulfate', 1.0),
#  ('a mental component summary mcs and a physical component summary', 1.0),
#  ('chronic pain post traumatic stress disorder ptsd and postconcussion syndrome',
#   1.0),
#  ('fig 1 contour plot show effects of porous calcium silicate', 1.0),
#  ('the mental component summary mcs and the physical component summary', 1.0),
#  ('uncertainty remain about the related benefits of primary cytoreductive surgery',
#   1),
#  ('ccount and addressed with addition treatment interventions independent association with physical',
#   1),
#  ('drug antimycin a anta amphotericin b amb itraconazole itz strobilurins pyraclostrobin',
#   1),
#  ('in this study resveratrol rvt was loaded onto porous calcium silicate', 1),
#  ('normalized of pcs respectively phytochelatin produced by the enzyme phytochelatin synthase',
#   1),
#  ('pathetic adrenomedullary system under stress conditions 14 16 recent psychological stress',
#   1),
#  ('pksv cells treated with indoxyl sulfate is and p cresol sulfate', 1.0),
#  ('protein bound uremic toxins indoxyl sulfate is and p cresol sulfate', 1),
#  ('protein bound uremic toxins indoxyl sulfate is and p cresyl sulfate', 1),
#  ('se overexpressed results in chromosomal instability cin including premature chromatid separation',
#   1),
#  ('two key enzyme in the synthesis of pcs are phytochelatin synthase', 1),
#  ('and depression score nsaids nonsteroidal anti inflammatory drug the pain catastrophizing scale',
#   1),
#  ('as bronchopulmonary dysplasia bpd anjari et al 2009 exposure to postnatal corticosteroid',
#   1),
#  ('characteristics in all participants by quintile classification of physical component summary score',
#   1),
#  ('collagenase digestible protein cdp and noncollagen protein ncp and percent collagen synthesis',
#   1),
#  ('displaced from the centromere of mitotic chromosomal results in premature chromatid separation',
#   1),
#  ('displayed in supplementary table ii r association of localization posterior circulation stroke',
#   1),
#  ('eins involved in glutathione metabolism one potential targeting identified was phytochelatin synthase',
#   1),
#  ('intraventricular hemorrhage ivh females and male and those exposed to postnatal corticosteroid',
#   1),
#  ('kaplan meier plot of the association between quintile of physical component summary',
#   1.0),
#  ('nce bpi pain sensitivity tpths pain related anxiety pass depression bdi catastrophizing',
#   1),
#  ('nova indicate significant differences between the patients and partners perceived physical health',
#   1),
#  ('oke acs since clinical characteristics mechanisms and outcomes of posterior circulation stroke',
#   1),
#  ('show that mice treated with indoxyl sulfate is and p cresol sulfate', 1.0),
#  ('to cause chromosomal abnormalities depletion of mcm7 also cause premature chromatid separation',
#   1),
#  ('to insulin dexamethasone isobutyl methylxanthine exposure the activity of palmitoyl coa synthetase',
#   1),
#  ('vitality social functioning and general health perceptions 16 from these subscores physical',
#   1),
#  ('1b gene encoding bubr1 cause a rare autosomal recessive disorder premature chromatid separation',
#   1),
#  ('9 we expected moderate to substantial positive correlation with the pain catastrophizing scale',
#   1),
#  ('95 ci = 95 confidence interval sf 12 version 1 physical component summary',
#   1.0),
#  ('a unique dimensions in predicting pain intensity and physical disability pain catastrophizing scale',
#   1),
#  ('al score and subscales score with other conceptually close constructs namely pain catastrophizing',
#   1),
#  ('ally disability extant literature has demonstrated women to reported greater post concussive symptoms',
#   1),
#  ('ament reconstruction aclr the tampa scale for kinesiophobia tsk and pain catastrophizing scale',
#   1),
#  ('analysis of covariance was conducted to compared adjusted physical health component summary score',
#   1),
#  ('archers have then overexpressed γ ecs and other pathway enzyme including phytochelatin synthase',
#   1),
#  ('ated with such injury remain poorly understood many children experience post concussive symptoms',
#   1),
#  ('beliefs 18 48 finally pain catastrophizing was assessed with the pain catastrophizing scale',
#   1),
#  ('cox regression model of the association between quintile of physical component summary score',
#   1),
#  ('deration for other cross cultural development of self reported measured pain catastrophizing scale',
#   1),
#  ('drugable we hypotheses that one such potential targeting in schistosomes is phytochelatin synthase',
#   1),
#  ('e selected referred gene candidates we analyzed the expression patterns of phytochelatin synthase',
#   1),
#  ('ed physician diagnosed arthritis was significant association with decreases score in the physical',
#   1),
#  ('eneral population cohort and osa patients independent association of sleep symptoms with physical',
#   1),
#  ('entration memory and mood 3 4 these symptoms collected define post concussive syndrome',
#   1),
#  ('ependent there is limitation evidence whether localization of stroke within the posterior circulation',
#   1),
#  ('ere prepared by shanghai ocean university shanghai china briefly pepsin soluble collagen sponge',
#   1),
#  ('erence gene candidates selected by three programs the transcript levels of phytochelatin synthetase',
#   1),
#  ('esholds ppt and psychological factors which were evaluate using the pain catastrophizing scale',
#   1),
#  ('esired properties various porous materials e g porous silicon dioxide porous calcium silicate',
#   1),
#  ('estigate the functioning outcomes of novel antidepressants when chronic he prevails portacaval shunt',
#   1),
#  ('eta coefficient baseline participants characteristics by tertile of sf 36 physical component score',
#   1),
#  ('for specific optical remote control of native protein using a photoswitchable conditions subunit',
#   1),
#  ('functioning 19 the instrument also including two summary score the physical component summary',
#   1),
#  ('imated however ipsilateral vah is common observed in patients with posterior circulation stroke',
#   1),
#  ('in liver transplant candidates remain unclear we examine whether the physical component summary',
#   1),
#  ('ional social functioning and vitality yielding 2 summary score the physical component summary',
#   1),
#  ('ke ovarian cancer 1 7 current managed of usc including primary cytoreductive surgery',
#   1),
#  ('limitation bodily pain and general health perceptions are gathered into physical component summary',
#   1),
#  ('mall heavy metal binding peptides which are synthesized from glutathione by phytochelatin synthase',
#   1),
#  ('measured of pain sensitivity and pain catastrophizing 61 comparison of a pain catastrophizing',
#   1),
#  ('of the variance multiple logistic regression predicting partners s post operative physical health',
#   1),
#  ('of the variance multiple logistic regression predicting patients s post operative physical health',
#   1),
#  ('orbid diagnosed of chronic pain post traumatic stress disorder ptsd and postconcussion syndrome',
#   1),
#  ('parase overexpressed cells are found to be thinner suggested premature sister chromatid separation',
#   1),
#  ('pct and including chronic pain post traumatic stress disorder ptsd and postconcussion syndrome',
#   1),
#  ('r who were treated with neoadjuvant chemotherapy nact compared with primary cytoreductive surgery',
#   1),
#  ('recent clinical study have shown that increased serum levels of p cresyl sulfate',
#   1),
#  ('red to anterior circulation stroke acs percentage of patients with posterior circulation stroke',
#   1),
#  ('reduced quality of life particularly on physical functioning the summary physical component score',
#   1),
#  ('rmed phytochelatin pcs grill et al 1985 which are synthesized by phytochelatin synthase',
#   1),
#  ('score of individual domains were summarized to three composite score physical composite summary',
#   1),
#  ('show that a 50 reduction leads to increased centromere separation premature chromatid separation',
#   1),
#  ('study three key gene encoding protein involved in divalent cation uptake zip detoxification',
#   1),
#  ('t chemotherapy nac and interval cytoreductive to women treated with primary cytoreductive surgery',
#   1),
#  ('tay los facility discharge and clinical significant veterans rand 12 physical component score',
#   1),
#  ('the follow outcomes variables sf 36 mental component summary mcs physical component summary',
#   1),
#  ('their parental reported on parental protective responses to pain pprp pain catastrophizing scale',
#   1),
#  ('thritis participants with arthritis had significant lower score on the physical composite scale',
#   1),
#  ('ures of pain severe bpi pain sensitivity tpths negative affect pass bdi catastrophizing',
#   1),
#  ('a functioning viral particle 16 a novel vaccine strategy targeting the protease cleavage sites',
#   1),
#  ('and emotional domains of hrqol in decompensated cirrhosis 10 11 the physical component summary',
#   1),
#  ('and structures equation model were using the two component model gave physical component summary',
#   1),
#  ('ao inhibitors with mao b selected our previous study show that psoralea corylifolia seeds',
#   1),
#  ('asures as the main outcomes for our analysis physical functioning pf physical component summary',
#   1),
#  ('ated with the highest case fatality ratio of all gynecologic cancer primary cytoreductive surgery',
#   1),
#  ('atients and assessed the differences in mental composite score mcs and physical composite score',
#   1),
#  ('bolism likely to be important but still under investigated in helminths is phytochelatin synthase',
#   1),
#  ('cardiac hypertrophy and cardiorenal fibrosis induced by indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('cirrhotic patients with minimal hepatic encephalopathy mhe rats with mhe due to portacaval shunt',
#   1),
#  ('compartments or tunnels connecting differences activity sites here we show that propionyl coa synthase',
#   1),
#  ('ctioning role emotional and mental health 7 these eight domains are summarized into physical',
#   1),
#  ('ctivity in fig 3b ranks were phellodendron amurense barks pab > psoralea corylifolia seeds',
#   1),
#  ('d those enrolled in the comparison group mental component summary mcs physical component summary',
#   1),
#  ('differences according to the analysis whether we analyzed subscales or total post concussive syndrome',
#   1),
#  ('domains summarized via norm based score algorithms referred to as the physical component summary',
#   1),
#  ('e 611 participants men reported high mental composite summary mcs and physical composite summary',
#   1),
#  ('e at http www qualitymetric com two summary measured were obtained physical component summary',
#   1),
#  ('e been association with cardiovascular disease these solutes indoxyl sulfate is p cresol sulfate',
#   1),
#  ('e survivors we examine the relationship between thi and depression ptsd post concussive syndrome',
#   1),
#  ('e well characterized variation of the medial frontal lobes variables of the paracingulate sulcus',
#   1),
#  ('each domains score was further summarised and standardised into the physical health component score',
#   1),
#  ('eatment phase with the continuation phase have the highest the physical health composite score',
#   1),
#  ('emotional problems and mental health which can be categorized into the physical component summary',
#   1),
#  ('equency of trauma exposure also had negative association with physical and mental health physical',
#   1),
#  ('es measured physical problems pain and self rated health constitute a physical component scale',
#   1),
#  ('essment and no missing data for selected baseline factors not applicable physical component score',
#   1),
#  ('flammatory cytokines auc cortisol with change in the mental mcs and physical component summary',
#   1),
#  ('for using among arabic speaking patients from a clinical perspective the pain catastrophizing scale',
#   1),
#  ('gy fatigue and general health perceptions were aggregated into two summary measured the physical',
#   1),
#  ('hand side of the corresponding control under these experimental conditions is p cresyl sulfate',
#   1),
#  ('higher prevalence of ui ui was independent association with both lower physical component score',
#   1),
#  ('ient outcomes this cross sectional study tested the hypothesis that the physical component summary',
#   1),
#  ('in neurological deficits in rats with minimal hepatic encephalopathy mhe due to portacaval shunt',
#   1),
#  ('l problems and mental health 5 these dimensions were gathered into physical component summary',
#   1),
#  ('l symptoms checklist bcpt assessed late treatment related symptoms sf 12 physical component scale',
#   1),
#  ('lial cells using in a with representative images of these features premature chromatid separation',
#   1),
#  ('luate solid dispersion tablets containing a poorly water soluble drug using porous calcium silicate',
#   1),
#  ('may be a candidates for drug targeting to control schistosomiasis this gene phytochelatin synthase',
#   1),
#  ('mensions extracted from 12 item table 2 28 30 two factors physical component summary',
#   1),
#  ('mental health mh these eight domains are further summarized into the physical component summary',
#   1),
#  ('metabolome as shown by the increased excreted of phenylacetylglutamine pag and p cresol sulfate',
#   1),
#  ('movement and injury pain catastrophizing was assessed with the 13 item pain catastrophizing scale',
#   1),
#  ('mtbi are evaluate in us emergency departments 1 the prevalence of post concussive syndrome',
#   1),
#  ('nal problems and mental health these dimensions can be categorized into physical component summary',
#   1),
#  ('nd depression 22 our results also show that association between thi post concussive syndrome',
#   1),
#  ('obavaisoflavone nbi and biochanin a bio a the structures of six psoralea corylifolia seeds',
#   1),
#  ('ocial functioning sf mental health mh and role emotional re the physical component summary',
#   1),
#  ('patients were higher compared with those in deceased patients score of physical component summary',
#   1),
#  ('plant candidates is an important area for study correlation between the physical component summary',
#   1),
#  ('possible causal link between va hypoplasia vah and the incidence of posterior circulation stroke',
#   1),
#  ('proportion who were not awarded disability pension by quartiles of the physical component summary',
#   1),
#  ('qol in chinese unemployed people coping had significant effects on both physical component summary',
#   1),
#  ('responses from the sf 12 questionnaire was using to calculated normalized physical component summary',
#   1),
#  ('ry characteristics and non injury child and family factors as predictor of postconcussion symptoms',
#   1),
#  ('s pcs are synthesized directly from reduced glutathione gsh by the enzyme phytochelatin synthase',
#   1),
#  ('s uncertain this study assessed the association of regular chocolate consumption with the physical',
#   1),
#  ('score in the role functioning general health and vitality domains and physical component summary',
#   1),
#  ('stribution of this gene in the fungi than previous appreciated a putative phytochelatin synthase',
#   1),
#  ('study period suppl table ii r fig 2 association of localization posterior circulation stroke',
#   1),
#  ('symptoms count ob patients had a significant higher better hrql mean physical component summary',
#   1),
#  ('t is severe enough to cause functioning disability and require treatment pelvic congestion syndrome',
#   1),
#  ('take at the culprit sites of acute myocardial infarction ami after percutaneous coronary stenting',
#   1),
#  ('tal health z transformed and normalized domains score were group into physical component summary',
#   1),
#  ('the survey responses allow generate of two component score the physical component summary score',
#   1),
#  ('these subscales are using to generate two composite summary score the physical composite summary',
#   1),
#  ('tive health regarding hrqol score among all subject the median physical component summary score',
#   1),
#  ('uestionnaire 25 and including 12 item which allow for calculated a physical component summary',
#   1),
#  ('uremic toxins such as indoxyl sulfate is and p cresol or p cresyl sulfate',
#   1),
#  ('using the anticholinergic drug scale the hrqol measured of interest were physical component score',
#   1),
#  ('voidance behaviours in a similar vein the fear avoidance model describes how pain catastrophizing',
#   1),
#  ('36 item short form health survey sf 36 mental component summary mcs physical component summary',
#   1),
#  ('42 patients died 280 of whom died of cardiovascular disease 49 the physical component score',
#   1),
#  ('7 8 9 to our knowledge only a few study investigated whether physical composite summary',
#   1),
#  ('al problems and mental health these dimensions can be categorized into a physical component scale',
#   1),
#  ('alitatively similar to those reported for linear regression of pcs this study found better health',
#   1),
#  ('ality of life were measured using the mental composite summary mcs and physical composite summary',
#   1),
#  ('and coumarins emphasize a high potential to inhibit mao b notably psoralea corylifolia l seeds',
#   1),
#  ('and social functioning results from sf 36 are further summarized into a physical composite summary',
#   1),
#  ('andom effects model we searched for the study that reported the physical component summary score',
#   1),
#  ('atrium hra later right atrium lra low septal right atrium sra and proximal coronary sinus',
#   1),
#  ('better health status score can also be summarized in 2 global score physical component score',
#   1),
#  ('control the cognitive and neural mechanisms of post error slowing pes and post conflict slowing',
#   1),
#  ('cted a compared study to examine the similar and differences between is p cresyl sulfate',
#   1),
#  ('d further research is require to establish a standard biomarker for pcs post concussive syndrome',
#   1),
#  ('days modified memory symptoms assessed scale 12 item short form health survey sf 12 physical',
#   1),
#  ('e proposed four hypotheses i ob patients would have better hrql physical component summary score',
#   1),
#  ('eclinical evaluate of a novel hiv vaccine strategy targeting the 12 viral protease cleavage sites',
#   1),
#  ('efits of an exercise referral scheme health related quality of life dimensions score and physical',
#   1),
#  ('ent score mcs normative score for us females according to age 21 physical component score',
#   1),
#  ('er hrqol two summary score are derived from the eight subscales physical component summary score',
#   1),
#  ('f 36 assessed eight generic scale of hrqol two composite measured the physical component summary',
#   1),
#  ('ferences between the patients and partners health status i e the physical health component score',
#   1),
#  ('fficient and added together with a pcs constant value to provide physical component summary score',
#   1),
#  ('functioning limitation scale jfls and hrqol measured by short form 12 s physical component summary',
#   1),
#  ('gregated into two summary score a mental component summary mcs and a physical component summary',
#   1),
#  ('h in patients with chronic kidney disease ckd is cardiovascular disease here p cresyl sulfate',
#   1),
#  ('health these eight domains can be summarized in two overall measured the physical component scale',
#   1),
#  ('hese 8 category score are aggregated into two summary scale the physical component summary scale',
#   1),
#  ('hese same symptoms remain beyond 3 months and are referred to as persistent postconcussion symptoms',
#   1),
#  ('hort form 12 sf 12v2 questionnaire 27 this instrument allow for the calculated of physical',
#   1),
#  ('icant reduction in pcs score were observed unadjusted mean sd sf 36 physical component summary',
#   1),
#  ('ient with chronic heart failure chf and may affect mental mcs and physical component summary',
#   1),
#  ('ii completed the medical outcomes trust short form sf 12 at baseline physical component summary',
#   1),
#  ('ility to provide informed consent priming was performed by mean of the pain catastrophizing scale',
#   1),
#  ('in a previous study by our group its was determine that pomegranate juice concentrated solutes',
#   1),
#  ('in compared sf 36 score 31 32 from the questionnaire responses the physical component score',
#   1),
#  ('ite summary scale were using the mental component summary mcs and the physical component summary',
#   1),
#  ('l binding sites that can binding a single lanthanide ion results in substantial pseudocontact shifts',
#   1),
#  ('lagen protein ncp fractions of the ossicles was measured and the percentage of collagen synthesis',
#   1),
#  ('le for study recruitment n = 574 upon admission patients completed the pain catastrophizing scale',
#   1),
#  ('lenge in biomedicine in this study four type of sample including pepsin soluble collagen sponge',
#   1),
#  ('lthy young adults we examine the association between crf and the hrqol physical component summary',
#   1),
#  ('measured of ses its examine physical health at midlife measured by the physical component summary',
#   1),
#  ('measured were utilised in this study the two summary measured are the physical component summary',
#   1),
#  ('mes figure 1 kaplan meier plot of the association between quintile of physical component summary',
#   1),
#  ('mes presented lower score in both mental component summary mcs and in psysical component summary',
#   1),
#  ('motic stress and non physiological levels of hyperosmotic stress induced peripheral ca 2 + sparks',
#   1),
#  ('mouse proximal renal tubular pksv cells treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('ms patients 17 we calculated the mental component score mcs and the physical component score',
#   1),
#  ('n injury mtbi while deployed up to one third will experience persistent post concussive symptoms',
#   1),
#  ('naire this may have results in a healthier subset of current smokers physical component score',
#   1),
#  ('nor 10 6 m and 10 5 m significant concentrated dependent decreases in percentage shortening',
#   1),
#  ('nosis enrolled in medicare managed care hrqol was measured by the physical component summary score',
#   1),
#  ('o 100 best state of health from these dimensions two summary scale physical component summary',
#   1),
#  ('observed in patients with chronic kidney disease ckd indoxyl sulfate is and p cresyl sulfate',
#   1),
#  ('ocial and role functioning are assessed item are weight and total to provide both physical',
#   1),
#  ('ociated of edss score change and relapse occurrence with msqol 54 physical health composite score',
#   1),
#  ('om the former two evaluate however vague reported of symptoms such as post concussive syndrome',
#   1),
#  ('on and analyzed hrqol by using short form 36 and patients demographics physical component summary',
#   1),
#  ('on or more persistent after age and bmi adjusted unadjusted mean sd physical component summary',
#   1),
#  ('r arteries and their branches 1 2 study have shown that posterior circulation ischemic stroke',
#   1),
#  ('rance flexibility and hrql medical outcomes study short form health survey sf 36 the physical',
#   1),
#  ('re combined to form summary score for physical and mental hrqol called physical component summary',
#   1),
#  ('re s2 a pleural effusions from uremic patients exert higher concentrated of p cresyl sulfate',
#   1),
#  ('rkinson s disease questionnaire 39 item pdq 39 for qol including the physical component summary',
#   1),
#  ('role emotional and mental health these concepts are summed to create a physical component summary',
#   1),
#  ('rospectively assessed using the short form 12 in 2478 pdac patients the physical component summary',
#   1),
#  ('s collected for each subscales were combined to provide two overall score physical component score',
#   1),
#  ('s role in cd and as stress tolerance and accumulation enzymatic activity of phytochelatin synthase',
#   1),
#  ('selected all those investigated in which the pvaq was related to the pain catastrophizing scale',
#   1),
#  ('sf 36v2 are using to constitute the mental component summary mcs and physical component summary',
#   1),
#  ('sibly by reduced tissue accumulation of uremic toxins indoxyl sulfate is and p cresyl sulfate',
#   1),
#  ('signaling is important the mechanisms by which the tgfβ pathway is activity post cataract surgery',
#   1),
#  ('stemic retention and accumulation of uremic toxins 6 indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('stood most children recover successfully but some suffer from a ranging of post concussive symptoms',
#   1),
#  ('t health dimensions can be summarized by two global hrql indicate the physical component summary',
#   1),
#  ('termine which ob patients should be screen for cs comparison of physical component summary score',
#   1),
#  ('the aims was to study the advantages of the using of a temporary portacaval shunt',
#   1),
#  ('therapeutic approach to improve cognitive functioning in patients with he rats with porta cava shunt',
#   1),
#  ('this is partially related to a myriad of potential chronic tbi related post concussive symptoms',
#   1),
#  ('uded seizures occurring in the first 24 postoperative hours as be seizures related to craniotomy',
#   1),
#  ('ve cognitive responses related to pain its is common assessed using the pain catastrophizing scale',
#   1),
#  ('vering 8 domains assessed the subject s physical and mental status the physical composite scale',
#   1),
#  ('we calculated two summary score from its eight scale first the physical component summary score',
#   1),
#  ('white mineral trioxide aggregated wmta mta prepared cs ah plus ahp and pulp canal sealer',
#   1),
#  ('widely using including in patients with osa asthma and copd 23 the physical component score',
#   1),
#  ('with the highest ri b in this screen were glycyrrhiza uralensis gur psoralea corylifolia seeds',
#   1),
#  ('00 100 scale mean and standard deviation were using to expression hrqol as physical composite score',
#   1),
#  ('2 recent clinical study have shown that the accumulation of a uremic toxins p cresyl sulfate',
#   1),
#  ('21 31 qol can be measured using the mental component scale mcs and physical component scale',
#   1),
#  ('27 age was negative related to all sf 36 physical domains score and physical component summary',
#   1),
#  ('31 st 2004 baseline measured of health related quality of life were estimated using the physical',
#   1),
#  ('74 and health problems 23 thi also appears to increased the risk of post concussive syndrome',
#   1),
#  ('= standard deviation 95 ci = 95 confidence interval sf 12 version 1 physical component summary',
#   1),
#  ('a produced uremic toxins such as advanced glycation end production phenols e g p cresyl sulfate',
#   1),
#  ('ace interviews we reported averages for the eight major domains and mental mcs and physical health',
#   1),
#  ('age were shown to be association with both mental component score mcs and physical component score',
#   1),
#  ('al health 57 4 and physical functioning 57 1 70 3 improve their physical component summary',
#   1),
#  ('al morbidity was association with all the score from sf 36 in multivariable analyses the physical',
#   1),
#  ('and hrqol was measured using the short form 12v2 which containing a physical component summary score',
#   1),
#  ('arse chain reaction results show that mice treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('ase chain reaction analysis show that mice treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('b western blotting show that pksv cells treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('barrier bbb was measured in male sprague dawley rats subject to 16 weeks of portacaval shunt',
#   1),
#  ('between pcs and gender was not significant p = 0 270 association between self perceived physical',
#   1),
#  ('binding low molecular weight compounds such as indoxyl sulfate is p cresol or p cresyl sulfate',
#   1),
#  ('ble solid however the shelf life of litchi fruit at ambient temperature after pre cold storage',
#   1),
#  ('cco using 18 27 charlson comorbidity score 12 veterans rand 12 vr 12 physical component score',
#   1),
#  ('crop debris 13 30 41 in the current study a significant decreases in potato tuber disease',
#   1),
#  ('d by the retention of various uremic toxins including the protein bound solutes p cresyl sulfate',
#   1),
#  ('death in patients with chronic kidney disease a body of evidence suggested that p cresyl sulfate',
#   1),
#  ('discarded i e returned to the ocean either dead or alive quantifying the post capture survival',
#   1),
#  ('dney disease ckd is a major health problems worldwide indoxyl sulfate is and p cresyl sulfate',
#   1),
#  ('down follow an error or conflict each called post error slowing pes and post conflict slowing',
#   1),
#  ('e another spearman correlation 0 12 p value < 0 0001 association of physical component summary',
#   1),
#  ('e potential for i v penicillins but not non penicillins to induced early post craniotomy seizures',
#   1),
#  ('ed of 1112 participants with ckd and baseline quality of life data the physical component summary',
#   1),
#  ('ex is also a promising predictor of general health status using the physical health component score',
#   1),
#  ('f the baseline ankle brachial index abi measured with change in sf 36 physical component score',
#   1),
#  ('follow up was measured using the sf 12 mental component score mcs and physical component score',
#   1),
#  ('gene delivery system cs pg pdna complexes were prepared by ionic interaction cs and pegylated cs',
#   1),
#  ('hese aclr study are the tampa scale for kinesiophobia tsk 2 3 and pain catastrophizing scale',
#   1),
#  ('hrqol was assessed by medical outcomes study short form 12 sf 12 with physical component score',
#   1),
#  ('hspwn were group into type a comprising s 3 hydroxyisobutyric acid 3 hiba p cresol sulfate',
#   1),
#  ('ical role in the progression of chronic kidney disease indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('ided for each component the sf 36 score system also generate a physical component summary score',
#   1),
#  ('ify independent variables that were association with the pcs and mcs results show that the physical',
#   1),
#  ('in both men and women with diagnosed osa unadjusted mean sd sf 36 physical component summary',
#   1),
#  ('in may in the future be achieved more effects by inhibit their production p cresol sulfate',
#   1),
#  ('intact and regenerating rats liver we also examine the effects on the liver of portacaval shunt',
#   1),
#  ('ion of gaba a ampa and nmda receptors and restores spatial learning rats with portacaval shunt',
#   1),
#  ('is widely using in research and is representative by its two summary score physical component summary',
#   1),
#  ('item of the sf 12 were selected to reproduce the two summary measured physical component summary',
#   1),
#  ('ity of resveratrol rvt pcs powders fig 1 contour plot show effects of porous calcium silicate',
#   1),
#  ('kidney disease quality of life 36 kdqol 36 short form score for the physical component summary',
#   1),
#  ('luate pain with the visual analog scale vas and assessed qol with the physical component summary',
#   1),
#  ('lues a percentile value mean 5 10 25 median 75 90 95 men physical component summary',
#   1),
#  ('ly in the domains of memory attention and executive functioning as well as post concussive symptoms',
#   1),
#  ('n of compounds that under normalized conditions are excreted by the healthy kidney p cresol sulfate',
#   1),
#  ('n the high levels of sedentary time and treatment related side effects in prostate cancer survivors',
#   1),
#  ('nic pain the most common measured of pain catastrophizing is the 13 item pain catastrophizing scale',
#   1),
#  ('nuous physical and emotional quality of life was assessed by the sf 36 physical component summary',
#   1),
#  ('of sports related mtbi within a short time frame 9 the persistent of post concussive symptoms',
#   1),
#  ('ol stability 7 however soemmering s ring can continuation to expand many years post cataract surgery',
#   1),
#  ('ost impaired hrqol and 100 ideal well be and two summary score the physical component score',
#   1),
#  ('pectively cg and cxg 5 cleavage of glycine from gsh or gsh conjugates by phytochelatin synthase',
#   1),
#  ('plasia bah and to evaluate whether bah is a possible risk factors for posterior circulation stroke',
#   1),
#  ('ptoms were assessed with standard scale hrql was measured with the rand 36 using the physical',
#   1),
#  ('ram marp follow a traumatic tta the study examine change in sf 36 physical component summary',
#   1),
#  ('remic retention solutes are known to interfere with no sgc signaling p cresol p cresyl sulfate',
#   1),
#  ('res the sf 8 can calculated two summary score namely the physical health component summary score',
#   1),
#  ('riables without thresholds the sf 12 score are sub scale into composite score for both physical',
#   1),
#  ('rom the sf 12v1 responses 43 these subscales are using to calculated the physical component summary',
#   1),
#  ('s for vascular remodeling the effects of fibroblast growth factors 23 fgf 23 and paracresyl sulfate',
#   1),
#  ('s in the aohcp group had significant better hrqol as assessed by physical component summary score',
#   1),
#  ('s score > 56 kaplan meier plot of the association between quintile of physical component summary',
#   1),
#  ('se questions which were using in the analyses for the current study the physical component summary',
#   1),
#  ('sf 36 and found that compared with related control case had a lower physical component summary',
#   1),
#  ('short form health survey 12 sf 12 the mental composite score mcs and physical composite score',
#   1),
#  ('smoking status t tested and anova determine mean age bmi and sf 36 physical component summary',
#   1),
#  ('tance 6mwd were association with physical functioning pf p < 0 01 and physical component summary',
#   1),
#  ('tcome of physical and mental health was measured using the sf 8 instrument which produced physical',
#   1),
#  ('tes to completed from the sf 36 two summary domains are calculated the physical component summary',
#   1),
#  ('these data were analyzed in terms of the institutional stratification of the patterns of care study',
#   1),
#  ('tive inhibit of h mao b ri b by extensively extracted plant of psoralea corylifolia seeds',
#   1),
#  ('tract production of uremic solutes in uremia many protein bound solutes such as p cresol sulfate',
#   1),
#  ('ulated on the basis of weight of the individual sf 36 dimensions the physical component summary',
#   1),
#  ('ument consisting of 36 item which can be score as two summary score physical component summary',
#   1),
#  ('umulation of endogenous uremic toxins 2 3 among which indoxyl sulfate is and p cresyl sulfate',
#   1),
#  ('y greater improve on the mental composite scale mcs but not on the physical component scale',
#   1),
#  ('2 two way analysis of variance of short form health survey 12 sf 12 physical composite score',
#   1),
#  ('812 participants with both baseline and follow up data on the abi sf 36 physical component score',
#   1),
#  ('= 1025 qol was measured using the short form 12 sf 12 generate a physical component summary',
#   1),
#  ('a multi sites randomized trial of primary care patients n = 15 889 the physical component scale',
#   1),
#  ('basic study show that protein bound uremic toxins such as indoxyl sulfate is and p crecyl sulfate',
#   1),
#  ('dential noise exposure and hrqol measured by the sf 36 there was no association with the physical',
#   1),
#  ('dy 12 item short form health survey at years 30 which including the physical component summary score',
#   1),
#  ('dy identified anterior n2 as an erp correlation of post error slowing pes and post conflict slowing',
#   1),
#  ('e renal disease esrd short form 36 was using to assessed hrqol its domains component and physical',
#   1),
#  ('each of the eight domains of the sf 36 in addition two summary score physical component summary',
#   1),
#  ('es in the rand 36 can further be divided into two component summary a physical component summary',
#   1),
#  ('i parameters in the human brain as a diagnostic tool for and predictor of post concussive syndrome',
#   1),
#  ('ion to staff responses to the kdqol sf were using to determine the physical health component score',
#   1),
#  ('ith score ranging from 0 to 100 these can be further summarised into a physical component summary',
#   1),
#  ('l membrane in wild type intact mammalian muscles our study show these peripheral ca 2 + sparks',
#   1),
#  ('l we using the short form 36 sf 36 to assessed physical functioning pf physical component summary',
#   1),
#  ('lity of life two summary component score are derived from the sf 12 the physical component score',
#   1),
#  ('may be accumulation in to 8 subscales which again are summed into a physical component summary score',
#   1),
#  ('mean that mcs only measured the variation in mental health that is not related to physical health',
#   1),
#  ('n anemia and hrql in individual with copd in a population based sample in these individual hrql',
#   1),
#  ('ociated with both ever and current cam using the finding that a drop in physical component score',
#   1),
#  ('ores from specific item from the eight domains of the sf 36 with physical component summary score',
#   1),
#  ('ps group i was composed of sham operative control group ii underwent end to side portacaval shunt',
#   1),
#  ('q score decreases all contents of the oiq were correlation with depression bdi ii and the physical',
#   1),
#  ('quare rmse = root mean square error fig 1 contour plot show effects of porous calcium silicate',
#   1),
#  ('ranks as the fourth main food crop produced after rice wheat and maize 1 potato common scab',
#   1),
#  ('re and mental health mh two summary scale from the sf 36 including the physical component score',
#   1),
#  ('red using a five point single item scale and hrqol was measured using the physical component scale',
#   1),
#  ('rse in order to assessed if indole 3 acetic acid iaa indoxyl sulfate is and paracresyl sulfate',
#   1),
#  ('ry adrenal 5 ectopic 6 the z score were calculated for short form 36 domains and physical',
#   1),
#  ('sis patients the purpose of this study was to determine whether the sf 12 physical component score',
#   1),
#  ('ssed by the short form health survey version 2 sf 12v2 from which the physical component summary',
#   1),
#  ('summary kdcs score the score of the sf 36 are also classified into a physical composite summary',
#   1),
#  ('t protein bound uremic toxins due to its higher affinity for serum protein 9 p cresyl sulfate',
#   1),
#  ('the retention of renal excreted compounds may play a role one such compounds is p cresyl sulfate',
#   1),
#  ('the sf 8 the score on both the mental component summary mcs and the physical component summary',
#   1),
#  ('urvey sf 36 29 score the sf 36 score were also separation by the physical component summary',
#   1),
#  ('ver a period of 2 years provide a mental component summary mcs and a physical component summary',
#   1),
#  ('with a standard deviation of 10 22 two summary score of the sf 36 physical component summary',
#   1),
#  ('wth factors β1 and snail expression in mice treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('xiety inventory bai 27 using a cut point of 8 to define significant anxiety and the physical',
#   1),
#  ('2 smad2 p smad3 smad3 p and smad4 when treated with indoxyl sulfate is and p cresol sulfate',
#   1),
#  ('= 0 02 table 3 95 ci = 95 confidence interval sf 12 version 1 physical component summary',
#   1),
#  ('ains score the ohip 14 explained 16 5 of the total variance of sf 12 physical component summary',
#   1),
#  ('e system of the usa and japan have very differences background in 1990 the patterns of care study',
#   1),
#  ('ey from the last two cohort including in this analysis sf 36 and vr 12 physical component summary',
#   1),
#  ('have no or a very low effects on anemia parameters the role of indole toxins or paracresyl sulfate',
#   1),
#  ('ion ile pbuts such as 3 carboxy 4 methyl 5 propyl 2 furanpropionic acid cmpf p cresyl sulfate',
#   1),
#  ('lysis women with poorly sleep at baseline global psqi > 5 had significant lower p < 001 physical',
#   1),
#  ('mit of detection was 0 2 μg ml spatial distribution of indoxyl sulfate is and p cresyl sulfate',
#   1),
#  ('ne structures on human mao a and mao b fig 1 the structures of six psoralea corylifolia seeds',
#   1),
#  ('ness scale and sf 36 questionnaire the effects of the apnea hypopnea index ahi on sf 36 physical',
#   1),
#  ('r among those in the lowest quartiles of crf p = 015 and among women physical component summary',
#   1),
#  ('reversed for score item no 1 8 9 and 10 each item has its own physical component summary',
#   1),
#  ('s the aims of this work were to assessed these hypotheses we analyzed in rats with portacaval shunt',
#   1),
# ...
#   1),
#  ('vo 2 peak b = 0 24 p = 0 02 increased age show a decline in measured physical performed',
#   1),
#  ('13 62 95 ci 6 47 20 76 p < 0 001 respectively as well as in the physical component summary',
#   1),
#  ('and was sample at 0 2 4 6 and 8 days the other group of fruit was stored at a cold temperature',
#   1),
#  ('ealth component summary mcs 42 2 13 0 n a 32 1 9 9 n a < 0 001 physical health component summary',
#   1),
#  ('ition ht 16 8 30 0 43 48 31 1 76 76 22 9 < 0 001 hrqol summary score physical health score',
#   1),
#  ('10 16 ≤ 44 60 44 61 53 71 57 94 ≥ 65 51 44 10 54 ≤ 43 42 43 43 55 08 58 96 physical component score',
#   1),
#  ('circulation', 0.0),
#  ('component', 0.0),
#  ('corticosteroid', 0.0),
#  ('corticosterone', 0.0),
#  ('craniotomy', 0.0),
#  ('cs', 0.0),
#  ('detoxification', 0.0),
#  ('disease', 0.0),
#  ('gene', 0.0),
#  ('hrql', 0.0),
#  ('performed', 0.0),
#  ('pyraclostrobin', 0.0),
#  ('scab', 0.0),
#  ('screen', 0.0),
#  ('sealer', 0.0),
#  ('seizures', 0.0),
#  ('separation', 0.0),
#  ('shifts', 0.0),
#  ('shortening', 0.0),
#  ('silicate', 0.0),
#  ('sinus', 0.0),
#  ('slowing', 0.0),
#  ('solutes', 0.0),
#  ('sparks', 0.0),
#  ('sponge', 0.0),
#  ('stenting', 0.0),
#  ('storage', 0.0),
#  ('study', 0.0),
#  ('subunit', 0.0),
#  ('sulcus', 0.0),
#  ('survival', 0.0),
#  ('survivors', 0.0),
#  ('synthesis', 0.0),
#  ('temperature', 0.0),
#  ('+ sparks', 0.0),
#  ('001 physical', 0.0),
#  ('12 physical', 0.0),
#  ('2 synthase', 0.0),
#  ('36 physical', 0.0),
#  ('better health', 0.0),
#  ('calcium silicate', 0.0),
#  ('called sites', 0.0),
#  ('canal sealer', 0.0),
#  ('cancer survivors', 0.0),
#  ('cap stress', 0.0),
#  ('capture survival', 0.0),
#  ('care study', 0.0),
#  ('carrier screen', 0.0),
#  ('cataract surgery', 0.0),
#  ('catastrophizing scale', 0.0),
#  ('cava shunt', 0.0),
#  ('caval shunt', 0.0),
#  ('circulation stroke', 0.0),
#  ('cleavage sites', 0.0),
#  ('coa synthase', 0.0),
#  ('coa synthetase', 0.0),
#  ('cold storage', 0.0),
#  ('cold temperature', 0.0),
#  ('collagen sponge', 0.0),
#  ('common scab', 0.0),
#  ('component scale', 0.0),
#  ('composite scale', 0.0),
#  ('composite summary', 0.0),
#  ('concentrated solutes', 0.0),
#  ('concussive symptoms', 0.0),
#  ('concussive syndrome', 0.0),
#  ('conditions subunit', 0.0),
#  ('conflict slowing', 0.0),
#  ('congestion syndrome', 0.0),
#  ('coronary sinus', 0.0),
#  ('coronary stenting', 0.0),
#  ('corylifolia seeds', 0.0),
#  ('craniotomy seizures', 0.0),
#  ('crecyl sulfate', 0.0),
#  ('cresol sulfate', 0.0),
#  ('cresyl sulfate', 0.0),
#  ('cushing syndrome', 0.0),
#  ('cytoreductive surgery', 0.0),
#  ('health physical', 0.0),
#  ('health score', 0.0),
#  ('individual hrql', 0.0),
#  ('into physical', 0.0),
#  ('ischemic stroke', 0.0),
#  ('l seeds', 0.0),
#  ('of physical', 0.0),
#  ('one component', 0.0),
#  ('paracingulate sulcus', 0.0),
#  ('pegylated cs', 0.0),
#  ('perceived physical', 0.0),
#  ('percentage shortening', 0.0),
#  ('physical performed', 0.0),
#  ('phytochelatin synthetase', 0.0),
#  ('plasma corticosterone', 0.0),
#  ('posterior circulation', 0.0),
#  ('postnatal corticosteroid', 0.0),
#  ('produced physical', 0.0),
#  ('pseudocontact shifts', 0.0),
#  ('psychological stress', 0.0),
#  ('strobilurins pyraclostrobin', 0.0),
#  ('subscores physical', 0.0),
#  ('summary scale', 0.0),
#  ('summary score', 0.0),
#  ('synthase gene', 0.0),
#  ('to craniotomy', 0.0),
#  ('tuber disease', 0.0),
#  ('zip detoxification', 0.0),
#  ('2 + sparks', 0.0),
#  ('36 the physical', 0.0),
#  ('< 001 physical', 0.0),
#  ('a cold temperature', 0.0),
#  ('a pain catastrophizing', 0.0),
#  ('after portacaval shunt', 0.0),
#  ('analyses the physical', 0.0),
#  ('and one component', 0.0),
#  ('and pegylated cs', 0.0),
#  ('and physical health', 0.0),
#  ('and postconcussion syndrome', 0.0),
#  ('are phytochelatin synthase', 0.0),
#  ('association with physical', 0.0),
#  ('calculated of physical', 0.0),
#  ('circulation ischemic stroke', 0.0),
#  ('component and physical', 0.0),
#  ('component summary scale', 0.0),
#  ('corylifolia l seeds', 0.0),
#  ('depression bdi catastrophizing', 0.0),
#  ('domains and physical', 0.0),
#  ('enzyme phytochelatin synthase', 0.0),
#  ('for both physical', 0.0),
#  ('found better health', 0.0),
#  ('gene phytochelatin synthase', 0.0),
#  ('health component score', 0.0),
#  ('health component summary', 0.0),
#  ('health composite score', 0.0),
#  ('how pain catastrophizing', 0.0),
#  ('in percentage shortening', 0.0),
#  ('in the physical', 0.0),
#  ('including phytochelatin synthase', 0.0),
#  ('itz strobilurins pyraclostrobin', 0.0),
#  ('juice concentrated solutes', 0.0),
#  ('mcs and physical', 0.0),
#  ('measured physical performed', 0.0),
#  ('measured the physical', 0.0),
#  ('mental health physical', 0.0),
#  ('namely pain catastrophizing', 0.0),
#  ('of care study', 0.0),
#  ('of collagen synthesis', 0.0),
#  ('of phytochelatin synthetase', 0.0),
#  ('of plasma corticosterone', 0.0),
#  ('of postconcussion symptoms', 0.0),
#  ('of postconcussion syndrome', 0.0),
#  ('operative physical health', 0.0),
#  ('or paracresyl sulfate', 0.0),
#  ('or portacaval shunt', 0.0),
#  ('p crecyl sulfate', 0.0),
#  ('palmitoyl coa synthetase', 0.0),
#  ('pass bdi catastrophizing', 0.0),
#  ('peak cap stress', 0.0),
#  ('pelvic congestion syndrome', 0.0),
#  ('perceived physical health', 0.0),
#  ('percent collagen synthesis', 0.0),
#  ('percutaneous coronary stenting', 0.0),
#  ('persistent postconcussion symptoms', 0.0),
#  ('pgi 2 synthase', 0.0),
#  ('photoswitchable conditions subunit', 0.0),
#  ('physical composite scale', 0.0),
#  ('physical health score', 0.0),
#  ('pontine called sites', 0.0),
#  ('porta cava shunt', 0.0),
#  ('porta caval shunt', 0.0),
#  ('post capture survival', 0.0),
#  ('post conflict slowing', 0.0),
#  ('potato tuber disease', 0.0),
#  ('pre cold storage', 0.0),
#  ('prevails portacaval shunt', 0.0),
#  ('propionyl coa synthase', 0.0),
#  ('prostate cancer survivors', 0.0),
#  ('provide both physical', 0.0),
#  ('proximal coronary sinus', 0.0),
#  ('psysical component summary', 0.0),
#  ('pulp canal sealer', 0.0),
#  ('putative phytochelatin synthase', 0.0),
#  ('recent psychological stress', 0.0),
#  ('related to craniotomy', 0.0),
#  ('score and physical', 0.0),
#  ('self perceived physical', 0.0),
#  ('sf 12 physical', 0.0),
#  ('sf 36 physical', 0.0),
#  ('side portacaval shunt', 0.0),
#  ('sister chromatid separation', 0.0),
#  ('soluble collagen sponge', 0.0),
#  ('subscales and physical', 0.0),
#  ('substantial pseudocontact shifts', 0.0),
#  ('summarized into physical', 0.0),
#  ('symptoms with physical', 0.0),
#  ('temporary portacaval shunt', 0.0),
#  ('that the physical', 0.0),
#  ('the paracingulate sulcus', 0.0),
#  ('the physical health', 0.0),
#  ('the posterior circulation', 0.0),
#  ('these individual hrql', 0.0),
#  ('these subscores physical', 0.0),
#  ('to physical health', 0.0),
#  ('to portacaval shunt', 0.0),
#  ('uptake zip detoxification', 0.0),
#  ('was phytochelatin synthase', 0.0),
#  ('whether postconcussion syndrome', 0.0),
#  ('which produced physical', 0.0),
#  ('with portacaval shunt', 0.0),
#  ('worm phytochelatin synthase', 0.0),
#  ('1 physical component summary', 0.0),
#  ('1 potato common scab', 0.0),
#  ('12 physical component scale', 0.0),
#  ('12 physical composite score', 0.0),
#  ('16 recent psychological stress', 0.0),
#  ('21 physical component score', 0.0),
#  ('23 and paracresyl sulfate', 0.0),
#  ('36 domains and physical', 0.0),
#  ('36 physical component score', 0.0),
#  ('36 physical component summary', 0.0),
#  ('36 subscales and physical', 0.0),
#  ('36 using the physical', 0.0),
#  ('53 p cresyl sulfate', 0.0),
#  ('9 p cresyl sulfate', 0.0),
#  ('96 physical component score', 0.0),
#  ('> psoralea corylifolia seeds', 0.0),
#  ('a photoswitchable conditions subunit', 0.0),
#  ('a physical composite summary', 0.0),
#  ('a putative phytochelatin synthase', 0.0),
#  ('a temporary portacaval shunt', 0.0),
#  ('activity of phytochelatin synthase', 0.0),
#  ('activity post cataract surgery', 0.0),
#  ('aetiology of postconcussion syndrome', 0.0),
#  ('affect pass bdi catastrophizing', 0.0),
#  ('after percutaneous coronary stenting', 0.0),
#  ('after pre cold storage', 0.0),
#  ('and mental health physical', 0.0),
#  ('and p crecyl sulfate', 0.0),
#  ('and percent collagen synthesis', 0.0),
#  ('and physical component scale', 0.0),
#  ('and physical component score', 0.0),
#  ('and physical composite score', 0.0),
#  ('and physical composite summary', 0.0),
#  ('and post conflict slowing', 0.0),
#  ('and proximal coronary sinus', 0.0),
#  ('and pulp canal sealer', 0.0),
#  ('anxiety and the physical', 0.0),
#  ('applicable physical component score', 0.0),
#  ('are summarized into physical', 0.0),
#  ('as p cresol sulfate', 0.0),
#  ('as persistent postconcussion symptoms', 0.0),
#  ('as physical composite score', 0.0),
#  ('as post concussive symptoms', 0.0),
#  ('as post concussive syndrome', 0.0),
#  ('association with the physical', 0.0),
#  ('at a cold temperature', 0.0),
#  ('baseline physical component summary', 0.0),
#  ('between self perceived physical', 0.0),
#  ('ca 2 + sparks', 0.0),
#  ('called physical component summary', 0.0),
#  ('cancer primary cytoreductive surgery', 0.0),
#  ('catalyzed by phytochelatin synthase', 0.0),
#  ('cation uptake zip detoxification', 0.0),
#  ('cause premature chromatid separation', 0.0),
#  ('cmpf p cresyl sulfate', 0.0),
#  ('conjugates by phytochelatin synthase', 0.0),
#  ('constructs namely pain catastrophizing', 0.0),
#  ('consumption with the physical', 0.0),
#  ('cresol p cresyl sulfate', 0.0),
#  ('cs and pegylated cs', 0.0),
#  ('decreases in percentage shortening', 0.0),
#  ('define post concussive syndrome', 0.0),
#  ('demographics physical component summary', 0.0),
#  ('derived physical component summary', 0.0),
#  ('describes how pain catastrophizing', 0.0),
#  ('determine whether postconcussion syndrome', 0.0),
#  ('dimensions score and physical', 0.0),
#  ('dioxide porous calcium silicate', 0.0),
#  ('disability pain catastrophizing scale', 0.0),
#  ('disorder premature chromatid separation', 0.0),
#  ('domains component and physical', 0.0),
#  ('due to portacaval shunt', 0.0),
#  ('early post craniotomy seizures', 0.0),
#  ('enzyme including phytochelatin synthase', 0.0),
#  ('estimated using the physical', 0.0),
#  ('experience post concussive symptoms', 0.0),
#  ('exposed to postnatal corticosteroid', 0.0),
#  ('exposure to postnatal corticosteroid', 0.0),
#  ('factors physical component summary', 0.0),
#  ('features premature chromatid separation', 0.0),
#  ('for physical component score', 0.0),
#  ('for posterior circulation stroke', 0.0),
#  ('from these subscores physical', 0.0),
#  ('g p cresyl sulfate', 0.0),
#  ('gave physical component summary', 0.0),
#  ('glutathione by phytochelatin synthase', 0.0),
#  ('greater post concussive symptoms', 0.0),
#  ('gur psoralea corylifolia seeds', 0.0),
#  ('he prevails portacaval shunt', 0.0),
#  ('health component summary score', 0.0),
#  ('helminths is phytochelatin synthase', 0.0),
#  ('hepatectomy or portacaval shunt', 0.0),
#  ('here p cresyl sulfate', 0.0),
#  ('hiba p cresol sulfate', 0.0),
#  ('hrqol physical component summary', 0.0),
#  ('identified was phytochelatin synthase', 0.0),
#  ('ii and the physical', 0.0),
#  ('in measured physical performed', 0.0),
#  ('in physical component score', 0.0),
#  ('in physical component summary', 0.0),
#  ('in potato tuber disease', 0.0),
#  ('in premature chromatid separation', 0.0),
#  ('in prostate cancer survivors', 0.0),
#  ('in psysical component summary', 0.0),
#  ('in substantial pseudocontact shifts', 0.0),
#  ('in these individual hrql', 0.0),
#  ('including premature chromatid separation', 0.0),
#  ('including primary cytoreductive surgery', 0.0),
#  ('independent association with physical', 0.0),
#  ('instrument which produced physical', 0.0),
#  ('is and paracresyl sulfate', 0.0),
#  ('is p cresol sulfate', 0.0),
#  ('item pain catastrophizing scale', 0.0),
#  ('itraconazole itz strobilurins pyraclostrobin', 0.0),
#  ('kidney p cresol sulfate', 0.0),
#  ('levels of phytochelatin synthetase', 0.0),
#  ('liver of portacaval shunt', 0.0),
#  ('loaded porous calcium silicate', 0.0),
#  ('localization posterior circulation stroke', 0.0),
#  ('lower physical component score', 0.0),
#  ('lower physical component summary', 0.0),
#  ('mcs and physical health', 0.0),
#  ('mcs physical component summary', 0.0),
#  ('mean physical component summary', 0.0),
#  ('measured pain catastrophizing scale', 0.0),
#  ('measured physical component summary', 0.0),
#  ('men physical component summary', 0.0),
#  ('mental mcs and physical', 0.0),
#  ('mh and one component', 0.0),
#  ('multivariable analyses the physical', 0.0),
#  ('normalized physical component summary', 0.0),
#  ('obtained physical component summary', 0.0),
#  ('of a pain catastrophizing', 0.0),
#  ('of palmitoyl coa synthetase', 0.0),
#  ('of porous calcium silicate', 0.0),
#  ('of primary cytoreductive surgery', 0.0),
#  ('of psoralea corylifolia seeds', 0.0),
#  ('of the paracingulate sulcus', 0.0),
#  ('of the physical health', 0.0),
#  ('on sf 36 physical', 0.0),
#  ('onto porous calcium silicate', 0.0),
#  ('or p cresyl sulfate', 0.0),
#  ('own physical component summary', 0.0),
#  ('p < 001 physical', 0.0),
#  ('partners perceived physical health', 0.0),
#  ('pass depression bdi catastrophizing', 0.0),
#  ('patterns of care study', 0.0),
#  ('patterns of phytochelatin synthase', 0.0),
#  ('pcs are phytochelatin synthase', 0.0),
#  ('pcs post concussive syndrome', 0.0),
#  ('percentage of collagen synthesis', 0.0),
#  ('persistent post concussive symptoms', 0.0),
#  ('pf physical component summary', 0.0),
#  ('physical component summary scale', 0.0),
#  ('physical health component score', 0.0),
#  ('physical health component summary', 0.0),
#  ('pomegranate juice concentrated solutes', 0.0),
#  ('post operative physical health', 0.0),
#  ('posterior circulation ischemic stroke', 0.0),
#  ('pprp pain catastrophizing scale', 0.0),
#  ('predictor of postconcussion symptoms', 0.0),
#  ('premature sister chromatid separation', 0.0),
#  ('production p cresol sulfate', 0.0),
#  ('prostacyclin pgi 2 synthase', 0.0),
#  ('psoralea corylifolia l seeds', 0.0),
#  ('ptsd and postconcussion syndrome', 0.0),
#  ('ptsd post concussive syndrome', 0.0),
#  ('purpose posterior circulation stroke', 0.0),
#  ('quartiles physical component summary', 0.0),
#  ('related post concussive symptoms', 0.0),
#  ('related to physical health', 0.0),
#  ('reported p cresyl sulfate', 0.0),
#  ('s physical component summary', 0.0),
#  ('scale physical component summary', 0.0),
#  ('schistosomes is phytochelatin synthase', 0.0),
#  ('score for both physical', 0.0),
#  ('score in the physical', 0.0),
#  ('score physical component summary', 0.0),
#  ('score physical composite summary', 0.0),
#  ('score physical health score', 0.0),
#  ('sd physical component summary', 0.0),
#  ('seizures related to craniotomy', 0.0),
#  ('separation premature chromatid separation', 0.0),
#  ('sf 36 the physical', 0.0),
#  ('show that the physical', 0.0),
#  ('six psoralea corylifolia seeds', 0.0),
#  ('sleep symptoms with physical', 0.0),
#  ('smokers physical component score', 0.0),
#  ('solutes p cresyl sulfate', 0.0),
#  ('study found better health', 0.0),
#  ('summary measured the physical', 0.0),
#  ('summary physical component score', 0.0),
#  ('survey sf 12 physical', 0.0),
#  ('synthesized by phytochelatin synthase', 0.0),
#  ('that p cresyl sulfate', 0.0),
#  ('that propionyl coa synthase', 0.0),
#  ('that psoralea corylifolia seeds', 0.0),
#  ('the calculated of physical', 0.0),
#  ('the peak cap stress', 0.0),
#  ('the physical composite summary', 0.0),
#  ('the pontine called sites', 0.0),
#  ('the post capture survival', 0.0),
#  ('the protease cleavage sites', 0.0),
#  ('the worm phytochelatin synthase', 0.0),
#  ('their physical component summary', 0.0),
#  ('thi post concussive syndrome', 0.0),
#  ('this gene phytochelatin synthase', 0.0),
#  ('to provide both physical', 0.0),
#  ('to side portacaval shunt', 0.0),
#  ('total post concussive syndrome', 0.0),
#  ('toxins or paracresyl sulfate', 0.0),
#  ('toxins p cresyl sulfate', 0.0),
#  ('treatment pelvic congestion syndrome', 0.0),
#  ('using porous calcium silicate', 0.0),
#  ('viral protease cleavage sites', 0.0),
#  ('weeks after portacaval shunt', 0.0),
#  ('weeks of portacaval shunt', 0.0),
#  ('were physical component score', 0.0),
#  ('whether physical composite summary', 0.0),
#  ('with physical component score', 0.0),
#  ...]

# %%
top[50]
# Out:
# ('postconcussion syndrome', 2.5)

# %%
longforms0 = miners['PCS'].get_longforms()

# %%
longforms0
# Out:
# [('physical component summary', 82.6315789473684),
#  ('score', 35.193548387096776),
#  ('sulfate', 29.0188679245283),
#  ('physical', 23.379310344827587),
#  ('scale', 18.064516129032256),
#  ('phytochelatin synthase', 16.705882352941178),
#  ('portacaval shunt', 11.571428571428571),
#  ('syndrome', 8.625),
#  ('posterior circulation stroke', 7.25),
#  ('post concussive symptoms', 6.25),
#  ('porous calcium silicate', 5.428571428571429),
#  ('premature chromatid separation', 5.0),
#  ('physical health', 4.666666666666667),
#  ('psoralea corylifolia seeds', 4.666666666666667),
#  ('primary cytoreductive surgery', 3.6),
#  ('catastrophizing', 2.4),
#  ('sites', 1.3333333333333333),
#  ('post error slowing pes and post conflict slowing', 1.3333333333333333)]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0, 5, 6 , 8, 9, 10, 11, 12, 13, 14]]

# %%
longforms0
# Out:
# [('physical component summary', 82.6315789473684),
#  ('phytochelatin synthase', 16.705882352941178),
#  ('portacaval shunt', 11.571428571428571),
#  ('posterior circulation stroke', 7.25),
#  ('post concussive symptoms', 6.25),
#  ('porous calcium silicate', 5.428571428571429),
#  ('premature chromatid separation', 5.0),
#  ('physical health', 4.666666666666667),
#  ('psoralea corylifolia seeds', 4.666666666666667),
#  ('primary cytoreductive surgery', 3.6)]

# %%
longforms0.extend([x for i, x in enumerate(top) if i in [4, 5, 9, 12, 13, 27, 50]])

# %%
longforms0
# Out:
# [('physical component summary', 82.6315789473684),
#  ('phytochelatin synthase', 16.705882352941178),
#  ('portacaval shunt', 11.571428571428571),
#  ('posterior circulation stroke', 7.25),
#  ('post concussive symptoms', 6.25),
#  ('porous calcium silicate', 5.428571428571429),
#  ('premature chromatid separation', 5.0),
#  ('physical health', 4.666666666666667),
#  ('psoralea corylifolia seeds', 4.666666666666667),
#  ('primary cytoreductive surgery', 3.6),
#  ('physical component score', 26.967741935483872),
#  ('p cresyl sulfate', 25.82758620689655),
#  ('physical component summary score', 14.666666666666666),
#  ('p cresol sulfate', 10.736842105263158),
#  ('pain catastrophizing scale', 10.666666666666668),
#  ('physical component scale', 5.25),
#  ('postconcussion syndrome', 2.5)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('physical component summary',
#  'physical component score',
#  'p cresyl sulfate',
#  'phytochelatin synthase',
#  'physical component summary score',
#  'portacaval shunt',
#  'p cresol sulfate',
#  'pain catastrophizing scale',
#  'posterior circulation stroke',
#  'post concussive symptoms',
#  'porous calcium silicate',
#  'physical component scale',
#  'premature chromatid separation',
#  'physical health',
#  'psoralea corylifolia seeds',
#  'primary cytoreductive surgery',
#  'postconcussion syndrome')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'p cresol sulfate': 'CHEBI:CHEBI:82914',
#  'p cresyl sulfate': 'CHEBI:CHEBI:82914',
#  'pain catastrophizing scale': 'ungrounded',
#  'physical component scale': 'physical component summary',
#  'physical component score': 'physical component summary',
#  'physical component summary': 'physical component summary',
#  'physical component summary score': 'physical component summary',
#  'physical health': 'ungrounded',
#  'phytochelatin synthase': 'UP:Q9S7Z3',
#  'porous calcium silicate': 'ungrounded',
#  'portacaval shunt': 'MESH:D011167',
#  'post concussive symptoms': 'MESH:D038223',
#  'postconcussion syndrome': 'MESH:D038223',
#  'posterior circulation stroke': 'ungrounded',
#  'premature chromatid separation': 'ungrounded',
#  'primary cytoreductive surgery': 'ungrounded',
#  'psoralea corylifolia seeds': 'ungrounded'}

# %%
names
# Out:
# {'CHEBI:CHEBI:82914': 'p-cresol sulfate',
#  'physical component summary': 'physical component summary',
#  'UP:Q9S7Z3': 'PCS1',
#  'MESH:D011167': 'Portacaval Shunt, Surgical',
#  'MESH:D038223': 'Post-Concussion Syndrome'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names.update({f'HGNC:{get_hgnc_id(gene)}': gene for gene in genes})
pos_labels = list(set(pos_labels) | set(f'HGNC:{get_hgnc_id(gene)}' for gene in genes))

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'p cresol sulfate': 'CHEBI:CHEBI:82914',
#   'p cresyl sulfate': 'CHEBI:CHEBI:82914',
#   'pain catastrophizing scale': 'ungrounded',
#   'physical component scale': 'physical component summary',
#   'physical component score': 'physical component summary',
#   'physical component summary': 'physical component summary',
#   'physical component summary score': 'physical component summary',
#   'physical health': 'ungrounded',
#   'phytochelatin synthase': 'UP:Q9S7Z3',
#   'porous calcium silicate': 'ungrounded',
#   'portacaval shunt': 'MESH:D011167',
#   'post concussive symptoms': 'MESH:D038223',
#   'postconcussion syndrome': 'MESH:D038223',
#   'posterior circulation stroke': 'ungrounded',
#   'premature chromatid separation': 'ungrounded',
#   'primary cytoreductive surgery': 'ungrounded',
#   'psoralea corylifolia seeds': 'ungrounded'},
#  {'CHEBI:CHEBI:82914': 'p-cresol sulfate',
#   'physical component summary': 'physical component summary',
#   'UP:Q9S7Z3': 'PCS1',
#   'MESH:D011167': 'Portacaval Shunt, Surgical',
#   'MESH:D038223': 'Post-Concussion Syndrome',
#   'HGNC:1149': 'BUB1B'},
#  ['CHEBI:CHEBI:82914', 'HGNC:1149', 'UP:Q9S7Z3'])

# %%
grounding_map, names, pos_labels = ({'p cresol sulfate': 'CHEBI:CHEBI:82914',
  'p cresyl sulfate': 'CHEBI:CHEBI:82914',
  'pain catastrophizing scale': 'ungrounded',
  'physical component scale': 'physical component summary',
  'physical component score': 'physical component summary',
  'physical component summary': 'physical component summary',
  'physical component summary score': 'physical component summary',
  'physical health': 'ungrounded',
  'phytochelatin synthase': 'UP:Q9S7Z3',
  'porous calcium silicate': 'ungrounded',
  'portacaval shunt': 'MESH:D011167',
  'post concussive symptoms': 'MESH:D038223',
  'postconcussion syndrome': 'MESH:D038223',
  'posterior circulation stroke': 'ungrounded',
  'premature chromatid separation': 'ungrounded',
  'primary cytoreductive surgery': 'ungrounded',
  'psoralea corylifolia seeds': 'ungrounded'},
 {'CHEBI:CHEBI:82914': 'p-cresol sulfate',
  'physical component summary': 'physical component summary',
  'UP:Q9S7Z3': 'PCS1',
  'MESH:D011167': 'Portacaval Shunt, Surgical',
  'MESH:D038223': 'Post-Concussion Syndrome'},
 ['CHEBI:CHEBI:82914', 'UP:Q9S7Z3'])

# %%
grounding_dict = {'PCS': grounding_map}

# %%
classifier = AdeftClassifier('PCS', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-13 13:48:26] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-13 13:48:29] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9659340659340658 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D038223': 8,
#   'physical component summary': 105,
#   'ungrounded': 32,
#   'CHEBI:CHEBI:82914': 29,
#   'MESH:D011167': 13,
#   'UP:Q9S7Z3': 12},
#  'f1': {'mean': 0.9659340659340658, 'std': 0.04690361407328684},
#  'precision': {'mean': 0.9401360544217686, 'std': 0.08099524389734541},
#  'recall': {'mean': 1.0, 'std': 0.0}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0].startswith('UP')]

# %%
len(a)
# Out:
# 23

# %%
a[16]
# Out:
# 'The OsPCS2 exhibits root- and shoot-specific differential ratios of alternatively spliced transcripts in indica rice under Cd stress, and plays role in Cd and As stress tolerance and accumulation. Enzymatic activity of phytochelatin synthase (PCS) in plant produces phytochelatins, which help in sequestration of heavy metal(loid)s inside the cell vacuole to alleviate toxicity. Here we report that among the two PCS genes-OsPCS1 and OsPCS2 in indica rice (Oryza sativa) cultivar, the OsPCS2 produces an alternatively spliced OsPCS2b transcript that bears the unusual premature termination codon besides the canonically spliced OsPCS2a transcript. Root- and shoot-specific differential ratios of alternatively spliced OsPCS2a and OsPCS2b transcript expressions were observed under cadmium stress. Saccharomyces cerevisiae cells transformed with OsPCS2a exhibited increased cadmium (Cd) and arsenic (As) tolerance and accumulation, unlike the OsPCS2b transformed yeast cells. An intron-containing hairpin RNA-mediated gene silencing was carried out in endosperm-specific manner for efficient down-regulation of OsPCS genes in rice grains. Analysis of the transgenic rice lines grown under metal(loid) stress revealed almost complete absence of both OsPCS1 and OsPCS2 transcripts in the developing seeds coupled with the significant reduction in the content of Cd (~51%) and As (~35%) in grains compared with the non-transgenic plant. Taken together, the findings indicate towards a crucial role played by the tissue-specific alternative splicing and relative abundance of the OsPCS2 gene during heavy metal(loid) stress mitigation in rice plant.\n'

# %%
disamb.dump('PCS', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
