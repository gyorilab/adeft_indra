# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['FRT']
genes = ['MOS', 'MOCOS']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
genes
# Out:
# ['MOS', 'MOCOS']

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['FRT'].top()

# %%
top
# Out:
# [('the female reproductive tract', 31.72340425531915),
#  ('in the female reproductive tract', 23.120000000000005),
#  ('target', 22.941176470588236),
#  ('female reproductive tract', 22.459016393442624),
#  ('rat thyroid', 12.32),
#  ('fischer rat thyroid', 12.14285714285714),
#  ('recognition target', 10.0),
#  ('of the female reproductive tract', 9.818181818181818),
#  ('fisher rat thyroid', 9.4),
#  ('flp recognition target', 5.555555555555555),
#  ('the human female reproductive tract', 4.6),
#  ('flippase recognition target', 4.333333333333333),
#  ('flp recombination target', 3.6),
#  ('folate receptor target', 3.5),
#  ('time', 3.2),
#  ('recombinase target', 3.2),
#  ('the flp recognition target', 3.2),
#  ('in fischer rat thyroid', 3.0),
#  ('immune system in the female reproductive tract', 2.5),
#  ('site', 2.0),
#  ('free running type', 2.0),
#  ('fischer rat thyroid cells', 2.0),
#  ('in fisher rat thyroid', 2.0),
#  ('cells in the female reproductive tract', 2.0),
#  ('from saccharomyces cerevisiae induces dna bending upon interaction with the flp recognition target',
#   2),
#  ('recombination target', 1.666666666666667),
#  ('thyroid cells', 1.5),
#  ('therapy', 1.3333333333333333),
#  ('rosa roxburghii tratt', 1.3333333333333333),
#  ('from the female reproductive tract', 1.3333333333333333),
#  ('ferritin', 1.0),
#  ('rise time', 1.0),
#  ('flip recombinase target', 1.0),
#  ('flp recombinase target', 1.0),
#  ('forelimb retraction time', 1.0),
#  ('fractionated radiation therapy', 1.0),
#  ('and female reproductive tract', 1.0),
#  ('of flp recognition target', 1.0),
#  ('the flexion rotation test', 1.0),
#  ('the flippase recognition target', 1.0),
#  ('the flp recombination target', 1.0),
#  ('upper female reproductive tract', 1.0),
#  ('flavonoids of rosa roxburghii tratt', 1.0),
#  ('the mouse female reproductive tract', 1),
#  ('to the female reproductive tract', 1.0),
#  ('when the flp recombination target', 1),
#  ('and carboplatin loaded folate receptor target', 1.0),
#  ('binding to the flp recognition target', 1.0),
#  ('expression in the female reproductive tract', 1.0),
#  ('in the human female reproductive tract', 1.0),
#  ('pain from the female reproductive tract', 1),
#  ('t rm in the female reproductive tract', 1.0),
#  ('that containing a single flippase recognition target', 1.0),
#  ('the mucosa of the female reproductive tract', 1),
#  ('both stereotactic radiosurgery srs and fractionated radiation therapy', 1),
#  ('dendritic cells dcs throughout the female reproductive tract', 1),
#  ('the immune system in the female reproductive tract', 1.0),
#  ('the mucosal surface of the female reproductive tract', 1.0),
#  ('the primary function of the female reproductive tract', 1),
#  ('or ~ 32 aco2 and entropic contributions increased ~ 39', 1),
#  ('the mucosa and overlying fluid of the female reproductive tract', 1),
#  ('post immune and lymphocytes were isolated from the female reproductive tract',
#   1.0),
#  ('a tetracycline driven bi directly expression plasmid containing the flippase recognition target',
#   1),
#  ('carboplatin loaded nontargeted nt liposomes red and carboplatin loaded folate receptor target',
#   1),
#  ('lore mechanisms associated with essential pathways of epithelial morphogenesis fischer rat thyroid',
#   1),
#  ('omologous recombination mediated gene target with the flippase flp flippase recognition target',
#   1),
#  ('therapy we encapsulated the most cytotoxic complex into biomacromolecular protein cage apoferritin',
#   1),
#  ('tin carboplatin loaded nontargeted nt liposomes and carboplatin loaded folate receptor target',
#   1),
#  ('al ion rna complex involve both electrostatic and coordination complex interaction the ferritin',
#   1),
#  ('by p element mediated transformation as the target vector comprises flp recombination target',
#   1),
#  ('despite extensive study of the mucosal immune system in the female reproductive tract',
#   1),
#  ('ein breeder associated anafi table 1 fertility traits included the aggregate fertility index',
#   1),
#  ('ethidium bromide staining amplified products were confirmed by dna sequence fisher rat thyroid',
#   1),
#  ('flippase recombination enzyme into hek293 cells that containing a single flippase recognition target',
#   1),
#  ('ging information from the physiology endocrinology and immunology of the female reproductive tract',
#   1),
#  ('hgf secretion facilitates epithelial cells growth and developed in the female reproductive tract',
#   1),
#  ('ithout drug related toxicities a cellular accumulation of dii labeled folate receptor target',
#   1),
#  ('t interaction with the canopy under observation we using the fluorescence reflectance transmittance',
#   1),
#  ('the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#   1.0),
#  ('the risk of edema when using stereotactic radiosurgery srs versus fractionated radiation therapy',
#   1),
#  ('we have investigated the mechanisms of prp c endocytosis in fischer rat thyroid',
#   1),
#  ('acketed by short sequence for site specific recombination such as the flippase recognition target',
#   1),
#  ('and tissue in particular we performed a comprehensive analysis of the female reproductive tract',
#   1),
#  ('antify the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#   1),
#  ('ation across the vaginal epithelial barrier in vivo neutrophils in the female reproductive tract',
#   1),
#  ('ction these directly or indirectly impact pathogens that enter the upper female reproductive tract',
#   1),
#  ('d caught herring pacific herring produce distinctive bursts of pulses termed fast repetitive tick',
#   1),
#  ('driven by the phosphoglycerate kinase pgk gene promoter and flanked by flip recombinase target',
#   1),
#  ('fp figure 1a flippase activity regulated by the rn2 promoter induces flip recombinase target',
#   1),
#  ('has a growth inhibitory effect on s cerevisiae when overexpressed 14 flp recombinase target',
#   1),
#  ('iene education however successful treatment method has not been established in free running type',
#   1),
#  ('lins complement factor and bacteria 1 3 semen deposition in the female reproductive tract',
#   1),
#  ('n harboring the native splice acceptor sa ii introduction of flp recombinase recognition site',
#   1),
#  ('o exposure to diethylstilbestrol des leads to patterning defects in the female reproductive tract',
#   1),
#  ('obial recognition and immune defense in the reproductive tract the human female reproductive tract',
#   1),
#  ('of the orthopedic surgeon in the management of these problems lifelong factor replaced therapy',
#   1),
#  ('ossessed channel activity fig 7 constructs were expression stably in fischer rat thyroid cells',
#   1),
#  ('persist in tissue reservoirs such as the gastrointestinal gi tract and female reproductive tract',
#   1),
#  ('prophylactic approaches designed to halt the transmission of hiv in the female reproductive tract',
#   1),
#  ('removed initially the marker was removed by recombination of the flanked flp recognition target',
#   1),
#  ('retention in the ectocervix and fornix epithelium cd47 expression in the female reproductive tract',
#   1),
#  ('rmined by the dosimetric calibration outlined above similarly the effect of daily fractionated rt',
#   1),
#  ('s we established three dimensional 3d epithelial culture model system using fischer rat thyroid',
#   1),
#  ('side effect of radiotherapy the radioprotective effect of the flavonoids of rosa roxburghii tratt',
#   1),
#  ('virus hpv generated of antigen specific cells mediated immune in the female reproductive tract',
#   1),
#  ('3 enhancer to initially replication at an ectopic location we insertion a flp recombination target',
#   1),
#  ('actions and their role in caveolar formation in polarized epithelial cells in fischer rat thyroid',
#   1),
#  ('adverse side effect in this study ip administration was coupled with a folate receptor target',
#   1),
#  ('ake and in some cells both iron acquisition and endosomal iron release ii cytoplasmic ferritin',
#   1),
#  ('alysis and understand of the innate and adaptive immune system in the female reproductive tract',
#   1),
#  ('and differentially many actions of hgf are mirrored by estradiol in the female reproductive tract',
#   1),
#  ('at intravaginal deposition of zikv can cause tgt hormonal changes in the female reproductive tract',
#   1),
#  ('binase flp1p and containing a pair of inverted repeats 599 bp containing flp1p recombinase target',
#   1),
#  ('bsequently the forelimb in the holes hind limb retraction time hrt and forelimb retraction time',
#   1),
#  ('c a mascia l nitsch cells polarized and morphogenetic properties of fischer rat thyroid cells',
#   1),
#  ('c12 activity to restore stimulated nf κb transcription fig 1a bottom a fisher rat thyroid',
#   1),
#  ('ced on day seven post immune and lymphocytes were isolated from the female reproductive tract',
#   1),
#  ('cretion of mucins which provide an additional layer of protection to the female reproductive tract',
#   1),
#  ('current method would also allow the insertion of certain dna sequence like flp recombinase target',
#   1),
#  ('d cystic fibrosis bronchial epithelial cells cfbe41o − human airway cells and fisher rat thyroid',
#   1),
#  ('d expression of both flp recombinase gene and gin11 flanked by flp recombinase recognition target',
#   1),
#  ('ein e g matrix ma and nucleocapsid nc allow efficient excision of flp recognition target',
#   1),
#  ('eir entry into the vaginal lumen during ovulation cd44 expression in the female reproductive tract',
#   1),
#  ('ell population was selected 48 h post transfection using hygromycin 150μg ml fischer rat thyroid',
#   1),
#  ('f protection against a broad range of potential pathogens that infection the female reproductive tract',
#   1),
#  ('genic bacterial population 1 bv is the most common infection of the female reproductive tract',
#   1),
#  ('gle nucleotide polymorphisms in circadian clock gene in 182 dspt individuals 67 free running type',
#   1),
#  ('ies target protection antigen specific cd8 + t cells responses to the female reproductive tract',
#   1),
#  ('ized mice were mock or candida albicans inoculated in the vagina a female reproductive tract',
#   1),
#  ('l lumen has been somewhat characterize 10 how they migrate into the female reproductive tract',
#   1),
#  ('lop these strategies it will be evermore importance to understand how the female reproductive tract',
#   1),
#  ('lp recombinase of the 2 microns plasmid of saccharomyces cerevisiae binding to it recognition target',
#   1),
#  ('ng technology to deliver carboplatin into ovarian cancer cells the authors developed a fr target',
#   1),
#  ('not be directly involve in these processes the polarized epithelial cells line fischer rat thyroid',
#   1),
#  ('nts of the inner retinal thickness irt outer retinal thickness ort and full retinal thickness',
#   1),
#  ('on is replaced by a cloramphenicol resistance cat cassette flanked by two flp recombinase site',
#   1),
#  ('on strategies generated large numbers of antigen specific t cells in the female reproductive tract',
#   1),
#  ('ore this hypothesis we study cftr mediated transepithelial cl − current in fischer rat thyroid',
#   1),
#  ('orldwide unaids world aids day report 2011 the earliest events in the female reproductive tract',
#   1),
#  ('ows one strategies using for identification of cftr inhibitor the assay utilizes fischer rat thyroid',
#   1),
#  ('quantification of the mmp9 expression in ly6g + neutrophils from the lower female reproductive tract',
#   1),
#  ('r study was to assess the radioprotective effect of flavonoids extracted from rosa roxburghii tratt',
#   1),
#  ('ration and camp dependent regulated this is of particular importance since the fisher rat thyroid',
#   1),
#  ('rich in the cholesterol binding protein caveolin vip21 in the golgi apparatus fischer rat thyroid',
#   1),
#  ('rificed on day 7 post immune and lymphocytes were isolated from the female reproductive tract',
#   1),
#  ('rta and rtc respectively were also measured finally cutaneous red blood cells flux recovery time',
#   1),
#  ('subtypes advanced sleep phase type aspt delayed sleep phase type dspt and free running type',
#   1),
#  ('t study evaluated the protection effect of the natural compound flavonoids of rosa roxburghii tratt',
#   1),
#  ('the interface of the external environment and the mucosal surface of the female reproductive tract',
#   1),
#  ('tipsychotic efficacy of the drug these data open the perspective that the forelimb retraction time',
#   1),
#  ('tissue our aims were to characterize the short and long termed effect of fractionated radiotherapy',
#   1),
#  ('to established a model for observation dynamic t cells behavior in the female reproductive tract',
#   1),
#  ('ushroom body which can be combined with a dna insertion carrying flippase recognition target site',
#   1),
#  ('v 1 sexual transmission occurs main via mucosal semen exposure in the female reproductive tract',
#   1),
#  ('yces cerevisiae and it recognizes a specific 34 bp dna sequence termed flippase recognition target',
#   1),
#  ('3b and 3c tq416 thus acts rapidly to prevent c12 mediated cellular responses fisher rat thyroid',
#   1),
#  ('anti hiv 1 mechanisms of actions of cationic peptides and peptides of the female reproductive tract',
#   1),
#  ('asing evidence that the first contact between hiv and immune cells in the female reproductive tract',
#   1),
#  ('flp protein is a site specific recombinase that recognizes and binding to the flp recognition target',
#   1),
#  ('host cells at a specific genomic location 21 in the fcho cells a flippase recombination target',
#   1),
#  ('in this review we will examine the complex and unique innervation of the female reproductive tract',
#   1),
#  ('ith engineered self organized tendon constructs sot or segments of adult art or fetal rat tail',
#   1),
#  ('late wild type wt and δf508 mutant cftr channel activity in cftr expression fischer rat thyroid',
#   1),
#  ('mined genomic locus this makes using of cells line that containing a single flippase recognition target',
#   1),
#  ('n overcomes the epithelial barrier 2 to reach immune target cells in the female reproductive tract',
#   1),
#  ('n the using of the yeast site specific recombinase flipase flp and it recognition target sequence',
#   1),
#  ('niques to study cells expression recombination human cftr thf increased i sc in fischer rat thyroid',
#   1),
#  ('o hiv infection or abort the infection before it spreads even though the female reproductive tract',
#   1),
#  ('or tissue in the secretory phase the mucosal immune system of the human female reproductive tract',
#   1),
#  ('percentage of cd4 + human t cells levels in the gastrointestinal gi and female reproductive tract',
#   1),
#  ('s a critical role in determined the outcome of virus transmission in the female reproductive tract',
#   1),
#  ('t has been report that expression of these receptor are altered in the female reproductive tract',
#   1),
#  ('ted gel forming mucins responses for the main structure of mucus in the female reproductive tract',
#   1),
#  ('the effect of dqa on cftr function and cells viability were investigated in fisher rat thyroid',
#   1),
#  ('the pcdna5 frt vector containing the gene of interest into the genomic via flp recombination target',
#   1),
#  ('v 434 hela 229 cells were obtained from the american type culture collection fischer rat thyroid',
#   1),
#  ('w for example the combined effect of ire irp interaction decrease iron efflux fpn and storage',
#   1),
#  ('y f0 onset and steady state formant frequencies f1 f2 f3 vowel duration formant rise time',
#   1),
#  ('0 was shown to potential fsk stimulated and cftr mediated i sc in recombination fisher rat thyroid',
#   1),
#  ('21 kda peptides containing a site specific dna binding domain that binding to the flp recognition target',
#   1),
#  ('frt with in immune the frequencies of antigen specific cd8 + t cells present in both mucosal',
#   1),
#  ('he possible role of il 36γ in host defense against pathogens in the human female reproductive tract',
#   1),
#  ('he semen ascends across the cervix into the lumen of the uterus and upper female reproductive tract',
#   1),
#  ('ing specific to each of three 13 base pair bp symmetry element of the flp recognition target',
#   1),
#  ('l gfp infection of cd4 + t cells fig 4a hiv transmission through the female reproductive tract',
#   1),
#  ('like small molecules was performed using a cells base assay of iodide influx in fisher rat thyroid',
#   1),
#  ('lish an antiviral state 49 51 fig 3 lcmv specific t rm in the female reproductive tract',
#   1),
#  ('men to women little attention is be paid to the immune system in the female reproductive tract',
#   1),
#  ('nt study have shown a high incidence of c1 c2 dysfunction evaluated by the flexion rotation test',
#   1),
#  ('serum fbs 10 penicillin streptomycin 1 and zeocin 100μg ml at 37 ° c fisher rat thyroid',
#   1),
#  ('ting tlrs in the hu man frt infection within the upper regions of the female reproductive tract',
#   1),
#  ('vaccination with an attenuated strain of hsv generated cd4 + t rm in the female reproductive tract',
#   1),
#  ('a cftr inhibitor with potency of 20 μm as determined by halide influx assay in fisher rat thyroid',
#   1),
#  ('and hek293t cells were maintained in dmem supplemented with 3 7 g l nahco 3 fischer rat thyroid',
#   1),
#  ('he frt and differentially regulated by poly i c gc and hiv 1 the human female reproductive tract',
#   1),
#  ('icated in etx binding and activity here we study the effect of etx on fischer rat thyroid cells',
#   1),
#  ('mulus in this study we proposed a new dimension for comparing the ldf signals the flux rise time',
#   1),
#  ('r processes the effect of cch on ca 2 + i was examine in nondifferentiated fischer rat thyroid',
#   1),
#  ('terminus leaving a 5 hydroxyl group at the site of the nick we have using flp recognition target',
#   1),
#  ('ele harboring both a pair of loxp site flanked apc exon 14 and a pair of flp recognition target',
#   1),
#  ('n of the pcdna5 frt abcb1 2677g t a vector flp in 293 cells have the flp recombination target',
#   1),
#  ('ng k d 12 fold frt ire rna or 6 fold aco2 ire rna enthalpic contributions decrease ~ 61',
#   1),
#  ('prr nod 1 nod 2 rig 1 and mda5 have not been elucidated in the human female reproductive tract',
#   1),
#  ('pwt ≤ 8 0 s brushing paw withdrawal latency pwl ≤ 0 16 g von frey flinching responses threshold',
#   1),
#  ('ted in a normal rat thyroid cells line frtl 5 but not in a dedifferentiated line of thyroid cells',
#   1),
#  ('sis of human peripheral blood pmns culture at basal 37 ° c and febrile range 39 5 ° c temperatures',
#   1),
#  ('sis of kpn i swa i digested dna of pcv21 dr in e coli left pretransformed and a pcv21 dr',
#   1),
#  ('ted plasmid dna of a pcv21 tn 5 1 in e coli left pretransformed and a pcv21 tn 5 1',
#   1),
#  ('1', 0.0),
#  ('39', 0.0),
#  ('61', 0.0),
#  ('apoferritin', 0.0),
#  ('cells', 0.0),
#  ('dr', 0.0),
#  ('index', 0.0),
#  ('mucosal', 0.0),
#  ('radiotherapy', 0.0),
#  ('rt', 0.0),
#  ('sequence', 0.0),
#  ('storage', 0.0),
#  ('tail', 0.0),
#  ('temperatures', 0.0),
#  ('test', 0.0),
#  ('thickness', 0.0),
#  ('threshold', 0.0),
#  ('thyroid', 0.0),
#  ('tick', 0.0),
#  ('tract', 0.0),
#  ('transmittance', 0.0),
#  ('tratt', 0.0),
#  ('type', 0.0),
#  ('5 1', 0.0),
#  ('and storage', 0.0),
#  ('both mucosal', 0.0),
#  ('c temperatures', 0.0),
#  ('cage apoferritin', 0.0),
#  ('cytoplasmic ferritin', 0.0),
#  ('fertility index', 0.0),
#  ('fr target', 0.0),
#  ('fractionated radiotherapy', 0.0),
#  ('fractionated rt', 0.0),
#  ('pcv21 dr', 0.0),
#  ('radiation therapy', 0.0),
#  ('rat tail', 0.0),
#  ('receptor target', 0.0),
#  ('recognition site', 0.0),
#  ('recombinase site', 0.0),
#  ('recovery time', 0.0),
#  ('reflectance transmittance', 0.0),
#  ('repetitive tick', 0.0),
#  ('replaced therapy', 0.0),
#  ('reproductive tract', 0.0),
#  ('responses threshold', 0.0),
#  ('retinal thickness', 0.0),
#  ('retraction time', 0.0),
#  ('rotation test', 0.0),
#  ('roxburghii tratt', 0.0),
#  ('running type', 0.0),
#  ('target sequence', 0.0),
#  ('target site', 0.0),
#  ('the ferritin', 0.0),
#  ('~ 39', 0.0),
#  ('~ 61', 0.0),
#  ('a fr target', 0.0),
#  ('a pcv21 dr', 0.0),
#  ('aggregate fertility index', 0.0),
#  ('daily fractionated rt', 0.0),
#  ('decrease ~ 61', 0.0),
#  ('factor replaced therapy', 0.0),
#  ('fast repetitive tick', 0.0),
#  ('fetal rat tail', 0.0),
#  ('flexion rotation test', 0.0),
#  ('flinching responses threshold', 0.0),
#  ('flippase recombination target', 0.0),
#  ('flp recombinase site', 0.0),
#  ('flp1p recombinase target', 0.0),
#  ('fluorescence reflectance transmittance', 0.0),
#  ('flux recovery time', 0.0),
#  ('flux rise time', 0.0),
#  ('formant rise time', 0.0),
#  ('fpn and storage', 0.0),
#  ('full retinal thickness', 0.0),
#  ('ii cytoplasmic ferritin', 0.0),
#  ('in both mucosal', 0.0),
#  ('increased ~ 39', 0.0),
#  ('interaction the ferritin', 0.0),
#  ('it recognition target', 0.0),
#  ('of fractionated radiotherapy', 0.0),
#  ('of thyroid cells', 0.0),
#  ('protein cage apoferritin', 0.0),
#  ('rat thyroid cells', 0.0),
#  ('recognition target sequence', 0.0),
#  ('recognition target site', 0.0),
#  ('recombinase recognition site', 0.0),
#  ('recombinase recognition target', 0.0),
#  ('tn 5 1', 0.0),
#  ('° c temperatures', 0.0),
#  ('14 flp recombinase target', 0.0),
#  ('3 fischer rat thyroid', 0.0),
#  ('5 ° c temperatures', 0.0),
#  ('67 free running type', 0.0),
#  ('a female reproductive tract', 0.0),
#  ('a fisher rat thyroid', 0.0),
#  ('a flippase recombination target', 0.0),
#  ('a flp recombination target', 0.0),
#  ('a folate receptor target', 0.0),
#  ('and a pcv21 dr', 0.0),
#  ('and fisher rat thyroid', 0.0),
#  ('and forelimb retraction time', 0.0),
#  ('and fractionated radiation therapy', 0.0),
#  ('and free running type', 0.0),
#  ('and full retinal thickness', 0.0),
#  ('apparatus fischer rat thyroid', 0.0),
#  ('biomacromolecular protein cage apoferritin', 0.0),
#  ('by flip recombinase target', 0.0),
#  ('c fisher rat thyroid', 0.0),
#  ('cells flux recovery time', 0.0),
#  ('collection fischer rat thyroid', 0.0),
#  ('complex interaction the ferritin', 0.0),
#  ('comprises flp recombination target', 0.0),
#  ('containing flp1p recombinase target', 0.0),
#  ('contributions decrease ~ 61', 0.0),
#  ('contributions increased ~ 39', 0.0),
#  ('developed a fr target', 0.0),
#  ('duration formant rise time', 0.0),
#  ('effect of fractionated radiotherapy', 0.0),
#  ('efflux fpn and storage', 0.0),
#  ('expression fischer rat thyroid', 0.0),
#  ('flanked flp recognition target', 0.0),
#  ('flippase recognition target site', 0.0),
#  ('flp flippase recognition target', 0.0),
#  ('flp recombinase recognition site', 0.0),
#  ('flp recombinase recognition target', 0.0),
#  ('frey flinching responses threshold', 0.0),
#  ('from rosa roxburghii tratt', 0.0),
#  ('human female reproductive tract', 0.0),
#  ('in free running type', 0.0),
#  ('induces flip recombinase target', 0.0),
#  ('it recognition target sequence', 0.0),
#  ('labeled folate receptor target', 0.0),
#  ('lifelong factor replaced therapy', 0.0),
#  ('like flp recombinase target', 0.0),
#  ('line fischer rat thyroid', 0.0),
#  ('line of thyroid cells', 0.0),
#  ('loaded folate receptor target', 0.0),
#  ('lower female reproductive tract', 0.0),
#  ('ml fischer rat thyroid', 0.0),
#  ('morphogenesis fischer rat thyroid', 0.0),
#  ('mouse female reproductive tract', 0.0),
#  ('nondifferentiated fischer rat thyroid', 0.0),
#  ('of daily fractionated rt', 0.0),
#  ('of rosa roxburghii tratt', 0.0),
#  ('or fetal rat tail', 0.0),
#  ('pcv21 tn 5 1', 0.0),
#  ('present in both mucosal', 0.0),
#  ('recombination fisher rat thyroid', 0.0),
#  ('release ii cytoplasmic ferritin', 0.0),
#  ('responses fisher rat thyroid', 0.0),
#  ('sequence fisher rat thyroid', 0.0),
#  ('single flippase recognition target', 0.0),
#  ('termed fast repetitive tick', 0.0),
#  ('termed flippase recognition target', 0.0),
#  ('the aggregate fertility index', 0.0),
#  ('the fisher rat thyroid', 0.0),
#  ('the fluorescence reflectance transmittance', 0.0),
#  ('the flux rise time', 0.0),
#  ('the forelimb retraction time', 0.0),
#  ('to it recognition target', 0.0),
#  ('two flp recombinase site', 0.0),
#  ('using fischer rat thyroid', 0.0),
#  ('using flp recognition target', 0.0),
#  ('utilizes fischer rat thyroid', 0.0),
#  ('versus fractionated radiation therapy', 0.0),
#  ('via flp recombination target', 0.0),
#  ('150μg ml fischer rat thyroid', 0.0),
#  ('39 5 ° c temperatures', 0.0),
#  ('a pcv21 tn 5 1', 0.0),
#  ('a single flippase recognition target', 0.0),
#  ('and it recognition target sequence', 0.0),
#  ('and upper female reproductive tract', 0.0),
#  ('art or fetal rat tail', 0.0),
#  ('as the flippase recognition target', 0.0),
#  ('assay in fisher rat thyroid', 0.0),
#  ('assay utilizes fischer rat thyroid', 0.0),
#  ('authors developed a fr target', 0.0),
#  ('binding to it recognition target', 0.0),
#  ('blood cells flux recovery time', 0.0),
#  ('bottom a fisher rat thyroid', 0.0),
#  ('bp containing flp1p recombinase target', 0.0),
#  ('by flp recombinase recognition target', 0.0),
#  ('by the flexion rotation test', 0.0),
#  ('by two flp recombinase site', 0.0),
#  ('carboplatin loaded folate receptor target', 0.0),
#  ('carrying flippase recognition target site', 0.0),
#  ('cells a flippase recombination target', 0.0),
#  ('cells and fisher rat thyroid', 0.0),
#  ('cells in fischer rat thyroid', 0.0),
#  ('cells line fischer rat thyroid', 0.0),
#  ('cells present in both mucosal', 0.0),
#  ('cellular responses fisher rat thyroid', 0.0),
#  ('cftr expression fischer rat thyroid', 0.0),
#  ('containing the flippase recognition target', 0.0),
#  ('coordination complex interaction the ferritin', 0.0),
#  ('culture collection fischer rat thyroid', 0.0),
#  ('current in fischer rat thyroid', 0.0),
#  ('dedifferentiated line of thyroid cells', 0.0),
#  ('dii labeled folate receptor target', 0.0),
#  ('dna sequence fisher rat thyroid', 0.0),
#  ('dspt and free running type', 0.0),
#  ('effect of daily fractionated rt', 0.0),
#  ('endocytosis in fischer rat thyroid', 0.0),
#  ('enthalpic contributions decrease ~ 61', 0.0),
#  ('entropic contributions increased ~ 39', 0.0),
#  ('epithelial morphogenesis fischer rat thyroid', 0.0),
#  ('established in free running type', 0.0),
#  ('excision of flp recognition target', 0.0),
#  ('extracted from rosa roxburghii tratt', 0.0),
#  ('flanked by flip recombinase target', 0.0),
#  ('flippase flp flippase recognition target', 0.0),
#  ('genomic via flp recombination target', 0.0),
#  ('gi and female reproductive tract', 0.0),
#  ('golgi apparatus fischer rat thyroid', 0.0),
#  ('have the flp recombination target', 0.0),
#  ('have using flp recognition target', 0.0),
#  ('how the female reproductive tract', 0.0),
#  ('hrt and forelimb retraction time', 0.0),
#  ('in fischer rat thyroid cells', 0.0),
#  ('in nondifferentiated fischer rat thyroid', 0.0),
#  ('in recombination fisher rat thyroid', 0.0),
#  ('included the aggregate fertility index', 0.0),
#  ('individuals 67 free running type', 0.0),
#  ('infection the female reproductive tract', 0.0),
#  ('influx in fisher rat thyroid', 0.0),
#  ('insertion a flp recombination target', 0.0),
#  ('into biomacromolecular protein cage apoferritin', 0.0),
#  ('into the female reproductive tract', 0.0),
#  ('investigated in fisher rat thyroid', 0.0),
#  ('iron efflux fpn and storage', 0.0),
#  ('iron release ii cytoplasmic ferritin', 0.0),
#  ('nahco 3 fischer rat thyroid', 0.0),
#  ('of fischer rat thyroid cells', 0.0),
#  ('of flp recombinase recognition site', 0.0),
#  ('of the flp recognition target', 0.0),
#  ('on fischer rat thyroid cells', 0.0),
#  ('ort and full retinal thickness', 0.0),
#  ('overexpressed 14 flp recombinase target', 0.0),
#  ('pair of flp recognition target', 0.0),
#  ('pretransformed and a pcv21 dr', 0.0),
#  ('problems lifelong factor replaced therapy', 0.0),
#  ('promoter induces flip recombinase target', 0.0),
#  ('pulses termed fast repetitive tick', 0.0),
#  ('sc in fischer rat thyroid', 0.0),
#  ('sequence like flp recombinase target', 0.0),
#  ('sequence termed flippase recognition target', 0.0),
#  ('signals the flux rise time', 0.0),
#  ('since the fisher rat thyroid', 0.0),
#  ('srs and fractionated radiation therapy', 0.0),
#  ('srs versus fractionated radiation therapy', 0.0),
#  ('system using fischer rat thyroid', 0.0),
#  ('termed effect of fractionated radiotherapy', 0.0),
#  ('that the forelimb retraction time', 0.0),
#  ('the flanked flp recognition target', 0.0),
#  ('the lower female reproductive tract', 0.0),
#  ('the upper female reproductive tract', 0.0),
#  ('though the female reproductive tract', 0.0),
#  ('through the female reproductive tract', 0.0),
#  ('throughout the female reproductive tract', 0.0),
#  ('to the flp recognition target', 0.0),
#  ('tract and female reproductive tract', 0.0),
#  ('using the fluorescence reflectance transmittance', 0.0),
#  ('vagina a female reproductive tract', 0.0),
#  ('vector comprises flp recombination target', 0.0),
#  ('von frey flinching responses threshold', 0.0),
#  ('vowel duration formant rise time', 0.0),
#  ('with a folate receptor target', 0.0),
#  ('with the flp recognition target', 0.0),
#  ('° c fisher rat thyroid', 0.0),
#  ('1 the human female reproductive tract', 0.0),
#  ('1a bottom a fisher rat thyroid', 0.0),
#  ('37 ° c fisher rat thyroid', 0.0),
#  ('599 bp containing flp1p recombinase target', 0.0),
#  ('a dedifferentiated line of thyroid cells', 0.0),
#  ('a pair of flp recognition target', 0.0),
#  ('adult art or fetal rat tail', 0.0),
#  ('airway cells and fisher rat thyroid', 0.0),
#  ('altered in the female reproductive tract', 0.0),
#  ('analysis of the female reproductive tract', 0.0),
#  ('and a pcv21 tn 5 1', 0.0),
#  ('and coordination complex interaction the ferritin', 0.0),
#  ('and entropic contributions increased ~ 39', 0.0),
#  ('and flanked by flip recombinase target', 0.0),
#  ('been established in free running type', 0.0),
#  ('behavior in the female reproductive tract', 0.0),
#  ('by dna sequence fisher rat thyroid', 0.0),
#  ('c endocytosis in fischer rat thyroid', 0.0),
#  ('cells have the flp recombination target', 0.0),
#  ('cerevisiae binding to it recognition target', 0.0),
#  ('changes in the female reproductive tract', 0.0),
#  ('complex into biomacromolecular protein cage apoferritin', 0.0),
#  ('compound flavonoids of rosa roxburghii tratt', 0.0),
#  ('containing a single flippase recognition target', 0.0),
#  ('coupled with a folate receptor target', 0.0),
#  ('dcs throughout the female reproductive tract', 0.0),
#  ('decrease iron efflux fpn and storage', 0.0),
#  ('defects in the female reproductive tract', 0.0),
#  ('deposition in the female reproductive tract', 0.0),
#  ('developed in the female reproductive tract', 0.0),
#  ('dna sequence like flp recombinase target', 0.0),
#  ('dna sequence termed flippase recognition target', 0.0),
#  ('dspt individuals 67 free running type', 0.0),
#  ('efficient excision of flp recognition target', 0.0),
#  ('element of the flp recognition target', 0.0),
#  ('endosomal iron release ii cytoplasmic ferritin', 0.0),
#  ('enter the upper female reproductive tract', 0.0),
#  ('epithelial cells in fischer rat thyroid', 0.0),
#  ('epithelial cells line fischer rat thyroid', 0.0),
#  ('estradiol in the female reproductive tract', 0.0),
#  ('etx on fischer rat thyroid cells', 0.0),
#  ('evaluated by the flexion rotation test', 0.0),
#  ('even though the female reproductive tract', 0.0),
#  ('events in the female reproductive tract', 0.0),
#  ('examine in nondifferentiated fischer rat thyroid', 0.0),
#  ('exposure in the female reproductive tract', 0.0),
#  ('f3 vowel duration formant rise time', 0.0),
#  ('fcho cells a flippase recombination target', 0.0),
#  ('flanked by flp recombinase recognition target', 0.0),
#  ('flanked by two flp recombinase site', 0.0),
#  ('flavonoids extracted from rosa roxburghii tratt', 0.0),
#  ('flp and it recognition target sequence', 0.0),
#  ('fluid of the female reproductive tract', 0.0),
#  ('from the lower female reproductive tract', 0.0),
#  ('function of the female reproductive tract', 0.0),
#  ('g von frey flinching responses threshold', 0.0),
#  ('gastrointestinal gi and female reproductive tract', 0.0),
#  ('gi tract and female reproductive tract', 0.0),
#  ('hiv in the female reproductive tract', 0.0),
#  ('hygromycin 150μg ml fischer rat thyroid', 0.0),
#  ('i sc in fischer rat thyroid', 0.0),
#  ('immune in the female reproductive tract', 0.0),
#  ('immunology of the female reproductive tract', 0.0),
#  ('importance since the fisher rat thyroid', 0.0),
#  ('in cftr expression fischer rat thyroid', 0.0),
#  ('infection of the female reproductive tract', 0.0),
#  ('influx assay in fisher rat thyroid', 0.0),
#  ('innervation of the female reproductive tract', 0.0),
#  ('insertion carrying flippase recognition target site', 0.0),
#  ('interaction with the flp recognition target', 0.0),
#  ('introduction of flp recombinase recognition site', 0.0),
#  ('iodide influx in fisher rat thyroid', 0.0),
#  ('isolated from the female reproductive tract', 0.0),
#  ('l nahco 3 fischer rat thyroid', 0.0),
#  ('ldf signals the flux rise time', 0.0),
#  ('left pretransformed and a pcv21 dr', 0.0),
#  ('long termed effect of fractionated radiotherapy', 0.0),
#  ('mediated cellular responses fisher rat thyroid', 0.0),
#  ('migrate into the female reproductive tract', 0.0),
#  ('model system using fischer rat thyroid', 0.0),
#  ('mucosa of the female reproductive tract', 0.0),
#  ('mucus in the female reproductive tract', 0.0),
#  ('neutrophils in the female reproductive tract', 0.0),
#  ('of dii labeled folate receptor target', 0.0),
#  ('of epithelial morphogenesis fischer rat thyroid', 0.0),
#  ('of pulses termed fast repetitive tick', 0.0),
#  ('of the flanked flp recognition target', 0.0),
#  ('of the human female reproductive tract', 0.0),
#  ('peptides of the female reproductive tract', 0.0),
#  ('perspective that the forelimb retraction time', 0.0),
#  ('plasmid containing the flippase recognition target', 0.0),
#  ('properties of fischer rat thyroid cells', 0.0),
#  ('protection to the female reproductive tract', 0.0),
#  ('radiosurgery srs and fractionated radiation therapy', 0.0),
#  ('radiosurgery srs versus fractionated radiation therapy', 0.0),
#  ('range 39 5 ° c temperatures', 0.0),
#  ('red blood cells flux recovery time', 0.0),
#  ('regions of the female reproductive tract', 0.0),
#  ('responses to the female reproductive tract', 0.0),
#  ('rm in the female reproductive tract', 0.0),
#  ('rn2 promoter induces flip recombinase target', 0.0),
#  ('rna enthalpic contributions decrease ~ 61', 0.0),
#  ('sc in recombination fisher rat thyroid', 0.0),
#  ('stably in fischer rat thyroid cells', 0.0),
#  ('such as the flippase recognition target', 0.0),
#  ('surface of the female reproductive tract', 0.0),
#  ('system in the female reproductive tract', 0.0),
#  ('t cells present in both mucosal', 0.0),
#  ('target vector comprises flp recombination target', 0.0),
#  ('that infection the female reproductive tract', 0.0),
#  ('the assay utilizes fischer rat thyroid', 0.0),
#  ('the authors developed a fr target', 0.0),
#  ('the effect of daily fractionated rt', 0.0),
#  ('the flavonoids of rosa roxburghii tratt', 0.0),
#  ('the flippase flp flippase recognition target', 0.0),
#  ('the genomic via flp recombination target', 0.0),
#  ('the golgi apparatus fischer rat thyroid', 0.0),
#  ('the vagina a female reproductive tract', 0.0),
#  ('these problems lifelong factor replaced therapy', 0.0),
#  ('thickness ort and full retinal thickness', 0.0),
#  ('time hrt and forelimb retraction time', 0.0),
#  ('tract the human female reproductive tract', 0.0),
#  ('traits included the aggregate fertility index', 0.0),
#  ('transmission in the female reproductive tract', 0.0),
#  ('transmission through the female reproductive tract', 0.0),
#  ('type culture collection fischer rat thyroid', 0.0),
#  ('type dspt and free running type', 0.0),
#  ('understand how the female reproductive tract', 0.0),
#  ('uterus and upper female reproductive tract', 0.0),
#  ('we have using flp recognition target', 0.0),
#  ('we insertion a flp recombination target', 0.0),
#  ('we using the fluorescence reflectance transmittance', 0.0),
#  ('were investigated in fisher rat thyroid', 0.0),
#  ('when overexpressed 14 flp recombinase target', 0.0),
#  ('− current in fischer rat thyroid', 0.0),
#  ('+ t cells present in both mucosal', 0.0),
#  ('16 g von frey flinching responses threshold', 0.0),
#  ('182 dspt individuals 67 free running type', 0.0),
#  ('293 cells have the flp recombination target', 0.0),
#  ('accumulation of dii labeled folate receptor target', 0.0),
#  ('aco2 and entropic contributions increased ~ 39', 0.0),
#  ('activity in cftr expression fischer rat thyroid', 0.0),
#  ('allow efficient excision of flp recognition target', 0.0),
#  ('american type culture collection fischer rat thyroid', 0.0),
#  ('and a pair of flp recognition target', 0.0),
#  ('and binding to the flp recognition target', 0.0),
#  ('and developed in the female reproductive tract', 0.0),
#  ('and endosomal iron release ii cytoplasmic ferritin', 0.0),
#  ('and immunology of the female reproductive tract', 0.0),
#  ('and long termed effect of fractionated radiotherapy', 0.0),
#  ('and peptides of the female reproductive tract', 0.0),
#  ('are altered in the female reproductive tract', 0.0),
#  ('at 37 ° c fisher rat thyroid', 0.0),
#  ('bp dna sequence termed flippase recognition target', 0.0),
#  ('bursts of pulses termed fast repetitive tick', 0.0),
#  ('by estradiol in the female reproductive tract', 0.0),
#  ('c12 mediated cellular responses fisher rat thyroid', 0.0),
#  ('cassette flanked by two flp recombinase site', 0.0),
#  ('cd44 expression in the female reproductive tract', 0.0),
#  ('cd47 expression in the female reproductive tract', 0.0),
#  ('cells behavior in the female reproductive tract', 0.0),
#  ('cells dcs throughout the female reproductive tract', 0.0),
#  ('cells responses to the female reproductive tract', 0.0),
#  ('cells the authors developed a fr target', 0.0),
#  ('cerevisiae when overexpressed 14 flp recombinase target', 0.0),
#  ('certain dna sequence like flp recombinase target', 0.0),
#  ('cl − current in fischer rat thyroid', 0.0),
#  ('coli left pretransformed and a pcv21 dr', 0.0),
#  ('common infection of the female reproductive tract', 0.0),
#  ('comprehensive analysis of the female reproductive tract', 0.0),
#  ('confirmed by dna sequence fisher rat thyroid', 0.0),
#  ('culture model system using fischer rat thyroid', 0.0),
#  ('cutaneous red blood cells flux recovery time', 0.0),
#  ('cytotoxic complex into biomacromolecular protein cage apoferritin', 0.0),
#  ('dna insertion carrying flippase recognition target site', 0.0),
#  ('dysfunction evaluated by the flexion rotation test', 0.0),
#  ('earliest events in the female reproductive tract', 0.0),
#  ('electrostatic and coordination complex interaction the ferritin', 0.0),
#  ('elucidated in the human female reproductive tract', 0.0),
#  ('expression plasmid containing the flippase recognition target', 0.0),
#  ('expression stably in fischer rat thyroid cells', 0.0),
#  ('f2 f3 vowel duration formant rise time', 0.0),
#  ('febrile range 39 5 ° c temperatures', 0.0),
#  ('fertility traits included the aggregate fertility index', 0.0),
#  ('fig 1a bottom a fisher rat thyroid', 0.0),
#  ('flipase flp and it recognition target sequence', 0.0),
#  ('g l nahco 3 fischer rat thyroid', 0.0),
#  ('gastrointestinal gi tract and female reproductive tract', 0.0),
#  ('gin11 flanked by flp recombinase recognition target', 0.0),
#  ('halide influx assay in fisher rat thyroid', 0.0),
#  ('hiv 1 the human female reproductive tract', 0.0),
#  ('hiv transmission through the female reproductive tract', 0.0),
#  ('hormonal changes in the female reproductive tract', 0.0),
#  ('human airway cells and fisher rat thyroid', 0.0),
#  ('i sc in recombination fisher rat thyroid', 0.0),
#  ('ii introduction of flp recombinase recognition site', 0.0),
#  ('immune cells in the female reproductive tract', 0.0),
#  ('in a dedifferentiated line of thyroid cells', 0.0),
#  ('in the golgi apparatus fischer rat thyroid', 0.0),
#  ('in the vagina a female reproductive tract', 0.0),
#  ('increased i sc in fischer rat thyroid', 0.0),
#  ('inhibitor the assay utilizes fischer rat thyroid', 0.0),
#  ('interaction decrease iron efflux fpn and storage', 0.0),
#  ('into the genomic via flp recombination target', 0.0),
#  ('ire rna enthalpic contributions decrease ~ 61', 0.0),
#  ('liposomes and carboplatin loaded folate receptor target', 0.0),
#  ('location we insertion a flp recombination target', 0.0),
#  ('mediated immune in the female reproductive tract', 0.0),
#  ('morphogenetic properties of fischer rat thyroid cells', 0.0),
#  ('mucosal surface of the female reproductive tract', 0.0),
#  ('natural compound flavonoids of rosa roxburghii tratt', 0.0),
#  ('neutrophils from the lower female reproductive tract', 0.0),
#  ('nick we have using flp recognition target', 0.0),
#  ('not been established in free running type', 0.0),
#  ('observation we using the fluorescence reflectance transmittance', 0.0),
#  ('of adult art or fetal rat tail', 0.0),
#  ('of etx on fischer rat thyroid cells', 0.0),
#  ('of flavonoids extracted from rosa roxburghii tratt', 0.0),
#  ('of hiv in the female reproductive tract', 0.0),
#  ('of iodide influx in fisher rat thyroid', 0.0),
#  ('of mucus in the female reproductive tract', 0.0),
#  ('of protection to the female reproductive tract', 0.0),
#  ('of the flavonoids of rosa roxburghii tratt', 0.0),
#  ('of these problems lifelong factor replaced therapy', 0.0),
#  ('overlying fluid of the female reproductive tract', 0.0),
#  ('particular importance since the fisher rat thyroid', 0.0),
#  ('pathogens in the human female reproductive tract', 0.0),
#  ('pathogens that infection the female reproductive tract', 0.0),
#  ('pathways of epithelial morphogenesis fischer rat thyroid', 0.0),
#  ('patterning defects in the female reproductive tract', 0.0),
#  ('phase type dspt and free running type', 0.0),
#  ('polarized epithelial cells in fischer rat thyroid', 0.0),
#  ('polarized epithelial cells line fischer rat thyroid', 0.0),
#  ('pretransformed and a pcv21 tn 5 1', 0.0),
#  ('primary function of the female reproductive tract', 0.0),
#  ('promoter and flanked by flip recombinase target', 0.0),
#  ('prp c endocytosis in fischer rat thyroid', 0.0),
#  ('recombination of the flanked flp recognition target', 0.0),
#  ('recombination such as the flippase recognition target', 0.0),
#  ('red and carboplatin loaded folate receptor target', 0.0),
#  ('repeats 599 bp containing flp1p recombinase target', 0.0),
#  ('reproductive tract the human female reproductive tract', 0.0),
#  ('retinal thickness ort and full retinal thickness', 0.0),
#  ('retraction time hrt and forelimb retraction time', 0.0),
#  ('saccharomyces cerevisiae binding to it recognition target', 0.0),
#  ('semen deposition in the female reproductive tract', 0.0),
#  ('semen exposure in the female reproductive tract', 0.0),
#  ('similarly the effect of daily fractionated rt', 0.0),
#  ('spreads even though the female reproductive tract', 0.0),
#  ('stereotactic radiosurgery srs and fractionated radiation therapy', 0.0),
#  ('stereotactic radiosurgery srs versus fractionated radiation therapy', 0.0),
#  ('symmetry element of the flp recognition target', 0.0),
#  ('system of the human female reproductive tract', 0.0),
#  ('t cells in the female reproductive tract', 0.0),
#  ('target cells in the female reproductive tract', 0.0),
#  ('that binding to the flp recognition target', 0.0),
#  ('that enter the upper female reproductive tract', 0.0),
#  ('the fcho cells a flippase recombination target', 0.0),
#  ('the gastrointestinal gi and female reproductive tract', 0.0),
#  ('the ldf signals the flux rise time', 0.0),
#  ('the perspective that the forelimb retraction time', 0.0),
#  ('the rn2 promoter induces flip recombinase target', 0.0),
#  ('the target vector comprises flp recombination target', 0.0),
#  ('the uterus and upper female reproductive tract', 0.0),
#  ('they migrate into the female reproductive tract', 0.0),
#  ('to understand how the female reproductive tract', 0.0),
#  ('unique innervation of the female reproductive tract', 0.0),
#  ('upon interaction with the flp recognition target', 0.0),
#  ('upper regions of the female reproductive tract', 0.0),
#  ('using hygromycin 150μg ml fischer rat thyroid', 0.0),
#  ('viability were investigated in fisher rat thyroid', 0.0),
#  ('virus transmission in the female reproductive tract', 0.0),
#  ('vivo neutrophils in the female reproductive tract', 0.0),
#  ('was coupled with a folate receptor target', 0.0),
#  ('was examine in nondifferentiated fischer rat thyroid', 0.0),
#  ('were isolated from the female reproductive tract', 0.0),
#  ('with the flippase flp flippase recognition target', 0.0),
#  ('+ neutrophils from the lower female reproductive tract', 0.0),
#  ('+ t rm in the female reproductive tract', 0.0),
#  ('0 16 g von frey flinching responses threshold', 0.0),
#  ('1 fertility traits included the aggregate fertility index', 0.0),
#  ('14 and a pair of flp recognition target', 0.0),
#  ('3 semen deposition in the female reproductive tract', 0.0),
#  ('32 aco2 and entropic contributions increased ~ 39', 0.0),
#  ('34 bp dna sequence termed flippase recognition target', 0.0),
#  ('4a hiv transmission through the female reproductive tract', 0.0),
#  ('7 g l nahco 3 fischer rat thyroid', 0.0),
#  ('a comprehensive analysis of the female reproductive tract', 0.0),
#  ('a dna insertion carrying flippase recognition target site', 0.0),
#  ('above similarly the effect of daily fractionated rt', 0.0),
#  ('aco2 ire rna enthalpic contributions decrease ~ 61', 0.0),
#  ('acquisition and endosomal iron release ii cytoplasmic ferritin', 0.0),
#  ('adaptive immune system in the female reproductive tract', 0.0),
#  ('administration was coupled with a folate receptor target', 0.0),
#  ('against pathogens in the human female reproductive tract', 0.0),
#  ('and febrile range 39 5 ° c temperatures', 0.0),
#  ('and gin11 flanked by flp recombinase recognition target', 0.0),
#  ('and hiv 1 the human female reproductive tract', 0.0),
#  ('and immune cells in the female reproductive tract', 0.0),
#  ('and morphogenetic properties of fischer rat thyroid cells', 0.0),
#  ('and overlying fluid of the female reproductive tract', 0.0),
#  ('and unique innervation of the female reproductive tract', 0.0),
#  ('as the target vector comprises flp recombination target', 0.0),
#  ('assay of iodide influx in fisher rat thyroid', 0.0),
#  ('been elucidated in the human female reproductive tract', 0.0),
#  ('bending upon interaction with the flp recognition target', 0.0),
#  ('both electrostatic and coordination complex interaction the ferritin', 0.0),
#  ('bp symmetry element of the flp recognition target', 0.0),
#  ('by halide influx assay in fisher rat thyroid', 0.0),
#  ('by recombination of the flanked flp recognition target', 0.0),
#  ('by the rn2 promoter induces flip recombinase target', 0.0),
#  ('c2 dysfunction evaluated by the flexion rotation test', 0.0),
#  ('cancer cells the authors developed a fr target', 0.0),
#  ('cat cassette flanked by two flp recombinase site', 0.0),
#  ('cd8 + t cells present in both mucosal', 0.0),
#  ('cells mediated immune in the female reproductive tract', 0.0),
#  ('cells that containing a single flippase recognition target', 0.0),
#  ('cells viability were investigated in fisher rat thyroid', 0.0),
#  ('cellular accumulation of dii labeled folate receptor target', 0.0),
#  ('cftr inhibitor the assay utilizes fischer rat thyroid', 0.0),
#  ('channel activity in cftr expression fischer rat thyroid', 0.0),
#  ('comparing the ldf signals the flux rise time', 0.0),
#  ('directly expression plasmid containing the flippase recognition target',
#   0.0),
#  ('distinctive bursts of pulses termed fast repetitive tick', 0.0),
#  ('domain that binding to the flp recognition target', 0.0),
#  ('e coli left pretransformed and a pcv21 dr', 0.0),
#  ('ectopic location we insertion a flp recombination target', 0.0),
#  ('effect of etx on fischer rat thyroid cells', 0.0),
#  ('effect of flavonoids extracted from rosa roxburghii tratt', 0.0),
#  ('effect of the flavonoids of rosa roxburghii tratt', 0.0),
#  ('endocrinology and immunology of the female reproductive tract', 0.0),
#  ('epithelial culture model system using fischer rat thyroid', 0.0),
#  ('epithelium cd47 expression in the female reproductive tract', 0.0),
#  ('essential pathways of epithelial morphogenesis fischer rat thyroid', 0.0),
#  ('f1 f2 f3 vowel duration formant rise time', 0.0),
#  ('finally cutaneous red blood cells flux recovery time', 0.0),
#  ('gene promoter and flanked by flip recombinase target', 0.0),
#  ('growth and developed in the female reproductive tract', 0.0),
#  ('has not been established in free running type', 0.0),
#  ('how they migrate into the female reproductive tract', 0.0),
#  ('i was examine in nondifferentiated fischer rat thyroid', 0.0),
#  ('immune system of the human female reproductive tract', 0.0),
#  ('immune target cells in the female reproductive tract', 0.0),
#  ('importance to understand how the female reproductive tract', 0.0),
#  ('in 182 dspt individuals 67 free running type', 0.0),
#  ('in 293 cells have the flp recombination target', 0.0),
#  ('in polarized epithelial cells in fischer rat thyroid', 0.0),
#  ('in the fcho cells a flippase recombination target', 0.0),
#  ('in the gastrointestinal gi and female reproductive tract', 0.0),
#  ('in vivo neutrophils in the female reproductive tract', 0.0),
#  ('inoculated in the vagina a female reproductive tract', 0.0),
#  ('interest into the genomic via flp recombination target', 0.0),
#  ('inverted repeats 599 bp containing flp1p recombinase target', 0.0),
#  ('irp interaction decrease iron efflux fpn and storage', 0.0),
#  ('it spreads even though the female reproductive tract', 0.0),
#  ('layer of protection to the female reproductive tract', 0.0),
#  ('left pretransformed and a pcv21 tn 5 1', 0.0),
#  ('limb retraction time hrt and forelimb retraction time', 0.0),
#  ('line that containing a single flippase recognition target', 0.0),
#  ('liposomes red and carboplatin loaded folate receptor target', 0.0),
#  ('lymphocytes were isolated from the female reproductive tract', 0.0),
#  ('management of these problems lifelong factor replaced therapy', 0.0),
#  ('mediated i sc in recombination fisher rat thyroid', 0.0),
#  ('mirrored by estradiol in the female reproductive tract', 0.0),
#  ('ml at 37 ° c fisher rat thyroid', 0.0),
#  ('most common infection of the female reproductive tract', 0.0),
#  ('most cytotoxic complex into biomacromolecular protein cage apoferritin',
#   0.0),
#  ('mucosal immune system in the female reproductive tract', 0.0),
#  ('mucosal semen exposure in the female reproductive tract', 0.0),
#  ('nc allow efficient excision of flp recognition target', 0.0),
#  ('not in a dedifferentiated line of thyroid cells', 0.0),
#  ('nt liposomes and carboplatin loaded folate receptor target', 0.0),
#  ('of certain dna sequence like flp recombinase target', 0.0),
#  ('of particular importance since the fisher rat thyroid', 0.0),
#  ('of prp c endocytosis in fischer rat thyroid', 0.0),
#  ('of saccharomyces cerevisiae binding to it recognition target', 0.0),
#  ('of the uterus and upper female reproductive tract', 0.0),
#  ('of virus transmission in the female reproductive tract', 0.0),
#  ('open the perspective that the forelimb retraction time', 0.0),
#  ('outer retinal thickness ort and full retinal thickness', 0.0),
#  ('ovulation cd44 expression in the female reproductive tract', 0.0),
#  ('pathogens that enter the upper female reproductive tract', 0.0),
#  ('peptides and peptides of the female reproductive tract', 0.0),
#  ('potential pathogens that infection the female reproductive tract', 0.0),
#  ('prevent c12 mediated cellular responses fisher rat thyroid', 0.0),
#  ('receptor are altered in the female reproductive tract', 0.0),
#  ('recognizes and binding to the flp recognition target', 0.0),
#  ('recombinase flipase flp and it recognition target sequence', 0.0),
#  ('s cerevisiae when overexpressed 14 flp recombinase target', 0.0),
#  ('sa ii introduction of flp recombinase recognition site', 0.0),
#  ('segments of adult art or fetal rat tail', 0.0),
#  ('short and long termed effect of fractionated radiotherapy', 0.0),
#  ('sleep phase type dspt and free running type', 0.0),
#  ('specific recombination such as the flippase recognition target', 0.0),
#  ('specific t cells in the female reproductive tract', 0.0),
#  ('specific t rm in the female reproductive tract', 0.0),
#  ('structure of mucus in the female reproductive tract', 0.0),
#  ('t cells behavior in the female reproductive tract', 0.0),
#  ('t cells responses to the female reproductive tract', 0.0),
#  ('target with the flippase flp flippase recognition target', 0.0),
#  ('tgt hormonal changes in the female reproductive tract', 0.0),
#  ('the american type culture collection fischer rat thyroid', 0.0),
#  ('the earliest events in the female reproductive tract', 0.0),
#  ('the gastrointestinal gi tract and female reproductive tract', 0.0),
#  ('the natural compound flavonoids of rosa roxburghii tratt', 0.0),
#  ('the nick we have using flp recognition target', 0.0),
#  ('the polarized epithelial cells line fischer rat thyroid', 0.0),
#  ('the reproductive tract the human female reproductive tract', 0.0),
#  ('the upper regions of the female reproductive tract', 0.0),
#  ('thf increased i sc in fischer rat thyroid', 0.0),
#  ('to patterning defects in the female reproductive tract', 0.0),
#  ('transcription fig 1a bottom a fisher rat thyroid', 0.0),
#  ('transepithelial cl − current in fischer rat thyroid', 0.0),
#  ('transfection using hygromycin 150μg ml fischer rat thyroid', 0.0),
#  ('transmission of hiv in the female reproductive tract', 0.0),
#  ('under observation we using the fluorescence reflectance transmittance',
#   0.0),
#  ('using stereotactic radiosurgery srs versus fractionated radiation therapy',
#   0.0),
#  ('vip21 in the golgi apparatus fischer rat thyroid', 0.0),
#  ('were confirmed by dna sequence fisher rat thyroid', 0.0),
#  ('were expression stably in fischer rat thyroid cells', 0.0),
#  ('− human airway cells and fisher rat thyroid', 0.0),
#  ('+ i was examine in nondifferentiated fischer rat thyroid', 0.0),
#  ('+ t cells responses to the female reproductive tract', 0.0),
#  ('1 3 semen deposition in the female reproductive tract', 0.0),
#  ('10 how they migrate into the female reproductive tract', 0.0),
#  ('100μg ml at 37 ° c fisher rat thyroid', 0.0),
#  ('2011 the earliest events in the female reproductive tract', 0.0),
#  ('21 in the fcho cells a flippase recombination target', 0.0),
#  ('3 7 g l nahco 3 fischer rat thyroid', 0.0),
#  ('3d epithelial culture model system using fischer rat thyroid', 0.0),
#  ('a cellular accumulation of dii labeled folate receptor target', 0.0),
#  ('acceptor sa ii introduction of flp recombinase recognition site', 0.0),
#  ('additional layer of protection to the female reproductive tract', 0.0),
#  ('albicans inoculated in the vagina a female reproductive tract', 0.0),
#  ('an ectopic location we insertion a flp recombination target', 0.0),
#  ('and adaptive immune system in the female reproductive tract', 0.0),
#  ('and cells viability were investigated in fisher rat thyroid', 0.0),
#  ('and lymphocytes were isolated from the female reproductive tract', 0.0),
#  ('and the mucosal surface of the female reproductive tract', 0.0),
#  ('antigen specific t cells in the female reproductive tract', 0.0),
#  ('are mirrored by estradiol in the female reproductive tract', 0.0),
#  ('as the gastrointestinal gi tract and female reproductive tract', 0.0),
#  ('barrier in vivo neutrophils in the female reproductive tract', 0.0),
#  ('base assay of iodide influx in fisher rat thyroid', 0.0),
#  ('before it spreads even though the female reproductive tract', 0.0),
#  ('bi directly expression plasmid containing the flippase recognition target',
#   0.0),
#  ('binding domain that binding to the flp recognition target', 0.0),
#  ('but not in a dedifferentiated line of thyroid cells', 0.0),
#  ('c and febrile range 39 5 ° c temperatures', 0.0),
#  ('c1 c2 dysfunction evaluated by the flexion rotation test', 0.0),
#  ('canopy under observation we using the fluorescence reflectance transmittance',
#   0.0),
#  ('cationic peptides and peptides of the female reproductive tract', 0.0),
#  ('cause tgt hormonal changes in the female reproductive tract', 0.0),
#  ('caveolin vip21 in the golgi apparatus fischer rat thyroid', 0.0),
#  ('cd4 + t rm in the female reproductive tract', 0.0),
#  ('cells growth and developed in the female reproductive tract', 0.0),
#  ('cells line that containing a single flippase recognition target', 0.0),
#  ('cfbe41o − human airway cells and fisher rat thyroid', 0.0),
#  ('cftr channel activity in cftr expression fischer rat thyroid', 0.0),
#  ('cftr mediated i sc in recombination fisher rat thyroid', 0.0),
#  ('cftr thf increased i sc in fischer rat thyroid', 0.0),
#  ('coli left pretransformed and a pcv21 tn 5 1', 0.0),
#  ('complex and unique innervation of the female reproductive tract', 0.0),
#  ('constructs were expression stably in fischer rat thyroid cells', 0.0),
#  ('data open the perspective that the forelimb retraction time', 0.0),
#  ('defense against pathogens in the human female reproductive tract', 0.0),
#  ('delayed sleep phase type dspt and free running type', 0.0),
#  ('determined by halide influx assay in fisher rat thyroid', 0.0),
#  ('dna bending upon interaction with the flp recognition target', 0.0),
#  ('during ovulation cd44 expression in the female reproductive tract', 0.0),
#  ('dynamic t cells behavior in the female reproductive tract', 0.0),
#  ('evermore importance to understand how the female reproductive tract', 0.0),
#  ('exon 14 and a pair of flp recognition target', 0.0),
#  ('fig 4a hiv transmission through the female reproductive tract', 0.0),
#  ('flp in 293 cells have the flp recombination target', 0.0),
#  ('fold aco2 ire rna enthalpic contributions decrease ~ 61', 0.0),
#  ('for comparing the ldf signals the flux rise time', 0.0),
#  ('formation in polarized epithelial cells in fischer rat thyroid', 0.0),
#  ('fornix epithelium cd47 expression in the female reproductive tract', 0.0),
#  ('frequencies f1 f2 f3 vowel duration formant rise time', 0.0),
#  ('from the american type culture collection fischer rat thyroid', 0.0),
#  ('gc and hiv 1 the human female reproductive tract', 0.0),
#  ('gene and gin11 flanked by flp recombinase recognition target', 0.0),
#  ('gene in 182 dspt individuals 67 free running type', 0.0),
#  ('gene target with the flippase flp flippase recognition target', 0.0),
#  ('hek293 cells that containing a single flippase recognition target', 0.0),
#  ('hind limb retraction time hrt and forelimb retraction time', 0.0),
#  ('hiv and immune cells in the female reproductive tract', 0.0),
#  ('impact pathogens that enter the upper female reproductive tract', 0.0),
#  ('in e coli left pretransformed and a pcv21 dr', 0.0),
#  ('in the reproductive tract the human female reproductive tract', 0.0),
#  ('insertion of certain dna sequence like flp recombinase target', 0.0),
#  ('involve both electrostatic and coordination complex interaction the ferritin',
#   0.0),
#  ('ip administration was coupled with a folate receptor target', 0.0),
#  ('ire irp interaction decrease iron efflux fpn and storage', 0.0),
#  ('iron acquisition and endosomal iron release ii cytoplasmic ferritin', 0.0),
#  ('irt outer retinal thickness ort and full retinal thickness', 0.0),
#  ('is of particular importance since the fisher rat thyroid', 0.0),
#  ('lcmv specific t rm in the female reproductive tract', 0.0),
#  ('leads to patterning defects in the female reproductive tract', 0.0),
#  ('levels in the gastrointestinal gi and female reproductive tract', 0.0),
#  ('lumen of the uterus and upper female reproductive tract', 0.0),
#  ('ly6g + neutrophils from the lower female reproductive tract', 0.0),
#  ('main structure of mucus in the female reproductive tract', 0.0),
#  ('measured finally cutaneous red blood cells flux recovery time', 0.0),
#  ('mechanisms of prp c endocytosis in fischer rat thyroid', 0.0),
#  ('mediated transepithelial cl − current in fischer rat thyroid', 0.0),
#  ('method has not been established in free running type', 0.0),
#  ('mucosal immune system of the human female reproductive tract', 0.0),
#  ('mucosa and overlying fluid of the female reproductive tract', 0.0),
#  ('nontargeted nt liposomes and carboplatin loaded folate receptor target',
#   0.0),
#  ('not been elucidated in the human female reproductive tract', 0.0),
#  ('nt liposomes red and carboplatin loaded folate receptor target', 0.0),
#  ('nucleocapsid nc allow efficient excision of flp recognition target', 0.0),
#  ('of cftr inhibitor the assay utilizes fischer rat thyroid', 0.0),
#  ('of interest into the genomic via flp recombination target', 0.0),
#  ('of inverted repeats 599 bp containing flp1p recombinase target', 0.0),
#  ('of potential pathogens that infection the female reproductive tract', 0.0),
#  ('of the natural compound flavonoids of rosa roxburghii tratt', 0.0),
#  ('of the nick we have using flp recognition target', 0.0),
#  ('on s cerevisiae when overexpressed 14 flp recombinase target', 0.0),
#  ('or segments of adult art or fetal rat tail', 0.0),
#  ('outcome of virus transmission in the female reproductive tract', 0.0),
#  ...]

# %%
longforms0 = miners['FRT'].get_longforms(smoothing_param=10)

# %%
longforms0
# Out:
# [('in the female reproductive tract', 0.6505882352941178),
#  ('target', 0.5102599179206566),
#  ('fischer rat thyroid', 0.4844720496894409),
#  ('fisher rat thyroid', 0.42000000000000004),
#  ('time', 0.15714285714285717),
#  ('site', 0.08333333333333333),
#  ('free running type', 0.08333333333333333),
#  ('fischer rat thyroid cells', 0.08333333333333333),
#  ('therapy', 0.027777777777777773),
#  ('rosa roxburghii tratt', 0.027777777777777773)]

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('in the female reproductive tract', 0.7900000000000001)),
#  (1, ('fischer rat thyroid', 0.6554621848739495)),
#  (2, ('of the female reproductive tract', 0.6298701298701299)),
#  (3, ('fisher rat thyroid', 0.6)),
#  (4, ('target', 0.5930047694753577)),
#  (5, ('the human female reproductive tract', 0.39999999999999997)),
#  (6, ('time', 0.275)),
#  (7, ('site', 0.16666666666666666)),
#  (8, ('free running type', 0.16666666666666666)),
#  (9, ('fischer rat thyroid cells', 0.16666666666666666)),
#  (10, ('therapy', 0.055555555555555546)),
#  (11, ('rosa roxburghii tratt', 0.055555555555555546))]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i not in [7, 8, 10, 12]]

# %%
list(enumerate(top))
# Out:
# [(0, ('mannan oligosaccharide', 34.74999999999999)),
#  (1, ('mannanoligosaccharides', 15.588235294117647)),
#  (2, ('oligosaccharide', 14.244897959183675)),
#  (3, ('mannooligosaccharides', 11.615384615384615)),
#  (4, ('mitochondrial oxidative stress', 10.8)),
#  (5, ('mosapride citrate', 9.125)),
#  (6, ('of mannan oligosaccharide', 7.833333333333333)),
#  (7, ('margin of stability', 7.6)),
#  (8, ('agonist mosapride citrate', 4.8)),
#  (9, ('the effects of mannan oligosaccharide', 4.0)),
#  (10, ('5 ht 4 r agonist mosapride citrate', 4.0)),
#  (11, ('of dietary mannan oligosaccharide', 3.4285714285714284)),
#  (12, ('dietary mannan oligosaccharide', 3.333333333333333)),
#  (13, ('of mannanoligosaccharides', 3.2)),
#  (14, ('motor optimality score', 3.0)),
#  (15, ('yeast cell wall mannooligosaccharides', 3.0)),
#  (16, ('the effects of dietary mannan oligosaccharide', 3.0)),
#  (17,
#   ('ention period consisting of control con soccer soc moderate intensity continuous swimming',
#    3)),
#  (18, ('the main olfactory system', 2.8)),
#  (19, ('manno oligosaccharide', 2.5)),
#  (20, ('metal oxidative semiconductor', 2.5)),
#  (21, ('maltooligosaccharides', 2.0)),
#  (22, ('and experimental', 2.0)),
#  (23, ('dynamic margin of stability', 2.0)),
#  (24, ('supplementation of mannan oligosaccharide', 2.0)),
#  (25, ('the margin of stability', 2.0)),
#  (26, ('5 ht 4 receptor agonist mosapride citrate', 2.0)),
#  (27,
#   ('of common carp fed different levels of dietary mannan oligosaccharide',
#    2.0)),
#  (28,
#   ('azone and sedatives antidepressants nefazodone and buspirone filled circles margin of safety',
#    2)),
#  (29, ('system', 1.7142857142857144)),
#  (30, ('main olfactory system', 1.666666666666667)),
#  (31, ('effects of mannan oligosaccharide', 1.666666666666667)),
#  (32, ('receptor agonist mosapride citrate', 1.5)),
#  (33, ('occlusal splint', 1.3333333333333333)),
#  (34, ('of mannooligosaccharides', 1.3333333333333333)),
#  (35, ('margin of safety', 1.3333333333333333)),
#  (36, ('by the main olfactory system', 1.3333333333333333)),
#  (37, ('mos', 1.0)),
#  (38, ('mosaicplasty', 1.0)),
#  (39, ('and mannanoligosaccharides', 1.0)),
#  (40, ('and mannan oligosaccharide', 1.0)),
#  (41, ('by mosapride citrate', 1.0)),
#  (42, ('exposure corrected cytotoxicity', 1.0)),
#  (43, ('mannose rich oligosaccharide', 1.0)),
#  (44, ('maxillary occlusal splint', 1.0)),
#  (45, ('of dietary mannanoligosaccharides', 1.0)),
#  (46, ('of manno oligosaccharide', 1.0)),
#  (47, ('prebiotics mannan oligosaccharide', 1.0)),
#  (48, ('cutaneous microvascular occlusal syndromes', 1)),
#  (49, ('dietary supplementation of mannanoligosaccharides', 1.0)),
#  (50, ('levels of mannan oligosaccharide', 1.0)),
#  (51, ('mediolateral margin of stability', 1.0)),
#  (52, ('such as mannan oligosaccharide', 1.0)),
#  (53, ('the metal oxidative semiconductor', 1.0)),
#  (54, ('to mitochondrial oxidative stress', 1.0)),
#  (55, ('of the medical outcomes study', 1.0)),
#  (56, ('the murine main olfactory system', 1)),
#  (57, ('the present resulting suggest that mannanoligosaccharides', 1)),
#  (58, ('to investigated the effects of mannanoligosaccharides', 1.0)),
#  (59, ('as well as in production of mannooligosaccharides', 1.0)),
#  (60, ('sio 2 si based metal oxidative semiconductor', 1)),
#  (61, ('a 5 ht 4 r agonist mosapride citrate', 1.0)),
#  (62, ('are processed primarily by the main olfactory system', 1.0)),
#  (63,
#   ('ccharides such as fructooligosaccharides fos xylooligosaccharides xos mannanoligosaccharides',
#    1)),
#  (64,
#   ('pounds with fructooligosaccharides fos galactooligosaccharides gos and mannanoligoasacchardes',
#    1)),
#  (65, ('the 5 ht 4 r agonist mosapride citrate', 1.0)),
#  (66, ('this study explore the hypothesis that mannan oligosaccharide', 1)),
#  (67,
#   ('this study investigated protective effects of mannan oligosaccharide', 1)),
#  (68, ('this study investigated the effects of mannan oligosaccharide', 1)),
#  (69,
#   ('effects of brain derived neurotrophic factor bdnf mosapride citrate',
#    1.0)),
#  (70,
#   ('lipopolysaccharide lps and three functional feed ingredient nucleotides mannanoligosaccharides',
#    1)),
#  (71,
#   ('nonsteroidal anti inflammatory drug nsaid induced mitochondrial oxidative stress',
#    1)),
#  (72,
#   ('obesity is associated with gut microbiome dysbiosis mannose oligosaccharide',
#    1)),
#  (73, ('the study assess the effects of dietary mannan oligosaccharide', 1)),
#  (74,
#   ('this study investigated the effects of dietary mannan oligosaccharide',
#    1)),
#  (75,
#   ('based on recent glycomics advancement specific mannose based oligosaccharide mannooligosaccharides',
#    1)),
#  (76,
#   ('clinical study have shown that the consumption of coffee mannooligosaccharides',
#    1)),
#  (77,
#   ('in the hydrolysis of softwood significant amounts of manno oligosaccharide',
#    1)),
#  (78, ('next s s determine the infant s motor optimality score', 1)),
#  (79,
#   ('the study was conducted to investigated the effects of mannanoligosaccharides',
#    1)),
#  (80,
#   ('ce fermentation begins these carbohydrates are enzymatically digested to form maltooligosaccharides',
#    1)),
#  (81,
#   ('glycolysis and also mitochondrial dysfunction and oxidative stress mitochondrial oxidative stress',
#    1)),
#  (82,
#   ('grand et al 2013 galactooligosaccharides kanakupt et al 2011 and mannanoligosaccharides',
#    1)),
#  (83,
#   ('grobiotic a ® increase survival rate likewise administration of dietary mannanoligosaccharides',
#    1)),
#  (84,
#   ('intestinal microflora resulting in enhanced health and wellbeing of animals mannanoligosaccharides',
#    1)),
#  (85,
#   ('rie restriction mimetic or body composition enhanced recent study suggest mannanoligosaccharides',
#    1)),
#  (86,
#   ('s control positive control zn bacitracin designated as antibiotic mannan oligosaccharide',
#    1)),
#  (87,
#   ('se pathologies apoptotic cell death mitochondrial dysfunction and mitochondrial oxidative stress',
#    1)),
#  (88,
#   ('the study was conducted to evaluate the effects of dietary mannanoligosaccharides',
#    1)),
#  (89,
#   ('this study was conducted to determine the effects of mannan oligosaccharide',
#    1)),
#  (90,
#   ('tion of semi crystalline structures disproportionating enzymes cleave short malto oligosaccharide',
#    1)),
#  (91,
#   ('tly required one potential candidate including dietary supplementation with mannan oligosaccharide',
#    1)),
#  (92,
#   ('twenty holstein calves were used to investigated the effects of mannanoligosaccharides',
#    1)),
#  (93,
#   ('yzed brewer s yeast dairy ingredient components and fermentation production mannanoligosaccharides',
#    1)),
#  (94,
#   ('02 current there is considerable evidence showed that the inclusion of mannanoligosaccharides',
#    1)),
#  (95,
#   ('an oral administered serotonin 4 5 ht 4 receptor agonist mosapride citrate',
#    1)),
#  (96,
#   ('control supplementation with zinc bacitracin and two test diet supplementation with mannoligosaccharide',
#    1)),
#  (97,
#   ('d measure and gratefully acknowledge alltech the netherlands for generously provided actigen',
#    1)),
#  (98,
#   ('e imaging mri in evaluate cartilage regeneration following microfracture mfx and mosaicplasty',
#    1)),
#  (99,
#   ('ects of diet supplementation with live yeast saccharomyces cerevisiae and mannan oligosaccharide',
#    1)),
#  (100,
#   ('hreatening due to emergence of multiple antibiotic resistant strains mannose rich oligosaccharide',
#    1)),
#  (101,
#   ('indicates a decreased endogenous threonine excretion the effects of dietary mannan oligosaccharide',
#    1)),
#  (102,
#   ('ious study reported that aflatoxin b1 afb1 promoted influenza replication mannan oligosaccharide',
#    1)),
#  (103,
#   ('ntrol basal a positive control zn bacitracin and two dietary additives mannanoligosaccharides',
#    1)),
#  (104,
#   ('pplemented diet growth performance of common carp fingerlings fed dietary mannan oligosaccharide',
#    1)),
#  (105,
#   ('raveolens essential oils aeo and deo respectively probiotic pro and mannan oligosaccharide',
#    1)),
#  (106,
#   ('study was conducted to investigated the effects of dietary supplementation of mannanoligosaccharides',
#    1)),
#  (107,
#   ('the apparent gender different in response to mos consumption coffee derived mannooligosaccharides',
#    1)),
#  (108,
#   ('to estimate the duration of survival s of patients with metastatic osteosarcoma',
#    1)),
#  (109,
#   ('1 taken together our resulting highlight protective effects of yeast cell wall mannooligosaccharides',
#    1)),
#  (110,
#   ('arbachol induced contractions in intestinal circular smooth muscles and effects of mosapride citrate',
#    1)),
#  (111,
#   ('ated intestinal microbiota of common carp among the most common prebiotics mannan oligosaccharide',
#    1)),
#  (112,
#   ('by a 5 hydroxytryptamine 4 receptor 5 ht 4 r agonist mosapride citrate',
#    1.0)),
#  (113,
#   ('cell pbmc and bronchoalveolar lavage fluid balf cell from control or mannan oligosaccharide',
#    1)),
#  (114,
#   ('cell transplantation fig 1 effects of brain derived neurotrophic factor bdnf mosapride citrate',
#    1)),
#  (115,
#   ('defence elicitor for several years here we reported a novel oligosaccharide mannan oligosaccharide',
#    1)),
#  (116,
#   ('exert direct toxic effects within neurons including the induction of mitochondrial oxidative stress',
#    1)),
#  (117,
#   ('g effects interventions to prevent falls this study quantified mediolateral margin of stability',
#    1)),
#  (118,
#   ('in feed and food industries by the production of potential health promoted mannooligosaccharides',
#    1)),
#  (119,
#   ('ion of mitochondrial glutathione is sufficient to sensitize cell to mitochondrial oxidative stress',
#    1)),
#  (120,
#   ('ional theory dft calculate finally we applied the recent introduced metrical oxidative state',
#    1)),
#  (121,
#   ('n biofuel production from lignocellulose biomass as well as in production of mannooligosaccharides',
#    1)),
#  (122,
#   ('ns for repair of cds exist including microfracture mfx and autologous osteochondral mosaicplasty',
#    1)),
#  (123,
#   ('ompositional change dethlefsen et al 2008 stanley et al 2014 the mannan oligosaccharide',
#    1)),
#  (124,
#   ('racteristics dogs were randomly allotted to treatment 1 chicory ch 1 mannan oligosaccharide',
#    1)),
#  (125,
#   ('recruitment and activation fig 5 per os treatment of control mice with mannooligosaccharides',
#    1)),
#  (126,
#   ('se isolated soy protein diet to examine the effects of inulin oligofructose mannanoligosaccharides',
#    1)),
#  (127,
#   ('stream regulatory signaling of these proteolytic events is linked to mitochondrial oxidative stress',
#    1)),
#  (128,
#   ('to determine the effects of the 5 ht 4 r agonist mosapride citrate', 1)),
#  (129,
#   ('turkeys was conducted to evaluate the administration of different levels of mannan oligosaccharide',
#    1)),
#  (130,
#   ('we previously reported that a serotonin 4 5 ht4 receptor agonist mosapride citrate',
#    1)),
#  (131,
#   ('xperiments the sows from the experimental groups had a dietary supplementation of mannanoligosaccharides',
#    1)),
#  (132,
#   ('05 serum lysozyme activation of common carp fed different levels of dietary mannan oligosaccharide',
#    1)),
#  (133,
#   ('a to test the protective effects of an oligomannan prebiotics yeast cell wall mannooligosaccharides',
#    1)),
#  (134,
#   ('al immunoglobulin ig levels of common carp fed different levels of dietary mannan oligosaccharide',
#    1)),
#  (135,
#   ('ance of spontaneous movement patterns from video recorded we calculate a motor optimality score',
#    1)),
#  (136,
#   ('clusion of probiotic such as live yeast cultures and prebiotics such as mannan oligosaccharide',
#    1)),
#  (137,
#   ('depression inventory ii bdi ii and social support medical outcomes study social support survey',
#    1)),
#  (138,
#   ('dy investigated the effects of fermentation soybean meal fsbm with or without mannan oligosaccharide',
#    1)),
#  (139,
#   ('ed by mos administration fig 8 here we have provided evidence that yeast mannooligosaccharides',
#    1)),
#  (140,
#   ('estinal tract git influences mucin gene expression and mucin types and 2 mannan oligosaccharide',
#    1)),
#  (141,
#   ('f broilers under cyclic heat stress hs as modulated by supplementation of mannan oligosaccharide',
#    1)),
#  (142,
#   ('feed trial was conducted to investigated the effects of dietary β glucan mannan oligosaccharide',
#    1)),
#  (143,
#   ('lement on β mannanase production by m cinnamomea nfcci 3724 mannose free manno oligosaccharide',
#    1)),
#  (144,
#   ('logical marker of hs in broilers as modulated by dietary supplementation of mannan oligosaccharide',
#    1)),
#  (145,
#   ('of hph notably both the translocation assay and the luciferase assay identified mosapride citrate',
#    1)),
#  (146,
#   ('of salmonella has also been reported in birds treated with the prebiotics mannan oligosaccharide',
#    1)),
#  (147,
#   ('pecifics johnston 1990 volatile odors cues are processed primarily by the main olfactory system',
#    1)),
#  (148,
#   ('present study we investigated the effects of prebiotics fructo fos galacto gos and mannan',
#    1)),
#  (149,
#   ('rch temporary custom fit mandibular advancement device mad and a single maxillary occlusal splint',
#    1)),
#  (150,
#   ('rojections cal bar 100 µm effects of brain derived neurotrophic factor bdnf mosapride citrate',
#    1)),
#  (151,
#   ('rom lignocellulose biomass ishii et al 2016 as well as in production of mannooligosaccharides',
#    1)),
#  (152,
#   ('sses making them ideal candidate for mass calibration used a wide range of maltooligosaccharides',
#    1)),
#  (153,
#   ('the mechanism of action of heme oxygenase 1 ho 1 in mitochondrial oxidative stress',
#    1)),
#  (154,
#   ('the objective of the current study were to explore the effects of mannan oligosaccharide',
#    1)),
#  (155,
#   ('the objective of this experiment was to compare the effects of dietary mannan oligosaccharide',
#    1)),
#  (156,
#   ('the purpose of this study was to investigated the effects of adding mannan oligosaccharide',
#    1)),
#  (157,
#   ('the world where antibiotic growth promoted have been banned the effects of mannan oligosaccharide',
#    1)),
#  (158,
#   ('tion through electric current and ethanol to improve embryonic developmental competence the c mos',
#    1)),
#  (159,
#   ('uggested that the processed of environmental odors occurs exclusively by the main olfactory system',
#    1)),
#  (160,
#   ('y four experimental groups were then form 1 control 2 yeast cell wall mannooligosaccharides',
#    1)),
#  (161,
#   ('1 0 and 1 3 of national research council nrc 1994 recommendations and manno oligosaccharide',
#    1)),
#  (162,
#   ('2010 than means or standard deviations alone this study determine how com margin of stability',
#    1)),
#  (163,
#   ('and crude mucin turnover 2 there was no interaction between the effects of manno oligosaccharide',
#    1)),
#  (164,
#   ('calized within the granulation tissue of anastomoses a 5 ht 4 receptor agonist mosapride citrate',
#    1)),
#  (165,
#   ('d in order to examine whether a glycogen like polymer or low molecular weight maltooligosaccharides',
#    1)),
#  (166,
#   ('e objective of this study was to evaluate the benefits of supplementation of mannan oligosaccharide',
#    1)),
#  (167,
#   ('en spitz pups were divided into two groups control con with no supplementation and experimental',
#    1)),
#  (168,
#   ('eo recorded for the assess of the early motor repertoire including their motor optimality score',
#    1)),
#  (169,
#   ('i cardiac version modified 24 and the physical functional scale of the medical outcomes study',
#    1)),
#  (170,
#   ('in this model of familial al further indicates a central role for mitochondrial oxidative stress',
#    1)),
#  (171,
#   ('ine production in this study we investigated the effects of a yeast cell wall mannooligosaccharides',
#    1)),
#  (172,
#   ('nd and colombia our recent study showed that pkc contains high levels of mannan oligosaccharide',
#    1)),
#  (173,
#   ('ne transport is a principal mechanism by which bcl 2 suppresses mos mitochondrial oxidative stress',
#    1)),
#  (174,
#   ('omplement activation ach 50 of common carp fed different levels of dietary mannan oligo saccharide',
#    1)),
#  (175,
#   ('or biosensor to turn on and off therapeutic gene is test herein mitochondrial oxidative stress',
#    1)),
#  (176,
#   ('rint of 500 bytes which including kernel scheduler and network stack the mantis operating system',
#    1)),
#  (177,
#   ('ry processed social odors 103 the majority of research has implicated the main olfactory system',
#    1)),
#  (178,
#   ('s in both poultry and humans is high desirable evidence exist that mannose rich oligosaccharide',
#    1)),
#  (179,
#   ('se through modulated of gut microbiota in the present study the effects of mannan oligosaccharide',
#    1)),
#  (180,
#   ('silicon si has the most mature and low cost technology moreover the metal oxidative semiconductor',
#    1)),
#  (181,
#   ('sulphate copper cu and zinc zn supplementation in presence or absence of a mannan oligosaccharide',
#    1)),
#  (182,
#   ('tio with vo blends could be to incorporate natural feed additives such as mannan oligosaccharide',
#    1)),
#  (183,
#   ('ucose and 0 8 galactose was supplied by friesland campina domo amersfoort netherlands bio mos',
#    1)),
#  (184,
#   ('ught to play independent role in mammalian olfaction according to this the main olfactory system',
#    1)),
#  (185,
#   ('which can more appropriately be applied to dynamic tasks like walking the margin of stability',
#    1)),
#  (186,
#   ('43 46 vimentin has been shown to be phosphorylated on ser459 by the p37mos protein kinase',
#    1)),
#  (187,
#   ('and department of health hospital episode statistics there was a 6 increase in minor oral surgery',
#    1)),
#  (188,
#   ('are detected odors from a distance the odors are processed primarily by the main olfactory system',
#    1)),
#  (189,
#   ('ated as 1 34 times the trochanteric height massen and kodde 1979 dynamic margin of stability',
#    1)),
#  (190,
#   ('b40 leiber gmbh hafenstraße germany consisting of 1 3 1 6 β d glucan and mannanoligosaccharides',
#    1)),
#  (191,
#   ('ders we have previously shown that enteric neural 5 ht 4 receptor activation by mosapride citrate',
#    1)),
#  (192,
#   ('eral edge of the based of support bos thus resulting in positive mediolateral margin of stability',
#    1)),
#  (193,
#   ('iance maa on sleep bruxism sb activation compare to baseline and to a mandibular occlusal splint',
#    1)),
#  (194,
#   ('imed to evaluate the impact of first line treatment on surgical outcomes and median overall survival',
#    1)),
#  (195,
#   ('ine procyclidine from phh in this category fig 3 b c fig 3 exposure corrected cytotoxicity',
#    1)),
#  (196,
#   ('log cfu per g of intestinal of common carp fed different levels of dietary mannan oligosaccharide',
#    1)),
#  (197,
#   ('mortality rate was not affected by fos or mos in this study the effects of mannooligosaccharides',
#    1)),
#  (198,
#   ('n here we describe the synthesis of three polyphenolic flavonoids 5 hydroxy 6 7 dimethoxy flavone',
#    1)),
#  (199,
#   ('pshire x duroc in each experiment the sows were assigned to two groups control and experimental',
#    1)),
#  (200,
#   ('s neurogenesis was promoted by oral application of the 5 ht 4 receptor agonist mosapride citrate',
#    1)),
#  (201,
#   ('study sleep scale mos sleep scale was originally developed as part of the medical outcomes study',
#    1)),
#  (202,
#   ('t detected nd value and filled square < ic 50 c max value exposure corrected cytotoxicity',
#    1)),
#  (203,
#   ('total plasma c max μm referred also throughout the manuscript as an assay margin of safety',
#    1)),
#  (204,
#   ('y caused by viruses bacteria and parasites in the last decade the used of mannan oligosaccharide',
#    1)),
#  (205,
#   ('apv or ml platform mlp or visual mlv oscillations we computed ap and ml margin of stability',
#    1)),
#  (206,
#   ('by 5 ht 4 receptor activation activation of enteric neural 5 ht 4 receptor by mosapride citrate',
#    1)),
#  (207,
#   ('dy is to clarify the anti inflammatory mechanism under the 5 ht 4 r agonist mosapride citrate',
#    1)),
#  (208,
#   ('ean distance from the lateral heel marker to the com at heelstrike the dynamic margin of stability',
#    1)),
#  (209,
#   ('ed in enteric neurogenesis by a 5 hydroxytryptamine 4 receptor 5 ht 4 r agonist mosapride citrate',
#    1)),
#  (210,
#   ('his limitation hof et al 2005 proposed a new measure referred to as the margin of stability',
#    1)),
#  (211,
#   ('ises the infant s early motor repertoire which can be assess by used the motor optimality score',
#    1)),
#  (212,
#   ('neural stem cell enhanced by a 5 hydroxytryptamine 4 receptor 5 ht 4 r agonist mosapride citrate',
#    1)),
#  (213,
#   ('the usual single pn junction model fails to explain the high ff resulting a metal oxidative semiconductor',
#    1)),
#  (214,
#   ('ths average body weight 4 2 kg were divided into two equal groups control con and experimental',
#    1)),
#  (215,
#   ('n guinea pigs and rats by rectal transection and anastomosis a 5 ht 4 r agonist mosapride citrate',
#    1)),
#  (216,
#   ('to rescue aganglionic disorders in the whole gut we applied a 5 ht 4 r agonist mosapride citrate',
#    1)),
#  (217,
#   ('to the next that were not apparent in means and standard deviations of mos the margin of stability',
#    1)),
#  (218,
#   ('ain objective of this study was to assess the effects of 4 g kg − 1 dietary mannan oligosaccharide',
#    1)),
#  (219,
#   ('eded the purpose of this study was to evaluate the effects of a mad and a maxillary occlusal splint',
#    1)),
#  (220,
#   ('mpared to the edge of the bos can be used to calculate an individual s dynamic margin of stability',
#    1)),
#  (221, ('actigen', 0.0)),
#  (222, ('citrate', 0.0)),
#  (223, ('cytotoxicity', 0.0)),
#  (224, ('experimental', 0.0)),
#  (225, ('flavone', 0.0)),
#  (226, ('kinase', 0.0)),
#  (227, ('mannan', 0.0)),
#  (228, ('mannanoligoasacchardes', 0.0)),
#  (229, ('mannoligosaccharide', 0.0)),
#  (230, ('osteosarcoma', 0.0)),
#  (231, ('saccharide', 0.0)),
#  (232, ('safety', 0.0)),
#  (233, ('score', 0.0)),
#  (234, ('semiconductor', 0.0)),
#  (235, ('splint', 0.0)),
#  (236, ('stability', 0.0)),
#  (237, ('state', 0.0)),
#  (238, ('stress', 0.0)),
#  (239, ('study', 0.0)),
#  (240, ('surgery', 0.0)),
#  (241, ('survey', 0.0)),
#  (242, ('survival', 0.0)),
#  (243, ('swimming', 0.0)),
#  (244, ('syndromes', 0.0)),
#  (245, ('additives mannanoligosaccharides', 0.0)),
#  (246, ('and mannan', 0.0)),
#  (247, ('and mannanoligoasacchardes', 0.0)),
#  (248, ('and mosaicplasty', 0.0)),
#  (249, ('animals mannanoligosaccharides', 0.0)),
#  (250, ('bio mos', 0.0)),
#  (251, ('c mos', 0.0)),
#  (252, ('coffee mannooligosaccharides', 0.0)),
#  (253, ('continuous swimming', 0.0)),
#  (254, ('corrected cytotoxicity', 0.0)),
#  (255, ('derived mannooligosaccharides', 0.0)),
#  (256, ('dietary mannanoligosaccharides', 0.0)),
#  (257, ('dimethoxy flavone', 0.0)),
#  (258, ('form maltooligosaccharides', 0.0)),
#  (259, ('malto oligosaccharide', 0.0)),
#  (260, ('mannose oligosaccharide', 0.0)),
#  (261, ('metastatic osteosarcoma', 0.0)),
#  (262, ('nucleotides mannanoligosaccharides', 0.0)),
#  (263, ('occlusal syndromes', 0.0)),
#  (264, ('of maltooligosaccharides', 0.0)),
#  (265, ('of safety', 0.0)),
#  (266, ('of stability', 0.0)),
#  (267, ('olfactory system', 0.0)),
#  (268, ('oligo saccharide', 0.0)),
#  (269, ('oligofructose mannanoligosaccharides', 0.0)),
#  (270, ('oligosaccharide mannooligosaccharides', 0.0)),
#  (271, ('operating system', 0.0)),
#  (272, ('optimality score', 0.0)),
#  (273, ('oral surgery', 0.0)),
#  (274, ('osteochondral mosaicplasty', 0.0)),
#  (275, ('outcomes study', 0.0)),
#  (276, ('overall survival', 0.0)),
#  (277, ('oxidative semiconductor', 0.0)),
#  (278, ('oxidative state', 0.0)),
#  (279, ('oxidative stress', 0.0)),
#  (280, ('production mannanoligosaccharides', 0.0)),
#  (281, ('promoted mannooligosaccharides', 0.0)),
#  (282, ('protein kinase', 0.0)),
#  (283, ('provided actigen', 0.0)),
#  (284, ('rich oligosaccharide', 0.0)),
#  (285, ('suggest mannanoligosaccharides', 0.0)),
#  (286, ('support survey', 0.0)),
#  (287, ('that mannanoligosaccharides', 0.0)),
#  (288, ('wall mannooligosaccharides', 0.0)),
#  (289, ('weight maltooligosaccharides', 0.0)),
#  (290, ('with mannoligosaccharide', 0.0)),
#  (291, ('with mannooligosaccharides', 0.0)),
#  (292, ('xos mannanoligosaccharides', 0.0)),
#  (293, ('yeast mannooligosaccharides', 0.0)),
#  (294, ('1 mannan oligosaccharide', 0.0)),
#  (295, ('2 mannan oligosaccharide', 0.0)),
#  (296, ('2011 and mannanoligosaccharides', 0.0)),
#  (297, ('7 dimethoxy flavone', 0.0)),
#  (298, ('a mannan oligosaccharide', 0.0)),
#  (299, ('adding mannan oligosaccharide', 0.0)),
#  (300, ('and manno oligosaccharide', 0.0)),
#  (301, ('antibiotic mannan oligosaccharide', 0.0)),
#  (302, ('as mannan oligosaccharide', 0.0)),
#  (303, ('autologous osteochondral mosaicplasty', 0.0)),
#  (304, ('based oligosaccharide mannooligosaccharides', 0.0)),
#  (305, ('bdnf mosapride citrate', 0.0)),
#  (306, ('cell wall mannooligosaccharides', 0.0)),
#  (307, ('coffee derived mannooligosaccharides', 0.0)),
#  (308, ('con and experimental', 0.0)),
#  (309, ('control and experimental', 0.0)),
#  (310, ('dietary additives mannanoligosaccharides', 0.0)),
#  (311, ('dysbiosis mannose oligosaccharide', 0.0)),
#  (312, ('effects of mannanoligosaccharides', 0.0)),
#  (313, ('effects of mannooligosaccharides', 0.0)),
#  (314, ('fermentation production mannanoligosaccharides', 0.0)),
#  (315, ('free manno oligosaccharide', 0.0)),
#  (316, ('generously provided actigen', 0.0)),
#  (317, ('glucan and mannanoligosaccharides', 0.0)),
#  (318, ('glucan mannan oligosaccharide', 0.0)),
#  (319, ('gos and mannan', 0.0)),
#  (320, ('gos and mannanoligoasacchardes', 0.0)),
#  (321, ('health promoted mannooligosaccharides', 0.0)),
#  (322, ('identified mosapride citrate', 0.0)),
#  (323, ('inclusion of mannanoligosaccharides', 0.0)),
#  (324, ('ingredient nucleotides mannanoligosaccharides', 0.0)),
#  (325, ('intensity continuous swimming', 0.0)),
#  (326, ('inulin oligofructose mannanoligosaccharides', 0.0)),
#  (327, ('mandibular occlusal splint', 0.0)),
#  (328, ('mannan oligo saccharide', 0.0)),
#  (329, ('mantis operating system', 0.0)),
#  (330, ('median overall survival', 0.0)),
#  (331, ('medical outcomes study', 0.0)),
#  (332, ('metrical oxidative state', 0.0)),
#  (333, ('mfx and mosaicplasty', 0.0)),
#  (334, ('mice with mannooligosaccharides', 0.0)),
#  (335, ('microvascular occlusal syndromes', 0.0)),
#  (336, ('minor oral surgery', 0.0)),
#  (337, ('molecular weight maltooligosaccharides', 0.0)),
#  (338, ('netherlands bio mos', 0.0)),
#  (339, ('of animals mannanoligosaccharides', 0.0)),
#  (340, ('of coffee mannooligosaccharides', 0.0)),
#  (341, ('of mosapride citrate', 0.0)),
#  (342, ('oligosaccharide mannan oligosaccharide', 0.0)),
#  (343, ('or mannan oligosaccharide', 0.0)),
#  (344, ('p37mos protein kinase', 0.0)),
#  (345, ('production of mannooligosaccharides', 0.0)),
#  (346, ('range of maltooligosaccharides', 0.0)),
#  (347, ('replication mannan oligosaccharide', 0.0)),
#  (348, ('short malto oligosaccharide', 0.0)),
#  (349, ('social support survey', 0.0)),
#  (350, ('study suggest mannanoligosaccharides', 0.0)),
#  (351, ('suggest that mannanoligosaccharides', 0.0)),
#  (352, ('supplementation and experimental', 0.0)),
#  (353, ('supplementation of mannanoligosaccharides', 0.0)),
#  (354, ('supplementation with mannoligosaccharide', 0.0)),
#  (355, ('that mannan oligosaccharide', 0.0)),
#  (356, ('that yeast mannooligosaccharides', 0.0)),
#  (357, ('the c mos', 0.0)),
#  (358, ('the mannan oligosaccharide', 0.0)),
#  (359, ('to form maltooligosaccharides', 0.0)),
#  (360, ('with mannan oligosaccharide', 0.0)),
#  (361, ('with metastatic osteosarcoma', 0.0)),
#  (362, ('without mannan oligosaccharide', 0.0)),
#  (363, ('xylooligosaccharides xos mannanoligosaccharides', 0.0)),
#  (364, ('1 dietary mannan oligosaccharide', 0.0)),
#  (365, ('2014 the mannan oligosaccharide', 0.0)),
#  (366, ('3 exposure corrected cytotoxicity', 0.0)),
#  (367, ('6 7 dimethoxy flavone', 0.0)),
#  (368, ('a mandibular occlusal splint', 0.0)),
#  (369, ('a maxillary occlusal splint', 0.0)),
#  (370, ('a metal oxidative semiconductor', 0.0)),
#  (371, ('a motor optimality score', 0.0)),
#  (372, ('activation by mosapride citrate', 0.0)),
#  (373, ('administration of dietary mannanoligosaccharides', 0.0)),
#  (374, ('al 2011 and mannanoligosaccharides', 0.0)),
#  (375, ('amersfoort netherlands bio mos', 0.0)),
#  (376, ('amounts of manno oligosaccharide', 0.0)),
#  (377, ('and 2 mannan oligosaccharide', 0.0)),
#  (378, ('and autologous osteochondral mosaicplasty', 0.0)),
#  (379, ('and fermentation production mannanoligosaccharides', 0.0)),
#  (380, ('and median overall survival', 0.0)),
#  (381, ('and mitochondrial oxidative stress', 0.0)),
#  (382, ('as antibiotic mannan oligosaccharide', 0.0)),
#  (383, ('assay identified mosapride citrate', 0.0)),
#  (384, ('assay margin of safety', 0.0)),
#  (385, ('based metal oxidative semiconductor', 0.0)),
#  (386, ('cerevisiae and mannan oligosaccharide', 0.0)),
#  (387, ('ch 1 mannan oligosaccharide', 0.0)),
#  (388, ('circles margin of safety', 0.0)),
#  (389, ('cleave short malto oligosaccharide', 0.0)),
#  (390, ('com margin of stability', 0.0)),
#  (391, ('common prebiotics mannan oligosaccharide', 0.0)),
#  (392, ('competence the c mos', 0.0)),
#  (393, ('consumption coffee derived mannooligosaccharides', 0.0)),
#  (394, ('consumption of coffee mannooligosaccharides', 0.0)),
#  (395, ('control con and experimental', 0.0)),
#  (396, ('control mice with mannooligosaccharides', 0.0)),
#  (397, ('control or mannan oligosaccharide', 0.0)),
#  (398, ('d glucan and mannanoligosaccharides', 0.0)),
#  (399, ('diet supplementation with mannoligosaccharide', 0.0)),
#  (400, ('dietary mannan oligo saccharide', 0.0)),
#  (401, ('digested to form maltooligosaccharides', 0.0)),
#  (402, ('effects of dietary mannanoligosaccharides', 0.0)),
#  (403, ('effects of manno oligosaccharide', 0.0)),
#  (404, ('effects of mosapride citrate', 0.0)),
#  (405, ('evidence that yeast mannooligosaccharides', 0.0)),
#  (406, ('factor bdnf mosapride citrate', 0.0)),
#  (407, ('fed dietary mannan oligosaccharide', 0.0)),
#  (408, ('feed ingredient nucleotides mannanoligosaccharides', 0.0)),
#  (409, ('for generously provided actigen', 0.0)),
#  (410, ('for mitochondrial oxidative stress', 0.0)),
#  (411, ('fos xylooligosaccharides xos mannanoligosaccharides', 0.0)),
#  (412, ('galacto gos and mannan', 0.0)),
#  (413, ('galactooligosaccharides gos and mannanoligoasacchardes', 0.0)),
#  (414, ('groups control and experimental', 0.0)),
#  (415, ('herein mitochondrial oxidative stress', 0.0)),
#  (416, ('hypothesis that mannan oligosaccharide', 0.0)),
#  (417, ('in minor oral surgery', 0.0)),
#  (418, ('in mitochondrial oxidative stress', 0.0)),
#  (419, ('in production of mannooligosaccharides', 0.0)),
#  (420, ('induced mitochondrial oxidative stress', 0.0)),
#  (421, ('influenza replication mannan oligosaccharide', 0.0)),
#  (422, ('introduced metrical oxidative state', 0.0)),
#  (423, ('low molecular weight maltooligosaccharides', 0.0)),
#  (424, ('mannose based oligosaccharide mannooligosaccharides', 0.0)),
#  (425, ('mannose free manno oligosaccharide', 0.0)),
#  (426, ('microbiome dysbiosis mannose oligosaccharide', 0.0)),
#  (427, ('microfracture mfx and mosaicplasty', 0.0)),
#  (428, ('ml margin of stability', 0.0)),
#  (429, ('moderate intensity continuous swimming', 0.0)),
#  (430, ('mos mitochondrial oxidative stress', 0.0)),
#  (431, ('murine main olfactory system', 0.0)),
#  (432, ('no supplementation and experimental', 0.0)),
#  (433, ('novel oligosaccharide mannan oligosaccharide', 0.0)),
#  (434, ('of a mannan oligosaccharide', 0.0)),
#  (435, ('of adding mannan oligosaccharide', 0.0)),
#  (436, ('of inulin oligofructose mannanoligosaccharides', 0.0)),
#  (437, ('of mitochondrial oxidative stress', 0.0)),
#  (438, ('or without mannan oligosaccharide', 0.0)),
#  (439, ('patients with metastatic osteosarcoma', 0.0)),
#  (440, ('potential health promoted mannooligosaccharides', 0.0)),
#  (441, ('pro and mannan oligosaccharide', 0.0)),
#  (442, ('r agonist mosapride citrate', 0.0)),
#  (443, ('recent study suggest mannanoligosaccharides', 0.0)),
#  (444, ('receptor by mosapride citrate', 0.0)),
#  (445, ('recommendations and manno oligosaccharide', 0.0)),
#  (446, ('resulting suggest that mannanoligosaccharides', 0.0)),
#  (447, ('s motor optimality score', 0.0)),
#  (448, ('single maxillary occlusal splint', 0.0)),
#  (449, ('strains mannose rich oligosaccharide', 0.0)),
#  (450, ('stress mitochondrial oxidative stress', 0.0)),
#  (451, ('study social support survey', 0.0)),
#  (452, ('supplementation with mannan oligosaccharide', 0.0)),
#  (453, ('that mannose rich oligosaccharide', 0.0)),
#  (454, ('the effects of mannanoligosaccharides', 0.0)),
#  (455, ('the effects of mannooligosaccharides', 0.0)),
#  (456, ('the inclusion of mannanoligosaccharides', 0.0)),
#  (457, ('the mantis operating system', 0.0)),
#  (458, ('the medical outcomes study', 0.0)),
#  (459, ('the motor optimality score', 0.0)),
#  (460, ('the p37mos protein kinase', 0.0)),
#  (461, ('the prebiotics mannan oligosaccharide', 0.0)),
#  (462, ('their motor optimality score', 0.0)),
#  (463, ('two dietary additives mannanoligosaccharides', 0.0)),
#  (464, ('used of mannan oligosaccharide', 0.0)),
#  (465, ('value exposure corrected cytotoxicity', 0.0)),
#  (466, ('wellbeing of animals mannanoligosaccharides', 0.0)),
#  (467, ('wide range of maltooligosaccharides', 0.0)),
#  (468, ('β glucan mannan oligosaccharide', 0.0)),
#  (469, ('1 in mitochondrial oxidative stress', 0.0)),
#  (470, ('1979 dynamic margin of stability', 0.0)),
#  (471, ('1994 recommendations and manno oligosaccharide', 0.0)),
#  (472, ('2 yeast cell wall mannooligosaccharides', 0.0)),
#  (473, ('3724 mannose free manno oligosaccharide', 0.0)),
#  (474, ('4 r agonist mosapride citrate', 0.0)),
#  (475, ('4 receptor agonist mosapride citrate', 0.0)),
#  (476, ('4 receptor by mosapride citrate', 0.0)),
#  (477, ('a dietary supplementation of mannanoligosaccharides', 0.0)),
#  (478, ('a novel oligosaccharide mannan oligosaccharide', 0.0)),
#  (479, ('a single maxillary occlusal splint', 0.0)),
#  (480, ('a wide range of maltooligosaccharides', 0.0)),
#  (481, ('a yeast cell wall mannooligosaccharides', 0.0)),
#  (482, ('absence of a mannan oligosaccharide', 0.0)),
#  (483, ('additives such as mannan oligosaccharide', 0.0)),
#  (484, ('al 2014 the mannan oligosaccharide', 0.0)),
#  (485, ('an assay margin of safety', 0.0)),
#  (486, ('and a maxillary occlusal splint', 0.0)),
#  (487, ('and effects of mosapride citrate', 0.0)),
#  (488, ('and ml margin of stability', 0.0)),
#  (489, ('and two dietary additives mannanoligosaccharides', 0.0)),
#  (490, ('and wellbeing of animals mannanoligosaccharides', 0.0)),
#  (491, ('as in production of mannooligosaccharides', 0.0)),
#  (492, ('as the margin of stability', 0.0)),
#  (493, ('by supplementation of mannan oligosaccharide', 0.0)),
#  (494, ('by the p37mos protein kinase', 0.0)),
#  (495, ('calculate a motor optimality score', 0.0)),
#  (496, ('cell to mitochondrial oxidative stress', 0.0)),
#  (497, ('chicory ch 1 mannan oligosaccharide', 0.0)),
#  (498, ('components and fermentation production mannanoligosaccharides', 0.0)),
#  (499, ('designated as antibiotic mannan oligosaccharide', 0.0)),
#  (500, ('developmental competence the c mos', 0.0)),
#  (501, ('dietary supplementation of mannan oligosaccharide', 0.0)),
#  (502, ('dietary supplementation with mannan oligosaccharide', 0.0)),
#  (503, ('dietary β glucan mannan oligosaccharide', 0.0)),
#  (504, ('different levels of mannan oligosaccharide', 0.0)),
#  (505, ('domo amersfoort netherlands bio mos', 0.0)),
#  (506, ('dysfunction and mitochondrial oxidative stress', 0.0)),
#  (507, ('effects of adding mannan oligosaccharide', 0.0)),
#  (508, ('effects of dietary mannan oligosaccharide', 0.0)),
#  (509, ('effects of inulin oligofructose mannanoligosaccharides', 0.0)),
#  (510, ('enhanced recent study suggest mannanoligosaccharides', 0.0)),
#  (511, ('enzymes cleave short malto oligosaccharide', 0.0)),
#  (512, ('enzymatically digested to form maltooligosaccharides', 0.0)),
#  (513, ('et al 2011 and mannanoligosaccharides', 0.0)),
#  (514, ('exist that mannose rich oligosaccharide', 0.0)),
#  (515, ('fig 3 exposure corrected cytotoxicity', 0.0)),
#  (516, ('filled circles margin of safety', 0.0)),
#  (517, ('fingerlings fed dietary mannan oligosaccharide', 0.0)),
#  (518, ('following microfracture mfx and mosaicplasty', 0.0)),
#  (519, ('fos galacto gos and mannan', 0.0)),
#  (520, ('fos galactooligosaccharides gos and mannanoligoasacchardes', 0.0)),
#  (521, ('from control or mannan oligosaccharide', 0.0)),
#  (522,
#   ('fructooligosaccharides fos xylooligosaccharides xos mannanoligosaccharides',
#    0.0)),
#  (523, ('functional feed ingredient nucleotides mannanoligosaccharides', 0.0)),
#  (524, ('groups control con and experimental', 0.0)),
#  (525, ('gut microbiome dysbiosis mannose oligosaccharide', 0.0)),
#  (526, ('high levels of mannan oligosaccharide', 0.0)),
#  (527, ('how com margin of stability', 0.0)),
#  (528, ('ht4 receptor agonist mosapride citrate', 0.0)),
#  (529, ('hydroxy 6 7 dimethoxy flavone', 0.0)),
#  (530, ('implicated the main olfactory system', 0.0)),
#  (531, ('including their motor optimality score', 0.0)),
#  (532, ('increase in minor oral surgery', 0.0)),
#  (533, ('induction of mitochondrial oxidative stress', 0.0)),
#  (534, ('infant s motor optimality score', 0.0)),
#  (535, ('investigated the effects of mannanoligosaccharides', 0.0)),
#  (536, ('levels of dietary mannan oligosaccharide', 0.0)),
#  (537, ('likewise administration of dietary mannanoligosaccharides', 0.0)),
#  (538, ('linked to mitochondrial oxidative stress', 0.0)),
#  (539, ('luciferase assay identified mosapride citrate', 0.0)),
#  (540, ('max value exposure corrected cytotoxicity', 0.0)),
#  (541, ('mfx and autologous osteochondral mosaicplasty', 0.0)),
#  (542, ('moreover the metal oxidative semiconductor', 0.0)),
#  (543, ('mos consumption coffee derived mannooligosaccharides', 0.0)),
#  (544, ('mos the margin of stability', 0.0)),
#  (545, ('most common prebiotics mannan oligosaccharide', 0.0)),
#  (546, ('netherlands for generously provided actigen', 0.0)),
#  (547, ('neurotrophic factor bdnf mosapride citrate', 0.0)),
#  (548, ('nsaid induced mitochondrial oxidative stress', 0.0)),
#  (549, ('of control mice with mannooligosaccharides', 0.0)),
#  (550, ('of dietary mannan oligo saccharide', 0.0)),
#  (551, ('of dietary supplementation of mannanoligosaccharides', 0.0)),
#  (552, ('of patients with metastatic osteosarcoma', 0.0)),
#  (553, ('of potential health promoted mannooligosaccharides', 0.0)),
#  (554, ('of supplementation of mannan oligosaccharide', 0.0)),
#  (555, ('of yeast cell wall mannooligosaccharides', 0.0)),
#  (556, ('or low molecular weight maltooligosaccharides', 0.0)),
#  (557, ('outcomes and median overall survival', 0.0)),
#  (558, ('outcomes study social support survey', 0.0)),
#  (559, ('oxidative stress mitochondrial oxidative stress', 0.0)),
#  (560, ('positive mediolateral margin of stability', 0.0)),
#  (561, ('prebiotics such as mannan oligosaccharide', 0.0)),
#  (562, ('prebiotics yeast cell wall mannooligosaccharides', 0.0)),
#  (563, ('present resulting suggest that mannanoligosaccharides', 0.0)),
#  (564, ('probiotic pro and mannan oligosaccharide', 0.0)),
#  (565, ('promoted influenza replication mannan oligosaccharide', 0.0)),
#  (566, ('protective effects of mannan oligosaccharide', 0.0)),
#  (567, ('provided evidence that yeast mannooligosaccharides', 0.0)),
#  (568, ('quantified mediolateral margin of stability', 0.0)),
#  (569, ('recent introduced metrical oxidative state', 0.0)),
#  (570, ('receptor activation by mosapride citrate', 0.0)),
#  (571, ('resistant strains mannose rich oligosaccharide', 0.0)),
#  (572, ('resulting a metal oxidative semiconductor', 0.0)),
#  (573, ('role for mitochondrial oxidative stress', 0.0)),
#  (574, ('s dynamic margin of stability', 0.0)),
#  (575, ('saccharomyces cerevisiae and mannan oligosaccharide', 0.0)),
#  (576, ('si based metal oxidative semiconductor', 0.0)),
#  (577, ('significant amounts of manno oligosaccharide', 0.0)),
#  (578, ('soc moderate intensity continuous swimming', 0.0)),
#  (579, ('specific mannose based oligosaccharide mannooligosaccharides', 0.0)),
#  (580, ('stack the mantis operating system', 0.0)),
#  (581, ('study the effects of mannooligosaccharides', 0.0)),
#  (582, ('suppresses mos mitochondrial oxidative stress', 0.0)),
#  (583, ('test diet supplementation with mannoligosaccharide', 0.0)),
#  (584, ('test herein mitochondrial oxidative stress', 0.0)),
#  (585, ('that the inclusion of mannanoligosaccharides', 0.0)),
#  (586, ('the consumption of coffee mannooligosaccharides', 0.0)),
#  (587, ('the dynamic margin of stability', 0.0)),
#  (588, ('the effects of dietary mannanoligosaccharides', 0.0)),
#  (589, ('the effects of manno oligosaccharide', 0.0)),
#  (590, ('the hypothesis that mannan oligosaccharide', 0.0)),
#  (591, ('the used of mannan oligosaccharide', 0.0)),
#  (592, ('this the main olfactory system', 0.0)),
#  (593, ('to a mandibular occlusal splint', 0.0)),
#  (594, ('two groups control and experimental', 0.0)),
#  (595, ('types and 2 mannan oligosaccharide', 0.0)),
#  (596, ('used the motor optimality score', 0.0)),
#  (597, ('walking the margin of stability', 0.0)),
#  (598, ('with no supplementation and experimental', 0.0)),
#  (599, ('with or without mannan oligosaccharide', 0.0)),
#  (600, ('with the prebiotics mannan oligosaccharide', 0.0)),
#  (601, ('β d glucan and mannanoligosaccharides', 0.0)),
#  (602, ('− 1 dietary mannan oligosaccharide', 0.0)),
#  (603, ('1 chicory ch 1 mannan oligosaccharide', 0.0)),
#  (604, ('2 si based metal oxidative semiconductor', 0.0)),
#  (605, ('2 suppresses mos mitochondrial oxidative stress', 0.0)),
#  (606, ('4 receptor activation by mosapride citrate', 0.0)),
#  (607, ('5 ht4 receptor agonist mosapride citrate', 0.0)),
#  (608, ('5 hydroxy 6 7 dimethoxy flavone', 0.0)),
#  (609, ('6 increase in minor oral surgery', 0.0)),
#  (610, ('6 β d glucan and mannanoligosaccharides', 0.0)),
#  (611,
#   ('advancement specific mannose based oligosaccharide mannooligosaccharides',
#    0.0)),
#  (612, ('afb1 promoted influenza replication mannan oligosaccharide', 0.0)),
#  (613, ('and a single maxillary occlusal splint', 0.0)),
#  (614, ('and oxidative stress mitochondrial oxidative stress', 0.0)),
#  (615, ('and prebiotics such as mannan oligosaccharide', 0.0)),
#  (616, ('and to a mandibular occlusal splint', 0.0)),
#  (617, ('antibiotic resistant strains mannose rich oligosaccharide', 0.0)),
#  (618, ('ap and ml margin of stability', 0.0)),
#  (619, ('are enzymatically digested to form maltooligosaccharides', 0.0)),
#  (620, ('as an assay margin of safety', 0.0)),
#  (621,
#   ('as fructooligosaccharides fos xylooligosaccharides xos mannanoligosaccharides',
#    0.0)),
#  (622, ('bacitracin and two dietary additives mannanoligosaccharides', 0.0)),
#  (623, ('bacitracin designated as antibiotic mannan oligosaccharide', 0.0)),
#  (624, ('banned the effects of mannan oligosaccharide', 0.0)),
#  (625, ('benefits of supplementation of mannan oligosaccharide', 0.0)),
#  (626, ('between the effects of manno oligosaccharide', 0.0)),
#  (627, ('buspirone filled circles margin of safety', 0.0)),
#  (628, ('by dietary supplementation of mannan oligosaccharide', 0.0)),
#  (629, ('by used the motor optimality score', 0.0)),
#  (630, ('c fig 3 exposure corrected cytotoxicity', 0.0)),
#  (631, ('c max value exposure corrected cytotoxicity', 0.0)),
#  (632, ('campina domo amersfoort netherlands bio mos', 0.0)),
#  (633, ('carp fingerlings fed dietary mannan oligosaccharide', 0.0)),
#  (634, ('cell from control or mannan oligosaccharide', 0.0)),
#  (635, ('central role for mitochondrial oxidative stress', 0.0)),
#  (636,
#   ('composition enhanced recent study suggest mannanoligosaccharides', 0.0)),
#  (637, ('con with no supplementation and experimental', 0.0)),
#  (638, ('contains high levels of mannan oligosaccharide', 0.0)),
#  (639, ('control 2 yeast cell wall mannooligosaccharides', 0.0)),
#  (640, ('decade the used of mannan oligosaccharide', 0.0)),
#  (641, ('derived neurotrophic factor bdnf mosapride citrate', 0.0)),
#  (642, ('determine how com margin of stability', 0.0)),
#  (643, ('determine the effects of mannan oligosaccharide', 0.0)),
#  (644, ('different levels of dietary mannan oligosaccharide', 0.0)),
#  (645, ('disproportionating enzymes cleave short malto oligosaccharide', 0.0)),
#  (646, ('drug nsaid induced mitochondrial oxidative stress', 0.0)),
#  (647, ('effects of dietary supplementation of mannanoligosaccharides', 0.0)),
#  (648, ('effects of yeast cell wall mannooligosaccharides', 0.0)),
#  (649, ('embryonic developmental competence the c mos', 0.0)),
#  (650, ('equal groups control con and experimental', 0.0)),
#  (651, ('et al 2014 the mannan oligosaccharide', 0.0)),
#  (652, ('evaluate the effects of dietary mannanoligosaccharides', 0.0)),
#  (653, ('evidence exist that mannose rich oligosaccharide', 0.0)),
#  (654, ('exclusively by the main olfactory system', 0.0)),
#  (655, ('explore the effects of mannan oligosaccharide', 0.0)),
#  (656, ('explore the hypothesis that mannan oligosaccharide', 0.0)),
#  (657, ('feed additives such as mannan oligosaccharide', 0.0)),
#  (658, ('ff resulting a metal oxidative semiconductor', 0.0)),
#  (659, ('fructo fos galacto gos and mannan', 0.0)),
#  (660,
#   ('fructooligosaccharides fos galactooligosaccharides gos and mannanoligoasacchardes',
#    0.0)),
#  (661, ('fsbm with or without mannan oligosaccharide', 0.0)),
#  (662, ('had a dietary supplementation of mannanoligosaccharides', 0.0)),
#  (663, ('has implicated the main olfactory system', 0.0)),
#  (664, ('have provided evidence that yeast mannooligosaccharides', 0.0)),
#  (665, ('health and wellbeing of animals mannanoligosaccharides', 0.0)),
#  (666, ('heelstrike the dynamic margin of stability', 0.0)),
#  (667, ('ho 1 in mitochondrial oxidative stress', 0.0)),
#  (668, ('ht 4 r agonist mosapride citrate', 0.0)),
#  (669, ('ht 4 receptor agonist mosapride citrate', 0.0)),
#  (670, ('ht 4 receptor by mosapride citrate', 0.0)),
#  (671, ('in positive mediolateral margin of stability', 0.0)),
#  (672, ('including dietary supplementation with mannan oligosaccharide', 0.0)),
#  (673, ('individual s dynamic margin of stability', 0.0)),
#  (674,
#   ('ingredient components and fermentation production mannanoligosaccharides',
#    0.0)),
#  (675, ('investigated protective effects of mannan oligosaccharide', 0.0)),
#  (676, ('investigated the effects of mannan oligosaccharide', 0.0)),
#  (677, ('is linked to mitochondrial oxidative stress', 0.0)),
#  (678, ('is test herein mitochondrial oxidative stress', 0.0)),
#  (679, ('kanakupt et al 2011 and mannanoligosaccharides', 0.0)),
#  (680, ('kg − 1 dietary mannan oligosaccharide', 0.0)),
#  (681, ('kodde 1979 dynamic margin of stability', 0.0)),
#  (682, ('levels of dietary mannan oligo saccharide', 0.0)),
#  (683, ('like walking the margin of stability', 0.0)),
#  (684, ('mad and a maxillary occlusal splint', 0.0)),
#  (685, ('medical outcomes study social support survey', 0.0)),
#  (686, ('microfracture mfx and autologous osteochondral mosaicplasty', 0.0)),
#  (687, ('mitochondrial dysfunction and mitochondrial oxidative stress', 0.0)),
#  (688, ('modulated by supplementation of mannan oligosaccharide', 0.0)),
#  (689, ('mucin types and 2 mannan oligosaccharide', 0.0)),
#  (690, ('muscles and effects of mosapride citrate', 0.0)),
#  (691, ('network stack the mantis operating system', 0.0)),
#  (692, ('nfcci 3724 mannose free manno oligosaccharide', 0.0)),
#  (693, ('nrc 1994 recommendations and manno oligosaccharide', 0.0)),
#  (694, ('of a yeast cell wall mannooligosaccharides', 0.0)),
#  (695, ('of dietary β glucan mannan oligosaccharide', 0.0)),
#  (696, ('of different levels of mannan oligosaccharide', 0.0)),
#  (697, ('of mos the margin of stability', 0.0)),
#  (698, ('oligomannan prebiotics yeast cell wall mannooligosaccharides', 0.0)),
#  (699, ('or absence of a mannan oligosaccharide', 0.0)),
#  (700, ('part of the medical outcomes study', 0.0)),
#  (701, ('polymer or low molecular weight maltooligosaccharides', 0.0)),
#  (702, ('primarily by the main olfactory system', 0.0)),
#  (703, ('production of potential health promoted mannooligosaccharides', 0.0)),
#  (704,
#   ('rate likewise administration of dietary mannanoligosaccharides', 0.0)),
#  (705, ('regeneration following microfracture mfx and mosaicplasty', 0.0)),
#  (706, ('repertoire including their motor optimality score', 0.0)),
#  (707, ('reported a novel oligosaccharide mannan oligosaccharide', 0.0)),
#  (708, ('respectively probiotic pro and mannan oligosaccharide', 0.0)),
# ...
#  (794, ('council nrc 1994 recommendations and manno oligosaccharide', 0.0)),
#  (795, ('cultures and prebiotics such as mannan oligosaccharide', 0.0)),
#  (796,
#   ('dairy ingredient components and fermentation production mannanoligosaccharides',
#    0.0)),
#  (797,
#   ('death mitochondrial dysfunction and mitochondrial oxidative stress', 0.0)),
#  (798, ('deo respectively probiotic pro and mannan oligosaccharide', 0.0)),
#  (799, ('desirable evidence exist that mannose rich oligosaccharide', 0.0)),
#  (800, ('determine the infant s motor optimality score', 0.0)),
#  (801, ('deviations of mos the margin of stability', 0.0)),
#  (802, ('different levels of dietary mannan oligo saccharide', 0.0)),
#  (803,
#   ('dysfunction and oxidative stress mitochondrial oxidative stress', 0.0)),
#  (804, ('effects of a yeast cell wall mannooligosaccharides', 0.0)),
#  (805, ('effects of dietary β glucan mannan oligosaccharide', 0.0)),
#  (806,
#   ('enhanced health and wellbeing of animals mannanoligosaccharides', 0.0)),
#  (807, ('events is linked to mitochondrial oxidative stress', 0.0)),
#  (808, ('evidence showed that the inclusion of mannanoligosaccharides', 0.0)),
#  (809,
#   ('examine the effects of inulin oligofructose mannanoligosaccharides', 0.0)),
#  (810, ('excretion the effects of dietary mannan oligosaccharide', 0.0)),
#  (811, ('fed different levels of dietary mannan oligosaccharide', 0.0)),
#  (812, ('flavonoids 5 hydroxy 6 7 dimethoxy flavone', 0.0)),
#  (813, ('friesland campina domo amersfoort netherlands bio mos', 0.0)),
#  (814, ('functional scale of the medical outcomes study', 0.0)),
#  (815, ('g kg − 1 dietary mannan oligosaccharide', 0.0)),
#  (816,
#   ('galactooligosaccharides kanakupt et al 2011 and mannanoligosaccharides',
#    0.0)),
#  (817, ('gene is test herein mitochondrial oxidative stress', 0.0)),
#  (818,
#   ('glycomics advancement specific mannose based oligosaccharide mannooligosaccharides',
#    0.0)),
#  (819,
#   ('groups had a dietary supplementation of mannanoligosaccharides', 0.0)),
#  (820, ('high ff resulting a metal oxidative semiconductor', 0.0)),
#  (821, ('ht 4 receptor activation by mosapride citrate', 0.0)),
#  (822, ('improve embryonic developmental competence the c mos', 0.0)),
#  (823, ('in this study the effects of mannooligosaccharides', 0.0)),
#  (824,
#   ('including microfracture mfx and autologous osteochondral mosaicplasty',
#    0.0)),
#  (825, ('including the induction of mitochondrial oxidative stress', 0.0)),
#  (826,
#   ('inflammatory drug nsaid induced mitochondrial oxidative stress', 0.0)),
#  (827, ('interaction between the effects of manno oligosaccharide', 0.0)),
#  (828, ('investigated the effects of adding mannan oligosaccharide', 0.0)),
#  (829, ('investigated the effects of dietary mannan oligosaccharide', 0.0)),
#  (830, ('last decade the used of mannan oligosaccharide', 0.0)),
#  (831, ('like polymer or low molecular weight maltooligosaccharides', 0.0)),
#  (832,
#   ('live yeast saccharomyces cerevisiae and mannan oligosaccharide', 0.0)),
#  (833, ('mad and a single maxillary occlusal splint', 0.0)),
#  (834, ('manuscript as an assay margin of safety', 0.0)),
#  (835, ('meal fsbm with or without mannan oligosaccharide', 0.0)),
#  (836,
#   ('modulated by dietary supplementation of mannan oligosaccharide', 0.0)),
#  (837, ('motor repertoire including their motor optimality score', 0.0)),
#  (838,
#   ('multiple antibiotic resistant strains mannose rich oligosaccharide', 0.0)),
#  (839, ('natural feed additives such as mannan oligosaccharide', 0.0)),
#  (840, ('occurs exclusively by the main olfactory system', 0.0)),
#  (841, ('of softwood significant amounts of manno oligosaccharide', 0.0)),
#  (842, ('on ser459 by the p37mos protein kinase', 0.0)),
#  (843, ('on surgical outcomes and median overall survival', 0.0)),
#  (844, ('os treatment of control mice with mannooligosaccharides', 0.0)),
#  (845, ('pkc contains high levels of mannan oligosaccharide', 0.0)),
#  (846, ('prebiotics fructo fos galacto gos and mannan', 0.0)),
#  (847, ('presence or absence of a mannan oligosaccharide', 0.0)),
#  (848, ('present study the effects of mannan oligosaccharide', 0.0)),
#  (849, ('processed primarily by the main olfactory system', 0.0)),
#  (850, ('protective effects of yeast cell wall mannooligosaccharides', 0.0)),
#  (851, ('recorded we calculate a motor optimality score', 0.0)),
#  (852, ('referred to as the margin of stability', 0.0)),
#  (853, ('research has implicated the main olfactory system', 0.0)),
#  (854,
#   ('response to mos consumption coffee derived mannooligosaccharides', 0.0)),
#  (855, ('resulting in positive mediolateral margin of stability', 0.0)),
#  (856, ('shown that the consumption of coffee mannooligosaccharides', 0.0)),
#  (857, ('smooth muscles and effects of mosapride citrate', 0.0)),
#  (858, ('stanley et al 2014 the mannan oligosaccharide', 0.0)),
#  (859,
#   ('structures disproportionating enzymes cleave short malto oligosaccharide',
#    0.0)),
#  (860, ('study determine how com margin of stability', 0.0)),
#  (861, ('study explore the hypothesis that mannan oligosaccharide', 0.0)),
#  (862,
#   ('study investigated protective effects of mannan oligosaccharide', 0.0)),
#  (863, ('study investigated the effects of mannan oligosaccharide', 0.0)),
#  (864,
#   ('such as fructooligosaccharides fos xylooligosaccharides xos mannanoligosaccharides',
#    0.0)),
#  (865, ('support medical outcomes study social support survey', 0.0)),
#  (866,
#   ('survival rate likewise administration of dietary mannanoligosaccharides',
#    0.0)),
#  (867, ('survival s of patients with metastatic osteosarcoma', 0.0)),
#  (868, ('tasks like walking the margin of stability', 0.0)),
#  (869, ('the benefits of supplementation of mannan oligosaccharide', 0.0)),
#  (870,
#   ('the effects of dietary supplementation of mannanoligosaccharides', 0.0)),
#  (871,
#   ('the production of potential health promoted mannooligosaccharides', 0.0)),
#  (872, ('this study quantified mediolateral margin of stability', 0.0)),
#  (873, ('to determine the effects of mannan oligosaccharide', 0.0)),
#  (874, ('to evaluate the effects of dietary mannanoligosaccharides', 0.0)),
#  (875, ('to explore the effects of mannan oligosaccharide', 0.0)),
#  (876, ('to sensitize cell to mitochondrial oxidative stress', 0.0)),
#  (877, ('treatment 1 chicory ch 1 mannan oligosaccharide', 0.0)),
#  (878, ('two equal groups control con and experimental', 0.0)),
#  (879, ('used to investigated the effects of mannanoligosaccharides', 0.0)),
#  (880, ('we have provided evidence that yeast mannooligosaccharides', 0.0)),
#  (881, ('we reported a novel oligosaccharide mannan oligosaccharide', 0.0)),
#  (882,
#   ('with fructooligosaccharides fos galactooligosaccharides gos and mannanoligoasacchardes',
#    0.0)),
#  (883,
#   ('zn bacitracin and two dietary additives mannanoligosaccharides', 0.0)),
#  (884, ('zn bacitracin designated as antibiotic mannan oligosaccharide', 0.0)),
#  (885, ('2008 stanley et al 2014 the mannan oligosaccharide', 0.0)),
#  (886,
#   ('2013 galactooligosaccharides kanakupt et al 2011 and mannanoligosaccharides',
#    0.0)),
#  (887, ('2016 as well as in production of mannooligosaccharides', 0.0)),
#  (888, ('3 1 6 β d glucan and mannanoligosaccharides', 0.0)),
#  (889, ('3 b c fig 3 exposure corrected cytotoxicity', 0.0)),
#  (890, ('4 5 ht 4 receptor agonist mosapride citrate', 0.0)),
#  (891, ('4 g kg − 1 dietary mannan oligosaccharide', 0.0)),
#  (892, ('5 ht 4 receptor activation by mosapride citrate', 0.0)),
#  (893, ('a 5 ht 4 receptor agonist mosapride citrate', 0.0)),
#  (894,
#   ('acknowledge alltech the netherlands for generously provided actigen',
#    0.0)),
#  (895,
#   ('aflatoxin b1 afb1 promoted influenza replication mannan oligosaccharide',
#    0.0)),
#  (896, ('and deo respectively probiotic pro and mannan oligosaccharide', 0.0)),
#  (897,
#   ('anti inflammatory drug nsaid induced mitochondrial oxidative stress',
#    0.0)),
#  (898,
#   ('as modulated by dietary supplementation of mannan oligosaccharide', 0.0)),
#  (899, ('assay and the luciferase assay identified mosapride citrate', 0.0)),
#  (900,
#   ('bacitracin and two test diet supplementation with mannoligosaccharide',
#    0.0)),
#  (901, ('be assess by used the motor optimality score', 0.0)),
#  (902, ('biomass as well as in production of mannooligosaccharides', 0.0)),
#  (903, ('by friesland campina domo amersfoort netherlands bio mos', 0.0)),
#  (904,
#   ('by the production of potential health promoted mannooligosaccharides',
#    0.0)),
#  (905, ('calculate an individual s dynamic margin of stability', 0.0)),
#  (906, ('carp among the most common prebiotics mannan oligosaccharide', 0.0)),
#  (907, ('carp fed different levels of dietary mannan oligosaccharide', 0.0)),
#  (908,
#   ('cell death mitochondrial dysfunction and mitochondrial oxidative stress',
#    0.0)),
#  (909, ('circular smooth muscles and effects of mosapride citrate', 0.0)),
#  (910, ('com at heelstrike the dynamic margin of stability', 0.0)),
#  (911, ('conducted to determine the effects of mannan oligosaccharide', 0.0)),
#  (912,
#   ('conducted to evaluate the effects of dietary mannanoligosaccharides',
#    0.0)),
#  (913,
#   ('considerable evidence showed that the inclusion of mannanoligosaccharides',
#    0.0)),
#  (914, ('control con soccer soc moderate intensity continuous swimming', 0.0)),
#  (915,
#   ('control zn bacitracin and two dietary additives mannanoligosaccharides',
#    0.0)),
#  (916,
#   ('control zn bacitracin designated as antibiotic mannan oligosaccharide',
#    0.0)),
#  (917,
#   ('crystalline structures disproportionating enzymes cleave short malto oligosaccharide',
#    0.0)),
#  (918, ('developed as part of the medical outcomes study', 0.0)),
#  (919, ('device mad and a single maxillary occlusal splint', 0.0)),
#  (920, ('dynamic tasks like walking the margin of stability', 0.0)),
#  (921, ('early motor repertoire including their motor optimality score', 0.0)),
#  (922,
#   ('evaluate cartilage regeneration following microfracture mfx and mosaicplasty',
#    0.0)),
#  (923,
#   ('evaluate the benefits of supplementation of mannan oligosaccharide', 0.0)),
#  (924,
#   ('exist including microfracture mfx and autologous osteochondral mosaicplasty',
#    0.0)),
#  (925,
#   ('experimental groups had a dietary supplementation of mannanoligosaccharides',
#    0.0)),
#  (926, ('expression and mucin types and 2 mannan oligosaccharide', 0.0)),
#  (927, ('falls this study quantified mediolateral margin of stability', 0.0)),
#  (928, ('fed different levels of dietary mannan oligo saccharide', 0.0)),
#  (929, ('fluid balf cell from control or mannan oligosaccharide', 0.0)),
#  (930, ('form 1 control 2 yeast cell wall mannooligosaccharides', 0.0)),
#  (931,
#   ('glycogen like polymer or low molecular weight maltooligosaccharides',
#    0.0)),
#  (932, ('groups control con with no supplementation and experimental', 0.0)),
#  (933, ('have been banned the effects of mannan oligosaccharide', 0.0)),
#  (934,
#   ('have shown that the consumption of coffee mannooligosaccharides', 0.0)),
#  (935,
#   ('here we have provided evidence that yeast mannooligosaccharides', 0.0)),
#  (936,
#   ('here we reported a novel oligosaccharide mannan oligosaccharide', 0.0)),
#  (937,
#   ('high desirable evidence exist that mannose rich oligosaccharide', 0.0)),
#  (938,
#   ('highlight protective effects of yeast cell wall mannooligosaccharides',
#    0.0)),
#  (939, ('hs as modulated by supplementation of mannan oligosaccharide', 0.0)),
#  (940,
#   ('hydrolysis of softwood significant amounts of manno oligosaccharide',
#    0.0)),
#  (941, ('ic 50 c max value exposure corrected cytotoxicity', 0.0)),
#  (942, ('in birds treated with the prebiotics mannan oligosaccharide', 0.0)),
#  (943,
#   ('in enhanced health and wellbeing of animals mannanoligosaccharides', 0.0)),
#  (944, ('in presence or absence of a mannan oligosaccharide', 0.0)),
#  (945,
#   ('in response to mos consumption coffee derived mannooligosaccharides',
#    0.0)),
#  (946,
#   ('incorporate natural feed additives such as mannan oligosaccharide', 0.0)),
#  (947,
#   ('increase survival rate likewise administration of dietary mannanoligosaccharides',
#    0.0)),
#  (948, ('indicates a central role for mitochondrial oxidative stress', 0.0)),
#  (949, ('into two equal groups control con and experimental', 0.0)),
#  (950,
#   ('investigated the effects of dietary supplementation of mannanoligosaccharides',
#    0.0)),
#  (951,
#   ('is associated with gut microbiome dysbiosis mannose oligosaccharide',
#    0.0)),
#  (952,
#   ('low cost technology moreover the metal oxidative semiconductor', 0.0)),
#  (953,
#   ('lps and three functional feed ingredient nucleotides mannanoligosaccharides',
#    0.0)),
#  (954, ('m cinnamomea nfcci 3724 mannose free manno oligosaccharide', 0.0)),
#  (955, ('mass calibration used a wide range of maltooligosaccharides', 0.0)),
#  (956, ('massen and kodde 1979 dynamic margin of stability', 0.0)),
#  (957, ('measure referred to as the margin of stability', 0.0)),
#  (958,
#   ('mitochondrial dysfunction and oxidative stress mitochondrial oxidative stress',
#    0.0)),
#  (959, ('mos in this study the effects of mannooligosaccharides', 0.0)),
#  (960, ('nefazodone and buspirone filled circles margin of safety', 0.0)),
#  (961, ('neural 5 ht 4 receptor by mosapride citrate', 0.0)),
#  (962,
#   ('neurons including the induction of mitochondrial oxidative stress', 0.0)),
#  (963, ('no interaction between the effects of manno oligosaccharide', 0.0)),
#  (964, ('odors occurs exclusively by the main olfactory system', 0.0)),
#  (965, ('of a mad and a maxillary occlusal splint', 0.0)),
#  (966,
#   ('of an oligomannan prebiotics yeast cell wall mannooligosaccharides', 0.0)),
#  (967, ('of brain derived neurotrophic factor bdnf mosapride citrate', 0.0)),
#  (968, ('of common carp fingerlings fed dietary mannan oligosaccharide', 0.0)),
#  (969,
#   ('of multiple antibiotic resistant strains mannose rich oligosaccharide',
#    0.0)),
#  (970, ('of prebiotics fructo fos galacto gos and mannan', 0.0)),
#  (971, ('of research has implicated the main olfactory system', 0.0)),
#  (972, ('of survival s of patients with metastatic osteosarcoma', 0.0)),
#  (973, ('olfaction according to this the main olfactory system', 0.0)),
#  (974,
#   ('or body composition enhanced recent study suggest mannanoligosaccharides',
#    0.0)),
#  (975, ('oxygenase 1 ho 1 in mitochondrial oxidative stress', 0.0)),
#  (976, ('per os treatment of control mice with mannooligosaccharides', 0.0)),
#  (977, ('phosphorylated on ser459 by the p37mos protein kinase', 0.0)),
#  (978, ('physical functional scale of the medical outcomes study', 0.0)),
#  (979, ('polyphenolic flavonoids 5 hydroxy 6 7 dimethoxy flavone', 0.0)),
#  (980,
#   ('potential candidate including dietary supplementation with mannan oligosaccharide',
#    0.0)),
#  (981,
#   ('proteolytic events is linked to mitochondrial oxidative stress', 0.0)),
#  (982,
#   ('recent glycomics advancement specific mannose based oligosaccharide mannooligosaccharides',
#    0.0)),
#  (983, ('receptor 5 ht 4 r agonist mosapride citrate', 0.0)),
#  (984,
#   ('research council nrc 1994 recommendations and manno oligosaccharide',
#    0.0)),
#  (985, ('s determine the infant s motor optimality score', 0.0)),
#  (986, ('scheduler and network stack the mantis operating system', 0.0)),
#  (987, ('serotonin 4 5 ht4 receptor agonist mosapride citrate', 0.0)),
#  (988, ('social support medical outcomes study social support survey', 0.0)),
#  (989, ('soybean meal fsbm with or without mannan oligosaccharide', 0.0)),
#  (990, ('standard deviations of mos the margin of stability', 0.0)),
#  (991, ('study assess the effects of dietary mannan oligosaccharide', 0.0)),
#  (992,
#   ('study investigated the effects of dietary mannan oligosaccharide', 0.0)),
#  (993,
#   ('sufficient to sensitize cell to mitochondrial oxidative stress', 0.0)),
#  (994, ('that pkc contains high levels of mannan oligosaccharide', 0.0)),
#  (995, ('the 5 ht 4 receptor agonist mosapride citrate', 0.0)),
#  (996,
#   ('the administration of different levels of mannan oligosaccharide', 0.0)),
#  (997, ('the effects of a yeast cell wall mannooligosaccharides', 0.0)),
#  (998, ('the effects of dietary β glucan mannan oligosaccharide', 0.0)),
#  (999, ('the high ff resulting a metal oxidative semiconductor', 0.0)),
#  ...]

# %%
longforms0.extend([(longform, score) for i, (longform, score) in enumerate(top)
                   if i in [30, 243]])

# %%
longforms0
# Out:
# [('mannan oligosaccharide', 34.74999999999999),
#  ('mannanoligosaccharides', 15.588235294117647),
#  ('mannooligosaccharides', 11.615384615384615),
#  ('mitochondrial oxidative stress', 10.8),
#  ('mosapride citrate', 9.125),
#  ('margin of stability', 7.6),
#  ('motor optimality score', 3.0),
#  ('metal oxidative semiconductor', 2.5),
#  ('maltooligosaccharides', 2.0),
#  ('occlusal splint', 1.3333333333333333),
#  ('main olfactory system', 1.666666666666667),
#  ('swimming', 0.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('mannan oligosaccharide',
#  'mannanoligosaccharides',
#  'mannooligosaccharides',
#  'mitochondrial oxidative stress',
#  'mosapride citrate',
#  'margin of stability',
#  'motor optimality score',
#  'metal oxidative semiconductor',
#  'maltooligosaccharides',
#  'main olfactory system',
#  'occlusal splint',
#  'swimming')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'mannooligosaccharides': 'CHEBI:CHEBI:25174',
#  'mosapride citrate': 'CHEBI:CHEBI:31867',
#  'maltooligosaccharides': 'CHEBI:CHEBI:17593',
#  'occlusal splint': 'MESH:D017090',
#  'swimming': 'GO:GO:0036268'}

# %%
names
# Out:
# {'CHEBI:CHEBI:25174': 'mannooligosaccharide',
#  'CHEBI:CHEBI:31867': 'Mosapride citrate',
#  'CHEBI:CHEBI:17593': 'maltooligosaccharide',
#  'MESH:D017090': 'Occlusal Splints',
#  'GO:GO:0036268': 'swimming'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names
# Out:
# {'CHEBI:CHEBI:17593': 'maltooligosaccharide',
#  'CHEBI:CHEBI:25174': 'mannooligosaccharide',
#  'MESH:D018384': 'Oxidative Stress',
#  'CHEBI:CHEBI:31867': 'Mosapride citrate'}

# %%
grounding_map
# Out:
# {'main olfactory system': 'ungrounded',
#  'maltooligosaccharides': 'CHEBI:CHEBI:17593',
#  'mannan oligosaccharide': 'CHEBI:CHEBI:25174',
#  'mannanoligosaccharides': 'CHEBI:CHEBI:25174',
#  'mannooligosaccharides': 'CHEBI:CHEBI:25174',
#  'margin of stability': 'ungrounded',
#  'metal oxidative semiconductor': 'ungrounded',
#  'mitochondrial oxidative stress': 'MESH:D018384',
#  'mosapride citrate': 'CHEBI:CHEBI:31867',
#  'motor optimality score': 'ungrounded',
#  'occlusal splint': 'ungrounded',
#  'swimming': 'ungrounded'}

# %%
names['HGNC:7199'] = 'MOS'
names['HGNC:18234'] = 'MOCOS'
pos_labels.extend(['HGNC:7199', 'HGNC:18234'])

# %%
result = grounding_map, names, pos_labels

# %%
result
# Out:
# ({'main olfactory system': 'ungrounded',
#   'maltooligosaccharides': 'CHEBI:CHEBI:17593',
#   'mannan oligosaccharide': 'CHEBI:CHEBI:25174',
#   'mannanoligosaccharides': 'CHEBI:CHEBI:25174',
#   'mannooligosaccharides': 'CHEBI:CHEBI:25174',
#   'margin of stability': 'ungrounded',
#   'metal oxidative semiconductor': 'ungrounded',
#   'mitochondrial oxidative stress': 'MESH:D018384',
#   'mosapride citrate': 'CHEBI:CHEBI:31867',
#   'motor optimality score': 'ungrounded',
#   'occlusal splint': 'ungrounded',
#   'swimming': 'ungrounded'},
#  {'CHEBI:CHEBI:17593': 'maltooligosaccharide',
#   'CHEBI:CHEBI:25174': 'mannooligosaccharide',
#   'MESH:D018384': 'Oxidative Stress',
#   'CHEBI:CHEBI:31867': 'Mosapride citrate',
#   'HGNC:7199': 'MOS',
#   'HGNC:18234': 'MOCOS'},
#  ['CHEBI:CHEBI:17593',
#   'CHEBI:CHEBI:25174',
#   'CHEBI:CHEBI:31867',
#   'MESH:D018384',
#   'HGNC:7199',
#   'HGNC:18234'])

# %%
grounding_map, names, pos_labels = ({'main olfactory system': 'ungrounded',
  'maltooligosaccharides': 'CHEBI:CHEBI:17593',
  'mannan oligosaccharide': 'CHEBI:CHEBI:25174',
  'mannanoligosaccharides': 'CHEBI:CHEBI:25174',
  'mannooligosaccharides': 'CHEBI:CHEBI:25174',
  'margin of stability': 'ungrounded',
  'metal oxidative semiconductor': 'ungrounded',
  'mitochondrial oxidative stress': 'MESH:D018384',
  'mosapride citrate': 'CHEBI:CHEBI:31867',
  'motor optimality score': 'ungrounded',
  'occlusal splint': 'ungrounded',
  'swimming': 'ungrounded'},
 {'CHEBI:CHEBI:17593': 'maltooligosaccharide',
  'CHEBI:CHEBI:25174': 'mannooligosaccharide',
  'MESH:D018384': 'Oxidative Stress',
  'CHEBI:CHEBI:31867': 'Mosapride citrate',
  'HGNC:7199': 'MOS',
  'HGNC:18234': 'MOCOS'},
 ['CHEBI:CHEBI:17593',
  'CHEBI:CHEBI:25174',
  'CHEBI:CHEBI:31867',
  'MESH:D018384',
  'HGNC:7199',
  'HGNC:18234'])

# %%
grounding_dict = {'MOS': grounding_map}

# %%
classifier = AdeftClassifier('MOS', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-21 11:08:44] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2020-01-21 11:09:27] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.7980731561371396 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'UP:Q9SCZ4': 32, 'ungrounded': 17, 'HGNC:3655': 78},
#  'f1': {'mean': 0.9610480217432276, 'std': 0.015913358823083618},
#  'precision': {'mean': 0.934003304879264, 'std': 0.02025652527603831},
#  'recall': {'mean': 0.9913043478260869, 'std': 0.017391304347826077}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [(text, pred) for pred, text in zip(d, shortform_texts)if pred[0].startswith('HGNC')]

# %%
len(a)
# Out:
# 37

# %%
a[1]
# Out:
# ('Interestingly, this potent kinase signaling pathway that regulates oocyte maturation is the mitogen-activated protein kinase (MAPK) pathway. At the top of the cascade is MOS, an oocyte-specific mitogen-activated protein kinase (Mek) kinase similar to Raf ( Fig. 1 ).  Mos  mRNA is present in immature oocytes, but essentially none is translated into stable MOS protein. Steroid-triggered reductions in cAMP lead to increased polyadenylation of  Mos  mRNA in a process that involves interactions of regulatory proteins EG2 and cytoplasmic polyadenylation element-binding protein (CPEB) with the 3′ untranslated region of  Mos  mRNA [ 21 – 26 ]. Increased polyadenylation of  Mos  mRNA leads to increased MOS protein expression. Once present, MOS protein is constitutively active and activates Mek1 [ 27 ], which in turn activates extracellular signaling-regulated kinase 2 (Erk2, or p42), and finally cycle-dependent kinase 1 (CDK1). Activated Erk2 then feeds back to promote further increases in MOS protein expression and activity, thus markedly enhancing the signaling cascade in a feed-forward fashion [ 28 – 30 ].\nWhile this unusual positive feedback loop was originally described in the 1960s and 1970s [ 10 ,  31 – 33 ], the description of regulatory factors that mediate this signaling pathway did not occur until nearly 30 years later, when paxillin was discovered to be an important component of steroid-triggered oocyte maturation. In retrospect, an association of paxillin with oocyte maturation makes sense, as, in somatic cells, paxillin is known to interact with and regulate the activity of several components of the MAPK signaling cascade, including Raf, MEK, and Erk [ 6 ,  34 ]. Since the same MOS/Mek/Erk pathway is crucial for steroid-triggered oocyte maturation, one might anticipate that paxillin would be involved. In fact, knockdown of paxillin expression in  Xenopus laevis  oocytes using either antisense oligonucleotides or siRNA almost completely abrogates androgen-induced maturation [ 35 ]. In addition, paxillin knockdown markedly attenuates androgen-triggered MOS protein expression and downstream Erk activation. In contrast, androgen-triggered polyadenylation of mRNA is unaffected by paxillin knockdown. Together, these results demonstrate that paxillin functions downstream of  Mos  mRNA modification and upstream of MOS translation to regulate nongenomic androgen-triggered oocyte maturation in  Xenopus laevis  oocytes ( Fig. 1 ).\nSurprisingly, in addition to this important upstream role in regulating activation of the MOS/Mek/Erk pathway, paxillin is also regulating important maturation-related processes downstream of the MAPK pathway. As mentioned earlier, paxillin contains serine residues that are targets for Erk-dependent phosphorylation. Interestingly, while re-expression of wild-type paxillin rescues steroid-triggered maturation in paxillin-knockdown oocytes, rescue with a paxillin protein containing alanine substitutions on serine residues 107 and 111 is ineffective at rescuing maturation. MOS and Erk activation are still intact in the presence of this mutated paxillin, though at significantly lower levels [ 35 ]. These data, plus others, suggest that paxillin subserves two separate functions doing androgen-triggered oocyte maturation. First, it regulates activation of the MAPK pathway, most likely by upregulating MOS protein expression and then possibly serving as a scaffold for Mek and Erk signaling. Second, after Erk-dependent phosphorylation on serine residues, phosphoserine-paxillin regulates downstream processes that are still not yet known to regulate oocyte maturation. In fact, since MOS expression and Erk activation are slightly reduced in the absence of phosphoserine-paxillin, it is possible that one of the functions of phosphoserine-paxillin is to enhance the aforementioned positive feedback loop in MAPK signaling that is critical for normal oocyte maturation ( Fig. 1 ). Further studies will help elucidate how  ...
#  ('HGNC:7199',
#   'MOS',
#   {'CHEBI:CHEBI:17593': 0.0024951505883109766,
#    'CHEBI:CHEBI:25174': 0.005309936673627085,
#    'CHEBI:CHEBI:31867': 0.0041298207091438255,
#    'HGNC:18234': 0.006718774908011465,
#    'HGNC:7199': 0.9741503031659994,
#    'MESH:D018384': 0.003693503289775186,
#    'ungrounded': 0.00350251066513202}))

# %%
disamb.dump('MOS', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('FES', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)
