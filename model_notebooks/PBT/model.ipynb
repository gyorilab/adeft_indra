# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['PBT']
genes = []
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts |= set(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['PBT'].top()

# %%
top
# Out:
# [('proton beam therapy', 56.793103448275865),
#  ('therapy', 18.281690140845072),
#  ('of proton beam therapy', 8.90909090909091),
#  ('perioperative blood transfusion', 8.76923076923077),
#  ('terephthalate', 8.470588235294118),
#  ('polybutylene terephthalate', 8.0),
#  ('peripheral blood t cells', 7.777777777777778),
#  ('of perioperative blood transfusion', 5.142857142857142),
#  ('poly butylene terephthalate', 5.0),
#  ('peripheral blood t', 4.285714285714286),
#  ('with proton beam therapy', 4.285714285714286),
#  ('butylene terephthalate', 3.0),
#  ('human peripheral blood t', 3.0),
#  ('treated with proton beam therapy', 3.0),
#  ('payback times', 2.0),
#  ('polyamine blockade therapy', 2.0),
#  ('and proton beam therapy', 2.0),
#  ('by proton beam therapy', 2.0),
#  ('using proton beam therapy', 2.0),
#  ('efficacy of proton beam therapy', 2.0),
#  ('imrt or proton beam therapy', 2.0),
#  ('transfusion', 1.8666666666666671),
#  ('blood transfusion', 1.8571428571428577),
#  ('times', 1.5),
#  ('benefits of proton beam therapy', 1.3333333333333333),
#  ('effect of perioperative blood transfusion', 1.3333333333333333),
#  ('brachytherapy', 1.0),
#  ('polymer', 1.0),
#  ('radiotherapy', 1.0),
#  ('test', 1.0),
#  ('translocation', 1.0),
#  ('tumor', 1.0),
#  ('papilla based thickness', 1.0),
#  ('platinum based therapy', 1.0),
#  ('polyamine blocking therapy', 1.0),
#  ('0 1 tween 20', 1.0),
#  ('additionally proton beam therapy', 1),
#  ('that proton beam therapy', 1.0),
#  ('the phenacetin breath test', 1),
#  ('a novel polyamine blocker therapy', 1.0),
#  ('human peripheral blood t cells', 1.0),
#  ('poly 1 4 butylene terephthalate', 1.0),
#  ('risk adapted proton beam therapy', 1.0),
#  ('we compared proton beam therapy', 1),
#  ('freshly isolated human peripheral blood t', 1),
#  ('the effect of perioperative blood transfusion', 1.0),
#  ('the efficacy of proton beam therapy', 1),
#  ('the relationship between perioperative blood transfusion', 1),
#  ('the role of proton beam therapy', 1),
#  ('high performed poly 1 4 butylene terephthalate', 1),
#  ('it was report that proton beam therapy', 1),
#  ('long term efficacy of proton beam therapy', 1),
#  ('normal liver sparing with proton beam therapy', 1),
#  ('patients level benefits of proton beam therapy', 1.0),
#  ('background to investigate the impact of proton radiotherapy', 1),
#  ('the induced immunosuppressive effect of perioperative blood transfusion',
#   1),
#  ('to compared clinical outcomes between proton beam therapy', 1),
#  ('to investigate the associated of perioperative blood transfusion', 1),
#  ('while the receipt of a perioperative blood transfusion', 1),
#  ('intensity modulated radiation therapy imrt and proton beam therapy', 1.0),
#  ('conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#   1.0),
#  ('to evaluate the role of risk adapted proton beam therapy', 1),
#  ('aromatic polyesters including poly ethylene terephthalate pet and poly butylene terephthalate',
#   1),
#  ('second order two component reactions chemical structures of polymer polybutylene terephthalate',
#   1),
#  ('this study documenting the utilization and efficacy of proton beam therapy',
#   1),
#  ('to evaluate the impact of preoperative anemia and perioperative blood transfusion',
#   1),
#  ('a number of study have investigate the effect of perioperative blood transfusion',
#   1),
#  ('atients who undergo surgical treatment for malignancy often receive perioperative blood transfusion',
#   1),
#  ('blends particles for selective laser sintering sls is demonstrate for polybutylene terephthalate',
#   1),
#  ('ex bmi preoperative hemoglobin and creatinine level receipt of perioperative blood transfusion',
#   1),
#  ('l intestine to the liver whereas isoproterenol treated mice demonstrate pathological translocation',
#   1),
#  ('presence of advanced chronic liver disease and culminates in pathological bacterial translocation',
#   1),
#  ('teractions between lymphocytes and human gingival fibroblasts hgf peripheral blood t lymphocytes',
#   1),
#  ('umerical models of these experiments blends of glass fiber reinforced polybutylene terephthalate',
#   1),
#  ('utuc who undergo radical nephroureterectomy rnu the effect of perioperative blood transfusion',
#   1),
#  ('39 40 41 accordingly task specific training such as perturbation based balance training',
#   1),
#  ('8 another interesting application of what is current be term polyamine blocking therapy',
#   1),
#  ('can be treated with a variety of treatment modalities including activated surveillance brachytherapy',
#   1),
#  ('ell source for therapy remain quiescence so proliferation is rare while photobiomodulation therapy',
#   1),
#  ('es such as nylon polyesters e g polyethylene terephthalate pet and polybutylene terephthalate',
#   1),
#  ('experimental or control group respectively of physical therapy treatment the prone bridge test',
#   1),
#  ('ion induced lymphopenia between intensity modulated radiation therapy imrt or proton beam therapy',
#   1),
#  ('lame retardancy on the dripping behaviour of four commercial polymer poly butylene terephthalate',
#   1),
#  ('ontrolled trials should be the preferred evidence based investigate regarding proton beam therapy',
#   1),
#  ('ould not induced proliferation but suppressed proliferation of alloreactive peripheral blood t cells',
#   1),
#  ('puncture technique was using to assess fibrinolytic hemorrhage 20 22 primary bleeding times',
#   1),
#  ('r example the rounding of grinded particles of polystyrene ps 28 polybutylene terephthalate',
#   1),
#  ('represents intensity modulated radiation therapy imrt and red line represents proton beam therapy',
#   1),
#  ('sed mortality risk 1 2 similar the adverse correlation of perioperative blood transfusion',
#   1),
#  ('simetric plans using conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#   1),
#  ('to tertiary reactive blends the subject of the current investigate is polybutylene terephthalate',
#   1),
#  ('zed standardized outcomes and times driven activated based costs tdabc for prostate brachytherapy',
#   1),
#  ('bt represents a significant public health problem an increasing incidence in primary brain tumor',
#   1),
#  ('by reduce the radiation dose to the bone surrounding the eye proton beam therapy',
#   1),
#  ('c of the bladder on the oncological prognosis and additionally on perioperative blood transfusion',
#   1),
#  ('cw clinical crown width dw diastema width pbt papilla based thickness papilla based thickness',
#   1),
#  ('d normal tissue complication probability ntcp models in patients treated with proton beam therapy',
#   1),
#  ('e this study examine outcomes of bone marrow transplantation bmt and period blood transfusion',
#   1),
#  ('ed function of irradiation organs and retardancy growth are significant problem proton beam therapy',
#   1),
#  ('ial hypotheses for further study and for establishing new treatment strategies proton beam therapy',
#   1),
#  ('in apparent diffusion coefficient adc value of ocular melanoma treated with proton beam therapy',
#   1),
#  ('ing to irradiation large owing to anatomic location and associated toxicities proton beam therapy',
#   1),
#  ('iomas the most common benign and malignancy primary brain tumor respectively proton beam therapy',
#   1),
#  ('iotherapy imrt reduce side effect compared to older technique but whether proton beam therapy',
#   1),
#  ('it has been believed that the fas expression on human peripheral blood t cells',
#   1),
#  ('ivities we previous showed that pbt 1 a synthetic c9 substituted phenanthrene based tylophorine',
#   1),
#  ('lated radiation therapy imrt however the superior dose profiles provided by proton beam therapy',
#   1),
#  ('mation and ex vivo prostaglandin inactivation were study in the ethanol etoh and phenylbutazone',
#   1),
#  ('ncer care rise the import of documenting value in oncological increasing proton beam radiotherapy',
#   1),
#  ('o be substantially different compared photon therapy to charged particles like proton beam therapy',
#   1),
#  ('or some treatment modalities such as intensity modulated radiotherapy imrt or proton beam therapy',
#   1),
#  ('owing to the superior dimensional stability and heat resistance poly 1 4 butylene terephthalate',
#   1),
#  ('pf peach flowers and it subfractions particularly the ethylacetate pea and n butanol extract',
#   1),
#  ('red the potential of conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#   1),
#  ('study demonstrate that upon activated monocytes mo were able to sensitize peripheral blood t',
#   1),
#  ('t technique was compared with intensity modulated radiation therapy imrt and proton beam therapy',
#   1),
#  ('the aim of our study was to assess the influence of perioperative blood transfusion',
#   1),
#  ('the upregulated import of polyamine into the tumor we demonstrate that polyamine blockade therapy',
#   1),
#  ('tion even to irregularly shaped target volume compared with 3d radiotherapy proton beam therapy',
#   1),
#  ('tion to improve perioperative haemostasis and diminish the need for allogeneic red cells transfusion',
#   1),
#  ('to report quality of life qol toxicities in men treated with proton beam therapy',
#   1),
#  ('using of advanced rt technique intensity modulated radiation therapy imrt and proton beam therapy',
#   1),
#  ('0l in plasma and supernatants of freshly isolated platelets and autologous peripheral blood t cells',
#   1),
#  ('182 183 184 185 nylon 6 6 182 pva 186 pan 187 poly butylene terephthalate',
#   1),
#  ('and poorter 1994 cc p total maintenance costs mc specific leaf area sla payback times',
#   1),
#  ('atistically significant a 6 3 cm hepatocellular carcinoma hcc was treated by proton beam therapy',
#   1),
#  ('d before orthodontic treatment on the alterations of papilla height ph and papilla based thickness',
#   1),
#  ('f cd45 + inflammatory cells in disaggregated viable tumor cells treatment with dfmo and amxt1501',
#   1),
#  ('his study is to retrospectively evaluate the incidence of lung toxicities after proton beam therapy',
#   1),
#  ('ine biosynthesis as well as polyamine transport must be achieved a novel polyamine blocker therapy',
#   1),
#  ('ine by the kaplan meier method due to unique dose deposition characteristics proton beam therapy',
#   1),
#  ('ion of alveolar gas into the circulation one of the critical complication of pulmonary barotrauma',
#   1),
#  ('l and extracranial location 7 11 dose sculpting was further enhanced by proton beam therapy',
#   1),
#  ('n strategies can exert antitumor effect that may also promote immune a polyamine blocking therapy',
#   1),
#  ('of lung tissue we have characterized the migration of t lymphocytes isolated from peripheral blood',
#   1),
#  ('of pa12 hdpe 17 18 pa6 pa12 19 pmma ps 20 and recently polybutylene terephthalate',
#   1),
#  ('ogistically challenging to circumvent this limitation a non powered co 2 baited passive box trap',
#   1),
#  ('ora to starve neoplastic lesions of polyamine we have employed a novel polyamine blocker therapy',
#   1),
#  ('re similar to those of photon with no apparent clinical advantage therefore proton beam therapy',
#   1),
#  ('safety of a spot scanning dedicated small 360 degree gantry synchrotron based proton beam therapy',
#   1),
#  ('to this extent the emerging modalities of particles therapy chiefly comprised of proton beam therapy',
#   1),
#  ('ure that should be considered karagatzides and ellison 2009 in this context the payback times',
#   1),
#  ('with other lrts the cases showed objective tumor response after risk adapted proton beam therapy',
#   1),
#  ('℃ the lyophilized ethanol extract of ppf pet ethylacetate fraction pea and n butanol fraction',
#   1),
#  ('acute radiation dermatitis ard is one of the most common adverse events of proton beam therapy',
#   1),
#  ('asible but further study on it long term safety and efficacy are warranted proton beam therapy',
#   1),
#  ('at deal of attention over the past 30 years has centered on whether perioperative blood transfusion',
#   1),
#  ('ated arc therapy vmat with linear accelerators as well as the developed of proton beam therapy',
#   1),
#  ('based reimbursement system a relative lack of costs effect in the using of proton beam therapy',
#   1),
#  ('end of the bragg peak 12 which under the better dose distribution with proton beam therapy',
#   1),
#  ('eted radical irradiation 8 9 based on this unique property we first using proton beam therapy',
#   1),
#  ('hat are essential for their growth and survival we have developed a new polyamine blockade therapy',
#   1),
#  ('in the tumor microenvironment but to which cells should til be compared peripheral blood t cells',
#   1),
#  ('ion at present an increasing number of lung cancer patients are treated using proton beam therapy',
#   1),
#  ('light the urgent need for prospective data using pbt patients level benefits of proton beam therapy',
#   1),
#  ('ol especially in the spine using photon this however can be achieved with proton beam therapy',
#   1),
#  ('on to silver nanoparticles ag nps on the surface give rise to a homogeneous bithiophene polymer',
#   1),
#  ('s between a polymer and an adhesion the samples employed in this work is polybutylene terephtharate',
#   1),
#  ('sponse on imaging 4 how does sbrt compared to other ldt modalities including proton beam therapy',
#   1),
#  ('te the amount that radiation induced secondary cancer would be reduce by using proton beam therapy',
#   1),
#  ('these patients may be considered for system therapy along with sbrt 39 41 proton beam therapy',
#   1),
#  ('tment in the majority of patients with recurrent and or metastatic hnc with platinum based therapy',
#   1),
#  ('to be an import factor from an esthetic perspective facio lingual thickness of the papilla based',
#   1),
#  ('was added when til were using in cytokines detection assay after recovery peripheral blood t cells',
#   1),
#  ('y activated an immune attack on these tumor to evaluate the effect of polyamine blockade therapy',
#   1),
#  ('article size x 50 3 and span on process times during co comminution of a polybutylene terephthalate',
#   1),
#  ('assay were performed in a group of 37 paired samples of sln metastasis and primary breast tumor',
#   1),
#  ('cells are susceptible to these mabs 17 18 a large fraction of the peripheral blood t cells',
#   1),
#  ('he additionally of mgo after melt annealing for 45 min at 237 ° c calculated polybutylene terephthalate',
#   1),
#  ('identify by flow cytometry the murine t cells clone 7139 and cd3 stimulated human peripheral blood t',
#   1),
#  ('ies and flame retardancy of a nano sb₂o₃ ⁻ brominated epoxy resin beo ⁻ poly butylene terephthalate',
#   1),
#  ('in brief 2 h fixed embryos were permeabilized by a methanol phosphate buffered saline 0 1 tween',
#   1),
#  ('on of acute mucositis reduction of auc of 0 17 the models overall performed well the validation',
#   1),
#  ('on the role of rt modalities using photon based intensity modulated rt imrt or proton beam therapy',
#   1),
#  ('r eap might interfere with t cells recruitment we first examine the adhesion of peripheral blood t',
#   1),
#  ('s e g in automotive as custom made fuel manifolds in racing cars the semi crystalline polymer',
#   1),
#  ('s in this study we characterized the expression and function of trail on human peripheral blood t',
#   1),
#  ('simple and robust method to reduce the rate of adverse events in this context proton beam therapy',
#   1),
#  ('t al 1987 cc w and poorter 1994 cc p total maintenance costs mc and payback times',
#   1),
#  ('t is difficult to achieved a sufficient irradiation dose to treated hcc 5 6 proton beam therapy',
#   1),
#  ('th the amount of flame retardancy added tga under n 2 mass of a poly butylene terephthalate',
#   1),
#  ('thout exit dose to outside of the target volume our previous study showed that proton beam therapy',
#   1),
#  ('ty in this study we investigate the expression and function of trail in human peripheral blood t',
#   1),
#  ('crt for esophageal cancer the aim of this study was to examine the benefits of proton beam therapy',
#   1),
#  ('l was several depressed on average ∼ 7 times smaller in til compared with peripheral blood t cells',
#   1),
#  ('rgans we conducted a quality of life qol study for ccs who were treated with proton beam therapy',
#   1),
#  ('the tyrosine kinase p56lck from 56 kda to apparent 60 kda in resting human peripheral blood t cells',
#   1),
#  ('y a role in the t cells dysfunction of cancer patients in multiple myeloma mm peripheral blood t',
#   1),
#  ('ml for more than 8 days to obtain a population of cd4 + cd45ro + peripheral blood t lymphoblasts',
#   1),
#  ('s and don t reduce average dose to the brain compared with 3d crt in contrast proton beam therapy',
#   1),
#  ('cold pbs and fixed o n in 4 paraformaldehyde pfa pbs after several washes in pbs 0 1 tween 20',
#   1),
#  ('a 1 h recovery period eye disks were dissected followed by blocking for 4 h in pbs + 0 1 tween 20',
#   1),
#  ('o mi rna 155 il 2 and ifn γ are down regulated by tgf β in activated cd4 peripheral blood t cells',
#   1),
#  ('e 36 in brief proboscides were dissected and fixed for 20 min in 4 pfa in pbs + 0 2 triton x 100',
#   1),
#  ('l min − 1 nitrogen flow or 30 ml min − 1 synthetic air flow respectively then 5 ± 0 1 mg samples',
#   1),
#  ('100', 0.0),
#  ('20', 0.0),
#  ('amxt1501', 0.0),
#  ('barotrauma', 0.0),
#  ('based', 0.0),
#  ('blood', 0.0),
#  ('cells', 0.0),
#  ('extract', 0.0),
#  ('fraction', 0.0),
#  ('lymphoblasts', 0.0),
#  ('lymphocytes', 0.0),
#  ('phenylbutazone', 0.0),
#  ('samples', 0.0),
#  ('t', 0.0),
#  ('terephtharate', 0.0),
#  ('thickness', 0.0),
#  ('training', 0.0),
#  ('trap', 0.0),
#  ('tween', 0.0),
#  ('tylophorine', 0.0),
#  ('validation', 0.0),
#  ('1 tween', 0.0),
#  ('and amxt1501', 0.0),
#  ('and phenylbutazone', 0.0),
#  ('bacterial translocation', 0.0),
#  ('balance training', 0.0),
#  ('based therapy', 0.0),
#  ('based thickness', 0.0),
#  ('based tylophorine', 0.0),
#  ('beam radiotherapy', 0.0),
#  ('beam therapy', 0.0),
#  ('bithiophene polymer', 0.0),
#  ('bleeding times', 0.0),
#  ('blocking therapy', 0.0),
#  ('blockade therapy', 0.0),
#  ('blocker therapy', 0.0),
#  ('blood t', 0.0),
#  ('box trap', 0.0),
#  ('brain tumor', 0.0),
#  ('breast tumor', 0.0),
#  ('breath test', 0.0),
#  ('bridge test', 0.0),
#  ('butanol extract', 0.0),
#  ('butanol fraction', 0.0),
#  ('cells transfusion', 0.0),
#  ('crystalline polymer', 0.0),
#  ('mg samples', 0.0),
#  ('papilla based', 0.0),
#  ('pathological translocation', 0.0),
#  ('peripheral blood', 0.0),
#  ('photobiomodulation therapy', 0.0),
#  ('polybutylene terephtharate', 0.0),
#  ('prostate brachytherapy', 0.0),
#  ('proton radiotherapy', 0.0),
#  ('pulmonary barotrauma', 0.0),
#  ('surveillance brachytherapy', 0.0),
#  ('t cells', 0.0),
#  ('t lymphoblasts', 0.0),
#  ('t lymphocytes', 0.0),
#  ('the validation', 0.0),
#  ('tween 20', 0.0),
#  ('x 100', 0.0),
#  ('0 1 tween', 0.0),
#  ('1 mg samples', 0.0),
#  ('1 tween 20', 0.0),
#  ('28 polybutylene terephthalate', 0.0),
#  ('4 butylene terephthalate', 0.0),
#  ('a polybutylene terephthalate', 0.0),
#  ('activated surveillance brachytherapy', 0.0),
#  ('and payback times', 0.0),
#  ('and polybutylene terephthalate', 0.0),
#  ('based balance training', 0.0),
#  ('blood t cells', 0.0),
#  ('blood t lymphoblasts', 0.0),
#  ('blood t lymphocytes', 0.0),
#  ('calculated polybutylene terephthalate', 0.0),
#  ('demonstrate pathological translocation', 0.0),
#  ('dfmo and amxt1501', 0.0),
#  ('etoh and phenylbutazone', 0.0),
#  ('for polybutylene terephthalate', 0.0),
#  ('for prostate brachytherapy', 0.0),
#  ('from peripheral blood', 0.0),
#  ('homogeneous bithiophene polymer', 0.0),
#  ('is polybutylene terephthalate', 0.0),
#  ('is polybutylene terephtharate', 0.0),
#  ('n butanol extract', 0.0),
#  ('n butanol fraction', 0.0),
#  ('of proton radiotherapy', 0.0),
#  ('of pulmonary barotrauma', 0.0),
#  ('passive box trap', 0.0),
#  ('pathological bacterial translocation', 0.0),
#  ('period blood transfusion', 0.0),
#  ('phenacetin breath test', 0.0),
#  ('phenanthrene based tylophorine', 0.0),
#  ('polyamine blocker therapy', 0.0),
#  ('polymer polybutylene terephthalate', 0.0),
#  ('primary bleeding times', 0.0),
#  ('primary brain tumor', 0.0),
#  ('primary breast tumor', 0.0),
#  ('prone bridge test', 0.0),
#  ('proton beam radiotherapy', 0.0),
#  ('recently polybutylene terephthalate', 0.0),
#  ('red cells transfusion', 0.0),
#  ('reinforced polybutylene terephthalate', 0.0),
#  ('semi crystalline polymer', 0.0),
#  ('sla payback times', 0.0),
#  ('the papilla based', 0.0),
#  ('the payback times', 0.0),
#  ('triton x 100', 0.0),
#  ('well the validation', 0.0),
#  ('while photobiomodulation therapy', 0.0),
#  ('0 1 mg samples', 0.0),
#  ('1 4 butylene terephthalate', 0.0),
#  ('187 poly butylene terephthalate', 0.0),
#  ('2 triton x 100', 0.0),
#  ('22 primary bleeding times', 0.0),
#  ('41 proton beam therapy', 0.0),
#  ('6 proton beam therapy', 0.0),
#  ('a homogeneous bithiophene polymer', 0.0),
#  ('a perioperative blood transfusion', 0.0),
#  ('a poly butylene terephthalate', 0.0),
#  ('a polyamine blocking therapy', 0.0),
#  ('adapted proton beam therapy', 0.0),
#  ('after proton beam therapy', 0.0),
#  ('allogeneic red cells transfusion', 0.0),
#  ('and n butanol extract', 0.0),
#  ('and n butanol fraction', 0.0),
#  ('and papilla based thickness', 0.0),
#  ('and period blood transfusion', 0.0),
#  ('and perioperative blood transfusion', 0.0),
#  ('and poly butylene terephthalate', 0.0),
#  ('and primary breast tumor', 0.0),
#  ('and recently polybutylene terephthalate', 0.0),
#  ('area sla payback times', 0.0),
#  ('baited passive box trap', 0.0),
#  ('based proton beam therapy', 0.0),
#  ('between perioperative blood transfusion', 0.0),
#  ('between proton beam therapy', 0.0),
#  ('c calculated polybutylene terephthalate', 0.0),
#  ('characteristics proton beam therapy', 0.0),
#  ('compared proton beam therapy', 0.0),
#  ('complication of pulmonary barotrauma', 0.0),
#  ('context proton beam therapy', 0.0),
#  ('context the payback times', 0.0),
#  ('contrast proton beam therapy', 0.0),
#  ('demonstrate for polybutylene terephthalate', 0.0),
#  ('ethanol etoh and phenylbutazone', 0.0),
#  ('eye proton beam therapy', 0.0),
#  ('fiber reinforced polybutylene terephthalate', 0.0),
#  ('impact of proton radiotherapy', 0.0),
#  ('in pathological bacterial translocation', 0.0),
#  ('in primary brain tumor', 0.0),
#  ('including activated surveillance brachytherapy', 0.0),
#  ('including proton beam therapy', 0.0),
#  ('increasing proton beam radiotherapy', 0.0),
#  ('investigate is polybutylene terephthalate', 0.0),
#  ('isolated from peripheral blood', 0.0),
#  ('like proton beam therapy', 0.0),
#  ('mc and payback times', 0.0),
#  ('mice demonstrate pathological translocation', 0.0),
#  ('mm peripheral blood t', 0.0),
#  ('new polyamine blockade therapy', 0.0),
#  ('novel polyamine blocker therapy', 0.0),
#  ('of a polybutylene terephthalate', 0.0),
#  ('of peripheral blood t', 0.0),
#  ('of polyamine blockade therapy', 0.0),
#  ('of polymer polybutylene terephthalate', 0.0),
#  ('of the papilla based', 0.0),
#  ('on perioperative blood transfusion', 0.0),
#  ('or proton beam therapy', 0.0),
#  ('performed well the validation', 0.0),
#  ('peripheral blood t lymphoblasts', 0.0),
#  ('peripheral blood t lymphocytes', 0.0),
#  ('perturbation based balance training', 0.0),
#  ('pet and polybutylene terephthalate', 0.0),
#  ('polymer poly butylene terephthalate', 0.0),
#  ('problem proton beam therapy', 0.0),
#  ('ps 28 polybutylene terephthalate', 0.0),
#  ('radiotherapy proton beam therapy', 0.0),
#  ('rare while photobiomodulation therapy', 0.0),
#  ('receive perioperative blood transfusion', 0.0),
#  ('regarding proton beam therapy', 0.0),
#  ('represents proton beam therapy', 0.0),
#  ('respectively proton beam therapy', 0.0),
#  ('saline 0 1 tween', 0.0),
#  ('sensitize peripheral blood t', 0.0),
#  ('strategies proton beam therapy', 0.0),
#  ('substituted phenanthrene based tylophorine', 0.0),
#  ('tdabc for prostate brachytherapy', 0.0),
#  ('term polyamine blocking therapy', 0.0),
#  ('that polyamine blockade therapy', 0.0),
#  ('the prone bridge test', 0.0),
#  ('the semi crystalline polymer', 0.0),
#  ('therefore proton beam therapy', 0.0),
#  ('thickness papilla based thickness', 0.0),
#  ('toxicities proton beam therapy', 0.0),
#  ('warranted proton beam therapy', 0.0),
#  ('whether perioperative blood transfusion', 0.0),
#  ('whether proton beam therapy', 0.0),
#  ('with dfmo and amxt1501', 0.0),
#  ('with platinum based therapy', 0.0),
#  ('work is polybutylene terephtharate', 0.0),
#  ('⁻ poly butylene terephthalate', 0.0),
#  ('+ 0 1 tween 20', 0.0),
#  ('+ peripheral blood t lymphoblasts', 0.0),
#  ('0 2 triton x 100', 0.0),
#  ('2 baited passive box trap', 0.0),
#  ('20 22 primary bleeding times', 0.0),
#  ('20 and recently polybutylene terephthalate', 0.0),
#  ('39 41 proton beam therapy', 0.0),
#  ('3d radiotherapy proton beam therapy', 0.0),
#  ('5 6 proton beam therapy', 0.0),
#  ('a new polyamine blockade therapy', 0.0),
#  ('achieved with proton beam therapy', 0.0),
#  ('additionally on perioperative blood transfusion', 0.0),
#  ('adhesion of peripheral blood t', 0.0),
#  ('advantage therefore proton beam therapy', 0.0),
#  ('alloreactive peripheral blood t cells', 0.0),
#  ('anemia and perioperative blood transfusion', 0.0),
#  ('are warranted proton beam therapy', 0.0),
#  ('as perturbation based balance training', 0.0),
#  ('associated of perioperative blood transfusion', 0.0),
#  ('associated toxicities proton beam therapy', 0.0),
#  ('autologous peripheral blood t cells', 0.0),
#  ('based thickness papilla based thickness', 0.0),
#  ('be term polyamine blocking therapy', 0.0),
#  ('beo ⁻ poly butylene terephthalate', 0.0),
#  ('bmt and period blood transfusion', 0.0),
#  ('buffered saline 0 1 tween', 0.0),
#  ('but whether proton beam therapy', 0.0),
#  ('by using proton beam therapy', 0.0),
#  ('c9 substituted phenanthrene based tylophorine', 0.0),
#  ('cars the semi crystalline polymer', 0.0),
#  ('cd4 peripheral blood t cells', 0.0),
#  ('commercial polymer poly butylene terephthalate', 0.0),
#  ('comminution of a polybutylene terephthalate', 0.0),
#  ('compared peripheral blood t cells', 0.0),
#  ('comprised of proton beam therapy', 0.0),
#  ('correlation of perioperative blood transfusion', 0.0),
#  ('costs mc and payback times', 0.0),
#  ('costs tdabc for prostate brachytherapy', 0.0),
#  ('critical complication of pulmonary barotrauma', 0.0),
#  ('culminates in pathological bacterial translocation', 0.0),
#  ('current investigate is polybutylene terephthalate', 0.0),
#  ('demonstrate that polyamine blockade therapy', 0.0),
#  ('deposition characteristics proton beam therapy', 0.0),
#  ('developed of proton beam therapy', 0.0),
#  ('distribution with proton beam therapy', 0.0),
#  ('effect of polyamine blockade therapy', 0.0),
#  ('enhanced by proton beam therapy', 0.0),
#  ('events of proton beam therapy', 0.0),
#  ('first using proton beam therapy', 0.0),
#  ('for allogeneic red cells transfusion', 0.0),
#  ('glass fiber reinforced polybutylene terephthalate', 0.0),
#  ('hgf peripheral blood t lymphocytes', 0.0),
#  ('hnc with platinum based therapy', 0.0),
#  ('ht and proton beam therapy', 0.0),
#  ('immune a polyamine blocking therapy', 0.0),
#  ('imrt and proton beam therapy', 0.0),
#  ('in contrast proton beam therapy', 0.0),
#  ('in human peripheral blood t', 0.0),
#  ('incidence in primary brain tumor', 0.0),
#  ('influence of perioperative blood transfusion', 0.0),
#  ('investigate regarding proton beam therapy', 0.0),
#  ('is demonstrate for polybutylene terephthalate', 0.0),
#  ('is rare while photobiomodulation therapy', 0.0),
#  ('isolated human peripheral blood t', 0.0),
#  ('leaf area sla payback times', 0.0),
#  ('line represents proton beam therapy', 0.0),
#  ('lymphocytes isolated from peripheral blood', 0.0),
#  ('metastasis and primary breast tumor', 0.0),
#  ('modalities including activated surveillance brachytherapy', 0.0),
#  ('modalities including proton beam therapy', 0.0),
#  ('myeloma mm peripheral blood t', 0.0),
#  ('of a perioperative blood transfusion', 0.0),
#  ('of a poly butylene terephthalate', 0.0),
#  ('often receive perioperative blood transfusion', 0.0),
#  ('on human peripheral blood t', 0.0),
#  ('on whether perioperative blood transfusion', 0.0),
#  ('oncological increasing proton beam radiotherapy', 0.0),
#  ('outcomes between proton beam therapy', 0.0),
#  ('overall performed well the validation', 0.0),
#  ('pan 187 poly butylene terephthalate', 0.0),
#  ('particles like proton beam therapy', 0.0),
#  ('pbs 0 1 tween 20', 0.0),
#  ('pea and n butanol extract', 0.0),
#  ('pea and n butanol fraction', 0.0),
#  ('pet and poly butylene terephthalate', 0.0),
#  ('ph and papilla based thickness', 0.0),
#  ('polystyrene ps 28 polybutylene terephthalate', 0.0),
#  ('provided by proton beam therapy', 0.0),
#  ('receipt of perioperative blood transfusion', 0.0),
#  ('recovery peripheral blood t cells', 0.0),
#  ('relationship between perioperative blood transfusion', 0.0),
#  ('report that proton beam therapy', 0.0),
#  ('role of proton beam therapy', 0.0),
#  ('showed that proton beam therapy', 0.0),
#  ('significant problem proton beam therapy', 0.0),
#  ('sparing with proton beam therapy', 0.0),
#  ('stimulated human peripheral blood t', 0.0),
#  ('structures of polymer polybutylene terephthalate', 0.0),
#  ('synchrotron based proton beam therapy', 0.0),
#  ('terephthalate pet and polybutylene terephthalate', 0.0),
#  ('the ethanol etoh and phenylbutazone', 0.0),
#  ('the eye proton beam therapy', 0.0),
#  ('the impact of proton radiotherapy', 0.0),
#  ('the peripheral blood t cells', 0.0),
#  ('thickness of the papilla based', 0.0),
#  ('this context proton beam therapy', 0.0),
#  ('this context the payback times', 0.0),
#  ('this work is polybutylene terephtharate', 0.0),
#  ('to a homogeneous bithiophene polymer', 0.0),
#  ('to sensitize peripheral blood t', 0.0),
#  ('toxicities after proton beam therapy', 0.0),
#  ('treated by proton beam therapy', 0.0),
#  ('treated mice demonstrate pathological translocation', 0.0),
#  ('treated using proton beam therapy', 0.0),
#  ('treatment strategies proton beam therapy', 0.0),
#  ('treatment the prone bridge test', 0.0),
#  ('treatment with dfmo and amxt1501', 0.0),
#  ('tumor respectively proton beam therapy', 0.0),
#  ('using of proton beam therapy', 0.0),
#  ('with peripheral blood t cells', 0.0),
#  ('° c calculated polybutylene terephthalate', 0.0),
#  ('± 0 1 mg samples', 0.0),
#  ('+ 0 2 triton x 100', 0.0),
#  ('186 pan 187 poly butylene terephthalate', 0.0),
#  ('237 ° c calculated polybutylene terephthalate', 0.0),
#  ('5 ± 0 1 mg samples', 0.0),
#  ('able to sensitize peripheral blood t', 0.0),
#  ('achieved a novel polyamine blocker therapy', 0.0),
#  ('activated cd4 peripheral blood t cells', 0.0),
#  ('adverse correlation of perioperative blood transfusion', 0.0),
#  ('adverse events of proton beam therapy', 0.0),
#  ('after recovery peripheral blood t cells', 0.0),
#  ('after risk adapted proton beam therapy', 0.0),
#  ('and additionally on perioperative blood transfusion', 0.0),
#  ('and associated toxicities proton beam therapy', 0.0),
#  ('and autologous peripheral blood t cells', 0.0),
#  ('and culminates in pathological bacterial translocation', 0.0),
#  ('and efficacy of proton beam therapy', 0.0),
#  ('are significant problem proton beam therapy', 0.0),
#  ('are treated using proton beam therapy', 0.0),
#  ('based costs tdabc for prostate brachytherapy', 0.0),
#  ('based investigate regarding proton beam therapy', 0.0),
#  ('be achieved with proton beam therapy', 0.0),
#  ('be compared peripheral blood t cells', 0.0),
#  ('brain tumor respectively proton beam therapy', 0.0),
#  ('cd3 stimulated human peripheral blood t', 0.0),
#  ('cd45ro + peripheral blood t lymphoblasts', 0.0),
#  ('cells treatment with dfmo and amxt1501', 0.0),
#  ('centered on whether perioperative blood transfusion', 0.0),
#  ('charged particles like proton beam therapy', 0.0),
#  ('chemical structures of polymer polybutylene terephthalate', 0.0),
#  ('chiefly comprised of proton beam therapy', 0.0),
#  ('clinical advantage therefore proton beam therapy', 0.0),
#  ('clinical outcomes between proton beam therapy', 0.0),
#  ('co 2 baited passive box trap', 0.0),
#  ('co comminution of a polybutylene terephthalate', 0.0),
#  ('compared with peripheral blood t cells', 0.0),
#  ('crt in contrast proton beam therapy', 0.0),
#  ('current be term polyamine blocking therapy', 0.0),
#  ('developed a new polyamine blockade therapy', 0.0),
#  ('dose deposition characteristics proton beam therapy', 0.0),
#  ('dose distribution with proton beam therapy', 0.0),
#  ('efficacy are warranted proton beam therapy', 0.0),
#  ('employed a novel polyamine blocker therapy', 0.0),
#  ('ethylacetate pea and n butanol extract', 0.0),
#  ('fibroblasts hgf peripheral blood t lymphocytes', 0.0),
#  ('four commercial polymer poly butylene terephthalate', 0.0),
#  ('fraction pea and n butanol fraction', 0.0),
#  ('further enhanced by proton beam therapy', 0.0),
#  ('gantry synchrotron based proton beam therapy', 0.0),
#  ('hcc 5 6 proton beam therapy', 0.0),
#  ('height ph and papilla based thickness', 0.0),
#  ('hemorrhage 20 22 primary bleeding times', 0.0),
#  ('immunosuppressive effect of perioperative blood transfusion', 0.0),
#  ('in oncological increasing proton beam radiotherapy', 0.0),
#  ('in pbs 0 1 tween 20', 0.0),
#  ('in the ethanol etoh and phenylbutazone', 0.0),
#  ('in this context proton beam therapy', 0.0),
#  ('in this context the payback times', 0.0),
#  ('in this work is polybutylene terephtharate', 0.0),
#  ('increasing incidence in primary brain tumor', 0.0),
#  ('investigate the impact of proton radiotherapy', 0.0),
#  ('isoproterenol treated mice demonstrate pathological translocation', 0.0),
#  ('ldt modalities including proton beam therapy', 0.0),
#  ('level benefits of proton beam therapy', 0.0),
#  ('level receipt of perioperative blood transfusion', 0.0),
#  ('lingual thickness of the papilla based', 0.0),
#  ('liver sparing with proton beam therapy', 0.0),
#  ('lung toxicities after proton beam therapy', 0.0),
#  ('maintenance costs mc and payback times', 0.0),
#  ('malignancy often receive perioperative blood transfusion', 0.0),
#  ('mass of a poly butylene terephthalate', 0.0),
#  ('melanoma treated with proton beam therapy', 0.0),
#  ('men treated with proton beam therapy', 0.0),
#  ('metastatic hnc with platinum based therapy', 0.0),
#  ('models overall performed well the validation', 0.0),
#  ('multiple myeloma mm peripheral blood t', 0.0),
#  ('need for allogeneic red cells transfusion', 0.0),
#  ('new treatment strategies proton beam therapy', 0.0),
#  ('of alloreactive peripheral blood t cells', 0.0),
#  ('of glass fiber reinforced polybutylene terephthalate', 0.0),
#  ('of polystyrene ps 28 polybutylene terephthalate', 0.0),
#  ('of risk adapted proton beam therapy', 0.0),
#  ('of the peripheral blood t cells', 0.0),
#  ('on human peripheral blood t cells', 0.0),
#  ('papilla based thickness papilla based thickness', 0.0),
#  ('patients treated with proton beam therapy', 0.0),
#  ('pbs + 0 1 tween 20', 0.0),
#  ('performed poly 1 4 butylene terephthalate', 0.0),
#  ('phosphate buffered saline 0 1 tween', 0.0),
#  ('polyethylene terephthalate pet and polybutylene terephthalate', 0.0),
#  ('preoperative anemia and perioperative blood transfusion', 0.0),
#  ('profiles provided by proton beam therapy', 0.0),
#  ('proliferation is rare while photobiomodulation therapy', 0.0),
#  ('promote immune a polyamine blocking therapy', 0.0),
#  ('ps 20 and recently polybutylene terephthalate', 0.0),
#  ('racing cars the semi crystalline polymer', 0.0),
#  ('radiotherapy imrt or proton beam therapy', 0.0),
#  ('receipt of a perioperative blood transfusion', 0.0),
#  ('red line represents proton beam therapy', 0.0),
#  ('reduce by using proton beam therapy', 0.0),
#  ('resin beo ⁻ poly butylene terephthalate', 0.0),
#  ('resistance poly 1 4 butylene terephthalate', 0.0),
#  ('resting human peripheral blood t cells', 0.0),
#  ('rise to a homogeneous bithiophene polymer', 0.0),
#  ('rt imrt or proton beam therapy', 0.0),
#  ('sbrt 39 41 proton beam therapy', 0.0),
#  ('sln metastasis and primary breast tumor', 0.0),
#  ('sls is demonstrate for polybutylene terephthalate', 0.0),
#  ('specific leaf area sla payback times', 0.0),
#  ('study showed that proton beam therapy', 0.0),
#  ('such as perturbation based balance training', 0.0),
#  ('surrounding the eye proton beam therapy', 0.0),
#  ('synthetic c9 substituted phenanthrene based tylophorine', 0.0),
#  ('t lymphocytes isolated from peripheral blood', 0.0),
#  ('technique but whether proton beam therapy', 0.0),
#  ('terephthalate pet and poly butylene terephthalate', 0.0),
#  ('term efficacy of proton beam therapy', 0.0),
#  ('the adhesion of peripheral blood t', 0.0),
#  ('the associated of perioperative blood transfusion', 0.0),
#  ('the benefits of proton beam therapy', 0.0),
#  ('the critical complication of pulmonary barotrauma', 0.0),
#  ('the current investigate is polybutylene terephthalate', 0.0),
#  ('the developed of proton beam therapy', 0.0),
#  ('the effect of polyamine blockade therapy', 0.0),
#  ('the influence of perioperative blood transfusion', 0.0),
#  ('the using of proton beam therapy', 0.0),
#  ('therapy imrt and proton beam therapy', 0.0),
#  ('therapy imrt or proton beam therapy', 0.0),
#  ('therapy treatment the prone bridge test', 0.0),
#  ('tomotherapy ht and proton beam therapy', 0.0),
#  ('trail in human peripheral blood t', 0.0),
#  ('trail on human peripheral blood t', 0.0),
#  ('transplantation bmt and period blood transfusion', 0.0),
#  ('treatment modalities including activated surveillance brachytherapy', 0.0),
#  ('was report that proton beam therapy', 0.0),
#  ('was treated by proton beam therapy', 0.0),
#  ('we demonstrate that polyamine blockade therapy', 0.0),
#  ('we first using proton beam therapy', 0.0),
#  ('were treated with proton beam therapy', 0.0),
#  ('with 3d radiotherapy proton beam therapy', 0.0),
#  ('+ cd45ro + peripheral blood t lymphoblasts', 0.0),
#  ('2 mass of a poly butylene terephthalate', 0.0),
#  ('2009 in this context the payback times', 0.0),
#  ('3d crt in contrast proton beam therapy', 0.0),
#  ('a synthetic c9 substituted phenanthrene based tylophorine', 0.0),
#  ('activated based costs tdabc for prostate brachytherapy', 0.0),
#  ('also promote immune a polyamine blocking therapy', 0.0),
#  ('an increasing incidence in primary brain tumor', 0.0),
#  ('and cd3 stimulated human peripheral blood t', 0.0),
#  ('and efficacy are warranted proton beam therapy', 0.0),
#  ('and red line represents proton beam therapy', 0.0),
#  ('apparent clinical advantage therefore proton beam therapy', 0.0),
#  ('as the developed of proton beam therapy', 0.0),
#  ('assay after recovery peripheral blood t cells', 0.0),
#  ('assess the influence of perioperative blood transfusion', 0.0),
#  ('at 237 ° c calculated polybutylene terephthalate', 0.0),
#  ('be achieved a novel polyamine blocker therapy', 0.0),
#  ('be reduce by using proton beam therapy', 0.0),
#  ('better dose distribution with proton beam therapy', 0.0),
#  ('blends of glass fiber reinforced polybutylene terephthalate', 0.0),
#  ('bone surrounding the eye proton beam therapy', 0.0),
#  ('can be achieved with proton beam therapy', 0.0),
#  ('common adverse events of proton beam therapy', 0.0),
#  ('compared clinical outcomes between proton beam therapy', 0.0),
#  ('compared with 3d radiotherapy proton beam therapy', 0.0),
#  ('creatinine level receipt of perioperative blood transfusion', 0.0),
#  ('degree gantry synchrotron based proton beam therapy', 0.0),
#  ('disease and culminates in pathological bacterial translocation', 0.0),
#  ('dose profiles provided by proton beam therapy', 0.0),
#  ('during co comminution of a polybutylene terephthalate', 0.0),
#  ('employed in this work is polybutylene terephtharate', 0.0),
#  ('epoxy resin beo ⁻ poly butylene terephthalate', 0.0),
#  ('establishing new treatment strategies proton beam therapy', 0.0),
#  ('ethylacetate fraction pea and n butanol fraction', 0.0),
#  ('ethylene terephthalate pet and poly butylene terephthalate', 0.0),
#  ('evaluate the effect of polyamine blockade therapy', 0.0),
#  ('events in this context proton beam therapy', 0.0),
#  ('evidence based investigate regarding proton beam therapy', 0.0),
#  ('examine the adhesion of peripheral blood t', 0.0),
#  ('examine the benefits of proton beam therapy', 0.0),
#  ('expression on human peripheral blood t cells', 0.0),
#  ('facio lingual thickness of the papilla based', 0.0),
#  ('fibrinolytic hemorrhage 20 22 primary bleeding times', 0.0),
#  ('for malignancy often receive perioperative blood transfusion', 0.0),
#  ('fraction of the peripheral blood t cells', 0.0),
#  ('g polyethylene terephthalate pet and polybutylene terephthalate', 0.0),
#  ('gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0),
#  ('give rise to a homogeneous bithiophene polymer', 0.0),
#  ('growth are significant problem proton beam therapy', 0.0),
#  ('has centered on whether perioperative blood transfusion', 0.0),
#  ('have developed a new polyamine blockade therapy', 0.0),
#  ('have employed a novel polyamine blocker therapy', 0.0),
#  ('hcc was treated by proton beam therapy', 0.0),
#  ('heat resistance poly 1 4 butylene terephthalate', 0.0),
#  ('helical tomotherapy ht and proton beam therapy', 0.0),
#  ('in activated cd4 peripheral blood t cells', 0.0),
#  ('in men treated with proton beam therapy', 0.0),
#  ('in multiple myeloma mm peripheral blood t', 0.0),
#  ('in patients treated with proton beam therapy', 0.0),
#  ('in pbs + 0 1 tween 20', 0.0),
#  ('in racing cars the semi crystalline polymer', 0.0),
#  ('in resting human peripheral blood t cells', 0.0),
#  ('in the using of proton beam therapy', 0.0),
#  ('induced immunosuppressive effect of perioperative blood transfusion', 0.0),
#  ('investigate the associated of perioperative blood transfusion', 0.0),
#  ('investigate the effect of perioperative blood transfusion', 0.0),
#  ('is current be term polyamine blocking therapy', 0.0),
#  ('location and associated toxicities proton beam therapy', 0.0),
#  ('marrow transplantation bmt and period blood transfusion', 0.0),
#  ('mc specific leaf area sla payback times', 0.0),
#  ('methanol phosphate buffered saline 0 1 tween', 0.0),
#  ('modulated radiotherapy imrt or proton beam therapy', 0.0),
#  ('modulated rt imrt or proton beam therapy', 0.0),
#  ('ocular melanoma treated with proton beam therapy', 0.0),
#  ('of four commercial polymer poly butylene terephthalate', 0.0),
#  ('of lung toxicities after proton beam therapy', 0.0),
#  ('of preoperative anemia and perioperative blood transfusion', 0.0),
#  ('of sln metastasis and primary breast tumor', 0.0),
#  ('of t lymphocytes isolated from peripheral blood', 0.0),
#  ('of the critical complication of pulmonary barotrauma', 0.0),
#  ('of the current investigate is polybutylene terephthalate', 0.0),
#  ('of trail in human peripheral blood t', 0.0),
#  ('of trail on human peripheral blood t', 0.0),
#  ('of treatment modalities including activated surveillance brachytherapy',
#   0.0),
#  ('older technique but whether proton beam therapy', 0.0),
#  ('or metastatic hnc with platinum based therapy', 0.0),
#  ('other ldt modalities including proton beam therapy', 0.0),
#  ('papilla height ph and papilla based thickness', 0.0),
#  ('particles of polystyrene ps 28 polybutylene terephthalate', 0.0),
#  ('patients are treated using proton beam therapy', 0.0),
#  ('pbs + 0 2 triton x 100', 0.0),
#  ('pbt papilla based thickness papilla based thickness', 0.0),
#  ('physical therapy treatment the prone bridge test', 0.0),
#  ('platelets and autologous peripheral blood t cells', 0.0),
#  ('pmma ps 20 and recently polybutylene terephthalate', 0.0),
#  ('powered co 2 baited passive box trap', 0.0),
#  ('previous study showed that proton beam therapy', 0.0),
#  ('primary brain tumor respectively proton beam therapy', 0.0),
#  ('prognosis and additionally on perioperative blood transfusion', 0.0),
#  ('proliferation of alloreactive peripheral blood t cells', 0.0),
#  ('property we first using proton beam therapy', 0.0),
#  ('pva 186 pan 187 poly butylene terephthalate', 0.0),
#  ('radiation therapy imrt and proton beam therapy', 0.0),
#  ('radiation therapy imrt or proton beam therapy', 0.0),
#  ('reactions chemical structures of polymer polybutylene terephthalate', 0.0),
#  ('response after risk adapted proton beam therapy', 0.0),
#  ('rnu the effect of perioperative blood transfusion', 0.0),
#  ('role of risk adapted proton beam therapy', 0.0),
#  ('sintering sls is demonstrate for polybutylene terephthalate', 0.0),
#  ('so proliferation is rare while photobiomodulation therapy', 0.0),
#  ('study in the ethanol etoh and phenylbutazone', 0.0),
#  ('the adverse correlation of perioperative blood transfusion', 0.0),
#  ('the ethylacetate pea and n butanol extract', 0.0),
#  ('the models overall performed well the validation', 0.0),
#  ('the need for allogeneic red cells transfusion', 0.0),
#  ('the receipt of a perioperative blood transfusion', 0.0),
#  ('then 5 ± 0 1 mg samples', 0.0),
#  ('therapy chiefly comprised of proton beam therapy', 0.0),
#  ('til be compared peripheral blood t cells', 0.0),
#  ('til compared with peripheral blood t cells', 0.0),
#  ('to charged particles like proton beam therapy', 0.0),
#  ('to investigate the impact of proton radiotherapy', 0.0),
#  ('total maintenance costs mc and payback times', 0.0),
#  ('training such as perturbation based balance training', 0.0),
#  ('treated hcc 5 6 proton beam therapy', 0.0),
#  ('tumor cells treatment with dfmo and amxt1501', 0.0),
#  ('tumor we demonstrate that polyamine blockade therapy', 0.0),
#  ('unique dose deposition characteristics proton beam therapy', 0.0),
#  ('utilization and efficacy of proton beam therapy', 0.0),
#  ('value in oncological increasing proton beam radiotherapy', 0.0),
#  ('was further enhanced by proton beam therapy', 0.0),
#  ('washes in pbs 0 1 tween 20', 0.0),
#  ('were able to sensitize peripheral blood t', 0.0),
#  ('whereas isoproterenol treated mice demonstrate pathological translocation',
#   0.0),
#  ('who were treated with proton beam therapy', 0.0),
#  ('with sbrt 39 41 proton beam therapy', 0.0),
#  ('1 a synthetic c9 substituted phenanthrene based tylophorine', 0.0),
#  ('17 the models overall performed well the validation', 0.0),
#  ('182 pva 186 pan 187 poly butylene terephthalate', 0.0),
#  ('19 pmma ps 20 and recently polybutylene terephthalate', 0.0),
#  ('360 degree gantry synchrotron based proton beam therapy', 0.0),
#  ('7139 and cd3 stimulated human peripheral blood t', 0.0),
#  ('a methanol phosphate buffered saline 0 1 tween', 0.0),
#  ('adverse events in this context proton beam therapy', 0.0),
#  ('along with sbrt 39 41 proton beam therapy', 0.0),
#  ('anatomic location and associated toxicities proton beam therapy', 0.0),
#  ('and creatinine level receipt of perioperative blood transfusion', 0.0),
#  ('and heat resistance poly 1 4 butylene terephthalate', 0.0),
#  ('and or metastatic hnc with platinum based therapy', 0.0),
#  ('assess fibrinolytic hemorrhage 20 22 primary bleeding times', 0.0),
#  ('behaviour of four commercial polymer poly butylene terephthalate', 0.0),
#  ('bone marrow transplantation bmt and period blood transfusion', 0.0),
#  ('brominated epoxy resin beo ⁻ poly butylene terephthalate', 0.0),
#  ('cancer patients are treated using proton beam therapy', 0.0),
#  ('carcinoma hcc was treated by proton beam therapy', 0.0),
#  ('ccs who were treated with proton beam therapy', 0.0),
#  ('cd4 + cd45ro + peripheral blood t lymphoblasts', 0.0),
#  ('component reactions chemical structures of polymer polybutylene terephthalate',
#   0.0),
#  ('costs mc specific leaf area sla payback times', 0.0),
#  ('crt helical tomotherapy ht and proton beam therapy', 0.0),
#  ('detection assay after recovery peripheral blood t cells', 0.0),
#  ('diminish the need for allogeneic red cells transfusion', 0.0),
#  ('documenting value in oncological increasing proton beam radiotherapy', 0.0),
#  ('driven activated based costs tdabc for prostate brachytherapy', 0.0),
#  ('e g polyethylene terephthalate pet and polybutylene terephthalate', 0.0),
#  ('effect in the using of proton beam therapy', 0.0),
#  ('ellison 2009 in this context the payback times', 0.0),
#  ('experiments blends of glass fiber reinforced polybutylene terephthalate',
#   0.0),
#  ('fas expression on human peripheral blood t cells', 0.0),
#  ('first examine the adhesion of peripheral blood t', 0.0),
#  ('for establishing new treatment strategies proton beam therapy', 0.0),
#  ('function of trail in human peripheral blood t', 0.0),
#  ('function of trail on human peripheral blood t', 0.0),
#  ('grinded particles of polystyrene ps 28 polybutylene terephthalate', 0.0),
#  ('h in pbs + 0 1 tween 20', 0.0),
#  ('have investigate the effect of perioperative blood transfusion', 0.0),
#  ('however can be achieved with proton beam therapy', 0.0),
#  ('human gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0),
#  ('impact of preoperative anemia and perioperative blood transfusion', 0.0),
#  ('imrt and red line represents proton beam therapy', 0.0),
#  ('in pbs + 0 2 triton x 100', 0.0),
#  ('in til compared with peripheral blood t cells', 0.0),
#  ('incidence of lung toxicities after proton beam therapy', 0.0),
#  ('intensity modulated radiotherapy imrt or proton beam therapy', 0.0),
#  ('intensity modulated rt imrt or proton beam therapy', 0.0),
#  ('isolated platelets and autologous peripheral blood t cells', 0.0),
#  ('kda in resting human peripheral blood t cells', 0.0),
#  ('large fraction of the peripheral blood t cells', 0.0),
#  ('laser sintering sls is demonstrate for polybutylene terephthalate', 0.0),
#  ('liver disease and culminates in pathological bacterial translocation', 0.0),
#  ('liver whereas isoproterenol treated mice demonstrate pathological translocation',
#   0.0),
#  ('malignancy primary brain tumor respectively proton beam therapy', 0.0),
#  ('manifolds in racing cars the semi crystalline polymer', 0.0),
#  ('may also promote immune a polyamine blocking therapy', 0.0),
#  ('migration of t lymphocytes isolated from peripheral blood', 0.0),
#  ('min at 237 ° c calculated polybutylene terephthalate', 0.0),
#  ('mo were able to sensitize peripheral blood t', 0.0),
#  ('models in patients treated with proton beam therapy', 0.0),
#  ('modulated radiation therapy imrt and proton beam therapy', 0.0),
#  ('modulated radiation therapy imrt or proton beam therapy', 0.0),
#  ('most common adverse events of proton beam therapy', 0.0),
#  ('must be achieved a novel polyamine blocker therapy', 0.0),
#  ('n 2 mass of a poly butylene terephthalate', 0.0),
#  ('nephroureterectomy rnu the effect of perioperative blood transfusion', 0.0),
#  ('no apparent clinical advantage therefore proton beam therapy', 0.0),
#  ('non powered co 2 baited passive box trap', 0.0),
#  ('of ocular melanoma treated with proton beam therapy', 0.0),
#  ('of papilla height ph and papilla based thickness', 0.0),
#  ('of physical therapy treatment the prone bridge test', 0.0),
#  ('oncological prognosis and additionally on perioperative blood transfusion',
#   0.0),
#  ('one of the critical complication of pulmonary barotrauma', 0.0),
#  ('our previous study showed that proton beam therapy', 0.0),
#  ('p total maintenance costs mc and payback times', 0.0),
#  ('particles therapy chiefly comprised of proton beam therapy', 0.0),
#  ('particularly the ethylacetate pea and n butanol extract', 0.0),
#  ('patients in multiple myeloma mm peripheral blood t', 0.0),
#  ('pbt patients level benefits of proton beam therapy', 0.0),
#  ('perspective facio lingual thickness of the papilla based', 0.0),
#  ('pet ethylacetate fraction pea and n butanol fraction', 0.0),
#  ('poly ethylene terephthalate pet and poly butylene terephthalate', 0.0),
#  ('preferred evidence based investigate regarding proton beam therapy', 0.0),
#  ('problem an increasing incidence in primary brain tumor', 0.0),
#  ('quiescence so proliferation is rare while photobiomodulation therapy', 0.0),
#  ('respectively then 5 ± 0 1 mg samples', 0.0),
#  ('retardancy growth are significant problem proton beam therapy', 0.0),
#  ('safety and efficacy are warranted proton beam therapy', 0.0),
#  ('samples employed in this work is polybutylene terephtharate', 0.0),
#  ('samples of sln metastasis and primary breast tumor', 0.0),
#  ('sculpting was further enhanced by proton beam therapy', 0.0),
#  ('several washes in pbs 0 1 tween 20', 0.0),
#  ('should til be compared peripheral blood t cells', 0.0),
#  ('similar the adverse correlation of perioperative blood transfusion', 0.0),
#  ('specific training such as perturbation based balance training', 0.0),
#  ('subject of the current investigate is polybutylene terephthalate', 0.0),
#  ('superior dose profiles provided by proton beam therapy', 0.0),
#  ('suppressed proliferation of alloreactive peripheral blood t cells', 0.0),
#  ('surface give rise to a homogeneous bithiophene polymer', 0.0),
#  ('the better dose distribution with proton beam therapy', 0.0),
#  ('the bone surrounding the eye proton beam therapy', 0.0),
#  ('the role of risk adapted proton beam therapy', 0.0),
#  ('the tumor we demonstrate that polyamine blockade therapy', 0.0),
#  ('the utilization and efficacy of proton beam therapy', 0.0),
#  ('therapy to charged particles like proton beam therapy', 0.0),
#  ('times during co comminution of a polybutylene terephthalate', 0.0),
#  ('to assess the influence of perioperative blood transfusion', 0.0),
#  ('to evaluate the effect of polyamine blockade therapy', 0.0),
#  ('to examine the benefits of proton beam therapy', 0.0),
#  ('to older technique but whether proton beam therapy', 0.0),
#  ('to other ldt modalities including proton beam therapy', 0.0),
#  ('to treated hcc 5 6 proton beam therapy', 0.0),
#  ('to unique dose deposition characteristics proton beam therapy', 0.0),
#  ('toxicities in men treated with proton beam therapy', 0.0),
#  ('treatment for malignancy often receive perioperative blood transfusion',
#   0.0),
#  ('tumor response after risk adapted proton beam therapy', 0.0),
#  ('unique property we first using proton beam therapy', 0.0),
#  ('variety of treatment modalities including activated surveillance brachytherapy',
#   0.0),
#  ('viable tumor cells treatment with dfmo and amxt1501', 0.0),
#  ('volume compared with 3d radiotherapy proton beam therapy', 0.0),
#  ('we have developed a new polyamine blockade therapy', 0.0),
#  ('we have employed a novel polyamine blocker therapy', 0.0),
#  ('well as the developed of proton beam therapy', 0.0),
#  ('were study in the ethanol etoh and phenylbutazone', 0.0),
#  ('what is current be term polyamine blocking therapy', 0.0),
#  ('width pbt papilla based thickness papilla based thickness', 0.0),
#  ('with 3d crt in contrast proton beam therapy', 0.0),
#  ('would be reduce by using proton beam therapy', 0.0),
#  ('years has centered on whether perioperative blood transfusion', 0.0),
#  ('β in activated cd4 peripheral blood t cells', 0.0),
#  ('0 17 the models overall performed well the validation', 0.0),
#  ('2 similar the adverse correlation of perioperative blood transfusion', 0.0),
#  ('30 years has centered on whether perioperative blood transfusion', 0.0),
#  ('4 h in pbs + 0 1 tween 20', 0.0),
#  ('45 min at 237 ° c calculated polybutylene terephthalate', 0.0),
#  ('6 182 pva 186 pan 187 poly butylene terephthalate', 0.0),
#  ('60 kda in resting human peripheral blood t cells', 0.0),
#  ('a large fraction of the peripheral blood t cells', 0.0),
#  ('a non powered co 2 baited passive box trap', 0.0),
#  ('a variety of treatment modalities including activated surveillance brachytherapy',
#   0.0),
#  ('after several washes in pbs 0 1 tween 20', 0.0),
#  ('alterations of papilla height ph and papilla based thickness', 0.0),
#  ('and diminish the need for allogeneic red cells transfusion', 0.0),
#  ('and ellison 2009 in this context the payback times', 0.0),
#  ('and for establishing new treatment strategies proton beam therapy', 0.0),
#  ('and function of trail in human peripheral blood t', 0.0),
#  ('and function of trail on human peripheral blood t', 0.0),
#  ('and human gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0),
#  ('and malignancy primary brain tumor respectively proton beam therapy', 0.0),
#  ('and retardancy growth are significant problem proton beam therapy', 0.0),
#  ('as intensity modulated radiotherapy imrt or proton beam therapy', 0.0),
#  ('as well as the developed of proton beam therapy', 0.0),
#  ('based intensity modulated rt imrt or proton beam therapy', 0.0),
#  ('but suppressed proliferation of alloreactive peripheral blood t cells',
#   0.0),
#  ('by a methanol phosphate buffered saline 0 1 tween', 0.0),
#  ('cancer patients in multiple myeloma mm peripheral blood t', 0.0),
#  ('cancer would be reduce by using proton beam therapy', 0.0),
#  ('cc p total maintenance costs mc and payback times', 0.0),
#  ('cells should til be compared peripheral blood t cells', 0.0),
#  ('chronic liver disease and culminates in pathological bacterial translocation',
#   0.0),
#  ('circulation one of the critical complication of pulmonary barotrauma', 0.0),
#  ('clone 7139 and cd3 stimulated human peripheral blood t', 0.0),
#  ('compared to older technique but whether proton beam therapy', 0.0),
#  ('compared to other ldt modalities including proton beam therapy', 0.0),
#  ('compared with 3d crt in contrast proton beam therapy', 0.0),
#  ('costs effect in the using of proton beam therapy', 0.0),
#  ('cytokines detection assay after recovery peripheral blood t cells', 0.0),
#  ('diastema width pbt papilla based thickness papilla based thickness', 0.0),
#  ('disaggregated viable tumor cells treatment with dfmo and amxt1501', 0.0),
#  ('documenting the utilization and efficacy of proton beam therapy', 0.0),
#  ('dose sculpting was further enhanced by proton beam therapy', 0.0),
#  ('dose to treated hcc 5 6 proton beam therapy', 0.0),
#  ('dripping behaviour of four commercial polymer poly butylene terephthalate',
#   0.0),
#  ('due to unique dose deposition characteristics proton beam therapy', 0.0),
#  ('esthetic perspective facio lingual thickness of the papilla based', 0.0),
#  ('evaluate the role of risk adapted proton beam therapy', 0.0),
#  ('flow respectively then 5 ± 0 1 mg samples', 0.0),
#  ('for ccs who were treated with proton beam therapy', 0.0),
#  ('freshly isolated platelets and autologous peripheral blood t cells', 0.0),
#  ('fuel manifolds in racing cars the semi crystalline polymer', 0.0),
#  ('health problem an increasing incidence in primary brain tumor', 0.0),
#  ('hemoglobin and creatinine level receipt of perioperative blood transfusion',
#   0.0),
#  ('hepatocellular carcinoma hcc was treated by proton beam therapy', 0.0),
#  ('inactivation were study in the ethanol etoh and phenylbutazone', 0.0),
#  ('including poly ethylene terephthalate pet and poly butylene terephthalate',
#   0.0),
#  ('intensity modulated radiation therapy imrt or proton beam therapy', 0.0),
#  ('into the tumor we demonstrate that polyamine blockade therapy', 0.0),
#  ('lung cancer patients are treated using proton beam therapy', 0.0),
#  ('maintenance costs mc specific leaf area sla payback times', 0.0),
#  ('monocytes mo were able to sensitize peripheral blood t', 0.0),
#  ('ntcp models in patients treated with proton beam therapy', 0.0),
#  ('objective tumor response after risk adapted proton beam therapy', 0.0),
#  ('of adverse events in this context proton beam therapy', 0.0),
#  ('of bone marrow transplantation bmt and period blood transfusion', 0.0),
#  ('of cd4 + cd45ro + peripheral blood t lymphoblasts', 0.0),
#  ('of documenting value in oncological increasing proton beam radiotherapy',
#   0.0),
#  ('of grinded particles of polystyrene ps 28 polybutylene terephthalate', 0.0),
#  ('of particles therapy chiefly comprised of proton beam therapy', 0.0),
#  ('of what is current be term polyamine blocking therapy', 0.0),
#  ('pa12 19 pmma ps 20 and recently polybutylene terephthalate', 0.0),
#  ('paired samples of sln metastasis and primary breast tumor', 0.0),
#  ('pbt 1 a synthetic c9 substituted phenanthrene based tylophorine', 0.0),
#  ('pfa in pbs + 0 2 triton x 100', 0.0),
#  ...]

# %%
longforms0 = miners['PBT'].get_longforms()

# %%
list(enumerate(longforms0))
# Out:
# [(0, ('proton beam therapy', 56.793103448275865)),
#  (1, ('perioperative blood transfusion', 8.76923076923077)),
#  (2, ('terephthalate', 8.470588235294118)),
#  (3, ('peripheral blood t cells', 7.777777777777778)),
#  (4, ('peripheral blood t', 4.285714285714286)),
#  (5, ('payback times', 2.0))]

# %%
longforms0 = [(longform, score) for i, (longform, score) in enumerate(longforms0)
              if i not in [2]]

# %%
list(enumerate(top))
# Out:
# [(0, ('proton beam therapy', 56.793103448275865)),
#  (1, ('therapy', 18.281690140845072)),
#  (2, ('of proton beam therapy', 8.90909090909091)),
#  (3, ('perioperative blood transfusion', 8.76923076923077)),
#  (4, ('terephthalate', 8.470588235294118)),
#  (5, ('polybutylene terephthalate', 8.0)),
#  (6, ('peripheral blood t cells', 7.777777777777778)),
#  (7, ('of perioperative blood transfusion', 5.142857142857142)),
#  (8, ('poly butylene terephthalate', 5.0)),
#  (9, ('peripheral blood t', 4.285714285714286)),
#  (10, ('with proton beam therapy', 4.285714285714286)),
#  (11, ('butylene terephthalate', 3.0)),
#  (12, ('human peripheral blood t', 3.0)),
#  (13, ('treated with proton beam therapy', 3.0)),
#  (14, ('payback times', 2.0)),
#  (15, ('polyamine blockade therapy', 2.0)),
#  (16, ('and proton beam therapy', 2.0)),
#  (17, ('by proton beam therapy', 2.0)),
#  (18, ('using proton beam therapy', 2.0)),
#  (19, ('efficacy of proton beam therapy', 2.0)),
#  (20, ('imrt or proton beam therapy', 2.0)),
#  (21, ('transfusion', 1.8666666666666671)),
#  (22, ('blood transfusion', 1.8571428571428577)),
#  (23, ('times', 1.5)),
#  (24, ('benefits of proton beam therapy', 1.3333333333333333)),
#  (25, ('effect of perioperative blood transfusion', 1.3333333333333333)),
#  (26, ('brachytherapy', 1.0)),
#  (27, ('polymer', 1.0)),
#  (28, ('radiotherapy', 1.0)),
#  (29, ('test', 1.0)),
#  (30, ('translocation', 1.0)),
#  (31, ('tumor', 1.0)),
#  (32, ('papilla based thickness', 1.0)),
#  (33, ('platinum based therapy', 1.0)),
#  (34, ('polyamine blocking therapy', 1.0)),
#  (35, ('0 1 tween 20', 1.0)),
#  (36, ('additionally proton beam therapy', 1)),
#  (37, ('that proton beam therapy', 1.0)),
#  (38, ('the phenacetin breath test', 1)),
#  (39, ('a novel polyamine blocker therapy', 1.0)),
#  (40, ('human peripheral blood t cells', 1.0)),
#  (41, ('poly 1 4 butylene terephthalate', 1.0)),
#  (42, ('risk adapted proton beam therapy', 1.0)),
#  (43, ('we compared proton beam therapy', 1)),
#  (44, ('freshly isolated human peripheral blood t', 1)),
#  (45, ('the effect of perioperative blood transfusion', 1.0)),
#  (46, ('the efficacy of proton beam therapy', 1)),
#  (47, ('the relationship between perioperative blood transfusion', 1)),
#  (48, ('the role of proton beam therapy', 1)),
#  (49, ('high performed poly 1 4 butylene terephthalate', 1)),
#  (50, ('it was report that proton beam therapy', 1)),
#  (51, ('long term efficacy of proton beam therapy', 1)),
#  (52, ('normal liver sparing with proton beam therapy', 1)),
#  (53, ('patients level benefits of proton beam therapy', 1.0)),
#  (54, ('background to investigate the impact of proton radiotherapy', 1)),
#  (55,
#   ('the induced immunosuppressive effect of perioperative blood transfusion',
#    1)),
#  (56, ('to compared clinical outcomes between proton beam therapy', 1)),
#  (57, ('to investigate the associated of perioperative blood transfusion', 1)),
#  (58, ('while the receipt of a perioperative blood transfusion', 1)),
#  (59,
#   ('intensity modulated radiation therapy imrt and proton beam therapy', 1.0)),
#  (60,
#   ('conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#    1.0)),
#  (61, ('to evaluate the role of risk adapted proton beam therapy', 1)),
#  (62,
#   ('aromatic polyesters including poly ethylene terephthalate pet and poly butylene terephthalate',
#    1)),
#  (63,
#   ('second order two component reactions chemical structures of polymer polybutylene terephthalate',
#    1)),
#  (64,
#   ('this study documenting the utilization and efficacy of proton beam therapy',
#    1)),
#  (65,
#   ('to evaluate the impact of preoperative anemia and perioperative blood transfusion',
#    1)),
#  (66,
#   ('a number of study have investigate the effect of perioperative blood transfusion',
#    1)),
#  (67,
#   ('atients who undergo surgical treatment for malignancy often receive perioperative blood transfusion',
#    1)),
#  (68,
#   ('blends particles for selective laser sintering sls is demonstrate for polybutylene terephthalate',
#    1)),
#  (69,
#   ('ex bmi preoperative hemoglobin and creatinine level receipt of perioperative blood transfusion',
#    1)),
#  (70,
#   ('l intestine to the liver whereas isoproterenol treated mice demonstrate pathological translocation',
#    1)),
#  (71,
#   ('presence of advanced chronic liver disease and culminates in pathological bacterial translocation',
#    1)),
#  (72,
#   ('teractions between lymphocytes and human gingival fibroblasts hgf peripheral blood t lymphocytes',
#    1)),
#  (73,
#   ('umerical models of these experiments blends of glass fiber reinforced polybutylene terephthalate',
#    1)),
#  (74,
#   ('utuc who undergo radical nephroureterectomy rnu the effect of perioperative blood transfusion',
#    1)),
#  (75,
#   ('39 40 41 accordingly task specific training such as perturbation based balance training',
#    1)),
#  (76,
#   ('8 another interesting application of what is current be term polyamine blocking therapy',
#    1)),
#  (77,
#   ('can be treated with a variety of treatment modalities including activated surveillance brachytherapy',
#    1)),
#  (78,
#   ('ell source for therapy remain quiescence so proliferation is rare while photobiomodulation therapy',
#    1)),
#  (79,
#   ('es such as nylon polyesters e g polyethylene terephthalate pet and polybutylene terephthalate',
#    1)),
#  (80,
#   ('experimental or control group respectively of physical therapy treatment the prone bridge test',
#    1)),
#  (81,
#   ('ion induced lymphopenia between intensity modulated radiation therapy imrt or proton beam therapy',
#    1)),
#  (82,
#   ('lame retardancy on the dripping behaviour of four commercial polymer poly butylene terephthalate',
#    1)),
#  (83,
#   ('ontrolled trials should be the preferred evidence based investigate regarding proton beam therapy',
#    1)),
#  (84,
#   ('ould not induced proliferation but suppressed proliferation of alloreactive peripheral blood t cells',
#    1)),
#  (85,
#   ('puncture technique was using to assess fibrinolytic hemorrhage 20 22 primary bleeding times',
#    1)),
#  (86,
#   ('r example the rounding of grinded particles of polystyrene ps 28 polybutylene terephthalate',
#    1)),
#  (87,
#   ('represents intensity modulated radiation therapy imrt and red line represents proton beam therapy',
#    1)),
#  (88,
#   ('sed mortality risk 1 2 similar the adverse correlation of perioperative blood transfusion',
#    1)),
#  (89,
#   ('simetric plans using conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#    1)),
#  (90,
#   ('to tertiary reactive blends the subject of the current investigate is polybutylene terephthalate',
#    1)),
#  (91,
#   ('zed standardized outcomes and times driven activated based costs tdabc for prostate brachytherapy',
#    1)),
#  (92,
#   ('bt represents a significant public health problem an increasing incidence in primary brain tumor',
#    1)),
#  (93,
#   ('by reduce the radiation dose to the bone surrounding the eye proton beam therapy',
#    1)),
#  (94,
#   ('c of the bladder on the oncological prognosis and additionally on perioperative blood transfusion',
#    1)),
#  (95,
#   ('cw clinical crown width dw diastema width pbt papilla based thickness papilla based thickness',
#    1)),
#  (96,
#   ('d normal tissue complication probability ntcp models in patients treated with proton beam therapy',
#    1)),
#  (97,
#   ('e this study examine outcomes of bone marrow transplantation bmt and period blood transfusion',
#    1)),
#  (98,
#   ('ed function of irradiation organs and retardancy growth are significant problem proton beam therapy',
#    1)),
#  (99,
#   ('ial hypotheses for further study and for establishing new treatment strategies proton beam therapy',
#    1)),
#  (100,
#   ('in apparent diffusion coefficient adc value of ocular melanoma treated with proton beam therapy',
#    1)),
#  (101,
#   ('ing to irradiation large owing to anatomic location and associated toxicities proton beam therapy',
#    1)),
#  (102,
#   ('iomas the most common benign and malignancy primary brain tumor respectively proton beam therapy',
#    1)),
#  (103,
#   ('iotherapy imrt reduce side effect compared to older technique but whether proton beam therapy',
#    1)),
#  (104,
#   ('it has been believed that the fas expression on human peripheral blood t cells',
#    1)),
#  (105,
#   ('ivities we previous showed that pbt 1 a synthetic c9 substituted phenanthrene based tylophorine',
#    1)),
#  (106,
#   ('lated radiation therapy imrt however the superior dose profiles provided by proton beam therapy',
#    1)),
#  (107,
#   ('mation and ex vivo prostaglandin inactivation were study in the ethanol etoh and phenylbutazone',
#    1)),
#  (108,
#   ('ncer care rise the import of documenting value in oncological increasing proton beam radiotherapy',
#    1)),
#  (109,
#   ('o be substantially different compared photon therapy to charged particles like proton beam therapy',
#    1)),
#  (110,
#   ('or some treatment modalities such as intensity modulated radiotherapy imrt or proton beam therapy',
#    1)),
#  (111,
#   ('owing to the superior dimensional stability and heat resistance poly 1 4 butylene terephthalate',
#    1)),
#  (112,
#   ('pf peach flowers and it subfractions particularly the ethylacetate pea and n butanol extract',
#    1)),
#  (113,
#   ('red the potential of conformal radiotherapy crt helical tomotherapy ht and proton beam therapy',
#    1)),
#  (114,
#   ('study demonstrate that upon activated monocytes mo were able to sensitize peripheral blood t',
#    1)),
#  (115,
#   ('t technique was compared with intensity modulated radiation therapy imrt and proton beam therapy',
#    1)),
#  (116,
#   ('the aim of our study was to assess the influence of perioperative blood transfusion',
#    1)),
#  (117,
#   ('the upregulated import of polyamine into the tumor we demonstrate that polyamine blockade therapy',
#    1)),
#  (118,
#   ('tion even to irregularly shaped target volume compared with 3d radiotherapy proton beam therapy',
#    1)),
#  (119,
#   ('tion to improve perioperative haemostasis and diminish the need for allogeneic red cells transfusion',
#    1)),
#  (120,
#   ('to report quality of life qol toxicities in men treated with proton beam therapy',
#    1)),
#  (121,
#   ('using of advanced rt technique intensity modulated radiation therapy imrt and proton beam therapy',
#    1)),
#  (122,
#   ('0l in plasma and supernatants of freshly isolated platelets and autologous peripheral blood t cells',
#    1)),
#  (123,
#   ('182 183 184 185 nylon 6 6 182 pva 186 pan 187 poly butylene terephthalate',
#    1)),
#  (124,
#   ('and poorter 1994 cc p total maintenance costs mc specific leaf area sla payback times',
#    1)),
#  (125,
#   ('atistically significant a 6 3 cm hepatocellular carcinoma hcc was treated by proton beam therapy',
#    1)),
#  (126,
#   ('d before orthodontic treatment on the alterations of papilla height ph and papilla based thickness',
#    1)),
#  (127,
#   ('f cd45 + inflammatory cells in disaggregated viable tumor cells treatment with dfmo and amxt1501',
#    1)),
#  (128,
#   ('his study is to retrospectively evaluate the incidence of lung toxicities after proton beam therapy',
#    1)),
#  (129,
#   ('ine biosynthesis as well as polyamine transport must be achieved a novel polyamine blocker therapy',
#    1)),
#  (130,
#   ('ine by the kaplan meier method due to unique dose deposition characteristics proton beam therapy',
#    1)),
#  (131,
#   ('ion of alveolar gas into the circulation one of the critical complication of pulmonary barotrauma',
#    1)),
#  (132,
#   ('l and extracranial location 7 11 dose sculpting was further enhanced by proton beam therapy',
#    1)),
#  (133,
#   ('n strategies can exert antitumor effect that may also promote immune a polyamine blocking therapy',
#    1)),
#  (134,
#   ('of lung tissue we have characterized the migration of t lymphocytes isolated from peripheral blood',
#    1)),
#  (135,
#   ('of pa12 hdpe 17 18 pa6 pa12 19 pmma ps 20 and recently polybutylene terephthalate',
#    1)),
#  (136,
#   ('ogistically challenging to circumvent this limitation a non powered co 2 baited passive box trap',
#    1)),
#  (137,
#   ('ora to starve neoplastic lesions of polyamine we have employed a novel polyamine blocker therapy',
#    1)),
#  (138,
#   ('re similar to those of photon with no apparent clinical advantage therefore proton beam therapy',
#    1)),
#  (139,
#   ('safety of a spot scanning dedicated small 360 degree gantry synchrotron based proton beam therapy',
#    1)),
#  (140,
#   ('to this extent the emerging modalities of particles therapy chiefly comprised of proton beam therapy',
#    1)),
#  (141,
#   ('ure that should be considered karagatzides and ellison 2009 in this context the payback times',
#    1)),
#  (142,
#   ('with other lrts the cases showed objective tumor response after risk adapted proton beam therapy',
#    1)),
#  (143,
#   ('℃ the lyophilized ethanol extract of ppf pet ethylacetate fraction pea and n butanol fraction',
#    1)),
#  (144,
#   ('acute radiation dermatitis ard is one of the most common adverse events of proton beam therapy',
#    1)),
#  (145,
#   ('asible but further study on it long term safety and efficacy are warranted proton beam therapy',
#    1)),
#  (146,
#   ('at deal of attention over the past 30 years has centered on whether perioperative blood transfusion',
#    1)),
#  (147,
#   ('ated arc therapy vmat with linear accelerators as well as the developed of proton beam therapy',
#    1)),
#  (148,
#   ('based reimbursement system a relative lack of costs effect in the using of proton beam therapy',
#    1)),
#  (149,
#   ('end of the bragg peak 12 which under the better dose distribution with proton beam therapy',
#    1)),
#  (150,
#   ('eted radical irradiation 8 9 based on this unique property we first using proton beam therapy',
#    1)),
#  (151,
#   ('hat are essential for their growth and survival we have developed a new polyamine blockade therapy',
#    1)),
#  (152,
#   ('in the tumor microenvironment but to which cells should til be compared peripheral blood t cells',
#    1)),
#  (153,
#   ('ion at present an increasing number of lung cancer patients are treated using proton beam therapy',
#    1)),
#  (154,
#   ('light the urgent need for prospective data using pbt patients level benefits of proton beam therapy',
#    1)),
#  (155,
#   ('ol especially in the spine using photon this however can be achieved with proton beam therapy',
#    1)),
#  (156,
#   ('on to silver nanoparticles ag nps on the surface give rise to a homogeneous bithiophene polymer',
#    1)),
#  (157,
#   ('s between a polymer and an adhesion the samples employed in this work is polybutylene terephtharate',
#    1)),
#  (158,
#   ('sponse on imaging 4 how does sbrt compared to other ldt modalities including proton beam therapy',
#    1)),
#  (159,
#   ('te the amount that radiation induced secondary cancer would be reduce by using proton beam therapy',
#    1)),
#  (160,
#   ('these patients may be considered for system therapy along with sbrt 39 41 proton beam therapy',
#    1)),
#  (161,
#   ('tment in the majority of patients with recurrent and or metastatic hnc with platinum based therapy',
#    1)),
#  (162,
#   ('to be an import factor from an esthetic perspective facio lingual thickness of the papilla based',
#    1)),
#  (163,
#   ('was added when til were using in cytokines detection assay after recovery peripheral blood t cells',
#    1)),
#  (164,
#   ('y activated an immune attack on these tumor to evaluate the effect of polyamine blockade therapy',
#    1)),
#  (165,
#   ('article size x 50 3 and span on process times during co comminution of a polybutylene terephthalate',
#    1)),
#  (166,
#   ('assay were performed in a group of 37 paired samples of sln metastasis and primary breast tumor',
#    1)),
#  (167,
#   ('cells are susceptible to these mabs 17 18 a large fraction of the peripheral blood t cells',
#    1)),
#  (168,
#   ('he additionally of mgo after melt annealing for 45 min at 237 ° c calculated polybutylene terephthalate',
#    1)),
#  (169,
#   ('identify by flow cytometry the murine t cells clone 7139 and cd3 stimulated human peripheral blood t',
#    1)),
#  (170,
#   ('ies and flame retardancy of a nano sb₂o₃ ⁻ brominated epoxy resin beo ⁻ poly butylene terephthalate',
#    1)),
#  (171,
#   ('in brief 2 h fixed embryos were permeabilized by a methanol phosphate buffered saline 0 1 tween',
#    1)),
#  (172,
#   ('on of acute mucositis reduction of auc of 0 17 the models overall performed well the validation',
#    1)),
#  (173,
#   ('on the role of rt modalities using photon based intensity modulated rt imrt or proton beam therapy',
#    1)),
#  (174,
#   ('r eap might interfere with t cells recruitment we first examine the adhesion of peripheral blood t',
#    1)),
#  (175,
#   ('s e g in automotive as custom made fuel manifolds in racing cars the semi crystalline polymer',
#    1)),
#  (176,
#   ('s in this study we characterized the expression and function of trail on human peripheral blood t',
#    1)),
#  (177,
#   ('simple and robust method to reduce the rate of adverse events in this context proton beam therapy',
#    1)),
#  (178,
#   ('t al 1987 cc w and poorter 1994 cc p total maintenance costs mc and payback times',
#    1)),
#  (179,
#   ('t is difficult to achieved a sufficient irradiation dose to treated hcc 5 6 proton beam therapy',
#    1)),
#  (180,
#   ('th the amount of flame retardancy added tga under n 2 mass of a poly butylene terephthalate',
#    1)),
#  (181,
#   ('thout exit dose to outside of the target volume our previous study showed that proton beam therapy',
#    1)),
#  (182,
#   ('ty in this study we investigate the expression and function of trail in human peripheral blood t',
#    1)),
#  (183,
#   ('crt for esophageal cancer the aim of this study was to examine the benefits of proton beam therapy',
#    1)),
#  (184,
#   ('l was several depressed on average ∼ 7 times smaller in til compared with peripheral blood t cells',
#    1)),
#  (185,
#   ('rgans we conducted a quality of life qol study for ccs who were treated with proton beam therapy',
#    1)),
#  (186,
#   ('the tyrosine kinase p56lck from 56 kda to apparent 60 kda in resting human peripheral blood t cells',
#    1)),
#  (187,
#   ('y a role in the t cells dysfunction of cancer patients in multiple myeloma mm peripheral blood t',
#    1)),
#  (188,
#   ('ml for more than 8 days to obtain a population of cd4 + cd45ro + peripheral blood t lymphoblasts',
#    1)),
#  (189,
#   ('s and don t reduce average dose to the brain compared with 3d crt in contrast proton beam therapy',
#    1)),
#  (190,
#   ('cold pbs and fixed o n in 4 paraformaldehyde pfa pbs after several washes in pbs 0 1 tween 20',
#    1)),
#  (191,
#   ('a 1 h recovery period eye disks were dissected followed by blocking for 4 h in pbs + 0 1 tween 20',
#    1)),
#  (192,
#   ('o mi rna 155 il 2 and ifn γ are down regulated by tgf β in activated cd4 peripheral blood t cells',
#    1)),
#  (193,
#   ('e 36 in brief proboscides were dissected and fixed for 20 min in 4 pfa in pbs + 0 2 triton x 100',
#    1)),
#  (194,
#   ('l min − 1 nitrogen flow or 30 ml min − 1 synthetic air flow respectively then 5 ± 0 1 mg samples',
#    1)),
#  (195, ('100', 0.0)),
#  (196, ('20', 0.0)),
#  (197, ('amxt1501', 0.0)),
#  (198, ('barotrauma', 0.0)),
#  (199, ('based', 0.0)),
#  (200, ('blood', 0.0)),
#  (201, ('cells', 0.0)),
#  (202, ('extract', 0.0)),
#  (203, ('fraction', 0.0)),
#  (204, ('lymphoblasts', 0.0)),
#  (205, ('lymphocytes', 0.0)),
#  (206, ('phenylbutazone', 0.0)),
#  (207, ('samples', 0.0)),
#  (208, ('t', 0.0)),
#  (209, ('terephtharate', 0.0)),
#  (210, ('thickness', 0.0)),
#  (211, ('training', 0.0)),
#  (212, ('trap', 0.0)),
#  (213, ('tween', 0.0)),
#  (214, ('tylophorine', 0.0)),
#  (215, ('validation', 0.0)),
#  (216, ('1 tween', 0.0)),
#  (217, ('and amxt1501', 0.0)),
#  (218, ('and phenylbutazone', 0.0)),
#  (219, ('bacterial translocation', 0.0)),
#  (220, ('balance training', 0.0)),
#  (221, ('based therapy', 0.0)),
#  (222, ('based thickness', 0.0)),
#  (223, ('based tylophorine', 0.0)),
#  (224, ('beam radiotherapy', 0.0)),
#  (225, ('beam therapy', 0.0)),
#  (226, ('bithiophene polymer', 0.0)),
#  (227, ('bleeding times', 0.0)),
#  (228, ('blocking therapy', 0.0)),
#  (229, ('blockade therapy', 0.0)),
#  (230, ('blocker therapy', 0.0)),
#  (231, ('blood t', 0.0)),
#  (232, ('box trap', 0.0)),
#  (233, ('brain tumor', 0.0)),
#  (234, ('breast tumor', 0.0)),
#  (235, ('breath test', 0.0)),
#  (236, ('bridge test', 0.0)),
#  (237, ('butanol extract', 0.0)),
#  (238, ('butanol fraction', 0.0)),
#  (239, ('cells transfusion', 0.0)),
#  (240, ('crystalline polymer', 0.0)),
#  (241, ('mg samples', 0.0)),
#  (242, ('papilla based', 0.0)),
#  (243, ('pathological translocation', 0.0)),
#  (244, ('peripheral blood', 0.0)),
#  (245, ('photobiomodulation therapy', 0.0)),
#  (246, ('polybutylene terephtharate', 0.0)),
#  (247, ('prostate brachytherapy', 0.0)),
#  (248, ('proton radiotherapy', 0.0)),
#  (249, ('pulmonary barotrauma', 0.0)),
#  (250, ('surveillance brachytherapy', 0.0)),
#  (251, ('t cells', 0.0)),
#  (252, ('t lymphoblasts', 0.0)),
#  (253, ('t lymphocytes', 0.0)),
#  (254, ('the validation', 0.0)),
#  (255, ('tween 20', 0.0)),
#  (256, ('x 100', 0.0)),
#  (257, ('0 1 tween', 0.0)),
#  (258, ('1 mg samples', 0.0)),
#  (259, ('1 tween 20', 0.0)),
#  (260, ('28 polybutylene terephthalate', 0.0)),
#  (261, ('4 butylene terephthalate', 0.0)),
#  (262, ('a polybutylene terephthalate', 0.0)),
#  (263, ('activated surveillance brachytherapy', 0.0)),
#  (264, ('and payback times', 0.0)),
#  (265, ('and polybutylene terephthalate', 0.0)),
#  (266, ('based balance training', 0.0)),
#  (267, ('blood t cells', 0.0)),
#  (268, ('blood t lymphoblasts', 0.0)),
#  (269, ('blood t lymphocytes', 0.0)),
#  (270, ('calculated polybutylene terephthalate', 0.0)),
#  (271, ('demonstrate pathological translocation', 0.0)),
#  (272, ('dfmo and amxt1501', 0.0)),
#  (273, ('etoh and phenylbutazone', 0.0)),
#  (274, ('for polybutylene terephthalate', 0.0)),
#  (275, ('for prostate brachytherapy', 0.0)),
#  (276, ('from peripheral blood', 0.0)),
#  (277, ('homogeneous bithiophene polymer', 0.0)),
#  (278, ('is polybutylene terephthalate', 0.0)),
#  (279, ('is polybutylene terephtharate', 0.0)),
#  (280, ('n butanol extract', 0.0)),
#  (281, ('n butanol fraction', 0.0)),
#  (282, ('of proton radiotherapy', 0.0)),
#  (283, ('of pulmonary barotrauma', 0.0)),
#  (284, ('passive box trap', 0.0)),
#  (285, ('pathological bacterial translocation', 0.0)),
#  (286, ('period blood transfusion', 0.0)),
#  (287, ('phenacetin breath test', 0.0)),
#  (288, ('phenanthrene based tylophorine', 0.0)),
#  (289, ('polyamine blocker therapy', 0.0)),
#  (290, ('polymer polybutylene terephthalate', 0.0)),
#  (291, ('primary bleeding times', 0.0)),
#  (292, ('primary brain tumor', 0.0)),
#  (293, ('primary breast tumor', 0.0)),
#  (294, ('prone bridge test', 0.0)),
#  (295, ('proton beam radiotherapy', 0.0)),
#  (296, ('recently polybutylene terephthalate', 0.0)),
#  (297, ('red cells transfusion', 0.0)),
#  (298, ('reinforced polybutylene terephthalate', 0.0)),
#  (299, ('semi crystalline polymer', 0.0)),
#  (300, ('sla payback times', 0.0)),
#  (301, ('the papilla based', 0.0)),
#  (302, ('the payback times', 0.0)),
#  (303, ('triton x 100', 0.0)),
#  (304, ('well the validation', 0.0)),
#  (305, ('while photobiomodulation therapy', 0.0)),
#  (306, ('0 1 mg samples', 0.0)),
#  (307, ('1 4 butylene terephthalate', 0.0)),
#  (308, ('187 poly butylene terephthalate', 0.0)),
#  (309, ('2 triton x 100', 0.0)),
#  (310, ('22 primary bleeding times', 0.0)),
#  (311, ('41 proton beam therapy', 0.0)),
#  (312, ('6 proton beam therapy', 0.0)),
#  (313, ('a homogeneous bithiophene polymer', 0.0)),
#  (314, ('a perioperative blood transfusion', 0.0)),
#  (315, ('a poly butylene terephthalate', 0.0)),
#  (316, ('a polyamine blocking therapy', 0.0)),
#  (317, ('adapted proton beam therapy', 0.0)),
#  (318, ('after proton beam therapy', 0.0)),
#  (319, ('allogeneic red cells transfusion', 0.0)),
#  (320, ('and n butanol extract', 0.0)),
#  (321, ('and n butanol fraction', 0.0)),
#  (322, ('and papilla based thickness', 0.0)),
#  (323, ('and period blood transfusion', 0.0)),
#  (324, ('and perioperative blood transfusion', 0.0)),
#  (325, ('and poly butylene terephthalate', 0.0)),
#  (326, ('and primary breast tumor', 0.0)),
#  (327, ('and recently polybutylene terephthalate', 0.0)),
#  (328, ('area sla payback times', 0.0)),
#  (329, ('baited passive box trap', 0.0)),
#  (330, ('based proton beam therapy', 0.0)),
#  (331, ('between perioperative blood transfusion', 0.0)),
#  (332, ('between proton beam therapy', 0.0)),
#  (333, ('c calculated polybutylene terephthalate', 0.0)),
#  (334, ('characteristics proton beam therapy', 0.0)),
#  (335, ('compared proton beam therapy', 0.0)),
#  (336, ('complication of pulmonary barotrauma', 0.0)),
#  (337, ('context proton beam therapy', 0.0)),
#  (338, ('context the payback times', 0.0)),
#  (339, ('contrast proton beam therapy', 0.0)),
#  (340, ('demonstrate for polybutylene terephthalate', 0.0)),
#  (341, ('ethanol etoh and phenylbutazone', 0.0)),
#  (342, ('eye proton beam therapy', 0.0)),
#  (343, ('fiber reinforced polybutylene terephthalate', 0.0)),
#  (344, ('impact of proton radiotherapy', 0.0)),
#  (345, ('in pathological bacterial translocation', 0.0)),
#  (346, ('in primary brain tumor', 0.0)),
#  (347, ('including activated surveillance brachytherapy', 0.0)),
#  (348, ('including proton beam therapy', 0.0)),
#  (349, ('increasing proton beam radiotherapy', 0.0)),
#  (350, ('investigate is polybutylene terephthalate', 0.0)),
#  (351, ('isolated from peripheral blood', 0.0)),
#  (352, ('like proton beam therapy', 0.0)),
#  (353, ('mc and payback times', 0.0)),
#  (354, ('mice demonstrate pathological translocation', 0.0)),
#  (355, ('mm peripheral blood t', 0.0)),
#  (356, ('new polyamine blockade therapy', 0.0)),
#  (357, ('novel polyamine blocker therapy', 0.0)),
#  (358, ('of a polybutylene terephthalate', 0.0)),
#  (359, ('of peripheral blood t', 0.0)),
#  (360, ('of polyamine blockade therapy', 0.0)),
#  (361, ('of polymer polybutylene terephthalate', 0.0)),
#  (362, ('of the papilla based', 0.0)),
#  (363, ('on perioperative blood transfusion', 0.0)),
#  (364, ('or proton beam therapy', 0.0)),
#  (365, ('performed well the validation', 0.0)),
#  (366, ('peripheral blood t lymphoblasts', 0.0)),
#  (367, ('peripheral blood t lymphocytes', 0.0)),
#  (368, ('perturbation based balance training', 0.0)),
#  (369, ('pet and polybutylene terephthalate', 0.0)),
#  (370, ('polymer poly butylene terephthalate', 0.0)),
#  (371, ('problem proton beam therapy', 0.0)),
#  (372, ('ps 28 polybutylene terephthalate', 0.0)),
#  (373, ('radiotherapy proton beam therapy', 0.0)),
#  (374, ('rare while photobiomodulation therapy', 0.0)),
#  (375, ('receive perioperative blood transfusion', 0.0)),
#  (376, ('regarding proton beam therapy', 0.0)),
#  (377, ('represents proton beam therapy', 0.0)),
#  (378, ('respectively proton beam therapy', 0.0)),
#  (379, ('saline 0 1 tween', 0.0)),
#  (380, ('sensitize peripheral blood t', 0.0)),
#  (381, ('strategies proton beam therapy', 0.0)),
#  (382, ('substituted phenanthrene based tylophorine', 0.0)),
#  (383, ('tdabc for prostate brachytherapy', 0.0)),
#  (384, ('term polyamine blocking therapy', 0.0)),
#  (385, ('that polyamine blockade therapy', 0.0)),
#  (386, ('the prone bridge test', 0.0)),
#  (387, ('the semi crystalline polymer', 0.0)),
#  (388, ('therefore proton beam therapy', 0.0)),
#  (389, ('thickness papilla based thickness', 0.0)),
#  (390, ('toxicities proton beam therapy', 0.0)),
#  (391, ('warranted proton beam therapy', 0.0)),
#  (392, ('whether perioperative blood transfusion', 0.0)),
#  (393, ('whether proton beam therapy', 0.0)),
#  (394, ('with dfmo and amxt1501', 0.0)),
#  (395, ('with platinum based therapy', 0.0)),
#  (396, ('work is polybutylene terephtharate', 0.0)),
#  (397, ('⁻ poly butylene terephthalate', 0.0)),
#  (398, ('+ 0 1 tween 20', 0.0)),
#  (399, ('+ peripheral blood t lymphoblasts', 0.0)),
#  (400, ('0 2 triton x 100', 0.0)),
#  (401, ('2 baited passive box trap', 0.0)),
#  (402, ('20 22 primary bleeding times', 0.0)),
#  (403, ('20 and recently polybutylene terephthalate', 0.0)),
#  (404, ('39 41 proton beam therapy', 0.0)),
#  (405, ('3d radiotherapy proton beam therapy', 0.0)),
#  (406, ('5 6 proton beam therapy', 0.0)),
#  (407, ('a new polyamine blockade therapy', 0.0)),
#  (408, ('achieved with proton beam therapy', 0.0)),
#  (409, ('additionally on perioperative blood transfusion', 0.0)),
#  (410, ('adhesion of peripheral blood t', 0.0)),
#  (411, ('advantage therefore proton beam therapy', 0.0)),
#  (412, ('alloreactive peripheral blood t cells', 0.0)),
#  (413, ('anemia and perioperative blood transfusion', 0.0)),
#  (414, ('are warranted proton beam therapy', 0.0)),
#  (415, ('as perturbation based balance training', 0.0)),
#  (416, ('associated of perioperative blood transfusion', 0.0)),
#  (417, ('associated toxicities proton beam therapy', 0.0)),
#  (418, ('autologous peripheral blood t cells', 0.0)),
#  (419, ('based thickness papilla based thickness', 0.0)),
#  (420, ('be term polyamine blocking therapy', 0.0)),
#  (421, ('beo ⁻ poly butylene terephthalate', 0.0)),
#  (422, ('bmt and period blood transfusion', 0.0)),
#  (423, ('buffered saline 0 1 tween', 0.0)),
#  (424, ('but whether proton beam therapy', 0.0)),
#  (425, ('by using proton beam therapy', 0.0)),
#  (426, ('c9 substituted phenanthrene based tylophorine', 0.0)),
#  (427, ('cars the semi crystalline polymer', 0.0)),
#  (428, ('cd4 peripheral blood t cells', 0.0)),
#  (429, ('commercial polymer poly butylene terephthalate', 0.0)),
#  (430, ('comminution of a polybutylene terephthalate', 0.0)),
#  (431, ('compared peripheral blood t cells', 0.0)),
#  (432, ('comprised of proton beam therapy', 0.0)),
#  (433, ('correlation of perioperative blood transfusion', 0.0)),
#  (434, ('costs mc and payback times', 0.0)),
#  (435, ('costs tdabc for prostate brachytherapy', 0.0)),
#  (436, ('critical complication of pulmonary barotrauma', 0.0)),
#  (437, ('culminates in pathological bacterial translocation', 0.0)),
#  (438, ('current investigate is polybutylene terephthalate', 0.0)),
#  (439, ('demonstrate that polyamine blockade therapy', 0.0)),
#  (440, ('deposition characteristics proton beam therapy', 0.0)),
#  (441, ('developed of proton beam therapy', 0.0)),
#  (442, ('distribution with proton beam therapy', 0.0)),
#  (443, ('effect of polyamine blockade therapy', 0.0)),
#  (444, ('enhanced by proton beam therapy', 0.0)),
#  (445, ('events of proton beam therapy', 0.0)),
#  (446, ('first using proton beam therapy', 0.0)),
#  (447, ('for allogeneic red cells transfusion', 0.0)),
#  (448, ('glass fiber reinforced polybutylene terephthalate', 0.0)),
#  (449, ('hgf peripheral blood t lymphocytes', 0.0)),
#  (450, ('hnc with platinum based therapy', 0.0)),
#  (451, ('ht and proton beam therapy', 0.0)),
#  (452, ('immune a polyamine blocking therapy', 0.0)),
#  (453, ('imrt and proton beam therapy', 0.0)),
#  (454, ('in contrast proton beam therapy', 0.0)),
#  (455, ('in human peripheral blood t', 0.0)),
#  (456, ('incidence in primary brain tumor', 0.0)),
#  (457, ('influence of perioperative blood transfusion', 0.0)),
#  (458, ('investigate regarding proton beam therapy', 0.0)),
#  (459, ('is demonstrate for polybutylene terephthalate', 0.0)),
#  (460, ('is rare while photobiomodulation therapy', 0.0)),
#  (461, ('isolated human peripheral blood t', 0.0)),
#  (462, ('leaf area sla payback times', 0.0)),
#  (463, ('line represents proton beam therapy', 0.0)),
#  (464, ('lymphocytes isolated from peripheral blood', 0.0)),
#  (465, ('metastasis and primary breast tumor', 0.0)),
#  (466, ('modalities including activated surveillance brachytherapy', 0.0)),
#  (467, ('modalities including proton beam therapy', 0.0)),
#  (468, ('myeloma mm peripheral blood t', 0.0)),
#  (469, ('of a perioperative blood transfusion', 0.0)),
#  (470, ('of a poly butylene terephthalate', 0.0)),
#  (471, ('often receive perioperative blood transfusion', 0.0)),
#  (472, ('on human peripheral blood t', 0.0)),
#  (473, ('on whether perioperative blood transfusion', 0.0)),
#  (474, ('oncological increasing proton beam radiotherapy', 0.0)),
#  (475, ('outcomes between proton beam therapy', 0.0)),
#  (476, ('overall performed well the validation', 0.0)),
#  (477, ('pan 187 poly butylene terephthalate', 0.0)),
#  (478, ('particles like proton beam therapy', 0.0)),
#  (479, ('pbs 0 1 tween 20', 0.0)),
#  (480, ('pea and n butanol extract', 0.0)),
#  (481, ('pea and n butanol fraction', 0.0)),
#  (482, ('pet and poly butylene terephthalate', 0.0)),
#  (483, ('ph and papilla based thickness', 0.0)),
#  (484, ('polystyrene ps 28 polybutylene terephthalate', 0.0)),
#  (485, ('provided by proton beam therapy', 0.0)),
#  (486, ('receipt of perioperative blood transfusion', 0.0)),
#  (487, ('recovery peripheral blood t cells', 0.0)),
#  (488, ('relationship between perioperative blood transfusion', 0.0)),
#  (489, ('report that proton beam therapy', 0.0)),
#  (490, ('role of proton beam therapy', 0.0)),
#  (491, ('showed that proton beam therapy', 0.0)),
#  (492, ('significant problem proton beam therapy', 0.0)),
#  (493, ('sparing with proton beam therapy', 0.0)),
#  (494, ('stimulated human peripheral blood t', 0.0)),
#  (495, ('structures of polymer polybutylene terephthalate', 0.0)),
#  (496, ('synchrotron based proton beam therapy', 0.0)),
#  (497, ('terephthalate pet and polybutylene terephthalate', 0.0)),
#  (498, ('the ethanol etoh and phenylbutazone', 0.0)),
#  (499, ('the eye proton beam therapy', 0.0)),
#  (500, ('the impact of proton radiotherapy', 0.0)),
#  (501, ('the peripheral blood t cells', 0.0)),
#  (502, ('thickness of the papilla based', 0.0)),
#  (503, ('this context proton beam therapy', 0.0)),
#  (504, ('this context the payback times', 0.0)),
#  (505, ('this work is polybutylene terephtharate', 0.0)),
#  (506, ('to a homogeneous bithiophene polymer', 0.0)),
#  (507, ('to sensitize peripheral blood t', 0.0)),
#  (508, ('toxicities after proton beam therapy', 0.0)),
#  (509, ('treated by proton beam therapy', 0.0)),
#  (510, ('treated mice demonstrate pathological translocation', 0.0)),
#  (511, ('treated using proton beam therapy', 0.0)),
#  (512, ('treatment strategies proton beam therapy', 0.0)),
#  (513, ('treatment the prone bridge test', 0.0)),
#  (514, ('treatment with dfmo and amxt1501', 0.0)),
#  (515, ('tumor respectively proton beam therapy', 0.0)),
#  (516, ('using of proton beam therapy', 0.0)),
#  (517, ('with peripheral blood t cells', 0.0)),
#  (518, ('° c calculated polybutylene terephthalate', 0.0)),
#  (519, ('± 0 1 mg samples', 0.0)),
#  (520, ('+ 0 2 triton x 100', 0.0)),
#  (521, ('186 pan 187 poly butylene terephthalate', 0.0)),
#  (522, ('237 ° c calculated polybutylene terephthalate', 0.0)),
#  (523, ('5 ± 0 1 mg samples', 0.0)),
#  (524, ('able to sensitize peripheral blood t', 0.0)),
#  (525, ('achieved a novel polyamine blocker therapy', 0.0)),
#  (526, ('activated cd4 peripheral blood t cells', 0.0)),
#  (527, ('adverse correlation of perioperative blood transfusion', 0.0)),
#  (528, ('adverse events of proton beam therapy', 0.0)),
#  (529, ('after recovery peripheral blood t cells', 0.0)),
#  (530, ('after risk adapted proton beam therapy', 0.0)),
#  (531, ('and additionally on perioperative blood transfusion', 0.0)),
#  (532, ('and associated toxicities proton beam therapy', 0.0)),
#  (533, ('and autologous peripheral blood t cells', 0.0)),
#  (534, ('and culminates in pathological bacterial translocation', 0.0)),
#  (535, ('and efficacy of proton beam therapy', 0.0)),
#  (536, ('are significant problem proton beam therapy', 0.0)),
#  (537, ('are treated using proton beam therapy', 0.0)),
#  (538, ('based costs tdabc for prostate brachytherapy', 0.0)),
#  (539, ('based investigate regarding proton beam therapy', 0.0)),
#  (540, ('be achieved with proton beam therapy', 0.0)),
#  (541, ('be compared peripheral blood t cells', 0.0)),
#  (542, ('brain tumor respectively proton beam therapy', 0.0)),
#  (543, ('cd3 stimulated human peripheral blood t', 0.0)),
#  (544, ('cd45ro + peripheral blood t lymphoblasts', 0.0)),
#  (545, ('cells treatment with dfmo and amxt1501', 0.0)),
#  (546, ('centered on whether perioperative blood transfusion', 0.0)),
#  (547, ('charged particles like proton beam therapy', 0.0)),
#  (548, ('chemical structures of polymer polybutylene terephthalate', 0.0)),
#  (549, ('chiefly comprised of proton beam therapy', 0.0)),
#  (550, ('clinical advantage therefore proton beam therapy', 0.0)),
#  (551, ('clinical outcomes between proton beam therapy', 0.0)),
#  (552, ('co 2 baited passive box trap', 0.0)),
#  (553, ('co comminution of a polybutylene terephthalate', 0.0)),
#  (554, ('compared with peripheral blood t cells', 0.0)),
#  (555, ('crt in contrast proton beam therapy', 0.0)),
#  (556, ('current be term polyamine blocking therapy', 0.0)),
#  (557, ('developed a new polyamine blockade therapy', 0.0)),
#  (558, ('dose deposition characteristics proton beam therapy', 0.0)),
#  (559, ('dose distribution with proton beam therapy', 0.0)),
#  (560, ('efficacy are warranted proton beam therapy', 0.0)),
#  (561, ('employed a novel polyamine blocker therapy', 0.0)),
#  (562, ('ethylacetate pea and n butanol extract', 0.0)),
#  (563, ('fibroblasts hgf peripheral blood t lymphocytes', 0.0)),
#  (564, ('four commercial polymer poly butylene terephthalate', 0.0)),
#  (565, ('fraction pea and n butanol fraction', 0.0)),
#  (566, ('further enhanced by proton beam therapy', 0.0)),
#  (567, ('gantry synchrotron based proton beam therapy', 0.0)),
#  (568, ('hcc 5 6 proton beam therapy', 0.0)),
#  (569, ('height ph and papilla based thickness', 0.0)),
#  (570, ('hemorrhage 20 22 primary bleeding times', 0.0)),
#  (571, ('immunosuppressive effect of perioperative blood transfusion', 0.0)),
#  (572, ('in oncological increasing proton beam radiotherapy', 0.0)),
#  (573, ('in pbs 0 1 tween 20', 0.0)),
#  (574, ('in the ethanol etoh and phenylbutazone', 0.0)),
#  (575, ('in this context proton beam therapy', 0.0)),
#  (576, ('in this context the payback times', 0.0)),
#  (577, ('in this work is polybutylene terephtharate', 0.0)),
#  (578, ('increasing incidence in primary brain tumor', 0.0)),
#  (579, ('investigate the impact of proton radiotherapy', 0.0)),
#  (580,
#   ('isoproterenol treated mice demonstrate pathological translocation', 0.0)),
#  (581, ('ldt modalities including proton beam therapy', 0.0)),
#  (582, ('level benefits of proton beam therapy', 0.0)),
#  (583, ('level receipt of perioperative blood transfusion', 0.0)),
#  (584, ('lingual thickness of the papilla based', 0.0)),
#  (585, ('liver sparing with proton beam therapy', 0.0)),
#  (586, ('lung toxicities after proton beam therapy', 0.0)),
#  (587, ('maintenance costs mc and payback times', 0.0)),
#  (588, ('malignancy often receive perioperative blood transfusion', 0.0)),
#  (589, ('mass of a poly butylene terephthalate', 0.0)),
#  (590, ('melanoma treated with proton beam therapy', 0.0)),
#  (591, ('men treated with proton beam therapy', 0.0)),
#  (592, ('metastatic hnc with platinum based therapy', 0.0)),
#  (593, ('models overall performed well the validation', 0.0)),
#  (594, ('multiple myeloma mm peripheral blood t', 0.0)),
#  (595, ('need for allogeneic red cells transfusion', 0.0)),
#  (596, ('new treatment strategies proton beam therapy', 0.0)),
#  (597, ('of alloreactive peripheral blood t cells', 0.0)),
#  (598, ('of glass fiber reinforced polybutylene terephthalate', 0.0)),
#  (599, ('of polystyrene ps 28 polybutylene terephthalate', 0.0)),
#  (600, ('of risk adapted proton beam therapy', 0.0)),
#  (601, ('of the peripheral blood t cells', 0.0)),
#  (602, ('on human peripheral blood t cells', 0.0)),
#  (603, ('papilla based thickness papilla based thickness', 0.0)),
#  (604, ('patients treated with proton beam therapy', 0.0)),
#  (605, ('pbs + 0 1 tween 20', 0.0)),
#  (606, ('performed poly 1 4 butylene terephthalate', 0.0)),
#  (607, ('phosphate buffered saline 0 1 tween', 0.0)),
#  (608, ('polyethylene terephthalate pet and polybutylene terephthalate', 0.0)),
#  (609, ('preoperative anemia and perioperative blood transfusion', 0.0)),
#  (610, ('profiles provided by proton beam therapy', 0.0)),
#  (611, ('proliferation is rare while photobiomodulation therapy', 0.0)),
#  (612, ('promote immune a polyamine blocking therapy', 0.0)),
#  (613, ('ps 20 and recently polybutylene terephthalate', 0.0)),
#  (614, ('racing cars the semi crystalline polymer', 0.0)),
#  (615, ('radiotherapy imrt or proton beam therapy', 0.0)),
#  (616, ('receipt of a perioperative blood transfusion', 0.0)),
#  (617, ('red line represents proton beam therapy', 0.0)),
#  (618, ('reduce by using proton beam therapy', 0.0)),
#  (619, ('resin beo ⁻ poly butylene terephthalate', 0.0)),
#  (620, ('resistance poly 1 4 butylene terephthalate', 0.0)),
#  (621, ('resting human peripheral blood t cells', 0.0)),
#  (622, ('rise to a homogeneous bithiophene polymer', 0.0)),
#  (623, ('rt imrt or proton beam therapy', 0.0)),
#  (624, ('sbrt 39 41 proton beam therapy', 0.0)),
#  (625, ('sln metastasis and primary breast tumor', 0.0)),
#  (626, ('sls is demonstrate for polybutylene terephthalate', 0.0)),
#  (627, ('specific leaf area sla payback times', 0.0)),
#  (628, ('study showed that proton beam therapy', 0.0)),
#  (629, ('such as perturbation based balance training', 0.0)),
#  (630, ('surrounding the eye proton beam therapy', 0.0)),
#  (631, ('synthetic c9 substituted phenanthrene based tylophorine', 0.0)),
#  (632, ('t lymphocytes isolated from peripheral blood', 0.0)),
#  (633, ('technique but whether proton beam therapy', 0.0)),
#  (634, ('terephthalate pet and poly butylene terephthalate', 0.0)),
#  (635, ('term efficacy of proton beam therapy', 0.0)),
#  (636, ('the adhesion of peripheral blood t', 0.0)),
#  (637, ('the associated of perioperative blood transfusion', 0.0)),
#  (638, ('the benefits of proton beam therapy', 0.0)),
#  (639, ('the critical complication of pulmonary barotrauma', 0.0)),
#  (640, ('the current investigate is polybutylene terephthalate', 0.0)),
#  (641, ('the developed of proton beam therapy', 0.0)),
#  (642, ('the effect of polyamine blockade therapy', 0.0)),
#  (643, ('the influence of perioperative blood transfusion', 0.0)),
#  (644, ('the using of proton beam therapy', 0.0)),
#  (645, ('therapy imrt and proton beam therapy', 0.0)),
#  (646, ('therapy imrt or proton beam therapy', 0.0)),
#  (647, ('therapy treatment the prone bridge test', 0.0)),
#  (648, ('tomotherapy ht and proton beam therapy', 0.0)),
#  (649, ('trail in human peripheral blood t', 0.0)),
#  (650, ('trail on human peripheral blood t', 0.0)),
#  (651, ('transplantation bmt and period blood transfusion', 0.0)),
#  (652,
#   ('treatment modalities including activated surveillance brachytherapy',
#    0.0)),
#  (653, ('was report that proton beam therapy', 0.0)),
#  (654, ('was treated by proton beam therapy', 0.0)),
#  (655, ('we demonstrate that polyamine blockade therapy', 0.0)),
#  (656, ('we first using proton beam therapy', 0.0)),
#  (657, ('were treated with proton beam therapy', 0.0)),
#  (658, ('with 3d radiotherapy proton beam therapy', 0.0)),
#  (659, ('+ cd45ro + peripheral blood t lymphoblasts', 0.0)),
#  (660, ('2 mass of a poly butylene terephthalate', 0.0)),
#  (661, ('2009 in this context the payback times', 0.0)),
#  (662, ('3d crt in contrast proton beam therapy', 0.0)),
#  (663, ('a synthetic c9 substituted phenanthrene based tylophorine', 0.0)),
#  (664, ('activated based costs tdabc for prostate brachytherapy', 0.0)),
#  (665, ('also promote immune a polyamine blocking therapy', 0.0)),
#  (666, ('an increasing incidence in primary brain tumor', 0.0)),
#  (667, ('and cd3 stimulated human peripheral blood t', 0.0)),
#  (668, ('and efficacy are warranted proton beam therapy', 0.0)),
#  (669, ('and red line represents proton beam therapy', 0.0)),
#  (670, ('apparent clinical advantage therefore proton beam therapy', 0.0)),
#  (671, ('as the developed of proton beam therapy', 0.0)),
#  (672, ('assay after recovery peripheral blood t cells', 0.0)),
#  (673, ('assess the influence of perioperative blood transfusion', 0.0)),
#  (674, ('at 237 ° c calculated polybutylene terephthalate', 0.0)),
#  (675, ('be achieved a novel polyamine blocker therapy', 0.0)),
#  (676, ('be reduce by using proton beam therapy', 0.0)),
#  (677, ('better dose distribution with proton beam therapy', 0.0)),
#  (678, ('blends of glass fiber reinforced polybutylene terephthalate', 0.0)),
#  (679, ('bone surrounding the eye proton beam therapy', 0.0)),
#  (680, ('can be achieved with proton beam therapy', 0.0)),
#  (681, ('common adverse events of proton beam therapy', 0.0)),
#  (682, ('compared clinical outcomes between proton beam therapy', 0.0)),
#  (683, ('compared with 3d radiotherapy proton beam therapy', 0.0)),
#  (684, ('creatinine level receipt of perioperative blood transfusion', 0.0)),
#  (685, ('degree gantry synchrotron based proton beam therapy', 0.0)),
#  (686,
#   ('disease and culminates in pathological bacterial translocation', 0.0)),
#  (687, ('dose profiles provided by proton beam therapy', 0.0)),
#  (688, ('during co comminution of a polybutylene terephthalate', 0.0)),
#  (689, ('employed in this work is polybutylene terephtharate', 0.0)),
#  (690, ('epoxy resin beo ⁻ poly butylene terephthalate', 0.0)),
#  (691, ('establishing new treatment strategies proton beam therapy', 0.0)),
#  (692, ('ethylacetate fraction pea and n butanol fraction', 0.0)),
#  (693, ('ethylene terephthalate pet and poly butylene terephthalate', 0.0)),
#  (694, ('evaluate the effect of polyamine blockade therapy', 0.0)),
#  (695, ('events in this context proton beam therapy', 0.0)),
#  (696, ('evidence based investigate regarding proton beam therapy', 0.0)),
#  (697, ('examine the adhesion of peripheral blood t', 0.0)),
#  (698, ('examine the benefits of proton beam therapy', 0.0)),
#  (699, ('expression on human peripheral blood t cells', 0.0)),
#  (700, ('facio lingual thickness of the papilla based', 0.0)),
#  (701, ('fibrinolytic hemorrhage 20 22 primary bleeding times', 0.0)),
#  (702, ('for malignancy often receive perioperative blood transfusion', 0.0)),
#  (703, ('fraction of the peripheral blood t cells', 0.0)),
#  (704,
#   ('g polyethylene terephthalate pet and polybutylene terephthalate', 0.0)),
#  (705, ('gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0)),
#  (706, ('give rise to a homogeneous bithiophene polymer', 0.0)),
#  (707, ('growth are significant problem proton beam therapy', 0.0)),
#  (708, ('has centered on whether perioperative blood transfusion', 0.0)),
#  (709, ('have developed a new polyamine blockade therapy', 0.0)),
#  (710, ('have employed a novel polyamine blocker therapy', 0.0)),
#  (711, ('hcc was treated by proton beam therapy', 0.0)),
#  (712, ('heat resistance poly 1 4 butylene terephthalate', 0.0)),
#  (713, ('helical tomotherapy ht and proton beam therapy', 0.0)),
#  (714, ('in activated cd4 peripheral blood t cells', 0.0)),
#  (715, ('in men treated with proton beam therapy', 0.0)),
#  (716, ('in multiple myeloma mm peripheral blood t', 0.0)),
#  (717, ('in patients treated with proton beam therapy', 0.0)),
#  (718, ('in pbs + 0 1 tween 20', 0.0)),
#  (719, ('in racing cars the semi crystalline polymer', 0.0)),
#  (720, ('in resting human peripheral blood t cells', 0.0)),
#  (721, ('in the using of proton beam therapy', 0.0)),
#  (722,
#   ('induced immunosuppressive effect of perioperative blood transfusion',
#    0.0)),
#  (723, ('investigate the associated of perioperative blood transfusion', 0.0)),
#  (724, ('investigate the effect of perioperative blood transfusion', 0.0)),
#  (725, ('is current be term polyamine blocking therapy', 0.0)),
#  (726, ('location and associated toxicities proton beam therapy', 0.0)),
#  (727, ('marrow transplantation bmt and period blood transfusion', 0.0)),
#  (728, ('mc specific leaf area sla payback times', 0.0)),
#  (729, ('methanol phosphate buffered saline 0 1 tween', 0.0)),
#  (730, ('modulated radiotherapy imrt or proton beam therapy', 0.0)),
#  (731, ('modulated rt imrt or proton beam therapy', 0.0)),
#  (732, ('ocular melanoma treated with proton beam therapy', 0.0)),
#  (733, ('of four commercial polymer poly butylene terephthalate', 0.0)),
#  (734, ('of lung toxicities after proton beam therapy', 0.0)),
#  (735, ('of preoperative anemia and perioperative blood transfusion', 0.0)),
#  (736, ('of sln metastasis and primary breast tumor', 0.0)),
#  (737, ('of t lymphocytes isolated from peripheral blood', 0.0)),
#  (738, ('of the critical complication of pulmonary barotrauma', 0.0)),
#  (739, ('of the current investigate is polybutylene terephthalate', 0.0)),
#  (740, ('of trail in human peripheral blood t', 0.0)),
#  (741, ('of trail on human peripheral blood t', 0.0)),
#  (742,
#   ('of treatment modalities including activated surveillance brachytherapy',
#    0.0)),
#  (743, ('older technique but whether proton beam therapy', 0.0)),
#  (744, ('or metastatic hnc with platinum based therapy', 0.0)),
#  (745, ('other ldt modalities including proton beam therapy', 0.0)),
#  (746, ('papilla height ph and papilla based thickness', 0.0)),
# ...
#  (786, ('unique dose deposition characteristics proton beam therapy', 0.0)),
#  (787, ('utilization and efficacy of proton beam therapy', 0.0)),
#  (788, ('value in oncological increasing proton beam radiotherapy', 0.0)),
#  (789, ('was further enhanced by proton beam therapy', 0.0)),
#  (790, ('washes in pbs 0 1 tween 20', 0.0)),
#  (791, ('were able to sensitize peripheral blood t', 0.0)),
#  (792,
#   ('whereas isoproterenol treated mice demonstrate pathological translocation',
#    0.0)),
#  (793, ('who were treated with proton beam therapy', 0.0)),
#  (794, ('with sbrt 39 41 proton beam therapy', 0.0)),
#  (795, ('1 a synthetic c9 substituted phenanthrene based tylophorine', 0.0)),
#  (796, ('17 the models overall performed well the validation', 0.0)),
#  (797, ('182 pva 186 pan 187 poly butylene terephthalate', 0.0)),
#  (798, ('19 pmma ps 20 and recently polybutylene terephthalate', 0.0)),
#  (799, ('360 degree gantry synchrotron based proton beam therapy', 0.0)),
#  (800, ('7139 and cd3 stimulated human peripheral blood t', 0.0)),
#  (801, ('a methanol phosphate buffered saline 0 1 tween', 0.0)),
#  (802, ('adverse events in this context proton beam therapy', 0.0)),
#  (803, ('along with sbrt 39 41 proton beam therapy', 0.0)),
#  (804,
#   ('anatomic location and associated toxicities proton beam therapy', 0.0)),
#  (805,
#   ('and creatinine level receipt of perioperative blood transfusion', 0.0)),
#  (806, ('and heat resistance poly 1 4 butylene terephthalate', 0.0)),
#  (807, ('and or metastatic hnc with platinum based therapy', 0.0)),
#  (808, ('assess fibrinolytic hemorrhage 20 22 primary bleeding times', 0.0)),
#  (809,
#   ('behaviour of four commercial polymer poly butylene terephthalate', 0.0)),
#  (810, ('bone marrow transplantation bmt and period blood transfusion', 0.0)),
#  (811, ('brominated epoxy resin beo ⁻ poly butylene terephthalate', 0.0)),
#  (812, ('cancer patients are treated using proton beam therapy', 0.0)),
#  (813, ('carcinoma hcc was treated by proton beam therapy', 0.0)),
#  (814, ('ccs who were treated with proton beam therapy', 0.0)),
#  (815, ('cd4 + cd45ro + peripheral blood t lymphoblasts', 0.0)),
#  (816,
#   ('component reactions chemical structures of polymer polybutylene terephthalate',
#    0.0)),
#  (817, ('costs mc specific leaf area sla payback times', 0.0)),
#  (818, ('crt helical tomotherapy ht and proton beam therapy', 0.0)),
#  (819, ('detection assay after recovery peripheral blood t cells', 0.0)),
#  (820, ('diminish the need for allogeneic red cells transfusion', 0.0)),
#  (821,
#   ('documenting value in oncological increasing proton beam radiotherapy',
#    0.0)),
#  (822, ('driven activated based costs tdabc for prostate brachytherapy', 0.0)),
#  (823,
#   ('e g polyethylene terephthalate pet and polybutylene terephthalate', 0.0)),
#  (824, ('effect in the using of proton beam therapy', 0.0)),
#  (825, ('ellison 2009 in this context the payback times', 0.0)),
#  (826,
#   ('experiments blends of glass fiber reinforced polybutylene terephthalate',
#    0.0)),
#  (827, ('fas expression on human peripheral blood t cells', 0.0)),
#  (828, ('first examine the adhesion of peripheral blood t', 0.0)),
#  (829, ('for establishing new treatment strategies proton beam therapy', 0.0)),
#  (830, ('function of trail in human peripheral blood t', 0.0)),
#  (831, ('function of trail on human peripheral blood t', 0.0)),
#  (832,
#   ('grinded particles of polystyrene ps 28 polybutylene terephthalate', 0.0)),
#  (833, ('h in pbs + 0 1 tween 20', 0.0)),
#  (834,
#   ('have investigate the effect of perioperative blood transfusion', 0.0)),
#  (835, ('however can be achieved with proton beam therapy', 0.0)),
#  (836, ('human gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0)),
#  (837,
#   ('impact of preoperative anemia and perioperative blood transfusion', 0.0)),
#  (838, ('imrt and red line represents proton beam therapy', 0.0)),
#  (839, ('in pbs + 0 2 triton x 100', 0.0)),
#  (840, ('in til compared with peripheral blood t cells', 0.0)),
#  (841, ('incidence of lung toxicities after proton beam therapy', 0.0)),
#  (842, ('intensity modulated radiotherapy imrt or proton beam therapy', 0.0)),
#  (843, ('intensity modulated rt imrt or proton beam therapy', 0.0)),
#  (844, ('isolated platelets and autologous peripheral blood t cells', 0.0)),
#  (845, ('kda in resting human peripheral blood t cells', 0.0)),
#  (846, ('large fraction of the peripheral blood t cells', 0.0)),
#  (847,
#   ('laser sintering sls is demonstrate for polybutylene terephthalate', 0.0)),
#  (848,
#   ('liver disease and culminates in pathological bacterial translocation',
#    0.0)),
#  (849,
#   ('liver whereas isoproterenol treated mice demonstrate pathological translocation',
#    0.0)),
#  (850,
#   ('malignancy primary brain tumor respectively proton beam therapy', 0.0)),
#  (851, ('manifolds in racing cars the semi crystalline polymer', 0.0)),
#  (852, ('may also promote immune a polyamine blocking therapy', 0.0)),
#  (853, ('migration of t lymphocytes isolated from peripheral blood', 0.0)),
#  (854, ('min at 237 ° c calculated polybutylene terephthalate', 0.0)),
#  (855, ('mo were able to sensitize peripheral blood t', 0.0)),
#  (856, ('models in patients treated with proton beam therapy', 0.0)),
#  (857, ('modulated radiation therapy imrt and proton beam therapy', 0.0)),
#  (858, ('modulated radiation therapy imrt or proton beam therapy', 0.0)),
#  (859, ('most common adverse events of proton beam therapy', 0.0)),
#  (860, ('must be achieved a novel polyamine blocker therapy', 0.0)),
#  (861, ('n 2 mass of a poly butylene terephthalate', 0.0)),
#  (862,
#   ('nephroureterectomy rnu the effect of perioperative blood transfusion',
#    0.0)),
#  (863, ('no apparent clinical advantage therefore proton beam therapy', 0.0)),
#  (864, ('non powered co 2 baited passive box trap', 0.0)),
#  (865, ('of ocular melanoma treated with proton beam therapy', 0.0)),
#  (866, ('of papilla height ph and papilla based thickness', 0.0)),
#  (867, ('of physical therapy treatment the prone bridge test', 0.0)),
#  (868,
#   ('oncological prognosis and additionally on perioperative blood transfusion',
#    0.0)),
#  (869, ('one of the critical complication of pulmonary barotrauma', 0.0)),
#  (870, ('our previous study showed that proton beam therapy', 0.0)),
#  (871, ('p total maintenance costs mc and payback times', 0.0)),
#  (872, ('particles therapy chiefly comprised of proton beam therapy', 0.0)),
#  (873, ('particularly the ethylacetate pea and n butanol extract', 0.0)),
#  (874, ('patients in multiple myeloma mm peripheral blood t', 0.0)),
#  (875, ('pbt patients level benefits of proton beam therapy', 0.0)),
#  (876, ('perspective facio lingual thickness of the papilla based', 0.0)),
#  (877, ('pet ethylacetate fraction pea and n butanol fraction', 0.0)),
#  (878,
#   ('poly ethylene terephthalate pet and poly butylene terephthalate', 0.0)),
#  (879,
#   ('preferred evidence based investigate regarding proton beam therapy', 0.0)),
#  (880, ('problem an increasing incidence in primary brain tumor', 0.0)),
#  (881,
#   ('quiescence so proliferation is rare while photobiomodulation therapy',
#    0.0)),
#  (882, ('respectively then 5 ± 0 1 mg samples', 0.0)),
#  (883, ('retardancy growth are significant problem proton beam therapy', 0.0)),
#  (884, ('safety and efficacy are warranted proton beam therapy', 0.0)),
#  (885, ('samples employed in this work is polybutylene terephtharate', 0.0)),
#  (886, ('samples of sln metastasis and primary breast tumor', 0.0)),
#  (887, ('sculpting was further enhanced by proton beam therapy', 0.0)),
#  (888, ('several washes in pbs 0 1 tween 20', 0.0)),
#  (889, ('should til be compared peripheral blood t cells', 0.0)),
#  (890,
#   ('similar the adverse correlation of perioperative blood transfusion', 0.0)),
#  (891, ('specific training such as perturbation based balance training', 0.0)),
#  (892,
#   ('subject of the current investigate is polybutylene terephthalate', 0.0)),
#  (893, ('superior dose profiles provided by proton beam therapy', 0.0)),
#  (894,
#   ('suppressed proliferation of alloreactive peripheral blood t cells', 0.0)),
#  (895, ('surface give rise to a homogeneous bithiophene polymer', 0.0)),
#  (896, ('the better dose distribution with proton beam therapy', 0.0)),
#  (897, ('the bone surrounding the eye proton beam therapy', 0.0)),
#  (898, ('the role of risk adapted proton beam therapy', 0.0)),
#  (899, ('the tumor we demonstrate that polyamine blockade therapy', 0.0)),
#  (900, ('the utilization and efficacy of proton beam therapy', 0.0)),
#  (901, ('therapy to charged particles like proton beam therapy', 0.0)),
#  (902, ('times during co comminution of a polybutylene terephthalate', 0.0)),
#  (903, ('to assess the influence of perioperative blood transfusion', 0.0)),
#  (904, ('to evaluate the effect of polyamine blockade therapy', 0.0)),
#  (905, ('to examine the benefits of proton beam therapy', 0.0)),
#  (906, ('to older technique but whether proton beam therapy', 0.0)),
#  (907, ('to other ldt modalities including proton beam therapy', 0.0)),
#  (908, ('to treated hcc 5 6 proton beam therapy', 0.0)),
#  (909, ('to unique dose deposition characteristics proton beam therapy', 0.0)),
#  (910, ('toxicities in men treated with proton beam therapy', 0.0)),
#  (911,
#   ('treatment for malignancy often receive perioperative blood transfusion',
#    0.0)),
#  (912, ('tumor response after risk adapted proton beam therapy', 0.0)),
#  (913, ('unique property we first using proton beam therapy', 0.0)),
#  (914,
#   ('variety of treatment modalities including activated surveillance brachytherapy',
#    0.0)),
#  (915, ('viable tumor cells treatment with dfmo and amxt1501', 0.0)),
#  (916, ('volume compared with 3d radiotherapy proton beam therapy', 0.0)),
#  (917, ('we have developed a new polyamine blockade therapy', 0.0)),
#  (918, ('we have employed a novel polyamine blocker therapy', 0.0)),
#  (919, ('well as the developed of proton beam therapy', 0.0)),
#  (920, ('were study in the ethanol etoh and phenylbutazone', 0.0)),
#  (921, ('what is current be term polyamine blocking therapy', 0.0)),
#  (922, ('width pbt papilla based thickness papilla based thickness', 0.0)),
#  (923, ('with 3d crt in contrast proton beam therapy', 0.0)),
#  (924, ('would be reduce by using proton beam therapy', 0.0)),
#  (925, ('years has centered on whether perioperative blood transfusion', 0.0)),
#  (926, ('β in activated cd4 peripheral blood t cells', 0.0)),
#  (927, ('0 17 the models overall performed well the validation', 0.0)),
#  (928,
#   ('2 similar the adverse correlation of perioperative blood transfusion',
#    0.0)),
#  (929,
#   ('30 years has centered on whether perioperative blood transfusion', 0.0)),
#  (930, ('4 h in pbs + 0 1 tween 20', 0.0)),
#  (931, ('45 min at 237 ° c calculated polybutylene terephthalate', 0.0)),
#  (932, ('6 182 pva 186 pan 187 poly butylene terephthalate', 0.0)),
#  (933, ('60 kda in resting human peripheral blood t cells', 0.0)),
#  (934, ('a large fraction of the peripheral blood t cells', 0.0)),
#  (935, ('a non powered co 2 baited passive box trap', 0.0)),
#  (936,
#   ('a variety of treatment modalities including activated surveillance brachytherapy',
#    0.0)),
#  (937, ('after several washes in pbs 0 1 tween 20', 0.0)),
#  (938, ('alterations of papilla height ph and papilla based thickness', 0.0)),
#  (939, ('and diminish the need for allogeneic red cells transfusion', 0.0)),
#  (940, ('and ellison 2009 in this context the payback times', 0.0)),
#  (941,
#   ('and for establishing new treatment strategies proton beam therapy', 0.0)),
#  (942, ('and function of trail in human peripheral blood t', 0.0)),
#  (943, ('and function of trail on human peripheral blood t', 0.0)),
#  (944,
#   ('and human gingival fibroblasts hgf peripheral blood t lymphocytes', 0.0)),
#  (945,
#   ('and malignancy primary brain tumor respectively proton beam therapy',
#    0.0)),
#  (946,
#   ('and retardancy growth are significant problem proton beam therapy', 0.0)),
#  (947,
#   ('as intensity modulated radiotherapy imrt or proton beam therapy', 0.0)),
#  (948, ('as well as the developed of proton beam therapy', 0.0)),
#  (949, ('based intensity modulated rt imrt or proton beam therapy', 0.0)),
#  (950,
#   ('but suppressed proliferation of alloreactive peripheral blood t cells',
#    0.0)),
#  (951, ('by a methanol phosphate buffered saline 0 1 tween', 0.0)),
#  (952, ('cancer patients in multiple myeloma mm peripheral blood t', 0.0)),
#  (953, ('cancer would be reduce by using proton beam therapy', 0.0)),
#  (954, ('cc p total maintenance costs mc and payback times', 0.0)),
#  (955, ('cells should til be compared peripheral blood t cells', 0.0)),
#  (956,
#   ('chronic liver disease and culminates in pathological bacterial translocation',
#    0.0)),
#  (957,
#   ('circulation one of the critical complication of pulmonary barotrauma',
#    0.0)),
#  (958, ('clone 7139 and cd3 stimulated human peripheral blood t', 0.0)),
#  (959, ('compared to older technique but whether proton beam therapy', 0.0)),
#  (960,
#   ('compared to other ldt modalities including proton beam therapy', 0.0)),
#  (961, ('compared with 3d crt in contrast proton beam therapy', 0.0)),
#  (962, ('costs effect in the using of proton beam therapy', 0.0)),
#  (963,
#   ('cytokines detection assay after recovery peripheral blood t cells', 0.0)),
#  (964,
#   ('diastema width pbt papilla based thickness papilla based thickness', 0.0)),
#  (965,
#   ('disaggregated viable tumor cells treatment with dfmo and amxt1501', 0.0)),
#  (966,
#   ('documenting the utilization and efficacy of proton beam therapy', 0.0)),
#  (967, ('dose sculpting was further enhanced by proton beam therapy', 0.0)),
#  (968, ('dose to treated hcc 5 6 proton beam therapy', 0.0)),
#  (969,
#   ('dripping behaviour of four commercial polymer poly butylene terephthalate',
#    0.0)),
#  (970,
#   ('due to unique dose deposition characteristics proton beam therapy', 0.0)),
#  (971,
#   ('esthetic perspective facio lingual thickness of the papilla based', 0.0)),
#  (972, ('evaluate the role of risk adapted proton beam therapy', 0.0)),
#  (973, ('flow respectively then 5 ± 0 1 mg samples', 0.0)),
#  (974, ('for ccs who were treated with proton beam therapy', 0.0)),
#  (975,
#   ('freshly isolated platelets and autologous peripheral blood t cells', 0.0)),
#  (976, ('fuel manifolds in racing cars the semi crystalline polymer', 0.0)),
#  (977, ('health problem an increasing incidence in primary brain tumor', 0.0)),
#  (978,
#   ('hemoglobin and creatinine level receipt of perioperative blood transfusion',
#    0.0)),
#  (979,
#   ('hepatocellular carcinoma hcc was treated by proton beam therapy', 0.0)),
#  (980,
#   ('inactivation were study in the ethanol etoh and phenylbutazone', 0.0)),
#  (981,
#   ('including poly ethylene terephthalate pet and poly butylene terephthalate',
#    0.0)),
#  (982,
#   ('intensity modulated radiation therapy imrt or proton beam therapy', 0.0)),
#  (983, ('into the tumor we demonstrate that polyamine blockade therapy', 0.0)),
#  (984, ('lung cancer patients are treated using proton beam therapy', 0.0)),
#  (985, ('maintenance costs mc specific leaf area sla payback times', 0.0)),
#  (986, ('monocytes mo were able to sensitize peripheral blood t', 0.0)),
#  (987, ('ntcp models in patients treated with proton beam therapy', 0.0)),
#  (988,
#   ('objective tumor response after risk adapted proton beam therapy', 0.0)),
#  (989, ('of adverse events in this context proton beam therapy', 0.0)),
#  (990,
#   ('of bone marrow transplantation bmt and period blood transfusion', 0.0)),
#  (991, ('of cd4 + cd45ro + peripheral blood t lymphoblasts', 0.0)),
#  (992,
#   ('of documenting value in oncological increasing proton beam radiotherapy',
#    0.0)),
#  (993,
#   ('of grinded particles of polystyrene ps 28 polybutylene terephthalate',
#    0.0)),
#  (994, ('of particles therapy chiefly comprised of proton beam therapy', 0.0)),
#  (995, ('of what is current be term polyamine blocking therapy', 0.0)),
#  (996, ('pa12 19 pmma ps 20 and recently polybutylene terephthalate', 0.0)),
#  (997, ('paired samples of sln metastasis and primary breast tumor', 0.0)),
#  (998,
#   ('pbt 1 a synthetic c9 substituted phenanthrene based tylophorine', 0.0)),
#  (999, ('pfa in pbs + 0 2 triton x 100', 0.0)),
#  ...]

# %%
longforms0.extend((longform, score) for i, (longform, score) in enumerate(top)
                 if i in [5, 8, 15, 32, 33, 34])

# %%
longforms = longforms0

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('proton beam therapy',
#  'perioperative blood transfusion',
#  'polybutylene terephthalate',
#  'peripheral blood t cells',
#  'poly butylene terephthalate',
#  'peripheral blood t',
#  'payback times',
#  'polyamine blockade therapy',
#  'papilla based thickness',
#  'platinum based therapy',
#  'polyamine blocking therapy')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'proton beam therapy': 'MESH:D061766'}

# %%
names
# Out:
# {'MESH:D061766': 'Proton Therapy'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'papilla based thickness': 'ungrounded',
#   'payback times': 'ungrounded',
#   'perioperative blood transfusion': 'MESH:D001803',
#   'peripheral blood t': 'ungrounded',
#   'peripheral blood t cells': 'ungrounded',
#   'platinum based therapy': 'ungrounded',
#   'poly butylene terephthalate': 'ungrounded',
#   'polyamine blockade therapy': 'ungrounded',
#   'polyamine blocking therapy': 'ungrounded',
#   'polybutylene terephthalate': 'ungrounded',
#   'proton beam therapy': 'MESH:D061766'},
#  {'MESH:D001803': 'Blood Transfusion', 'MESH:D061766': 'Proton Therapy'},
#  ['MESH:D001803', 'MESH:D061766'])

# %%
grounding_map, names, pos_labels = ({'papilla based thickness': 'ungrounded',
  'payback times': 'ungrounded',
  'perioperative blood transfusion': 'MESH:D001803',
  'peripheral blood t': 'ungrounded',
  'peripheral blood t cells': 'ungrounded',
  'platinum based therapy': 'ungrounded',
  'poly butylene terephthalate': 'ungrounded',
  'polyamine blockade therapy': 'ungrounded',
  'polyamine blocking therapy': 'ungrounded',
  'polybutylene terephthalate': 'ungrounded',
  'proton beam therapy': 'MESH:D061766'},
 {'MESH:D001803': 'Blood Transfusion', 'MESH:D061766': 'Proton Therapy'},
 ['MESH:D001803', 'MESH:D061766'])

# %%
grounding_dict = {'PBT': grounding_map}

# %%
classifier = AdeftClassifier('PBT', pos_labels=pos_labels)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2020-01-27 15:14:00] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [100.0], 'max_features': [10000]}
# INFO: [2020-01-27 15:14:01] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.9810734798970092 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 10000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'ungrounded': 25,
#   'MESH:D061766': 38,
#   'MESH:D001803': 11},
#  'f1': {'mean': 0.9810734798970092, 'std': 0.023356974036023197},
#  'precision': {'mean': 0.9643939393939395, 'std': 0.04391616708753207},
#  'recall': {'mean': 1.0, 'std': 0.0}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'HGNC:6342']

# %%
a[40]
# Out:
# 'The ability of T cells to microlocalize within tissues, such as the lung, is crucial for immune surveillance and increased T-cell infiltration is a feature of many inflammatory lung conditions. T-cell migration has mainly been studied in two-dimensional assays. Using three-dimensional collagen gels to mimic the extracellular matrix of lung tissue, we have characterized the migration of T lymphocytes isolated from peripheral blood (PBT) and lung (LT) in response to interleukin-2 (IL-2) and CXCL12. Freshly isolated PBT and LT showed a low degree of migration (blood 4·0 ± 1·3% and lung 4·1 ± 1·7%). Twenty-four hours of culture increased the percentage of migrating PBT and LT (blood 17·5 ± 2·9% and lung 17·7 ± 3·8%). The IL-2 stimulation modestly increased migration of PBT after 6 days (32·3 ± 6·0%), but had no effect on the migration of LT (25·5 ± 3·2%). Twenty-four hours of stimulation with anti-CD3/CD28 caused a small but significant increase in the migration of PBT (to 36·4 ± 5·8%). In a directional three-dimensional assay, CXCL12 failed to induce migration of fresh PBT or LT. Twenty-four hours of culture, which increased CXCR4 expression of PBT 3·6-fold, significantly increased the migration of PBT in response to CXCL12. Migration of PBT to CXCL12 was blocked by pertussis toxin, but not by the phosphoinositide 3-kinase inhibitor wortmannin. Twenty-four-hour cultured LT did not respond to CXCL12. CD3/CD28-stimulation inhibited CXCL12-mediated migration of PBT. These results suggest that the migration pattern of PBT is distinct from that of LT.\n'

# %%
disamb.dump('PBT', '../results')

# %%
from adeft.disambiguate import load_disambiguator, load_disambiguator_directly

# %%
disamb.classifier.training_set_digest
# Out:
# 'baeb1ba13324f4192620577a2d3e6ab9'

# %%
model_to_s3(disamb)

# %%
d.disambiguate(texts[0])
# Out:
# ('CHEBI:CHEBI:29016',
#  'arginine',
#  {'CHEBI:CHEBI:29016': 0.9667882794828576,
#   'CHEBI:CHEBI:79': 0.004343534773612251,
#   'HGNC:651': 0.00798509086185913,
#   'HGNC:77': 0.00973784879530277,
#   'HGNC:9965': 0.011145246086368127})

# %%
print(d.info())
# Out:
# Disambiguation model for ARG
#
# Produces the disambiguations:
# 	(-)-Arctigenin*	CHEBI:CHEBI:79
# 	ABL2*	HGNC:77
# 	AREG*	HGNC:651
# 	RERE*	HGNC:9965
# 	arginine*	CHEBI:CHEBI:29016
#
# Training data had class balance:
# 	AREG*	157
# 	ABL2*	88
# 	RERE*	39
# 	arginine*	15
# 	(-)-Arctigenin*	2
#
# Classification Metrics:
# 	F1 score:	0.81188
# 	Precision:	0.82394
# 	Recall:		0.8205
#
# * Positive labels
# See Docstring for explanation

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)

# %%
classifier.feature_importances()['FPLX:RAC']
# Out:
# [('rac1', 3.0203950681340763),
#  ('cdc42', 0.46463658443237615),
#  ('cells', 0.26067826443238284),
#  ('rhoa', 0.2284452268653803),
#  ('rho', 0.201414697794678),
#  ('rac1b', 0.1862119230497441),
#  ('actin', 0.16300556582714468),
#  ('gtpases', 0.15543881285531247),
#  ('rictor', 0.14896197766149943),
#  ('pak1', 0.14776120596579687),
#  ('jnk', 0.13802477317328446),
#  ('activation', 0.13739172186857945),
#  ('s1p', 0.12195584486540219),
#  ('thrombin', 0.12054088946040988),
#  ('endothelial', 0.11948523924516169),
#  ('proteins', 0.11834598588132215),
#  ('cell', 0.11418065253318789),
#  ('phox', 0.11144187989246301),
#  ('chimaerin', 0.1102266733731222),
#  ('elmo1', 0.10886660370678143),
#  ('vav', 0.10685654194092864),
#  ('ros', 0.1017412296369346),
#  ('gtp', 0.09970566367485924),
#  ('escc', 0.09632367768212988),
#  ('ras', 0.09346518511044424),
#  ('nef', 0.08938792674953275),
#  ('ubiquitylation', 0.0893305800391189),
#  ('p85', 0.08885763883676143),
#  ('gtpase', 0.08833886568389247),
#  ('figure', 0.087475101884638),
#  ('complexes', 0.0872265272835201),
#  ('hcc', 0.0862347075830363),
#  ('small', 0.08509078434544262),
#  ('domain', 0.08492635500235372),
#  ('region', 0.0841391109644385),
#  ('nox', 0.08167855496471926),
#  ('bfgf', 0.07852529781557573),
#  ('glioma', 0.0754901259891954),
#  ('syk', 0.07470961043787495),
#  ('wasp', 0.0742950745186167),
#  ('oscc', 0.07402266033376588),
#  ('protein', 0.07386030185484761),
#  ('apoptotic', 0.07258466038676381),
#  ('neurons', 0.07164901466379286),
#  ('mapk', 0.0693512216241394),
#  ('methylation', 0.06882298766794948),
#  ('rac1 activation', 0.06832338117403505),
#  ('integrin', 0.06827423774405098),
#  ('gef', 0.0671435194882063),
#  ('active', 0.06693609445326244),
#  ('p75', 0.06570119946407436),
#  ('cases', 0.06567364135565414),
#  ('tcr', 0.06475739947254273),
#  ('icam', 0.06340546963244698),
#  ('hep3b', 0.06316817405048261),
#  ('fa', 0.0628753619339119),
#  ('mediated', 0.06285616023878235),
#  ('egf', 0.06277717335021338),
#  ('infection', 0.061523518414123436),
#  ('sf', 0.06134784459551271),
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:18:53] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
d.info()
# Out:
# 'Disambiguation model for ALK\n\nProduces the disambiguations:\n\tALK*\tHGNC:427\n\tAlkaline Phosphatase*\tMESH:D000469\n\tRSTK1*\tFPLX:RSTK1\n\nTraining data had class balance:\n\tALK*\t1181\n\tRSTK1*\t155\n\tAlkaline Phosphatase*\t6\n\nClassification Metrics:\n\tF1 score:\t0.97493\n\tPrecision:\t0.97367\n\tRecall:\t\t0.97767\n\n* Positive labels\nSee Docstring for explanation\n'

# %%
print(d.info())
# Out:
# Disambiguation model for ALK
#
# Produces the disambiguations:
# 	ALK*	HGNC:427
# 	Alkaline Phosphatase*	MESH:D000469
# 	RSTK1*	FPLX:RSTK1
#
# Training data had class balance:
# 	ALK*	1181
# 	RSTK1*	155
# 	Alkaline Phosphatase*	6
#
# Classification Metrics:
# 	F1 score:	0.97493
# 	Precision:	0.97367
# 	Recall:		0.97767
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d = load_disambiguator('TAK', '../results')
# Out:
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# WARNING: [2020-01-24 11:34:16] /Users/albertsteppi/adeft/adeft/download/download.py - Shortform EAG has multiple adeft modelsThis may lead to unexpected behavior

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
from adeft import available_shortforms

# %%
print(d.info())
# Out:
# Disambiguation model for TAK
#
# Produces the disambiguations:
# 	MAP3K7*	HGNC:6859
# 	Takayasu Arteritis*	MESH:D013625
#
# Training data had class balance:
# 	MAP3K7*	327
# 	Ungrounded*	241
# 	Ungrounded	36
# 	Takayasu Arteritis*	13
#
# Classification Metrics:
# 	F1 score:	0.94043
# 	Precision:	0.93685
# 	Recall:		0.94658
#
# * Positive labels
# See Docstring for explanation

# %%
d.classifier.feature_importances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f3f38030175b> in <module>
# ----> 1 d.classifier.feature_importances()
#
# ~/adeft/adeft/modeling/classify.py in feature_importances(self)
#     299         # When there are greater than two classes, the logistic
#     300         # regression model will have a row of coefficients for
# --> 301         # each class. When there are only two classes, there is
#     302         # only one row of coefficients corresponding to the label classes[1]
#     303         if len(classes) > 2:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
from adeft import __version__

# %%
__version__
# Out:
# '0.5.5'

# %%
from adeft.disambiguate import load_disambiguator_directly

# %%
d = load_disambiguator_directly('../results/TEK/')

# %%
print(d.info())
# Out:
# Disambiguation model for TEK
#
# Produces the disambiguations:
# 	TEK*	HGNC:11724
#
# Training data had class balance:
# 	TEK*	217
# 	Ungrounded	9
#
# Classification Metrics:
# 	F1 score:	0.99316
# 	Precision:	0.98646
# 	Recall:		1.0
#
# * Positive labels
# See Docstring for explanation

# %%
model_to_s3(d)

# %%
d.grounding_dict
# Out:
# {'TEC': {'ternary elongation complex': 'transcription elongation complex',
#   'thermal expansion coefficient': 'ungrounded',
#   'thromboembolic complications': 'ungrounded',
#   'thymic epithelial cells': 'NCIT:C33771',
#   'thymic epithelial cells line': 'NCIT:C33771',
#   'thyrocyte': 'MESH:D000072637',
#   'thyroid epithelial cells': 'MESH:D000072637',
#   'tissue engineered construct': 'ungrounded',
#   'total electron content': 'ungrounded',
#   'tracheal epithelial cells': 'ungrounded',
#   'transcription elongation complex': 'transcription elongation complex',
#   'triethyl citrate': 'PUBCHEM:6506',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor endothelial cells': 'NCIT:C37088'},
#  'TECs': {'thymic epithelial cells': 'NCIT:C33771',
#   'thymus epithelial cells': 'NCIT:C33771',
#   'tissue engineered constructs': 'ungrounded',
#   'transcription elongation complexes': 'transcription elongation complex',
#   'tubular epithelial cells': 'NCIT:C61147',
#   'tubule epithelial cells': 'NCIT:C61147',
#   'tumor associated endothelial cells': 'NCIT:C37088',
#   'tumor ecs': 'ungrounded'}}

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008

# %%
from adeft import available_shortforms

# %%
len(available_shortforms)
# Out:
# 72

# %%
available_shortforms
# Out:
# {'PC': 'PC',
#  'DOG1': 'DOG1',
#  'TEK': 'TEK',
#  'EMT': 'EMT',
#  'SP': 'SP',
#  'PCS': 'PCS',
#  'CKI': 'CKI',
#  'PE': 'PE',
#  'RET': 'RET',
#  'TEC': 'TEC',
#  'ROS': 'ROS',
#  'NP': 'NP:NP_S',
#  'NPs': 'NP:NP_S',
#  'MS': 'MS',
#  'MT': 'MT',
#  'BP': 'BP',
#  'GH': 'GH',
#  'AD': 'AD',
#  'GT': 'GT',
#  'SNS': 'SNS',
#  'GARP': 'GARP',
#  'DA': 'DA',
#  'BCR': 'BCR',
#  'GR': 'GR',
#  'HIR': 'HIR',
#  'IR': 'IR',
#  'HK2': 'HK2',
#  'ARF': 'ARF',
#  'CS': 'CS',
#  'UFO': 'UFO',
#  'LAK': 'LAK',
#  'EC': 'EC',
#  'ARG': 'ARG',
#  'MOS': 'MOS',
#  'STD': 'STD',
#  'PD1': 'PD1',
#  'TGH': 'TGH',
#  'PKD': 'PKD',
#  'MIP': 'MIP',
#  'RA': 'RA',
#  'PCP': 'PCP',
#  'EAG': 'EAG',
#  'PI': 'PI',
#  'PS': 'PS',
#  'PA': 'PA',
#  'MB': 'MB',
#  'HA': 'HA',
#  'FES': 'FES',
#  'AR': 'AR',
#  'HR': 'HR',
#  'NE': 'NE',
#  'UBC': 'UBC',
#  'GSC': 'GSC',
#  'AA': 'AA',
#  'FER': 'FER',
#  'NIS': 'NIS',
#  'GC': 'GC',
#  'DLK': 'DLK',
#  'HK1': 'HK1',
#  'CM': 'CM',
#  'RB': 'RB:R_B',
#  'Rb': 'RB:R_B',
#  'LH': 'LH',
#  'ER': 'ER',
#  'TF': 'TF',
#  'PGP': 'PGP',
#  'GCA': 'GCA',
#  'RK': 'RK',
#  'RAC': 'RAC',
#  'MCT': 'MCT',
#  'CIR': 'CIR',
#  'TG': 'TG'}

# %%
'TEC' in available_shortforms
# Out:
# True

# %%
'TECs' in available_shortforms
# Out:
# False

# %%
# !python -m adeft.download --update
# Out:
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# Shortform TEC has multiple adeft modelsThis may lead to unexpected behavior
# 100% [........................................................] 194559 / 194559Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/albertsteppi/adeft/adeft/download/__main__.py", line 18, in <module>
#     download_models(update=args.update)
#   File "/Users/albertsteppi/adeft/adeft/download/download.py", line 65, in download_models
#     out=resource_path)
#   File "/Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found

# %%
# !python -m adeft.download --update
# Out:
# 100% [......................................................] 1181008 / 1181008
