# %%
import re
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground
# Out:
# INFO: [2020-01-24 16:30:28] /Users/albertsteppi/adeft/adeft/recognize.py - OneShotRecognizer not available. AdeftLongformScorer has not been built successfully.

# %%
shortforms = ['TAK']
genes = ['CDK9', 'MAP3K7']
families = {}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['TAK'].top()

# %%
top
# Out:
# [('takayasu arteritis', 22.3),
#  ('arteritis', 12.342857142857142),
#  ('activated kinase', 7.166666666666667),
#  ('takayasu s arteritis', 6.75),
#  ('with takayasu arteritis', 5.555555555555555),
#  ('β activated kinase', 3.4285714285714284),
#  ('tgf β activated kinase', 3.0),
#  ('patients with takayasu arteritis', 2.4),
#  ('transforming growth factor β activated kinase', 2.0),
#  ('rations of il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   2),
#  ('of patients with takayasu arteritis', 1.3333333333333333),
#  ('tak 242', 1.0),
#  ('beta activated kinase', 1.0),
#  ('of takayasu arteritis', 1.0),
#  ('activated takayasu s arteritis', 1.0),
#  ('in patients with takayasu arteritis', 1.0),
#  ('characteristics of patients with takayasu arteritis', 1.0),
#  ('with the exception of takayasu arteritis', 1),
#  ('the tlr4 signaling pathway inhibitors tak 242', 1),
#  ('a previous study revealed the associated between susceptibility to takayasu arteritis',
#   1),
#  ('ependent pathway and noncanonical smad independent transforming growth factor beta activated kinase',
#   1),
#  ('eritis uc ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#   1),
#  ('and c peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#   1),
#  ('gic therapies were associated with better control of disease activated childhood takayasu arteritis',
#   1),
#  ('ne morphogenetic protein bmp signaling mediated via transforming growth factor β activated kinase',
#   1),
#  ('rucial role in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#   1),
#  ('study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   1.0),
#  ('with mitogen activated protein kinase map2k transforming growth factor tgf β activated kinase',
#   1),
#  ('12p70 these enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#   1),
#  ('a pubmed search through february 2014 the main characteristics of patients with takayasu arteritis',
#   1),
#  ('assification criteria ara criteria for this disease and since then the name takayasu arteritis',
#   1),
#  ('e formation of an activated signaling complex containing transforming growth factor β activated kinase',
#   1),
#  ('f6 self ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#   1),
#  ('factor tnf receptor associated factor traf 6 and transforming growth factor β activated kinase',
#   1),
#  ('mportant complication of tak and bone scintigraphy is use for its detection takayasu arteritis',
#   1),
#  ('of diabetic neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#   1),
#  ('proaches for the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#   1),
#  ('s an important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#   1),
#  ('s identified potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#   1),
#  ('to assess the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#   1),
#  ('to investigate the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#   1),
#  ('tor 6 traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   1),
#  ('we reported a rare case of a 27 year old woman with takayasu arteritis', 1),
#  ('compare eight structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#   1),
#  ('dent manner fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#   1),
#  ('gers lys 63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   1),
#  ('ion microarray data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#   1),
#  ('its expression study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   1),
#  ('o and neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#   1),
#  ('ple and convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#   1),
#  ('representative images are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#   1),
#  ('ry large vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#   1),
#  ('s a and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   1),
#  ('to compare the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#   1),
#  ('et al 2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   1),
#  ('e the overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#   1),
#  ('ept to a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   1),
#  ('onal relevance of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   1),
#  ('f rats were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   1),
#  ('o neurospheres fig 3 i however the combination of these two inhibitors or the use of tak 779',
#   1),
#  ('to evaluate the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   1),
#  ('044', 0.0),
#  ('242', 0.0),
#  ('632', 0.0),
#  ('779', 0.0),
#  ('kinase', 0.0),
#  ('s arteritis', 0.0),
#  ('tak 044', 0.0),
#  ('tak 632', 0.0),
#  ('tak 779', 0.0),
#  ('2007 tak 632', 0.0),
#  ('childhood takayasu arteritis', 0.0),
#  ('detection takayasu arteritis', 0.0),
#  ('disease takayasu arteritis', 0.0),
#  ('especially takayasu arteritis', 0.0),
#  ('evaluate tak 242', 0.0),
#  ('formation takayasu arteritis', 0.0),
#  ('include takayasu arteritis', 0.0),
#  ('inhibitors tak 242', 0.0),
#  ('name takayasu arteritis', 0.0),
#  ('of tak 779', 0.0),
#  ('performed tak 044', 0.0),
#  ('tak takayasu arteritis', 0.0),
#  ('tgfβ activated kinase', 0.0),
#  ('to takayasu arteritis', 0.0),
#  ('β1 activated kinase', 0.0),
#  ('80 takayasu s arteritis', 0.0),
#  ('activated childhood takayasu arteritis', 0.0),
#  ('al 2007 tak 632', 0.0),
#  ('and include takayasu arteritis', 0.0),
#  ('cell of takayasu arteritis', 0.0),
#  ('chinese takayasu s arteritis', 0.0),
#  ('exception of takayasu arteritis', 0.0),
#  ('factor beta activated kinase', 0.0),
#  ('factor β activated kinase', 0.0),
#  ('further evaluate tak 242', 0.0),
#  ('further takayasu s arteritis', 0.0),
#  ('in takayasu s arteritis', 0.0),
#  ('inflammasome formation takayasu arteritis', 0.0),
#  ('its detection takayasu arteritis', 0.0),
#  ('of tak takayasu arteritis', 0.0),
#  ('of takayasu s arteritis', 0.0),
#  ('of tgfβ activated kinase', 0.0),
#  ('pathway inhibitors tak 242', 0.0),
#  ('pt with takayasu arteritis', 0.0),
#  ('relapse takayasu s arteritis', 0.0),
#  ('rs665268 with takayasu arteritis', 0.0),
#  ('susceptibility to takayasu arteritis', 0.0),
#  ('tgf beta activated kinase', 0.0),
#  ('tgf β1 activated kinase', 0.0),
#  ('the disease takayasu arteritis', 0.0),
#  ('the name takayasu arteritis', 0.0),
#  ('use of tak 779', 0.0),
#  ('vasculitis especially takayasu arteritis', 0.0),
#  ('was performed tak 044', 0.0),
#  ('woman with takayasu arteritis', 0.0),
#  ('activated in takayasu s arteritis', 0.0),
#  ('activated of tgfβ activated kinase', 0.0),
#  ('and activated takayasu s arteritis', 0.0),
#  ('be further evaluate tak 242', 0.0),
#  ('between susceptibility to takayasu arteritis', 0.0),
#  ('branches and include takayasu arteritis', 0.0),
#  ('disease activated childhood takayasu arteritis', 0.0),
#  ('disease activated takayasu s arteritis', 0.0),
#  ('et al 2007 tak 632', 0.0),
#  ('explored further takayasu s arteritis', 0.0),
#  ('factor tgf β activated kinase', 0.0),
#  ('for its detection takayasu arteritis', 0.0),
#  ('for tgf beta activated kinase', 0.0),
#  ('growth factor beta activated kinase', 0.0),
#  ('growth factor β activated kinase', 0.0),
#  ('hepatectomy was performed tak 044', 0.0),
#  ('is 80 takayasu s arteritis', 0.0),
#  ('mononuclear cell of takayasu arteritis', 0.0),
#  ('of relapse takayasu s arteritis', 0.0),
#  ('of the disease takayasu arteritis', 0.0),
#  ('old woman with takayasu arteritis', 0.0),
#  ('on chinese takayasu s arteritis', 0.0),
#  ('pathophysiology of tak takayasu arteritis', 0.0),
#  ('patients pt with takayasu arteritis', 0.0),
#  ('polymorphism rs665268 with takayasu arteritis', 0.0),
#  ('promoting inflammasome formation takayasu arteritis', 0.0),
#  ('recruits tgf β activated kinase', 0.0),
#  ('signaling pathway inhibitors tak 242', 0.0),
#  ('that tgf β1 activated kinase', 0.0),
#  ('the exception of takayasu arteritis', 0.0),
#  ('the tgf β activated kinase', 0.0),
#  ('the use of tak 779', 0.0),
#  ('then the name takayasu arteritis', 0.0),
#  ('treatment of takayasu s arteritis', 0.0),
#  ('vessel vasculitis especially takayasu arteritis', 0.0),
#  ('with tgf β activated kinase', 0.0),
#  ('12p70 in patients with takayasu arteritis', 0.0),
#  ('2009 that tgf β1 activated kinase', 0.0),
#  ('associated between susceptibility to takayasu arteritis', 0.0),
#  ('be explored further takayasu s arteritis', 0.0),
#  ('blood mononuclear cell of takayasu arteritis', 0.0),
#  ('complex with tgf β activated kinase', 0.0),
#  ('disease activated in takayasu s arteritis', 0.0),
#  ('growth factor tgf β activated kinase', 0.0),
#  ('in patients pt with takayasu arteritis', 0.0),
#  ('inactive and activated takayasu s arteritis', 0.0),
#  ('involve activated of tgfβ activated kinase', 0.0),
#  ('its branches and include takayasu arteritis', 0.0),
#  ('large vessel vasculitis especially takayasu arteritis', 0.0),
#  ('macrophages of patients with takayasu arteritis', 0.0),
#  ('mcdermott et al 2007 tak 632', 0.0),
#  ('mlx polymorphism rs665268 with takayasu arteritis', 0.0),
#  ('mmf on chinese takayasu s arteritis', 0.0),
#  ('of disease activated childhood takayasu arteritis', 0.0),
#  ('of the tgf β activated kinase', 0.0),
#  ('or the use of tak 779', 0.0),
#  ('partial hepatectomy was performed tak 044', 0.0),
#  ('proposed for tgf beta activated kinase', 0.0),
#  ('risk of relapse takayasu s arteritis', 0.0),
#  ('rtx in patients with takayasu arteritis', 0.0),
#  ('should be further evaluate tak 242', 0.0),
#  ('since then the name takayasu arteritis', 0.0),
#  ('tak disease activated takayasu s arteritis', 0.0),
#  ('tak is 80 takayasu s arteritis', 0.0),
#  ('the pathophysiology of tak takayasu arteritis', 0.0),
#  ('the treatment of takayasu s arteritis', 0.0),
#  ('through promoting inflammasome formation takayasu arteritis', 0.0),
#  ('tlr4 signaling pathway inhibitors tak 242', 0.0),
#  ('traf6 recruits tgf β activated kinase', 0.0),
#  ('transforming growth factor beta activated kinase', 0.0),
#  ('treatment of the disease takayasu arteritis', 0.0),
#  ('use for its detection takayasu arteritis', 0.0),
#  ('year old woman with takayasu arteritis', 0.0),
#  ('27 year old woman with takayasu arteritis', 0.0),
#  ('70 partial hepatectomy was performed tak 044', 0.0),
#  ('a complex with tgf β activated kinase', 0.0),
#  ('activated of the tgf β activated kinase', 0.0),
#  ('al 2009 that tgf β1 activated kinase', 0.0),
#  ('and its branches and include takayasu arteritis', 0.0),
#  ('and since then the name takayasu arteritis', 0.0),
#  ('and transforming growth factor β activated kinase', 0.0),
#  ('and treatment of the disease takayasu arteritis', 0.0),
#  ('az mcdermott et al 2007 tak 632', 0.0),
#  ('can involve activated of tgfβ activated kinase', 0.0),
#  ('containing transforming growth factor β activated kinase', 0.0),
#  ('control of disease activated childhood takayasu arteritis', 0.0),
#  ('derived macrophages of patients with takayasu arteritis', 0.0),
#  ('for the treatment of takayasu s arteritis', 0.0),
#  ('higher in patients pt with takayasu arteritis', 0.0),
#  ('il 12p70 in patients with takayasu arteritis', 0.0),
#  ('in the pathophysiology of tak takayasu arteritis', 0.0),
#  ('independent transforming growth factor beta activated kinase', 0.0),
#  ('inhibitors or the use of tak 779', 0.0),
#  ('is use for its detection takayasu arteritis', 0.0),
#  ('main characteristics of patients with takayasu arteritis', 0.0),
#  ('mofetil mmf on chinese takayasu s arteritis', 0.0),
#  ('monitor disease activated in takayasu s arteritis', 0.0),
#  ('of mlx polymorphism rs665268 with takayasu arteritis', 0.0),
#  ('of tak disease activated takayasu s arteritis', 0.0),
#  ('pain should be further evaluate tak 242', 0.0),
#  ('pattern proposed for tgf beta activated kinase', 0.0),
#  ('peripheral blood mononuclear cell of takayasu arteritis', 0.0),
#  ('rituximab rtx in patients with takayasu arteritis', 0.0),
#  ('tak through promoting inflammasome formation takayasu arteritis', 0.0),
#  ('the associated between susceptibility to takayasu arteritis', 0.0),
#  ('the risk of relapse takayasu s arteritis', 0.0),
#  ('to be explored further takayasu s arteritis', 0.0),
#  ('transforming growth factor tgf β activated kinase', 0.0),
#  ('treating tak is 80 takayasu s arteritis', 0.0),
#  ('ubiquitination traf6 recruits tgf β activated kinase', 0.0),
#  ('vascular characteristics of patients with takayasu arteritis', 0.0),
#  ('via transforming growth factor β activated kinase', 0.0),
#  ('with inactive and activated takayasu s arteritis', 0.0),
#  ('with large vessel vasculitis especially takayasu arteritis', 0.0),
#  ('6 and transforming growth factor β activated kinase', 0.0),
#  ('628 az mcdermott et al 2007 tak 632', 0.0),
#  ('a 27 year old woman with takayasu arteritis', 0.0),
#  ('a 70 partial hepatectomy was performed tak 044', 0.0),
#  ('aorta and its branches and include takayasu arteritis', 0.0),
#  ('associated of mlx polymorphism rs665268 with takayasu arteritis', 0.0),
#  ('better control of disease activated childhood takayasu arteritis', 0.0),
#  ('cell derived macrophages of patients with takayasu arteritis', 0.0),
#  ('complex containing transforming growth factor β activated kinase', 0.0),
#  ('disease and since then the name takayasu arteritis', 0.0),
#  ('et al 2009 that tgf β1 activated kinase', 0.0),
#  ('evaluate of tak disease activated takayasu s arteritis', 0.0),
#  ('expression pattern proposed for tgf beta activated kinase', 0.0),
#  ('forms a complex with tgf β activated kinase', 0.0),
#  ('from peripheral blood mononuclear cell of takayasu arteritis', 0.0),
#  ('in treating tak is 80 takayasu s arteritis', 0.0),
#  ('map2k transforming growth factor tgf β activated kinase', 0.0),
#  ('mediated via transforming growth factor β activated kinase', 0.0),
#  ('mycophenolate mofetil mmf on chinese takayasu s arteritis', 0.0),
#  ('needs to be explored further takayasu s arteritis', 0.0),
#  ('neuropathic pain should be further evaluate tak 242', 0.0),
#  ('of il 12p70 in patients with takayasu arteritis', 0.0),
#  ('of rituximab rtx in patients with takayasu arteritis', 0.0),
#  ('of tak through promoting inflammasome formation takayasu arteritis', 0.0),
#  ('pathogenesis and treatment of the disease takayasu arteritis', 0.0),
#  ('pathway can involve activated of tgfβ activated kinase', 0.0),
#  ('patients with inactive and activated takayasu s arteritis', 0.0),
#  ('patients with large vessel vasculitis especially takayasu arteritis', 0.0),
#  ('placebo for the treatment of takayasu s arteritis', 0.0),
#  ('reduce the risk of relapse takayasu s arteritis', 0.0),
#  ('revealed the associated between susceptibility to takayasu arteritis', 0.0),
#  ('role in the pathophysiology of tak takayasu arteritis', 0.0),
#  ('scintigraphy is use for its detection takayasu arteritis', 0.0),
#  ('significantly higher in patients pt with takayasu arteritis', 0.0),
#  ('smad independent transforming growth factor beta activated kinase', 0.0),
#  ('subsequent activated of the tgf β activated kinase', 0.0),
#  ('the main characteristics of patients with takayasu arteritis', 0.0),
#  ('to monitor disease activated in takayasu s arteritis', 0.0),
#  ('two inhibitors or the use of tak 779', 0.0),
#  ('ubiquitination ubiquitination traf6 recruits tgf β activated kinase', 0.0),
#  ('vasc vascular characteristics of patients with takayasu arteritis', 0.0),
#  ('2014 the main characteristics of patients with takayasu arteritis', 0.0),
#  ('and a 70 partial hepatectomy was performed tak 044', 0.0),
#  ('and subsequent activated of the tgf β activated kinase', 0.0),
#  ('az 628 az mcdermott et al 2007 tak 632', 0.0),
#  ('between patients with inactive and activated takayasu s arteritis', 0.0),
#  ('bone scintigraphy is use for its detection takayasu arteritis', 0.0),
#  ('churchman et al 2009 that tgf β1 activated kinase', 0.0),
#  ('clinical evaluate of tak disease activated takayasu s arteritis', 0.0),
#  ('colitis vasc vascular characteristics of patients with takayasu arteritis',
#   0.0),
#  ('derived from peripheral blood mononuclear cell of takayasu arteritis', 0.0),
#  ('diabetic neuropathic pain should be further evaluate tak 242', 0.0),
#  ('kinase map2k transforming growth factor tgf β activated kinase', 0.0),
#  ('levels of il 12p70 in patients with takayasu arteritis', 0.0),
#  ('markers to monitor disease activated in takayasu s arteritis', 0.0),
#  ('mmf in treating tak is 80 takayasu s arteritis', 0.0),
#  ('mononuclear cell derived macrophages of patients with takayasu arteritis',
#   0.0),
#  ('noncanonical smad independent transforming growth factor beta activated kinase',
#   0.0),
#  ('not reduce the risk of relapse takayasu s arteritis', 0.0),
#  ('of a 27 year old woman with takayasu arteritis', 0.0),
#  ('of mycophenolate mofetil mmf on chinese takayasu s arteritis', 0.0),
#  ('pathogenesis needs to be explored further takayasu s arteritis', 0.0),
#  ('pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#   0.0),
#  ('play role in the pathophysiology of tak takayasu arteritis', 0.0),
#  ('safety of rituximab rtx in patients with takayasu arteritis', 0.0),
#  ('signaling complex containing transforming growth factor β activated kinase',
#   0.0),
#  ('signaling mediated via transforming growth factor β activated kinase', 0.0),
#  ('signaling pathway can involve activated of tgfβ activated kinase', 0.0),
#  ('some patients with large vessel vasculitis especially takayasu arteritis',
#   0.0),
#  ('study revealed the associated between susceptibility to takayasu arteritis',
#   0.0),
#  ('tak associated of mlx polymorphism rs665268 with takayasu arteritis', 0.0),
#  ('the aorta and its branches and include takayasu arteritis', 0.0),
#  ('the expression pattern proposed for tgf beta activated kinase', 0.0),
#  ('the pathogenesis and treatment of the disease takayasu arteritis', 0.0),
#  ('their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   0.0),
#  ('these two inhibitors or the use of tak 779', 0.0),
#  ('this disease and since then the name takayasu arteritis', 0.0),
#  ('to placebo for the treatment of takayasu s arteritis', 0.0),
#  ('traf 6 and transforming growth factor β activated kinase', 0.0),
#  ('traf6 forms a complex with tgf β activated kinase', 0.0),
#  ('were significantly higher in patients pt with takayasu arteritis', 0.0),
#  ('with better control of disease activated childhood takayasu arteritis',
#   0.0),
#  ('12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('54 the expression pattern proposed for tgf beta activated kinase', 0.0),
#  ('abatacept to placebo for the treatment of takayasu s arteritis', 0.0),
#  ('activated signaling complex containing transforming growth factor β activated kinase',
#   0.0),
#  ('affect the aorta and its branches and include takayasu arteritis', 0.0),
#  ('and bone scintigraphy is use for its detection takayasu arteritis', 0.0),
#  ('and noncanonical smad independent transforming growth factor beta activated kinase',
#   0.0),
#  ('and safety of rituximab rtx in patients with takayasu arteritis', 0.0),
#  ('as markers to monitor disease activated in takayasu s arteritis', 0.0),
#  ('associated with better control of disease activated childhood takayasu arteritis',
#   0.0),
#  ('blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#   0.0),
#  ('bmp signaling mediated via transforming growth factor β activated kinase',
#   0.0),
#  ('case of a 27 year old woman with takayasu arteritis', 0.0),
#  ('did not reduce the risk of relapse takayasu s arteritis', 0.0),
#  ('effect of mycophenolate mofetil mmf on chinese takayasu s arteritis', 0.0),
#  ('factor traf 6 and transforming growth factor β activated kinase', 0.0),
#  ('february 2014 the main characteristics of patients with takayasu arteritis',
#   0.0),
#  ('for this disease and since then the name takayasu arteritis', 0.0),
#  ('in some patients with large vessel vasculitis especially takayasu arteritis',
#   0.0),
#  ('in the pathogenesis and treatment of the disease takayasu arteritis', 0.0),
#  ('include mmf in treating tak is 80 takayasu s arteritis', 0.0),
#  ('inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0),
#  ('lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   0.0),
#  ('might play role in the pathophysiology of tak takayasu arteritis', 0.0),
#  ('of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#   0.0),
#  ('of these two inhibitors or the use of tak 779', 0.0),
#  ('polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   0.0),
#  ('previous study revealed the associated between susceptibility to takayasu arteritis',
#   0.0),
#  ('protein kinase map2k transforming growth factor tgf β activated kinase',
#   0.0),
#  ('ratio between patients with inactive and activated takayasu s arteritis',
#   0.0),
#  ('relieves diabetic neuropathic pain should be further evaluate tak 242',
#   0.0),
#  ('reported churchman et al 2009 that tgf β1 activated kinase', 0.0),
#  ('serum levels of il 12p70 in patients with takayasu arteritis', 0.0),
#  ('smad signaling pathway can involve activated of tgfβ activated kinase',
#   0.0),
#  ('tak pathogenesis needs to be explored further takayasu s arteritis', 0.0),
#  ('the clinical evaluate of tak disease activated takayasu s arteritis', 0.0),
#  ('the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#   0.0),
#  ('to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   0.0),
#  ('ubiquitination traf6 forms a complex with tgf β activated kinase', 0.0),
#  ('ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#   0.0),
#  ('unclamped and a 70 partial hepatectomy was performed tak 044', 0.0),
#  ('activated protein kinase map2k transforming growth factor tgf β activated kinase',
#   0.0),
#  ('an activated signaling complex containing transforming growth factor β activated kinase',
#   0.0),
#  ('and relieves diabetic neuropathic pain should be further evaluate tak 242',
#   0.0),
#  ('associated factor traf 6 and transforming growth factor β activated kinase',
#   0.0),
#  ('been reported churchman et al 2009 that tgf β1 activated kinase', 0.0),
#  ('combination of these two inhibitors or the use of tak 779', 0.0),
#  ('criteria for this disease and since then the name takayasu arteritis', 0.0),
#  ('cytokines might play role in the pathophysiology of tak takayasu arteritis',
#   0.0),
#  ('e serum levels of il 12p70 in patients with takayasu arteritis', 0.0),
#  ('efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#   0.0),
#  ('following ubiquitination traf6 forms a complex with tgf β activated kinase',
#   0.0),
#  ('for the clinical evaluate of tak disease activated takayasu s arteritis',
#   0.0),
#  ('gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#   0.0),
#  ('il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#   0.0),
#  ('leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   0.0),
#  ('lvv affect the aorta and its branches and include takayasu arteritis', 0.0),
#  ('lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#   0.0),
#  ('nlr as markers to monitor disease activated in takayasu s arteritis', 0.0),
#  ('non smad signaling pathway can involve activated of tgfβ activated kinase',
#   0.0),
#  ('of abatacept to placebo for the treatment of takayasu s arteritis', 0.0),
#  ('pathway and noncanonical smad independent transforming growth factor beta activated kinase',
#   0.0),
#  ('peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#   0.0),
#  ('prednisone did not reduce the risk of relapse takayasu s arteritis', 0.0),
#  ('problem in some patients with large vessel vasculitis especially takayasu arteritis',
#   0.0),
#  ('protein bmp signaling mediated via transforming growth factor β activated kinase',
#   0.0),
#  ('raf inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0),
#  ('rare case of a 27 year old woman with takayasu arteritis', 0.0),
#  ('t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   0.0),
#  ('tak and bone scintigraphy is use for its detection takayasu arteritis',
#   0.0),
#  ('targets in the pathogenesis and treatment of the disease takayasu arteritis',
#   0.0),
#  ('then unclamped and a 70 partial hepatectomy was performed tak 044', 0.0),
#  ('therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#   0.0),
#  ('therapies include mmf in treating tak is 80 takayasu s arteritis', 0.0),
#  ('through february 2014 the main characteristics of patients with takayasu arteritis',
#   0.0),
#  ('traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   0.0),
#  ('treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#   0.0),
#  ('uc ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#   0.0),
#  ('were associated with better control of disease activated childhood takayasu arteritis',
#   0.0),
#  ('1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#   0.0),
#  ('52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('a rare case of a 27 year old woman with takayasu arteritis', 0.0),
#  ('and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('ara criteria for this disease and since then the name takayasu arteritis',
#   0.0),
#  ('b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   0.0),
#  ('c peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#   0.0),
#  ('diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0),
#  ('efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#   0.0),
#  ('enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#   0.0),
#  ('has been reported churchman et al 2009 that tgf β1 activated kinase', 0.0),
#  ('important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#   0.0),
#  ('in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#   0.0),
#  ('linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   0.0),
#  ('method for the clinical evaluate of tak disease activated takayasu s arteritis',
#   0.0),
#  ('min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0),
#  ('mitogen activated protein kinase map2k transforming growth factor tgf β activated kinase',
#   0.0),
#  ('morphogenetic protein bmp signaling mediated via transforming growth factor β activated kinase',
#   0.0),
#  ('neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#   0.0),
#  ('of an activated signaling complex containing transforming growth factor β activated kinase',
#   0.0),
#  ('of tak and bone scintigraphy is use for its detection takayasu arteritis',
#   0.0),
#  ('of therapies include mmf in treating tak is 80 takayasu s arteritis', 0.0),
#  ('potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#   0.0),
#  ('receptor associated factor traf 6 and transforming growth factor β activated kinase',
#   0.0),
#  ('role in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#   0.0),
#  ('search through february 2014 the main characteristics of patients with takayasu arteritis',
#   0.0),
#  ('shown e serum levels of il 12p70 in patients with takayasu arteritis', 0.0),
#  ('the combination of these two inhibitors or the use of tak 779', 0.0),
#  ('the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#   0.0),
#  ('the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#   0.0),
#  ('the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#   0.0),
#  ('therapies were associated with better control of disease activated childhood takayasu arteritis',
#   0.0),
#  ('to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#   0.0),
#  ('traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   0.0),
#  ('ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#   0.0),
#  ('vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#   0.0),
#  ('with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   0.0),
#  ('12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0),
#  ('6 traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#   0.0),
#  ('63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   0.0),
#  ('an important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#   0.0),
#  ('and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   0.0),
#  ('are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#   0.0),
#  ('assess the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#   0.0),
#  ('b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('complication of tak and bone scintigraphy is use for its detection takayasu arteritis',
#   0.0),
#  ('convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#   0.0),
#  ('criteria ara criteria for this disease and since then the name takayasu arteritis',
#   0.0),
#  ('data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#   0.0),
#  ('diabetic neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#   0.0),
#  ('fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#   0.0),
#  ('for the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#   0.0),
#  ('formation of an activated signaling complex containing transforming growth factor β activated kinase',
#   0.0),
#  ('however the combination of these two inhibitors or the use of tak 779',
#   0.0),
#  ('identified potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#   0.0),
#  ('investigate the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#   0.0),
#  ('neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#   0.0),
#  ('plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('pubmed search through february 2014 the main characteristics of patients with takayasu arteritis',
#   0.0),
#  ('rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#   0.0),
#  ('regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   0.0),
#  ('reported a rare case of a 27 year old woman with takayasu arteritis', 0.0),
#  ('self ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#   0.0),
#  ('structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#   0.0),
#  ('the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#   0.0),
#  ('these enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#   0.0),
#  ('tnf receptor associated factor traf 6 and transforming growth factor β activated kinase',
#   0.0),
#  ('vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#   0.0),
#  ('2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   0.0),
#  ('a and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#   0.0),
#  ('and convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#   0.0),
#  ('and neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#   0.0),
#  ('compare the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#   0.0),
#  ('effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#   0.0),
#  ('eight structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#   0.0),
#  ('expression study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   0.0),
#  ('for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0),
#  ('hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('i however the combination of these two inhibitors or the use of tak 779',
#   0.0),
#  ('il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('images are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#   0.0),
#  ('large vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#   0.0),
#  ('lys 63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#   0.0),
#  ('manner fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#   0.0),
#  ('microarray data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#   0.0),
#  ('of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   0.0),
#  ('3 i however the combination of these two inhibitors or the use of tak 779',
#   0.0),
#  ('a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   0.0),
#  ('al 2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#   0.0),
#  ('clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0),
#  ('of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('of il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#   0.0),
#  ('overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#   0.0),
#  ('value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('fig 3 i however the combination of these two inhibitors or the use of tak 779',
#   0.0),
#  ('relevance of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#   0.0),
#  ('the overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#   0.0),
#  ('the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('to a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#   0.0),
#  ('were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0),
#  ('evaluate the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#   0.0),
#  ('neurospheres fig 3 i however the combination of these two inhibitors or the use of tak 779',
#   0.0),
#  ('rats were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#   0.0)]

# %%
longforms0 = miners['TAK'].get_longforms()

# %%
longforms0
# Out:
# [('takayasu arteritis', 22.3), ('activated kinase', 7.166666666666667)]

# %%
longforms0 = [x for i, x in enumerate(longforms0) if i in [0]]

# %%
list(enumerate(top))
# Out:
# [(0, ('takayasu arteritis', 22.3)),
#  (1, ('arteritis', 12.342857142857142)),
#  (2, ('activated kinase', 7.166666666666667)),
#  (3, ('takayasu s arteritis', 6.75)),
#  (4, ('with takayasu arteritis', 5.555555555555555)),
#  (5, ('β activated kinase', 3.4285714285714284)),
#  (6, ('tgf β activated kinase', 3.0)),
#  (7, ('patients with takayasu arteritis', 2.4)),
#  (8, ('transforming growth factor β activated kinase', 2.0)),
#  (9,
#   ('rations of il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    2)),
#  (10, ('of patients with takayasu arteritis', 1.3333333333333333)),
#  (11, ('tak 242', 1.0)),
#  (12, ('beta activated kinase', 1.0)),
#  (13, ('of takayasu arteritis', 1.0)),
#  (14, ('activated takayasu s arteritis', 1.0)),
#  (15, ('in patients with takayasu arteritis', 1.0)),
#  (16, ('characteristics of patients with takayasu arteritis', 1.0)),
#  (17, ('with the exception of takayasu arteritis', 1)),
#  (18, ('the tlr4 signaling pathway inhibitors tak 242', 1)),
#  (19,
#   ('a previous study revealed the associated between susceptibility to takayasu arteritis',
#    1)),
#  (20,
#   ('ependent pathway and noncanonical smad independent transforming growth factor beta activated kinase',
#    1)),
#  (21,
#   ('eritis uc ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#    1)),
#  (22,
#   ('and c peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#    1)),
#  (23,
#   ('gic therapies were associated with better control of disease activated childhood takayasu arteritis',
#    1)),
#  (24,
#   ('ne morphogenetic protein bmp signaling mediated via transforming growth factor β activated kinase',
#    1)),
#  (25,
#   ('rucial role in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#    1)),
#  (26,
#   ('study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    1.0)),
#  (27,
#   ('with mitogen activated protein kinase map2k transforming growth factor tgf β activated kinase',
#    1)),
#  (28,
#   ('12p70 these enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#    1)),
#  (29,
#   ('a pubmed search through february 2014 the main characteristics of patients with takayasu arteritis',
#    1)),
#  (30,
#   ('assification criteria ara criteria for this disease and since then the name takayasu arteritis',
#    1)),
#  (31,
#   ('e formation of an activated signaling complex containing transforming growth factor β activated kinase',
#    1)),
#  (32,
#   ('f6 self ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#    1)),
#  (33,
#   ('factor tnf receptor associated factor traf 6 and transforming growth factor β activated kinase',
#    1)),
#  (34,
#   ('mportant complication of tak and bone scintigraphy is use for its detection takayasu arteritis',
#    1)),
#  (35,
#   ('of diabetic neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#    1)),
#  (36,
#   ('proaches for the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    1)),
#  (37,
#   ('s an important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#    1)),
#  (38,
#   ('s identified potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#    1)),
#  (39,
#   ('to assess the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#    1)),
#  (40,
#   ('to investigate the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#    1)),
#  (41,
#   ('tor 6 traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    1)),
#  (42,
#   ('we reported a rare case of a 27 year old woman with takayasu arteritis',
#    1)),
#  (43,
#   ('compare eight structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#    1)),
#  (44,
#   ('dent manner fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#    1)),
#  (45,
#   ('gers lys 63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    1)),
#  (46,
#   ('ion microarray data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#    1)),
#  (47,
#   ('its expression study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    1)),
#  (48,
#   ('o and neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#    1)),
#  (49,
#   ('ple and convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#    1)),
#  (50,
#   ('representative images are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#    1)),
#  (51,
#   ('ry large vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#    1)),
#  (52,
#   ('s a and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    1)),
#  (53,
#   ('to compare the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#    1)),
#  (54,
#   ('et al 2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    1)),
#  (55,
#   ('e the overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    1)),
#  (56,
#   ('ept to a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    1)),
#  (57,
#   ('onal relevance of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    1)),
#  (58,
#   ('f rats were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    1)),
#  (59,
#   ('o neurospheres fig 3 i however the combination of these two inhibitors or the use of tak 779',
#    1)),
#  (60,
#   ('to evaluate the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    1)),
#  (61, ('044', 0.0)),
#  (62, ('242', 0.0)),
#  (63, ('632', 0.0)),
#  (64, ('779', 0.0)),
#  (65, ('kinase', 0.0)),
#  (66, ('s arteritis', 0.0)),
#  (67, ('tak 044', 0.0)),
#  (68, ('tak 632', 0.0)),
#  (69, ('tak 779', 0.0)),
#  (70, ('2007 tak 632', 0.0)),
#  (71, ('childhood takayasu arteritis', 0.0)),
#  (72, ('detection takayasu arteritis', 0.0)),
#  (73, ('disease takayasu arteritis', 0.0)),
#  (74, ('especially takayasu arteritis', 0.0)),
#  (75, ('evaluate tak 242', 0.0)),
#  (76, ('formation takayasu arteritis', 0.0)),
#  (77, ('include takayasu arteritis', 0.0)),
#  (78, ('inhibitors tak 242', 0.0)),
#  (79, ('name takayasu arteritis', 0.0)),
#  (80, ('of tak 779', 0.0)),
#  (81, ('performed tak 044', 0.0)),
#  (82, ('tak takayasu arteritis', 0.0)),
#  (83, ('tgfβ activated kinase', 0.0)),
#  (84, ('to takayasu arteritis', 0.0)),
#  (85, ('β1 activated kinase', 0.0)),
#  (86, ('80 takayasu s arteritis', 0.0)),
#  (87, ('activated childhood takayasu arteritis', 0.0)),
#  (88, ('al 2007 tak 632', 0.0)),
#  (89, ('and include takayasu arteritis', 0.0)),
#  (90, ('cell of takayasu arteritis', 0.0)),
#  (91, ('chinese takayasu s arteritis', 0.0)),
#  (92, ('exception of takayasu arteritis', 0.0)),
#  (93, ('factor beta activated kinase', 0.0)),
#  (94, ('factor β activated kinase', 0.0)),
#  (95, ('further evaluate tak 242', 0.0)),
#  (96, ('further takayasu s arteritis', 0.0)),
#  (97, ('in takayasu s arteritis', 0.0)),
#  (98, ('inflammasome formation takayasu arteritis', 0.0)),
#  (99, ('its detection takayasu arteritis', 0.0)),
#  (100, ('of tak takayasu arteritis', 0.0)),
#  (101, ('of takayasu s arteritis', 0.0)),
#  (102, ('of tgfβ activated kinase', 0.0)),
#  (103, ('pathway inhibitors tak 242', 0.0)),
#  (104, ('pt with takayasu arteritis', 0.0)),
#  (105, ('relapse takayasu s arteritis', 0.0)),
#  (106, ('rs665268 with takayasu arteritis', 0.0)),
#  (107, ('susceptibility to takayasu arteritis', 0.0)),
#  (108, ('tgf beta activated kinase', 0.0)),
#  (109, ('tgf β1 activated kinase', 0.0)),
#  (110, ('the disease takayasu arteritis', 0.0)),
#  (111, ('the name takayasu arteritis', 0.0)),
#  (112, ('use of tak 779', 0.0)),
#  (113, ('vasculitis especially takayasu arteritis', 0.0)),
#  (114, ('was performed tak 044', 0.0)),
#  (115, ('woman with takayasu arteritis', 0.0)),
#  (116, ('activated in takayasu s arteritis', 0.0)),
#  (117, ('activated of tgfβ activated kinase', 0.0)),
#  (118, ('and activated takayasu s arteritis', 0.0)),
#  (119, ('be further evaluate tak 242', 0.0)),
#  (120, ('between susceptibility to takayasu arteritis', 0.0)),
#  (121, ('branches and include takayasu arteritis', 0.0)),
#  (122, ('disease activated childhood takayasu arteritis', 0.0)),
#  (123, ('disease activated takayasu s arteritis', 0.0)),
#  (124, ('et al 2007 tak 632', 0.0)),
#  (125, ('explored further takayasu s arteritis', 0.0)),
#  (126, ('factor tgf β activated kinase', 0.0)),
#  (127, ('for its detection takayasu arteritis', 0.0)),
#  (128, ('for tgf beta activated kinase', 0.0)),
#  (129, ('growth factor beta activated kinase', 0.0)),
#  (130, ('growth factor β activated kinase', 0.0)),
#  (131, ('hepatectomy was performed tak 044', 0.0)),
#  (132, ('is 80 takayasu s arteritis', 0.0)),
#  (133, ('mononuclear cell of takayasu arteritis', 0.0)),
#  (134, ('of relapse takayasu s arteritis', 0.0)),
#  (135, ('of the disease takayasu arteritis', 0.0)),
#  (136, ('old woman with takayasu arteritis', 0.0)),
#  (137, ('on chinese takayasu s arteritis', 0.0)),
#  (138, ('pathophysiology of tak takayasu arteritis', 0.0)),
#  (139, ('patients pt with takayasu arteritis', 0.0)),
#  (140, ('polymorphism rs665268 with takayasu arteritis', 0.0)),
#  (141, ('promoting inflammasome formation takayasu arteritis', 0.0)),
#  (142, ('recruits tgf β activated kinase', 0.0)),
#  (143, ('signaling pathway inhibitors tak 242', 0.0)),
#  (144, ('that tgf β1 activated kinase', 0.0)),
#  (145, ('the exception of takayasu arteritis', 0.0)),
#  (146, ('the tgf β activated kinase', 0.0)),
#  (147, ('the use of tak 779', 0.0)),
#  (148, ('then the name takayasu arteritis', 0.0)),
#  (149, ('treatment of takayasu s arteritis', 0.0)),
#  (150, ('vessel vasculitis especially takayasu arteritis', 0.0)),
#  (151, ('with tgf β activated kinase', 0.0)),
#  (152, ('12p70 in patients with takayasu arteritis', 0.0)),
#  (153, ('2009 that tgf β1 activated kinase', 0.0)),
#  (154, ('associated between susceptibility to takayasu arteritis', 0.0)),
#  (155, ('be explored further takayasu s arteritis', 0.0)),
#  (156, ('blood mononuclear cell of takayasu arteritis', 0.0)),
#  (157, ('complex with tgf β activated kinase', 0.0)),
#  (158, ('disease activated in takayasu s arteritis', 0.0)),
#  (159, ('growth factor tgf β activated kinase', 0.0)),
#  (160, ('in patients pt with takayasu arteritis', 0.0)),
#  (161, ('inactive and activated takayasu s arteritis', 0.0)),
#  (162, ('involve activated of tgfβ activated kinase', 0.0)),
#  (163, ('its branches and include takayasu arteritis', 0.0)),
#  (164, ('large vessel vasculitis especially takayasu arteritis', 0.0)),
#  (165, ('macrophages of patients with takayasu arteritis', 0.0)),
#  (166, ('mcdermott et al 2007 tak 632', 0.0)),
#  (167, ('mlx polymorphism rs665268 with takayasu arteritis', 0.0)),
#  (168, ('mmf on chinese takayasu s arteritis', 0.0)),
#  (169, ('of disease activated childhood takayasu arteritis', 0.0)),
#  (170, ('of the tgf β activated kinase', 0.0)),
#  (171, ('or the use of tak 779', 0.0)),
#  (172, ('partial hepatectomy was performed tak 044', 0.0)),
#  (173, ('proposed for tgf beta activated kinase', 0.0)),
#  (174, ('risk of relapse takayasu s arteritis', 0.0)),
#  (175, ('rtx in patients with takayasu arteritis', 0.0)),
#  (176, ('should be further evaluate tak 242', 0.0)),
#  (177, ('since then the name takayasu arteritis', 0.0)),
#  (178, ('tak disease activated takayasu s arteritis', 0.0)),
#  (179, ('tak is 80 takayasu s arteritis', 0.0)),
#  (180, ('the pathophysiology of tak takayasu arteritis', 0.0)),
#  (181, ('the treatment of takayasu s arteritis', 0.0)),
#  (182, ('through promoting inflammasome formation takayasu arteritis', 0.0)),
#  (183, ('tlr4 signaling pathway inhibitors tak 242', 0.0)),
#  (184, ('traf6 recruits tgf β activated kinase', 0.0)),
#  (185, ('transforming growth factor beta activated kinase', 0.0)),
#  (186, ('treatment of the disease takayasu arteritis', 0.0)),
#  (187, ('use for its detection takayasu arteritis', 0.0)),
#  (188, ('year old woman with takayasu arteritis', 0.0)),
#  (189, ('27 year old woman with takayasu arteritis', 0.0)),
#  (190, ('70 partial hepatectomy was performed tak 044', 0.0)),
#  (191, ('a complex with tgf β activated kinase', 0.0)),
#  (192, ('activated of the tgf β activated kinase', 0.0)),
#  (193, ('al 2009 that tgf β1 activated kinase', 0.0)),
#  (194, ('and its branches and include takayasu arteritis', 0.0)),
#  (195, ('and since then the name takayasu arteritis', 0.0)),
#  (196, ('and transforming growth factor β activated kinase', 0.0)),
#  (197, ('and treatment of the disease takayasu arteritis', 0.0)),
#  (198, ('az mcdermott et al 2007 tak 632', 0.0)),
#  (199, ('can involve activated of tgfβ activated kinase', 0.0)),
#  (200, ('containing transforming growth factor β activated kinase', 0.0)),
#  (201, ('control of disease activated childhood takayasu arteritis', 0.0)),
#  (202, ('derived macrophages of patients with takayasu arteritis', 0.0)),
#  (203, ('for the treatment of takayasu s arteritis', 0.0)),
#  (204, ('higher in patients pt with takayasu arteritis', 0.0)),
#  (205, ('il 12p70 in patients with takayasu arteritis', 0.0)),
#  (206, ('in the pathophysiology of tak takayasu arteritis', 0.0)),
#  (207, ('independent transforming growth factor beta activated kinase', 0.0)),
#  (208, ('inhibitors or the use of tak 779', 0.0)),
#  (209, ('is use for its detection takayasu arteritis', 0.0)),
#  (210, ('main characteristics of patients with takayasu arteritis', 0.0)),
#  (211, ('mofetil mmf on chinese takayasu s arteritis', 0.0)),
#  (212, ('monitor disease activated in takayasu s arteritis', 0.0)),
#  (213, ('of mlx polymorphism rs665268 with takayasu arteritis', 0.0)),
#  (214, ('of tak disease activated takayasu s arteritis', 0.0)),
#  (215, ('pain should be further evaluate tak 242', 0.0)),
#  (216, ('pattern proposed for tgf beta activated kinase', 0.0)),
#  (217, ('peripheral blood mononuclear cell of takayasu arteritis', 0.0)),
#  (218, ('rituximab rtx in patients with takayasu arteritis', 0.0)),
#  (219,
#   ('tak through promoting inflammasome formation takayasu arteritis', 0.0)),
#  (220, ('the associated between susceptibility to takayasu arteritis', 0.0)),
#  (221, ('the risk of relapse takayasu s arteritis', 0.0)),
#  (222, ('to be explored further takayasu s arteritis', 0.0)),
#  (223, ('transforming growth factor tgf β activated kinase', 0.0)),
#  (224, ('treating tak is 80 takayasu s arteritis', 0.0)),
#  (225, ('ubiquitination traf6 recruits tgf β activated kinase', 0.0)),
#  (226, ('vascular characteristics of patients with takayasu arteritis', 0.0)),
#  (227, ('via transforming growth factor β activated kinase', 0.0)),
#  (228, ('with inactive and activated takayasu s arteritis', 0.0)),
#  (229, ('with large vessel vasculitis especially takayasu arteritis', 0.0)),
#  (230, ('6 and transforming growth factor β activated kinase', 0.0)),
#  (231, ('628 az mcdermott et al 2007 tak 632', 0.0)),
#  (232, ('a 27 year old woman with takayasu arteritis', 0.0)),
#  (233, ('a 70 partial hepatectomy was performed tak 044', 0.0)),
#  (234, ('aorta and its branches and include takayasu arteritis', 0.0)),
#  (235,
#   ('associated of mlx polymorphism rs665268 with takayasu arteritis', 0.0)),
#  (236,
#   ('better control of disease activated childhood takayasu arteritis', 0.0)),
#  (237, ('cell derived macrophages of patients with takayasu arteritis', 0.0)),
#  (238,
#   ('complex containing transforming growth factor β activated kinase', 0.0)),
#  (239, ('disease and since then the name takayasu arteritis', 0.0)),
#  (240, ('et al 2009 that tgf β1 activated kinase', 0.0)),
#  (241, ('evaluate of tak disease activated takayasu s arteritis', 0.0)),
#  (242, ('expression pattern proposed for tgf beta activated kinase', 0.0)),
#  (243, ('forms a complex with tgf β activated kinase', 0.0)),
#  (244, ('from peripheral blood mononuclear cell of takayasu arteritis', 0.0)),
#  (245, ('in treating tak is 80 takayasu s arteritis', 0.0)),
#  (246, ('map2k transforming growth factor tgf β activated kinase', 0.0)),
#  (247, ('mediated via transforming growth factor β activated kinase', 0.0)),
#  (248, ('mycophenolate mofetil mmf on chinese takayasu s arteritis', 0.0)),
#  (249, ('needs to be explored further takayasu s arteritis', 0.0)),
#  (250, ('neuropathic pain should be further evaluate tak 242', 0.0)),
#  (251, ('of il 12p70 in patients with takayasu arteritis', 0.0)),
#  (252, ('of rituximab rtx in patients with takayasu arteritis', 0.0)),
#  (253,
#   ('of tak through promoting inflammasome formation takayasu arteritis', 0.0)),
#  (254, ('pathogenesis and treatment of the disease takayasu arteritis', 0.0)),
#  (255, ('pathway can involve activated of tgfβ activated kinase', 0.0)),
#  (256, ('patients with inactive and activated takayasu s arteritis', 0.0)),
#  (257,
#   ('patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (258, ('placebo for the treatment of takayasu s arteritis', 0.0)),
#  (259, ('reduce the risk of relapse takayasu s arteritis', 0.0)),
#  (260,
#   ('revealed the associated between susceptibility to takayasu arteritis',
#    0.0)),
#  (261, ('role in the pathophysiology of tak takayasu arteritis', 0.0)),
#  (262, ('scintigraphy is use for its detection takayasu arteritis', 0.0)),
#  (263, ('significantly higher in patients pt with takayasu arteritis', 0.0)),
#  (264,
#   ('smad independent transforming growth factor beta activated kinase', 0.0)),
#  (265, ('subsequent activated of the tgf β activated kinase', 0.0)),
#  (266, ('the main characteristics of patients with takayasu arteritis', 0.0)),
#  (267, ('to monitor disease activated in takayasu s arteritis', 0.0)),
#  (268, ('two inhibitors or the use of tak 779', 0.0)),
#  (269,
#   ('ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (270,
#   ('vasc vascular characteristics of patients with takayasu arteritis', 0.0)),
#  (271,
#   ('2014 the main characteristics of patients with takayasu arteritis', 0.0)),
#  (272, ('and a 70 partial hepatectomy was performed tak 044', 0.0)),
#  (273, ('and subsequent activated of the tgf β activated kinase', 0.0)),
#  (274, ('az 628 az mcdermott et al 2007 tak 632', 0.0)),
#  (275,
#   ('between patients with inactive and activated takayasu s arteritis', 0.0)),
#  (276, ('bone scintigraphy is use for its detection takayasu arteritis', 0.0)),
#  (277, ('churchman et al 2009 that tgf β1 activated kinase', 0.0)),
#  (278,
#   ('clinical evaluate of tak disease activated takayasu s arteritis', 0.0)),
#  (279,
#   ('colitis vasc vascular characteristics of patients with takayasu arteritis',
#    0.0)),
#  (280,
#   ('derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (281, ('diabetic neuropathic pain should be further evaluate tak 242', 0.0)),
#  (282,
#   ('kinase map2k transforming growth factor tgf β activated kinase', 0.0)),
#  (283, ('levels of il 12p70 in patients with takayasu arteritis', 0.0)),
#  (284, ('markers to monitor disease activated in takayasu s arteritis', 0.0)),
#  (285, ('mmf in treating tak is 80 takayasu s arteritis', 0.0)),
#  (286,
#   ('mononuclear cell derived macrophages of patients with takayasu arteritis',
#    0.0)),
#  (287,
#   ('noncanonical smad independent transforming growth factor beta activated kinase',
#    0.0)),
#  (288, ('not reduce the risk of relapse takayasu s arteritis', 0.0)),
#  (289, ('of a 27 year old woman with takayasu arteritis', 0.0)),
#  (290, ('of mycophenolate mofetil mmf on chinese takayasu s arteritis', 0.0)),
#  (291,
#   ('pathogenesis needs to be explored further takayasu s arteritis', 0.0)),
#  (292,
#   ('pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#    0.0)),
#  (293, ('play role in the pathophysiology of tak takayasu arteritis', 0.0)),
#  (294, ('safety of rituximab rtx in patients with takayasu arteritis', 0.0)),
#  (295,
#   ('signaling complex containing transforming growth factor β activated kinase',
#    0.0)),
#  (296,
#   ('signaling mediated via transforming growth factor β activated kinase',
#    0.0)),
#  (297,
#   ('signaling pathway can involve activated of tgfβ activated kinase', 0.0)),
#  (298,
#   ('some patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (299,
#   ('study revealed the associated between susceptibility to takayasu arteritis',
#    0.0)),
#  (300,
#   ('tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    0.0)),
#  (301, ('the aorta and its branches and include takayasu arteritis', 0.0)),
#  (302, ('the expression pattern proposed for tgf beta activated kinase', 0.0)),
#  (303,
#   ('the pathogenesis and treatment of the disease takayasu arteritis', 0.0)),
#  (304,
#   ('their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (305, ('these two inhibitors or the use of tak 779', 0.0)),
#  (306, ('this disease and since then the name takayasu arteritis', 0.0)),
#  (307, ('to placebo for the treatment of takayasu s arteritis', 0.0)),
#  (308, ('traf 6 and transforming growth factor β activated kinase', 0.0)),
#  (309, ('traf6 forms a complex with tgf β activated kinase', 0.0)),
#  (310,
#   ('were significantly higher in patients pt with takayasu arteritis', 0.0)),
#  (311,
#   ('with better control of disease activated childhood takayasu arteritis',
#    0.0)),
#  (312,
#   ('12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (313,
#   ('54 the expression pattern proposed for tgf beta activated kinase', 0.0)),
#  (314,
#   ('abatacept to placebo for the treatment of takayasu s arteritis', 0.0)),
#  (315,
#   ('activated signaling complex containing transforming growth factor β activated kinase',
#    0.0)),
#  (316,
#   ('affect the aorta and its branches and include takayasu arteritis', 0.0)),
#  (317,
#   ('and bone scintigraphy is use for its detection takayasu arteritis', 0.0)),
#  (318,
#   ('and noncanonical smad independent transforming growth factor beta activated kinase',
#    0.0)),
#  (319,
#   ('and safety of rituximab rtx in patients with takayasu arteritis', 0.0)),
#  (320,
#   ('as markers to monitor disease activated in takayasu s arteritis', 0.0)),
#  (321,
#   ('associated with better control of disease activated childhood takayasu arteritis',
#    0.0)),
#  (322,
#   ('blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#    0.0)),
#  (323,
#   ('bmp signaling mediated via transforming growth factor β activated kinase',
#    0.0)),
#  (324, ('case of a 27 year old woman with takayasu arteritis', 0.0)),
#  (325, ('did not reduce the risk of relapse takayasu s arteritis', 0.0)),
#  (326,
#   ('effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#    0.0)),
#  (327,
#   ('factor traf 6 and transforming growth factor β activated kinase', 0.0)),
#  (328,
#   ('february 2014 the main characteristics of patients with takayasu arteritis',
#    0.0)),
#  (329, ('for this disease and since then the name takayasu arteritis', 0.0)),
#  (330,
#   ('in some patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (331,
#   ('in the pathogenesis and treatment of the disease takayasu arteritis',
#    0.0)),
#  (332, ('include mmf in treating tak is 80 takayasu s arteritis', 0.0)),
#  (333, ('inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0)),
#  (334,
#   ('lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (335,
#   ('might play role in the pathophysiology of tak takayasu arteritis', 0.0)),
#  (336,
#   ('of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    0.0)),
#  (337, ('of these two inhibitors or the use of tak 779', 0.0)),
#  (338,
#   ('polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    0.0)),
#  (339,
#   ('previous study revealed the associated between susceptibility to takayasu arteritis',
#    0.0)),
#  (340,
#   ('protein kinase map2k transforming growth factor tgf β activated kinase',
#    0.0)),
#  (341,
#   ('ratio between patients with inactive and activated takayasu s arteritis',
#    0.0)),
#  (342,
#   ('relieves diabetic neuropathic pain should be further evaluate tak 242',
#    0.0)),
#  (343, ('reported churchman et al 2009 that tgf β1 activated kinase', 0.0)),
#  (344, ('serum levels of il 12p70 in patients with takayasu arteritis', 0.0)),
#  (345,
#   ('smad signaling pathway can involve activated of tgfβ activated kinase',
#    0.0)),
#  (346,
#   ('tak pathogenesis needs to be explored further takayasu s arteritis', 0.0)),
#  (347,
#   ('the clinical evaluate of tak disease activated takayasu s arteritis',
#    0.0)),
#  (348,
#   ('the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#    0.0)),
#  (349,
#   ('to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (350,
#   ('ubiquitination traf6 forms a complex with tgf β activated kinase', 0.0)),
#  (351,
#   ('ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#    0.0)),
#  (352, ('unclamped and a 70 partial hepatectomy was performed tak 044', 0.0)),
#  (353,
#   ('activated protein kinase map2k transforming growth factor tgf β activated kinase',
#    0.0)),
#  (354,
#   ('an activated signaling complex containing transforming growth factor β activated kinase',
#    0.0)),
#  (355,
#   ('and relieves diabetic neuropathic pain should be further evaluate tak 242',
#    0.0)),
#  (356,
#   ('associated factor traf 6 and transforming growth factor β activated kinase',
#    0.0)),
#  (357,
#   ('been reported churchman et al 2009 that tgf β1 activated kinase', 0.0)),
#  (358, ('combination of these two inhibitors or the use of tak 779', 0.0)),
#  (359,
#   ('criteria for this disease and since then the name takayasu arteritis',
#    0.0)),
#  (360,
#   ('cytokines might play role in the pathophysiology of tak takayasu arteritis',
#    0.0)),
#  (361,
#   ('e serum levels of il 12p70 in patients with takayasu arteritis', 0.0)),
#  (362,
#   ('efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#    0.0)),
#  (363,
#   ('following ubiquitination traf6 forms a complex with tgf β activated kinase',
#    0.0)),
#  (364,
#   ('for the clinical evaluate of tak disease activated takayasu s arteritis',
#    0.0)),
#  (365,
#   ('gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#    0.0)),
#  (366,
#   ('il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (367,
#   ('in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (368,
#   ('in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#    0.0)),
#  (369,
#   ('leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (370,
#   ('lvv affect the aorta and its branches and include takayasu arteritis',
#    0.0)),
#  (371,
#   ('lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#    0.0)),
#  (372,
#   ('nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (373,
#   ('non smad signaling pathway can involve activated of tgfβ activated kinase',
#    0.0)),
#  (374,
#   ('of abatacept to placebo for the treatment of takayasu s arteritis', 0.0)),
#  (375,
#   ('pathway and noncanonical smad independent transforming growth factor beta activated kinase',
#    0.0)),
#  (376,
#   ('peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#    0.0)),
#  (377,
#   ('prednisone did not reduce the risk of relapse takayasu s arteritis', 0.0)),
#  (378,
#   ('problem in some patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (379,
#   ('protein bmp signaling mediated via transforming growth factor β activated kinase',
#    0.0)),
#  (380, ('raf inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0)),
#  (381, ('rare case of a 27 year old woman with takayasu arteritis', 0.0)),
#  (382,
#   ('t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (383,
#   ('tak and bone scintigraphy is use for its detection takayasu arteritis',
#    0.0)),
#  (384,
#   ('targets in the pathogenesis and treatment of the disease takayasu arteritis',
#    0.0)),
#  (385,
#   ('then unclamped and a 70 partial hepatectomy was performed tak 044', 0.0)),
#  (386,
#   ('therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#    0.0)),
#  (387,
#   ('therapies include mmf in treating tak is 80 takayasu s arteritis', 0.0)),
#  (388,
#   ('through february 2014 the main characteristics of patients with takayasu arteritis',
#    0.0)),
#  (389,
#   ('traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    0.0)),
#  (390,
#   ('treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    0.0)),
#  (391,
#   ('uc ulcerative colitis vasc vascular characteristics of patients with takayasu arteritis',
#    0.0)),
#  (392,
#   ('were associated with better control of disease activated childhood takayasu arteritis',
#    0.0)),
#  (393,
#   ('1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#    0.0)),
#  (394,
#   ('52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (395, ('a rare case of a 27 year old woman with takayasu arteritis', 0.0)),
#  (396,
#   ('and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (397,
#   ('and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (398,
#   ('ara criteria for this disease and since then the name takayasu arteritis',
#    0.0)),
#  (399,
#   ('b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (400,
#   ('c peripheral blood mononuclear cell derived macrophages of patients with takayasu arteritis',
#    0.0)),
#  (401, ('diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632', 0.0)),
#  (402,
#   ('efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#    0.0)),
#  (403,
#   ('enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#    0.0)),
#  (404,
#   ('has been reported churchman et al 2009 that tgf β1 activated kinase',
#    0.0)),
#  (405,
#   ('important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (406,
#   ('in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#    0.0)),
#  (407,
#   ('linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    0.0)),
#  (408,
#   ('method for the clinical evaluate of tak disease activated takayasu s arteritis',
#    0.0)),
#  (409,
#   ('min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0)),
#  (410,
#   ('mitogen activated protein kinase map2k transforming growth factor tgf β activated kinase',
#    0.0)),
#  (411,
#   ('morphogenetic protein bmp signaling mediated via transforming growth factor β activated kinase',
#    0.0)),
#  (412,
#   ('neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#    0.0)),
#  (413,
#   ('of an activated signaling complex containing transforming growth factor β activated kinase',
#    0.0)),
#  (414,
#   ('of tak and bone scintigraphy is use for its detection takayasu arteritis',
#    0.0)),
#  (415,
#   ('of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    0.0)),
#  (416,
#   ('potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#    0.0)),
#  (417,
#   ('receptor associated factor traf 6 and transforming growth factor β activated kinase',
#    0.0)),
#  (418,
#   ('role in the pathogenesis of tak through promoting inflammasome formation takayasu arteritis',
#    0.0)),
#  (419,
#   ('search through february 2014 the main characteristics of patients with takayasu arteritis',
#    0.0)),
#  (420,
#   ('shown e serum levels of il 12p70 in patients with takayasu arteritis',
#    0.0)),
#  (421, ('the combination of these two inhibitors or the use of tak 779', 0.0)),
#  (422,
#   ('the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#    0.0)),
#  (423,
#   ('the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#    0.0)),
#  (424,
#   ('the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    0.0)),
#  (425,
#   ('therapies were associated with better control of disease activated childhood takayasu arteritis',
#    0.0)),
#  (426,
#   ('to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#    0.0)),
#  (427,
#   ('traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (428,
#   ('ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#    0.0)),
#  (429,
#   ('vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#    0.0)),
#  (430,
#   ('with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    0.0)),
#  (431,
#   ('12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (432,
#   ('20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0)),
#  (433,
#   ('6 traf6 leading to their ubiquitination ubiquitination traf6 recruits tgf β activated kinase',
#    0.0)),
#  (434,
#   ('63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    0.0)),
#  (435,
#   ('an important problem in some patients with large vessel vasculitis especially takayasu arteritis',
#    0.0)),
#  (436,
#   ('and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (437,
#   ('are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#    0.0)),
#  (438,
#   ('assess the efficacy and safety of rituximab rtx in patients with takayasu arteritis',
#    0.0)),
#  (439,
#   ('b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (440,
#   ('complication of tak and bone scintigraphy is use for its detection takayasu arteritis',
#    0.0)),
#  (441,
#   ('convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#    0.0)),
#  (442,
#   ('criteria ara criteria for this disease and since then the name takayasu arteritis',
#    0.0)),
#  (443,
#   ('data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#    0.0)),
#  (444,
#   ('diabetic neuropathy and relieves diabetic neuropathic pain should be further evaluate tak 242',
#    0.0)),
#  (445,
#   ('fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#    0.0)),
#  (446,
#   ('for the treatment of tak associated of mlx polymorphism rs665268 with takayasu arteritis',
#    0.0)),
#  (447,
#   ('formation of an activated signaling complex containing transforming growth factor β activated kinase',
#    0.0)),
#  (448,
#   ('however the combination of these two inhibitors or the use of tak 779',
#    0.0)),
#  (449,
#   ('identified potential targets in the pathogenesis and treatment of the disease takayasu arteritis',
#    0.0)),
#  (450,
#   ('investigate the therapeutic effect of mycophenolate mofetil mmf on chinese takayasu s arteritis',
#    0.0)),
#  (451,
#   ('neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#    0.0)),
#  (452,
#   ('plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (453,
#   ('pubmed search through february 2014 the main characteristics of patients with takayasu arteritis',
#    0.0)),
#  (454,
#   ('rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    0.0)),
#  (455,
#   ('regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    0.0)),
#  (456,
#   ('reported a rare case of a 27 year old woman with takayasu arteritis',
#    0.0)),
#  (457,
#   ('self ubiquitination following ubiquitination traf6 forms a complex with tgf β activated kinase',
#    0.0)),
#  (458,
#   ('structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#    0.0)),
#  (459,
#   ('the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#    0.0)),
#  (460,
#   ('these enhanced cytokines might play role in the pathophysiology of tak takayasu arteritis',
#    0.0)),
#  (461,
#   ('tnf receptor associated factor traf 6 and transforming growth factor β activated kinase',
#    0.0)),
#  (462,
#   ('vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#    0.0)),
#  (463,
#   ('2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    0.0)),
#  (464,
#   ('a and b t lymphocyte derived from peripheral blood mononuclear cell of takayasu arteritis',
#    0.0)),
#  (465,
#   ('and convenient method for the clinical evaluate of tak disease activated takayasu s arteritis',
#    0.0)),
#  (466,
#   ('and neutrophil to lymphocyte ratio between patients with inactive and activated takayasu s arteritis',
#    0.0)),
#  (467,
#   ('compare the efficacy of abatacept to placebo for the treatment of takayasu s arteritis',
#    0.0)),
#  (468,
#   ('effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    0.0)),
#  (469,
#   ('eight structurally diverse raf inhibitors az 628 az mcdermott et al 2007 tak 632',
#    0.0)),
#  (470,
#   ('expression study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    0.0)),
#  (471,
#   ('for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0)),
#  (472,
#   ('hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (473,
#   ('i however the combination of these two inhibitors or the use of tak 779',
#    0.0)),
#  (474,
#   ('il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (475,
#   ('images are shown e serum levels of il 12p70 in patients with takayasu arteritis',
#    0.0)),
#  (476,
#   ('large vessel vasculitides lvv affect the aorta and its branches and include takayasu arteritis',
#    0.0)),
#  (477,
#   ('lys 63 linked traf4 polyubiquitylation and subsequent activated of the tgf β activated kinase',
#    0.0)),
#  (478,
#   ('manner fig 1 non smad signaling pathway can involve activated of tgfβ activated kinase',
#    0.0)),
#  (479,
#   ('microarray data in gudmap 54 the expression pattern proposed for tgf beta activated kinase',
#    0.0)),
#  (480,
#   ('of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (481,
#   ('treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    0.0)),
#  (482,
#   ('3 i however the combination of these two inhibitors or the use of tak 779',
#    0.0)),
#  (483,
#   ('a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    0.0)),
#  (484,
#   ('al 2000 study has been reported churchman et al 2009 that tgf β1 activated kinase',
#    0.0)),
#  (485,
#   ('clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0)),
#  (486,
#   ('of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (487,
#   ('of il 12p40 and il 12p70 were significantly higher in patients pt with takayasu arteritis',
#    0.0)),
#  (488,
#   ('overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    0.0)),
#  (489,
#   ('value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (490,
#   ('fig 3 i however the combination of these two inhibitors or the use of tak 779',
#    0.0)),
#  (491,
#   ('relevance of hla b 52 in tak pathogenesis needs to be explored further takayasu s arteritis',
#    0.0)),
#  (492,
#   ('the overall effect rate of therapies include mmf in treating tak is 80 takayasu s arteritis',
#    0.0)),
#  (493,
#   ('the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (494,
#   ('to a treatment regimen with prednisone did not reduce the risk of relapse takayasu s arteritis',
#    0.0)),
#  (495,
#   ('were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0)),
#  (496,
#   ('evaluate the value of plr and nlr as markers to monitor disease activated in takayasu s arteritis',
#    0.0)),
#  (497,
#   ('neurospheres fig 3 i however the combination of these two inhibitors or the use of tak 779',
#    0.0)),
#  (498,
#   ('rats were clamped for 20 min then unclamped and a 70 partial hepatectomy was performed tak 044',
#    0.0))]

# %%
longforms0.extend([x for i, x in enumerate(top) if i in [6, 8]])

# %%
longforms0
# Out:
# [('takayasu arteritis', 22.3),
#  ('tgf β activated kinase', 3.0),
#  ('transforming growth factor β activated kinase', 2.0)]

# %%
longforms0.sort(key=lambda x: -x[1])

# %%
longforms, scores = zip(*longforms0)

# %%
longforms
# Out:
# ('takayasu arteritis',
#  'tgf β activated kinase',
#  'transforming growth factor β activated kinase')

# %%
grounding_map = {}
names = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
        names[grounding_map[longform]] = grounding[2]

# %%
grounding_map
# Out:
# {'takayasu arteritis': 'MESH:D013625'}

# %%
names
# Out:
# {'MESH:D013625': 'Takayasu Arteritis'}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map, names=names)

# %%
names.update({f'HGNC:{get_hgnc_id(gene)}': gene for gene in genes})
pos_labels = list(set(pos_labels) | set(f'HGNC:{get_hgnc_id(gene)}' for gene in genes))

# %%
pos_labels
# Out:
# ['HGNC:6859', 'HGNC:1780', 'MESH:D013625']

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'takayasu arteritis': 'MESH:D013625',
#   'tgf β activated kinase': 'HGNC:6859',
#   'transforming growth factor β activated kinase': 'HGNC:6859'},
#  {'MESH:D013625': 'Takayasu Arteritis',
#   'HGNC:6859': 'MAP3K7',
#   'HGNC:1780': 'CDK9'},
#  ['HGNC:6859', 'HGNC:1780', 'MESH:D013625'])

# %%
grounding_map, names, pos_labels = ({'takayasu arteritis': 'MESH:D013625',
  'tgf β activated kinase': 'HGNC:6859',
  'transforming growth factor β activated kinase': 'HGNC:6859'},
 {'MESH:D013625': 'Takayasu Arteritis',
  'HGNC:6859': 'MAP3K7',
  'HGNC:1780': 'CDK9'},
 ['HGNC:6859', 'HGNC:1780', 'MESH:D013625'])

# %%
grounding_dict = {'TAK': grounding_map}

# %%
classifier = AdeftClassifier('TAK', pos_labels=pos_labels, random_state=1729)

# %%
param_grid = {'C': [100.0], 'max_features': [10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
takeda_texts = [(text, 'ungrounded') for text in shortform_texts if re.search(r'TAK[\s-]?[1-9]{3}', text)]

# %%
len(takeda_texts)
# Out:
# 34

# %%
corpus.extend(takeda_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-8be5f180a725> in <module>
# ----> 1 classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
#
# ~/adeft/adeft/modeling/classify.py in cv(self, texts, y, param_grid, n_jobs, cv)
#     139         """
#     140         # Initialize pipeline
# --> 141         seed = self.random_state
#     142         logit_pipeline = Pipeline([('tfidf',
#     143                                     TfidfVectorizer(ngram_range=(1, 2),
#
# AttributeError: 'AdeftClassifier' object has no attribute 'random_state'

# %%
classifier.stats
# Out:
# {'label_distribution': {'MESH:D013625': 13,
#   'HGNC:6859': 324,
#   'HGNC:1780': 384,
#   'ungrounded': 34},
#  'f1': {'mean': 0.9465550518709265, 'std': 0.016695552638681083},
#  'precision': {'mean': 0.9433116657968711, 'std': 0.01511936783513322},
#  'recall': {'mean': 0.9514626841508823, 'std': 0.0199721773884108}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0].startswith('HGNC:1')]

# %%
a[2]
# Out:
# 'EFS (2–32 Hz) induced frequency-dependent contractions of prostate strips, which were inhibited by SBE 13 (1 μM), cyclapolin 9 (3 μM), TAK 960 (100 nM), and Ro 3280 (100 nM) ( Figure  4 ). Two-way ANOVA was conducted to compare inhibitor and control groups, and indicated that the inhibition by SBE 13 ( p  < 0.02), cyclapolin 9 ( p  < 0.03), TAK 960 ( p  < 0.007), and Ro 3280 ( p  < 0.04) was significant. Multivariate analysis revealed that inhibition was significant for all four inhibitors at least at 32 Hz ( Figure  4 ).\nEffects of SBE 13 (1 μM), cyclapolin 9 (3 μM), TAK 960 (100 nM), and Ro 3280 (100 nM) on EFS-induced prostate contractions. In an organ bath, contractions of human prostate strips were induced by EFS. Effects of inhibitors on contractions were compared with corresponding controls (DMSO) in separate sets of experiments. To eliminate heterogeneities including any individual variations, different degree of BPH, or varying smooth muscle content (compare  Figure  1 ), tensions have been expressed as % of highmolar KCl-induced contraction, which was assessed before application of inhibitors or solvent. Data are means ± SEM from series with tissues from  n  = 7 patients/group for SBE 13,  n  = 7 patients/group for cyclapolin 9,  n  = 7 patients/groups for TAK 960, and  n  = 10 patients/group for Ro 3280. For each diagram, samples from each patient were allocated to both the control and inhibitor groups, so that both groups in each diagram are obtained from the same tissues ( ∗ p  < 0.05 for control vs. inhibitor).\nIncubation of prostate tissues with SBE 13 (1 μM), cyclapolin 9 (3 μM), Ro 3280 (100 nM), or TAK 960 (100 nM) for 60 min reduced the average content of phospho-vimentin (serine 56). This was significant for Ro 3280 ( p  < 0.05) and TAK960 ( p  < 0.009), while a trend was observed for SBE 13 and cyclapolin 9 ( Figure  8 ). In contrast, none of the inhibitors changed the content of total vimentin, phospho-MLC (serine 19), or MLC ( Figure  8 ).\nEffects of PLK inhibitors on phosphorylation of vimentin and MLC. Prostate tissues were incubated with PLK inhibitors and equivalent amounts of solvent (DMSO) for 60 min. Two sets of experiments were performed, where effects of SBE 13 (1 μM) and cyclapolin 9 (3 μM), or of Ro 3280 (100 nM) and TAK 960 (100 nM) were assessed. Vimentin phosphorylation at serine 56 and MLC phosphorylation at serine 19 were compared between inhibitor-treated samples and corresponding controls (exposed to identical experimental conditions) by Western blot analysis using phospho-specific antibodies. In each series, tissues in the agonist and corresponding control group were obtained from the same prostates. Shown are representative Western blots and quantification of all experiments, from series with  n  = 8 patients the SBE 13/cyclapolin 9 series, and  n  = 8 other patients for the Ro 3280/TAK960 series ( ∗ p  < 0.05 for control vs. inhibitor).\nFollowing the discovery of PLK1 as important regulator of mitosis and proliferation in different cell types, PLKs emerged as promising new targets in oncology ( McInnes et al., 2005 ). This initiated the development of PLK-specific small molecule inhibitors, which has been promoted during the last decade and resulted in several inhibitors which are now available for research purposes ( Gutteridge et al., 2016 ). In kinase assays based on immunoprecipitated enzymes, SBE 13 showed high selectivity for PLK1, with an IC 50  value of 200 pM for PLK1 inhibition, and IC 50  values of 66 μM and 875 nM for inhibition of PLK2 and -3, while no inhibition of aurora kinase was observed ( Keppner et al., 2009 ,  2010 ). In different cell lines, including HeLa and cancer cells, proliferation was inhibited with EC 50  values ranging between 5 and 60 μM ( Keppner et al., 2009 ,  2010 ). Cyclapolin 9 showed an IC 50  of 500 nM for PLK1 in  in vitro  kinase assays, while a panel of at least 37 other kinases was not inhibited even at a cyclapolin 9 concentration of  ...

# %%
a[16]
# Out:
# 'The OsPCS2 exhibits root- and shoot-specific differential ratios of alternatively spliced transcripts in indica rice under Cd stress, and plays role in Cd and As stress tolerance and accumulation. Enzymatic activity of phytochelatin synthase (PCS) in plant produces phytochelatins, which help in sequestration of heavy metal(loid)s inside the cell vacuole to alleviate toxicity. Here we report that among the two PCS genes-OsPCS1 and OsPCS2 in indica rice (Oryza sativa) cultivar, the OsPCS2 produces an alternatively spliced OsPCS2b transcript that bears the unusual premature termination codon besides the canonically spliced OsPCS2a transcript. Root- and shoot-specific differential ratios of alternatively spliced OsPCS2a and OsPCS2b transcript expressions were observed under cadmium stress. Saccharomyces cerevisiae cells transformed with OsPCS2a exhibited increased cadmium (Cd) and arsenic (As) tolerance and accumulation, unlike the OsPCS2b transformed yeast cells. An intron-containing hairpin RNA-mediated gene silencing was carried out in endosperm-specific manner for efficient down-regulation of OsPCS genes in rice grains. Analysis of the transgenic rice lines grown under metal(loid) stress revealed almost complete absence of both OsPCS1 and OsPCS2 transcripts in the developing seeds coupled with the significant reduction in the content of Cd (~51%) and As (~35%) in grains compared with the non-transgenic plant. Taken together, the findings indicate towards a crucial role played by the tissue-specific alternative splicing and relative abundance of the OsPCS2 gene during heavy metal(loid) stress mitigation in rice plant.\n'

# %%
disamb.dump('TAK', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('ARG', '../results')

# %%
d.disambiguate(texts[0])

# %%
print(d.info())

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_

# %%
model_to_s3(disamb)

# %%
a = frozenset([(1, 1), (1, 2), (1, 3)])

# %%
dict(a)
# Out:
# {1: 1}

# %%
a = frozenset([(1, 2), (2, 2), (3, 2)])

# %%
x = dict(a)

# %%
frozenset(x.items())
# Out:
# frozenset({(1, 2), (2, 2), (3, 2)})

# %%
x[_86] = 2

# %%
x
# Out:
# {1: 2, 3: 2, 2: 2, frozenset({(1, 2), (2, 2), (3, 2)}): 2}

# %%
from indra_db.util import get_primary_db

# %%
db = get_primary_db()

# %%
dir(db)
# Out:
# ['Base',
#  'Curation',
#  'DBInfo',
#  'EvidenceCounts',
#  'FastRawPaLink',
#  'MeshRefAnnotations',
#  'NameMeta',
#  'OtherMeta',
#  'PAAgents',
#  'PAMods',
#  'PAMuts',
#  'PAStatements',
#  'PASupportLinks',
#  'PaMeta',
#  'PaRefLink',
#  'PaSourceLookup',
#  'PreassemblyUpdates',
#  'RawAgents',
#  'RawMods',
#  'RawMuts',
#  'RawStatements',
#  'RawStmtSrc',
#  'RawUniqueLinks',
#  'Reading',
#  'ReadingRefLink',
#  'ReadingUpdates',
#  'RejectedStatements',
#  'SourceFile',
#  'TextContent',
#  'TextMeta',
#  'TextRef',
#  'Updates',
#  '_DatabaseManager__foreign_key_graph',
#  '_PrincipalDatabaseManager__PaStmtSrc',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_clear',
#  '_conn',
#  '_form_pg_args',
#  '_get_foreign_key_constraint',
#  '_init_foreign_key_map',
#  'commit',
#  'commit_copy',
#  'copy',
#  'count',
#  'create_schema',
#  'create_tables',
#  'delete_all',
#  'drop_schema',
#  'drop_tables',
#  'dump_readonly',
#  'engine',
#  'filter_query',
#  'generate_readonly',
#  'get_active_tables',
#  'get_column_names',
#  'get_column_objects',
#  'get_latest_dump_file',
#  'get_primary_key',
#  'get_schemas',
#  'get_tables',
#  'get_values',
#  'grab_session',
#  'has_entry',
#  'insert',
#  'insert_many',
#  'label',
#  'link',
#  'make_copy_batch_id',
#  'readonly',
#  'select_all',
#  'select_all_batched',
#  'select_one',
#  'select_sample_from_table',
#  'session',
#  'show_tables',
#  'tables',
#  'url',
#  'vacuum']

# %%
db.
# Out:
# ['text_ref', 'mesh_ref_annotations', 'source_file', 'updates', 'text_content', 'reading', 'reading_updates', 'db_info', 'raw_statements', 'rejected_statements', 'raw_agents', 'raw_mods', 'raw_muts', 'raw_unique_links', 'preassembly_updates', 'pa_statements', 'pa_agents', 'pa_mods', 'pa_muts', 'pa_support_links', 'curation']

# %%
from indra_db.util.content_scripts import get_text_content_from_text_refs

# %%
# %time x = get_text_content_from_text_refs({'PMID': '28684774'}, use_cache=True)
# Out:
# CPU times: user 10 µs, sys: 0 ns, total: 10 µs
# Wall time: 13.1 µs

# %%
from indra_db.util import get_text_content_from_pmids
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-95-de71203e99f8> in <module>
# ----> 1 from indra_db.util import get_text_content_from_pmids
#
# ImportError: cannot import name 'get_text_content_from_pmids' from 'indra_db.util' (/Users/albertsteppi/indra_db/indra_db/util/__init__.py)
