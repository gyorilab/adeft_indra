# %%
import json
import pickle

from indra.literature.adeft_tools import universal_extract_text
from indra.databases.hgnc_client import get_hgnc_name, get_hgnc_id

from indra_db.util.content_scripts import get_text_content_from_pmids
from indra_db.util.content_scripts import get_stmts_with_agent_text_like
from indra_db.util.content_scripts import get_text_content_from_stmt_ids

from adeft.discover import AdeftMiner
from adeft.gui import ground_with_gui
from adeft.modeling.label import AdeftLabeler
from adeft.modeling.classify import AdeftClassifier
from adeft.disambiguate import AdeftDisambiguator

from adeft_indra.s3 import model_to_s3
from adeft_indra.ground import gilda_ground

# %%
shortforms = ['ABL']
genes = ['ABL1']
families = {'ABL_family': ['KCNH1', 'KCNH2', 'KCNH3', 'KCNH4',
                     'KCNH5', 'KCNH6', 'KCNH7', 'KCNH8']}
groundings = [f'HGNC:{get_hgnc_id(gene)}' for gene in genes]
for family, members in families.items():
    genes.extend(members)
    groundings.append(f'FPLX:{family}')
with open('../data/entrez_all_pmids.json', 'r') as f:
    all_pmids = json.load(f)

# %%
entrez_texts = []
entrez_refs = set()
for gene, grounding in zip(genes, groundings):
    try:
        pmids = all_pmids[gene]
    except KeyError:
        continue
    _, content = get_text_content_from_pmids(pmids)
    entrez_texts.extend([(universal_extract_text(text), grounding)
                          for text in content.values() if text])
    entrez_refs.update(content.keys())

# %%
miners = dict()
all_texts = set()
for shortform in shortforms:
    stmts = get_stmts_with_agent_text_like(shortform)[shortform]
    _, content = get_text_content_from_stmt_ids(stmts)
    shortform_texts = [universal_extract_text(text, contains=shortforms)
                       for ref, text in content.items() if text and ref not in entrez_refs]
    miners[shortform] = AdeftMiner(shortform)
    miners[shortform].process_texts(shortform_texts)
    all_texts.union(shortform_texts)

# %% [markdown]
# It's then necessary to check if Acromine produced the correct results. We must fix errors manually

# %%
top = miners['ABL'].top()

# %%
top
# Out:
# [('alveolar bone loss', 31.823529411764707),
#  ('acetylbritannilactone', 11.125),
#  ('agaricus bisporus lectin', 10.333333333333334),
#  ('1 o acetylbritannilactone', 7.75),
#  ('abetalipoproteinemia', 7.666666666666666),
#  ('average sleep bout length', 7.4),
#  ('abelson', 7.111111111111111),
#  ('kinase', 5.5),
#  ('acid bone lysate', 4.666666666666667),
#  ('on alveolar bone loss', 4.0),
#  ('loss', 3.7837837837837824),
#  ('basolateral amygdala', 3.6),
#  ('lectin', 3.571428571428571),
#  ('level', 2.5),
#  ('patients with abetalipoproteinemia', 2.5),
#  ('binding loop', 2.4),
#  ('abelson murine leukemia viral oncogene homolog', 2.333333333333333),
#  ('abetalipoproteinaemia', 2.0),
#  ('abelson kinase', 2.0),
#  ('of alveolar bone loss', 2.0),
#  ('vertical alveolar bone loss', 2.0),
#  ('edible mushroom agaricus bisporus lectin', 2.0),
#  ('the abelson tyrosine kinase 1', 2.0),
#  ('a sleep duration and b average sleep bout length', 2.0),
#  ('bone loss', 1.942857142857143),
#  ('amygdala', 1.666666666666667),
#  ('agaricus bisporus', 1.6),
#  ('1', 1.5),
#  ('nucleus', 1.5),
#  ('mushroom agaricus bisporus', 1.5),
#  ('b average sleep bout length', 1.5),
#  ('ablation', 1.3333333333333333),
#  ('basolateral nucleus', 1.3333333333333333),
#  ('of acetylbritannilactone', 1.3333333333333333),
#  ('tyrosine kinase', 1.3333333333333333),
#  ('adenylate binding loop', 1.3333333333333333),
#  ('cluster region bcr abelson', 1.3333333333333333),
#  ('the edible mushroom agaricus bisporus', 1.3333333333333333),
#  ('abaloparatide', 1.0),
#  ('lactam', 1.0),
#  ('mushroom', 1.0),
#  ('oncogene', 1.0),
#  ('blood loss', 1.0),
#  ('catheter ablation', 1.0),
#  ('radiofrequency ablation', 1),
#  ('the abelson', 1.0),
#  ('abelson tyrosine kinase', 1.0),
#  ('ampc beta lactamase', 1.0),
#  ('atp binding loop', 1.0),
#  ('effects of acetylbritannilactone', 1.0),
#  ('for osteoporosis abaloparatide', 1.0),
#  ('the basolateral amygdala', 1.0),
#  ('the basolateral nucleus', 1.0),
#  ('the mammalian abelson', 1),
#  ('and alveolar bone loss', 1.0),
#  ('day alveolar bone loss', 1.0),
#  ('dependent on stimulus level', 1.0),
#  ('induced alveolar bone loss', 1.0),
#  ('of agaricus bisporus lectin', 1.0),
#  ('of antigen binding lymphocytes', 1.0),
#  ('the abelson murine leukemia', 1.0),
#  ('the adenylate binding loop', 1.0),
#  ('the alveolar bone loss', 1.0),
#  ('the potency of abelson', 1),
#  ('upon acid bone lysate', 1.0),
#  ('and average sleep bout length', 1.0),
#  ('breakpoint cluster region bcr abelson', 1.0),
#  ('c average sleep bout length', 1.0),
#  ('effects of 1 o acetylbritannilactone', 1.0),
#  ('in five patients with abetalipoproteinemia', 1.0),
#  ('the dietary lectin edible mushroom', 1),
#  ('immunomodulatory activated of agaricus bisporus lectin', 1),
#  ('to determine whether agaricus bisporus lectin', 1),
#  ('lectin from the edible mushroom agaricus bisporus', 1.0),
#  ('this study examined 1 alveolar bone loss', 1),
#  ('two natural stls 1 o acetyl britannilactone', 1),
#  ('inhibitor directed abelson murine leukemia viral oncogene homolog', 1.0),
#  ('the primary interaction between purified agaricus bisporus lectin', 1),
#  ('inhibitor proteasome inhibitor directed abelson murine leukemia viral oncogene homolog',
#   1),
#  ('the effects of systemic administered rosuvastatin on alveolar bone loss',
#   1),
#  ('iferation competitive binding assay against asialoglycophorin showed that agaricus bisporus lectin',
#   1),
#  ('ncluding a cardiomyocyte specifically regulated stress response to elevated lipids abetalipoproteinemia',
#   1),
#  ('quiterpenoids anticancer agent we obtained two natural sesquiterpenes 1 o acetylbritannilactone',
#   1),
#  ('similar firing patterns have also been reported in rat basolateral amygdala',
#   1),
#  ('systemic melatonin administration on proinflammatory cytokines level apoptosis alveolar bone loss',
#   1),
#  ('the effects of lesions of the basolateral nucleus of the amygdala', 1),
#  ('the present study was designed to determine the effects of acetylbritannilactone',
#   1),
#  ('the present study was designed to determine the possibility of acetylbritannilactone',
#   1),
#  ('the receptor characteristics as well as incidence of antigen binding lymphocytes',
#   1),
#  ('dasatinib bms354825 which targeted src as well as abelson tyrosine protein kinase',
#   1),
#  ('hange and transfer of lipids and apolipoproteins within the plasma compartment abetalipoproteinemia',
#   1),
#  ('hronic ischemia by regulated vegf signaling and modulating angiogenesis 1 o acetylbritannilactone',
#   1),
#  ('l 5 12 etoposide 13 camptothecin 4 and vinca alkaloids 14 acetylbritannilactone',
#   1),
#  ('lease and platelet malondialdehyde production were determine in a patients with abetalipoproteinemia',
#   1),
#  ('microrna 155 mir 155 induced the expression of inflammatory cytokines and acetylbritannilactone',
#   1),
#  ('other signaling pathway previous research also support our finding 1 o acetylbritannilactone',
#   1),
#  ('r2 erbb2 inhibitor angiogenic inhibitor directed abelson murine leukemia viral oncogene homolog',
#   1),
#  ('tylgalactosamine and galactose affinities at present this family contains agaricus bisporus lectin',
#   1),
#  ('ve parameters represent atrial conducted heterogeneity and af recurrence after catheter ablation',
#   1),
#  ('1 fig 2 plasma a tocopherol concentrations nmollml in five patients with abetalipoproteinemia',
#   1),
#  ('17 and may minimize dose related cardiovascular side effects 18 19 20 acetylbritannilactone',
#   1),
#  ('density lipoproteins vldl c and low density lipoproteins ldl c 1 2 abetalipoproteinemia',
#   1),
#  ('e14a3 breakpoint cluster region bcr abl proto oncogene 1 non receptor tyrosine kinase',
#   1),
#  ('f rapamycin mtor phosphatase and tensin homologue pten breakpoint cluster region bcr abelson',
#   1),
#  ('frda like syndrome 6 20 the 744deletiona is the most common mutation abetalipoproteinaemia',
#   1),
#  ('iminate between stereoisomers of a tocopherol was study in five patients with abetalipoproteinemia',
#   1),
#  ('lammatory cytokines and it inhibitory effects on lipopolysaccharide lps induced alveolar bone loss',
#   1),
#  ('les were collected for quantitative crp analysis use turbidimetric immunoassay alveolar bone loss',
#   1),
#  ('paraformaldehyde and submitted to routine microcomputed tomography micro ct for alveolar bone loss',
#   1),
#  ('robbins and everitt 1999 these area include subcortical region such as basolateral amygdala',
#   1),
#  ('the aim of this study was to investigate the protective effects of acetylbritannilactone',
#   1),
#  ('the present study was conducted to determine the effects of 1 o acetylbritannilactone',
#   1),
#  ('this study was designed to determine the therapeutic effects of agaricus bisporus lectin',
#   1),
#  ('tyrosine kinase inhibitor designed to specifically inhibit break point cluster region bcr abelson',
#   1),
#  ('vitamin a and e treatment in preventing retinal degeneration in patients with abetalipoproteinaemia',
#   1),
#  ('a of three normolipidemic nl subjected and whole plasma from two patients with abetalipoproteinemia',
#   1),
#  ('an experimental carcinogenic 4 nitroquinoline 1 oxidative 4nqo in the spontaneous alveolar bone loss',
#   1),
#  ('atase 2 ship2 phosphatase and tensin homologue pten and breakpoint cluster region bcr abelson',
#   1),
#  ('be limited owing to cardiovascular side effects in this study we found that acetylbritannilactone',
#   1),
#  ('bl which is a constitutively activated kinase imatinib inhibit the normal abelson tyrosine kinase',
#   1),
#  ('ding on probing periodontitis probing depth ppd and oral panoramic radiographs alveolar bone loss',
#   1),
#  ('ed of rat subjected to periodontitis that receiv no pharmacological treatment alveolar bone loss',
#   1),
#  ('group receiv ing control surgery or bilateral electrolytic lesions of the baso lateral nucleus',
#   1),
#  ('has been characterized in vivo by analyzing the numerical expansion of antigen binding lymphocytes',
#   1),
#  ('hematological malignancy that arises due to reciprocal translocation of 3 sequence from c abelson',
#   1),
#  ('implicated in the development of retinal disease lectin from the edible mushroom agaricus bisporus',
#   1),
#  ('in order to elucidate the mechanism of anti inflammatory effects of 1 o acetylbritannilatone',
#   1),
#  ('ivities towards mouse t cell were compared to the extensively investigate agaricus bisporus lectin',
#   1),
#  ('merase chain reaction rt pcr for comparison a fungal antimitogenic lectin from agaricus bisporus',
#   1),
#  ('nduce β cell proliferation early study revealed that a lectin from agaricus bisporus mushroom',
#   1),
#  ('ral half of the central nucleus race or the cholinergically richly innervated basolateral nucleus',
#   1),
#  ('reported a decrease in offense following neurotoxic lesions cen tered in the basolateral nucleus',
#   1),
#  ('sacrificed and the upper maxillae removed and defleshed morphometric analysis of alveolar bone loss',
#   1),
#  ('sclerostin and dickkopf wnt signaling pathway inhibitor 1 level higher linear alveolar bone loss',
#   1),
#  ('somal translocation between the breakpoint cluster region bcr gene and the abelson tyrosine kinase',
#   1),
#  ('tis in wistar rat 55 antiproliferative effects of an edible mushroom agaricus bisporus lectin',
#   1),
#  ('to simulate bone lysis by osteoclasts titanium discs were exposed to acid bone lysate',
#   1),
#  ('use bone marrow derived macrophages 10 12 imatinib an inhibitor of ableson family kinase',
#   1),
#  ('we evaluate the structure of other glcnac binding protein for example agaricus bisporus lectin',
#   1),
#  ('while the monosaccharide composition was analysed by hplc a bisporus abs and a brasiliensis',
#   1),
#  ('1 patients with abeta 28 m g traber et allatherosclerosis 108 1994 27 37 lipoproteinemia',
#   1),
#  ('and hdl are specifically bound to the surface of human blood platelet 17 20 abetalipoproteinemia',
#   1),
#  ('at by various clinical parameters like gingival index gi tooth mobility tm alveolar bone loss',
#   1),
#  ('b previous reported in pediatric cancer patients have described the use of antibiotic lock solutions',
#   1),
#  ('catabolism of blps causes low plasma apob and ldl cholesterol ldl c level in abetalipoproteinemia',
#   1),
#  ('clarify the neural pathway leading to the growth hormone gh release when the basolateral amygdala',
#   1),
#  ('e expression was assessed by quantitative polymerase chain reaction moreover the area of bone loss',
#   1),
#  ('ecreted protein and cytokines mrna induced in cord blood leukocytes cbl and adult blood leukocytes',
#   1),
#  ('effects and mechanism of b gymnorrhiza on experimental uc aqueous extract of b gymnorrhiza leaves',
#   1),
#  ('effects of systemic melatonin treatment on serum oxidative stress index osi and alveolar bone loss',
#   1),
#  ('ell acute lymphoblastic leukemia ph like all is associated with activated jak stat abelson kinase',
#   1),
#  ('en periodontitis disease and chd digital panoramic radiographs were use to assessed alveolar bone loss',
#   1),
#  ('etermine the rate of the extended spectrum beta lactamase esbl production and ampc beta lactamase',
#   1),
#  ('hairpin pre mirna from the primary microrna transcript pri mirna the abelson tyrosine kinase 1',
#   1),
#  ('hout chd were recruited consecutively from the copenhagen city heart study mean alveolar bone level',
#   1),
#  ('ired t test table 3 illustrated statistical significance the mean value of alveolar bone loss',
#   1),
#  ('is a first lines tyrosine kinase inhibitor tki targeted at breakpoint cluster region abelson kinase',
#   1),
#  ('lar sialic acid springer and desai 1982 the lectin of the edible mushroom agaricus bisporus',
#   1),
#  ('ntouring method and assessed use the built in software program the vertical alveolar bone loss',
#   1),
#  ('o other bacteria horizontal 5 in nepal limited information is present in ampc beta lactamase',
#   1),
#  ('of transmission and severe of symptoms differ patients with loss of function mutation in mttp',
#   1),
#  ('other lung cancer is important here we explored the potential effects of 1 o acetylbritannilactone',
#   1),
#  ('positive and negative reward prediction errors pe s in rat dopamine da and basolateral amygdala',
#   1),
#  ('represent a good small animal model for the accelerated horizontal and vertical alveolar bone loss',
#   1),
#  ('ructures taking this into account we reason that the adoptive transfer of activated b lymphoblastic',
#   1),
#  ('stimulate hepatocytes to produce elevated crp level 5 in the present study alveolar bone loss',
#   1),
#  ('tein coupled receptor that mediate a slow prolonged form of inhibit in the basolateral amygdala',
#   1),
#  ('the mechanism of action by which a new anti inflammatory activated compound 1 o acetylbritannilactone',
#   1),
#  ('ve properties against two mammalian cell lines 8 we can also mention agaricus bisporus lectin',
#   1),
#  ('a nylon thread ligature around the maxillary molars and sacrificed after 7 day alveolar bone loss',
#   1),
#  ('alysis figure 4 demonstrated that the sensitivity to ild of a1 neurons dependent on stimulus level',
#   1),
#  ('and cell cycle distribution patterns primary human rpe cell were grown with or without the lectin',
#   1),
#  ('atocrit hct were measured before and after surgery the estimated blood loss and actual blood loss',
#   1),
#  ('biotin in the two structure in the adenylate bound structure the fourth or adenylate binding loop',
#   1),
#  ('chitecture sleep duration a latency to sleep after lights off b and average sleep bout length',
#   1),
#  ('conditions sleep duration b latency to sleep after lights off c and average sleep bout length',
#   1),
#  ('d alkaline phosphatase and osteopontin in st2 cell we have previous reported on acid bone lysate',
#   1),
#  ('dicator for have both chd and severe abl in the investigate syrian population alveolar bone loss',
#   1),
#  ('e kinase activated similar to that seen with the transforming oncogene of the abelson murine leukemia',
#   1),
#  ('elial function in patients with af before and after restoration of sinus rhythm by catheter ablation',
#   1),
#  ('females mean age 53 16 probing depth pd clinical attachment loss cal and alveolar bone loss',
#   1),
#  ('h similar to the sequence of a saline soluble lectin isolated from the mushroom agaricus bisporus',
#   1),
#  ('he next study according to kobayashi 18 the ovx mouse model exhibits severe alveolar bone loss',
#   1),
#  ('ile of abl indicates that it would be a suitable bone anabolic agent for osteoporosis abaloparatide',
#   1),
#  ('intervention of lipids and may be altered in infections here we use apoptotic body like liposomes',
#   1),
#  ('ion of bcl 2 and parp through a p53 dependent caspase mediate pathway 1 o acetylbritannilactone',
#   1),
#  ('itors is concerned a replicative block was demonstrated at the immediate early ampk or early late',
#   1),
#  ('llular kinase once in the cytosol caga is phosphorylated by src family kinase sfks and abelson',
#   1),
#  ('of another dietary gal beta 1 3 galnac binding lectin the edible mushroom agaricus bisporus lectin',
#   1),
#  ('or the basolateral nucleus 12 a small lesions within the very center of the basolateral nucleus',
#   1),
#  ('otherapy or allo sct is not the most effects therapeutic schedule however the abl proto oncogene',
#   1),
#  ('p a balance among pro and anti inflammatory cytokines to evaluate if the a brasiliensis extract',
#   1),
#  ('re form between the breakpoint cluster region bcr gene on chromosome 22 and the abelson oncogene',
#   1),
#  ('rt poorly consolidated sleep in inc females a sleep duration and b average sleep bout length',
#   1),
#  ('s and schmidt ruppin a 2 viral oncogene homolog src abelson murine leukemia viral oncogene homolog',
#   1),
#  ('s encoding the break point cluster region bcr and abelson murine leukemia viral oncogene homolog 1',
#   1),
#  ('tion the peptide fragment pth 1 34 is currently in use as therapy for osteoporosis abaloparatide',
#   1),
#  ('ulose alone the blank control group did not get induction of periodontitis the alveolar bone loss',
#   1),
#  ('viduals in a randomized double blind cross over trial include a beta blocker bbl alpha blocker',
#   1),
#  ('abl are viable under the present in vitro model cell viability is maintained upon acid bone lysate',
#   1),
#  ('buted therefore mann whitney u test was use a sleep duration and b average sleep bout length',
#   1),
#  ('e breakpoint cluster region bcr gene on chromosome 22 at band q11 with the abelson murine leukemia',
#   1),
#  ('ed by an unusual salt bridge between the activated loop and αd helix differ to abelson kinase',
#   1),
#  ('hat osteocytic dkk 1 is a key factor in the pathogenesis of periodontitis induced alveolar bone loss',
#   1),
#  ('have amino acid replacements in the biotin binding loop bbl and two in the adenylate binding loop',
#   1),
#  ('ies highlighted in the oval the biotin binding loop bbl shown in blue the adenylate binding loop',
#   1),
#  ('ion the aim of this study was to evaluate the influence of edible mushroom agaricus bisporus lectin',
#   1),
#  ('matrix however has not been study here we investigate the in vitro impact of acid bone lysate',
#   1),
#  ('n and conjugation of the breakpoint cluster region bcr gene bcr on chromosome 22 and the abelson',
#   1),
#  ('nd the maxillae was fixed in 4 w v paraformaldehyde for micro ct analysis alveolar bone loss',
#   1),
#  ('nother rna binding protein rbpx that binding dgcr8 in place of drosha the abelson tyrosine kinase 1',
#   1),
#  ('r support the hypothesis that abl derived tgf β activated adsorbs to titanium discs acid bone lysate',
#   1),
#  ('reakpoint cluster region bcr gene on chromosome 22 to the 3 segment of the abelson leukemia virus',
#   1),
#  ('s our recent finding that phosphorylated of dgcr8 at tyrosine 267 by the abelson tyrosine kinase 1',
#   1),
#  ('s we have study the use of con a ricinus communis agglutinin rca and abrus precatorius lectin',
#   1),
#  ('t 2 standard deviations from the population mean for sleep duration and or average sleep bout length',
#   1),
#  ('the aim of this study is to investigate effects of strontium ranelate sr on alveolar bone loss',
#   1),
#  ('the purpose of this study was to investigate the effects of vitamin e on alveolar bone loss',
#   1),
#  ('this study aim to investigate the effects of a 2 cholesterol enriched diet on alveolar bone loss',
#   1),
#  ('to cf pure tones and calls were similar in that sensitivity was heavily dependent on stimulus level',
#   1),
#  ('ty to ild was test for each stimulus ild sensitivity was test use the average binaural level',
#   1),
#  ('until the sacrifice on the 11th day the weight and survival rate were monitored alveolar bone loss',
#   1),
#  ('will be required to confirm a sleep regulatory role for these alleles a average sleep bout length',
#   1),
#  ('0 m 1 the other lectin had considerably lower affinities with k d ranging from 0 16 microm',
#   1),
#  ('abl holds a tgf β activated that adsorbs to titanium discs cell increase il11 upon acid bone lysate',
#   1),
#  ('gene selection at each stage of the screen b the sleep duration and c average sleep bout length',
#   1),
#  ('igature place at lower right first molars and nm + ligature group the amount of alveolar bone loss',
#   1),
#  ('il the structure of goox t1 bound by a substrate analogue 5 amino 5 deoxycellobiono 1 5 lactam',
#   1),
#  ('l apoptosis and vascular channel regression both in vivo and in a 3d fibrin gel assay the abelson',
#   1),
#  ('n = 10 males and the screen population average grey > 4000 males b average sleep bout length',
#   1),
#  ('nt s t test inc f00285 gal4 rescue screen a sleep duration and b average sleep bout length',
#   1),
#  ('of homolog of 2 uas inc rnai lines of interest b sleep duration c average sleep bout length',
#   1),
#  ('s are not well understood in this study we examined the effects of myricetin on alveolar bone loss',
#   1),
#  ('tency and selection for src were enhanced by the proximity of the dimethylamino to the ring ic 50',
#   1),
#  ('were performed on the 9th day all the animal were euthanized on the 30th day alveolar bone loss',
#   1),
#  ('a ddx3x structure loop n terminal to the first reca domain that we define as the atp binding loop',
#   1),
#  ('mbly of laf 1 rnp granules a recent study reported a structure of ddx3x bearing an atp binding loop',
#   1),
#  ('pme 1 resulting in the discovery of a highly potent low nm and selection class of aza β lactam',
#   1),
#  ('vehicle or hd zol 80 μg kg iv once monthly bmd a bone volume b vertical alveolar bone loss',
#   1),
#  ('76 8 corpses were males and 56 23 2 corpses were females it was found that in acute blood loss',
#   1),
#  ('0 mg kg or mangiferin 100 mg kg on day 1 4 or 7 after ligature application the alveolar bone loss',
#   1),
#  ('ts for ~ 85 of all lung cancer cases with a 5 year survival rate of < 15 1 o acetylbritannilactone',
#   1),
#  ('s 4s 7ar 4 hydroxy 6 methyl 3 methylene 2 oxo 2 3 3a 4 7 7a hexahydrobenzofuran 5 yl pentyl acetate',
#   1),
#  ('with denaturation at 94 ° c for 45 s for abl c myc and for 30 s rb1 annealing at 63 ° c for 45 s',
#   1),
#  ('at 61 ° c for 45 s c myc and at 56 6 ° c for 30 s rb1 elongation was at 72 ° c for 1 min',
#   1),
#  ('50', 0.0),
#  ('acetate', 0.0),
#  ('acetylbritannilatone', 0.0),
#  ('bisporus', 0.0),
#  ('blocker', 0.0),
#  ('brasiliensis', 0.0),
#  ('britannilactone', 0.0),
#  ('extract', 0.0),
#  ('homolog', 0.0),
#  ('lactamase', 0.0),
#  ('late', 0.0),
#  ('leaves', 0.0),
#  ('length', 0.0),
#  ('leukemia', 0.0),
#  ('leukocytes', 0.0),
#  ('lipoproteinemia', 0.0),
#  ('liposomes', 0.0),
#  ('loop', 0.0),
#  ('lymphoblastic', 0.0),
#  ('lymphocytes', 0.0),
#  ('lysate', 0.0),
#  ('microm', 0.0),
#  ('min', 0.0),
#  ('mttp', 0.0),
#  ('s', 0.0),
#  ('solutions', 0.0),
#  ('virus', 0.0),
#  ('1 min', 0.0),
#  ('14 acetylbritannilactone', 0.0),
#  ('16 microm', 0.0),
#  ('2 abetalipoproteinemia', 0.0),
#  ('20 abetalipoproteinemia', 0.0),
#  ('20 acetylbritannilactone', 0.0),
#  ('37 lipoproteinemia', 0.0),
#  ('45 s', 0.0),
#  ('5 lactam', 0.0),
#  ('a brasiliensis', 0.0),
#  ('abelson oncogene', 0.0),
#  ('acetyl britannilactone', 0.0),
#  ('alpha blocker', 0.0),
#  ('and abelson', 0.0),
#  ('and acetylbritannilactone', 0.0),
#  ('b lymphoblastic', 0.0),
#  ('bcr abelson', 0.0),
#  ('beta lactamase', 0.0),
#  ('binaural level', 0.0),
#  ('binding lymphocytes', 0.0),
#  ('bisporus lectin', 0.0),
#  ('bisporus mushroom', 0.0),
#  ('blood leukocytes', 0.0),
#  ('bone level', 0.0),
#  ('bone lysate', 0.0),
#  ('bout length', 0.0),
#  ('brasiliensis extract', 0.0),
#  ('c abelson', 0.0),
#  ('compartment abetalipoproteinemia', 0.0),
#  ('early late', 0.0),
#  ('edible mushroom', 0.0),
#  ('family kinase', 0.0),
#  ('gymnorrhiza leaves', 0.0),
#  ('homolog 1', 0.0),
#  ('ic 50', 0.0),
#  ('in abetalipoproteinemia', 0.0),
#  ('in mttp', 0.0),
#  ('kinase 1', 0.0),
#  ('lateral nucleus', 0.0),
#  ('leukemia virus', 0.0),
#  ('like liposomes', 0.0),
#  ('lipids abetalipoproteinemia', 0.0),
#  ('lock solutions', 0.0),
#  ('mammalian abelson', 0.0),
#  ('murine leukemia', 0.0),
#  ('mutation abetalipoproteinaemia', 0.0),
#  ('o acetylbritannilactone', 0.0),
#  ('o acetylbritannilatone', 0.0),
#  ('of abelson', 0.0),
#  ('oncogene homolog', 0.0),
#  ('osteoporosis abaloparatide', 0.0),
#  ('pentyl acetate', 0.0),
#  ('precatorius lectin', 0.0),
#  ('protein kinase', 0.0),
#  ('proto oncogene', 0.0),
#  ('stimulus level', 0.0),
#  ('that acetylbritannilactone', 0.0),
#  ('the amygdala', 0.0),
#  ('the lectin', 0.0),
#  ('with abetalipoproteinaemia', 0.0),
#  ('with abetalipoproteinemia', 0.0),
#  ('β lactam', 0.0),
#  ('0 16 microm', 0.0),
#  ('1 2 abetalipoproteinemia', 0.0),
#  ('1 5 lactam', 0.0),
#  ('1 o acetylbritannilatone', 0.0),
#  ('17 20 abetalipoproteinemia', 0.0),
#  ('19 20 acetylbritannilactone', 0.0),
#  ('27 37 lipoproteinemia', 0.0),
#  ('a brasiliensis extract', 0.0),
#  ('abelson leukemia virus', 0.0),
#  ('abelson murine leukemia', 0.0),
#  ('abl proto oncogene', 0.0),
#  ('ableson family kinase', 0.0),
#  ('abrus precatorius lectin', 0.0),
#  ('activated b lymphoblastic', 0.0),
#  ('actual blood loss', 0.0),
#  ('acute blood loss', 0.0),
#  ('adult blood leukocytes', 0.0),
#  ('after catheter ablation', 0.0),
#  ('agaricus bisporus mushroom', 0.0),
#  ('alkaloids 14 acetylbritannilactone', 0.0),
#  ('alveolar bone level', 0.0),
#  ('and a brasiliensis', 0.0),
#  ('and basolateral amygdala', 0.0),
#  ('and the abelson', 0.0),
#  ('antibiotic lock solutions', 0.0),
#  ('antigen binding lymphocytes', 0.0),
#  ('as basolateral amygdala', 0.0),
#  ('assay the abelson', 0.0),
#  ('average binaural level', 0.0),
#  ('aza β lactam', 0.0),
#  ('b gymnorrhiza leaves', 0.0),
#  ('baso lateral nucleus', 0.0),
#  ('bbl alpha blocker', 0.0),
#  ('body like liposomes', 0.0),
#  ('by catheter ablation', 0.0),
#  ('common mutation abetalipoproteinaemia', 0.0),
#  ('cytokines and acetylbritannilactone', 0.0),
#  ('elevated lipids abetalipoproteinemia', 0.0),
#  ('for 1 min', 0.0),
#  ('for 45 s', 0.0),
#  ('found that acetylbritannilactone', 0.0),
#  ('from agaricus bisporus', 0.0),
#  ('from c abelson', 0.0),
#  ('innervated basolateral nucleus', 0.0),
#  ('lectin edible mushroom', 0.0),
#  ('level in abetalipoproteinemia', 0.0),
#  ('mutation in mttp', 0.0),
#  ('o acetyl britannilactone', 0.0),
#  ('of bone loss', 0.0),
#  ('of the amygdala', 0.0),
#  ('on stimulus level', 0.0),
#  ('oncogene homolog 1', 0.0),
#  ('or early late', 0.0),
#  ('patients with abetalipoproteinaemia', 0.0),
#  ('plasma compartment abetalipoproteinemia', 0.0),
#  ('possibility of acetylbritannilactone', 0.0),
#  ('potency of abelson', 0.0),
#  ('rat basolateral amygdala', 0.0),
#  ('receptor tyrosine kinase', 0.0),
#  ('region abelson kinase', 0.0),
#  ('region bcr abelson', 0.0),
#  ('ring ic 50', 0.0),
#  ('sfks and abelson', 0.0),
#  ('sleep bout length', 0.0),
#  ('stat abelson kinase', 0.0),
#  ('the abelson oncogene', 0.0),
#  ('to abelson kinase', 0.0),
#  ('tyrosine kinase 1', 0.0),
#  ('tyrosine protein kinase', 0.0),
#  ('viral oncogene homolog', 0.0),
#  ('without the lectin', 0.0),
#  ('yl pentyl acetate', 0.0),
#  ('1 alveolar bone loss', 0.0),
#  ('1 o acetyl britannilactone', 0.0),
#  ('15 1 o acetylbritannilactone', 0.0),
#  ('18 19 20 acetylbritannilactone', 0.0),
#  ('1994 27 37 lipoproteinemia', 0.0),
#  ('22 and the abelson', 0.0),
#  ('5 yl pentyl acetate', 0.0),
#  ('a patients with abetalipoproteinemia', 0.0),
#  ('abs and a brasiliensis', 0.0),
#  ('abelson tyrosine kinase 1', 0.0),
#  ('abelson tyrosine protein kinase', 0.0),
#  ('agent for osteoporosis abaloparatide', 0.0),
#  ('ampk or early late', 0.0),
#  ('an atp binding loop', 0.0),
#  ('analysis alveolar bone loss', 0.0),
#  ('and abrus precatorius lectin', 0.0),
#  ('and actual blood loss', 0.0),
#  ('and adult blood leukocytes', 0.0),
#  ('and ampc beta lactamase', 0.0),
#  ('and the abelson oncogene', 0.0),
#  ('angiogenesis 1 o acetylbritannilactone', 0.0),
#  ('apoptosis alveolar bone loss', 0.0),
#  ('apoptotic body like liposomes', 0.0),
#  ('area of bone loss', 0.0),
#  ('assessed alveolar bone loss', 0.0),
#  ('blocker bbl alpha blocker', 0.0),
#  ('c 1 2 abetalipoproteinemia', 0.0),
#  ('c for 1 min', 0.0),
#  ('c for 45 s', 0.0),
#  ('c level in abetalipoproteinemia', 0.0),
#  ('cluster region abelson kinase', 0.0),
#  ('compound 1 o acetylbritannilactone', 0.0),
#  ('contains agaricus bisporus lectin', 0.0),
#  ('da and basolateral amygdala', 0.0),
#  ('deoxycellobiono 1 5 lactam', 0.0),
#  ('dietary lectin edible mushroom', 0.0),
#  ('differ to abelson kinase', 0.0),
#  ('discs acid bone lysate', 0.0),
#  ('edible mushroom agaricus bisporus', 0.0),
#  ('example agaricus bisporus lectin', 0.0),
#  ('finding 1 o acetylbritannilactone', 0.0),
#  ('five patients with abetalipoproteinemia', 0.0),
#  ('for alveolar bone loss', 0.0),
#  ('from 0 16 microm', 0.0),
#  ('from agaricus bisporus mushroom', 0.0),
#  ('function mutation in mttp', 0.0),
#  ('gel assay the abelson', 0.0),
#  ('immunoassay alveolar bone loss', 0.0),
#  ('in acute blood loss', 0.0),
#  ('in ampc beta lactamase', 0.0),
#  ('in patients with abetalipoproteinaemia', 0.0),
#  ('in rat basolateral amygdala', 0.0),
#  ('in the basolateral amygdala', 0.0),
#  ('in the basolateral nucleus', 0.0),
#  ('inflammatory cytokines and acetylbritannilactone', 0.0),
#  ('investigate agaricus bisporus lectin', 0.0),
#  ('jak stat abelson kinase', 0.0),
#  ('kinase sfks and abelson', 0.0),
#  ('lectin from agaricus bisporus', 0.0),
#  ('leukemia viral oncogene homolog', 0.0),
#  ('linear alveolar bone loss', 0.0),
#  ('mean alveolar bone level', 0.0),
#  ('mention agaricus bisporus lectin', 0.0),
#  ('monitored alveolar bone loss', 0.0),
#  ('most common mutation abetalipoproteinaemia', 0.0),
#  ('mushroom agaricus bisporus lectin', 0.0),
#  ('non receptor tyrosine kinase', 0.0),
#  ('normal abelson tyrosine kinase', 0.0),
#  ('nucleus of the amygdala', 0.0),
#  ('of 1 o acetylbritannilactone', 0.0),
#  ('of 1 o acetylbritannilatone', 0.0),
#  ('of ableson family kinase', 0.0),
#  ('of acid bone lysate', 0.0),
#  ('of activated b lymphoblastic', 0.0),
#  ('of antibiotic lock solutions', 0.0),
#  ('of aza β lactam', 0.0),
#  ('of b gymnorrhiza leaves', 0.0),
#  ('of the basolateral nucleus', 0.0),
#  ('on acid bone lysate', 0.0),
#  ('or adenylate binding loop', 0.0),
#  ('or without the lectin', 0.0),
#  ('pathway 1 o acetylbritannilactone', 0.0),
#  ('platelet 17 20 abetalipoproteinemia', 0.0),
#  ('population alveolar bone loss', 0.0),
#  ('protective effects of acetylbritannilactone', 0.0),
#  ('purified agaricus bisporus lectin', 0.0),
#  ('radiographs alveolar bone loss', 0.0),
#  ('recurrence after catheter ablation', 0.0),
#  ('rhythm by catheter ablation', 0.0),
#  ('richly innervated basolateral nucleus', 0.0),
#  ('sequence from c abelson', 0.0),
#  ('sesquiterpenes 1 o acetylbritannilactone', 0.0),
#  ('severe alveolar bone loss', 0.0),
#  ('spontaneous alveolar bone loss', 0.0),
#  ('study alveolar bone loss', 0.0),
#  ('such as basolateral amygdala', 0.0),
#  ('that agaricus bisporus lectin', 0.0),
#  ('the a brasiliensis extract', 0.0),
#  ('the abelson leukemia virus', 0.0),
#  ('the abelson tyrosine kinase', 0.0),
#  ('the abl proto oncogene', 0.0),
#  ('the atp binding loop', 0.0),
#  ('the average binaural level', 0.0),
#  ('the baso lateral nucleus', 0.0),
#  ('the effects of acetylbritannilactone', 0.0),
#  ('the mushroom agaricus bisporus', 0.0),
#  ('the plasma compartment abetalipoproteinemia', 0.0),
#  ('the possibility of acetylbritannilactone', 0.0),
#  ('the ring ic 50', 0.0),
#  ('therapy for osteoporosis abaloparatide', 0.0),
#  ('tm alveolar bone loss', 0.0),
#  ('to acid bone lysate', 0.0),
#  ('to elevated lipids abetalipoproteinemia', 0.0),
#  ('treatment alveolar bone loss', 0.0),
#  ('two patients with abetalipoproteinemia', 0.0),
#  ('vinca alkaloids 14 acetylbritannilactone', 0.0),
#  ('viral oncogene homolog 1', 0.0),
#  ('we found that acetylbritannilactone', 0.0),
#  ('when the basolateral amygdala', 0.0),
#  ('whether agaricus bisporus lectin', 0.0),
#  ('1 non receptor tyrosine kinase', 0.0),
#  ('108 1994 27 37 lipoproteinemia', 0.0),
#  ('22 and the abelson oncogene', 0.0),
#  ('3 sequence from c abelson', 0.0),
#  ('30th day alveolar bone loss', 0.0),
#  ('5 deoxycellobiono 1 5 lactam', 0.0),
#  ('7 day alveolar bone loss', 0.0),
#  ('< 15 1 o acetylbritannilactone', 0.0),
#  ('a average sleep bout length', 0.0),
#  ('activated compound 1 o acetylbritannilactone', 0.0),
#  ('activated jak stat abelson kinase', 0.0),
#  ('activated of agaricus bisporus lectin', 0.0),
#  ('af recurrence after catheter ablation', 0.0),
#  ('also mention agaricus bisporus lectin', 0.0),
#  ('amount of alveolar bone loss', 0.0),
#  ('anabolic agent for osteoporosis abaloparatide', 0.0),
#  ('analysis of alveolar bone loss', 0.0),
#  ('and the abelson tyrosine kinase', 0.0),
#  ('and vertical alveolar bone loss', 0.0),
#  ('and vinca alkaloids 14 acetylbritannilactone', 0.0),
#  ('antimitogenic lectin from agaricus bisporus', 0.0),
#  ('application the alveolar bone loss', 0.0),
#  ('as abelson tyrosine protein kinase', 0.0),
#  ('as the atp binding loop', 0.0),
#  ('as therapy for osteoporosis abaloparatide', 0.0),
#  ('b vertical alveolar bone loss', 0.0),
#  ('basolateral nucleus of the amygdala', 0.0),
#  ('bearing an atp binding loop', 0.0),
#  ('beta blocker bbl alpha blocker', 0.0),
#  ('between purified agaricus bisporus lectin', 0.0),
#  ('bisporus abs and a brasiliensis', 0.0),
#  ('blood platelet 17 20 abetalipoproteinemia', 0.0),
#  ('blue the adenylate binding loop', 0.0),
#  ('breakpoint cluster region abelson kinase', 0.0),
#  ('cal and alveolar bone loss', 0.0),
#  ('cbl and adult blood leukocytes', 0.0),
#  ('center of the basolateral nucleus', 0.0),
#  ('cholinergically richly innervated basolateral nucleus', 0.0),
#  ('chromosome 22 and the abelson', 0.0),
#  ('class of aza β lactam', 0.0),
#  ('ct analysis alveolar bone loss', 0.0),
#  ('ct for alveolar bone loss', 0.0),
#  ('degeneration in patients with abetalipoproteinaemia', 0.0),
#  ('determine the effects of acetylbritannilactone', 0.0),
#  ('determine the possibility of acetylbritannilactone', 0.0),
#  ('determine whether agaricus bisporus lectin', 0.0),
#  ('diet on alveolar bone loss', 0.0),
#  ('dopamine da and basolateral amygdala', 0.0),
#  ('e on alveolar bone loss', 0.0),
#  ('early ampk or early late', 0.0),
#  ('effects 18 19 20 acetylbritannilactone', 0.0),
#  ('effects of 1 o acetylbritannilatone', 0.0),
#  ('effects of agaricus bisporus lectin', 0.0),
#  ('examined 1 alveolar bone loss', 0.0),
#  ('exhibits severe alveolar bone loss', 0.0),
#  ('expansion of antigen binding lymphocytes', 0.0),
#  ('exposed to acid bone lysate', 0.0),
#  ('extensively investigate agaricus bisporus lectin', 0.0),
#  ('extract of b gymnorrhiza leaves', 0.0),
#  ('family contains agaricus bisporus lectin', 0.0),
#  ('family kinase sfks and abelson', 0.0),
#  ('fibrin gel assay the abelson', 0.0),
#  ('for example agaricus bisporus lectin', 0.0),
#  ('fourth or adenylate binding loop', 0.0),
#  ('from the mushroom agaricus bisporus', 0.0),
#  ('from two patients with abetalipoproteinemia', 0.0),
#  ('heavily dependent on stimulus level', 0.0),
#  ('helix differ to abelson kinase', 0.0),
#  ('hexahydrobenzofuran 5 yl pentyl acetate', 0.0),
#  ('higher linear alveolar bone loss', 0.0),
#  ('however the abl proto oncogene', 0.0),
#  ('if the a brasiliensis extract', 0.0),
#  ('il11 upon acid bone lysate', 0.0),
#  ('impact of acid bone lysate', 0.0),
#  ('in a patients with abetalipoproteinemia', 0.0),
#  ('in the adenylate binding loop', 0.0),
#  ('incidence of antigen binding lymphocytes', 0.0),
#  ('inhibit in the basolateral amygdala', 0.0),
#  ('inhibitor of ableson family kinase', 0.0),
#  ('ldl c 1 2 abetalipoproteinemia', 0.0),
#  ('ldl c level in abetalipoproteinemia', 0.0),
#  ('lectin from agaricus bisporus mushroom', 0.0),
#  ('leukemia viral oncogene homolog 1', 0.0),
#  ('level apoptosis alveolar bone loss', 0.0),
#  ('loss and actual blood loss', 0.0),
#  ('lps induced alveolar bone loss', 0.0),
#  ('maintained upon acid bone lysate', 0.0),
#  ('mediate pathway 1 o acetylbritannilactone', 0.0),
#  ('mobility tm alveolar bone loss', 0.0),
#  ('modulating angiogenesis 1 o acetylbritannilactone', 0.0),
#  ('murine leukemia viral oncogene homolog', 0.0),
#  ('myricetin on alveolar bone loss', 0.0),
#  ('natural sesquiterpenes 1 o acetylbritannilactone', 0.0),
#  ('neurons dependent on stimulus level', 0.0),
#  ('of function mutation in mttp', 0.0),
#  ('of inflammatory cytokines and acetylbritannilactone', 0.0),
#  ('of the abelson leukemia virus', 0.0),
#  ('of the abelson murine leukemia', 0.0),
#  ('of the baso lateral nucleus', 0.0),
#  ('or average sleep bout length', 0.0),
#  ('osi and alveolar bone loss', 0.0),
#  ('our finding 1 o acetylbritannilactone', 0.0),
#  ('panoramic radiographs alveolar bone loss', 0.0),
#  ('periodontitis induced alveolar bone loss', 0.0),
#  ('periodontitis the alveolar bone loss', 0.0),
#  ('pharmacological treatment alveolar bone loss', 0.0),
#  ('point cluster region bcr abelson', 0.0),
#  ('present in ampc beta lactamase', 0.0),
#  ('present study alveolar bone loss', 0.0),
#  ('production and ampc beta lactamase', 0.0),
#  ('ranging from 0 16 microm', 0.0),
#  ('rca and abrus precatorius lectin', 0.0),
#  ('region such as basolateral amygdala', 0.0),
#  ('release when the basolateral amygdala', 0.0),
#  ('reported in rat basolateral amygdala', 0.0),
#  ('reported on acid bone lysate', 0.0),
#  ('response to elevated lipids abetalipoproteinemia', 0.0),
#  ('rosuvastatin on alveolar bone loss', 0.0),
#  ('showed that agaricus bisporus lectin', 0.0),
#  ('sinus rhythm by catheter ablation', 0.0),
#  ('sr on alveolar bone loss', 0.0),
#  ('stls 1 o acetyl britannilactone', 0.0),
#  ('study mean alveolar bone level', 0.0),
#  ('study we found that acetylbritannilactone', 0.0),
#  ('syrian population alveolar bone loss', 0.0),
#  ('tered in the basolateral nucleus', 0.0),
#  ('that in acute blood loss', 0.0),
#  ('the area of bone loss', 0.0),
#  ('the most common mutation abetalipoproteinaemia', 0.0),
#  ('the normal abelson tyrosine kinase', 0.0),
#  ('the protective effects of acetylbritannilactone', 0.0),
#  ('the spontaneous alveolar bone loss', 0.0),
#  ('the vertical alveolar bone loss', 0.0),
#  ('titanium discs acid bone lysate', 0.0),
#  ('to assessed alveolar bone loss', 0.0),
#  ('to the ring ic 50', 0.0),
#  ('transfer of activated b lymphoblastic', 0.0),
#  ('turbidimetric immunoassay alveolar bone loss', 0.0),
#  ('use apoptotic body like liposomes', 0.0),
#  ('use of antibiotic lock solutions', 0.0),
#  ('use the average binaural level', 0.0),
#  ('value of alveolar bone loss', 0.0),
#  ('were monitored alveolar bone loss', 0.0),
#  ('with or without the lectin', 0.0),
#  ('with the abelson murine leukemia', 0.0),
#  ('within the plasma compartment abetalipoproteinemia', 0.0),
#  ('° c for 1 min', 0.0),
#  ('° c for 45 s', 0.0),
#  ('3d fibrin gel assay the abelson', 0.0),
#  ('4 and vinca alkaloids 14 acetylbritannilactone', 0.0),
#  ('63 ° c for 45 s', 0.0),
#  ('72 ° c for 1 min', 0.0),
#  ('7a hexahydrobenzofuran 5 yl pentyl acetate', 0.0),
#  ('a beta blocker bbl alpha blocker', 0.0),
#  ('a bisporus abs and a brasiliensis', 0.0),
#  ('a lectin from agaricus bisporus mushroom', 0.0),
#  ('a1 neurons dependent on stimulus level', 0.0),
#  ('administered rosuvastatin on alveolar bone loss', 0.0),
#  ('adoptive transfer of activated b lymphoblastic', 0.0),
#  ('after 7 day alveolar bone loss', 0.0),
#  ('agglutinin rca and abrus precatorius lectin', 0.0),
#  ('allatherosclerosis 108 1994 27 37 lipoproteinemia', 0.0),
#  ('alleles a average sleep bout length', 0.0),
#  ('amino 5 deoxycellobiono 1 5 lactam', 0.0),
#  ('an edible mushroom agaricus bisporus lectin', 0.0),
#  ('an inhibitor of ableson family kinase', 0.0),
#  ('and af recurrence after catheter ablation', 0.0),
#  ('and b average sleep bout length', 0.0),
#  ('and breakpoint cluster region bcr abelson', 0.0),
#  ('and c average sleep bout length', 0.0),
#  ('and modulating angiogenesis 1 o acetylbritannilactone', 0.0),
#  ('and or average sleep bout length', 0.0),
#  ('apolipoproteins within the plasma compartment abetalipoproteinemia', 0.0),
#  ('aqueous extract of b gymnorrhiza leaves', 0.0),
#  ('as incidence of antigen binding lymphocytes', 0.0),
#  ('asialoglycophorin showed that agaricus bisporus lectin', 0.0),
#  ('at breakpoint cluster region abelson kinase', 0.0),
#  ('b and average sleep bout length', 0.0),
#  ('been reported in rat basolateral amygdala', 0.0),
#  ('blood loss and actual blood loss', 0.0),
#  ('bone anabolic agent for osteoporosis abaloparatide', 0.0),
#  ('break point cluster region bcr abelson', 0.0),
#  ('by the abelson tyrosine kinase 1', 0.0),
#  ('c and average sleep bout length', 0.0),
#  ('can also mention agaricus bisporus lectin', 0.0),
#  ('caspase mediate pathway 1 o acetylbritannilactone', 0.0),
#  ('cen tered in the basolateral nucleus', 0.0),
#  ('cholesterol ldl c level in abetalipoproteinemia', 0.0),
#  ('chromosome 22 and the abelson oncogene', 0.0),
#  ('cytokines level apoptosis alveolar bone loss', 0.0),
#  ('d ranging from 0 16 microm', 0.0),
#  ('ddx3x bearing an atp binding loop', 0.0),
#  ('define as the atp binding loop', 0.0),
#  ('determine in a patients with abetalipoproteinemia', 0.0),
#  ('dimethylamino to the ring ic 50', 0.0),
#  ('drosha the abelson tyrosine kinase 1', 0.0),
#  ('duration c average sleep bout length', 0.0),
#  ('enriched diet on alveolar bone loss', 0.0),
#  ('esbl production and ampc beta lactamase', 0.0),
#  ('evaluate if the a brasiliensis extract', 0.0),
#  ('expression of inflammatory cytokines and acetylbritannilactone', 0.0),
#  ('found that in acute blood loss', 0.0),
#  ('from the edible mushroom agaricus bisporus', 0.0),
#  ('fungal antimitogenic lectin from agaricus bisporus', 0.0),
#  ('gene and the abelson tyrosine kinase', 0.0),
#  ('gh release when the basolateral amygdala', 0.0),
#  ('grown with or without the lectin', 0.0),
#  ('heart study mean alveolar bone level', 0.0),
#  ('horizontal and vertical alveolar bone loss', 0.0),
#  ('human blood platelet 17 20 abetalipoproteinemia', 0.0),
#  ('immediate early ampk or early late', 0.0),
#  ('in blue the adenylate binding loop', 0.0),
#  ('in the spontaneous alveolar bone loss', 0.0),
#  ('increase il11 upon acid bone lysate', 0.0),
#  ('index osi and alveolar bone loss', 0.0),
#  ('inflammatory activated compound 1 o acetylbritannilactone', 0.0),
#  ('inflammatory effects of 1 o acetylbritannilatone', 0.0),
#  ('inhibit the normal abelson tyrosine kinase', 0.0),
#  ('interaction between purified agaricus bisporus lectin', 0.0),
#  ('investigate syrian population alveolar bone loss', 0.0),
#  ('investigate the protective effects of acetylbritannilactone', 0.0),
#  ('is maintained upon acid bone lysate', 0.0),
#  ('is present in ampc beta lactamase', 0.0),
#  ('is the most common mutation abetalipoproteinaemia', 0.0),
#  ('isolated from the mushroom agaricus bisporus', 0.0),
#  ('lesions of the baso lateral nucleus', 0.0),
#  ('leukocytes cbl and adult blood leukocytes', 0.0),
#  ('level higher linear alveolar bone loss', 0.0),
#  ('ligature application the alveolar bone loss', 0.0),
#  ('lipopolysaccharide lps induced alveolar bone loss', 0.0),
#  ('lipoproteins ldl c 1 2 abetalipoproteinemia', 0.0),
#  ('loss cal and alveolar bone loss', 0.0),
#  ('loss of function mutation in mttp', 0.0),
#  ('males b average sleep bout length', 0.0),
#  ('mean value of alveolar bone loss', 0.0),
#  ('micro ct analysis alveolar bone loss', 0.0),
#  ('micro ct for alveolar bone loss', 0.0),
#  ('mirna the abelson tyrosine kinase 1', 0.0),
#  ('model exhibits severe alveolar bone loss', 0.0),
#  ('moreover the area of bone loss', 0.0),
#  ('morphometric analysis of alveolar bone loss', 0.0),
#  ('murine leukemia viral oncogene homolog 1', 0.0),
#  ('natural stls 1 o acetyl britannilactone', 0.0),
#  ('nmollml in five patients with abetalipoproteinemia', 0.0),
#  ('no pharmacological treatment alveolar bone loss', 0.0),
#  ('numerical expansion of antigen binding lymphocytes', 0.0),
#  ('of 3 sequence from c abelson', 0.0),
#  ('of < 15 1 o acetylbritannilactone', 0.0),
#  ('of edible mushroom agaricus bisporus lectin', 0.0),
#  ('of inhibit in the basolateral amygdala', 0.0),
#  ('of myricetin on alveolar bone loss', 0.0),
#  ('of periodontitis induced alveolar bone loss', 0.0),
#  ('of periodontitis the alveolar bone loss', 0.0),
#  ('of sinus rhythm by catheter ablation', 0.0),
#  ('of the edible mushroom agaricus bisporus', 0.0),
#  ('on chromosome 22 and the abelson', 0.0),
#  ('oncogene 1 non receptor tyrosine kinase', 0.0),
#  ('oncogene of the abelson murine leukemia', 0.0),
#  ('oral panoramic radiographs alveolar bone loss', 0.0),
#  ('plasma from two patients with abetalipoproteinemia', 0.0),
#  ('potential effects of 1 o acetylbritannilactone', 0.0),
#  ('previous reported on acid bone lysate', 0.0),
#  ('program the vertical alveolar bone loss', 0.0),
#  ('protein for example agaricus bisporus lectin', 0.0),
#  ('pten breakpoint cluster region bcr abelson', 0.0),
#  ('q11 with the abelson murine leukemia', 0.0),
#  ('ranelate sr on alveolar bone loss', 0.0),
#  ('rat dopamine da and basolateral amygdala', 0.0),
#  ('rate were monitored alveolar bone loss', 0.0),
#  ('retinal degeneration in patients with abetalipoproteinaemia', 0.0),
#  ('schedule however the abl proto oncogene', 0.0),
#  ('segment of the abelson leukemia virus', 0.0),
#  ('selection class of aza β lactam', 0.0),
#  ('side effects 18 19 20 acetylbritannilactone', 0.0),
#  ('src family kinase sfks and abelson', 0.0),
#  ('stress response to elevated lipids abetalipoproteinemia', 0.0),
#  ('study examined 1 alveolar bone loss', 0.0),
#  ('study in five patients with abetalipoproteinemia', 0.0),
#  ('subcortical region such as basolateral amygdala', 0.0),
#  ('support our finding 1 o acetylbritannilactone', 0.0),
#  ('test use the average binaural level', 0.0),
#  ('the 30th day alveolar bone loss', 0.0),
#  ('the amount of alveolar bone loss', 0.0),
#  ('the basolateral nucleus of the amygdala', 0.0),
#  ('the cholinergically richly innervated basolateral nucleus', 0.0),
#  ('the edible mushroom agaricus bisporus lectin', 0.0),
#  ('the effects of 1 o acetylbritannilactone', 0.0),
#  ('the extensively investigate agaricus bisporus lectin', 0.0),
#  ('the fourth or adenylate binding loop', 0.0),
#  ('the present study alveolar bone loss', 0.0),
#  ('the use of antibiotic lock solutions', 0.0),
#  ('therapeutic effects of agaricus bisporus lectin', 0.0),
#  ('this family contains agaricus bisporus lectin', 0.0),
#  ('this study we found that acetylbritannilactone', 0.0),
#  ('to determine the effects of acetylbritannilactone', 0.0),
#  ('to determine the possibility of acetylbritannilactone', 0.0),
#  ('to titanium discs acid bone lysate', 0.0),
#  ('tooth mobility tm alveolar bone loss', 0.0),
#  ('two in the adenylate binding loop', 0.0),
#  ('two natural sesquiterpenes 1 o acetylbritannilactone', 0.0),
#  ('use as therapy for osteoporosis abaloparatide', 0.0),
#  ('use to assessed alveolar bone loss', 0.0),
#  ('use turbidimetric immunoassay alveolar bone loss', 0.0),
#  ('very center of the basolateral nucleus', 0.0),
#  ('vitamin e on alveolar bone loss', 0.0),
#  ('vitro impact of acid bone lysate', 0.0),
#  ('volume b vertical alveolar bone loss', 0.0),
#  ('was heavily dependent on stimulus level', 0.0),
#  ('we use apoptotic body like liposomes', 0.0),
#  ('well as abelson tyrosine protein kinase', 0.0),
#  ('were exposed to acid bone lysate', 0.0),
#  ('with activated jak stat abelson kinase', 0.0),
#  ('αd helix differ to abelson kinase', 0.0),
#  ('1 level higher linear alveolar bone loss', 0.0),
#  ('267 by the abelson tyrosine kinase 1', 0.0),
#  ('3 segment of the abelson leukemia virus', 0.0),
#  ('4000 males b average sleep bout length', 0.0),
#  ('4nqo in the spontaneous alveolar bone loss', 0.0),
#  ('5 amino 5 deoxycellobiono 1 5 lactam', 0.0),
#  ('7 7a hexahydrobenzofuran 5 yl pentyl acetate', 0.0),
#  ('744deletiona is the most common mutation abetalipoproteinaemia', 0.0),
#  ('a 3d fibrin gel assay the abelson', 0.0),
#  ('a fungal antimitogenic lectin from agaricus bisporus', 0.0),
#  ('abelson murine leukemia viral oncogene homolog 1', 0.0),
#  ('accelerated horizontal and vertical alveolar bone loss', 0.0),
#  ('adsorbs to titanium discs acid bone lysate', 0.0),
#  ('after ligature application the alveolar bone loss', 0.0),
#  ('against asialoglycophorin showed that agaricus bisporus lectin', 0.0),
#  ('also been reported in rat basolateral amygdala', 0.0),
#  ('also support our finding 1 o acetylbritannilactone', 0.0),
#  ('analysis use turbidimetric immunoassay alveolar bone loss', 0.0),
#  ('and apolipoproteins within the plasma compartment abetalipoproteinemia',
#   0.0),
#  ('and oral panoramic radiographs alveolar bone loss', 0.0),
#  ('and selection class of aza β lactam', 0.0),
#  ('and two in the adenylate binding loop', 0.0),
#  ('and αd helix differ to abelson kinase', 0.0),
#  ('anti inflammatory activated compound 1 o acetylbritannilactone', 0.0),
#  ('anti inflammatory effects of 1 o acetylbritannilatone', 0.0),
#  ('as well as abelson tyrosine protein kinase', 0.0),
#  ('associated with activated jak stat abelson kinase', 0.0),
#  ('at 63 ° c for 45 s', 0.0),
#  ('at 72 ° c for 1 min', 0.0),
#  ('attachment loss cal and alveolar bone loss', 0.0),
#  ('band q11 with the abelson murine leukemia', 0.0),
#  ('bcr gene and the abelson tyrosine kinase', 0.0),
#  ('bcr on chromosome 22 and the abelson', 0.0),
#  ('binding protein for example agaricus bisporus lectin', 0.0),
#  ('blood leukocytes cbl and adult blood leukocytes', 0.0),
#  ('bone volume b vertical alveolar bone loss', 0.0),
#  ('by src family kinase sfks and abelson', 0.0),
#  ('camptothecin 4 and vinca alkaloids 14 acetylbritannilactone', 0.0),
#  ('cardiovascular side effects 18 19 20 acetylbritannilactone', 0.0),
#  ('cell increase il11 upon acid bone lysate', 0.0),
#  ('cholesterol enriched diet on alveolar bone loss', 0.0),
#  ('city heart study mean alveolar bone level', 0.0),
#  ('communis agglutinin rca and abrus precatorius lectin', 0.0),
#  ('concentrations nmollml in five patients with abetalipoproteinemia', 0.0),
#  ('defleshed morphometric analysis of alveolar bone loss', 0.0),
#  ('density lipoproteins ldl c 1 2 abetalipoproteinemia', 0.0),
#  ('dependent caspase mediate pathway 1 o acetylbritannilactone', 0.0),
#  ('described the use of antibiotic lock solutions', 0.0),
#  ('designed to determine the effects of acetylbritannilactone', 0.0),
#  ('designed to determine the possibility of acetylbritannilactone', 0.0),
#  ('determine the effects of 1 o acetylbritannilactone', 0.0),
#  ('directed abelson murine leukemia viral oncogene homolog', 0.0),
#  ('discs were exposed to acid bone lysate', 0.0),
#  ('duration and b average sleep bout length', 0.0),
#  ('duration and c average sleep bout length', 0.0),
#  ('duration and or average sleep bout length', 0.0),
#  ('effects of myricetin on alveolar bone loss', 0.0),
#  ('electrolytic lesions of the baso lateral nucleus', 0.0),
#  ('estimated blood loss and actual blood loss', 0.0),
#  ('et allatherosclerosis 108 1994 27 37 lipoproteinemia', 0.0),
#  ('for micro ct analysis alveolar bone loss', 0.0),
#  ('form of inhibit in the basolateral amygdala', 0.0),
#  ('gi tooth mobility tm alveolar bone loss', 0.0),
#  ('group the amount of alveolar bone loss', 0.0),
#  ('have previous reported on acid bone lysate', 0.0),
#  ('here we use apoptotic body like liposomes', 0.0),
#  ('heterogeneity and af recurrence after catheter ablation', 0.0),
#  ('homologue pten breakpoint cluster region bcr abelson', 0.0),
#  ('hormone gh release when the basolateral amygdala', 0.0),
#  ('hplc a bisporus abs and a brasiliensis', 0.0),
#  ('imatinib an inhibitor of ableson family kinase', 0.0),
#  ('imatinib inhibit the normal abelson tyrosine kinase', 0.0),
#  ('in rat dopamine da and basolateral amygdala', 0.0),
#  ('in the present study alveolar bone loss', 0.0),
#  ('in this study we found that acetylbritannilactone', 0.0),
#  ('in use as therapy for osteoporosis abaloparatide', 0.0),
#  ('in vitro impact of acid bone lysate', 0.0),
#  ('include a beta blocker bbl alpha blocker', 0.0),
#  ('include subcortical region such as basolateral amygdala', 0.0),
#  ('induction of periodontitis the alveolar bone loss', 0.0),
#  ('influence of edible mushroom agaricus bisporus lectin', 0.0),
#  ('information is present in ampc beta lactamase', 0.0),
#  ('inhibit break point cluster region bcr abelson', 0.0),
#  ('k d ranging from 0 16 microm', 0.0),
#  ('lactamase esbl production and ampc beta lactamase', 0.0),
#  ('ldl cholesterol ldl c level in abetalipoproteinemia', 0.0),
#  ('lectin isolated from the mushroom agaricus bisporus', 0.0),
#  ('lectin of the edible mushroom agaricus bisporus', 0.0),
#  ('lectin the edible mushroom agaricus bisporus lectin', 0.0),
#  ('lesions cen tered in the basolateral nucleus', 0.0),
#  ('mouse model exhibits severe alveolar bone loss', 0.0),
#  ('obtained two natural sesquiterpenes 1 o acetylbritannilactone', 0.0),
#  ('of a1 neurons dependent on stimulus level', 0.0),
#  ('of an edible mushroom agaricus bisporus lectin', 0.0),
#  ('of ddx3x bearing an atp binding loop', 0.0),
#  ('of drosha the abelson tyrosine kinase 1', 0.0),
#  ('of human blood platelet 17 20 abetalipoproteinemia', 0.0),
#  ('of the basolateral nucleus of the amygdala', 0.0),
#  ('of vitamin e on alveolar bone loss', 0.0),
#  ('off b and average sleep bout length', 0.0),
#  ('off c and average sleep bout length', 0.0),
#  ('on chromosome 22 and the abelson oncogene', 0.0),
#  ('on lipopolysaccharide lps induced alveolar bone loss', 0.0),
#  ('on the 30th day alveolar bone loss', 0.0),
#  ('or the cholinergically richly innervated basolateral nucleus', 0.0),
#  ('pathogenesis of periodontitis induced alveolar bone loss', 0.0),
#  ('present this family contains agaricus bisporus lectin', 0.0),
#  ('preventing retinal degeneration in patients with abetalipoproteinaemia',
#   0.0),
#  ('pri mirna the abelson tyrosine kinase 1', 0.0),
#  ('primary interaction between purified agaricus bisporus lectin', 0.0),
#  ('proinflammatory cytokines level apoptosis alveolar bone loss', 0.0),
#  ('proto oncogene 1 non receptor tyrosine kinase', 0.0),
#  ('pten and breakpoint cluster region bcr abelson', 0.0),
#  ('rate of < 15 1 o acetylbritannilactone', 0.0),
#  ('reaction moreover the area of bone loss', 0.0),
#  ('receiv no pharmacological treatment alveolar bone loss', 0.0),
#  ('regulated stress response to elevated lipids abetalipoproteinemia', 0.0),
#  ('restoration of sinus rhythm by catheter ablation', 0.0),
#  ('sacrificed after 7 day alveolar bone loss', 0.0),
#  ('sensitivity was heavily dependent on stimulus level', 0.0),
#  ('shown in blue the adenylate binding loop', 0.0),
#  ('signaling and modulating angiogenesis 1 o acetylbritannilactone', 0.0),
#  ('sleep duration c average sleep bout length', 0.0),
#  ('software program the vertical alveolar bone loss', 0.0),
#  ('src abelson murine leukemia viral oncogene homolog', 0.0),
#  ('stress index osi and alveolar bone loss', 0.0),
#  ('strontium ranelate sr on alveolar bone loss', 0.0),
#  ('structure the fourth or adenylate binding loop', 0.0),
#  ('suitable bone anabolic agent for osteoporosis abaloparatide', 0.0),
#  ('survival rate were monitored alveolar bone loss', 0.0),
#  ('systemic administered rosuvastatin on alveolar bone loss', 0.0),
#  ('targeted at breakpoint cluster region abelson kinase', 0.0),
#  ('that a lectin from agaricus bisporus mushroom', 0.0),
#  ('the adoptive transfer of activated b lymphoblastic', 0.0),
#  ('the dimethylamino to the ring ic 50', 0.0),
#  ('the expression of inflammatory cytokines and acetylbritannilactone', 0.0),
#  ('the immediate early ampk or early late', 0.0),
#  ('the investigate syrian population alveolar bone loss', 0.0),
#  ('the mean value of alveolar bone loss', 0.0),
#  ('the numerical expansion of antigen binding lymphocytes', 0.0),
#  ('the potential effects of 1 o acetylbritannilactone', 0.0),
#  ('the therapeutic effects of agaricus bisporus lectin', 0.0),
#  ('the very center of the basolateral nucleus', 0.0),
#  ('therapeutic schedule however the abl proto oncogene', 0.0),
#  ('these alleles a average sleep bout length', 0.0),
#  ('to evaluate if the a brasiliensis extract', 0.0),
#  ('to investigate the protective effects of acetylbritannilactone', 0.0),
#  ('to the extensively investigate agaricus bisporus lectin', 0.0),
#  ('tomography micro ct for alveolar bone loss', 0.0),
#  ('transforming oncogene of the abelson murine leukemia', 0.0),
#  ('translocation of 3 sequence from c abelson', 0.0),
#  ('uc aqueous extract of b gymnorrhiza leaves', 0.0),
#  ('viability is maintained upon acid bone lysate', 0.0),
#  ('was found that in acute blood loss', 0.0),
#  ('was study in five patients with abetalipoproteinemia', 0.0),
#  ('was test use the average binaural level', 0.0),
#  ('we can also mention agaricus bisporus lectin', 0.0),
#  ('we define as the atp binding loop', 0.0),
#  ('well as incidence of antigen binding lymphocytes', 0.0),
#  ('were determine in a patients with abetalipoproteinemia', 0.0),
#  ('were grown with or without the lectin', 0.0),
#  ...]

# %%
odd = top[11][0]

# %%
odd
# Out:
# 'basolateral amygdala'

# %%
grounder.ground('1-O-Acetylbritannilactone')
# Out:
# []

# %%
longforms0 = miners['ABL'].get_longforms()

# %%
longforms0
# Out:
# [('alveolar bone loss', 34, 0.8399940091612061),
#  ('acetylbritannilactone', 17, 0.5634141862971518),
#  ('agaricus bisporus lectin', 12, 0.7566427025585514),
#  ('abetalipoproteinemia', 10, 0.6989512039226189),
#  ('average sleep bout length', 10, 0.6826730608584346),
#  ('abelson', 9, 0.7306272408509953),
#  ('acid bone lysate', 6, 0.7790157542358851),
#  ('basolateral amygdala', 5, 0.7084951552942763),
#  ('agaricus bisporus', 5, 0.6466115592082996),
#  ('ablation', 3, 0.8723476565530921),
#  ('abaloparatide', 3, 0.8686623494967154),
#  ('adenylate binding loop', 3, 0.7984818687850783),
#  ('abetalipoproteinaemia', 3, 0.7781069647142249),
#  ('abelson kinase', 3, 0.49027361512639545),
#  ('antigen binding lymphocytes', 2, 1.0),
#  ('ampc beta lactamase', 2, 0.9048374180359595),
#  ('atp binding loop', 2, 0.7866278610665535),
#  ('activated b lymphoblastic', 1, 1.0),
#  ('adult blood leukocytes', 1, 1.0),
#  ('alpha blocker', 1, 1.0),
#  ('apoptotic body like liposomes', 1, 0.8913012289830017),
#  ('acetyl britannilactone', 1, 0.8572052992258644),
#  ('abs and a brasiliensis', 1, 0.8377268532794314),
#  ('antibiotic lock solutions', 1, 0.782864417001273),
#  ('b gymnorrhiza leaves', 1, 0.7448500611341166),
#  ('alveolar bone level', 1, 0.7235009788392561),
#  ('average binaural level', 1, 0.7235009788392561),
#  ('acetylbritannilatone', 1, 0.6801408126271837),
#  ('a brasiliensis extract', 1, 0.6363863767315654),
#  ('actual blood loss', 1, 0.6062140916328997),
#  ('acute blood loss', 1, 0.6062140916328997),
#  ('abrus precatorius lectin', 1, 0.5198377987326196),
#  ('baso lateral nucleus', 1, 0.4389243895099773),
#  ('pentyl acetate', 1, 0.36180997363261536),
#  ('ableson family kinase', 1, 0.2790552539259604)]

# %%
from adeft.ground import AdeftGrounder

# %%
grounder = AdeftGrounder()

# %%
groundings = [(longform, grounder.ground(longform)) for longform, _, _ in longforms0]

# %%
groundings
# Out:
# [('alveolar bone loss',
#   [{'name_space': 'MESH',
#     'id': 'D016301',
#     'canonical_name': 'Alveolar Bone Loss',
#     'type': 'name',
#     'raw_text': 'Alveolar Bone Loss',
#     'longform_text': 'alveolar bone loss',
#     'score': (1.0, 2)}]),
#  ('acetylbritannilactone', []),
#  ('agaricus bisporus lectin', []),
#  ('abetalipoproteinemia',
#   [{'name_space': 'MESH',
#     'id': 'D000012',
#     'canonical_name': 'Abetalipoproteinemia',
#     'type': 'name',
#     'raw_text': 'Abetalipoproteinemia',
#     'longform_text': 'abetalipoproteinemia',
#     'score': (1.0, 2)}]),
#  ('average sleep bout length', []),
#  ('abelson', []),
#  ('acid bone lysate', []),
#  ('basolateral amygdala',
#   [{'name_space': 'MESH',
#     'id': 'D000679',
#     'canonical_name': 'Amygdala',
#     'type': 'name',
#     'raw_text': 'Amygdala',
#     'longform_text': 'amygdala',
#     'score': (1.0, 2)}]),
#  ('agaricus bisporus', []),
#  ('ablation', []),
#  ('abaloparatide', []),
#  ('adenylate binding loop', []),
#  ('abetalipoproteinaemia', []),
#  ('abelson kinase', []),
#  ('antigen binding lymphocytes',
#   [{'name_space': 'MESH',
#     'id': 'D008214',
#     'canonical_name': 'Lymphocytes',
#     'type': 'name',
#     'raw_text': 'Lymphocytes',
#     'longform_text': 'lymphocytes',
#     'score': (1.0, 2)}]),
#  ('ampc beta lactamase', []),
#  ('atp binding loop', []),
#  ('activated b lymphoblastic', []),
#  ('adult blood leukocytes',
#   [{'name_space': 'MESH',
#     'id': 'D007962',
#     'canonical_name': 'Leukocytes',
#     'type': 'name',
#     'raw_text': 'Leukocytes',
#     'longform_text': 'leukocytes',
#     'score': (1.0, 2)}]),
#  ('alpha blocker', []),
#  ('apoptotic body like liposomes',
#   [{'name_space': 'MESH',
#     'id': 'D008081',
#     'canonical_name': 'Liposomes',
#     'type': 'assertion',
#     'raw_text': 'liposomes',
#     'longform_text': 'liposomes',
#     'score': (1.0, 3)}]),
#  ('acetyl britannilactone', []),
#  ('abs and a brasiliensis', []),
#  ('antibiotic lock solutions',
#   [{'name_space': 'MESH',
#     'id': 'D012996',
#     'canonical_name': 'Solutions',
#     'type': 'name',
#     'raw_text': 'Solutions',
#     'longform_text': 'solutions',
#     'score': (1.0, 2)}]),
#  ('b gymnorrhiza leaves', []),
#  ('alveolar bone level', []),
#  ('average binaural level', []),
#  ('acetylbritannilatone', []),
#  ('a brasiliensis extract', []),
#  ('actual blood loss', []),
#  ('acute blood loss', []),
#  ('abrus precatorius lectin', []),
#  ('baso lateral nucleus',
#   [{'name_space': 'GO',
#     'id': 'GO:0005634',
#     'canonical_name': 'nucleus',
#     'type': 'name',
#     'raw_text': 'nucleus',
#     'longform_text': 'nucleus',
#     'score': (1.0, 2)},
#    {'name_space': 'CHEBI',
#     'id': 'CHEBI:33252',
#     'canonical_name': 'atomic nucleus',
#     'type': 'synonym',
#     'raw_text': 'nucleus',
#     'longform_text': 'nucleus',
#     'score': (1.0, 1)}]),
#  ('pentyl acetate',
#   [{'name_space': 'CHEBI',
#     'id': 'CHEBI:87362',
#     'canonical_name': 'pentyl acetate',
#     'type': 'name',
#     'raw_text': 'pentyl acetate',
#     'longform_text': 'pentyl acetate',
#     'score': (1.0, 2)}]),
#  ('ableson family kinase', [])]

# %%
g = [x for x in groundings if x[1] and len(x[1][0]['longform_text'].split()) == len(x[0].split())]

# %%
g
# Out:
# [('alveolar bone loss',
#   [{'name_space': 'MESH',
#     'id': 'D016301',
#     'canonical_name': 'Alveolar Bone Loss',
#     'type': 'name',
#     'raw_text': 'Alveolar Bone Loss',
#     'longform_text': 'alveolar bone loss',
#     'score': (1.0, 2)}]),
#  ('abetalipoproteinemia',
#   [{'name_space': 'MESH',
#     'id': 'D000012',
#     'canonical_name': 'Abetalipoproteinemia',
#     'type': 'name',
#     'raw_text': 'Abetalipoproteinemia',
#     'longform_text': 'abetalipoproteinemia',
#     'score': (1.0, 2)}]),
#  ('pentyl acetate',
#   [{'name_space': 'CHEBI',
#     'id': 'CHEBI:87362',
#     'canonical_name': 'pentyl acetate',
#     'type': 'name',
#     'raw_text': 'pentyl acetate',
#     'longform_text': 'pentyl acetate',
#     'score': (1.0, 2)}])]

# %%
longforms = [x for i, x in enumerate(longforms0) if i not in [2, 6, 7]]

# %%
# !pip install python-levenshtein
# Out:
# Collecting python-levenshtein
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 3.8MB/s eta 0:00:011
# Requirement already satisfied: setuptools in /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages (from python-levenshtein) (42.0.2)
# Building wheels for collected packages: python-levenshtein
#   Building wheel for python-levenshtein (setup.py) ... done
#   Created wheel for python-levenshtein: filename=python_Levenshtein-0.12.0-cp37-cp37m-macosx_10_14_x86_64.whl size=79615 sha256=baa8c609eaeb0375accda8cf76335deb18f5e20b04561fb4c6faeb62b716829e
#   Stored in directory: /Users/albertsteppi/Library/Caches/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-levenshtein
# Installing collected packages: python-levenshtein
# Successfully installed python-levenshtein-0.12.0
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
top[29]
# Out:
# ('octadecenyl 2 acetylglycerol', 1.0)

# %%
longforms.extend([top[4], top[11], top[17], top[29]])

# %%
longforms.sort(key=lambda x: -x[1])

# %%
longforms
# Out:
# [('electroantennogram', 50.84313725490196),
#  ('electroantennography', 9.833333333333332),
#  ('ethanol extract of angelica gigas', 7.833333333333333),
#  ('ether a go go', 7.8),
#  ('electroantennographic', 5.714285714285714),
#  ('experimental autoimmune glomerulonephritis', 4.0),
#  ('ether à go go', 3.6),
#  ('experimental autoimmune gastritis', 2),
#  ('1 o hexadecyl 2 acetylglycerol', 2.0),
#  ('octadecenyl 2 acetylglycerol', 1.0)]

# %%
longforms, scores = zip(*longforms)

# %%
grounding_map = {}
for longform in longforms:
    grounding = gilda_ground(longform)
    if grounding[0]:
        grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-de4c99b23a41> in <module>
#       1 grounding_map = {}
#       2 for longform in longforms:
# ----> 3     grounding = gilda_ground(longform)
#       4     if grounding[0]:
#       5         grounding_map[longform] = f'{grounding[0]}:{grounding[1]}'
#
# ~/adeft_indra/adeft_indra/ground.py in gilda_ground(agent_text)
#      23                              json={'text': agent_text})
#      24     if response.status_code != 200:
# ---> 25         raise RuntimeError(f'Received response with code'
#      26                            '{response.status_code}')
#      27     result = response.json()
#
# RuntimeError: Received response with code{response.status_code}

# %%
grounding_map
# Out:
# {}

# %%
grounding_map, names, pos_labels = ground_with_gui(longforms, scores, grounding_map=grounding_map)

# %%
result = (grounding_map, names, pos_labels)

# %%
result
# Out:
# ({'1 o hexadecyl 2 acetylglycerol': 'CHEBI:75882',
#   'electroantennogram': 'electroantennogram',
#   'electroantennographic': 'electroantennogram',
#   'electroantennography': 'electroantennogram',
#   'ethanol extract of angelica gigas': 'ungrounded',
#   'ether a go go': 'FPLX:KCNH',
#   'ether à go go': 'FPLX:KCNH',
#   'experimental autoimmune gastritis': 'ungrounded',
#   'experimental autoimmune glomerulonephritis': 'ungrounded',
#   'octadecenyl 2 acetylglycerol': 'CHEBI:75882'},
#  {'CHEBI:75882': '1-alkyl-2-acetylglycerol',
#   'electroantennogram': 'electroantennogram',
#   'FPLX:KCNH': 'KCNH'},
#  ['CHEBI:75882', 'FPLX:KCNH'])

# %%
grounding_map, names, pos_labels = ({'1 o hexadecyl 2 acetylglycerol': 'CHEBI:75882',
      'electroantennogram': 'electroantennogram',
      'electroantennographic': 'electroantennogram',
      'electroantennography': 'electroantennogram',
      'ethanol extract of angelica gigas': 'ungrounded',
      'ether a go go': 'FPLX:KCNH',
      'ether à go go': 'FPLX:KCNH',
      'experimental autoimmune gastritis': 'ungrounded',
      'experimental autoimmune glomerulonephritis': 'ungrounded',
      'octadecenyl 2 acetylglycerol': 'CHEBI:75882'},
     {'CHEBI:75882': '1-alkyl-2-acetylglycerol',
      'electroantennogram': 'electroantennogram',
      'FPLX:KCNH': 'KCNH'},
     ['CHEBI:75882', 'FPLX:KCNH'])

# %%
grounding_dict = {'EAG': grounding_map}

# %%
classifier = AdeftClassifier('EAG', pos_labels=pos_labels)

# %%
param_grid = {'C': [10.0, 100.0], 'max_features': [1000, 10000]}

# %%
labeler = AdeftLabeler(grounding_dict)

# %%
corpus = labeler.build_from_texts(shortform_texts)

# %%
corpus.extend(entrez_texts)

# %%
texts, labels = zip(*corpus)

# %%
classifier.cv(texts, labels, param_grid, cv=5, n_jobs=8)
# Out:
# INFO: [2019-12-19 13:28:29] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Beginning grid search in parameter space:
# {'C': [10.0, 100.0], 'max_features': [1000, 10000]}
# /Users/albertsteppi/.virtualenvs/py37/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# INFO: [2019-12-19 13:30:33] /Users/albertsteppi/adeft/adeft/modeling/classify.py - Best f1 score of 0.99 found for parameter values:
# {'logit__C': 100.0, 'tfidf__max_features': 1000}

# %%
classifier.stats
# Out:
# {'label_distribution': {'electroantennogram': 55,
#   'FPLX:KCNH': 92,
#   'ungrounded': 11,
#   'CHEBI:75882': 3},
#  'f1': {'mean': 0.9740682788051209, 'std': 0.015838198371254553},
#  'precision': {'mean': 0.9589750692520773, 'std': 0.020548042527284788},
#  'recall': {'mean': 0.99, 'std': 0.020000000000000018}}

# %%
disamb = AdeftDisambiguator(classifier, grounding_dict, names)

# %%
d = disamb.disambiguate(shortform_texts)

# %%
a = [text for pred, text in zip(d, shortform_texts)if pred[0] == 'electroantennogram']

# %%
a[1]
# Out:
# "The dual roles of CRY as a photoreceptor and a clock component are well-demonstrated in Malpighian tubules (MT) (Stanewsky et al.,  1998 ; Ivanchenko et al.,  2001 ). In this organ, a light pulse given during the subjective night induces the degradation of TIM, resulting in a reset of the phase of circadian oscillation. Light-induced TIM degradation was eliminated in  cry b , hypomorphic mutants lacking functional CRY. In addition, the PER and TIM oscillations in the MT disappeared in  cry b  mutants (Stanewsky et al.,  1998 ; Ivanchenko et al.,  2001 ). These studies suggest that CRY has roles both in light entrainment and in the molecular oscillatory machinery of the clock. Another example is the antenna. Its response to odorants, as measured by an electroantennogram (EAG), increases at night and decreases during the day under light-dark (LD) cycles (Krishnan et al.,  1999 ). The olfactory EAG rhythm is driven by a peripheral circadian clock in antennal olfactory sensory neurons, persisting under constant darkness (DD) (Krishnan et al.,  1999 ; Tanoue et al.,  2004 ). The rhythm is based on the molecular oscillatory mechanism and is abolished in  per  and  tim  null mutants (Krishnan et al.,  1999 ). The circadian rhythms in olfactory EAG responses and clock gene expressions were both eliminated in  cry b  mutant flies (Stanewsky et al.,  1998 ; Krishnan et al.,  2001 ). One might argue that the loss of rhythm is derived from desynchronization among constituent clock cells caused by a loss of photic entrainability. However, it is more likely that CRY serves as an essential component for the oscillatory machinery (Krishnan et al.,  2001 ; Levine et al.,  2002 ; Collins et al.,  2006 ). CRY may function as a transcriptional repressor together with PER, because overexpression of  cry  and  per  repressed CLK-CYC activity in the compound eyes. The function of CRY as a transcriptional repressor was also confirmed in cultured cells (Collins et al.,  2006 ). Thus, CRY's repressor activity explains why most peripheral clocks lose their oscillation in  cry b  mutants (Levine et al.,  2002 ).\n"

# %%
disamb.dump('MED', '../results')

# %%
from adeft.disambiguate import load_disambiguator

# %%
d = load_disambiguator('HIR', '../results')

# %%
d.disambiguate(texts[0])
# Out:
# ('HGNC:6091',
#  'INSR',
#  {'HGNC:6091': 0.9495047219792215,
#   'MESH:D015427': 0.03378744088190508,
#   'ungrounded': 0.016707837138873322})

# %%
a = load_disambiguator('AR')

# %%
a.disambiguate('Androgen')
# Out:
# ('HGNC:644',
#  'AR',
#  {'FPLX:ADRB': 4.719192246728643e-10,
#   'GO:GO:0007340': 1.3624879544267196e-09,
#   'HGNC:381': 5.2828214761836554e-12,
#   'HGNC:644': 0.9999384718638125,
#   'HGNC:651': 1.8656671170325e-12,
#   'ungrounded': 6.152629463170691e-05})

# %%
logit = d.classifier.estimator.named_steps['logit']

# %%
logit.classes_
# Out:
# array(['FPLX:AQP', 'FPLX:Macrophage_inflammatory_pro', 'MESH:D000072277',
#        'polymer', 'ungrounded'], dtype='<U32')

# %%
model_to_s3(disamb)
